# %% [markdown]
# # Station Stacking v18 Wunderground Physics - KATL
#
# Experimental notebook for `KATL`.
#
# This v18 run keeps the v11 remaining-warmup ridge-stack backbone, requires Wunderground station-history labels, adds NBM hourly curve and HRRR/RAP physics shard features, and writes isolated artifacts to `data/calibration/station_stacking_v18`.

# %%
from pathlib import Path
import os
import sys
import warnings

warnings.filterwarnings("ignore", message="IProgress not found.*")
warnings.filterwarnings("ignore", message="Skipping features without any observed values.*")

PROJECT_ROOT = Path.cwd().resolve()
while not (PROJECT_ROOT / "src" / "calibration" / "station_stacking.py").exists():
    if PROJECT_ROOT.parent == PROJECT_ROOT:
        raise RuntimeError("Could not find project root containing src/calibration/station_stacking.py")
    PROJECT_ROOT = PROJECT_ROOT.parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

os.environ["WEATHER_RESEARCH_INCLUDE_DIRECT_NBM"] = "1"

STATION_ID = "KATL"
PROVIDERS = ("gfs", "hrrr", "nbm")
TREND_COLUMNS = [
    "observed_temp_change_last_1h_f",
    "observed_temp_change_last_3h_f",
    "observed_morning_warmup_rate_f_per_hour",
    "observed_high_so_far_change_since_9am_f",
]
TIMING_MODE = "same_day_11am_live_safe"
FAST_MODE = False
OPTUNA_TRIALS = 100
STACK_OPTUNA_TRIALS = 100
OPTUNA_STARTUP_TRIALS = 40
STACK_OPTUNA_STARTUP_TRIALS = 40
OPTUNA_METRIC = "mae_f"
OPTUNA_VERBOSE = True
MODEL_VERSION = "station_high_regressor_v18_nbm_hrrr_physics_settlement_stack"
PROJECT_ROOT
# Out:
# WindowsPath('D:/dev/weather-research')

# %%
import numpy as np
import pandas as pd

from src.export_station_stacking_v2_models import export_station_model_weights
from src.calibration.station_stacking import (
    StationStackingConfig,
    V11_DROPPED_FEATURE_COLUMNS,
    V11_FEATURE_COLUMNS,
    YEAR_SPLIT_EXPANDING_FOLDS,
    missing_model_dependencies,
    provider_availability,
    run_station_year_split_experiment,
)

# %% [markdown]
# ## V11 Contract
#
# `feature_version="v18"` adds coverage-gated NBM hourly curve and HRRR/RAP physics features while selecting by validation MAE.

# %%
fold_spec = pd.DataFrame(
    [
        {
            "fold": fold.name,
            "train_start_year": fold.train_start_year,
            "train_end_year": fold.train_end_year,
            "validation_year": fold.validation_year,
        }
        for fold in YEAR_SPLIT_EXPANDING_FOLDS
    ]
)

fold_spec
# Out:
#                      fold  train_start_year  train_end_year  validation_year
# 0  fold_2021_2023_to_2024              2021            2023             2024
# 1  fold_2021_2024_to_2025              2021            2024             2025

# %%
V11_FEATURE_COLUMNS, sorted(V11_DROPPED_FEATURE_COLUMNS)
# Out:
# (['v2_recent_heat_anomaly_f',
#   'v2_recent_heat_momentum_f',
#   'v2_morning_warmup_to_consensus_f',
#   'v2_consensus_minus_7d_actual_f',
#   'v2_spread_per_warmup_f',
#   'v2_humidity_warmup_interaction',
#   'v3_high_so_far_above_current_f',
#   'v3_remaining_warmup_from_high_so_far_f',
#   'v3_high_so_far_minus_lag_1d_f',
#   'v3_high_so_far_minus_7d_actual_f',
#   'v3_remaining_warmup_per_spread_f',
#   'v3_humidity_remaining_warmup_interaction',
#   'v4_forecast_precip_total_mean_mm',
#   'v4_forecast_precip_total_max_mm',
#   'v4_forecast_precip_total_spread_mm',
#   'v4_forecast_precip_max_1h_mean_mm',
#   'v4_forecast_precip_hours_mean',
#   'v4_forecast_precip_intensity_mean',
#   'v4_forecast_precip_intensity_max',
#   'v4_any_forecast_precip',
#   'v4_all_forecast_precip',
#   'v4_observed_precip_any',
#   'v4_observed_precip_recent_mm_est',
#   'v4_forecast_total_minus_observed_recent_mm',
#   'v4_forecast_observed_precip_match',
#   'v4_forecast_wet_observed_dry',
#   'v4_observed_wet_forecast_dry',
#   'v4_precip_humidity_interaction',
#   'v4_precip_remaining_warmup_interaction',
#   'observed_temp_change_last_1h_f',
#   'observed_temp_change_last_3h_f',
#   'observed_morning_warmup_rate_f_per_hour',
#   'observed_high_so_far_change_since_9am_f',
#   'v8_provider_max_remaining_from_high_so_far_f',
#   'v8_provider_min_remaining_from_high_so_far_f',
#   'v8_provider_median_remaining_from_high_so_far_f',
#   'v8_provider_spread_per_remaining_warmup_f',
#   'v8_month_remaining_warmup_mean_f',
#   'v8_month_remaining_warmup_count',
#   'v8_recent_remaining_warmup_7d_mean_f',
#   'v8_recent_remaining_warmup_30d_mean_f',
#   'v8_provider_mean_remaining_vs_month_normal_f',
#   'v8_cloud_cover_mean_remaining_warmup_interaction',
#   'v8_cloud_cover_max_remaining_warmup_interaction',
#   'v8_precip_total_remaining_warmup_interaction',
#   'v8_precip_max_1h_remaining_warmup_interaction',
#   'v8_wind_speed_mean_remaining_warmup_interaction',
#   'v8_wind_gust_max_remaining_warmup_interaction',
#   'v8_forecast_dewpoint_mean_f',
#   'v8_forecast_dewpoint_depression_mean_f',
#   'v8_dewpoint_mean_remaining_warmup_interaction',
#   'v8_dewpoint_depression_remaining_warmup_interaction',
#   'climatology_high_10y_f',
#   'climatology_high_10y_std_f',
#   'climatology_high_10y_count',
#   'provider_mean_minus_climatology_10y_f',
#   'observed_temp_minus_climatology_10y_f',
#   'observed_high_so_far_minus_climatology_10y_f'],
#  ['actual_minus_climatology_10y_f_DIAGNOSTIC_ONLY',
#   'climatology_source_end_year',
#   'climatology_source_start_year',
#   'gfs_as_of_hour_local',
#   'gfs_available',
#   'gfs_forecast_window_hours',
#   'gfs_grid_dist_km_mean',
#   'gfs_horizon_hours',
#   'gfs_hrrr_grid_dist_km_mean_abs_diff_f',
#   'gfs_hrrr_grid_dist_km_mean_diff_f',
#   'gfs_issue_hour_utc',
#   'gfs_missing',
#   'hrrr_as_of_hour_local',
#   'hrrr_available',
#   'hrrr_forecast_hour_max',
#   'hrrr_forecast_hour_min',
#   'hrrr_forecast_lead_hours',
#   'hrrr_forecast_window_hours',
#   'hrrr_grid_dist_km_mean',
#   'hrrr_horizon_hours',
#   'hrrr_issue_hour_local',
#   'hrrr_issue_hour_utc',
#   'hrrr_missing',
#   'is_active_polymarket_station',
#   'lat',
#   'lon',
#   'nbm_as_of_hour_local',
#   'nbm_available',
#   'nbm_forecast_window_hours',
#   'nbm_horizon_hours',
#   'nbm_issue_hour_local',
#   'nbm_issue_hour_utc',
#   'nbm_missing',
#   'observed_fetch_status',
#   'observed_observation_type',
#   'observed_pressure_source',
#   'provider_count_available',
#   'year'])

# %% [markdown]
# ## Data Availability

# %%
availability = provider_availability(
    PROJECT_ROOT,
    timing_mode=TIMING_MODE,
    providers=PROVIDERS,
)

availability.loc[availability["station_id"].eq(STATION_ID)]
# Out:
#   station_id provider  row_count first_contract_date last_contract_date
# 0       KATL      gfs       1998          2021-01-01         2026-06-21
# 1       KATL     hrrr       1998          2021-01-01         2026-06-21
# 2       KATL      nbm       1997          2021-01-01         2026-06-21

# %% [markdown]
# ## Model Scores

# %%
missing_packages = missing_model_dependencies()
if missing_packages:
    raise ImportError(
        "Missing station-stacking ML packages: "
        + ", ".join(missing_packages)
        + ". Install them with: python -m pip install -r requirements.txt"
    )

config = StationStackingConfig(
    station_id=STATION_ID,
    project_root=PROJECT_ROOT,
    timing_mode=TIMING_MODE,
    providers=PROVIDERS,
    fast_mode=FAST_MODE,
    optuna_trials=OPTUNA_TRIALS,
    stack_optuna_trials=STACK_OPTUNA_TRIALS,
    optuna_startup_trials=OPTUNA_STARTUP_TRIALS,
    stack_optuna_startup_trials=STACK_OPTUNA_STARTUP_TRIALS,
    optuna_metric=OPTUNA_METRIC,
    optuna_verbose=OPTUNA_VERBOSE,
    feature_version="v18",
    target_mode="remaining_warmup",
    target_source="wunderground_only",
    base_model_methods=("xgboost", "lightgbm", "catboost"),
    stack_enabled=True,
    hyperparameter_space="wide_plus",
    year_split_folds=YEAR_SPLIT_EXPANDING_FOLDS,
    year_split_test_train_years=(2021, 2025),
    year_split_test_year=2026,
    output_dir=PROJECT_ROOT / "data" / "calibration" / "station_stacking_v18",
)

config.resolved_optuna_storage_path()
# Out:
# WindowsPath('D:/dev/weather-research/data/calibration/station_stacking_v18/KATL_optuna.sqlite3')

# %%
result = run_station_year_split_experiment(config)
result.scoreboard
# Out:
# [I 2026-07-10 01:57:29,617] A new study created in RDB with name: KATL_v18_remaining_warmup_base_xgboost_mae_f_wide_plus
# [I 2026-07-10 01:57:39,910] Trial 0 finished with value: 1.610519024157138 and parameters: {'n_estimators': 2278, 'learning_rate': 0.18404304074388048, 'max_depth': 9, 'min_child_weight': 2.481040974867813, 'gamma': 2.340279606636548, 'subsample': 0.4513964382185317, 'colsample_bytree': 0.3877543479093296, 'reg_alpha': 2.478071022662141, 'reg_lambda': 0.6132587025321562}. Best is trial 0 with value: 1.610519024157138.
# [I 2026-07-10 01:58:23,782] Trial 1 finished with value: 1.3645760350856062 and parameters: {'n_estimators': 4263, 'learning_rate': 0.0005682336350005583, 'max_depth': 12, 'min_child_weight': 21.368329072358772, 'gamma': 3.185086660174142, 'subsample': 0.4681862286846154, 'colsample_bytree': 0.46921293140473197, 'reg_alpha': 4.476173538513514e-07, 'reg_lambda': 0.20253776634919213}. Best is trial 1 with value: 1.3645760350856062.
# [I 2026-07-10 01:58:30,387] Trial 2 finished with value: 1.278480728482709 and parameters: {'n_estimators': 2620, 'learning_rate': 0.0030548417550612453, 'max_depth': 8, 'min_child_weight': 0.03613894271216528, 'gamma': 4.3821697280282725, 'subsample': 0.5881351981408995, 'colsample_bytree': 0.6464454897410734, 'reg_alpha': 0.26430874752361627, 'reg_lambda': 0.0018119678627933364}. Best is trial 2 with value: 1.278480728482709.
# [I 2026-07-10 01:58:34,137] Trial 3 finished with value: 1.5372293349175536 and parameters: {'n_estimators': 3110, 'learning_rate': 0.019855423553962363, 'max_depth': 1, 'min_child_weight': 2.69264691008618, 'gamma': 2.557861855309373, 'subsample': 0.39228353544043165, 'colsample_bytree': 0.9667755992146666, 'reg_alpha': 38.6887231523051, 'reg_lambda': 12.408975837016275}. Best is trial 2 with value: 1.278480728482709.
# [I 2026-07-10 01:58:55,767] Trial 4 finished with value: 1.3777048414642767 and parameters: {'n_estimators': 1862, 'learning_rate': 0.0009174536024527723, 'max_depth': 9, 'min_child_weight': 0.5762487216478605, 'gamma': 1.8305735226716824, 'subsample': 0.6718649915723256, 'colsample_bytree': 0.37235253872489193, 'reg_alpha': 8.162906555194692, 'reg_lambda': 0.004271500153828077}. Best is trial 2 with value: 1.278480728482709.
# [I 2026-07-10 01:59:20,422] Trial 5 finished with value: 1.3913886970380165 and parameters: {'n_estimators': 3992, 'learning_rate': 0.0034695156333098714, 'max_depth': 7, 'min_child_weight': 1.5375920235481764, 'gamma': 2.7728168328829055, 'subsample': 0.980230008046963, 'colsample_bytree': 0.8538363351847245, 'reg_alpha': 18.792618557420877, 'reg_lambda': 43.484449457612314}. Best is trial 2 with value: 1.278480728482709.
# [I 2026-07-10 01:59:21,808] Trial 6 finished with value: 1.2767185329043738 and parameters: {'n_estimators': 3608, 'learning_rate': 0.15384412371507689, 'max_depth': 2, 'min_child_weight': 0.06080390190296603, 'gamma': 0.678409333658071, 'subsample': 0.5614647149961218, 'colsample_bytree': 0.6026402382981633, 'reg_alpha': 1.8037999945880162e-07, 'reg_lambda': 16.668629892722056}. Best is trial 6 with value: 1.2767185329043738.
# [I 2026-07-10 01:59:24,515] Trial 7 pruned.
# [I 2026-07-10 01:59:25,167] Trial 8 pruned.
# [I 2026-07-10 01:59:33,468] Trial 9 finished with value: 1.2874702807259024 and parameters: {'n_estimators': 3759, 'learning_rate': 0.003908893589205689, 'max_depth': 1, 'min_child_weight': 0.17535949529764422, 'gamma': 4.877749830401205, 'subsample': 0.8242440159197416, 'colsample_bytree': 0.7644123563808884, 'reg_alpha': 4.4315220126915325, 'reg_lambda': 0.09450187118503514}. Best is trial 6 with value: 1.2767185329043738.
# [I 2026-07-10 01:59:34,224] Trial 10 pruned.
# [I 2026-07-10 01:59:39,674] Trial 11 pruned.
# [I 2026-07-10 01:59:44,736] Trial 12 pruned.
# [I 2026-07-10 01:59:45,877] Trial 13 finished with value: 1.32014620454983 and parameters: {'n_estimators': 1160, 'learning_rate': 0.12822123876714564, 'max_depth': 7, 'min_child_weight': 16.973078532467014, 'gamma': 13.4413694988524, 'subsample': 0.5567022587317115, 'colsample_bytree': 0.4215337509429899, 'reg_alpha': 5.435280359192946e-08, 'reg_lambda': 0.049115547267693904}. Best is trial 6 with value: 1.2767185329043738.
# [I 2026-07-10 01:59:47,432] Trial 14 finished with value: 1.312296223028503 and parameters: {'n_estimators': 4918, 'learning_rate': 0.10520976010930978, 'max_depth': 1, 'min_child_weight': 1.1040511903162256, 'gamma': 6.261165047231685, 'subsample': 0.49437007680597467, 'colsample_bytree': 0.4279124887668938, 'reg_alpha': 1.125594744942969e-06, 'reg_lambda': 87.35792858155622}. Best is trial 6 with value: 1.2767185329043738.
# [I 2026-07-10 01:59:48,643] Trial 15 pruned.
# [I 2026-07-10 02:00:20,598] Trial 16 finished with value: 1.2074346776140192 and parameters: {'n_estimators': 1745, 'learning_rate': 0.0006288206118124717, 'max_depth': 8, 'min_child_weight': 1.0249816559563216, 'gamma': 0.7721812687498403, 'subsample': 0.5311202017537975, 'colsample_bytree': 0.9403728258783249, 'reg_alpha': 7.494500415302305e-08, 'reg_lambda': 0.0008184401669032867}. Best is trial 16 with value: 1.2074346776140192.
# [I 2026-07-10 02:00:21,436] Trial 17 pruned.
# [I 2026-07-10 02:00:25,695] Trial 18 finished with value: 1.2779259090356296 and parameters: {'n_estimators': 3820, 'learning_rate': 0.013963998893741949, 'max_depth': 2, 'min_child_weight': 21.938654178115062, 'gamma': 4.811700974576038, 'subsample': 0.4712370317599052, 'colsample_bytree': 0.3765038420105965, 'reg_alpha': 0.0012322967930262527, 'reg_lambda': 1.859316691031827}. Best is trial 16 with value: 1.2074346776140192.
# [I 2026-07-10 02:00:26,521] Trial 19 pruned.
# [I 2026-07-10 02:00:36,169] Trial 20 pruned.
# [I 2026-07-10 02:00:39,279] Trial 21 pruned.
# [I 2026-07-10 02:00:40,547] Trial 22 pruned.
# [I 2026-07-10 02:00:55,968] Trial 23 finished with value: 1.2888460827795132 and parameters: {'n_estimators': 3998, 'learning_rate': 0.0005159778604125024, 'max_depth': 2, 'min_child_weight': 1.566517163094647, 'gamma': 10.378427965390399, 'subsample': 0.7737748186766904, 'colsample_bytree': 0.4957750511493638, 'reg_alpha': 0.03516824175268894, 'reg_lambda': 0.003125457636899047}. Best is trial 16 with value: 1.2074346776140192.
# [I 2026-07-10 02:00:57,588] Trial 24 finished with value: 1.292926673667789 and parameters: {'n_estimators': 1986, 'learning_rate': 0.051728265370804466, 'max_depth': 8, 'min_child_weight': 24.939838794891504, 'gamma': 9.86419338450515, 'subsample': 0.7194005921680565, 'colsample_bytree': 0.4108885990882601, 'reg_alpha': 2.5857684771732316e-06, 'reg_lambda': 0.0046886527972766386}. Best is trial 16 with value: 1.2074346776140192.
# [I 2026-07-10 02:00:58,783] Trial 25 finished with value: 1.303490110656735 and parameters: {'n_estimators': 1501, 'learning_rate': 0.21139577614731828, 'max_depth': 5, 'min_child_weight': 36.99867920489091, 'gamma': 9.467079389958943, 'subsample': 0.8666273473020715, 'colsample_bytree': 0.6767141105183749, 'reg_alpha': 0.0008372335350726891, 'reg_lambda': 0.12687286940538833}. Best is trial 16 with value: 1.2074346776140192.
# [I 2026-07-10 02:01:00,740] Trial 26 pruned.
# [I 2026-07-10 02:01:23,269] Trial 27 finished with value: 1.2374821712265471 and parameters: {'n_estimators': 2252, 'learning_rate': 0.0005504108022880858, 'max_depth': 12, 'min_child_weight': 0.5161032492347074, 'gamma': 14.499822285655043, 'subsample': 0.9763529851080144, 'colsample_bytree': 0.904456146053784, 'reg_alpha': 3.414968521807482e-07, 'reg_lambda': 0.026700066263292452}. Best is trial 16 with value: 1.2074346776140192.
# [I 2026-07-10 02:01:30,023] Trial 28 finished with value: 1.2477347404280579 and parameters: {'n_estimators': 5115, 'learning_rate': 0.0035837110844026934, 'max_depth': 3, 'min_child_weight': 1.687349510456895, 'gamma': 14.042321612411715, 'subsample': 0.8024193678387325, 'colsample_bytree': 0.7205397605580872, 'reg_alpha': 1.4659458394743598e-09, 'reg_lambda': 0.7502033220845526}. Best is trial 16 with value: 1.2074346776140192.
# [I 2026-07-10 02:01:55,562] Trial 29 finished with value: 1.263945424178043 and parameters: {'n_estimators': 5941, 'learning_rate': 0.001194132613025411, 'max_depth': 7, 'min_child_weight': 32.32155805617899, 'gamma': 11.111529266313067, 'subsample': 0.8030602316469242, 'colsample_bytree': 0.8066146545916211, 'reg_alpha': 2.0601261491259473e-06, 'reg_lambda': 0.007078333440672503}. Best is trial 16 with value: 1.2074346776140192.
# [I 2026-07-10 02:01:56,491] Trial 30 pruned.
# [I 2026-07-10 02:01:57,173] Trial 31 pruned.
# [I 2026-07-10 02:02:00,392] Trial 32 finished with value: 1.268215995401873 and parameters: {'n_estimators': 1755, 'learning_rate': 0.01966125573748198, 'max_depth': 1, 'min_child_weight': 0.014105638677535273, 'gamma': 12.339008409894873, 'subsample': 0.5841239169173209, 'colsample_bytree': 0.43258933322372506, 'reg_alpha': 0.0001848924258849832, 'reg_lambda': 7.108082741221897}. Best is trial 16 with value: 1.2074346776140192.
# [I 2026-07-10 02:02:03,003] Trial 33 pruned.
# [I 2026-07-10 02:02:08,104] Trial 34 pruned.
# [I 2026-07-10 02:02:09,337] Trial 35 pruned.
# [I 2026-07-10 02:02:11,091] Trial 36 finished with value: 1.2618719102717042 and parameters: {'n_estimators': 5732, 'learning_rate': 0.04903787573670302, 'max_depth': 7, 'min_child_weight': 2.7982272717049295, 'gamma': 6.2940009364168485, 'subsample': 0.5110251431757523, 'colsample_bytree': 0.58138224112332, 'reg_alpha': 0.12420907443411108, 'reg_lambda': 0.00012322357473726174}. Best is trial 16 with value: 1.2074346776140192.
# [I 2026-07-10 02:02:13,042] Trial 37 pruned.
# [I 2026-07-10 02:02:16,362] Trial 38 finished with value: 1.214379447569704 and parameters: {'n_estimators': 1080, 'learning_rate': 0.0074117812297848015, 'max_depth': 5, 'min_child_weight': 2.9067012153229124, 'gamma': 9.526404763014657, 'subsample': 0.3794476063518289, 'colsample_bytree': 0.5934981995072063, 'reg_alpha': 0.0032383142323839692, 'reg_lambda': 0.14800509200124298}. Best is trial 16 with value: 1.2074346776140192.
# [I 2026-07-10 02:02:17,731] Trial 39 pruned.
# [I 2026-07-10 02:02:57,195] Trial 40 finished with value: 1.214167618816314 and parameters: {'n_estimators': 2487, 'learning_rate': 0.0017360316408241015, 'max_depth': 6, 'min_child_weight': 1.0733810647403217, 'gamma': 13.372030886937258, 'subsample': 0.4249983991610017, 'colsample_bytree': 0.9180728722402602, 'reg_alpha': 1.3313838550339106e-08, 'reg_lambda': 0.021700147757243188}. Best is trial 16 with value: 1.2074346776140192.
# [I 2026-07-10 02:03:42,373] Trial 41 finished with value: 1.2118726347910287 and parameters: {'n_estimators': 2804, 'learning_rate': 0.0016925403713501936, 'max_depth': 6, 'min_child_weight': 0.7734714559391724, 'gamma': 14.956018049510302, 'subsample': 0.4300763075428102, 'colsample_bytree': 0.9042720235267022, 'reg_alpha': 1.1604754388001184e-08, 'reg_lambda': 0.023314110138612582}. Best is trial 16 with value: 1.2074346776140192.
# [I 2026-07-10 02:04:28,798] Trial 42 finished with value: 1.215458406728275 and parameters: {'n_estimators': 2529, 'learning_rate': 0.0014233573476129628, 'max_depth': 6, 'min_child_weight': 0.7618205814136683, 'gamma': 14.915655457689336, 'subsample': 0.43811039512119965, 'colsample_bytree': 0.9119477049816305, 'reg_alpha': 3.5803303651384616e-08, 'reg_lambda': 0.021311668950095425}. Best is trial 16 with value: 1.2074346776140192.
# [I 2026-07-10 02:05:17,507] Trial 43 finished with value: 1.2078201977790002 and parameters: {'n_estimators': 2649, 'learning_rate': 0.0016404134277253422, 'max_depth': 6, 'min_child_weight': 0.7873620068833378, 'gamma': 12.809149731542185, 'subsample': 0.4293282836633801, 'colsample_bytree': 0.9245921032618803, 'reg_alpha': 3.312356736039182e-08, 'reg_lambda': 0.018953845429366834}. Best is trial 16 with value: 1.2074346776140192.
# [I 2026-07-10 02:06:00,317] Trial 44 finished with value: 1.209898912924136 and parameters: {'n_estimators': 2802, 'learning_rate': 0.0018190421945417042, 'max_depth': 6, 'min_child_weight': 0.8647971954451943, 'gamma': 13.136716600105354, 'subsample': 0.4334774161414045, 'colsample_bytree': 0.9458506710169167, 'reg_alpha': 6.335102660926578e-09, 'reg_lambda': 0.015659073616661946}. Best is trial 16 with value: 1.2074346776140192.
# [I 2026-07-10 02:06:12,582] Trial 45 finished with value: 1.2035594572365018 and parameters: {'n_estimators': 3400, 'learning_rate': 0.0019568034978216073, 'max_depth': 6, 'min_child_weight': 0.783143104026325, 'gamma': 13.253036089935616, 'subsample': 0.43121055185581536, 'colsample_bytree': 0.9453554881425408, 'reg_alpha': 5.9000101408350975e-09, 'reg_lambda': 0.014799031105858786}. Best is trial 45 with value: 1.2035594572365018.
# [I 2026-07-10 02:06:20,463] Trial 46 finished with value: 1.2171346997302281 and parameters: {'n_estimators': 3385, 'learning_rate': 0.0023323615273259024, 'max_depth': 6, 'min_child_weight': 0.466426762645245, 'gamma': 12.610281644296437, 'subsample': 0.5241587003759987, 'colsample_bytree': 0.9536459435548018, 'reg_alpha': 3.5377799621332905e-09, 'reg_lambda': 0.013576703791679634}. Best is trial 45 with value: 1.2035594572365018.
# [I 2026-07-10 02:06:27,713] Trial 47 finished with value: 1.2026397045571575 and parameters: {'n_estimators': 2828, 'learning_rate': 0.0017016764038950997, 'max_depth': 6, 'min_child_weight': 0.78844552948852, 'gamma': 12.867922539814991, 'subsample': 0.6109253115736245, 'colsample_bytree': 0.9825547309712386, 'reg_alpha': 4.0871032233194313e-10, 'reg_lambda': 0.0013913482404626272}. Best is trial 47 with value: 1.2026397045571575.
# [I 2026-07-10 02:06:43,420] Trial 48 finished with value: 1.2254184242032256 and parameters: {'n_estimators': 3368, 'learning_rate': 0.002580405758774046, 'max_depth': 5, 'min_child_weight': 0.3407670779965146, 'gamma': 12.975107436788232, 'subsample': 0.6217018528962136, 'colsample_bytree': 0.9951241200493778, 'reg_alpha': 4.1971738454371963e-10, 'reg_lambda': 0.0009343193231566469}. Best is trial 47 with value: 1.2026397045571575.
# [I 2026-07-10 02:06:45,350] Trial 49 pruned.
# [I 2026-07-10 02:07:00,557] Trial 50 finished with value: 1.1992147171702054 and parameters: {'n_estimators': 3413, 'learning_rate': 0.002052145286118634, 'max_depth': 4, 'min_child_weight': 8.13109529059537, 'gamma': 0.22531817438530943, 'subsample': 0.608472910494863, 'colsample_bytree': 0.9742922234170419, 'reg_alpha': 6.803885413736588e-10, 'reg_lambda': 0.0022379153035570554}. Best is trial 50 with value: 1.1992147171702054.
# [I 2026-07-10 02:07:24,585] Trial 51 finished with value: 1.2039589919172693 and parameters: {'n_estimators': 3276, 'learning_rate': 0.0020463467324336937, 'max_depth': 4, 'min_child_weight': 8.81398591083758, 'gamma': 0.10154863581892618, 'subsample': 0.6151633511795236, 'colsample_bytree': 0.9370437427938375, 'reg_alpha': 7.773948134649131e-10, 'reg_lambda': 0.0019353362485819829}. Best is trial 50 with value: 1.1992147171702054.
# [I 2026-07-10 02:08:20,249] Trial 52 finished with value: 1.1975096205665554 and parameters: {'n_estimators': 3278, 'learning_rate': 0.0021588237644396594, 'max_depth': 5, 'min_child_weight': 8.972608024760497, 'gamma': 0.6058261587436105, 'subsample': 0.6201304517028453, 'colsample_bytree': 0.9827755049421107, 'reg_alpha': 5.440191698243688e-10, 'reg_lambda': 0.0013259800234024161}. Best is trial 52 with value: 1.1975096205665554.
# [I 2026-07-10 02:09:15,522] Trial 53 finished with value: 1.204882524371745 and parameters: {'n_estimators': 3441, 'learning_rate': 0.0023926894166096044, 'max_depth': 4, 'min_child_weight': 8.665262489184716, 'gamma': 0.04318000211075565, 'subsample': 0.618621422276056, 'colsample_bytree': 0.9791105024625548, 'reg_alpha': 1.1100957199770559e-10, 'reg_lambda': 0.0018174198311071534}. Best is trial 52 with value: 1.1975096205665554.
# [I 2026-07-10 02:10:04,881] Trial 54 finished with value: 1.2079785207723015 and parameters: {'n_estimators': 3495, 'learning_rate': 0.0021616074221720454, 'max_depth': 4, 'min_child_weight': 10.298734931814295, 'gamma': 0.15712634397877867, 'subsample': 0.6204418556009657, 'colsample_bytree': 0.9774728151749981, 'reg_alpha': 9.116845589607782e-10, 'reg_lambda': 0.0023415515002591955}. Best is trial 52 with value: 1.1975096205665554.
# [I 2026-07-10 02:10:36,101] Trial 55 finished with value: 1.20315330659098 and parameters: {'n_estimators': 4420, 'learning_rate': 0.005024570909678855, 'max_depth': 4, 'min_child_weight': 7.406677047280806, 'gamma': 1.4946222971928596, 'subsample': 0.6140072894354126, 'colsample_bytree': 0.9953564644503275, 'reg_alpha': 1.3746114118824655e-10, 'reg_lambda': 0.0015505301312701784}. Best is trial 52 with value: 1.1975096205665554.
# [I 2026-07-10 02:12:07,564] Trial 56 finished with value: 1.2075853412730906 and parameters: {'n_estimators': 4544, 'learning_rate': 0.004547673413639173, 'max_depth': 4, 'min_child_weight': 13.646266583174631, 'gamma': 1.683965727262397, 'subsample': 0.6391932185872093, 'colsample_bytree': 0.9947637211906167, 'reg_alpha': 3.3948077289224013e-10, 'reg_lambda': 0.0010214184681742332}. Best is trial 52 with value: 1.1975096205665554.
# [I 2026-07-10 02:13:37,734] Trial 57 finished with value: 1.1963341697544267 and parameters: {'n_estimators': 3093, 'learning_rate': 0.0011993663909115116, 'max_depth': 5, 'min_child_weight': 5.632436390753993, 'gamma': 0.9999907688896679, 'subsample': 0.6035358159567851, 'colsample_bytree': 0.8400024759571527, 'reg_alpha': 4.720555750547703e-10, 'reg_lambda': 0.0002927526591928871}. Best is trial 57 with value: 1.1963341697544267.
# [I 2026-07-10 02:15:15,091] Trial 58 finished with value: 1.1974010468132634 and parameters: {'n_estimators': 4288, 'learning_rate': 0.0011570632502766126, 'max_depth': 5, 'min_child_weight': 5.4174653581303795, 'gamma': 0.7759998901722368, 'subsample': 0.5929983668887594, 'colsample_bytree': 0.8855045498299983, 'reg_alpha': 2.3271943623899823e-10, 'reg_lambda': 0.0002484132490969225}. Best is trial 57 with value: 1.1963341697544267.
# [I 2026-07-10 02:16:25,737] Trial 59 finished with value: 1.191114529113976 and parameters: {'n_estimators': 3794, 'learning_rate': 0.0012019216206290732, 'max_depth': 5, 'min_child_weight': 4.453207046345402, 'gamma': 1.1032430434196083, 'subsample': 0.595962761139864, 'colsample_bytree': 0.8527289170747322, 'reg_alpha': 2.9801902222692954e-10, 'reg_lambda': 0.00037268032475146044}. Best is trial 59 with value: 1.191114529113976.
# [I 2026-07-10 02:16:43,002] Trial 60 finished with value: 1.1967834806038093 and parameters: {'n_estimators': 3748, 'learning_rate': 0.0011911242769337114, 'max_depth': 5, 'min_child_weight': 5.511913852767233, 'gamma': 1.0564154855255332, 'subsample': 0.5926079568492625, 'colsample_bytree': 0.8488158982934113, 'reg_alpha': 1.8935191646689956e-09, 'reg_lambda': 0.0002455245136106631}. Best is trial 59 with value: 1.191114529113976.
# [I 2026-07-10 02:17:40,600] Trial 61 finished with value: 1.1977838112898938 and parameters: {'n_estimators': 3791, 'learning_rate': 0.001141493149995543, 'max_depth': 5, 'min_child_weight': 5.2548854563981315, 'gamma': 0.7787617795983149, 'subsample': 0.58022459371447, 'colsample_bytree': 0.8401420076858003, 'reg_alpha': 3.471685041090779e-10, 'reg_lambda': 0.00024143846024222664}. Best is trial 59 with value: 1.191114529113976.
# [I 2026-07-10 02:19:40,627] Trial 62 finished with value: 1.196469135826193 and parameters: {'n_estimators': 3697, 'learning_rate': 0.0011558129666459007, 'max_depth': 5, 'min_child_weight': 5.107588283569695, 'gamma': 0.9120334974014284, 'subsample': 0.5834385242296869, 'colsample_bytree': 0.8378516770476963, 'reg_alpha': 1.825651492121393e-09, 'reg_lambda': 0.00024272199112527899}. Best is trial 59 with value: 1.191114529113976.
# [I 2026-07-10 02:20:32,799] Trial 63 finished with value: 1.1929501034276533 and parameters: {'n_estimators': 3769, 'learning_rate': 0.0013197988186579995, 'max_depth': 5, 'min_child_weight': 5.502484275822717, 'gamma': 0.9292226946631309, 'subsample': 0.557197212746792, 'colsample_bytree': 0.8457160314376369, 'reg_alpha': 2.0656520204328993e-09, 'reg_lambda': 0.00029743677172231267}. Best is trial 59 with value: 1.191114529113976.
# [I 2026-07-10 02:20:53,328] Trial 64 finished with value: 1.1960724821839457 and parameters: {'n_estimators': 4044, 'learning_rate': 0.0008627047536330783, 'max_depth': 5, 'min_child_weight': 4.654447561534572, 'gamma': 2.0790193887739212, 'subsample': 0.5474351095053613, 'colsample_bytree': 0.7890032262709096, 'reg_alpha': 2.3267455538788173e-09, 'reg_lambda': 0.0005004010474830577}. Best is trial 59 with value: 1.191114529113976.
# [I 2026-07-10 02:21:44,740] Trial 65 finished with value: 1.1928962085434944 and parameters: {'n_estimators': 4053, 'learning_rate': 0.0007225634802124411, 'max_depth': 5, 'min_child_weight': 4.459065479231847, 'gamma': 2.9789740734588586, 'subsample': 0.5585915113200705, 'colsample_bytree': 0.7967368328436019, 'reg_alpha': 2.243099263397109e-09, 'reg_lambda': 0.00046971687825376644}. Best is trial 59 with value: 1.191114529113976.
# [I 2026-07-10 02:22:12,664] Trial 66 finished with value: 1.189523136871929 and parameters: {'n_estimators': 4092, 'learning_rate': 0.0007204998271991639, 'max_depth': 5, 'min_child_weight': 3.919353958848907, 'gamma': 3.1338600756784727, 'subsample': 0.5527863020330592, 'colsample_bytree': 0.7935124600157765, 'reg_alpha': 1.986991139492284e-09, 'reg_lambda': 0.000572061372821266}. Best is trial 66 with value: 1.189523136871929.
# [I 2026-07-10 02:22:43,265] Trial 67 finished with value: 1.1853566041883017 and parameters: {'n_estimators': 4024, 'learning_rate': 0.0007325939471104987, 'max_depth': 5, 'min_child_weight': 2.3870377504657236, 'gamma': 3.0529834956292077, 'subsample': 0.5525934920036233, 'colsample_bytree': 0.7875089603062597, 'reg_alpha': 1.5395891243478234e-08, 'reg_lambda': 0.0005826585409163034}. Best is trial 67 with value: 1.1853566041883017.
# [I 2026-07-10 02:23:19,351] Trial 68 finished with value: 1.1901084850014765 and parameters: {'n_estimators': 4066, 'learning_rate': 0.0007893411756937001, 'max_depth': 5, 'min_child_weight': 3.760851504569925, 'gamma': 3.133817135484062, 'subsample': 0.5549445672802872, 'colsample_bytree': 0.7813800824998713, 'reg_alpha': 1.801418278012321e-08, 'reg_lambda': 0.0004983200621308561}. Best is trial 67 with value: 1.1853566041883017.
# [I 2026-07-10 02:23:40,976] Trial 69 pruned.
# [I 2026-07-10 02:24:38,296] Trial 70 finished with value: 1.1941521370962132 and parameters: {'n_estimators': 4671, 'learning_rate': 0.0008540629915479828, 'max_depth': 5, 'min_child_weight': 4.12182105867008, 'gamma': 2.054403401008708, 'subsample': 0.48015843680959125, 'colsample_bytree': 0.792706894138871, 'reg_alpha': 6.036279253242039e-07, 'reg_lambda': 0.00054637052326807}. Best is trial 67 with value: 1.1853566041883017.
# [I 2026-07-10 02:25:06,651] Trial 71 finished with value: 1.193170105232981 and parameters: {'n_estimators': 4539, 'learning_rate': 0.000828356908755382, 'max_depth': 5, 'min_child_weight': 3.495044407967037, 'gamma': 2.1979467380790805, 'subsample': 0.49155260763470066, 'colsample_bytree': 0.7906456758046432, 'reg_alpha': 4.9397547663234e-07, 'reg_lambda': 0.0004899281061583621}. Best is trial 67 with value: 1.1853566041883017.
# [I 2026-07-10 02:25:41,092] Trial 72 finished with value: 1.2034986318774128 and parameters: {'n_estimators': 4550, 'learning_rate': 0.0007238627567972986, 'max_depth': 4, 'min_child_weight': 3.4329227402327636, 'gamma': 3.1450905105813964, 'subsample': 0.4798674807477287, 'colsample_bytree': 0.7831933632558263, 'reg_alpha': 4.553083598613436e-07, 'reg_lambda': 0.00012740204731903737}. Best is trial 67 with value: 1.1853566041883017.
# [I 2026-07-10 02:26:30,052] Trial 73 finished with value: 1.1920944921678795 and parameters: {'n_estimators': 4253, 'learning_rate': 0.000942676779297598, 'max_depth': 5, 'min_child_weight': 2.4722803401773605, 'gamma': 4.690756124745505, 'subsample': 0.4965598923858324, 'colsample_bytree': 0.7432125024930263, 'reg_alpha': 2.665647622052024e-07, 'reg_lambda': 0.0006260465504237522}. Best is trial 67 with value: 1.1853566041883017.
# [I 2026-07-10 02:27:16,701] Trial 74 finished with value: 1.1930574470110438 and parameters: {'n_estimators': 4302, 'learning_rate': 0.0005116162700083185, 'max_depth': 6, 'min_child_weight': 2.31954629652802, 'gamma': 4.151812657264477, 'subsample': 0.49999953771037564, 'colsample_bytree': 0.7007154357547732, 'reg_alpha': 1.7514280548898548e-07, 'reg_lambda': 0.00017599406489137587}. Best is trial 67 with value: 1.1853566041883017.
# [I 2026-07-10 02:28:22,860] Trial 75 finished with value: 1.1924192572394194 and parameters: {'n_estimators': 4290, 'learning_rate': 0.0005400936566826725, 'max_depth': 6, 'min_child_weight': 1.974205793785473, 'gamma': 5.159605726001866, 'subsample': 0.5210186209507662, 'colsample_bytree': 0.6805063262159043, 'reg_alpha': 9.304869521773897e-08, 'reg_lambda': 0.0001673034772265166}. Best is trial 67 with value: 1.1853566041883017.
# [I 2026-07-10 02:29:14,802] Trial 76 finished with value: 1.1915163034786946 and parameters: {'n_estimators': 4164, 'learning_rate': 0.0009758967086848515, 'max_depth': 7, 'min_child_weight': 1.2195688366952764, 'gamma': 5.633463297993991, 'subsample': 0.562595177371247, 'colsample_bytree': 0.6255107845552468, 'reg_alpha': 7.549730447878673e-08, 'reg_lambda': 0.00010379042407809307}. Best is trial 67 with value: 1.1853566041883017.
# [I 2026-07-10 02:29:48,014] Trial 77 finished with value: 1.1845953579594521 and parameters: {'n_estimators': 3910, 'learning_rate': 0.0006264736600416557, 'max_depth': 7, 'min_child_weight': 1.4539023859853093, 'gamma': 5.436368258203391, 'subsample': 0.5254424665694799, 'colsample_bytree': 0.640479616021299, 'reg_alpha': 9.242203370280904e-08, 'reg_lambda': 0.0034250005294932666}. Best is trial 77 with value: 1.1845953579594521.
# [I 2026-07-10 02:30:26,616] Trial 78 finished with value: 1.1877091179619308 and parameters: {'n_estimators': 3897, 'learning_rate': 0.0006134308775267398, 'max_depth': 7, 'min_child_weight': 1.4093988713267815, 'gamma': 5.456888091791981, 'subsample': 0.5226181453909189, 'colsample_bytree': 0.6377453811581189, 'reg_alpha': 1.055821909931812e-05, 'reg_lambda': 0.003623185416325387}. Best is trial 77 with value: 1.1845953579594521.
# [I 2026-07-10 02:30:45,562] Trial 79 finished with value: 1.191119901980454 and parameters: {'n_estimators': 3915, 'learning_rate': 0.000976508117431694, 'max_depth': 9, 'min_child_weight': 1.3530476098125896, 'gamma': 5.690588144578456, 'subsample': 0.530052972795962, 'colsample_bytree': 0.6308563008262122, 'reg_alpha': 1.4757514655959682e-05, 'reg_lambda': 0.003988207511871227}. Best is trial 77 with value: 1.1845953579594521.
# [I 2026-07-10 02:31:17,750] Trial 80 finished with value: 1.1782826054025581 and parameters: {'n_estimators': 3869, 'learning_rate': 0.0006244172103604893, 'max_depth': 9, 'min_child_weight': 1.2755438056214836, 'gamma': 5.477980832748351, 'subsample': 0.45497470137836715, 'colsample_bytree': 0.6336938763565254, 'reg_alpha': 1.5862197594247325e-05, 'reg_lambda': 0.00911229885311687}. Best is trial 80 with value: 1.1782826054025581.
# [I 2026-07-10 02:31:48,390] Trial 81 finished with value: 1.1871917457690484 and parameters: {'n_estimators': 3944, 'learning_rate': 0.0006222176920443551, 'max_depth': 9, 'min_child_weight': 1.4012108545502884, 'gamma': 5.5651663705906085, 'subsample': 0.45149519380169334, 'colsample_bytree': 0.6285386909829395, 'reg_alpha': 7.750773991347837e-06, 'reg_lambda': 0.009787742005510492}. Best is trial 80 with value: 1.1782826054025581.
# [I 2026-07-10 02:32:16,771] Trial 82 finished with value: 1.1890124546645344 and parameters: {'n_estimators': 3923, 'learning_rate': 0.0005981424502518016, 'max_depth': 9, 'min_child_weight': 1.310194458220326, 'gamma': 6.920469816804076, 'subsample': 0.5315459874754188, 'colsample_bytree': 0.649099398246989, 'reg_alpha': 7.573760886651996e-06, 'reg_lambda': 0.0037199186049810006}. Best is trial 80 with value: 1.1782826054025581.
# [I 2026-07-10 02:32:44,406] Trial 83 finished with value: 1.1939817576118619 and parameters: {'n_estimators': 3637, 'learning_rate': 0.0006002466396541831, 'max_depth': 10, 'min_child_weight': 1.5199867112957608, 'gamma': 6.870427305001856, 'subsample': 0.4523561950732424, 'colsample_bytree': 0.6556806483112357, 'reg_alpha': 5.5607178412832235e-05, 'reg_lambda': 0.009474528089807055}. Best is trial 80 with value: 1.1782826054025581.
# [I 2026-07-10 02:33:04,938] Trial 84 finished with value: 1.201820562857832 and parameters: {'n_estimators': 3884, 'learning_rate': 0.0006415044917540391, 'max_depth': 10, 'min_child_weight': 0.6182644266470058, 'gamma': 8.417113534395801, 'subsample': 0.45310602095721164, 'colsample_bytree': 0.5437262971353222, 'reg_alpha': 5.474965283527647e-06, 'reg_lambda': 0.05098503967347981}. Best is trial 80 with value: 1.1782826054025581.
# [I 2026-07-10 02:33:39,230] Trial 85 finished with value: 1.1784723720639732 and parameters: {'n_estimators': 3585, 'learning_rate': 0.0006169467972589197, 'max_depth': 8, 'min_child_weight': 1.7789797004784345, 'gamma': 3.6717277813796807, 'subsample': 0.5114110214429416, 'colsample_bytree': 0.5648591538224964, 'reg_alpha': 2.1070207745880855e-05, 'reg_lambda': 0.0031281611186559197}. Best is trial 80 with value: 1.1782826054025581.
# [I 2026-07-10 02:34:10,977] Trial 86 finished with value: 1.1830451537299966 and parameters: {'n_estimators': 3579, 'learning_rate': 0.0006065114459863218, 'max_depth': 8, 'min_child_weight': 1.1192830773923652, 'gamma': 3.6807719749001824, 'subsample': 0.512703495889504, 'colsample_bytree': 0.5519114089521604, 'reg_alpha': 1.820239846722051e-05, 'reg_lambda': 0.0033953811356733643}. Best is trial 80 with value: 1.1782826054025581.
# [I 2026-07-10 02:34:42,430] Trial 87 finished with value: 1.1778161745317182 and parameters: {'n_estimators': 3610, 'learning_rate': 0.0006193059201860571, 'max_depth': 8, 'min_child_weight': 0.995172183982497, 'gamma': 3.6642806494170252, 'subsample': 0.5115343333815113, 'colsample_bytree': 0.5353456376619428, 'reg_alpha': 1.150573182034809e-05, 'reg_lambda': 0.0032731422575509655}. Best is trial 87 with value: 1.1778161745317182.
# [I 2026-07-10 02:35:15,449] Trial 88 finished with value: 1.1832316669044094 and parameters: {'n_estimators': 3533, 'learning_rate': 0.0005013343571367434, 'max_depth': 8, 'min_child_weight': 0.9873909557178991, 'gamma': 3.7032467288798405, 'subsample': 0.4127712228076435, 'colsample_bytree': 0.559528728260393, 'reg_alpha': 1.9412640891843176e-05, 'reg_lambda': 0.0029933175506904226}. Best is trial 87 with value: 1.1778161745317182.
# [I 2026-07-10 02:35:45,942] Trial 89 finished with value: 1.1867832432054617 and parameters: {'n_estimators': 3111, 'learning_rate': 0.0005030277663508677, 'max_depth': 8, 'min_child_weight': 0.5896567914085781, 'gamma': 3.8550927705585805, 'subsample': 0.40949051688043775, 'colsample_bytree': 0.5531370246474251, 'reg_alpha': 2.6697926389372584e-05, 'reg_lambda': 0.009122870544203058}. Best is trial 87 with value: 1.1778161745317182.
# [I 2026-07-10 02:36:20,641] Trial 90 finished with value: 1.1823415268463044 and parameters: {'n_estimators': 3562, 'learning_rate': 0.0005046186821059268, 'max_depth': 8, 'min_child_weight': 0.431608376439439, 'gamma': 3.6478122344004, 'subsample': 0.39355209462908775, 'colsample_bytree': 0.5509184985494768, 'reg_alpha': 0.0002646505335520435, 'reg_lambda': 0.00983958655581133}. Best is trial 87 with value: 1.1778161745317182.
# [I 2026-07-10 02:36:57,147] Trial 91 finished with value: 1.1824274365156593 and parameters: {'n_estimators': 3529, 'learning_rate': 0.0005070930666019618, 'max_depth': 8, 'min_child_weight': 0.43905913988900613, 'gamma': 3.609976677131254, 'subsample': 0.4006396560514487, 'colsample_bytree': 0.5549783225252882, 'reg_alpha': 0.0002470275076794898, 'reg_lambda': 0.034646907317531256}. Best is trial 87 with value: 1.1778161745317182.
# [I 2026-07-10 02:37:31,100] Trial 92 finished with value: 1.1870625921184048 and parameters: {'n_estimators': 2970, 'learning_rate': 0.00050362655626121, 'max_depth': 8, 'min_child_weight': 0.40248362261794546, 'gamma': 3.507976118189822, 'subsample': 0.4067961298665501, 'colsample_bytree': 0.5549159141628036, 'reg_alpha': 0.00020989287104839437, 'reg_lambda': 0.00590820313304805}. Best is trial 87 with value: 1.1778161745317182.
# [I 2026-07-10 02:37:59,928] Trial 93 finished with value: 1.1872355801732883 and parameters: {'n_estimators': 3559, 'learning_rate': 0.0005196523934513253, 'max_depth': 8, 'min_child_weight': 0.13467527583412905, 'gamma': 4.091654922891149, 'subsample': 0.37428456165015933, 'colsample_bytree': 0.488280686037026, 'reg_alpha': 2.1053289812789045e-05, 'reg_lambda': 0.03212387206781994}. Best is trial 87 with value: 1.1778161745317182.
# [I 2026-07-10 02:38:09,506] Trial 94 pruned.
# [I 2026-07-10 02:38:44,472] Trial 95 finished with value: 1.184682298333561 and parameters: {'n_estimators': 3629, 'learning_rate': 0.0005736159503531963, 'max_depth': 8, 'min_child_weight': 0.6541346652556647, 'gamma': 2.6308639483117515, 'subsample': 0.4109167272924554, 'colsample_bytree': 0.4552220786195989, 'reg_alpha': 0.00044002070200221114, 'reg_lambda': 0.043225165501753635}. Best is trial 87 with value: 1.1778161745317182.
# [I 2026-07-10 02:39:16,598] Trial 96 finished with value: 1.187837809563988 and parameters: {'n_estimators': 3546, 'learning_rate': 0.0005919067116183862, 'max_depth': 9, 'min_child_weight': 0.24543306410754936, 'gamma': 2.7738600349526643, 'subsample': 0.3837052684724316, 'colsample_bytree': 0.5100238158071866, 'reg_alpha': 0.0009026529472923967, 'reg_lambda': 0.04526167894688076}. Best is trial 87 with value: 1.1778161745317182.
# [I 2026-07-10 02:39:40,632] Trial 97 finished with value: 1.1810778528106782 and parameters: {'n_estimators': 3658, 'learning_rate': 0.0008106173554728383, 'max_depth': 8, 'min_child_weight': 1.0022127302799972, 'gamma': 3.6110115991201956, 'subsample': 0.4150611929036403, 'colsample_bytree': 0.45611437239709524, 'reg_alpha': 0.0004339513503898024, 'reg_lambda': 0.0026862984136083704}. Best is trial 87 with value: 1.1778161745317182.
# [I 2026-07-10 02:39:55,483] Trial 98 finished with value: 1.1858446795069733 and parameters: {'n_estimators': 3625, 'learning_rate': 0.0013960393357956929, 'max_depth': 8, 'min_child_weight': 1.030023015535473, 'gamma': 4.32924456170111, 'subsample': 0.4154457222002752, 'colsample_bytree': 0.4548463111435016, 'reg_alpha': 0.000622963283080093, 'reg_lambda': 0.0029090775107857396}. Best is trial 87 with value: 1.1778161745317182.
# [I 2026-07-10 02:40:03,466] Trial 99 pruned.
# [I 2026-07-10 02:40:03,539] A new study created in RDB with name: KATL_v18_remaining_warmup_base_lightgbm_mae_f_wide_plus
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-10 02:40:05,449] Trial 0 finished with value: 1.2823519683201663 and parameters: {'n_estimators': 447, 'learning_rate': 0.028873871707375695, 'num_leaves': 71, 'max_depth': 5, 'min_child_samples': 83, 'min_split_gain': 4.295687454742988, 'bagging_fraction': 0.7829586385137167, 'bagging_freq': 4, 'feature_fraction': 0.3688589858758342, 'lambda_l1': 0.06382334403151436, 'lambda_l2': 0.03080292177315921, 'huber_alpha': 0.95}. Best is trial 0 with value: 1.2823519683201663.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-10 02:40:13,628] Trial 1 finished with value: 1.5918820477552953 and parameters: {'n_estimators': 812, 'learning_rate': 0.009357081249483435, 'num_leaves': 164, 'max_depth': 2, 'min_child_samples': 211, 'min_split_gain': 4.244695738724308, 'bagging_fraction': 0.9814523094330022, 'bagging_freq': 3, 'feature_fraction': 0.9704172813206324, 'lambda_l1': 2.234088279028776e-05, 'lambda_l2': 1.6594154120142632, 'huber_alpha': 0.85}. Best is trial 0 with value: 1.2823519683201663.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-10 02:40:15,271] Trial 2 finished with value: 2.5161057003924925 and parameters: {'n_estimators': 67, 'learning_rate': 0.02007090910723469, 'num_leaves': 246, 'max_depth': 10, 'min_child_samples': 245, 'min_split_gain': 4.543313789155439, 'bagging_fraction': 0.9415994992571017, 'bagging_freq': 4, 'feature_fraction': 0.41761231740559585, 'lambda_l1': 1.4824332354449863e-08, 'lambda_l2': 101.18939970488272, 'huber_alpha': 0.85}. Best is trial 0 with value: 1.2823519683201663.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-10 02:40:18,002] Trial 3 finished with value: 1.5637564779301036 and parameters: {'n_estimators': 1000, 'learning_rate': 0.1413663860910666, 'num_leaves': 109, 'max_depth': 7, 'min_child_samples': 249, 'min_split_gain': 3.678635407535604, 'bagging_fraction': 0.6392899181182937, 'bagging_freq': 4, 'feature_fraction': 0.6173160679063129, 'lambda_l1': 0.052948773379180566, 'lambda_l2': 0.032760577756785814, 'huber_alpha': 0.85}. Best is trial 0 with value: 1.2823519683201663.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-10 02:40:23,773] Trial 4 finished with value: 2.2818719153502833 and parameters: {'n_estimators': 761, 'learning_rate': 0.003003151716938294, 'num_leaves': 409, 'max_depth': 5, 'min_child_samples': 165, 'min_split_gain': 1.498083879035124, 'bagging_fraction': 0.44391094597483866, 'bagging_freq': 3, 'feature_fraction': 0.5516751924489833, 'lambda_l1': 8.332516750396116e-08, 'lambda_l2': 0.5077631895453656, 'huber_alpha': 0.85}. Best is trial 0 with value: 1.2823519683201663.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-10 02:40:25,871] Trial 5 finished with value: 1.259449009331163 and parameters: {'n_estimators': 404, 'learning_rate': 0.18314620854695027, 'num_leaves': 260, 'max_depth': 13, 'min_child_samples': 51, 'min_split_gain': 2.972245934092154, 'bagging_fraction': 0.9775155780902212, 'bagging_freq': 7, 'feature_fraction': 0.365709606237354, 'lambda_l1': 5.9654059281874116e-05, 'lambda_l2': 0.006859036422781172, 'huber_alpha': 0.95}. Best is trial 5 with value: 1.259449009331163.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-10 02:40:29,231] Trial 6 finished with value: 1.2340007533206017 and parameters: {'n_estimators': 3052, 'learning_rate': 0.13146898336096702, 'num_leaves': 489, 'max_depth': 11, 'min_child_samples': 47, 'min_split_gain': 2.173391605434026, 'bagging_fraction': 0.9258346721061177, 'bagging_freq': 2, 'feature_fraction': 0.6381532515738396, 'lambda_l1': 0.002530717742378322, 'lambda_l2': 0.0004479476588817844, 'huber_alpha': 0.95}. Best is trial 6 with value: 1.2340007533206017.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-10 02:40:31,304] Trial 7 finished with value: 1.3809167566662404 and parameters: {'n_estimators': 2519, 'learning_rate': 0.18104669093362824, 'num_leaves': 399, 'max_depth': 4, 'min_child_samples': 227, 'min_split_gain': 2.761320735057018, 'bagging_fraction': 0.8991836269249566, 'bagging_freq': 7, 'feature_fraction': 0.8888248313104422, 'lambda_l1': 5.374969144858311e-06, 'lambda_l2': 0.5877618471031133, 'huber_alpha': 0.85}. Best is trial 6 with value: 1.2340007533206017.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-10 02:41:03,487] Trial 8 finished with value: 1.4549824036282 and parameters: {'n_estimators': 2273, 'learning_rate': 0.0030965152683643635, 'num_leaves': 383, 'max_depth': 3, 'min_child_samples': 3, 'min_split_gain': 1.6724449577646616, 'bagging_fraction': 0.9800160774901863, 'bagging_freq': 5, 'feature_fraction': 0.6188955975766686, 'lambda_l1': 2.8120694751804143e-09, 'lambda_l2': 0.00024007807690373727, 'huber_alpha': 0.85}. Best is trial 6 with value: 1.2340007533206017.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-10 02:41:09,941] Trial 9 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-10 02:41:32,382] Trial 10 finished with value: 1.3536475710721232 and parameters: {'n_estimators': 2941, 'learning_rate': 0.007104579859769969, 'num_leaves': 424, 'max_depth': 2, 'min_child_samples': 2, 'min_split_gain': 4.6220887565718325, 'bagging_fraction': 0.7880566131549542, 'bagging_freq': 7, 'feature_fraction': 0.661678263936434, 'lambda_l1': 8.121756387194875e-09, 'lambda_l2': 100.08386764870838, 'huber_alpha': 0.9}. Best is trial 6 with value: 1.2340007533206017.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-10 02:41:33,600] Trial 11 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-10 02:41:38,895] Trial 12 finished with value: 1.2656477094331602 and parameters: {'n_estimators': 3404, 'learning_rate': 0.03866939016656176, 'num_leaves': 50, 'max_depth': 9, 'min_child_samples': 54, 'min_split_gain': 3.975378174997817, 'bagging_fraction': 0.5776988884481041, 'bagging_freq': 4, 'feature_fraction': 0.8073004449855348, 'lambda_l1': 1.1469173194560514e-08, 'lambda_l2': 0.6127644589218547, 'huber_alpha': 0.85}. Best is trial 6 with value: 1.2340007533206017.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-10 02:41:39,919] Trial 13 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-10 02:41:56,784] Trial 14 finished with value: 1.3037721714388284 and parameters: {'n_estimators': 2440, 'learning_rate': 0.007089782197514698, 'num_leaves': 92, 'max_depth': 2, 'min_child_samples': 83, 'min_split_gain': 1.7789721315624618, 'bagging_fraction': 0.6616016865596667, 'bagging_freq': 5, 'feature_fraction': 0.4058624376375402, 'lambda_l1': 3.60867143771307e-07, 'lambda_l2': 0.0019132656772962273, 'huber_alpha': 0.9}. Best is trial 6 with value: 1.2340007533206017.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-10 02:41:58,347] Trial 15 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-10 02:41:59,503] Trial 16 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-10 02:42:03,658] Trial 17 finished with value: 1.2857305280984246 and parameters: {'n_estimators': 3309, 'learning_rate': 0.078175866300593, 'num_leaves': 508, 'max_depth': 13, 'min_child_samples': 103, 'min_split_gain': 2.183821929239314, 'bagging_fraction': 0.7553174967176419, 'bagging_freq': 3, 'feature_fraction': 0.37118098042063996, 'lambda_l1': 9.397361325633357e-09, 'lambda_l2': 0.32009070345347035, 'huber_alpha': 0.85}. Best is trial 6 with value: 1.2340007533206017.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-10 02:42:13,279] Trial 18 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# ...
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
#                   period                method  count     mae_f    rmse_f
# 0   validation_2024_2025               xgboost    729  1.178125  1.580773
# 1   validation_2024_2025              lightgbm    729  1.202739  1.617678
# 2   validation_2024_2025              catboost    729  1.198491  1.589170
# 3   validation_2024_2025         provider_mean    729  2.102767  3.049105
# 4   validation_2024_2025       provider_median    729  2.022252  2.951401
# 5   validation_2024_2025               nbm_raw    729  1.987547  2.848066
# 6   validation_2024_2025              hrrr_raw    729  2.790393  3.978949
# 7   validation_2024_2025               gfs_raw    729  2.859717  3.849158
# 8              test_2026               xgboost    171  1.197424  1.634991
# 9              test_2026              lightgbm    171  1.235546  1.671854
# 10             test_2026              catboost    171  1.230610  1.597826
# 11             test_2026           ridge_stack    171  1.189857  1.591116
# 12             test_2026  guarded_blend_cap_1f    171  1.755709  2.895440
# 13             test_2026  guarded_blend_cap_2f    171  1.542628  2.634484
# 14             test_2026  guarded_blend_cap_3f    171  1.449169  2.465219
# 15             test_2026         provider_mean    171  2.145562  3.337353
# 16             test_2026       provider_median    171  2.126776  3.276249
# 17             test_2026               nbm_raw    171  2.088445  3.229287
# 18             test_2026              hrrr_raw    171  2.539610  3.830303
# 19             test_2026               gfs_raw    171  2.838918  3.971651

# %%
exported_weights = export_station_model_weights(
    project_root=PROJECT_ROOT,
    station_id=STATION_ID,
    artifact_dir=config.resolved_output_dir(),
    model_version=MODEL_VERSION,
    timing_mode=config.timing_mode,
    providers=tuple(config.providers),
    feature_version=config.effective_feature_version,
    optuna_metric=config.effective_optuna_metric,
    target_mode=config.effective_target_mode,
    target_source=config.effective_target_source,
    base_model_methods=tuple(config.effective_base_model_methods),
    stack_enabled=config.stack_enabled,
    source_pipeline="notebooks/station_stacking_v18",
)

exported_weights.bundle_path, exported_weights.manifest_path
# Out:
# (WindowsPath('D:/dev/weather-research/data/calibration/station_stacking_v18/model_weights/KATL_station_high_regressor_v18_nbm_hrrr_physics_settlement_stack.joblib'),
#  WindowsPath('D:/dev/weather-research/data/calibration/station_stacking_v18/model_weights/KATL_station_high_regressor_v18_nbm_hrrr_physics_settlement_stack.json'))

# %% [markdown]
# ## V11 Feature Coverage

# %%
v11_feature_coverage = (
    result.features[V11_FEATURE_COLUMNS]
    .notna()
    .mean()
    .mul(100)
    .sort_values(ascending=False)
    .rename("coverage_pct")
    .reset_index()
    .rename(columns={"index": "feature"})
)

v11_feature_coverage
# Out:
#                                               feature  coverage_pct
# 0                              v2_spread_per_warmup_f    100.000000
# 1                    v2_morning_warmup_to_consensus_f    100.000000
# 2              v3_remaining_warmup_from_high_so_far_f    100.000000
# 3                      v3_high_so_far_above_current_f    100.000000
# 4                      v2_humidity_warmup_interaction    100.000000
# 5                    v4_observed_precip_recent_mm_est    100.000000
# 6                        v4_forecast_wet_observed_dry    100.000000
# 7                   v4_forecast_observed_precip_match    100.000000
# 8            v3_humidity_remaining_warmup_interaction    100.000000
# 9                    v3_remaining_warmup_per_spread_f    100.000000
# 10                             v4_all_forecast_precip    100.000000
# 11                             v4_observed_precip_any    100.000000
# 12                             v4_any_forecast_precip    100.000000
# 13                    v8_month_remaining_warmup_count    100.000000
# 14                             climatology_high_10y_f    100.000000
# 15                         climatology_high_10y_std_f    100.000000
# 16       observed_high_so_far_minus_climatology_10y_f    100.000000
# 17              observed_temp_minus_climatology_10y_f    100.000000
# 18                         climatology_high_10y_count    100.000000
# 19              provider_mean_minus_climatology_10y_f    100.000000
# 20          v8_provider_spread_per_remaining_warmup_f    100.000000
# 21                       v4_observed_wet_forecast_dry    100.000000
# 22       v8_provider_min_remaining_from_high_so_far_f    100.000000
# 23    v8_provider_median_remaining_from_high_so_far_f    100.000000
# 24       v8_provider_max_remaining_from_high_so_far_f    100.000000
# 25                          v2_recent_heat_momentum_f     99.949950
# 26                   v3_high_so_far_minus_7d_actual_f     99.949950
# 27                     v2_consensus_minus_7d_actual_f     99.949950
# 28            observed_high_so_far_change_since_9am_f     99.899900
# 29            observed_morning_warmup_rate_f_per_hour     99.899900
# 30               v8_recent_remaining_warmup_7d_mean_f     99.899900
# 31                     observed_temp_change_last_1h_f     99.899900
# 32                     observed_temp_change_last_3h_f     99.899900
# 33              v8_recent_remaining_warmup_30d_mean_f     99.749750
# 34                           v2_recent_heat_anomaly_f     99.699700
# 35                      v3_high_so_far_minus_lag_1d_f     99.699700
# 36       v8_provider_mean_remaining_vs_month_normal_f     98.798799
# 37                   v8_month_remaining_warmup_mean_f     98.798799
# 38      v8_dewpoint_mean_remaining_warmup_interaction     78.828829
# 39  v8_dewpoint_depression_remaining_warmup_intera...     78.828829
# 40                        v8_forecast_dewpoint_mean_f     78.828829
# 41             v8_forecast_dewpoint_depression_mean_f     78.828829
# 42         v4_forecast_total_minus_observed_recent_mm     78.478478
# 43                   v4_forecast_precip_intensity_max     78.478478
# 44                   v4_forecast_precip_total_mean_mm     78.478478
# 45                    v4_forecast_precip_total_max_mm     78.478478
# 46                 v4_forecast_precip_total_spread_mm     78.478478
# 47                  v4_forecast_precip_max_1h_mean_mm     78.478478
# 48                      v4_forecast_precip_hours_mean     78.478478
# 49                  v4_forecast_precip_intensity_mean     78.478478
# 50             v4_precip_remaining_warmup_interaction     78.478478
# 51                     v4_precip_humidity_interaction     78.478478
# 52       v8_precip_total_remaining_warmup_interaction     78.478478
# 53      v8_precip_max_1h_remaining_warmup_interaction     78.478478
# 54    v8_wind_speed_mean_remaining_warmup_interaction     30.980981
# 55      v8_wind_gust_max_remaining_warmup_interaction     30.980981
# 56    v8_cloud_cover_max_remaining_warmup_interaction      0.000000
# 57   v8_cloud_cover_mean_remaining_warmup_interaction      0.000000

# %%
result.feature_columns.loc[result.feature_columns["feature"].isin(V11_FEATURE_COLUMNS)]
# Out:
#                                                feature     kind
# 3                       observed_temp_change_last_1h_f  numeric
# 4                       observed_temp_change_last_3h_f  numeric
# 5              observed_morning_warmup_rate_f_per_hour  numeric
# 6              observed_high_so_far_change_since_9am_f  numeric
# 49                            v2_recent_heat_anomaly_f  numeric
# 50                           v2_recent_heat_momentum_f  numeric
# 51                    v2_morning_warmup_to_consensus_f  numeric
# 52                      v2_consensus_minus_7d_actual_f  numeric
# 53                              v2_spread_per_warmup_f  numeric
# 54                      v2_humidity_warmup_interaction  numeric
# 55                      v3_high_so_far_above_current_f  numeric
# 56              v3_remaining_warmup_from_high_so_far_f  numeric
# 57                       v3_high_so_far_minus_lag_1d_f  numeric
# 58                    v3_high_so_far_minus_7d_actual_f  numeric
# 59                    v3_remaining_warmup_per_spread_f  numeric
# 60            v3_humidity_remaining_warmup_interaction  numeric
# 61                    v4_forecast_precip_total_mean_mm  numeric
# 62                     v4_forecast_precip_total_max_mm  numeric
# 63                  v4_forecast_precip_total_spread_mm  numeric
# 64                   v4_forecast_precip_max_1h_mean_mm  numeric
# 65                       v4_forecast_precip_hours_mean  numeric
# 66                   v4_forecast_precip_intensity_mean  numeric
# 67                    v4_forecast_precip_intensity_max  numeric
# 68                              v4_any_forecast_precip  numeric
# 69                              v4_all_forecast_precip  numeric
# 70                              v4_observed_precip_any  numeric
# 71                    v4_observed_precip_recent_mm_est  numeric
# 72          v4_forecast_total_minus_observed_recent_mm  numeric
# 73                   v4_forecast_observed_precip_match  numeric
# 74                        v4_forecast_wet_observed_dry  numeric
# 75                        v4_observed_wet_forecast_dry  numeric
# 76                      v4_precip_humidity_interaction  numeric
# 77              v4_precip_remaining_warmup_interaction  numeric
# 78        v8_provider_max_remaining_from_high_so_far_f  numeric
# 79        v8_provider_min_remaining_from_high_so_far_f  numeric
# 80     v8_provider_median_remaining_from_high_so_far_f  numeric
# 81           v8_provider_spread_per_remaining_warmup_f  numeric
# 82                    v8_month_remaining_warmup_mean_f  numeric
# 83                     v8_month_remaining_warmup_count  numeric
# 84                v8_recent_remaining_warmup_7d_mean_f  numeric
# 85               v8_recent_remaining_warmup_30d_mean_f  numeric
# 86        v8_provider_mean_remaining_vs_month_normal_f  numeric
# 87        v8_precip_total_remaining_warmup_interaction  numeric
# 88       v8_precip_max_1h_remaining_warmup_interaction  numeric
# 89     v8_wind_speed_mean_remaining_warmup_interaction  numeric
# 90       v8_wind_gust_max_remaining_warmup_interaction  numeric
# 91                         v8_forecast_dewpoint_mean_f  numeric
# 92              v8_forecast_dewpoint_depression_mean_f  numeric
# 93       v8_dewpoint_mean_remaining_warmup_interaction  numeric
# 94   v8_dewpoint_depression_remaining_warmup_intera...  numeric
# 95                              climatology_high_10y_f  numeric
# 96                          climatology_high_10y_std_f  numeric
# 97                          climatology_high_10y_count  numeric
# 98               provider_mean_minus_climatology_10y_f  numeric
# 99               observed_temp_minus_climatology_10y_f  numeric
# 100       observed_high_so_far_minus_climatology_10y_f  numeric

# %% [markdown]
# ## Dropped Feature Check

# %%
dropped_present = result.feature_columns.loc[
    result.feature_columns["feature"].isin(V11_DROPPED_FEATURE_COLUMNS)
]

dropped_present
# Out:
# Empty DataFrame
# Columns: [feature, kind]
# Index: []

# %% [markdown]
# ## Morning Trend Coverage

# %%
trend_coverage = (
    result.features[TREND_COLUMNS]
    .notna()
    .mean()
    .mul(100)
    .sort_values(ascending=False)
    .rename("coverage_pct")
    .reset_index()
    .rename(columns={"index": "feature"})
)

trend_coverage
# Out:
#                                    feature  coverage_pct
# 0           observed_temp_change_last_1h_f       99.8999
# 1           observed_temp_change_last_3h_f       99.8999
# 2  observed_morning_warmup_rate_f_per_hour       99.8999
# 3  observed_high_so_far_change_since_9am_f       99.8999

# %% [markdown]
# ## Rounded Within 1F Accuracy

# %%
preds = pd.concat(
    [
        result.validation_predictions.assign(period="validation_2024_2025"),
        result.test_predictions.assign(period="oof_2026"),
    ],
    ignore_index=True,
)

predicted_high = pd.to_numeric(preds["predicted_high_f"], errors="coerce")
preds["predicted_high_rounded_f"] = np.floor(predicted_high + 0.5)
preds["within_1f_after_round"] = (
    pd.to_numeric(preds["actual_high_f"], errors="coerce") - preds["predicted_high_rounded_f"]
).abs().le(1)

within_1f_accuracy_by_period = (
    preds
    .dropna(subset=["actual_high_f", "predicted_high_rounded_f"])
    .groupby(["period", "method"], as_index=False)
    .agg(
        count=("within_1f_after_round", "size"),
        within_1f_count=("within_1f_after_round", "sum"),
        within_1f_accuracy_pct=("within_1f_after_round", lambda x: x.mean() * 100),
    )
    .sort_values(["period", "within_1f_accuracy_pct"], ascending=[True, False])
)

within_1f_accuracy_by_period
# Out:
#                   period                method  count  within_1f_count  \
# 10              oof_2026           ridge_stack    171              127
# 6               oof_2026              lightgbm    171              124
# 11              oof_2026               xgboost    171              123
# 4               oof_2026  guarded_blend_cap_3f    171              120
# 0               oof_2026              catboost    171              119
# 3               oof_2026  guarded_blend_cap_2f    171              118
# 2               oof_2026  guarded_blend_cap_1f    171              108
# 7               oof_2026               nbm_raw    171               91
# 9               oof_2026       provider_median    171               84
# 8               oof_2026         provider_mean    171               78
# 5               oof_2026              hrrr_raw    171               71
# 1               oof_2026               gfs_raw    171               59
# 19  validation_2024_2025               xgboost    729              524
# 12  validation_2024_2025              catboost    729              520
# 15  validation_2024_2025              lightgbm    729              516
# 16  validation_2024_2025               nbm_raw    729              358
# 18  validation_2024_2025       provider_median    729              353
# 17  validation_2024_2025         provider_mean    729              344
# 14  validation_2024_2025              hrrr_raw    729              278
# 13  validation_2024_2025               gfs_raw    729              233
#
#     within_1f_accuracy_pct
# 10               74.269006
# 6                72.514620
# 11               71.929825
# 4                70.175439
# 0                69.590643
# 3                69.005848
# 2                63.157895
# 7                53.216374
# 9                49.122807
# 8                45.614035
# 5                41.520468
# 1                34.502924
# 19               71.879287
# 12               71.330590
# 15               70.781893
# 16               49.108368
# 18               48.422497
# 17               47.187929
# 14               38.134431
# 13               31.961591

# %% [markdown]
# ## Version Comparison

# %%
comparison_frames = []
for version, folder in [
    ("v1", PROJECT_ROOT / "data" / "calibration" / "station_stacking"),
    ("v2", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v2"),
    ("v3", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v3"),
    ("v4", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v4"),
    ("v5", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v5"),
    ("v6", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v6"),
    ("v7", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v7"),
    ("v8", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v8"),
    ("v9", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v9"),
    ("v10", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v10"),
    ("v11", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v11"),
]:
    path = folder / f"{STATION_ID}_year_split_scoreboard.csv"
    if path.exists():
        frame = pd.read_csv(path)
        frame["version"] = version
        comparison_frames.append(frame)

version_comparison = pd.concat(comparison_frames, ignore_index=True) if comparison_frames else pd.DataFrame()
if not version_comparison.empty:
    version_comparison = version_comparison.sort_values(["period", "mae_f", "version", "method"]).reset_index(drop=True)
version_comparison
# Out:
#                    period       method  count     mae_f    rmse_f version
# 0               test_2026     lightgbm    137  1.529121  2.224566     v11
# 1               test_2026  ridge_stack    137  1.531900  2.209782     v11
# 2               test_2026     lightgbm    125  1.547989  2.093915      v5
# 3               test_2026  ridge_stack    125  1.566708  2.118374      v5
# 4               test_2026      xgboost    125  1.569277  2.117086      v5
# ..                    ...          ...    ...       ...       ...     ...
# 111  validation_2024_2025      gfs_raw    541  3.557627  5.060559      v1
# 112  validation_2024_2025     hrrr_raw    664  3.630969  5.083107      v2
# 113  validation_2024_2025     hrrr_raw    664  3.630969  5.083107      v3
# 114  validation_2024_2025     hrrr_raw    664  3.630969  5.083107      v4
# 115  validation_2024_2025     hrrr_raw    541  4.010898  5.487445      v1
#
# [116 rows x 6 columns]

# %% [markdown]
# ## 2026 OOF Weather Brackets

# %%
result.bracket_metrics
# Out:
#                   method  count     mae_f    rmse_f  bucket_log_loss  \
# 0                xgboost    171  1.197424  1.634991         1.292433
# 1               lightgbm    171  1.235546  1.671854         1.320984
# 2               catboost    171  1.230610  1.597826         1.269001
# 3            ridge_stack    171  1.189857  1.591116         1.276732
# 4   guarded_blend_cap_1f    171  1.755709  2.895440         1.777331
# 5   guarded_blend_cap_2f    171  1.542628  2.634484         1.711656
# 6   guarded_blend_cap_3f    171  1.449169  2.465219         1.654067
# 7          provider_mean    171  2.145562  3.337353         1.877072
# 8        provider_median    171  2.126776  3.276249         1.874809
# 9                nbm_raw    171  2.088445  3.229287         1.869976
# 10              hrrr_raw    171  2.539610  3.830303         1.975896
# 11               gfs_raw    171  2.838918  3.971651         2.083263
#
#     bracket_accuracy_pct  p95_absolute_error_f  large_miss_5f_pct
# 0              47.368421              3.269993           1.754386
# 1              42.105263              3.536565           1.754386
# 2              43.859649              3.055834           1.754386
# 3              45.614035              3.203913           1.754386
# 4              37.426901              4.357125           4.678363
# 5              43.274854              3.834019           4.093567
# 6              43.859649              3.741480           4.093567
# 7              34.502924              5.357125           6.432749
# 8              33.918129              5.905997           7.017544
# 9              35.672515              5.905997           7.602339
# 10             29.824561              7.038774          12.280702
# 11             21.637427              7.412432          12.865497

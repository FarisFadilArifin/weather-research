# %% [markdown]
# # Station Stacking v2 - KLGA
#
# Wide HRRR/GFS same-day 11am notebook for `KLGA`.
#
# This workflow tunes XGBoost, LightGBM, and CatBoost with Optuna/TPE against RMSE on two fixed validation folds: train 2021-2023 validate 2024, train 2022-2024 validate 2025. It then trains on 2021-2025, tests on 2026, adds a Ridge meta-model stack, and simulates deterministic 2-degree weather brackets without calling Polymarket.
#
# Version 2 adds notebook-level feature engineering and writes experiment artifacts to `data/calibration/station_stacking_v2`.

# %%
from pathlib import Path
import sys
import warnings

warnings.filterwarnings("ignore", message="IProgress not found.*")
warnings.filterwarnings("ignore", message="Skipping features without any observed values.*")

PROJECT_ROOT = Path.cwd().resolve()
while not (PROJECT_ROOT / "src" / "calibration" / "station_stacking.py").exists():
    if PROJECT_ROOT.parent == PROJECT_ROOT:
        raise RuntimeError("Could not find project root containing src/calibration/station_stacking.py")
    PROJECT_ROOT = PROJECT_ROOT.parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

STATION_ID = "KLGA"
FAST_MODE = False
OPTUNA_TRIALS = 100
STACK_OPTUNA_TRIALS = 50
OPTUNA_VERBOSE = True
PROJECT_ROOT
# Out:
# WindowsPath('D:/dev/weather-research')

# %%
from src.calibration.station_stacking import (
    StationStackingConfig,
    missing_model_dependencies,
    run_station_year_split_experiment,
)

# %% [markdown]
# ## V2 Feature Engineering
#
# Adds extra pre-model features from existing same-day and lagged signals. These features use only 11 AM observations, provider forecasts, and prior actual-high history, then patch the station-stacking dataset builder before the experiment runs.

# %%
import numpy as np
import pandas as pd
import src.calibration.station_stacking as station_stacking_module

V2_FEATURE_COLUMNS = [
    "v2_recent_heat_anomaly_f",
    "v2_recent_heat_momentum_f",
    "v2_morning_warmup_to_consensus_f",
    "v2_consensus_minus_7d_actual_f",
    "v2_spread_per_warmup_f",
    "v2_humidity_warmup_interaction",
]


def add_v2_feature_engineering(frame: pd.DataFrame) -> pd.DataFrame:
    out = frame.copy()
    observed_temp = pd.to_numeric(out.get("observed_temp_at_as_of_f"), errors="coerce")
    observed_humidity = pd.to_numeric(out.get("observed_humidity_at_as_of"), errors="coerce")
    provider_mean = pd.to_numeric(out.get("provider_mean_high_f"), errors="coerce")
    provider_spread = pd.to_numeric(out.get("provider_spread_high_f"), errors="coerce")
    lag_1d = pd.to_numeric(out.get("actual_high_lag_1d"), errors="coerce")
    roll_7d = pd.to_numeric(out.get("actual_high_roll_7d_mean"), errors="coerce")
    roll_30d = pd.to_numeric(out.get("actual_high_roll_30d_mean"), errors="coerce")

    warmup_to_consensus = provider_mean - observed_temp
    out["v2_recent_heat_anomaly_f"] = lag_1d - roll_30d
    out["v2_recent_heat_momentum_f"] = roll_7d - roll_30d
    out["v2_morning_warmup_to_consensus_f"] = warmup_to_consensus
    out["v2_consensus_minus_7d_actual_f"] = provider_mean - roll_7d
    out["v2_spread_per_warmup_f"] = provider_spread / warmup_to_consensus.abs().clip(lower=1.0)
    out["v2_humidity_warmup_interaction"] = (observed_humidity / 100.0) * warmup_to_consensus
    return out


if not hasattr(station_stacking_module, "_v2_original_build_station_wide_dataset"):
    station_stacking_module._v2_original_build_station_wide_dataset = station_stacking_module.build_station_wide_dataset


def build_station_wide_dataset_v2(*args, **kwargs):
    frame = station_stacking_module._v2_original_build_station_wide_dataset(*args, **kwargs)
    return add_v2_feature_engineering(frame)


station_stacking_module.build_station_wide_dataset = build_station_wide_dataset_v2
V2_FEATURE_COLUMNS
# Out:
# ['v2_recent_heat_anomaly_f',
#  'v2_recent_heat_momentum_f',
#  'v2_morning_warmup_to_consensus_f',
#  'v2_consensus_minus_7d_actual_f',
#  'v2_spread_per_warmup_f',
#  'v2_humidity_warmup_interaction']

# %% [markdown]
# ## Model Scores

# %%
missing_packages = missing_model_dependencies()
if missing_packages:
    raise ImportError(
        "Missing station-stacking ML packages: "
        + ", ".join(missing_packages)
        + ". Install them with: python -m pip install -r requirements.txt"
    )

config = StationStackingConfig(
    station_id=STATION_ID,
    project_root=PROJECT_ROOT,
    fast_mode=FAST_MODE,
    optuna_trials=OPTUNA_TRIALS,
    stack_optuna_trials=STACK_OPTUNA_TRIALS,
    optuna_verbose=OPTUNA_VERBOSE,
    output_dir=PROJECT_ROOT / "data" / "calibration" / "station_stacking_v2",
)
result = run_station_year_split_experiment(config)
result.scoreboard
# Out:
# [I 2026-06-06 13:40:42,456] A new study created in memory with name: no-name-8c58d558-8b4e-4855-b43b-a0b54a6e19ad
# [I 2026-06-06 13:41:01,285] Trial 0 finished with value: 3.4273259352332888 and parameters: {'n_estimators': 799, 'learning_rate': 0.12369619597856178, 'max_depth': 6, 'min_child_weight': 2.385234757844707, 'gamma': 0.7800932022121826, 'subsample': 0.5779972601681014, 'colsample_bytree': 0.5290418060840998, 'reg_alpha': 0.6245760287469893, 'reg_lambda': 0.6677615511747083}. Best is trial 0 with value: 3.4273259352332888.
# [I 2026-06-06 13:45:46,741] Trial 1 finished with value: 3.369402481218137 and parameters: {'n_estimators': 1440, 'learning_rate': 0.0032515743808034223, 'max_depth': 8, 'min_child_weight': 8.23143373099555, 'gamma': 1.0616955533913808, 'subsample': 0.5909124836035503, 'colsample_bytree': 0.5917022549267169, 'reg_alpha': 5.472429642032198e-06, 'reg_lambda': 0.2922905212920093}. Best is trial 1 with value: 3.369402481218137.
# [I 2026-06-06 13:47:02,365] Trial 2 finished with value: 3.688151192552237 and parameters: {'n_estimators': 909, 'learning_rate': 0.009373695213782608, 'max_depth': 5, 'min_child_weight': 0.20940138873937433, 'gamma': 1.4607232426760908, 'subsample': 0.6831809216468459, 'colsample_bytree': 0.728034992108518, 'reg_alpha': 0.1165691561324743, 'reg_lambda': 0.008674832802525461}. Best is trial 1 with value: 3.369402481218137.
# [I 2026-06-06 13:47:24,957] Trial 3 finished with value: 3.3616436024061014 and parameters: {'n_estimators': 1067, 'learning_rate': 0.03045200113778571, 'max_depth': 1, 'min_child_weight': 2.5002240473339543, 'gamma': 0.8526206184364576, 'subsample': 0.5325257964926398, 'colsample_bytree': 0.9744427686266666, 'reg_alpha': 4.905556676028774, 'reg_lambda': 6.289771819487036}. Best is trial 3 with value: 3.3616436024061014.
# [I 2026-06-06 13:48:43,452] Trial 4 finished with value: 3.7149938665849236 and parameters: {'n_estimators': 665, 'learning_rate': 0.004396056309201638, 'max_depth': 6, 'min_child_weight': 1.0299214204601976, 'gamma': 0.6101911742238941, 'subsample': 0.7475884550556351, 'colsample_bytree': 0.5171942605576092, 'reg_alpha': 1.527156759251193, 'reg_lambda': 0.016443693426189242}. Best is trial 3 with value: 3.3616436024061014.
# [I 2026-06-06 13:49:21,123] Trial 5 pruned.
# [I 2026-06-06 13:49:29,493] Trial 6 finished with value: 3.4314984115435454 and parameters: {'n_estimators': 1228, 'learning_rate': 0.11049889315270257, 'max_depth': 1, 'min_child_weight': 0.28246357083904894, 'gamma': 0.22613644455269033, 'subsample': 0.6626651653816322, 'colsample_bytree': 0.6943386448447411, 'reg_alpha': 2.7678419414850017e-06, 'reg_lambda': 7.838134236608707}. Best is trial 3 with value: 3.3616436024061014.
# [I 2026-06-06 13:49:58,206] Trial 7 pruned.
# [I 2026-06-06 13:50:09,193] Trial 8 finished with value: 3.432734448749823 and parameters: {'n_estimators': 90, 'learning_rate': 0.07287285110476487, 'max_depth': 6, 'min_child_weight': 4.758470274910409, 'gamma': 3.8563517334297286, 'subsample': 0.5370223258670452, 'colsample_bytree': 0.6792328642721364, 'reg_alpha': 1.1036250149900698e-07, 'reg_lambda': 11.368341439732731}. Best is trial 3 with value: 3.3616436024061014.
# [I 2026-06-06 13:50:37,789] Trial 9 finished with value: 3.468488250977348 and parameters: {'n_estimators': 1277, 'learning_rate': 0.01094730135557207, 'max_depth': 1, 'min_child_weight': 0.5194929407101735, 'gamma': 1.6259166101337352, 'subsample': 0.864803089169032, 'colsample_bytree': 0.8187787356776066, 'reg_alpha': 0.9658611176861268, 'reg_lambda': 0.16554793541373172}. Best is trial 3 with value: 3.3616436024061014.
# [I 2026-06-06 13:51:01,215] Trial 10 finished with value: 3.3754601645454785 and parameters: {'n_estimators': 1915, 'learning_rate': 0.036235378997051045, 'max_depth': 3, 'min_child_weight': 13.97101765312176, 'gamma': 2.828065453407016, 'subsample': 0.8211770829222278, 'colsample_bytree': 0.9805126451489784, 'reg_alpha': 0.0025347992375043043, 'reg_lambda': 2.1525808090182244}. Best is trial 3 with value: 3.3616436024061014.
# [I 2026-06-06 13:51:40,026] Trial 11 finished with value: 3.382416398759272 and parameters: {'n_estimators': 1816, 'learning_rate': 0.03287546171457566, 'max_depth': 8, 'min_child_weight': 10.967975722691842, 'gamma': 2.1717813587820567, 'subsample': 0.6158877708273484, 'colsample_bytree': 0.6109402802946341, 'reg_alpha': 6.982496886163948e-05, 'reg_lambda': 0.1500406109373817}. Best is trial 3 with value: 3.3616436024061014.
# [I 2026-06-06 13:54:49,562] Trial 12 finished with value: 3.372612283074978 and parameters: {'n_estimators': 1606, 'learning_rate': 0.003196962615028647, 'max_depth': 8, 'min_child_weight': 5.967787778328425, 'gamma': 2.5182196590789347, 'subsample': 0.5224078715805444, 'colsample_bytree': 0.8285397244388237, 'reg_alpha': 2.0057322817130592e-08, 'reg_lambda': 0.9111568610251692}. Best is trial 3 with value: 3.3616436024061014.
# [I 2026-06-06 13:55:27,807] Trial 13 finished with value: 3.379873205407249 and parameters: {'n_estimators': 1067, 'learning_rate': 0.022426968689597045, 'max_depth': 3, 'min_child_weight': 4.27533932135294, 'gamma': 0.022350197382312254, 'subsample': 0.6223441463224711, 'colsample_bytree': 0.8910368801788895, 'reg_alpha': 0.0005372302104189243, 'reg_lambda': 48.823076726100275}. Best is trial 3 with value: 3.3616436024061014.
# [I 2026-06-06 13:55:44,327] Trial 14 finished with value: 3.381983530878579 and parameters: {'n_estimators': 382, 'learning_rate': 0.018272312202213956, 'max_depth': 3, 'min_child_weight': 19.58235722169521, 'gamma': 1.4988959592627205, 'subsample': 0.730666690330899, 'colsample_bytree': 0.5869307363177139, 'reg_alpha': 4.003697756647738e-06, 'reg_lambda': 0.13349585351437454}. Best is trial 3 with value: 3.3616436024061014.
# [I 2026-06-06 13:56:27,840] Trial 15 finished with value: 3.3900160269336888 and parameters: {'n_estimators': 1567, 'learning_rate': 0.0054302816952434725, 'max_depth': 2, 'min_child_weight': 1.442472624894894, 'gamma': 3.202139292383121, 'subsample': 0.5891074478961835, 'colsample_bytree': 0.7848102912411731, 'reg_alpha': 0.010836930382935862, 'reg_lambda': 2.8828636675558346}. Best is trial 3 with value: 3.3616436024061014.
# [I 2026-06-06 13:56:40,487] Trial 16 finished with value: 3.4096106114814075 and parameters: {'n_estimators': 1526, 'learning_rate': 0.06093534784471525, 'max_depth': 7, 'min_child_weight': 8.391287970209302, 'gamma': 1.999607323157001, 'subsample': 0.506987049090697, 'colsample_bytree': 0.9261919312665499, 'reg_alpha': 3.154443500139828e-05, 'reg_lambda': 0.0011532639937455423}. Best is trial 3 with value: 3.3616436024061014.
# [I 2026-06-06 13:57:10,453] Trial 17 finished with value: 3.37050809910746 and parameters: {'n_estimators': 1044, 'learning_rate': 0.01657918685034158, 'max_depth': 4, 'min_child_weight': 3.244002960024353, 'gamma': 1.1493791421141606, 'subsample': 0.6637452938214105, 'colsample_bytree': 0.6246385122073203, 'reg_alpha': 9.655342270839855, 'reg_lambda': 0.034431939043098554}. Best is trial 3 with value: 3.3616436024061014.
# [I 2026-06-06 13:57:13,997] Trial 18 pruned.
# [I 2026-06-06 13:58:35,937] Trial 19 pruned.
# [I 2026-06-06 13:59:18,488] Trial 20 pruned.
# [I 2026-06-06 13:59:26,679] Trial 21 pruned.
# [I 2026-06-06 13:59:51,017] Trial 22 finished with value: 3.3527053156383295 and parameters: {'n_estimators': 1124, 'learning_rate': 0.014430549338317911, 'max_depth': 2, 'min_child_weight': 3.3785415908164915, 'gamma': 1.1210616256399502, 'subsample': 0.6247169050806954, 'colsample_bytree': 0.6434346341153047, 'reg_alpha': 9.489175007246127, 'reg_lambda': 0.03263676529611168}. Best is trial 22 with value: 3.3527053156383295.
# [I 2026-06-06 13:59:55,422] Trial 23 pruned.
# [I 2026-06-06 13:59:57,932] Trial 24 pruned.
# [I 2026-06-06 14:00:04,376] Trial 25 pruned.
# [I 2026-06-06 14:00:18,575] Trial 26 pruned.
# [I 2026-06-06 14:00:35,191] Trial 27 pruned.
# [I 2026-06-06 14:00:46,138] Trial 28 finished with value: 3.3467619024010786 and parameters: {'n_estimators': 1691, 'learning_rate': 0.025653002391883797, 'max_depth': 2, 'min_child_weight': 1.9414166196019222, 'gamma': 0.949799921341298, 'subsample': 0.5586603567550253, 'colsample_bytree': 0.8546885026442839, 'reg_alpha': 0.0007374649479104668, 'reg_lambda': 5.917404425562434}. Best is trial 28 with value: 3.3467619024010786.
# [I 2026-06-06 14:00:59,784] Trial 29 finished with value: 3.3399787222635755 and parameters: {'n_estimators': 1695, 'learning_rate': 0.026084499312987307, 'max_depth': 2, 'min_child_weight': 2.045989843707311, 'gamma': 0.8658401526352575, 'subsample': 0.5628691957044822, 'colsample_bytree': 0.8796654061766072, 'reg_alpha': 0.41686618567972056, 'reg_lambda': 5.809685481322924}. Best is trial 29 with value: 3.3399787222635755.
# [I 2026-06-06 14:01:03,169] Trial 30 pruned.
# [I 2026-06-06 14:01:17,265] Trial 31 finished with value: 3.329448272685557 and parameters: {'n_estimators': 1722, 'learning_rate': 0.027472934487623314, 'max_depth': 2, 'min_child_weight': 2.235734436651338, 'gamma': 0.8621485761571044, 'subsample': 0.5537626891427895, 'colsample_bytree': 0.9348658639034384, 'reg_alpha': 0.7145335120962533, 'reg_lambda': 7.736172381385489}. Best is trial 31 with value: 3.329448272685557.
# [I 2026-06-06 14:01:36,065] Trial 32 finished with value: 3.3131733503912204 and parameters: {'n_estimators': 1820, 'learning_rate': 0.025313222155607912, 'max_depth': 2, 'min_child_weight': 2.069015237947459, 'gamma': 1.376757664702603, 'subsample': 0.5624331323923365, 'colsample_bytree': 0.9267061524064799, 'reg_alpha': 0.5313903624351682, 'reg_lambda': 24.557743820314386}. Best is trial 32 with value: 3.3131733503912204.
# [I 2026-06-06 14:01:59,565] Trial 33 finished with value: 3.316048978850204 and parameters: {'n_estimators': 1716, 'learning_rate': 0.027520414852039005, 'max_depth': 2, 'min_child_weight': 2.0005667468877597, 'gamma': 1.4245486072597209, 'subsample': 0.5572916235684584, 'colsample_bytree': 0.9121279108518066, 'reg_alpha': 0.4296103293358943, 'reg_lambda': 23.067996475346344}. Best is trial 32 with value: 3.3131733503912204.
# [I 2026-06-06 14:02:05,586] Trial 34 pruned.
# [I 2026-06-06 14:02:23,405] Trial 35 finished with value: 3.3331616686139296 and parameters: {'n_estimators': 1702, 'learning_rate': 0.029223703842428856, 'max_depth': 2, 'min_child_weight': 1.0243610571666222, 'gamma': 1.4756213386123107, 'subsample': 0.5487349527901371, 'colsample_bytree': 0.9501813260897719, 'reg_alpha': 0.03720119132724381, 'reg_lambda': 24.52265865946321}. Best is trial 32 with value: 3.3131733503912204.
# [I 2026-06-06 14:02:30,239] Trial 36 finished with value: 3.3190982978741914 and parameters: {'n_estimators': 1835, 'learning_rate': 0.08325244094552596, 'max_depth': 1, 'min_child_weight': 0.9254599479650862, 'gamma': 1.766236717586684, 'subsample': 0.5289386645506157, 'colsample_bytree': 0.948590127667327, 'reg_alpha': 0.032655248768750644, 'reg_lambda': 26.372286539516228}. Best is trial 32 with value: 3.3131733503912204.
# [I 2026-06-06 14:02:32,752] Trial 37 pruned.
# [I 2026-06-06 14:02:40,564] Trial 38 finished with value: 3.339808549646184 and parameters: {'n_estimators': 1856, 'learning_rate': 0.08374366894898577, 'max_depth': 1, 'min_child_weight': 0.9308937531584378, 'gamma': 2.123631942314758, 'subsample': 0.5129415984700154, 'colsample_bytree': 0.9227533786446734, 'reg_alpha': 0.12888942146666554, 'reg_lambda': 30.416258884703268}. Best is trial 32 with value: 3.3131733503912204.
# [I 2026-06-06 14:02:50,161] Trial 39 finished with value: 3.383177240823046 and parameters: {'n_estimators': 1534, 'learning_rate': 0.06746023088203097, 'max_depth': 1, 'min_child_weight': 0.38895415975614334, 'gamma': 2.4892015721253373, 'subsample': 0.5310990238874808, 'colsample_bytree': 0.9032135618053097, 'reg_alpha': 1.8988660734353089, 'reg_lambda': 8.774443260154664}. Best is trial 32 with value: 3.3131733503912204.
# [I 2026-06-06 14:02:53,373] Trial 40 pruned.
# [I 2026-06-06 14:03:11,019] Trial 41 finished with value: 3.3544046346181853 and parameters: {'n_estimators': 1625, 'learning_rate': 0.03183174660094374, 'max_depth': 2, 'min_child_weight': 0.9855664148895096, 'gamma': 1.4630775494148323, 'subsample': 0.5419054160914165, 'colsample_bytree': 0.9511839908809164, 'reg_alpha': 0.042534692571774634, 'reg_lambda': 29.882719626712582}. Best is trial 32 with value: 3.3131733503912204.
# [I 2026-06-06 14:03:22,173] Trial 42 finished with value: 3.350951496280148 and parameters: {'n_estimators': 1894, 'learning_rate': 0.05087818892759769, 'max_depth': 2, 'min_child_weight': 1.6676655329058316, 'gamma': 1.7705539788526186, 'subsample': 0.9862845659408341, 'colsample_bytree': 0.9683342551646279, 'reg_alpha': 0.06028224370399866, 'reg_lambda': 20.24360335304643}. Best is trial 32 with value: 3.3131733503912204.
# [I 2026-06-06 14:03:34,420] Trial 43 finished with value: 3.380515550742569 and parameters: {'n_estimators': 1766, 'learning_rate': 0.021293334678862658, 'max_depth': 1, 'min_child_weight': 0.8032903721893546, 'gamma': 1.4429266934651739, 'subsample': 0.5457754874080805, 'colsample_bytree': 0.9974687975382852, 'reg_alpha': 0.14694009942047756, 'reg_lambda': 4.698163533538601}. Best is trial 32 with value: 3.3131733503912204.
# [I 2026-06-06 14:03:41,036] Trial 44 pruned.
# [I 2026-06-06 14:03:53,331] Trial 45 finished with value: 3.313935643146208 and parameters: {'n_estimators': 2000, 'learning_rate': 0.02900998767404204, 'max_depth': 2, 'min_child_weight': 0.5156210887417495, 'gamma': 1.627383328643943, 'subsample': 0.5187311774948768, 'colsample_bytree': 0.9046043070613577, 'reg_alpha': 0.005986667384280771, 'reg_lambda': 8.641888507785557}. Best is trial 32 with value: 3.3131733503912204.
# [I 2026-06-06 14:04:07,645] Trial 46 finished with value: 3.3346696997971432 and parameters: {'n_estimators': 1913, 'learning_rate': 0.020138156046422453, 'max_depth': 1, 'min_child_weight': 0.1824583763878018, 'gamma': 1.905814341029938, 'subsample': 0.5238037315617705, 'colsample_bytree': 0.8413163691453247, 'reg_alpha': 0.001324376298102997, 'reg_lambda': 9.004897750829924}. Best is trial 32 with value: 3.3131733503912204.
# [I 2026-06-06 14:04:17,513] Trial 47 pruned.
# [I 2026-06-06 14:04:19,825] Trial 48 pruned.
# [I 2026-06-06 14:04:28,620] Trial 49 pruned.
# [I 2026-06-06 14:04:42,845] Trial 50 finished with value: 3.3118215372790165 and parameters: {'n_estimators': 1517, 'learning_rate': 0.028599762392951738, 'max_depth': 1, 'min_child_weight': 3.981555078704871, 'gamma': 3.3182911630032996, 'subsample': 0.5807497702910517, 'colsample_bytree': 0.9073628858382432, 'reg_alpha': 0.20860058028429035, 'reg_lambda': 10.500499192093114}. Best is trial 50 with value: 3.3118215372790165.
# [I 2026-06-06 14:04:57,782] Trial 51 finished with value: 3.337447604278464 and parameters: {'n_estimators': 1511, 'learning_rate': 0.029043865434248875, 'max_depth': 1, 'min_child_weight': 3.635510712795861, 'gamma': 4.231467239144024, 'subsample': 0.5297589754759988, 'colsample_bytree': 0.906986920611048, 'reg_alpha': 0.2226857211359183, 'reg_lambda': 10.60009206434861}. Best is trial 50 with value: 3.3118215372790165.
# [I 2026-06-06 14:05:11,825] Trial 52 finished with value: 3.3890688691602615 and parameters: {'n_estimators': 1640, 'learning_rate': 0.022722683017082086, 'max_depth': 1, 'min_child_weight': 5.527082827213857, 'gamma': 3.56543999333923, 'subsample': 0.5810856042759838, 'colsample_bytree': 0.9784847670323078, 'reg_alpha': 0.8308429616672137, 'reg_lambda': 3.564430643386608}. Best is trial 50 with value: 3.3118215372790165.
# [I 2026-06-06 14:05:19,547] Trial 53 finished with value: 3.362086479693539 and parameters: {'n_estimators': 1782, 'learning_rate': 0.04640665979332471, 'max_depth': 2, 'min_child_weight': 2.442921636668535, 'gamma': 3.3441844661374063, 'subsample': 0.5726415918437828, 'colsample_bytree': 0.8616977542430174, 'reg_alpha': 0.18104537249901637, 'reg_lambda': 7.184888327893237}. Best is trial 50 with value: 3.3118215372790165.
# [I 2026-06-06 14:05:35,200] Trial 54 finished with value: 3.3283149487301893 and parameters: {'n_estimators': 1476, 'learning_rate': 0.03386917155186028, 'max_depth': 1, 'min_child_weight': 4.146695808133639, 'gamma': 4.978633836110259, 'subsample': 0.5229639389849222, 'colsample_bytree': 0.8892111366884455, 'reg_alpha': 0.0019185385696387372, 'reg_lambda': 16.34284941753303}. Best is trial 50 with value: 3.3118215372790165.
# [I 2026-06-06 14:05:44,202] Trial 55 pruned.
# [I 2026-06-06 14:05:53,563] Trial 56 finished with value: 3.3839774671835574 and parameters: {'n_estimators': 1498, 'learning_rate': 0.055241197533647986, 'max_depth': 1, 'min_child_weight': 3.5710217737575602, 'gamma': 3.8900945100328066, 'subsample': 0.6110616163864597, 'colsample_bytree': 0.8006326277488497, 'reg_alpha': 0.0002912855646571415, 'reg_lambda': 17.558371610938913}. Best is trial 50 with value: 3.3118215372790165.
# [I 2026-06-06 14:06:28,209] Trial 57 finished with value: 3.3514174259700096 and parameters: {'n_estimators': 1385, 'learning_rate': 0.011720860476716607, 'max_depth': 1, 'min_child_weight': 4.362376660489164, 'gamma': 3.027036611556686, 'subsample': 0.5378582860936731, 'colsample_bytree': 0.8397153267509696, 'reg_alpha': 0.006904212105166819, 'reg_lambda': 30.53783608529707}. Best is trial 50 with value: 3.3118215372790165.
# [I 2026-06-06 14:06:47,066] Trial 58 finished with value: 3.2896538950271395 and parameters: {'n_estimators': 1244, 'learning_rate': 0.017285428595992147, 'max_depth': 2, 'min_child_weight': 10.51089963267727, 'gamma': 4.392515001438429, 'subsample': 0.5131398147672351, 'colsample_bytree': 0.8704394118199212, 'reg_alpha': 0.015287660975210513, 'reg_lambda': 13.062268721288353}. Best is trial 58 with value: 3.2896538950271395.
# [I 2026-06-06 14:07:02,177] Trial 59 finished with value: 3.336539918425199 and parameters: {'n_estimators': 1245, 'learning_rate': 0.017524082789702446, 'max_depth': 2, 'min_child_weight': 19.779048954251813, 'gamma': 4.215849010232294, 'subsample': 0.6350283996286519, 'colsample_bytree': 0.8639488106842643, 'reg_alpha': 0.018203320358164143, 'reg_lambda': 2.177540498057041}. Best is trial 58 with value: 3.2896538950271395.
# [I 2026-06-06 14:07:11,791] Trial 60 pruned.
# [I 2026-06-06 14:07:22,766] Trial 61 finished with value: 3.331779823643525 and parameters: {'n_estimators': 1589, 'learning_rate': 0.032657163461020836, 'max_depth': 2, 'min_child_weight': 13.966329469324807, 'gamma': 4.86712612498567, 'subsample': 0.5195801700330771, 'colsample_bytree': 0.8932895098885998, 'reg_alpha': 0.0012212422514212148, 'reg_lambda': 15.290879943229191}. Best is trial 58 with value: 3.2896538950271395.
# [I 2026-06-06 14:07:45,001] Trial 62 finished with value: 3.2940850165768687 and parameters: {'n_estimators': 1474, 'learning_rate': 0.02313284583164037, 'max_depth': 1, 'min_child_weight': 2.88795939597737, 'gamma': 4.513015718161743, 'subsample': 0.5002253019329894, 'colsample_bytree': 0.8766105186819425, 'reg_alpha': 0.009069697016162125, 'reg_lambda': 22.49450443887811}. Best is trial 58 with value: 3.2896538950271395.
# [I 2026-06-06 14:08:14,094] Trial 63 finished with value: 3.3189176570253536 and parameters: {'n_estimators': 1948, 'learning_rate': 0.022704832683867342, 'max_depth': 2, 'min_child_weight': 2.9028359682177594, 'gamma': 4.317935070175954, 'subsample': 0.5117974475133299, 'colsample_bytree': 0.9282445746470508, 'reg_alpha': 0.00479644683058605, 'reg_lambda': 33.0618290116883}. Best is trial 58 with value: 3.2896538950271395.
# [I 2026-06-06 14:08:35,342] Trial 64 finished with value: 3.359170156206428 and parameters: {'n_estimators': 1283, 'learning_rate': 0.023137796943508836, 'max_depth': 2, 'min_child_weight': 2.9379658244687055, 'gamma': 4.476017500366979, 'subsample': 0.5031718028963241, 'colsample_bytree': 0.8446342671692594, 'reg_alpha': 0.00456745046662657, 'reg_lambda': 38.71953687091988}. Best is trial 58 with value: 3.2896538950271395.
# [I 2026-06-06 14:08:41,219] Trial 65 pruned.
# [I 2026-06-06 14:08:49,988] Trial 66 pruned.
# [I 2026-06-06 14:08:53,894] Trial 67 pruned.
# [I 2026-06-06 14:09:18,097] Trial 68 finished with value: 3.3067382818712066 and parameters: {'n_estimators': 1547, 'learning_rate': 0.018004357925947432, 'max_depth': 2, 'min_child_weight': 1.4553415706001485, 'gamma': 3.63628295129071, 'subsample': 0.5697812818138454, 'colsample_bytree': 0.9323580198736757, 'reg_alpha': 0.003700306616522819, 'reg_lambda': 21.624120225862068}. Best is trial 58 with value: 3.2896538950271395.
# [I 2026-06-06 14:09:42,690] Trial 69 pruned.
# [I 2026-06-06 14:09:46,301] Trial 70 pruned.
# [I 2026-06-06 14:10:03,271] Trial 71 finished with value: 3.304896188489821 and parameters: {'n_estimators': 1555, 'learning_rate': 0.02728857883018879, 'max_depth': 2, 'min_child_weight': 2.4726245275820156, 'gamma': 4.323079213750243, 'subsample': 0.5003569144824455, 'colsample_bytree': 0.9318544303841018, 'reg_alpha': 0.0050135958369916245, 'reg_lambda': 23.60360959120996}. Best is trial 58 with value: 3.2896538950271395.
# [I 2026-06-06 14:10:16,917] Trial 72 finished with value: 3.3411260957706976 and parameters: {'n_estimators': 1576, 'learning_rate': 0.02672030503471668, 'max_depth': 2, 'min_child_weight': 2.33908448520609, 'gamma': 4.00374980281161, 'subsample': 0.5575242901030257, 'colsample_bytree': 0.9854104642183698, 'reg_alpha': 0.021606673504924723, 'reg_lambda': 23.711661833995816}. Best is trial 58 with value: 3.2896538950271395.
# [I 2026-06-06 14:10:26,264] Trial 73 finished with value: 3.360127166099721 and parameters: {'n_estimators': 1374, 'learning_rate': 0.04163506183140011, 'max_depth': 2, 'min_child_weight': 1.759268242674567, 'gamma': 4.7173896953119465, 'subsample': 0.5432380056267476, 'colsample_bytree': 0.9024130800508174, 'reg_alpha': 0.0002983146571308757, 'reg_lambda': 6.8581294936591215}. Best is trial 58 with value: 3.2896538950271395.
# [I 2026-06-06 14:10:43,828] Trial 74 finished with value: 3.3074751854804956 and parameters: {'n_estimators': 1561, 'learning_rate': 0.029938620304745842, 'max_depth': 1, 'min_child_weight': 1.3840303101761515, 'gamma': 3.388740032285163, 'subsample': 0.5657984372585209, 'colsample_bytree': 0.9365649752058184, 'reg_alpha': 0.291618890404437, 'reg_lambda': 11.991323945940364}. Best is trial 58 with value: 3.2896538950271395.
# [I 2026-06-06 14:11:05,893] Trial 75 finished with value: 3.3000059161915276 and parameters: {'n_estimators': 1480, 'learning_rate': 0.019414346566485108, 'max_depth': 1, 'min_child_weight': 1.2713936427397996, 'gamma': 3.3999416135734792, 'subsample': 0.5014206562625312, 'colsample_bytree': 0.8757915959844123, 'reg_alpha': 0.2902161935710466, 'reg_lambda': 12.718275095775068}. Best is trial 58 with value: 3.2896538950271395.
# [I 2026-06-06 14:11:38,083] Trial 76 finished with value: 3.3509788479207083 and parameters: {'n_estimators': 1454, 'learning_rate': 0.010249873495251353, 'max_depth': 1, 'min_child_weight': 1.3494057832232094, 'gamma': 3.265305545349331, 'subsample': 0.7775672625679751, 'colsample_bytree': 0.9378625891167708, 'reg_alpha': 0.292827242350911, 'reg_lambda': 10.675346367979909}. Best is trial 58 with value: 3.2896538950271395.
# [I 2026-06-06 14:11:49,820] Trial 77 pruned.
# [I 2026-06-06 14:12:08,137] Trial 78 finished with value: 3.311105905750762 and parameters: {'n_estimators': 1556, 'learning_rate': 0.019603126906891248, 'max_depth': 1, 'min_child_weight': 2.402884832878455, 'gamma': 3.466607653963127, 'subsample': 0.5675072816509468, 'colsample_bytree': 0.8718928461861162, 'reg_alpha': 4.515129341392424, 'reg_lambda': 14.219903296595524}. Best is trial 58 with value: 3.2896538950271395.
# [I 2026-06-06 14:12:34,503] Trial 79 finished with value: 3.3026480406341587 and parameters: {'n_estimators': 1549, 'learning_rate': 0.013708434173238979, 'max_depth': 1, 'min_child_weight': 5.070961491640266, 'gamma': 3.403584563621794, 'subsample': 0.5957515969719596, 'colsample_bytree': 0.8696599276112501, 'reg_alpha': 4.27463498516313, 'reg_lambda': 13.203948877812543}. Best is trial 58 with value: 3.2896538950271395.
# [I 2026-06-06 14:12:43,310] Trial 80 pruned.
# [I 2026-06-06 14:13:03,573] Trial 81 finished with value: 3.3112894072043435 and parameters: {'n_estimators': 1544, 'learning_rate': 0.019195733206729494, 'max_depth': 1, 'min_child_weight': 5.227534914836499, 'gamma': 3.4387534541567155, 'subsample': 0.5909102817264809, 'colsample_bytree': 0.8322695282708474, 'reg_alpha': 8.333746600729429, 'reg_lambda': 6.622619927710559}. Best is trial 58 with value: 3.2896538950271395.
# [I 2026-06-06 14:13:21,820] Trial 82 finished with value: 3.3372110416427363 and parameters: {'n_estimators': 1434, 'learning_rate': 0.019023676589246374, 'max_depth': 1, 'min_child_weight': 1.1549601880472855, 'gamma': 3.041735391779304, 'subsample': 0.6322254469082876, 'colsample_bytree': 0.7996084118844782, 'reg_alpha': 5.440819187851367, 'reg_lambda': 3.7735594279001763}. Best is trial 58 with value: 3.2896538950271395.
# [I 2026-06-06 14:13:31,209] Trial 83 pruned.
# [I 2026-06-06 14:13:44,183] Trial 84 pruned.
# [I 2026-06-06 14:13:50,513] Trial 85 pruned.
# [I 2026-06-06 14:14:06,101] Trial 86 pruned.
# [I 2026-06-06 14:14:43,240] Trial 87 finished with value: 3.315590332409919 and parameters: {'n_estimators': 1575, 'learning_rate': 0.011493446714416098, 'max_depth': 1, 'min_child_weight': 0.7698239455559764, 'gamma': 3.14521716894421, 'subsample': 0.5740304470819987, 'colsample_bytree': 0.8362115152235302, 'reg_alpha': 7.726314255896527, 'reg_lambda': 13.459660706963083}. Best is trial 58 with value: 3.2896538950271395.
# [I 2026-06-06 14:15:10,707] Trial 88 finished with value: 3.3167057603065317 and parameters: {'n_estimators': 1658, 'learning_rate': 0.013683526017474787, 'max_depth': 1, 'min_child_weight': 3.298618331800016, 'gamma': 3.8116887740724406, 'subsample': 0.6509455680262006, 'colsample_bytree': 0.7830290277968133, 'reg_alpha': 3.8996563572814664, 'reg_lambda': 8.34209597123729}. Best is trial 58 with value: 3.2896538950271395.
# [I 2026-06-06 14:15:39,843] Trial 89 finished with value: 3.2991470029105825 and parameters: {'n_estimators': 1476, 'learning_rate': 0.019650744019082213, 'max_depth': 1, 'min_child_weight': 6.904134565709126, 'gamma': 2.7239033807014152, 'subsample': 0.6125944223597399, 'colsample_bytree': 0.8871628109426007, 'reg_alpha': 1.0260450842329858, 'reg_lambda': 19.288697207143805}. Best is trial 58 with value: 3.2896538950271395.
# [I 2026-06-06 14:16:07,319] Trial 90 finished with value: 3.308341973389539 and parameters: {'n_estimators': 1474, 'learning_rate': 0.015520882589153726, 'max_depth': 1, 'min_child_weight': 6.939340851477612, 'gamma': 2.5939930077577795, 'subsample': 0.6151440013005888, 'colsample_bytree': 0.8944449707664696, 'reg_alpha': 0.8777695135998902, 'reg_lambda': 35.47605653732176}. Best is trial 58 with value: 3.2896538950271395.
# [I 2026-06-06 14:16:30,635] Trial 91 finished with value: 3.3125326070126793 and parameters: {'n_estimators': 1464, 'learning_rate': 0.014631744644135128, 'max_depth': 1, 'min_child_weight': 6.928819951568262, 'gamma': 2.5576257728215763, 'subsample': 0.6825435408051923, 'colsample_bytree': 0.8926744692106575, 'reg_alpha': 0.9328858127753312, 'reg_lambda': 19.665342941379983}. Best is trial 58 with value: 3.2896538950271395.
# [I 2026-06-06 14:16:59,194] Trial 92 finished with value: 3.304075401361705 and parameters: {'n_estimators': 1494, 'learning_rate': 0.020585648932129125, 'max_depth': 1, 'min_child_weight': 8.711396609430325, 'gamma': 2.7011387324988183, 'subsample': 0.6255711853050847, 'colsample_bytree': 0.9173456959752557, 'reg_alpha': 0.06548179395396456, 'reg_lambda': 38.042602012708635}. Best is trial 58 with value: 3.2896538950271395.
# [I 2026-06-06 14:17:27,641] Trial 93 finished with value: 3.3079885985267072 and parameters: {'n_estimators': 1491, 'learning_rate': 0.015734003987912932, 'max_depth': 1, 'min_child_weight': 8.519515250008759, 'gamma': 2.7021222447400213, 'subsample': 0.61592613931833, 'colsample_bytree': 0.9401023803673993, 'reg_alpha': 0.06407927397099616, 'reg_lambda': 36.14743928771455}. Best is trial 58 with value: 3.2896538950271395.
# [I 2026-06-06 14:17:45,814] Trial 94 finished with value: 3.304316169735436 and parameters: {'n_estimators': 1230, 'learning_rate': 0.021563818791528227, 'max_depth': 1, 'min_child_weight': 8.756990232617463, 'gamma': 2.7005050862279627, 'subsample': 0.6386329725955403, 'colsample_bytree': 0.9540235012931856, 'reg_alpha': 0.08198397687990149, 'reg_lambda': 26.38144372608654}. Best is trial 58 with value: 3.2896538950271395.
# [I 2026-06-06 14:18:01,187] Trial 95 finished with value: 3.3076559597501136 and parameters: {'n_estimators': 1206, 'learning_rate': 0.02141297882897051, 'max_depth': 1, 'min_child_weight': 9.698774504714919, 'gamma': 2.9255473253237283, 'subsample': 0.6615565317832646, 'colsample_bytree': 0.9185939665259112, 'reg_alpha': 0.10514953473421026, 'reg_lambda': 27.907770849922237}. Best is trial 58 with value: 3.2896538950271395.
# [I 2026-06-06 14:18:11,243] Trial 96 pruned.
# [I 2026-06-06 14:18:20,806] Trial 97 pruned.
# [I 2026-06-06 14:18:38,037] Trial 98 finished with value: 3.3320147788620034 and parameters: {'n_estimators': 1092, 'learning_rate': 0.017299149243212804, 'max_depth': 2, 'min_child_weight': 6.360220487867053, 'gamma': 3.1990225671167503, 'subsample': 0.6758557566442093, 'colsample_bytree': 0.9869245921274561, 'reg_alpha': 0.010290345393786256, 'reg_lambda': 41.73629906198955}. Best is trial 58 with value: 3.2896538950271395.
# [I 2026-06-06 14:18:53,027] Trial 99 finished with value: 3.2962684937517404 and parameters: {'n_estimators': 1410, 'learning_rate': 0.02094069346185196, 'max_depth': 1, 'min_child_weight': 8.375727392384208, 'gamma': 2.6744671549417665, 'subsample': 0.5131991106436923, 'colsample_bytree': 0.954092580570463, 'reg_alpha': 0.03911603239575642, 'reg_lambda': 26.104299419141388}. Best is trial 58 with value: 3.2896538950271395.
# [I 2026-06-06 14:18:53,034] A new study created in memory with name: no-name-465bff66-5dba-4493-8cff-45ec0d9d64bb
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-06 14:19:00,872] Trial 0 finished with value: 3.4279224330656777 and parameters: {'n_estimators': 301, 'learning_rate': 0.03250177171527344, 'num_leaves': 37, 'max_depth': 4, 'min_child_samples': 52, 'min_split_gain': 1.7182749818971954, 'bagging_fraction': 0.8330451065490129, 'bagging_freq': 4, 'feature_fraction': 0.5145069122121801, 'lambda_l1': 0.04015454105555427, 'lambda_l2': 0.07175601133819473}. Best is trial 0 with value: 3.4279224330656777.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-06 14:19:50,846] Trial 1 finished with value: 3.450519897170531 and parameters: {'n_estimators': 1620, 'learning_rate': 0.008116618171663207, 'num_leaves': 18, 'max_depth': 9, 'min_child_samples': 37, 'min_split_gain': 0.8099788960945193, 'bagging_fraction': 0.6580482355091044, 'bagging_freq': 1, 'feature_fraction': 0.9216123471148523, 'lambda_l1': 0.43697071238567825, 'lambda_l2': 36.7185332724254}. Best is trial 0 with value: 3.4279224330656777.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-06 14:19:56,572] Trial 2 finished with value: 3.4334204614417976 and parameters: {'n_estimators': 820, 'learning_rate': 0.1255359023925396, 'num_leaves': 116, 'max_depth': 8, 'min_child_samples': 17, 'min_split_gain': 1.7941971599630686, 'bagging_fraction': 0.6490017503443813, 'bagging_freq': 2, 'feature_fraction': 0.5025647745322285, 'lambda_l1': 0.0007741455782248723, 'lambda_l2': 0.1717169091593679}. Best is trial 0 with value: 3.4279224330656777.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-06 14:20:01,836] Trial 3 finished with value: 3.706182912716626 and parameters: {'n_estimators': 1302, 'learning_rate': 0.13774020868800516, 'num_leaves': 233, 'max_depth': 10, 'min_child_samples': 81, 'min_split_gain': 0.2080378997095258, 'bagging_fraction': 0.5904572976289505, 'bagging_freq': 7, 'feature_fraction': 0.7059764916931793, 'lambda_l1': 0.6097531961875766, 'lambda_l2': 1.4405915859050216}. Best is trial 0 with value: 3.4279224330656777.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-06 14:20:26,919] Trial 4 finished with value: 3.483729626889107 and parameters: {'n_estimators': 1287, 'learning_rate': 0.008816320113501107, 'num_leaves': 230, 'max_depth': 3, 'min_child_samples': 64, 'min_split_gain': 1.987144984788207, 'bagging_fraction': 0.8678635407535604, 'bagging_freq': 4, 'feature_fraction': 0.7803315847218675, 'lambda_l1': 5.026890229380336e-05, 'lambda_l2': 2.6067223030440956}. Best is trial 0 with value: 3.4279224330656777.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-06 14:20:32,659] Trial 5 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-06 14:20:39,632] Trial 6 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-06 14:20:42,168] Trial 7 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-06 14:20:43,582] Trial 8 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-06 14:20:59,330] Trial 9 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-06 14:21:54,997] Trial 10 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-06 14:22:31,839] Trial 11 finished with value: 3.465870879571942 and parameters: {'n_estimators': 598, 'learning_rate': 0.05642532812077397, 'num_leaves': 112, 'max_depth': 6, 'min_child_samples': 6, 'min_split_gain': 1.5728258526088479, 'bagging_fraction': 0.7368592807094115, 'bagging_freq': 1, 'feature_fraction': 0.5259001926996263, 'lambda_l1': 0.0007798973479050788, 'lambda_l2': 0.017382620881059765}. Best is trial 0 with value: 3.4279224330656777.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-06 14:23:55,180] Trial 12 finished with value: 3.425397477015305 and parameters: {'n_estimators': 517, 'learning_rate': 0.024262419120912624, 'num_leaves': 157, 'max_depth': 6, 'min_child_samples': 15, 'min_split_gain': 1.6887824309347674, 'bagging_fraction': 0.7533243400910767, 'bagging_freq': 2, 'feature_fraction': 0.5065623605708911, 'lambda_l1': 0.006165921259221086, 'lambda_l2': 0.05114673429014843}. Best is trial 12 with value: 3.425397477015305.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-06 14:25:43,902] Trial 13 finished with value: 3.4075031320535087 and parameters: {'n_estimators': 337, 'learning_rate': 0.022578327487275188, 'num_leaves': 168, 'max_depth': 5, 'min_child_samples': 31, 'min_split_gain': 1.2104408428825577, 'bagging_fraction': 0.7741904208705135, 'bagging_freq': 3, 'feature_fraction': 0.5881265628661578, 'lambda_l1': 0.02559020904036742, 'lambda_l2': 0.012465220013992015}. Best is trial 13 with value: 3.4075031320535087.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-06 14:26:48,405] Trial 14 finished with value: 3.4188247685910818 and parameters: {'n_estimators': 544, 'learning_rate': 0.02013235568641657, 'num_leaves': 168, 'max_depth': 6, 'min_child_samples': 32, 'min_split_gain': 1.1526647845049771, 'bagging_fraction': 0.7646146105305598, 'bagging_freq': 2, 'feature_fraction': 0.591161964450205, 'lambda_l1': 0.012242661910714407, 'lambda_l2': 0.002739932991191867}. Best is trial 13 with value: 3.4075031320535087.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-06 14:26:55,478] Trial 15 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-06 14:27:17,345] Trial 16 finished with value: 3.4052463357977785 and parameters: {'n_estimators': 661, 'learning_rate': 0.06562028161232118, 'num_leaves': 163, 'max_depth': 6, 'min_child_samples': 39, 'min_split_gain': 1.1266405474044552, 'bagging_fraction': 0.9826565708275925, 'bagging_freq': 2, 'feature_fraction': 0.7152788085776162, 'lambda_l1': 0.05793371056327044, 'lambda_l2': 0.009249589894977013}. Best is trial 16 with value: 3.4052463357977785.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-06 14:27:22,232] Trial 17 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-06 14:27:39,110] Trial 18 finished with value: 3.451219720768362 and parameters: {'n_estimators': 330, 'learning_rate': 0.054400323407327894, 'num_leaves': 147, 'max_depth': 2, 'min_child_samples': 47, 'min_split_gain': 1.3103578013683534, 'bagging_fraction': 0.944395804805049, 'bagging_freq': 5, 'feature_fraction': 0.9991355829538757, 'lambda_l1': 4.42941937336854, 'lambda_l2': 0.007335302401385905}. Best is trial 16 with value: 3.4052463357977785.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-06 14:31:03,408] Trial 19 finished with value: 3.4098307035043374 and parameters: {'n_estimators': 971, 'learning_rate': 0.010610654633281622, 'num_leaves': 252, 'max_depth': 7, 'min_child_samples': 24, 'min_split_gain': 0.8489074890132076, 'bagging_fraction': 0.9336586204819712, 'bagging_freq': 1, 'feature_fraction': 0.6998125557000708, 'lambda_l1': 0.04048852590278449, 'lambda_l2': 0.006193431969451585}. Best is trial 16 with value: 3.4052463357977785.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-06 14:31:13,349] Trial 20 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-06 14:33:17,801] Trial 21 finished with value: 3.4176859793473797 and parameters: {'n_estimators': 967, 'learning_rate': 0.010384611145605642, 'num_leaves': 256, 'max_depth': 7, 'min_child_samples': 23, 'min_split_gain': 0.9123525930454635, 'bagging_fraction': 0.9422008743303576, 'bagging_freq': 1, 'feature_fraction': 0.6754055340740563, 'lambda_l1': 0.07984318719423437, 'lambda_l2': 0.010093252310351152}. Best is trial 16 with value: 3.4052463357977785.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-06 14:36:48,437] Trial 22 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-06 14:37:59,701] Trial 23 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-06 14:39:10,723] Trial 24 finished with value: 3.413615307316206 and parameters: {'n_estimators': 731, 'learning_rate': 0.026242797810088755, 'num_leaves': 250, 'max_depth': 8, 'min_child_samples': 32, 'min_split_gain': 0.6164630353988318, 'bagging_fraction': 0.9694848785557418, 'bagging_freq': 2, 'feature_fraction': 0.7842745333436444, 'lambda_l1': 0.04404797665804821, 'lambda_l2': 0.052866847963598834}. Best is trial 16 with value: 3.4052463357977785.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-06 14:46:55,817] Trial 25 finished with value: 3.4130921285067655 and parameters: {'n_estimators': 1184, 'learning_rate': 0.006139498468894654, 'num_leaves': 133, 'max_depth': 5, 'min_child_samples': 19, 'min_split_gain': 0.6699535523993186, 'bagging_fraction': 0.8980365376960783, 'bagging_freq': 1, 'feature_fraction': 0.6858775196059491, 'lambda_l1': 1.1771307482066513, 'lambda_l2': 0.005208870931652718}. Best is trial 16 with value: 3.4052463357977785.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-06 14:47:34,773] Trial 26 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-06 14:48:07,528] Trial 27 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-06 14:48:31,304] Trial 28 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-06 14:49:09,052] Trial 29 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-06 14:49:18,730] Trial 30 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-06 14:51:34,049] Trial 31 finished with value: 3.410996039789449 and parameters: {'n_estimators': 1487, 'learning_rate': 0.006778090791313264, 'num_leaves': 136, 'max_depth': 5, 'min_child_samples': 18, 'min_split_gain': 0.7422534943550853, 'bagging_fraction': 0.8677633772241372, 'bagging_freq': 1, 'feature_fraction': 0.6994838540283903, 'lambda_l1': 1.1787235890025418, 'lambda_l2': 0.004735543592040302}. Best is trial 16 with value: 3.4052463357977785.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-06 14:51:53,546] Trial 32 pruned.
# ...
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
#                   period       method  count     mae_f    rmse_f
# 0   validation_2024_2025      xgboost    664  2.219795  3.293241
# 1   validation_2024_2025     lightgbm    664  2.328704  3.430549
# 2   validation_2024_2025     catboost    664  2.264221  3.333379
# 3   validation_2024_2025     hrrr_raw    664  2.427198  3.642842
# 4   validation_2024_2025      gfs_raw    664  2.792138  3.930603
# 5              test_2026      xgboost    133  3.027904  4.344040
# 6              test_2026     lightgbm    133  3.126845  4.527050
# 7              test_2026     catboost    133  3.129860  4.537605
# 8              test_2026  ridge_stack    133  2.882420  4.225630
# 9              test_2026     hrrr_raw    133  3.395743  4.730333
# 10             test_2026      gfs_raw    133  3.421896  4.734724

# %% [markdown]
# ## 2026 Weather Brackets

# %%
result.bracket_metrics
# Out:
#         method  count     mae_f    rmse_f  bracket_accuracy_pct
# 0      xgboost    133  3.027904  4.344040             26.315789
# 1     lightgbm    133  3.126845  4.527050             29.323308
# 2     catboost    133  3.129860  4.537605              25.56391
# 3  ridge_stack    133  2.882420  4.225630             33.082707
# 4     hrrr_raw    133  3.395743  4.730333             21.052632
# 5      gfs_raw    133  3.421896  4.734724              24.81203

# %%
import pandas as pd


def adjacent_brackets(bracket):
    if pd.isna(bracket):
        return []
    text = str(bracket).strip()
    if not text or "-" not in text:
        return []
    try:
        lower = int(text.split("-", 1)[0])
    except ValueError:
        return []
    return [
        f"{lower - 2}-{lower - 1}",
        f"{lower}-{lower + 1}",
        f"{lower + 2}-{lower + 3}",
    ]


bracket_3way = result.bracket_predictions.copy()

valid = bracket_3way["actual_bracket"].notna() & bracket_3way["predicted_bracket"].astype(str).str.strip().ne("")
bracket_3way = bracket_3way.loc[valid].copy()
bracket_3way["picked_brackets"] = bracket_3way["predicted_bracket"].map(adjacent_brackets)
bracket_3way["three_bracket_hit"] = bracket_3way.apply(
    lambda row: row["actual_bracket"] in row["picked_brackets"],
    axis=1,
)

three_bracket_accuracy = (
    bracket_3way
    .groupby("method", as_index=False)
    .agg(
        count=("three_bracket_hit", "size"),
        exact_bracket_accuracy_pct=("bracket_hit", lambda x: x.mean() * 100),
        three_bracket_accuracy_pct=("three_bracket_hit", lambda x: x.mean() * 100),
    )
    .sort_values("three_bracket_accuracy_pct", ascending=False)
)

three_bracket_accuracy
# Out:
#         method  count  exact_bracket_accuracy_pct  three_bracket_accuracy_pct
# 4  ridge_stack    133                   33.082707                   70.676692
# 0     catboost    133                    25.56391                   68.421053
# 5      xgboost    133                   26.315789                   67.669173
# 3     lightgbm    133                   29.323308                   66.165414
# 2     hrrr_raw    133                   21.052632                   57.894737
# 1      gfs_raw    133                    24.81203                   56.390977

# %% [markdown]
# # Polymarket Weather Exploratory Analysis
#
# Run the CLI first, then use this notebook to inspect station mappings, model errors, and trading research candidates.

# %%
from pathlib import Path
import pandas as pd

processed = Path('../data/processed')
outputs = Path('../data/outputs')
markets = pd.read_csv(processed / 'polymarket_markets.csv')
station_map = pd.read_csv(processed / 'polymarket_station_map.csv')
errors = pd.read_csv(processed / 'model_errors.csv')
trading = pd.read_csv(outputs / 'trading_research_table.csv')

station_map.head(), errors.head(), trading.head()

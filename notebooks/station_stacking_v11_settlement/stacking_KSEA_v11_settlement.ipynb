# %% [markdown]
# # Station Stacking v11 Settlement - KSEA
#
# Experimental notebook for `KSEA`.
#
# This controlled rerun keeps the exact v11 feature/model contract, replaces daily-high labels with settlement-first Wunderground station history when available, and writes separate artifacts to `data/calibration/station_stacking_v11_settlement`.

# %%
from pathlib import Path
import os
import sys
import warnings

warnings.filterwarnings("ignore", message="IProgress not found.*")
warnings.filterwarnings("ignore", message="Skipping features without any observed values.*")

PROJECT_ROOT = Path.cwd().resolve()
while not (PROJECT_ROOT / "src" / "calibration" / "station_stacking.py").exists():
    if PROJECT_ROOT.parent == PROJECT_ROOT:
        raise RuntimeError("Could not find project root containing src/calibration/station_stacking.py")
    PROJECT_ROOT = PROJECT_ROOT.parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

os.environ["WEATHER_RESEARCH_INCLUDE_DIRECT_NBM"] = "1"

STATION_ID = "KSEA"
PROVIDERS = ("gfs", "hrrr", "nbm")
TREND_COLUMNS = [
    "observed_temp_change_last_1h_f",
    "observed_temp_change_last_3h_f",
    "observed_morning_warmup_rate_f_per_hour",
    "observed_high_so_far_change_since_9am_f",
]
TIMING_MODE = "same_day_11am_live_safe"
FAST_MODE = False
OPTUNA_TRIALS = 30
STACK_OPTUNA_TRIALS = 30
OPTUNA_STARTUP_TRIALS = 15
STACK_OPTUNA_STARTUP_TRIALS = 15
OPTUNA_METRIC = "mae_f"
OPTUNA_VERBOSE = True
MODEL_VERSION = "station_high_regressor_v11_wunderground_settlement_stack"
PROJECT_ROOT
# Out:
# WindowsPath('D:/dev/weather-research')

# %%
import numpy as np
import pandas as pd

from src.export_station_stacking_v2_models import export_station_model_weights
from src.calibration.station_stacking import (
    StationStackingConfig,
    V11_DROPPED_FEATURE_COLUMNS,
    V11_FEATURE_COLUMNS,
    YEAR_SPLIT_EXPANDING_FOLDS,
    missing_model_dependencies,
    provider_availability,
    run_station_year_split_experiment,
)

# %% [markdown]
# ## V11 Contract
#
# `feature_version="v11"` keeps the v9 feature contract and remaining-warmup target, but trains base learners with Huber-style objectives while retaining the ridge stack selected by validation MAE.

# %%
fold_spec = pd.DataFrame(
    [
        {
            "fold": fold.name,
            "train_start_year": fold.train_start_year,
            "train_end_year": fold.train_end_year,
            "validation_year": fold.validation_year,
        }
        for fold in YEAR_SPLIT_EXPANDING_FOLDS
    ]
)

fold_spec
# Out:
#                      fold  train_start_year  train_end_year  validation_year
# 0  fold_2021_2023_to_2024              2021            2023             2024
# 1  fold_2021_2024_to_2025              2021            2024             2025

# %%
V11_FEATURE_COLUMNS, sorted(V11_DROPPED_FEATURE_COLUMNS)
# Out:
# (['v2_recent_heat_anomaly_f',
#   'v2_recent_heat_momentum_f',
#   'v2_morning_warmup_to_consensus_f',
#   'v2_consensus_minus_7d_actual_f',
#   'v2_spread_per_warmup_f',
#   'v2_humidity_warmup_interaction',
#   'v3_high_so_far_above_current_f',
#   'v3_remaining_warmup_from_high_so_far_f',
#   'v3_high_so_far_minus_lag_1d_f',
#   'v3_high_so_far_minus_7d_actual_f',
#   'v3_remaining_warmup_per_spread_f',
#   'v3_humidity_remaining_warmup_interaction',
#   'v4_forecast_precip_total_mean_mm',
#   'v4_forecast_precip_total_max_mm',
#   'v4_forecast_precip_total_spread_mm',
#   'v4_forecast_precip_max_1h_mean_mm',
#   'v4_forecast_precip_hours_mean',
#   'v4_forecast_precip_intensity_mean',
#   'v4_forecast_precip_intensity_max',
#   'v4_any_forecast_precip',
#   'v4_all_forecast_precip',
#   'v4_observed_precip_any',
#   'v4_observed_precip_recent_mm_est',
#   'v4_forecast_total_minus_observed_recent_mm',
#   'v4_forecast_observed_precip_match',
#   'v4_forecast_wet_observed_dry',
#   'v4_observed_wet_forecast_dry',
#   'v4_precip_humidity_interaction',
#   'v4_precip_remaining_warmup_interaction',
#   'observed_temp_change_last_1h_f',
#   'observed_temp_change_last_3h_f',
#   'observed_morning_warmup_rate_f_per_hour',
#   'observed_high_so_far_change_since_9am_f',
#   'v8_provider_max_remaining_from_high_so_far_f',
#   'v8_provider_min_remaining_from_high_so_far_f',
#   'v8_provider_median_remaining_from_high_so_far_f',
#   'v8_provider_spread_per_remaining_warmup_f',
#   'v8_month_remaining_warmup_mean_f',
#   'v8_month_remaining_warmup_count',
#   'v8_recent_remaining_warmup_7d_mean_f',
#   'v8_recent_remaining_warmup_30d_mean_f',
#   'v8_provider_mean_remaining_vs_month_normal_f',
#   'v8_cloud_cover_mean_remaining_warmup_interaction',
#   'v8_cloud_cover_max_remaining_warmup_interaction',
#   'v8_precip_total_remaining_warmup_interaction',
#   'v8_precip_max_1h_remaining_warmup_interaction',
#   'v8_wind_speed_mean_remaining_warmup_interaction',
#   'v8_wind_gust_max_remaining_warmup_interaction',
#   'v8_forecast_dewpoint_mean_f',
#   'v8_forecast_dewpoint_depression_mean_f',
#   'v8_dewpoint_mean_remaining_warmup_interaction',
#   'v8_dewpoint_depression_remaining_warmup_interaction',
#   'climatology_high_10y_f',
#   'climatology_high_10y_std_f',
#   'climatology_high_10y_count',
#   'provider_mean_minus_climatology_10y_f',
#   'observed_temp_minus_climatology_10y_f',
#   'observed_high_so_far_minus_climatology_10y_f'],
#  ['actual_minus_climatology_10y_f_DIAGNOSTIC_ONLY',
#   'climatology_source_end_year',
#   'climatology_source_start_year',
#   'gfs_as_of_hour_local',
#   'gfs_available',
#   'gfs_forecast_window_hours',
#   'gfs_grid_dist_km_mean',
#   'gfs_horizon_hours',
#   'gfs_hrrr_grid_dist_km_mean_abs_diff_f',
#   'gfs_hrrr_grid_dist_km_mean_diff_f',
#   'gfs_issue_hour_utc',
#   'gfs_missing',
#   'hrrr_as_of_hour_local',
#   'hrrr_available',
#   'hrrr_forecast_hour_max',
#   'hrrr_forecast_hour_min',
#   'hrrr_forecast_lead_hours',
#   'hrrr_forecast_window_hours',
#   'hrrr_grid_dist_km_mean',
#   'hrrr_horizon_hours',
#   'hrrr_issue_hour_local',
#   'hrrr_issue_hour_utc',
#   'hrrr_missing',
#   'is_active_polymarket_station',
#   'lat',
#   'lon',
#   'nbm_as_of_hour_local',
#   'nbm_available',
#   'nbm_forecast_window_hours',
#   'nbm_horizon_hours',
#   'nbm_issue_hour_local',
#   'nbm_issue_hour_utc',
#   'nbm_missing',
#   'observed_fetch_status',
#   'observed_observation_type',
#   'observed_pressure_source',
#   'provider_count_available',
#   'year'])

# %% [markdown]
# ## Data Availability

# %%
availability = provider_availability(
    PROJECT_ROOT,
    timing_mode=TIMING_MODE,
    providers=PROVIDERS,
)

availability.loc[availability["station_id"].eq(STATION_ID)]
# Out:
#    station_id provider  row_count first_contract_date last_contract_date
# 24       KSEA      gfs       1992          2021-01-01         2026-06-21
# 25       KSEA     hrrr       1998          2021-01-01         2026-06-21
# 26       KSEA      nbm       1997          2021-01-01         2026-06-21

# %% [markdown]
# ## Model Scores

# %%
missing_packages = missing_model_dependencies()
if missing_packages:
    raise ImportError(
        "Missing station-stacking ML packages: "
        + ", ".join(missing_packages)
        + ". Install them with: python -m pip install -r requirements.txt"
    )

config = StationStackingConfig(
    station_id=STATION_ID,
    project_root=PROJECT_ROOT,
    timing_mode=TIMING_MODE,
    providers=PROVIDERS,
    fast_mode=FAST_MODE,
    optuna_trials=OPTUNA_TRIALS,
    stack_optuna_trials=STACK_OPTUNA_TRIALS,
    optuna_startup_trials=OPTUNA_STARTUP_TRIALS,
    stack_optuna_startup_trials=STACK_OPTUNA_STARTUP_TRIALS,
    optuna_metric=OPTUNA_METRIC,
    optuna_verbose=OPTUNA_VERBOSE,
    feature_version="v11",
    target_mode="remaining_warmup",
    target_source="settlement_first",
    base_model_methods=("xgboost", "lightgbm", "catboost"),
    stack_enabled=True,
    hyperparameter_space="wide",
    year_split_folds=YEAR_SPLIT_EXPANDING_FOLDS,
    year_split_test_train_years=(2021, 2025),
    year_split_test_year=2026,
    output_dir=PROJECT_ROOT / "data" / "calibration" / "station_stacking_v11_settlement",
)

config.resolved_optuna_storage_path()
# Out:
# WindowsPath('D:/dev/weather-research/data/calibration/station_stacking_v11_settlement/KSEA_optuna.sqlite3')

# %%
result = run_station_year_split_experiment(config)
result.scoreboard
# Out:
# [I 2026-07-08 13:10:36,203] A new study created in RDB with name: KSEA_v11_remaining_warmup_base_xgboost_mae_f
# [I 2026-07-08 13:10:40,451] Trial 0 finished with value: 1.5104906530326412 and parameters: {'n_estimators': 1342, 'learning_rate': 0.19043899115982607, 'max_depth': 9, 'min_child_weight': 2.481040974867813, 'gamma': 2.340279606636548, 'subsample': 0.4513964382185317, 'colsample_bytree': 0.3877543479093296, 'reg_alpha': 2.478071022662141, 'reg_lambda': 0.6132587025321562}. Best is trial 0 with value: 1.5104906530326412.
# [I 2026-07-08 13:11:13,847] Trial 1 finished with value: 1.2640667756977186 and parameters: {'n_estimators': 2493, 'learning_rate': 0.001120367191095075, 'max_depth': 12, 'min_child_weight': 21.368329072358772, 'gamma': 3.185086660174142, 'subsample': 0.4681862286846154, 'colsample_bytree': 0.46921293140473197, 'reg_alpha': 4.476173538513514e-07, 'reg_lambda': 0.20253776634919213}. Best is trial 1 with value: 1.2640667756977186.
# [I 2026-07-08 13:11:24,012] Trial 2 finished with value: 1.2620098567356743 and parameters: {'n_estimators': 1540, 'learning_rate': 0.004992867109217114, 'max_depth': 8, 'min_child_weight': 0.03613894271216528, 'gamma': 4.3821697280282725, 'subsample': 0.5881351981408995, 'colsample_bytree': 0.6464454897410734, 'reg_alpha': 0.26430874752361627, 'reg_lambda': 0.0018119678627933364}. Best is trial 2 with value: 1.2620098567356743.
# [I 2026-07-08 13:11:28,461] Trial 3 finished with value: 1.3628288236786321 and parameters: {'n_estimators': 1824, 'learning_rate': 0.026337502897485255, 'max_depth': 1, 'min_child_weight': 2.69264691008618, 'gamma': 2.557861855309373, 'subsample': 0.39228353544043165, 'colsample_bytree': 0.9667755992146666, 'reg_alpha': 38.6887231523051, 'reg_lambda': 12.408975837016275}. Best is trial 2 with value: 1.2620098567356743.
# [I 2026-07-08 13:12:09,271] Trial 4 finished with value: 1.3536581182052512 and parameters: {'n_estimators': 1101, 'learning_rate': 0.0017147936629846843, 'max_depth': 9, 'min_child_weight': 0.5762487216478605, 'gamma': 1.8305735226716824, 'subsample': 0.6718649915723256, 'colsample_bytree': 0.37235253872489193, 'reg_alpha': 8.162906555194692, 'reg_lambda': 0.004271500153828077}. Best is trial 2 with value: 1.2620098567356743.
# [I 2026-07-08 13:12:40,132] Trial 5 finished with value: 1.3006630564757349 and parameters: {'n_estimators': 2336, 'learning_rate': 0.00559067775661512, 'max_depth': 7, 'min_child_weight': 1.5375920235481764, 'gamma': 2.7728168328829055, 'subsample': 0.980230008046963, 'colsample_bytree': 0.8538363351847245, 'reg_alpha': 18.792618557420877, 'reg_lambda': 43.484449457612314}. Best is trial 2 with value: 1.2620098567356743.
# [I 2026-07-08 13:12:41,870] Trial 6 finished with value: 1.25758903270911 and parameters: {'n_estimators': 2113, 'learning_rate': 0.16240489353272883, 'max_depth': 2, 'min_child_weight': 0.06080390190296603, 'gamma': 0.678409333658071, 'subsample': 0.5614647149961218, 'colsample_bytree': 0.6026402382981633, 'reg_alpha': 1.8037999945880162e-07, 'reg_lambda': 16.668629892722056}. Best is trial 6 with value: 1.25758903270911.
# [I 2026-07-08 13:12:48,954] Trial 7 finished with value: 1.284233487513408 and parameters: {'n_estimators': 1281, 'learning_rate': 0.0047169807141865345, 'max_depth': 7, 'min_child_weight': 0.0366181922039243, 'gamma': 12.032954711310595, 'subsample': 0.398457918391851, 'colsample_bytree': 0.9914765087903362, 'reg_alpha': 0.18490013641000916, 'reg_lambda': 0.0017869543989965139}. Best is trial 6 with value: 1.25758903270911.
# [I 2026-07-08 13:12:49,609] Trial 8 pruned.
# [I 2026-07-08 13:12:55,929] Trial 9 finished with value: 1.2397312396728266 and parameters: {'n_estimators': 2201, 'learning_rate': 0.006215464818952927, 'max_depth': 1, 'min_child_weight': 0.17535949529764422, 'gamma': 4.877749830401205, 'subsample': 0.8242440159197416, 'colsample_bytree': 0.7644123563808884, 'reg_alpha': 4.4315220126915325, 'reg_lambda': 0.09450187118503514}. Best is trial 9 with value: 1.2397312396728266.
# [I 2026-07-08 13:12:56,989] Trial 10 pruned.
# [I 2026-07-08 13:13:02,336] Trial 11 pruned.
# [I 2026-07-08 13:13:07,421] Trial 12 pruned.
# [I 2026-07-08 13:13:08,829] Trial 13 finished with value: 1.2809028155072577 and parameters: {'n_estimators': 693, 'learning_rate': 0.13813474572232612, 'max_depth': 7, 'min_child_weight': 16.973078532467014, 'gamma': 13.4413694988524, 'subsample': 0.5567022587317115, 'colsample_bytree': 0.4215337509429899, 'reg_alpha': 5.435280359192946e-08, 'reg_lambda': 0.049115547267693904}. Best is trial 9 with value: 1.2397312396728266.
# [I 2026-07-08 13:13:10,993] Trial 14 finished with value: 1.2650804954499053 and parameters: {'n_estimators': 2872, 'learning_rate': 0.11587248002108354, 'max_depth': 1, 'min_child_weight': 1.1040511903162256, 'gamma': 6.261165047231685, 'subsample': 0.49437007680597467, 'colsample_bytree': 0.4279124887668938, 'reg_alpha': 1.125594744942969e-06, 'reg_lambda': 87.35792858155622}. Best is trial 9 with value: 1.2397312396728266.
# [I 2026-07-08 13:13:14,559] Trial 15 finished with value: 1.2788990688151882 and parameters: {'n_estimators': 3311, 'learning_rate': 0.021882197214300323, 'max_depth': 3, 'min_child_weight': 0.011927859366875052, 'gamma': 0.14583408410588616, 'subsample': 0.7986605978199443, 'colsample_bytree': 0.7925816793363801, 'reg_alpha': 0.000682381751719726, 'reg_lambda': 0.8912768993161009}. Best is trial 9 with value: 1.2397312396728266.
# [I 2026-07-08 13:13:19,034] Trial 16 finished with value: 1.2521344806982104 and parameters: {'n_estimators': 2000, 'learning_rate': 0.010276279465997379, 'max_depth': 3, 'min_child_weight': 0.21462366415816406, 'gamma': 8.034363960532348, 'subsample': 0.791072070839649, 'colsample_bytree': 0.5690357865213579, 'reg_alpha': 1.5951939686644245e-10, 'reg_lambda': 0.04930333822034091}. Best is trial 9 with value: 1.2397312396728266.
# [I 2026-07-08 13:13:20,991] Trial 17 pruned.
# [I 2026-07-08 13:13:21,931] Trial 18 pruned.
# [I 2026-07-08 13:13:32,664] Trial 19 finished with value: 1.229708910885251 and parameters: {'n_estimators': 2054, 'learning_rate': 0.0032530471166634487, 'max_depth': 3, 'min_child_weight': 0.18171322743329588, 'gamma': 9.258905935750837, 'subsample': 0.8764490931760355, 'colsample_bytree': 0.5709449417633365, 'reg_alpha': 0.0035849619178030135, 'reg_lambda': 1.4522005847259958}. Best is trial 19 with value: 1.229708910885251.
# [I 2026-07-08 13:13:45,491] Trial 20 finished with value: 1.2295662939039105 and parameters: {'n_estimators': 3371, 'learning_rate': 0.002906215880615357, 'max_depth': 2, 'min_child_weight': 0.011065136021091005, 'gamma': 9.761789245109593, 'subsample': 0.889440631894038, 'colsample_bytree': 0.9109027592046143, 'reg_alpha': 0.011131192957886156, 'reg_lambda': 1.8945396009557154}. Best is trial 20 with value: 1.2295662939039105.
# [I 2026-07-08 13:13:56,964] Trial 21 finished with value: 1.2309236527179386 and parameters: {'n_estimators': 3357, 'learning_rate': 0.002691702568750416, 'max_depth': 2, 'min_child_weight': 0.010283299393332246, 'gamma': 9.90898868742687, 'subsample': 0.8706470975824592, 'colsample_bytree': 0.9046717698055134, 'reg_alpha': 0.01655384361820373, 'reg_lambda': 2.0356378323895914}. Best is trial 20 with value: 1.2295662939039105.
# [I 2026-07-08 13:14:13,170] Trial 22 finished with value: 1.2277843610235157 and parameters: {'n_estimators': 3469, 'learning_rate': 0.0021615808163972456, 'max_depth': 3, 'min_child_weight': 0.01786815574706905, 'gamma': 9.935237321166024, 'subsample': 0.8852394786669182, 'colsample_bytree': 0.9043504350933096, 'reg_alpha': 0.001036352768406767, 'reg_lambda': 2.0029987076043043}. Best is trial 22 with value: 1.2277843610235157.
# [I 2026-07-08 13:14:29,733] Trial 23 finished with value: 1.2370631193988535 and parameters: {'n_estimators': 3496, 'learning_rate': 0.002726239717317172, 'max_depth': 4, 'min_child_weight': 0.02041162758890082, 'gamma': 10.237575885597778, 'subsample': 0.9213647234702445, 'colsample_bytree': 0.9092856488271192, 'reg_alpha': 0.0015881031335481088, 'reg_lambda': 2.4170505008769716}. Best is trial 22 with value: 1.2277843610235157.
# [I 2026-07-08 13:14:43,146] Trial 24 finished with value: 1.2433094453171862 and parameters: {'n_estimators': 2900, 'learning_rate': 0.0024973826108755253, 'max_depth': 3, 'min_child_weight': 0.08276057851519489, 'gamma': 9.767131565653834, 'subsample': 0.9981323636681808, 'colsample_bytree': 0.9279127517159691, 'reg_alpha': 0.00843500958687033, 'reg_lambda': 0.8028812989528697}. Best is trial 22 with value: 1.2277843610235157.
# [I 2026-07-08 13:14:55,662] Trial 25 pruned.
# [I 2026-07-08 13:14:59,972] Trial 26 finished with value: 1.2539314277076368 and parameters: {'n_estimators': 2688, 'learning_rate': 0.009148754528993611, 'max_depth': 2, 'min_child_weight': 0.10751097270278007, 'gamma': 8.766825282604684, 'subsample': 0.8659897128375396, 'colsample_bytree': 0.7048000469246536, 'reg_alpha': 0.04657769104095179, 'reg_lambda': 0.35189570426115957}. Best is trial 22 with value: 1.2277843610235157.
# [I 2026-07-08 13:15:19,875] Trial 27 finished with value: 1.2392663765688936 and parameters: {'n_estimators': 3137, 'learning_rate': 0.0019502762588971233, 'max_depth': 4, 'min_child_weight': 0.4452412312976287, 'gamma': 11.000500657748251, 'subsample': 0.9247121221837726, 'colsample_bytree': 0.946429910086817, 'reg_alpha': 0.0001151135747085441, 'reg_lambda': 3.056131425614761}. Best is trial 22 with value: 1.2277843610235157.
# [I 2026-07-08 13:15:24,150] Trial 28 pruned.
# [I 2026-07-08 13:15:24,928] Trial 29 pruned.
# [I 2026-07-08 13:15:24,998] A new study created in RDB with name: KSEA_v11_remaining_warmup_base_lightgbm_mae_f
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-08 13:15:27,308] Trial 0 finished with value: 1.2534684418708901 and parameters: {'n_estimators': 447, 'learning_rate': 0.028873871707375695, 'num_leaves': 71, 'max_depth': 5, 'min_child_samples': 83, 'min_split_gain': 4.295687454742988, 'bagging_fraction': 0.7829586385137167, 'bagging_freq': 4, 'feature_fraction': 0.3688589858758342, 'lambda_l1': 0.06382334403151436, 'lambda_l2': 0.03080292177315921, 'huber_alpha': 0.95}. Best is trial 0 with value: 1.2534684418708901.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-08 13:15:30,074] Trial 1 finished with value: 1.4240164326902118 and parameters: {'n_estimators': 812, 'learning_rate': 0.009357081249483435, 'num_leaves': 164, 'max_depth': 2, 'min_child_samples': 211, 'min_split_gain': 4.244695738724308, 'bagging_fraction': 0.9814523094330022, 'bagging_freq': 3, 'feature_fraction': 0.9704172813206324, 'lambda_l1': 2.234088279028776e-05, 'lambda_l2': 1.6594154120142632, 'huber_alpha': 0.85}. Best is trial 0 with value: 1.2534684418708901.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-08 13:15:31,149] Trial 2 finished with value: 2.8161749679629056 and parameters: {'n_estimators': 67, 'learning_rate': 0.02007090910723469, 'num_leaves': 246, 'max_depth': 10, 'min_child_samples': 245, 'min_split_gain': 4.543313789155439, 'bagging_fraction': 0.9415994992571017, 'bagging_freq': 4, 'feature_fraction': 0.41761231740559585, 'lambda_l1': 1.4824332354449863e-08, 'lambda_l2': 101.18939970488272, 'huber_alpha': 0.85}. Best is trial 0 with value: 1.2534684418708901.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-08 13:15:32,326] Trial 3 finished with value: 1.4172132049856299 and parameters: {'n_estimators': 1000, 'learning_rate': 0.1413663860910666, 'num_leaves': 109, 'max_depth': 7, 'min_child_samples': 249, 'min_split_gain': 3.678635407535604, 'bagging_fraction': 0.6392899181182937, 'bagging_freq': 4, 'feature_fraction': 0.6173160679063129, 'lambda_l1': 0.052948773379180566, 'lambda_l2': 0.032760577756785814, 'huber_alpha': 0.85}. Best is trial 0 with value: 1.2534684418708901.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-08 13:15:34,028] Trial 4 finished with value: 2.3973584064546785 and parameters: {'n_estimators': 761, 'learning_rate': 0.003003151716938294, 'num_leaves': 409, 'max_depth': 5, 'min_child_samples': 165, 'min_split_gain': 1.498083879035124, 'bagging_fraction': 0.44391094597483866, 'bagging_freq': 3, 'feature_fraction': 0.5516751924489833, 'lambda_l1': 8.332516750396116e-08, 'lambda_l2': 0.5077631895453656, 'huber_alpha': 0.85}. Best is trial 0 with value: 1.2534684418708901.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-08 13:15:35,151] Trial 5 finished with value: 1.247363066917102 and parameters: {'n_estimators': 404, 'learning_rate': 0.18314620854695027, 'num_leaves': 260, 'max_depth': 13, 'min_child_samples': 51, 'min_split_gain': 2.972245934092154, 'bagging_fraction': 0.9775155780902212, 'bagging_freq': 7, 'feature_fraction': 0.365709606237354, 'lambda_l1': 5.9654059281874116e-05, 'lambda_l2': 0.006859036422781172, 'huber_alpha': 0.95}. Best is trial 5 with value: 1.247363066917102.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-08 13:15:36,621] Trial 6 finished with value: 1.223011984309102 and parameters: {'n_estimators': 3052, 'learning_rate': 0.13146898336096702, 'num_leaves': 489, 'max_depth': 11, 'min_child_samples': 47, 'min_split_gain': 2.173391605434026, 'bagging_fraction': 0.9258346721061177, 'bagging_freq': 2, 'feature_fraction': 0.6381532515738396, 'lambda_l1': 0.002530717742378322, 'lambda_l2': 0.0004479476588817844, 'huber_alpha': 0.95}. Best is trial 6 with value: 1.223011984309102.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-08 13:15:37,754] Trial 7 finished with value: 1.2904768660350447 and parameters: {'n_estimators': 2519, 'learning_rate': 0.18104669093362824, 'num_leaves': 399, 'max_depth': 4, 'min_child_samples': 227, 'min_split_gain': 2.761320735057018, 'bagging_fraction': 0.8991836269249566, 'bagging_freq': 7, 'feature_fraction': 0.8888248313104422, 'lambda_l1': 5.374969144858311e-06, 'lambda_l2': 0.5877618471031133, 'huber_alpha': 0.85}. Best is trial 6 with value: 1.223011984309102.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-08 13:15:42,324] Trial 8 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-08 13:15:44,228] Trial 9 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-08 13:15:51,011] Trial 10 finished with value: 1.2626079960867753 and parameters: {'n_estimators': 2941, 'learning_rate': 0.007104579859769969, 'num_leaves': 424, 'max_depth': 2, 'min_child_samples': 2, 'min_split_gain': 4.6220887565718325, 'bagging_fraction': 0.7880566131549542, 'bagging_freq': 7, 'feature_fraction': 0.661678263936434, 'lambda_l1': 8.121756387194875e-09, 'lambda_l2': 100.08386764870838, 'huber_alpha': 0.9}. Best is trial 6 with value: 1.223011984309102.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-08 13:15:51,820] Trial 11 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-08 13:15:53,477] Trial 12 finished with value: 1.2343179887772202 and parameters: {'n_estimators': 3404, 'learning_rate': 0.03866939016656176, 'num_leaves': 50, 'max_depth': 9, 'min_child_samples': 54, 'min_split_gain': 3.975378174997817, 'bagging_fraction': 0.5776988884481041, 'bagging_freq': 4, 'feature_fraction': 0.8073004449855348, 'lambda_l1': 1.1469173194560514e-08, 'lambda_l2': 0.6127644589218547, 'huber_alpha': 0.85}. Best is trial 6 with value: 1.223011984309102.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-08 13:15:54,057] Trial 13 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-08 13:15:59,299] Trial 14 finished with value: 1.2534012344638086 and parameters: {'n_estimators': 2440, 'learning_rate': 0.007089782197514698, 'num_leaves': 92, 'max_depth': 2, 'min_child_samples': 83, 'min_split_gain': 1.7789721315624618, 'bagging_fraction': 0.6616016865596667, 'bagging_freq': 5, 'feature_fraction': 0.4058624376375402, 'lambda_l1': 3.60867143771307e-07, 'lambda_l2': 0.0019132656772962273, 'huber_alpha': 0.9}. Best is trial 6 with value: 1.223011984309102.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-08 13:16:01,326] Trial 15 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-08 13:16:05,086] Trial 16 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-08 13:16:06,623] Trial 17 finished with value: 1.217692589230501 and parameters: {'n_estimators': 3062, 'learning_rate': 0.07112147025749754, 'num_leaves': 297, 'max_depth': 8, 'min_child_samples': 35, 'min_split_gain': 3.6100866711450985, 'bagging_fraction': 0.6739444228784396, 'bagging_freq': 2, 'feature_fraction': 0.7792136144717134, 'lambda_l1': 0.0038962288315584673, 'lambda_l2': 0.06929123350140612, 'huber_alpha': 0.95}. Best is trial 17 with value: 1.217692589230501.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-08 13:16:09,028] Trial 18 finished with value: 1.2099399162732767 and parameters: {'n_estimators': 1870, 'learning_rate': 0.09144898595741836, 'num_leaves': 335, 'max_depth': 7, 'min_child_samples': 34, 'min_split_gain': 1.0914849460867937, 'bagging_fraction': 0.7049783992086796, 'bagging_freq': 2, 'feature_fraction': 0.5512444597516468, 'lambda_l1': 0.004410788775045123, 'lambda_l2': 0.002207265180946189, 'huber_alpha': 0.95}. Best is trial 18 with value: 1.2099399162732767.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-08 13:16:10,138] Trial 19 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-08 13:16:11,809] Trial 20 finished with value: 1.2420450097331488 and parameters: {'n_estimators': 1809, 'learning_rate': 0.07314844784325947, 'num_leaves': 324, 'max_depth': 7, 'min_child_samples': 95, 'min_split_gain': 3.414800552047821, 'bagging_fraction': 0.7318145537325754, 'bagging_freq': 2, 'feature_fraction': 0.5042677658430949, 'lambda_l1': 0.002216425654723661, 'lambda_l2': 0.003683001804422559, 'huber_alpha': 0.95}. Best is trial 18 with value: 1.2099399162732767.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-08 13:16:13,909] Trial 21 finished with value: 1.2052673211483675 and parameters: {'n_estimators': 2996, 'learning_rate': 0.0976025307299067, 'num_leaves': 485, 'max_depth': 8, 'min_child_samples': 30, 'min_split_gain': 1.1817549064936783, 'bagging_fraction': 0.8719698680673628, 'bagging_freq': 2, 'feature_fraction': 0.7330866317879842, 'lambda_l1': 0.0025966905752955695, 'lambda_l2': 0.001313878070396331, 'huber_alpha': 0.95}. Best is trial 21 with value: 1.2052673211483675.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-08 13:16:16,892] Trial 22 finished with value: 1.19368365189771 and parameters: {'n_estimators': 2055, 'learning_rate': 0.08526493450021155, 'num_leaves': 328, 'max_depth': 8, 'min_child_samples': 27, 'min_split_gain': 0.002760685709903843, 'bagging_fraction': 0.8665927277296104, 'bagging_freq': 2, 'feature_fraction': 0.74303619929294, 'lambda_l1': 0.10321295741876295, 'lambda_l2': 0.0016039296526076687, 'huber_alpha': 0.95}. Best is trial 22 with value: 1.19368365189771.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-08 13:16:20,308] Trial 23 finished with value: 1.2088967220199367 and parameters: {'n_estimators': 2052, 'learning_rate': 0.08994613818356707, 'num_leaves': 452, 'max_depth': 6, 'min_child_samples': 25, 'min_split_gain': 0.015352006388086587, 'bagging_fraction': 0.8554625959530964, 'bagging_freq': 3, 'feature_fraction': 0.7219797515727795, 'lambda_l1': 1.2163313584555064, 'lambda_l2': 0.0022992709692429085, 'huber_alpha': 0.95}. Best is trial 22 with value: 1.19368365189771.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-08 13:16:27,040] Trial 24 finished with value: 1.217046311932179 and parameters: {'n_estimators': 2105, 'learning_rate': 0.021865803891171015, 'num_leaves': 464, 'max_depth': 6, 'min_child_samples': 23, 'min_split_gain': 0.045099770785295895, 'bagging_fraction': 0.8671901369689475, 'bagging_freq': 3, 'feature_fraction': 0.7221322995134479, 'lambda_l1': 1.8321093229025271, 'lambda_l2': 0.001046537017553987, 'huber_alpha': 0.95}. Best is trial 22 with value: 1.19368365189771.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-08 13:16:30,454] Trial 25 finished with value: 1.2216409316796109 and parameters: {'n_estimators': 1366, 'learning_rate': 0.040386949937597345, 'num_leaves': 457, 'max_depth': 8, 'min_child_samples': 72, 'min_split_gain': 0.08470217337296776, 'bagging_fraction': 0.8332197024199794, 'bagging_freq': 1, 'feature_fraction': 0.8523492865856052, 'lambda_l1': 1.3732833396070667, 'lambda_l2': 0.00917789416994039, 'huber_alpha': 0.75}. Best is trial 22 with value: 1.19368365189771.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-08 13:16:32,141] Trial 26 finished with value: 1.251512717086198 and parameters: {'n_estimators': 1459, 'learning_rate': 0.09669573918330461, 'num_leaves': 365, 'max_depth': 5, 'min_child_samples': 116, 'min_split_gain': 0.6330631190697176, 'bagging_fraction': 0.7651371121064252, 'bagging_freq': 3, 'feature_fraction': 0.7250466643782668, 'lambda_l1': 0.16430886399256933, 'lambda_l2': 0.0006228241199421295, 'huber_alpha': 0.9}. Best is trial 22 with value: 1.19368365189771.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-08 13:16:34,415] Trial 27 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-08 13:16:36,174] Trial 28 finished with value: 1.2430218664874277 and parameters: {'n_estimators': 2742, 'learning_rate': 0.23419043323966612, 'num_leaves': 507, 'max_depth': 6, 'min_child_samples': 72, 'min_split_gain': 0.5012786669543638, 'bagging_fraction': 0.8536028388226697, 'bagging_freq': 1, 'feature_fraction': 0.7184557840124689, 'lambda_l1': 0.00028588540787417063, 'lambda_l2': 0.011377674002894727, 'huber_alpha': 0.95}. Best is trial 22 with value: 1.19368365189771.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-08 13:16:40,642] Trial 29 finished with value: 1.2131623378860137 and parameters: {'n_estimators': 1260, 'learning_rate': 0.02037585744004758, 'num_leaves': 214, 'max_depth': 5, 'min_child_samples': 40, 'min_split_gain': 1.3495315433863841, 'bagging_fraction': 0.7897610978697149, 'bagging_freq': 2, 'feature_fraction': 0.8397841247703921, 'lambda_l1': 0.2023848181091528, 'lambda_l2': 0.016510829801482434, 'huber_alpha': 0.95}. Best is trial 22 with value: 1.19368365189771.
# [I 2026-07-08 13:16:40,721] A new study created in RDB with name: KSEA_v11_remaining_warmup_base_catboost_mae_f
# [I 2026-07-08 13:27:52,607] Trial 0 finished with value: 1.452545420873132 and parameters: {'iterations': 2931, 'learning_rate': 0.001783588943232587, 'depth': 10, 'l2_leaf_reg': 0.9942958882300413, 'random_strength': 7.186216756161439, 'bagging_temperature': 12.184767612363034, 'border_count': 110, 'rsm': 0.6158971964095841, 'huber_delta': 1.5}. Best is trial 0 with value: 1.452545420873132.
# [I 2026-07-08 13:43:08,228] Trial 1 finished with value: 1.6472465544241541 and parameters: {'iterations': 801, 'learning_rate': 0.19767902101650964, 'depth': 12, 'l2_leaf_reg': 75.05056513807031, 'random_strength': 12.92821124806787, 'bagging_temperature': 4.276496242612171, 'border_count': 168, 'rsm': 0.4404450637901872, 'huber_delta': 1.0}. Best is trial 0 with value: 1.452545420873132.
# [I 2026-07-08 13:44:15,344] Trial 2 finished with value: 1.4769682550401482 and parameters: {'iterations': 1992, 'learning_rate': 0.0024079350849750287, 'depth': 3, 'l2_leaf_reg': 0.118485976001343, 'random_strength': 4.058751860003342, 'bagging_temperature': 9.103785934457758, 'border_count': 206, 'rsm': 0.994034742637508, 'huber_delta': 0.5}. Best is trial 0 with value: 1.452545420873132.
# [I 2026-07-08 14:12:41,201] Trial 3 finished with value: 1.5842881498317127 and parameters: {'iterations': 3095, 'learning_rate': 0.05508623515899769, 'depth': 11, 'l2_leaf_reg': 18.082710740309665, 'random_strength': 13.948598364083836, 'bagging_temperature': 18.60205606816345, 'border_count': 227, 'rsm': 0.4117317891426977, 'huber_delta': 3.0}. Best is trial 0 with value: 1.452545420873132.
# [I 2026-07-08 14:13:13,783] Trial 4 finished with value: 1.3455268546026913 and parameters: {'iterations': 3146, 'learning_rate': 0.0024764229908984673, 'depth': 3, 'l2_leaf_reg': 0.6951779671472356, 'random_strength': 6.148451176512449, 'bagging_temperature': 8.441103735088014, 'border_count': 95, 'rsm': 0.7192489923988105, 'huber_delta': 2.0}. Best is trial 4 with value: 1.3455268546026913.
# [I 2026-07-08 14:13:24,721] Trial 5 finished with value: 1.4516253505385799 and parameters: {'iterations': 2996, 'learning_rate': 0.04169299311145666, 'depth': 2, 'l2_leaf_reg': 0.6483636109972302, 'random_strength': 11.284989840243444, 'bagging_temperature': 11.881552589055849, 'border_count': 179, 'rsm': 0.7610806862514128, 'huber_delta': 0.5}. Best is trial 4 with value: 1.3455268546026913.
# [I 2026-07-08 14:13:26,209] Trial 6 pruned.
# [I 2026-07-08 14:13:29,420] Trial 7 pruned.
# [I 2026-07-08 14:13:47,412] Trial 8 pruned.
# [I 2026-07-08 14:17:20,494] Trial 9 finished with value: 1.359644342569251 and parameters: {'iterations': 2176, 'learning_rate': 0.006973123504821021, 'depth': 7, 'l2_leaf_reg': 1.0111907140307084, 'random_strength': 19.613513312465464, 'bagging_temperature': 8.113717548278494, 'border_count': 208, 'rsm': 0.7899333278528806, 'huber_delta': 5.0}. Best is trial 4 with value: 1.3455268546026913.
# [I 2026-07-08 14:17:55,400] Trial 10 pruned.
# [I 2026-07-08 14:18:55,902] Trial 11 finished with value: 1.313356711475556 and parameters: {'iterations': 2772, 'learning_rate': 0.014522829031783214, 'depth': 5, 'l2_leaf_reg': 15.987388321276002, 'random_strength': 11.591109950971106, 'bagging_temperature': 7.790667047006705, 'border_count': 126, 'rsm': 0.7500006952294106, 'huber_delta': 5.0}. Best is trial 11 with value: 1.313356711475556.
# [I 2026-07-08 14:19:56,064] Trial 12 pruned.
# [I 2026-07-08 14:20:02,035] Trial 13 pruned.
# [I 2026-07-08 14:20:10,248] Trial 14 finished with value: 1.3667010461721656 and parameters: {'iterations': 2033, 'learning_rate': 0.03406017942217813, 'depth': 3, 'l2_leaf_reg': 2.8273302406131626, 'random_strength': 2.5986858551767766, 'bagging_temperature': 5.630188860588947, 'border_count': 58, 'rsm': 0.9026140460549269, 'huber_delta': 1.0}. Best is trial 11 with value: 1.313356711475556.
# [I 2026-07-08 14:20:32,401] Trial 15 pruned.
# [I 2026-07-08 14:21:37,446] Trial 16 finished with value: 1.3180795351071537 and parameters: {'iterations': 3416, 'learning_rate': 0.006424948471040994, 'depth': 5, 'l2_leaf_reg': 197.98083807490883, 'random_strength': 17.110130348053506, 'bagging_temperature': 0.2920642424315254, 'border_count': 68, 'rsm': 0.7385632694163883, 'huber_delta': 2.0}. Best is trial 11 with value: 1.313356711475556.
# [I 2026-07-08 14:23:21,255] Trial 17 finished with value: 1.3125470138534574 and parameters: {'iterations': 3466, 'learning_rate': 0.008839187675884689, 'depth': 6, 'l2_leaf_reg': 181.94585851916037, 'random_strength': 16.574794818938415, 'bagging_temperature': 0.7402526726861892, 'border_count': 55, 'rsm': 0.8398125158187049, 'huber_delta': 2.0}. Best is trial 17 with value: 1.3125470138534574.
# [I 2026-07-08 14:23:56,581] Trial 18 finished with value: 1.252667674884926 and parameters: {'iterations': 2586, 'learning_rate': 0.01434793462583799, 'depth': 6, 'l2_leaf_reg': 13.631090697889816, 'random_strength': 15.709820874401833, 'bagging_temperature': 0.31515488633751154, 'border_count': 22, 'rsm': 0.9036273826932942, 'huber_delta': 5.0}. Best is trial 18 with value: 1.252667674884926.
# [I 2026-07-08 14:24:14,682] Trial 19 pruned.
# [I 2026-07-08 14:26:37,404] Trial 20 finished with value: 1.3120385139751018 and parameters: {'iterations': 2577, 'learning_rate': 0.004676708515936048, 'depth': 8, 'l2_leaf_reg': 4.981810712898586, 'random_strength': 17.393800977915493, 'bagging_temperature': 1.877311124133894, 'border_count': 45, 'rsm': 0.8489343699812769, 'huber_delta': 5.0}. Best is trial 18 with value: 1.252667674884926.
# [I 2026-07-08 14:27:53,921] Trial 21 pruned.
# [I 2026-07-08 14:28:12,341] Trial 22 pruned.
# [I 2026-07-08 14:29:47,903] Trial 23 pruned.
# [I 2026-07-08 14:31:01,885] Trial 24 finished with value: 1.283682803715427 and parameters: {'iterations': 3233, 'learning_rate': 0.008990340227887814, 'depth': 6, 'l2_leaf_reg': 25.277618367757142, 'random_strength': 18.306095008587434, 'bagging_temperature': 3.6275293310436814, 'border_count': 39, 'rsm': 0.8071842238977195, 'huber_delta': 5.0}. Best is trial 18 with value: 1.252667674884926.
# [I 2026-07-08 14:33:39,404] Trial 25 pruned.
# [I 2026-07-08 14:35:21,746] Trial 26 finished with value: 1.3036115422448686 and parameters: {'iterations': 2782, 'learning_rate': 0.011251080539372224, 'depth': 6, 'l2_leaf_reg': 30.378560158338114, 'random_strength': 15.091326194088985, 'bagging_temperature': 5.777060212273695, 'border_count': 33, 'rsm': 0.8055321311194606, 'huber_delta': 5.0}. Best is trial 18 with value: 1.252667674884926.
# [I 2026-07-08 14:38:05,679] Trial 27 finished with value: 1.292392665766605 and parameters: {'iterations': 3232, 'learning_rate': 0.012064406455849667, 'depth': 6, 'l2_leaf_reg': 28.596731715820596, 'random_strength': 14.949755753334692, 'bagging_temperature': 6.129687181439552, 'border_count': 26, 'rsm': 0.7977353753348255, 'huber_delta': 5.0}. Best is trial 18 with value: 1.252667674884926.
# [I 2026-07-08 14:38:50,421] Trial 28 finished with value: 1.286068824325057 and parameters: {'iterations': 3247, 'learning_rate': 0.02723235695970831, 'depth': 4, 'l2_leaf_reg': 31.494688177643468, 'random_strength': 11.901141680369905, 'bagging_temperature': 6.311450453181169, 'border_count': 17, 'rsm': 0.618238808908431, 'huber_delta': 5.0}. Best is trial 18 with value: 1.252667674884926.
# [I 2026-07-08 14:39:10,456] Trial 29 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-08 14:42:13,018] A new study created in RDB with name: KSEA_v11_remaining_warmup_stack_ridge_stack_mae_f
# [I 2026-07-08 14:42:13,321] Trial 0 finished with value: 1.2096305703628898 and parameters: {'feature_set': 'models_only', 'alpha': 1061.6032395070417, 'fit_intercept': False}. Best is trial 0 with value: 1.2096305703628898.
# [I 2026-07-08 14:42:13,593] Trial 1 finished with value: 1.214241674805338 and parameters: {'feature_set': 'models_only', 'alpha': 29.13552742298041, 'fit_intercept': False}. Best is trial 0 with value: 1.2096305703628898.
# [I 2026-07-08 14:42:13,868] Trial 2 finished with value: 1.2084218029649925 and parameters: {'feature_set': 'models_only', 'alpha': 0.0005260598165963439, 'fit_intercept': True}. Best is trial 2 with value: 1.2084218029649925.
# [I 2026-07-08 14:42:14,135] Trial 3 finished with value: 1.2180100496619235 and parameters: {'feature_set': 'models_only', 'alpha': 2.2872748315304782e-05, 'fit_intercept': False}. Best is trial 2 with value: 1.2084218029649925.
# [I 2026-07-08 14:42:14,369] Trial 4 finished with value: 1.229408824650262 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 1013.2424299869091, 'fit_intercept': True}. Best is trial 2 with value: 1.2084218029649925.
# [I 2026-07-08 14:42:14,610] Trial 5 finished with value: 1.222339091998312 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 826.0185608286423, 'fit_intercept': True}. Best is trial 2 with value: 1.2084218029649925.
# [I 2026-07-08 14:42:14,858] Trial 6 finished with value: 1.2079875813826901 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 3.929417958656645e-06, 'fit_intercept': True}. Best is trial 6 with value: 1.2079875813826901.
# [I 2026-07-08 14:42:15,095] Trial 7 finished with value: 1.207844880533527 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 0.8901780240435773, 'fit_intercept': True}. Best is trial 7 with value: 1.207844880533527.
# [I 2026-07-08 14:42:15,326] Trial 8 finished with value: 1.2116778604497438 and parameters: {'feature_set': 'models_only', 'alpha': 2828.538706546869, 'fit_intercept': False}. Best is trial 7 with value: 1.207844880533527.
# [I 2026-07-08 14:42:15,561] Trial 9 finished with value: 1.2137785232067995 and parameters: {'feature_set': 'models_only', 'alpha': 35.97860619804126, 'fit_intercept': False}. Best is trial 7 with value: 1.207844880533527.
# [I 2026-07-08 14:42:15,817] Trial 10 finished with value: 1.2084218701220002 and parameters: {'feature_set': 'models_only', 'alpha': 1.8087400416300714e-05, 'fit_intercept': True}. Best is trial 7 with value: 1.207844880533527.
# [I 2026-07-08 14:42:16,051] Trial 11 finished with value: 1.207987517523986 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 0.00039823854294263674, 'fit_intercept': True}. Best is trial 7 with value: 1.207844880533527.
# [I 2026-07-08 14:42:16,280] Trial 12 finished with value: 1.2119553470742497 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 0.44507773547737556, 'fit_intercept': False}. Best is trial 7 with value: 1.207844880533527.
# [I 2026-07-08 14:42:16,512] Trial 13 finished with value: 1.2120308829293198 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 7.810619739021528e-06, 'fit_intercept': False}. Best is trial 7 with value: 1.207844880533527.
# [I 2026-07-08 14:42:16,752] Trial 14 finished with value: 1.210528783103119 and parameters: {'feature_set': 'models_only', 'alpha': 150.11205568245393, 'fit_intercept': False}. Best is trial 7 with value: 1.207844880533527.
# [I 2026-07-08 14:42:16,985] Trial 15 finished with value: 1.207985402824865 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 0.013457925255984786, 'fit_intercept': True}. Best is trial 7 with value: 1.207844880533527.
# [I 2026-07-08 14:42:17,228] Trial 16 finished with value: 1.207940231188979 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 0.2933659355731618, 'fit_intercept': True}. Best is trial 7 with value: 1.207844880533527.
# [I 2026-07-08 14:42:17,466] Trial 17 finished with value: 1.2078397783633366 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 0.9223435367617162, 'fit_intercept': True}. Best is trial 17 with value: 1.2078397783633366.
# [I 2026-07-08 14:42:17,711] Trial 18 finished with value: 1.207792977898453 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 1.2184887908027806, 'fit_intercept': True}. Best is trial 18 with value: 1.207792977898453.
# [I 2026-07-08 14:42:17,968] Trial 19 finished with value: 1.2079828824299523 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 0.029028198639461465, 'fit_intercept': True}. Best is trial 18 with value: 1.207792977898453.
# [I 2026-07-08 14:42:18,216] Trial 20 finished with value: 1.2074245435378583 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 3.8801777545197877, 'fit_intercept': True}. Best is trial 20 with value: 1.2074245435378583.
# [I 2026-07-08 14:42:18,459] Trial 21 finished with value: 1.2068619570423265 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 8.472913611794915, 'fit_intercept': True}. Best is trial 21 with value: 1.2068619570423265.
# [I 2026-07-08 14:42:18,696] Trial 22 finished with value: 1.7554760409732344 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 35526.85501758518, 'fit_intercept': True}. Best is trial 21 with value: 1.2068619570423265.
# [I 2026-07-08 14:42:18,940] Trial 23 finished with value: 1.207154375163985 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 6.026212751234412, 'fit_intercept': True}. Best is trial 21 with value: 1.2068619570423265.
# [I 2026-07-08 14:42:19,182] Trial 24 finished with value: 1.207261903569961 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 5.159354713014635, 'fit_intercept': True}. Best is trial 21 with value: 1.2068619570423265.
# [I 2026-07-08 14:42:19,425] Trial 25 finished with value: 1.2066584169175592 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 10.257239822773434, 'fit_intercept': True}. Best is trial 25 with value: 1.2066584169175592.
# [I 2026-07-08 14:42:19,665] Trial 26 finished with value: 1.2079755627954643 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 0.07427852182860559, 'fit_intercept': True}. Best is trial 25 with value: 1.2066584169175592.
# [I 2026-07-08 14:42:19,895] Trial 27 finished with value: 1.2046971862600369 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 34.12570459611437, 'fit_intercept': True}. Best is trial 27 with value: 1.2046971862600369.
# [I 2026-07-08 14:42:20,125] Trial 28 finished with value: 1.519132176727895 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 19958.429856637005, 'fit_intercept': True}. Best is trial 27 with value: 1.2046971862600369.
# [I 2026-07-08 14:42:20,380] Trial 29 finished with value: 1.2026100156675505 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 141.68205598666881, 'fit_intercept': True}. Best is trial 29 with value: 1.2026100156675505.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
# ...
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
#                   period           method  count     mae_f    rmse_f
# 0   validation_2024_2025          xgboost    731  1.216445  1.641696
# 1   validation_2024_2025         lightgbm    731  1.223148  1.650741
# 2   validation_2024_2025         catboost    731  1.245145  1.667625
# 3   validation_2024_2025    provider_mean    731  1.764052  2.323288
# 4   validation_2024_2025  provider_median    731  1.671656  2.127781
# 5   validation_2024_2025          nbm_raw    731  1.692062  2.145010
# 6   validation_2024_2025         hrrr_raw    731  2.293620  3.058271
# 7   validation_2024_2025          gfs_raw    731  2.709279  3.742089
# 8              test_2026          xgboost    172  1.239072  1.653153
# 9              test_2026         lightgbm    172  1.277145  1.694463
# 10             test_2026         catboost    172  1.259298  1.621928
# 11             test_2026      ridge_stack    172  1.224363  1.615884
# 12             test_2026    provider_mean    172  1.730164  2.311456
# 13             test_2026  provider_median    172  1.759978  2.394178
# 14             test_2026          nbm_raw    172  1.749735  2.370646
# 15             test_2026         hrrr_raw    172  2.283232  2.738016
# 16             test_2026          gfs_raw    172  2.457536  3.577140

# %%
exported_weights = export_station_model_weights(
    project_root=PROJECT_ROOT,
    station_id=STATION_ID,
    artifact_dir=config.resolved_output_dir(),
    model_version=MODEL_VERSION,
    timing_mode=config.timing_mode,
    providers=tuple(config.providers),
    feature_version=config.effective_feature_version,
    optuna_metric=config.effective_optuna_metric,
    target_mode=config.effective_target_mode,
    target_source=config.effective_target_source,
    base_model_methods=tuple(config.effective_base_model_methods),
    stack_enabled=config.stack_enabled,
    source_pipeline="notebooks/station_stacking_v11_settlement",
)

exported_weights.bundle_path, exported_weights.manifest_path
# Out:
# (WindowsPath('D:/dev/weather-research/data/calibration/station_stacking_v11_settlement/model_weights/KSEA_station_high_regressor_v11_wunderground_settlement_stack.joblib'),
#  WindowsPath('D:/dev/weather-research/data/calibration/station_stacking_v11_settlement/model_weights/KSEA_station_high_regressor_v11_wunderground_settlement_stack.json'))

# %% [markdown]
# ## V11 Feature Coverage

# %%
v11_feature_coverage = (
    result.features[V11_FEATURE_COLUMNS]
    .notna()
    .mean()
    .mul(100)
    .sort_values(ascending=False)
    .rename("coverage_pct")
    .reset_index()
    .rename(columns={"index": "feature"})
)

v11_feature_coverage
# Out:
#                                               feature  coverage_pct
# 0                              v2_spread_per_warmup_f    100.000000
# 1                    v2_morning_warmup_to_consensus_f    100.000000
# 2              v3_remaining_warmup_from_high_so_far_f    100.000000
# 3                      v3_high_so_far_above_current_f    100.000000
# 4                      v2_humidity_warmup_interaction    100.000000
# 5                    v4_observed_precip_recent_mm_est    100.000000
# 6                        v4_forecast_wet_observed_dry    100.000000
# 7                   v4_forecast_observed_precip_match    100.000000
# 8            v3_humidity_remaining_warmup_interaction    100.000000
# 9                    v3_remaining_warmup_per_spread_f    100.000000
# 10                             v4_all_forecast_precip    100.000000
# 11                             v4_observed_precip_any    100.000000
# 12                             v4_any_forecast_precip    100.000000
# 13              observed_temp_minus_climatology_10y_f    100.000000
# 14                             climatology_high_10y_f    100.000000
# 15                         climatology_high_10y_std_f    100.000000
# 16                    v8_month_remaining_warmup_count    100.000000
# 17          v8_provider_spread_per_remaining_warmup_f    100.000000
# 18       v8_provider_min_remaining_from_high_so_far_f    100.000000
# 19    v8_provider_median_remaining_from_high_so_far_f    100.000000
# 20       v8_provider_max_remaining_from_high_so_far_f    100.000000
# 21            observed_high_so_far_change_since_9am_f    100.000000
# 22                     observed_temp_change_last_3h_f    100.000000
# 23            observed_morning_warmup_rate_f_per_hour    100.000000
# 24                     observed_temp_change_last_1h_f    100.000000
# 25                       v4_observed_wet_forecast_dry    100.000000
# 26              provider_mean_minus_climatology_10y_f    100.000000
# 27       observed_high_so_far_minus_climatology_10y_f    100.000000
# 28                         climatology_high_10y_count    100.000000
# 29                          v2_recent_heat_momentum_f     99.949950
# 30                   v3_high_so_far_minus_7d_actual_f     99.949950
# 31                     v2_consensus_minus_7d_actual_f     99.949950
# 32                      v3_high_so_far_minus_lag_1d_f     99.949950
# 33                           v2_recent_heat_anomaly_f     99.949950
# 34               v8_recent_remaining_warmup_7d_mean_f     99.899900
# 35              v8_recent_remaining_warmup_30d_mean_f     99.749750
# 36       v8_provider_mean_remaining_vs_month_normal_f     98.798799
# 37                   v8_month_remaining_warmup_mean_f     98.798799
# 38      v8_dewpoint_mean_remaining_warmup_interaction     80.030030
# 39  v8_dewpoint_depression_remaining_warmup_intera...     80.030030
# 40                        v8_forecast_dewpoint_mean_f     80.030030
# 41             v8_forecast_dewpoint_depression_mean_f     80.030030
# 42         v4_forecast_total_minus_observed_recent_mm     79.579580
# 43                   v4_forecast_precip_intensity_max     79.579580
# 44                   v4_forecast_precip_total_mean_mm     79.579580
# 45                    v4_forecast_precip_total_max_mm     79.579580
# 46                 v4_forecast_precip_total_spread_mm     79.579580
# 47                  v4_forecast_precip_max_1h_mean_mm     79.579580
# 48                      v4_forecast_precip_hours_mean     79.579580
# 49                  v4_forecast_precip_intensity_mean     79.579580
# 50             v4_precip_remaining_warmup_interaction     79.579580
# 51                     v4_precip_humidity_interaction     79.579580
# 52       v8_precip_total_remaining_warmup_interaction     79.579580
# 53      v8_precip_max_1h_remaining_warmup_interaction     79.579580
# 54    v8_wind_speed_mean_remaining_warmup_interaction     38.338338
# 55      v8_wind_gust_max_remaining_warmup_interaction     38.338338
# 56    v8_cloud_cover_max_remaining_warmup_interaction      0.000000
# 57   v8_cloud_cover_mean_remaining_warmup_interaction      0.000000

# %%
result.feature_columns.loc[result.feature_columns["feature"].isin(V11_FEATURE_COLUMNS)]
# Out:
#                                                feature     kind
# 21                      observed_temp_change_last_1h_f  numeric
# 22                      observed_temp_change_last_3h_f  numeric
# 23             observed_morning_warmup_rate_f_per_hour  numeric
# 24             observed_high_so_far_change_since_9am_f  numeric
# 222                           v2_recent_heat_anomaly_f  numeric
# 223                          v2_recent_heat_momentum_f  numeric
# 224                   v2_morning_warmup_to_consensus_f  numeric
# 225                     v2_consensus_minus_7d_actual_f  numeric
# 226                             v2_spread_per_warmup_f  numeric
# 227                     v2_humidity_warmup_interaction  numeric
# 228                     v3_high_so_far_above_current_f  numeric
# 229             v3_remaining_warmup_from_high_so_far_f  numeric
# 230                      v3_high_so_far_minus_lag_1d_f  numeric
# 231                   v3_high_so_far_minus_7d_actual_f  numeric
# 232                   v3_remaining_warmup_per_spread_f  numeric
# 233           v3_humidity_remaining_warmup_interaction  numeric
# 234                   v4_forecast_precip_total_mean_mm  numeric
# 235                    v4_forecast_precip_total_max_mm  numeric
# 236                 v4_forecast_precip_total_spread_mm  numeric
# 237                  v4_forecast_precip_max_1h_mean_mm  numeric
# 238                      v4_forecast_precip_hours_mean  numeric
# 239                  v4_forecast_precip_intensity_mean  numeric
# 240                   v4_forecast_precip_intensity_max  numeric
# 241                             v4_any_forecast_precip  numeric
# 242                             v4_all_forecast_precip  numeric
# 243                             v4_observed_precip_any  numeric
# 244                   v4_observed_precip_recent_mm_est  numeric
# 245         v4_forecast_total_minus_observed_recent_mm  numeric
# 246                  v4_forecast_observed_precip_match  numeric
# 247                       v4_forecast_wet_observed_dry  numeric
# 248                       v4_observed_wet_forecast_dry  numeric
# 249                     v4_precip_humidity_interaction  numeric
# 250             v4_precip_remaining_warmup_interaction  numeric
# 251       v8_provider_max_remaining_from_high_so_far_f  numeric
# 252       v8_provider_min_remaining_from_high_so_far_f  numeric
# 253    v8_provider_median_remaining_from_high_so_far_f  numeric
# 254          v8_provider_spread_per_remaining_warmup_f  numeric
# 255                   v8_month_remaining_warmup_mean_f  numeric
# 256                    v8_month_remaining_warmup_count  numeric
# 257               v8_recent_remaining_warmup_7d_mean_f  numeric
# 258              v8_recent_remaining_warmup_30d_mean_f  numeric
# 259       v8_provider_mean_remaining_vs_month_normal_f  numeric
# 260       v8_precip_total_remaining_warmup_interaction  numeric
# 261      v8_precip_max_1h_remaining_warmup_interaction  numeric
# 262    v8_wind_speed_mean_remaining_warmup_interaction  numeric
# 263      v8_wind_gust_max_remaining_warmup_interaction  numeric
# 264                        v8_forecast_dewpoint_mean_f  numeric
# 265             v8_forecast_dewpoint_depression_mean_f  numeric
# 266      v8_dewpoint_mean_remaining_warmup_interaction  numeric
# 267  v8_dewpoint_depression_remaining_warmup_intera...  numeric
# 268                             climatology_high_10y_f  numeric
# 269                         climatology_high_10y_std_f  numeric
# 270                         climatology_high_10y_count  numeric
# 271              provider_mean_minus_climatology_10y_f  numeric
# 272              observed_temp_minus_climatology_10y_f  numeric
# 273       observed_high_so_far_minus_climatology_10y_f  numeric

# %% [markdown]
# ## Dropped Feature Check

# %%
dropped_present = result.feature_columns.loc[
    result.feature_columns["feature"].isin(V11_DROPPED_FEATURE_COLUMNS)
]

dropped_present
# Out:
# Empty DataFrame
# Columns: [feature, kind]
# Index: []

# %% [markdown]
# ## Morning Trend Coverage

# %%
trend_coverage = (
    result.features[TREND_COLUMNS]
    .notna()
    .mean()
    .mul(100)
    .sort_values(ascending=False)
    .rename("coverage_pct")
    .reset_index()
    .rename(columns={"index": "feature"})
)

trend_coverage
# Out:
#                                    feature  coverage_pct
# 0           observed_temp_change_last_1h_f         100.0
# 1           observed_temp_change_last_3h_f         100.0
# 2  observed_morning_warmup_rate_f_per_hour         100.0
# 3  observed_high_so_far_change_since_9am_f         100.0

# %% [markdown]
# ## Rounded Within 1F Accuracy

# %%
preds = pd.concat(
    [
        result.validation_predictions.assign(period="validation_2024_2025"),
        result.test_predictions.assign(period="oof_2026"),
    ],
    ignore_index=True,
)

predicted_high = pd.to_numeric(preds["predicted_high_f"], errors="coerce")
preds["predicted_high_rounded_f"] = np.floor(predicted_high + 0.5)
preds["within_1f_after_round"] = (
    pd.to_numeric(preds["actual_high_f"], errors="coerce") - preds["predicted_high_rounded_f"]
).abs().le(1)

within_1f_accuracy_by_period = (
    preds
    .dropna(subset=["actual_high_f", "predicted_high_rounded_f"])
    .groupby(["period", "method"], as_index=False)
    .agg(
        count=("within_1f_after_round", "size"),
        within_1f_count=("within_1f_after_round", "sum"),
        within_1f_accuracy_pct=("within_1f_after_round", lambda x: x.mean() * 100),
    )
    .sort_values(["period", "within_1f_accuracy_pct"], ascending=[True, False])
)

within_1f_accuracy_by_period
# Out:
#                   period           method  count  within_1f_count  \
# 8               oof_2026          xgboost    172              118
# 7               oof_2026      ridge_stack    172              116
# 0               oof_2026         catboost    172              115
# 3               oof_2026         lightgbm    172              112
# 6               oof_2026  provider_median    172               92
# 5               oof_2026    provider_mean    172               90
# 4               oof_2026          nbm_raw    172               87
# 1               oof_2026          gfs_raw    172               81
# 2               oof_2026         hrrr_raw    172               66
# 12  validation_2024_2025         lightgbm    731              523
# 16  validation_2024_2025          xgboost    731              513
# 9   validation_2024_2025         catboost    731              496
# 14  validation_2024_2025    provider_mean    731              395
# 15  validation_2024_2025  provider_median    731              392
# 13  validation_2024_2025          nbm_raw    731              381
# 10  validation_2024_2025          gfs_raw    731              313
# 11  validation_2024_2025         hrrr_raw    731              287
#
#     within_1f_accuracy_pct
# 8                68.604651
# 7                67.441860
# 0                66.860465
# 3                65.116279
# 6                53.488372
# 5                52.325581
# 4                50.581395
# 1                47.093023
# 2                38.372093
# 12               71.545828
# 16               70.177839
# 9                67.852257
# 14               54.035568
# 15               53.625171
# 13               52.120383
# 10               42.818057
# 11               39.261286

# %% [markdown]
# ## Version Comparison

# %%
comparison_frames = []
for version, folder in [
    ("v1", PROJECT_ROOT / "data" / "calibration" / "station_stacking"),
    ("v2", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v2"),
    ("v3", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v3"),
    ("v4", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v4"),
    ("v5", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v5"),
    ("v6", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v6"),
    ("v7", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v7"),
    ("v8", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v8"),
    ("v9", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v9"),
    ("v10", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v10"),
    ("v11", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v11"),
]:
    path = folder / f"{STATION_ID}_year_split_scoreboard.csv"
    if path.exists():
        frame = pd.read_csv(path)
        frame["version"] = version
        comparison_frames.append(frame)

version_comparison = pd.concat(comparison_frames, ignore_index=True) if comparison_frames else pd.DataFrame()
if not version_comparison.empty:
    version_comparison = version_comparison.sort_values(["period", "mae_f", "version", "method"]).reset_index(drop=True)
version_comparison
# Out:
#                   period       method  count     mae_f    rmse_f version
# 0              test_2026  ridge_stack    113  1.246979  1.575892      v6
# 1              test_2026     lightgbm    114  1.270993  1.676493      v7
# 2              test_2026     catboost    114  1.282843  1.677358      v7
# 3              test_2026     catboost    113  1.282965  1.612390      v6
# 4              test_2026      xgboost    136  1.292638  1.737796      v8
# ..                   ...          ...    ...       ...       ...     ...
# 83  validation_2024_2025     hrrr_raw    664  2.844736  3.500632      v3
# 84  validation_2024_2025     hrrr_raw    663  2.848232  3.503212      v5
# 85  validation_2024_2025     hrrr_raw    589  2.854942  3.482365      v6
# 86  validation_2024_2025      gfs_raw    644  2.917917  3.861741      v7
# 87  validation_2024_2025     hrrr_raw    568  3.000941  3.671190      v1
#
# [88 rows x 6 columns]

# %% [markdown]
# ## 2026 OOF Weather Brackets

# %%
result.bracket_metrics
# Out:
#             method  count     mae_f    rmse_f  bracket_accuracy_pct
# 0          xgboost    172  1.239072  1.653153             48.837209
# 1         lightgbm    172  1.277145  1.694463             46.511628
# 2         catboost    172  1.259298  1.621928             49.418605
# 3      ridge_stack    172  1.224363  1.615884             49.418605
# 4    provider_mean    172  1.730164  2.311456             39.534884
# 5  provider_median    172  1.759978  2.394178             36.627907
# 6          nbm_raw    172  1.749735  2.370646             34.302326
# 7         hrrr_raw    172  2.283232  2.738016             25.581395
# 8          gfs_raw    172  2.457536  3.577140              33.72093

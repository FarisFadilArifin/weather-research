# %% [markdown]
# # Station Stacking v11 Settlement - KORD
#
# Experimental notebook for `KORD`.
#
# This controlled rerun keeps the exact v11 feature/model contract, replaces daily-high labels with settlement-first Wunderground station history when available, and writes separate artifacts to `data/calibration/station_stacking_v11_settlement`.

# %%
from pathlib import Path
import os
import sys
import warnings

warnings.filterwarnings("ignore", message="IProgress not found.*")
warnings.filterwarnings("ignore", message="Skipping features without any observed values.*")

PROJECT_ROOT = Path.cwd().resolve()
while not (PROJECT_ROOT / "src" / "calibration" / "station_stacking.py").exists():
    if PROJECT_ROOT.parent == PROJECT_ROOT:
        raise RuntimeError("Could not find project root containing src/calibration/station_stacking.py")
    PROJECT_ROOT = PROJECT_ROOT.parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

os.environ["WEATHER_RESEARCH_INCLUDE_DIRECT_NBM"] = "1"

STATION_ID = "KORD"
PROVIDERS = ("gfs", "hrrr", "nbm")
TREND_COLUMNS = [
    "observed_temp_change_last_1h_f",
    "observed_temp_change_last_3h_f",
    "observed_morning_warmup_rate_f_per_hour",
    "observed_high_so_far_change_since_9am_f",
]
TIMING_MODE = "same_day_11am_live_safe"
FAST_MODE = False
OPTUNA_TRIALS = 30
STACK_OPTUNA_TRIALS = 30
OPTUNA_STARTUP_TRIALS = 15
STACK_OPTUNA_STARTUP_TRIALS = 15
OPTUNA_METRIC = "mae_f"
OPTUNA_VERBOSE = True
MODEL_VERSION = "station_high_regressor_v11_wunderground_settlement_stack"
PROJECT_ROOT
# Out:
# WindowsPath('D:/dev/weather-research')

# %%
import numpy as np
import pandas as pd

from src.export_station_stacking_v2_models import export_station_model_weights
from src.calibration.station_stacking import (
    StationStackingConfig,
    V11_DROPPED_FEATURE_COLUMNS,
    V11_FEATURE_COLUMNS,
    YEAR_SPLIT_EXPANDING_FOLDS,
    missing_model_dependencies,
    provider_availability,
    run_station_year_split_experiment,
)

# %% [markdown]
# ## V11 Contract
#
# `feature_version="v11"` keeps the v9 feature contract and remaining-warmup target, but trains base learners with Huber-style objectives while retaining the ridge stack selected by validation MAE.

# %%
fold_spec = pd.DataFrame(
    [
        {
            "fold": fold.name,
            "train_start_year": fold.train_start_year,
            "train_end_year": fold.train_end_year,
            "validation_year": fold.validation_year,
        }
        for fold in YEAR_SPLIT_EXPANDING_FOLDS
    ]
)

fold_spec
# Out:
#                      fold  train_start_year  train_end_year  validation_year
# 0  fold_2021_2023_to_2024              2021            2023             2024
# 1  fold_2021_2024_to_2025              2021            2024             2025

# %%
V11_FEATURE_COLUMNS, sorted(V11_DROPPED_FEATURE_COLUMNS)
# Out:
# (['v2_recent_heat_anomaly_f',
#   'v2_recent_heat_momentum_f',
#   'v2_morning_warmup_to_consensus_f',
#   'v2_consensus_minus_7d_actual_f',
#   'v2_spread_per_warmup_f',
#   'v2_humidity_warmup_interaction',
#   'v3_high_so_far_above_current_f',
#   'v3_remaining_warmup_from_high_so_far_f',
#   'v3_high_so_far_minus_lag_1d_f',
#   'v3_high_so_far_minus_7d_actual_f',
#   'v3_remaining_warmup_per_spread_f',
#   'v3_humidity_remaining_warmup_interaction',
#   'v4_forecast_precip_total_mean_mm',
#   'v4_forecast_precip_total_max_mm',
#   'v4_forecast_precip_total_spread_mm',
#   'v4_forecast_precip_max_1h_mean_mm',
#   'v4_forecast_precip_hours_mean',
#   'v4_forecast_precip_intensity_mean',
#   'v4_forecast_precip_intensity_max',
#   'v4_any_forecast_precip',
#   'v4_all_forecast_precip',
#   'v4_observed_precip_any',
#   'v4_observed_precip_recent_mm_est',
#   'v4_forecast_total_minus_observed_recent_mm',
#   'v4_forecast_observed_precip_match',
#   'v4_forecast_wet_observed_dry',
#   'v4_observed_wet_forecast_dry',
#   'v4_precip_humidity_interaction',
#   'v4_precip_remaining_warmup_interaction',
#   'observed_temp_change_last_1h_f',
#   'observed_temp_change_last_3h_f',
#   'observed_morning_warmup_rate_f_per_hour',
#   'observed_high_so_far_change_since_9am_f',
#   'v8_provider_max_remaining_from_high_so_far_f',
#   'v8_provider_min_remaining_from_high_so_far_f',
#   'v8_provider_median_remaining_from_high_so_far_f',
#   'v8_provider_spread_per_remaining_warmup_f',
#   'v8_month_remaining_warmup_mean_f',
#   'v8_month_remaining_warmup_count',
#   'v8_recent_remaining_warmup_7d_mean_f',
#   'v8_recent_remaining_warmup_30d_mean_f',
#   'v8_provider_mean_remaining_vs_month_normal_f',
#   'v8_cloud_cover_mean_remaining_warmup_interaction',
#   'v8_cloud_cover_max_remaining_warmup_interaction',
#   'v8_precip_total_remaining_warmup_interaction',
#   'v8_precip_max_1h_remaining_warmup_interaction',
#   'v8_wind_speed_mean_remaining_warmup_interaction',
#   'v8_wind_gust_max_remaining_warmup_interaction',
#   'v8_forecast_dewpoint_mean_f',
#   'v8_forecast_dewpoint_depression_mean_f',
#   'v8_dewpoint_mean_remaining_warmup_interaction',
#   'v8_dewpoint_depression_remaining_warmup_interaction',
#   'climatology_high_10y_f',
#   'climatology_high_10y_std_f',
#   'climatology_high_10y_count',
#   'provider_mean_minus_climatology_10y_f',
#   'observed_temp_minus_climatology_10y_f',
#   'observed_high_so_far_minus_climatology_10y_f'],
#  ['actual_minus_climatology_10y_f_DIAGNOSTIC_ONLY',
#   'climatology_source_end_year',
#   'climatology_source_start_year',
#   'gfs_as_of_hour_local',
#   'gfs_available',
#   'gfs_forecast_window_hours',
#   'gfs_grid_dist_km_mean',
#   'gfs_horizon_hours',
#   'gfs_hrrr_grid_dist_km_mean_abs_diff_f',
#   'gfs_hrrr_grid_dist_km_mean_diff_f',
#   'gfs_issue_hour_utc',
#   'gfs_missing',
#   'hrrr_as_of_hour_local',
#   'hrrr_available',
#   'hrrr_forecast_hour_max',
#   'hrrr_forecast_hour_min',
#   'hrrr_forecast_lead_hours',
#   'hrrr_forecast_window_hours',
#   'hrrr_grid_dist_km_mean',
#   'hrrr_horizon_hours',
#   'hrrr_issue_hour_local',
#   'hrrr_issue_hour_utc',
#   'hrrr_missing',
#   'is_active_polymarket_station',
#   'lat',
#   'lon',
#   'nbm_as_of_hour_local',
#   'nbm_available',
#   'nbm_forecast_window_hours',
#   'nbm_horizon_hours',
#   'nbm_issue_hour_local',
#   'nbm_issue_hour_utc',
#   'nbm_missing',
#   'observed_fetch_status',
#   'observed_observation_type',
#   'observed_pressure_source',
#   'provider_count_available',
#   'year'])

# %% [markdown]
# ## Data Availability

# %%
availability = provider_availability(
    PROJECT_ROOT,
    timing_mode=TIMING_MODE,
    providers=PROVIDERS,
)

availability.loc[availability["station_id"].eq(STATION_ID)]
# Out:
#    station_id provider  row_count first_contract_date last_contract_date
# 21       KORD      gfs       1992          2021-01-01         2026-06-21
# 22       KORD     hrrr       1998          2021-01-01         2026-06-21
# 23       KORD      nbm       1997          2021-01-01         2026-06-21

# %% [markdown]
# ## Model Scores

# %%
missing_packages = missing_model_dependencies()
if missing_packages:
    raise ImportError(
        "Missing station-stacking ML packages: "
        + ", ".join(missing_packages)
        + ". Install them with: python -m pip install -r requirements.txt"
    )

config = StationStackingConfig(
    station_id=STATION_ID,
    project_root=PROJECT_ROOT,
    timing_mode=TIMING_MODE,
    providers=PROVIDERS,
    fast_mode=FAST_MODE,
    optuna_trials=OPTUNA_TRIALS,
    stack_optuna_trials=STACK_OPTUNA_TRIALS,
    optuna_startup_trials=OPTUNA_STARTUP_TRIALS,
    stack_optuna_startup_trials=STACK_OPTUNA_STARTUP_TRIALS,
    optuna_metric=OPTUNA_METRIC,
    optuna_verbose=OPTUNA_VERBOSE,
    feature_version="v11",
    target_mode="remaining_warmup",
    target_source="settlement_first",
    base_model_methods=("xgboost", "lightgbm", "catboost"),
    stack_enabled=True,
    hyperparameter_space="wide",
    year_split_folds=YEAR_SPLIT_EXPANDING_FOLDS,
    year_split_test_train_years=(2021, 2025),
    year_split_test_year=2026,
    output_dir=PROJECT_ROOT / "data" / "calibration" / "station_stacking_v11_settlement",
)

config.resolved_optuna_storage_path()
# Out:
# WindowsPath('D:/dev/weather-research/data/calibration/station_stacking_v11_settlement/KORD_optuna.sqlite3')

# %%
result = run_station_year_split_experiment(config)
result.scoreboard
# Out:
# [I 2026-07-08 17:54:21,857] A new study created in RDB with name: KORD_v11_remaining_warmup_base_xgboost_mae_f
# [I 2026-07-08 17:54:25,700] Trial 0 finished with value: 1.3693129383548162 and parameters: {'n_estimators': 1342, 'learning_rate': 0.19043899115982607, 'max_depth': 9, 'min_child_weight': 2.481040974867813, 'gamma': 2.340279606636548, 'subsample': 0.4513964382185317, 'colsample_bytree': 0.3877543479093296, 'reg_alpha': 2.478071022662141, 'reg_lambda': 0.6132587025321562}. Best is trial 0 with value: 1.3693129383548162.
# [I 2026-07-08 17:54:50,949] Trial 1 finished with value: 1.2439189739838004 and parameters: {'n_estimators': 2493, 'learning_rate': 0.001120367191095075, 'max_depth': 12, 'min_child_weight': 21.368329072358772, 'gamma': 3.185086660174142, 'subsample': 0.4681862286846154, 'colsample_bytree': 0.46921293140473197, 'reg_alpha': 4.476173538513514e-07, 'reg_lambda': 0.20253776634919213}. Best is trial 1 with value: 1.2439189739838004.
# [I 2026-07-08 17:55:01,985] Trial 2 finished with value: 1.2579596777319335 and parameters: {'n_estimators': 1540, 'learning_rate': 0.004992867109217114, 'max_depth': 8, 'min_child_weight': 0.03613894271216528, 'gamma': 4.3821697280282725, 'subsample': 0.5881351981408995, 'colsample_bytree': 0.6464454897410734, 'reg_alpha': 0.26430874752361627, 'reg_lambda': 0.0018119678627933364}. Best is trial 1 with value: 1.2439189739838004.
# [I 2026-07-08 17:55:05,025] Trial 3 finished with value: 1.4530498282769422 and parameters: {'n_estimators': 1824, 'learning_rate': 0.026337502897485255, 'max_depth': 1, 'min_child_weight': 2.69264691008618, 'gamma': 2.557861855309373, 'subsample': 0.39228353544043165, 'colsample_bytree': 0.9667755992146666, 'reg_alpha': 38.6887231523051, 'reg_lambda': 12.408975837016275}. Best is trial 1 with value: 1.2439189739838004.
# [I 2026-07-08 17:55:25,494] Trial 4 finished with value: 1.275002260173137 and parameters: {'n_estimators': 1101, 'learning_rate': 0.0017147936629846843, 'max_depth': 9, 'min_child_weight': 0.5762487216478605, 'gamma': 1.8305735226716824, 'subsample': 0.6718649915723256, 'colsample_bytree': 0.37235253872489193, 'reg_alpha': 8.162906555194692, 'reg_lambda': 0.004271500153828077}. Best is trial 1 with value: 1.2439189739838004.
# [I 2026-07-08 17:55:33,514] Trial 5 pruned.
# [I 2026-07-08 17:55:35,012] Trial 6 finished with value: 1.1785476921404914 and parameters: {'n_estimators': 2113, 'learning_rate': 0.16240489353272883, 'max_depth': 2, 'min_child_weight': 0.06080390190296603, 'gamma': 0.678409333658071, 'subsample': 0.5614647149961218, 'colsample_bytree': 0.6026402382981633, 'reg_alpha': 1.8037999945880162e-07, 'reg_lambda': 16.668629892722056}. Best is trial 6 with value: 1.1785476921404914.
# [I 2026-07-08 17:55:43,584] Trial 7 finished with value: 1.2530316076224328 and parameters: {'n_estimators': 1281, 'learning_rate': 0.0047169807141865345, 'max_depth': 7, 'min_child_weight': 0.0366181922039243, 'gamma': 12.032954711310595, 'subsample': 0.398457918391851, 'colsample_bytree': 0.9914765087903362, 'reg_alpha': 0.18490013641000916, 'reg_lambda': 0.0017869543989965139}. Best is trial 6 with value: 1.1785476921404914.
# [I 2026-07-08 17:55:44,289] Trial 8 pruned.
# [I 2026-07-08 17:55:51,693] Trial 9 finished with value: 1.1822747725055494 and parameters: {'n_estimators': 2201, 'learning_rate': 0.006215464818952927, 'max_depth': 1, 'min_child_weight': 0.17535949529764422, 'gamma': 4.877749830401205, 'subsample': 0.8242440159197416, 'colsample_bytree': 0.7644123563808884, 'reg_alpha': 4.4315220126915325, 'reg_lambda': 0.09450187118503514}. Best is trial 6 with value: 1.1785476921404914.
# [I 2026-07-08 17:55:54,081] Trial 10 finished with value: 1.2067674730917255 and parameters: {'n_estimators': 462, 'learning_rate': 0.051323729958866915, 'max_depth': 10, 'min_child_weight': 1.7583640270008525, 'gamma': 11.564507699318415, 'subsample': 0.670967137636854, 'colsample_bytree': 0.689776339098296, 'reg_alpha': 1.3504926357029513e-05, 'reg_lambda': 0.0001445994629863374}. Best is trial 6 with value: 1.1785476921404914.
# [I 2026-07-08 17:55:58,793] Trial 11 pruned.
# [I 2026-07-08 17:56:03,522] Trial 12 pruned.
# [I 2026-07-08 17:56:04,739] Trial 13 finished with value: 1.2631667876796353 and parameters: {'n_estimators': 693, 'learning_rate': 0.13813474572232612, 'max_depth': 7, 'min_child_weight': 16.973078532467014, 'gamma': 13.4413694988524, 'subsample': 0.5567022587317115, 'colsample_bytree': 0.4215337509429899, 'reg_alpha': 5.435280359192946e-08, 'reg_lambda': 0.049115547267693904}. Best is trial 6 with value: 1.1785476921404914.
# [I 2026-07-08 17:56:07,013] Trial 14 finished with value: 1.2426761378932731 and parameters: {'n_estimators': 2872, 'learning_rate': 0.11587248002108354, 'max_depth': 1, 'min_child_weight': 1.1040511903162256, 'gamma': 6.261165047231685, 'subsample': 0.49437007680597467, 'colsample_bytree': 0.4279124887668938, 'reg_alpha': 1.125594744942969e-06, 'reg_lambda': 87.35792858155622}. Best is trial 6 with value: 1.1785476921404914.
# [I 2026-07-08 17:56:11,931] Trial 15 finished with value: 1.1678578603263365 and parameters: {'n_estimators': 3311, 'learning_rate': 0.021882197214300323, 'max_depth': 3, 'min_child_weight': 0.011927859366875052, 'gamma': 0.14583408410588616, 'subsample': 0.7986605978199443, 'colsample_bytree': 0.7925816793363801, 'reg_alpha': 0.000682381751719726, 'reg_lambda': 0.8912768993161009}. Best is trial 15 with value: 1.1678578603263365.
# [I 2026-07-08 17:56:18,072] Trial 16 finished with value: 1.1491604893704173 and parameters: {'n_estimators': 3489, 'learning_rate': 0.016923377887394654, 'max_depth': 4, 'min_child_weight': 0.012617266144018207, 'gamma': 0.4214460473461219, 'subsample': 0.785824078413485, 'colsample_bytree': 0.8628314771242156, 'reg_alpha': 0.0007576903076688566, 'reg_lambda': 1.1625216460944126}. Best is trial 16 with value: 1.1491604893704173.
# [I 2026-07-08 17:56:23,157] Trial 17 finished with value: 1.1555870299823945 and parameters: {'n_estimators': 3387, 'learning_rate': 0.017478919982976338, 'max_depth': 4, 'min_child_weight': 0.010688271471270726, 'gamma': 0.29701791685388135, 'subsample': 0.7742427801462375, 'colsample_bytree': 0.8836776088772242, 'reg_alpha': 0.004205855623396795, 'reg_lambda': 1.465423547146301}. Best is trial 16 with value: 1.1491604893704173.
# [I 2026-07-08 17:56:32,650] Trial 18 finished with value: 1.1585523162272624 and parameters: {'n_estimators': 3487, 'learning_rate': 0.01438545138802679, 'max_depth': 5, 'min_child_weight': 0.01017151639939029, 'gamma': 0.037889982164313885, 'subsample': 0.7340250690390144, 'colsample_bytree': 0.9063825581088962, 'reg_alpha': 0.0007359158454620779, 'reg_lambda': 2.0863400644255874}. Best is trial 16 with value: 1.1491604893704173.
# [I 2026-07-08 17:56:33,419] Trial 19 pruned.
# [I 2026-07-08 17:56:37,048] Trial 20 finished with value: 1.1944756175856144 and parameters: {'n_estimators': 2840, 'learning_rate': 0.0386264925527886, 'max_depth': 5, 'min_child_weight': 0.16089865946724494, 'gamma': 4.080078198702429, 'subsample': 0.8920319373806807, 'colsample_bytree': 0.8257583539924084, 'reg_alpha': 0.011131192957886156, 'reg_lambda': 2.712345891564254}. Best is trial 16 with value: 1.1491604893704173.
# [I 2026-07-08 17:56:45,609] Trial 21 finished with value: 1.1665164710705787 and parameters: {'n_estimators': 3471, 'learning_rate': 0.01204085449781824, 'max_depth': 5, 'min_child_weight': 0.0101840470324183, 'gamma': 0.03682297702110965, 'subsample': 0.7421394390884934, 'colsample_bytree': 0.9100805168854703, 'reg_alpha': 0.00012770666329636773, 'reg_lambda': 1.4281476698681874}. Best is trial 16 with value: 1.1491604893704173.
# [I 2026-07-08 17:56:50,094] Trial 22 finished with value: 1.1608614595579998 and parameters: {'n_estimators': 3111, 'learning_rate': 0.011165768124789038, 'max_depth': 3, 'min_child_weight': 0.01734791175943169, 'gamma': 1.3185057940720795, 'subsample': 0.6951401952749463, 'colsample_bytree': 0.9122903086448946, 'reg_alpha': 0.007190045560383356, 'reg_lambda': 0.39847427538905034}. Best is trial 16 with value: 1.1491604893704173.
# [I 2026-07-08 17:56:55,428] Trial 23 finished with value: 1.1618833812454405 and parameters: {'n_estimators': 3498, 'learning_rate': 0.020079297049253847, 'max_depth': 4, 'min_child_weight': 0.020235408412826842, 'gamma': 1.1519887619234084, 'subsample': 0.7919911798594643, 'colsample_bytree': 0.9404120157589297, 'reg_alpha': 0.0001391865601304027, 'reg_lambda': 3.1245271118195688}. Best is trial 16 with value: 1.1491604893704173.
# [I 2026-07-08 17:57:02,704] Trial 24 pruned.
# [I 2026-07-08 17:57:05,913] Trial 25 pruned.
# [I 2026-07-08 17:57:10,342] Trial 26 finished with value: 1.1826020025465587 and parameters: {'n_estimators': 2724, 'learning_rate': 0.014578363133963716, 'max_depth': 4, 'min_child_weight': 0.024336575395157052, 'gamma': 3.471741955807347, 'subsample': 0.7472498828633195, 'colsample_bytree': 0.8708942068406261, 'reg_alpha': 0.17780671342024662, 'reg_lambda': 0.1762932451396051}. Best is trial 16 with value: 1.1491604893704173.
# [I 2026-07-08 17:57:21,670] Trial 27 finished with value: 1.1643522798348787 and parameters: {'n_estimators': 3261, 'learning_rate': 0.00793551688421859, 'max_depth': 6, 'min_child_weight': 0.09749313672443319, 'gamma': 5.383339043898889, 'subsample': 0.6293815246746044, 'colsample_bytree': 0.945244543190166, 'reg_alpha': 1.9259069399239586e-05, 'reg_lambda': 2.461231370061554}. Best is trial 16 with value: 1.1491604893704173.
# [I 2026-07-08 17
 'huber_alpha': 0.95}. Best is trial 17 with value: 1.1739634497669709.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-08 17:58:16,330] Trial 22 finished with value: 1.1645032615675435 and parameters: {'n_estimators': 2055, 'learning_rate': 0.019934773440976425, 'num_leaves': 304, 'max_depth': 11, 'min_child_samples': 40, 'min_split_gain': 0.0024354529791752455, 'bagging_fraction': 0.7291762177441562, 'bagging_freq': 2, 'feature_fraction': 0.5557241983652298, 'lambda_l1': 0.07171853203786484, 'lambda_l2': 0.0006428279147979261, 'huber_alpha': 0.95}. Best is trial 22 with value: 1.1645032615675435.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-08 17:58:35,813] Trial 23 finished with value: 1.1547263774905614 and parameters: {'n_estimators': 1328, 'learning_rate': 0.021585287413772768, 'num_leaves': 323, 'max_depth': 6, 'min_child_samples': 28, 'min_split_gain': 0.015352952334779678, 'bagging_fraction': 0.7309314872450814, 'bagging_freq': 3, 'feature_fraction': 0.557693606143406, 'lambda_l1': 0.9800796584420298, 'lambda_l2': 0.0008908231972832377, 'huber_alpha': 0.95}. Best is trial 23 with value: 1.1547263774905614.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-08 17:58:48,320] Trial 24 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-08 18:00:40,370] Trial 25 finished with value: 1.1697729526814364 and parameters: {'n_estimators': 1235, 'learning_rate': 0.014954189371028215, 'num_leaves': 304, 'max_depth': 11, 'min_child_samples': 19, 'min_split_gain': 0.08468128821849114, 'bagging_fraction': 0.7595282157263585, 'bagging_freq': 1, 'feature_fraction': 0.47572116569105155, 'lambda_l1': 1.0951835699276729, 'lambda_l2': 0.0001080290874103325, 'huber_alpha': 0.75}. Best is trial 23 with value: 1.1547263774905614.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-08 18:02:17,992] Trial 26 finished with value: 1.171853106372852 and parameters: {'n_estimators': 1255, 'learning_rate': 0.014763300300996122, 'num_leaves': 354, 'max_depth': 12, 'min_child_samples': 17, 'min_split_gain': 0.022576008250848656, 'bagging_fraction': 0.7378403668009111, 'bagging_freq': 1, 'feature_fraction': 0.4562666601364905, 'lambda_l1': 1.8793325289280458, 'lambda_l2': 0.0008969418918440284, 'huber_alpha': 0.75}. Best is trial 23 with value: 1.1547263774905614.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-08 18:02:41,432] Trial 27 finished with value: 1.185776662489472 and parameters: {'n_estimators': 1274, 'learning_rate': 0.025307285209842705, 'num_leaves': 297, 'max_depth': 14, 'min_child_samples': 71, 'min_split_gain': 0.43131121811245965, 'bagging_fraction': 0.8249590658178106, 'bagging_freq': 1, 'feature_fraction': 0.5789237449599572, 'lambda_l1': 0.3968815338983269, 'lambda_l2': 0.00010621128607907683, 'huber_alpha': 0.75}. Best is trial 23 with value: 1.1547263774905614.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-08 18:02:51,853] Trial 28 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-08 18:03:12,348] Trial 29 finished with value: 1.196165690218648 and parameters: {'n_estimators': 1337, 'learning_rate': 0.03332797246324888, 'num_leaves': 368, 'max_depth': 12, 'min_child_samples': 16, 'min_split_gain': 0.3746514965281494, 'bagging_fraction': 0.8085254705393697, 'bagging_freq': 1, 'feature_fraction': 0.4355979162244991, 'lambda_l1': 8.64934486396058, 'lambda_l2': 0.013078608496018312, 'huber_alpha': 0.9}. Best is trial 23 with value: 1.1547263774905614.
# [I 2026-07-08 18:03:12,506] A new study created in RDB with name: KORD_v11_remaining_warmup_base_catboost_mae_f
# [I 2026-07-08 18:18:16,236] Trial 0 finished with value: 1.3976871102387285 and parameters: {'iterations': 2931, 'learning_rate': 0.001783588943232587, 'depth': 10, 'l2_leaf_reg': 0.9942958882300413, 'random_strength': 7.186216756161439, 'bagging_temperature': 12.184767612363034, 'border_count': 110, 'rsm': 0.6158971964095841, 'huber_delta': 1.5}. Best is trial 0 with value: 1.3976871102387285.
# [I 2026-07-08 18:32:48,995] Trial 1 finished with value: 1.472495491171738 and parameters: {'iterations': 801, 'learning_rate': 0.19767902101650964, 'depth': 12, 'l2_leaf_reg': 75.05056513807031, 'random_strength': 12.92821124806787, 'bagging_temperature': 4.276496242612171, 'border_count': 168, 'rsm': 0.4404450637901872, 'huber_delta': 1.0}. Best is trial 0 with value: 1.3976871102387285.
# [I 2026-07-08 18:33:52,361] Trial 2 finished with value: 1.4447398869442174 and parameters: {'iterations': 1992, 'learning_rate': 0.0024079350849750287, 'depth': 3, 'l2_leaf_reg': 0.118485976001343, 'random_strength': 4.058751860003342, 'bagging_temperature': 9.103785934457758, 'border_count': 206, 'rsm': 0.994034742637508, 'huber_delta': 0.5}. Best is trial 0 with value: 1.3976871102387285.
# [I 2026-07-08 18:52:51,894] Trial 3 finished with value: 1.5297699724132694 and parameters: {'iterations': 3095, 'learning_rate': 0.05508623515899769, 'depth': 11, 'l2_leaf_reg': 18.082710740309665, 'random_strength': 13.948598364083836, 'bagging_temperature': 18.60205606816345, 'border_count': 227, 'rsm': 0.4117317891426977, 'huber_delta': 3.0}. Best is trial 0 with value: 1.3976871102387285.
# [I 2026-07-08 18:53:16,607] Trial 4 finished with value: 1.3023690411591695 and parameters: {'iterations': 3146, 'learning_rate': 0.0024764229908984673, 'depth': 3, 'l2_leaf_reg': 0.6951779671472356, 'random_strength': 6.148451176512449, 'bagging_temperature': 8.441103735088014, 'border_count': 95, 'rsm': 0.7192489923988105, 'huber_delta': 2.0}. Best is trial 4 with value: 1.3023690411591695.
# [I 2026-07-08 18:53:23,248] Trial 5 finished with value: 1.2839266678420624 and parameters: {'iterations': 2996, 'learning_rate': 0.04169299311145666, 'depth': 2, 'l2_leaf_reg': 0.6483636109972302, 'random_strength': 11.284989840243444, 'bagging_temperature': 11.881552589055849, 'border_count': 179, 'rsm': 0.7610806862514128, 'huber_delta': 0.5}. Best is trial 5 with value: 1.2839266678420624.
# [I 2026-07-08 18:53:24,736] Trial 6 pruned.
# [I 2026-07-08 18:53:30,202] Trial 7 finished with value: 1.2992415430104243 and parameters: {'iterations': 2269, 'learning_rate': 0.05988786419186062, 'depth': 3, 'l2_leaf_reg': 0.8727148674658863, 'random_strength': 13.785080578883292, 'bagging_temperature': 3.643240241026453, 'border_count': 16, 'rsm': 0.5239102067389221, 'huber_delta': 0.5}. Best is trial 5 with value: 1.2839266678420624.
# [I 2026-07-08 18:53:46,216] Trial 8 pruned.
# [I 2026-07-08 18:56:16,822] Trial 9 finished with value: 1.247304470922023 and parameters: {'iterations': 2176, 'learning_rate': 0.006973123504821021, 'depth': 7, 'l2_leaf_reg': 1.0111907140307084, 'random_strength': 19.613513312465464, 'bagging_temperature': 8.113717548278494, 'border_count': 208, 'rsm': 0.7899333278528806, 'huber_delta': 5.0}. Best is trial 9 with value: 1.247304470922023.
# [I 2026-07-08 18:57:16,991] Trial 10 pruned.
# [I 2026-07-08 18:58:06,792] Trial 11 finished with value: 1.1775796809089054 and parameters: {'iterations': 2772, 'learning_rate': 0.014522829031783214, 'depth': 5, 'l2_leaf_reg': 15.987388321276002, 'random_strength': 11.591109950971106, 'bagging_temperature': 7.790667047006705, 'border_count': 126, 'rsm': 0.7500006952294106, 'huber_delta': 5.0}. Best is trial 11 with value: 1.1775796809089054.
# [I 2026-07-08 18:58:57,439] Trial 12 pruned.
# [I 2026-07-08 18:59:05,124] Trial 13 pruned.
# [I 2026-07-08 18:59:12,600] Trial 14 finished with value: 1.2337439380457897 and parameters: {'iterations': 2033, 'learning_rate': 0.03406017942217813, 'depth': 3, 'l2_leaf_reg': 2.8273302406131626, 'random_strength': 2.5986858551767766, 'bagging_temperature': 5.630188860588947, 'border_count': 58, 'rsm': 0.9026140460549269, 'huber_delta': 1.0}. Best is trial 11 with value: 1.1775796809089054.
# [I 2026-07-08 18:59:30,508] Trial 15 finished with value: 1.2232687069968706 and parameters: {'iterations': 1315, 'learning_rate': 0.014385732536856719, 'depth': 5, 'l2_leaf_reg': 3.851734847884429, 'random_strength': 16.094365397211288, 'bagging_temperature': 5.889443951608335, 'border_count': 45, 'rsm': 0.9247512589809201, 'huber_delta': 5.0}. Best is trial 11 with value: 1.1775796809089054.
# [I 2026-07-08 18:59:39,026] Trial 16 pruned.
# [I 2026-07-08 19:01:39,605] Trial 17 finished with value: 1.1857815773591733 and parameters: {'iterations': 3466, 'learning_rate': 0.006277057772508926, 'depth': 6, 'l2_leaf_reg': 8.15026783421867, 'random_strength': 16.574794818938415, 'bagging_temperature': 1.3263969896774768, 'border_count': 147, 'rsm': 0.9160969794177436, 'huber_delta': 5.0}. Best is trial 11 with value: 1.1775796809089054.
# [I 2026-07-08 19:03:24,798] Trial 18 finished with value: 1.2356927481879096 and parameters: {'iterations': 2613, 'learning_rate': 0.004994299712769344, 'depth': 6, 'l2_leaf_reg': 13.631090697889816, 'random_strength': 17.124972126147984, 'bagging_temperature': 0.31515488633751154, 'border_count': 125, 'rsm': 0.8260109735014788, 'huber_delta': 5.0}. Best is trial 11 with value: 1.1775796809089054.
# [I 2026-07-08 19:08:05,235] Trial 19 finished with value: 1.2261751199683608 and parameters: {'iterations': 3472, 'learning_rate': 0.004501937745014823, 'depth': 8, 'l2_leaf_reg': 11.368163253677341, 'random_strength': 11.184394489768632, 'bagging_temperature': 2.3007263719374276, 'border_count': 149, 'rsm': 0.6950418748652112, 'huber_delta': 3.0}. Best is trial 11 with value: 1.1775796809089054.
# [I 2026-07-08 19:08:36,233] Trial 20 finished with value: 1.1863483452097574 and parameters: {'iterations': 3478, 'learning_rate': 0.019410928337830636, 'depth': 5, 'l2_leaf_reg': 7.7001667147105195, 'random_strength': 15.230008686860389, 'bagging_temperature': 2.521731951133892, 'border_count': 155, 'rsm': 0.8910683221416084, 'huber_delta': 2.0}. Best is trial 11 with value: 1.1775796809089054.
# [I 2026-07-08
 'fit_intercept': False}. Best is trial 8 with value: 1.1694707064222174.
# [I 2026-07-08 19:12:59,809] Trial 18 finished with value: 1.172046139607942 and parameters: {'feature_set': 'models_only', 'alpha': 0.5783830013770976, 'fit_intercept': False}. Best is trial 8 with value: 1.1694707064222174.
# [I 2026-07-08 19:13:00,102] Trial 19 finished with value: 1.171799373777464 and parameters: {'feature_set': 'models_only', 'alpha': 4.358270202053984, 'fit_intercept': False}. Best is trial 8 with value: 1.1694707064222174.
# [I 2026-07-08 19:13:00,402] Trial 20 finished with value: 1.172085307696959 and parameters: {'feature_set': 'models_only', 'alpha': 0.0608965157002749, 'fit_intercept': False}. Best is trial 8 with value: 1.1694707064222174.
# [I 2026-07-08 19:13:00,692] Trial 21 finished with value: 1.1699886625379707 and parameters: {'feature_set': 'models_only', 'alpha': 5436.865513585029, 'fit_intercept': False}. Best is trial 8 with value: 1.1694707064222174.
# [I 2026-07-08 19:13:00,984] Trial 22 finished with value: 1.1705762274665905 and parameters: {'feature_set': 'models_only', 'alpha': 6599.751119819393, 'fit_intercept': False}. Best is trial 8 with value: 1.1694707064222174.
# [I 2026-07-08 19:13:01,284] Trial 23 finished with value: 1.1703532496551312 and parameters: {'feature_set': 'models_only', 'alpha': 6220.745525502731, 'fit_intercept': False}. Best is trial 8 with value: 1.1694707064222174.
# [I 2026-07-08 19:13:01,574] Trial 24 finished with value: 1.1697986436815013 and parameters: {'feature_set': 'models_only', 'alpha': 390.6518650948634, 'fit_intercept': False}. Best is trial 8 with value: 1.1694707064222174.
# [I 2026-07-08 19:13:01,860] Trial 25 finished with value: 1.1698355453024805 and parameters: {'feature_set': 'models_only', 'alpha': 320.46907188132917, 'fit_intercept': False}. Best is trial 8 with value: 1.1694707064222174.
# [I 2026-07-08 19:13:02,157] Trial 26 finished with value: 1.1710227978158507 and parameters: {'feature_set': 'models_only', 'alpha': 22.48897749615831, 'fit_intercept': False}. Best is trial 8 with value: 1.1694707064222174.
# [I 2026-07-08 19:13:02,452] Trial 27 finished with value: 1.1698693240496807 and parameters: {'feature_set': 'models_only', 'alpha': 265.781405531212, 'fit_intercept': False}. Best is trial 8 with value: 1.1694707064222174.
# [I 2026-07-08 19:13:02,747] Trial 28 finished with value: 1.1916866068373153 and parameters: {'feature_set': 'models_only', 'alpha': 23003.851097665724, 'fit_intercept': False}. Best is trial 8 with value: 1.1694707064222174.
# [I 2026-07-08 19:13:03,033] Trial 29 finished with value: 1.1713515841936513 and parameters: {'feature_set': 'models_only', 'alpha': 13.367293608180681, 'fit_intercept': False}. Best is trial 8 with value: 1.1694707064222174.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# ...
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
#                   period           method  count     mae_f    rmse_f
# 0   validation_2024_2025          xgboost    729  1.137944  1.597618
# 1   validation_2024_2025         lightgbm    729  1.147737  1.628881
# 2   validation_2024_2025         catboost    729  1.147623  1.606859
# 3   validation_2024_2025    provider_mean    729  1.693936  2.459455
# 4   validation_2024_2025  provider_median    729  1.725265  2.493881
# 5   validation_2024_2025          nbm_raw    729  1.799021  2.535360
# 6   validation_2024_2025         hrrr_raw    729  1.969290  2.855008
# 7   validation_2024_2025          gfs_raw    729  2.420050  3.277222
# 8              test_2026          xgboost    171  1.412887  1.842801
# 9              test_2026         lightgbm    171  1.462128  2.026468
# 10             test_2026         catboost    171  1.433127  1.967937
# 11             test_2026      ridge_stack    171  1.432844  1.927536
# 12             test_2026    provider_mean    171  2.382000  3.965904
# 13             test_2026  provider_median    171  2.582172  4.112286
# 14             test_2026          nbm_raw    171  2.571279  4.132723
# 15             test_2026         hrrr_raw    171  2.655024  4.335363
# 16             test_2026          gfs_raw    171  3.133090  4.515405

# %%
exported_weights = export_station_model_weights(
    project_root=PROJECT_ROOT,
    station_id=STATION_ID,
    artifact_dir=config.resolved_output_dir(),
    model_version=MODEL_VERSION,
    timing_mode=config.timing_mode,
    providers=tuple(config.providers),
    feature_version=config.effective_feature_version,
    optuna_metric=config.effective_optuna_metric,
    target_mode=config.effective_target_mode,
    target_source=config.effective_target_source,
    base_model_methods=tuple(config.effective_base_model_methods),
    stack_enabled=config.stack_enabled,
    source_pipeline="notebooks/station_stacking_v11_settlement",
)

exported_weights.bundle_path, exported_weights.manifest_path
# Out:
# (WindowsPath('D:/dev/weather-research/data/calibration/station_stacking_v11_settlement/model_weights/KORD_station_high_regressor_v11_wunderground_settlement_stack.joblib'),
#  WindowsPath('D:/dev/weather-research/data/calibration/station_stacking_v11_settlement/model_weights/KORD_station_high_regressor_v11_wunderground_settlement_stack.json'))

# %% [markdown]
# ## V11 Feature Coverage

# %%
v11_feature_coverage = (
    result.features[V11_FEATURE_COLUMNS]
    .notna()
    .mean()
    .mul(100)
    .sort_values(ascending=False)
    .rename("coverage_pct")
    .reset_index()
    .rename(columns={"index": "feature"})
)

v11_feature_coverage
# Out:
#                                               feature  coverage_pct
# 0                              v2_spread_per_warmup_f    100.000000
# 1                    v2_morning_warmup_to_consensus_f    100.000000
# 2              v3_remaining_warmup_from_high_so_far_f    100.000000
# 3                      v3_high_so_far_above_current_f    100.000000
# 4                      v2_humidity_warmup_interaction    100.000000
# 5                    v4_observed_precip_recent_mm_est    100.000000
# 6                        v4_forecast_wet_observed_dry    100.000000
# 7                   v4_forecast_observed_precip_match    100.000000
# 8            v3_humidity_remaining_warmup_interaction    100.000000
# 9                    v3_remaining_warmup_per_spread_f    100.000000
# 10                             v4_all_forecast_precip    100.000000
# 11                             v4_observed_precip_any    100.000000
# 12                             v4_any_forecast_precip    100.000000
# 13                    v8_month_remaining_warmup_count    100.000000
# 14                             climatology_high_10y_f    100.000000
# 15                         climatology_high_10y_std_f    100.000000
# 16       observed_high_so_far_minus_climatology_10y_f    100.000000
# 17              observed_temp_minus_climatology_10y_f    100.000000
# 18                         climatology_high_10y_count    100.000000
# 19              provider_mean_minus_climatology_10y_f    100.000000
# 20          v8_provider_spread_per_remaining_warmup_f    100.000000
# 21                       v4_observed_wet_forecast_dry    100.000000
# 22       v8_provider_min_remaining_from_high_so_far_f    100.000000
# 23    v8_provider_median_remaining_from_high_so_far_f    100.000000
# 24       v8_provider_max_remaining_from_high_so_far_f    100.000000
# 25                   v3_high_so_far_minus_7d_actual_f     99.949950
# 26                          v2_recent_heat_momentum_f     99.949950
# 27                     v2_consensus_minus_7d_actual_f     99.949950
# 28                      v3_high_so_far_minus_lag_1d_f     99.949950
# 29                           v2_recent_heat_anomaly_f     99.949950
# 30            observed_high_so_far_change_since_9am_f     99.949950
# 31            observed_morning_warmup_rate_f_per_hour     99.949950
# 32                     observed_temp_change_last_3h_f     99.949950
# 33                     observed_temp_change_last_1h_f     99.949950
# 34               v8_recent_remaining_warmup_7d_mean_f     99.899900
# 35              v8_recent_remaining_warmup_30d_mean_f     99.749750
# 36       v8_provider_mean_remaining_vs_month_normal_f     98.798799
# 37                   v8_month_remaining_warmup_mean_f     98.798799
# 38      v8_dewpoint_mean_remaining_warmup_interaction     79.929930
# 39  v8_dewpoint_depression_remaining_warmup_intera...     79.929930
# 40                        v8_forecast_dewpoint_mean_f     79.929930
# 41             v8_forecast_dewpoint_depression_mean_f     79.929930
# 42         v4_forecast_total_minus_observed_recent_mm     79.479479
# 43                   v4_forecast_precip_intensity_max     79.479479
# 44                   v4_forecast_precip_total_mean_mm     79.479479
# 45                    v4_forecast_precip_total_max_mm     79.479479
# 46                 v4_forecast_precip_total_spread_mm     79.479479
# 47                  v4_forecast_precip_max_1h_mean_mm     79.479479
# 48                      v4_forecast_precip_hours_mean     79.479479
# 49                  v4_forecast_precip_intensity_mean     79.479479
# 50             v4_precip_remaining_warmup_interaction     79.479479
# 51                     v4_precip_humidity_interaction     79.479479
# 52       v8_precip_total_remaining_warmup_interaction     79.479479
# 53      v8_precip_max_1h_remaining_warmup_interaction     79.479479
# 54    v8_wind_speed_mean_remaining_warmup_interaction     36.186186
# 55      v8_wind_gust_max_remaining_warmup_interaction     36.186186
# 56    v8_cloud_cover_max_remaining_warmup_interaction      0.000000
# 57   v8_cloud_cover_mean_remaining_warmup_interaction      0.000000

# %%
result.feature_columns.loc[result.feature_columns["feature"].isin(V11_FEATURE_COLUMNS)]
# Out:
#                                                feature     kind
# 20                      observed_temp_change_last_1h_f  numeric
# 21                      observed_temp_change_last_3h_f  numeric
# 22             observed_morning_warmup_rate_f_per_hour  numeric
# 23             observed_high_so_far_change_since_9am_f  numeric
# 221                           v2_recent_heat_anomaly_f  numeric
# 222                          v2_recent_heat_momentum_f  numeric
# 223                   v2_morning_warmup_to_consensus_f  numeric
# 224                     v2_consensus_minus_7d_actual_f  numeric
# 225                             v2_spread_per_warmup_f  numeric
# 226                     v2_humidity_warmup_interaction  numeric
# 227                     v3_high_so_far_above_current_f  numeric
# 228             v3_remaining_warmup_from_high_so_far_f  numeric
# 229                      v3_high_so_far_minus_lag_1d_f  numeric
# 230                   v3_high_so_far_minus_7d_actual_f  numeric
# 231                   v3_remaining_warmup_per_spread_f  numeric
# 232           v3_humidity_remaining_warmup_interaction  numeric
# 233                   v4_forecast_precip_total_mean_mm  numeric
# 234                    v4_forecast_precip_total_max_mm  numeric
# 235                 v4_forecast_precip_total_spread_mm  numeric
# 236                  v4_forecast_precip_max_1h_mean_mm  numeric
# 237                      v4_forecast_precip_hours_mean  numeric
# 238                  v4_forecast_precip_intensity_mean  numeric
# 239                   v4_forecast_precip_intensity_max  numeric
# 240                             v4_any_forecast_precip  numeric
# 241                             v4_all_forecast_precip  numeric
# 242                             v4_observed_precip_any  numeric
# 243                   v4_observed_precip_recent_mm_est  numeric
# 244         v4_forecast_total_minus_observed_recent_mm  numeric
# 245                  v4_forecast_observed_precip_match  numeric
# 246                       v4_forecast_wet_observed_dry  numeric
# 247                       v4_observed_wet_forecast_dry  numeric
# 248                     v4_precip_humidity_interaction  numeric
# 249             v4_precip_remaining_warmup_interaction  numeric
# 250       v8_provider_max_remaining_from_high_so_far_f  numeric
# 251       v8_provider_min_remaining_from_high_so_far_f  numeric
# 252    v8_provider_median_remaining_from_high_so_far_f  numeric
# 253          v8_provider_spread_per_remaining_warmup_f  numeric
# 254                   v8_month_remaining_warmup_mean_f  numeric
# 255                    v8_month_remaining_warmup_count  numeric
# 256               v8_recent_remaining_warmup_7d_mean_f  numeric
# 257              v8_recent_remaining_warmup_30d_mean_f  numeric
# 258       v8_provider_mean_remaining_vs_month_normal_f  numeric
# 259       v8_precip_total_remaining_warmup_interaction  numeric
# 260      v8_precip_max_1h_remaining_warmup_interaction  numeric
# 261    v8_wind_speed_mean_remaining_warmup_interaction  numeric
# 262      v8_wind_gust_max_remaining_warmup_interaction  numeric
# 263                        v8_forecast_dewpoint_mean_f  numeric
# 264             v8_forecast_dewpoint_depression_mean_f  numeric
# 265      v8_dewpoint_mean_remaining_warmup_interaction  numeric
# 266  v8_dewpoint_depression_remaining_warmup_intera...  numeric
# 267                             climatology_high_10y_f  numeric
# 268                         climatology_high_10y_std_f  numeric
# 269                         climatology_high_10y_count  numeric
# 270              provider_mean_minus_climatology_10y_f  numeric
# 271              observed_temp_minus_climatology_10y_f  numeric
# 272       observed_high_so_far_minus_climatology_10y_f  numeric

# %% [markdown]
# ## Dropped Feature Check

# %%
dropped_present = result.feature_columns.loc[
    result.feature_columns["feature"].isin(V11_DROPPED_FEATURE_COLUMNS)
]

dropped_present
# Out:
# Empty DataFrame
# Columns: [feature, kind]
# Index: []

# %% [markdown]
# ## Morning Trend Coverage

# %%
trend_coverage = (
    result.features[TREND_COLUMNS]
    .notna()
    .mean()
    .mul(100)
    .sort_values(ascending=False)
    .rename("coverage_pct")
    .reset_index()
    .rename(columns={"index": "feature"})
)

trend_coverage
# Out:
#                                    feature  coverage_pct
# 0           observed_temp_change_last_1h_f      99.94995
# 1           observed_temp_change_last_3h_f      99.94995
# 2  observed_morning_warmup_rate_f_per_hour      99.94995
# 3  observed_high_so_far_change_since_9am_f      99.94995

# %% [markdown]
# ## Rounded Within 1F Accuracy

# %%
preds = pd.concat(
    [
        result.validation_predictions.assign(period="validation_2024_2025"),
        result.test_predictions.assign(period="oof_2026"),
    ],
    ignore_index=True,
)

predicted_high = pd.to_numeric(preds["predicted_high_f"], errors="coerce")
preds["predicted_high_rounded_f"] = np.floor(predicted_high + 0.5)
preds["within_1f_after_round"] = (
    pd.to_numeric(preds["actual_high_f"], errors="coerce") - preds["predicted_high_rounded_f"]
).abs().le(1)

within_1f_accuracy_by_period = (
    preds
    .dropna(subset=["actual_high_f", "predicted_high_rounded_f"])
    .groupby(["period", "method"], as_index=False)
    .agg(
        count=("within_1f_after_round", "size"),
        within_1f_count=("within_1f_after_round", "sum"),
        within_1f_accuracy_pct=("within_1f_after_round", lambda x: x.mean() * 100),
    )
    .sort_values(["period", "within_1f_accuracy_pct"], ascending=[True, False])
)

within_1f_accuracy_by_period
# Out:
#                   period           method  count  within_1f_count  \
# 7               oof_2026      ridge_stack    171              106
# 0               oof_2026         catboost    171              105
# 3               oof_2026         lightgbm    171              104
# 8               oof_2026          xgboost    171              104
# 5               oof_2026    provider_mean    171               85
# 2               oof_2026         hrrr_raw    171               78
# 4               oof_2026          nbm_raw    171               78
# 6               oof_2026  provider_median    171               76
# 1               oof_2026          gfs_raw    171               69
# 12  validation_2024_2025         lightgbm    729              533
# 9   validation_2024_2025         catboost    729              529
# 16  validation_2024_2025          xgboost    729              528
# 15  validation_2024_2025  provider_median    729              421
# 14  validation_2024_2025    provider_mean    729              416
# 11  validation_2024_2025         hrrr_raw    729              403
# 13  validation_2024_2025          nbm_raw    729              399
# 10  validation_2024_2025          gfs_raw    729              303
#
#     within_1f_accuracy_pct
# 7                61.988304
# 0                61.403509
# 3                60.818713
# 8                60.818713
# 5                49.707602
# 2                45.614035
# 4                45.614035
# 6                44.444444
# 1                40.350877
# 12               73.113855
# 9                72.565158
# 16               72.427984
# 15               57.750343
# 14               57.064472
# 11               55.281207
# 13               54.732510
# 10               41.563786

# %% [markdown]
# ## Version Comparison

# %%
comparison_frames = []
for version, folder in [
    ("v1", PROJECT_ROOT / "data" / "calibration" / "station_stacking"),
    ("v2", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v2"),
    ("v3", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v3"),
    ("v4", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v4"),
    ("v5", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v5"),
    ("v6", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v6"),
    ("v7", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v7"),
    ("v8", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v8"),
    ("v9", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v9"),
    ("v10", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v10"),
    ("v11", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v11"),
]:
    path = folder / f"{STATION_ID}_year_split_scoreboard.csv"
    if path.exists():
        frame = pd.read_csv(path)
        frame["version"] = version
        comparison_frames.append(frame)

version_comparison = pd.concat(comparison_frames, ignore_index=True) if comparison_frames else pd.DataFrame()
if not version_comparison.empty:
    version_comparison = version_comparison.sort_values(["period", "mae_f", "version", "method"]).reset_index(drop=True)
version_comparison
# Out:
#                   period       method  count     mae_f    rmse_f version
# 0              test_2026      xgboost    137  1.391125  1.821460      v9
# 1              test_2026  ridge_stack    137  1.393311  1.886898      v9
# 2              test_2026     catboost    137  1.406520  1.847189      v9
# 3              test_2026      xgboost    137  1.426283  1.945238     v11
# 4              test_2026  ridge_stack    137  1.438460  1.967711     v11
# ..                   ...          ...    ...       ...       ...     ...
# 83  validation_2024_2025      gfs_raw    722  2.760890  3.651039      v9
# 84  validation_2024_2025      gfs_raw    658  2.805959  3.717535      v7
# 85  validation_2024_2025      gfs_raw    660  2.893424  4.186794      v1
# 86  validation_2024_2025      gfs_raw    660  2.893424  4.186794      v2
# 87  validation_2024_2025      gfs_raw    660  2.893424  4.186794      v3
#
# [88 rows x 6 columns]

# %% [markdown]
# ## 2026 OOF Weather Brackets

# %%
result.bracket_metrics
# Out:
#             method  count     mae_f    rmse_f  bracket_accuracy_pct
# 0          xgboost    171  1.412887  1.842801              45.02924
# 1         lightgbm    171  1.462128  2.026468             41.520468
# 2         catboost    171  1.433127  1.967937             44.444444
# 3      ridge_stack    171  1.432844  1.927536              45.02924
# 4    provider_mean    171  2.382000  3.965904             37.426901
# 5  provider_median    171  2.582172  4.112286             33.918129
# 6          nbm_raw    171  2.571279  4.132723             29.239766
# 7         hrrr_raw    171  2.655024  4.335363             32.748538
# 8          gfs_raw    171  3.133090  4.515405             28.654971

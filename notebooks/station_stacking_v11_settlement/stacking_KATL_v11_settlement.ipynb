# %% [markdown]
# # Station Stacking v11 Settlement - KATL
#
# Experimental notebook for `KATL`.
#
# This controlled rerun keeps the exact v11 feature/model contract, replaces daily-high labels with settlement-first Wunderground station history when available, and writes separate artifacts to `data/calibration/station_stacking_v11_settlement`.

# %%
from pathlib import Path
import os
import sys
import warnings

warnings.filterwarnings("ignore", message="IProgress not found.*")
warnings.filterwarnings("ignore", message="Skipping features without any observed values.*")

PROJECT_ROOT = Path.cwd().resolve()
while not (PROJECT_ROOT / "src" / "calibration" / "station_stacking.py").exists():
    if PROJECT_ROOT.parent == PROJECT_ROOT:
        raise RuntimeError("Could not find project root containing src/calibration/station_stacking.py")
    PROJECT_ROOT = PROJECT_ROOT.parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

os.environ["WEATHER_RESEARCH_INCLUDE_DIRECT_NBM"] = "1"

STATION_ID = "KATL"
PROVIDERS = ("gfs", "hrrr", "nbm")
TREND_COLUMNS = [
    "observed_temp_change_last_1h_f",
    "observed_temp_change_last_3h_f",
    "observed_morning_warmup_rate_f_per_hour",
    "observed_high_so_far_change_since_9am_f",
]
TIMING_MODE = "same_day_11am_live_safe"
FAST_MODE = False
OPTUNA_TRIALS = 30
STACK_OPTUNA_TRIALS = 30
OPTUNA_STARTUP_TRIALS = 15
STACK_OPTUNA_STARTUP_TRIALS = 15
OPTUNA_METRIC = "mae_f"
OPTUNA_VERBOSE = True
MODEL_VERSION = "station_high_regressor_v11_wunderground_settlement_stack"
PROJECT_ROOT
# Out:
# WindowsPath('D:/dev/weather-research')

# %%
import numpy as np
import pandas as pd

from src.export_station_stacking_v2_models import export_station_model_weights
from src.calibration.station_stacking import (
    StationStackingConfig,
    V11_DROPPED_FEATURE_COLUMNS,
    V11_FEATURE_COLUMNS,
    YEAR_SPLIT_EXPANDING_FOLDS,
    missing_model_dependencies,
    provider_availability,
    run_station_year_split_experiment,
)

# %% [markdown]
# ## V11 Contract
#
# `feature_version="v11"` keeps the v9 feature contract and remaining-warmup target, but trains base learners with Huber-style objectives while retaining the ridge stack selected by validation MAE.

# %%
fold_spec = pd.DataFrame(
    [
        {
            "fold": fold.name,
            "train_start_year": fold.train_start_year,
            "train_end_year": fold.train_end_year,
            "validation_year": fold.validation_year,
        }
        for fold in YEAR_SPLIT_EXPANDING_FOLDS
    ]
)

fold_spec
# Out:
#                      fold  train_start_year  train_end_year  validation_year
# 0  fold_2021_2023_to_2024              2021            2023             2024
# 1  fold_2021_2024_to_2025              2021            2024             2025

# %%
V11_FEATURE_COLUMNS, sorted(V11_DROPPED_FEATURE_COLUMNS)
# Out:
# (['v2_recent_heat_anomaly_f',
#   'v2_recent_heat_momentum_f',
#   'v2_morning_warmup_to_consensus_f',
#   'v2_consensus_minus_7d_actual_f',
#   'v2_spread_per_warmup_f',
#   'v2_humidity_warmup_interaction',
#   'v3_high_so_far_above_current_f',
#   'v3_remaining_warmup_from_high_so_far_f',
#   'v3_high_so_far_minus_lag_1d_f',
#   'v3_high_so_far_minus_7d_actual_f',
#   'v3_remaining_warmup_per_spread_f',
#   'v3_humidity_remaining_warmup_interaction',
#   'v4_forecast_precip_total_mean_mm',
#   'v4_forecast_precip_total_max_mm',
#   'v4_forecast_precip_total_spread_mm',
#   'v4_forecast_precip_max_1h_mean_mm',
#   'v4_forecast_precip_hours_mean',
#   'v4_forecast_precip_intensity_mean',
#   'v4_forecast_precip_intensity_max',
#   'v4_any_forecast_precip',
#   'v4_all_forecast_precip',
#   'v4_observed_precip_any',
#   'v4_observed_precip_recent_mm_est',
#   'v4_forecast_total_minus_observed_recent_mm',
#   'v4_forecast_observed_precip_match',
#   'v4_forecast_wet_observed_dry',
#   'v4_observed_wet_forecast_dry',
#   'v4_precip_humidity_interaction',
#   'v4_precip_remaining_warmup_interaction',
#   'observed_temp_change_last_1h_f',
#   'observed_temp_change_last_3h_f',
#   'observed_morning_warmup_rate_f_per_hour',
#   'observed_high_so_far_change_since_9am_f',
#   'v8_provider_max_remaining_from_high_so_far_f',
#   'v8_provider_min_remaining_from_high_so_far_f',
#   'v8_provider_median_remaining_from_high_so_far_f',
#   'v8_provider_spread_per_remaining_warmup_f',
#   'v8_month_remaining_warmup_mean_f',
#   'v8_month_remaining_warmup_count',
#   'v8_recent_remaining_warmup_7d_mean_f',
#   'v8_recent_remaining_warmup_30d_mean_f',
#   'v8_provider_mean_remaining_vs_month_normal_f',
#   'v8_cloud_cover_mean_remaining_warmup_interaction',
#   'v8_cloud_cover_max_remaining_warmup_interaction',
#   'v8_precip_total_remaining_warmup_interaction',
#   'v8_precip_max_1h_remaining_warmup_interaction',
#   'v8_wind_speed_mean_remaining_warmup_interaction',
#   'v8_wind_gust_max_remaining_warmup_interaction',
#   'v8_forecast_dewpoint_mean_f',
#   'v8_forecast_dewpoint_depression_mean_f',
#   'v8_dewpoint_mean_remaining_warmup_interaction',
#   'v8_dewpoint_depression_remaining_warmup_interaction',
#   'climatology_high_10y_f',
#   'climatology_high_10y_std_f',
#   'climatology_high_10y_count',
#   'provider_mean_minus_climatology_10y_f',
#   'observed_temp_minus_climatology_10y_f',
#   'observed_high_so_far_minus_climatology_10y_f'],
#  ['actual_minus_climatology_10y_f_DIAGNOSTIC_ONLY',
#   'climatology_source_end_year',
#   'climatology_source_start_year',
#   'gfs_as_of_hour_local',
#   'gfs_available',
#   'gfs_forecast_window_hours',
#   'gfs_grid_dist_km_mean',
#   'gfs_horizon_hours',
#   'gfs_hrrr_grid_dist_km_mean_abs_diff_f',
#   'gfs_hrrr_grid_dist_km_mean_diff_f',
#   'gfs_issue_hour_utc',
#   'gfs_missing',
#   'hrrr_as_of_hour_local',
#   'hrrr_available',
#   'hrrr_forecast_hour_max',
#   'hrrr_forecast_hour_min',
#   'hrrr_forecast_lead_hours',
#   'hrrr_forecast_window_hours',
#   'hrrr_grid_dist_km_mean',
#   'hrrr_horizon_hours',
#   'hrrr_issue_hour_local',
#   'hrrr_issue_hour_utc',
#   'hrrr_missing',
#   'is_active_polymarket_station',
#   'lat',
#   'lon',
#   'nbm_as_of_hour_local',
#   'nbm_available',
#   'nbm_forecast_window_hours',
#   'nbm_horizon_hours',
#   'nbm_issue_hour_local',
#   'nbm_issue_hour_utc',
#   'nbm_missing',
#   'observed_fetch_status',
#   'observed_observation_type',
#   'observed_pressure_source',
#   'provider_count_available',
#   'year'])

# %% [markdown]
# ## Data Availability

# %%
availability = provider_availability(
    PROJECT_ROOT,
    timing_mode=TIMING_MODE,
    providers=PROVIDERS,
)

availability.loc[availability["station_id"].eq(STATION_ID)]
# Out:
#   station_id provider  row_count first_contract_date last_contract_date
# 0       KATL      gfs       1998          2021-01-01         2026-06-21
# 1       KATL     hrrr       1998          2021-01-01         2026-06-21
# 2       KATL      nbm       1997          2021-01-01         2026-06-21

# %% [markdown]
# ## Model Scores

# %%
missing_packages = missing_model_dependencies()
if missing_packages:
    raise ImportError(
        "Missing station-stacking ML packages: "
        + ", ".join(missing_packages)
        + ". Install them with: python -m pip install -r requirements.txt"
    )

config = StationStackingConfig(
    station_id=STATION_ID,
    project_root=PROJECT_ROOT,
    timing_mode=TIMING_MODE,
    providers=PROVIDERS,
    fast_mode=FAST_MODE,
    optuna_trials=OPTUNA_TRIALS,
    stack_optuna_trials=STACK_OPTUNA_TRIALS,
    optuna_startup_trials=OPTUNA_STARTUP_TRIALS,
    stack_optuna_startup_trials=STACK_OPTUNA_STARTUP_TRIALS,
    optuna_metric=OPTUNA_METRIC,
    optuna_verbose=OPTUNA_VERBOSE,
    feature_version="v11",
    target_mode="remaining_warmup",
    target_source="settlement_first",
    base_model_methods=("xgboost", "lightgbm", "catboost"),
    stack_enabled=True,
    hyperparameter_space="wide",
    year_split_folds=YEAR_SPLIT_EXPANDING_FOLDS,
    year_split_test_train_years=(2021, 2025),
    year_split_test_year=2026,
    output_dir=PROJECT_ROOT / "data" / "calibration" / "station_stacking_v11_settlement",
)

config.resolved_optuna_storage_path()
# Out:
# WindowsPath('D:/dev/weather-research/data/calibration/station_stacking_v11_settlement/KATL_optuna.sqlite3')

# %%
result = run_station_year_split_experiment(config)
result.scoreboard
# Out:
# [I 2026-07-06 21:20:30,045] A new study created in RDB with name: KATL_v11_remaining_warmup_base_xgboost_mae_f
# [I 2026-07-06 21:20:37,765] Trial 0 finished with value: 1.970061125040234 and parameters: {'n_estimators': 1342, 'learning_rate': 0.19043899115982607, 'max_depth': 9, 'min_child_weight': 2.481040974867813, 'gamma': 2.340279606636548, 'subsample': 0.4513964382185317, 'colsample_bytree': 0.3877543479093296, 'reg_alpha': 2.478071022662141, 'reg_lambda': 0.6132587025321562}. Best is trial 0 with value: 1.970061125040234.
# [I 2026-07-06 21:22:18,796] Trial 1 finished with value: 1.4499781290268485 and parameters: {'n_estimators': 2493, 'learning_rate': 0.001120367191095075, 'max_depth': 12, 'min_child_weight': 21.368329072358772, 'gamma': 3.185086660174142, 'subsample': 0.4681862286846154, 'colsample_bytree': 0.46921293140473197, 'reg_alpha': 4.476173538513514e-07, 'reg_lambda': 0.20253776634919213}. Best is trial 1 with value: 1.4499781290268485.
# [I 2026-07-06 21:22:49,267] Trial 2 finished with value: 1.4618948102925717 and parameters: {'n_estimators': 1540, 'learning_rate': 0.004992867109217114, 'max_depth': 8, 'min_child_weight': 0.03613894271216528, 'gamma': 4.3821697280282725, 'subsample': 0.5881351981408995, 'colsample_bytree': 0.6464454897410734, 'reg_alpha': 0.26430874752361627, 'reg_lambda': 0.0018119678627933364}. Best is trial 1 with value: 1.4499781290268485.
# [I 2026-07-06 21:23:01,893] Trial 3 finished with value: 1.6153060612621704 and parameters: {'n_estimators': 1824, 'learning_rate': 0.026337502897485255, 'max_depth': 1, 'min_child_weight': 2.69264691008618, 'gamma': 2.557861855309373, 'subsample': 0.39228353544043165, 'colsample_bytree': 0.9667755992146666, 'reg_alpha': 38.6887231523051, 'reg_lambda': 12.408975837016275}. Best is trial 1 with value: 1.4499781290268485.
# [I 2026-07-06 21:24:59,149] Trial 4 finished with value: 1.445989159771258 and parameters: {'n_estimators': 1101, 'learning_rate': 0.0017147936629846843, 'max_depth': 9, 'min_child_weight': 0.5762487216478605, 'gamma': 1.8305735226716824, 'subsample': 0.6718649915723256, 'colsample_bytree': 0.37235253872489193, 'reg_alpha': 8.162906555194692, 'reg_lambda': 0.004271500153828077}. Best is trial 4 with value: 1.445989159771258.
# [I 2026-07-06 21:26:43,043] Trial 5 finished with value: 1.5187456388442162 and parameters: {'n_estimators': 2336, 'learning_rate': 0.00559067775661512, 'max_depth': 7, 'min_child_weight': 1.5375920235481764, 'gamma': 2.7728168328829055, 'subsample': 0.980230008046963, 'colsample_bytree': 0.8538363351847245, 'reg_alpha': 18.792618557420877, 'reg_lambda': 43.484449457612314}. Best is trial 4 with value: 1.445989159771258.
# [I 2026-07-06 21:26:47,634] Trial 6 finished with value: 1.3917106318527075 and parameters: {'n_estimators': 2113, 'learning_rate': 0.16240489353272883, 'max_depth': 2, 'min_child_weight': 0.06080390190296603, 'gamma': 0.678409333658071, 'subsample': 0.5614647149961218, 'colsample_bytree': 0.6026402382981633, 'reg_alpha': 1.8037999945880162e-07, 'reg_lambda': 16.668629892722056}. Best is trial 6 with value: 1.3917106318527075.
# [I 2026-07-06 21:26:56,034] Trial 7 pruned.
# [I 2026-07-06 21:27:00,566] Trial 8 pruned.
# [I 2026-07-06 21:27:31,464] Trial 9 finished with value: 1.4017033602415783 and parameters: {'n_estimators': 2201, 'learning_rate': 0.006215464818952927, 'max_depth': 1, 'min_child_weight': 0.17535949529764422, 'gamma': 4.877749830401205, 'subsample': 0.8242440159197416, 'colsample_bytree': 0.7644123563808884, 'reg_alpha': 4.4315220126915325, 'reg_lambda': 0.09450187118503514}. Best is trial 6 with value: 1.3917106318527075.
# [I 2026-07-06 21:27:43,923] Trial 10 finished with value: 1.4369746911396646 and parameters: {'n_estimators': 462, 'learning_rate': 0.051323729958866915, 'max_depth': 10, 'min_child_weight': 1.7583640270008525, 'gamma': 11.564507699318415, 'subsample': 0.670967137636854, 'colsample_bytree': 0.689776339098296, 'reg_alpha': 1.3504926357029513e-05, 'reg_lambda': 0.0001445994629863374}. Best is trial 6 with value: 1.3917106318527075.
# [I 2026-07-06 21:28:00,189] Trial 11 pruned.
# [I 2026-07-06 21:28:17,045] Trial 12 pruned.
# [I 2026-07-06 21:28:19,031] Trial 13 pruned.
# [I 2026-07-06 21:28:25,612] Trial 14 finished with value: 1.4075385046347622 and parameters: {'n_estimators': 2872, 'learning_rate': 0.11587248002108354, 'max_depth': 1, 'min_child_weight': 1.1040511903162256, 'gamma': 6.261165047231685, 'subsample': 0.49437007680597467, 'colsample_bytree': 0.4279124887668938, 'reg_alpha': 1.125594744942969e-06, 'reg_lambda': 87.35792858155622}. Best is trial 6 with value: 1.3917106318527075.
# [I 2026-07-06 21:28:41,559] Trial 15 finished with value: 1.3804406416138697 and parameters: {'n_estimators': 3311, 'learning_rate': 0.021882197214300323, 'max_depth': 3, 'min_child_weight': 0.011927859366875052, 'gamma': 0.14583408410588616, 'subsample': 0.7986605978199443, 'colsample_bytree': 0.7925816793363801, 'reg_alpha': 0.000682381751719726, 'reg_lambda': 0.8912768993161009}. Best is trial 15 with value: 1.3804406416138697.
# [I 2026-07-06 21:29:05,235] Trial 16 finished with value: 1.345375001139902 and parameters: {'n_estimators': 3489, 'learning_rate': 0.016923377887394654, 'max_depth': 4, 'min_child_weight': 0.012617266144018207, 'gamma': 0.4214460473461219, 'subsample': 0.785824078413485, 'colsample_bytree': 0.8628314771242156, 'reg_alpha': 0.0007576903076688566, 'reg_lambda': 1.1625216460944126}. Best is trial 16 with value: 1.345375001139902.
# [I 2026-07-06 21:29:38,370] Trial 17 finished with value: 1.3589970671420546 and parameters: {'n_estimators': 3387, 'learning_rate': 0.017478919982976338, 'max_depth': 4, 'min_child_weight': 0.010688271471270726, 'gamma': 0.29701791685388135, 'subsample': 0.7742427801462375, 'colsample_bytree': 0.8836776088772242, 'reg_alpha': 0.004205855623396795, 'reg_lambda': 1.465423547146301}. Best is trial 16 with value: 1.345375001139902.
# [I 2026-07-06 21:30:16,814] Trial 18 finished with value: 1.5199860888601395 and parameters: {'n_estimators': 3487, 'learning_rate': 0.01438545138802679, 'max_depth': 5, 'min_child_weight': 0.01017151639939029, 'gamma': 0.037889982164313885, 'subsample': 0.7340250690390144, 'colsample_bytree': 0.9063825581088962, 'reg_alpha': 0.0007359158454620779, 'reg_lambda': 2.0863400644255874}. Best is trial 16 with value: 1.345375001139902.
# [I 2026-07-06 21:30:18,349] Trial 19 pruned.
# [I 2026-07-06 21:30:30,610] Trial 20 finished with value: 1.4178006468474473 and parameters: {'n_estimators': 2840, 'learning_rate': 0.0386264925527886, 'max_depth': 5, 'min_child_weight': 0.16089865946724494, 'gamma': 4.080078198702429, 'subsample': 0.8920319373806807, 'colsample_bytree': 0.8257583539924084, 'reg_alpha': 0.011131192957886156, 'reg_lambda': 2.712345891564254}. Best is trial 16 with value: 1.345375001139902.
# [I 2026-07-06 21:30:35,454] Trial 21 pruned.
# [I 2026-07-06 21:30:59,914] Trial 22 finished with value: 1.361584319123598 and parameters: {'n_estimators': 3145, 'learning_rate': 0.010055444949257489, 'max_depth': 3, 'min_child_weight': 0.01796933469777027, 'gamma': 0.07379839518518894, 'subsample': 0.7777811474432504, 'colsample_bytree': 0.9316687547614655, 'reg_alpha': 0.02494739267944637, 'reg_lambda': 0.5304771054562575}. Best is trial 16 with value: 1.345375001139902.
# [I 2026-07-06 21:31:13,246] Trial 23 pruned.
# [I 2026-07-06 21:32:12,988] Trial 24 finished with value: 1.3454780898623182 and parameters: {'n_estimators': 2596, 'learning_rate': 0.002901655072788854, 'max_depth': 3, 'min_child_weight': 0.0835087918517862, 'gamma': 1.4084855015891504, 'subsample': 0.6609736494383504, 'colsample_bytree': 0.9537018404155351, 'reg_alpha': 0.02515130223873041, 'reg_lambda': 2.276948717348185}. Best is trial 16 with value: 1.345375001139902.
# [I 2026-07-06 21:32:49,511] Trial 25 pruned.
# [I 2026-07-06 21:34:04,637] Trial 26 finished with value: 1.328180732403085 and parameters: {'n_estimators': 2658, 'learning_rate': 0.0024642344059875075, 'max_depth': 4, 'min_child_weight': 0.10551592014412141, 'gamma': 5.847990992552352, 'subsample': 0.6223533523574417, 'colsample_bytree': 0.706528585357953, 'reg_alpha': 0.004168734048752712, 'reg_lambda': 2.3678622791821877}. Best is trial 26 with value: 1.328180732403085.
# [I 2026-07-06 21:34:40,088] Trial 27 finished with value: 1.356299715711458 and parameters: {'n_estimators': 1887, 'learning_rate': 0.0027367298730260467, 'max_depth': 2, 'min_child_weight': 0.5093378558495012, 'gamma': 8.79723111039987, 'subsample': 0.5964524417132991, 'colsample_bytree': 0.6697821647511688, 'reg_alpha': 7.38048396574196e-05, 'reg_lambda': 4.832808690610203}. Best is trial 26 with value: 1.328180732403085.

# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-06 21:37:23,815] Trial 20 finished with value: 1.4022253872559682 and parameters: {'n_estimators': 1981, 'learning_rate': 0.014586408444441508, 'num_leaves': 444, 'max_depth': 12, 'min_child_samples': 120, 'min_split_gain': 0.9204928809026841, 'bagging_fraction': 0.6487368878624546, 'bagging_freq': 2, 'feature_fraction': 0.7592273782036654, 'lambda_l1': 1.3663845900300427e-10, 'lambda_l2': 0.09031704393757714, 'huber_alpha': 0.95}. Best is trial 19 with value: 1.3252893141793916.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-06 21:37:26,887] Trial 21 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-06 21:37:30,188] Trial 22 finished with value: 1.317666184721049 and parameters: {'n_estimators': 2055, 'learning_rate': 0.046128456183836604, 'num_leaves': 347, 'max_depth': 13, 'min_child_samples': 28, 'min_split_gain': 0.9671987726705117, 'bagging_fraction': 0.8665927277296104, 'bagging_freq': 1, 'feature_fraction': 0.5397623740000719, 'lambda_l1': 0.004320469653742817, 'lambda_l2': 0.0007363742010087261, 'huber_alpha': 0.95}. Best is trial 22 with value: 1.317666184721049.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-06 21:37:34,316] Trial 23 finished with value: 1.3060135613649053 and parameters: {'n_estimators': 2109, 'learning_rate': 0.03641975695899514, 'num_leaves': 344, 'max_depth': 13, 'min_child_samples': 20, 'min_split_gain': 1.0413136756232446, 'bagging_fraction': 0.8554625959530964, 'bagging_freq': 1, 'feature_fraction': 0.5532123411314687, 'lambda_l1': 0.9100777646757591, 'lambda_l2': 0.004804534972712218, 'huber_alpha': 0.95}. Best is trial 23 with value: 1.3060135613649053.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-06 21:37:37,717] Trial 24 finished with value: 1.301362230842132 and parameters: {'n_estimators': 2122, 'learning_rate': 0.035298375224709876, 'num_leaves': 332, 'max_depth': 13, 'min_child_samples': 22, 'min_split_gain': 1.0564290108936518, 'bagging_fraction': 0.7060172746323962, 'bagging_freq': 1, 'feature_fraction': 0.566085210464914, 'lambda_l1': 0.6872285219878831, 'lambda_l2': 0.010989627803841825, 'huber_alpha': 0.95}. Best is trial 24 with value: 1.301362230842132.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-06 21:37:40,656] Trial 25 finished with value: 1.3076795154580445 and parameters: {'n_estimators': 2115, 'learning_rate': 0.040386949937597345, 'num_leaves': 323, 'max_depth': 13, 'min_child_samples': 17, 'min_split_gain': 1.1858118769931503, 'bagging_fraction': 0.8831209216847683, 'bagging_freq': 1, 'feature_fraction': 0.5549536570514435, 'lambda_l1': 0.9436359031041671, 'lambda_l2': 0.000736671572835336, 'huber_alpha': 0.9}. Best is trial 24 with value: 1.301362230842132.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-06 21:37:45,059] Trial 26 finished with value: 1.3027639960231003 and parameters: {'n_estimators': 1890, 'learning_rate': 0.023194020936828097, 'num_leaves': 318, 'max_depth': 13, 'min_child_samples': 17, 'min_split_gain': 1.1747020065433345, 'bagging_fraction': 0.8048672080725924, 'bagging_freq': 1, 'feature_fraction': 0.5711759683606732, 'lambda_l1': 0.6434328109592911, 'lambda_l2': 0.015346895320103778, 'huber_alpha': 0.9}. Best is trial 24 with value: 1.301362230842132.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-06 21:37:48,175] Trial 27 finished with value: 1.340859518622728 and parameters: {'n_estimators': 1198, 'learning_rate': 0.02289952747874147, 'num_leaves': 297, 'max_depth': 10, 'min_child_samples': 70, 'min_split_gain': 1.482850855832702, 'bagging_fraction': 0.7948599363955349, 'bagging_freq': 3, 'feature_fraction': 0.44853757974477554, 'lambda_l1': 0.28474693879796115, 'lambda_l2': 0.11157399633220123, 'huber_alpha': 0.9}. Best is trial 24 with value: 1.301362230842132.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-06 21:38:05,025] Trial 28 finished with value: 1.3016114339193798 and parameters: {'n_estimators': 2727, 'learning_rate': 0.011912353672289181, 'num_leaves': 225, 'max_depth': 13, 'min_child_samples': 11, 'min_split_gain': 0.6568537967527185, 'bagging_fraction': 0.7183841468785245, 'bagging_freq': 1, 'feature_fraction': 0.5847034040422516, 'lambda_l1': 0.04917354903717822, 'lambda_l2': 4.804963557542592, 'huber_alpha': 0.9}. Best is trial 24 with value: 1.301362230842132.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-06 21:38:16,864] Trial 29 finished with value: 1.3562015814277073 and parameters: {'n_estimators': 2817, 'learning_rate': 0.013014308846476938, 'num_leaves': 214, 'max_depth': 12, 'min_child_samples': 70, 'min_split_gain': 0.5998109623032735, 'bagging_fraction': 0.6833886057662658, 'bagging_freq': 2, 'feature_fraction': 0.5914655594734786, 'lambda_l1': 0.00041141313607313644, 'lambda_l2': 7.274901206163191, 'huber_alpha': 0.9}. Best is trial 24 with value: 1.301362230842132.
# [I 2026-07-06 21:38:16,966] A new study created in RDB with name: KATL_v11_remaining_warmup_base_catboost_mae_f
# [I 2026-07-06 21:50:32,627] Trial 0 finished with value: 1.6388713996985214 and parameters: {'iterations': 2931, 'learning_rate': 0.001783588943232587, 'depth': 10, 'l2_leaf_reg': 0.9942958882300413, 'random_strength': 7.186216756161439, 'bagging_temperature': 12.184767612363034, 'border_count': 110, 'rsm': 0.6158971964095841, 'huber_delta': 1.5}. Best is trial 0 with value: 1.6388713996985214.
# [I 2026-07-06 22:03:48,207] Trial 1 finished with value: 1.867064674588661 and parameters: {'iterations': 801, 'learning_rate': 0.19767902101650964, 'depth': 12, 'l2_leaf_reg': 75.05056513807031, 'random_strength': 12.92821124806787, 'bagging_temperature': 4.276496242612171, 'border_count': 168, 'rsm': 0.4404450637901872, 'huber_delta': 1.0}. Best is trial 0 with value: 1.6388713996985214.
# [I 2026-07-06 22:04:07,692] Trial 2 finished with value: 1.654074456068393 and parameters: {'iterations': 1992, 'learning_rate': 0.0024079350849750287, 'depth': 3, 'l2_leaf_reg': 0.118485976001343, 'random_strength': 4.058751860003342, 'bagging_temperature': 9.103785934457758, 'border_count': 206, 'rsm': 0.994034742637508, 'huber_delta': 0.5}. Best is trial 0 with value: 1.6388713996985214.
# [I 2026-07-06 22:16:17,079] Trial 3 finished with value: 1.7846652080867305 and parameters: {'iterations': 3095, 'learning_rate': 0.05508623515899769, 'depth': 11, 'l2_leaf_reg': 18.082710740309665, 'random_strength': 13.948598364083836, 'bagging_temperature': 18.60205606816345, 'border_count': 227, 'rsm': 0.4117317891426977, 'huber_delta': 3.0}. Best is trial 0 with value: 1.6388713996985214.
# [I 2026-07-06 22:16:49,320] Trial 4 finished with value: 1.5040842480137333 and parameters: {'iterations': 3146, 'learning_rate': 0.0024764229908984673, 'depth': 3, 'l2_leaf_reg': 0.6951779671472356, 'random_strength': 6.148451176512449, 'bagging_temperature': 8.441103735088014, 'border_count': 95, 'rsm': 0.7192489923988105, 'huber_delta': 2.0}. Best is trial 4 with value: 1.5040842480137333.
# [I 2026-07-06 22:16:52,585] Trial 5 finished with value: 1.7066264334789585 and parameters: {'iterations': 2996, 'learning_rate': 0.04169299311145666, 'depth': 2, 'l2_leaf_reg': 0.6483636109972302, 'random_strength': 11.284989840243444, 'bagging_temperature': 11.881552589055849, 'border_count': 179, 'rsm': 0.7610806862514128, 'huber_delta': 0.5}. Best is trial 4 with value: 1.5040842480137333.
# [I 2026-07-06 22:16:53,728] Trial 6 pruned.
# [I 2026-07-06 22:16:57,501] Trial 7 finished with value: 1.4877266682952082 and parameters: {'iterations': 2269, 'learning_rate': 0.05988786419186062, 'depth': 3, 'l2_leaf_reg': 0.8727148674658863, 'random_strength': 13.785080578883292, 'bagging_temperature': 3.643240241026453, 'border_count': 16, 'rsm': 0.5239102067389221, 'huber_delta': 0.5}. Best is trial 7 with value: 1.4877266682952082.
# [I 2026-07-06 22:17:09,529] Trial 8 pruned.
# [I 2026-07-06 22:20:05,725] Trial 9 finished with value: 1.4196090840671423 and parameters: {'iterations': 2176, 'learning_rate': 0.006973123504821021, 'depth': 7, 'l2_leaf_reg': 1.0111907140307084, 'random_strength': 19.613513312465464, 'bagging_temperature': 8.113717548278494, 'border_count': 208, 'rsm': 0.7899333278528806, 'huber_delta': 5.0}. Best is trial 9 with value: 1.4196090840671423.
# [I 2026-07-06 22:20:43,448] Trial 10 pruned.
# [I 2026-07-06 22:21:28,991] Trial 11 finished with value: 1.3462878591793732 and parameters: {'iterations': 2772, 'learning_rate': 0.014522829031783214, 'depth': 5, 'l2_leaf_reg': 15.987388321276002, 'random_strength': 11.591109950971106, 'bagging_temperature': 7.790667047006705, 'border_count': 126, 'rsm': 0.7500006952294106, 'huber_delta': 5.0}. Best is trial 11 with value: 1.3462878591793732.
# [I 2026-07-06 22:22:26,096] Trial 12 pruned.
# [I 2026-07-06 22:22:31,081] Trial 13 pruned.
# [I 2026-07-06 22:22:37,879] Trial 14 finished with value: 1.5073388625199704 and parameters: {'iterations': 2033, 'learning_rate': 0.03406017942217813, 'depth': 3, 'l2_leaf_reg': 2.8273302406131626, 'random_strength': 2.5986858551767766, 'bagging_temperature': 5.630188860588947, 'border_count': 58, 'rsm': 0.9026140460549269, 'huber_delta': 1.0}. Best is trial 11 with value: 1.3462878591793732.
# [I 2026-07-06 22:22:49,879] Trial 15 pruned.
# [I 2026-07-06 22:23:12,773] Trial 16 pruned.
# [I 2026-07-06 22:24:55,906] Trial 17 finished with value: 1.3815820997041957 and parameters: {'iterations': 2536, 'learning_rate': 0.008839187675884689, 'depth': 8, 'l2_leaf_reg': 7.939365760496926, 'random_strength': 16.574794818938415, 'bagging_temperature': 1.3263969896774768, 'border_count': 43, 'rsm': 0.8989809553994637, 'huber_delta': 5.0}. Best is trial 11 with value: 1.3462878591793732.
# [I 2026-07-06 22
# [I 2026-07-06 22:31:34,354] Trial 23 finished with value: 1.336909302131654 and parameters: {'feature_set': 'models_only', 'alpha': 1.4381014631031364, 'fit_intercept': True}. Best is trial 22 with value: 1.3367463207978882.
# [I 2026-07-06 22:31:34,561] Trial 24 finished with value: 1.3363217663370066 and parameters: {'feature_set': 'models_only', 'alpha': 4.98213392656453, 'fit_intercept': True}. Best is trial 24 with value: 1.3363217663370066.
# [I 2026-07-06 22:31:34,763] Trial 25 finished with value: 2.297842742231876 and parameters: {'feature_set': 'models_only', 'alpha': 35855.55721556136, 'fit_intercept': True}. Best is trial 24 with value: 1.3363217663370066.
# [I 2026-07-06 22:31:34,965] Trial 26 finished with value: 1.3361201445659554 and parameters: {'feature_set': 'models_only', 'alpha': 6.373305022170856, 'fit_intercept': True}. Best is trial 26 with value: 1.3361201445659554.
# [I 2026-07-06 22:31:35,175] Trial 27 finished with value: 1.3362517906200926 and parameters: {'feature_set': 'models_only', 'alpha': 5.434279327249428, 'fit_intercept': True}. Best is trial 26 with value: 1.3361201445659554.
# ...
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
#                   period           method  count     mae_f    rmse_f
# 0   validation_2024_2025          xgboost    731  1.307541  1.820646
# 1   validation_2024_2025         lightgbm    731  1.300695  1.792130
# 2   validation_2024_2025         catboost    731  1.321238  1.804971
# 3   validation_2024_2025    provider_mean    731  2.127199  3.107267
# 4   validation_2024_2025  provider_median    731  2.044175  3.004660
# 5   validation_2024_2025          nbm_raw    731  2.006541  2.889070
# 6   validation_2024_2025         hrrr_raw    731  2.817351  4.029933
# 7   validation_2024_2025          gfs_raw    731  2.883423  3.907159
# 8              test_2026          xgboost    172  1.276827  1.783732
# 9              test_2026         lightgbm    172  1.297384  1.838263
# 10             test_2026         catboost    172  1.340354  1.803328
# 11             test_2026      ridge_stack    172  1.300745  1.788543
# 12             test_2026    provider_mean    172  2.139412  3.328671
# 13             test_2026  provider_median    172  2.119176  3.267309
# 14             test_2026          nbm_raw    172  2.082419  3.220885
# 15             test_2026         hrrr_raw    172  2.529610  3.819664
# 16             test_2026          gfs_raw    172  2.842734  3.969046

# %%
exported_weights = export_station_model_weights(
    project_root=PROJECT_ROOT,
    station_id=STATION_ID,
    artifact_dir=config.resolved_output_dir(),
    model_version=MODEL_VERSION,
    timing_mode=config.timing_mode,
    providers=tuple(config.providers),
    feature_version=config.effective_feature_version,
    optuna_metric=config.effective_optuna_metric,
    target_mode=config.effective_target_mode,
    target_source=config.effective_target_source,
    base_model_methods=tuple(config.effective_base_model_methods),
    stack_enabled=config.stack_enabled,
    source_pipeline="notebooks/station_stacking_v11_settlement",
)

exported_weights.bundle_path, exported_weights.manifest_path
# Out:
# (WindowsPath('D:/dev/weather-research/data/calibration/station_stacking_v11_settlement/model_weights/KATL_station_high_regressor_v11_wunderground_settlement_stack.joblib'),
#  WindowsPath('D:/dev/weather-research/data/calibration/station_stacking_v11_settlement/model_weights/KATL_station_high_regressor_v11_wunderground_settlement_stack.json'))

# %% [markdown]
# ## V11 Feature Coverage

# %%
v11_feature_coverage = (
    result.features[V11_FEATURE_COLUMNS]
    .notna()
    .mean()
    .mul(100)
    .sort_values(ascending=False)
    .rename("coverage_pct")
    .reset_index()
    .rename(columns={"index": "feature"})
)

v11_feature_coverage
# Out:
#                                               feature  coverage_pct
# 0                              v2_spread_per_warmup_f    100.000000
# 1                    v2_morning_warmup_to_consensus_f    100.000000
# 2              v3_remaining_warmup_from_high_so_far_f    100.000000
# 3                      v3_high_so_far_above_current_f    100.000000
# 4                      v2_humidity_warmup_interaction    100.000000
# 5                    v4_observed_precip_recent_mm_est    100.000000
# 6                        v4_forecast_wet_observed_dry    100.000000
# 7                   v4_forecast_observed_precip_match    100.000000
# 8            v3_humidity_remaining_warmup_interaction    100.000000
# 9                    v3_remaining_warmup_per_spread_f    100.000000
# 10                             v4_all_forecast_precip    100.000000
# 11                             v4_observed_precip_any    100.000000
# 12                             v4_any_forecast_precip    100.000000
# 13                    v8_month_remaining_warmup_count    100.000000
# 14                             climatology_high_10y_f    100.000000
# 15                         climatology_high_10y_std_f    100.000000
# 16       observed_high_so_far_minus_climatology_10y_f    100.000000
# 17              observed_temp_minus_climatology_10y_f    100.000000
# 18                         climatology_high_10y_count    100.000000
# 19              provider_mean_minus_climatology_10y_f    100.000000
# 20          v8_provider_spread_per_remaining_warmup_f    100.000000
# 21                       v4_observed_wet_forecast_dry    100.000000
# 22       v8_provider_min_remaining_from_high_so_far_f    100.000000
# 23    v8_provider_median_remaining_from_high_so_far_f    100.000000
# 24       v8_provider_max_remaining_from_high_so_far_f    100.000000
# 25                   v3_high_so_far_minus_7d_actual_f     99.949950
# 26                          v2_recent_heat_momentum_f     99.949950
# 27                     v2_consensus_minus_7d_actual_f     99.949950
# 28                      v3_high_so_far_minus_lag_1d_f     99.949950
# 29                           v2_recent_heat_anomaly_f     99.949950
# 30               v8_recent_remaining_warmup_7d_mean_f     99.899900
# 31            observed_morning_warmup_rate_f_per_hour     99.899900
# 32                     observed_temp_change_last_3h_f     99.899900
# 33                     observed_temp_change_last_1h_f     99.899900
# 34            observed_high_so_far_change_since_9am_f     99.899900
# 35              v8_recent_remaining_warmup_30d_mean_f     99.749750
# 36       v8_provider_mean_remaining_vs_month_normal_f     98.798799
# 37                   v8_month_remaining_warmup_mean_f     98.798799
# 38      v8_dewpoint_mean_remaining_warmup_interaction     78.828829
# 39  v8_dewpoint_depression_remaining_warmup_intera...     78.828829
# 40                        v8_forecast_dewpoint_mean_f     78.828829
# 41             v8_forecast_dewpoint_depression_mean_f     78.828829
# 42         v4_forecast_total_minus_observed_recent_mm     78.478478
# 43                   v4_forecast_precip_intensity_max     78.478478
# 44                   v4_forecast_precip_total_mean_mm     78.478478
# 45                    v4_forecast_precip_total_max_mm     78.478478
# 46                 v4_forecast_precip_total_spread_mm     78.478478
# 47                  v4_forecast_precip_max_1h_mean_mm     78.478478
# 48                      v4_forecast_precip_hours_mean     78.478478
# 49                  v4_forecast_precip_intensity_mean     78.478478
# 50             v4_precip_remaining_warmup_interaction     78.478478
# 51                     v4_precip_humidity_interaction     78.478478
# 52       v8_precip_total_remaining_warmup_interaction     78.478478
# 53      v8_precip_max_1h_remaining_warmup_interaction     78.478478
# 54    v8_wind_speed_mean_remaining_warmup_interaction     30.980981
# 55      v8_wind_gust_max_remaining_warmup_interaction     30.980981
# 56    v8_cloud_cover_max_remaining_warmup_interaction      0.000000
# 57   v8_cloud_cover_mean_remaining_warmup_interaction      0.000000

# %%
result.feature_columns.loc[result.feature_columns["feature"].isin(V11_FEATURE_COLUMNS)]
# Out:
#                                                feature     kind
# 20                      observed_temp_change_last_1h_f  numeric
# 21                      observed_temp_change_last_3h_f  numeric
# 22             observed_morning_warmup_rate_f_per_hour  numeric
# 23             observed_high_so_far_change_since_9am_f  numeric
# 221                           v2_recent_heat_anomaly_f  numeric
# 222                          v2_recent_heat_momentum_f  numeric
# 223                   v2_morning_warmup_to_consensus_f  numeric
# 224                     v2_consensus_minus_7d_actual_f  numeric
# 225                             v2_spread_per_warmup_f  numeric
# 226                     v2_humidity_warmup_interaction  numeric
# 227                     v3_high_so_far_above_current_f  numeric
# 228             v3_remaining_warmup_from_high_so_far_f  numeric
# 229                      v3_high_so_far_minus_lag_1d_f  numeric
# 230                   v3_high_so_far_minus_7d_actual_f  numeric
# 231                   v3_remaining_warmup_per_spread_f  numeric
# 232           v3_humidity_remaining_warmup_interaction  numeric
# 233                   v4_forecast_precip_total_mean_mm  numeric
# 234                    v4_forecast_precip_total_max_mm  numeric
# 235                 v4_forecast_precip_total_spread_mm  numeric
# 236                  v4_forecast_precip_max_1h_mean_mm  numeric
# 237                      v4_forecast_precip_hours_mean  numeric
# 238                  v4_forecast_precip_intensity_mean  numeric
# 239                   v4_forecast_precip_intensity_max  numeric
# 240                             v4_any_forecast_precip  numeric
# 241                             v4_all_forecast_precip  numeric
# 242                             v4_observed_precip_any  numeric
# 243                   v4_observed_precip_recent_mm_est  numeric
# 244         v4_forecast_total_minus_observed_recent_mm  numeric
# 245                  v4_forecast_observed_precip_match  numeric
# 246                       v4_forecast_wet_observed_dry  numeric
# 247                       v4_observed_wet_forecast_dry  numeric
# 248                     v4_precip_humidity_interaction  numeric
# 249             v4_precip_remaining_warmup_interaction  numeric
# 250       v8_provider_max_remaining_from_high_so_far_f  numeric
# 251       v8_provider_min_remaining_from_high_so_far_f  numeric
# 252    v8_provider_median_remaining_from_high_so_far_f  numeric
# 253          v8_provider_spread_per_remaining_warmup_f  numeric
# 254                   v8_month_remaining_warmup_mean_f  numeric
# 255                    v8_month_remaining_warmup_count  numeric
# 256               v8_recent_remaining_warmup_7d_mean_f  numeric
# 257              v8_recent_remaining_warmup_30d_mean_f  numeric
# 258       v8_provider_mean_remaining_vs_month_normal_f  numeric
# 259       v8_precip_total_remaining_warmup_interaction  numeric
# 260      v8_precip_max_1h_remaining_warmup_interaction  numeric
# 261    v8_wind_speed_mean_remaining_warmup_interaction  numeric
# 262      v8_wind_gust_max_remaining_warmup_interaction  numeric
# 263                        v8_forecast_dewpoint_mean_f  numeric
# 264             v8_forecast_dewpoint_depression_mean_f  numeric
# 265      v8_dewpoint_mean_remaining_warmup_interaction  numeric
# 266  v8_dewpoint_depression_remaining_warmup_intera...  numeric
# 267                             climatology_high_10y_f  numeric
# 268                         climatology_high_10y_std_f  numeric
# 269                         climatology_high_10y_count  numeric
# 270              provider_mean_minus_climatology_10y_f  numeric
# 271              observed_temp_minus_climatology_10y_f  numeric
# 272       observed_high_so_far_minus_climatology_10y_f  numeric

# %% [markdown]
# ## Dropped Feature Check

# %%
dropped_present = result.feature_columns.loc[
    result.feature_columns["feature"].isin(V11_DROPPED_FEATURE_COLUMNS)
]

dropped_present
# Out:
# Empty DataFrame
# Columns: [feature, kind]
# Index: []

# %% [markdown]
# ## Morning Trend Coverage

# %%
trend_coverage = (
    result.features[TREND_COLUMNS]
    .notna()
    .mean()
    .mul(100)
    .sort_values(ascending=False)
    .rename("coverage_pct")
    .reset_index()
    .rename(columns={"index": "feature"})
)

trend_coverage
# Out:
#                                    feature  coverage_pct
# 0           observed_temp_change_last_1h_f       99.8999
# 1           observed_temp_change_last_3h_f       99.8999
# 2  observed_morning_warmup_rate_f_per_hour       99.8999
# 3  observed_high_so_far_change_since_9am_f       99.8999

# %% [markdown]
# ## Rounded Within 1F Accuracy

# %%
preds = pd.concat(
    [
        result.validation_predictions.assign(period="validation_2024_2025"),
        result.test_predictions.assign(period="oof_2026"),
    ],
    ignore_index=True,
)

predicted_high = pd.to_numeric(preds["predicted_high_f"], errors="coerce")
preds["predicted_high_rounded_f"] = np.floor(predicted_high + 0.5)
preds["within_1f_after_round"] = (
    pd.to_numeric(preds["actual_high_f"], errors="coerce") - preds["predicted_high_rounded_f"]
).abs().le(1)

within_1f_accuracy_by_period = (
    preds
    .dropna(subset=["actual_high_f", "predicted_high_rounded_f"])
    .groupby(["period", "method"], as_index=False)
    .agg(
        count=("within_1f_after_round", "size"),
        within_1f_count=("within_1f_after_round", "sum"),
        within_1f_accuracy_pct=("within_1f_after_round", lambda x: x.mean() * 100),
    )
    .sort_values(["period", "within_1f_accuracy_pct"], ascending=[True, False])
)

within_1f_accuracy_by_period
# Out:
#                   period           method  count  within_1f_count  \
# 8               oof_2026          xgboost    172              122
# 3               oof_2026         lightgbm    172              116
# 7               oof_2026      ridge_stack    172              115
# 0               oof_2026         catboost    172              114
# 4               oof_2026          nbm_raw    172               92
# 6               oof_2026  provider_median    172               85
# 5               oof_2026    provider_mean    172               79
# 2               oof_2026         hrrr_raw    172               72
# 1               oof_2026          gfs_raw    172               59
# 16  validation_2024_2025          xgboost    731              491
# 9   validation_2024_2025         catboost    731              484
# 12  validation_2024_2025         lightgbm    731              482
# 13  validation_2024_2025          nbm_raw    731              358
# 15  validation_2024_2025  provider_median    731              353
# 14  validation_2024_2025    provider_mean    731              344
# 11  validation_2024_2025         hrrr_raw    731              278
# 10  validation_2024_2025          gfs_raw    731              233
#
#     within_1f_accuracy_pct
# 8                70.930233
# 3                67.441860
# 7                66.860465
# 0                66.279070
# 4                53.488372
# 6                49.418605
# 5                45.930233
# 2                41.860465
# 1                34.302326
# 16               67.168263
# 9                66.210670
# 12               65.937073
# 13               48.974008
# 15               48.290014
# 14               47.058824
# 11               38.030096
# 10               31.874145

# %% [markdown]
# ## Version Comparison

# %%
comparison_frames = []
for version, folder in [
    ("v1", PROJECT_ROOT / "data" / "calibration" / "station_stacking"),
    ("v2", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v2"),
    ("v3", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v3"),
    ("v4", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v4"),
    ("v5", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v5"),
    ("v6", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v6"),
    ("v7", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v7"),
    ("v8", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v8"),
    ("v9", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v9"),
    ("v10", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v10"),
    ("v11", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v11"),
]:
    path = folder / f"{STATION_ID}_year_split_scoreboard.csv"
    if path.exists():
        frame = pd.read_csv(path)
        frame["version"] = version
        comparison_frames.append(frame)

version_comparison = pd.concat(comparison_frames, ignore_index=True) if comparison_frames else pd.DataFrame()
if not version_comparison.empty:
    version_comparison = version_comparison.sort_values(["period", "mae_f", "version", "method"]).reset_index(drop=True)
version_comparison
# Out:
#                    period       method  count     mae_f    rmse_f version
# 0               test_2026     lightgbm    137  1.529121  2.224566     v11
# 1               test_2026  ridge_stack    137  1.531900  2.209782     v11
# 2               test_2026     lightgbm    125  1.547989  2.093915      v5
# 3               test_2026  ridge_stack    125  1.566708  2.118374      v5
# 4               test_2026      xgboost    125  1.569277  2.117086      v5
# ..                    ...          ...    ...       ...       ...     ...
# 111  validation_2024_2025      gfs_raw    541  3.557627  5.060559      v1
# 112  validation_2024_2025     hrrr_raw    664  3.630969  5.083107      v2
# 113  validation_2024_2025     hrrr_raw    664  3.630969  5.083107      v3
# 114  validation_2024_2025     hrrr_raw    664  3.630969  5.083107      v4
# 115  validation_2024_2025     hrrr_raw    541  4.010898  5.487445      v1
#
# [116 rows x 6 columns]

# %% [markdown]
# ## 2026 OOF Weather Brackets

# %%
result.bracket_metrics
# Out:
#             method  count     mae_f    rmse_f  bracket_accuracy_pct
# 0          xgboost    172  1.276827  1.783732             44.767442
# 1         lightgbm    172  1.297384  1.838263             45.930233
# 2         catboost    172  1.340354  1.803328             44.767442
# 3      ridge_stack    172  1.300745  1.788543             49.418605
# 4    provider_mean    172  2.139412  3.328671             34.883721
# 5  provider_median    172  2.119176  3.267309             34.302326
# 6          nbm_raw    172  2.082419  3.220885             35.465116
# 7         hrrr_raw    172  2.529610  3.819664             30.232558
# 8          gfs_raw    172  2.842734  3.969046             21.511628

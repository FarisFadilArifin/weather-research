# %% [markdown]
# # KDAL Station Stacking V20 Peak Timing
#
# Single-arm Wunderground-only experiment using V11 Settlement Fix temperature alignment, curated live-safe HRRR/NBM peak-timing features, a 3% train-fold missingness gate, and expanding 2021–2025 validation folds. The readiness section can run while shards are still being pulled and blocks model tuning until coverage is sufficient.

# %%
from pathlib import Path
import os
import sys
import warnings

warnings.filterwarnings("ignore", message="IProgress not found.*")
warnings.filterwarnings("ignore", message="Skipping features without any observed values.*")

PROJECT_ROOT = Path.cwd().resolve()
while not (PROJECT_ROOT / "src" / "calibration" / "station_stacking.py").exists():
    if PROJECT_ROOT.parent == PROJECT_ROOT:
        raise RuntimeError("Could not find project root containing src/calibration/station_stacking.py")
    PROJECT_ROOT = PROJECT_ROOT.parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

os.environ["WEATHER_RESEARCH_INCLUDE_DIRECT_NBM"] = "1"

STATION_ID = "KDAL"
PROVIDERS = ("gfs", "hrrr", "nbm")
TREND_COLUMNS = [
    "observed_temp_change_last_1h_f",
    "observed_temp_change_last_3h_f",
    "observed_morning_warmup_rate_f_per_hour",
    "observed_high_so_far_change_since_9am_f",
]
TIMING_MODE = "same_day_11am_live_safe"
FAST_MODE = False
OPTUNA_TRIALS = 30
STACK_OPTUNA_TRIALS = 30
OPTUNA_STARTUP_TRIALS = 15
STACK_OPTUNA_STARTUP_TRIALS = 15
OPTUNA_METRIC = "mae_f"
OPTUNA_VERBOSE = True
MODEL_VERSION = "station_high_regressor_v20_peak_timing_stack"
EXPORT_MODEL_WEIGHTS = False
PROJECT_ROOT
# Out:
# WindowsPath('D:/dev/weather-research')

# %%
import numpy as np
import pandas as pd

from src.export_station_stacking_v2_models import export_station_model_weights
from src.calibration.station_stacking import (
    StationStackingConfig,
    V20_ENGINEERED_FEATURE_COLUMNS,
    V20_PEAK_TIMING_RAW_FEATURE_COLUMNS,
    build_station_wide_dataset,
    v20_peak_timing_readiness,
    V11_SETTLEMENT_FIX_TEMP_FEATURE_COLUMNS,
    _fit_feature_columns,
    _modeling_frame,
    V11_DROPPED_FEATURE_COLUMNS,
    V11_FEATURE_COLUMNS,
    V20_EXPANDING_FOLDS,
    missing_model_dependencies,
    provider_availability,
    run_station_year_split_experiment,
)

# %% [markdown]
# ## V11 Contract
#
# `feature_version="v20_peak_timing"` keeps the v9 feature contract and remaining-warmup target, but trains base learners with Huber-style objectives while retaining the ridge stack selected by validation MAE.

# %%
fold_spec = pd.DataFrame(
    [
        {
            "fold": fold.name,
            "train_start_year": fold.train_start_year,
            "train_end_year": fold.train_end_year,
            "validation_year": fold.validation_year,
        }
        for fold in V20_EXPANDING_FOLDS
    ]
)

fold_spec
# Out:
#                      fold  train_start_year  train_end_year  validation_year
# 0       fold_2021_to_2022              2021            2021             2022
# 1  fold_2021_2022_to_2023              2021            2022             2023
# 2  fold_2021_2023_to_2024              2021            2023             2024
# 3  fold_2021_2024_to_2025              2021            2024             2025

# %%
V11_FEATURE_COLUMNS, sorted(V11_DROPPED_FEATURE_COLUMNS)
# Out:
# (['v2_recent_heat_anomaly_f',
#   'v2_recent_heat_momentum_f',
#   'v2_morning_warmup_to_consensus_f',
#   'v2_consensus_minus_7d_actual_f',
#   'v2_spread_per_warmup_f',
#   'v2_humidity_warmup_interaction',
#   'v3_high_so_far_above_current_f',
#   'v3_remaining_warmup_from_high_so_far_f',
#   'v3_high_so_far_minus_lag_1d_f',
#   'v3_high_so_far_minus_7d_actual_f',
#   'v3_remaining_warmup_per_spread_f',
#   'v3_humidity_remaining_warmup_interaction',
#   'v4_forecast_precip_total_mean_mm',
#   'v4_forecast_precip_total_max_mm',
#   'v4_forecast_precip_total_spread_mm',
#   'v4_forecast_precip_max_1h_mean_mm',
#   'v4_forecast_precip_hours_mean',
#   'v4_forecast_precip_intensity_mean',
#   'v4_forecast_precip_intensity_max',
#   'v4_any_forecast_precip',
#   'v4_all_forecast_precip',
#   'v4_observed_precip_any',
#   'v4_observed_precip_recent_mm_est',
#   'v4_forecast_total_minus_observed_recent_mm',
#   'v4_forecast_observed_precip_match',
#   'v4_forecast_wet_observed_dry',
#   'v4_observed_wet_forecast_dry',
#   'v4_precip_humidity_interaction',
#   'v4_precip_remaining_warmup_interaction',
#   'observed_temp_change_last_1h_f',
#   'observed_temp_change_last_3h_f',
#   'observed_morning_warmup_rate_f_per_hour',
#   'observed_high_so_far_change_since_9am_f',
#   'v8_provider_max_remaining_from_high_so_far_f',
#   'v8_provider_min_remaining_from_high_so_far_f',
#   'v8_provider_median_remaining_from_high_so_far_f',
#   'v8_provider_spread_per_remaining_warmup_f',
#   'v8_month_remaining_warmup_mean_f',
#   'v8_month_remaining_warmup_count',
#   'v8_recent_remaining_warmup_7d_mean_f',
#   'v8_recent_remaining_warmup_30d_mean_f',
#   'v8_provider_mean_remaining_vs_month_normal_f',
#   'v8_cloud_cover_mean_remaining_warmup_interaction',
#   'v8_cloud_cover_max_remaining_warmup_interaction',
#   'v8_precip_total_remaining_warmup_interaction',
#   'v8_precip_max_1h_remaining_warmup_interaction',
#   'v8_wind_speed_mean_remaining_warmup_interaction',
#   'v8_wind_gust_max_remaining_warmup_interaction',
#   'v8_forecast_dewpoint_mean_f',
#   'v8_forecast_dewpoint_depression_mean_f',
#   'v8_dewpoint_mean_remaining_warmup_interaction',
#   'v8_dewpoint_depression_remaining_warmup_interaction',
#   'climatology_high_10y_f',
#   'climatology_high_10y_std_f',
#   'climatology_high_10y_count',
#   'provider_mean_minus_climatology_10y_f',
#   'observed_temp_minus_climatology_10y_f',
#   'observed_high_so_far_minus_climatology_10y_f'],
#  ['actual_minus_climatology_10y_f_DIAGNOSTIC_ONLY',
#   'climatology_source_end_year',
#   'climatology_source_start_year',
#   'gfs_as_of_hour_local',
#   'gfs_available',
#   'gfs_forecast_window_hours',
#   'gfs_grid_dist_km_mean',
#   'gfs_horizon_hours',
#   'gfs_hrrr_grid_dist_km_mean_abs_diff_f',
#   'gfs_hrrr_grid_dist_km_mean_diff_f',
#   'gfs_issue_hour_utc',
#   'gfs_missing',
#   'hrrr_as_of_hour_local',
#   'hrrr_available',
#   'hrrr_forecast_hour_max',
#   'hrrr_forecast_hour_min',
#   'hrrr_forecast_lead_hours',
#   'hrrr_forecast_window_hours',
#   'hrrr_grid_dist_km_mean',
#   'hrrr_horizon_hours',
#   'hrrr_issue_hour_local',
#   'hrrr_issue_hour_utc',
#   'hrrr_missing',
#   'is_active_polymarket_station',
#   'lat',
#   'lon',
#   'nbm_as_of_hour_local',
#   'nbm_available',
#   'nbm_forecast_window_hours',
#   'nbm_horizon_hours',
#   'nbm_issue_hour_local',
#   'nbm_issue_hour_utc',
#   'nbm_missing',
#   'observed_fetch_status',
#   'observed_observation_type',
#   'observed_pressure_source',
#   'provider_count_available',
#   'year'])

# %% [markdown]
# ## Data Availability

# %%
availability = provider_availability(
    PROJECT_ROOT,
    timing_mode=TIMING_MODE,
    providers=PROVIDERS,
)

availability.loc[availability["station_id"].eq(STATION_ID)]
# Out:
#   station_id provider  row_count first_contract_date last_contract_date
# 6       KDAL      gfs       1993          2021-01-01         2026-07-12
# 7       KDAL     hrrr       1999          2021-01-01         2026-07-12
# 8       KDAL      nbm       1998          2021-01-01         2026-07-12

# %% [markdown]
# ## Model Scores

# %% [markdown]
# ## Peak-Timing and Wunderground Readiness Gate

# %%
readiness_features = build_station_wide_dataset(
    PROJECT_ROOT,
    station_id=STATION_ID,
    timing_mode=TIMING_MODE,
    providers=PROVIDERS,
    feature_version="v20_peak_timing",
    target_source="wunderground_only",
)
EVALUATION_END_DATE = "2026-07-01"  # provisional; official V20 cutoff remains 2026-07-14
v20_ready, readiness_summary, readiness_missing_dates, readiness_fold_missingness = v20_peak_timing_readiness(
    readiness_features,
    station_id=STATION_ID,
    folds=V20_EXPANDING_FOLDS,
    max_missing_fraction=0.03,
    end_date=EVALUATION_END_DATE,
)
readiness_dir = PROJECT_ROOT / "data" / "calibration" / "station_stacking_v20_peak_timing"
readiness_dir.mkdir(parents=True, exist_ok=True)
readiness_summary.to_csv(readiness_dir / f"{STATION_ID}_readiness_summary.csv", index=False)
readiness_missing_dates.to_csv(readiness_dir / f"{STATION_ID}_readiness_missing_dates.csv", index=False)
readiness_fold_missingness.to_csv(readiness_dir / f"{STATION_ID}_readiness_fold_feature_missingness.csv", index=False)
display(readiness_summary)
display(readiness_fold_missingness.groupby(["fold", "retained"], as_index=False).agg(feature_count=("feature", "nunique")))
if not v20_ready:
    raise RuntimeError(
        "V20 readiness failed. Audit artifacts were written; rerun this notebook after peak-timing and "
        "Wunderground pulls reduce each station-year missing fraction to 3% or less."
    )
# Out:
# D:\dev\weather-research\src\calibration\station_stacking.py:3399: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[f"{prefix}_{feature_name}_abs_diff_f"] = (left_values - right_values).abs()
# D:\dev\weather-research\src\calibration\station_stacking.py:3398: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[f"{prefix}_{feature_name}_diff_f"] = left_values - right_values
# D:\dev\weather-research\src\calibration\station_stacking.py:3399: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[f"{prefix}_{feature_name}_abs_diff_f"] = (left_values - right_values).abs()
# D:\dev\weather-research\src\calibration\station_stacking.py:3398: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[f"{prefix}_{feature_name}_diff_f"] = left_values - right_values
# D:\dev\weather-research\src\calibration\station_stacking.py:3399: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[f"{prefix}_{feature_name}_abs_diff_f"] = (left_values - right_values).abs()
# D:\dev\weather-research\src\calibration\station_stacking.py:3398: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[f"{prefix}_{feature_name}_diff_f"] = left_values - right_values
# D:\dev\weather-research\src\calibration\station_stacking.py:3399: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[f"{prefix}_{feature_name}_abs_diff_f"] = (left_values - right_values).abs()
# D:\dev\weather-research\src\calibration\station_stacking.py:3398: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[f"{prefix}_{feature_name}_diff_f"] = left_values - right_values
# D:\dev\weather-research\src\calibration\station_stacking.py:3399: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[f"{prefix}_{feature_name}_abs_diff_f"] = (left_values - right_values).abs()
# D:\dev\weather-research\src\calibration\station_stacking.py:3398: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[f"{prefix}_{feature_name}_diff_f"] = left_values - right_values
# D:\dev\weather-research\src\calibration\station_stacking.py:3399: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[f"{prefix}_{feature_name}_abs_diff_f"] = (left_values - right_values).abs()
# D:\dev\weather-research\src\calibration\station_stacking.py:3398: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[f"{prefix}_{feature_name}_diff_f"] = left_values - right_values
# D:\dev\weather-research\src\calibration\station_stacking.py:3399: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[f"{prefix}_{feature_name}_abs_diff_f"] = (left_values - right_values).abs()
# D:\dev\weather-research\src\calibration\station_stacking.py:3398: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[f"{prefix}_{feature_name}_diff_f"] = left_values - right_values
# D:\dev\weather-research\src\calibration\station_stacking.py:3399: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[f"{prefix}_{feature_name}_abs_diff_f"] = (left_values - right_values).abs()
# D:\dev\weather-research\src\calibration\station_stacking.py:3398: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[f"{prefix}_{feature_name}_diff_f"] = left_values - right_values
# D:\dev\weather-research\src\calibration\station_stacking.py:3399: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[f"{prefix}_{feature_name}_abs_diff_f"] = (left_values - right_values).abs()
# D:\dev\weather-research\src\calibration\station_stacking.py:3398: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[f"{prefix}_{feature_name}_diff_f"] = left_values - right_values
# D:\dev\weather-research\src\calibration\station_stacking.py:3399: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[f"{prefix}_{feature_name}_abs_diff_f"] = (left_values - right_values).abs()
# D:\dev\weather-research\src\calibration\station_stacking.py:3398: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[f"{prefix}_{feature_name}_diff_f"] = left_values - right_values
# D:\dev\weather-research\src\calibration\station_stacking.py:3399: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[f"{prefix}_{feature_name}_abs_diff_f"] = (left_values - right_values).abs()
# D:\dev\weather-research\src\calibration\station_stacking.py:3398: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[f"{prefix}_{feature_name}_diff_f"] = left_values - right_values
# D:\dev\weather-research\src\calibration\station_stacking.py:3399: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[f"{prefix}_{feature_name}_abs_diff_f"] = (left_values - right_values).abs()
# D:\dev\weather-research\src\calibration\station_stacking.py:3398: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[f"{prefix}_{feature_name}_diff_f"] = left_values - right_values
# D:\dev\weather-research\src\calibration\station_stacking.py:3399: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[f"{prefix}_{feature_name}_abs_diff_f"] = (left_values - right_values).abs()
#   station_id  year  expected_days  peak_ready_days  wunderground_target_days  \
# 0       KDAL  2021            365              364                       364
# 1       KDAL  2022            365              365                       364
# 2       KDAL  2023            365              365                       364
# 3       KDAL  2024            366              366                       365
# 4       KDAL  2025            365              365                       364
# 5       KDAL  2026            182              182                       181
#
#    peak_missing_fraction  target_missing_fraction  peak_ready  target_ready
# 0                0.00274                 0.002740        True          True
# 1                0.00000                 0.002740        True          True
# 2                0.00000                 0.002740        True          True
# 3                0.00000                 0.002732        True          True
# 4                0.00000                 0.002740        True          True
# 5                0.00000                 0.005495        True          True
#                      fold  retained  feature_count
# 0  fold_2021_2022_to_2023     False              1
# 1  fold_2021_2022_to_2023      True             54
# 2  fold_2021_2023_to_2024     False              1
# 3  fold_2021_2023_to_2024      True             54
# 4  fold_2021_2024_to_2025     False              1
# 5  fold_2021_2024_to_2025      True             54
# 6       fold_2021_to_2022     False              1
# 7       fold_2021_to_2022      True             54
# 8    test_refit_2021_2025     False              1
# 9    test_refit_2021_2025      True             54

# %%
missing_packages = missing_model_dependencies()
if missing_packages:
    raise ImportError(
        "Missing station-stacking ML packages: "
        + ", ".join(missing_packages)
        + ". Install them with: python -m pip install -r requirements.txt"
    )

config = StationStackingConfig(
    station_id=STATION_ID,
    project_root=PROJECT_ROOT,
    timing_mode=TIMING_MODE,
    providers=PROVIDERS,
    fast_mode=FAST_MODE,
    optuna_trials=OPTUNA_TRIALS,
    stack_optuna_trials=STACK_OPTUNA_TRIALS,
    optuna_startup_trials=OPTUNA_STARTUP_TRIALS,
    stack_optuna_startup_trials=STACK_OPTUNA_STARTUP_TRIALS,
    optuna_metric=OPTUNA_METRIC,
    optuna_verbose=OPTUNA_VERBOSE,
    feature_version="v20_peak_timing",
    training_profile="v20_aligned",
    target_mode="remaining_warmup",
    target_source="wunderground_only",
    max_feature_missing_fraction=0.03,
    base_model_methods=("xgboost", "lightgbm", "catboost"),
    stack_enabled=True,
    hyperparameter_space="wide",
    year_split_folds=V20_EXPANDING_FOLDS,
    year_split_validation_weights={2022: 1.0, 2023: 1.0, 2024: 1.0, 2025: 1.0},
    year_split_test_train_years=(2021, 2025),
    year_split_test_year=2026,
    output_dir=PROJECT_ROOT / "data" / "calibration" / "station_stacking_v20_peak_timing",
)

config.resolved_optuna_storage_path()
# Out:
# WindowsPath('D:/dev/weather-research/data/calibration/station_stacking_v20_peak_timing/KDAL_optuna.sqlite3')

# %%
result = run_station_year_split_experiment(config)
result.scoreboard
# Out:
# D:\dev\weather-research\src\calibration\station_stacking.py:3399: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[f"{prefix}_{feature_name}_abs_diff_f"] = (left_values - right_values).abs()
# D:\dev\weather-research\src\calibration\station_stacking.py:3398: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[f"{prefix}_{feature_name}_diff_f"] = left_values - right_values
# D:\dev\weather-research\src\calibration\station_stacking.py:3399: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[f"{prefix}_{feature_name}_abs_diff_f"] = (left_values - right_values).abs()
# D:\dev\weather-research\src\calibration\station_stacking.py:3398: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[f"{prefix}_{feature_name}_diff_f"] = left_values - right_values
# D:\dev\weather-research\src\calibration\station_stacking.py:3399: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[f"{prefix}_{feature_name}_abs_diff_f"] = (left_values - right_values).abs()
# D:\dev\weather-research\src\calibration\station_stacking.py:3398: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[f"{prefix}_{feature_name}_diff_f"] = left_values - right_values
# D:\dev\weather-research\src\calibration\station_stacking.py:3399: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[f"{prefix}_{feature_name}_abs_diff_f"] = (left_values - right_values).abs()
# D:\dev\weather-research\src\calibration\station_stacking.py:3398: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[f"{prefix}_{feature_name}_diff_f"] = left_values - right_values
# D:\dev\weather-research\src\calibration\station_stacking.py:3399: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[f"{prefix}_{feature_name}_abs_diff_f"] = (left_values - right_values).abs()
# D:\dev\weather-research\src\calibration\station_stacking.py:3398: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[f"{prefix}_{feature_name}_diff_f"] = left_values - right_values
# D:\dev\weather-research\src\calibration\station_stacking.py:3399: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[f"{prefix}_{feature_name}_abs_diff_f"] = (left_values - right_values).abs()
# D:\dev\weather-research\src\calibration\station_stacking.py:3398: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[f"{prefix}_{feature_name}_diff_f"] = left_values - right_values
# D:\dev\weather-research\src\calibration\station_stacking.py:3399: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[f"{prefix}_{feature_name}_abs_diff_f"] = (left_values - right_values).abs()
# D:\dev\weather-research\src\calibration\station_stacking.py:3398: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[f"{prefix}_{feature_name}_diff_f"] = left_values - right_values
# D:\dev\weather-research\src\calibration\station_stacking.py:3399: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[f"{prefix}_{feature_name}_abs_diff_f"] = (left_values - right_values).abs()
# D:\dev\weather-research\src\calibration\station_stacking.py:3398: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[f"{prefix}_{feature_name}_diff_f"] = left_values - right_values
# D:\dev\weather-research\src\calibration\station_stacking.py:3399: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[f"{prefix}_{feature_name}_abs_diff_f"] = (left_values - right_values).abs()
# D:\dev\weather-research\src\calibration\station_stacking.py:3398: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[f"{prefix}_{feature_name}_diff_f"] = left_values - right_values
# D:\dev\weather-research\src\calibration\station_stacking.py:3399: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[f"{prefix}_{feature_name}_abs_diff_f"] = (left_values - right_values).abs()
# D:\dev\weather-research\src\calibration\station_stacking.py:3398: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[f"{prefix}_{feature_name}_diff_f"] = left_values - right_values
# D:\dev\weather-research\src\calibration\station_stacking.py:3399: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[f"{prefix}_{feature_name}_abs_diff_f"] = (left_values - right_values).abs()
# D:\dev\weather-research\src\calibration\station_stacking.py:3398: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[f"{prefix}_{feature_name}_diff_f"] = left_values - right_values
# D:\dev\weather-research\src\calibration\station_stacking.py:3399: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[f"{prefix}_{feature_name}_abs_diff_f"] = (left_values - right_values).abs()
# D:\dev\weather-research\src\calibration\station_stacking.py:3398: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[f"{prefix}_{feature_name}_diff_f"] = left_values - right_values
# D:\dev\weather-research\src\calibration\station_stacking.py:3399: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[f"{prefix}_{feature_name}_abs_diff_f"] = (left_values - right_values).abs()
# [I 2026-07-16 06:59:16,640] A new study created in RDB with name: KDAL_v20_peak_timing_remaining_warmup_base_xgboost_mae_f_wide
# [I 2026-07-16 06:59:27,407] Trial 0 finished with value: 1.707950414114737 and parameters: {'n_estimators': 1342, 'learning_rate': 0.19043899115982607, 'max_depth': 9, 'min_child_weight': 2.481040974867813, 'gamma': 2.340279606636548, 'subsample': 0.4513964382185317, 'colsample_bytree': 0.3877543479093296, 'reg_alpha': 2.478071022662141, 'reg_lambda': 0.6132587025321562}. Best is trial 0 with value: 1.707950414114737.
# [I 2026-07-16 07:02:19,941] Trial 1 finished with value: 2.252368217707209 and parameters: {'n_estimators': 2493, 'learning_rate': 0.001120367191095075, 'max_depth': 12, 'min_child_weight': 21.368329072358772, 'gamma': 3.185086660174142, 'subsample': 0.4681862286846154, 'colsample_bytree': 0.46921293140473197, 'reg_alpha': 4.476173538513514e-07, 'reg_lambda': 0.20253776634919213}. Best is trial 0 with value: 1.707950414114737.
# [I 2026-07-16 07:03:47,932] Trial 2 finished with value: 1.4222821186415848 and parameters: {'n_estimators': 1540, 'learning_rate': 0.004992867109217114, 'max_depth': 8, 'min_child_weight': 0.03613894271216528, 'gamma': 4.3821697280282725, 'subsample': 0.5881351981408995, 'colsample_bytree': 0.6464454897410734, 'reg_alpha': 0.26430874752361627, 'reg_lambda': 0.0018119678627933364}. Best is trial 2 with value: 1.4222821186415848.
# [I 2026-07-16 07:04:10,859] Trial 3 finished with value: 1.967901777142356 and parameters: {'n_estimators': 1824, 'learning_rate': 0.026337502897485255, 'max_depth': 1, 'min_child_weight': 2.69264691008618, 'gamma': 2.557861855309373, 'subsample': 0.39228353544043165, 'colsample_bytree': 0.9667755992146666, 'reg_alpha': 38.6887231523051, 'reg_lambda': 12.408975837016275}. Best is trial 2 with value: 1.4222821186415848.
# [I 2026-07-16 07:05:58,765] Trial 4 finished with value: 1.6185892834395894 and parameters: {'n_estimators': 1101, 'learning_rate': 0.0017147936629846843, 'max_depth': 9, 'min_child_weight': 0.5762487216478605, 'gamma': 1.8305735226716824, 'subsample': 0.6718649915723256, 'colsample_bytree': 0.37235253872489193, 'reg_alpha': 8.162906555194692, 'reg_lambda': 0.004271500153828077}. Best is trial 2 with value: 1.4222821186415848.
# [I 2026-07-16 07:06:16,420] Trial 5 pruned.
# [I 2026-07-16 07:06:25,627] Trial 6 finished with value: 1.4309421119715293 and parameters: {'n_estimators': 2113, 'learning_rate': 0.16240489353272883, 'max_depth': 2, 'min_child_weight': 0.06080390190296603, 'gamma': 0.678409333658071, 'subsample': 0.5614647149961218, 'colsample_bytree': 0.6026402382981633, 'reg_alpha': 1.8037999945880162e-07, 'reg_lambda': 16.668629892722056}. Best is trial 2 with value: 1.4222821186415848.
# [I 2026-07-16 07:07:02,352] Trial 7 finished with value: 1.4452171151033717 and parameters: {'n_estimators': 1281, 'learning_rate': 0.0047169807141865345, 'max_depth': 7, 'min_child_weight': 0.0366181922039243, 'gamma': 12.032954711310595, 'subsample': 0.398457918391851, 'colsample_bytree': 0.9914765087903362, 'reg_alpha': 0.18490013641000916, 'reg_lambda': 0.0017869543989965139}. Best is trial 2 with value: 1.4222821186415848.
# [I 2026-07-16 07:07:03,904] Trial 8 pruned.
# [I 2026-07-16 07:07:42,823] Trial 9 finished with value: 1.4669867028980843 and parameters: {'n_estimators': 2201, 'learning_rate': 0.006215464818952927, 'max_depth': 1, 'min_child_weight': 0.17535949529764422, 'gamma': 4.877749830401205, 'subsample': 0.8242440159197416, 'colsample_bytree': 0.7644123563808884, 'reg_alpha': 4.4315220126915325, 'reg_lambda': 0.09450187118503514}. Best is trial 2 with value: 1.4222821186415848.
# [I 2026-07-16 07:07:49,868] Trial 10 finished with value: 1.4417540276626686 and parameters: {'n_estimators': 462, 'learning_rate': 0.051323729958866915, 'max_depth': 10, 'min_child_weight': 1.7583640270008525, 'gamma': 11.564507699318415, 'subsample': 0.670967137636854, 'colsample_bytree': 0.689776339098296, 'reg_alpha': 1.3504926357029513e-05, 'reg_lambda': 0.0001445994629863374}. Best is trial 2 with value: 1.4222821186415848.
# [I 2026-07-16 07:07:57,957] Trial 11 pruned.
# [I 2026-07-16 07:08:09,241] Trial 12 pruned.
# [I 2026-07-16 07:08:12,998] Trial 13 pruned.
# [I 2026-07-16 07:08:16,923] Trial 14 pruned.
# [I 2026-07-16 07:08:26,110] Trial 15 pruned.
# [I 2026-07-16 07:08:28,440] Trial 16 pruned.
# [I 2026-07-16 07:11:26,472] Trial 17 finished with value: 1.399557288833836 and parameters: {'n_estimators': 1745, 'learning_rate': 0.0031164113293281432, 'max_depth': 12, 'min_child_weight': 0.09188227716652786, 'gamma': 0.31395751113927606, 'subsample': 0.5733185506424886, 'colsample_bytree': 0.6886213055044286, 'reg_alpha': 2.5294763267016314e-10, 'reg_lambda': 0.00013075110675691903}. Best is trial 17 with value: 1.399557288833836.
# [I 2026-07-16 07:11:27,869] Trial 18 pruned.
# [I 2026-07-16 07:11:44,239] Trial 19 finished with value: 1.440995956901708 and parameters: {'n_estimators': 2928, 'learning_rate': 0.010584592769093184, 'max_depth': 11, 'min_child_weight': 0.1952798533119673, 'gamma': 9.466265153084475, 'subsample': 0.5968616983652272, 'colsample_bytree': 0.8435801758097969, 'reg_alpha': 0.0008497939354226009, 'reg_lambda': 0.0007299268013672949}. Best is trial 17 with value: 1.399557288833836.
# [I 2026-07-16 07:12:19,998] Trial 20 finished with value: 1.3560763866599792 and parameters: {'n_estimators': 1518, 'learning_rate': 0.0027386795744723785, 'max_depth': 6, 'min_child_weight': 0.39943453164171294, 'gamma': 4.4749240182872505, 'subsample': 0.5234874388491093, 'colsample_bytree': 0.6803218310036104, 'reg_alpha': 1.4425455478689164e-10, 'reg_lambda': 0.0004833247919900993}. Best is trial 20 with value: 1.3560763866599792.
# [I 2026-07-16 07:12:53,284] Trial 21 finished with value: 1.3611154891387816 and parameters: {'n_estimators': 1541, 'learning_rate': 0.0027728657015494546, 'max_depth': 5, 'min_child_weight': 0.42070836388727434, 'gamma': 4.721903621078615, 'subsample': 0.5223046396606033, 'colsample_bytree': 0.6952605277429902, 'reg_alpha': 1.2019565578055396e-10, 'reg_lambda': 0.0005768374683807865}. Best is trial 20 with value: 1.3560763866599792.
# [I 2026-07-16 07:13:43,584] Trial 22 finished with value: 1.3639578431133552 and parameters: {'n_estimators': 1917, 'learning_rate': 0.002112342848788146, 'max_depth': 5, 'min_child_weight': 0.43036072905633616, 'gamma': 6.414996983178163, 'subsample': 0.5046041363777497, 'colsample_bytree': 0.7612272333361183, 'reg_alpha': 2.1157140048866737e-10, 'reg_lambda': 0.00047671198593240765}. Best is trial 20 with value: 1.3560763866599792.
# [I 2026-07-16 07:14:37,671] Trial 23 finished with value: 1.360614837642942 and parameters: {'n_estimators': 2035, 'learning_rate': 0.0024613299555391968, 'max_depth': 5, 'min_child_weight': 0.5382480247341842, 'gamma': 6.888678473641707, 'subsample': 0.515341825432807, 'colsample_bytree': 0.7881167371438914, 'reg_alpha': 2.4910075924516804e-10, 'reg_lambda': 0.0006674485503740463}. Best is trial 20 with value: 1.3560763866599792.
# [I 2026-07-16 07:14:54,274] Trial 24 finished with value: 1.3684246135718325 and parameters: {'n_estimators': 2626, 'learning_rate': 0.010685212646498897, 'max_depth': 5, 'min_child_weight': 0.5338646243349574, 'gamma': 5.932785058852056, 'subsample': 0.5155379056116736, 'colsample_bytree': 0.839574109342289, 'reg_alpha': 5.040408718234795e-09, 'reg_lambda': 0.007445895625095237}. Best is trial 20 with value: 1.3560763866599792.
# [I 2026-07-16 07:15:34,491] Trial 25 finished with value: 1.3629031910061895 and parameters: {'n_estimators': 1049, 'learning_rate': 0.0028731267465622835, 'max_depth': 6, 'min_child_weight': 0.305117723262803, 'gamma': 8.214269348398311, 'subsample': 0.44371636541047277, 'colsample_bytree': 0.9129523634831146, 'reg_alpha': 1.3786421094960863e-10, 'reg_lambda': 0.0005466878467355077}. Best is trial 20 with value: 1.3560763866599792.
# [I 2026-07-16 07:15:38,633] Trial 26 pruned.
# [I 2026-07-16 07:16:36,321] Trial 27 finished with value: 1.365945260734692 and parameters: {'n_estimators': 2025, 'learning_rate': 0.002406295546785699, 'max_depth': 6, 'min_child_weight': 0.9853711056760383, 'gamma': 5.383339043898889, 'subsample': 0.6416105288654992, 'colsample_bytree': 0.8054045890353372, 'reg_alpha': 7.984684433105977e-10, 'reg_lambda': 0.0028133114306440332}. Best is trial 20 with value: 1.3560763866599792.
# [I 2026-07-16 07:17:08,413] Trial 28 finished with value: 1.3816439027890663 and parameters: {'n_estimators': 1021, 'learning_rate': 0.003821954825067971, 'max_depth': 5, 'min_child_weight': 0.12828720143718955, 'gamma': 3.8188129567821223, 'subsample': 0.437417808312026, 'colsample_bytree': 0.7174303761367979, 'reg_alpha': 1.8084039741378796e-08, 'reg_lambda': 0.00041529068349210765}. Best is trial 20 with value: 1.3560763866599792.
# [I 2026-07-16 07:17:09,460] Trial 29 pruned.
# [I 2026-07-16 07:17:09,630] A new study created in RDB with name: KDAL_v20_peak_timing_remaining_warmup_base_lightgbm_mae_f_wide
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-16 07:17:16,127] Trial 0 finished with value: 1.5679389763202825 and parameters: {'n_estimators': 447, 'learning_rate': 0.028873871707375695, 'num_leaves': 71, 'max_depth': 5, 'min_child_samples': 83, 'min_split_gain': 4.295687454742988, 'bagging_fraction': 0.7829586385137167, 'bagging_freq': 4, 'feature_fraction': 0.3688589858758342, 'lambda_l1': 0.06382334403151436, 'lambda_l2': 0.03080292177315921, 'huber_alpha': 0.95}. Best is trial 0 with value: 1.5679389763202825.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-16 07:17:24,661] Trial 1 finished with value: 2.205868516319878 and parameters: {'n_estimators': 812, 'learning_rate': 0.009357081249483435, 'num_leaves': 164, 'max_depth': 2, 'min_child_samples': 211, 'min_split_gain': 4.244695738724308, 'bagging_fraction': 0.9814523094330022, 'bagging_freq': 3, 'feature_fraction': 0.9704172813206324, 'lambda_l1': 2.234088279028776e-05, 'lambda_l2': 1.6594154120142632, 'huber_alpha': 0.85}. Best is trial 0 with value: 1.5679389763202825.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-16 07:17:27,103] Trial 2 finished with value: 2.806106094397829 and parameters: {'n_estimators': 67, 'learning_rate': 0.02007090910723469, 'num_leaves': 246, 'max_depth': 10, 'min_child_samples': 245, 'min_split_gain': 4.543313789155439, 'bagging_fraction': 0.9415994992571017, 'bagging_freq': 4, 'feature_fraction': 0.41761231740559585, 'lambda_l1': 1.4824332354449863e-08, 'lambda_l2': 101.18939970488272, 'huber_alpha': 0.85}. Best is trial 0 with value: 1.5679389763202825.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-16 07:17:29,883] Trial 3 finished with value: 2.420634541584434 and parameters: {'n_estimators': 1000, 'learning_rate': 0.1413663860910666, 'num_leaves': 109, 'max_depth': 7, 'min_child_samples': 249, 'min_split_gain': 3.678635407535604, 'bagging_fraction': 0.6392899181182937, 'bagging_freq': 4, 'feature_fraction': 0.6173160679063129, 'lambda_l1': 0.052948773379180566, 'lambda_l2': 0.032760577756785814, 'huber_alpha': 0.85}. Best is trial 0 with value: 1.5679389763202825.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-16 07:17:35,164] Trial 4 finished with value: 2.7009243788433137 and parameters: {'n_estimators': 761, 'learning_rate': 0.003003151716938294, 'num_leaves': 409, 'max_depth': 5, 'min_child_samples': 165, 'min_split_gain': 1.498083879035124, 'bagging_fraction': 0.44391094597483866, 'bagging_freq': 3, 'feature_fraction': 0.5516751924489833, 'lambda_l1': 8.332516750396116e-08, 'lambda_l2': 0.5077631895453656, 'huber_alpha': 0.85}. Best is trial 0 with value: 1.5679389763202825.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-16 07:17:38,475] Trial 5 finished with value: 1.4528021649677103 and parameters: {'n_estimators': 404, 'learning_rate': 0.18314620854695027, 'num_leaves': 260, 'max_depth': 13, 'min_child_samples': 51, 'min_split_gain': 2.972245934092154, 'bagging_fraction': 0.9775155780902212, 'bagging_freq': 7, 'feature_fraction': 0.365709606237354, 'lambda_l1': 5.9654059281874116e-05, 'lambda_l2': 0.006859036422781172, 'huber_alpha': 0.95}. Best is trial 5 with value: 1.4528021649677103.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-16 07:17:42,555] Trial 6 finished with value: 1.4391754421033915 and parameters: {'n_estimators': 3052, 'learning_rate': 0.13146898336096702, 'num_leaves': 489, 'max_depth': 11, 'min_child_samples': 47, 'min_split_gain': 2.173391605434026, 'bagging_fraction': 0.9258346721061177, 'bagging_freq': 2, 'feature_fraction': 0.6381532515738396, 'lambda_l1': 0.002530717742378322, 'lambda_l2': 0.0004479476588817844, 'huber_alpha': 0.95}. Best is trial 6 with value: 1.4391754421033915.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-16 07:17:45,688] Trial 7 finished with value: 1.980545298856971 and parameters: {'n_estimators': 2519, 'learning_rate': 0.18104669093362824, 'num_leaves': 399, 'max_depth': 4, 'min_child_samples': 227, 'min_split_gain': 2.761320735057018, 'bagging_fraction': 0.8991836269249566, 'bagging_freq': 7, 'feature_fraction': 0.8888248313104422, 'lambda_l1': 5.374969144858311e-06, 'lambda_l2': 0.5877618471031133, 'huber_alpha': 0.85}. Best is trial 6 with value: 1.4391754421033915.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-16 07:18:30,756] Trial 8 finished with value: 1.6499970428264539 and parameters: {'n_estimators': 2273, 'learning_rate': 0.0030965152683643635, 'num_leaves': 383, 'max_depth': 3, 'min_child_samples': 3, 'min_split_gain': 1.6724449577646616, 'bagging_fraction': 0.9800160774901863, 'bagging_freq': 5, 'feature_fraction': 0.6188955975766686, 'lambda_l1': 2.8120694751804143e-09, 'lambda_l2': 0.00024007807690373727, 'huber_alpha': 0.85}. Best is trial 6 with value: 1.4391754421033915.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-16 07:18:36,191] Trial 9 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-16 07:19:01,533] Trial 10 finished with value: 1.6322813511036562 and parameters: {'n_estimators': 2941, 'learning_rate': 0.007104579859769969, 'num_leaves': 424, 'max_depth': 2, 'min_child_samples': 2, 'min_split_gain': 4.6220887565718325, 'bagging_fraction': 0.7880566131549542, 'bagging_freq': 7, 'feature_fraction': 0.661678263936434, 'lambda_l1': 8.121756387194875e-09, 'lambda_l2': 100.08386764870838, 'huber_alpha': 0.9}. Best is trial 6 with value: 1.4391754421033915.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-16 07:19:02,316] Trial 11 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-16 07:19:07,981] Trial 12 finished with value: 1.5320452973346599 and parameters: {'n_estimators': 3404, 'learning_rate': 0.03866939016656176, 'num_leaves': 50, 'max_depth': 9, 'min_child_samples': 54, 'min_split_gain': 3.975378174997817, 'bagging_fraction': 0.5776988884481041, 'bagging_freq': 4, 'feature_fraction': 0.8073004449855348, 'lambda_l1': 1.1469173194560514e-08, 'lambda_l2': 0.6127644589218547, 'huber_alpha': 0.85}. Best is trial 6 with value: 1.4391754421033915.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-16 07:19:08,763] Trial 13 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-16 07:19:13,893] Trial 14 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-16 07:19:26,014] Trial 15 finished with value: 1.4003452591887358 and parameters: {'n_estimators': 1596, 'learning_rate': 0.07412684021464837, 'num_leaves': 490, 'max_depth': 14, 'min_child_samples': 54, 'min_split_gain': 0.3349947053308182, 'bagging_fraction': 0.8356054383416602, 'bagging_freq': 1, 'feature_fraction': 0.4928412115082472, 'lambda_l1': 5.944760726571435, 'lambda_l2': 0.004183303285898086, 'huber_alpha': 0.95}. Best is trial 15 with value: 1.4003452591887358.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-16 07:19:28,789] Trial 16 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-16 07:19:30,461] Trial 17 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-16 07:19:45,322] Trial 18 finished with value: 1.4563132800565253 and parameters: {'n_estimators': 3498, 'learning_rate': 0.059131536443425475, 'num_leaves': 342, 'max_depth': 8, 'min_child_samples': 95, 'min_split_gain': 0.9297846530290041, 'bagging_fraction': 0.8581088794716628, 'bagging_freq': 2, 'feature_fraction': 0.5067584209831179, 'lambda_l1': 0.009409403770416278, 'lambda_l2': 0.01950927643144989, 'huber_alpha': 0.75}. Best is trial 15 with value: 1.4003452591887358.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-16 07:20:11,043] Trial 19 finished with value: 1.4049913089773844 and parameters: {'n_estimators': 2048, 'learning_rate': 0.015467561997108534, 'num_leaves': 467, 'max_depth': 12, 'min_child_samples': 36, 'min_split_gain': 0.8867366054404582, 'bagging_fraction': 0.7386509877156308, 'bagging_freq': 2, 'feature_fraction': 0.7453029649885938, 'lambda_l1': 1.0612674116708008e-10, 'lambda_l2': 0.005680543170358973, 'huber_alpha': 0.95}. Best is trial 15 with value: 1.4003452591887358.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-16 07:20:13,760] Trial 20 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-16 07:20:17,811] Trial 21 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-16 07:20:31,589] Trial 22 finished with value: 1.3971751365465466 and parameters: {'n_estimators': 2055, 'learning_rate': 0.046128456183836604, 'num_leaves': 347, 'max_depth': 13, 'min_child_samples': 28, 'min_split_gain': 0.9671987726705117, 'bagging_fraction': 0.8665927277296104, 'bagging_freq': 1, 'feature_fraction': 0.5397623740000719, 'lambda_l1': 0.004320469653742817, 'lambda_l2': 0.0007363742010087261, 'huber_alpha': 0.95}. Best is trial 22 with value: 1.3971751365465466.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-16 07:20:49,080] Trial 23 finished with value: 1.3899524607725662 and parameters: {'n_estimators': 2109, 'learning_rate': 0.03641975695899514, 'num_leaves': 344, 'max_depth': 13, 'min_child_samples': 20, 'min_split_gain': 1.0413136756232446, 'bagging_fraction': 0.8554625959530964, 'bagging_freq': 1, 'feature_fraction': 0.5532123411314687, 'lambda_l1': 0.9100777646757591, 'lambda_l2': 0.004804534972712218, 'huber_alpha': 0.95}. Best is trial 23 with value: 1.3899524607725662.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-16 07:21:05,455] Trial 24 finished with value: 1.3869541305878046 and parameters: {'n_estimators': 1415, 'learning_rate': 0.038445558365750164, 'num_leaves': 332, 'max_depth': 14, 'min_child_samples': 17, 'min_split_gain': 1.2517538075691048, 'bagging_fraction': 0.8504114068321648, 'bagging_freq': 1, 'feature_fraction': 0.5467102972042218, 'lambda_l1': 1.1284356770941455, 'lambda_l2': 0.0005139858207053422, 'huber_alpha': 0.95}. Best is trial 24 with value: 1.3869541305878046.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-16 07:21:16,184] Trial 25 finished with value: 1.3842791550398785 and parameters: {'n_estimators': 1235, 'learning_rate': 0.040386949937597345, 'num_leaves': 323, 'max_depth': 13, 'min_child_samples': 17, 'min_split_gain': 1.1858118769931503, 'bagging_fraction': 0.8831209216847683, 'bagging_freq': 1, 'feature_fraction': 0.5549536570514435, 'lambda_l1': 0.9436359031041671, 'lambda_l2': 0.00010180464548530071, 'huber_alpha': 0.9}. Best is trial 25 with value: 1.3842791550398785.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-16 07:21:33,808] Trial 26 finished with value: 1.3844288814272456 and parameters: {'n_estimators': 1255, 'learning_rate': 0.023194020936828097, 'num_leaves': 318, 'max_depth': 13, 'min_child_samples': 17, 'min_split_gain': 1.1747020065433345, 'bagging_fraction': 0.8048672080725924, 'bagging_freq': 1, 'feature_fraction': 0.5596130811853627, 'lambda_l1': 0.6434328109592911, 'lambda_l2': 0.00013086881779019436, 'huber_alpha': 0.9}. Best is trial 25 with value: 1.3842791550398785.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-16 07:21:49,641] Trial 27 finished with value: 1.3926886566264065 and parameters: {'n_estimators': 1188, 'learning_rate': 0.02289952747874147, 'num_leaves': 297, 'max_depth': 13, 'min_child_samples': 16, 'min_split_gain': 1.482850855832702, 'bagging_fraction': 0.7948599363955349, 'bagging_freq': 3, 'feature_fraction': 0.4456592814579891, 'lambda_l1': 0.28474693879796115, 'lambda_l2': 0.00010656339267134812, 'huber_alpha': 0.9}. Best is trial 25 with value: 1.3842791550398785.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-16 07:21:53,320] Trial 28 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-16 07:21:56,038] Trial 29 pruned.
# [I 2026-07-16 07:21:56,239] A new study created in RDB with name: KDAL_v20_peak_timing_remaining_warmup_base_catboost_mae_f_wide
# ...
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
#                   period           method  count     mae_f    rmse_f
# 0   validation_2024_2025          xgboost   1452  1.365158  1.834831
# 1   validation_2024_2025         lightgbm   1452  1.389562  1.879503
# 2   validation_2024_2025         catboost   1452  1.362249  1.835313
# 3   validation_2024_2025    provider_mean   1452  2.717663  3.648723
# 4   validation_2024_2025  provider_median   1452  2.344602  3.323749
# 5   validation_2024_2025          nbm_raw   1452  2.078083  2.977793
# 6   validation_2024_2025         hrrr_raw   1452  4.924938  6.153463
# 7   validation_2024_2025          gfs_raw   1452  3.041998  4.098564
# 8              test_2026          xgboost    170  1.376147  1.805753
# 9              test_2026         lightgbm    170  1.369703  1.813706
# 10             test_2026         catboost    170  1.375788  1.819497
# 11             test_2026      ridge_stack    170  1.338366  1.781229
# 12             test_2026    provider_mean    170  2.583543  3.303107
# 13             test_2026  provider_median    170  2.428105  3.214617
# 14             test_2026          nbm_raw    170  2.045105  2.795566
# 15             test_2026         hrrr_raw    170  4.927253  5.592931
# 16             test_2026          gfs_raw    170  2.550131  3.455843

# %%
if EXPORT_MODEL_WEIGHTS:
    exported_weights = export_station_model_weights(
        project_root=PROJECT_ROOT,
        station_id=STATION_ID,
        artifact_dir=config.resolved_output_dir(),
        model_version=MODEL_VERSION,
        timing_mode=config.timing_mode,
        providers=tuple(config.providers),
        feature_version=config.effective_feature_version,
        training_profile=config.effective_training_profile,
        optuna_metric=config.effective_optuna_metric,
        target_mode=config.effective_target_mode,
        target_source=config.effective_target_source,
        base_model_methods=tuple(config.effective_base_model_methods),
        stack_enabled=config.stack_enabled,
        source_pipeline="notebooks/station_stacking_v20_peak_timing",
    )

    exported_weights.bundle_path, exported_weights.manifest_path
else:
    print("Model export disabled for this experimental notebook.")
# Out:
# Model export disabled for this experimental notebook.

# %% [markdown]
# ## V11 Feature Coverage

# %%
v11_feature_coverage = (
    result.features[V11_FEATURE_COLUMNS]
    .notna()
    .mean()
    .mul(100)
    .sort_values(ascending=False)
    .rename("coverage_pct")
    .reset_index()
    .rename(columns={"index": "feature"})
)

v11_feature_coverage
# Out:
#                                               feature  coverage_pct
# 0                              v4_observed_precip_any    100.000000
# 1                        v4_forecast_wet_observed_dry    100.000000
# 2                   v4_forecast_observed_precip_match    100.000000
# 3                              v4_all_forecast_precip    100.000000
# 4                              v4_any_forecast_precip    100.000000
# 5                          climatology_high_10y_std_f    100.000000
# 6                              climatology_high_10y_f    100.000000
# 7                          climatology_high_10y_count    100.000000
# 8                     v8_month_remaining_warmup_count    100.000000
# 9                        v4_observed_wet_forecast_dry    100.000000
# 10              v8_recent_remaining_warmup_30d_mean_f     99.752598
# 11                          v2_recent_heat_momentum_f     99.653637
# 12                           v2_recent_heat_anomaly_f     99.059871
# 13               v8_recent_remaining_warmup_7d_mean_f     99.059871
# 14                     v3_high_so_far_above_current_f     98.911430
# 15       v8_provider_max_remaining_from_high_so_far_f     98.911430
# 16          v8_provider_spread_per_remaining_warmup_f     98.911430
# 17    v8_provider_median_remaining_from_high_so_far_f     98.911430
# 18            observed_high_so_far_change_since_9am_f     98.911430
# 19                   v3_remaining_warmup_per_spread_f     98.911430
# 20           v3_humidity_remaining_warmup_interaction     98.911430
# 21             v3_remaining_warmup_from_high_so_far_f     98.911430
# 22       v8_provider_min_remaining_from_high_so_far_f     98.911430
# 23                   v2_morning_warmup_to_consensus_f     98.911430
# 24                     v2_humidity_warmup_interaction     98.911430
# 25                             v2_spread_per_warmup_f     98.911430
# 26       observed_high_so_far_minus_climatology_10y_f     98.911430
# 27              observed_temp_minus_climatology_10y_f     98.911430
# 28            observed_morning_warmup_rate_f_per_hour     98.911430
# 29                     observed_temp_change_last_3h_f     98.911430
# 30              provider_mean_minus_climatology_10y_f     98.911430
# 31                     observed_temp_change_last_1h_f     98.911430
# 32                   v8_month_remaining_warmup_mean_f     98.812469
# 33                     v2_consensus_minus_7d_actual_f     98.812469
# 34                   v3_high_so_far_minus_7d_actual_f     98.812469
# 35                   v4_observed_precip_recent_mm_est     98.812469
# 36                      v3_high_so_far_minus_lag_1d_f     98.515586
# 37       v8_provider_mean_remaining_vs_month_normal_f     97.723899
# 38      v8_dewpoint_mean_remaining_warmup_interaction     79.069767
# 39  v8_dewpoint_depression_remaining_warmup_intera...     79.069767
# 40                        v8_forecast_dewpoint_mean_f     79.069767
# 41             v8_forecast_dewpoint_depression_mean_f     79.069767
# 42             v4_precip_remaining_warmup_interaction     78.624443
# 43                   v4_forecast_precip_intensity_max     78.624443
# 44                   v4_forecast_precip_total_mean_mm     78.624443
# 45                    v4_forecast_precip_total_max_mm     78.624443
# 46                 v4_forecast_precip_total_spread_mm     78.624443
# 47                  v4_forecast_precip_max_1h_mean_mm     78.624443
# 48                      v4_forecast_precip_hours_mean     78.624443
# 49                  v4_forecast_precip_intensity_mean     78.624443
# 50       v8_precip_total_remaining_warmup_interaction     78.624443
# 51                     v4_precip_humidity_interaction     78.624443
# 52      v8_precip_max_1h_remaining_warmup_interaction     78.624443
# 53         v4_forecast_total_minus_observed_recent_mm     78.525482
# 54    v8_cloud_cover_max_remaining_warmup_interaction     64.423553
# 55   v8_cloud_cover_mean_remaining_warmup_interaction     64.423553
# 56    v8_wind_speed_mean_remaining_warmup_interaction     35.823850
# 57      v8_wind_gust_max_remaining_warmup_interaction     35.823850

# %%
result.feature_columns.loc[result.feature_columns["feature"].isin(V11_FEATURE_COLUMNS)]
# Out:
#                                                feature     kind
# 3                       observed_temp_change_last_1h_f  numeric
# 4                       observed_temp_change_last_3h_f  numeric
# 5              observed_morning_warmup_rate_f_per_hour  numeric
# 6              observed_high_so_far_change_since_9am_f  numeric
# 32                            v2_recent_heat_anomaly_f  numeric
# 33                           v2_recent_heat_momentum_f  numeric
# 34                    v2_morning_warmup_to_consensus_f  numeric
# 35                      v2_consensus_minus_7d_actual_f  numeric
# 36                              v2_spread_per_warmup_f  numeric
# 37                      v2_humidity_warmup_interaction  numeric
# 38                      v3_high_so_far_above_current_f  numeric
# 39              v3_remaining_warmup_from_high_so_far_f  numeric
# 40                       v3_high_so_far_minus_lag_1d_f  numeric
# 41                    v3_high_so_far_minus_7d_actual_f  numeric
# 42                    v3_remaining_warmup_per_spread_f  numeric
# 43            v3_humidity_remaining_warmup_interaction  numeric
# 44                    v4_forecast_precip_total_mean_mm  numeric
# 45                     v4_forecast_precip_total_max_mm  numeric
# 46                  v4_forecast_precip_total_spread_mm  numeric
# 47                   v4_forecast_precip_max_1h_mean_mm  numeric
# 48                       v4_forecast_precip_hours_mean  numeric
# 49                   v4_forecast_precip_intensity_mean  numeric
# 50                    v4_forecast_precip_intensity_max  numeric
# 51                              v4_any_forecast_precip  numeric
# 52                              v4_all_forecast_precip  numeric
# 53                              v4_observed_precip_any  numeric
# 54                    v4_observed_precip_recent_mm_est  numeric
# 55          v4_forecast_total_minus_observed_recent_mm  numeric
# 56                   v4_forecast_observed_precip_match  numeric
# 57                        v4_forecast_wet_observed_dry  numeric
# 58                        v4_observed_wet_forecast_dry  numeric
# 59                      v4_precip_humidity_interaction  numeric
# 60              v4_precip_remaining_warmup_interaction  numeric
# 61        v8_provider_max_remaining_from_high_so_far_f  numeric
# 62        v8_provider_min_remaining_from_high_so_far_f  numeric
# 63     v8_provider_median_remaining_from_high_so_far_f  numeric
# 64           v8_provider_spread_per_remaining_warmup_f  numeric
# 65                    v8_month_remaining_warmup_mean_f  numeric
# 66                     v8_month_remaining_warmup_count  numeric
# 67                v8_recent_remaining_warmup_7d_mean_f  numeric
# 68               v8_recent_remaining_warmup_30d_mean_f  numeric
# 69        v8_provider_mean_remaining_vs_month_normal_f  numeric
# 70    v8_cloud_cover_mean_remaining_warmup_interaction  numeric
# 71     v8_cloud_cover_max_remaining_warmup_interaction  numeric
# 72        v8_precip_total_remaining_warmup_interaction  numeric
# 73       v8_precip_max_1h_remaining_warmup_interaction  numeric
# 74     v8_wind_speed_mean_remaining_warmup_interaction  numeric
# 75       v8_wind_gust_max_remaining_warmup_interaction  numeric
# 76                         v8_forecast_dewpoint_mean_f  numeric
# 77              v8_forecast_dewpoint_depression_mean_f  numeric
# 78       v8_dewpoint_mean_remaining_warmup_interaction  numeric
# 79   v8_dewpoint_depression_remaining_warmup_intera...  numeric
# 110                             climatology_high_10y_f  numeric
# 111                         climatology_high_10y_std_f  numeric
# 112                         climatology_high_10y_count  numeric
# 113              provider_mean_minus_climatology_10y_f  numeric
# 114              observed_temp_minus_climatology_10y_f  numeric
# 115       observed_high_so_far_minus_climatology_10y_f  numeric

# %% [markdown]
# ## Dropped Feature Check

# %%
dropped_present = result.feature_columns.loc[
    result.feature_columns["feature"].isin(V11_DROPPED_FEATURE_COLUMNS)
]

dropped_present
# Out:
# Empty DataFrame
# Columns: [feature, kind]
# Index: []

# %% [markdown]
# ## Morning Trend Coverage

# %%
trend_coverage = (
    result.features[TREND_COLUMNS]
    .notna()
    .mean()
    .mul(100)
    .sort_values(ascending=False)
    .rename("coverage_pct")
    .reset_index()
    .rename(columns={"index": "feature"})
)

trend_coverage
# Out:
#                                    feature  coverage_pct
# 0           observed_temp_change_last_1h_f      98.91143
# 1           observed_temp_change_last_3h_f      98.91143
# 2  observed_morning_warmup_rate_f_per_hour      98.91143
# 3  observed_high_so_far_change_since_9am_f      98.91143

# %% [markdown]
# ## Rounded Within 1F Accuracy

# %%
preds = pd.concat(
    [
        result.validation_predictions.assign(period="validation_2024_2025"),
        result.test_predictions.assign(period="oof_2026"),
    ],
    ignore_index=True,
)

predicted_high = pd.to_numeric(preds["predicted_high_f"], errors="coerce")
preds["predicted_high_rounded_f"] = np.floor(predicted_high + 0.5)
preds["within_1f_after_round"] = (
    pd.to_numeric(preds["actual_high_f"], errors="coerce") - preds["predicted_high_rounded_f"]
).abs().le(1)

within_1f_accuracy_by_period = (
    preds
    .dropna(subset=["actual_high_f", "predicted_high_rounded_f"])
    .groupby(["period", "method"], as_index=False)
    .agg(
        count=("within_1f_after_round", "size"),
        within_1f_count=("within_1f_after_round", "sum"),
        within_1f_accuracy_pct=("within_1f_after_round", lambda x: x.mean() * 100),
    )
    .sort_values(["period", "within_1f_accuracy_pct"], ascending=[True, False])
)

within_1f_accuracy_by_period
# Out:
#                   period           method  count  within_1f_count  \
# 0               oof_2026         catboost    170              109
# 7               oof_2026      ridge_stack    170              108
# 3               oof_2026         lightgbm    170              104
# 8               oof_2026          xgboost    170              104
# 4               oof_2026          nbm_raw    170               84
# 1               oof_2026          gfs_raw    170               69
# 6               oof_2026  provider_median    170               69
# 5               oof_2026    provider_mean    170               57
# 2               oof_2026         hrrr_raw    170               17
# 9   validation_2024_2025         catboost   1452              943
# 12  validation_2024_2025         lightgbm   1452              941
# 16  validation_2024_2025          xgboost   1452              930
# 13  validation_2024_2025          nbm_raw   1452              707
# 15  validation_2024_2025  provider_median   1452              630
# 14  validation_2024_2025    provider_mean   1452              474
# 10  validation_2024_2025          gfs_raw   1452              463
# 11  validation_2024_2025         hrrr_raw   1452              234
#
#     within_1f_accuracy_pct
# 0                64.117647
# 7                63.529412
# 3                61.176471
# 8                61.176471
# 4                49.411765
# 1                40.588235
# 6                40.588235
# 5                33.529412
# 2                10.000000
# 9                64.944904
# 12               64.807163
# 16               64.049587
# 13               48.691460
# 15               43.388430
# 14               32.644628
# 10               31.887052
# 11               16.115702

# %% [markdown]
# ## Version Comparison

# %%
comparison_frames = []
for version, folder in [
    ("v1", PROJECT_ROOT / "data" / "calibration" / "station_stacking"),
    ("v2", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v2"),
    ("v3", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v3"),
    ("v4", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v4"),
    ("v5", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v5"),
    ("v6", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v6"),
    ("v7", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v7"),
    ("v8", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v8"),
    ("v9", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v9"),
    ("v10", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v10"),
    ("v11", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v11"),
]:
    path = folder / f"{STATION_ID}_year_split_scoreboard.csv"
    if path.exists():
        frame = pd.read_csv(path)
        frame["version"] = version
        comparison_frames.append(frame)

version_comparison = pd.concat(comparison_frames, ignore_index=True) if comparison_frames else pd.DataFrame()
if not version_comparison.empty:
    version_comparison = version_comparison.sort_values(["period", "mae_f", "version", "method"]).reset_index(drop=True)
version_comparison
# Out:
#                   period       method  count     mae_f    rmse_f version
# 0              test_2026  ridge_stack    138  1.369446  1.890651      v9
# 1              test_2026      xgboost    138  1.402066  1.889472     v11
# 2              test_2026      xgboost    138  1.419940  1.895994      v9
# 3              test_2026  ridge_stack    138  1.429989  1.907881     v11
# 4              test_2026     lightgbm    138  1.454606  1.932482     v11
# ..                   ...          ...    ...       ...       ...     ...
# 83  validation_2024_2025     hrrr_raw    660  5.477361  6.266007      v3
# 84  validation_2024_2025     hrrr_raw    668  5.486824  6.274688      v7
# 85  validation_2024_2025     hrrr_raw    606  5.497186  6.283967      v5
# 86  validation_2024_2025     hrrr_raw    606  5.497186  6.283967      v6
# 87  validation_2024_2025     hrrr_raw    623  5.564150  6.352240      v1
#
# [88 rows x 6 columns]

# %% [markdown]
# ## 2026 OOF Weather Brackets

# %%
result.bracket_metrics
# Out:
#             method  count     mae_f    rmse_f  bucket_log_loss  \
# 0          xgboost    170  1.376147  1.805753         1.365203
# 1         lightgbm    170  1.369703  1.813706         1.377378
# 2         catboost    170  1.375788  1.819497         1.369970
# 3      ridge_stack    170  1.338366  1.781229         1.350258
# 4    provider_mean    170  2.583543  3.303107         1.678281
# 5  provider_median    170  2.428105  3.214617         1.757808
# 6          nbm_raw    170  2.045105  2.795566         1.726940
# 7         hrrr_raw    170  4.927253  5.592931         1.838395
# 8          gfs_raw    170  2.550131  3.455843         1.948382
#
#    bracket_accuracy_pct  p95_absolute_error_f  large_miss_5f_pct
# 0             41.764706              3.459871           1.764706
# 1             41.176471              3.904035           1.764706
# 2             44.705882              3.514327           1.176471
# 3             45.294118              3.485369           1.764706
# 4             23.529412              5.481044           8.235294
# 5             22.941176              5.950489           8.823529
# 6             34.117647              5.718984           8.235294
# 7              5.294118              9.733436          45.294118
# 8             27.058824              6.385804          11.176471

# %% [markdown]
# ## Train-Fold 3% Missingness Audit

# %%
modeling_frame, candidate_categorical, candidate_numeric = _modeling_frame(result.features, config)
candidate_features = [*candidate_categorical, *candidate_numeric]
audit_specs = [
    (fold.name, fold.train_start_year, fold.train_end_year)
    for fold in V20_EXPANDING_FOLDS
] + [("test_refit_2021_2025", 2021, 2025)]

missingness_rows = []
years = pd.to_numeric(modeling_frame["year"], errors="coerce")
for fold_name, train_start, train_end in audit_specs:
    train = modeling_frame.loc[years.between(train_start, train_end)].copy()
    retained_categorical, retained_numeric = _fit_feature_columns(
        train,
        candidate_categorical,
        candidate_numeric,
        max_missing_fraction=config.effective_max_feature_missing_fraction,
    )
    retained = set(retained_categorical) | set(retained_numeric)
    for feature in candidate_features:
        numeric_feature = feature in candidate_numeric
        values = pd.to_numeric(train[feature], errors="coerce") if numeric_feature else train[feature]
        missingness_rows.append(
            {
                "fold": fold_name,
                "train_start_year": train_start,
                "train_end_year": train_end,
                "feature": feature,
                "kind": "numeric" if numeric_feature else "categorical",
                "missing_fraction": float(values.isna().mean()),
                "retained": feature in retained,
            }
        )

fold_feature_missingness = pd.DataFrame(missingness_rows)
retained_dropped_summary = (
    fold_feature_missingness.groupby(["fold", "retained"], as_index=False)
    .agg(feature_count=("feature", "nunique"), maximum_missing_fraction=("missing_fraction", "max"))
)
fold_feature_missingness.to_csv(config.resolved_output_dir() / f"{STATION_ID}_fold_feature_missingness.csv", index=False)
retained_dropped_summary, fold_feature_missingness.loc[~fold_feature_missingness["retained"]].sort_values(
    ["fold", "missing_fraction"], ascending=[True, False]
)
# Out:
# (                     fold  retained  feature_count  maximum_missing_fraction
#  0  fold_2021_2022_to_2023     False             24                  0.915278
#  1  fold_2021_2022_to_2023      True             92                  0.006944
#  2  fold_2021_2023_to_2024     False             22                  0.907664
#  3  fold_2021_2023_to_2024      True             94                  0.022161
#  4  fold_2021_2024_to_2025     False             22                  0.911541
#  5  fold_2021_2024_to_2025      True             94                  0.016586
#  6       fold_2021_to_2022     False             24                  0.896936
#  7       fold_2021_to_2022      True             92                  0.013928
#  8    test_refit_2021_2025     False             22                  0.915516
#  9    test_refit_2021_2025      True             94                  0.013252,
#                         fold  train_start_year  train_end_year  \
#  117  fold_2021_2022_to_2023              2021            2022
#  190  fold_2021_2022_to_2023              2021            2022
#  191  fold_2021_2022_to_2023              2021            2022
#  186  fold_2021_2022_to_2023              2021            2022
#  187  fold_2021_2022_to_2023              2021            2022
#  ..                      ...               ...             ...
#  540    test_refit_2021_2025              2021            2025
#  541    test_refit_2021_2025              2021            2025
#  542    test_refit_2021_2025              2021            2025
#  543    test_refit_2021_2025              2021            2025
#  476    test_refit_2021_2025              2021            2025
#
#                                                 feature         kind  \
#  117                     observed_weather_code_at_as_of  categorical
#  190    v8_wind_speed_mean_remaining_warmup_interaction      numeric
#  191      v8_wind_gust_max_remaining_warmup_interaction      numeric
#  186   v8_cloud_cover_mean_remaining_warmup_interaction      numeric
#  187    v8_cloud_cover_max_remaining_warmup_interaction      numeric
#  ..                                                 ...          ...
#  540                        v8_forecast_dewpoint_mean_f      numeric
#  541             v8_forecast_dewpoint_depression_mean_f      numeric
#  542      v8_dewpoint_mean_remaining_warmup_interaction      numeric
#  543  v8_dewpoint_depression_remaining_warmup_intera...      numeric
#  476                       nbm_cooling_onset_hour_local      numeric
#
#       missing_fraction  retained
#  117          0.915278     False
#  190          0.413889     False
#  191          0.413889     False
#  186          0.350000     False
#  187          0.350000     False
#  ..                ...       ...
#  540          0.133076     False
#  541          0.133076     False
#  542          0.133076     False
#  543          0.133076     False
#  476          0.078962     False
#
#  [114 rows x 7 columns])

# %% [markdown]
# ## Expanded 11 AM Feature Coverage and Provider Count

# %%
new_feature_coverage = (
    result.features[V11_SETTLEMENT_FIX_TEMP_FEATURE_COLUMNS]
    .notna()
    .mean()
    .mul(100)
    .rename("coverage_pct")
    .reset_index()
    .rename(columns={"index": "feature"})
)
provider_count_coverage = (
    result.features["v11sf_forecast_temp_11am_provider_count"]
    .value_counts(dropna=False)
    .sort_index()
    .rename_axis("available_provider_count")
    .reset_index(name="row_count")
)
provider_count_coverage["row_pct"] = provider_count_coverage["row_count"] / len(result.features) * 100
new_feature_coverage.to_csv(config.resolved_output_dir() / f"{STATION_ID}_11am_feature_coverage.csv", index=False)
new_feature_coverage, provider_count_coverage
# Out:
# (                                              feature  coverage_pct
#  0                     v11sf_forecast_temp_11am_mean_f      98.91143
#  1                   v11sf_forecast_temp_11am_median_f      98.91143
#  2           v11sf_forecast_temp_11am_minus_observed_f      98.91143
#  3                v11sf_forecast_temp_11am_abs_error_f      98.91143
#  4               v11sf_forecast_temp_11am_warm_error_f      98.91143
#  5               v11sf_forecast_temp_11am_cool_error_f      98.91143
#  6                   v11sf_forecast_temp_11am_spread_f      98.91143
#  7             v11sf_forecast_temp_11am_provider_count     100.00000
#  8   v11sf_forecast_temp_bias_remaining_warmup_inte...      98.91143
#  9          v11sf_observation_adjusted_provider_high_f      98.91143
#  10                 v11sf_forecast_warmup_after_11am_f      98.91143,
#     available_provider_count  row_count    row_pct
#  0                         0         22   1.088570
#  1                         1         23   1.138050
#  2                         2        349  17.268679
#  3                         3       1627  80.504701)

# %% [markdown]
# ## New-Feature Importance

# %%
new_feature_importance = result.feature_importance.loc[
    result.feature_importance["feature"].isin(V11_SETTLEMENT_FIX_TEMP_FEATURE_COLUMNS)
].sort_values(["method", "importance_mean_mae_f"], ascending=[True, False])
new_feature_importance
# Out:
#        method param_key                                            feature  \
# 29   catboost  trial_26                  v11sf_forecast_temp_11am_median_f
# 35   catboost  trial_26                 v11sf_forecast_warmup_after_11am_f
# 70   catboost  trial_26                    v11sf_forecast_temp_11am_mean_f
# 71   catboost  trial_26          v11sf_forecast_temp_11am_minus_observed_f
# 178  catboost  trial_26                  v11sf_forecast_temp_11am_spread_f
# 185  catboost  trial_26            v11sf_forecast_temp_11am_provider_count
# 208  catboost  trial_26              v11sf_forecast_temp_11am_warm_error_f
# 218  catboost  trial_26         v11sf_observation_adjusted_provider_high_f
# 230  catboost  trial_26               v11sf_forecast_temp_11am_abs_error_f
# 249  catboost  trial_26              v11sf_forecast_temp_11am_cool_error_f
# 270  catboost  trial_26  v11sf_forecast_temp_bias_remaining_warmup_inte...
# 54   lightgbm  trial_25          v11sf_forecast_temp_11am_minus_observed_f
# 76   lightgbm  trial_25         v11sf_observation_adjusted_provider_high_f
# 110  lightgbm  trial_25                  v11sf_forecast_temp_11am_median_f
# 118  lightgbm  trial_25  v11sf_forecast_temp_bias_remaining_warmup_inte...
# 121  lightgbm  trial_25                    v11sf_forecast_temp_11am_mean_f
# 137  lightgbm  trial_25               v11sf_forecast_temp_11am_abs_error_f
# 147  lightgbm  trial_25              v11sf_forecast_temp_11am_cool_error_f
# 148  lightgbm  trial_25              v11sf_forecast_temp_11am_warm_error_f
# 166  lightgbm  trial_25                 v11sf_forecast_warmup_after_11am_f
# 196  lightgbm  trial_25            v11sf_forecast_temp_11am_provider_count
# 227  lightgbm  trial_25                  v11sf_forecast_temp_11am_spread_f
# 59    xgboost  trial_20                 v11sf_forecast_warmup_after_11am_f
# 77    xgboost  trial_20         v11sf_observation_adjusted_provider_high_f
# 81    xgboost  trial_20          v11sf_forecast_temp_11am_minus_observed_f
# 102   xgboost  trial_20                  v11sf_forecast_temp_11am_median_f
# 109   xgboost  trial_20                  v11sf_forecast_temp_11am_spread_f
# 134   xgboost  trial_20                    v11sf_forecast_temp_11am_mean_f
# 158   xgboost  trial_20              v11sf_forecast_temp_11am_warm_error_f
# 202   xgboost  trial_20            v11sf_forecast_temp_11am_provider_count
# 231   xgboost  trial_20  v11sf_forecast_temp_bias_remaining_warmup_inte...
# 237   xgboost  trial_20              v11sf_forecast_temp_11am_cool_error_f
# 268   xgboost  trial_20               v11sf_forecast_temp_11am_abs_error_f
#
#      importance_mean_mae_f  importance_std_mae_f  n_repeats  train_start_year  \
# 29                0.019567              0.007638         10              2021
# 35                0.015571              0.006605         10              2021
# 70                0.006415              0.004650         10              2021
# 71                0.006401              0.003336         10              2021
# 178               0.000158              0.000912         10              2021
# 185               0.000000              0.000000         10              2021
# 208              -0.000091              0.000664         10              2021
# 218              -0.000263              0.001625         10              2021
# 230              -0.000743              0.002534         10              2021
# 249              -0.001716              0.002963         10              2021
# 270              -0.004161              0.011734         10              2021
# 54                0.010240              0.005137         10              2021
# 76                0.005926              0.002200         10              2021
# 110               0.002727              0.001444         10              2021
# 118               0.002433              0.003915         10              2021
# 121               0.002365              0.002174         10              2021
# 137               0.001535              0.000689         10              2021
# 147               0.000987              0.001920         10              2021
# 148               0.000962              0.000290         10              2021
# 166               0.000305              0.005852         10              2021
# 196               0.000000              0.000000         10              2021
# 227              -0.000598              0.001469         10              2021
# 59                0.009270              0.012084         10              2021
# 77                0.005516              0.002127         10              2021
# 81                0.005273              0.004944         10              2021
# 102               0.003510              0.001781         10              2021
# 109               0.002759              0.003020         10              2021
# 134               0.001597              0.001412         10              2021
# 158               0.000409              0.000566         10              2021
# 202               0.000000              0.000000         10              2021
# 231              -0.000745              0.002051         10              2021
# 237              -0.000976              0.000858         10              2021
# 268              -0.004073              0.002041         10              2021
#
#      train_end_year  test_year  train_rows  test_rows
# 29             2025       2026        1811        170
# 35             2025       2026        1811        170
# 70             2025       2026        1811        170
# 71             2025       2026        1811        170
# 178            2025       2026        1811        170
# 185            2025       2026        1811        170
# 208            2025       2026        1811        170
# 218            2025       2026        1811        170
# 230            2025       2026        1811        170
# 249            2025       2026        1811        170
# 270            2025       2026        1811        170
# 54             2025       2026        1811        170
# 76             2025       2026        1811        170
# 110            2025       2026        1811        170
# 118            2025       2026        1811        170
# 121            2025       2026        1811        170
# 137            2025       2026        1811        170
# 147            2025       2026        1811        170
# 148            2025       2026        1811        170
# 166            2025       2026        1811        170
# 196            2025       2026        1811        170
# 227            2025       2026        1811        170
# 59             2025       2026        1811        170
# 77             2025       2026        1811        170
# 81             2025       2026        1811        170
# 102            2025       2026        1811        170
# 109            2025       2026        1811        170
# 134            2025       2026        1811        170
# 158            2025       2026        1811        170
# 202            2025       2026        1811        170
# 231            2025       2026        1811        170
# 237            2025       2026        1811        170
# 268            2025       2026        1811        170

# %% [markdown]
# ## 2026 Monthly Metrics

# %%
monthly_predictions = result.test_predictions.copy()
monthly_predictions["month"] = pd.to_datetime(monthly_predictions["contract_date"], errors="coerce").dt.month
monthly_metrics = (
    monthly_predictions.dropna(subset=["month", "error_f"])
    .groupby(["method", "month"], as_index=False)
    .agg(
        count=("error_f", "size"),
        mae_f=("absolute_error_f", "mean"),
        rmse_f=("error_f", lambda values: float(np.sqrt(np.mean(np.square(values))))),
        bias_f=("error_f", "mean"),
    )
)
monthly_metrics.to_csv(config.resolved_output_dir() / f"{STATION_ID}_2026_monthly_metrics.csv", index=False)
monthly_metrics
# Out:
#              method  month  count     mae_f    rmse_f    bias_f
# 0          catboost      1     31  1.197349  1.587689  0.454584
# 1          catboost      2     28  1.363405  1.687484  0.329992
# 2          catboost      3     30  1.706382  2.135975  0.796718
# 3          catboost      4     29  1.166289  1.570732 -0.242847
# 4          catboost      5     31  1.372013  2.073485  0.031408
# 5          catboost      6     21  1.478312  1.735074  0.075332
# 6           gfs_raw      1     31  2.272084  2.918034  1.454306
# 7           gfs_raw      2     28  2.593110  3.145965  2.344093
# 8           gfs_raw      3     30  2.316502  3.900639  1.927191
# 9           gfs_raw      4     29  2.979966  3.917502  1.035080
# 10          gfs_raw      5     31  2.462938  3.057074 -1.313341
# 11          gfs_raw      6     21  2.772160  3.766890 -1.882365
# 12         hrrr_raw      1     31  5.097723  5.694206  5.049364
# 13         hrrr_raw      2     28  5.920618  6.503826  5.863340
# 14         hrrr_raw      3     30  6.576098  7.210073  6.153609
# 15         hrrr_raw      4     29  3.755997  4.410109  3.527816
# 16         hrrr_raw      5     31  3.868945  4.347534  3.544661
# 17         hrrr_raw      6     21  4.175339  4.465224  4.175339
# 18         lightgbm      1     31  1.197871  1.568054  0.163095
# 19         lightgbm      2     28  1.364286  1.644430  0.385984
# 20         lightgbm      3     30  1.717644  2.184458  0.156844
# 21         lightgbm      4     29  1.120056  1.499444 -0.428890
# 22         lightgbm      5     31  1.437968  2.023524 -0.360762
# 23         lightgbm      6     21  1.377507  1.851508 -0.245878
# 24          nbm_raw      1     31  2.297808  3.062490  1.490712
# 25          nbm_raw      2     28  1.700431  2.032226  0.986146
# 26          nbm_raw      3     30  2.190935  3.409878  0.707346
# 27          nbm_raw      4     29  1.624618  2.487355 -0.159503
# 28          nbm_raw      5     31  2.302316  2.748128  1.340644
# 29          nbm_raw      6     21  2.124280  2.758901  1.330953
# 30    provider_mean      1     31  3.035519  3.483475  2.664794
# 31    provider_mean      2     28  3.086386  3.616570  3.064526
# 32    provider_mean      3     30  3.201143  4.272842  2.929382
# 33    provider_mean      4     29  2.180801  3.090271  1.467798
# 34    provider_mean      5     31  1.893032  2.356121  1.190655
# 35    provider_mean      6     21  1.939093  2.346607  1.207976
# 36  provider_median      1     31  2.393357  2.984986  1.813582
# 37  provider_median      2     28  2.587368  3.146662  2.336346
# 38  provider_median      3     30  2.695185  4.114605  1.986193
# 39  provider_median      4     29  2.354510  3.278241  1.208679
# 40  provider_median      5     31  2.272063  2.684389  1.418412
# 41  provider_median      6     21  2.217485  2.763204  1.434635
# 42      ridge_stack      1     31  1.260434  1.618437  0.369082
# 43      ridge_stack      2     28  1.285303  1.612593  0.440450
# 44      ridge_stack      3     30  1.621561  2.114698  0.618336
# 45      ridge_stack      4     29  1.112129  1.511494 -0.207428
# 46      ridge_stack      5     31  1.399774  2.026559  0.143983
# 47      ridge_stack      6     21  1.341366  1.656625  0.240535
# 48          xgboost      1     31  1.266447  1.652368 -0.059791
# 49          xgboost      2     28  1.168113  1.527499  0.028531
# 50          xgboost      3     30  1.618946  2.087564 -0.003191
# 51          xgboost      4     29  1.349603  1.702040 -0.710206
# 52          xgboost      5     31  1.506556  2.060733 -0.330811
# 53          xgboost      6     21  1.312752  1.661347 -0.245984

# %% [markdown]
# ## Performance by Warm/Cool 11 AM Forecast Delta

# %%
delta_by_date = result.features[[
    "contract_date",
    "v11sf_forecast_temp_11am_minus_observed_f",
]].copy()
delta_predictions = result.test_predictions.merge(delta_by_date, on="contract_date", how="left")
delta_predictions["forecast_temp_delta_bucket"] = pd.cut(
    delta_predictions["v11sf_forecast_temp_11am_minus_observed_f"],
    bins=[-np.inf, -2.0, -0.5, 0.5, 2.0, np.inf],
    labels=["cool_gt_2f", "cool_0.5_to_2f", "near_match", "warm_0.5_to_2f", "warm_gt_2f"],
)
warm_cool_metrics = (
    delta_predictions.dropna(subset=["forecast_temp_delta_bucket", "error_f"])
    .groupby(["method", "forecast_temp_delta_bucket"], observed=True, as_index=False)
    .agg(count=("error_f", "size"), mae_f=("absolute_error_f", "mean"), bias_f=("error_f", "mean"))
)
warm_cool_metrics.to_csv(config.resolved_output_dir() / f"{STATION_ID}_warm_cool_delta_metrics.csv", index=False)
warm_cool_metrics
# Out:
#              method forecast_temp_delta_bucket  count     mae_f    bias_f
# 0          catboost                 cool_gt_2f     44  1.447820  0.297626
# 1          catboost             cool_0.5_to_2f     61  1.337656  0.450931
# 2          catboost                 near_match     30  1.342637  0.183679
# 3          catboost             warm_0.5_to_2f     27  1.295239  0.369115
# 4          catboost                 warm_gt_2f      8  1.666542 -1.666542
# 5           gfs_raw                 cool_gt_2f     44  2.320652  1.990974
# 6           gfs_raw             cool_0.5_to_2f     61  2.575091  0.574414
# 7           gfs_raw                 near_match     30  1.737724  0.214046
# 8           gfs_raw             warm_0.5_to_2f     27  2.405779  0.065448
# 9           gfs_raw                 warm_gt_2f      8  7.155651 -1.565332
# 10         hrrr_raw                 cool_gt_2f     44  5.681803  5.513503
# 11         hrrr_raw             cool_0.5_to_2f     61  4.816010  4.775554
# 12         hrrr_raw                 near_match     30  4.264444  4.081129
# 13         hrrr_raw             warm_0.5_to_2f     27  5.110833  4.641401
# 14         hrrr_raw                 warm_gt_2f      8  3.491401  2.941342
# 15         lightgbm                 cool_gt_2f     44  1.453264  0.073782
# 16         lightgbm             cool_0.5_to_2f     61  1.362766  0.028426
# 17         lightgbm                 near_match     30  1.188745 -0.183390
# 18         lightgbm             warm_0.5_to_2f     27  1.269081  0.302035
# 19         lightgbm                 warm_gt_2f      8  1.981209 -1.981209
# 20          nbm_raw                 cool_gt_2f     44  2.249912  1.607916
# 21          nbm_raw             cool_0.5_to_2f     61  1.785699  0.942561
# 22          nbm_raw                 near_match     30  1.410870  0.232474
# 23          nbm_raw             warm_0.5_to_2f     27  2.273411  0.999484
# 24          nbm_raw                 warm_gt_2f      8  4.504478 -0.284484
# 25    provider_mean                 cool_gt_2f     44  3.194849  3.037464
# 26    provider_mean             cool_0.5_to_2f     61  2.373537  2.097510
# 27    provider_mean                 near_match     30  1.820746  1.509216
# 28    provider_mean             warm_0.5_to_2f     27  2.348047  1.902111
# 29    provider_mean                 warm_gt_2f      8  4.477953  0.363842
# 30  provider_median                 cool_gt_2f     44  2.736250  2.526214
# 31  provider_median             cool_0.5_to_2f     61  2.206821  1.730982
# 32  provider_median                 near_match     30  1.661462  1.032189
# 33  provider_median             warm_0.5_to_2f     27  2.478296  1.472154
# 34  provider_median                 warm_gt_2f      8  5.126110  0.364650
# 35      ridge_stack                 cool_gt_2f     44  1.432289  0.362173
# 36      ridge_stack             cool_0.5_to_2f     61  1.318799  0.361849
# 37      ridge_stack                 near_match     30  1.223352  0.129300
# 38      ridge_stack             warm_0.5_to_2f     27  1.294662  0.559218
# 39      ridge_stack                 warm_gt_2f      8  1.549787 -1.395348
# 40          xgboost                 cool_gt_2f     44  1.480088 -0.109351
# 41          xgboost             cool_0.5_to_2f     61  1.351189 -0.210725
# 42          xgboost                 near_match     30  1.294634 -0.375083
# 43          xgboost             warm_0.5_to_2f     27  1.256328  0.199618
# 44          xgboost                 warm_gt_2f      8  1.704832 -1.704832

# %% [markdown]
# ## Common-Date Comparison with Existing V11 Settlement Fix

# %%
baseline_path = (
    PROJECT_ROOT
    / "data"
    / "calibration"
    / "station_stacking_v11_settlement_fix"
    / f"{STATION_ID}_year_split_test_predictions.csv"
)
baseline_predictions = pd.read_csv(baseline_path)
baseline_predictions["contract_date"] = baseline_predictions["contract_date"].astype(str).str[:10]
v20_predictions = result.test_predictions.copy()
v20_predictions["contract_date"] = v20_predictions["contract_date"].astype(str).str[:10]
comparison = baseline_predictions.merge(
    v20_predictions,
    on=["contract_date", "method"],
    suffixes=("_baseline", "_v20"),
)
comparison["baseline_abs_error_f"] = (
    pd.to_numeric(comparison["actual_high_f_baseline"], errors="coerce")
    - pd.to_numeric(comparison["predicted_high_f_baseline"], errors="coerce")
).abs()
comparison["v20_abs_error_f"] = (
    pd.to_numeric(comparison["actual_high_f_v20"], errors="coerce")
    - pd.to_numeric(comparison["predicted_high_f_v20"], errors="coerce")
).abs()
common_date_comparison = (
    comparison.groupby("method", as_index=False)
    .agg(
        common_date_count=("contract_date", "size"),
        baseline_mae_f=("baseline_abs_error_f", "mean"),
        v20_mae_f=("v20_abs_error_f", "mean"),
        v20_better_days=("v20_abs_error_f", lambda values: int((values < comparison.loc[values.index, "baseline_abs_error_f"]).sum())),
        baseline_better_days=("v20_abs_error_f", lambda values: int((values > comparison.loc[values.index, "baseline_abs_error_f"]).sum())),
    )
)
common_date_comparison["v20_delta_mae_f"] = common_date_comparison["v20_mae_f"] - common_date_comparison["baseline_mae_f"]
common_date_comparison.to_csv(config.resolved_output_dir() / f"{STATION_ID}_v11_common_date_comparison.csv", index=False)
common_date_comparison.sort_values("v20_delta_mae_f")
# Out:
#             method  common_date_count  baseline_mae_f  v20_mae_f  \
# 1          gfs_raw                170        2.550131   2.550131
# 2         hrrr_raw                170        4.927253   4.927253
# 5    provider_mean                170        2.583543   2.583543
# 4          nbm_raw                170        2.045105   2.045105
# 6  provider_median                170        2.428105   2.428105
# 3         lightgbm                170        1.344043   1.369703
# 0         catboost                170        1.343391   1.375788
# 7      ridge_stack                170        1.300208   1.338366
# 8          xgboost                170        1.326717   1.376147
#
#    v20_better_days  baseline_better_days  v20_delta_mae_f
# 1                0                     0         0.000000
# 2                0                     0         0.000000
# 5                2                     6         0.000000
# 4                0                     0         0.000000
# 6                0                     0         0.000000
# 3               78                    87         0.025661
# 0               73                    93         0.032397
# 7               67                   103         0.038158
# 8               74                    89         0.049429

# %% [markdown]
# ## V20 Peak-Timing Feature Coverage

# %%
v20_feature_columns = [*V20_PEAK_TIMING_RAW_FEATURE_COLUMNS, *V20_ENGINEERED_FEATURE_COLUMNS]
v20_feature_coverage = (
    result.features[v20_feature_columns]
    .notna().mean().mul(100)
    .rename("coverage_pct").reset_index().rename(columns={"index": "feature"})
)
v20_feature_coverage.to_csv(
    config.resolved_output_dir() / f"{STATION_ID}_v20_peak_feature_coverage.csv", index=False
)
v20_feature_coverage.sort_values("coverage_pct")
# Out:
#                                               feature  coverage_pct
# 5                        nbm_cooling_onset_hour_local     92.083127
# 30                v20_nbm_observation_adjusted_high_f     98.861950
# 26                       v20_nbm_t11_minus_observed_f     98.861950
# 25                      v20_hrrr_t11_minus_observed_f     98.911430
# 29               v20_hrrr_observation_adjusted_high_f     98.911430
# 31                           v20_adjusted_high_mean_f     98.911430
# 32                         v20_adjusted_high_spread_f     98.911430
# 2                               nbm_hour_of_max_local     99.950520
# 17               hrrr_precip_wet_hours_11_to_nbm_peak     99.950520
# 22                    hrrr_tcc_11_to_nbm_peak_max_pct     99.950520
# 16                hrrr_precip_total_11_to_nbm_peak_mm     99.950520
# 1                                    nbm_max_post11_f     99.950520
# 3                                   nbm_slope_11_14_f     99.950520
# 4                                   nbm_slope_14_17_f     99.950520
# 13             hrrr_solar_energy_11_to_nbm_peak_wh_m2     99.950520
# 0                                          nbm_t11l_f     99.950520
# 28                           v20_nbm_remaining_rise_f     99.950520
# 24                   hrrr_lcc_11_to_nbm_peak_mean_pct     99.950520
# 23                  hrrr_blcc_11_to_nbm_peak_mean_pct     99.950520
# 21                   hrrr_tcc_11_to_nbm_peak_mean_pct     99.950520
# 40                           v20_rain_before_nbm_peak     99.950520
# 34                           v20_peak_hour_difference     99.950520
# 33                        v20_model_high_difference_f     99.950520
# 15              hrrr_precip_wet_hours_11_to_hrrr_peak    100.000000
# 6                                         hrrr_t11l_f    100.000000
# 14               hrrr_precip_total_11_to_hrrr_peak_mm    100.000000
# 12            hrrr_solar_energy_11_to_hrrr_peak_wh_m2    100.000000
# 11                            hrrr_slope_14_to_peak_f    100.000000
# 9                             hrrr_peak_at_window_end    100.000000
# 10                                 hrrr_slope_11_14_f    100.000000
# 8                              hrrr_hour_of_max_local    100.000000
# 7                                   hrrr_max_post11_f    100.000000
# 27                          v20_hrrr_remaining_rise_f    100.000000
# 18                               hrrr_no_precip_11_18    100.000000
# 19                  hrrr_tcc_11_to_hrrr_peak_mean_pct    100.000000
# 20                   hrrr_tcc_11_to_hrrr_peak_max_pct    100.000000
# 36                       v20_solar_energy_15_18_wh_m2    100.000000
# 37                 v20_tcc_change_11_to_hrrr_peak_pct    100.000000
# 38                  v20_tcc_change_11_to_nbm_peak_pct    100.000000
# 35                       v20_solar_energy_11_14_wh_m2    100.000000
# 39                          v20_rain_before_hrrr_peak    100.000000
# 41                             v20_rain_present_11_18    100.000000
# 42  v20_precip_onset_minus_hrrr_peak_hours_zero_fi...    100.000000
# 43  v20_precip_onset_minus_nbm_peak_hours_zero_filled    100.000000

# %% [markdown]
# ## Fold Metrics and Peak-Feature Importance

# %%
fold_metrics = (
    result.validation_predictions.groupby(["fold", "method"], as_index=False)
    .agg(count=("absolute_error_f", "size"), mae_f=("absolute_error_f", "mean"), bias_f=("error_f", "mean"))
)
peak_feature_importance = result.feature_importance.loc[
    result.feature_importance["feature"].isin(v20_feature_columns)
].sort_values(["method", "importance_mean_mae_f"], ascending=[True, False])
fold_metrics.to_csv(config.resolved_output_dir() / f"{STATION_ID}_fold_metrics.csv", index=False)
fold_metrics, peak_feature_importance
# Out:
# (                      fold           method  count     mae_f    bias_f
#  0   fold_2021_2022_to_2023         catboost    363  1.396980 -0.579171
#  1   fold_2021_2022_to_2023          gfs_raw    363  3.028109 -0.132348
#  2   fold_2021_2022_to_2023         hrrr_raw    363  5.080056  4.869236
#  3   fold_2021_2022_to_2023         lightgbm    363  1.396931 -0.622360
#  4   fold_2021_2022_to_2023          nbm_raw    363  2.039734  0.963740
#  5   fold_2021_2022_to_2023    provider_mean    363  2.672864  1.900209
#  6   fold_2021_2022_to_2023  provider_median    363  2.277639  1.410090
#  7   fold_2021_2022_to_2023          xgboost    363  1.378467 -0.676461
#  8   fold_2021_2023_to_2024         catboost    364  1.257373 -0.157357
#  9   fold_2021_2023_to_2024          gfs_raw    364  2.468857  0.110129
#  10  fold_2021_2023_to_2024         hrrr_raw    364  4.475751  4.295993
#  11  fold_2021_2023_to_2024         lightgbm    364  1.265839 -0.301960
#  12  fold_2021_2023_to_2024          nbm_raw    364  1.880132  1.016588
#  13  fold_2021_2023_to_2024    provider_mean    364  2.436153  1.807570
#  14  fold_2021_2023_to_2024  provider_median    364  2.037473  1.335194
#  15  fold_2021_2023_to_2024          xgboost    364  1.240117 -0.226788
#  16  fold_2021_2024_to_2025         catboost    364  1.286190  0.001535
#  17  fold_2021_2024_to_2025          gfs_raw    364  2.820566 -0.746663
#  18  fold_2021_2024_to_2025         hrrr_raw    364  4.609335  4.461602
#  19  fold_2021_2024_to_2025         lightgbm    364  1.297520 -0.107165
#  20  fold_2021_2024_to_2025          nbm_raw    364  1.885549  0.934016
#  21  fold_2021_2024_to_2025    provider_mean    364  2.308677  1.549652
#  22  fold_2021_2024_to_2025  provider_median    364  2.031523  1.233092
#  23  fold_2021_2024_to_2025          xgboost    364  1.346496 -0.405975
#  24       fold_2021_to_2022         catboost    361  1.509764 -0.126345
#  25       fold_2021_to_2022          gfs_raw    361  3.857138  1.936825
#  26       fold_2021_to_2022         hrrr_raw    361  5.540105  5.394762
#  27       fold_2021_to_2022         lightgbm    361  1.599708 -0.442619
#  28       fold_2021_to_2022          nbm_raw    361  2.510377  2.031433
#  29       fold_2021_to_2022    provider_mean    361  3.458945  3.121007
#  30       fold_2021_to_2022  provider_median    361  3.037298  2.725399
#  31       fold_2021_to_2022          xgboost    361  1.496673 -0.284758,
#         method param_key                                            feature  \
#  9    catboost  trial_26                                  nbm_slope_11_14_f
#  17   catboost  trial_26                           v20_nbm_remaining_rise_f
#  21   catboost  trial_26                                 hrrr_slope_11_14_f
#  33   catboost  trial_26                              nbm_hour_of_max_local
#  34   catboost  trial_26             hrrr_solar_energy_11_to_nbm_peak_wh_m2
#  ..        ...       ...                                                ...
#  272   xgboost  trial_20  v20_precip_onset_minus_hrrr_peak_hours_zero_fi...
#  276   xgboost  trial_20                       v20_solar_energy_15_18_wh_m2
#  279   xgboost  trial_20                  hrrr_tcc_11_to_hrrr_peak_mean_pct
#  280   xgboost  trial_20                  hrrr_blcc_11_to_nbm_peak_mean_pct
#  281   xgboost  trial_20                   hrrr_tcc_11_to_nbm_peak_mean_pct
#
#       importance_mean_mae_f  importance_std_mae_f  n_repeats  train_start_year  \
#  9                 0.151671              0.029350         10              2021
#  17                0.052161              0.021912         10              2021
#  21                0.037062              0.025473         10              2021
#  33                0.017485              0.008249         10              2021
#  34                0.016662              0.005333         10              2021
#  ..                     ...                   ...        ...               ...
#  272              -0.004319              0.002482         10              2021
#  276              -0.005974              0.006959         10              2021
#  279              -0.008987              0.006290         10              2021
#  280              -0.012739              0.008136         10              2021
#  281              -0.022106              0.007674         10              2021
#
#       train_end_year  test_year  train_rows  test_rows
#  9              2025       2026        1811        170
#  17             2025       2026        1811        170
#  21             2025       2026        1811        170
#  33             2025       2026        1811        170
#  34             2025       2026        1811        170
#  ..              ...        ...         ...        ...
#  272            2025       2026        1811        170
#  276            2025       2026        1811        170
#  279            2025       2026        1811        170
#  280            2025       2026        1811        170
#  281            2025       2026        1811        170
#
#  [129 rows x 11 columns])

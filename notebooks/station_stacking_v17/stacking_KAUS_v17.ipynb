# %% [markdown]
# # Station Stacking v17 - KAUS
#
# Experimental notebook for `KAUS`.
#
# V17 is the importance-pruned experiment: only the KATL v16 fused features with `max_importance_mae_f >= 0.015`.

# %%
from pathlib import Path
import os
import sys
import warnings

warnings.filterwarnings("ignore", message="IProgress not found.*")
warnings.filterwarnings("ignore", message="Skipping features without any observed values.*")

PROJECT_ROOT = Path.cwd().resolve()
while not (PROJECT_ROOT / "src" / "calibration" / "station_stacking.py").exists():
    if PROJECT_ROOT.parent == PROJECT_ROOT:
        raise RuntimeError("Could not find project root containing src/calibration/station_stacking.py")
    PROJECT_ROOT = PROJECT_ROOT.parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

os.environ["WEATHER_RESEARCH_INCLUDE_DIRECT_NBM"] = "1"

STATION_ID = "KAUS"
PROVIDERS = ("gfs", "hrrr", "nbm")
TIMING_MODE = "same_day_11am_live_safe"
TARGET_SOURCE = "iem_hourly"
FAST_MODE = False
OPTUNA_TRIALS = 30
STACK_OPTUNA_TRIALS = 30
OPTUNA_STARTUP_TRIALS = 15
STACK_OPTUNA_STARTUP_TRIALS = 15
OPTUNA_METRIC = "mae_f"
OPTUNA_VERBOSE = True
EXPORT_MODEL_WEIGHTS = True
OUTPUT_DIR = PROJECT_ROOT / "data" / "calibration" / "station_stacking_v17"
V15_OUTPUT_DIR = PROJECT_ROOT / "data" / "calibration" / "station_stacking_v15"
V16_OUTPUT_DIR = PROJECT_ROOT / "data" / "calibration" / "station_stacking_v16"
MODEL_VERSION = "station_high_regressor_v17_importance_015_stack"

PROJECT_ROOT
# Out:
# WindowsPath('D:/dev/weather-research')

# %%
import numpy as np
import pandas as pd

from scripts.run_station_stacking_v17 import write_reference_comparisons
from src.export_station_stacking_v2_models import export_station_model_weights
from src.calibration.station_stacking import (
    StationStackingConfig,
    V17_ADDITIONAL_FEATURE_COLUMNS,
    V17_DROPPED_FEATURE_COLUMNS,
    V17_IMPORTANCE_015_FEATURE_COLUMNS,
    YEAR_SPLIT_EXPANDING_FOLDS,
    missing_model_dependencies,
    provider_availability,
    run_station_year_split_experiment,
)

# %% [markdown]
# ## V17 Contract
#
# `feature_version="v17_importance_015"` uses only the 17-feature allowlist from the KATL v16 fused importance summary. The single v13 weather interaction is kept only when train-year coverage passes.

# %%
fold_spec = pd.DataFrame(
    [
        {
            "fold": fold.name,
            "train_start_year": fold.train_start_year,
            "train_end_year": fold.train_end_year,
            "validation_year": fold.validation_year,
        }
        for fold in YEAR_SPLIT_EXPANDING_FOLDS
    ]
)

{
    "folds": fold_spec,
    "v17_feature_count": len(V17_IMPORTANCE_015_FEATURE_COLUMNS),
    "v17_features": V17_IMPORTANCE_015_FEATURE_COLUMNS,
    "v17_coverage_gated_features": V17_ADDITIONAL_FEATURE_COLUMNS,
    "v17_dropped_features": sorted(V17_DROPPED_FEATURE_COLUMNS),
}
# Out:
# {'folds':                      fold  train_start_year  train_end_year  validation_year
#  0  fold_2021_2023_to_2024              2021            2023             2024
#  1  fold_2021_2024_to_2025              2021            2024             2025,
#  'v17_feature_count': 17,
#  'v17_features': ['nbm_high_minus_observed_high_temp_f',
#   'v8_provider_median_remaining_from_high_so_far_f',
#   'observed_high_so_far_change_since_9am_f',
#   'nbm_high_minus_observed_temp_f',
#   'v3_remaining_warmup_per_spread_f',
#   'v8_provider_max_remaining_from_high_so_far_f',
#   'v8_provider_mean_remaining_vs_month_normal_f',
#   'hrrr_high_minus_observed_high_temp_f',
#   'observed_high_temp_minus_temp_at_as_of_f',
#   'gfs_high_minus_observed_high_temp_f',
#   'observed_cloud_cover_at_as_of',
#   'v3_remaining_warmup_from_high_so_far_f',
#   'v3_humidity_remaining_warmup_interaction',
#   'v13_forecast_temp_bias_remaining_warmup_interaction',
#   'gfs_high_minus_observed_temp_f',
#   'hrrr_rolling_bias_30d_f',
#   'observed_temp_change_last_3h_f'],
#  'v17_coverage_gated_features': ['v13_forecast_temp_bias_remaining_warmup_interaction'],
#  'v17_dropped_features': ['actual_minus_climatology_10y_f_DIAGNOSTIC_ONLY',
#   'climatology_source_end_year',
#   'climatology_source_start_year',
#   'gfs_as_of_hour_local',
#   'gfs_available',
#   'gfs_forecast_window_hours',
#   'gfs_grid_dist_km_mean',
#   'gfs_horizon_hours',
#   'gfs_hrrr_grid_dist_km_mean_abs_diff_f',
#   'gfs_hrrr_grid_dist_km_mean_diff_f',
#   'gfs_issue_hour_utc',
#   'gfs_missing',
#   'hrrr_as_of_hour_local',
#   'hrrr_available',
#   'hrrr_forecast_hour_max',
#   'hrrr_forecast_hour_min',
#   'hrrr_forecast_lead_hours',
#   'hrrr_forecast_window_hours',
#   'hrrr_grid_dist_km_mean',
#   'hrrr_horizon_hours',
#   'hrrr_issue_hour_local',
#   'hrrr_issue_hour_utc',
#   'hrrr_missing',
#   'is_active_polymarket_station',
#   'lat',
#   'lon',
#   'nbm_as_of_hour_local',
#   'nbm_available',
#   'nbm_forecast_window_hours',
#   'nbm_horizon_hours',
#   'nbm_issue_hour_local',
#   'nbm_issue_hour_utc',
#   'nbm_missing',
#   'observed_fetch_status',
#   'observed_observation_type',
#   'observed_pressure_source',
#   'provider_count_available',
#   'year']}

# %% [markdown]
# ## Data Availability

# %%
availability = provider_availability(
    PROJECT_ROOT,
    timing_mode=TIMING_MODE,
    providers=PROVIDERS,
)

availability.loc[availability["station_id"].eq(STATION_ID)]
# Out:
#   station_id provider  row_count first_contract_date last_contract_date
# 3       KAUS      gfs       1992          2021-01-01         2026-06-21
# 4       KAUS     hrrr       1998          2021-01-01         2026-06-21
# 5       KAUS      nbm       1997          2021-01-01         2026-06-21

# %% [markdown]
# ## Run Importance-Pruned Model

# %%
missing_packages = missing_model_dependencies()
if missing_packages:
    raise ImportError(
        "Missing station-stacking ML packages: "
        + ", ".join(missing_packages)
        + ". Install them with: python -m pip install -r requirements.txt"
    )

config = StationStackingConfig(
    station_id=STATION_ID,
    project_root=PROJECT_ROOT,
    timing_mode=TIMING_MODE,
    providers=PROVIDERS,
    fast_mode=FAST_MODE,
    optuna_trials=OPTUNA_TRIALS,
    stack_optuna_trials=STACK_OPTUNA_TRIALS,
    optuna_startup_trials=OPTUNA_STARTUP_TRIALS,
    stack_optuna_startup_trials=STACK_OPTUNA_STARTUP_TRIALS,
    optuna_metric=OPTUNA_METRIC,
    optuna_verbose=OPTUNA_VERBOSE,
    feature_version="v17_importance_015",
    target_mode="remaining_warmup",
    target_source=TARGET_SOURCE,
    base_model_methods=("xgboost", "lightgbm", "catboost"),
    stack_enabled=True,
    hyperparameter_space="wide",
    year_split_folds=YEAR_SPLIT_EXPANDING_FOLDS,
    year_split_test_train_years=(2021, 2025),
    year_split_test_year=2026,
    output_dir=OUTPUT_DIR / "importance_015",
    climatology_normals_path=PROJECT_ROOT / "data" / "calibration" / "station_stacking_v9" / "station_rolling_10y_daily_high_normals.csv",
)

config.resolved_optuna_storage_path()
# Out:
# WindowsPath('D:/dev/weather-research/data/calibration/station_stacking_v17/importance_015/KAUS_optuna.sqlite3')

# %%
result = run_station_year_split_experiment(config)
result.scoreboard
# Out:
# D:\dev\weather-research\src\calibration\station_stacking.py:2711: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[f"{prefix}_{feature_name}_abs_diff_f"] = (left_values - right_values).abs()
# D:\dev\weather-research\src\calibration\station_stacking.py:2710: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[f"{prefix}_{feature_name}_diff_f"] = left_values - right_values
# D:\dev\weather-research\src\calibration\station_stacking.py:2711: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[f"{prefix}_{feature_name}_abs_diff_f"] = (left_values - right_values).abs()
# D:\dev\weather-research\src\calibration\station_stacking.py:2710: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[f"{prefix}_{feature_name}_diff_f"] = left_values - right_values
# D:\dev\weather-research\src\calibration\station_stacking.py:2711: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[f"{prefix}_{feature_name}_abs_diff_f"] = (left_values - right_values).abs()
# D:\dev\weather-research\src\calibration\station_stacking.py:2710: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[f"{prefix}_{feature_name}_diff_f"] = left_values - right_values
# D:\dev\weather-research\src\calibration\station_stacking.py:2711: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[f"{prefix}_{feature_name}_abs_diff_f"] = (left_values - right_values).abs()
# D:\dev\weather-research\src\calibration\station_stacking.py:2710: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[f"{prefix}_{feature_name}_diff_f"] = left_values - right_values
# D:\dev\weather-research\src\calibration\station_stacking.py:2711: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[f"{prefix}_{feature_name}_abs_diff_f"] = (left_values - right_values).abs()
# D:\dev\weather-research\src\calibration\station_stacking.py:2710: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[f"{prefix}_{feature_name}_diff_f"] = left_values - right_values
# D:\dev\weather-research\src\calibration\station_stacking.py:2711: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[f"{prefix}_{feature_name}_abs_diff_f"] = (left_values - right_values).abs()
# D:\dev\weather-research\src\calibration\station_stacking.py:2710: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[f"{prefix}_{feature_name}_diff_f"] = left_values - right_values
# D:\dev\weather-research\src\calibration\station_stacking.py:2711: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[f"{prefix}_{feature_name}_abs_diff_f"] = (left_values - right_values).abs()
# D:\dev\weather-research\src\calibration\station_stacking.py:2710: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[f"{prefix}_{feature_name}_diff_f"] = left_values - right_values
# D:\dev\weather-research\src\calibration\station_stacking.py:2711: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[f"{prefix}_{feature_name}_abs_diff_f"] = (left_values - right_values).abs()
# D:\dev\weather-research\src\calibration\station_stacking.py:2710: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[f"{prefix}_{feature_name}_diff_f"] = left_values - right_values
# D:\dev\weather-research\src\calibration\station_stacking.py:2711: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[f"{prefix}_{feature_name}_abs_diff_f"] = (left_values - right_values).abs()
# D:\dev\weather-research\src\calibration\station_stacking.py:2710: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[f"{prefix}_{feature_name}_diff_f"] = left_values - right_values
# D:\dev\weather-research\src\calibration\station_stacking.py:2711: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[f"{prefix}_{feature_name}_abs_diff_f"] = (left_values - right_values).abs()
# D:\dev\weather-research\src\calibration\station_stacking.py:2710: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[f"{prefix}_{feature_name}_diff_f"] = left_values - right_values
# D:\dev\weather-research\src\calibration\station_stacking.py:2711: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[f"{prefix}_{feature_name}_abs_diff_f"] = (left_values - right_values).abs()
# D:\dev\weather-research\src\calibration\station_stacking.py:2710: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[f"{prefix}_{feature_name}_diff_f"] = left_values - right_values
# D:\dev\weather-research\src\calibration\station_stacking.py:2711: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[f"{prefix}_{feature_name}_abs_diff_f"] = (left_values - right_values).abs()
# D:\dev\weather-research\src\calibration\station_stacking.py:2710: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[f"{prefix}_{feature_name}_diff_f"] = left_values - right_values
# D:\dev\weather-research\src\calibration\station_stacking.py:2711: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[f"{prefix}_{feature_name}_abs_diff_f"] = (left_values - right_values).abs()
# [I 2026-06-30 00:38:08,477] A new study created in RDB with name: KAUS_v17_importance_015_remaining_warmup_base_xgboost_mae_f
# [I 2026-06-30 00:38:14,225] Trial 0 finished with value: 12.174661872481899 and parameters: {'n_estimators': 1342, 'learning_rate': 0.19043899115982607, 'max_depth': 9, 'min_child_weight': 2.481040974867813, 'gamma': 2.340279606636548, 'subsample': 0.4513964382185317, 'colsample_bytree': 0.3877543479093296, 'reg_alpha': 2.478071022662141, 'reg_lambda': 0.6132587025321562}. Best is trial 0 with value: 12.174661872481899.
# [I 2026-06-30 00:38:15,412] Trial 1 finished with value: 12.174661872481899 and parameters: {'n_estimators': 2493, 'learning_rate': 0.001120367191095075, 'max_depth': 12, 'min_child_weight': 21.368329072358772, 'gamma': 3.185086660174142, 'subsample': 0.4681862286846154, 'colsample_bytree': 0.46921293140473197, 'reg_alpha': 4.476173538513514e-07, 'reg_lambda': 0.20253776634919213}. Best is trial 0 with value: 12.174661872481899.
# [I 2026-06-30 00:38:28,890] Trial 2 finished with value: 1.9407679048965991 and parameters: {'n_estimators': 1540, 'learning_rate': 0.004992867109217114, 'max_depth': 8, 'min_child_weight': 0.03613894271216528, 'gamma': 4.3821697280282725, 'subsample': 0.5881351981408995, 'colsample_bytree': 0.6464454897410734, 'reg_alpha': 0.26430874752361627, 'reg_lambda': 0.0018119678627933364}. Best is trial 2 with value: 1.9407679048965991.
# [I 2026-06-30 00:38:30,250] Trial 3 finished with value: 12.174661872481899 and parameters: {'n_estimators': 1824, 'learning_rate': 0.026337502897485255, 'max_depth': 1, 'min_child_weight': 2.69264691008618, 'gamma': 2.557861855309373, 'subsample': 0.39228353544043165, 'colsample_bytree': 0.9667755992146666, 'reg_alpha': 38.6887231523051, 'reg_lambda': 12.408975837016275}. Best is trial 2 with value: 1.9407679048965991.
# [I 2026-06-30 00:38:40,022] Trial 4 finished with value: 1.7860594246406483 and parameters: {'n_estimators': 1101, 'learning_rate': 0.0017147936629846843, 'max_depth': 9, 'min_child_weight': 0.5762487216478605, 'gamma': 1.8305735226716824, 'subsample': 0.6718649915723256, 'colsample_bytree': 0.37235253872489193, 'reg_alpha': 8.162906555194692, 'reg_lambda': 0.004271500153828077}. Best is trial 4 with value: 1.7860594246406483.
# [I 2026-06-30 00:38:52,378] Trial 5 finished with value: 1.7008460332874376 and parameters: {'n_estimators': 2336, 'learning_rate': 0.00559067775661512, 'max_depth': 7, 'min_child_weight': 1.5375920235481764, 'gamma': 2.7728168328829055, 'subsample': 0.980230008046963, 'colsample_bytree': 0.8538363351847245, 'reg_alpha': 18.792618557420877, 'reg_lambda': 43.484449457612314}. Best is trial 5 with value: 1.7008460332874376.
# [I 2026-06-30 00:38:54,198] Trial 6 finished with value: 1.7005288028603396 and parameters: {'n_estimators': 2113, 'learning_rate': 0.16240489353272883, 'max_depth': 2, 'min_child_weight': 0.06080390190296603, 'gamma': 0.678409333658071, 'subsample': 0.5614647149961218, 'colsample_bytree': 0.6026402382981633, 'reg_alpha': 1.8037999945880162e-07, 'reg_lambda': 16.668629892722056}. Best is trial 6 with value: 1.7005288028603396.
# [I 2026-06-30 00:38:55,953] Trial 7 pruned.
# [I 2026-06-30 00:38:56,719] Trial 8 pruned.
# [I 2026-06-30 00:39:10,198] Trial 9 finished with value: 1.7591843507119285 and parameters: {'n_estimators': 2201, 'learning_rate': 0.006215464818952927, 'max_depth': 1, 'min_child_weight': 0.17535949529764422, 'gamma': 4.877749830401205, 'subsample': 0.8242440159197416, 'colsample_bytree': 0.7644123563808884, 'reg_alpha': 4.4315220126915325, 'reg_lambda': 0.09450187118503514}. Best is trial 6 with value: 1.7005288028603396.
# [I 2026-06-30 00:39:11,243] Trial 10 pruned.
# [I 2026-06-30 00:39:14,807] Trial 11 pruned.
# [I 2026-06-30 00:39:19,612] Trial 12 pruned.
# [I 2026-06-30 00:39:20,381] Trial 13 pruned.
# [I 2026-06-30 00:39:22,939] Trial 14 finished with value: 1.6695272515089545 and parameters: {'n_estimators': 2872, 'learning_rate': 0.11587248002108354, 'max_depth': 1, 'min_child_weight': 1.1040511903162256, 'gamma': 6.261165047231685, 'subsample': 0.49437007680597467, 'colsample_bytree': 0.4279124887668938, 'reg_alpha': 1.125594744942969e-06, 'reg_lambda': 87.35792858155622}. Best is trial 14 with value: 1.6695272515089545.
# [I 2026-06-30 00:39:30,840] Trial 15 finished with value: 1.653642187505772 and parameters: {'n_estimators': 3311, 'learning_rate': 0.04016687409111762, 'max_depth': 3, 'min_child_weight': 0.012905294825774771, 'gamma': 0.18586716971939637, 'subsample': 0.5599207159834859, 'colsample_bytree': 0.5396163811224401, 'reg_alpha': 0.0016913438352762248, 'reg_lambda': 131.8838700608262}. Best is trial 15 with value: 1.653642187505772.
# [I 2026-06-30 00:39:39,470] Trial 16 finished with value: 1.6910272323028808 and parameters: {'n_estimators': 3332, 'learning_rate': 0.031184182180475774, 'max_depth': 4, 'min_child_weight': 0.016581267455563507, 'gamma': 7.515853622869325, 'subsample': 0.7245159430745359, 'colsample_bytree': 0.5157551306129865, 'reg_alpha': 0.0014033169134723444, 'reg_lambda': 196.90312078844747}. Best is trial 15 with value: 1.653642187505772.
# [I 2026-06-30 00:39:40,179] Trial 17 pruned.
# [I 2026-06-30 00:39:41,964] Trial 18 pruned.
# [I 2026-06-30 00:39:49,903] Trial 19 finished with value: 1.6728414034427659 and parameters: {'n_estimators': 2824, 'learning_rate': 0.013346525112419762, 'max_depth': 5, 'min_child_weight': 0.31119554628630514, 'gamma': 9.466265153084475, 'subsample': 0.7732981551774945, 'colsample_bytree': 0.41532599251824875, 'reg_alpha': 1.7788279338939752e-05, 'reg_lambda': 81.31666476185187}. Best is trial 15 with value: 1.653642187505772.
# [I 2026-06-30 00:39:50,781] Trial 20 pruned.
# [I 2026-06-30 00:40:01,075] Trial 21 finished with value: 1.6690344735736966 and parameters: {'n_estimators': 2951, 'learning_rate': 0.015222899456230985, 'max_depth': 5, 'min_child_weight': 0.3042117838838079, 'gamma': 9.439929990447231, 'subsample': 0.7250169630282906, 'colsample_bytree': 0.44214896163017314, 'reg_alpha': 4.518198641380436e-05, 'reg_lambda': 79.96727867741009}. Best is trial 15 with value: 1.653642187505772.
# [I 2026-06-30 00:40:05,209] Trial 22 finished with value: 1.663685436997323 and parameters: {'n_estimators': 3084, 'learning_rate': 0.04273494762230192, 'max_depth': 5, 'min_child_weight': 0.11147578980048696, 'gamma': 9.397183703274244, 'subsample': 0.6334648918219821, 'colsample_bytree': 0.4449727896122752, 'reg_alpha': 0.00012055907171152694, 'reg_lambda': 65.72603515229355}. Best is trial 15 with value: 1.653642187505772.
# [I 2026-06-30 00:40:08,110] Trial 23 finished with value: 1.6897020410134156 and parameters: {'n_estimators': 3495, 'learning_rate': 0.03993247535926261, 'max_depth': 5, 'min_child_weight': 0.1244785829766384, 'gamma': 9.50017621718565, 'subsample': 0.6261477257223655, 'colsample_bytree': 0.35341403839684593, 'reg_alpha': 0.00021635829279679497, 'reg_lambda': 4.944059581445349}. Best is trial 15 with value: 1.653642187505772.
# [I 2026-06-30 00:40:16,188] Trial 24 finished with value: 1.6619652389813022 and parameters: {'n_estimators': 3135, 'learning_rate': 0.010685212646498897, 'max_depth': 6, 'min_child_weight': 0.07465590306050865, 'gamma': 9.37749096744472, 'subsample': 0.7126877198139485, 'colsample_bytree': 0.47380699044607455, 'reg_alpha': 0.006034128802366579, 'reg_lambda': 43.45016900954872}. Best is trial 15 with value: 1.653642187505772.
# [I 2026-06-30 00:40:24,280] Trial 25 finished with value: 1.666505235891322 and parameters: {'n_estimators': 3180, 'learning_rate': 0.008599437758490657, 'max_depth': 6, 'min_child_weight': 0.019615400650040207, 'gamma': 14.951280740961167, 'subsample': 0.7583890334307434, 'colsample_bytree': 0.5576455305268746, 'reg_alpha': 0.016488083078203233, 'reg_lambda': 32.33699711962274}. Best is trial 15 with value: 1.653642187505772.
# [I 2026-06-30 00:40:26,548] Trial 26 pruned.
# [I 2026-06-30 00:40:47,463] Trial 27 finished with value: 1.6556108926896425 and parameters: {'n_estimators': 3170, 'learning_rate': 0.0030271307361119403, 'max_depth': 6, 'min_child_weight': 0.026158138328893795, 'gamma': 10.690316805346225, 'subsample': 0.6962358182560595, 'colsample_bytree': 0.48132448388002813, 'reg_alpha': 0.019016590723861325, 'reg_lambda': 11.455185880826082}. Best is trial 15 with value: 1.653642187505772.
# [I 2026-06-30 00:40:59,075] Trial 28 finished with value: 1.6645205013353783 and parameters: {'n_estimators': 3170, 'learning_rate': 0.002477913943812953, 'max_depth': 6, 'min_child_weight': 0.02062354689466967, 'gamma': 12.756877584711233, 'subsample': 0.8069074411174837, 'colsample_bytree': 0.4835813028334238, 'reg_alpha': 0.018893135227194758, 'reg_lambda': 5.402933209026566}. Best is trial 15 with value: 1.653642187505772.
# [I 2026-06-30 00:41:09,817] Trial 29 pruned.
# [I 2026-06-30 00:41:09,975] A new study created in RDB with name: KAUS_v17_importance_015_remaining_warmup_base_lightgbm_mae_f
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-30 00:41:14,271] Trial 0 finished with value: 1.6931880286664829 and parameters: {'n_estimators': 447, 'learning_rate': 0.028873871707375695, 'num_leaves': 71, 'max_depth': 5, 'min_child_samples': 83, 'min_split_gain': 4.295687454742988, 'bagging_fraction': 0.7829586385137167, 'bagging_freq': 4, 'feature_fraction': 0.3688589858758342, 'lambda_l1': 0.06382334403151436, 'lambda_l2': 0.03080292177315921, 'huber_alpha': 0.95}. Best is trial 0 with value: 1.6931880286664829.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-30 00:41:19,081] Trial 1 finished with value: 1.9334436145575025 and parameters: {'n_estimators': 812, 'learning_rate': 0.009357081249483435, 'num_leaves': 164, 'max_depth': 2, 'min_child_samples': 211, 'min_split_gain': 4.244695738724308, 'bagging_fraction': 0.9814523094330022, 'bagging_freq': 3, 'feature_fraction': 0.9704172813206324, 'lambda_l1': 2.234088279028776e-05, 'lambda_l2': 1.6594154120142632, 'huber_alpha': 0.85}. Best is trial 0 with value: 1.6931880286664829.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-30 00:41:20,432] Trial 2 finished with value: 2.5996635242995683 and parameters: {'n_estimators': 67, 'learning_rate': 0.02007090910723469, 'num_leaves': 246, 'max_depth': 10, 'min_child_samples': 245, 'min_split_gain': 4.543313789155439, 'bagging_fraction': 0.9415994992571017, 'bagging_freq': 4, 'feature_fraction': 0.41761231740559585, 'lambda_l1': 1.4824332354449863e-08, 'lambda_l2': 101.18939970488272, 'huber_alpha': 0.85}. Best is trial 0 with value: 1.6931880286664829.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-30 00:41:21,691] Trial 3 finished with value: 1.9046401861222806 and parameters: {'n_estimators': 1000, 'learning_rate': 0.1413663860910666, 'num_leaves': 109, 'max_depth': 7, 'min_child_samples': 249, 'min_split_gain': 3.678635407535604, 'bagging_fraction': 0.6392899181182937, 'bagging_freq': 4, 'feature_fraction': 0.6173160679063129, 'lambda_l1': 0.052948773379180566, 'lambda_l2': 0.032760577756785814, 'huber_alpha': 0.85}. Best is trial 0 with value: 1.6931880286664829.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-30 00:41:24,384] Trial 4 finished with value: 2.4154119739503366 and parameters: {'n_estimators': 761, 'learning_rate': 0.003003151716938294, 'num_leaves': 409, 'max_depth': 5, 'min_child_samples': 165, 'min_split_gain': 1.498083879035124, 'bagging_fraction': 0.44391094597483866, 'bagging_freq': 3, 'feature_fraction': 0.5516751924489833, 'lambda_l1': 8.332516750396116e-08, 'lambda_l2': 0.5077631895453656, 'huber_alpha': 0.85}. Best is trial 0 with value: 1.6931880286664829.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-30 00:41:26,011] Trial 5 finished with value: 1.6674898422786693 and parameters: {'n_estimators': 404, 'learning_rate': 0.18314620854695027, 'num_leaves': 260, 'max_depth': 13, 'min_child_samples': 51, 'min_split_gain': 2.972245934092154, 'bagging_fraction': 0.9775155780902212, 'bagging_freq': 7, 'feature_fraction': 0.365709606237354, 'lambda_l1': 5.9654059281874116e-05, 'lambda_l2': 0.006859036422781172, 'huber_alpha': 0.95}. Best is trial 5 with value: 1.6674898422786693.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-30 00:41:28,217] Trial 6 finished with value: 1.6785989370647099 and parameters: {'n_estimators': 3052, 'learning_rate': 0.13146898336096702, 'num_leaves': 489, 'max_depth': 11, 'min_child_samples': 47, 'min_split_gain': 2.173391605434026, 'bagging_fraction': 0.9258346721061177, 'bagging_freq': 2, 'feature_fraction': 0.6381532515738396, 'lambda_l1': 0.002530717742378322, 'lambda_l2': 0.0004479476588817844, 'huber_alpha': 0.95}. Best is trial 5 with value: 1.6674898422786693.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-30 00:41:29,695] Trial 7 finished with value: 1.7989373597197307 and parameters: {'n_estimators': 2519, 'learning_rate': 0.18104669093362824, 'num_leaves': 399, 'max_depth': 4, 'min_child_samples': 227, 'min_split_gain': 2.761320735057018, 'bagging_fraction': 0.8991836269249566, 'bagging_freq': 7, 'feature_fraction': 0.8888248313104422, 'lambda_l1': 5.374969144858311e-06, 'lambda_l2': 0.5877618471031133, 'huber_alpha': 0.85}. Best is trial 5 with value: 1.6674898422786693.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-30 00:41:42,637] Trial 8 finished with value: 1.8425851385718373 and parameters: {'n_estimators': 2273, 'learning_rate': 0.0030965152683643635, 'num_leaves': 383, 'max_depth': 3, 'min_child_samples': 3, 'min_split_gain': 1.6724449577646616, 'bagging_fraction': 0.9800160774901863, 'bagging_freq': 5, 'feature_fraction': 0.6188955975766686, 'lambda_l1': 2.8120694751804143e-09, 'lambda_l2': 0.00024007807690373727, 'huber_alpha': 0.85}. Best is trial 5 with value: 1.6674898422786693.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-30 00:41:45,936] Trial 9 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-30 00:42:00,606] Trial 10 finished with value: 1.7663865617373562 and parameters: {'n_estimators': 2941, 'learning_rate': 0.007104579859769969, 'num_leaves': 424, 'max_depth': 2, 'min_child_samples': 2, 'min_split_gain': 4.6220887565718325, 'bagging_fraction': 0.7880566131549542, 'bagging_freq': 7, 'feature_fraction': 0.661678263936434, 'lambda_l1': 8.121756387194875e-09, 'lambda_l2': 100.08386764870838, 'huber_alpha': 0.9}. Best is trial 5 with value: 1.6674898422786693.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-30 00:42:01,914] Trial 11 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-30 00:42:07,854] Trial 12 finished with value: 1.6863051442330392 and parameters: {'n_estimators': 3404, 'learning_rate': 0.03866939016656176, 'num_leaves': 50, 'max_depth': 9, 'min_child_samples': 54, 'min_split_gain': 3.975378174997817, 'bagging_fraction': 0.5776988884481041, 'bagging_freq': 4, 'feature_fraction': 0.8073004449855348, 'lambda_l1': 1.1469173194560514e-08, 'lambda_l2': 0.6127644589218547, 'huber_alpha': 0.85}. Best is trial 5 with value: 1.6674898422786693.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-30 00:42:08,938] Trial 13 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-30 00:42:26,148] Trial 14 finished with value: 1.7026204774165614 and parameters: {'n_estimators': 2440, 'learning_rate': 0.007089782197514698, 'num_leaves': 92, 'max_depth': 2, 'min_child_samples': 83, 'min_split_gain': 1.7789721315624618, 'bagging_fraction': 0.6616016865596667, 'bagging_freq': 5, 'feature_fraction': 0.4058624376375402, 'lambda_l1': 3.60867143771307e-07, 'lambda_l2': 0.0019132656772962273, 'huber_alpha': 0.9}. Best is trial 5 with value: 1.6674898422786693.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-30 00:42:31,524] Trial 15 finished with value: 1.6623462374017084 and parameters: {'n_estimators': 1596, 'learning_rate': 0.07412684021464837, 'num_leaves': 490, 'max_depth': 14, 'min_child_samples': 54, 'min_split_gain': 0.3349947053308182, 'bagging_fraction': 0.8356054383416602, 'bagging_freq': 1, 'feature_fraction': 0.4928412115082472, 'lambda_l1': 5.944760726571435, 'lambda_l2': 0.004183303285898086, 'huber_alpha': 0.95}. Best is trial 15 with value: 1.6623462374017084.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-30 00:42:39,776] Trial 16 finished with value: 1.6951222101207883 and parameters: {'n_estimators': 1560, 'learning_rate': 0.05724323224858166, 'num_leaves': 296, 'max_depth': 14, 'min_child_samples': 114, 'min_split_gain': 0.030568099179320463, 'bagging_fraction': 0.8470371295272184, 'bagging_freq': 1, 'feature_fraction': 0.4785667004725681, 'lambda_l1': 13.21912397934445, 'lambda_l2': 0.005342762353707092, 'huber_alpha': 0.95}. Best is trial 15 with value: 1.6623462374017084.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-30 00:42:44,400] Trial 17 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-30 00:42:51,746] Trial 18 finished with value: 1.6974218827176617 and parameters: {'n_estimators': 1955, 'learning_rate': 0.07097571971728425, 'num_leaves': 509, 'max_depth': 11, 'min_child_samples': 89, 'min_split_gain': 0.7589244099255104, 'bagging_fraction': 0.6944068854745972, 'bagging_freq': 2, 'feature_fraction': 0.4794181722976582, 'lambda_l1': 0.8715047800270023, 'lambda_l2': 0.0029733904771583634, 'huber_alpha': 0.75}. Best is trial 15 with value: 1.6623462374017084.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-30 00:42:53,112] Trial 19 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-30 00:42:57,343] Trial 20 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-30 00:43:17,406] Trial 21 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-30 00:43:20,527] Trial 22 finished with value: 1.6685299022477091 and parameters: {'n_estimators': 2055, 'learning_rate': 0.09058835546385445, 'num_leaves': 341, 'max_depth': 12, 'min_child_samples': 29, 'min_split_gain': 3.271284508854157, 'bagging_fraction': 0.9149221483066088, 'bagging_freq': 1, 'feature_fraction': 0.4347861094760637, 'lambda_l1': 0.0013412764130900441, 'lambda_l2': 0.010119541980572567, 'huber_alpha': 0.95}. Best is trial 15 with value: 1.6623462374017084.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-30 00:43:25,084] Trial 23 finished with value: 1.6696383523252087 and parameters: {'n_estimators': 1896, 'learning_rate': 0.09328775717671366, 'num_leaves': 331, 'max_depth': 13, 'min_child_samples': 28, 'min_split_gain': 3.185301128637624, 'bagging_fraction': 0.8435672626561848, 'bagging_freq': 1, 'feature_fraction': 0.4239502614548779, 'lambda_l1': 0.026828101006819885, 'lambda_l2': 0.007103172694272659, 'huber_alpha': 0.95}. Best is trial 15 with value: 1.6623462374017084.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-30 00:43:27,920] Trial 24 finished with value: 1.677089499062887 and parameters: {'n_estimators': 1976, 'learning_rate': 0.04480675351782893, 'num_leaves': 243, 'max_depth': 12, 'min_child_samples': 69, 'min_split_gain': 1.0564290108936518, 'bagging_fraction': 0.7536077295062384, 'bagging_freq': 3, 'feature_fraction': 0.5298444044884849, 'lambda_l1': 1.3020284182451296, 'lambda_l2': 0.010989627803841825, 'huber_alpha': 0.95}. Best is trial 15 with value: 1.6623462374017084.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-30 00:43:30,408] Trial 25 finished with value: 1.6911458845798701 and parameters: {'n_estimators': 1193, 'learning_rate': 0.23830176320744734, 'num_leaves': 345, 'max_depth': 14, 'min_child_samples': 25, 'min_split_gain': 3.58378699536182, 'bagging_fraction': 0.9930046526010886, 'bagging_freq': 1, 'feature_fraction': 0.43894257746968385, 'lambda_l1': 1.1632212059611532e-06, 'lambda_l2': 0.09440286894622338, 'huber_alpha': 0.75}. Best is trial 15 with value: 1.6623462374017084.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-30 00:43:34,462] Trial 26 finished with value: 1.6667457592357655 and parameters: {'n_estimators': 461, 'learning_rate': 0.09709638751161342, 'num_leaves': 436, 'max_depth': 12, 'min_child_samples': 68, 'min_split_gain': 2.9896312701233003, 'bagging_fraction': 0.8967125339851596, 'bagging_freq': 5, 'feature_fraction': 0.35011309145472125, 'lambda_l1': 0.00014787674474687847, 'lambda_l2': 0.09829404285628204, 'huber_alpha': 0.9}. Best is trial 15 with value: 1.6623462374017084.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-30 00:43:37,815] Trial 27 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-30 00:43:42,118] Trial 28 finished with value: 1.6877574767416752 and parameters: {'n_estimators': 360, 'learning_rate': 0.12444867763358988, 'num_leaves': 444, 'max_depth': 13, 'min_child_samples': 66, 'min_split_gain': 1.3039194598800457, 'bagging_fraction': 0.8313820921242322, 'bagging_freq': 5, 'feature_fraction': 0.5807776752666926, 'lambda_l1': 0.586587522135145, 'lambda_l2': 0.09357704217627819, 'huber_alpha': 0.9}. Best is trial 15 with value: 1.6623462374017084.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-30 00:43:45,781] Trial 29 pruned.
# [I 2026-06-30 00:43:45,970] A new study created in RDB with name: KAUS_v17_importance_015_remaining_warmup_base_catboost_mae_f
# [I 2026-06-30 00:46:52,405] Trial 0 finished with value: 1.8212047730738368 and parameters: {'iterations': 2931, 'learning_rate': 0.001783588943232587, 'depth': 10, 'l2_leaf_reg': 0.9942958882300413, 'random_strength': 7.186216756161439, 'bagging_temperature': 12.184767612363034, 'border_count': 110, 'rsm': 0.6158971964095841, 'huber_delta': 1.5}. Best is trial 0 with value: 1.8212047730738368.
# [I 2026-06-30 00:49:27,428] Trial 1 finished with value: 2.014784675202335 and parameters: {'iterations': 801, 'learning_rate': 0.19767902101650964, 'depth': 12, 'l2_leaf_reg': 75.05056513807031, 'random_strength': 12.92821124806787, 'bagging_temperature': 4.276496242612171, 'border_count': 168, 'rsm': 0.4404450637901872, 'huber_delta': 1.0}. Best is trial 0 with value: 1.8212047730738368.
# [I 2026-06-30 00:49:38,648] Trial 2 finished with value: 2.0193207049066633 and parameters: {'iterations': 1992, 'learning_rate': 0.0024079350849750287, 'depth': 3, 'l2_leaf_reg': 0.118485976001343, 'random_strength': 4.058751860003342, 'bagging_temperature': 9.103785934457758, 'border_count': 206, 'rsm': 0.994034742637508, 'huber_delta': 0.5}. Best is trial 0 with value: 1.8212047730738368.
# [I 2026-06-30 00:51:41,596] Trial 3 finished with value: 1.9824615589419756 and parameters: {'iterations': 3095, 'learning_rate': 0.05508623515899769, 'depth': 11, 'l2_leaf_reg': 18.082710740309665, 'random_strength': 13.948598364083836, 'bagging_temperature': 18.60205606816345, 'border_count': 227, 'rsm': 0.4117317891426977, 'huber_delta': 3.0}. Best is trial 0 with value: 1.8212047730738368.
# [I 2026-06-30 00:51:52,423] Trial 4 finished with value: 1.6836559137512261 and parameters: {'iterations': 3146, 'learning_rate': 0.0024764229908984673, 'depth': 3, 'l2_leaf_reg': 0.6951779671472356, 'random_strength': 6.148451176512449, 'bagging_temperature': 8.441103735088014, 'border_count': 95, 'rsm': 0.7192489923988105, 'huber_delta': 2.0}. Best is trial 4 with value: 1.6836559137512261.
# [I 2026-06-30 00:51:55,737] Trial 5 finished with value: 1.792152578229898 and parameters: {'iterations': 2996, 'learning_rate': 0.04169299311145666, 'depth': 2, 'l2_leaf_reg': 0.6483636109972302, 'random_strength': 11.284989840243444, 'bagging_temperature': 11.881552589055849, 'border_count': 179, 'rsm': 0.7610806862514128, 'huber_delta': 0.5}. Best is trial 4 with value: 1.6836559137512261.
# [I 2026-06-30 00:51:56,848] Trial 6 pruned.
# [I 2026-06-30 00:52:00,013] Trial 7 finished with value: 1.9200363673991019 and parameters: {'iterations': 2269, 'learning_rate': 0.05988786419186062, 'depth': 3, 'l2_leaf_reg': 0.8727148674658863, 'random_strength': 13.785080578883292, 'bagging_temperature': 3.643240241026453, 'border_count': 16, 'rsm': 0.5239102067389221, 'huber_delta': 0.5}. Best is trial 4 with value: 1.6836559137512261.
# [I 2026-06-30 00:52:11,359] Trial 8 finished with value: 1.8005958465400256 and parameters: {'iterations': 505, 'learning_rate': 0.04208463092506502, 'depth': 7, 'l2_leaf_reg': 61.30136526040692, 'random_strength': 0.007275503409398532, 'bagging_temperature': 15.582899976989255, 'border_count': 206, 'rsm': 0.39169077091200666, 'huber_delta': 1.5}. Best is trial 4 with value: 1.6836559137512261.
# [I 2026-06-30 00:52:56,380] Trial 9 finished with value: 1.7562610150946332 and parameters: {'iterations': 2176, 'learning_rate': 0.006973123504821021, 'depth': 7, 'l2_leaf_reg': 1.0111907140307084, 'random_strength': 19.613513312465464, 'bagging_temperature': 8.113717548278494, 'border_count': 208, 'rsm': 0.7899333278528806, 'huber_delta': 5.0}. Best is trial 4 with value: 1.6836559137512261.
# [I 2026-06-30 00:53:13,577] Trial 10 pruned.
# [I 2026-06-30 00:53:28,495] Trial 11 finished with value: 1.6961322050720669 and parameters: {'iterations': 2772, 'learning_rate': 0.014522829031783214, 'depth': 5, 'l2_leaf_reg': 15.987388321276002, 'random_strength': 11.591109950971106, 'bagging_temperature': 7.790667047006705, 'border_count': 126, 'rsm': 0.7500006952294106, 'huber_delta': 5.0}. Best is trial 4 with value: 1.6836559137512261.
# [I 2026-06-30 00:53:43,598] Trial 12 pruned.
# [I 2026-06-30 00:53:50,567] Trial 13 pruned.
# [I 2026-06-30 00:53:54,774] Trial 14 finished with value: 1.755369621324793 and parameters: {'iterations': 2033, 'learning_rate': 0.03406017942217813, 'depth': 3, 'l2_leaf_reg': 2.8273302406131626, 'random_strength': 2.5986858551767766, 'bagging_temperature': 5.630188860588947, 'border_count': 58, 'rsm': 0.9026140460549269, 'huber_delta': 1.0}. Best is trial 4 with value: 1.6836559137512261.
# [I 2026-06-30 00:54:04,778] Trial 15 pruned.
# [I 2026-06-30 00:54:30,740] Trial 16 finished with value: 1.7505827965365963 and parameters: {'iterations': 3416, 'learning_rate': 0.006424948471040994, 'depth': 5, 'l2_leaf_reg': 197.98083807490883, 'random_strength': 17.110130348053506, 'bagging_temperature': 0.2920642424315254, 'border_count': 68, 'rsm': 0.7385632694163883, 'huber_delta': 2.0}. Best is trial 4 with value: 1.6836559137512261.
# [I 2026-06-30 00:54:42,385] Trial 17 finished with value: 1.66442721322098 and parameters: {'iterations': 2601, 'learning_rate': 0.014152852966759031, 'depth': 5, 'l2_leaf_reg': 6.836575112864214, 'random_strength': 9.87120584290834, 'bagging_temperature': 1.3263969896774768, 'border_count': 115, 'rsm': 0.599180522095796, 'huber_delta': 5.0}. Best is trial 17 with value: 1.66442721322098.
# [I 2026-06-30 00:55:03,620] Trial 18 finished with value: 1.7322304335462269 and parameters: {'iterations': 1477, 'learning_rate': 0.003758003222718985, 'depth': 7, 'l2_leaf_reg': 5.222415796042149, 'random_strength': 5.47533085667722, 'bagging_temperature': 0.31515488633751154, 'border_count': 97, 'rsm': 0.5867965029065665, 'huber_delta': 2.0}. Best is trial 17 with value: 1.66442721322098.
# [I 2026-06-30 00:55:04,583] Trial 19 pruned.
# [I 2026-06-30 00:55:05,866] Trial 20 pruned.
# [I 2026-06-30 00:55:13,548] Trial 21 finished with value: 1.6665087104355933 and parameters: {'iterations': 2694, 'learning_rate': 0.015996828890910152, 'depth': 5, 'l2_leaf_reg': 11.233084430057469, 'random_strength': 11.157935335373866, 'bagging_temperature': 7.2210937897805945, 'border_count': 124, 'rsm': 0.7149740515044226, 'huber_delta': 5.0}. Best is trial 17 with value: 1.66442721322098.
# [I 2026-06-30 00:55:20,289] Trial 22 finished with value: 1.6619038995463544 and parameters: {'iterations': 2465, 'learning_rate': 0.011880557599444983, 'depth': 4, 'l2_leaf_reg': 8.317205121752096, 'random_strength': 9.417006045600889, 'bagging_temperature': 6.088201509946642, 'border_count': 154, 'rsm': 0.6100804402174579, 'huber_delta': 5.0}. Best is trial 22 with value: 1.6619038995463544.
# [I 2026-06-30 00:55:35,038] Trial 23 finished with value: 1.6589045409333685 and parameters: {'iterations': 2426, 'learning_rate': 0.00952258264621606, 'depth': 6, 'l2_leaf_reg': 8.597769120558171, 'random_strength': 16.097713705054858, 'bagging_temperature': 2.0154662827391245, 'border_count': 156, 'rsm': 0.6239803919403365, 'huber_delta': 5.0}. Best is trial 23 with value: 1.6589045409333685.
# [I 2026-06-30 00:55:44,600] Trial 24 pruned.
# [I 2026-06-30 00:55:51,154] Trial 25 pruned.
# ...
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
#                   period           method  count     mae_f    rmse_f
# 0   validation_2024_2025          xgboost    729  1.730809  2.433138
# 1   validation_2024_2025         lightgbm    729  1.710025  2.419640
# 2   validation_2024_2025         catboost    729  1.680529  2.378064
# 3   validation_2024_2025    provider_mean    729  2.350300  3.163180
# 4   validation_2024_2025  provider_median    729  2.394468  3.212344
# 5   validation_2024_2025          nbm_raw    729  2.505677  3.334672
# 6   validation_2024_2025         hrrr_raw    729  2.909102  3.884978
# 7   validation_2024_2025          gfs_raw    729  2.920089  3.877962
# 8              test_2026          xgboost    171  1.437245  1.923768
# 9              test_2026         lightgbm    171  1.482562  2.009045
# 10             test_2026         catboost    171  1.524820  2.028061
# 11             test_2026      ridge_stack    171  1.467547  1.949552
# 12             test_2026    provider_mean    171  2.152290  2.608884
# 13             test_2026  provider_median    171  2.053307  2.474275
# 14             test_2026          nbm_raw    171  1.988577  2.490816
# 15             test_2026         hrrr_raw    171  2.551778  3.114698
# 16             test_2026          gfs_raw    171  2.702238  3.353030

# %%
if EXPORT_MODEL_WEIGHTS:
    exported_weights = export_station_model_weights(
        project_root=PROJECT_ROOT,
        station_id=STATION_ID,
        artifact_dir=config.resolved_output_dir(),
        model_version=MODEL_VERSION,
        timing_mode=config.timing_mode,
        providers=tuple(config.providers),
        feature_version=config.effective_feature_version,
        optuna_metric=config.effective_optuna_metric,
        target_mode=config.effective_target_mode,
        target_source=config.effective_target_source,
        base_model_methods=tuple(config.effective_base_model_methods),
        stack_enabled=config.stack_enabled,
        source_pipeline="notebooks/station_stacking_v17",
    )
    display((exported_weights.bundle_path, exported_weights.manifest_path))

write_reference_comparisons(OUTPUT_DIR, V15_OUTPUT_DIR, V16_OUTPUT_DIR, STATION_ID)
# Out:
# (WindowsPath('D:/dev/weather-research/data/calibration/station_stacking_v17/importance_015/model_weights/KAUS_station_high_regressor_v17_importance_015_stack.joblib'),
#  WindowsPath('D:/dev/weather-research/data/calibration/station_stacking_v17/importance_015/model_weights/KAUS_station_high_regressor_v17_importance_015_stack.json'))
# Wrote KAUS v17 reference comparison: D:\dev\weather-research\data\calibration\station_stacking_v17\KAUS_v17_importance_015_vs_references_common_date_comparison.csv

# %% [markdown]
# ## Reference Comparison

# %%
comparison_path = OUTPUT_DIR / f"{STATION_ID}_v17_importance_015_vs_references_common_date_comparison.csv"
comparison = pd.read_csv(comparison_path) if comparison_path.exists() else pd.DataFrame()
comparison.sort_values(["method", "delta_mae_f", "reference"]) if not comparison.empty else comparison
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# Cell In[12], line 2
#       1 comparison_path = OUTPUT_DIR / f"{STATION_ID}_v17_importance_015_vs_references_common_date_comparison.csv"
# ----> 2 comparison = pd.read_csv(comparison_path) if comparison_path.exists() else pd.DataFrame()
#       3 comparison.sort_values(["method", "delta_mae_f", "reference"]) if not comparison.empty else comparison
#
# File d:\dev\weather-research\.venv\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File d:\dev\weather-research\.venv\Lib\site-packages\pandas\io\parsers\readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File d:\dev\weather-research\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File d:\dev\weather-research\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1922, in TextFileReader._make_engine(self, f, engine)
#    1919     raise ValueError(msg)
#    1921 try:
# -> 1922     return mapping[engine](f, **self.options)
#    1923 except Exception:
#    1924     if self.handles is not None:
#
# File d:\dev\weather-research\.venv\Lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:95, in CParserWrapper.__init__(self, src, **kwds)
#      92 if kwds["dtype_backend"] == "pyarrow":
#      93     # Fail here loudly instead of in cython after reading
#      94     import_optional_dependency("pyarrow")
# ---> 95 self._reader = parsers.TextReader(src, **kwds)
#      97 self.unnamed_cols = self._reader.unnamed_cols
#      99 passed_names = self.names is None
#
# File pandas/_libs/parsers.pyx:575, in pandas._libs.parsers.TextReader.__cinit__()
# --> 575 'Could not get source, probably due dynamically evaluated source code.'
#
# EmptyDataError: No columns to parse from file

# %% [markdown]
# ## Selected Feature Audit

# %%
expected = set(V17_IMPORTANCE_015_FEATURE_COLUMNS)
selected = set(result.feature_columns["feature"].astype(str))
{
    "selected_feature_count": len(selected),
    "expected_feature_count": len(expected),
    "selected_features": sorted(selected),
    "missing_expected": sorted(expected - selected),
    "unexpected_selected": sorted(selected - expected),
    "coverage_gated_selected": sorted(selected & set(V17_ADDITIONAL_FEATURE_COLUMNS)),
}
# Out:
# {'selected_feature_count': 17,
#  'expected_feature_count': 17,
#  'selected_features': ['gfs_high_minus_observed_high_temp_f',
#   'gfs_high_minus_observed_temp_f',
#   'hrrr_high_minus_observed_high_temp_f',
#   'hrrr_rolling_bias_30d_f',
#   'nbm_high_minus_observed_high_temp_f',
#   'nbm_high_minus_observed_temp_f',
#   'observed_cloud_cover_at_as_of',
#   'observed_high_so_far_change_since_9am_f',
#   'observed_high_temp_minus_temp_at_as_of_f',
#   'observed_temp_change_last_3h_f',
#   'v13_forecast_temp_bias_remaining_warmup_interaction',
#   'v3_humidity_remaining_warmup_interaction',
#   'v3_remaining_warmup_from_high_so_far_f',
#   'v3_remaining_warmup_per_spread_f',
#   'v8_provider_max_remaining_from_high_so_far_f',
#   'v8_provider_mean_remaining_vs_month_normal_f',
#   'v8_provider_median_remaining_from_high_so_far_f'],
#  'missing_expected': [],
#  'unexpected_selected': [],
#  'coverage_gated_selected': ['v13_forecast_temp_bias_remaining_warmup_interaction']}

# %% [markdown]
# ## Accidental Weather Sprawl Check

# %%
raw_weather_tokens = (
    "cloud",
    "ceiling",
    "dewpoint",
    "forecast_temp_at_as_of",
    "humidity",
    "precip",
    "pressure",
    "shortwave",
    "visibility",
    "wind_",
)
selected_features = result.feature_columns["feature"].astype(str)
accidental_weather_selected = pd.DataFrame(
    [
        {"feature": feature}
        for feature in selected_features
        if (
            feature.startswith(("gfs_", "hrrr_", "nbm_", "v13_", "v8_"))
            and any(token in feature for token in raw_weather_tokens)
            and feature not in set(V17_IMPORTANCE_015_FEATURE_COLUMNS)
        )
    ]
)

accidental_weather_selected
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## Feature Importance

# %%
importance_path = config.resolved_output_dir() / f"{STATION_ID}_year_split_feature_importance.csv"
importance = pd.read_csv(importance_path) if importance_path.exists() else pd.DataFrame()
importance.sort_values(["method", "importance_mae_f"], ascending=[True, False]) if not importance.empty else importance
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 3
#       1 importance_path = config.resolved_output_dir() / f"{STATION_ID}_year_split_feature_importance.csv"
#       2 importance = pd.read_csv(importance_path) if importance_path.exists() else pd.DataFrame()
# ----> 3 importance.sort_values(["method", "importance_mae_f"], ascending=[True, False]) if not importance.empty else importance
#
# File d:\dev\weather-research\.venv\Lib\site-packages\pandas\core\frame.py:8351, in DataFrame.sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    8347             else:
#    8348                 # error: Argument 1 to "list" has incompatible type
#    8349                 # "Generator[ExtensionArray | ndarray[Any, Any], None, None]";
#    8350                 # expected "Iterable[Series]"
# -> 8351                 keys_data = list(keys)  # type: ignore[arg-type]
#    8352
#    8353             indexer = lexsort_indexer(
#    8354                 keys_data, orders=ascending, na_position=na_position, key=key
#
# File d:\dev\weather-research\.venv\Lib\site-packages\pandas\core\frame.py:8340, in DataFrame.sort_values.<locals>.<genexpr>(.0)
# -> 8340             keys = (self._get_label_or_level_values(x, axis=axis) for x in by)
#
# File d:\dev\weather-research\.venv\Lib\site-packages\pandas\core\generic.py:1776, in NDFrame._get_label_or_level_values(self, key, axis)
#    1772             values = self.xs(key, axis=first_other_axes)._values
#    1773         elif self._is_level_reference(key, axis=axis):
#    1774             values = self.axes[axis].get_level_values(key)._values
#    1775         else:
# -> 1776             raise KeyError(key)
#    1777
#    1778         # Check for duplicates
#    1779         if values.ndim > 1:
#
# KeyError: 'importance_mae_f'

# %% [markdown]
# ## Rounded Within 1F Accuracy

# %%
preds = pd.concat(
    [
        result.validation_predictions.assign(period="validation_2024_2025"),
        result.test_predictions.assign(period="oof_2026"),
    ],
    ignore_index=True,
)
predicted_high = pd.to_numeric(preds["predicted_high_f"], errors="coerce")
preds["predicted_high_rounded_f"] = np.floor(predicted_high + 0.5)
preds["within_1f_after_round"] = (
    pd.to_numeric(preds["actual_high_f"], errors="coerce") - preds["predicted_high_rounded_f"]
).abs().le(1)

within_1f_accuracy_by_period = (
    preds
    .dropna(subset=["actual_high_f", "predicted_high_rounded_f"])
    .groupby(["period", "method"], as_index=False)
    .agg(
        count=("within_1f_after_round", "size"),
        within_1f_count=("within_1f_after_round", "sum"),
        within_1f_accuracy_pct=("within_1f_after_round", lambda x: x.mean() * 100),
    )
    .sort_values(["period", "within_1f_accuracy_pct"], ascending=[True, False])
)

within_1f_accuracy_by_period
# Out:
#                   period           method  count  within_1f_count  \
# 7               oof_2026      ridge_stack    171              110
# 8               oof_2026          xgboost    171              107
# 3               oof_2026         lightgbm    171              106
# 0               oof_2026         catboost    171              105
# 5               oof_2026    provider_mean    171               73
# 4               oof_2026          nbm_raw    171               70
# 6               oof_2026  provider_median    171               69
# 1               oof_2026          gfs_raw    171               59
# 2               oof_2026         hrrr_raw    171               58
# 9   validation_2024_2025         catboost    729              434
# 12  validation_2024_2025         lightgbm    729              424
# 16  validation_2024_2025          xgboost    729              416
# 14  validation_2024_2025    provider_mean    729              303
# 15  validation_2024_2025  provider_median    729              298
# 13  validation_2024_2025          nbm_raw    729              281
# 11  validation_2024_2025         hrrr_raw    729              253
# 10  validation_2024_2025          gfs_raw    729              228
#
#     within_1f_accuracy_pct
# 7                64.327485
# 8                62.573099
# 3                61.988304
# 0                61.403509
# 5                42.690058
# 4                40.935673
# 6                40.350877
# 1                34.502924
# 2                33.918129
# 9                59.533608
# 12               58.161866
# 16               57.064472
# 14               41.563786
# 15               40.877915
# 13               38.545953
# 11               34.705075
# 10               31.275720

# %% [markdown]
# ## Bracket Metrics

# %%
result.bracket_metrics
# Out:
#             method  count     mae_f    rmse_f  bracket_accuracy_pct
# 0          xgboost    171  1.437245  1.923768             42.105263
# 1         lightgbm    171  1.482562  2.009045             39.181287
# 2         catboost    171  1.524820  2.028061             40.935673
# 3      ridge_stack    171  1.467547  1.949552             42.105263
# 4    provider_mean    171  2.152290  2.608884             30.994152
# 5  provider_median    171  2.053307  2.474275             30.994152
# 6          nbm_raw    171  1.988577  2.490816             30.409357
# 7         hrrr_raw    171  2.551778  3.114698             23.391813
# 8          gfs_raw    171  2.702238  3.353030             25.146199

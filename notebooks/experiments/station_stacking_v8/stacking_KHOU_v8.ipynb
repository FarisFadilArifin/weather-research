# %% [markdown]
# # Station Stacking v8 - KHOU
#
# Experimental notebook for `KHOU`.
#
# This version keeps the v7 live-safe GFS/HRRR/NBM contract, adds source-owned remaining-warmup feature engineering, and drops only conservative zero-importance input fields. Artifacts are written to `data/calibration/station_stacking_v8`.

# %%
from pathlib import Path
import os
import sys
import warnings

warnings.filterwarnings("ignore", message="IProgress not found.*")
warnings.filterwarnings("ignore", message="Skipping features without any observed values.*")

PROJECT_ROOT = Path.cwd().resolve()
while not (PROJECT_ROOT / "src" / "calibration" / "station_stacking.py").exists():
    if PROJECT_ROOT.parent == PROJECT_ROOT:
        raise RuntimeError("Could not find project root containing src/calibration/station_stacking.py")
    PROJECT_ROOT = PROJECT_ROOT.parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

os.environ["WEATHER_RESEARCH_INCLUDE_DIRECT_NBM"] = "1"

STATION_ID = "KHOU"
PROVIDERS = ("gfs", "hrrr", "nbm")
TIMING_MODE = "same_day_11am_live_safe"
FAST_MODE = False
OPTUNA_TRIALS = 50
STACK_OPTUNA_TRIALS = 50
OPTUNA_STARTUP_TRIALS = 20
STACK_OPTUNA_STARTUP_TRIALS = 20
OPTUNA_METRIC = "mae_f"
OPTUNA_VERBOSE = True
PROJECT_ROOT
# Out:
# WindowsPath('D:/dev/weather-research')

# %%
import numpy as np
import pandas as pd

from src.calibration.station_stacking import (
    StationStackingConfig,
    V8_DROPPED_FEATURE_COLUMNS,
    V8_FEATURE_COLUMNS,
    YEAR_SPLIT_EXPANDING_FOLDS,
    missing_model_dependencies,
    provider_availability,
    run_station_year_split_experiment,
)

# %% [markdown]
# ## V8 Contract
#
# `feature_version="v8"` keeps the v7 live-safe NBM setup and direct `actual_high_f` target. V8 adds remaining-warmup features and removes only conservative zero-importance model inputs from the feature matrix.

# %%
fold_spec = pd.DataFrame(
    [
        {
            "fold": fold.name,
            "train_start_year": fold.train_start_year,
            "train_end_year": fold.train_end_year,
            "validation_year": fold.validation_year,
        }
        for fold in YEAR_SPLIT_EXPANDING_FOLDS
    ]
)

fold_spec
# Out:
#                      fold  train_start_year  train_end_year  validation_year
# 0  fold_2021_2023_to_2024              2021            2023             2024
# 1  fold_2021_2024_to_2025              2021            2024             2025

# %%
V8_FEATURE_COLUMNS, sorted(V8_DROPPED_FEATURE_COLUMNS)
# Out:
# (['v2_recent_heat_anomaly_f',
#   'v2_recent_heat_momentum_f',
#   'v2_morning_warmup_to_consensus_f',
#   'v2_consensus_minus_7d_actual_f',
#   'v2_spread_per_warmup_f',
#   'v2_humidity_warmup_interaction',
#   'v3_high_so_far_above_current_f',
#   'v3_remaining_warmup_from_high_so_far_f',
#   'v3_high_so_far_minus_lag_1d_f',
#   'v3_high_so_far_minus_7d_actual_f',
#   'v3_remaining_warmup_per_spread_f',
#   'v3_humidity_remaining_warmup_interaction',
#   'v4_forecast_precip_total_mean_mm',
#   'v4_forecast_precip_total_max_mm',
#   'v4_forecast_precip_total_spread_mm',
#   'v4_forecast_precip_max_1h_mean_mm',
#   'v4_forecast_precip_hours_mean',
#   'v4_forecast_precip_intensity_mean',
#   'v4_forecast_precip_intensity_max',
#   'v4_any_forecast_precip',
#   'v4_all_forecast_precip',
#   'v4_observed_precip_any',
#   'v4_observed_precip_recent_mm_est',
#   'v4_forecast_total_minus_observed_recent_mm',
#   'v4_forecast_observed_precip_match',
#   'v4_forecast_wet_observed_dry',
#   'v4_observed_wet_forecast_dry',
#   'v4_precip_humidity_interaction',
#   'v4_precip_remaining_warmup_interaction',
#   'observed_temp_change_last_1h_f',
#   'observed_temp_change_last_3h_f',
#   'observed_morning_warmup_rate_f_per_hour',
#   'observed_high_so_far_change_since_9am_f',
#   'v8_provider_max_remaining_from_high_so_far_f',
#   'v8_provider_min_remaining_from_high_so_far_f',
#   'v8_provider_median_remaining_from_high_so_far_f',
#   'v8_provider_spread_per_remaining_warmup_f',
#   'v8_month_remaining_warmup_mean_f',
#   'v8_month_remaining_warmup_count',
#   'v8_recent_remaining_warmup_7d_mean_f',
#   'v8_recent_remaining_warmup_30d_mean_f',
#   'v8_provider_mean_remaining_vs_month_normal_f',
#   'v8_cloud_cover_mean_remaining_warmup_interaction',
#   'v8_cloud_cover_max_remaining_warmup_interaction',
#   'v8_precip_total_remaining_warmup_interaction',
#   'v8_precip_max_1h_remaining_warmup_interaction',
#   'v8_wind_speed_mean_remaining_warmup_interaction',
#   'v8_wind_gust_max_remaining_warmup_interaction',
#   'v8_forecast_dewpoint_mean_f',
#   'v8_forecast_dewpoint_depression_mean_f',
#   'v8_dewpoint_mean_remaining_warmup_interaction',
#   'v8_dewpoint_depression_remaining_warmup_interaction'],
#  ['gfs_as_of_hour_local',
#   'gfs_available',
#   'gfs_forecast_window_hours',
#   'gfs_grid_dist_km_mean',
#   'gfs_horizon_hours',
#   'gfs_hrrr_grid_dist_km_mean_abs_diff_f',
#   'gfs_hrrr_grid_dist_km_mean_diff_f',
#   'gfs_issue_hour_utc',
#   'gfs_missing',
#   'hrrr_as_of_hour_local',
#   'hrrr_available',
#   'hrrr_forecast_hour_max',
#   'hrrr_forecast_hour_min',
#   'hrrr_forecast_lead_hours',
#   'hrrr_forecast_window_hours',
#   'hrrr_grid_dist_km_mean',
#   'hrrr_horizon_hours',
#   'hrrr_issue_hour_local',
#   'hrrr_issue_hour_utc',
#   'hrrr_missing',
#   'is_active_polymarket_station',
#   'lat',
#   'lon',
#   'nbm_as_of_hour_local',
#   'nbm_available',
#   'nbm_forecast_window_hours',
#   'nbm_horizon_hours',
#   'nbm_issue_hour_local',
#   'nbm_issue_hour_utc',
#   'nbm_missing',
#   'observed_fetch_status',
#   'observed_observation_type',
#   'observed_pressure_source',
#   'provider_count_available',
#   'year'])

# %% [markdown]
# ## Data Availability

# %%
availability = provider_availability(
    PROJECT_ROOT,
    timing_mode=TIMING_MODE,
    providers=PROVIDERS,
)

availability.loc[availability["station_id"].eq(STATION_ID)]
# Out:
#    station_id provider  row_count first_contract_date last_contract_date
# 9        KHOU      gfs       1983          2021-01-01         2026-06-10
# 10       KHOU     hrrr       1987          2021-01-01         2026-06-10
# 11       KHOU      nbm       1986          2021-01-01         2026-06-10

# %% [markdown]
# ## Model Scores

# %%
missing_packages = missing_model_dependencies()
if missing_packages:
    raise ImportError(
        "Missing station-stacking ML packages: "
        + ", ".join(missing_packages)
        + ". Install them with: python -m pip install -r requirements.txt"
    )

config = StationStackingConfig(
    station_id=STATION_ID,
    project_root=PROJECT_ROOT,
    timing_mode=TIMING_MODE,
    providers=PROVIDERS,
    fast_mode=FAST_MODE,
    optuna_trials=OPTUNA_TRIALS,
    stack_optuna_trials=STACK_OPTUNA_TRIALS,
    optuna_startup_trials=OPTUNA_STARTUP_TRIALS,
    stack_optuna_startup_trials=STACK_OPTUNA_STARTUP_TRIALS,
    optuna_metric=OPTUNA_METRIC,
    optuna_verbose=OPTUNA_VERBOSE,
    feature_version="v8",
    hyperparameter_space="wide",
    year_split_folds=YEAR_SPLIT_EXPANDING_FOLDS,
    year_split_test_train_years=(2021, 2025),
    year_split_test_year=2026,
    output_dir=PROJECT_ROOT / "data" / "calibration" / "station_stacking_v8",
)

config.resolved_optuna_storage_path()
# Out:
# WindowsPath('D:/dev/weather-research/data/calibration/station_stacking_v8/KHOU_optuna.sqlite3')

# %%
result = run_station_year_split_experiment(config)
result.scoreboard
# Out:
# [I 2026-06-15 05:47:39,636] A new study created in RDB with name: KHOU_v8_base_xgboost_mae_f
# [I 2026-06-15 05:47:50,368] Trial 0 finished with value: 1.8559307743568851 and parameters: {'n_estimators': 1342, 'learning_rate': 0.19043899115982607, 'max_depth': 9, 'min_child_weight': 2.481040974867813, 'gamma': 2.340279606636548, 'subsample': 0.4513964382185317, 'colsample_bytree': 0.3877543479093296, 'reg_alpha': 2.478071022662141, 'reg_lambda': 0.6132587025321562}. Best is trial 0 with value: 1.8559307743568851.
# [I 2026-06-15 05:51:35,319] Trial 1 finished with value: 1.844294874343258 and parameters: {'n_estimators': 2493, 'learning_rate': 0.001120367191095075, 'max_depth': 12, 'min_child_weight': 21.368329072358772, 'gamma': 3.185086660174142, 'subsample': 0.4681862286846154, 'colsample_bytree': 0.46921293140473197, 'reg_alpha': 4.476173538513514e-07, 'reg_lambda': 0.20253776634919213}. Best is trial 1 with value: 1.844294874343258.
# [I 2026-06-15 05:53:26,014] Trial 2 finished with value: 1.7061648609325477 and parameters: {'n_estimators': 1540, 'learning_rate': 0.004992867109217114, 'max_depth': 8, 'min_child_weight': 0.03613894271216528, 'gamma': 4.3821697280282725, 'subsample': 0.5881351981408995, 'colsample_bytree': 0.6464454897410734, 'reg_alpha': 0.26430874752361627, 'reg_lambda': 0.0018119678627933364}. Best is trial 2 with value: 1.7061648609325477.
# [I 2026-06-15 05:53:50,124] Trial 3 finished with value: 1.7943194621244358 and parameters: {'n_estimators': 1824, 'learning_rate': 0.026337502897485255, 'max_depth': 1, 'min_child_weight': 2.69264691008618, 'gamma': 2.557861855309373, 'subsample': 0.39228353544043165, 'colsample_bytree': 0.9667755992146666, 'reg_alpha': 38.6887231523051, 'reg_lambda': 12.408975837016275}. Best is trial 2 with value: 1.7061648609325477.
# [I 2026-06-15 05:57:54,041] Trial 4 finished with value: 2.5364456928642807 and parameters: {'n_estimators': 1101, 'learning_rate': 0.0017147936629846843, 'max_depth': 9, 'min_child_weight': 0.5762487216478605, 'gamma': 1.8305735226716824, 'subsample': 0.6718649915723256, 'colsample_bytree': 0.37235253872489193, 'reg_alpha': 8.162906555194692, 'reg_lambda': 0.004271500153828077}. Best is trial 2 with value: 1.7061648609325477.
# [I 2026-06-15 06:00:00,482] Trial 5 pruned.
# [I 2026-06-15 06:00:07,071] Trial 6 finished with value: 1.7598503847500104 and parameters: {'n_estimators': 2113, 'learning_rate': 0.16240489353272883, 'max_depth': 2, 'min_child_weight': 0.06080390190296603, 'gamma': 0.678409333658071, 'subsample': 0.5614647149961218, 'colsample_bytree': 0.6026402382981633, 'reg_alpha': 1.8037999945880162e-07, 'reg_lambda': 16.668629892722056}. Best is trial 2 with value: 1.7061648609325477.
# [I 2026-06-15 06:02:04,204] Trial 7 finished with value: 1.7070343487948323 and parameters: {'n_estimators': 1281, 'learning_rate': 0.0047169807141865345, 'max_depth': 7, 'min_child_weight': 0.0366181922039243, 'gamma': 12.032954711310595, 'subsample': 0.398457918391851, 'colsample_bytree': 0.9914765087903362, 'reg_alpha': 0.18490013641000916, 'reg_lambda': 0.0017869543989965139}. Best is trial 2 with value: 1.7061648609325477.
# [I 2026-06-15 06:02:08,347] Trial 8 pruned.
# [I 2026-06-15 06:03:21,600] Trial 9 finished with value: 1.7240314931277376 and parameters: {'n_estimators': 2201, 'learning_rate': 0.006215464818952927, 'max_depth': 1, 'min_child_weight': 0.17535949529764422, 'gamma': 4.877749830401205, 'subsample': 0.8242440159197416, 'colsample_bytree': 0.7644123563808884, 'reg_alpha': 4.4315220126915325, 'reg_lambda': 0.09450187118503514}. Best is trial 2 with value: 1.7061648609325477.
# [I 2026-06-15 06:03:41,197] Trial 10 finished with value: 1.7186614746510869 and parameters: {'n_estimators': 462, 'learning_rate': 0.051323729958866915, 'max_depth': 10, 'min_child_weight': 1.7583640270008525, 'gamma': 11.564507699318415, 'subsample': 0.670967137636854, 'colsample_bytree': 0.689776339098296, 'reg_alpha': 1.3504926357029513e-05, 'reg_lambda': 0.0001445994629863374}. Best is trial 2 with value: 1.7061648609325477.
# [I 2026-06-15 06:04:04,372] Trial 11 pruned.
# [I 2026-06-15 06:04:31,942] Trial 12 pruned.
# [I 2026-06-15 06:04:39,906] Trial 13 finished with value: 1.7805969322957989 and parameters: {'n_estimators': 693, 'learning_rate': 0.13813474572232612, 'max_depth': 7, 'min_child_weight': 16.973078532467014, 'gamma': 13.4413694988524, 'subsample': 0.5567022587317115, 'colsample_bytree': 0.4215337509429899, 'reg_alpha': 5.435280359192946e-08, 'reg_lambda': 0.049115547267693904}. Best is trial 2 with value: 1.7061648609325477.
# [I 2026-06-15 06:04:49,247] Trial 14 pruned.
# [I 2026-06-15 06:05:17,781] Trial 15 finished with value: 1.736144239676658 and parameters: {'n_estimators': 1165, 'learning_rate': 0.01753996764864722, 'max_depth': 9, 'min_child_weight': 0.28478585168562975, 'gamma': 14.57673124081441, 'subsample': 0.9755907417123723, 'colsample_bytree': 0.5136584922864866, 'reg_alpha': 9.267915611871232e-05, 'reg_lambda': 0.007867617817691417}. Best is trial 2 with value: 1.7061648609325477.
# [I 2026-06-15 06:06:51,218] Trial 16 pruned.
# [I 2026-06-15 06:06:54,546] Trial 17 pruned.
# [I 2026-06-15 06:07:06,489] Trial 18 pruned.
# [I 2026-06-15 06:07:09,605] Trial 19 pruned.
# [I 2026-06-15 06:08:55,463] Trial 20 finished with value: 1.7145499360690204 and parameters: {'n_estimators': 3311, 'learning_rate': 0.003670255109095971, 'max_depth': 5, 'min_child_weight': 0.010825117624685654, 'gamma': 9.207834502381042, 'subsample': 0.6259883401420862, 'colsample_bytree': 0.8901252743324245, 'reg_alpha': 0.02076114774608232, 'reg_lambda': 0.012869285860036094}. Best is trial 2 with value: 1.7061648609325477.
# [I 2026-06-15 06:10:14,964] Trial 21 finished with value: 1.7178777278088542 and parameters: {'n_estimators': 3484, 'learning_rate': 0.003842226452185392, 'max_depth': 5, 'min_child_weight': 0.011852657412666471, 'gamma': 9.067258589995172, 'subsample': 0.6546132843781011, 'colsample_bytree': 0.9005360568871793, 'reg_alpha': 0.05416525155032146, 'reg_lambda': 0.010112204936631015}. Best is trial 2 with value: 1.7061648609325477.
# [I 2026-06-15 06:12:30,067] Trial 22 finished with value: 1.717619904554302 and parameters: {'n_estimators': 3257, 'learning_rate': 0.0029208109057494713, 'max_depth': 5, 'min_child_weight': 0.010984904325890223, 'gamma': 9.437519661494324, 'subsample': 0.6222039902697608, 'colsample_bytree': 0.9946583823596207, 'reg_alpha': 0.027631674232991257, 'reg_lambda': 0.001704835020308066}. Best is trial 2 with value: 1.7061648609325477.
# [I 2026-06-15 06:13:22,299] Trial 23 pruned.
# [I 2026-06-15 06:15:28,485] Trial 24 finished with value: 1.714060279862763 and parameters: {'n_estimators': 2804, 'learning_rate': 0.0026164788833611652, 'max_depth': 6, 'min_child_weight': 0.03207310460098612, 'gamma': 7.848774901460422, 'subsample': 0.6042766999539945, 'colsample_bytree': 0.7132190789781543, 'reg_alpha': 0.0035849619178030135, 'reg_lambda': 0.020264729078054062}. Best is trial 2 with value: 1.7061648609325477.
# [I 2026-06-15 06:17:52,476] Trial 25 finished with value: 1.713012638524519 and parameters: {'n_estimators': 2742, 'learning_rate': 0.0026464176449374375, 'max_depth': 7, 'min_child_weight': 0.03775691104017259, 'gamma': 7.256313701119361, 'subsample': 0.7316915146377875, 'colsample_bytree': 0.6702118022972327, 'reg_alpha': 0.36142889591710725, 'reg_lambda': 0.030498707789394234}. Best is trial 2 with value: 1.7061648609325477.
# [I 2026-06-15 06:18:51,749] Trial 26 finished with value: 1.6978642183583932 and parameters: {'n_estimators': 1609, 'learning_rate': 0.009470869946461435, 'max_depth': 11, 'min_child_weight': 0.07658638239642364, 'gamma': 4.919779822026933, 'subsample': 0.7250169630282906, 'colsample_bytree': 0.6330869647497746, 'reg_alpha': 0.2565390933601031, 'reg_lambda': 0.002122308015578743}. Best is trial 26 with value: 1.6978642183583932.
# [I 2026-06-15 06:20:02,021] Trial 27 finished with value: 1.7005165723249758 and parameters: {'n_estimators': 1499, 'learning_rate': 0.01027211765396897, 'max_depth': 12, 'min_child_weight': 0.08194257583127271, 'gamma': 4.436845015353384, 'subsample': 0.3695177124334029, 'colsample_bytree': 0.637358609985945, 'reg_alpha': 0.0007660790927527445, 'reg_lambda': 0.0022704970317511163}. Best is trial 26 with value: 1.6978642183583932.
# [I 2026-06-15 06:21:21,603] Trial 28 finished with value: 1.7018850055026866 and parameters: {'n_estimators': 1637, 'learning_rate': 0.008908131824087754, 'max_depth': 12, 'min_child_weight': 0.10447428719706058, 'gamma': 4.826492912029622, 'subsample': 0.7344864861472217, 'colsample_bytree': 0.654150983955254, 'reg_alpha': 0.0003746538828244485, 'reg_lambda': 0.00040294896388288196}. Best is trial 26 with value: 1.6978642183583932.
# [I 2026-06-15 06:22:01,497] Trial 29 pruned.
# [I 2026-06-15 06:23:18,252] Trial 30 finished with value: 1.710325283467656 and parameters: {'n_estimators': 1469, 'learning_rate': 0.0089374036849998, 'max_depth': 11, 'min_child_weight': 0.116265288279854, 'gamma': 5.8691135295814085, 'subsample': 0.895081593358845, 'colsample_bytree': 0.7526148086300664, 'reg_alpha': 0.0034625456656477913, 'reg_lambda': 0.004112198691918111}. Best is trial 26 with value: 1.6978642183583932.
# [I 2026-06-15 06:23:58,996] Trial 31 pruned.
# [I 2026-06-15 06:24:45,842] Trial 32 finished with value: 1.7103888246209267 and parameters: {'n_estimators': 1387, 'learning_rate': 0.013444501941202428, 'max_depth': 11, 'min_child_weight': 0.01890010247306243, 'gamma': 3.8653205335414134, 'subsample': 0.7608457209850282, 'colsample_bytree': 0.6389629857840772, 'reg_alpha': 0.006623965959383784, 'reg_lambda': 0.002181373495242665}. Best is trial 26 with value: 1.6978642183583932.
# [I 2026-06-15 06:24:54,722] Trial 33 pruned.
# [I 2026-06-15 06:25:06,507] Trial 34 pruned.
# [I 2026-06-15 06:25:31,746] Trial 35 pruned.
# [I 2026-06-15 06:26:19,195] Trial 36 pruned.
# [I 2026-06-15 06:27:19,679] Trial 37 pruned.
# [I 2026-06-15 06:27:30,660] Trial 38 pruned.
# [I 2026-06-15 06:27:38,884] Trial 39 pruned.
# [I 2026-06-15 06:28:00,030] Trial 40 pruned.
# [I 2026-06-15 06:29:27,426] Trial 41 finished with value: 1.7131557718528785 and parameters: {'n_estimators': 1334, 'learning_rate': 0.004892087079323623, 'max_depth': 8, 'min_child_weight': 0.15646782925547545, 'gamma': 8.234241818991057, 'subsample': 0.3925418914059914, 'colsample_bytree': 0.5696712296314621, 'reg_alpha': 1.4448402206072801, 'reg_lambda': 0.001282631719670643}. Best is trial 26 with value: 1.6978642183583932.
# [I 2026-06-15 06:30:41,613] Trial 42 finished with value: 1.6940729475900462 and parameters: {'n_estimators': 1710, 'learning_rate': 0.005764562868018237, 'max_depth': 12, 'min_child_weight': 0.027103613940684702, 'gamma': 12.389697022757941, 'subsample': 0.3558763750806118, 'colsample_bytree': 0.8194914729874649, 'reg_alpha': 0.21694013396118988, 'reg_lambda': 0.0003252761198389708}. Best is trial 42 with value: 1.6940729475900462.
# [I 2026-06-15 06:32:43,297] Trial 43 pruned.
# [I 2026-06-15 06:33:35,721] Trial 44 finished with value: 1.7099798953288134 and parameters: {'n_estimators': 2075, 'learning_rate': 0.007234235893027351, 'max_depth': 11, 'min_child_weight': 0.0597400558039787, 'gamma': 10.40023119155433, 'subsample': 0.4130215127477326, 'colsample_bytree': 0.543267906517734, 'reg_alpha': 0.06838509485092333, 'reg_lambda': 0.00048395735834309465}. Best is trial 42 with value: 1.6940729475900462.
# [I 2026-06-15 06:34:47,450] Trial 45 pruned.
# [I 2026-06-15 06:36:55,065] Trial 46 finished with value: 1.712660176846455 and parameters: {'n_estimators': 1832, 'learning_rate': 0.003839253679118696, 'max_depth': 12, 'min_child_weight': 0.1222802283256759, 'gamma': 6.794909673459232, 'subsample': 0.3623190060203915, 'colsample_bytree': 0.5878197819228222, 'reg_alpha': 0.00011787919902189929, 'reg_lambda': 0.00023088534782473983}. Best is trial 42 with value: 1.6940729475900462.
# [I 2026-06-15 06:37:43,193] Trial 47 finished with value: 1.7024505019869989 and parameters: {'n_estimators': 2445, 'learning_rate': 0.008338279864228516, 'max_depth': 11, 'min_child_weight': 0.045445642753894594, 'gamma': 5.392292649824261, 'subsample': 0.5417774983944311, 'colsample_bytree': 0.7307652338670447, 'reg_alpha': 0.3152011136595096, 'reg_lambda': 0.005054318700763967}. Best is trial 42 with value: 1.6940729475900462.
# [I 2026-06-15 06:38:29,304] Trial 48 finished with value: 1.6848975718438208 and parameters: {'n_estimators': 2538, 'learning_rate': 0.010328343144531642, 'max_depth': 11, 'min_child_weight': 0.08637211179740148, 'gamma': 12.705318414449403, 'subsample': 0.4190120849407554, 'colsample_bytree': 0.8369901798539898, 'reg_alpha': 0.009090104864760426, 'reg_lambda': 0.0791648314783262}. Best is trial 48 with value: 1.6848975718438208.
# [I 2026-06-15 06:39:31,770] Trial 49 finished with value: 1.7200975597245787 and parameters: {'n_estimators': 737, 'learning_rate': 0.021321400416842645, 'max_depth': 9, 'min_child_weight': 0.2581091147680528, 'gamma': 12.84574349897226, 'subsample': 0.43001168452624006, 'colsample_bytree': 0.8364679958715168, 'reg_alpha': 0.0018969925273821721, 'reg_lambda': 0.31752633575174866}. Best is trial 48 with value: 1.6848975718438208.
# [I 2026-06-15 06:39:32,016] A new study created in RDB with name: KHOU_v8_base_lightgbm_mae_f
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 06:40:36,315] Trial 0 finished with value: 2.0108096974572494 and parameters: {'n_estimators': 447, 'learning_rate': 0.028873871707375695, 'num_leaves': 71, 'max_depth': 5, 'min_child_samples': 83, 'min_split_gain': 4.295687454742988, 'bagging_fraction': 0.7829586385137167, 'bagging_freq': 4, 'feature_fraction': 0.3688589858758342, 'lambda_l1': 0.06382334403151436, 'lambda_l2': 0.03080292177315921}. Best is trial 0 with value: 2.0108096974572494.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 06:47:50,851] Trial 1 finished with value: 2.0294607601888135 and parameters: {'n_estimators': 2817, 'learning_rate': 0.004074615160588706, 'num_leaves': 32, 'max_depth': 13, 'min_child_samples': 57, 'min_split_gain': 2.0249472402362985, 'bagging_fraction': 0.5554627061618356, 'bagging_freq': 1, 'feature_fraction': 0.898096051249308, 'lambda_l1': 1.5391104005532914, 'lambda_l2': 132.19976430960952}. Best is trial 0 with value: 2.0108096974572494.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 06:48:17,806] Trial 2 finished with value: 1.8327735260836373 and parameters: {'n_estimators': 1379, 'learning_rate': 0.1944487980595256, 'num_leaves': 230, 'max_depth': 10, 'min_child_samples': 22, 'min_split_gain': 4.485492899907672, 'bagging_fraction': 0.5437022754476957, 'bagging_freq': 2, 'feature_fraction': 0.353334206891897, 'lambda_l1': 0.00032993636349211094, 'lambda_l2': 0.09925376145099525}. Best is trial 2 with value: 1.8327735260836373.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 06:48:26,189] Trial 3 finished with value: 2.5922940058938506 and parameters: {'n_estimators': 2246, 'learning_rate': 0.22165362064553062, 'num_leaves': 466, 'max_depth': 13, 'min_child_samples': 132, 'min_split_gain': 0.5200947492738145, 'bagging_fraction': 0.4675944869176356, 'bagging_freq': 7, 'feature_fraction': 0.6177694392011331, 'lambda_l1': 2.399967979035352, 'lambda_l2': 1.7195277953675168}. Best is trial 2 with value: 1.8327735260836373.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 06:52:37,830] Trial 4 finished with value: 2.0398525129031038 and parameters: {'n_estimators': 2219, 'learning_rate': 0.004579029224032115, 'num_leaves': 460, 'max_depth': 4, 'min_child_samples': 102, 'min_split_gain': 4.967862461970517, 'bagging_fraction': 0.8282226029796285, 'bagging_freq': 4, 'feature_fraction': 0.7144310601384277, 'lambda_l1': 8.61124348208611e-06, 'lambda_l2': 3.808668235343267}. Best is trial 2 with value: 1.8327735260836373.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 06:53:03,677] Trial 5 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 06:53:46,095] Trial 6 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 06:53:47,926] Trial 7 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 06:53:50,752] Trial 8 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 06:56:33,283] Trial 9 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 06:57:14,605] Trial 10 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 06:57:55,613] Trial 11 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 07:08:54,920] Trial 12 finished with value: 1.9757857869966355 and parameters: {'n_estimators': 3174, 'learning_rate': 0.0010925194811392835, 'num_leaves': 301, 'max_depth': 11, 'min_child_samples': 74, 'min_split_gain': 2.613988081636218, 'bagging_fraction': 0.8796537260629015, 'bagging_freq': 5, 'feature_fraction': 0.5960609706435204, 'lambda_l1': 8.524985832885774e-10, 'lambda_l2': 0.1169527455154188}. Best is trial 2 with value: 1.8327735260836373.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 07:09:22,951] Trial 13 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 07:09:24,442] Trial 14 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 07:09:27,171] Trial 15 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 07:09:28,392] Trial 16 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 07:09:40,910] Trial 17 finished with value: 1.949017321191342 and parameters: {'n_estimators': 1783, 'learning_rate': 0.04864572341122393, 'num_leaves': 91, 'max_depth': 9, 'min_child_samples': 41, 'min_split_gain': 4.132892006727957, 'bagging_fraction': 0.5662560585201368, 'bagging_freq': 4, 'feature_fraction': 0.8899618930175198, 'lambda_l1': 42.540711148076, 'lambda_l2': 0.011582644290167256}. Best is trial 2 with value: 1.8327735260836373.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 07:09:46,571] Trial 18 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 07:10:00,504] Trial 19 finished with value: 1.743849155869492 and parameters: {'n_estimators': 3473, 'learning_rate': 0.04578852488428539, 'num_leaves': 184, 'max_depth': 4, 'min_child_samples': 13, 'min_split_gain': 1.633948525123912, 'bagging_fraction': 0.58126637710312, 'bagging_freq': 4, 'feature_fraction': 0.7783357811218745, 'lambda_l1': 1.074747741122124e-09, 'lambda_l2': 0.007377559017382262}. Best is trial 19 with value: 1.743849155869492.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 07:12:02,724] Trial 20 finished with value: 1.7273704534086725 and parameters: {'n_estimators': 3449, 'learning_rate': 0.012050791686618947, 'num_leaves': 221, 'max_depth': 7, 'min_child_samples': 7, 'min_split_gain': 0.04810004645591315, 'bagging_fraction': 0.685937988994649, 'bagging_freq': 1, 'feature_fraction': 0.772427228137977, 'lambda_l1': 0.0004686667014769191, 'lambda_l2': 0.0018026337369408825}. Best is trial 20 with value: 1.7273704534086725.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 07:15:25,791] Trial 21 finished with value: 1.7510152836488704 and parameters: {'n_estimators': 3468, 'learning_rate': 0.012405429414511872, 'num_leaves': 221, 'max_depth': 7, 'min_child_samples': 3, 'min_split_gain': 1.6653740659816891, 'bagging_fraction': 0.6976761581665516, 'bagging_freq': 1, 'feature_fraction': 0.7668826297243814, 'lambda_l1': 0.00016983532804446316, 'lambda_l2': 0.0017161410033910418}. Best is trial 20 with value: 1.7273704534086725.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 07:20:18,386] Trial 22 finished with value: 1.7240175946991396 and parameters: {'n_estimators': 3422, 'learning_rate': 0.012136880366846417, 'num_leaves': 188, 'max_depth': 7, 'min_child_samples': 6, 'min_split_gain': 0.16257371424216893, 'bagging_fraction': 0.6920347958562258, 'bagging_freq': 1, 'feature_fraction': 0.7587665955858165, 'lambda_l1': 0.0007296636992448463, 'lambda_l2': 0.0015580708681508719}. Best is trial 22 with value: 1.7240175946991396.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 07:23:48,385] Trial 23 finished with value: 1.7192766795084147 and parameters: {'n_estimators': 2803, 'learning_rate': 0.011463689632416414, 'num_leaves': 166, 'max_depth': 6, 'min_child_samples': 11, 'min_split_gain': 0.08973227313140214, 'bagging_fraction': 0.7268124074583289, 'bagging_freq': 2, 'feature_fraction': 0.7382425750680321, 'lambda_l1': 0.004703035469907831, 'lambda_l2': 0.0017773139855421628}. Best is trial 23 with value: 1.7192766795084147.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 07:35:39,865] Trial 24 finished with value: 1.802752600053417 and parameters: {'n_estimators': 2805, 'learning_rate': 0.012801696636877, 'num_leaves': 135, 'max_depth': 7, 'min_child_samples': 36, 'min_split_gain': 0.19589217858466343, 'bagging_fraction': 0.7345511503913964, 'bagging_freq': 2, 'feature_fraction': 0.6873903584246481, 'lambda_l1': 0.009080399893216922, 'lambda_l2': 0.0015041588126055686}. Best is trial 23 with value: 1.7192766795084147.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 07:46:35,471] Trial 25 finished with value: 1.806088013897597 and parameters: {'n_estimators': 2904, 'learning_rate': 0.008041285131345973, 'num_leaves': 209, 'max_depth': 6, 'min_child_samples': 36, 'min_split_gain': 0.11720996530459091, 'bagging_fraction': 0.7323957333850323, 'bagging_freq': 1, 'feature_fraction': 0.7283484291241694, 'lambda_l1': 0.0005501065580481173, 'lambda_l2': 0.0012127682343844627}. Best is trial 23 with value: 1.7192766795084147.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 07:55:48,247] Trial 26 finished with value: 1.7439494177640746 and parameters: {'n_estimators': 3100, 'learning_rate': 0.018519807038490987, 'num_leaves': 295, 'max_depth': 7, 'min_child_samples': 3, 'min_split_gain': 0.47625545570311184, 'bagging_fraction': 0.6764371455623306, 'bagging_freq': 2, 'feature_fraction': 0.8346068295217345, 'lambda_l1': 9.795847841808628e-06, 'lambda_l2': 0.0005986741434787606}. Best is trial 23 with value: 1.7192766795084147.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 08:05:03,877] Trial 27 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 08:08:41,735] Trial 28 finished with value: 1.732069104795627 and parameters: {'n_estimators': 3212, 'learning_rate': 0.017537676332558115, 'num_leaves': 112, 'max_depth': 8, 'min_child_samples': 23, 'min_split_gain': 0.5615639740369466, 'bagging_fraction': 0.9115593910138216, 'bagging_freq': 3, 'feature_fraction': 0.7443030950310666, 'lambda_l1': 1.0227517946741578e-06, 'lambda_l2': 0.003957300661209487}. Best is trial 23 with value: 1.7192766795084147.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 08:09:18,344] Trial 29 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 08:09:43,398] Trial 30 finished with value: 1.715154023562138 and parameters: {'n_estimators': 3371, 'learning_rate': 0.02918878322169824, 'num_leaves': 197, 'max_depth': 5, 'min_child_samples': 23, 'min_split_gain': 1.3997018833972181, 'bagging_fraction': 0.7012354251341311, 'bagging_freq': 2, 'feature_fraction': 0.9581782013368707, 'lambda_l1': 0.04916893485490145, 'lambda_l2': 0.0005909689167752862}. Best is trial 30 with value: 1.715154023562138.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 08:10:23,648] Trial 31 finished with value: 1.7024989341895091 and parameters: {'n_estimators': 3302, 'learning_rate': 0.023518363924630616, 'num_leaves': 196, 'max_depth': 5, 'min_child_samples': 19, 'min_split_gain': 1.4454397293007584, 'bagging_fraction': 0.712464416962567, 'bagging_freq': 2, 'feature_fraction': 0.9838287593087431, 'lambda_l1': 0.07510440662436721, 'lambda_l2': 0.00048582304076785223}. Best is trial 31 with value: 1.7024989341895091.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 08:10:43,959] Trial 32 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 08:10:47,782] Trial 33 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 08:11:07,245] Trial 34 finished with value: 1.709151262875595 and parameters: {'n_estimators': 3261, 'learning_rate': 0.020963957700855358, 'num_leaves': 248, 'max_depth': 5, 'min_child_samples': 23, 'min_split_gain': 1.444117101229595, 'bagging_fraction': 0.6349556738836125, 'bagging_freq': 2, 'feature_fraction': 0.9404284672312255, 'lambda_l1': 0.0026087051397087613, 'lambda_l2': 0.000130546512360913}. Best is trial 31 with value: 1.7024989341895091.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 08:11:25,403] Trial 35 finished with value: 1.731650616936962 and parameters: {'n_estimators': 3231, 'learning_rate': 0.02045737408126181, 'num_leaves': 250, 'max_depth': 5, 'min_child_samples': 24, 'min_split_gain': 1.390766793378453, 'bagging_fraction': 0.6099047019634285, 'bagging_freq': 2, 'feature_fraction': 0.9509873812549712, 'lambda_l1': 0.01575063117587994, 'lambda_l2': 0.00010514007492881852}. Best is trial 31 with value: 1.7024989341895091.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 08:11:34,487] Trial 36 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 08:12:36,520] Trial 37 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 08:15:04,137] Trial 38 finished with value: 1.7179189186127277 and parameters: {'n_estimators': 2766, 'learning_rate': 0.004919665575749804, 'num_leaves': 275, 'max_depth': 3, 'min_child_samples': 17, 'min_split_gain': 1.3003343578320523, 'bagging_fraction': 0.6488224768749324, 'bagging_freq': 2, 'feature_fraction': 0.8788466361731379, 'lambda_l1': 0.25096729217992814, 'lambda_l2': 0.004549659715175589}. Best is trial 31 with value: 1.7024989341895091.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 08:16:28,031] Trial 39 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 08:17:07,714] Trial 40 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 08:22:31,672] Trial 41 finished with value: 1.7093543429852898 and parameters: {'n_estimators': 2762, 'learning_rate': 0.005561954345153443, 'num_leaves': 247, 'max_depth': 5, 'min_child_samples': 17, 'min_split_gain': 1.855633735887713, 'bagging_fraction': 0.6426124317038742, 'bagging_freq': 2, 'feature_fraction': 0.9689586839659572, 'lambda_l1': 0.03252268192265418, 'lambda_l2': 0.00025917914562430114}. Best is trial 31 with value: 1.7024989341895091.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 08:27:47,408] Trial 42 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 08:35:22,263] Trial 43 finished with value: 1.7056702283067642 and parameters: {'n_estimators': 2621, 'learning_rate': 0.003153459936791632, 'num_leaves': 203, 'max_depth': 4, 'min_child_samples': 20, 'min_split_gain': 1.9034402238982078, 'bagging_fraction': 0.6054313602623365, 'bagging_freq': 1, 'feature_fraction': 0.9209917996300219, 'lambda_l1': 0.15283164148316883, 'lambda_l2': 0.000785719295304774}. Best is trial 31 with value: 1.7024989341895091.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 08:42:03,765] Trial 44 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 08:54:21,516] Trial 45 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 09:01:40,835] Trial 46 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 09:02:03,356] Trial 47 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 09:04:23,810] Trial 48 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 09:05:20,215] Trial 49 pruned.
# [I 2026-06-15 09:05:20,494] A new study created in RDB with name: KHOU_v8_base_catboost_mae_f
# [I 2026-06-15 09:27:39,314] Trial 0 finished with value: 2.5247667373946716 and parameters: {'iterations': 2931, 'learning_rate': 0.001783588943232587, 'depth': 10, 'l2_leaf_reg': 0.9942958882300413, 'random_strength': 7.186216756161439, 'bagging_temperature': 12.184767612363034, 'border_count': 110, 'rsm': 0.6158971964095841}. Best is trial 0 with value: 2.5247667373946716.
# [I 2026-06-15 09:37:05,345] Trial 1 finished with value: 2.4340132745281475 and parameters: {'iterations': 1809, 'learning_rate': 0.05045361458210069, 'depth': 12, 'l2_leaf_reg': 2.206716955900187, 'random_strength': 8.55303042123218, 'bagging_temperature': 2.269274022399408, 'border_count': 68, 'rsm': 0.9723568448941463}. Best is trial 1 with value: 2.4340132745281475.
# [I 2026-06-15 09:38:26,330] Trial 2 finished with value: 2.247947398701107 and parameters: {'iterations': 3305, 'learning_rate': 0.13018523290940803, 'depth': 9, 'l2_leaf_reg': 0.29456409265689415, 'random_strength': 12.736640276136784, 'bagging_temperature': 2.78292503969807, 'border_count': 126, 'rsm': 0.9180110703516069}. Best is trial 2 with value: 2.247947398701107.
# [I 2026-06-15 09:40:39,889] Trial 3 finished with value: 2.3086488924812896 and parameters: {'iterations': 941, 'learning_rate': 0.039289187448897187, 'depth': 11, 'l2_leaf_reg': 0.17184213389305913, 'random_strength': 11.258999163179464, 'bagging_temperature': 3.183105276262954, 'border_count': 57, 'rsm': 0.4176149246436502}. Best is trial 2 with value: 2.247947398701107.
# [I 2026-06-15 09:45:29,743] Trial 4 finished with value: 4.050013645331791 and parameters: {'iterations': 750, 'learning_rate': 0.012345725775087685, 'depth': 10, 'l2_leaf_reg': 185.34152922460115, 'random_strength': 16.100344011609046, 'bagging_temperature': 7.548308114328448, 'border_count': 139, 'rsm': 0.3882842988918503}. Best is trial 2 with value: 2.247947398701107.
# [I 2026-06-15 10:16:01,348] Trial 5 pruned.
# [I 2026-06-15 10:26:20,933] Trial 6 finished with value: 1.9023799831773895 and parameters: {'iterations': 3092, 'learning_rate': 0.0016894180053021765, 'depth': 7, 'l2_leaf_reg': 2.9770736659303028, 'random_strength': 2.1794700787166432, 'bagging_temperature': 3.0746892172349938, 'border_count': 252, 'rsm': 0.5265140999127667}. Best is trial 6 with value: 1.9023799831773895.
# [I 2026-06-15 10:27:51,460] Trial 7 finished with value: 1.9341069945348228 and parameters: {'iterations': 3146, 'learning_rate': 0.0024764229908984673, 'depth': 3, 'l2_leaf_reg': 0.6951779671472356, 'random_strength': 6.148451176512449, 'bagging_temperature': 8.441103735088014, 'border_count': 95, 'rsm': 0.7192489923988105}. Best is trial 6 with value: 1.9023799831773895.
# [I 2026-06-15 10:28:19,535] Trial 8 finished with value: 2.0854848291366874 and parameters: {'iterations': 378, 'learning_rate': 0.08194116550819189, 'depth': 4, 'l2_leaf_reg': 95.92707399961093, 'random_strength': 18.034879593317157, 'bagging_temperature': 0.3171560070252766, 'border_count': 220, 'rsm': 0.7891440128855358}. Best is trial 6 with value: 1.9023799831773895.
# [I 2026-06-15 10:29:04,897] Trial 9 pruned.
# [I 2026-06-15 10:34:24,113] Trial 10 finished with value: 2.2869836110302715 and parameters: {'iterations': 2620, 'learning_rate': 0.0018243204452312886, 'depth': 7, 'l2_leaf_reg': 66.23068301639817, 'random_strength': 0.365102153659036, 'bagging_temperature': 3.658074414811323, 'border_count': 43, 'rsm': 0.9046434784876821}. Best is trial 6 with value: 1.9023799831773895.
# [I 2026-06-15 10:34:37,812] Trial 11 pruned.
# [I 2026-06-15 10:35:38,804] Trial 12 pruned.
# [I 2026-06-15 10:35:50,808] Trial 13 pruned.
# [I 2026-06-15 10:36:43,694] Trial 14 pruned.
# [I 2026-06-15 11:02:22,190] Trial 15 finished with value: 2.1809614342604227 and parameters: {'iterations': 1533, 'learning_rate': 0.00677555105014573, 'depth': 11, 'l2_leaf_reg': 2.772143189189951, 'random_strength': 5.175604669479215, 'bagging_temperature': 2.338512109369544, 'border_count': 163, 'rsm': 0.5786244777864037}. Best is trial 6 with value: 1.9023799831773895.
# [I 2026-06-15 11:23:26,774] Trial 16 pruned.
# [I 2026-06-15 11:25:46,089] Trial 17 finished with value: 2.339915144503744 and parameters: {'iterations': 1447, 'learning_rate': 0.05575694750770886, 'depth': 5, 'l2_leaf_reg': 72.58680458994696, 'random_strength': 9.214098028406127, 'bagging_temperature': 18.71633726082786, 'border_count': 220, 'rsm': 0.5547113607542395}. Best is trial 6 with value: 1.9023799831773895.
# [I 2026-06-15 11:43:55,695] Trial 18 pruned.
# [I 2026-06-15 11:45:20,272] Trial 19 pruned.
# [I 2026-06-15 11:46:09,756] Trial 20 finished with value: 1.9634605819488422 and parameters: {'iterations': 3486, 'learning_rate': 0.0031221828161265204, 'depth': 2, 'l2_leaf_reg': 0.05272080051940796, 'random_strength': 3.5052369253312046, 'bagging_temperature': 9.750131674871632, 'border_count': 19, 'rsm': 0.4751182877052444}. Best is trial 6 with value: 1.9023799831773895.
# [I 2026-06-15 11:47:10,639] Trial 21 finished with value: 1.9321146577571748 and parameters: {'iterations': 3456, 'learning_rate': 0.002928433964986125, 'depth': 2, 'l2_leaf_reg': 0.10989512952082721, 'random_strength': 3.539152488165065, 'bagging_temperature': 9.883751751951994, 'border_count': 19, 'rsm': 0.4930253114169302}. Best is trial 6 with value: 1.9023799831773895.
# [I 2026-06-15 11:48:09,412] Trial 22 finished with value: 1.8428600312354535 and parameters: {'iterations': 3058, 'learning_rate': 0.0030793976419771817, 'depth': 3, 'l2_leaf_reg': 0.39705879179322784, 'random_strength': 3.7574836985461753, 'bagging_temperature': 5.9078080292997015, 'border_count': 22, 'rsm': 0.5126000525801067}. Best is trial 22 with value: 1.8428600312354535.
# [I 2026-06-15 11:48:49,669] Trial 23 finished with value: 1.99510135400246 and parameters: {'iterations': 2889, 'learning_rate': 0.0012832045781608684, 'depth': 2, 'l2_leaf_reg': 0.055157117690379114, 'random_strength': 3.5673042218070714, 'bagging_temperature': 5.058428712128438, 'border_count': 21, 'rsm': 0.5048188848688917}. Best is trial 22 with value: 1.8428600312354535.
# [I 2026-06-15 11:50:10,422] Trial 24 finished with value: 1.864249337949187 and parameters: {'iterations': 2267, 'learning_rate': 0.0031659145042851424, 'depth': 5, 'l2_leaf_reg': 0.14359718647839395, 'random_strength': 3.3864840508074088, 'bagging_temperature': 6.035308083092801, 'border_count': 30, 'rsm': 0.5354071619223021}. Best is trial 22 with value: 1.8428600312354535.
# [I 2026-06-15 11:51:26,773] Trial 25 pruned.
# [I 2026-06-15 11:53:24,181] Trial 26 finished with value: 1.7640253416280265 and parameters: {'iterations': 2298, 'learning_rate': 0.004030473370846289, 'depth': 5, 'l2_leaf_reg': 6.3106753381436915, 'random_strength': 1.7472644872425667, 'bagging_temperature': 0.5660834469932556, 'border_count': 41, 'rsm': 0.6446567865539333}. Best is trial 26 with value: 1.7640253416280265.
# [I 2026-06-15 11:55:05,654] Trial 27 finished with value: 1.8900560646232867 and parameters: {'iterations': 2193, 'learning_rate': 0.004194761211434674, 'depth': 5, 'l2_leaf_reg': 9.047210342416575, 'random_strength': 3.906851220071794, 'bagging_temperature': 0.6241124525112158, 'border_count': 42, 'rsm': 0.4337974629062779}. Best is trial 26 with value: 1.7640253416280265.
# [I 2026-06-15 11:55:32,763] Trial 28 finished with value: 1.7970765505138606 and parameters: {'iterations': 2189, 'learning_rate': 0.01613275000199144, 'depth': 4, 'l2_leaf_reg': 0.21581728935674072, 'random_strength': 1.309242612837441, 'bagging_temperature': 5.515833190570735, 'border_count': 39, 'rsm': 0.666236979637858}. Best is trial 26 with value: 1.7640253416280265.
# [I 2026-06-15 11:56:14,319] Trial 29 finished with value: 1.9531137104751082 and parameters: {'iterations': 2815, 'learning_rate': 0.019187155997646685, 'depth': 4, 'l2_leaf_reg': 0.36819208352710436, 'random_strength': 0.9143540873668972, 'bagging_temperature': 10.986050634391827, 'border_count': 41, 'rsm': 0.6465123064337542}. Best is trial 26 with value: 1.7640253416280265.
# ...
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
#                   period       method  count     mae_f    rmse_f
# 0   validation_2024_2025      xgboost    727  1.660401  2.791505
# 1   validation_2024_2025     lightgbm    727  1.753390  2.867129
# 2   validation_2024_2025     catboost    727  1.651095  2.764698
# 3   validation_2024_2025     hrrr_raw    727  2.580021  4.041296
# 4   validation_2024_2025      gfs_raw    727  2.633905  4.043772
# 5              test_2026      xgboost    138  1.681795  2.312683
# 6              test_2026     lightgbm    138  1.709715  2.281661
# 7              test_2026     catboost    138  1.500974  1.999894
# 8              test_2026  ridge_stack    138  1.543434  2.069538
# 9              test_2026     hrrr_raw    138  2.086037  3.182691
# 10             test_2026      gfs_raw    138  1.902165  2.843842

# %% [markdown]
# ## V8 Feature Coverage

# %%
v8_feature_coverage = (
    result.features[V8_FEATURE_COLUMNS]
    .notna()
    .mean()
    .mul(100)
    .sort_values(ascending=False)
    .rename("coverage_pct")
    .reset_index()
    .rename(columns={"index": "feature"})
)

v8_feature_coverage
# Out:
#                                               feature  coverage_pct
# 0                    v2_morning_warmup_to_consensus_f    100.000000
# 1                      v3_high_so_far_above_current_f    100.000000
# 2                      v2_humidity_warmup_interaction    100.000000
# 3                              v2_spread_per_warmup_f    100.000000
# 4            v3_humidity_remaining_warmup_interaction    100.000000
# 5                    v3_remaining_warmup_per_spread_f    100.000000
# 6                              v4_any_forecast_precip    100.000000
# 7              v3_remaining_warmup_from_high_so_far_f    100.000000
# 8             observed_high_so_far_change_since_9am_f    100.000000
# 9     v8_provider_median_remaining_from_high_so_far_f    100.000000
# 10       v8_provider_max_remaining_from_high_so_far_f    100.000000
# 11       v8_provider_min_remaining_from_high_so_far_f    100.000000
# 12                     observed_temp_change_last_1h_f    100.000000
# 13                     observed_temp_change_last_3h_f    100.000000
# 14            observed_morning_warmup_rate_f_per_hour    100.000000
# 15                       v4_observed_wet_forecast_dry    100.000000
# 16                  v4_forecast_observed_precip_match    100.000000
# 17                       v4_forecast_wet_observed_dry    100.000000
# 18                             v4_observed_precip_any    100.000000
# 19                             v4_all_forecast_precip    100.000000
# 20                    v8_month_remaining_warmup_count    100.000000
# 21          v8_provider_spread_per_remaining_warmup_f    100.000000
# 22                          v2_recent_heat_momentum_f     99.949084
# 23                     v2_consensus_minus_7d_actual_f     99.949084
# 24                   v3_high_so_far_minus_7d_actual_f     99.949084
# 25                           v2_recent_heat_anomaly_f     99.949084
# 26                      v3_high_so_far_minus_lag_1d_f     99.949084
# 27                   v4_observed_precip_recent_mm_est     99.898167
# 28               v8_recent_remaining_warmup_7d_mean_f     99.898167
# 29              v8_recent_remaining_warmup_30d_mean_f     99.745418
# 30       v8_provider_mean_remaining_vs_month_normal_f     98.778004
# 31                   v8_month_remaining_warmup_mean_f     98.778004
# 32                    v4_forecast_precip_total_max_mm      0.000000
# 33                 v4_forecast_precip_total_spread_mm      0.000000
# 34                   v4_forecast_precip_total_mean_mm      0.000000
# 35                  v4_forecast_precip_max_1h_mean_mm      0.000000
# 36                   v4_forecast_precip_intensity_max      0.000000
# 37                  v4_forecast_precip_intensity_mean      0.000000
# 38                      v4_forecast_precip_hours_mean      0.000000
# 39         v4_forecast_total_minus_observed_recent_mm      0.000000
# 40             v4_precip_remaining_warmup_interaction      0.000000
# 41                     v4_precip_humidity_interaction      0.000000
# 42   v8_cloud_cover_mean_remaining_warmup_interaction      0.000000
# 43    v8_cloud_cover_max_remaining_warmup_interaction      0.000000
# 44       v8_precip_total_remaining_warmup_interaction      0.000000
# 45      v8_precip_max_1h_remaining_warmup_interaction      0.000000
# 46    v8_wind_speed_mean_remaining_warmup_interaction      0.000000
# 47      v8_wind_gust_max_remaining_warmup_interaction      0.000000
# 48                        v8_forecast_dewpoint_mean_f      0.000000
# 49             v8_forecast_dewpoint_depression_mean_f      0.000000
# 50      v8_dewpoint_mean_remaining_warmup_interaction      0.000000
# 51  v8_dewpoint_depression_remaining_warmup_intera...      0.000000

# %%
result.feature_columns.loc[result.feature_columns["feature"].isin(V8_FEATURE_COLUMNS)]
# Out:
#                                              feature     kind
# 20                    observed_temp_change_last_1h_f  numeric
# 21                    observed_temp_change_last_3h_f  numeric
# 22           observed_morning_warmup_rate_f_per_hour  numeric
# 23           observed_high_so_far_change_since_9am_f  numeric
# 163                         v2_recent_heat_anomaly_f  numeric
# 164                        v2_recent_heat_momentum_f  numeric
# 165                 v2_morning_warmup_to_consensus_f  numeric
# 166                   v2_consensus_minus_7d_actual_f  numeric
# 167                           v2_spread_per_warmup_f  numeric
# 168                   v2_humidity_warmup_interaction  numeric
# 169                   v3_high_so_far_above_current_f  numeric
# 170           v3_remaining_warmup_from_high_so_far_f  numeric
# 171                    v3_high_so_far_minus_lag_1d_f  numeric
# 172                 v3_high_so_far_minus_7d_actual_f  numeric
# 173                 v3_remaining_warmup_per_spread_f  numeric
# 174         v3_humidity_remaining_warmup_interaction  numeric
# 175                           v4_any_forecast_precip  numeric
# 176                           v4_all_forecast_precip  numeric
# 177                           v4_observed_precip_any  numeric
# 178                 v4_observed_precip_recent_mm_est  numeric
# 179                v4_forecast_observed_precip_match  numeric
# 180                     v4_forecast_wet_observed_dry  numeric
# 181                     v4_observed_wet_forecast_dry  numeric
# 182     v8_provider_max_remaining_from_high_so_far_f  numeric
# 183     v8_provider_min_remaining_from_high_so_far_f  numeric
# 184  v8_provider_median_remaining_from_high_so_far_f  numeric
# 185        v8_provider_spread_per_remaining_warmup_f  numeric
# 186                 v8_month_remaining_warmup_mean_f  numeric
# 187                  v8_month_remaining_warmup_count  numeric
# 188             v8_recent_remaining_warmup_7d_mean_f  numeric
# 189            v8_recent_remaining_warmup_30d_mean_f  numeric
# 190     v8_provider_mean_remaining_vs_month_normal_f  numeric

# %% [markdown]
# ## Dropped Feature Check

# %%
dropped_present = result.feature_columns.loc[
    result.feature_columns["feature"].isin(V8_DROPPED_FEATURE_COLUMNS)
]

dropped_present
# Out:
# Empty DataFrame
# Columns: [feature, kind]
# Index: []

# %% [markdown]
# ## Morning Trend Coverage

# %%
trend_coverage = (
    result.features[TREND_COLUMNS]
    .notna()
    .mean()
    .mul(100)
    .sort_values(ascending=False)
    .rename("coverage_pct")
    .reset_index()
    .rename(columns={"index": "feature"})
)

trend_coverage
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 trend_coverage = (
# ----> 2     result.features[TREND_COLUMNS]
#       3     .notna()
#       4     .mean()
#       5     .mul(100)
#
# NameError: name 'TREND_COLUMNS' is not defined

# %% [markdown]
# ## Rounded Within 1F Accuracy

# %%
preds = pd.concat(
    [
        result.validation_predictions.assign(period="validation_2024_2025"),
        result.test_predictions.assign(period="oof_2026"),
    ],
    ignore_index=True,
)

predicted_high = pd.to_numeric(preds["predicted_high_f"], errors="coerce")
preds["predicted_high_rounded_f"] = np.floor(predicted_high + 0.5)
preds["within_1f_after_round"] = (
    pd.to_numeric(preds["actual_high_f"], errors="coerce") - preds["predicted_high_rounded_f"]
).abs().le(1)

within_1f_accuracy_by_period = (
    preds
    .dropna(subset=["actual_high_f", "predicted_high_rounded_f"])
    .groupby(["period", "method"], as_index=False)
    .agg(
        count=("within_1f_after_round", "size"),
        within_1f_count=("within_1f_after_round", "sum"),
        within_1f_accuracy_pct=("within_1f_after_round", lambda x: x.mean() * 100),
    )
    .sort_values(["period", "within_1f_accuracy_pct"], ascending=[True, False])
)

within_1f_accuracy_by_period
# Out:
#                   period       method  count  within_1f_count  \
# 5               oof_2026  ridge_stack    138               85
# 0               oof_2026     catboost    138               83
# 1               oof_2026      gfs_raw    138               80
# 6               oof_2026      xgboost    138               80
# 3               oof_2026     lightgbm    138               78
# 2               oof_2026     hrrr_raw    138               73
# 4               oof_2026      nbm_raw    138               72
# 7   validation_2024_2025     catboost    727              429
# 12  validation_2024_2025      xgboost    727              428
# 10  validation_2024_2025     lightgbm    727              406
# 8   validation_2024_2025      gfs_raw    727              309
# 9   validation_2024_2025     hrrr_raw    727              301
# 11  validation_2024_2025      nbm_raw    727              259
#
#     within_1f_accuracy_pct
# 5                61.594203
# 0                60.144928
# 1                57.971014
# 6                57.971014
# 3                56.521739
# 2                52.898551
# 4                52.173913
# 7                59.009629
# 12               58.872077
# 10               55.845942
# 8                42.503439
# 9                41.403026
# 11               35.625860

# %% [markdown]
# ## Version Comparison

# %%
comparison_frames = []
for version, folder in [
    ("v1", PROJECT_ROOT / "data" / "calibration" / "station_stacking"),
    ("v2", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v2"),
    ("v3", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v3"),
    ("v4", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v4"),
    ("v5", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v5"),
    ("v6", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v6"),
    ("v7", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v7"),
    ("v8", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v8"),
]:
    path = folder / f"{STATION_ID}_year_split_scoreboard.csv"
    if path.exists():
        frame = pd.read_csv(path)
        frame["version"] = version
        comparison_frames.append(frame)

version_comparison = pd.concat(comparison_frames, ignore_index=True) if comparison_frames else pd.DataFrame()
if not version_comparison.empty:
    version_comparison = version_comparison.sort_values(["period", "mae_f", "version", "method"]).reset_index(drop=True)
version_comparison
# Out:
#                   period       method  count     mae_f    rmse_f version
# 0              test_2026     catboost    113  1.494937  2.042136      v7
# 1              test_2026     catboost    138  1.500974  1.999894      v8
# 2              test_2026  ridge_stack    113  1.520068  2.109425      v7
# 3              test_2026  ridge_stack    138  1.543434  2.069538      v8
# 4              test_2026     catboost    112  1.618150  2.285576      v6
# ..                   ...          ...    ...       ...       ...     ...
# 72  validation_2024_2025      gfs_raw    660  3.229322  5.522959      v3
# 73  validation_2024_2025      gfs_raw    660  3.229322  5.522959      v5
# 74  validation_2024_2025      xgboost    660  3.389709  5.303918      v2
# 75  validation_2024_2025      xgboost    660  3.571129  5.524430      v3
# 76  validation_2024_2025      xgboost    660  3.584630  5.485720      v1
#
# [77 rows x 6 columns]

# %% [markdown]
# ## 2026 OOF Weather Brackets

# %%
result.bracket_metrics
# Out:
#         method  count     mae_f    rmse_f  bracket_accuracy_pct
# 0      xgboost    138  1.681795  2.312683              40.57971
# 1     lightgbm    138  1.709715  2.281661             41.304348
# 2     catboost    138  1.500974  1.999894             41.304348
# 3  ridge_stack    138  1.543434  2.069538             38.405797
# 4     hrrr_raw    138  2.086037  3.182691             36.231884
# 5      gfs_raw    138  1.902165  2.843842             36.956522

# %% [markdown]
# # Station Stacking v8 - KLGA
#
# Experimental notebook for `KLGA`.
#
# This version keeps the v7 live-safe GFS/HRRR/NBM contract, adds source-owned remaining-warmup feature engineering, and drops only conservative zero-importance input fields. Artifacts are written to `data/calibration/station_stacking_v8`.

# %%
from pathlib import Path
import os
import sys
import warnings

warnings.filterwarnings("ignore", message="IProgress not found.*")
warnings.filterwarnings("ignore", message="Skipping features without any observed values.*")

PROJECT_ROOT = Path.cwd().resolve()
while not (PROJECT_ROOT / "src" / "calibration" / "station_stacking.py").exists():
    if PROJECT_ROOT.parent == PROJECT_ROOT:
        raise RuntimeError("Could not find project root containing src/calibration/station_stacking.py")
    PROJECT_ROOT = PROJECT_ROOT.parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

os.environ["WEATHER_RESEARCH_INCLUDE_DIRECT_NBM"] = "1"

STATION_ID = "KLGA"
PROVIDERS = ("gfs", "hrrr", "nbm")
TIMING_MODE = "same_day_11am_live_safe"
FAST_MODE = False
OPTUNA_TRIALS = 50
STACK_OPTUNA_TRIALS = 50
OPTUNA_STARTUP_TRIALS = 20
STACK_OPTUNA_STARTUP_TRIALS = 20
OPTUNA_METRIC = "mae_f"
OPTUNA_VERBOSE = True
PROJECT_ROOT
# Out:
# WindowsPath('D:/dev/weather-research')

# %%
import numpy as np
import pandas as pd

from src.calibration.station_stacking import (
    StationStackingConfig,
    V8_DROPPED_FEATURE_COLUMNS,
    V8_FEATURE_COLUMNS,
    YEAR_SPLIT_EXPANDING_FOLDS,
    missing_model_dependencies,
    provider_availability,
    run_station_year_split_experiment,
)

# %% [markdown]
# ## V8 Contract
#
# `feature_version="v8"` keeps the v7 live-safe NBM setup and direct `actual_high_f` target. V8 adds remaining-warmup features and removes only conservative zero-importance model inputs from the feature matrix.

# %%
fold_spec = pd.DataFrame(
    [
        {
            "fold": fold.name,
            "train_start_year": fold.train_start_year,
            "train_end_year": fold.train_end_year,
            "validation_year": fold.validation_year,
        }
        for fold in YEAR_SPLIT_EXPANDING_FOLDS
    ]
)

fold_spec
# Out:
#                      fold  train_start_year  train_end_year  validation_year
# 0  fold_2021_2023_to_2024              2021            2023             2024
# 1  fold_2021_2024_to_2025              2021            2024             2025

# %%
V8_FEATURE_COLUMNS, sorted(V8_DROPPED_FEATURE_COLUMNS)
# Out:
# (['v2_recent_heat_anomaly_f',
#   'v2_recent_heat_momentum_f',
#   'v2_morning_warmup_to_consensus_f',
#   'v2_consensus_minus_7d_actual_f',
#   'v2_spread_per_warmup_f',
#   'v2_humidity_warmup_interaction',
#   'v3_high_so_far_above_current_f',
#   'v3_remaining_warmup_from_high_so_far_f',
#   'v3_high_so_far_minus_lag_1d_f',
#   'v3_high_so_far_minus_7d_actual_f',
#   'v3_remaining_warmup_per_spread_f',
#   'v3_humidity_remaining_warmup_interaction',
#   'v4_forecast_precip_total_mean_mm',
#   'v4_forecast_precip_total_max_mm',
#   'v4_forecast_precip_total_spread_mm',
#   'v4_forecast_precip_max_1h_mean_mm',
#   'v4_forecast_precip_hours_mean',
#   'v4_forecast_precip_intensity_mean',
#   'v4_forecast_precip_intensity_max',
#   'v4_any_forecast_precip',
#   'v4_all_forecast_precip',
#   'v4_observed_precip_any',
#   'v4_observed_precip_recent_mm_est',
#   'v4_forecast_total_minus_observed_recent_mm',
#   'v4_forecast_observed_precip_match',
#   'v4_forecast_wet_observed_dry',
#   'v4_observed_wet_forecast_dry',
#   'v4_precip_humidity_interaction',
#   'v4_precip_remaining_warmup_interaction',
#   'observed_temp_change_last_1h_f',
#   'observed_temp_change_last_3h_f',
#   'observed_morning_warmup_rate_f_per_hour',
#   'observed_high_so_far_change_since_9am_f',
#   'v8_provider_max_remaining_from_high_so_far_f',
#   'v8_provider_min_remaining_from_high_so_far_f',
#   'v8_provider_median_remaining_from_high_so_far_f',
#   'v8_provider_spread_per_remaining_warmup_f',
#   'v8_month_remaining_warmup_mean_f',
#   'v8_month_remaining_warmup_count',
#   'v8_recent_remaining_warmup_7d_mean_f',
#   'v8_recent_remaining_warmup_30d_mean_f',
#   'v8_provider_mean_remaining_vs_month_normal_f',
#   'v8_cloud_cover_mean_remaining_warmup_interaction',
#   'v8_cloud_cover_max_remaining_warmup_interaction',
#   'v8_precip_total_remaining_warmup_interaction',
#   'v8_precip_max_1h_remaining_warmup_interaction',
#   'v8_wind_speed_mean_remaining_warmup_interaction',
#   'v8_wind_gust_max_remaining_warmup_interaction',
#   'v8_forecast_dewpoint_mean_f',
#   'v8_forecast_dewpoint_depression_mean_f',
#   'v8_dewpoint_mean_remaining_warmup_interaction',
#   'v8_dewpoint_depression_remaining_warmup_interaction'],
#  ['gfs_as_of_hour_local',
#   'gfs_available',
#   'gfs_forecast_window_hours',
#   'gfs_grid_dist_km_mean',
#   'gfs_horizon_hours',
#   'gfs_hrrr_grid_dist_km_mean_abs_diff_f',
#   'gfs_hrrr_grid_dist_km_mean_diff_f',
#   'gfs_issue_hour_utc',
#   'gfs_missing',
#   'hrrr_as_of_hour_local',
#   'hrrr_available',
#   'hrrr_forecast_hour_max',
#   'hrrr_forecast_hour_min',
#   'hrrr_forecast_lead_hours',
#   'hrrr_forecast_window_hours',
#   'hrrr_grid_dist_km_mean',
#   'hrrr_horizon_hours',
#   'hrrr_issue_hour_local',
#   'hrrr_issue_hour_utc',
#   'hrrr_missing',
#   'is_active_polymarket_station',
#   'lat',
#   'lon',
#   'nbm_as_of_hour_local',
#   'nbm_available',
#   'nbm_forecast_window_hours',
#   'nbm_horizon_hours',
#   'nbm_issue_hour_local',
#   'nbm_issue_hour_utc',
#   'nbm_missing',
#   'observed_fetch_status',
#   'observed_observation_type',
#   'observed_pressure_source',
#   'provider_count_available',
#   'year'])

# %% [markdown]
# ## Data Availability

# %%
availability = provider_availability(
    PROJECT_ROOT,
    timing_mode=TIMING_MODE,
    providers=PROVIDERS,
)

availability.loc[availability["station_id"].eq(STATION_ID)]
# Out:
#    station_id provider  row_count first_contract_date last_contract_date
# 15       KLGA      gfs       1987          2021-01-01         2026-06-10
# 16       KLGA     hrrr       1987          2021-01-01         2026-06-10
# 17       KLGA      nbm       1986          2021-01-01         2026-06-10

# %% [markdown]
# ## Model Scores

# %%
missing_packages = missing_model_dependencies()
if missing_packages:
    raise ImportError(
        "Missing station-stacking ML packages: "
        + ", ".join(missing_packages)
        + ". Install them with: python -m pip install -r requirements.txt"
    )

config = StationStackingConfig(
    station_id=STATION_ID,
    project_root=PROJECT_ROOT,
    timing_mode=TIMING_MODE,
    providers=PROVIDERS,
    fast_mode=FAST_MODE,
    optuna_trials=OPTUNA_TRIALS,
    stack_optuna_trials=STACK_OPTUNA_TRIALS,
    optuna_startup_trials=OPTUNA_STARTUP_TRIALS,
    stack_optuna_startup_trials=STACK_OPTUNA_STARTUP_TRIALS,
    optuna_metric=OPTUNA_METRIC,
    optuna_verbose=OPTUNA_VERBOSE,
    feature_version="v8",
    hyperparameter_space="wide",
    year_split_folds=YEAR_SPLIT_EXPANDING_FOLDS,
    year_split_test_train_years=(2021, 2025),
    year_split_test_year=2026,
    output_dir=PROJECT_ROOT / "data" / "calibration" / "station_stacking_v8",
)

config.resolved_optuna_storage_path()
# Out:
# WindowsPath('D:/dev/weather-research/data/calibration/station_stacking_v8/KLGA_optuna.sqlite3')

# %%
result = run_station_year_split_experiment(config)
result.scoreboard
# Out:
# [I 2026-06-15 05:48:10,775] A new study created in RDB with name: KLGA_v8_base_xgboost_mae_f
# [I 2026-06-15 05:48:28,448] Trial 0 finished with value: 1.529836094332381 and parameters: {'n_estimators': 1342, 'learning_rate': 0.19043899115982607, 'max_depth': 9, 'min_child_weight': 2.481040974867813, 'gamma': 2.340279606636548, 'subsample': 0.4513964382185317, 'colsample_bytree': 0.3877543479093296, 'reg_alpha': 2.478071022662141, 'reg_lambda': 0.6132587025321562}. Best is trial 0 with value: 1.529836094332381.
# [I 2026-06-15 05:52:11,432] Trial 1 finished with value: 1.8770324840259627 and parameters: {'n_estimators': 2493, 'learning_rate': 0.001120367191095075, 'max_depth': 12, 'min_child_weight': 21.368329072358772, 'gamma': 3.185086660174142, 'subsample': 0.4681862286846154, 'colsample_bytree': 0.46921293140473197, 'reg_alpha': 4.476173538513514e-07, 'reg_lambda': 0.20253776634919213}. Best is trial 0 with value: 1.529836094332381.
# [I 2026-06-15 05:55:17,678] Trial 2 finished with value: 1.4743670240950189 and parameters: {'n_estimators': 1540, 'learning_rate': 0.004992867109217114, 'max_depth': 8, 'min_child_weight': 0.03613894271216528, 'gamma': 4.3821697280282725, 'subsample': 0.5881351981408995, 'colsample_bytree': 0.6464454897410734, 'reg_alpha': 0.26430874752361627, 'reg_lambda': 0.0018119678627933364}. Best is trial 2 with value: 1.4743670240950189.
# [I 2026-06-15 05:56:51,592] Trial 3 finished with value: 1.5658097212203583 and parameters: {'n_estimators': 1824, 'learning_rate': 0.026337502897485255, 'max_depth': 1, 'min_child_weight': 2.69264691008618, 'gamma': 2.557861855309373, 'subsample': 0.39228353544043165, 'colsample_bytree': 0.9667755992146666, 'reg_alpha': 38.6887231523051, 'reg_lambda': 12.408975837016275}. Best is trial 2 with value: 1.4743670240950189.
# [I 2026-06-15 06:00:04,266] Trial 4 finished with value: 3.154254547516568 and parameters: {'n_estimators': 1101, 'learning_rate': 0.0017147936629846843, 'max_depth': 9, 'min_child_weight': 0.5762487216478605, 'gamma': 1.8305735226716824, 'subsample': 0.6718649915723256, 'colsample_bytree': 0.37235253872489193, 'reg_alpha': 8.162906555194692, 'reg_lambda': 0.004271500153828077}. Best is trial 2 with value: 1.4743670240950189.
# [I 2026-06-15 06:04:15,009] Trial 5 finished with value: 1.599195343561782 and parameters: {'n_estimators': 2336, 'learning_rate': 0.00559067775661512, 'max_depth': 7, 'min_child_weight': 1.5375920235481764, 'gamma': 2.7728168328829055, 'subsample': 0.980230008046963, 'colsample_bytree': 0.8538363351847245, 'reg_alpha': 18.792618557420877, 'reg_lambda': 43.484449457612314}. Best is trial 2 with value: 1.4743670240950189.
# [I 2026-06-15 06:04:22,765] Trial 6 finished with value: 1.5570164393889405 and parameters: {'n_estimators': 2113, 'learning_rate': 0.16240489353272883, 'max_depth': 2, 'min_child_weight': 0.06080390190296603, 'gamma': 0.678409333658071, 'subsample': 0.5614647149961218, 'colsample_bytree': 0.6026402382981633, 'reg_alpha': 1.8037999945880162e-07, 'reg_lambda': 16.668629892722056}. Best is trial 2 with value: 1.4743670240950189.
# [I 2026-06-15 06:06:46,768] Trial 7 finished with value: 1.475921909434643 and parameters: {'n_estimators': 1281, 'learning_rate': 0.0047169807141865345, 'max_depth': 7, 'min_child_weight': 0.0366181922039243, 'gamma': 12.032954711310595, 'subsample': 0.398457918391851, 'colsample_bytree': 0.9914765087903362, 'reg_alpha': 0.18490013641000916, 'reg_lambda': 0.0017869543989965139}. Best is trial 2 with value: 1.4743670240950189.
# [I 2026-06-15 06:06:50,708] Trial 8 pruned.
# [I 2026-06-15 06:08:13,511] Trial 9 finished with value: 1.5731942612257357 and parameters: {'n_estimators': 2201, 'learning_rate': 0.006215464818952927, 'max_depth': 1, 'min_child_weight': 0.17535949529764422, 'gamma': 4.877749830401205, 'subsample': 0.8242440159197416, 'colsample_bytree': 0.7644123563808884, 'reg_alpha': 4.4315220126915325, 'reg_lambda': 0.09450187118503514}. Best is trial 2 with value: 1.4743670240950189.
# [I 2026-06-15 06:08:36,189] Trial 10 finished with value: 1.5069281323838628 and parameters: {'n_estimators': 462, 'learning_rate': 0.051323729958866915, 'max_depth': 10, 'min_child_weight': 1.7583640270008525, 'gamma': 11.564507699318415, 'subsample': 0.670967137636854, 'colsample_bytree': 0.689776339098296, 'reg_alpha': 1.3504926357029513e-05, 'reg_lambda': 0.0001445994629863374}. Best is trial 2 with value: 1.4743670240950189.
# [I 2026-06-15 06:08:58,273] Trial 11 pruned.
# [I 2026-06-15 06:09:18,093] Trial 12 pruned.
# [I 2026-06-15 06:09:28,660] Trial 13 finished with value: 1.5284768716876866 and parameters: {'n_estimators': 693, 'learning_rate': 0.13813474572232612, 'max_depth': 7, 'min_child_weight': 16.973078532467014, 'gamma': 13.4413694988524, 'subsample': 0.5567022587317115, 'colsample_bytree': 0.4215337509429899, 'reg_alpha': 5.435280359192946e-08, 'reg_lambda': 0.049115547267693904}. Best is trial 2 with value: 1.4743670240950189.
# [I 2026-06-15 06:09:38,981] Trial 14 pruned.
# [I 2026-06-15 06:10:15,765] Trial 15 finished with value: 1.5320926521176321 and parameters: {'n_estimators': 1165, 'learning_rate': 0.01753996764864722, 'max_depth': 9, 'min_child_weight': 0.28478585168562975, 'gamma': 14.57673124081441, 'subsample': 0.9755907417123723, 'colsample_bytree': 0.5136584922864866, 'reg_alpha': 9.267915611871232e-05, 'reg_lambda': 0.007867617817691417}. Best is trial 2 with value: 1.4743670240950189.
# [I 2026-06-15 06:11:46,817] Trial 16 pruned.
# [I 2026-06-15 06:11:50,979] Trial 17 pruned.
# [I 2026-06-15 06:12:24,401] Trial 18 finished with value: 1.4806948858447777 and parameters: {'n_estimators': 2236, 'learning_rate': 0.01926440281006607, 'max_depth': 2, 'min_child_weight': 21.938654178115062, 'gamma': 4.811700974576038, 'subsample': 0.4712370317599052, 'colsample_bytree': 0.3765038420105965, 'reg_alpha': 0.0012322967930262527, 'reg_lambda': 1.859316691031827}. Best is trial 2 with value: 1.4743670240950189.
# [I 2026-06-15 06:12:28,193] Trial 19 pruned.
# [I 2026-06-15 06:14:52,483] Trial 20 finished with value: 1.4788307902939035 and parameters: {'n_estimators': 3311, 'learning_rate': 0.003670255109095971, 'max_depth': 5, 'min_child_weight': 0.010825117624685654, 'gamma': 9.207834502381042, 'subsample': 0.6259883401420862, 'colsample_bytree': 0.8901252743324245, 'reg_alpha': 0.02076114774608232, 'reg_lambda': 0.012869285860036094}. Best is trial 2 with value: 1.4743670240950189.
# [I 2026-06-15 06:17:09,545] Trial 21 finished with value: 1.486774074796061 and parameters: {'n_estimators': 3484, 'learning_rate': 0.003842226452185392, 'max_depth': 5, 'min_child_weight': 0.011852657412666471, 'gamma': 9.067258589995172, 'subsample': 0.6546132843781011, 'colsample_bytree': 0.9005360568871793, 'reg_alpha': 0.05416525155032146, 'reg_lambda': 0.010112204936631015}. Best is trial 2 with value: 1.4743670240950189.
# [I 2026-06-15 06:20:34,924] Trial 22 finished with value: 1.478920690130792 and parameters: {'n_estimators': 3257, 'learning_rate': 0.0029208109057494713, 'max_depth': 5, 'min_child_weight': 0.010984904325890223, 'gamma': 9.437519661494324, 'subsample': 0.6222039902697608, 'colsample_bytree': 0.9946583823596207, 'reg_alpha': 0.027631674232991257, 'reg_lambda': 0.001704835020308066}. Best is trial 2 with value: 1.4743670240950189.
# [I 2026-06-15 06:21:42,407] Trial 23 pruned.
# [I 2026-06-15 06:25:34,016] Trial 24 finished with value: 1.483279142214166 and parameters: {'n_estimators': 2804, 'learning_rate': 0.0026164788833611652, 'max_depth': 6, 'min_child_weight': 0.03207310460098612, 'gamma': 7.848774901460422, 'subsample': 0.6042766999539945, 'colsample_bytree': 0.7132190789781543, 'reg_alpha': 0.0035849619178030135, 'reg_lambda': 0.020264729078054062}. Best is trial 2 with value: 1.4743670240950189.
# [I 2026-06-15 06:26:48,447] Trial 25 finished with value: 1.49112520778659 and parameters: {'n_estimators': 1414, 'learning_rate': 0.008299987643734434, 'max_depth': 12, 'min_child_weight': 0.024805385926896125, 'gamma': 13.11311481985289, 'subsample': 0.7316915146377875, 'colsample_bytree': 0.8298189124129385, 'reg_alpha': 0.36142889591710725, 'reg_lambda': 0.0028017399171312587}. Best is trial 2 with value: 1.4743670240950189.
# [I 2026-06-15 06:28:38,168] Trial 26 finished with value: 1.4634775759389105 and parameters: {'n_estimators': 1922, 'learning_rate': 0.004565947851445241, 'max_depth': 6, 'min_child_weight': 0.07658638239642364, 'gamma': 10.822049870481713, 'subsample': 0.36054728750028886, 'colsample_bytree': 0.9137336691025132, 'reg_alpha': 0.0027361299969985535, 'reg_lambda': 0.028549329549124907}. Best is trial 26 with value: 1.4634775759389105.
# [I 2026-06-15 06:29:45,184] Trial 27 finished with value: 1.4459559197489822 and parameters: {'n_estimators': 1886, 'learning_rate': 0.011117220755349492, 'max_depth': 7, 'min_child_weight': 0.08194257583127271, 'gamma': 10.70210505239059, 'subsample': 0.36286648557956797, 'colsample_bytree': 0.9613252410248188, 'reg_alpha': 0.0007660790927527445, 'reg_lambda': 0.0004615943164796123}. Best is trial 27 with value: 1.4459559197489822.
# [I 2026-06-15 06:30:59,034] Trial 28 finished with value: 1.4467125369887137 and parameters: {'n_estimators': 1830, 'learning_rate': 0.00959221113152912, 'max_depth': 11, 'min_child_weight': 0.10447428719706058, 'gamma': 6.251953015720163, 'subsample': 0.3596572439673767, 'colsample_bytree': 0.7743750350488265, 'reg_alpha': 0.0003969835053270476, 'reg_lambda': 0.00036471208004417306}. Best is trial 27 with value: 1.4459559197489822.
# [I 2026-06-15 06:32:24,933] Trial 29 finished with value: 1.4585554260481222 and parameters: {'n_estimators': 1960, 'learning_rate': 0.011100265997766747, 'max_depth': 11, 'min_child_weight': 0.07465590306050865, 'gamma': 10.690614550462298, 'subsample': 0.35224319408354626, 'colsample_bytree': 0.7800272614287065, 'reg_alpha': 0.00030280640573063217, 'reg_lambda': 0.00028327651220870595}. Best is trial 27 with value: 1.4459559197489822.
# [I 2026-06-15 06:33:24,392] Trial 30 finished with value: 1.4612676101871243 and parameters: {'n_estimators': 2517, 'learning_rate': 0.010976279428311147, 'max_depth': 11, 'min_child_weight': 0.10824612462501718, 'gamma': 7.7602884782110015, 'subsample': 0.42410425393941975, 'colsample_bytree': 0.7464914342070406, 'reg_alpha': 0.0001651594679749245, 'reg_lambda': 0.00032525116780115316}. Best is trial 27 with value: 1.4459559197489822.
# [I 2026-06-15 06:34:18,827] Trial 31 finished with value: 1.454060550006996 and parameters: {'n_estimators': 2579, 'learning_rate': 0.011238822388776746, 'max_depth': 11, 'min_child_weight': 0.12368099671672866, 'gamma': 7.1707245741656145, 'subsample': 0.43305576292925496, 'colsample_bytree': 0.7775630807898758, 'reg_alpha': 6.122938219869056e-05, 'reg_lambda': 0.00040712173512839005}. Best is trial 27 with value: 1.4459559197489822.
# [I 2026-06-15 06:34:29,399] Trial 32 pruned.
# [I 2026-06-15 06:35:12,622] Trial 33 finished with value: 1.4609647824054828 and parameters: {'n_estimators': 2499, 'learning_rate': 0.013103702605698106, 'max_depth': 11, 'min_child_weight': 0.12828720143718955, 'gamma': 6.308276491992946, 'subsample': 0.44273549014375857, 'colsample_bytree': 0.6682616327442611, 'reg_alpha': 3.4207479016948306e-05, 'reg_lambda': 0.0005869082566270693}. Best is trial 27 with value: 1.4459559197489822.
# [I 2026-06-15 06:36:50,401] Trial 34 finished with value: 1.4597918880954914 and parameters: {'n_estimators': 1674, 'learning_rate': 0.007579323369918836, 'max_depth': 10, 'min_child_weight': 0.2972601384123093, 'gamma': 10.38827336536741, 'subsample': 0.35547462362802873, 'colsample_bytree': 0.796640888023584, 'reg_alpha': 0.0011148925598718617, 'reg_lambda': 0.00012299966758969183}. Best is trial 27 with value: 1.4459559197489822.
# [I 2026-06-15 06:37:01,105] Trial 35 pruned.
# [I 2026-06-15 06:37:43,640] Trial 36 finished with value: 1.4716845864090473 and parameters: {'n_estimators': 2019, 'learning_rate': 0.013575569741383752, 'max_depth': 10, 'min_child_weight': 0.07007653606206396, 'gamma': 6.970391957733767, 'subsample': 0.40538085365917037, 'colsample_bytree': 0.8539837903717094, 'reg_alpha': 0.00035913923672595824, 'reg_lambda': 0.0011372260129606157}. Best is trial 27 with value: 1.4459559197489822.
# [I 2026-06-15 06:37:50,925] Trial 37 pruned.
# [I 2026-06-15 06:38:07,684] Trial 38 pruned.
# [I 2026-06-15 06:43:41,665] Trial 39 finished with value: 1.4521914748385278 and parameters: {'n_estimators': 3024, 'learning_rate': 0.006565003498496348, 'max_depth': 10, 'min_child_weight': 0.21990433692091055, 'gamma': 3.817059087982287, 'subsample': 0.35085406604697655, 'colsample_bytree': 0.7841903203771199, 'reg_alpha': 1.3310098444571814e-10, 'reg_lambda': 0.00010797106421242371}. Best is trial 27 with value: 1.4459559197489822.
# [I 2026-06-15 06:46:04,651] Trial 40 pruned.
# [I 2026-06-15 06:49:23,043] Trial 41 finished with value: 1.4538967487279506 and parameters: {'n_estimators': 3000, 'learning_rate': 0.011187301655626753, 'max_depth': 11, 'min_child_weight': 0.05188762884145973, 'gamma': 3.4430282836024704, 'subsample': 0.3738743479038219, 'colsample_bytree': 0.7846538674576612, 'reg_alpha': 1.2705566949662315e-08, 'reg_lambda': 0.0005543734488655054}. Best is trial 27 with value: 1.4459559197489822.
# [I 2026-06-15 06:53:31,103] Trial 42 finished with value: 1.4581831794511453 and parameters: {'n_estimators': 2947, 'learning_rate': 0.009186844320807987, 'max_depth': 9, 'min_child_weight': 0.04704651480749789, 'gamma': 3.5106540624120117, 'subsample': 0.3801204146255527, 'colsample_bytree': 0.7005443402710999, 'reg_alpha': 1.1627943276554833e-10, 'reg_lambda': 0.000645568394795162}. Best is trial 27 with value: 1.4459559197489822.
# [I 2026-06-15 06:57:51,519] Trial 43 finished with value: 1.4724756654831208 and parameters: {'n_estimators': 2367, 'learning_rate': 0.015369312114779576, 'max_depth': 12, 'min_child_weight': 0.7437832156303668, 'gamma': 3.985026118180568, 'subsample': 0.4543380964105046, 'colsample_bytree': 0.8281885079403524, 'reg_alpha': 1.4252382782522117e-08, 'reg_lambda': 0.0017094397349135986}. Best is trial 27 with value: 1.4459559197489822.
# [I 2026-06-15 07:04:54,088] Trial 44 finished with value: 1.459345844794938 and parameters: {'n_estimators': 3072, 'learning_rate': 0.005889745208943103, 'max_depth': 8, 'min_child_weight': 0.18071140542381517, 'gamma': 5.430983693089244, 'subsample': 0.49953270068215316, 'colsample_bytree': 0.9557825312522196, 'reg_alpha': 7.024329150488925e-09, 'reg_lambda': 0.00010414231360311209}. Best is trial 27 with value: 1.4459559197489822.
# [I 2026-06-15 07:07:09,009] Trial 45 finished with value: 1.4778983056498214 and parameters: {'n_estimators': 2703, 'learning_rate': 0.022844791066016033, 'max_depth': 10, 'min_child_weight': 0.01770324388172471, 'gamma': 1.7602199122337794, 'subsample': 0.3891797375954595, 'colsample_bytree': 0.7801539807740521, 'reg_alpha': 4.331478020738345e-10, 'reg_lambda': 0.004269136229391438}. Best is trial 27 with value: 1.4459559197489822.
# [I 2026-06-15 07:08:06,103] Trial 46 finished with value: 1.4580216838133646 and parameters: {'n_estimators': 3116, 'learning_rate': 0.01144934393893932, 'max_depth': 9, 'min_child_weight': 0.1112343521098089, 'gamma': 5.496505325724595, 'subsample': 0.41948950000334173, 'colsample_bytree': 0.6690470879155228, 'reg_alpha': 4.7131890866491276e-06, 'reg_lambda': 0.0005266293024158712}. Best is trial 27 with value: 1.4459559197489822.
# [I 2026-06-15 07:11:27,264] Trial 47 finished with value: 1.4848910979991272 and parameters: {'n_estimators': 2656, 'learning_rate': 0.0073199787830234226, 'max_depth': 11, 'min_child_weight': 0.4038806910670634, 'gamma': 0.0029108803655475413, 'subsample': 0.38369713758734725, 'colsample_bytree': 0.7487250824572197, 'reg_alpha': 6.175924908052072e-07, 'reg_lambda': 0.001215711678036825}. Best is trial 27 with value: 1.4459559197489822.
# [I 2026-06-15 07:12:28,281] Trial 48 pruned.
# [I 2026-06-15 07:15:56,883] Trial 49 pruned.
# [I 2026-06-15 07:15:57,031] A new study created in RDB with name: KLGA_v8_base_lightgbm_mae_f
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 07:16:54,336] Trial 0 finished with value: 1.6751042807129695 and parameters: {'n_estimators': 447, 'learning_rate': 0.028873871707375695, 'num_leaves': 71, 'max_depth': 5, 'min_child_samples': 83, 'min_split_gain': 4.295687454742988, 'bagging_fraction': 0.7829586385137167, 'bagging_freq': 4, 'feature_fraction': 0.3688589858758342, 'lambda_l1': 0.06382334403151436, 'lambda_l2': 0.03080292177315921}. Best is trial 0 with value: 1.6751042807129695.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 07:22:13,901] Trial 1 finished with value: 1.7982377523865527 and parameters: {'n_estimators': 2817, 'learning_rate': 0.004074615160588706, 'num_leaves': 32, 'max_depth': 13, 'min_child_samples': 57, 'min_split_gain': 2.0249472402362985, 'bagging_fraction': 0.5554627061618356, 'bagging_freq': 1, 'feature_fraction': 0.898096051249308, 'lambda_l1': 1.5391104005532914, 'lambda_l2': 132.19976430960952}. Best is trial 0 with value: 1.6751042807129695.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 07:22:34,069] Trial 2 finished with value: 1.5669588070861775 and parameters: {'n_estimators': 1379, 'learning_rate': 0.1944487980595256, 'num_leaves': 230, 'max_depth': 10, 'min_child_samples': 22, 'min_split_gain': 4.485492899907672, 'bagging_fraction': 0.5437022754476957, 'bagging_freq': 2, 'feature_fraction': 0.353334206891897, 'lambda_l1': 0.00032993636349211094, 'lambda_l2': 0.09925376145099525}. Best is trial 2 with value: 1.5669588070861775.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 07:23:04,913] Trial 3 finished with value: 2.4913095773124163 and parameters: {'n_estimators': 2246, 'learning_rate': 0.22165362064553062, 'num_leaves': 466, 'max_depth': 13, 'min_child_samples': 132, 'min_split_gain': 0.5200947492738145, 'bagging_fraction': 0.4675944869176356, 'bagging_freq': 7, 'feature_fraction': 0.6177694392011331, 'lambda_l1': 2.399967979035352, 'lambda_l2': 1.7195277953675168}. Best is trial 2 with value: 1.5669588070861775.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 07:35:47,261] Trial 4 finished with value: 1.7658363091516043 and parameters: {'n_estimators': 2219, 'learning_rate': 0.004579029224032115, 'num_leaves': 460, 'max_depth': 4, 'min_child_samples': 102, 'min_split_gain': 4.967862461970517, 'bagging_fraction': 0.8282226029796285, 'bagging_freq': 4, 'feature_fraction': 0.7144310601384277, 'lambda_l1': 8.61124348208611e-06, 'lambda_l2': 3.808668235343267}. Best is trial 2 with value: 1.5669588070861775.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 07:36:55,456] Trial 5 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 07:38:53,757] Trial 6 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 07:38:59,804] Trial 7 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 07:39:11,720] Trial 8 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 07:44:36,759] Trial 9 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 07:44:43,771] Trial 10 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 07:45:29,142] Trial 11 finished with value: 1.7020287037483168 and parameters: {'n_estimators': 756, 'learning_rate': 0.06114521776634082, 'num_leaves': 57, 'max_depth': 2, 'min_child_samples': 85, 'min_split_gain': 4.846277519155279, 'bagging_fraction': 0.8056341981316478, 'bagging_freq': 3, 'feature_fraction': 0.42848891083526186, 'lambda_l1': 5.301057710204056e-10, 'lambda_l2': 3.7660106129974493}. Best is trial 2 with value: 1.5669588070861775.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 08:08:43,719] Trial 12 finished with value: 1.7655298277758193 and parameters: {'n_estimators': 3174, 'learning_rate': 0.0010925194811392835, 'num_leaves': 301, 'max_depth': 11, 'min_child_samples': 74, 'min_split_gain': 2.613988081636218, 'bagging_fraction': 0.8796537260629015, 'bagging_freq': 5, 'feature_fraction': 0.5960609706435204, 'lambda_l1': 8.524985832885774e-10, 'lambda_l2': 0.1169527455154188}. Best is trial 2 with value: 1.5669588070861775.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 08:09:27,607] Trial 13 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 08:09:30,869] Trial 14 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 08:09:34,645] Trial 15 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 08:09:35,914] Trial 16 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 08:09:43,232] Trial 17 finished with value: 1.6949819124156784 and parameters: {'n_estimators': 1783, 'learning_rate': 0.04864572341122393, 'num_leaves': 91, 'max_depth': 9, 'min_child_samples': 41, 'min_split_gain': 4.132892006727957, 'bagging_fraction': 0.5662560585201368, 'bagging_freq': 4, 'feature_fraction': 0.8899618930175198, 'lambda_l1': 42.540711148076, 'lambda_l2': 0.011582644290167256}. Best is trial 2 with value: 1.5669588070861775.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 08:09:45,681] Trial 18 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 08:10:10,644] Trial 19 finished with value: 1.469987111505729 and parameters: {'n_estimators': 3473, 'learning_rate': 0.04578852488428539, 'num_leaves': 184, 'max_depth': 4, 'min_child_samples': 13, 'min_split_gain': 1.633948525123912, 'bagging_fraction': 0.58126637710312, 'bagging_freq': 4, 'feature_fraction': 0.7783357811218745, 'lambda_l1': 1.074747741122124e-09, 'lambda_l2': 0.007377559017382262}. Best is trial 19 with value: 1.469987111505729.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 08:13:59,167] Trial 20 finished with value: 1.4763168824803685 and parameters: {'n_estimators': 3449, 'learning_rate': 0.012050791686618947, 'num_leaves': 221, 'max_depth': 7, 'min_child_samples': 7, 'min_split_gain': 0.04810004645591315, 'bagging_fraction': 0.685937988994649, 'bagging_freq': 1, 'feature_fraction': 0.772427228137977, 'lambda_l1': 0.0004686667014769191, 'lambda_l2': 0.0018026337369408825}. Best is trial 19 with value: 1.469987111505729.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 08:22:06,482] Trial 21 finished with value: 1.4980156939992764 and parameters: {'n_estimators': 3468, 'learning_rate': 0.012405429414511872, 'num_leaves': 221, 'max_depth': 7, 'min_child_samples': 3, 'min_split_gain': 1.6653740659816891, 'bagging_fraction': 0.6976761581665516, 'bagging_freq': 1, 'feature_fraction': 0.7668826297243814, 'lambda_l1': 0.00016983532804446316, 'lambda_l2': 0.0017161410033910418}. Best is trial 19 with value: 1.469987111505729.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 08:36:33,434] Trial 22 finished with value: 1.4814754151138398 and parameters: {'n_estimators': 3422, 'learning_rate': 0.012136880366846417, 'num_leaves': 188, 'max_depth': 7, 'min_child_samples': 6, 'min_split_gain': 0.16257371424216893, 'bagging_fraction': 0.6920347958562258, 'bagging_freq': 1, 'feature_fraction': 0.7587665955858165, 'lambda_l1': 0.0007296636992448463, 'lambda_l2': 0.0015580708681508719}. Best is trial 19 with value: 1.469987111505729.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 08:50:02,776] Trial 23 finished with value: 1.4819961930808896 and parameters: {'n_estimators': 2803, 'learning_rate': 0.011463689632416414, 'num_leaves': 166, 'max_depth': 6, 'min_child_samples': 11, 'min_split_gain': 0.08973227313140214, 'bagging_fraction': 0.7268124074583289, 'bagging_freq': 2, 'feature_fraction': 0.7382425750680321, 'lambda_l1': 0.004703035469907831, 'lambda_l2': 0.0017773139855421628}. Best is trial 19 with value: 1.469987111505729.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 08:53:03,011] Trial 24 finished with value: 1.4718169729844965 and parameters: {'n_estimators': 3442, 'learning_rate': 0.017181116675724604, 'num_leaves': 263, 'max_depth': 3, 'min_child_samples': 30, 'min_split_gain': 0.20162519988018046, 'bagging_fraction': 0.6278417003009079, 'bagging_freq': 1, 'feature_fraction': 0.8223799407117091, 'lambda_l1': 9.97840865586377e-07, 'lambda_l2': 0.0016463309709537379}. Best is trial 19 with value: 1.469987111505729.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 08:55:54,892] Trial 25 finished with value: 1.5270919491765382 and parameters: {'n_estimators': 3021, 'learning_rate': 0.01989049568999302, 'num_leaves': 122, 'max_depth': 3, 'min_child_samples': 40, 'min_split_gain': 0.5150017301400388, 'bagging_fraction': 0.6179055898348816, 'bagging_freq': 3, 'feature_fraction': 0.8271988632255527, 'lambda_l1': 3.3809759628846126e-06, 'lambda_l2': 0.0006012839720218327}. Best is trial 19 with value: 1.469987111505729.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 09:04:16,321] Trial 26 finished with value: 1.483170188228365 and parameters: {'n_estimators': 2565, 'learning_rate': 0.006750640330840502, 'num_leaves': 274, 'max_depth': 4, 'min_child_samples': 33, 'min_split_gain': 1.5923035146294813, 'bagging_fraction': 0.7312068943854049, 'bagging_freq': 2, 'feature_fraction': 0.6706157319255103, 'lambda_l1': 3.429462943634539e-07, 'lambda_l2': 0.0050222287782427525}. Best is trial 19 with value: 1.469987111505729.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 09:05:01,778] Trial 27 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 09:09:17,212] Trial 28 finished with value: 1.4598804054754695 and parameters: {'n_estimators': 3500, 'learning_rate': 0.020178656226515598, 'num_leaves': 209, 'max_depth': 5, 'min_child_samples': 23, 'min_split_gain': 0.5235970617890513, 'bagging_fraction': 0.5118143505542393, 'bagging_freq': 1, 'feature_fraction': 0.9771920446807143, 'lambda_l1': 8.195288695655462e-07, 'lambda_l2': 0.0007056984882824929}. Best is trial 28 with value: 1.4598804054754695.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 09:11:04,791] Trial 29 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 09:12:51,199] Trial 30 finished with value: 1.4823860601406726 and parameters: {'n_estimators': 2824, 'learning_rate': 0.07202467638561193, 'num_leaves': 129, 'max_depth': 5, 'min_child_samples': 27, 'min_split_gain': 0.5430110273387039, 'bagging_fraction': 0.7596951546129965, 'bagging_freq': 2, 'feature_fraction': 0.9947817732032778, 'lambda_l1': 8.570308873846414e-07, 'lambda_l2': 0.025295630231941788}. Best is trial 28 with value: 1.4598804054754695.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 09:23:31,341] Trial 31 finished with value: 1.4596268828475343 and parameters: {'n_estimators': 3492, 'learning_rate': 0.032083327305921235, 'num_leaves': 201, 'max_depth': 6, 'min_child_samples': 19, 'min_split_gain': 0.38080132707773684, 'bagging_fraction': 0.6660560793608125, 'bagging_freq': 1, 'feature_fraction': 0.6926966562588014, 'lambda_l1': 4.63139868073627e-05, 'lambda_l2': 0.00044785316015053894}. Best is trial 31 with value: 1.4596268828475343.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 09:31:27,167] Trial 32 finished with value: 1.4495993173294435 and parameters: {'n_estimators': 3300, 'learning_rate': 0.03343016860548087, 'num_leaves': 194, 'max_depth': 4, 'min_child_samples': 23, 'min_split_gain': 2.067958138185463, 'bagging_fraction': 0.593047531942575, 'bagging_freq': 1, 'feature_fraction': 0.8565887056743531, 'lambda_l1': 1.5079162572332115e-06, 'lambda_l2': 0.0005967985736003214}. Best is trial 32 with value: 1.4495993173294435.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 09:38:04,745] Trial 33 finished with value: 1.4994795253222013 and parameters: {'n_estimators': 2957, 'learning_rate': 0.03639690524466849, 'num_leaves': 202, 'max_depth': 6, 'min_child_samples': 21, 'min_split_gain': 1.948892128164563, 'bagging_fraction': 0.5189427490086218, 'bagging_freq': 2, 'feature_fraction': 0.8802803369802628, 'lambda_l1': 3.286240117333422e-05, 'lambda_l2': 0.0006838139526209848}. Best is trial 32 with value: 1.4495993173294435.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 09:39:04,103] Trial 34 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 09:51:04,679] Trial 35 finished with value: 1.4845324694038649 and parameters: {'n_estimators': 3262, 'learning_rate': 0.028177633357145612, 'num_leaves': 198, 'max_depth': 6, 'min_child_samples': 18, 'min_split_gain': 0.8011589247988702, 'bagging_fraction': 0.527458720705247, 'bagging_freq': 3, 'feature_fraction': 0.9523070665957765, 'lambda_l1': 3.6077151683014744e-06, 'lambda_l2': 0.0004044642312147505}. Best is trial 32 with value: 1.4495993173294435.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 09:55:34,527] Trial 36 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 09:58:38,047] Trial 37 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 10:22:29,149] Trial 38 finished with value: 1.4537496919953021 and parameters: {'n_estimators': 2919, 'learning_rate': 0.006674944786843212, 'num_leaves': 90, 'max_depth': 4, 'min_child_samples': 18, 'min_split_gain': 0.7173093900429903, 'bagging_fraction': 0.4205993193925741, 'bagging_freq': 2, 'feature_fraction': 0.6821166438497444, 'lambda_l1': 0.05277321853473327, 'lambda_l2': 0.04630083790408421}. Best is trial 32 with value: 1.4495993173294435.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 10:25:00,598] Trial 39 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 10:31:14,306] Trial 40 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 10:34:19,743] Trial 41 finished with value: 1.4829374117054315 and parameters: {'n_estimators': 3061, 'learning_rate': 0.05541178432646321, 'num_leaves': 184, 'max_depth': 4, 'min_child_samples': 19, 'min_split_gain': 2.2064428805817005, 'bagging_fraction': 0.4778813126855944, 'bagging_freq': 1, 'feature_fraction': 0.6767784301581894, 'lambda_l1': 7.035184476648454e-08, 'lambda_l2': 0.027573801610799094}. Best is trial 32 with value: 1.4495993173294435.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 10:45:18,931] Trial 42 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 10:46:01,999] Trial 43 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 10:57:03,422] Trial 44 finished with value: 1.4564225527992518 and parameters: {'n_estimators': 2740, 'learning_rate': 0.016807116426149245, 'num_leaves': 231, 'max_depth': 4, 'min_child_samples': 18, 'min_split_gain': 1.037203465569943, 'bagging_fraction': 0.5027069372967022, 'bagging_freq': 3, 'feature_fraction': 0.8484999051568752, 'lambda_l1': 5.636842278593182e-07, 'lambda_l2': 0.0010119872107225403}. Best is trial 32 with value: 1.4495993173294435.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 11:06:06,291] Trial 45 finished with value: 1.4702584128203013 and parameters: {'n_estimators': 2781, 'learning_rate': 0.014665162581662337, 'num_leaves': 246, 'max_depth': 5, 'min_child_samples': 24, 'min_split_gain': 1.013599722392346, 'bagging_fraction': 0.49506721507623896, 'bagging_freq': 3, 'feature_fraction': 0.8393379970357177, 'lambda_l1': 2.3733550078237555e-07, 'lambda_l2': 0.0009391216074959635}. Best is trial 32 with value: 1.4495993173294435.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 11:08:40,925] Trial 46 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 11:12:57,956] Trial 47 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 11:17:48,366] Trial 48 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 11:28:05,343] Trial 49 pruned.
# [I 2026-06-15 11:28:05,978] A new study created in RDB with name: KLGA_v8_base_catboost_mae_f
# [I 2026-06-15 11:51:14,790] Trial 0 finished with value: 3.4142863632315454 and parameters: {'iterations': 2931, 'learning_rate': 0.001783588943232587, 'depth': 10, 'l2_leaf_reg': 0.9942958882300413, 'random_strength': 7.186216756161439, 'bagging_temperature': 12.184767612363034, 'border_count': 110, 'rsm': 0.6158971964095841}. Best is trial 0 with value: 3.4142863632315454.
# [I 2026-06-15 12:02:13,536] Trial 1 finished with value: 2.886922594769633 and parameters: {'iterations': 1809, 'learning_rate': 0.05045361458210069, 'depth': 12, 'l2_leaf_reg': 2.206716955900187, 'random_strength': 8.55303042123218, 'bagging_temperature': 2.269274022399408, 'border_count': 68, 'rsm': 0.9723568448941463}. Best is trial 1 with value: 2.886922594769633.
# [I 2026-06-15 12:03:28,427] Trial 2 finished with value: 2.178899141203052 and parameters: {'iterations': 3305, 'learning_rate': 0.13018523290940803, 'depth': 9, 'l2_leaf_reg': 0.29456409265689415, 'random_strength': 12.736640276136784, 'bagging_temperature': 2.78292503969807, 'border_count': 126, 'rsm': 0.9180110703516069}. Best is trial 2 with value: 2.178899141203052.
# [I 2026-06-15 12:07:13,066] Trial 3 finished with value: 2.413381944752449 and parameters: {'iterations': 941, 'learning_rate': 0.039289187448897187, 'depth': 11, 'l2_leaf_reg': 0.17184213389305913, 'random_strength': 11.258999163179464, 'bagging_temperature': 3.183105276262954, 'border_count': 57, 'rsm': 0.4176149246436502}. Best is trial 2 with value: 2.178899141203052.
# [I 2026-06-15 12:17:37,594] Trial 4 finished with value: 6.315510779990788 and parameters: {'iterations': 750, 'learning_rate': 0.012345725775087685, 'depth': 10, 'l2_leaf_reg': 185.34152922460115, 'random_strength': 16.100344011609046, 'bagging_temperature': 7.548308114328448, 'border_count': 139, 'rsm': 0.3882842988918503}. Best is trial 2 with value: 2.178899141203052.
# [I 2026-06-15 12:54:45,184] Trial 5 pruned.
# [I 2026-06-15 13:08:43,049] Trial 6 finished with value: 1.80873884536754 and parameters: {'iterations': 3092, 'learning_rate': 0.0016894180053021765, 'depth': 7, 'l2_leaf_reg': 2.9770736659303028, 'random_strength': 2.1794700787166432, 'bagging_temperature': 3.0746892172349938, 'border_count': 252, 'rsm': 0.5265140999127667}. Best is trial 6 with value: 1.80873884536754.
# [I 2026-06-15 13:10:43,761] Trial 7 finished with value: 1.8340122689030969 and parameters: {'iterations': 3146, 'learning_rate': 0.0024764229908984673, 'depth': 3, 'l2_leaf_reg': 0.6951779671472356, 'random_strength': 6.148451176512449, 'bagging_temperature': 8.441103735088014, 'border_count': 95, 'rsm': 0.7192489923988105}. Best is trial 6 with value: 1.80873884536754.
# [I 2026-06-15 13:11:12,858] Trial 8 finished with value: 1.9247778406184772 and parameters: {'iterations': 378, 'learning_rate': 0.08194116550819189, 'depth': 4, 'l2_leaf_reg': 95.92707399961093, 'random_strength': 18.034879593317157, 'bagging_temperature': 0.3171560070252766, 'border_count': 220, 'rsm': 0.7891440128855358}. Best is trial 6 with value: 1.80873884536754.
# [I 2026-06-15 13:11:48,190] Trial 9 pruned.
# [I 2026-06-15 13:14:48,961] Trial 10 pruned.
# [I 2026-06-15 13:15:07,856] Trial 11 pruned.
# [I 2026-06-15 13:16:20,981] Trial 12 pruned.
# [I 2026-06-15 13:16:29,902] Trial 13 pruned.
# [I 2026-06-15 13:17:19,412] Trial 14 pruned.
# [I 2026-06-15 13:32:42,403] Trial 15 pruned.
# [I 2026-06-15 13:52:33,254] Trial 16 pruned.
# [I 2026-06-15 13:53:01,900] Trial 17 pruned.
# [I 2026-06-15 14:08:02,090] Trial 18 pruned.
# ...
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
#                   period       method  count     mae_f    rmse_f
# 0   validation_2024_2025      xgboost    726  1.423659  1.830590
# 1   validation_2024_2025     lightgbm    726  1.503692  1.977839
# 2   validation_2024_2025     catboost    726  1.501164  1.977878
# 3   validation_2024_2025     hrrr_raw    726  1.957962  2.658436
# 4   validation_2024_2025      gfs_raw    726  2.404729  3.165146
# 5              test_2026      xgboost    138  1.784946  2.304505
# 6              test_2026     lightgbm    138  2.033646  2.693404
# 7              test_2026     catboost    138  2.264830  2.968731
# 8              test_2026  ridge_stack    138  1.792165  2.306571
# 9              test_2026     hrrr_raw    138  3.101148  4.363122
# 10             test_2026      gfs_raw    138  3.458600  4.757469

# %% [markdown]
# ## V8 Feature Coverage

# %%
v8_feature_coverage = (
    result.features[V8_FEATURE_COLUMNS]
    .notna()
    .mean()
    .mul(100)
    .sort_values(ascending=False)
    .rename("coverage_pct")
    .reset_index()
    .rename(columns={"index": "feature"})
)

v8_feature_coverage
# Out:
#                                               feature  coverage_pct
# 0                    v2_morning_warmup_to_consensus_f    100.000000
# 1                      v3_high_so_far_above_current_f    100.000000
# 2                      v2_humidity_warmup_interaction    100.000000
# 3                              v2_spread_per_warmup_f    100.000000
# 4            v3_humidity_remaining_warmup_interaction    100.000000
# 5                    v3_remaining_warmup_per_spread_f    100.000000
# 6                              v4_any_forecast_precip    100.000000
# 7              v3_remaining_warmup_from_high_so_far_f    100.000000
# 8                   v4_forecast_observed_precip_match    100.000000
# 9                        v4_forecast_wet_observed_dry    100.000000
# 10          v8_provider_spread_per_remaining_warmup_f    100.000000
# 11                    v8_month_remaining_warmup_count    100.000000
# 12       v8_provider_min_remaining_from_high_so_far_f    100.000000
# 13    v8_provider_median_remaining_from_high_so_far_f    100.000000
# 14       v8_provider_max_remaining_from_high_so_far_f    100.000000
# 15                       v4_observed_wet_forecast_dry    100.000000
# 16                             v4_observed_precip_any    100.000000
# 17                             v4_all_forecast_precip    100.000000
# 18                     v2_consensus_minus_7d_actual_f     99.949084
# 19                          v2_recent_heat_momentum_f     99.949084
# 20                   v3_high_so_far_minus_7d_actual_f     99.949084
# 21                           v2_recent_heat_anomaly_f     99.949084
# 22                     observed_temp_change_last_3h_f     99.949084
# 23            observed_morning_warmup_rate_f_per_hour     99.949084
# 24            observed_high_so_far_change_since_9am_f     99.949084
# 25                     observed_temp_change_last_1h_f     99.949084
# 26                   v4_observed_precip_recent_mm_est     99.949084
# 27                      v3_high_so_far_minus_lag_1d_f     99.949084
# 28               v8_recent_remaining_warmup_7d_mean_f     99.898167
# 29              v8_recent_remaining_warmup_30d_mean_f     99.745418
# 30       v8_provider_mean_remaining_vs_month_normal_f     98.778004
# 31                   v8_month_remaining_warmup_mean_f     98.778004
# 32                    v4_forecast_precip_total_max_mm      0.000000
# 33                 v4_forecast_precip_total_spread_mm      0.000000
# 34                   v4_forecast_precip_total_mean_mm      0.000000
# 35                  v4_forecast_precip_max_1h_mean_mm      0.000000
# 36                   v4_forecast_precip_intensity_max      0.000000
# 37                  v4_forecast_precip_intensity_mean      0.000000
# 38                      v4_forecast_precip_hours_mean      0.000000
# 39         v4_forecast_total_minus_observed_recent_mm      0.000000
# 40             v4_precip_remaining_warmup_interaction      0.000000
# 41                     v4_precip_humidity_interaction      0.000000
# 42   v8_cloud_cover_mean_remaining_warmup_interaction      0.000000
# 43    v8_cloud_cover_max_remaining_warmup_interaction      0.000000
# 44       v8_precip_total_remaining_warmup_interaction      0.000000
# 45      v8_precip_max_1h_remaining_warmup_interaction      0.000000
# 46    v8_wind_speed_mean_remaining_warmup_interaction      0.000000
# 47      v8_wind_gust_max_remaining_warmup_interaction      0.000000
# 48                        v8_forecast_dewpoint_mean_f      0.000000
# 49             v8_forecast_dewpoint_depression_mean_f      0.000000
# 50      v8_dewpoint_mean_remaining_warmup_interaction      0.000000
# 51  v8_dewpoint_depression_remaining_warmup_intera...      0.000000

# %%
result.feature_columns.loc[result.feature_columns["feature"].isin(V8_FEATURE_COLUMNS)]
# Out:
#                                              feature     kind
# 20                    observed_temp_change_last_1h_f  numeric
# 21                    observed_temp_change_last_3h_f  numeric
# 22           observed_morning_warmup_rate_f_per_hour  numeric
# 23           observed_high_so_far_change_since_9am_f  numeric
# 163                         v2_recent_heat_anomaly_f  numeric
# 164                        v2_recent_heat_momentum_f  numeric
# 165                 v2_morning_warmup_to_consensus_f  numeric
# 166                   v2_consensus_minus_7d_actual_f  numeric
# 167                           v2_spread_per_warmup_f  numeric
# 168                   v2_humidity_warmup_interaction  numeric
# 169                   v3_high_so_far_above_current_f  numeric
# 170           v3_remaining_warmup_from_high_so_far_f  numeric
# 171                    v3_high_so_far_minus_lag_1d_f  numeric
# 172                 v3_high_so_far_minus_7d_actual_f  numeric
# 173                 v3_remaining_warmup_per_spread_f  numeric
# 174         v3_humidity_remaining_warmup_interaction  numeric
# 175                           v4_any_forecast_precip  numeric
# 176                           v4_all_forecast_precip  numeric
# 177                           v4_observed_precip_any  numeric
# 178                 v4_observed_precip_recent_mm_est  numeric
# 179                v4_forecast_observed_precip_match  numeric
# 180                     v4_forecast_wet_observed_dry  numeric
# 181                     v4_observed_wet_forecast_dry  numeric
# 182     v8_provider_max_remaining_from_high_so_far_f  numeric
# 183     v8_provider_min_remaining_from_high_so_far_f  numeric
# 184  v8_provider_median_remaining_from_high_so_far_f  numeric
# 185        v8_provider_spread_per_remaining_warmup_f  numeric
# 186                 v8_month_remaining_warmup_mean_f  numeric
# 187                  v8_month_remaining_warmup_count  numeric
# 188             v8_recent_remaining_warmup_7d_mean_f  numeric
# 189            v8_recent_remaining_warmup_30d_mean_f  numeric
# 190     v8_provider_mean_remaining_vs_month_normal_f  numeric

# %% [markdown]
# ## Dropped Feature Check

# %%
dropped_present = result.feature_columns.loc[
    result.feature_columns["feature"].isin(V8_DROPPED_FEATURE_COLUMNS)
]

dropped_present
# Out:
# Empty DataFrame
# Columns: [feature, kind]
# Index: []

# %% [markdown]
# ## Morning Trend Coverage

# %%
trend_coverage = (
    result.features[TREND_COLUMNS]
    .notna()
    .mean()
    .mul(100)
    .sort_values(ascending=False)
    .rename("coverage_pct")
    .reset_index()
    .rename(columns={"index": "feature"})
)

trend_coverage
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 trend_coverage = (
# ----> 2     result.features[TREND_COLUMNS]
#       3     .notna()
#       4     .mean()
#       5     .mul(100)
#
# NameError: name 'TREND_COLUMNS' is not defined

# %% [markdown]
# ## Rounded Within 1F Accuracy

# %%
preds = pd.concat(
    [
        result.validation_predictions.assign(period="validation_2024_2025"),
        result.test_predictions.assign(period="oof_2026"),
    ],
    ignore_index=True,
)

predicted_high = pd.to_numeric(preds["predicted_high_f"], errors="coerce")
preds["predicted_high_rounded_f"] = np.floor(predicted_high + 0.5)
preds["within_1f_after_round"] = (
    pd.to_numeric(preds["actual_high_f"], errors="coerce") - preds["predicted_high_rounded_f"]
).abs().le(1)

within_1f_accuracy_by_period = (
    preds
    .dropna(subset=["actual_high_f", "predicted_high_rounded_f"])
    .groupby(["period", "method"], as_index=False)
    .agg(
        count=("within_1f_after_round", "size"),
        within_1f_count=("within_1f_after_round", "sum"),
        within_1f_accuracy_pct=("within_1f_after_round", lambda x: x.mean() * 100),
    )
    .sort_values(["period", "within_1f_accuracy_pct"], ascending=[True, False])
)

within_1f_accuracy_by_period
# Out:
#                   period       method  count  within_1f_count  \
# 5               oof_2026  ridge_stack    138               74
# 3               oof_2026     lightgbm    138               71
# 6               oof_2026      xgboost    138               71
# 0               oof_2026     catboost    138               62
# 4               oof_2026      nbm_raw    138               52
# 2               oof_2026     hrrr_raw    138               48
# 1               oof_2026      gfs_raw    138               40
# 12  validation_2024_2025      xgboost    726              456
# 10  validation_2024_2025     lightgbm    726              453
# 7   validation_2024_2025     catboost    726              431
# 9   validation_2024_2025     hrrr_raw    726              361
# 11  validation_2024_2025      nbm_raw    726              302
# 8   validation_2024_2025      gfs_raw    726              297
#
#     within_1f_accuracy_pct
# 5                53.623188
# 3                51.449275
# 6                51.449275
# 0                44.927536
# 4                37.681159
# 2                34.782609
# 1                28.985507
# 12               62.809917
# 10               62.396694
# 7                59.366391
# 9                49.724518
# 11               41.597796
# 8                40.909091

# %% [markdown]
# ## Version Comparison

# %%
comparison_frames = []
for version, folder in [
    ("v1", PROJECT_ROOT / "data" / "calibration" / "station_stacking"),
    ("v2", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v2"),
    ("v3", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v3"),
    ("v4", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v4"),
    ("v5", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v5"),
    ("v6", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v6"),
    ("v7", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v7"),
    ("v8", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v8"),
]:
    path = folder / f"{STATION_ID}_year_split_scoreboard.csv"
    if path.exists():
        frame = pd.read_csv(path)
        frame["version"] = version
        comparison_frames.append(frame)

version_comparison = pd.concat(comparison_frames, ignore_index=True) if comparison_frames else pd.DataFrame()
if not version_comparison.empty:
    version_comparison = version_comparison.sort_values(["period", "mae_f", "version", "method"]).reset_index(drop=True)
version_comparison
# Out:
#                   period       method  count     mae_f    rmse_f version
# 0              test_2026     catboost     56  1.462532  1.895086      v7
# 1              test_2026  ridge_stack     56  1.508430  1.957996      v7
# 2              test_2026      xgboost     56  1.610561  2.095189      v7
# 3              test_2026     lightgbm     56  1.636683  2.069996      v7
# 4              test_2026  ridge_stack     51  1.698213  2.153980      v6
# ..                   ...          ...    ...       ...       ...     ...
# 61  validation_2024_2025     hrrr_raw    664  2.427198  3.642842      v1
# 62  validation_2024_2025     hrrr_raw    664  2.427198  3.642842      v2
# 63  validation_2024_2025     catboost    664  2.431915  3.439788      v1
# 64  validation_2024_2025      gfs_raw    664  2.792138  3.930603      v1
# 65  validation_2024_2025      gfs_raw    664  2.792138  3.930603      v2
#
# [66 rows x 6 columns]

# %% [markdown]
# ## 2026 OOF Weather Brackets

# %%
result.bracket_metrics
# Out:
#         method  count     mae_f    rmse_f  bracket_accuracy_pct
# 0      xgboost    138  1.784946  2.304505             37.681159
# 1     lightgbm    138  2.033646  2.693404             32.608696
# 2     catboost    138  2.264830  2.968731              28.26087
# 3  ridge_stack    138  1.792165  2.306571             31.884058
# 4     hrrr_raw    138  3.101148  4.363122             23.188406
# 5      gfs_raw    138  3.458600  4.757469              18.84058

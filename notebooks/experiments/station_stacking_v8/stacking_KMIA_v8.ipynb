# %% [markdown]
# # Station Stacking v8 - KMIA
#
# Experimental notebook for `KMIA`.
#
# This version keeps the v7 live-safe GFS/HRRR/NBM contract, adds source-owned remaining-warmup feature engineering, and drops only conservative zero-importance input fields. Artifacts are written to `data/calibration/station_stacking_v8`.

# %%
from pathlib import Path
import os
import sys
import warnings

warnings.filterwarnings("ignore", message="IProgress not found.*")
warnings.filterwarnings("ignore", message="Skipping features without any observed values.*")

PROJECT_ROOT = Path.cwd().resolve()
while not (PROJECT_ROOT / "src" / "calibration" / "station_stacking.py").exists():
    if PROJECT_ROOT.parent == PROJECT_ROOT:
        raise RuntimeError("Could not find project root containing src/calibration/station_stacking.py")
    PROJECT_ROOT = PROJECT_ROOT.parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

os.environ["WEATHER_RESEARCH_INCLUDE_DIRECT_NBM"] = "1"

STATION_ID = "KMIA"
PROVIDERS = ("gfs", "hrrr", "nbm")
TIMING_MODE = "same_day_11am_live_safe"
FAST_MODE = False
OPTUNA_TRIALS = 50
STACK_OPTUNA_TRIALS = 50
OPTUNA_STARTUP_TRIALS = 20
STACK_OPTUNA_STARTUP_TRIALS = 20
OPTUNA_METRIC = "mae_f"
OPTUNA_VERBOSE = True
PROJECT_ROOT
# Out:
# WindowsPath('D:/dev/weather-research')

# %%
import numpy as np
import pandas as pd

from src.calibration.station_stacking import (
    StationStackingConfig,
    V8_DROPPED_FEATURE_COLUMNS,
    V8_FEATURE_COLUMNS,
    YEAR_SPLIT_EXPANDING_FOLDS,
    missing_model_dependencies,
    provider_availability,
    run_station_year_split_experiment,
)

# %% [markdown]
# ## V8 Contract
#
# `feature_version="v8"` keeps the v7 live-safe NBM setup and direct `actual_high_f` target. V8 adds remaining-warmup features and removes only conservative zero-importance model inputs from the feature matrix.

# %%
fold_spec = pd.DataFrame(
    [
        {
            "fold": fold.name,
            "train_start_year": fold.train_start_year,
            "train_end_year": fold.train_end_year,
            "validation_year": fold.validation_year,
        }
        for fold in YEAR_SPLIT_EXPANDING_FOLDS
    ]
)

fold_spec
# Out:
#                      fold  train_start_year  train_end_year  validation_year
# 0  fold_2021_2023_to_2024              2021            2023             2024
# 1  fold_2021_2024_to_2025              2021            2024             2025

# %%
V8_FEATURE_COLUMNS, sorted(V8_DROPPED_FEATURE_COLUMNS)
# Out:
# (['v2_recent_heat_anomaly_f',
#   'v2_recent_heat_momentum_f',
#   'v2_morning_warmup_to_consensus_f',
#   'v2_consensus_minus_7d_actual_f',
#   'v2_spread_per_warmup_f',
#   'v2_humidity_warmup_interaction',
#   'v3_high_so_far_above_current_f',
#   'v3_remaining_warmup_from_high_so_far_f',
#   'v3_high_so_far_minus_lag_1d_f',
#   'v3_high_so_far_minus_7d_actual_f',
#   'v3_remaining_warmup_per_spread_f',
#   'v3_humidity_remaining_warmup_interaction',
#   'v4_forecast_precip_total_mean_mm',
#   'v4_forecast_precip_total_max_mm',
#   'v4_forecast_precip_total_spread_mm',
#   'v4_forecast_precip_max_1h_mean_mm',
#   'v4_forecast_precip_hours_mean',
#   'v4_forecast_precip_intensity_mean',
#   'v4_forecast_precip_intensity_max',
#   'v4_any_forecast_precip',
#   'v4_all_forecast_precip',
#   'v4_observed_precip_any',
#   'v4_observed_precip_recent_mm_est',
#   'v4_forecast_total_minus_observed_recent_mm',
#   'v4_forecast_observed_precip_match',
#   'v4_forecast_wet_observed_dry',
#   'v4_observed_wet_forecast_dry',
#   'v4_precip_humidity_interaction',
#   'v4_precip_remaining_warmup_interaction',
#   'observed_temp_change_last_1h_f',
#   'observed_temp_change_last_3h_f',
#   'observed_morning_warmup_rate_f_per_hour',
#   'observed_high_so_far_change_since_9am_f',
#   'v8_provider_max_remaining_from_high_so_far_f',
#   'v8_provider_min_remaining_from_high_so_far_f',
#   'v8_provider_median_remaining_from_high_so_far_f',
#   'v8_provider_spread_per_remaining_warmup_f',
#   'v8_month_remaining_warmup_mean_f',
#   'v8_month_remaining_warmup_count',
#   'v8_recent_remaining_warmup_7d_mean_f',
#   'v8_recent_remaining_warmup_30d_mean_f',
#   'v8_provider_mean_remaining_vs_month_normal_f',
#   'v8_cloud_cover_mean_remaining_warmup_interaction',
#   'v8_cloud_cover_max_remaining_warmup_interaction',
#   'v8_precip_total_remaining_warmup_interaction',
#   'v8_precip_max_1h_remaining_warmup_interaction',
#   'v8_wind_speed_mean_remaining_warmup_interaction',
#   'v8_wind_gust_max_remaining_warmup_interaction',
#   'v8_forecast_dewpoint_mean_f',
#   'v8_forecast_dewpoint_depression_mean_f',
#   'v8_dewpoint_mean_remaining_warmup_interaction',
#   'v8_dewpoint_depression_remaining_warmup_interaction'],
#  ['gfs_as_of_hour_local',
#   'gfs_available',
#   'gfs_forecast_window_hours',
#   'gfs_grid_dist_km_mean',
#   'gfs_horizon_hours',
#   'gfs_hrrr_grid_dist_km_mean_abs_diff_f',
#   'gfs_hrrr_grid_dist_km_mean_diff_f',
#   'gfs_issue_hour_utc',
#   'gfs_missing',
#   'hrrr_as_of_hour_local',
#   'hrrr_available',
#   'hrrr_forecast_hour_max',
#   'hrrr_forecast_hour_min',
#   'hrrr_forecast_lead_hours',
#   'hrrr_forecast_window_hours',
#   'hrrr_grid_dist_km_mean',
#   'hrrr_horizon_hours',
#   'hrrr_issue_hour_local',
#   'hrrr_issue_hour_utc',
#   'hrrr_missing',
#   'is_active_polymarket_station',
#   'lat',
#   'lon',
#   'nbm_as_of_hour_local',
#   'nbm_available',
#   'nbm_forecast_window_hours',
#   'nbm_horizon_hours',
#   'nbm_issue_hour_local',
#   'nbm_issue_hour_utc',
#   'nbm_missing',
#   'observed_fetch_status',
#   'observed_observation_type',
#   'observed_pressure_source',
#   'provider_count_available',
#   'year'])

# %% [markdown]
# ## Data Availability

# %%
availability = provider_availability(
    PROJECT_ROOT,
    timing_mode=TIMING_MODE,
    providers=PROVIDERS,
)

availability.loc[availability["station_id"].eq(STATION_ID)]
# Out:
#    station_id provider  row_count first_contract_date last_contract_date
# 18       KMIA      gfs       1987          2021-01-01         2026-06-10
# 19       KMIA     hrrr       1987          2021-01-01         2026-06-10
# 20       KMIA      nbm       1986          2021-01-01         2026-06-10

# %% [markdown]
# ## Model Scores

# %%
missing_packages = missing_model_dependencies()
if missing_packages:
    raise ImportError(
        "Missing station-stacking ML packages: "
        + ", ".join(missing_packages)
        + ". Install them with: python -m pip install -r requirements.txt"
    )

config = StationStackingConfig(
    station_id=STATION_ID,
    project_root=PROJECT_ROOT,
    timing_mode=TIMING_MODE,
    providers=PROVIDERS,
    fast_mode=FAST_MODE,
    optuna_trials=OPTUNA_TRIALS,
    stack_optuna_trials=STACK_OPTUNA_TRIALS,
    optuna_startup_trials=OPTUNA_STARTUP_TRIALS,
    stack_optuna_startup_trials=STACK_OPTUNA_STARTUP_TRIALS,
    optuna_metric=OPTUNA_METRIC,
    optuna_verbose=OPTUNA_VERBOSE,
    feature_version="v8",
    hyperparameter_space="wide",
    year_split_folds=YEAR_SPLIT_EXPANDING_FOLDS,
    year_split_test_train_years=(2021, 2025),
    year_split_test_year=2026,
    output_dir=PROJECT_ROOT / "data" / "calibration" / "station_stacking_v8",
)

config.resolved_optuna_storage_path()
# Out:
# WindowsPath('D:/dev/weather-research/data/calibration/station_stacking_v8/KMIA_optuna.sqlite3')

# %%
result = run_station_year_split_experiment(config)
result.scoreboard
# Out:
# [I 2026-06-15 05:48:25,091] A new study created in RDB with name: KMIA_v8_base_xgboost_mae_f
# [I 2026-06-15 05:48:37,679] Trial 0 finished with value: 1.3735962053069508 and parameters: {'n_estimators': 1342, 'learning_rate': 0.19043899115982607, 'max_depth': 9, 'min_child_weight': 2.481040974867813, 'gamma': 2.340279606636548, 'subsample': 0.4513964382185317, 'colsample_bytree': 0.3877543479093296, 'reg_alpha': 2.478071022662141, 'reg_lambda': 0.6132587025321562}. Best is trial 0 with value: 1.3735962053069508.
# [I 2026-06-15 05:52:56,174] Trial 1 finished with value: 1.2863415176885036 and parameters: {'n_estimators': 2493, 'learning_rate': 0.001120367191095075, 'max_depth': 12, 'min_child_weight': 21.368329072358772, 'gamma': 3.185086660174142, 'subsample': 0.4681862286846154, 'colsample_bytree': 0.46921293140473197, 'reg_alpha': 4.476173538513514e-07, 'reg_lambda': 0.20253776634919213}. Best is trial 1 with value: 1.2863415176885036.
# [I 2026-06-15 05:55:50,144] Trial 2 finished with value: 1.2492842451624282 and parameters: {'n_estimators': 1540, 'learning_rate': 0.004992867109217114, 'max_depth': 8, 'min_child_weight': 0.03613894271216528, 'gamma': 4.3821697280282725, 'subsample': 0.5881351981408995, 'colsample_bytree': 0.6464454897410734, 'reg_alpha': 0.26430874752361627, 'reg_lambda': 0.0018119678627933364}. Best is trial 2 with value: 1.2492842451624282.
# [I 2026-06-15 05:56:50,717] Trial 3 finished with value: 1.2697917175578521 and parameters: {'n_estimators': 1824, 'learning_rate': 0.026337502897485255, 'max_depth': 1, 'min_child_weight': 2.69264691008618, 'gamma': 2.557861855309373, 'subsample': 0.39228353544043165, 'colsample_bytree': 0.9667755992146666, 'reg_alpha': 38.6887231523051, 'reg_lambda': 12.408975837016275}. Best is trial 2 with value: 1.2492842451624282.
# [I 2026-06-15 06:00:04,492] Trial 4 finished with value: 1.5296123975771918 and parameters: {'n_estimators': 1101, 'learning_rate': 0.0017147936629846843, 'max_depth': 9, 'min_child_weight': 0.5762487216478605, 'gamma': 1.8305735226716824, 'subsample': 0.6718649915723256, 'colsample_bytree': 0.37235253872489193, 'reg_alpha': 8.162906555194692, 'reg_lambda': 0.004271500153828077}. Best is trial 2 with value: 1.2492842451624282.
# [I 2026-06-15 06:01:57,005] Trial 5 pruned.
# [I 2026-06-15 06:02:02,888] Trial 6 pruned.
# [I 2026-06-15 06:04:04,725] Trial 7 finished with value: 1.2441122575958776 and parameters: {'n_estimators': 1281, 'learning_rate': 0.0047169807141865345, 'max_depth': 7, 'min_child_weight': 0.0366181922039243, 'gamma': 12.032954711310595, 'subsample': 0.398457918391851, 'colsample_bytree': 0.9914765087903362, 'reg_alpha': 0.18490013641000916, 'reg_lambda': 0.0017869543989965139}. Best is trial 7 with value: 1.2441122575958776.
# [I 2026-06-15 06:04:06,616] Trial 8 pruned.
# [I 2026-06-15 06:05:18,050] Trial 9 finished with value: 1.2627757401134059 and parameters: {'n_estimators': 2201, 'learning_rate': 0.006215464818952927, 'max_depth': 1, 'min_child_weight': 0.17535949529764422, 'gamma': 4.877749830401205, 'subsample': 0.8242440159197416, 'colsample_bytree': 0.7644123563808884, 'reg_alpha': 4.4315220126915325, 'reg_lambda': 0.09450187118503514}. Best is trial 7 with value: 1.2441122575958776.
# [I 2026-06-15 06:05:25,475] Trial 10 pruned.
# [I 2026-06-15 06:05:58,569] Trial 11 pruned.
# [I 2026-06-15 06:06:42,303] Trial 12 pruned.
# [I 2026-06-15 06:06:46,357] Trial 13 pruned.
# [I 2026-06-15 06:07:03,919] Trial 14 finished with value: 1.2906227806965669 and parameters: {'n_estimators': 2872, 'learning_rate': 0.11587248002108354, 'max_depth': 1, 'min_child_weight': 1.1040511903162256, 'gamma': 6.261165047231685, 'subsample': 0.49437007680597467, 'colsample_bytree': 0.4279124887668938, 'reg_alpha': 1.125594744942969e-06, 'reg_lambda': 87.35792858155622}. Best is trial 7 with value: 1.2441122575958776.
# [I 2026-06-15 06:07:22,334] Trial 15 pruned.
# [I 2026-06-15 06:08:46,526] Trial 16 pruned.
# [I 2026-06-15 06:08:49,435] Trial 17 pruned.
# [I 2026-06-15 06:09:07,950] Trial 18 finished with value: 1.2472406974225372 and parameters: {'n_estimators': 2236, 'learning_rate': 0.01926440281006607, 'max_depth': 2, 'min_child_weight': 21.938654178115062, 'gamma': 4.811700974576038, 'subsample': 0.4712370317599052, 'colsample_bytree': 0.3765038420105965, 'reg_alpha': 0.0012322967930262527, 'reg_lambda': 1.859316691031827}. Best is trial 7 with value: 1.2441122575958776.
# [I 2026-06-15 06:09:10,973] Trial 19 pruned.
# [I 2026-06-15 06:11:24,350] Trial 20 finished with value: 1.24360960638499 and parameters: {'n_estimators': 3311, 'learning_rate': 0.0034946952714912344, 'max_depth': 5, 'min_child_weight': 0.012924385355194606, 'gamma': 8.484196360221048, 'subsample': 0.374243553773315, 'colsample_bytree': 0.9094746100989712, 'reg_alpha': 0.004525442618650345, 'reg_lambda': 0.029415678590637127}. Best is trial 20 with value: 1.24360960638499.
# [I 2026-06-15 06:13:04,290] Trial 21 finished with value: 1.244619993002385 and parameters: {'n_estimators': 3490, 'learning_rate': 0.003872034609857173, 'max_depth': 5, 'min_child_weight': 0.013533287273328096, 'gamma': 8.682406879949763, 'subsample': 0.3700781416241226, 'colsample_bytree': 0.8992404671808738, 'reg_alpha': 0.004585396673084557, 'reg_lambda': 0.02416104833098225}. Best is trial 20 with value: 1.24360960638499.
# [I 2026-06-15 06:15:02,110] Trial 22 finished with value: 1.2396159749117088 and parameters: {'n_estimators': 3406, 'learning_rate': 0.0032662567611587297, 'max_depth': 5, 'min_child_weight': 0.010565072041071107, 'gamma': 8.955467548583915, 'subsample': 0.3649038954394528, 'colsample_bytree': 0.8996800426529598, 'reg_alpha': 0.021015514889023586, 'reg_lambda': 0.01537856927133844}. Best is trial 22 with value: 1.2396159749117088.
# [I 2026-06-15 06:17:08,878] Trial 23 finished with value: 1.2336221761565713 and parameters: {'n_estimators': 3487, 'learning_rate': 0.0029714201254226716, 'max_depth': 5, 'min_child_weight': 0.010137092555420344, 'gamma': 9.702738651046282, 'subsample': 0.3666071716268531, 'colsample_bytree': 0.9989932881577939, 'reg_alpha': 0.03964636339740288, 'reg_lambda': 0.011966540574698807}. Best is trial 23 with value: 1.2336221761565713.
# [I 2026-06-15 06:19:38,689] Trial 24 finished with value: 1.2380765294125626 and parameters: {'n_estimators': 3477, 'learning_rate': 0.002803670244105958, 'max_depth': 5, 'min_child_weight': 0.010122189279062551, 'gamma': 9.526236492748248, 'subsample': 0.35606692091169406, 'colsample_bytree': 0.9043644863212803, 'reg_alpha': 0.010078243741346707, 'reg_lambda': 0.01900706014102316}. Best is trial 23 with value: 1.2336221761565713.
# [I 2026-06-15 06:20:27,346] Trial 25 finished with value: 1.2304221914585358 and parameters: {'n_estimators': 3050, 'learning_rate': 0.00964910146418919, 'max_depth': 5, 'min_child_weight': 0.011065136021091005, 'gamma': 10.154974087413414, 'subsample': 0.4310961696197222, 'colsample_bytree': 0.8578112004310914, 'reg_alpha': 0.09768461307146693, 'reg_lambda': 0.009182396923157966}. Best is trial 25 with value: 1.2304221914585358.
# [I 2026-06-15 06:21:10,775] Trial 26 pruned.
# [I 2026-06-15 06:21:24,798] Trial 27 pruned.
# [I 2026-06-15 06:23:20,897] Trial 28 pruned.
# [I 2026-06-15 06:24:47,680] Trial 29 pruned.
# [I 2026-06-15 06:25:29,673] Trial 30 finished with value: 1.241148317543919 and parameters: {'n_estimators': 2654, 'learning_rate': 0.009708915866091846, 'max_depth': 6, 'min_child_weight': 0.10126115193837884, 'gamma': 12.836971484943934, 'subsample': 0.44349236666514275, 'colsample_bytree': 0.9385621037034377, 'reg_alpha': 0.025489453458386754, 'reg_lambda': 0.002929040032192403}. Best is trial 25 with value: 1.2304221914585358.
# [I 2026-06-15 06:26:22,943] Trial 31 pruned.
# [I 2026-06-15 06:28:07,287] Trial 32 finished with value: 1.2425252101032114 and parameters: {'n_estimators': 3193, 'learning_rate': 0.003215217499028054, 'max_depth': 5, 'min_child_weight': 0.02411178880684975, 'gamma': 9.642926176986602, 'subsample': 0.360294134923233, 'colsample_bytree': 0.7985717127882922, 'reg_alpha': 0.002854202907462613, 'reg_lambda': 0.014663201401830358}. Best is trial 25 with value: 1.2304221914585358.
# [I 2026-06-15 06:29:52,767] Trial 33 pruned.
# [I 2026-06-15 06:30:27,900] Trial 34 finished with value: 1.2332180156375094 and parameters: {'n_estimators': 2817, 'learning_rate': 0.011906334659525177, 'max_depth': 3, 'min_child_weight': 0.03238271672122124, 'gamma': 9.23932093712343, 'subsample': 0.40563988082838814, 'colsample_bytree': 0.8674933567610645, 'reg_alpha': 0.03314766978872093, 'reg_lambda': 0.051683617448478124}. Best is trial 25 with value: 1.2304221914585358.
# [I 2026-06-15 06:30:41,012] Trial 35 finished with value: 1.2354675789516176 and parameters: {'n_estimators': 2676, 'learning_rate': 0.03895445076641896, 'max_depth': 3, 'min_child_weight': 0.025445421280644705, 'gamma': 10.50597569837468, 'subsample': 0.41363024313302726, 'colsample_bytree': 0.7117336320844124, 'reg_alpha': 0.13628354712365134, 'reg_lambda': 0.07536750407718719}. Best is trial 25 with value: 1.2304221914585358.
# [I 2026-06-15 06:30:50,770] Trial 36 finished with value: 1.2343051824334836 and parameters: {'n_estimators': 2549, 'learning_rate': 0.03891066914058971, 'max_depth': 3, 'min_child_weight': 0.02248621053557973, 'gamma': 10.893019030811717, 'subsample': 0.5136934092949687, 'colsample_bytree': 0.6949261941870268, 'reg_alpha': 1.2195442962574496, 'reg_lambda': 0.06360678111640442}. Best is trial 25 with value: 1.2304221914585358.
# [I 2026-06-15 06:30:54,688] Trial 37 pruned.
# [I 2026-06-15 06:31:05,565] Trial 38 finished with value: 1.2354733908180884 and parameters: {'n_estimators': 1965, 'learning_rate': 0.030948982242405686, 'max_depth': 2, 'min_child_weight': 0.05542570709462065, 'gamma': 12.426388819829828, 'subsample': 0.5176610820427819, 'colsample_bytree': 0.9617998536846171, 'reg_alpha': 0.865856672922535, 'reg_lambda': 0.036570799294973484}. Best is trial 25 with value: 1.2304221914585358.
# [I 2026-06-15 06:32:04,470] Trial 39 finished with value: 1.2305949869847634 and parameters: {'n_estimators': 2889, 'learning_rate': 0.013111837163530518, 'max_depth': 3, 'min_child_weight': 0.10055903826060685, 'gamma': 7.967246646529486, 'subsample': 0.47190918753172373, 'colsample_bytree': 0.645244095185769, 'reg_alpha': 1.1969099413554638, 'reg_lambda': 0.001736089645462534}. Best is trial 25 with value: 1.2304221914585358.
# [I 2026-06-15 06:32:20,718] Trial 40 pruned.
# [I 2026-06-15 06:32:30,899] Trial 41 finished with value: 1.2496469420809904 and parameters: {'n_estimators': 2467, 'learning_rate': 0.024835476857271353, 'max_depth': 3, 'min_child_weight': 0.02476911858373345, 'gamma': 8.048151518158166, 'subsample': 0.544964296170311, 'colsample_bytree': 0.7296811837016328, 'reg_alpha': 0.5756309549425566, 'reg_lambda': 0.004219924567550363}. Best is trial 25 with value: 1.2304221914585358.
# [I 2026-06-15 06:32:52,901] Trial 42 pruned.
# [I 2026-06-15 06:32:57,006] Trial 43 pruned.
# [I 2026-06-15 06:33:27,461] Trial 44 pruned.
# [I 2026-06-15 06:33:38,773] Trial 45 pruned.
# [I 2026-06-15 06:33:56,359] Trial 46 pruned.
# [I 2026-06-15 06:34:40,883] Trial 47 finished with value: 1.229394861991306 and parameters: {'n_estimators': 2878, 'learning_rate': 0.007751685916738902, 'max_depth': 2, 'min_child_weight': 0.07830504404568042, 'gamma': 8.083162239274158, 'subsample': 0.622579217545733, 'colsample_bytree': 0.5459457848378938, 'reg_alpha': 0.3706116331950148, 'reg_lambda': 0.00035225058022374364}. Best is trial 47 with value: 1.229394861991306.
# [I 2026-06-15 06:35:15,122] Trial 48 finished with value: 1.2321867602160077 and parameters: {'n_estimators': 3111, 'learning_rate': 0.00987766734083488, 'max_depth': 2, 'min_child_weight': 0.21429979024950235, 'gamma': 5.40379769168705, 'subsample': 0.6942771295418754, 'colsample_bytree': 0.5286177392623719, 'reg_alpha': 0.4735525175916247, 'reg_lambda': 0.00010148166172678651}. Best is trial 47 with value: 1.229394861991306.
# [I 2026-06-15 06:36:26,004] Trial 49 finished with value: 1.2634387413371564 and parameters: {'n_estimators': 2814, 'learning_rate': 0.007735686072959333, 'max_depth': 1, 'min_child_weight': 0.21759752537219915, 'gamma': 5.650917322037734, 'subsample': 0.7327785242063063, 'colsample_bytree': 0.4927203161435202, 'reg_alpha': 19.666491458031853, 'reg_lambda': 0.00020147288941395715}. Best is trial 47 with value: 1.229394861991306.
# [I 2026-06-15 06:36:26,531] A new study created in RDB with name: KMIA_v8_base_lightgbm_mae_f
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 06:36:54,949] Trial 0 finished with value: 1.3128206802476658 and parameters: {'n_estimators': 447, 'learning_rate': 0.028873871707375695, 'num_leaves': 71, 'max_depth': 5, 'min_child_samples': 83, 'min_split_gain': 4.295687454742988, 'bagging_fraction': 0.7829586385137167, 'bagging_freq': 4, 'feature_fraction': 0.3688589858758342, 'lambda_l1': 0.06382334403151436, 'lambda_l2': 0.03080292177315921}. Best is trial 0 with value: 1.3128206802476658.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 06:40:43,316] Trial 1 finished with value: 1.3473970608261978 and parameters: {'n_estimators': 2817, 'learning_rate': 0.004074615160588706, 'num_leaves': 32, 'max_depth': 13, 'min_child_samples': 57, 'min_split_gain': 2.0249472402362985, 'bagging_fraction': 0.5554627061618356, 'bagging_freq': 1, 'feature_fraction': 0.898096051249308, 'lambda_l1': 1.5391104005532914, 'lambda_l2': 132.19976430960952}. Best is trial 0 with value: 1.3128206802476658.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 06:41:05,538] Trial 2 finished with value: 1.3065384888144305 and parameters: {'n_estimators': 1379, 'learning_rate': 0.1944487980595256, 'num_leaves': 230, 'max_depth': 10, 'min_child_samples': 22, 'min_split_gain': 4.485492899907672, 'bagging_fraction': 0.5437022754476957, 'bagging_freq': 2, 'feature_fraction': 0.353334206891897, 'lambda_l1': 0.00032993636349211094, 'lambda_l2': 0.09925376145099525}. Best is trial 2 with value: 1.3065384888144305.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 06:41:26,195] Trial 3 finished with value: 1.6076244374645112 and parameters: {'n_estimators': 2246, 'learning_rate': 0.22165362064553062, 'num_leaves': 466, 'max_depth': 13, 'min_child_samples': 132, 'min_split_gain': 0.5200947492738145, 'bagging_fraction': 0.4675944869176356, 'bagging_freq': 7, 'feature_fraction': 0.6177694392011331, 'lambda_l1': 2.399967979035352, 'lambda_l2': 1.7195277953675168}. Best is trial 2 with value: 1.3065384888144305.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 06:45:41,136] Trial 4 finished with value: 1.326112218071625 and parameters: {'n_estimators': 2219, 'learning_rate': 0.004579029224032115, 'num_leaves': 460, 'max_depth': 4, 'min_child_samples': 102, 'min_split_gain': 4.967862461970517, 'bagging_fraction': 0.8282226029796285, 'bagging_freq': 4, 'feature_fraction': 0.7144310601384277, 'lambda_l1': 8.61124348208611e-06, 'lambda_l2': 3.808668235343267}. Best is trial 2 with value: 1.3065384888144305.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 06:45:59,633] Trial 5 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 06:46:30,475] Trial 6 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 06:46:32,470] Trial 7 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 06:46:36,078] Trial 8 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 06:48:24,235] Trial 9 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 06:48:27,176] Trial 10 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 06:48:54,862] Trial 11 finished with value: 1.3129314871047193 and parameters: {'n_estimators': 756, 'learning_rate': 0.06114521776634082, 'num_leaves': 57, 'max_depth': 2, 'min_child_samples': 85, 'min_split_gain': 4.846277519155279, 'bagging_fraction': 0.8056341981316478, 'bagging_freq': 3, 'feature_fraction': 0.42848891083526186, 'lambda_l1': 5.301057710204056e-10, 'lambda_l2': 3.7660106129974493}. Best is trial 2 with value: 1.3065384888144305.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 07:04:40,511] Trial 12 finished with value: 1.3115684258790719 and parameters: {'n_estimators': 3174, 'learning_rate': 0.0010925194811392835, 'num_leaves': 301, 'max_depth': 11, 'min_child_samples': 74, 'min_split_gain': 2.613988081636218, 'bagging_fraction': 0.8796537260629015, 'bagging_freq': 5, 'feature_fraction': 0.5960609706435204, 'lambda_l1': 8.524985832885774e-10, 'lambda_l2': 0.1169527455154188}. Best is trial 2 with value: 1.3065384888144305.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 07:06:32,305] Trial 13 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 07:06:40,970] Trial 14 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 07:06:52,812] Trial 15 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 07:06:54,857] Trial 16 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 07:07:08,845] Trial 17 finished with value: 1.3101566122057466 and parameters: {'n_estimators': 1783, 'learning_rate': 0.04864572341122393, 'num_leaves': 91, 'max_depth': 9, 'min_child_samples': 41, 'min_split_gain': 4.132892006727957, 'bagging_fraction': 0.5662560585201368, 'bagging_freq': 4, 'feature_fraction': 0.8899618930175198, 'lambda_l1': 42.540711148076, 'lambda_l2': 0.011582644290167256}. Best is trial 2 with value: 1.3065384888144305.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 07:07:12,603] Trial 18 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 07:07:18,202] Trial 19 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 07:08:15,084] Trial 20 finished with value: 1.2595067933417265 and parameters: {'n_estimators': 1026, 'learning_rate': 0.01346984807869096, 'num_leaves': 225, 'max_depth': 7, 'min_child_samples': 7, 'min_split_gain': 4.29797426762184, 'bagging_fraction': 0.7154120013233167, 'bagging_freq': 1, 'feature_fraction': 0.7175524319335512, 'lambda_l1': 0.0009588490840578117, 'lambda_l2': 0.0015763843743935306}. Best is trial 20 with value: 1.2595067933417265.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 07:09:32,810] Trial 21 finished with value: 1.2508302465569998 and parameters: {'n_estimators': 1101, 'learning_rate': 0.013638258695806675, 'num_leaves': 234, 'max_depth': 7, 'min_child_samples': 3, 'min_split_gain': 4.2292975158377, 'bagging_fraction': 0.7031710350923159, 'bagging_freq': 1, 'feature_fraction': 0.7069008123206584, 'lambda_l1': 0.00016983532804446316, 'lambda_l2': 0.001231424710035767}. Best is trial 21 with value: 1.2508302465569998.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 07:11:03,575] Trial 22 finished with value: 1.2395637546127722 and parameters: {'n_estimators': 1154, 'learning_rate': 0.012043472722636504, 'num_leaves': 231, 'max_depth': 7, 'min_child_samples': 6, 'min_split_gain': 4.397927319423328, 'bagging_fraction': 0.7086505653514206, 'bagging_freq': 1, 'feature_fraction': 0.7081123169214917, 'lambda_l1': 0.0010501110869942088, 'lambda_l2': 0.0012772194718336147}. Best is trial 22 with value: 1.2395637546127722.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 07:12:10,405] Trial 23 finished with value: 1.257232964786444 and parameters: {'n_estimators': 1067, 'learning_rate': 0.012894965354680417, 'num_leaves': 236, 'max_depth': 7, 'min_child_samples': 10, 'min_split_gain': 3.840903672418179, 'bagging_fraction': 0.7273575463536788, 'bagging_freq': 1, 'feature_fraction': 0.7025910260091389, 'lambda_l1': 0.0014998437732602512, 'lambda_l2': 0.0014072594559156803}. Best is trial 22 with value: 1.2395637546127722.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 07:12:52,921] Trial 24 finished with value: 1.26470893375786 and parameters: {'n_estimators': 1079, 'learning_rate': 0.013416212732091004, 'num_leaves': 289, 'max_depth': 7, 'min_child_samples': 34, 'min_split_gain': 3.6767102217753256, 'bagging_fraction': 0.7144876039419391, 'bagging_freq': 2, 'feature_fraction': 0.7089536778949107, 'lambda_l1': 9.409005884570874e-06, 'lambda_l2': 0.0013356727327440514}. Best is trial 22 with value: 1.2395637546127722.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 07:15:58,717] Trial 25 finished with value: 1.2647237338866533 and parameters: {'n_estimators': 1047, 'learning_rate': 0.007983307430182943, 'num_leaves': 130, 'max_depth': 6, 'min_child_samples': 48, 'min_split_gain': 3.283382747140546, 'bagging_fraction': 0.7169534482041409, 'bagging_freq': 1, 'feature_fraction': 0.7762987583805963, 'lambda_l1': 0.00020953188654073516, 'lambda_l2': 0.0010822096172625848}. Best is trial 22 with value: 1.2395637546127722.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 07:17:10,102] Trial 26 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 07:20:24,138] Trial 27 finished with value: 1.2764929015719968 and parameters: {'n_estimators': 1293, 'learning_rate': 0.006667453634301145, 'num_leaves': 206, 'max_depth': 6, 'min_child_samples': 27, 'min_split_gain': 4.5578612215358, 'bagging_fraction': 0.6562409790062428, 'bagging_freq': 2, 'feature_fraction': 0.8126305575187669, 'lambda_l1': 7.306537579492853e-07, 'lambda_l2': 0.0007483858025055497}. Best is trial 22 with value: 1.2395637546127722.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 07:21:34,041] Trial 28 finished with value: 1.2640631387678258 and parameters: {'n_estimators': 749, 'learning_rate': 0.020166961373635443, 'num_leaves': 408, 'max_depth': 8, 'min_child_samples': 57, 'min_split_gain': 3.4029184110952717, 'bagging_fraction': 0.8905145367925327, 'bagging_freq': 1, 'feature_fraction': 0.6627778780969137, 'lambda_l1': 0.006882799864679927, 'lambda_l2': 0.003367911886726897}. Best is trial 22 with value: 1.2395637546127722.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 07:22:42,603] Trial 29 finished with value: 1.252600437168911 and parameters: {'n_estimators': 391, 'learning_rate': 0.020208215982157492, 'num_leaves': 369, 'max_depth': 5, 'min_child_samples': 2, 'min_split_gain': 4.559485112774523, 'bagging_fraction': 0.7620435726328098, 'bagging_freq': 3, 'feature_fraction': 0.7519100966211761, 'lambda_l1': 0.06186504569789034, 'lambda_l2': 0.0003833129929254704}. Best is trial 22 with value: 1.2395637546127722.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 07:25:08,594] Trial 30 finished with value: 1.2615546491280438 and parameters: {'n_estimators': 461, 'learning_rate': 0.0245274453894478, 'num_leaves': 412, 'max_depth': 4, 'min_child_samples': 29, 'min_split_gain': 4.553873947164433, 'bagging_fraction': 0.6744849476543653, 'bagging_freq': 3, 'feature_fraction': 0.7348017933910919, 'lambda_l1': 0.039270262182014036, 'lambda_l2': 0.00039279440670288076}. Best is trial 22 with value: 1.2395637546127722.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 07:29:02,319] Trial 31 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 07:32:55,837] Trial 32 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 07:37:12,220] Trial 33 finished with value: 1.2787415144582135 and parameters: {'n_estimators': 636, 'learning_rate': 0.029716554097760892, 'num_leaves': 198, 'max_depth': 8, 'min_child_samples': 58, 'min_split_gain': 4.475788733456922, 'bagging_fraction': 0.6270028324056692, 'bagging_freq': 1, 'feature_fraction': 0.6852422489309256, 'lambda_l1': 0.00068523581571997, 'lambda_l2': 0.030676413531104587}. Best is trial 22 with value: 1.2395637546127722.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 07:44:20,907] Trial 34 finished with value: 1.2451484358961202 and parameters: {'n_estimators': 922, 'learning_rate': 0.012345801085254259, 'num_leaves': 324, 'max_depth': 3, 'min_child_samples': 18, 'min_split_gain': 4.654197707108661, 'bagging_fraction': 0.6897809988774619, 'bagging_freq': 2, 'feature_fraction': 0.6269379399667697, 'lambda_l1': 0.002030023275212622, 'lambda_l2': 0.0001273959949664855}. Best is trial 22 with value: 1.2395637546127722.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 07:44:58,501] Trial 35 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 07:45:57,127] Trial 36 finished with value: 1.2619658305052885 and parameters: {'n_estimators': 2614, 'learning_rate': 0.018920230808043222, 'num_leaves': 406, 'max_depth': 3, 'min_child_samples': 25, 'min_split_gain': 4.20452062858487, 'bagging_fraction': 0.6091701290263896, 'bagging_freq': 2, 'feature_fraction': 0.6268414313704826, 'lambda_l1': 1.9039018125570657e-06, 'lambda_l2': 0.0005273146305355516}. Best is trial 22 with value: 1.2395637546127722.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 07:46:31,242] Trial 37 finished with value: 1.2695110636126197 and parameters: {'n_estimators': 1385, 'learning_rate': 0.0796820911195036, 'num_leaves': 374, 'max_depth': 3, 'min_child_samples': 55, 'min_split_gain': 4.352515074647492, 'bagging_fraction': 0.7879557073158923, 'bagging_freq': 2, 'feature_fraction': 0.5569104649593065, 'lambda_l1': 0.00011822517451982104, 'lambda_l2': 0.00022890904623697512}. Best is trial 22 with value: 1.2395637546127722.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 07:47:15,973] Trial 38 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 07:47:43,024] Trial 39 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 07:48:16,904] Trial 40 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 07:50:23,019] Trial 41 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 08:01:21,723] Trial 42 finished with value: 1.2552641115092236 and parameters: {'n_estimators': 980, 'learning_rate': 0.007802183568437913, 'num_leaves': 247, 'max_depth': 7, 'min_child_samples': 35, 'min_split_gain': 3.996994774198407, 'bagging_fraction': 0.7755115331757597, 'bagging_freq': 1, 'feature_fraction': 0.6326950047422214, 'lambda_l1': 0.021266067275296122, 'lambda_l2': 0.0002525985382017863}. Best is trial 22 with value: 1.2395637546127722.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 08:08:28,951] Trial 43 finished with value: 1.2683810434490062 and parameters: {'n_estimators': 1423, 'learning_rate': 0.007613126072940919, 'num_leaves': 260, 'max_depth': 8, 'min_child_samples': 36, 'min_split_gain': 4.326070343093587, 'bagging_fraction': 0.7911459288391949, 'bagging_freq': 2, 'feature_fraction': 0.6281334853118042, 'lambda_l1': 0.014881638625019868, 'lambda_l2': 0.00022545126650441488}. Best is trial 22 with value: 1.2395637546127722.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 08:08:40,564] Trial 44 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 08:09:45,564] Trial 45 finished with value: 1.2832357718172542 and parameters: {'n_estimators': 960, 'learning_rate': 0.016656022488492208, 'num_leaves': 297, 'max_depth': 9, 'min_child_samples': 65, 'min_split_gain': 2.978324303733964, 'bagging_fraction': 0.7737408637086103, 'bagging_freq': 2, 'feature_fraction': 0.6496716277016971, 'lambda_l1': 0.00021656168062763166, 'lambda_l2': 0.00029640792688890314}. Best is trial 22 with value: 1.2395637546127722.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 08:10:46,091] Trial 46 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 08:11:19,798] Trial 47 finished with value: 1.2691553791494887 and parameters: {'n_estimators': 2032, 'learning_rate': 0.009607958944630542, 'num_leaves': 184, 'max_depth': 10, 'min_child_samples': 46, 'min_split_gain': 3.9994174833925813, 'bagging_fraction': 0.6020292999626728, 'bagging_freq': 3, 'feature_fraction': 0.8652358918068445, 'lambda_l1': 0.2068194224987506, 'lambda_l2': 0.00017582701854919555}. Best is trial 22 with value: 1.2395637546127722.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 08:11:40,884] Trial 48 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 08:12:06,289] Trial 49 finished with value: 1.2798915469480878 and parameters: {'n_estimators': 1498, 'learning_rate': 0.03450581974288525, 'num_leaves': 276, 'max_depth': 5, 'min_child_samples': 33, 'min_split_gain': 4.416894690643237, 'bagging_fraction': 0.8454114262482355, 'bagging_freq': 1, 'feature_fraction': 0.6828955776698838, 'lambda_l1': 1.1758117071681087e-10, 'lambda_l2': 19.283567779168237}. Best is trial 22 with value: 1.2395637546127722.
# [I 2026-06-15 08:12:06,524] A new study created in RDB with name: KMIA_v8_base_catboost_mae_f
# [I 2026-06-15 08:23:33,695] Trial 0 finished with value: 1.60585185940337 and parameters: {'iterations': 2931, 'learning_rate': 0.001783588943232587, 'depth': 10, 'l2_leaf_reg': 0.9942958882300413, 'random_strength': 7.186216756161439, 'bagging_temperature': 12.184767612363034, 'border_count': 110, 'rsm': 0.6158971964095841}. Best is trial 0 with value: 1.60585185940337.
# [I 2026-06-15 08:29:38,951] Trial 1 finished with value: 1.597120027383506 and parameters: {'iterations': 1809, 'learning_rate': 0.05045361458210069, 'depth': 12, 'l2_leaf_reg': 2.206716955900187, 'random_strength': 8.55303042123218, 'bagging_temperature': 2.269274022399408, 'border_count': 68, 'rsm': 0.9723568448941463}. Best is trial 1 with value: 1.597120027383506.
# [I 2026-06-15 08:30:36,357] Trial 2 finished with value: 1.4461146183165992 and parameters: {'iterations': 3305, 'learning_rate': 0.13018523290940803, 'depth': 9, 'l2_leaf_reg': 0.29456409265689415, 'random_strength': 12.736640276136784, 'bagging_temperature': 2.78292503969807, 'border_count': 126, 'rsm': 0.9180110703516069}. Best is trial 2 with value: 1.4461146183165992.
# [I 2026-06-15 08:32:14,821] Trial 3 finished with value: 1.5038498474797786 and parameters: {'iterations': 941, 'learning_rate': 0.039289187448897187, 'depth': 11, 'l2_leaf_reg': 0.17184213389305913, 'random_strength': 11.258999163179464, 'bagging_temperature': 3.183105276262954, 'border_count': 57, 'rsm': 0.4176149246436502}. Best is trial 2 with value: 1.4461146183165992.
# [I 2026-06-15 08:35:48,513] Trial 4 finished with value: 2.6373268557163105 and parameters: {'iterations': 750, 'learning_rate': 0.012345725775087685, 'depth': 10, 'l2_leaf_reg': 185.34152922460115, 'random_strength': 16.100344011609046, 'bagging_temperature': 7.548308114328448, 'border_count': 139, 'rsm': 0.3882842988918503}. Best is trial 2 with value: 1.4461146183165992.
# [I 2026-06-15 09:01:15,329] Trial 5 pruned.
# [I 2026-06-15 09:11:38,840] Trial 6 finished with value: 1.3024964911561339 and parameters: {'iterations': 3092, 'learning_rate': 0.0016894180053021765, 'depth': 7, 'l2_leaf_reg': 2.9770736659303028, 'random_strength': 2.1794700787166432, 'bagging_temperature': 3.0746892172349938, 'border_count': 252, 'rsm': 0.5265140999127667}. Best is trial 6 with value: 1.3024964911561339.
# [I 2026-06-15 09:13:42,517] Trial 7 finished with value: 1.3010106444904372 and parameters: {'iterations': 3146, 'learning_rate': 0.0024764229908984673, 'depth': 3, 'l2_leaf_reg': 0.6951779671472356, 'random_strength': 6.148451176512449, 'bagging_temperature': 8.441103735088014, 'border_count': 95, 'rsm': 0.7192489923988105}. Best is trial 7 with value: 1.3010106444904372.
# [I 2026-06-15 09:14:17,315] Trial 8 finished with value: 1.3860181296390894 and parameters: {'iterations': 378, 'learning_rate': 0.08194116550819189, 'depth': 4, 'l2_leaf_reg': 95.92707399961093, 'random_strength': 18.034879593317157, 'bagging_temperature': 0.3171560070252766, 'border_count': 220, 'rsm': 0.7891440128855358}. Best is trial 7 with value: 1.3010106444904372.
# [I 2026-06-15 09:14:59,376] Trial 9 pruned.
# [I 2026-06-15 09:18:07,476] Trial 10 pruned.
# [I 2026-06-15 09:18:32,396] Trial 11 pruned.
# [I 2026-06-15 09:19:28,355] Trial 12 pruned.
# [I 2026-06-15 09:19:41,013] Trial 13 pruned.
# [I 2026-06-15 09:20:25,148] Trial 14 pruned.
# [I 2026-06-15 09:41:01,532] Trial 15 finished with value: 1.4316525266096827 and parameters: {'iterations': 1533, 'learning_rate': 0.00677555105014573, 'depth': 11, 'l2_leaf_reg': 2.772143189189951, 'random_strength': 5.175604669479215, 'bagging_temperature': 2.338512109369544, 'border_count': 163, 'rsm': 0.5786244777864037}. Best is trial 7 with value: 1.3010106444904372.
# [I 2026-06-15 09:55:38,907] Trial 16 pruned.
# [I 2026-06-15 09:58:36,191] Trial 17 finished with value: 1.359557942173545 and parameters: {'iterations': 1447, 'learning_rate': 0.05575694750770886, 'depth': 5, 'l2_leaf_reg': 72.58680458994696, 'random_strength': 9.214098028406127, 'bagging_temperature': 18.71633726082786, 'border_count': 220, 'rsm': 0.5547113607542395}. Best is trial 7 with value: 1.3010106444904372.
# [I 2026-06-15 10:15:20,893] Trial 18 pruned.
# [I 2026-06-15 10:16:26,761] Trial 19 pruned.
# [I 2026-06-15 10:16:59,806] Trial 20 finished with value: 1.319255488658741 and parameters: {'iterations': 3486, 'learning_rate': 0.0031221828161265204, 'depth': 2, 'l2_leaf_reg': 0.05272080051940796, 'random_strength': 3.5052369253312046, 'bagging_temperature': 9.750131674871632, 'border_count': 19, 'rsm': 0.4751182877052444}. Best is trial 7 with value: 1.3010106444904372.
# [I 2026-06-15 10:17:46,468] Trial 21 finished with value: 1.3173463797029115 and parameters: {'iterations': 3456, 'learning_rate': 0.002928433964986125, 'depth': 2, 'l2_leaf_reg': 0.10989512952082721, 'random_strength': 3.539152488165065, 'bagging_temperature': 9.883751751951994, 'border_count': 19, 'rsm': 0.4930253114169302}. Best is trial 7 with value: 1.3010106444904372.
# [I 2026-06-15 10:18:32,334] Trial 22 finished with value: 1.2693709243282243 and parameters: {'iterations': 3058, 'learning_rate': 0.0030793976419771817, 'depth': 3, 'l2_leaf_reg': 0.39705879179322784, 'random_strength': 3.7574836985461753, 'bagging_temperature': 5.9078080292997015, 'border_count': 22, 'rsm': 0.5126000525801067}. Best is trial 22 with value: 1.2693709243282243.
# [I 2026-06-15 10:21:38,778] Trial 23 finished with value: 1.3211279368130193 and parameters: {'iterations': 3005, 'learning_rate': 0.0012832045781608684, 'depth': 4, 'l2_leaf_reg': 0.4557553405493115, 'random_strength': 3.6282329777678903, 'bagging_temperature': 5.963051746427249, 'border_count': 253, 'rsm': 0.5209920457282655}. Best is trial 22 with value: 1.2693709243282243.
# [I 2026-06-15 10:23:12,383] Trial 24 finished with value: 1.2539745001048765 and parameters: {'iterations': 3044, 'learning_rate': 0.002805228155583156, 'depth': 3, 'l2_leaf_reg': 0.7830772601808509, 'random_strength': 1.8627362930689797, 'bagging_temperature': 4.938944271040962, 'border_count': 107, 'rsm': 0.6688961272537146}. Best is trial 24 with value: 1.2539745001048765.
# [I 2026-06-15 10:24:19,230] Trial 25 finished with value: 1.2787605954016108 and parameters: {'iterations': 2200, 'learning_rate': 0.0029633114063924554, 'depth': 3, 'l2_leaf_reg': 0.6606923325945357, 'random_strength': 4.725809573139636, 'bagging_temperature': 5.697739812117263, 'border_count': 128, 'rsm': 0.6541007647373536}. Best is trial 24 with value: 1.2539745001048765.
# ...
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
#                   period       method  count     mae_f    rmse_f
# 0   validation_2024_2025      xgboost    731  1.219377  1.672704
# 1   validation_2024_2025     lightgbm    731  1.239554  1.703610
# 2   validation_2024_2025     catboost    731  1.200066  1.661912
# 3   validation_2024_2025     hrrr_raw    731  2.070383  2.761185
# 4   validation_2024_2025      gfs_raw    731  3.467263  3.977150
# 5              test_2026      xgboost    137  1.838153  2.325162
# 6              test_2026     lightgbm    137  1.739676  2.301509
# 7              test_2026     catboost    137  1.802951  2.390258
# 8              test_2026  ridge_stack    137  1.785590  2.312794
# 9              test_2026     hrrr_raw    137  2.192168  2.892819
# 10             test_2026      gfs_raw    137  4.064228  4.540821

# %% [markdown]
# ## V8 Feature Coverage

# %%
v8_feature_coverage = (
    result.features[V8_FEATURE_COLUMNS]
    .notna()
    .mean()
    .mul(100)
    .sort_values(ascending=False)
    .rename("coverage_pct")
    .reset_index()
    .rename(columns={"index": "feature"})
)

v8_feature_coverage
# Out:
#                                               feature  coverage_pct
# 0                    v2_morning_warmup_to_consensus_f    100.000000
# 1                      v3_high_so_far_above_current_f    100.000000
# 2                      v2_humidity_warmup_interaction    100.000000
# 3                              v2_spread_per_warmup_f    100.000000
# 4            v3_humidity_remaining_warmup_interaction    100.000000
# 5                    v3_remaining_warmup_per_spread_f    100.000000
# 6                              v4_any_forecast_precip    100.000000
# 7              v3_remaining_warmup_from_high_so_far_f    100.000000
# 8                   v4_forecast_observed_precip_match    100.000000
# 9                        v4_forecast_wet_observed_dry    100.000000
# 10          v8_provider_spread_per_remaining_warmup_f    100.000000
# 11                    v8_month_remaining_warmup_count    100.000000
# 12       v8_provider_min_remaining_from_high_so_far_f    100.000000
# 13    v8_provider_median_remaining_from_high_so_far_f    100.000000
# 14       v8_provider_max_remaining_from_high_so_far_f    100.000000
# 15                       v4_observed_wet_forecast_dry    100.000000
# 16                             v4_observed_precip_any    100.000000
# 17                             v4_all_forecast_precip    100.000000
# 18                     v2_consensus_minus_7d_actual_f     99.949084
# 19                          v2_recent_heat_momentum_f     99.949084
# 20                   v3_high_so_far_minus_7d_actual_f     99.949084
# 21                           v2_recent_heat_anomaly_f     99.949084
# 22                     observed_temp_change_last_3h_f     99.949084
# 23            observed_morning_warmup_rate_f_per_hour     99.949084
# 24            observed_high_so_far_change_since_9am_f     99.949084
# 25                     observed_temp_change_last_1h_f     99.949084
# 26                      v3_high_so_far_minus_lag_1d_f     99.949084
# 27                   v4_observed_precip_recent_mm_est     99.898167
# 28               v8_recent_remaining_warmup_7d_mean_f     99.898167
# 29              v8_recent_remaining_warmup_30d_mean_f     99.745418
# 30       v8_provider_mean_remaining_vs_month_normal_f     98.778004
# 31                   v8_month_remaining_warmup_mean_f     98.778004
# 32                    v4_forecast_precip_total_max_mm      0.000000
# 33                 v4_forecast_precip_total_spread_mm      0.000000
# 34                   v4_forecast_precip_total_mean_mm      0.000000
# 35                  v4_forecast_precip_max_1h_mean_mm      0.000000
# 36                   v4_forecast_precip_intensity_max      0.000000
# 37                  v4_forecast_precip_intensity_mean      0.000000
# 38                      v4_forecast_precip_hours_mean      0.000000
# 39         v4_forecast_total_minus_observed_recent_mm      0.000000
# 40             v4_precip_remaining_warmup_interaction      0.000000
# 41                     v4_precip_humidity_interaction      0.000000
# 42   v8_cloud_cover_mean_remaining_warmup_interaction      0.000000
# 43    v8_cloud_cover_max_remaining_warmup_interaction      0.000000
# 44       v8_precip_total_remaining_warmup_interaction      0.000000
# 45      v8_precip_max_1h_remaining_warmup_interaction      0.000000
# 46    v8_wind_speed_mean_remaining_warmup_interaction      0.000000
# 47      v8_wind_gust_max_remaining_warmup_interaction      0.000000
# 48                        v8_forecast_dewpoint_mean_f      0.000000
# 49             v8_forecast_dewpoint_depression_mean_f      0.000000
# 50      v8_dewpoint_mean_remaining_warmup_interaction      0.000000
# 51  v8_dewpoint_depression_remaining_warmup_intera...      0.000000

# %%
result.feature_columns.loc[result.feature_columns["feature"].isin(V8_FEATURE_COLUMNS)]
# Out:
#                                              feature     kind
# 20                    observed_temp_change_last_1h_f  numeric
# 21                    observed_temp_change_last_3h_f  numeric
# 22           observed_morning_warmup_rate_f_per_hour  numeric
# 23           observed_high_so_far_change_since_9am_f  numeric
# 163                         v2_recent_heat_anomaly_f  numeric
# 164                        v2_recent_heat_momentum_f  numeric
# 165                 v2_morning_warmup_to_consensus_f  numeric
# 166                   v2_consensus_minus_7d_actual_f  numeric
# 167                           v2_spread_per_warmup_f  numeric
# 168                   v2_humidity_warmup_interaction  numeric
# 169                   v3_high_so_far_above_current_f  numeric
# 170           v3_remaining_warmup_from_high_so_far_f  numeric
# 171                    v3_high_so_far_minus_lag_1d_f  numeric
# 172                 v3_high_so_far_minus_7d_actual_f  numeric
# 173                 v3_remaining_warmup_per_spread_f  numeric
# 174         v3_humidity_remaining_warmup_interaction  numeric
# 175                           v4_any_forecast_precip  numeric
# 176                           v4_all_forecast_precip  numeric
# 177                           v4_observed_precip_any  numeric
# 178                 v4_observed_precip_recent_mm_est  numeric
# 179                v4_forecast_observed_precip_match  numeric
# 180                     v4_forecast_wet_observed_dry  numeric
# 181                     v4_observed_wet_forecast_dry  numeric
# 182     v8_provider_max_remaining_from_high_so_far_f  numeric
# 183     v8_provider_min_remaining_from_high_so_far_f  numeric
# 184  v8_provider_median_remaining_from_high_so_far_f  numeric
# 185        v8_provider_spread_per_remaining_warmup_f  numeric
# 186                 v8_month_remaining_warmup_mean_f  numeric
# 187                  v8_month_remaining_warmup_count  numeric
# 188             v8_recent_remaining_warmup_7d_mean_f  numeric
# 189            v8_recent_remaining_warmup_30d_mean_f  numeric
# 190     v8_provider_mean_remaining_vs_month_normal_f  numeric

# %% [markdown]
# ## Dropped Feature Check

# %%
dropped_present = result.feature_columns.loc[
    result.feature_columns["feature"].isin(V8_DROPPED_FEATURE_COLUMNS)
]

dropped_present
# Out:
# Empty DataFrame
# Columns: [feature, kind]
# Index: []

# %% [markdown]
# ## Morning Trend Coverage

# %%
trend_coverage = (
    result.features[TREND_COLUMNS]
    .notna()
    .mean()
    .mul(100)
    .sort_values(ascending=False)
    .rename("coverage_pct")
    .reset_index()
    .rename(columns={"index": "feature"})
)

trend_coverage
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 trend_coverage = (
# ----> 2     result.features[TREND_COLUMNS]
#       3     .notna()
#       4     .mean()
#       5     .mul(100)
#
# NameError: name 'TREND_COLUMNS' is not defined

# %% [markdown]
# ## Rounded Within 1F Accuracy

# %%
preds = pd.concat(
    [
        result.validation_predictions.assign(period="validation_2024_2025"),
        result.test_predictions.assign(period="oof_2026"),
    ],
    ignore_index=True,
)

predicted_high = pd.to_numeric(preds["predicted_high_f"], errors="coerce")
preds["predicted_high_rounded_f"] = np.floor(predicted_high + 0.5)
preds["within_1f_after_round"] = (
    pd.to_numeric(preds["actual_high_f"], errors="coerce") - preds["predicted_high_rounded_f"]
).abs().le(1)

within_1f_accuracy_by_period = (
    preds
    .dropna(subset=["actual_high_f", "predicted_high_rounded_f"])
    .groupby(["period", "method"], as_index=False)
    .agg(
        count=("within_1f_after_round", "size"),
        within_1f_count=("within_1f_after_round", "sum"),
        within_1f_accuracy_pct=("within_1f_after_round", lambda x: x.mean() * 100),
    )
    .sort_values(["period", "within_1f_accuracy_pct"], ascending=[True, False])
)

within_1f_accuracy_by_period
# Out:
#                   period       method  count  within_1f_count  \
# 3               oof_2026     lightgbm    137               72
# 0               oof_2026     catboost    137               69
# 5               oof_2026  ridge_stack    137               68
# 6               oof_2026      xgboost    137               67
# 2               oof_2026     hrrr_raw    137               57
# 4               oof_2026      nbm_raw    137               43
# 1               oof_2026      gfs_raw    137               18
# 7   validation_2024_2025     catboost    731              527
# 10  validation_2024_2025     lightgbm    731              518
# 12  validation_2024_2025      xgboost    731              508
# 9   validation_2024_2025     hrrr_raw    731              361
# 11  validation_2024_2025      nbm_raw    731              173
# 8   validation_2024_2025      gfs_raw    731              124
#
#     within_1f_accuracy_pct
# 3                52.554745
# 0                50.364964
# 5                49.635036
# 6                48.905109
# 2                41.605839
# 4                31.386861
# 1                13.138686
# 7                72.093023
# 10               70.861833
# 12               69.493844
# 9                49.384405
# 11               23.666211
# 8                16.963064

# %% [markdown]
# ## Version Comparison

# %%
comparison_frames = []
for version, folder in [
    ("v1", PROJECT_ROOT / "data" / "calibration" / "station_stacking"),
    ("v2", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v2"),
    ("v3", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v3"),
    ("v4", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v4"),
    ("v5", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v5"),
    ("v6", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v6"),
    ("v7", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v7"),
    ("v8", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v8"),
]:
    path = folder / f"{STATION_ID}_year_split_scoreboard.csv"
    if path.exists():
        frame = pd.read_csv(path)
        frame["version"] = version
        comparison_frames.append(frame)

version_comparison = pd.concat(comparison_frames, ignore_index=True) if comparison_frames else pd.DataFrame()
if not version_comparison.empty:
    version_comparison = version_comparison.sort_values(["period", "mae_f", "version", "method"]).reset_index(drop=True)
version_comparison
# Out:
#                   period       method  count     mae_f    rmse_f version
# 0              test_2026     catboost    104  1.550583  2.063820      v5
# 1              test_2026  ridge_stack    104  1.552819  2.095250      v5
# 2              test_2026     catboost    104  1.563938  2.156057      v6
# 3              test_2026     lightgbm    107  1.580786  2.439781      v7
# 4              test_2026  ridge_stack    104  1.591358  2.159365      v6
# ..                   ...          ...    ...       ...       ...     ...
# 61  validation_2024_2025      gfs_raw    664  3.540756  4.037614      v2
# 62  validation_2024_2025      gfs_raw    664  3.540756  4.037614      v3
# 63  validation_2024_2025      gfs_raw    562  3.592958  4.064970      v5
# 64  validation_2024_2025      gfs_raw    562  3.592958  4.064970      v6
# 65  validation_2024_2025      gfs_raw    619  3.722649  4.201516      v7
#
# [66 rows x 6 columns]

# %% [markdown]
# ## 2026 OOF Weather Brackets

# %%
result.bracket_metrics
# Out:
#         method  count     mae_f    rmse_f  bracket_accuracy_pct
# 0      xgboost    137  1.838153  2.325162             33.576642
# 1     lightgbm    137  1.739676  2.301509             35.766423
# 2     catboost    137  1.802951  2.390258             31.386861
# 3  ridge_stack    137  1.785590  2.312794             29.927007
# 4     hrrr_raw    137  2.192168  2.892819              29.19708
# 5      gfs_raw    137  4.064228  4.540821              8.759124

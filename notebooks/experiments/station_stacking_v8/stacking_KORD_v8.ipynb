# %% [markdown]
# # Station Stacking v8 - KORD
#
# Experimental notebook for `KORD`.
#
# This version keeps the v7 live-safe GFS/HRRR/NBM contract, adds source-owned remaining-warmup feature engineering, and drops only conservative zero-importance input fields. Artifacts are written to `data/calibration/station_stacking_v8`.

# %%
from pathlib import Path
import os
import sys
import warnings

warnings.filterwarnings("ignore", message="IProgress not found.*")
warnings.filterwarnings("ignore", message="Skipping features without any observed values.*")

PROJECT_ROOT = Path.cwd().resolve()
while not (PROJECT_ROOT / "src" / "calibration" / "station_stacking.py").exists():
    if PROJECT_ROOT.parent == PROJECT_ROOT:
        raise RuntimeError("Could not find project root containing src/calibration/station_stacking.py")
    PROJECT_ROOT = PROJECT_ROOT.parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

os.environ["WEATHER_RESEARCH_INCLUDE_DIRECT_NBM"] = "1"

STATION_ID = "KORD"
PROVIDERS = ("gfs", "hrrr", "nbm")
TIMING_MODE = "same_day_11am_live_safe"
FAST_MODE = False
OPTUNA_TRIALS = 50
STACK_OPTUNA_TRIALS = 50
OPTUNA_STARTUP_TRIALS = 20
STACK_OPTUNA_STARTUP_TRIALS = 20
OPTUNA_METRIC = "mae_f"
OPTUNA_VERBOSE = True
PROJECT_ROOT
# Out:
# WindowsPath('D:/dev/weather-research')

# %%
import numpy as np
import pandas as pd

from src.calibration.station_stacking import (
    StationStackingConfig,
    V8_DROPPED_FEATURE_COLUMNS,
    V8_FEATURE_COLUMNS,
    YEAR_SPLIT_EXPANDING_FOLDS,
    missing_model_dependencies,
    provider_availability,
    run_station_year_split_experiment,
)

# %% [markdown]
# ## V8 Contract
#
# `feature_version="v8"` keeps the v7 live-safe NBM setup and direct `actual_high_f` target. V8 adds remaining-warmup features and removes only conservative zero-importance model inputs from the feature matrix.

# %%
fold_spec = pd.DataFrame(
    [
        {
            "fold": fold.name,
            "train_start_year": fold.train_start_year,
            "train_end_year": fold.train_end_year,
            "validation_year": fold.validation_year,
        }
        for fold in YEAR_SPLIT_EXPANDING_FOLDS
    ]
)

fold_spec
# Out:
#                      fold  train_start_year  train_end_year  validation_year
# 0  fold_2021_2023_to_2024              2021            2023             2024
# 1  fold_2021_2024_to_2025              2021            2024             2025

# %%
V8_FEATURE_COLUMNS, sorted(V8_DROPPED_FEATURE_COLUMNS)
# Out:
# (['v2_recent_heat_anomaly_f',
#   'v2_recent_heat_momentum_f',
#   'v2_morning_warmup_to_consensus_f',
#   'v2_consensus_minus_7d_actual_f',
#   'v2_spread_per_warmup_f',
#   'v2_humidity_warmup_interaction',
#   'v3_high_so_far_above_current_f',
#   'v3_remaining_warmup_from_high_so_far_f',
#   'v3_high_so_far_minus_lag_1d_f',
#   'v3_high_so_far_minus_7d_actual_f',
#   'v3_remaining_warmup_per_spread_f',
#   'v3_humidity_remaining_warmup_interaction',
#   'v4_forecast_precip_total_mean_mm',
#   'v4_forecast_precip_total_max_mm',
#   'v4_forecast_precip_total_spread_mm',
#   'v4_forecast_precip_max_1h_mean_mm',
#   'v4_forecast_precip_hours_mean',
#   'v4_forecast_precip_intensity_mean',
#   'v4_forecast_precip_intensity_max',
#   'v4_any_forecast_precip',
#   'v4_all_forecast_precip',
#   'v4_observed_precip_any',
#   'v4_observed_precip_recent_mm_est',
#   'v4_forecast_total_minus_observed_recent_mm',
#   'v4_forecast_observed_precip_match',
#   'v4_forecast_wet_observed_dry',
#   'v4_observed_wet_forecast_dry',
#   'v4_precip_humidity_interaction',
#   'v4_precip_remaining_warmup_interaction',
#   'observed_temp_change_last_1h_f',
#   'observed_temp_change_last_3h_f',
#   'observed_morning_warmup_rate_f_per_hour',
#   'observed_high_so_far_change_since_9am_f',
#   'v8_provider_max_remaining_from_high_so_far_f',
#   'v8_provider_min_remaining_from_high_so_far_f',
#   'v8_provider_median_remaining_from_high_so_far_f',
#   'v8_provider_spread_per_remaining_warmup_f',
#   'v8_month_remaining_warmup_mean_f',
#   'v8_month_remaining_warmup_count',
#   'v8_recent_remaining_warmup_7d_mean_f',
#   'v8_recent_remaining_warmup_30d_mean_f',
#   'v8_provider_mean_remaining_vs_month_normal_f',
#   'v8_cloud_cover_mean_remaining_warmup_interaction',
#   'v8_cloud_cover_max_remaining_warmup_interaction',
#   'v8_precip_total_remaining_warmup_interaction',
#   'v8_precip_max_1h_remaining_warmup_interaction',
#   'v8_wind_speed_mean_remaining_warmup_interaction',
#   'v8_wind_gust_max_remaining_warmup_interaction',
#   'v8_forecast_dewpoint_mean_f',
#   'v8_forecast_dewpoint_depression_mean_f',
#   'v8_dewpoint_mean_remaining_warmup_interaction',
#   'v8_dewpoint_depression_remaining_warmup_interaction'],
#  ['gfs_as_of_hour_local',
#   'gfs_available',
#   'gfs_forecast_window_hours',
#   'gfs_grid_dist_km_mean',
#   'gfs_horizon_hours',
#   'gfs_hrrr_grid_dist_km_mean_abs_diff_f',
#   'gfs_hrrr_grid_dist_km_mean_diff_f',
#   'gfs_issue_hour_utc',
#   'gfs_missing',
#   'hrrr_as_of_hour_local',
#   'hrrr_available',
#   'hrrr_forecast_hour_max',
#   'hrrr_forecast_hour_min',
#   'hrrr_forecast_lead_hours',
#   'hrrr_forecast_window_hours',
#   'hrrr_grid_dist_km_mean',
#   'hrrr_horizon_hours',
#   'hrrr_issue_hour_local',
#   'hrrr_issue_hour_utc',
#   'hrrr_missing',
#   'is_active_polymarket_station',
#   'lat',
#   'lon',
#   'nbm_as_of_hour_local',
#   'nbm_available',
#   'nbm_forecast_window_hours',
#   'nbm_horizon_hours',
#   'nbm_issue_hour_local',
#   'nbm_issue_hour_utc',
#   'nbm_missing',
#   'observed_fetch_status',
#   'observed_observation_type',
#   'observed_pressure_source',
#   'provider_count_available',
#   'year'])

# %% [markdown]
# ## Data Availability

# %%
availability = provider_availability(
    PROJECT_ROOT,
    timing_mode=TIMING_MODE,
    providers=PROVIDERS,
)

availability.loc[availability["station_id"].eq(STATION_ID)]
# Out:
#    station_id provider  row_count first_contract_date last_contract_date
# 21       KORD      gfs       1983          2021-01-01         2026-06-10
# 22       KORD     hrrr       1987          2021-01-01         2026-06-10
# 23       KORD      nbm       1986          2021-01-01         2026-06-10

# %% [markdown]
# ## Model Scores

# %%
missing_packages = missing_model_dependencies()
if missing_packages:
    raise ImportError(
        "Missing station-stacking ML packages: "
        + ", ".join(missing_packages)
        + ". Install them with: python -m pip install -r requirements.txt"
    )

config = StationStackingConfig(
    station_id=STATION_ID,
    project_root=PROJECT_ROOT,
    timing_mode=TIMING_MODE,
    providers=PROVIDERS,
    fast_mode=FAST_MODE,
    optuna_trials=OPTUNA_TRIALS,
    stack_optuna_trials=STACK_OPTUNA_TRIALS,
    optuna_startup_trials=OPTUNA_STARTUP_TRIALS,
    stack_optuna_startup_trials=STACK_OPTUNA_STARTUP_TRIALS,
    optuna_metric=OPTUNA_METRIC,
    optuna_verbose=OPTUNA_VERBOSE,
    feature_version="v8",
    hyperparameter_space="wide",
    year_split_folds=YEAR_SPLIT_EXPANDING_FOLDS,
    year_split_test_train_years=(2021, 2025),
    year_split_test_year=2026,
    output_dir=PROJECT_ROOT / "data" / "calibration" / "station_stacking_v8",
)

config.resolved_optuna_storage_path()
# Out:
# WindowsPath('D:/dev/weather-research/data/calibration/station_stacking_v8/KORD_optuna.sqlite3')

# %%
result = run_station_year_split_experiment(config)
result.scoreboard
# Out:
# [I 2026-06-15 05:48:29,662] A new study created in RDB with name: KORD_v8_base_xgboost_mae_f
# [I 2026-06-15 05:48:47,200] Trial 0 finished with value: 1.6542957244254408 and parameters: {'n_estimators': 1342, 'learning_rate': 0.19043899115982607, 'max_depth': 9, 'min_child_weight': 2.481040974867813, 'gamma': 2.340279606636548, 'subsample': 0.4513964382185317, 'colsample_bytree': 0.3877543479093296, 'reg_alpha': 2.478071022662141, 'reg_lambda': 0.6132587025321562}. Best is trial 0 with value: 1.6542957244254408.
# [I 2026-06-15 05:52:24,638] Trial 1 finished with value: 2.0307891774700084 and parameters: {'n_estimators': 2493, 'learning_rate': 0.001120367191095075, 'max_depth': 12, 'min_child_weight': 21.368329072358772, 'gamma': 3.185086660174142, 'subsample': 0.4681862286846154, 'colsample_bytree': 0.46921293140473197, 'reg_alpha': 4.476173538513514e-07, 'reg_lambda': 0.20253776634919213}. Best is trial 0 with value: 1.6542957244254408.
# [I 2026-06-15 05:55:50,261] Trial 2 finished with value: 1.4901088123138135 and parameters: {'n_estimators': 1540, 'learning_rate': 0.004992867109217114, 'max_depth': 8, 'min_child_weight': 0.03613894271216528, 'gamma': 4.3821697280282725, 'subsample': 0.5881351981408995, 'colsample_bytree': 0.6464454897410734, 'reg_alpha': 0.26430874752361627, 'reg_lambda': 0.0018119678627933364}. Best is trial 2 with value: 1.4901088123138135.
# [I 2026-06-15 05:57:21,673] Trial 3 finished with value: 1.6948227680544 and parameters: {'n_estimators': 1824, 'learning_rate': 0.026337502897485255, 'max_depth': 1, 'min_child_weight': 2.69264691008618, 'gamma': 2.557861855309373, 'subsample': 0.39228353544043165, 'colsample_bytree': 0.9667755992146666, 'reg_alpha': 38.6887231523051, 'reg_lambda': 12.408975837016275}. Best is trial 2 with value: 1.4901088123138135.
# [I 2026-06-15 06:00:13,586] Trial 4 finished with value: 3.4488379164115006 and parameters: {'n_estimators': 1101, 'learning_rate': 0.0017147936629846843, 'max_depth': 9, 'min_child_weight': 0.5762487216478605, 'gamma': 1.8305735226716824, 'subsample': 0.6718649915723256, 'colsample_bytree': 0.37235253872489193, 'reg_alpha': 8.162906555194692, 'reg_lambda': 0.004271500153828077}. Best is trial 2 with value: 1.4901088123138135.
# [I 2026-06-15 06:04:28,417] Trial 5 finished with value: 1.673380436311221 and parameters: {'n_estimators': 2336, 'learning_rate': 0.00559067775661512, 'max_depth': 7, 'min_child_weight': 1.5375920235481764, 'gamma': 2.7728168328829055, 'subsample': 0.980230008046963, 'colsample_bytree': 0.8538363351847245, 'reg_alpha': 18.792618557420877, 'reg_lambda': 43.484449457612314}. Best is trial 2 with value: 1.4901088123138135.
# [I 2026-06-15 06:04:43,431] Trial 6 finished with value: 1.7685093075971927 and parameters: {'n_estimators': 2113, 'learning_rate': 0.16240489353272883, 'max_depth': 2, 'min_child_weight': 0.06080390190296603, 'gamma': 0.678409333658071, 'subsample': 0.5614647149961218, 'colsample_bytree': 0.6026402382981633, 'reg_alpha': 1.8037999945880162e-07, 'reg_lambda': 16.668629892722056}. Best is trial 2 with value: 1.4901088123138135.
# [I 2026-06-15 06:07:07,560] Trial 7 finished with value: 1.4881219874598408 and parameters: {'n_estimators': 1281, 'learning_rate': 0.0047169807141865345, 'max_depth': 7, 'min_child_weight': 0.0366181922039243, 'gamma': 12.032954711310595, 'subsample': 0.398457918391851, 'colsample_bytree': 0.9914765087903362, 'reg_alpha': 0.18490013641000916, 'reg_lambda': 0.0017869543989965139}. Best is trial 7 with value: 1.4881219874598408.
# [I 2026-06-15 06:07:11,392] Trial 8 pruned.
# [I 2026-06-15 06:08:35,664] Trial 9 finished with value: 1.687548942867143 and parameters: {'n_estimators': 2201, 'learning_rate': 0.006215464818952927, 'max_depth': 1, 'min_child_weight': 0.17535949529764422, 'gamma': 4.877749830401205, 'subsample': 0.8242440159197416, 'colsample_bytree': 0.7644123563808884, 'reg_alpha': 4.4315220126915325, 'reg_lambda': 0.09450187118503514}. Best is trial 7 with value: 1.4881219874598408.
# [I 2026-06-15 06:08:53,196] Trial 10 finished with value: 1.5220193149183356 and parameters: {'n_estimators': 462, 'learning_rate': 0.051323729958866915, 'max_depth': 10, 'min_child_weight': 1.7583640270008525, 'gamma': 11.564507699318415, 'subsample': 0.670967137636854, 'colsample_bytree': 0.689776339098296, 'reg_alpha': 1.3504926357029513e-05, 'reg_lambda': 0.0001445994629863374}. Best is trial 7 with value: 1.4881219874598408.
# [I 2026-06-15 06:09:08,404] Trial 11 pruned.
# [I 2026-06-15 06:09:35,730] Trial 12 pruned.
# [I 2026-06-15 06:09:46,187] Trial 13 finished with value: 1.6309104523793998 and parameters: {'n_estimators': 693, 'learning_rate': 0.13813474572232612, 'max_depth': 7, 'min_child_weight': 16.973078532467014, 'gamma': 13.4413694988524, 'subsample': 0.5567022587317115, 'colsample_bytree': 0.4215337509429899, 'reg_alpha': 5.435280359192946e-08, 'reg_lambda': 0.049115547267693904}. Best is trial 7 with value: 1.4881219874598408.
# [I 2026-06-15 06:10:07,479] Trial 14 finished with value: 1.708004158732714 and parameters: {'n_estimators': 2872, 'learning_rate': 0.11587248002108354, 'max_depth': 1, 'min_child_weight': 1.1040511903162256, 'gamma': 6.261165047231685, 'subsample': 0.49437007680597467, 'colsample_bytree': 0.4279124887668938, 'reg_alpha': 1.125594744942969e-06, 'reg_lambda': 87.35792858155622}. Best is trial 7 with value: 1.4881219874598408.
# [I 2026-06-15 06:10:41,612] Trial 15 finished with value: 1.5189778955955078 and parameters: {'n_estimators': 1165, 'learning_rate': 0.01753996764864722, 'max_depth': 9, 'min_child_weight': 0.28478585168562975, 'gamma': 14.57673124081441, 'subsample': 0.9755907417123723, 'colsample_bytree': 0.5136584922864866, 'reg_alpha': 9.267915611871232e-05, 'reg_lambda': 0.007867617817691417}. Best is trial 7 with value: 1.4881219874598408.
# [I 2026-06-15 06:12:17,665] Trial 16 pruned.
# [I 2026-06-15 06:12:23,560] Trial 17 finished with value: 1.7017344881548715 and parameters: {'n_estimators': 1739, 'learning_rate': 0.23095674942027827, 'max_depth': 3, 'min_child_weight': 4.881375191603673, 'gamma': 11.424294229930764, 'subsample': 0.5044644035950597, 'colsample_bytree': 0.8233406265977088, 'reg_alpha': 2.5905834853865256e-06, 'reg_lambda': 0.9642241508030058}. Best is trial 7 with value: 1.4881219874598408.
# [I 2026-06-15 06:12:55,738] Trial 18 finished with value: 1.6592027726991012 and parameters: {'n_estimators': 2236, 'learning_rate': 0.01926440281006607, 'max_depth': 2, 'min_child_weight': 21.938654178115062, 'gamma': 4.811700974576038, 'subsample': 0.4712370317599052, 'colsample_bytree': 0.3765038420105965, 'reg_alpha': 0.0012322967930262527, 'reg_lambda': 1.859316691031827}. Best is trial 7 with value: 1.4881219874598408.
# [I 2026-06-15 06:12:59,800] Trial 19 pruned.
# [I 2026-06-15 06:15:12,789] Trial 20 finished with value: 1.4572921883230001 and parameters: {'n_estimators': 3311, 'learning_rate': 0.003670255109095971, 'max_depth': 5, 'min_child_weight': 0.010825117624685654, 'gamma': 9.207834502381042, 'subsample': 0.6259883401420862, 'colsample_bytree': 0.8901252743324245, 'reg_alpha': 0.02076114774608232, 'reg_lambda': 0.012869285860036094}. Best is trial 20 with value: 1.4572921883230001.
# [I 2026-06-15 06:17:09,829] Trial 21 finished with value: 1.4584545190901934 and parameters: {'n_estimators': 3484, 'learning_rate': 0.003842226452185392, 'max_depth': 5, 'min_child_weight': 0.011852657412666471, 'gamma': 9.067258589995172, 'subsample': 0.6546132843781011, 'colsample_bytree': 0.9005360568871793, 'reg_alpha': 0.05416525155032146, 'reg_lambda': 0.010112204936631015}. Best is trial 20 with value: 1.4572921883230001.
# [I 2026-06-15 06:19:57,856] Trial 22 finished with value: 1.462871076769208 and parameters: {'n_estimators': 3406, 'learning_rate': 0.0032662567611587297, 'max_depth': 5, 'min_child_weight': 0.010521267410862093, 'gamma': 9.004676488001623, 'subsample': 0.6539681036550723, 'colsample_bytree': 0.9067897279391067, 'reg_alpha': 0.021015514889023586, 'reg_lambda': 0.019790047668152944}. Best is trial 20 with value: 1.4572921883230001.
# [I 2026-06-15 06:23:40,615] Trial 23 finished with value: 1.4565390660724877 and parameters: {'n_estimators': 3487, 'learning_rate': 0.002820951626347038, 'max_depth': 5, 'min_child_weight': 0.010136842282118842, 'gamma': 8.820079496804484, 'subsample': 0.6631499191126086, 'colsample_bytree': 0.8999551774479133, 'reg_alpha': 0.006747380679394789, 'reg_lambda': 0.013205248890677666}. Best is trial 23 with value: 1.4565390660724877.
# [I 2026-06-15 06:26:44,866] Trial 24 finished with value: 1.4623224330834683 and parameters: {'n_estimators': 3479, 'learning_rate': 0.0024187942910374833, 'max_depth': 5, 'min_child_weight': 0.010122187965441924, 'gamma': 9.480347542579763, 'subsample': 0.7531564633047163, 'colsample_bytree': 0.8757165957535693, 'reg_alpha': 0.0035849619178030135, 'reg_lambda': 0.020731767266903563}. Best is trial 23 with value: 1.4565390660724877.
# [I 2026-06-15 06:27:27,772] Trial 25 finished with value: 1.468451300764166 and parameters: {'n_estimators': 3093, 'learning_rate': 0.010368856783458887, 'max_depth': 5, 'min_child_weight': 0.018644547759783643, 'gamma': 9.586888391501523, 'subsample': 0.6182564011645987, 'colsample_bytree': 0.7977304787938344, 'reg_alpha': 0.023255619734384274, 'reg_lambda': 0.010975225078446072}. Best is trial 23 with value: 1.4565390660724877.
# [I 2026-06-15 06:30:30,455] Trial 26 finished with value: 1.4829355649262679 and parameters: {'n_estimators': 3109, 'learning_rate': 0.0027213640998641187, 'max_depth': 6, 'min_child_weight': 0.019459731171464312, 'gamma': 7.672623782027944, 'subsample': 0.7250169630282906, 'colsample_bytree': 0.9183013497498486, 'reg_alpha': 0.00020358055897526917, 'reg_lambda': 0.0001210716957163458}. Best is trial 23 with value: 1.4565390660724877.
# [I 2026-06-15 06:31:18,261] Trial 27 finished with value: 1.469624810432435 and parameters: {'n_estimators': 2730, 'learning_rate': 0.008618463400958615, 'max_depth': 4, 'min_child_weight': 0.08610115413709321, 'gamma': 8.152597818668024, 'subsample': 0.7313649494132782, 'colsample_bytree': 0.8782571285421782, 'reg_alpha': 0.06139205570751336, 'reg_lambda': 0.056556792860514245}. Best is trial 23 with value: 1.4565390660724877.
# [I 2026-06-15 06:34:01,463] Trial 28 finished with value: 1.4692495430238164 and parameters: {'n_estimators': 3141, 'learning_rate': 0.0031266902581905203, 'max_depth': 6, 'min_child_weight': 0.02077496101143485, 'gamma': 10.487032090972027, 'subsample': 0.6219832327312058, 'colsample_bytree': 0.7185154718452946, 'reg_alpha': 0.0021276142782059577, 'reg_lambda': 0.21750782420502218}. Best is trial 23 with value: 1.4565390660724877.
# [I 2026-06-15 06:35:16,757] Trial 29 pruned.
# [I 2026-06-15 06:36:34,996] Trial 30 finished with value: 1.475392080457312 and parameters: {'n_estimators': 2850, 'learning_rate': 0.008454997140876629, 'max_depth': 6, 'min_child_weight': 0.09656687015514333, 'gamma': 6.779313041259529, 'subsample': 0.6158506961957103, 'colsample_bytree': 0.8273541932830581, 'reg_alpha': 0.0002989989989380722, 'reg_lambda': 0.006501384152230931}. Best is trial 23 with value: 1.4565390660724877.
# [I 2026-06-15 06:38:09,497] Trial 31 finished with value: 1.4846743672048786 and parameters: {'n_estimators': 3456, 'learning_rate': 0.0033115205517413103, 'max_depth': 4, 'min_child_weight': 0.011045126971218738, 'gamma': 9.8944432334615, 'subsample': 0.7260051130997733, 'colsample_bytree': 0.8875679195857704, 'reg_alpha': 0.006761896088182293, 'reg_lambda': 0.027189715904205665}. Best is trial 23 with value: 1.4565390660724877.
# [I 2026-06-15 06:46:06,643] Trial 32 finished with value: 1.4803341443593991 and parameters: {'n_estimators': 3199, 'learning_rate': 0.0021199841844527904, 'max_depth': 5, 'min_child_weight': 0.020949240256273823, 'gamma': 8.823789806850383, 'subsample': 0.8087463195567189, 'colsample_bytree': 0.8741537589131635, 'reg_alpha': 0.45312995285879637, 'reg_lambda': 0.149665204381857}. Best is trial 23 with value: 1.4565390660724877.
# [I 2026-06-15 06:50:45,851] Trial 33 finished with value: 1.4660623094607281 and parameters: {'n_estimators': 3465, 'learning_rate': 0.003977961621767453, 'max_depth': 5, 'min_child_weight': 0.010332868321214599, 'gamma': 10.564100836959927, 'subsample': 0.7631706157843746, 'colsample_bytree': 0.9954962811756795, 'reg_alpha': 0.007914939210979955, 'reg_lambda': 0.0031239653488205283}. Best is trial 23 with value: 1.4565390660724877.
# [I 2026-06-15 06:59:54,637] Trial 34 finished with value: 1.5416151876914743 and parameters: {'n_estimators': 2926, 'learning_rate': 0.002517765336032587, 'max_depth': 3, 'min_child_weight': 0.03240174316164981, 'gamma': 12.524163577718845, 'subsample': 0.7674739551619567, 'colsample_bytree': 0.9249962092511467, 'reg_alpha': 0.0011148925598718667, 'reg_lambda': 0.015612255026815453}. Best is trial 23 with value: 1.4565390660724877.
# [I 2026-06-15 07:06:18,773] Trial 35 pruned.
# [I 2026-06-15 07:07:56,178] Trial 36 finished with value: 1.4613772246911385 and parameters: {'n_estimators': 3282, 'learning_rate': 0.006528371072659524, 'max_depth': 5, 'min_child_weight': 0.03586747540869105, 'gamma': 10.496880707977457, 'subsample': 0.5848387219085791, 'colsample_bytree': 0.7468142768098173, 'reg_alpha': 6.926690681472101e-05, 'reg_lambda': 0.035335816772197416}. Best is trial 23 with value: 1.4565390660724877.
# [I 2026-06-15 07:09:26,083] Trial 37 finished with value: 1.4926314169007102 and parameters: {'n_estimators': 2599, 'learning_rate': 0.006572119855267846, 'max_depth': 11, 'min_child_weight': 0.030035842914427284, 'gamma': 10.482240496676193, 'subsample': 0.590474261078047, 'colsample_bytree': 0.7811499819226497, 'reg_alpha': 2.4684238218893253e-05, 'reg_lambda': 0.002298726096824992}. Best is trial 23 with value: 1.4565390660724877.
# [I 2026-06-15 07:11:46,624] Trial 38 finished with value: 1.4813104563687665 and parameters: {'n_estimators': 3021, 'learning_rate': 0.004135470207370576, 'max_depth': 7, 'min_child_weight': 0.058522649382855944, 'gamma': 7.169682797322761, 'subsample': 0.6499796762194039, 'colsample_bytree': 0.7090039394927043, 'reg_alpha': 0.045090124301228475, 'reg_lambda': 0.042125469849241724}. Best is trial 23 with value: 1.4565390660724877.
# [I 2026-06-15 07:12:32,759] Trial 39 finished with value: 1.4639317351218504 and parameters: {'n_estimators': 3257, 'learning_rate': 0.009891397083830916, 'max_depth': 6, 'min_child_weight': 0.09679854433057206, 'gamma': 13.059835890707877, 'subsample': 0.5814096702902352, 'colsample_bytree': 0.6643581648539975, 'reg_alpha': 1.3310098444571814e-10, 'reg_lambda': 0.4305825213762497}. Best is trial 23 with value: 1.4565390660724877.
# [I 2026-06-15 07:14:38,109] Trial 40 finished with value: 1.4563406820326954 and parameters: {'n_estimators': 2716, 'learning_rate': 0.006621736445179285, 'max_depth': 4, 'min_child_weight': 0.05267411493320409, 'gamma': 5.779312631252608, 'subsample': 0.692537107884177, 'colsample_bytree': 0.7363350290072265, 'reg_alpha': 6.149247856417916e-05, 'reg_lambda': 0.004911235775435307}. Best is trial 40 with value: 1.4563406820326954.
# [I 2026-06-15 07:17:30,343] Trial 41 finished with value: 1.4701102715758843 and parameters: {'n_estimators': 2756, 'learning_rate': 0.006548056098473416, 'max_depth': 4, 'min_child_weight': 0.04900531733370841, 'gamma': 3.9483935101246344, 'subsample': 0.6907225508864598, 'colsample_bytree': 0.7288093809687222, 'reg_alpha': 5.277878553845616e-05, 'reg_lambda': 0.004435959819547812}. Best is trial 40 with value: 1.4563406820326954.
# [I 2026-06-15 07:20:23,707] Trial 42 finished with value: 1.5199733236161843 and parameters: {'n_estimators': 2446, 'learning_rate': 0.004969758140232131, 'max_depth': 3, 'min_child_weight': 0.02815025177335222, 'gamma': 5.605328782392123, 'subsample': 0.6309393557097258, 'colsample_bytree': 0.8175757768333133, 'reg_alpha': 0.0005412060603583277, 'reg_lambda': 0.0011043828947308518}. Best is trial 40 with value: 1.4563406820326954.
# [I 2026-06-15 07:21:17,251] Trial 43 pruned.
# [I 2026-06-15 07:22:37,415] Trial 44 finished with value: 1.5681225627366184 and parameters: {'n_estimators': 3031, 'learning_rate': 0.013511512816800623, 'max_depth': 2, 'min_child_weight': 0.014954016669498305, 'gamma': 8.021060012939394, 'subsample': 0.5534484495463537, 'colsample_bytree': 0.7550940891263069, 'reg_alpha': 0.8274283181587587, 'reg_lambda': 0.008415092535331133}. Best is trial 40 with value: 1.4563406820326954.
# [I 2026-06-15 07:28:43,324] Trial 45 finished with value: 1.4594760186486762 and parameters: {'n_estimators': 3305, 'learning_rate': 0.00727591535873493, 'max_depth': 4, 'min_child_weight': 0.2810597023317019, 'gamma': 9.171110905807828, 'subsample': 0.43995826345972977, 'colsample_bytree': 0.9747188951069675, 'reg_alpha': 0.11168261811866306, 'reg_lambda': 0.0285507533706269}. Best is trial 40 with value: 1.4563406820326954.
# [I 2026-06-15 07:30:37,133] Trial 46 finished with value: 1.4619295589648247 and parameters: {'n_estimators': 2042, 'learning_rate': 0.02701714872733871, 'max_depth': 4, 'min_child_weight': 0.41261328551681986, 'gamma': 7.194202668989909, 'subsample': 0.43978231294868964, 'colsample_bytree': 0.9726030166037297, 'reg_alpha': 0.09089503454046083, 'reg_lambda': 0.004595392319038469}. Best is trial 40 with value: 1.4563406820326954.
# [I 2026-06-15 07:44:39,864] Trial 47 finished with value: 1.506255699794693 and parameters: {'n_estimators': 2669, 'learning_rate': 0.004073422591094764, 'max_depth': 3, 'min_child_weight': 0.3085593688024881, 'gamma': 9.486771537964694, 'subsample': 0.42955904668097855, 'colsample_bytree': 0.9628167011222738, 'reg_alpha': 0.01216195853515399, 'reg_lambda': 0.0003161596078284625}. Best is trial 40 with value: 1.4563406820326954.
# [I 2026-06-15 07:47:29,008] Trial 48 pruned.
# [I 2026-06-15 08:07:12,916] Trial 49 finished with value: 1.4755922103624872 and parameters: {'n_estimators': 3360, 'learning_rate': 0.0015215129704305953, 'max_depth': 4, 'min_child_weight': 0.07351696260971347, 'gamma': 5.628382822058974, 'subsample': 0.5200006972252884, 'colsample_bytree': 0.8520967336204456, 'reg_alpha': 0.1579066055085808, 'reg_lambda': 0.013195277679635251}. Best is trial 40 with value: 1.4563406820326954.
# [I 2026-06-15 08:07:13,540] A new study created in RDB with name: KORD_v8_base_lightgbm_mae_f
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 08:08:32,220] Trial 0 finished with value: 1.872467254349396 and parameters: {'n_estimators': 447, 'learning_rate': 0.028873871707375695, 'num_leaves': 71, 'max_depth': 5, 'min_child_samples': 83, 'min_split_gain': 4.295687454742988, 'bagging_fraction': 0.7829586385137167, 'bagging_freq': 4, 'feature_fraction': 0.3688589858758342, 'lambda_l1': 0.06382334403151436, 'lambda_l2': 0.03080292177315921}. Best is trial 0 with value: 1.872467254349396.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 08:11:21,027] Trial 1 finished with value: 2.0375165806012383 and parameters: {'n_estimators': 2817, 'learning_rate': 0.004074615160588706, 'num_leaves': 32, 'max_depth': 13, 'min_child_samples': 57, 'min_split_gain': 2.0249472402362985, 'bagging_fraction': 0.5554627061618356, 'bagging_freq': 1, 'feature_fraction': 0.898096051249308, 'lambda_l1': 1.5391104005532914, 'lambda_l2': 132.19976430960952}. Best is trial 0 with value: 1.872467254349396.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 08:11:27,222] Trial 2 finished with value: 1.7626164376674645 and parameters: {'n_estimators': 1379, 'learning_rate': 0.1944487980595256, 'num_leaves': 230, 'max_depth': 10, 'min_child_samples': 22, 'min_split_gain': 4.485492899907672, 'bagging_fraction': 0.5437022754476957, 'bagging_freq': 2, 'feature_fraction': 0.353334206891897, 'lambda_l1': 0.00032993636349211094, 'lambda_l2': 0.09925376145099525}. Best is trial 2 with value: 1.7626164376674645.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 08:11:34,173] Trial 3 finished with value: 2.655460847951656 and parameters: {'n_estimators': 2246, 'learning_rate': 0.22165362064553062, 'num_leaves': 466, 'max_depth': 13, 'min_child_samples': 132, 'min_split_gain': 0.5200947492738145, 'bagging_fraction': 0.4675944869176356, 'bagging_freq': 7, 'feature_fraction': 0.6177694392011331, 'lambda_l1': 2.399967979035352, 'lambda_l2': 1.7195277953675168}. Best is trial 2 with value: 1.7626164376674645.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 08:16:47,566] Trial 4 finished with value: 2.012635412935741 and parameters: {'n_estimators': 2219, 'learning_rate': 0.004579029224032115, 'num_leaves': 460, 'max_depth': 4, 'min_child_samples': 102, 'min_split_gain': 4.967862461970517, 'bagging_fraction': 0.8282226029796285, 'bagging_freq': 4, 'feature_fraction': 0.7144310601384277, 'lambda_l1': 8.61124348208611e-06, 'lambda_l2': 3.808668235343267}. Best is trial 2 with value: 1.7626164376674645.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 08:17:13,621] Trial 5 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 08:17:30,407] Trial 6 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 08:17:32,149] Trial 7 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 08:17:35,368] Trial 8 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 08:18:59,795] Trial 9 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 08:19:51,540] Trial 10 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 08:21:08,441] Trial 11 finished with value: 1.9813166588009972 and parameters: {'n_estimators': 756, 'learning_rate': 0.06114521776634082, 'num_leaves': 57, 'max_depth': 2, 'min_child_samples': 85, 'min_split_gain': 4.846277519155279, 'bagging_fraction': 0.8056341981316478, 'bagging_freq': 3, 'feature_fraction': 0.42848891083526186, 'lambda_l1': 5.301057710204056e-10, 'lambda_l2': 3.7660106129974493}. Best is trial 2 with value: 1.7626164376674645.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 08:28:49,210] Trial 12 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 08:31:03,318] Trial 13 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 08:31:13,537] Trial 14 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 08:31:31,516] Trial 15 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 08:31:33,913] Trial 16 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 08:32:24,727] Trial 17 finished with value: 1.8718997678328704 and parameters: {'n_estimators': 1783, 'learning_rate': 0.04864572341122393, 'num_leaves': 91, 'max_depth': 9, 'min_child_samples': 41, 'min_split_gain': 4.132892006727957, 'bagging_fraction': 0.5662560585201368, 'bagging_freq': 4, 'feature_fraction': 0.8899618930175198, 'lambda_l1': 42.540711148076, 'lambda_l2': 0.011582644290167256}. Best is trial 2 with value: 1.7626164376674645.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 08:32:48,722] Trial 18 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 08:33:52,736] Trial 19 finished with value: 1.6001416011144984 and parameters: {'n_estimators': 3473, 'learning_rate': 0.04578852488428539, 'num_leaves': 184, 'max_depth': 4, 'min_child_samples': 13, 'min_split_gain': 1.633948525123912, 'bagging_fraction': 0.58126637710312, 'bagging_freq': 4, 'feature_fraction': 0.7783357811218745, 'lambda_l1': 1.074747741122124e-09, 'lambda_l2': 0.007377559017382262}. Best is trial 19 with value: 1.6001416011144984.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 08:52:35,023] Trial 20 finished with value: 1.5595130010078426 and parameters: {'n_estimators': 3449, 'learning_rate': 0.012050791686618947, 'num_leaves': 221, 'max_depth': 7, 'min_child_samples': 7, 'min_split_gain': 0.04810004645591315, 'bagging_fraction': 0.685937988994649, 'bagging_freq': 1, 'feature_fraction': 0.772427228137977, 'lambda_l1': 0.0004686667014769191, 'lambda_l2': 0.0018026337369408825}. Best is trial 20 with value: 1.5595130010078426.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 09:05:58,398] Trial 21 finished with value: 1.537583386511568 and parameters: {'n_estimators': 3468, 'learning_rate': 0.012405429414511872, 'num_leaves': 221, 'max_depth': 7, 'min_child_samples': 3, 'min_split_gain': 1.6653740659816891, 'bagging_fraction': 0.6976761581665516, 'bagging_freq': 1, 'feature_fraction': 0.7668826297243814, 'lambda_l1': 0.00016983532804446316, 'lambda_l2': 0.0017161410033910418}. Best is trial 21 with value: 1.537583386511568.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 09:50:35,999] Trial 22 finished with value: 1.5697783977796038 and parameters: {'n_estimators': 3422, 'learning_rate': 0.012136880366846417, 'num_leaves': 188, 'max_depth': 7, 'min_child_samples': 6, 'min_split_gain': 0.16257371424216893, 'bagging_fraction': 0.6920347958562258, 'bagging_freq': 1, 'feature_fraction': 0.7587665955858165, 'lambda_l1': 0.0007296636992448463, 'lambda_l2': 0.0015580708681508719}. Best is trial 21 with value: 1.537583386511568.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 10:32:39,586] Trial 23 finished with value: 1.5621546018139818 and parameters: {'n_estimators': 2803, 'learning_rate': 0.011783442528891321, 'num_leaves': 233, 'max_depth': 7, 'min_child_samples': 10, 'min_split_gain': 0.12417864582046478, 'bagging_fraction': 0.7237152383414144, 'bagging_freq': 1, 'feature_fraction': 0.7382425750680321, 'lambda_l1': 0.0014998437732602512, 'lambda_l2': 0.0017228162877362474}. Best is trial 21 with value: 1.537583386511568.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 11:06:12,600] Trial 24 finished with value: 1.5911794718688355 and parameters: {'n_estimators': 2827, 'learning_rate': 0.013140329305025355, 'num_leaves': 233, 'max_depth': 7, 'min_child_samples': 36, 'min_split_gain': 0.29944085865147974, 'bagging_fraction': 0.7316535557096503, 'bagging_freq': 2, 'feature_fraction': 0.6873903584246481, 'lambda_l1': 9.409005884570874e-06, 'lambda_l2': 0.0015964639052574825}. Best is trial 21 with value: 1.537583386511568.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 11:36:05,836] Trial 25 finished with value: 1.576048553127138 and parameters: {'n_estimators': 2863, 'learning_rate': 0.007316668949100746, 'num_leaves': 277, 'max_depth': 6, 'min_child_samples': 35, 'min_split_gain': 1.5695914888437539, 'bagging_fraction': 0.7377357122142238, 'bagging_freq': 1, 'feature_fraction': 0.823915773450376, 'lambda_l1': 0.0005501065580481173, 'lambda_l2': 0.0012841920123523244}. Best is trial 21 with value: 1.537583386511568.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 11:52:35,879] Trial 26 finished with value: 1.5365976458058426 and parameters: {'n_estimators': 3100, 'learning_rate': 0.0190119853266352, 'num_leaves': 129, 'max_depth': 7, 'min_child_samples': 2, 'min_split_gain': 0.03572557546627626, 'bagging_fraction': 0.6764371455623306, 'bagging_freq': 1, 'feature_fraction': 0.7469256473103405, 'lambda_l1': 0.009254184562278441, 'lambda_l2': 0.0005895591203529165}. Best is trial 26 with value: 1.5365976458058426.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 11:54:19,600] Trial 27 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 11:57:09,493] Trial 28 finished with value: 1.607600511016845 and parameters: {'n_estimators': 3102, 'learning_rate': 0.017537676332558115, 'num_leaves': 9, 'max_depth': 8, 'min_child_samples': 24, 'min_split_gain': 1.559835286448352, 'bagging_fraction': 0.6788769092647768, 'bagging_freq': 1, 'feature_fraction': 0.8407840342899706, 'lambda_l1': 5.788122173668678e-07, 'lambda_l2': 0.0005566408972651704}. Best is trial 26 with value: 1.5365976458058426.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 12:29:49,523] Trial 29 finished with value: 1.5098826347656717 and parameters: {'n_estimators': 2523, 'learning_rate': 0.005409468473392092, 'num_leaves': 140, 'max_depth': 5, 'min_child_samples': 2, 'min_split_gain': 0.035102529334624516, 'bagging_fraction': 0.7616464289207343, 'bagging_freq': 3, 'feature_fraction': 0.7211560624868477, 'lambda_l1': 0.11153354263838905, 'lambda_l2': 0.003791026119802556}. Best is trial 29 with value: 1.5098826347656717.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 12:45:21,741] Trial 30 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 13:29:08,525] Trial 31 finished with value: 1.5269013698854188 and parameters: {'n_estimators': 3106, 'learning_rate': 0.004996336494505103, 'num_leaves': 212, 'max_depth': 6, 'min_child_samples': 5, 'min_split_gain': 0.05078456501291617, 'bagging_fraction': 0.7689621899219725, 'bagging_freq': 3, 'feature_fraction': 0.7801018012820025, 'lambda_l1': 6.684685049479242e-05, 'lambda_l2': 0.0031513226347746007}. Best is trial 29 with value: 1.5098826347656717.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 14:13:41,602] Trial 32 finished with value: 1.5101824280547218 and parameters: {'n_estimators': 3103, 'learning_rate': 0.004107684825490217, 'num_leaves': 83, 'max_depth': 5, 'min_child_samples': 2, 'min_split_gain': 0.4293422069050008, 'bagging_fraction': 0.7860830921586199, 'bagging_freq': 3, 'feature_fraction': 0.6451537042230601, 'lambda_l1': 0.007830755358098697, 'lambda_l2': 0.032557574145145804}. Best is trial 29 with value: 1.5098826347656717.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 14:17:04,886] Trial 33 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 14:18:41,074] Trial 34 finished with value: 1.6151641848482061 and parameters: {'n_estimators': 3090, 'learning_rate': 0.002814242647205991, 'num_leaves': 135, 'max_depth': 3, 'min_child_samples': 21, 'min_split_gain': 0.7747222815249407, 'bagging_fraction': 0.7642250803365246, 'bagging_freq': 3, 'feature_fraction': 0.702842822426032, 'lambda_l1': 0.04619911320861131, 'lambda_l2': 0.003956672430193216}. Best is trial 29 with value: 1.5098826347656717.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 14:19:23,640] Trial 35 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 14:20:43,139] Trial 36 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 14:21:03,116] Trial 37 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 14:21:38,796] Trial 38 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 14:21:59,246] Trial 39 finished with value: 1.6263088537327857 and parameters: {'n_estimators': 2364, 'learning_rate': 0.008668451175948043, 'num_leaves': 8, 'max_depth': 4, 'min_child_samples': 24, 'min_split_gain': 0.39442744301919525, 'bagging_fraction': 0.8464826640187657, 'bagging_freq': 3, 'feature_fraction': 0.8751696250593741, 'lambda_l1': 6.004293275786326e-05, 'lambda_l2': 0.00010437808487239928}. Best is trial 29 with value: 1.5098826347656717.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 14:36:41,025] Trial 40 finished with value: 1.5329292069680203 and parameters: {'n_estimators': 3037, 'learning_rate': 0.0019918996748927013, 'num_leaves': 165, 'max_depth': 8, 'min_child_samples': 2, 'min_split_gain': 0.5998808791796995, 'bagging_fraction': 0.5930243417883629, 'bagging_freq': 2, 'feature_fraction': 0.9375027893912848, 'lambda_l1': 2.0751874847765327e-06, 'lambda_l2': 0.000601842669608288}. Best is trial 29 with value: 1.5098826347656717.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 14:40:50,752] Trial 41 finished with value: 1.555841412346874 and parameters: {'n_estimators': 2977, 'learning_rate': 0.0023949654700942146, 'num_leaves': 169, 'max_depth': 8, 'min_child_samples': 5, 'min_split_gain': 0.5961675482912061, 'bagging_fraction': 0.6345867665629358, 'bagging_freq': 2, 'feature_fraction': 0.9564162896723346, 'lambda_l1': 1.2856518185217394e-06, 'lambda_l2': 0.0007367376751436616}. Best is trial 29 with value: 1.5098826347656717.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 14:42:00,926] Trial 42 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 14:44:12,458] Trial 43 finished with value: 1.5040185945919955 and parameters: {'n_estimators': 2375, 'learning_rate': 0.003538593414077517, 'num_leaves': 155, 'max_depth': 6, 'min_child_samples': 2, 'min_split_gain': 0.24573849951498294, 'bagging_fraction': 0.6108983776180088, 'bagging_freq': 3, 'feature_fraction': 0.8071423640626222, 'lambda_l1': 0.00252508633095351, 'lambda_l2': 0.015834105039219556}. Best is trial 43 with value: 1.5040185945919955.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 14:44:38,498] Trial 44 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 14:44:44,154] Trial 45 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 14:44:47,219] Trial 46 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 14:44:58,136] Trial 47 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 14:45:01,168] Trial 48 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 14:45:11,058] Trial 49 pruned.
# [I 2026-06-15 14:45:11,235] A new study created in RDB with name: KORD_v8_base_catboost_mae_f
# [I 2026-06-15 14:51:26,993] Trial 0 finished with value: 3.7889666332562526 and parameters: {'iterations': 2931, 'learning_rate': 0.001783588943232587, 'depth': 10, 'l2_leaf_reg': 0.9942958882300413, 'random_strength': 7.186216756161439, 'bagging_temperature': 12.184767612363034, 'border_count': 110, 'rsm': 0.6158971964095841}. Best is trial 0 with value: 3.7889666332562526.
# [I 2026-06-15 14:58:12,377] Trial 1 finished with value: 2.9091915174520744 and parameters: {'iterations': 1809, 'learning_rate': 0.05045361458210069, 'depth': 12, 'l2_leaf_reg': 2.206716955900187, 'random_strength': 8.55303042123218, 'bagging_temperature': 2.269274022399408, 'border_count': 68, 'rsm': 0.9723568448941463}. Best is trial 1 with value: 2.9091915174520744.
# [W 2026-06-15 14:58:35,059] Trial 2 failed with parameters: {'iterations': 3305, 'learning_rate': 0.13018523290940803, 'depth': 9, 'l2_leaf_reg': 0.29456409265689415, 'random_strength': 12.736640276136784, 'bagging_temperature': 2.78292503969807, 'border_count': 126, 'rsm': 0.9180110703516069} because of the following error: KeyboardInterrupt('').
# Traceback (most recent call last):
#   File "d:\dev\weather-research\.venv\Lib\site-packages\optuna\study\_optimize.py", line 206, in _run_trial
#     value_or_values = func(trial)
#   File "D:\dev\weather-research\src\calibration\station_stacking.py", line 1057, in objective
#     predicted, fit_metadata = _fit_predict_base_model(
#                               ~~~~~~~~~~~~~~~~~~~~~~~^
#         config=config,
#         ^^^^^^^^^^^^^^
#     ...<6 lines>...
#         early_stopping=True,
#         ^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "D:\dev\weather-research\src\calibration\station_stacking.py", line 2530, in _fit_predict_base_model
#     _fit_base_estimator(
#     ~~~~~~~~~~~~~~~~~~~^
#         estimator=estimator,
#         ^^^^^^^^^^^^^^^^^^^^
#     ...<5 lines>...
#         early_stopping_rounds=early_stopping_rounds,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "D:\dev\weather-research\src\calibration\station_stacking.py", line 2581, in _fit_base_estimator
#     estimator.fit(
#     ~~~~~~~~~~~~~^
#         x_train,
#         ^^^^^^^^
#     ...<4 lines>...
#         verbose=False,
#         ^^^^^^^^^^^^^^
#     )
#     ^
#   File "d:\dev\weather-research\.venv\Lib\site-packages\catboost\core.py", line 6178, in fit
#     return self._fit(X, y, cat_features, text_features, embedding_features, None, graph, sample_weight, None, None, None, None, baseline,
#            ~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#                      use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description,
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#                      verbose_eval, metric_period, silent, early_stopping_rounds,
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#                      save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\dev\weather-research\.venv\Lib\site-packages\catboost\core.py", line 2716, in _fit
#     self._train(
#     ~~~~~~~~~~~^
#         train_pool,
#         ^^^^^^^^^^^
#     ...<3 lines>...
#         train_params["init_model"]
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "d:\dev\weather-research\.venv\Lib\site-packages\catboost\core.py", line 1824, in _train
#     self._object._train(train_pool, test_pool, params, allow_clear_pool, init_model._object if init_model else None)
#     ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "_catboost.pyx", line 5430, in _catboost._CatBoost._train
#   File "_catboost.pyx", line 5479, in _catboost._CatBoost._train
# KeyboardInterrupt
# [W 2026-06-15 14:58:35,123] Trial 2 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 result = run_station_year_split_experiment(config)
#       2 result.scoreboard
#
# File D:\dev\weather-research\src\calibration\station_stacking.py:889, in run_station_year_split_experiment(config)
#     883 feature_columns_frame = pd.DataFrame(
#     884     [{"feature": feature, "kind": "categorical"} for feature in categorical]
#     885     + [{"feature": feature, "kind": "numeric"} for feature in numeric]
#     886 )
#     888 baseline_validation = year_split_baseline_predictions(modeling_frame, config, folds)
# --> 889 tuning_results, validation_predictions, selected = tune_year_split_base_models(
#     890     modeling_frame,
#     891     config,
#     892     categorical,
#     893     numeric,
#     894     folds,
#     895 )
#     896 test_predictions = year_split_test_predictions(
#     897     modeling_frame,
#     898     config,
#    (...)    903     test_year=test_year,
#     904 )
#     905 test_stack_predictions, stack_tuning_results = tune_year_split_stack_model(
#     906     validation_predictions=pd.concat(
#     907         [frame for frame in [baseline_validation, validation_predictions] if not frame.empty],
#    (...)    914     test_year=test_year,
#     915 )
#
# File D:\dev\weather-research\src\calibration\station_stacking.py:1178, in tune_year_split_base_models(frame, config, categorical, numeric, folds)
#    1176 remaining_trials = _remaining_optuna_trials(study, config.effective_optuna_trials)
#    1177 if remaining_trials > 0:
# -> 1178     study.optimize(objective, n_trials=remaining_trials, show_progress_bar=False, catch=(Exception,))
#    1179 stored_rows = _study_tuning_rows(study)
#    1180 rows.extend(stored_rows if stored_rows else method_rows)
#
# File d:\dev\weather-research\.venv\Lib\site-packages\optuna\study\study.py:516, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     414 def optimize(
#     415     self,
#     416     func: ObjectiveFuncType,
#    (...)    423     show_progress_bar: bool = False,
#     424 ) -> None:
#     425     """Optimize an objective function.
#     426
#     427     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)    514             If nested invocation of this method occurs.
#     515     """
# --> 516     _optimize(
#     517         study=self,
#     518         func=func,
#     519         n_trials=n_trials,
#     520         timeout=timeout,
#     521         n_jobs=n_jobs,
#     522         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     523         callbacks=callbacks,
#     524         gc_after_trial=gc_after_trial,
#     525         show_progress_bar=show_progress_bar,
#     526     )
#
# File d:\dev\weather-research\.venv\Lib\site-packages\optuna\study\_optimize.py:68, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      66 try:
#      67     if n_jobs == 1:
# ---> 68         _optimize_sequential(
#      69             study,
#      70             func,
#      71             n_trials,
#      72             timeout,
#      73             catch,
#      74             callbacks,
#      75             gc_after_trial,
#      76             reseed_sampler_rng=False,
#      77             time_start=None,
#      78             progress_bar=progress_bar,
#      79         )
#      80     else:
#      81         if n_jobs == -1:
#
# File d:\dev\weather-research\.venv\Lib\site-packages\optuna\study\_optimize.py:165, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     162         break
#     164 try:
# --> 165     frozen_trial_id = _run_trial(study, func, catch)
#     166 finally:
#     167     # The following line mitigates memory problems that can be occurred in some
#     168     # environments (e.g., services that use computing containers such as GitHub Actions).
#     169     # Please refer to the following PR for further details:
#     170     # https://github.com/optuna/optuna/pull/325.
#     171     if gc_after_trial:
#
# File d:\dev\weather-research\.venv\Lib\site-packages\optuna\study\_optimize.py:263, in _run_trial(study, func, catch)
#     256         assert False, "Should not reach."
#     258 if (
#     259     updated_state == TrialState.FAIL
#     260     and func_err is not None
#     261     and not isinstance(func_err, catch)
#     262 ):
# --> 263     raise func_err
#     264 return trial._trial_id
#
# File d:\dev\weather-research\.venv\Lib\site-packages\optuna\study\_optimize.py:206, in _run_trial(study, func, catch)
#     204 with get_heartbeat_thread(trial._trial_id, study._storage):
#     205     try:
# --> 206         value_or_values = func(trial)
#     207     except exceptions.TrialPruned as e:
#     208         # TODO(mamu): Handle multi-objective cases.
#     209         state = TrialState.PRUNED
#
# File D:\dev\weather-research\src\calibration\station_stacking.py:1057, in tune_year_split_base_models.<locals>.objective(trial)
#    1055     continue
#    1056 try:
# -> 1057     predicted, fit_metadata = _fit_predict_base_model(
#    1058         config=config,
#    1059         categorical=categorical,
#    1060         numeric=numeric,
#    1061         method=method,
#    1062         params=params,
#    1063         train=train,
#    1064         valid=valid,
#    1065         early_stopping=True,
#    1066     )
#    1067 except Exception as exc:  # noqa: BLE001
#    1068     row = {
#    1069         "method": method,
#    1070         "trial_number": trial.number,
#    (...)   1079         **{f"param_{key}": value for key, value in params.items()},
#    1080     }
#
# File D:\dev\weather-research\src\calibration\station_stacking.py:2530, in _fit_predict_base_model(config, categorical, numeric, method, params, train, valid, early_stopping)
#    2528 early_stopping_rounds = _early_stopping_rounds(config) if early_stopping else None
#    2529 estimator = _build_base_model_estimator(config, method, params, early_stopping_rounds=early_stopping_rounds)
# -> 2530 _fit_base_estimator(
#    2531     estimator=estimator,
#    2532     method=method,
#    2533     x_train=x_train,
#    2534     y_train=y_train,
#    2535     x_valid=x_valid,
#    2536     y_valid=y_valid,
#    2537     early_stopping_rounds=early_stopping_rounds,
#    2538 )
#    2539 metadata = {
#    2540     "numeric_features": ",".join(fit_numeric),
#    2541     "categorical_features": ",".join(fit_categorical),
#    2542     "best_iteration": _best_iteration(estimator),
#    2543 }
#    2544 return np.asarray(estimator.predict(x_valid), dtype=float), metadata
#
# File D:\dev\weather-research\src\calibration\station_stacking.py:2581, in _fit_base_estimator(estimator, method, x_train, y_train, x_valid, y_valid, early_stopping_rounds)
#    2579         return
#    2580     if method == "catboost":
# -> 2581         estimator.fit(
#    2582             x_train,
#    2583             y_train,
#    2584             eval_set=(x_valid, y_valid),
#    2585             early_stopping_rounds=early_stopping_rounds,
#    2586             use_best_model=True,
#    2587             verbose=False,
#    2588         )
#    2589         return
#    2590 except TypeError:
#
# File d:\dev\weather-research\.venv\Lib\site-packages\catboost\core.py:6178, in CatBoostRegressor.fit(self, X, y, cat_features, text_features, embedding_features, graph, sample_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    6176 if 'loss_function' in params:
#    6177     CatBoostRegressor._check_is_compatible_loss(params['loss_function'])
# -> 6178 return self._fit(X, y, cat_features, text_features, embedding_features, None, graph, sample_weight, None, None, None, None, baseline,
#    6179                  use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description,
#    6180                  verbose_eval, metric_period, silent, early_stopping_rounds,
#    6181                  save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#
# File d:\dev\weather-research\.venv\Lib\site-packages\catboost\core.py:2716, in CatBoost._fit(self, X, y, cat_features, text_features, embedding_features, pairs, graph, sample_weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    2713 allow_clear_pool = train_params["allow_clear_pool"]
#    2715 with plot_wrapper(plot, plot_file, 'Training plots', [_get_train_dir(params)]):
# -> 2716     self._train(
#    2717         train_pool,
#    2718         train_params["eval_sets"],
#    2719         params,
#    2720         allow_clear_pool,
#    2721         train_params["init_model"]
#    2722     )
#    2724 # Have property feature_importance possibly set
#    2725 loss = self._object._get_loss_function_name()
#
# File d:\dev\weather-research\.venv\Lib\site-packages\catboost\core.py:1824, in _CatBoostBase._train(self, train_pool, test_pool, params, allow_clear_pool, init_model)
#    1823 def _train(self, train_pool, test_pool, params, allow_clear_pool, init_model):
# -> 1824     self._object._train(train_pool, test_pool, params, allow_clear_pool, init_model._object if init_model else None)
#    1825     self._set_trained_model_attributes()
#
# File _catboost.pyx:5430, in _catboost._CatBoost._train()
# -> 5430 'Could not get source, probably due dynamically evaluated source code.'
#
# File _catboost.pyx:5479, in _catboost._CatBoost._train()
# -> 5479 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyboardInterrupt:

# %% [markdown]
# ## V8 Feature Coverage

# %%
v8_feature_coverage = (
    result.features[V8_FEATURE_COLUMNS]
    .notna()
    .mean()
    .mul(100)
    .sort_values(ascending=False)
    .rename("coverage_pct")
    .reset_index()
    .rename(columns={"index": "feature"})
)

v8_feature_coverage

# %%
result.feature_columns.loc[result.feature_columns["feature"].isin(V8_FEATURE_COLUMNS)]

# %% [markdown]
# ## Dropped Feature Check

# %%
dropped_present = result.feature_columns.loc[
    result.feature_columns["feature"].isin(V8_DROPPED_FEATURE_COLUMNS)
]

dropped_present

# %% [markdown]
# ## Morning Trend Coverage

# %%
trend_coverage = (
    result.features[TREND_COLUMNS]
    .notna()
    .mean()
    .mul(100)
    .sort_values(ascending=False)
    .rename("coverage_pct")
    .reset_index()
    .rename(columns={"index": "feature"})
)

trend_coverage

# %% [markdown]
# ## Rounded Within 1F Accuracy

# %%
preds = pd.concat(
    [
        result.validation_predictions.assign(period="validation_2024_2025"),
        result.test_predictions.assign(period="oof_2026"),
    ],
    ignore_index=True,
)

predicted_high = pd.to_numeric(preds["predicted_high_f"], errors="coerce")
preds["predicted_high_rounded_f"] = np.floor(predicted_high + 0.5)
preds["within_1f_after_round"] = (
    pd.to_numeric(preds["actual_high_f"], errors="coerce") - preds["predicted_high_rounded_f"]
).abs().le(1)

within_1f_accuracy_by_period = (
    preds
    .dropna(subset=["actual_high_f", "predicted_high_rounded_f"])
    .groupby(["period", "method"], as_index=False)
    .agg(
        count=("within_1f_after_round", "size"),
        within_1f_count=("within_1f_after_round", "sum"),
        within_1f_accuracy_pct=("within_1f_after_round", lambda x: x.mean() * 100),
    )
    .sort_values(["period", "within_1f_accuracy_pct"], ascending=[True, False])
)

within_1f_accuracy_by_period

# %% [markdown]
# ## Version Comparison

# %%
comparison_frames = []
for version, folder in [
    ("v1", PROJECT_ROOT / "data" / "calibration" / "station_stacking"),
    ("v2", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v2"),
    ("v3", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v3"),
    ("v4", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v4"),
    ("v5", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v5"),
    ("v6", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v6"),
    ("v7", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v7"),
    ("v8", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v8"),
]:
    path = folder / f"{STATION_ID}_year_split_scoreboard.csv"
    if path.exists():
        frame = pd.read_csv(path)
        frame["version"] = version
        comparison_frames.append(frame)

version_comparison = pd.concat(comparison_frames, ignore_index=True) if comparison_frames else pd.DataFrame()
if not version_comparison.empty:
    version_comparison = version_comparison.sort_values(["period", "mae_f", "version", "method"]).reset_index(drop=True)
version_comparison

# %% [markdown]
# ## 2026 OOF Weather Brackets

# %%
result.bracket_metrics

# %% [markdown]
# # Station Stacking v8 - KAUS
#
# Experimental notebook for `KAUS`.
#
# This version keeps the v7 live-safe GFS/HRRR/NBM contract, adds source-owned remaining-warmup feature engineering, and drops only conservative zero-importance input fields. Artifacts are written to `data/calibration/station_stacking_v8`.

# %%
from pathlib import Path
import os
import sys
import warnings

warnings.filterwarnings("ignore", message="IProgress not found.*")
warnings.filterwarnings("ignore", message="Skipping features without any observed values.*")

PROJECT_ROOT = Path.cwd().resolve()
while not (PROJECT_ROOT / "src" / "calibration" / "station_stacking.py").exists():
    if PROJECT_ROOT.parent == PROJECT_ROOT:
        raise RuntimeError("Could not find project root containing src/calibration/station_stacking.py")
    PROJECT_ROOT = PROJECT_ROOT.parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

os.environ["WEATHER_RESEARCH_INCLUDE_DIRECT_NBM"] = "1"

STATION_ID = "KAUS"
PROVIDERS = ("gfs", "hrrr", "nbm")
TIMING_MODE = "same_day_11am_live_safe"
FAST_MODE = False
OPTUNA_TRIALS = 50
STACK_OPTUNA_TRIALS = 50
OPTUNA_STARTUP_TRIALS = 20
STACK_OPTUNA_STARTUP_TRIALS = 20
OPTUNA_METRIC = "mae_f"
OPTUNA_VERBOSE = True
PROJECT_ROOT
# Out:
# WindowsPath('D:/dev/weather-research')

# %%
import numpy as np
import pandas as pd

from src.calibration.station_stacking import (
    StationStackingConfig,
    V8_DROPPED_FEATURE_COLUMNS,
    V8_FEATURE_COLUMNS,
    YEAR_SPLIT_EXPANDING_FOLDS,
    missing_model_dependencies,
    provider_availability,
    run_station_year_split_experiment,
)

# %% [markdown]
# ## V8 Contract
#
# `feature_version="v8"` keeps the v7 live-safe NBM setup and direct `actual_high_f` target. V8 adds remaining-warmup features and removes only conservative zero-importance model inputs from the feature matrix.

# %%
fold_spec = pd.DataFrame(
    [
        {
            "fold": fold.name,
            "train_start_year": fold.train_start_year,
            "train_end_year": fold.train_end_year,
            "validation_year": fold.validation_year,
        }
        for fold in YEAR_SPLIT_EXPANDING_FOLDS
    ]
)

fold_spec
# Out:
#                      fold  train_start_year  train_end_year  validation_year
# 0  fold_2021_2023_to_2024              2021            2023             2024
# 1  fold_2021_2024_to_2025              2021            2024             2025

# %%
V8_FEATURE_COLUMNS, sorted(V8_DROPPED_FEATURE_COLUMNS)
# Out:
# (['v2_recent_heat_anomaly_f',
#   'v2_recent_heat_momentum_f',
#   'v2_morning_warmup_to_consensus_f',
#   'v2_consensus_minus_7d_actual_f',
#   'v2_spread_per_warmup_f',
#   'v2_humidity_warmup_interaction',
#   'v3_high_so_far_above_current_f',
#   'v3_remaining_warmup_from_high_so_far_f',
#   'v3_high_so_far_minus_lag_1d_f',
#   'v3_high_so_far_minus_7d_actual_f',
#   'v3_remaining_warmup_per_spread_f',
#   'v3_humidity_remaining_warmup_interaction',
#   'v4_forecast_precip_total_mean_mm',
#   'v4_forecast_precip_total_max_mm',
#   'v4_forecast_precip_total_spread_mm',
#   'v4_forecast_precip_max_1h_mean_mm',
#   'v4_forecast_precip_hours_mean',
#   'v4_forecast_precip_intensity_mean',
#   'v4_forecast_precip_intensity_max',
#   'v4_any_forecast_precip',
#   'v4_all_forecast_precip',
#   'v4_observed_precip_any',
#   'v4_observed_precip_recent_mm_est',
#   'v4_forecast_total_minus_observed_recent_mm',
#   'v4_forecast_observed_precip_match',
#   'v4_forecast_wet_observed_dry',
#   'v4_observed_wet_forecast_dry',
#   'v4_precip_humidity_interaction',
#   'v4_precip_remaining_warmup_interaction',
#   'observed_temp_change_last_1h_f',
#   'observed_temp_change_last_3h_f',
#   'observed_morning_warmup_rate_f_per_hour',
#   'observed_high_so_far_change_since_9am_f',
#   'v8_provider_max_remaining_from_high_so_far_f',
#   'v8_provider_min_remaining_from_high_so_far_f',
#   'v8_provider_median_remaining_from_high_so_far_f',
#   'v8_provider_spread_per_remaining_warmup_f',
#   'v8_month_remaining_warmup_mean_f',
#   'v8_month_remaining_warmup_count',
#   'v8_recent_remaining_warmup_7d_mean_f',
#   'v8_recent_remaining_warmup_30d_mean_f',
#   'v8_provider_mean_remaining_vs_month_normal_f',
#   'v8_cloud_cover_mean_remaining_warmup_interaction',
#   'v8_cloud_cover_max_remaining_warmup_interaction',
#   'v8_precip_total_remaining_warmup_interaction',
#   'v8_precip_max_1h_remaining_warmup_interaction',
#   'v8_wind_speed_mean_remaining_warmup_interaction',
#   'v8_wind_gust_max_remaining_warmup_interaction',
#   'v8_forecast_dewpoint_mean_f',
#   'v8_forecast_dewpoint_depression_mean_f',
#   'v8_dewpoint_mean_remaining_warmup_interaction',
#   'v8_dewpoint_depression_remaining_warmup_interaction'],
#  ['gfs_as_of_hour_local',
#   'gfs_available',
#   'gfs_forecast_window_hours',
#   'gfs_grid_dist_km_mean',
#   'gfs_horizon_hours',
#   'gfs_hrrr_grid_dist_km_mean_abs_diff_f',
#   'gfs_hrrr_grid_dist_km_mean_diff_f',
#   'gfs_issue_hour_utc',
#   'gfs_missing',
#   'hrrr_as_of_hour_local',
#   'hrrr_available',
#   'hrrr_forecast_hour_max',
#   'hrrr_forecast_hour_min',
#   'hrrr_forecast_lead_hours',
#   'hrrr_forecast_window_hours',
#   'hrrr_grid_dist_km_mean',
#   'hrrr_horizon_hours',
#   'hrrr_issue_hour_local',
#   'hrrr_issue_hour_utc',
#   'hrrr_missing',
#   'is_active_polymarket_station',
#   'lat',
#   'lon',
#   'nbm_as_of_hour_local',
#   'nbm_available',
#   'nbm_forecast_window_hours',
#   'nbm_horizon_hours',
#   'nbm_issue_hour_local',
#   'nbm_issue_hour_utc',
#   'nbm_missing',
#   'observed_fetch_status',
#   'observed_observation_type',
#   'observed_pressure_source',
#   'provider_count_available',
#   'year'])

# %% [markdown]
# ## Data Availability

# %%
availability = provider_availability(
    PROJECT_ROOT,
    timing_mode=TIMING_MODE,
    providers=PROVIDERS,
)

availability.loc[availability["station_id"].eq(STATION_ID)]
# Out:
#   station_id provider  row_count first_contract_date last_contract_date
# 3       KAUS      gfs       1983          2021-01-01         2026-06-10
# 4       KAUS     hrrr       1987          2021-01-01         2026-06-10
# 5       KAUS      nbm       1986          2021-01-01         2026-06-10

# %% [markdown]
# ## Model Scores

# %%
missing_packages = missing_model_dependencies()
if missing_packages:
    raise ImportError(
        "Missing station-stacking ML packages: "
        + ", ".join(missing_packages)
        + ". Install them with: python -m pip install -r requirements.txt"
    )

config = StationStackingConfig(
    station_id=STATION_ID,
    project_root=PROJECT_ROOT,
    timing_mode=TIMING_MODE,
    providers=PROVIDERS,
    fast_mode=FAST_MODE,
    optuna_trials=OPTUNA_TRIALS,
    stack_optuna_trials=STACK_OPTUNA_TRIALS,
    optuna_startup_trials=OPTUNA_STARTUP_TRIALS,
    stack_optuna_startup_trials=STACK_OPTUNA_STARTUP_TRIALS,
    optuna_metric=OPTUNA_METRIC,
    optuna_verbose=OPTUNA_VERBOSE,
    feature_version="v8",
    hyperparameter_space="wide",
    year_split_folds=YEAR_SPLIT_EXPANDING_FOLDS,
    year_split_test_train_years=(2021, 2025),
    year_split_test_year=2026,
    output_dir=PROJECT_ROOT / "data" / "calibration" / "station_stacking_v8",
)

config.resolved_optuna_storage_path()
# Out:
# WindowsPath('D:/dev/weather-research/data/calibration/station_stacking_v8/KAUS_optuna.sqlite3')

# %%
result = run_station_year_split_experiment(config)
result.scoreboard
# Out:
# [I 2026-06-15 05:46:41,829] A new study created in RDB with name: KAUS_v8_base_xgboost_mae_f
# [I 2026-06-15 05:46:51,439] Trial 0 finished with value: 1.8379036794145944 and parameters: {'n_estimators': 1342, 'learning_rate': 0.19043899115982607, 'max_depth': 9, 'min_child_weight': 2.481040974867813, 'gamma': 2.340279606636548, 'subsample': 0.4513964382185317, 'colsample_bytree': 0.3877543479093296, 'reg_alpha': 2.478071022662141, 'reg_lambda': 0.6132587025321562}. Best is trial 0 with value: 1.8379036794145944.
# [I 2026-06-15 05:48:58,636] Trial 1 finished with value: 1.8675148065022347 and parameters: {'n_estimators': 2493, 'learning_rate': 0.001120367191095075, 'max_depth': 12, 'min_child_weight': 21.368329072358772, 'gamma': 3.185086660174142, 'subsample': 0.4681862286846154, 'colsample_bytree': 0.46921293140473197, 'reg_alpha': 4.476173538513514e-07, 'reg_lambda': 0.20253776634919213}. Best is trial 0 with value: 1.8379036794145944.
# [I 2026-06-15 05:51:01,327] Trial 2 finished with value: 1.6533207591391463 and parameters: {'n_estimators': 1540, 'learning_rate': 0.004992867109217114, 'max_depth': 8, 'min_child_weight': 0.03613894271216528, 'gamma': 4.3821697280282725, 'subsample': 0.5881351981408995, 'colsample_bytree': 0.6464454897410734, 'reg_alpha': 0.26430874752361627, 'reg_lambda': 0.0018119678627933364}. Best is trial 2 with value: 1.6533207591391463.
# [I 2026-06-15 05:51:30,032] Trial 3 finished with value: 1.7093879441541664 and parameters: {'n_estimators': 1824, 'learning_rate': 0.026337502897485255, 'max_depth': 1, 'min_child_weight': 2.69264691008618, 'gamma': 2.557861855309373, 'subsample': 0.39228353544043165, 'colsample_bytree': 0.9667755992146666, 'reg_alpha': 38.6887231523051, 'reg_lambda': 12.408975837016275}. Best is trial 2 with value: 1.6533207591391463.
# [I 2026-06-15 05:54:00,661] Trial 4 finished with value: 2.784892969764573 and parameters: {'n_estimators': 1101, 'learning_rate': 0.0017147936629846843, 'max_depth': 9, 'min_child_weight': 0.5762487216478605, 'gamma': 1.8305735226716824, 'subsample': 0.6718649915723256, 'colsample_bytree': 0.37235253872489193, 'reg_alpha': 8.162906555194692, 'reg_lambda': 0.004271500153828077}. Best is trial 2 with value: 1.6533207591391463.
# [I 2026-06-15 05:59:21,867] Trial 5 finished with value: 1.8056320096871121 and parameters: {'n_estimators': 2336, 'learning_rate': 0.00559067775661512, 'max_depth': 7, 'min_child_weight': 1.5375920235481764, 'gamma': 2.7728168328829055, 'subsample': 0.980230008046963, 'colsample_bytree': 0.8538363351847245, 'reg_alpha': 18.792618557420877, 'reg_lambda': 43.484449457612314}. Best is trial 2 with value: 1.6533207591391463.
# [I 2026-06-15 05:59:31,571] Trial 6 finished with value: 1.7396291632597012 and parameters: {'n_estimators': 2113, 'learning_rate': 0.16240489353272883, 'max_depth': 2, 'min_child_weight': 0.06080390190296603, 'gamma': 0.678409333658071, 'subsample': 0.5614647149961218, 'colsample_bytree': 0.6026402382981633, 'reg_alpha': 1.8037999945880162e-07, 'reg_lambda': 16.668629892722056}. Best is trial 2 with value: 1.6533207591391463.
# [I 2026-06-15 06:02:10,188] Trial 7 finished with value: 1.6327556572020745 and parameters: {'n_estimators': 1281, 'learning_rate': 0.0047169807141865345, 'max_depth': 7, 'min_child_weight': 0.0366181922039243, 'gamma': 12.032954711310595, 'subsample': 0.398457918391851, 'colsample_bytree': 0.9914765087903362, 'reg_alpha': 0.18490013641000916, 'reg_lambda': 0.0017869543989965139}. Best is trial 7 with value: 1.6327556572020745.
# [I 2026-06-15 06:02:15,002] Trial 8 pruned.
# [I 2026-06-15 06:03:46,710] Trial 9 finished with value: 1.6928994914377453 and parameters: {'n_estimators': 2201, 'learning_rate': 0.006215464818952927, 'max_depth': 1, 'min_child_weight': 0.17535949529764422, 'gamma': 4.877749830401205, 'subsample': 0.8242440159197416, 'colsample_bytree': 0.7644123563808884, 'reg_alpha': 4.4315220126915325, 'reg_lambda': 0.09450187118503514}. Best is trial 7 with value: 1.6327556572020745.
# [I 2026-06-15 06:04:03,191] Trial 10 finished with value: 1.6478254307585094 and parameters: {'n_estimators': 462, 'learning_rate': 0.051323729958866915, 'max_depth': 10, 'min_child_weight': 1.7583640270008525, 'gamma': 11.564507699318415, 'subsample': 0.670967137636854, 'colsample_bytree': 0.689776339098296, 'reg_alpha': 1.3504926357029513e-05, 'reg_lambda': 0.0001445994629863374}. Best is trial 7 with value: 1.6327556572020745.
# [I 2026-06-15 06:04:25,590] Trial 11 pruned.
# [I 2026-06-15 06:04:59,832] Trial 12 pruned.
# [I 2026-06-15 06:05:13,716] Trial 13 finished with value: 1.6568819326796698 and parameters: {'n_estimators': 693, 'learning_rate': 0.13813474572232612, 'max_depth': 7, 'min_child_weight': 16.973078532467014, 'gamma': 13.4413694988524, 'subsample': 0.5567022587317115, 'colsample_bytree': 0.4215337509429899, 'reg_alpha': 5.435280359192946e-08, 'reg_lambda': 0.049115547267693904}. Best is trial 7 with value: 1.6327556572020745.
# [I 2026-06-15 06:05:19,847] Trial 14 pruned.
# [I 2026-06-15 06:06:06,334] Trial 15 finished with value: 1.6848905207912335 and parameters: {'n_estimators': 1165, 'learning_rate': 0.01753996764864722, 'max_depth': 9, 'min_child_weight': 0.28478585168562975, 'gamma': 14.57673124081441, 'subsample': 0.9755907417123723, 'colsample_bytree': 0.5136584922864866, 'reg_alpha': 9.267915611871232e-05, 'reg_lambda': 0.007867617817691417}. Best is trial 7 with value: 1.6327556572020745.
# [I 2026-06-15 06:07:46,425] Trial 16 pruned.
# [I 2026-06-15 06:07:52,681] Trial 17 pruned.
# [I 2026-06-15 06:08:00,816] Trial 18 pruned.
# [I 2026-06-15 06:08:03,433] Trial 19 pruned.
# [I 2026-06-15 06:08:28,159] Trial 20 finished with value: 1.6456543689583074 and parameters: {'n_estimators': 3311, 'learning_rate': 0.053750870493696305, 'max_depth': 12, 'min_child_weight': 0.01287956208997519, 'gamma': 9.601327537013342, 'subsample': 0.6737419762327789, 'colsample_bytree': 0.7057240902279666, 'reg_alpha': 0.02251183442930878, 'reg_lambda': 0.00017053170670602817}. Best is trial 7 with value: 1.6327556572020745.
# [I 2026-06-15 06:08:53,283] Trial 21 finished with value: 1.6560664914254772 and parameters: {'n_estimators': 3483, 'learning_rate': 0.052799895109863736, 'max_depth': 12, 'min_child_weight': 0.012764211484073218, 'gamma': 9.574981611158378, 'subsample': 0.7001207052805446, 'colsample_bytree': 0.7074044750647771, 'reg_alpha': 0.01804468490465271, 'reg_lambda': 0.00010569723894268946}. Best is trial 7 with value: 1.6327556572020745.
# [I 2026-06-15 06:09:00,756] Trial 22 pruned.
# [I 2026-06-15 06:09:15,627] Trial 23 pruned.
# [I 2026-06-15 06:12:21,112] Trial 24 finished with value: 1.6505050653954076 and parameters: {'n_estimators': 2787, 'learning_rate': 0.003326416805485848, 'max_depth': 5, 'min_child_weight': 0.025232832707151685, 'gamma': 9.032067381753372, 'subsample': 0.7732981551774945, 'colsample_bytree': 0.7031464797249688, 'reg_alpha': 0.030439547869255956, 'reg_lambda': 0.013447683455424273}. Best is trial 7 with value: 1.6327556572020745.
# [I 2026-06-15 06:13:08,364] Trial 25 pruned.
# [I 2026-06-15 06:13:17,667] Trial 26 finished with value: 1.6369477655312283 and parameters: {'n_estimators': 2910, 'learning_rate': 0.07406979103589699, 'max_depth': 6, 'min_child_weight': 0.02018983898103213, 'gamma': 10.822049870481713, 'subsample': 0.630601310079343, 'colsample_bytree': 0.8042147821222629, 'reg_alpha': 0.18689086977577798, 'reg_lambda': 0.0022551702281315934}. Best is trial 7 with value: 1.6327556572020745.
# [I 2026-06-15 06:13:27,968] Trial 27 finished with value: 1.6498194042020904 and parameters: {'n_estimators': 3084, 'learning_rate': 0.08056041037842705, 'max_depth': 6, 'min_child_weight': 0.01805186167915039, 'gamma': 10.797203906259021, 'subsample': 0.6310704563685381, 'colsample_bytree': 0.7739657941389151, 'reg_alpha': 0.40930677975006907, 'reg_lambda': 0.002792466335600671}. Best is trial 7 with value: 1.6327556572020745.
# [I 2026-06-15 06:16:25,339] Trial 28 finished with value: 1.647348257151243 and parameters: {'n_estimators': 3497, 'learning_rate': 0.002630131532599853, 'max_depth': 5, 'min_child_weight': 0.10538114949529365, 'gamma': 13.190393326975881, 'subsample': 0.7344864861472217, 'colsample_bytree': 0.8207403068508103, 'reg_alpha': 0.0029555063969925726, 'reg_lambda': 0.02142381065704311}. Best is trial 7 with value: 1.6327556572020745.
# [I 2026-06-15 06:17:16,460] Trial 29 finished with value: 1.620485787386638 and parameters: {'n_estimators': 2679, 'learning_rate': 0.010685212646498897, 'max_depth': 6, 'min_child_weight': 0.024351979482722514, 'gamma': 8.27452701986975, 'subsample': 0.3544240757968657, 'colsample_bytree': 0.8779404171814037, 'reg_alpha': 0.21424523606524465, 'reg_lambda': 0.0013636282684302437}. Best is trial 29 with value: 1.620485787386638.
# [I 2026-06-15 06:18:31,290] Trial 30 finished with value: 1.631257619400547 and parameters: {'n_estimators': 2548, 'learning_rate': 0.008676175141818702, 'max_depth': 6, 'min_child_weight': 0.027581901222744794, 'gamma': 7.760288478211003, 'subsample': 0.4248353350258679, 'colsample_bytree': 0.8828624087111651, 'reg_alpha': 0.26807695533548026, 'reg_lambda': 0.001266292141152401}. Best is trial 29 with value: 1.620485787386638.
# [I 2026-06-15 06:19:52,619] Trial 31 finished with value: 1.627743767832805 and parameters: {'n_estimators': 2614, 'learning_rate': 0.009337975899438135, 'max_depth': 6, 'min_child_weight': 0.02639494384056944, 'gamma': 8.131145305890442, 'subsample': 0.37350754072911513, 'colsample_bytree': 0.8727751149045346, 'reg_alpha': 0.36526222532707864, 'reg_lambda': 0.0013445606654745956}. Best is trial 29 with value: 1.620485787386638.
# [I 2026-06-15 06:21:25,755] Trial 32 finished with value: 1.6265277344158 and parameters: {'n_estimators': 2585, 'learning_rate': 0.009026398712949649, 'max_depth': 6, 'min_child_weight': 0.03225947124079673, 'gamma': 6.964846087361352, 'subsample': 0.36339386946515684, 'colsample_bytree': 0.8943620813786962, 'reg_alpha': 0.4924129574032742, 'reg_lambda': 0.0006804500946801738}. Best is trial 29 with value: 1.620485787386638.
# [I 2026-06-15 06:22:59,650] Trial 33 finished with value: 1.6230224242124969 and parameters: {'n_estimators': 2729, 'learning_rate': 0.010571564290290386, 'max_depth': 5, 'min_child_weight': 0.07116706643236823, 'gamma': 6.3347105513087, 'subsample': 0.4361175109831786, 'colsample_bytree': 0.8873630025807318, 'reg_alpha': 1.0493296607712883, 'reg_lambda': 0.0009831616945737327}. Best is trial 29 with value: 1.620485787386638.
# [I 2026-06-15 06:23:44,296] Trial 34 pruned.
# [I 2026-06-15 06:24:12,608] Trial 35 finished with value: 1.6143381408192963 and parameters: {'n_estimators': 2675, 'learning_rate': 0.026876300131457084, 'max_depth': 4, 'min_child_weight': 0.4274191122149963, 'gamma': 6.298988891810571, 'subsample': 0.3502146248462783, 'colsample_bytree': 0.8628593940608356, 'reg_alpha': 0.877438700160538, 'reg_lambda': 0.0004156528201512737}. Best is trial 35 with value: 1.6143381408192963.
# [I 2026-06-15 06:24:40,626] Trial 36 finished with value: 1.614436940156999 and parameters: {'n_estimators': 1995, 'learning_rate': 0.026712486503806736, 'max_depth': 4, 'min_child_weight': 0.5516789129968943, 'gamma': 6.2321636519835515, 'subsample': 0.4398371064042974, 'colsample_bytree': 0.9541068816618629, 'reg_alpha': 1.3559414466939002, 'reg_lambda': 0.0004295477833006162}. Best is trial 35 with value: 1.6143381408192963.
# [I 2026-06-15 06:25:06,318] Trial 37 finished with value: 1.5957630099687488 and parameters: {'n_estimators': 1978, 'learning_rate': 0.020536065910633106, 'max_depth': 4, 'min_child_weight': 0.43959275214116234, 'gamma': 3.838934795066849, 'subsample': 0.4365719065122194, 'colsample_bytree': 0.9536915967269891, 'reg_alpha': 0.8255568289542441, 'reg_lambda': 0.0003189302140128514}. Best is trial 37 with value: 1.5957630099687488.
# [I 2026-06-15 06:25:28,813] Trial 38 pruned.
# [I 2026-06-15 06:25:45,663] Trial 39 finished with value: 1.6254395843984204 and parameters: {'n_estimators': 2354, 'learning_rate': 0.027495093335067108, 'max_depth': 4, 'min_child_weight': 0.5880440038350594, 'gamma': 3.989257807244612, 'subsample': 0.4178871066029308, 'colsample_bytree': 0.8416472835586264, 'reg_alpha': 0.08591711612988036, 'reg_lambda': 0.0003789063893743567}. Best is trial 37 with value: 1.5957630099687488.
# [I 2026-06-15 06:26:08,052] Trial 40 finished with value: 1.647202195216783 and parameters: {'n_estimators': 1537, 'learning_rate': 0.021328316794960892, 'max_depth': 3, 'min_child_weight': 0.3277990227609308, 'gamma': 5.4517057612028665, 'subsample': 0.48718151338920107, 'colsample_bytree': 0.9718740679979408, 'reg_alpha': 10.349619935184782, 'reg_lambda': 0.003913053853946482}. Best is trial 37 with value: 1.5957630099687488.
# [I 2026-06-15 06:26:52,166] Trial 41 finished with value: 1.6047746594210945 and parameters: {'n_estimators': 1920, 'learning_rate': 0.013055619972818918, 'max_depth': 4, 'min_child_weight': 0.6898638690557226, 'gamma': 6.216087457793703, 'subsample': 0.4275148751811636, 'colsample_bytree': 0.9253982181343176, 'reg_alpha': 1.2500995387144205, 'reg_lambda': 0.0005958427119063456}. Best is trial 37 with value: 1.5957630099687488.
# [I 2026-06-15 06:27:12,859] Trial 42 finished with value: 1.621101811793883 and parameters: {'n_estimators': 1968, 'learning_rate': 0.03430086350581705, 'max_depth': 4, 'min_child_weight': 0.8200502551124011, 'gamma': 5.290555301908441, 'subsample': 0.39417338174222477, 'colsample_bytree': 0.9304804341775608, 'reg_alpha': 1.1325126763213014, 'reg_lambda': 0.00023144689558398106}. Best is trial 37 with value: 1.5957630099687488.
# [I 2026-06-15 06:27:26,038] Trial 43 pruned.
# [I 2026-06-15 06:28:02,053] Trial 44 finished with value: 1.6314620328929328 and parameters: {'n_estimators': 2034, 'learning_rate': 0.012455964829554663, 'max_depth': 3, 'min_child_weight': 1.9542190766751435, 'gamma': 7.054213675757753, 'subsample': 0.4117237653236712, 'colsample_bytree': 0.8499015497087241, 'reg_alpha': 0.004689119090851613, 'reg_lambda': 0.0021467767208216194}. Best is trial 37 with value: 1.5957630099687488.
# [I 2026-06-15 06:28:14,782] Trial 45 pruned.
# [I 2026-06-15 06:28:52,941] Trial 46 pruned.
# [I 2026-06-15 06:29:19,360] Trial 47 finished with value: 1.6151563261733541 and parameters: {'n_estimators': 1719, 'learning_rate': 0.02162476055024096, 'max_depth': 3, 'min_child_weight': 1.3411960696067664, 'gamma': 5.658211457508457, 'subsample': 0.3913059465436538, 'colsample_bytree': 0.8556919543034569, 'reg_alpha': 1.32950878015936, 'reg_lambda': 0.006364022783510682}. Best is trial 37 with value: 1.5957630099687488.
# [I 2026-06-15 06:29:25,851] Trial 48 pruned.
# [I 2026-06-15 06:29:39,297] Trial 49 pruned.
# [I 2026-06-15 06:29:39,498] A new study created in RDB with name: KAUS_v8_base_lightgbm_mae_f
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 06:30:18,292] Trial 0 finished with value: 1.8454997078581017 and parameters: {'n_estimators': 447, 'learning_rate': 0.028873871707375695, 'num_leaves': 71, 'max_depth': 5, 'min_child_samples': 83, 'min_split_gain': 4.295687454742988, 'bagging_fraction': 0.7829586385137167, 'bagging_freq': 4, 'feature_fraction': 0.3688589858758342, 'lambda_l1': 0.06382334403151436, 'lambda_l2': 0.03080292177315921}. Best is trial 0 with value: 1.8454997078581017.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 06:33:11,322] Trial 1 finished with value: 1.9022992817836304 and parameters: {'n_estimators': 2817, 'learning_rate': 0.004074615160588706, 'num_leaves': 32, 'max_depth': 13, 'min_child_samples': 57, 'min_split_gain': 2.0249472402362985, 'bagging_fraction': 0.5554627061618356, 'bagging_freq': 1, 'feature_fraction': 0.898096051249308, 'lambda_l1': 1.5391104005532914, 'lambda_l2': 132.19976430960952}. Best is trial 0 with value: 1.8454997078581017.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 06:33:22,462] Trial 2 finished with value: 1.8081248655189084 and parameters: {'n_estimators': 1379, 'learning_rate': 0.1944487980595256, 'num_leaves': 230, 'max_depth': 10, 'min_child_samples': 22, 'min_split_gain': 4.485492899907672, 'bagging_fraction': 0.5437022754476957, 'bagging_freq': 2, 'feature_fraction': 0.353334206891897, 'lambda_l1': 0.00032993636349211094, 'lambda_l2': 0.09925376145099525}. Best is trial 2 with value: 1.8081248655189084.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 06:33:29,249] Trial 3 finished with value: 2.7487843971585675 and parameters: {'n_estimators': 2246, 'learning_rate': 0.22165362064553062, 'num_leaves': 466, 'max_depth': 13, 'min_child_samples': 132, 'min_split_gain': 0.5200947492738145, 'bagging_fraction': 0.4675944869176356, 'bagging_freq': 7, 'feature_fraction': 0.6177694392011331, 'lambda_l1': 2.399967979035352, 'lambda_l2': 1.7195277953675168}. Best is trial 2 with value: 1.8081248655189084.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 06:34:57,042] Trial 4 finished with value: 1.9052219002618056 and parameters: {'n_estimators': 2219, 'learning_rate': 0.004579029224032115, 'num_leaves': 460, 'max_depth': 4, 'min_child_samples': 102, 'min_split_gain': 4.967862461970517, 'bagging_fraction': 0.8282226029796285, 'bagging_freq': 4, 'feature_fraction': 0.7144310601384277, 'lambda_l1': 8.61124348208611e-06, 'lambda_l2': 3.808668235343267}. Best is trial 2 with value: 1.8081248655189084.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 06:35:04,315] Trial 5 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 06:35:13,689] Trial 6 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 06:35:14,980] Trial 7 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 06:35:16,612] Trial 8 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 06:35:49,491] Trial 9 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 06:35:53,502] Trial 10 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 06:36:02,741] Trial 11 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 06:44:06,075] Trial 12 finished with value: 1.8825447325152425 and parameters: {'n_estimators': 3174, 'learning_rate': 0.0010925194811392835, 'num_leaves': 301, 'max_depth': 11, 'min_child_samples': 74, 'min_split_gain': 2.613988081636218, 'bagging_fraction': 0.8796537260629015, 'bagging_freq': 5, 'feature_fraction': 0.5960609706435204, 'lambda_l1': 8.524985832885774e-10, 'lambda_l2': 0.1169527455154188}. Best is trial 2 with value: 1.8081248655189084.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 06:45:21,202] Trial 13 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 06:45:26,973] Trial 14 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 06:45:33,328] Trial 15 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 06:45:34,227] Trial 16 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 06:45:55,377] Trial 17 finished with value: 1.8249608088832463 and parameters: {'n_estimators': 1783, 'learning_rate': 0.04864572341122393, 'num_leaves': 91, 'max_depth': 9, 'min_child_samples': 41, 'min_split_gain': 4.132892006727957, 'bagging_fraction': 0.5662560585201368, 'bagging_freq': 4, 'feature_fraction': 0.8899618930175198, 'lambda_l1': 42.540711148076, 'lambda_l2': 0.011582644290167256}. Best is trial 2 with value: 1.8081248655189084.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 06:45:58,965] Trial 18 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 06:47:01,543] Trial 19 finished with value: 1.6538959475916917 and parameters: {'n_estimators': 3473, 'learning_rate': 0.04578852488428539, 'num_leaves': 184, 'max_depth': 4, 'min_child_samples': 13, 'min_split_gain': 1.633948525123912, 'bagging_fraction': 0.58126637710312, 'bagging_freq': 4, 'feature_fraction': 0.7783357811218745, 'lambda_l1': 1.074747741122124e-09, 'lambda_l2': 0.007377559017382262}. Best is trial 19 with value: 1.6538959475916917.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 06:58:05,938] Trial 20 finished with value: 1.6705805905736757 and parameters: {'n_estimators': 3449, 'learning_rate': 0.012050791686618947, 'num_leaves': 221, 'max_depth': 7, 'min_child_samples': 7, 'min_split_gain': 0.04810004645591315, 'bagging_fraction': 0.685937988994649, 'bagging_freq': 1, 'feature_fraction': 0.772427228137977, 'lambda_l1': 0.0004686667014769191, 'lambda_l2': 0.0018026337369408825}. Best is trial 19 with value: 1.6538959475916917.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 07:07:22,348] Trial 21 finished with value: 1.6736631533975856 and parameters: {'n_estimators': 3468, 'learning_rate': 0.012405429414511872, 'num_leaves': 221, 'max_depth': 7, 'min_child_samples': 3, 'min_split_gain': 1.6653740659816891, 'bagging_fraction': 0.6976761581665516, 'bagging_freq': 1, 'feature_fraction': 0.7668826297243814, 'lambda_l1': 0.00016983532804446316, 'lambda_l2': 0.0017161410033910418}. Best is trial 19 with value: 1.6538959475916917.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 07:10:30,937] Trial 22 finished with value: 1.6659957832030983 and parameters: {'n_estimators': 3422, 'learning_rate': 0.012136880366846417, 'num_leaves': 188, 'max_depth': 7, 'min_child_samples': 6, 'min_split_gain': 0.16257371424216893, 'bagging_fraction': 0.6920347958562258, 'bagging_freq': 1, 'feature_fraction': 0.7587665955858165, 'lambda_l1': 0.0007296636992448463, 'lambda_l2': 0.0015580708681508719}. Best is trial 19 with value: 1.6538959475916917.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 07:12:31,333] Trial 23 finished with value: 1.6564700321350019 and parameters: {'n_estimators': 2803, 'learning_rate': 0.011463689632416414, 'num_leaves': 166, 'max_depth': 6, 'min_child_samples': 11, 'min_split_gain': 0.08973227313140214, 'bagging_fraction': 0.7268124074583289, 'bagging_freq': 2, 'feature_fraction': 0.7382425750680321, 'lambda_l1': 0.004703035469907831, 'lambda_l2': 0.0017773139855421628}. Best is trial 19 with value: 1.6538959475916917.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 07:13:21,521] Trial 24 finished with value: 1.7648989105753456 and parameters: {'n_estimators': 2805, 'learning_rate': 0.018694241693013952, 'num_leaves': 147, 'max_depth': 6, 'min_child_samples': 38, 'min_split_gain': 0.19589217858466343, 'bagging_fraction': 0.7345511503913964, 'bagging_freq': 2, 'feature_fraction': 0.6873903584246481, 'lambda_l1': 1.2180430744190801e-06, 'lambda_l2': 0.0015041588126055686}. Best is trial 19 with value: 1.6538959475916917.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 07:16:04,034] Trial 25 finished with value: 1.7720349658683028 and parameters: {'n_estimators': 2914, 'learning_rate': 0.006686857079855193, 'num_leaves': 128, 'max_depth': 4, 'min_child_samples': 36, 'min_split_gain': 1.5080627274968053, 'bagging_fraction': 0.6289403981108314, 'bagging_freq': 3, 'feature_fraction': 0.823915773450376, 'lambda_l1': 0.006066322295927195, 'lambda_l2': 0.000624574868996783}. Best is trial 19 with value: 1.6538959475916917.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 07:17:05,036] Trial 26 finished with value: 1.6577075014690519 and parameters: {'n_estimators': 2565, 'learning_rate': 0.018519807038490987, 'num_leaves': 189, 'max_depth': 3, 'min_child_samples': 18, 'min_split_gain': 0.47625545570311184, 'bagging_fraction': 0.7432656007734421, 'bagging_freq': 3, 'feature_fraction': 0.7395463117918004, 'lambda_l1': 0.008877108413852067, 'lambda_l2': 0.005306655581500069}. Best is trial 19 with value: 1.6538959475916917.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 07:17:30,270] Trial 27 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 07:18:30,406] Trial 28 finished with value: 1.6584215169764356 and parameters: {'n_estimators': 3091, 'learning_rate': 0.01923992461515857, 'num_leaves': 9, 'max_depth': 3, 'min_child_samples': 23, 'min_split_gain': 1.7825234432942936, 'bagging_fraction': 0.9155995314302665, 'bagging_freq': 3, 'feature_fraction': 0.6615279162073165, 'lambda_l1': 1.137070018419209e-06, 'lambda_l2': 0.004029557860355075}. Best is trial 19 with value: 1.6538959475916917.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 07:19:42,193] Trial 29 finished with value: 1.6552375695205261 and parameters: {'n_estimators': 2523, 'learning_rate': 0.03031821286485395, 'num_leaves': 184, 'max_depth': 5, 'min_child_samples': 20, 'min_split_gain': 0.5533191438962903, 'bagging_fraction': 0.7480279643500221, 'bagging_freq': 2, 'feature_fraction': 0.8389003149771204, 'lambda_l1': 0.020524411213826622, 'lambda_l2': 0.03150249174624671}. Best is trial 19 with value: 1.6538959475916917.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 07:19:56,657] Trial 30 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 07:20:40,986] Trial 31 finished with value: 1.651797074715979 and parameters: {'n_estimators': 2527, 'learning_rate': 0.0330022780774488, 'num_leaves': 187, 'max_depth': 5, 'min_child_samples': 21, 'min_split_gain': 0.539290382897783, 'bagging_fraction': 0.7586117916546873, 'bagging_freq': 2, 'feature_fraction': 0.8303237567491542, 'lambda_l1': 0.0104673021485029, 'lambda_l2': 0.020991940388591444}. Best is trial 31 with value: 1.651797074715979.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 07:22:01,773] Trial 32 finished with value: 1.680520429629786 and parameters: {'n_estimators': 3096, 'learning_rate': 0.02864403279848931, 'num_leaves': 187, 'max_depth': 6, 'min_child_samples': 25, 'min_split_gain': 0.8175992999305941, 'bagging_fraction': 0.7731168953689024, 'bagging_freq': 2, 'feature_fraction': 0.851996652808324, 'lambda_l1': 0.021898402063016152, 'lambda_l2': 0.02897731860737869}. Best is trial 31 with value: 1.651797074715979.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 07:22:25,250] Trial 33 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 07:22:42,935] Trial 34 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 07:25:13,677] Trial 35 finished with value: 1.6575373352720182 and parameters: {'n_estimators': 3205, 'learning_rate': 0.06411707172214177, 'num_leaves': 77, 'max_depth': 5, 'min_child_samples': 18, 'min_split_gain': 0.8311619500355832, 'bagging_fraction': 0.7223387936066386, 'bagging_freq': 2, 'feature_fraction': 0.8760946611677927, 'lambda_l1': 3.227206642647941e-05, 'lambda_l2': 0.0006546982439136854}. Best is trial 31 with value: 1.651797074715979.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 07:26:55,381] Trial 36 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 07:41:27,677] Trial 37 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 07:47:02,565] Trial 38 finished with value: 1.6563686428490825 and parameters: {'n_estimators': 2933, 'learning_rate': 0.009176756304007022, 'num_leaves': 186, 'max_depth': 4, 'min_child_samples': 3, 'min_split_gain': 1.969314391226511, 'bagging_fraction': 0.8446804779367613, 'bagging_freq': 2, 'feature_fraction': 0.699302122375979, 'lambda_l1': 0.00314194145334428, 'lambda_l2': 0.01137169866515314}. Best is trial 31 with value: 1.651797074715979.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 07:47:39,071] Trial 39 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 07:50:54,627] Trial 40 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 08:09:11,121] Trial 41 finished with value: 1.647257489339788 and parameters: {'n_estimators': 2684, 'learning_rate': 0.0032003342370132003, 'num_leaves': 172, 'max_depth': 4, 'min_child_samples': 7, 'min_split_gain': 2.17513943631348, 'bagging_fraction': 0.9163659771671073, 'bagging_freq': 2, 'feature_fraction': 0.7972398074671802, 'lambda_l1': 0.003385979557576996, 'lambda_l2': 0.04554657724982769}. Best is trial 41 with value: 1.647257489339788.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 08:10:46,635] Trial 42 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 08:20:25,374] Trial 43 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 08:22:11,936] Trial 44 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 08:22:34,971] Trial 45 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 08:22:59,056] Trial 46 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 08:27:44,527] Trial 47 finished with value: 1.6640694030214163 and parameters: {'n_estimators': 2342, 'learning_rate': 0.015091637149144445, 'num_leaves': 143, 'max_depth': 5, 'min_child_samples': 14, 'min_split_gain': 2.3931475752347513, 'bagging_fraction': 0.9936300559683304, 'bagging_freq': 4, 'feature_fraction': 0.9077431953058436, 'lambda_l1': 2.631730656944984e-07, 'lambda_l2': 0.013494716261436153}. Best is trial 41 with value: 1.647257489339788.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 08:28:42,867] Trial 48 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-15 08:29:13,667] Trial 49 pruned.
# [I 2026-06-15 08:29:14,012] A new study created in RDB with name: KAUS_v8_base_catboost_mae_f
# [I 2026-06-15 08:45:52,450] Trial 0 finished with value: 2.6964486924136954 and parameters: {'iterations': 2931, 'learning_rate': 0.001783588943232587, 'depth': 10, 'l2_leaf_reg': 0.9942958882300413, 'random_strength': 7.186216756161439, 'bagging_temperature': 12.184767612363034, 'border_count': 110, 'rsm': 0.6158971964095841}. Best is trial 0 with value: 2.6964486924136954.
# [I 2026-06-15 08:59:58,778] Trial 1 finished with value: 2.4164959221655766 and parameters: {'iterations': 1809, 'learning_rate': 0.05045361458210069, 'depth': 12, 'l2_leaf_reg': 2.206716955900187, 'random_strength': 8.55303042123218, 'bagging_temperature': 2.269274022399408, 'border_count': 68, 'rsm': 0.9723568448941463}. Best is trial 1 with value: 2.4164959221655766.
# [I 2026-06-15 09:00:46,419] Trial 2 finished with value: 2.1782972824219238 and parameters: {'iterations': 3305, 'learning_rate': 0.13018523290940803, 'depth': 9, 'l2_leaf_reg': 0.29456409265689415, 'random_strength': 12.736640276136784, 'bagging_temperature': 2.78292503969807, 'border_count': 126, 'rsm': 0.9180110703516069}. Best is trial 2 with value: 2.1782972824219238.
# [I 2026-06-15 09:03:12,268] Trial 3 finished with value: 2.208321393590019 and parameters: {'iterations': 941, 'learning_rate': 0.039289187448897187, 'depth': 11, 'l2_leaf_reg': 0.17184213389305913, 'random_strength': 11.258999163179464, 'bagging_temperature': 3.183105276262954, 'border_count': 57, 'rsm': 0.4176149246436502}. Best is trial 2 with value: 2.1782972824219238.
# [I 2026-06-15 09:06:29,400] Trial 4 finished with value: 4.736870213080115 and parameters: {'iterations': 750, 'learning_rate': 0.012345725775087685, 'depth': 10, 'l2_leaf_reg': 185.34152922460115, 'random_strength': 16.100344011609046, 'bagging_temperature': 7.548308114328448, 'border_count': 139, 'rsm': 0.3882842988918503}. Best is trial 2 with value: 2.1782972824219238.
# [I 2026-06-15 09:31:33,403] Trial 5 pruned.
# [I 2026-06-15 09:44:58,567] Trial 6 finished with value: 1.8224831650734434 and parameters: {'iterations': 3092, 'learning_rate': 0.0016894180053021765, 'depth': 7, 'l2_leaf_reg': 2.9770736659303028, 'random_strength': 2.1794700787166432, 'bagging_temperature': 3.0746892172349938, 'border_count': 252, 'rsm': 0.5265140999127667}. Best is trial 6 with value: 1.8224831650734434.
# [I 2026-06-15 09:47:25,951] Trial 7 finished with value: 1.8046814329896548 and parameters: {'iterations': 3146, 'learning_rate': 0.0024764229908984673, 'depth': 3, 'l2_leaf_reg': 0.6951779671472356, 'random_strength': 6.148451176512449, 'bagging_temperature': 8.441103735088014, 'border_count': 95, 'rsm': 0.7192489923988105}. Best is trial 7 with value: 1.8046814329896548.
# [I 2026-06-15 09:48:14,140] Trial 8 finished with value: 2.0093208926602504 and parameters: {'iterations': 378, 'learning_rate': 0.08194116550819189, 'depth': 4, 'l2_leaf_reg': 95.92707399961093, 'random_strength': 18.034879593317157, 'bagging_temperature': 0.3171560070252766, 'border_count': 220, 'rsm': 0.7891440128855358}. Best is trial 7 with value: 1.8046814329896548.
# [I 2026-06-15 09:49:10,644] Trial 9 pruned.
# [I 2026-06-15 09:53:33,422] Trial 10 pruned.
# [I 2026-06-15 09:53:57,383] Trial 11 pruned.
# [I 2026-06-15 09:55:16,580] Trial 12 pruned.
# [I 2026-06-15 09:55:32,689] Trial 13 pruned.
# [I 2026-06-15 09:56:18,960] Trial 14 pruned.
# [I 2026-06-15 10:20:02,161] Trial 15 finished with value: 2.1499286737805883 and parameters: {'iterations': 1533, 'learning_rate': 0.00677555105014573, 'depth': 11, 'l2_leaf_reg': 2.772143189189951, 'random_strength': 5.175604669479215, 'bagging_temperature': 2.338512109369544, 'border_count': 163, 'rsm': 0.5786244777864037}. Best is trial 7 with value: 1.8046814329896548.
# [I 2026-06-15 10:29:33,406] Trial 16 pruned.
# [I 2026-06-15 10:31:12,919] Trial 17 pruned.
# [I 2026-06-15 10:42:25,467] Trial 18 pruned.
# [I 2026-06-15 10:44:02,642] Trial 19 pruned.
# [I 2026-06-15 10:44:57,098] Trial 20 finished with value: 1.8186625102204084 and parameters: {'iterations': 3486, 'learning_rate': 0.0031221828161265204, 'depth': 2, 'l2_leaf_reg': 0.05272080051940796, 'random_strength': 3.5052369253312046, 'bagging_temperature': 9.750131674871632, 'border_count': 19, 'rsm': 0.4751182877052444}. Best is trial 7 with value: 1.8046814329896548.
# [I 2026-06-15 10:45:51,857] Trial 21 finished with value: 1.8216298825387705 and parameters: {'iterations': 3456, 'learning_rate': 0.002928433964986125, 'depth': 2, 'l2_leaf_reg': 0.10989512952082721, 'random_strength': 3.539152488165065, 'bagging_temperature': 9.883751751951994, 'border_count': 19, 'rsm': 0.4930253114169302}. Best is trial 7 with value: 1.8046814329896548.
# [I 2026-06-15 10:46:41,101] Trial 22 finished with value: 1.8022740143085978 and parameters: {'iterations': 3491, 'learning_rate': 0.003180407927940926, 'depth': 2, 'l2_leaf_reg': 0.055809390456365904, 'random_strength': 3.6874060324781968, 'bagging_temperature': 10.412797955361198, 'border_count': 22, 'rsm': 0.5054015294141041}. Best is trial 22 with value: 1.8022740143085978.
# [I 2026-06-15 10:47:31,662] Trial 23 finished with value: 1.8507546315499508 and parameters: {'iterations': 2932, 'learning_rate': 0.003380298706813519, 'depth': 2, 'l2_leaf_reg': 0.05231770540210025, 'random_strength': 3.77054751755842, 'bagging_temperature': 11.089669972995337, 'border_count': 21, 'rsm': 0.6481982036054095}. Best is trial 22 with value: 1.8022740143085978.
# [I 2026-06-15 10:48:59,273] Trial 24 finished with value: 1.722192816720415 and parameters: {'iterations': 3456, 'learning_rate': 0.0027632280259776098, 'depth': 3, 'l2_leaf_reg': 0.48038152334278694, 'random_strength': 4.172054726340164, 'bagging_temperature': 6.035308083092801, 'border_count': 30, 'rsm': 0.3518609807012372}. Best is trial 24 with value: 1.722192816720415.
# [I 2026-06-15 10:50:14,182] Trial 25 pruned.
# [I 2026-06-15 10:52:21,982] Trial 26 finished with value: 1.8633185599349376 and parameters: {'iterations': 2227, 'learning_rate': 0.002547869751681066, 'depth': 3, 'l2_leaf_reg': 0.5829461622200993, 'random_strength': 4.95155216884183, 'bagging_temperature': 8.318312727971978, 'border_count': 108, 'rsm': 0.7962753641575684}. Best is trial 24 with value: 1.722192816720415.
# [I 2026-06-15 10:54:15,920] Trial 27 pruned.
# ...
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
#                   period       method  count     mae_f    rmse_f
# 0   validation_2024_2025      xgboost    729  1.640461  2.274973
# 1   validation_2024_2025     lightgbm    729  1.664352  2.315019
# 2   validation_2024_2025     catboost    729  1.653632  2.344961
# 3   validation_2024_2025     hrrr_raw    729  2.716582  3.534099
# 4   validation_2024_2025      gfs_raw    729  2.915723  3.874023
# 5              test_2026      xgboost    137  1.594349  2.068159
# 6              test_2026     lightgbm    137  1.529158  2.006654
# 7              test_2026     catboost    137  1.692461  2.203526
# 8              test_2026  ridge_stack    137  1.557921  2.024451
# 9              test_2026     hrrr_raw    137  2.740739  3.273220
# 10             test_2026      gfs_raw    137  2.810295  3.512785

# %% [markdown]
# ## V8 Feature Coverage

# %%
v8_feature_coverage = (
    result.features[V8_FEATURE_COLUMNS]
    .notna()
    .mean()
    .mul(100)
    .sort_values(ascending=False)
    .rename("coverage_pct")
    .reset_index()
    .rename(columns={"index": "feature"})
)

v8_feature_coverage
# Out:
#                                               feature  coverage_pct
# 0                    v2_morning_warmup_to_consensus_f    100.000000
# 1                      v3_high_so_far_above_current_f    100.000000
# 2                      v2_humidity_warmup_interaction    100.000000
# 3                              v2_spread_per_warmup_f    100.000000
# 4            v3_humidity_remaining_warmup_interaction    100.000000
# 5                    v3_remaining_warmup_per_spread_f    100.000000
# 6                              v4_any_forecast_precip    100.000000
# 7              v3_remaining_warmup_from_high_so_far_f    100.000000
# 8           v8_provider_spread_per_remaining_warmup_f    100.000000
# 9                     v8_month_remaining_warmup_count    100.000000
# 10            observed_high_so_far_change_since_9am_f    100.000000
# 11       v8_provider_max_remaining_from_high_so_far_f    100.000000
# 12    v8_provider_median_remaining_from_high_so_far_f    100.000000
# 13       v8_provider_min_remaining_from_high_so_far_f    100.000000
# 14                       v4_forecast_wet_observed_dry    100.000000
# 15                       v4_observed_wet_forecast_dry    100.000000
# 16                  v4_forecast_observed_precip_match    100.000000
# 17                   v4_observed_precip_recent_mm_est    100.000000
# 18                             v4_observed_precip_any    100.000000
# 19                             v4_all_forecast_precip    100.000000
# 20                   v3_high_so_far_minus_7d_actual_f     99.949084
# 21                           v2_recent_heat_anomaly_f     99.949084
# 22                          v2_recent_heat_momentum_f     99.949084
# 23                     v2_consensus_minus_7d_actual_f     99.949084
# 24                     observed_temp_change_last_1h_f     99.949084
# 25            observed_morning_warmup_rate_f_per_hour     99.949084
# 26                     observed_temp_change_last_3h_f     99.949084
# 27                      v3_high_so_far_minus_lag_1d_f     99.949084
# 28               v8_recent_remaining_warmup_7d_mean_f     99.898167
# 29              v8_recent_remaining_warmup_30d_mean_f     99.745418
# 30       v8_provider_mean_remaining_vs_month_normal_f     98.778004
# 31                   v8_month_remaining_warmup_mean_f     98.778004
# 32                    v4_forecast_precip_total_max_mm      0.000000
# 33                 v4_forecast_precip_total_spread_mm      0.000000
# 34                   v4_forecast_precip_total_mean_mm      0.000000
# 35                  v4_forecast_precip_max_1h_mean_mm      0.000000
# 36                   v4_forecast_precip_intensity_max      0.000000
# 37                  v4_forecast_precip_intensity_mean      0.000000
# 38                      v4_forecast_precip_hours_mean      0.000000
# 39         v4_forecast_total_minus_observed_recent_mm      0.000000
# 40             v4_precip_remaining_warmup_interaction      0.000000
# 41                     v4_precip_humidity_interaction      0.000000
# 42   v8_cloud_cover_mean_remaining_warmup_interaction      0.000000
# 43    v8_cloud_cover_max_remaining_warmup_interaction      0.000000
# 44       v8_precip_total_remaining_warmup_interaction      0.000000
# 45      v8_precip_max_1h_remaining_warmup_interaction      0.000000
# 46    v8_wind_speed_mean_remaining_warmup_interaction      0.000000
# 47      v8_wind_gust_max_remaining_warmup_interaction      0.000000
# 48                        v8_forecast_dewpoint_mean_f      0.000000
# 49             v8_forecast_dewpoint_depression_mean_f      0.000000
# 50      v8_dewpoint_mean_remaining_warmup_interaction      0.000000
# 51  v8_dewpoint_depression_remaining_warmup_intera...      0.000000

# %%
result.feature_columns.loc[result.feature_columns["feature"].isin(V8_FEATURE_COLUMNS)]
# Out:
#                                              feature     kind
# 20                    observed_temp_change_last_1h_f  numeric
# 21                    observed_temp_change_last_3h_f  numeric
# 22           observed_morning_warmup_rate_f_per_hour  numeric
# 23           observed_high_so_far_change_since_9am_f  numeric
# 163                         v2_recent_heat_anomaly_f  numeric
# 164                        v2_recent_heat_momentum_f  numeric
# 165                 v2_morning_warmup_to_consensus_f  numeric
# 166                   v2_consensus_minus_7d_actual_f  numeric
# 167                           v2_spread_per_warmup_f  numeric
# 168                   v2_humidity_warmup_interaction  numeric
# 169                   v3_high_so_far_above_current_f  numeric
# 170           v3_remaining_warmup_from_high_so_far_f  numeric
# 171                    v3_high_so_far_minus_lag_1d_f  numeric
# 172                 v3_high_so_far_minus_7d_actual_f  numeric
# 173                 v3_remaining_warmup_per_spread_f  numeric
# 174         v3_humidity_remaining_warmup_interaction  numeric
# 175                           v4_any_forecast_precip  numeric
# 176                           v4_all_forecast_precip  numeric
# 177                           v4_observed_precip_any  numeric
# 178                 v4_observed_precip_recent_mm_est  numeric
# 179                v4_forecast_observed_precip_match  numeric
# 180                     v4_forecast_wet_observed_dry  numeric
# 181                     v4_observed_wet_forecast_dry  numeric
# 182     v8_provider_max_remaining_from_high_so_far_f  numeric
# 183     v8_provider_min_remaining_from_high_so_far_f  numeric
# 184  v8_provider_median_remaining_from_high_so_far_f  numeric
# 185        v8_provider_spread_per_remaining_warmup_f  numeric
# 186                 v8_month_remaining_warmup_mean_f  numeric
# 187                  v8_month_remaining_warmup_count  numeric
# 188             v8_recent_remaining_warmup_7d_mean_f  numeric
# 189            v8_recent_remaining_warmup_30d_mean_f  numeric
# 190     v8_provider_mean_remaining_vs_month_normal_f  numeric

# %% [markdown]
# ## Dropped Feature Check

# %%
dropped_present = result.feature_columns.loc[
    result.feature_columns["feature"].isin(V8_DROPPED_FEATURE_COLUMNS)
]

dropped_present
# Out:
# Empty DataFrame
# Columns: [feature, kind]
# Index: []

# %% [markdown]
# ## Morning Trend Coverage

# %%
trend_coverage = (
    result.features[TREND_COLUMNS]
    .notna()
    .mean()
    .mul(100)
    .sort_values(ascending=False)
    .rename("coverage_pct")
    .reset_index()
    .rename(columns={"index": "feature"})
)

trend_coverage
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 trend_coverage = (
# ----> 2     result.features[TREND_COLUMNS]
#       3     .notna()
#       4     .mean()
#       5     .mul(100)
#
# NameError: name 'TREND_COLUMNS' is not defined

# %% [markdown]
# ## Rounded Within 1F Accuracy

# %%
preds = pd.concat(
    [
        result.validation_predictions.assign(period="validation_2024_2025"),
        result.test_predictions.assign(period="oof_2026"),
    ],
    ignore_index=True,
)

predicted_high = pd.to_numeric(preds["predicted_high_f"], errors="coerce")
preds["predicted_high_rounded_f"] = np.floor(predicted_high + 0.5)
preds["within_1f_after_round"] = (
    pd.to_numeric(preds["actual_high_f"], errors="coerce") - preds["predicted_high_rounded_f"]
).abs().le(1)

within_1f_accuracy_by_period = (
    preds
    .dropna(subset=["actual_high_f", "predicted_high_rounded_f"])
    .groupby(["period", "method"], as_index=False)
    .agg(
        count=("within_1f_after_round", "size"),
        within_1f_count=("within_1f_after_round", "sum"),
        within_1f_accuracy_pct=("within_1f_after_round", lambda x: x.mean() * 100),
    )
    .sort_values(["period", "within_1f_accuracy_pct"], ascending=[True, False])
)

within_1f_accuracy_by_period
# Out:
#                   period       method  count  within_1f_count  \
# 5               oof_2026  ridge_stack    137               84
# 3               oof_2026     lightgbm    137               82
# 6               oof_2026      xgboost    137               81
# 0               oof_2026     catboost    137               79
# 4               oof_2026      nbm_raw    137               57
# 1               oof_2026      gfs_raw    137               47
# 2               oof_2026     hrrr_raw    137               39
# 10  validation_2024_2025     lightgbm    729              440
# 7   validation_2024_2025     catboost    729              434
# 12  validation_2024_2025      xgboost    729              431
# 11  validation_2024_2025      nbm_raw    729              281
# 9   validation_2024_2025     hrrr_raw    729              261
# 8   validation_2024_2025      gfs_raw    729              229
#
#     within_1f_accuracy_pct
# 5                61.313869
# 3                59.854015
# 6                59.124088
# 0                57.664234
# 4                41.605839
# 1                34.306569
# 2                28.467153
# 10               60.356653
# 7                59.533608
# 12               59.122085
# 11               38.545953
# 9                35.802469
# 8                31.412894

# %% [markdown]
# ## Version Comparison

# %%
comparison_frames = []
for version, folder in [
    ("v1", PROJECT_ROOT / "data" / "calibration" / "station_stacking"),
    ("v2", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v2"),
    ("v3", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v3"),
    ("v4", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v4"),
    ("v5", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v5"),
    ("v6", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v6"),
    ("v7", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v7"),
    ("v8", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v8"),
]:
    path = folder / f"{STATION_ID}_year_split_scoreboard.csv"
    if path.exists():
        frame = pd.read_csv(path)
        frame["version"] = version
        comparison_frames.append(frame)

version_comparison = pd.concat(comparison_frames, ignore_index=True) if comparison_frames else pd.DataFrame()
if not version_comparison.empty:
    version_comparison = version_comparison.sort_values(["period", "mae_f", "version", "method"]).reset_index(drop=True)
version_comparison
# Out:
#                   period       method  count     mae_f    rmse_f version
# 0              test_2026     lightgbm    137  1.529158  2.006654      v8
# 1              test_2026  ridge_stack    137  1.557921  2.024451      v8
# 2              test_2026  ridge_stack     98  1.587308  2.183874      v7
# 3              test_2026      xgboost    137  1.594349  2.068159      v8
# 4              test_2026      xgboost     98  1.621233  2.264251      v7
# ..                   ...          ...    ...       ...       ...     ...
# 83  validation_2024_2025      gfs_raw    660  4.616216  6.792032      v2
# 84  validation_2024_2025      gfs_raw    660  4.616216  6.792032      v3
# 85  validation_2024_2025      gfs_raw    660  4.616216  6.792032      v4
# 86  validation_2024_2025      gfs_raw    596  4.846561  7.070391      v1
# 87  validation_2024_2025      xgboost    660  5.333859  6.998391      v4
#
# [88 rows x 6 columns]

# %% [markdown]
# ## 2026 OOF Weather Brackets

# %%
result.bracket_metrics

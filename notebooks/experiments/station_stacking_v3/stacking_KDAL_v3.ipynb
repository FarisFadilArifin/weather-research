# %% [markdown]
# # Station Stacking v3 - KDAL
#
# Wide HRRR/GFS same-day 11am notebook for `KDAL`.
#
# This version keeps the v2 notebook feature engineering and adds SDK-backed 11 AM high-so-far features from `observed_high_temp_through_as_of_f`. Artifacts are written to `data/calibration/station_stacking_v3`.

# %%
from pathlib import Path
import sys
import warnings

warnings.filterwarnings("ignore", message="IProgress not found.*")
warnings.filterwarnings("ignore", message="Skipping features without any observed values.*")

PROJECT_ROOT = Path.cwd().resolve()
while not (PROJECT_ROOT / "src" / "calibration" / "station_stacking.py").exists():
    if PROJECT_ROOT.parent == PROJECT_ROOT:
        raise RuntimeError("Could not find project root containing src/calibration/station_stacking.py")
    PROJECT_ROOT = PROJECT_ROOT.parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

STATION_ID = "KDAL"
FAST_MODE = False
OPTUNA_TRIALS = 100
STACK_OPTUNA_TRIALS = 50
OPTUNA_VERBOSE = True
PROJECT_ROOT
# Out:
# WindowsPath('D:/dev/weather-research')

# %%
from src.calibration.station_stacking import (
    StationStackingConfig,
    missing_model_dependencies,
    run_station_year_split_experiment,
)

# %% [markdown]
# ## V3 Feature Engineering
#
# Adds v2 features plus SDK-backed 11 AM high-so-far signals. The high-so-far feature is computed from same-day station observations at or before the 11 AM local as-of time.

# %%
import numpy as np
import pandas as pd
import src.calibration.station_stacking as station_stacking_module

V3_FEATURE_COLUMNS = [
    "v2_recent_heat_anomaly_f",
    "v2_recent_heat_momentum_f",
    "v2_morning_warmup_to_consensus_f",
    "v2_consensus_minus_7d_actual_f",
    "v2_spread_per_warmup_f",
    "v2_humidity_warmup_interaction",
    "v3_high_so_far_above_current_f",
    "v3_remaining_warmup_from_high_so_far_f",
    "v3_high_so_far_minus_lag_1d_f",
    "v3_high_so_far_minus_7d_actual_f",
    "v3_remaining_warmup_per_spread_f",
    "v3_humidity_remaining_warmup_interaction",
]


def add_v3_feature_engineering(frame: pd.DataFrame) -> pd.DataFrame:
    out = frame.copy()
    observed_temp = pd.to_numeric(out.get("observed_temp_at_as_of_f"), errors="coerce")
    high_so_far = pd.to_numeric(out.get("observed_high_temp_through_as_of_f"), errors="coerce")
    observed_humidity = pd.to_numeric(out.get("observed_humidity_at_as_of"), errors="coerce")
    provider_mean = pd.to_numeric(out.get("provider_mean_high_f"), errors="coerce")
    provider_spread = pd.to_numeric(out.get("provider_spread_high_f"), errors="coerce")
    lag_1d = pd.to_numeric(out.get("actual_high_lag_1d"), errors="coerce")
    roll_7d = pd.to_numeric(out.get("actual_high_roll_7d_mean"), errors="coerce")
    roll_30d = pd.to_numeric(out.get("actual_high_roll_30d_mean"), errors="coerce")

    warmup_to_consensus = provider_mean - observed_temp
    remaining_warmup = provider_mean - high_so_far
    out["v2_recent_heat_anomaly_f"] = lag_1d - roll_30d
    out["v2_recent_heat_momentum_f"] = roll_7d - roll_30d
    out["v2_morning_warmup_to_consensus_f"] = warmup_to_consensus
    out["v2_consensus_minus_7d_actual_f"] = provider_mean - roll_7d
    out["v2_spread_per_warmup_f"] = provider_spread / warmup_to_consensus.abs().clip(lower=1.0)
    out["v2_humidity_warmup_interaction"] = (observed_humidity / 100.0) * warmup_to_consensus
    out["v3_high_so_far_above_current_f"] = high_so_far - observed_temp
    out["v3_remaining_warmup_from_high_so_far_f"] = remaining_warmup
    out["v3_high_so_far_minus_lag_1d_f"] = high_so_far - lag_1d
    out["v3_high_so_far_minus_7d_actual_f"] = high_so_far - roll_7d
    out["v3_remaining_warmup_per_spread_f"] = remaining_warmup / provider_spread.abs().clip(lower=1.0)
    out["v3_humidity_remaining_warmup_interaction"] = (observed_humidity / 100.0) * remaining_warmup
    return out


if not hasattr(station_stacking_module, "_v3_original_build_station_wide_dataset"):
    station_stacking_module._v3_original_build_station_wide_dataset = station_stacking_module.build_station_wide_dataset


def build_station_wide_dataset_v3(*args, **kwargs):
    frame = station_stacking_module._v3_original_build_station_wide_dataset(*args, **kwargs)
    return add_v3_feature_engineering(frame)


station_stacking_module.build_station_wide_dataset = build_station_wide_dataset_v3
V3_FEATURE_COLUMNS
# Out:
# ['v2_recent_heat_anomaly_f',
#  'v2_recent_heat_momentum_f',
#  'v2_morning_warmup_to_consensus_f',
#  'v2_consensus_minus_7d_actual_f',
#  'v2_spread_per_warmup_f',
#  'v2_humidity_warmup_interaction',
#  'v3_high_so_far_above_current_f',
#  'v3_remaining_warmup_from_high_so_far_f',
#  'v3_high_so_far_minus_lag_1d_f',
#  'v3_high_so_far_minus_7d_actual_f',
#  'v3_remaining_warmup_per_spread_f',
#  'v3_humidity_remaining_warmup_interaction']

# %% [markdown]
# ## Model Scores

# %%
missing_packages = missing_model_dependencies()
if missing_packages:
    raise ImportError(
        "Missing station-stacking ML packages: "
        + ", ".join(missing_packages)
        + ". Install them with: python -m pip install -r requirements.txt"
    )

config = StationStackingConfig(
    station_id=STATION_ID,
    project_root=PROJECT_ROOT,
    fast_mode=FAST_MODE,
    optuna_trials=OPTUNA_TRIALS,
    stack_optuna_trials=STACK_OPTUNA_TRIALS,
    optuna_verbose=OPTUNA_VERBOSE,
    output_dir=PROJECT_ROOT / "data" / "calibration" / "station_stacking_v3",
)
result = run_station_year_split_experiment(config)
result.scoreboard
# Out:
# [I 2026-06-08 22:56:39,254] A new study created in memory with name: no-name-5fc9664d-e6ff-4396-bcbd-a5131ac46238
# [I 2026-06-08 22:56:45,897] Trial 0 finished with value: 3.5572121799445577 and parameters: {'n_estimators': 799, 'learning_rate': 0.12369619597856178, 'max_depth': 6, 'min_child_weight': 2.385234757844707, 'gamma': 0.7800932022121826, 'subsample': 0.5779972601681014, 'colsample_bytree': 0.5290418060840998, 'reg_alpha': 0.6245760287469893, 'reg_lambda': 0.6677615511747083}. Best is trial 0 with value: 3.5572121799445577.
# [I 2026-06-08 22:57:54,476] Trial 1 finished with value: 3.2432666948656967 and parameters: {'n_estimators': 1440, 'learning_rate': 0.0032515743808034223, 'max_depth': 8, 'min_child_weight': 8.23143373099555, 'gamma': 1.0616955533913808, 'subsample': 0.5909124836035503, 'colsample_bytree': 0.5917022549267169, 'reg_alpha': 5.472429642032198e-06, 'reg_lambda': 0.2922905212920093}. Best is trial 1 with value: 3.2432666948656967.
# [I 2026-06-08 22:58:09,658] Trial 2 finished with value: 4.24805907023268 and parameters: {'n_estimators': 909, 'learning_rate': 0.009373695213782608, 'max_depth': 5, 'min_child_weight': 0.20940138873937433, 'gamma': 1.4607232426760908, 'subsample': 0.6831809216468459, 'colsample_bytree': 0.728034992108518, 'reg_alpha': 0.1165691561324743, 'reg_lambda': 0.008674832802525461}. Best is trial 1 with value: 3.2432666948656967.
# [I 2026-06-08 22:58:14,875] Trial 3 finished with value: 3.1928161422710404 and parameters: {'n_estimators': 1067, 'learning_rate': 0.03045200113778571, 'max_depth': 1, 'min_child_weight': 2.5002240473339543, 'gamma': 0.8526206184364576, 'subsample': 0.5325257964926398, 'colsample_bytree': 0.9744427686266666, 'reg_alpha': 4.905556676028774, 'reg_lambda': 6.289771819487036}. Best is trial 3 with value: 3.1928161422710404.
# [I 2026-06-08 22:58:39,573] Trial 4 finished with value: 3.7735133208744083 and parameters: {'n_estimators': 665, 'learning_rate': 0.004396056309201638, 'max_depth': 6, 'min_child_weight': 1.0299214204601976, 'gamma': 0.6101911742238941, 'subsample': 0.7475884550556351, 'colsample_bytree': 0.5171942605576092, 'reg_alpha': 1.527156759251193, 'reg_lambda': 0.016443693426189242}. Best is trial 3 with value: 3.1928161422710404.
# [I 2026-06-08 22:58:48,931] Trial 5 pruned.
# [I 2026-06-08 22:58:50,091] Trial 6 finished with value: 3.2939340316844437 and parameters: {'n_estimators': 1228, 'learning_rate': 0.11049889315270257, 'max_depth': 1, 'min_child_weight': 0.28246357083904894, 'gamma': 0.22613644455269033, 'subsample': 0.6626651653816322, 'colsample_bytree': 0.6943386448447411, 'reg_alpha': 2.7678419414850017e-06, 'reg_lambda': 7.838134236608707}. Best is trial 3 with value: 3.1928161422710404.
# [I 2026-06-08 22:58:56,188] Trial 7 pruned.
# [I 2026-06-08 22:58:58,835] Trial 8 finished with value: 3.3754834495520596 and parameters: {'n_estimators': 90, 'learning_rate': 0.07287285110476487, 'max_depth': 6, 'min_child_weight': 4.758470274910409, 'gamma': 3.8563517334297286, 'subsample': 0.5370223258670452, 'colsample_bytree': 0.6792328642721364, 'reg_alpha': 1.1036250149900698e-07, 'reg_lambda': 11.368341439732731}. Best is trial 3 with value: 3.1928161422710404.
# [I 2026-06-08 22:59:04,616] Trial 9 finished with value: 3.2385804956599777 and parameters: {'n_estimators': 1277, 'learning_rate': 0.01094730135557207, 'max_depth': 1, 'min_child_weight': 0.5194929407101735, 'gamma': 1.6259166101337352, 'subsample': 0.864803089169032, 'colsample_bytree': 0.8187787356776066, 'reg_alpha': 0.9658611176861268, 'reg_lambda': 0.16554793541373172}. Best is trial 3 with value: 3.1928161422710404.
# [I 2026-06-08 22:59:06,643] Trial 10 finished with value: 3.2446662574801777 and parameters: {'n_estimators': 1915, 'learning_rate': 0.036235378997051045, 'max_depth': 3, 'min_child_weight': 13.97101765312176, 'gamma': 2.828065453407016, 'subsample': 0.8211770829222278, 'colsample_bytree': 0.9805126451489784, 'reg_alpha': 0.0025347992375043043, 'reg_lambda': 2.1525808090182244}. Best is trial 3 with value: 3.1928161422710404.
# [I 2026-06-08 22:59:09,440] Trial 11 finished with value: 3.249081652128689 and parameters: {'n_estimators': 1702, 'learning_rate': 0.023509678188609322, 'max_depth': 1, 'min_child_weight': 0.688588546457162, 'gamma': 2.1717813587820567, 'subsample': 0.9230401133008451, 'colsample_bytree': 0.8391354614798949, 'reg_alpha': 0.0029151336209232823, 'reg_lambda': 0.11201577705436261}. Best is trial 3 with value: 3.1928161422710404.
# [I 2026-06-08 22:59:11,807] Trial 12 finished with value: 3.22489568908541 and parameters: {'n_estimators': 1159, 'learning_rate': 0.023540187160304347, 'max_depth': 2, 'min_child_weight': 0.5599673733323597, 'gamma': 2.0858621438084413, 'subsample': 0.8384090290478075, 'colsample_bytree': 0.85058129769688, 'reg_alpha': 8.570867787439136, 'reg_lambda': 0.0012192090404368188}. Best is trial 3 with value: 3.1928161422710404.
# [I 2026-06-08 22:59:12,913] Trial 13 pruned.
# [I 2026-06-08 22:59:13,719] Trial 14 pruned.
# [I 2026-06-08 22:59:22,899] Trial 15 finished with value: 3.2315426721511407 and parameters: {'n_estimators': 1633, 'learning_rate': 0.014972146841544968, 'max_depth': 2, 'min_child_weight': 1.2988608490074383, 'gamma': 1.9394588959120636, 'subsample': 0.9913430783889022, 'colsample_bytree': 0.9159006128831201, 'reg_alpha': 9.842839418534158, 'reg_lambda': 39.09721369856506}. Best is trial 3 with value: 3.1928161422710404.
# [I 2026-06-08 22:59:28,274] Trial 16 finished with value: 3.195593323712659 and parameters: {'n_estimators': 1056, 'learning_rate': 0.018108041390302598, 'max_depth': 2, 'min_child_weight': 6.2861243298903755, 'gamma': 0.03564089363659739, 'subsample': 0.8108482895051157, 'colsample_bytree': 0.9473022142160039, 'reg_alpha': 0.0348885376241305, 'reg_lambda': 0.0011532639937455423}. Best is trial 3 with value: 3.1928161422710404.
# [I 2026-06-08 22:59:31,631] Trial 17 finished with value: 3.1900343567865344 and parameters: {'n_estimators': 489, 'learning_rate': 0.0492709205335101, 'max_depth': 2, 'min_child_weight': 5.286850270900009, 'gamma': 0.029042535507300286, 'subsample': 0.7700475100567968, 'colsample_bytree': 0.9512213330989459, 'reg_alpha': 0.04210657654980502, 'reg_lambda': 1.4260093575263733}. Best is trial 17 with value: 3.1900343567865344.
# [I 2026-06-08 22:59:34,632] Trial 18 pruned.
# [I 2026-06-08 22:59:36,207] Trial 19 pruned.
# [I 2026-06-08 22:59:39,280] Trial 20 finished with value: 3.1864687303500396 and parameters: {'n_estimators': 160, 'learning_rate': 0.0910963275808075, 'max_depth': 1, 'min_child_weight': 7.902120525724466, 'gamma': 0.5633765746133375, 'subsample': 0.6200392464368687, 'colsample_bytree': 0.8790963886169064, 'reg_alpha': 0.24570608971682925, 'reg_lambda': 0.6795005553479959}. Best is trial 20 with value: 3.1864687303500396.
# [I 2026-06-08 22:59:39,686] Trial 21 pruned.
# [I 2026-06-08 22:59:40,610] Trial 22 pruned.
# [I 2026-06-08 22:59:41,357] Trial 23 pruned.
# [I 2026-06-08 22:59:46,142] Trial 24 pruned.
# [I 2026-06-08 22:59:49,123] Trial 25 pruned.
# [I 2026-06-08 22:59:52,033] Trial 26 finished with value: 3.218376016029747 and parameters: {'n_estimators': 178, 'learning_rate': 0.08665338766727078, 'max_depth': 2, 'min_child_weight': 5.733860017515316, 'gamma': 1.608359654727031, 'subsample': 0.7787588257864038, 'colsample_bytree': 0.9083655697548045, 'reg_alpha': 0.47394385422125057, 'reg_lambda': 1.137432447217439}. Best is trial 20 with value: 3.1864687303500396.
# [I 2026-06-08 22:59:55,238] Trial 27 pruned.
# [I 2026-06-08 22:59:58,017] Trial 28 pruned.
# [I 2026-06-08 22:59:58,718] Trial 29 pruned.
# [I 2026-06-08 23:00:02,405] Trial 30 finished with value: 3.142896293686367 and parameters: {'n_estimators': 194, 'learning_rate': 0.034812537461815965, 'max_depth': 2, 'min_child_weight': 10.135634157977798, 'gamma': 0.6548711973037427, 'subsample': 0.6929710096563917, 'colsample_bytree': 0.5615546708760338, 'reg_alpha': 0.4548021734884193, 'reg_lambda': 1.2787779152609444}. Best is trial 30 with value: 3.142896293686367.
# [I 2026-06-08 23:00:05,512] Trial 31 finished with value: 3.1660100775072904 and parameters: {'n_estimators': 220, 'learning_rate': 0.034302151905345794, 'max_depth': 2, 'min_child_weight': 11.316782257611944, 'gamma': 0.7310582128677481, 'subsample': 0.7105452933672429, 'colsample_bytree': 0.5928421846942739, 'reg_alpha': 0.46701873302377467, 'reg_lambda': 1.3068458597417727}. Best is trial 30 with value: 3.142896293686367.
# [I 2026-06-08 23:00:11,409] Trial 32 pruned.
# [I 2026-06-08 23:00:14,216] Trial 33 pruned.
# [I 2026-06-08 23:00:19,601] Trial 34 finished with value: 3.1673195890671244 and parameters: {'n_estimators': 210, 'learning_rate': 0.06699161605164122, 'max_depth': 2, 'min_child_weight': 7.02936085433684, 'gamma': 0.722902714132647, 'subsample': 0.6825544090482419, 'colsample_bytree': 0.629739271089939, 'reg_alpha': 0.14375006015764208, 'reg_lambda': 0.4830774275378004}. Best is trial 30 with value: 3.142896293686367.
# [I 2026-06-08 23:00:22,781] Trial 35 pruned.
# [I 2026-06-08 23:00:28,152] Trial 36 pruned.
# [I 2026-06-08 23:00:29,697] Trial 37 pruned.
# [I 2026-06-08 23:00:36,456] Trial 38 finished with value: 3.1472831079016697 and parameters: {'n_estimators': 410, 'learning_rate': 0.03314950681387999, 'max_depth': 2, 'min_child_weight': 11.45778858474274, 'gamma': 0.6588603029705173, 'subsample': 0.676414199881723, 'colsample_bytree': 0.5536369471561254, 'reg_alpha': 0.011177777259444936, 'reg_lambda': 0.6601850378224449}. Best is trial 30 with value: 3.142896293686367.
# [I 2026-06-08 23:00:40,898] Trial 39 pruned.
# [I 2026-06-08 23:00:48,032] Trial 40 pruned.
# [I 2026-06-08 23:00:51,802] Trial 41 finished with value: 3.1709099515988983 and parameters: {'n_estimators': 251, 'learning_rate': 0.032910583352170196, 'max_depth': 2, 'min_child_weight': 7.27359264872281, 'gamma': 0.6804463692556393, 'subsample': 0.6371720957834796, 'colsample_bytree': 0.5486013433839096, 'reg_alpha': 2.5864914497102185, 'reg_lambda': 0.6279834391052044}. Best is trial 30 with value: 3.142896293686367.
# [I 2026-06-08 23:00:56,171] Trial 42 finished with value: 3.151364115296251 and parameters: {'n_estimators': 294, 'learning_rate': 0.031642392296595455, 'max_depth': 2, 'min_child_weight': 7.33497231357889, 'gamma': 0.6800563258727854, 'subsample': 0.6406285557404656, 'colsample_bytree': 0.5446510418040151, 'reg_alpha': 2.9300141978729877, 'reg_lambda': 0.29961408240152326}. Best is trial 30 with value: 3.142896293686367.
# [I 2026-06-08 23:01:00,166] Trial 43 finished with value: 3.169828007510761 and parameters: {'n_estimators': 405, 'learning_rate': 0.0263435063179854, 'max_depth': 2, 'min_child_weight': 11.544140884976876, 'gamma': 1.0884358816400186, 'subsample': 0.5957202956591534, 'colsample_bytree': 0.5296649475295371, 'reg_alpha': 0.7972811282490991, 'reg_lambda': 0.2975428020837716}. Best is trial 30 with value: 3.142896293686367.
# [I 2026-06-08 23:01:04,947] Trial 44 pruned.
# [I 2026-06-08 23:01:08,880] Trial 45 finished with value: 3.175345372032454 and parameters: {'n_estimators': 559, 'learning_rate': 0.03526077256834652, 'max_depth': 2, 'min_child_weight': 6.31105111397266, 'gamma': 0.706805933352862, 'subsample': 0.6985452803246426, 'colsample_bytree': 0.6353142954449115, 'reg_alpha': 0.12590898250585275, 'reg_lambda': 0.13726296623752493}. Best is trial 30 with value: 3.142896293686367.
# [I 2026-06-08 23:01:11,337] Trial 46 pruned.
# [I 2026-06-08 23:01:13,975] Trial 47 pruned.
# [I 2026-06-08 23:01:14,933] Trial 48 pruned.
# [I 2026-06-08 23:01:18,902] Trial 49 pruned.
# [I 2026-06-08 23:01:26,997] Trial 50 finished with value: 3.1721183308684817 and parameters: {'n_estimators': 668, 'learning_rate': 0.035702201345215324, 'max_depth': 2, 'min_child_weight': 5.312740989195525, 'gamma': 3.6589288407001392, 'subsample': 0.6356374512024875, 'colsample_bytree': 0.5033800193721841, 'reg_alpha': 0.5808297738511439, 'reg_lambda': 0.41189391359415567}. Best is trial 30 with value: 3.142896293686367.
# [I 2026-06-08 23:01:29,489] Trial 51 pruned.
# [I 2026-06-08 23:01:31,401] Trial 52 pruned.
# [I 2026-06-08 23:01:32,674] Trial 53 pruned.
# [I 2026-06-08 23:01:36,428] Trial 54 finished with value: 3.161625893228419 and parameters: {'n_estimators': 162, 'learning_rate': 0.04036581169761348, 'max_depth': 2, 'min_child_weight': 12.072755695693575, 'gamma': 2.354342646923259, 'subsample': 0.7098786281881801, 'colsample_bytree': 0.5794846494793499, 'reg_alpha': 0.08902848374334289, 'reg_lambda': 0.2469985662489677}. Best is trial 30 with value: 3.142896293686367.
# [I 2026-06-08 23:01:39,676] Trial 55 pruned.
# [I 2026-06-08 23:01:42,957] Trial 56 finished with value: 3.165990537999786 and parameters: {'n_estimators': 259, 'learning_rate': 0.05981672240769367, 'max_depth': 2, 'min_child_weight': 9.697007203982567, 'gamma': 2.514080722582498, 'subsample': 0.7362887670685114, 'colsample_bytree': 0.6210786639348762, 'reg_alpha': 1.7944365024927385e-06, 'reg_lambda': 3.5482285322640457}. Best is trial 30 with value: 3.142896293686367.
# [I 2026-06-08 23:01:44,550] Trial 57 pruned.
# [I 2026-06-08 23:01:45,954] Trial 58 pruned.
# [I 2026-06-08 23:01:48,023] Trial 59 pruned.
# [I 2026-06-08 23:01:49,245] Trial 60 pruned.
# [I 2026-06-08 23:01:52,952] Trial 61 finished with value: 3.1219231924352107 and parameters: {'n_estimators': 210, 'learning_rate': 0.047837203321342114, 'max_depth': 2, 'min_child_weight': 7.060721801708312, 'gamma': 3.4025619262264195, 'subsample': 0.6962011488440425, 'colsample_bytree': 0.6287073457448153, 'reg_alpha': 0.34078608052858383, 'reg_lambda': 0.6225047643709534}. Best is trial 61 with value: 3.1219231924352107.
# [I 2026-06-08 23:01:56,569] Trial 62 finished with value: 3.1543405066216375 and parameters: {'n_estimators': 175, 'learning_rate': 0.04780046787331708, 'max_depth': 2, 'min_child_weight': 5.7590419808107605, 'gamma': 4.374966853609464, 'subsample': 0.6985633875315984, 'colsample_bytree': 0.7228743471086065, 'reg_alpha': 0.3514082140114939, 'reg_lambda': 1.35282042822032}. Best is trial 61 with value: 3.1219231924352107.
# [I 2026-06-08 23:01:59,005] Trial 63 finished with value: 3.158358322182046 and parameters: {'n_estimators': 132, 'learning_rate': 0.04710523235790703, 'max_depth': 2, 'min_child_weight': 4.186730569660771, 'gamma': 4.670042613803195, 'subsample': 0.6450788360849611, 'colsample_bytree': 0.7175885901485166, 'reg_alpha': 4.770619182543623, 'reg_lambda': 0.0031473656603618278}. Best is trial 61 with value: 3.1219231924352107.
# [I 2026-06-08 23:02:03,462] Trial 64 pruned.
# [I 2026-06-08 23:02:05,673] Trial 65 pruned.
# [I 2026-06-08 23:02:09,244] Trial 66 finished with value: 3.1472283688368075 and parameters: {'n_estimators': 163, 'learning_rate': 0.050820944206967825, 'max_depth': 2, 'min_child_weight': 5.1516434805029565, 'gamma': 3.570731671822988, 'subsample': 0.6945447712252159, 'colsample_bytree': 0.6783406599538633, 'reg_alpha': 0.3444771038476939, 'reg_lambda': 0.007447091461992598}. Best is trial 61 with value: 3.1219231924352107.
# [I 2026-06-08 23:02:11,618] Trial 67 pruned.
# [I 2026-06-08 23:02:13,407] Trial 68 pruned.
# [I 2026-06-08 23:02:16,311] Trial 69 finished with value: 3.136818185944784 and parameters: {'n_estimators': 208, 'learning_rate': 0.04488746344798919, 'max_depth': 2, 'min_child_weight': 5.705376906916126, 'gamma': 4.548026885955387, 'subsample': 0.6227552898593165, 'colsample_bytree': 0.7452967306168995, 'reg_alpha': 0.029585448198242763, 'reg_lambda': 0.004501764984405641}. Best is trial 61 with value: 3.1219231924352107.
# [I 2026-06-08 23:02:17,171] Trial 70 pruned.
# [I 2026-06-08 23:02:19,864] Trial 71 finished with value: 3.153784569640149 and parameters: {'n_estimators': 196, 'learning_rate': 0.04560877056509767, 'max_depth': 2, 'min_child_weight': 4.686102374343835, 'gamma': 4.768136607945865, 'subsample': 0.6305537974044904, 'colsample_bytree': 0.7639263770239666, 'reg_alpha': 0.02438965105126012, 'reg_lambda': 0.0034075563601432116}. Best is trial 61 with value: 3.1219231924352107.
# [I 2026-06-08 23:02:22,919] Trial 72 pruned.
# [I 2026-06-08 23:02:26,246] Trial 73 finished with value: 3.1501560101783292 and parameters: {'n_estimators': 234, 'learning_rate': 0.04394569392019783, 'max_depth': 2, 'min_child_weight': 7.636216675636189, 'gamma': 4.183428243053896, 'subsample': 0.6747711850768688, 'colsample_bytree': 0.7459754453052803, 'reg_alpha': 0.0351056851515546, 'reg_lambda': 0.002979719622723297}. Best is trial 61 with value: 3.1219231924352107.
# [I 2026-06-08 23:02:27,625] Trial 74 pruned.
# [I 2026-06-08 23:02:28,769] Trial 75 pruned.
# [I 2026-06-08 23:02:30,161] Trial 76 pruned.
# [I 2026-06-08 23:02:31,496] Trial 77 pruned.
# [I 2026-06-08 23:02:34,271] Trial 78 pruned.
# [I 2026-06-08 23:02:35,560] Trial 79 pruned.
# [I 2026-06-08 23:02:36,979] Trial 80 pruned.
# [I 2026-06-08 23:02:40,954] Trial 81 finished with value: 3.15217882247456 and parameters: {'n_estimators': 201, 'learning_rate': 0.04596424179550531, 'max_depth': 2, 'min_child_weight': 5.782456957577343, 'gamma': 4.306662688053473, 'subsample': 0.6945781131814786, 'colsample_bytree': 0.7018706462157284, 'reg_alpha': 0.2906495294372313, 'reg_lambda': 0.005806689795965021}. Best is trial 61 with value: 3.1219231924352107.
# [I 2026-06-08 23:02:42,131] Trial 82 pruned.
# [I 2026-06-08 23:02:46,255] Trial 83 pruned.
# [I 2026-06-08 23:02:47,589] Trial 84 pruned.
# [I 2026-06-08 23:02:51,435] Trial 85 pruned.
# [I 2026-06-08 23:02:58,043] Trial 86 pruned.
# [I 2026-06-08 23:03:04,004] Trial 87 finished with value: 3.159969680890982 and parameters: {'n_estimators': 245, 'learning_rate': 0.052683061976195864, 'max_depth': 2, 'min_child_weight': 7.863194200569682, 'gamma': 4.260267785599166, 'subsample': 0.7617453168463838, 'colsample_bytree': 0.5451345489663016, 'reg_alpha': 0.10803869271296146, 'reg_lambda': 0.001417892186649798}. Best is trial 61 with value: 3.1219231924352107.
# [I 2026-06-08 23:03:07,106] Trial 88 pruned.
# [I 2026-06-08 23:03:08,198] Trial 89 pruned.
# [I 2026-06-08 23:03:12,318] Trial 90 finished with value: 3.1710358190145893 and parameters: {'n_estimators': 1389, 'learning_rate': 0.047389163679649744, 'max_depth': 2, 'min_child_weight': 6.181599238704159, 'gamma': 0.46488749697286835, 'subsample': 0.6719890248226122, 'colsample_bytree': 0.6887493655787328, 'reg_alpha': 0.1941988140792175, 'reg_lambda': 0.019832525267582116}. Best is trial 61 with value: 3.1219231924352107.
# [I 2026-06-08 23:03:15,286] Trial 91 finished with value: 3.1475784676700593 and parameters: {'n_estimators': 180, 'learning_rate': 0.0498606534549726, 'max_depth': 2, 'min_child_weight': 5.768988114287368, 'gamma': 4.405886272474615, 'subsample': 0.7019628266117076, 'colsample_bytree': 0.7325537399530326, 'reg_alpha': 0.32939072976942774, 'reg_lambda': 0.8220321044168668}. Best is trial 61 with value: 3.1219231924352107.
# [I 2026-06-08 23:03:17,279] Trial 92 pruned.
# [I 2026-06-08 23:03:19,849] Trial 93 pruned.
# [I 2026-06-08 23:03:22,676] Trial 94 finished with value: 3.1487041009063974 and parameters: {'n_estimators': 180, 'learning_rate': 0.041205422306618264, 'max_depth': 2, 'min_child_weight': 7.400510527918992, 'gamma': 4.871559547241528, 'subsample': 0.6888525860190557, 'colsample_bytree': 0.5412340242090892, 'reg_alpha': 0.32816542728205056, 'reg_lambda': 0.002202722767149677}. Best is trial 61 with value: 3.1219231924352107.
# [I 2026-06-08 23:03:23,579] Trial 95 pruned.
# [I 2026-06-08 23:03:25,632] Trial 96 pruned.
# [I 2026-06-08 23:03:29,166] Trial 97 pruned.
# [I 2026-06-08 23:03:30,307] Trial 98 pruned.
# [I 2026-06-08 23:03:32,614] Trial 99 pruned.
# [I 2026-06-08 23:03:32,616] A new study created in memory with name: no-name-1a2e0745-3073-424c-9335-74b3f261b990
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-08 23:03:42,041] Trial 0 finished with value: 3.3824178265502973 and parameters: {'n_estimators': 301, 'learning_rate': 0.03250177171527344, 'num_leaves': 37, 'max_depth': 4, 'min_child_samples': 52, 'min_split_gain': 1.7182749818971954, 'bagging_fraction': 0.8330451065490129, 'bagging_freq': 4, 'feature_fraction': 0.5145069122121801, 'lambda_l1': 0.04015454105555427, 'lambda_l2': 0.07175601133819473}. Best is trial 0 with value: 3.3824178265502973.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-08 23:04:20,107] Trial 1 finished with value: 3.408108891202496 and parameters: {'n_estimators': 1620, 'learning_rate': 0.008116618171663207, 'num_leaves': 18, 'max_depth': 9, 'min_child_samples': 37, 'min_split_gain': 0.8099788960945193, 'bagging_fraction': 0.6580482355091044, 'bagging_freq': 1, 'feature_fraction': 0.9216123471148523, 'lambda_l1': 0.43697071238567825, 'lambda_l2': 36.7185332724254}. Best is trial 0 with value: 3.3824178265502973.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-08 23:04:23,684] Trial 2 finished with value: 3.33661496770544 and parameters: {'n_estimators': 820, 'learning_rate': 0.1255359023925396, 'num_leaves': 116, 'max_depth': 8, 'min_child_samples': 17, 'min_split_gain': 1.7941971599630686, 'bagging_fraction': 0.6490017503443813, 'bagging_freq': 2, 'feature_fraction': 0.5025647745322285, 'lambda_l1': 0.0007741455782248723, 'lambda_l2': 0.1717169091593679}. Best is trial 2 with value: 3.33661496770544.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-08 23:04:25,934] Trial 3 finished with value: 3.814717145139787 and parameters: {'n_estimators': 1302, 'learning_rate': 0.13774020868800516, 'num_leaves': 233, 'max_depth': 10, 'min_child_samples': 81, 'min_split_gain': 0.2080378997095258, 'bagging_fraction': 0.5904572976289505, 'bagging_freq': 7, 'feature_fraction': 0.7059764916931793, 'lambda_l1': 0.6097531961875766, 'lambda_l2': 1.4405915859050216}. Best is trial 2 with value: 3.33661496770544.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-08 23:04:40,885] Trial 4 finished with value: 3.418817425860138 and parameters: {'n_estimators': 1287, 'learning_rate': 0.008816320113501107, 'num_leaves': 230, 'max_depth': 3, 'min_child_samples': 64, 'min_split_gain': 1.987144984788207, 'bagging_fraction': 0.8678635407535604, 'bagging_freq': 4, 'feature_fraction': 0.7803315847218675, 'lambda_l1': 5.026890229380336e-05, 'lambda_l2': 2.6067223030440956}. Best is trial 2 with value: 3.33661496770544.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-08 23:04:44,188] Trial 5 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-08 23:04:47,490] Trial 6 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-08 23:04:49,362] Trial 7 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-08 23:04:49,963] Trial 8 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-08 23:04:56,236] Trial 9 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-08 23:05:56,218] Trial 10 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-08 23:05:58,306] Trial 11 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-08 23:06:07,998] Trial 12 finished with value: 3.3176079831894496 and parameters: {'n_estimators': 517, 'learning_rate': 0.024262419120912624, 'num_leaves': 91, 'max_depth': 8, 'min_child_samples': 31, 'min_split_gain': 1.6887824309347674, 'bagging_fraction': 0.7533243400910767, 'bagging_freq': 2, 'feature_fraction': 0.5065623605708911, 'lambda_l1': 0.013234943178919222, 'lambda_l2': 0.05114673429014843}. Best is trial 12 with value: 3.3176079831894496.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-08 23:06:12,749] Trial 13 finished with value: 3.3173504299505274 and parameters: {'n_estimators': 675, 'learning_rate': 0.07837634048216681, 'num_leaves': 99, 'max_depth': 8, 'min_child_samples': 26, 'min_split_gain': 1.1936481141102784, 'bagging_fraction': 0.7318201539923618, 'bagging_freq': 2, 'feature_fraction': 0.6091484946086794, 'lambda_l1': 0.0002258437315475552, 'lambda_l2': 0.002382249432418657}. Best is trial 13 with value: 3.3173504299505274.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-08 23:06:24,607] Trial 14 finished with value: 3.3033461971947236 and parameters: {'n_estimators': 569, 'learning_rate': 0.019285776368722102, 'num_leaves': 85, 'max_depth': 8, 'min_child_samples': 32, 'min_split_gain': 1.1526647845049771, 'bagging_fraction': 0.7587409687084421, 'bagging_freq': 2, 'feature_fraction': 0.602205334676884, 'lambda_l1': 8.412981494010534, 'lambda_l2': 0.0010944898563967323}. Best is trial 14 with value: 3.3033461971947236.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-08 23:06:29,228] Trial 15 finished with value: 3.329821665088862 and parameters: {'n_estimators': 755, 'learning_rate': 0.06874074573185468, 'num_leaves': 169, 'max_depth': 10, 'min_child_samples': 28, 'min_split_gain': 1.20245693037544, 'bagging_fraction': 0.7643494573197516, 'bagging_freq': 2, 'feature_fraction': 0.6075258671475778, 'lambda_l1': 5.630959744996288, 'lambda_l2': 0.0010249748310612416}. Best is trial 14 with value: 3.3033461971947236.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-08 23:06:37,127] Trial 16 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-08 23:06:38,452] Trial 17 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-08 23:06:44,552] Trial 18 finished with value: 3.308006527999275 and parameters: {'n_estimators': 549, 'learning_rate': 0.08359760184228063, 'num_leaves': 106, 'max_depth': 8, 'min_child_samples': 21, 'min_split_gain': 1.3044339526975424, 'bagging_fraction': 0.9507090584192602, 'bagging_freq': 1, 'feature_fraction': 0.9991355829538757, 'lambda_l1': 0.00035386531703076625, 'lambda_l2': 0.005012107356306188}. Best is trial 14 with value: 3.3033461971947236.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-08 23:06:48,631] Trial 19 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-08 23:07:05,240] Trial 20 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-08 23:07:07,470] Trial 21 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-08 23:07:14,157] Trial 22 finished with value: 3.236195205246939 and parameters: {'n_estimators': 510, 'learning_rate': 0.07871112706783634, 'num_leaves': 106, 'max_depth': 8, 'min_child_samples': 23, 'min_split_gain': 0.9266906735690459, 'bagging_fraction': 0.924005977696853, 'bagging_freq': 2, 'feature_fraction': 0.5788778890547622, 'lambda_l1': 8.046339496407077e-05, 'lambda_l2': 0.0024655757674493114}. Best is trial 22 with value: 3.236195205246939.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-08 23:07:36,004] Trial 23 finished with value: 3.2264970984411034 and parameters: {'n_estimators': 463, 'learning_rate': 0.01835241125639079, 'num_leaves': 68, 'max_depth': 9, 'min_child_samples': 13, 'min_split_gain': 0.9607081447193196, 'bagging_fraction': 0.9218048482763271, 'bagging_freq': 3, 'feature_fraction': 0.5755968611728078, 'lambda_l1': 3.6960945148159155e-07, 'lambda_l2': 0.0054860481044522015}. Best is trial 23 with value: 3.2264970984411034.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-08 23:08:00,640] Trial 24 finished with value: 3.2250813565381655 and parameters: {'n_estimators': 240, 'learning_rate': 0.017742115293309733, 'num_leaves': 56, 'max_depth': 10, 'min_child_samples': 13, 'min_split_gain': 0.9626484320899533, 'bagging_fraction': 0.8827403483594165, 'bagging_freq': 3, 'feature_fraction': 0.5831478944044304, 'lambda_l1': 2.639734056862393e-07, 'lambda_l2': 0.0011510144844720986}. Best is trial 24 with value: 3.2250813565381655.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-08 23:08:22,050] Trial 25 finished with value: 3.2819267059525834 and parameters: {'n_estimators': 255, 'learning_rate': 0.01209149087394847, 'num_leaves': 42, 'max_depth': 10, 'min_child_samples': 12, 'min_split_gain': 0.5921857746033761, 'bagging_fraction': 0.9128086572267741, 'bagging_freq': 3, 'feature_fraction': 0.5628064531129603, 'lambda_l1': 2.2623217287956907e-07, 'lambda_l2': 0.027648613217623193}. Best is trial 24 with value: 3.2250813565381655.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-08 23:08:33,076] Trial 26 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-08 23:08:36,348] Trial 27 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-08 23:08:42,084] Trial 28 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-08 23:08:48,060] Trial 29 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-08 23:08:52,065] Trial 30 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-08 23:09:16,442] Trial 31 finished with value: 3.229238525587311 and parameters: {'n_estimators': 295, 'learning_rate': 0.012078449135110395, 'num_leaves': 39, 'max_depth': 10, 'min_child_samples': 14, 'min_split_gain': 0.6622883854696449, 'bagging_fraction': 0.9149309996248719, 'bagging_freq': 3, 'feature_fraction': 0.579438121624549, 'lambda_l1': 1.9240036788061382e-07, 'lambda_l2': 0.03050814284523635}. Best is trial 24 with value: 3.2250813565381655.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-08 23:09:26,082] Trial 32 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-08 23:09:50,204] Trial 33 finished with value: 3.2694293732126183 and parameters: {'n_estimators': 302, 'learning_rate': 0.010686974853995581, 'num_leaves': 52, 'max_depth': 9, 'min_child_samples': 16, 'min_split_gain': 0.7048282564315675, 'bagging_fraction': 0.9023700948325, 'bagging_freq': 2, 'feature_fraction': 0.5917824851896374, 'lambda_l1': 1.8773675150447215e-08, 'lambda_l2': 0.018344103625250987}. Best is trial 24 with value: 3.2250813565381655.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-08 23:09:56,680] Trial 34 finished with value: 3.2483317390629685 and parameters: {'n_estimators': 716, 'learning_rate': 0.016733521462523795, 'num_leaves': 4, 'max_depth': 10, 'min_child_samples': 29, 'min_split_gain': 0.5573386971042422, 'bagging_fraction': 0.9551381721731974, 'bagging_freq': 4, 'feature_fraction': 0.5290306584000597, 'lambda_l1': 8.004268344281343e-07, 'lambda_l2': 0.1335074367218765}. Best is trial 24 with value: 3.2250813565381655.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-08 23:10:00,760] Trial 35 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-08 23:10:05,240] Trial 36 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-08 23:10:32,884] Trial 37 finished with value: 3.257739027744479 and parameters: {'n_estimators': 829, 'learning_rate': 0.00807768315454033, 'num_leaves': 23, 'max_depth': 10, 'min_child_samples': 23, 'min_split_gain': 0.6496139329436793, 'bagging_fraction': 0.928138888720362, 'bagging_freq': 4, 'feature_fraction': 0.7486917522481321, 'lambda_l1': 2.513499072286372e-07, 'lambda_l2': 0.40557622874992594}. Best is trial 24 with value: 3.2250813565381655.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-08 23:10:34,177] Trial 38 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-08 23:10:39,128] Trial 39 finished with value: 3.2619712051343415 and parameters: {'n_estimators': 204, 'learning_rate': 0.11058020412814412, 'num_leaves': 256, 'max_depth': 9, 'min_child_samples': 13, 'min_split_gain': 1.0335296240349738, 'bagging_fraction': 0.9655305513276605, 'bagging_freq': 3, 'feature_fraction': 0.5039760388823395, 'lambda_l1': 8.883694369198594e-05, 'lambda_l2': 8.737940975177578}. Best is trial 24 with value: 3.2250813565381655.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-08 23:10:45,166] Trial 40 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-08 23:10:49,302] Trial 41 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-08 23:10:58,494] Trial 42 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-08 23:11:10,035] Trial 43 finished with value: 3.1984861294014317 and parameters: {'n_estimators': 483, 'learning_rate': 0.03003578867687798, 'num_leaves': 43, 'max_depth': 9, 'min_child_samples': 19, 'min_split_gain': 0.5630209584453697, 'bagging_fraction': 0.8799987079885366, 'bagging_freq': 4, 'feature_fraction': 0.5212290945557128, 'lambda_l1': 1.0729922703682281e-06, 'lambda_l2': 0.08416336824276323}. Best is trial 43 with value: 3.1984861294014317.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-08 23:11:21,926] Trial 44 finished with value: 3.2348685131305728 and parameters: {'n_estimators': 502, 'learning_rate': 0.029125476009263924, 'num_leaves': 76, 'max_depth': 9, 'min_child_samples': 17, 'min_split_gain': 0.8976301675989279, 'bagging_fraction': 0.8791484486691757, 'bagging_freq': 3, 'feature_fraction': 0.5697621490905044, 'lambda_l1': 1.0168354070508785e-07, 'lambda_l2': 0.2527557751635267}. Best is trial 43 with value: 3.1984861294014317.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-08 23:11:24,280] Trial 45 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-08 23:11:27,129] Trial 46 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-08 23:11:35,136] Trial 47 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-08 23:11:38,477] Trial 48 finished with value: 3.2659029445973573 and parameters: {'n_estimators': 610, 'learning_rate': 0.043646566075202696, 'num_leaves': 81, 'max_depth': 3, 'min_child_samples': 32, 'min_split_gain': 0.3821842571105083, 'bagging_fraction': 0.8414459162495658, 'bagging_freq': 3, 'feature_fraction': 0.5021506012879291, 'lambda_l1': 1.4695399944506195e-06, 'lambda_l2': 0.24777675710343183}. Best is trial 43 with value: 3.1984861294014317.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-08 23:11:43,775] Trial 49 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-08 23:11:49,994] Trial 50 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-08 23:11:55,834] Trial 51 finished with value: 3.193717596057708 and parameters: {'n_estimators': 505, 'learning_rate': 0.06113398589477586, 'num_leaves': 108, 'max_depth': 8, 'min_child_samples': 21, 'min_split_gain': 0.9593843611462717, 'bagging_fraction': 0.9152483905351124, 'bagging_freq': 2, 'feature_fraction': 0.5590895993494256, 'lambda_l1': 1.4524643925440167e-07, 'lambda_l2': 0.0010121055012505405}. Best is trial 51 with value: 3.193717596057708.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-08 23:12:01,278] Trial 52 finished with value: 3.202937958358017 and parameters: {'n_estimators': 358, 'learning_rate': 0.0548190030310385, 'num_leaves': 90, 'max_depth': 8, 'min_child_samples': 19, 'min_split_gain': 1.2339601145244625, 'bagging_fraction': 0.8956369583762119, 'bagging_freq': 2, 'feature_fraction': 0.551504224496641, 'lambda_l1': 1.5856101424203838e-07, 'lambda_l2': 0.0010846150708264182}. Best is trial 51 with value: 3.193717596057708.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# ...
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
#                   period       method  count     mae_f    rmse_f
# 0   validation_2024_2025      xgboost    660  2.386828  3.447733
# 1   validation_2024_2025     lightgbm    660  2.451067  3.479666
# 2   validation_2024_2025     catboost    660  2.343776  3.446326
# 3   validation_2024_2025     hrrr_raw    660  5.477361  6.266007
# 4   validation_2024_2025      gfs_raw    660  2.899120  4.128792
# 5              test_2026      xgboost    137  2.189738  3.085003
# 6              test_2026     lightgbm    137  2.327655  3.360767
# 7              test_2026     catboost    137  2.132711  3.084719
# 8              test_2026  ridge_stack    137  2.122623  3.170424
# 9              test_2026     hrrr_raw    137  5.923409  6.665741
# 10             test_2026      gfs_raw    137  3.230973  4.254676

# %% [markdown]
# ## Version Comparison

# %%
comparison_frames = []
for version, folder in [
    ("v1", PROJECT_ROOT / "data" / "calibration" / "station_stacking"),
    ("v2", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v2"),
    ("v3", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v3"),
]:
    path = folder / f"{STATION_ID}_year_split_scoreboard.csv"
    if path.exists():
        frame = pd.read_csv(path)
        frame["version"] = version
        comparison_frames.append(frame)

version_comparison = pd.concat(comparison_frames, ignore_index=True) if comparison_frames else pd.DataFrame()
if not version_comparison.empty:
    version_comparison = version_comparison.sort_values(["period", "mae_f", "version", "method"]).reset_index(drop=True)
version_comparison
# Out:
#                   period       method  count     mae_f    rmse_f version
# 0              test_2026  ridge_stack    137  2.122623  3.170424      v3
# 1              test_2026     catboost    137  2.132711  3.084719      v3
# 2              test_2026      xgboost    137  2.189738  3.085003      v3
# 3              test_2026     catboost    137  2.248778  3.374915      v2
# 4              test_2026  ridge_stack    137  2.259618  3.395940      v2
# 5              test_2026     lightgbm    137  2.327655  3.360767      v3
# 6              test_2026      xgboost    137  2.399165  3.437813      v2
# 7              test_2026  ridge_stack    103  2.526511  3.691661      v1
# 8              test_2026     lightgbm    137  2.542576  3.560398      v2
# 9              test_2026     catboost    103  2.625892  3.731759      v1
# 10             test_2026     lightgbm    103  2.691791  3.745604      v1
# 11             test_2026      xgboost    103  2.707634  3.913309      v1
# 12             test_2026      gfs_raw    137  3.230973  4.254676      v2
# 13             test_2026      gfs_raw    137  3.230973  4.254676      v3
# 14             test_2026      gfs_raw    103  3.292308  4.357120      v1
# 15             test_2026     hrrr_raw    137  5.923409  6.665741      v2
# 16             test_2026     hrrr_raw    137  5.923409  6.665741      v3
# 17             test_2026     hrrr_raw    103  6.387225  7.041360      v1
# 18  validation_2024_2025     lightgbm    623  2.264418  3.555268      v1
# 19  validation_2024_2025     catboost    660  2.343776  3.446326      v3
# 20  validation_2024_2025      xgboost    660  2.386828  3.447733      v3
# 21  validation_2024_2025     catboost    660  2.410967  3.571568      v2
# 22  validation_2024_2025     lightgbm    660  2.451067  3.479666      v3
# 23  validation_2024_2025      xgboost    623  2.554467  3.771995      v1
# 24  validation_2024_2025     catboost    623  2.833299  4.067342      v1
# 25  validation_2024_2025      gfs_raw    660  2.899120  4.128792      v2
# 26  validation_2024_2025      gfs_raw    660  2.899120  4.128792      v3
# 27  validation_2024_2025      gfs_raw    623  2.954097  4.206206      v1
# 28  validation_2024_2025     lightgbm    660  3.021274  4.165467      v2
# 29  validation_2024_2025      xgboost    660  3.116791  4.321197      v2
# 30  validation_2024_2025     hrrr_raw    660  5.477361  6.266007      v2
# 31  validation_2024_2025     hrrr_raw    660  5.477361  6.266007      v3
# 32  validation_2024_2025     hrrr_raw    623  5.564150  6.352240      v1

# %% [markdown]
# ## 2026 Weather Brackets

# %%
result.bracket_metrics
# Out:
#         method  count     mae_f    rmse_f  bracket_accuracy_pct
# 0      xgboost    137  2.189738  3.085003             30.656934
# 1     lightgbm    137  2.327655  3.360767             32.116788
# 2     catboost    137  2.132711  3.084719             35.766423
# 3  ridge_stack    137  2.122623  3.170424             35.766423
# 4     hrrr_raw    137  5.923409  6.665741              6.569343
# 5      gfs_raw    137  3.230973  4.254676             17.518248

# %%
import pandas as pd


def adjacent_brackets(bracket):
    if pd.isna(bracket):
        return []
    text = str(bracket).strip()
    if not text or "-" not in text:
        return []
    try:
        lower = int(text.split("-", 1)[0])
    except ValueError:
        return []
    return [
        f"{lower - 2}-{lower - 1}",
        f"{lower}-{lower + 1}",
        f"{lower + 2}-{lower + 3}",
    ]


bracket_3way = result.bracket_predictions.copy()

valid = bracket_3way["actual_bracket"].notna() & bracket_3way["predicted_bracket"].astype(str).str.strip().ne("")
bracket_3way = bracket_3way.loc[valid].copy()
bracket_3way["picked_brackets"] = bracket_3way["predicted_bracket"].map(adjacent_brackets)
bracket_3way["three_bracket_hit"] = bracket_3way.apply(
    lambda row: row["actual_bracket"] in row["picked_brackets"],
    axis=1,
)

three_bracket_accuracy = (
    bracket_3way
    .groupby("method", as_index=False)
    .agg(
        count=("three_bracket_hit", "size"),
        exact_bracket_accuracy_pct=("bracket_hit", lambda x: x.mean() * 100),
        three_bracket_accuracy_pct=("three_bracket_hit", lambda x: x.mean() * 100),
    )
    .sort_values("three_bracket_accuracy_pct", ascending=False)
)

three_bracket_accuracy
# Out:
#         method  count  exact_bracket_accuracy_pct  three_bracket_accuracy_pct
# 4  ridge_stack    137                   35.766423                   75.912409
# 5      xgboost    137                   30.656934                   75.182482
# 0     catboost    137                   35.766423                   74.452555
# 3     lightgbm    137                   32.116788                   72.992701
# 1      gfs_raw    137                   17.518248                   56.204380
# 2     hrrr_raw    137                    6.569343                   19.708029

# %%
preds = pd.concat(
    [
        result.validation_predictions.assign(period="validation_2024_2025"),
        result.test_predictions.assign(period="test_2026"),
    ],
    ignore_index=True,
)

preds["predicted_high_rounded_up_f"] = np.ceil(pd.to_numeric(preds["predicted_high_f"], errors="coerce"))
preds["within_1f_after_round_up"] = (
    pd.to_numeric(preds["actual_high_f"], errors="coerce") - preds["predicted_high_rounded_up_f"]
).abs().le(1)

within_1f_accuracy_by_period = (
    preds
    .dropna(subset=["actual_high_f", "predicted_high_rounded_up_f"])
    .groupby(["period", "method"], as_index=False)
    .agg(
        count=("within_1f_after_round_up", "size"),
        within_1f_count=("within_1f_after_round_up", "sum"),
        within_1f_accuracy_pct=("within_1f_after_round_up", lambda x: x.mean() * 100),
    )
    .sort_values(["period", "within_1f_accuracy_pct"], ascending=[True, False])
)

within_1f_accuracy_by_period
# Out:
#                   period       method  count  within_1f_count  \
# 4              test_2026  ridge_stack    137               72
# 0              test_2026     catboost    137               71
# 5              test_2026      xgboost    137               69
# 3              test_2026     lightgbm    137               66
# 1              test_2026      gfs_raw    137               46
# 2              test_2026     hrrr_raw    137               11
# 6   validation_2024_2025     catboost    660              326
# 10  validation_2024_2025      xgboost    660              306
# 9   validation_2024_2025     lightgbm    660              289
# 7   validation_2024_2025      gfs_raw    660              232
# 8   validation_2024_2025     hrrr_raw    660               80
#
#     within_1f_accuracy_pct
# 4                52.554745
# 0                51.824818
# 5                50.364964
# 3                48.175182
# 1                33.576642
# 2                 8.029197
# 6                49.393939
# 10               46.363636
# 9                43.787879
# 7                35.151515
# 8                12.121212

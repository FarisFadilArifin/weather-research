# %% [markdown]
# # Station Stacking v4 - KATL
#
# Wide HRRR/GFS same-day 11am notebook for `KATL`.
#
# This version keeps the v3 high-so-far features and adds SDK-backed precipitation features from HRRR/GFS forecast precipitation plus 11 AM METAR precipitation codes. Artifacts are written to `data/calibration/station_stacking_v4`.

# %%
from pathlib import Path
import sys
import warnings

warnings.filterwarnings("ignore", message="IProgress not found.*")
warnings.filterwarnings("ignore", message="Skipping features without any observed values.*")

PROJECT_ROOT = Path.cwd().resolve()
while not (PROJECT_ROOT / "src" / "calibration" / "station_stacking.py").exists():
    if PROJECT_ROOT.parent == PROJECT_ROOT:
        raise RuntimeError("Could not find project root containing src/calibration/station_stacking.py")
    PROJECT_ROOT = PROJECT_ROOT.parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

STATION_ID = "KATL"
FAST_MODE = False
OPTUNA_TRIALS = 100
STACK_OPTUNA_TRIALS = 50
OPTUNA_VERBOSE = True
PROJECT_ROOT
# Out:
# WindowsPath('D:/dev/weather-research')

# %%
from src.calibration.station_stacking import (
    StationStackingConfig,
    missing_model_dependencies,
    run_station_year_split_experiment,
)

# %% [markdown]
# ## V4 Feature Engineering
#
# Adds v2/v3 temperature features plus forecast and observed precipitation signals. Forecast precipitation comes from provider-prefixed SDK summary columns such as `gfs_forecast_precip_total_mm`, with `gfs_precip_amount` as a fallback for older caches.

# %%
import numpy as np
import pandas as pd
import src.calibration.station_stacking as station_stacking_module

V4_PROVIDERS = ("gfs", "hrrr")
V4_FEATURE_COLUMNS = [
    "v2_recent_heat_anomaly_f",
    "v2_recent_heat_momentum_f",
    "v2_morning_warmup_to_consensus_f",
    "v2_consensus_minus_7d_actual_f",
    "v2_spread_per_warmup_f",
    "v2_humidity_warmup_interaction",
    "v3_high_so_far_above_current_f",
    "v3_remaining_warmup_from_high_so_far_f",
    "v3_high_so_far_minus_lag_1d_f",
    "v3_high_so_far_minus_7d_actual_f",
    "v3_remaining_warmup_per_spread_f",
    "v3_humidity_remaining_warmup_interaction",
    "v4_forecast_precip_total_mean_mm",
    "v4_forecast_precip_total_max_mm",
    "v4_forecast_precip_total_spread_mm",
    "v4_forecast_precip_max_1h_mean_mm",
    "v4_forecast_precip_hours_mean",
    "v4_forecast_precip_intensity_mean",
    "v4_forecast_precip_intensity_max",
    "v4_any_forecast_precip",
    "v4_all_forecast_precip",
    "v4_observed_precip_any",
    "v4_observed_precip_recent_mm_est",
    "v4_forecast_total_minus_observed_recent_mm",
    "v4_forecast_observed_precip_match",
    "v4_forecast_wet_observed_dry",
    "v4_observed_wet_forecast_dry",
    "v4_precip_humidity_interaction",
    "v4_precip_remaining_warmup_interaction",
]


def _num(frame: pd.DataFrame, column: str) -> pd.Series:
    if column in frame:
        return pd.to_numeric(frame[column], errors="coerce")
    return pd.Series(np.nan, index=frame.index, dtype="float64")


def _bool_num(frame: pd.DataFrame, column: str) -> pd.Series:
    if column not in frame:
        return pd.Series(0, index=frame.index, dtype="int64")
    series = frame[column]
    if pd.api.types.is_bool_dtype(series):
        return series.fillna(False).astype(int)
    if pd.api.types.is_numeric_dtype(series):
        return pd.to_numeric(series, errors="coerce").fillna(0).gt(0).astype(int)
    return series.astype("string").str.lower().isin({"1", "true", "yes", "y"}).astype(int)


def _provider_series(frame: pd.DataFrame, provider: str, primary: str, fallback: str | None = None) -> pd.Series:
    primary_column = f"{provider}_{primary}"
    if primary_column in frame:
        return _num(frame, primary_column)
    if fallback is not None:
        return _num(frame, f"{provider}_{fallback}")
    return pd.Series(np.nan, index=frame.index, dtype="float64")


def _provider_matrix(frame: pd.DataFrame, primary: str, fallback: str | None = None) -> pd.DataFrame:
    return pd.DataFrame(
        {provider: _provider_series(frame, provider, primary, fallback) for provider in V4_PROVIDERS},
        index=frame.index,
    )


def add_v4_feature_engineering(frame: pd.DataFrame) -> pd.DataFrame:
    out = frame.copy()
    observed_temp = _num(out, "observed_temp_at_as_of_f")
    high_so_far = _num(out, "observed_high_temp_through_as_of_f")
    observed_humidity = _num(out, "observed_humidity_at_as_of")
    provider_mean = _num(out, "provider_mean_high_f")
    provider_spread = _num(out, "provider_spread_high_f")
    lag_1d = _num(out, "actual_high_lag_1d")
    roll_7d = _num(out, "actual_high_roll_7d_mean")
    roll_30d = _num(out, "actual_high_roll_30d_mean")

    warmup_to_consensus = provider_mean - observed_temp
    remaining_warmup = provider_mean - high_so_far
    out["v2_recent_heat_anomaly_f"] = lag_1d - roll_30d
    out["v2_recent_heat_momentum_f"] = roll_7d - roll_30d
    out["v2_morning_warmup_to_consensus_f"] = warmup_to_consensus
    out["v2_consensus_minus_7d_actual_f"] = provider_mean - roll_7d
    out["v2_spread_per_warmup_f"] = provider_spread / warmup_to_consensus.abs().clip(lower=1.0)
    out["v2_humidity_warmup_interaction"] = (observed_humidity / 100.0) * warmup_to_consensus
    out["v3_high_so_far_above_current_f"] = high_so_far - observed_temp
    out["v3_remaining_warmup_from_high_so_far_f"] = remaining_warmup
    out["v3_high_so_far_minus_lag_1d_f"] = high_so_far - lag_1d
    out["v3_high_so_far_minus_7d_actual_f"] = high_so_far - roll_7d
    out["v3_remaining_warmup_per_spread_f"] = remaining_warmup / provider_spread.abs().clip(lower=1.0)
    out["v3_humidity_remaining_warmup_interaction"] = (observed_humidity / 100.0) * remaining_warmup

    precip_total = _provider_matrix(out, "forecast_precip_total_mm", fallback="precip_amount")
    precip_max_1h = _provider_matrix(out, "forecast_precip_max_1h_mm")
    precip_hours = _provider_matrix(out, "forecast_precip_hours_count")
    precip_intensity = _provider_matrix(out, "forecast_precip_intensity_code")
    has_precip = _provider_matrix(out, "forecast_has_precip").fillna(0).clip(lower=0, upper=1)

    out["v4_forecast_precip_total_mean_mm"] = precip_total.mean(axis=1)
    out["v4_forecast_precip_total_max_mm"] = precip_total.max(axis=1)
    out["v4_forecast_precip_total_spread_mm"] = precip_total.max(axis=1) - precip_total.min(axis=1)
    out["v4_forecast_precip_max_1h_mean_mm"] = precip_max_1h.mean(axis=1)
    out["v4_forecast_precip_hours_mean"] = precip_hours.mean(axis=1)
    out["v4_forecast_precip_intensity_mean"] = precip_intensity.mean(axis=1)
    out["v4_forecast_precip_intensity_max"] = precip_intensity.max(axis=1)
    out["v4_any_forecast_precip"] = has_precip.max(axis=1).fillna(0).astype(int)
    out["v4_all_forecast_precip"] = has_precip.min(axis=1).fillna(0).astype(int)

    observed_any = (
        _bool_num(out, "observed_is_raining_at_as_of")
        | _bool_num(out, "observed_is_drizzle_at_as_of")
        | _bool_num(out, "observed_is_snowing_at_as_of")
    ).astype(int)
    observed_recent_mm = _num(out, "observed_precip_recent_at_as_of") * 25.4
    out["v4_observed_precip_any"] = observed_any
    out["v4_observed_precip_recent_mm_est"] = observed_recent_mm
    out["v4_forecast_total_minus_observed_recent_mm"] = out["v4_forecast_precip_total_mean_mm"] - observed_recent_mm
    out["v4_forecast_observed_precip_match"] = out["v4_any_forecast_precip"].eq(observed_any).astype(int)
    out["v4_forecast_wet_observed_dry"] = (out["v4_any_forecast_precip"].eq(1) & observed_any.eq(0)).astype(int)
    out["v4_observed_wet_forecast_dry"] = (observed_any.eq(1) & out["v4_any_forecast_precip"].eq(0)).astype(int)
    out["v4_precip_humidity_interaction"] = out["v4_forecast_precip_total_mean_mm"] * (observed_humidity / 100.0)
    out["v4_precip_remaining_warmup_interaction"] = out["v4_forecast_precip_total_mean_mm"] * remaining_warmup
    return out


if not hasattr(station_stacking_module, "_v4_original_build_station_wide_dataset"):
    station_stacking_module._v4_original_build_station_wide_dataset = station_stacking_module.build_station_wide_dataset


def build_station_wide_dataset_v4(*args, **kwargs):
    frame = station_stacking_module._v4_original_build_station_wide_dataset(*args, **kwargs)
    return add_v4_feature_engineering(frame)


station_stacking_module.build_station_wide_dataset = build_station_wide_dataset_v4
V4_FEATURE_COLUMNS
# Out:
# ['v2_recent_heat_anomaly_f',
#  'v2_recent_heat_momentum_f',
#  'v2_morning_warmup_to_consensus_f',
#  'v2_consensus_minus_7d_actual_f',
#  'v2_spread_per_warmup_f',
#  'v2_humidity_warmup_interaction',
#  'v3_high_so_far_above_current_f',
#  'v3_remaining_warmup_from_high_so_far_f',
#  'v3_high_so_far_minus_lag_1d_f',
#  'v3_high_so_far_minus_7d_actual_f',
#  'v3_remaining_warmup_per_spread_f',
#  'v3_humidity_remaining_warmup_interaction',
#  'v4_forecast_precip_total_mean_mm',
#  'v4_forecast_precip_total_max_mm',
#  'v4_forecast_precip_total_spread_mm',
#  'v4_forecast_precip_max_1h_mean_mm',
#  'v4_forecast_precip_hours_mean',
#  'v4_forecast_precip_intensity_mean',
#  'v4_forecast_precip_intensity_max',
#  'v4_any_forecast_precip',
#  'v4_all_forecast_precip',
#  'v4_observed_precip_any',
#  'v4_observed_precip_recent_mm_est',
#  'v4_forecast_total_minus_observed_recent_mm',
#  'v4_forecast_observed_precip_match',
#  'v4_forecast_wet_observed_dry',
#  'v4_observed_wet_forecast_dry',
#  'v4_precip_humidity_interaction',
#  'v4_precip_remaining_warmup_interaction']

# %% [markdown]
# ## Model Scores

# %%
missing_packages = missing_model_dependencies()
if missing_packages:
    raise ImportError(
        "Missing station-stacking ML packages: "
        + ", ".join(missing_packages)
        + ". Install them with: python -m pip install -r requirements.txt"
    )

config = StationStackingConfig(
    station_id=STATION_ID,
    project_root=PROJECT_ROOT,
    fast_mode=FAST_MODE,
    optuna_trials=OPTUNA_TRIALS,
    stack_optuna_trials=STACK_OPTUNA_TRIALS,
    optuna_verbose=OPTUNA_VERBOSE,
    output_dir=PROJECT_ROOT / "data" / "calibration" / "station_stacking_v4",
)
result = run_station_year_split_experiment(config)
result.scoreboard
# Out:
# [I 2026-06-09 06:27:22,125] A new study created in memory with name: no-name-47a5030b-94bb-4420-92df-f12d1ac267ef
# [I 2026-06-09 06:27:25,333] Trial 0 finished with value: 3.6728599266866873 and parameters: {'n_estimators': 799, 'learning_rate': 0.12369619597856178, 'max_depth': 6, 'min_child_weight': 2.385234757844707, 'gamma': 0.7800932022121826, 'subsample': 0.5779972601681014, 'colsample_bytree': 0.5290418060840998, 'reg_alpha': 0.6245760287469893, 'reg_lambda': 0.6677615511747083}. Best is trial 0 with value: 3.6728599266866873.
# [I 2026-06-09 06:30:16,874] Trial 1 finished with value: 3.4455097060542794 and parameters: {'n_estimators': 1440, 'learning_rate': 0.0032515743808034223, 'max_depth': 8, 'min_child_weight': 8.23143373099555, 'gamma': 1.0616955533913808, 'subsample': 0.5909124836035503, 'colsample_bytree': 0.5917022549267169, 'reg_alpha': 5.472429642032198e-06, 'reg_lambda': 0.2922905212920093}. Best is trial 1 with value: 3.4455097060542794.
# [I 2026-06-09 06:31:26,015] Trial 2 finished with value: 3.64240625452333 and parameters: {'n_estimators': 909, 'learning_rate': 0.009373695213782608, 'max_depth': 5, 'min_child_weight': 0.20940138873937433, 'gamma': 1.4607232426760908, 'subsample': 0.6831809216468459, 'colsample_bytree': 0.728034992108518, 'reg_alpha': 0.1165691561324743, 'reg_lambda': 0.008674832802525461}. Best is trial 1 with value: 3.4455097060542794.
# [I 2026-06-09 06:31:47,383] Trial 3 finished with value: 3.442185300400138 and parameters: {'n_estimators': 1067, 'learning_rate': 0.03045200113778571, 'max_depth': 1, 'min_child_weight': 2.5002240473339543, 'gamma': 0.8526206184364576, 'subsample': 0.5325257964926398, 'colsample_bytree': 0.9744427686266666, 'reg_alpha': 4.905556676028774, 'reg_lambda': 6.289771819487036}. Best is trial 3 with value: 3.442185300400138.
# [I 2026-06-09 06:33:20,076] Trial 4 finished with value: 3.6958546494465585 and parameters: {'n_estimators': 665, 'learning_rate': 0.004396056309201638, 'max_depth': 6, 'min_child_weight': 1.0299214204601976, 'gamma': 0.6101911742238941, 'subsample': 0.7475884550556351, 'colsample_bytree': 0.5171942605576092, 'reg_alpha': 1.527156759251193, 'reg_lambda': 0.016443693426189242}. Best is trial 3 with value: 3.442185300400138.
# [I 2026-06-09 06:33:54,339] Trial 5 pruned.
# [I 2026-06-09 06:34:04,580] Trial 6 finished with value: 3.445068084988678 and parameters: {'n_estimators': 1228, 'learning_rate': 0.11049889315270257, 'max_depth': 1, 'min_child_weight': 0.28246357083904894, 'gamma': 0.22613644455269033, 'subsample': 0.6626651653816322, 'colsample_bytree': 0.6943386448447411, 'reg_alpha': 2.7678419414850017e-06, 'reg_lambda': 7.838134236608707}. Best is trial 3 with value: 3.442185300400138.
# [I 2026-06-09 06:34:35,659] Trial 7 pruned.
# [I 2026-06-09 06:34:42,574] Trial 8 pruned.
# [I 2026-06-09 06:35:07,121] Trial 9 finished with value: 3.4273564798929943 and parameters: {'n_estimators': 1277, 'learning_rate': 0.01094730135557207, 'max_depth': 1, 'min_child_weight': 0.5194929407101735, 'gamma': 1.6259166101337352, 'subsample': 0.864803089169032, 'colsample_bytree': 0.8187787356776066, 'reg_alpha': 0.9658611176861268, 'reg_lambda': 0.16554793541373172}. Best is trial 9 with value: 3.4273564798929943.
# [I 2026-06-09 06:35:12,440] Trial 10 pruned.
# [I 2026-06-09 06:35:35,579] Trial 11 finished with value: 3.3882435374960806 and parameters: {'n_estimators': 1702, 'learning_rate': 0.029837101549845032, 'max_depth': 1, 'min_child_weight': 0.688588546457162, 'gamma': 2.1717813587820567, 'subsample': 0.8579328744354449, 'colsample_bytree': 0.9777833521699496, 'reg_alpha': 0.0029151336209232823, 'reg_lambda': 1.477313598872863}. Best is trial 11 with value: 3.3882435374960806.
# [I 2026-06-09 06:35:55,063] Trial 12 finished with value: 3.3929862452159893 and parameters: {'n_estimators': 1782, 'learning_rate': 0.02600143267644442, 'max_depth': 2, 'min_child_weight': 0.6243838727697036, 'gamma': 2.343526094439211, 'subsample': 0.8608706114175635, 'colsample_bytree': 0.85058129769688, 'reg_alpha': 0.0018527674778937963, 'reg_lambda': 1.0698131273173805}. Best is trial 11 with value: 3.3882435374960806.
# [I 2026-06-09 06:36:03,544] Trial 13 pruned.
# [I 2026-06-09 06:36:09,859] Trial 14 pruned.
# [I 2026-06-09 06:36:59,433] Trial 15 pruned.
# [I 2026-06-09 06:37:17,419] Trial 16 finished with value: 3.4228877143542205 and parameters: {'n_estimators': 1706, 'learning_rate': 0.018975065776796664, 'max_depth': 2, 'min_child_weight': 1.0719659807607782, 'gamma': 1.9306562372432885, 'subsample': 0.7751231143623358, 'colsample_bytree': 0.9474428417036006, 'reg_alpha': 3.154443500139828e-05, 'reg_lambda': 0.0011532639937455423}. Best is trial 11 with value: 3.3882435374960806.
# [I 2026-06-09 06:37:22,408] Trial 17 pruned.
# [I 2026-06-09 06:37:33,338] Trial 18 pruned.
# [I 2026-06-09 06:37:34,810] Trial 19 pruned.
# [I 2026-06-09 06:37:36,629] Trial 20 pruned.
# [I 2026-06-09 06:37:50,819] Trial 21 finished with value: 3.4077394895975868 and parameters: {'n_estimators': 1749, 'learning_rate': 0.01919376184542413, 'max_depth': 2, 'min_child_weight': 0.86058288801, 'gamma': 1.9021733398440623, 'subsample': 0.803253570592388, 'colsample_bytree': 0.952148763679415, 'reg_alpha': 2.7217278948374996e-05, 'reg_lambda': 0.0011754652184565305}. Best is trial 11 with value: 3.3882435374960806.
# [I 2026-06-09 06:37:58,632] Trial 22 pruned.
# [I 2026-06-09 06:38:04,479] Trial 23 pruned.
# [I 2026-06-09 06:38:15,916] Trial 24 pruned.
# [I 2026-06-09 06:38:32,491] Trial 25 pruned.
# [I 2026-06-09 06:38:34,919] Trial 26 pruned.
# [I 2026-06-09 06:38:43,417] Trial 27 pruned.
# [I 2026-06-09 06:38:45,949] Trial 28 pruned.
# [I 2026-06-09 06:38:47,776] Trial 29 pruned.
# [I 2026-06-09 06:38:52,031] Trial 30 pruned.
# [I 2026-06-09 06:39:00,810] Trial 31 pruned.
# [I 2026-06-09 06:39:34,165] Trial 32 pruned.
# [I 2026-06-09 06:39:40,498] Trial 33 pruned.
# [I 2026-06-09 06:39:56,827] Trial 34 pruned.
# [I 2026-06-09 06:40:13,945] Trial 35 pruned.
# [I 2026-06-09 06:40:30,487] Trial 36 pruned.
# [I 2026-06-09 06:40:40,181] Trial 37 finished with value: 3.3813405199779405 and parameters: {'n_estimators': 1370, 'learning_rate': 0.03741413888433877, 'max_depth': 1, 'min_child_weight': 1.901152049226878, 'gamma': 1.1091830915033194, 'subsample': 0.7988140769150139, 'colsample_bytree': 0.5567598685384798, 'reg_alpha': 6.966690307599097e-06, 'reg_lambda': 0.002359409654292211}. Best is trial 37 with value: 3.3813405199779405.
# [I 2026-06-09 06:41:13,082] Trial 38 finished with value: 3.3688023669310265 and parameters: {'n_estimators': 955, 'learning_rate': 0.025322308626875865, 'max_depth': 1, 'min_child_weight': 2.3182538685417473, 'gamma': 1.0446057118280205, 'subsample': 0.9501794076029684, 'colsample_bytree': 0.5540759349926228, 'reg_alpha': 5.317950940762494e-06, 'reg_lambda': 0.014035692059582244}. Best is trial 38 with value: 3.3688023669310265.
# [I 2026-06-09 06:41:26,527] Trial 39 pruned.
# [I 2026-06-09 06:41:30,335] Trial 40 pruned.
# [I 2026-06-09 06:41:42,044] Trial 41 pruned.
# [I 2026-06-09 06:41:50,381] Trial 42 pruned.
# [I 2026-06-09 06:42:14,473] Trial 43 finished with value: 3.3597313110490994 and parameters: {'n_estimators': 1334, 'learning_rate': 0.02385030042338497, 'max_depth': 1, 'min_child_weight': 3.0065440234673484, 'gamma': 0.962294998146025, 'subsample': 0.8394693638207555, 'colsample_bytree': 0.6777177115186539, 'reg_alpha': 8.199719679379686e-06, 'reg_lambda': 0.0058257949631250775}. Best is trial 43 with value: 3.3597313110490994.
# [I 2026-06-09 06:42:31,337] Trial 44 finished with value: 3.348171639495232 and parameters: {'n_estimators': 1346, 'learning_rate': 0.028655393715689485, 'max_depth': 1, 'min_child_weight': 3.665698605188336, 'gamma': 0.37036421417710574, 'subsample': 0.8437988948642238, 'colsample_bytree': 0.5472546377919848, 'reg_alpha': 7.855714241940035e-06, 'reg_lambda': 0.007239931010567532}. Best is trial 44 with value: 3.348171639495232.
# [I 2026-06-09 06:42:35,658] Trial 45 pruned.
# [I 2026-06-09 06:42:37,612] Trial 46 pruned.
# [I 2026-06-09 06:42:44,652] Trial 47 pruned.
# [I 2026-06-09 06:43:05,620] Trial 48 finished with value: 3.3867750735170725 and parameters: {'n_estimators': 1280, 'learning_rate': 0.029527164696272652, 'max_depth': 1, 'min_child_weight': 7.734864780832193, 'gamma': 0.029379344034370536, 'subsample': 0.9393677368397175, 'colsample_bytree': 0.5745077506848465, 'reg_alpha': 1.5807996999321126e-07, 'reg_lambda': 0.02833317453159168}. Best is trial 44 with value: 3.348171639495232.
# [I 2026-06-09 06:43:21,554] Trial 49 finished with value: 3.378966765102594 and parameters: {'n_estimators': 1278, 'learning_rate': 0.05152415662273589, 'max_depth': 1, 'min_child_weight': 8.861446989010737, 'gamma': 0.09536969792963172, 'subsample': 0.9682025443201522, 'colsample_bytree': 0.5773687637869077, 'reg_alpha': 1.8320098913489483e-07, 'reg_lambda': 0.03188646058775152}. Best is trial 44 with value: 3.348171639495232.
# [I 2026-06-09 06:43:30,316] Trial 50 pruned.
# [I 2026-06-09 06:43:56,408] Trial 51 finished with value: 3.3718799142376596 and parameters: {'n_estimators': 1279, 'learning_rate': 0.029054281902712083, 'max_depth': 1, 'min_child_weight': 9.263300297715043, 'gamma': 0.16407747320819896, 'subsample': 0.9390421735254725, 'colsample_bytree': 0.5728950699921006, 'reg_alpha': 1.2941840795198729e-07, 'reg_lambda': 0.030517164701910106}. Best is trial 44 with value: 3.348171639495232.
# [I 2026-06-09 06:44:04,024] Trial 52 pruned.
# [I 2026-06-09 06:44:09,314] Trial 53 pruned.
# [I 2026-06-09 06:44:20,730] Trial 54 finished with value: 3.348139953253961 and parameters: {'n_estimators': 1278, 'learning_rate': 0.03275965058789661, 'max_depth': 1, 'min_child_weight': 6.773668348179419, 'gamma': 1.0179548912891, 'subsample': 0.9259045379153384, 'colsample_bytree': 0.6296500498742514, 'reg_alpha': 8.888384536538117e-06, 'reg_lambda': 0.06071722415633734}. Best is trial 54 with value: 3.348139953253961.
# [I 2026-06-09 06:44:35,451] Trial 55 finished with value: 3.375259794096297 and parameters: {'n_estimators': 1273, 'learning_rate': 0.022983486738499485, 'max_depth': 2, 'min_child_weight': 6.2944321086480794, 'gamma': 0.004531474653865553, 'subsample': 0.9312635158596717, 'colsample_bytree': 0.7134550386146016, 'reg_alpha': 7.023929062729676e-08, 'reg_lambda': 0.07492743987080094}. Best is trial 54 with value: 3.348139953253961.
# [I 2026-06-09 06:44:45,093] Trial 56 pruned.
# [I 2026-06-09 06:44:51,177] Trial 57 pruned.
# [I 2026-06-09 06:44:56,945] Trial 58 pruned.
# [I 2026-06-09 06:46:49,098] Trial 59 pruned.
# [I 2026-06-09 06:47:02,345] Trial 60 pruned.
# [I 2026-06-09 06:47:32,395] Trial 61 finished with value: 3.3723056654079526 and parameters: {'n_estimators': 1257, 'learning_rate': 0.028302810468009927, 'max_depth': 1, 'min_child_weight': 9.511713135502717, 'gamma': 0.1136959927516317, 'subsample': 0.971564120329147, 'colsample_bytree': 0.5969425522050872, 'reg_alpha': 2.9734597943094337e-08, 'reg_lambda': 0.026455679769858523}. Best is trial 54 with value: 3.348139953253961.
# [I 2026-06-09 06:47:45,625] Trial 62 pruned.
# [I 2026-06-09 06:47:53,754] Trial 63 pruned.
# [I 2026-06-09 06:48:06,163] Trial 64 pruned.
# [I 2026-06-09 06:48:18,690] Trial 65 pruned.
# [I 2026-06-09 06:48:30,370] Trial 66 pruned.
# [I 2026-06-09 06:48:43,832] Trial 67 pruned.
# [I 2026-06-09 06:48:57,071] Trial 68 pruned.
# [I 2026-06-09 06:49:06,167] Trial 69 pruned.
# [I 2026-06-09 06:49:25,736] Trial 70 finished with value: 3.373322309349257 and parameters: {'n_estimators': 1079, 'learning_rate': 0.04420893590989049, 'max_depth': 1, 'min_child_weight': 4.5921770423798245, 'gamma': 1.0718671013758565, 'subsample': 0.9849689390576049, 'colsample_bytree': 0.5682273026219664, 'reg_alpha': 5.355869761993359e-05, 'reg_lambda': 0.17973742142462973}. Best is trial 54 with value: 3.348139953253961.
# [I 2026-06-09 06:49:33,008] Trial 71 pruned.
# [I 2026-06-09 06:49:41,715] Trial 72 pruned.
# [I 2026-06-09 06:49:49,679] Trial 73 pruned.
# [I 2026-06-09 06:49:56,874] Trial 74 pruned.
# [I 2026-06-09 06:50:10,407] Trial 75 pruned.
# [I 2026-06-09 06:50:32,620] Trial 76 finished with value: 3.369084548613317 and parameters: {'n_estimators': 1187, 'learning_rate': 0.027262751463896045, 'max_depth': 1, 'min_child_weight': 10.8312654900614, 'gamma': 0.27572003900772035, 'subsample': 0.8198357170644974, 'colsample_bytree': 0.5867463482688943, 'reg_alpha': 8.921058408208146e-07, 'reg_lambda': 0.13576063476307917}. Best is trial 54 with value: 3.348139953253961.
# [I 2026-06-09 06:51:00,918] Trial 77 finished with value: 3.3751866052806356 and parameters: {'n_estimators': 1179, 'learning_rate': 0.02649886918202135, 'max_depth': 1, 'min_child_weight': 10.997979922941134, 'gamma': 0.3195282548765102, 'subsample': 0.8132167634382454, 'colsample_bytree': 0.5621352467290497, 'reg_alpha': 3.72966548162082e-06, 'reg_lambda': 0.1315754985725382}. Best is trial 54 with value: 3.348139953253961.
# [I 2026-06-09 06:51:07,333] Trial 78 pruned.
# [I 2026-06-09 06:51:30,544] Trial 79 finished with value: 3.3640975245802887 and parameters: {'n_estimators': 1344, 'learning_rate': 0.029456220550291783, 'max_depth': 1, 'min_child_weight': 4.570509570347593, 'gamma': 1.1097086903385391, 'subsample': 0.8626381710724204, 'colsample_bytree': 0.6474920695719213, 'reg_alpha': 1.0210415645642643e-05, 'reg_lambda': 0.1917760698279984}. Best is trial 54 with value: 3.348139953253961.
# [I 2026-06-09 06:51:45,874] Trial 80 pruned.
# [I 2026-06-09 06:52:17,583] Trial 81 finished with value: 3.3677307385990565 and parameters: {'n_estimators': 1144, 'learning_rate': 0.025608855191020154, 'max_depth': 1, 'min_child_weight': 4.428932693851124, 'gamma': 1.170181852870324, 'subsample': 0.8263530347401843, 'colsample_bytree': 0.6187334918840189, 'reg_alpha': 8.45933063172784, 'reg_lambda': 0.3712478943688679}. Best is trial 54 with value: 3.348139953253961.
# [I 2026-06-09 06:52:36,606] Trial 82 finished with value: 3.3734024338819104 and parameters: {'n_estimators': 1461, 'learning_rate': 0.024902511387707486, 'max_depth': 1, 'min_child_weight': 9.618094337825367, 'gamma': 1.409078926022378, 'subsample': 0.7845807810980546, 'colsample_bytree': 0.6164216842234866, 'reg_alpha': 5.8035762398660635, 'reg_lambda': 0.4526891236718094}. Best is trial 54 with value: 3.348139953253961.
# [I 2026-06-09 06:53:00,978] Trial 83 finished with value: 3.368154792725711 and parameters: {'n_estimators': 1322, 'learning_rate': 0.028699760728376076, 'max_depth': 1, 'min_child_weight': 4.1172509318051045, 'gamma': 1.1510496108838146, 'subsample': 0.8221495503095642, 'colsample_bytree': 0.6328678460702202, 'reg_alpha': 0.042285197483134675, 'reg_lambda': 0.9566746547258117}. Best is trial 54 with value: 3.348139953253961.
# [I 2026-06-09 06:53:07,028] Trial 84 pruned.
# [I 2026-06-09 06:53:40,079] Trial 85 finished with value: 3.3736937805446336 and parameters: {'n_estimators': 1323, 'learning_rate': 0.01952308531873675, 'max_depth': 1, 'min_child_weight': 3.67922517957132, 'gamma': 1.7255223988022967, 'subsample': 0.8449311544708532, 'colsample_bytree': 0.6339200705178822, 'reg_alpha': 2.790010228997334, 'reg_lambda': 1.2017571009059167}. Best is trial 54 with value: 3.348139953253961.
# [I 2026-06-09 06:53:49,578] Trial 86 pruned.
# [I 2026-06-09 06:53:58,012] Trial 87 pruned.
# [I 2026-06-09 06:54:23,269] Trial 88 finished with value: 3.3594315783023037 and parameters: {'n_estimators': 1367, 'learning_rate': 0.026028675082444323, 'max_depth': 1, 'min_child_weight': 2.057034674753119, 'gamma': 0.829953775158967, 'subsample': 0.8278163088051949, 'colsample_bytree': 0.545965835066757, 'reg_alpha': 0.03064254307482554, 'reg_lambda': 2.550713093223276}. Best is trial 54 with value: 3.348139953253961.
# [I 2026-06-09 06:54:34,095] Trial 89 pruned.
# [I 2026-06-09 06:54:45,238] Trial 90 pruned.
# [I 2026-06-09 06:55:01,631] Trial 91 pruned.
# [I 2026-06-09 06:55:07,745] Trial 92 pruned.
# [I 2026-06-09 06:55:29,847] Trial 93 finished with value: 3.354375043595999 and parameters: {'n_estimators': 1295, 'learning_rate': 0.034696046895819815, 'max_depth': 1, 'min_child_weight': 5.501253126258275, 'gamma': 0.6743579033670184, 'subsample': 0.8278677850501065, 'colsample_bytree': 0.611022305082234, 'reg_alpha': 0.004188491172852384, 'reg_lambda': 7.2231124768240775}. Best is trial 54 with value: 3.348139953253961.
# [I 2026-06-09 06:55:46,311] Trial 94 pruned.
# [I 2026-06-09 06:55:54,829] Trial 95 pruned.
# [I 2026-06-09 06:56:08,770] Trial 96 pruned.
# [I 2026-06-09 06:56:34,603] Trial 97 finished with value: 3.3699701618400524 and parameters: {'n_estimators': 1239, 'learning_rate': 0.03194650066610012, 'max_depth': 1, 'min_child_weight': 4.395022113374273, 'gamma': 1.1500200902020457, 'subsample': 0.8256822324092042, 'colsample_bytree': 0.6438007764299494, 'reg_alpha': 0.004711493026220999, 'reg_lambda': 5.308071092617893}. Best is trial 54 with value: 3.348139953253961.
# [I 2026-06-09 06:57:01,324] Trial 98 pruned.
# [I 2026-06-09 06:57:29,061] Trial 99 pruned.
# [I 2026-06-09 06:57:29,068] A new study created in memory with name: no-name-0060b5b5-f014-44c3-810c-488b5abde4f8
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 06:57:41,099] Trial 0 finished with value: 3.6203280560471702 and parameters: {'n_estimators': 301, 'learning_rate': 0.03250177171527344, 'num_leaves': 37, 'max_depth': 4, 'min_child_samples': 52, 'min_split_gain': 1.7182749818971954, 'bagging_fraction': 0.8330451065490129, 'bagging_freq': 4, 'feature_fraction': 0.5145069122121801, 'lambda_l1': 0.04015454105555427, 'lambda_l2': 0.07175601133819473}. Best is trial 0 with value: 3.6203280560471702.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 06:59:36,967] Trial 1 finished with value: 3.6367946504771025 and parameters: {'n_estimators': 1620, 'learning_rate': 0.008116618171663207, 'num_leaves': 18, 'max_depth': 9, 'min_child_samples': 37, 'min_split_gain': 0.8099788960945193, 'bagging_fraction': 0.6580482355091044, 'bagging_freq': 1, 'feature_fraction': 0.9216123471148523, 'lambda_l1': 0.43697071238567825, 'lambda_l2': 36.7185332724254}. Best is trial 0 with value: 3.6203280560471702.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 06:59:50,199] Trial 2 finished with value: 3.5638391648676304 and parameters: {'n_estimators': 820, 'learning_rate': 0.1255359023925396, 'num_leaves': 116, 'max_depth': 8, 'min_child_samples': 17, 'min_split_gain': 1.7941971599630686, 'bagging_fraction': 0.6490017503443813, 'bagging_freq': 2, 'feature_fraction': 0.5025647745322285, 'lambda_l1': 0.0007741455782248723, 'lambda_l2': 0.1717169091593679}. Best is trial 2 with value: 3.5638391648676304.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 06:59:55,514] Trial 3 finished with value: 3.9809122155246808 and parameters: {'n_estimators': 1302, 'learning_rate': 0.13774020868800516, 'num_leaves': 233, 'max_depth': 10, 'min_child_samples': 81, 'min_split_gain': 0.2080378997095258, 'bagging_fraction': 0.5904572976289505, 'bagging_freq': 7, 'feature_fraction': 0.7059764916931793, 'lambda_l1': 0.6097531961875766, 'lambda_l2': 1.4405915859050216}. Best is trial 2 with value: 3.5638391648676304.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:00:20,487] Trial 4 finished with value: 3.6764517269579686 and parameters: {'n_estimators': 1287, 'learning_rate': 0.008816320113501107, 'num_leaves': 230, 'max_depth': 3, 'min_child_samples': 64, 'min_split_gain': 1.987144984788207, 'bagging_fraction': 0.8678635407535604, 'bagging_freq': 4, 'feature_fraction': 0.7803315847218675, 'lambda_l1': 5.026890229380336e-05, 'lambda_l2': 2.6067223030440956}. Best is trial 2 with value: 3.5638391648676304.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:00:26,683] Trial 5 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:00:35,271] Trial 6 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:00:38,391] Trial 7 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:00:39,744] Trial 8 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:00:57,610] Trial 9 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:03:08,681] Trial 10 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:03:11,955] Trial 11 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:03:25,047] Trial 12 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:03:31,415] Trial 13 finished with value: 3.6073810542662827 and parameters: {'n_estimators': 202, 'learning_rate': 0.07346206023751993, 'num_leaves': 143, 'max_depth': 5, 'min_child_samples': 31, 'min_split_gain': 1.2104408428825577, 'bagging_fraction': 0.7741904208705135, 'bagging_freq': 3, 'feature_fraction': 0.5881265628661578, 'lambda_l1': 8.093792632155067, 'lambda_l2': 0.0044763646224247715}. Best is trial 2 with value: 3.5638391648676304.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:03:37,189] Trial 14 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:03:40,731] Trial 15 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:03:46,687] Trial 16 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:03:50,909] Trial 17 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:03:53,487] Trial 18 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:04:00,835] Trial 19 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:04:14,422] Trial 20 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:04:31,674] Trial 21 finished with value: 3.610594498174338 and parameters: {'n_estimators': 258, 'learning_rate': 0.03395627752430977, 'num_leaves': 34, 'max_depth': 4, 'min_child_samples': 53, 'min_split_gain': 1.7458136264215665, 'bagging_fraction': 0.8259873578431348, 'bagging_freq': 3, 'feature_fraction': 0.5002659227910871, 'lambda_l1': 0.03868776077265334, 'lambda_l2': 0.11017283856439612}. Best is trial 2 with value: 3.5638391648676304.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:04:38,957] Trial 22 finished with value: 3.619692728242431 and parameters: {'n_estimators': 255, 'learning_rate': 0.04698311908948575, 'num_leaves': 43, 'max_depth': 3, 'min_child_samples': 64, 'min_split_gain': 1.3551481281304028, 'bagging_fraction': 0.924005977696853, 'bagging_freq': 3, 'feature_fraction': 0.5000474491752473, 'lambda_l1': 0.16860071226292062, 'lambda_l2': 1.102035155077091}. Best is trial 2 with value: 3.5638391648676304.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:04:43,172] Trial 23 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:04:49,342] Trial 24 finished with value: 3.5831789879078775 and parameters: {'n_estimators': 565, 'learning_rate': 0.041122363005332216, 'num_leaves': 112, 'max_depth': 3, 'min_child_samples': 44, 'min_split_gain': 1.6234475175255225, 'bagging_fraction': 0.6980160105441087, 'bagging_freq': 2, 'feature_fraction': 0.6347273542446452, 'lambda_l1': 0.07755904643630607, 'lambda_l2': 0.016543197961217875}. Best is trial 2 with value: 3.5638391648676304.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:04:57,833] Trial 25 finished with value: 3.565203124722899 and parameters: {'n_estimators': 690, 'learning_rate': 0.04662992636462373, 'num_leaves': 105, 'max_depth': 3, 'min_child_samples': 40, 'min_split_gain': 1.3566628652178114, 'bagging_fraction': 0.7038814391652481, 'bagging_freq': 2, 'feature_fraction': 0.7469711235036146, 'lambda_l1': 2.020666875513458, 'lambda_l2': 0.019423236523402262}. Best is trial 2 with value: 3.5638391648676304.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:05:04,202] Trial 26 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:05:10,791] Trial 27 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:05:20,390] Trial 28 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:05:41,776] Trial 29 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:05:43,879] Trial 30 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:05:44,790] Trial 31 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:05:51,556] Trial 32 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:06:00,204] Trial 33 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:06:06,285] Trial 34 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:06:08,775] Trial 35 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:06:23,535] Trial 36 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:06:38,065] Trial 37 finished with value: 3.602208888198283 and parameters: {'n_estimators': 816, 'learning_rate': 0.05258536350375635, 'num_leaves': 85, 'max_depth': 10, 'min_child_samples': 40, 'min_split_gain': 1.8930691223040454, 'bagging_fraction': 0.5355450406251157, 'bagging_freq': 1, 'feature_fraction': 0.6849414710924459, 'lambda_l1': 0.37381002495238813, 'lambda_l2': 0.20564032708934202}. Best is trial 2 with value: 3.5638391648676304.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:06:46,012] Trial 38 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:06:51,888] Trial 39 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:07:11,145] Trial 40 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:07:16,546] Trial 41 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:07:20,218] Trial 42 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:07:22,230] Trial 43 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:07:27,913] Trial 44 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:07:34,151] Trial 45 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:07:39,243] Trial 46 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:07:51,790] Trial 47 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:08:03,530] Trial 48 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:08:07,686] Trial 49 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:08:15,428] Trial 50 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:08:20,693] Trial 51 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:08:28,203] Trial 52 finished with value: 3.5764696523254207 and parameters: {'n_estimators': 228, 'learning_rate': 0.04648902786140132, 'num_leaves': 12, 'max_depth': 3, 'min_child_samples': 49, 'min_split_gain': 1.9313077125904297, 'bagging_fraction': 0.887100335993773, 'bagging_freq': 4, 'feature_fraction': 0.5172452048235607, 'lambda_l1': 0.01924443202014575, 'lambda_l2': 0.21503314390660505}. Best is trial 2 with value: 3.5638391648676304.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:08:31,697] Trial 53 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:08:34,566] Trial 54 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:08:37,835] Trial 55 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:08:41,007] Trial 56 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:08:43,174] Trial 57 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:08:44,307] Trial 58 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:08:49,770] Trial 59 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:08:58,721] Trial 60 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:09:14,500] Trial 61 finished with value: 3.591111178881058 and parameters: {'n_estimators': 518, 'learning_rate': 0.0314431078882002, 'num_leaves': 24, 'max_depth': 4, 'min_child_samples': 53, 'min_split_gain': 1.6620091766428886, 'bagging_fraction': 0.9077009884979694, 'bagging_freq': 3, 'feature_fraction': 0.5070755284033958, 'lambda_l1': 0.006187825227523546, 'lambda_l2': 0.10854402351573265}. Best is trial 2 with value: 3.5638391648676304.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:09:32,222] Trial 62 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:09:38,880] Trial 63 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:09:45,122] Trial 64 finished with value: 3.578256210275492 and parameters: {'n_estimators': 599, 'learning_rate': 0.038922371435409595, 'num_leaves': 7, 'max_depth': 3, 'min_child_samples': 42, 'min_split_gain': 1.9071922364576548, 'bagging_fraction': 0.7811741874940822, 'bagging_freq': 4, 'feature_fraction': 0.5127985659093498, 'lambda_l1': 0.00018599949392683886, 'lambda_l2': 0.3806708364662868}. Best is trial 2 with value: 3.5638391648676304.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:09:53,076] Trial 65 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:09:58,719] Trial 66 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:10:02,233] Trial 67 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:10:13,109] Trial 68 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:10:20,299] Trial 69 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:10:24,701] Trial 70 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:10:32,715] Trial 71 finished with value: 3.5701667335650864 and parameters: {'n_estimators': 759, 'learning_rate': 0.06364321191520031, 'num_leaves': 110, 'max_depth': 4, 'min_child_samples': 40, 'min_split_gain': 1.2697935252132524, 'bagging_fraction': 0.7799095037820364, 'bagging_freq': 3, 'feature_fraction': 0.6057841945090071, 'lambda_l1': 0.001194332439975441, 'lambda_l2': 0.03623871292198377}. Best is trial 2 with value: 3.5638391648676304.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:10:42,327] Trial 72 finished with value: 3.539701375429147 and parameters: {'n_estimators': 782, 'learning_rate': 0.06328209504468947, 'num_leaves': 123, 'max_depth': 4, 'min_child_samples': 39, 'min_split_gain': 1.4244097371108713, 'bagging_fraction': 0.8391159905405374, 'bagging_freq': 4, 'feature_fraction': 0.5629240277618761, 'lambda_l1': 0.0014079038935782588, 'lambda_l2': 0.03359171882057328}. Best is trial 72 with value: 3.539701375429147.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:10:48,545] Trial 73 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:10:53,318] Trial 74 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:10:58,638] Trial 75 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:11:03,146] Trial 76 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:11:15,154] Trial 77 finished with value: 3.5828183422911613 and parameters: {'n_estimators': 574, 'learning_rate': 0.032325426759492334, 'num_leaves': 217, 'max_depth': 3, 'min_child_samples': 44, 'min_split_gain': 1.3144853577637017, 'bagging_fraction': 0.7670746211760754, 'bagging_freq': 3, 'feature_fraction': 0.5772446089746179, 'lambda_l1': 0.0027650619402422036, 'lambda_l2': 0.06902537909382231}. Best is trial 72 with value: 3.539701375429147.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:11:22,422] Trial 78 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# ...
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
#                   period       method  count     mae_f    rmse_f
# 0   validation_2024_2025      xgboost    664  2.517809  3.609504
# 1   validation_2024_2025     lightgbm    664  2.615929  3.731918
# 2   validation_2024_2025     catboost    664  2.380098  3.518379
# 3   validation_2024_2025     hrrr_raw    664  3.630969  5.083107
# 4   validation_2024_2025      gfs_raw    664  3.466124  4.873332
# 5              test_2026      xgboost    133  1.982206  2.891394
# 6              test_2026     lightgbm    133  2.155591  3.147649
# 7              test_2026     catboost    133  2.047055  2.939812
# 8              test_2026  ridge_stack    133  1.815943  2.876923
# 9              test_2026     hrrr_raw    133  3.693741  5.210154
# 10             test_2026      gfs_raw    133  3.138464  4.599189

# %% [markdown]
# ## Rounded Within 1F Accuracy

# %%
preds = pd.concat(
    [
        result.validation_predictions.assign(period="validation_2024_2025"),
        result.test_predictions.assign(period="test_2026"),
    ],
    ignore_index=True,
)

predicted_high = pd.to_numeric(preds["predicted_high_f"], errors="coerce")
preds["predicted_high_rounded_f"] = np.floor(predicted_high + 0.5)
preds["within_1f_after_round"] = (
    pd.to_numeric(preds["actual_high_f"], errors="coerce") - preds["predicted_high_rounded_f"]
).abs().le(1)

within_1f_accuracy_by_period = (
    preds
    .dropna(subset=["actual_high_f", "predicted_high_rounded_f"])
    .groupby(["period", "method"], as_index=False)
    .agg(
        count=("within_1f_after_round", "size"),
        within_1f_count=("within_1f_after_round", "sum"),
        within_1f_accuracy_pct=("within_1f_after_round", lambda x: x.mean() * 100),
    )
    .sort_values(["period", "within_1f_accuracy_pct"], ascending=[True, False])
)

within_1f_accuracy_by_period
# Out:
#                   period       method  count  within_1f_count  \
# 4              test_2026  ridge_stack    133               76
# 0              test_2026     catboost    133               67
# 3              test_2026     lightgbm    133               67
# 5              test_2026      xgboost    133               66
# 1              test_2026      gfs_raw    133               43
# 2              test_2026     hrrr_raw    133               35
# 6   validation_2024_2025     catboost    664              309
# 10  validation_2024_2025      xgboost    664              266
# 9   validation_2024_2025     lightgbm    664              256
# 7   validation_2024_2025      gfs_raw    664              187
# 8   validation_2024_2025     hrrr_raw    664              186
#
#     within_1f_accuracy_pct
# 4                57.142857
# 0                50.375940
# 3                50.375940
# 5                49.624060
# 1                32.330827
# 2                26.315789
# 6                46.536145
# 10               40.060241
# 9                38.554217
# 7                28.162651
# 8                28.012048

# %% [markdown]
# ## Precipitation Feature Coverage

# %%
precip_columns = [column for column in result.features.columns if "precip" in column.lower()]
coverage = (
    result.features[precip_columns]
    .notna()
    .mean()
    .mul(100)
    .sort_values(ascending=False)
    .rename("coverage_pct")
    .reset_index()
    .rename(columns={"index": "feature"})
)
coverage
# Out:
#                                               feature  coverage_pct
# 0                      observed_precip_intensity_code    100.000000
# 1                   v4_forecast_observed_precip_match    100.000000
# 2                              v4_observed_precip_any    100.000000
# 3                              v4_all_forecast_precip    100.000000
# 4                              v4_any_forecast_precip    100.000000
# 5                           observed_precip_intensity    100.000000
# 6                    v4_forecast_precip_total_mean_mm     99.745418
# 7                     v4_forecast_precip_total_max_mm     99.745418
# 8                  v4_forecast_precip_total_spread_mm     99.745418
# 9              v4_precip_remaining_warmup_interaction     99.745418
# 10                  v4_forecast_precip_intensity_mean     99.745418
# 11                     v4_precip_humidity_interaction     99.745418
# 12                   v4_forecast_precip_intensity_max     99.745418
# 13                                  gfs_precip_amount     96.181263
# 14                 gfs_forecast_precip_intensity_code     96.181263
# 15                       gfs_forecast_precip_total_mm     96.181263
# 16                      gfs_forecast_precip_intensity     96.181263
# 17                            gfs_forecast_has_precip     96.181263
# 18                     hrrr_forecast_precip_intensity     95.468432
# 19                      hrrr_forecast_precip_total_mm     95.468432
# 20                                 hrrr_precip_amount     95.468432
# 21                hrrr_forecast_precip_intensity_code     95.468432
# 22                           hrrr_forecast_has_precip     95.468432
# 23                      gfs_hrrr_precip_amount_diff_f     91.904277
# 24                  gfs_hrrr_precip_amount_abs_diff_f     91.904277
# 25  gfs_hrrr_forecast_precip_intensity_code_abs_di...     91.904277
# 26           gfs_hrrr_forecast_precip_total_mm_diff_f     91.904277
# 27       gfs_hrrr_forecast_precip_total_mm_abs_diff_f     91.904277
# 28     gfs_hrrr_forecast_precip_intensity_code_diff_f     91.904277
# 29                    observed_precip_recent_at_as_of     75.254582
# 30                   v4_observed_precip_recent_mm_est     75.254582
# 31                      v4_forecast_precip_hours_mean      0.101833
# 32                  v4_forecast_precip_max_1h_mean_mm      0.101833
# 33                      gfs_forecast_precip_max_1h_mm      0.050916
# 34                    gfs_forecast_precip_hours_count      0.050916
# 35                   hrrr_forecast_precip_hours_count      0.050916
# 36                     hrrr_forecast_precip_max_1h_mm      0.050916
# 37    gfs_hrrr_forecast_precip_hours_count_abs_diff_f      0.000000
# 38        gfs_hrrr_forecast_precip_hours_count_diff_f      0.000000
# 39      gfs_hrrr_forecast_precip_max_1h_mm_abs_diff_f      0.000000
# 40          gfs_hrrr_forecast_precip_max_1h_mm_diff_f      0.000000

# %% [markdown]
# ## Version Comparison

# %%
comparison_frames = []
for version, folder in [
    ("v1", PROJECT_ROOT / "data" / "calibration" / "station_stacking"),
    ("v2", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v2"),
    ("v3", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v3"),
    ("v4", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v4"),
]:
    path = folder / f"{STATION_ID}_year_split_scoreboard.csv"
    if path.exists():
        frame = pd.read_csv(path)
        frame["version"] = version
        comparison_frames.append(frame)

version_comparison = pd.concat(comparison_frames, ignore_index=True) if comparison_frames else pd.DataFrame()
if not version_comparison.empty:
    version_comparison = version_comparison.sort_values(["period", "mae_f", "version", "method"]).reset_index(drop=True)
version_comparison
# Out:
#                   period       method  count     mae_f    rmse_f version
# 0              test_2026  ridge_stack    133  1.815943  2.876923      v4
# 1              test_2026  ridge_stack    133  1.841345  2.851669      v3
# 2              test_2026      xgboost    133  1.931785  2.868651      v3
# 3              test_2026  ridge_stack    133  1.937448  3.116074      v2
# 4              test_2026     catboost    133  1.977588  2.932487      v3
# 5              test_2026      xgboost    133  1.982206  2.891394      v4
# 6              test_2026     catboost    133  2.047055  2.939812      v4
# 7              test_2026  ridge_stack    109  2.125658  3.320448      v1
# 8              test_2026     lightgbm    133  2.142000  3.018886      v3
# 9              test_2026     lightgbm    133  2.155591  3.147649      v4
# 10             test_2026     catboost    133  2.262970  3.334402      v2
# 11             test_2026      xgboost    133  2.296218  3.322394      v2
# 12             test_2026     lightgbm    109  2.307444  3.402624      v1
# 13             test_2026     catboost    109  2.359257  3.458341      v1
# 14             test_2026     lightgbm    133  2.396837  3.292145      v2
# 15             test_2026      xgboost    109  2.501018  3.459863      v1
# 16             test_2026      gfs_raw    133  3.138464  4.599189      v2
# 17             test_2026      gfs_raw    133  3.138464  4.599189      v3
# 18             test_2026      gfs_raw    133  3.138464  4.599189      v4
# 19             test_2026      gfs_raw    109  3.448213  4.976408      v1
# 20             test_2026     hrrr_raw    133  3.693741  5.210154      v2
# 21             test_2026     hrrr_raw    133  3.693741  5.210154      v3
# 22             test_2026     hrrr_raw    133  3.693741  5.210154      v4
# 23             test_2026     hrrr_raw    109  4.110563  5.638604      v1
# 24  validation_2024_2025     catboost    664  2.258910  3.456403      v3
# 25  validation_2024_2025     catboost    664  2.380098  3.518379      v4
# 26  validation_2024_2025      xgboost    664  2.450058  3.553687      v3
# 27  validation_2024_2025      xgboost    664  2.517809  3.609504      v4
# 28  validation_2024_2025     lightgbm    664  2.521801  3.646919      v3
# 29  validation_2024_2025     catboost    541  2.546951  3.861493      v1
# 30  validation_2024_2025     catboost    664  2.594471  3.742167      v2
# 31  validation_2024_2025     lightgbm    664  2.615929  3.731918      v4
# 32  validation_2024_2025     lightgbm    541  2.702392  3.895986      v1
# 33  validation_2024_2025     lightgbm    664  2.805702  3.927142      v2
# 34  validation_2024_2025      xgboost    541  3.003893  4.167687      v1
# 35  validation_2024_2025      xgboost    664  3.113831  4.209634      v2
# 36  validation_2024_2025      gfs_raw    664  3.466124  4.873332      v2
# 37  validation_2024_2025      gfs_raw    664  3.466124  4.873332      v3
# 38  validation_2024_2025      gfs_raw    664  3.466124  4.873332      v4
# 39  validation_2024_2025      gfs_raw    541  3.557627  5.060559      v1
# 40  validation_2024_2025     hrrr_raw    664  3.630969  5.083107      v2
# 41  validation_2024_2025     hrrr_raw    664  3.630969  5.083107      v3
# 42  validation_2024_2025     hrrr_raw    664  3.630969  5.083107      v4
# 43  validation_2024_2025     hrrr_raw    541  4.010898  5.487445      v1

# %% [markdown]
# ## 2026 Weather Brackets

# %%
result.bracket_metrics
# Out:
#         method  count     mae_f    rmse_f  bracket_accuracy_pct
# 0      xgboost    133  1.982206  2.891394             36.090226
# 1     lightgbm    133  2.155591  3.147649             35.338346
# 2     catboost    133  2.047055  2.939812             32.330827
# 3  ridge_stack    133  1.815943  2.876923             44.360902
# 4     hrrr_raw    133  3.693741  5.210154             18.796992
# 5      gfs_raw    133  3.138464  4.599189             21.804511

# %%
import pandas as pd


def adjacent_brackets(bracket):
    if pd.isna(bracket):
        return []
    text = str(bracket).strip()
    if not text or "-" not in text:
        return []
    try:
        lower = int(text.split("-", 1)[0])
    except ValueError:
        return []
    return [
        f"{lower - 2}-{lower - 1}",
        f"{lower}-{lower + 1}",
        f"{lower + 2}-{lower + 3}",
    ]


bracket_3way = result.bracket_predictions.copy()

valid = bracket_3way["actual_bracket"].notna() & bracket_3way["predicted_bracket"].astype(str).str.strip().ne("")
bracket_3way = bracket_3way.loc[valid].copy()
bracket_3way["picked_brackets"] = bracket_3way["predicted_bracket"].map(adjacent_brackets)
bracket_3way["three_bracket_hit"] = bracket_3way.apply(
    lambda row: row["actual_bracket"] in row["picked_brackets"],
    axis=1,
)

three_bracket_accuracy = (
    bracket_3way
    .groupby("method", as_index=False)
    .agg(
        count=("three_bracket_hit", "size"),
        exact_bracket_accuracy_pct=("bracket_hit", lambda x: x.mean() * 100),
        three_bracket_accuracy_pct=("three_bracket_hit", lambda x: x.mean() * 100),
    )
    .sort_values("three_bracket_accuracy_pct", ascending=False)
)

three_bracket_accuracy
# Out:
#         method  count  exact_bracket_accuracy_pct  three_bracket_accuracy_pct
# 4  ridge_stack    133                   44.360902                   84.962406
# 5      xgboost    133                   36.090226                   82.706767
# 0     catboost    133                   32.330827                   78.195489
# 3     lightgbm    133                   35.338346                   75.939850
# 1      gfs_raw    133                   21.804511                   60.902256
# 2     hrrr_raw    133                   18.796992                   54.135338

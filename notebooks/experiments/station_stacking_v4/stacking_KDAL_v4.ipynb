# %% [markdown]
# # Station Stacking v4 - KDAL
#
# Wide HRRR/GFS same-day 11am notebook for `KDAL`.
#
# This version keeps the v3 high-so-far features and adds SDK-backed precipitation features from HRRR/GFS forecast precipitation plus 11 AM METAR precipitation codes. Artifacts are written to `data/calibration/station_stacking_v4`.

# %%
from pathlib import Path
import sys
import warnings

warnings.filterwarnings("ignore", message="IProgress not found.*")
warnings.filterwarnings("ignore", message="Skipping features without any observed values.*")

PROJECT_ROOT = Path.cwd().resolve()
while not (PROJECT_ROOT / "src" / "calibration" / "station_stacking.py").exists():
    if PROJECT_ROOT.parent == PROJECT_ROOT:
        raise RuntimeError("Could not find project root containing src/calibration/station_stacking.py")
    PROJECT_ROOT = PROJECT_ROOT.parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

STATION_ID = "KDAL"
FAST_MODE = False
OPTUNA_TRIALS = 100
STACK_OPTUNA_TRIALS = 50
OPTUNA_VERBOSE = True
PROJECT_ROOT
# Out:
# WindowsPath('D:/dev/weather-research')

# %%
from src.calibration.station_stacking import (
    StationStackingConfig,
    missing_model_dependencies,
    run_station_year_split_experiment,
)

# %% [markdown]
# ## V4 Feature Engineering
#
# Adds v2/v3 temperature features plus forecast and observed precipitation signals. Forecast precipitation comes from provider-prefixed SDK summary columns such as `gfs_forecast_precip_total_mm`, with `gfs_precip_amount` as a fallback for older caches.

# %%
import numpy as np
import pandas as pd
import src.calibration.station_stacking as station_stacking_module

V4_PROVIDERS = ("gfs", "hrrr")
V4_FEATURE_COLUMNS = [
    "v2_recent_heat_anomaly_f",
    "v2_recent_heat_momentum_f",
    "v2_morning_warmup_to_consensus_f",
    "v2_consensus_minus_7d_actual_f",
    "v2_spread_per_warmup_f",
    "v2_humidity_warmup_interaction",
    "v3_high_so_far_above_current_f",
    "v3_remaining_warmup_from_high_so_far_f",
    "v3_high_so_far_minus_lag_1d_f",
    "v3_high_so_far_minus_7d_actual_f",
    "v3_remaining_warmup_per_spread_f",
    "v3_humidity_remaining_warmup_interaction",
    "v4_forecast_precip_total_mean_mm",
    "v4_forecast_precip_total_max_mm",
    "v4_forecast_precip_total_spread_mm",
    "v4_forecast_precip_max_1h_mean_mm",
    "v4_forecast_precip_hours_mean",
    "v4_forecast_precip_intensity_mean",
    "v4_forecast_precip_intensity_max",
    "v4_any_forecast_precip",
    "v4_all_forecast_precip",
    "v4_observed_precip_any",
    "v4_observed_precip_recent_mm_est",
    "v4_forecast_total_minus_observed_recent_mm",
    "v4_forecast_observed_precip_match",
    "v4_forecast_wet_observed_dry",
    "v4_observed_wet_forecast_dry",
    "v4_precip_humidity_interaction",
    "v4_precip_remaining_warmup_interaction",
]


def _num(frame: pd.DataFrame, column: str) -> pd.Series:
    if column in frame:
        return pd.to_numeric(frame[column], errors="coerce")
    return pd.Series(np.nan, index=frame.index, dtype="float64")


def _bool_num(frame: pd.DataFrame, column: str) -> pd.Series:
    if column not in frame:
        return pd.Series(0, index=frame.index, dtype="int64")
    series = frame[column]
    if pd.api.types.is_bool_dtype(series):
        return series.fillna(False).astype(int)
    if pd.api.types.is_numeric_dtype(series):
        return pd.to_numeric(series, errors="coerce").fillna(0).gt(0).astype(int)
    return series.astype("string").str.lower().isin({"1", "true", "yes", "y"}).astype(int)


def _provider_series(frame: pd.DataFrame, provider: str, primary: str, fallback: str | None = None) -> pd.Series:
    primary_column = f"{provider}_{primary}"
    if primary_column in frame:
        return _num(frame, primary_column)
    if fallback is not None:
        return _num(frame, f"{provider}_{fallback}")
    return pd.Series(np.nan, index=frame.index, dtype="float64")


def _provider_matrix(frame: pd.DataFrame, primary: str, fallback: str | None = None) -> pd.DataFrame:
    return pd.DataFrame(
        {provider: _provider_series(frame, provider, primary, fallback) for provider in V4_PROVIDERS},
        index=frame.index,
    )


def add_v4_feature_engineering(frame: pd.DataFrame) -> pd.DataFrame:
    out = frame.copy()
    observed_temp = _num(out, "observed_temp_at_as_of_f")
    high_so_far = _num(out, "observed_high_temp_through_as_of_f")
    observed_humidity = _num(out, "observed_humidity_at_as_of")
    provider_mean = _num(out, "provider_mean_high_f")
    provider_spread = _num(out, "provider_spread_high_f")
    lag_1d = _num(out, "actual_high_lag_1d")
    roll_7d = _num(out, "actual_high_roll_7d_mean")
    roll_30d = _num(out, "actual_high_roll_30d_mean")

    warmup_to_consensus = provider_mean - observed_temp
    remaining_warmup = provider_mean - high_so_far
    out["v2_recent_heat_anomaly_f"] = lag_1d - roll_30d
    out["v2_recent_heat_momentum_f"] = roll_7d - roll_30d
    out["v2_morning_warmup_to_consensus_f"] = warmup_to_consensus
    out["v2_consensus_minus_7d_actual_f"] = provider_mean - roll_7d
    out["v2_spread_per_warmup_f"] = provider_spread / warmup_to_consensus.abs().clip(lower=1.0)
    out["v2_humidity_warmup_interaction"] = (observed_humidity / 100.0) * warmup_to_consensus
    out["v3_high_so_far_above_current_f"] = high_so_far - observed_temp
    out["v3_remaining_warmup_from_high_so_far_f"] = remaining_warmup
    out["v3_high_so_far_minus_lag_1d_f"] = high_so_far - lag_1d
    out["v3_high_so_far_minus_7d_actual_f"] = high_so_far - roll_7d
    out["v3_remaining_warmup_per_spread_f"] = remaining_warmup / provider_spread.abs().clip(lower=1.0)
    out["v3_humidity_remaining_warmup_interaction"] = (observed_humidity / 100.0) * remaining_warmup

    precip_total = _provider_matrix(out, "forecast_precip_total_mm", fallback="precip_amount")
    precip_max_1h = _provider_matrix(out, "forecast_precip_max_1h_mm")
    precip_hours = _provider_matrix(out, "forecast_precip_hours_count")
    precip_intensity = _provider_matrix(out, "forecast_precip_intensity_code")
    has_precip = _provider_matrix(out, "forecast_has_precip").fillna(0).clip(lower=0, upper=1)

    out["v4_forecast_precip_total_mean_mm"] = precip_total.mean(axis=1)
    out["v4_forecast_precip_total_max_mm"] = precip_total.max(axis=1)
    out["v4_forecast_precip_total_spread_mm"] = precip_total.max(axis=1) - precip_total.min(axis=1)
    out["v4_forecast_precip_max_1h_mean_mm"] = precip_max_1h.mean(axis=1)
    out["v4_forecast_precip_hours_mean"] = precip_hours.mean(axis=1)
    out["v4_forecast_precip_intensity_mean"] = precip_intensity.mean(axis=1)
    out["v4_forecast_precip_intensity_max"] = precip_intensity.max(axis=1)
    out["v4_any_forecast_precip"] = has_precip.max(axis=1).fillna(0).astype(int)
    out["v4_all_forecast_precip"] = has_precip.min(axis=1).fillna(0).astype(int)

    observed_any = (
        _bool_num(out, "observed_is_raining_at_as_of")
        | _bool_num(out, "observed_is_drizzle_at_as_of")
        | _bool_num(out, "observed_is_snowing_at_as_of")
    ).astype(int)
    observed_recent_mm = _num(out, "observed_precip_recent_at_as_of") * 25.4
    out["v4_observed_precip_any"] = observed_any
    out["v4_observed_precip_recent_mm_est"] = observed_recent_mm
    out["v4_forecast_total_minus_observed_recent_mm"] = out["v4_forecast_precip_total_mean_mm"] - observed_recent_mm
    out["v4_forecast_observed_precip_match"] = out["v4_any_forecast_precip"].eq(observed_any).astype(int)
    out["v4_forecast_wet_observed_dry"] = (out["v4_any_forecast_precip"].eq(1) & observed_any.eq(0)).astype(int)
    out["v4_observed_wet_forecast_dry"] = (observed_any.eq(1) & out["v4_any_forecast_precip"].eq(0)).astype(int)
    out["v4_precip_humidity_interaction"] = out["v4_forecast_precip_total_mean_mm"] * (observed_humidity / 100.0)
    out["v4_precip_remaining_warmup_interaction"] = out["v4_forecast_precip_total_mean_mm"] * remaining_warmup
    return out


if not hasattr(station_stacking_module, "_v4_original_build_station_wide_dataset"):
    station_stacking_module._v4_original_build_station_wide_dataset = station_stacking_module.build_station_wide_dataset


def build_station_wide_dataset_v4(*args, **kwargs):
    frame = station_stacking_module._v4_original_build_station_wide_dataset(*args, **kwargs)
    return add_v4_feature_engineering(frame)


station_stacking_module.build_station_wide_dataset = build_station_wide_dataset_v4
V4_FEATURE_COLUMNS
# Out:
# ['v2_recent_heat_anomaly_f',
#  'v2_recent_heat_momentum_f',
#  'v2_morning_warmup_to_consensus_f',
#  'v2_consensus_minus_7d_actual_f',
#  'v2_spread_per_warmup_f',
#  'v2_humidity_warmup_interaction',
#  'v3_high_so_far_above_current_f',
#  'v3_remaining_warmup_from_high_so_far_f',
#  'v3_high_so_far_minus_lag_1d_f',
#  'v3_high_so_far_minus_7d_actual_f',
#  'v3_remaining_warmup_per_spread_f',
#  'v3_humidity_remaining_warmup_interaction',
#  'v4_forecast_precip_total_mean_mm',
#  'v4_forecast_precip_total_max_mm',
#  'v4_forecast_precip_total_spread_mm',
#  'v4_forecast_precip_max_1h_mean_mm',
#  'v4_forecast_precip_hours_mean',
#  'v4_forecast_precip_intensity_mean',
#  'v4_forecast_precip_intensity_max',
#  'v4_any_forecast_precip',
#  'v4_all_forecast_precip',
#  'v4_observed_precip_any',
#  'v4_observed_precip_recent_mm_est',
#  'v4_forecast_total_minus_observed_recent_mm',
#  'v4_forecast_observed_precip_match',
#  'v4_forecast_wet_observed_dry',
#  'v4_observed_wet_forecast_dry',
#  'v4_precip_humidity_interaction',
#  'v4_precip_remaining_warmup_interaction']

# %% [markdown]
# ## Model Scores

# %%
missing_packages = missing_model_dependencies()
if missing_packages:
    raise ImportError(
        "Missing station-stacking ML packages: "
        + ", ".join(missing_packages)
        + ". Install them with: python -m pip install -r requirements.txt"
    )

config = StationStackingConfig(
    station_id=STATION_ID,
    project_root=PROJECT_ROOT,
    fast_mode=FAST_MODE,
    optuna_trials=OPTUNA_TRIALS,
    stack_optuna_trials=STACK_OPTUNA_TRIALS,
    optuna_verbose=OPTUNA_VERBOSE,
    output_dir=PROJECT_ROOT / "data" / "calibration" / "station_stacking_v4",
)
result = run_station_year_split_experiment(config)
result.scoreboard
# Out:
# [I 2026-06-09 06:27:42,897] A new study created in memory with name: no-name-124ce9bd-7a19-4133-8a52-8d26dc4a54dd
# [I 2026-06-09 06:27:55,985] Trial 0 finished with value: 3.5338968151788137 and parameters: {'n_estimators': 799, 'learning_rate': 0.12369619597856178, 'max_depth': 6, 'min_child_weight': 2.385234757844707, 'gamma': 0.7800932022121826, 'subsample': 0.5779972601681014, 'colsample_bytree': 0.5290418060840998, 'reg_alpha': 0.6245760287469893, 'reg_lambda': 0.6677615511747083}. Best is trial 0 with value: 3.5338968151788137.
# [I 2026-06-09 06:31:06,323] Trial 1 finished with value: 3.243628216845896 and parameters: {'n_estimators': 1440, 'learning_rate': 0.0032515743808034223, 'max_depth': 8, 'min_child_weight': 8.23143373099555, 'gamma': 1.0616955533913808, 'subsample': 0.5909124836035503, 'colsample_bytree': 0.5917022549267169, 'reg_alpha': 5.472429642032198e-06, 'reg_lambda': 0.2922905212920093}. Best is trial 1 with value: 3.243628216845896.
# [I 2026-06-09 06:31:41,680] Trial 2 finished with value: 4.215746061611399 and parameters: {'n_estimators': 909, 'learning_rate': 0.009373695213782608, 'max_depth': 5, 'min_child_weight': 0.20940138873937433, 'gamma': 1.4607232426760908, 'subsample': 0.6831809216468459, 'colsample_bytree': 0.728034992108518, 'reg_alpha': 0.1165691561324743, 'reg_lambda': 0.008674832802525461}. Best is trial 1 with value: 3.243628216845896.
# [I 2026-06-09 06:32:01,419] Trial 3 finished with value: 3.1930496641818866 and parameters: {'n_estimators': 1067, 'learning_rate': 0.03045200113778571, 'max_depth': 1, 'min_child_weight': 2.5002240473339543, 'gamma': 0.8526206184364576, 'subsample': 0.5325257964926398, 'colsample_bytree': 0.9744427686266666, 'reg_alpha': 4.905556676028774, 'reg_lambda': 6.289771819487036}. Best is trial 3 with value: 3.1930496641818866.
# [I 2026-06-09 06:33:35,759] Trial 4 finished with value: 3.712022792050062 and parameters: {'n_estimators': 665, 'learning_rate': 0.004396056309201638, 'max_depth': 6, 'min_child_weight': 1.0299214204601976, 'gamma': 0.6101911742238941, 'subsample': 0.7475884550556351, 'colsample_bytree': 0.5171942605576092, 'reg_alpha': 1.527156759251193, 'reg_lambda': 0.016443693426189242}. Best is trial 3 with value: 3.1930496641818866.
# [I 2026-06-09 06:34:15,672] Trial 5 pruned.
# [I 2026-06-09 06:34:24,714] Trial 6 finished with value: 3.191111721336921 and parameters: {'n_estimators': 1228, 'learning_rate': 0.11049889315270257, 'max_depth': 1, 'min_child_weight': 0.28246357083904894, 'gamma': 0.22613644455269033, 'subsample': 0.6626651653816322, 'colsample_bytree': 0.6943386448447411, 'reg_alpha': 2.7678419414850017e-06, 'reg_lambda': 7.838134236608707}. Best is trial 6 with value: 3.191111721336921.
# [I 2026-06-09 06:34:45,295] Trial 7 pruned.
# [I 2026-06-09 06:34:50,938] Trial 8 finished with value: 3.3120470609809063 and parameters: {'n_estimators': 90, 'learning_rate': 0.07287285110476487, 'max_depth': 6, 'min_child_weight': 4.758470274910409, 'gamma': 3.8563517334297286, 'subsample': 0.5370223258670452, 'colsample_bytree': 0.6792328642721364, 'reg_alpha': 1.1036250149900698e-07, 'reg_lambda': 11.368341439732731}. Best is trial 6 with value: 3.191111721336921.
# [I 2026-06-09 06:35:17,351] Trial 9 finished with value: 3.230841672332662 and parameters: {'n_estimators': 1277, 'learning_rate': 0.01094730135557207, 'max_depth': 1, 'min_child_weight': 0.5194929407101735, 'gamma': 1.6259166101337352, 'subsample': 0.864803089169032, 'colsample_bytree': 0.8187787356776066, 'reg_alpha': 0.9658611176861268, 'reg_lambda': 0.16554793541373172}. Best is trial 6 with value: 3.191111721336921.
# [I 2026-06-09 06:35:28,581] Trial 10 finished with value: 3.1962541523706682 and parameters: {'n_estimators': 1929, 'learning_rate': 0.04129736987626858, 'max_depth': 3, 'min_child_weight': 13.97101765312176, 'gamma': 2.828065453407016, 'subsample': 0.7990877054953648, 'colsample_bytree': 0.7113756625097372, 'reg_alpha': 0.00028185317575043605, 'reg_lambda': 0.0023664089613270804}. Best is trial 6 with value: 3.191111721336921.
# [I 2026-06-09 06:35:44,732] Trial 11 finished with value: 3.2180252377843317 and parameters: {'n_estimators': 1673, 'learning_rate': 0.03712646252231192, 'max_depth': 1, 'min_child_weight': 0.49574099861479426, 'gamma': 0.15689602475459427, 'subsample': 0.6712579968688783, 'colsample_bytree': 0.9677809380407124, 'reg_alpha': 0.0010917426334276603, 'reg_lambda': 2.601507805065152}. Best is trial 6 with value: 3.191111721336921.
# [I 2026-06-09 06:36:24,042] Trial 12 finished with value: 3.176218843975776 and parameters: {'n_estimators': 1159, 'learning_rate': 0.02600143267644442, 'max_depth': 2, 'min_child_weight': 0.10885718775492667, 'gamma': 2.343526094439211, 'subsample': 0.6454016179244165, 'colsample_bytree': 0.8170724374146281, 'reg_alpha': 2.0057322817130592e-08, 'reg_lambda': 45.5545248514823}. Best is trial 12 with value: 3.176218843975776.
# [I 2026-06-09 06:36:27,612] Trial 13 pruned.
# [I 2026-06-09 06:36:30,473] Trial 14 pruned.
# [I 2026-06-09 06:37:01,017] Trial 15 finished with value: 3.1520378177372397 and parameters: {'n_estimators': 1633, 'learning_rate': 0.023845460367996143, 'max_depth': 2, 'min_child_weight': 0.28232739842208715, 'gamma': 2.24274028445038, 'subsample': 0.6207387910758648, 'colsample_bytree': 0.6098562926184794, 'reg_alpha': 1.1913068421542029e-08, 'reg_lambda': 39.09721369856506}. Best is trial 15 with value: 3.1520378177372397.
# [I 2026-06-09 06:37:34,050] Trial 16 finished with value: 3.126136746279345 and parameters: {'n_estimators': 1711, 'learning_rate': 0.01831067298627652, 'max_depth': 2, 'min_child_weight': 0.4611310130818257, 'gamma': 2.408281850813539, 'subsample': 0.6084030728233546, 'colsample_bytree': 0.6185040775362227, 'reg_alpha': 1.7578071939504844e-08, 'reg_lambda': 27.8562448265403}. Best is trial 16 with value: 3.126136746279345.
# [I 2026-06-09 06:38:13,955] Trial 17 finished with value: 3.1397282486569944 and parameters: {'n_estimators': 1968, 'learning_rate': 0.01657918685034158, 'max_depth': 2, 'min_child_weight': 0.6798764860465696, 'gamma': 3.132394567758081, 'subsample': 0.6055419251280871, 'colsample_bytree': 0.6114256230451962, 'reg_alpha': 5.732858624620853e-07, 'reg_lambda': 49.20909367216055}. Best is trial 16 with value: 3.126136746279345.
# [I 2026-06-09 06:38:23,287] Trial 18 pruned.
# [I 2026-06-09 06:38:48,988] Trial 19 finished with value: 3.138872874137333 and parameters: {'n_estimators': 1754, 'learning_rate': 0.016070403827632678, 'max_depth': 2, 'min_child_weight': 0.9856386369178421, 'gamma': 3.0376386748636763, 'subsample': 0.5046700299984039, 'colsample_bytree': 0.5804160795569803, 'reg_alpha': 3.35918377898784e-07, 'reg_lambda': 18.80235351378782}. Best is trial 16 with value: 3.126136746279345.
# [I 2026-06-09 06:39:08,122] Trial 20 pruned.
# [I 2026-06-09 06:39:39,123] Trial 21 finished with value: 3.1498471961995422 and parameters: {'n_estimators': 1763, 'learning_rate': 0.01639494441023718, 'max_depth': 2, 'min_child_weight': 0.6004616462206399, 'gamma': 3.131792764570564, 'subsample': 0.5143842055686383, 'colsample_bytree': 0.6398991603194922, 'reg_alpha': 3.4476876611055856e-07, 'reg_lambda': 13.447512261114895}. Best is trial 16 with value: 3.126136746279345.
# [I 2026-06-09 06:40:18,562] Trial 22 finished with value: 3.1449796232951046 and parameters: {'n_estimators': 1510, 'learning_rate': 0.01588211152593489, 'max_depth': 2, 'min_child_weight': 0.9314308975825015, 'gamma': 2.725364746537104, 'subsample': 0.6023004730590329, 'colsample_bytree': 0.5717465647291204, 'reg_alpha': 1.9544709710311215e-07, 'reg_lambda': 19.84353155564365}. Best is trial 16 with value: 3.126136746279345.
# [I 2026-06-09 06:40:25,924] Trial 23 pruned.
# [I 2026-06-09 06:41:00,867] Trial 24 pruned.
# [I 2026-06-09 06:41:18,839] Trial 25 pruned.
# [I 2026-06-09 06:41:39,618] Trial 26 finished with value: 3.144597609495035 and parameters: {'n_estimators': 1978, 'learning_rate': 0.04747531082124818, 'max_depth': 2, 'min_child_weight': 0.8348889396985673, 'gamma': 2.955585296373202, 'subsample': 0.7060029223128934, 'colsample_bytree': 0.5036897664228597, 'reg_alpha': 3.3676799397408195e-07, 'reg_lambda': 25.577253362686758}. Best is trial 16 with value: 3.126136746279345.
# [I 2026-06-09 06:41:49,496] Trial 27 pruned.
# [I 2026-06-09 06:42:45,799] Trial 28 finished with value: 3.1605042518526814 and parameters: {'n_estimators': 1859, 'learning_rate': 0.006890892123463998, 'max_depth': 1, 'min_child_weight': 0.3949027796824409, 'gamma': 2.0687055375368635, 'subsample': 0.6323585999023396, 'colsample_bytree': 0.5449590752148814, 'reg_alpha': 0.00018881085488178814, 'reg_lambda': 4.874470472209425}. Best is trial 16 with value: 3.126136746279345.
# [I 2026-06-09 06:42:53,687] Trial 29 pruned.
# [I 2026-06-09 06:43:10,465] Trial 30 pruned.
# [I 2026-06-09 06:43:18,519] Trial 31 pruned.
# [I 2026-06-09 06:43:37,548] Trial 32 pruned.
# [I 2026-06-09 06:43:43,268] Trial 33 pruned.
# [I 2026-06-09 06:43:56,397] Trial 34 pruned.
# [I 2026-06-09 06:44:06,712] Trial 35 finished with value: 3.1789005917224484 and parameters: {'n_estimators': 1483, 'learning_rate': 0.0513429790838049, 'max_depth': 2, 'min_child_weight': 0.1688406482534976, 'gamma': 2.0091060992700984, 'subsample': 0.7083048239184466, 'colsample_bytree': 0.5871088229263532, 'reg_alpha': 9.525110305034481e-06, 'reg_lambda': 4.499242959197729}. Best is trial 16 with value: 3.126136746279345.
# [I 2026-06-09 06:45:37,666] Trial 36 pruned.
# [I 2026-06-09 06:46:08,470] Trial 37 pruned.
# [I 2026-06-09 06:46:21,552] Trial 38 pruned.
# [I 2026-06-09 06:47:18,911] Trial 39 pruned.
# [I 2026-06-09 06:47:28,394] Trial 40 pruned.
# [I 2026-06-09 06:47:53,652] Trial 41 finished with value: 3.1296200716147937 and parameters: {'n_estimators': 1556, 'learning_rate': 0.018205531268436846, 'max_depth': 2, 'min_child_weight': 0.9855664148895096, 'gamma': 2.7513765273545205, 'subsample': 0.608605405457361, 'colsample_bytree': 0.5702819206540061, 'reg_alpha': 1.3576029243079274e-07, 'reg_lambda': 12.742868491742476}. Best is trial 16 with value: 3.126136746279345.
# [I 2026-06-09 06:48:23,747] Trial 42 finished with value: 3.1785350781877653 and parameters: {'n_estimators': 1583, 'learning_rate': 0.021556253005495168, 'max_depth': 2, 'min_child_weight': 0.5076167418772031, 'gamma': 3.234797575256124, 'subsample': 0.9862845659408341, 'colsample_bytree': 0.5287423166325973, 'reg_alpha': 6.351539128811923e-07, 'reg_lambda': 12.987468473494884}. Best is trial 16 with value: 3.126136746279345.
# [I 2026-06-09 06:48:45,888] Trial 43 pruned.
# [I 2026-06-09 06:49:49,438] Trial 44 pruned.
# [I 2026-06-09 06:49:58,520] Trial 45 pruned.
# [I 2026-06-09 06:50:26,596] Trial 46 pruned.
# [I 2026-06-09 06:50:32,921] Trial 47 pruned.
# [I 2026-06-09 06:50:37,086] Trial 48 pruned.
# [I 2026-06-09 06:51:20,172] Trial 49 finished with value: 3.176674564353406 and parameters: {'n_estimators': 1894, 'learning_rate': 0.027288227955248132, 'max_depth': 1, 'min_child_weight': 1.8124626935941035, 'gamma': 3.4101497902297773, 'subsample': 0.6098913852917637, 'colsample_bytree': 0.5989453369859726, 'reg_alpha': 1.1423814214431758e-08, 'reg_lambda': 43.59924592565287}. Best is trial 16 with value: 3.126136746279345.
# [I 2026-06-09 06:51:27,922] Trial 50 pruned.
# [I 2026-06-09 06:52:15,332] Trial 51 finished with value: 3.1274303146866558 and parameters: {'n_estimators': 1548, 'learning_rate': 0.015098691280313471, 'max_depth': 2, 'min_child_weight': 0.955982946489235, 'gamma': 2.8623770240557014, 'subsample': 0.5973329060181136, 'colsample_bytree': 0.5709156887650981, 'reg_alpha': 2.1971533402624142e-07, 'reg_lambda': 20.193866648861796}. Best is trial 16 with value: 3.126136746279345.
# [I 2026-06-09 06:52:55,237] Trial 52 pruned.
# [I 2026-06-09 06:53:50,626] Trial 53 finished with value: 3.1341797501170077 and parameters: {'n_estimators': 1315, 'learning_rate': 0.01370550214342739, 'max_depth': 2, 'min_child_weight': 0.7394337919761885, 'gamma': 3.175326567470622, 'subsample': 0.5314065839402677, 'colsample_bytree': 0.540112034132531, 'reg_alpha': 2.4962292271857867e-08, 'reg_lambda': 28.72651648628197}. Best is trial 16 with value: 3.126136746279345.
# [I 2026-06-09 06:54:30,022] Trial 54 finished with value: 3.1312882282328722 and parameters: {'n_estimators': 1207, 'learning_rate': 0.01339285233816933, 'max_depth': 2, 'min_child_weight': 0.45594509542516454, 'gamma': 3.14562153040498, 'subsample': 0.5235739953589247, 'colsample_bytree': 0.5734299149764764, 'reg_alpha': 3.342551306915966e-08, 'reg_lambda': 15.575068867241601}. Best is trial 16 with value: 3.126136746279345.
# [I 2026-06-09 06:54:40,462] Trial 55 pruned.
# [I 2026-06-09 06:54:59,932] Trial 56 finished with value: 3.1459163992144417 and parameters: {'n_estimators': 1214, 'learning_rate': 0.023637599195331455, 'max_depth': 1, 'min_child_weight': 0.48744562541348974, 'gamma': 2.4020417595111097, 'subsample': 0.5264891527190757, 'colsample_bytree': 0.5435303795176775, 'reg_alpha': 4.3726747119444093e-08, 'reg_lambda': 12.695457224487562}. Best is trial 16 with value: 3.126136746279345.
# [I 2026-06-09 06:55:13,120] Trial 57 pruned.
# [I 2026-06-09 06:55:22,223] Trial 58 pruned.
# [I 2026-06-09 06:55:53,425] Trial 59 pruned.
# [I 2026-06-09 06:56:04,281] Trial 60 pruned.
# [I 2026-06-09 06:56:24,333] Trial 61 pruned.
# [I 2026-06-09 06:56:58,313] Trial 62 finished with value: 3.1347379399808304 and parameters: {'n_estimators': 1445, 'learning_rate': 0.020111965922097404, 'max_depth': 2, 'min_child_weight': 0.5930847763122998, 'gamma': 3.3533793078130243, 'subsample': 0.5008892631671595, 'colsample_bytree': 0.5671778146709996, 'reg_alpha': 1.705989103533729e-07, 'reg_lambda': 21.140590404074093}. Best is trial 16 with value: 3.126136746279345.
# [I 2026-06-09 06:57:07,287] Trial 63 pruned.
# [I 2026-06-09 06:57:36,333] Trial 64 finished with value: 3.163035272185828 and parameters: {'n_estimators': 1336, 'learning_rate': 0.014189521821423981, 'max_depth': 1, 'min_child_weight': 0.5736412530191715, 'gamma': 3.5541446010989937, 'subsample': 0.5031718028963241, 'colsample_bytree': 0.5568390813543654, 'reg_alpha': 7.127080832560536e-08, 'reg_lambda': 5.3006510576703425}. Best is trial 16 with value: 3.126136746279345.
# [I 2026-06-09 06:57:38,572] Trial 65 pruned.
# [I 2026-06-09 06:57:57,093] Trial 66 finished with value: 3.13785353942827 and parameters: {'n_estimators': 1394, 'learning_rate': 0.01781974383108747, 'max_depth': 2, 'min_child_weight': 8.246133902571563, 'gamma': 2.81480280725806, 'subsample': 0.5751415164844761, 'colsample_bytree': 0.5214215132654845, 'reg_alpha': 4.7315574913929507e-08, 'reg_lambda': 10.010858506352392}. Best is trial 16 with value: 3.126136746279345.
# [I 2026-06-09 06:58:06,619] Trial 67 pruned.
# [I 2026-06-09 06:58:20,972] Trial 68 pruned.
# [I 2026-06-09 06:58:34,314] Trial 69 pruned.
# [I 2026-06-09 06:58:58,797] Trial 70 pruned.
# [I 2026-06-09 06:59:08,120] Trial 71 pruned.
# [I 2026-06-09 06:59:35,788] Trial 72 finished with value: 3.1325114576123596 and parameters: {'n_estimators': 1428, 'learning_rate': 0.015246877560088109, 'max_depth': 2, 'min_child_weight': 0.43364334045429037, 'gamma': 3.0531706378530337, 'subsample': 0.5243096978164797, 'colsample_bytree': 0.595628797794854, 'reg_alpha': 2.1068323847521087e-07, 'reg_lambda': 24.217421440718546}. Best is trial 16 with value: 3.126136746279345.
# [I 2026-06-09 06:59:56,323] Trial 73 finished with value: 3.1491656170325273 and parameters: {'n_estimators': 1158, 'learning_rate': 0.02311638638374154, 'max_depth': 2, 'min_child_weight': 0.43368361482077805, 'gamma': 3.405698956919804, 'subsample': 0.5227911216546279, 'colsample_bytree': 0.5997107143293184, 'reg_alpha': 2.027924846953422e-07, 'reg_lambda': 27.693166198114376}. Best is trial 16 with value: 3.126136746279345.
# [I 2026-06-09 07:00:16,815] Trial 74 finished with value: 3.129560526911814 and parameters: {'n_estimators': 1472, 'learning_rate': 0.015268377756247406, 'max_depth': 2, 'min_child_weight': 0.25562692250924, 'gamma': 2.9891077501826033, 'subsample': 0.5856306742970097, 'colsample_bytree': 0.5344481291058929, 'reg_alpha': 1.4158226200219925e-06, 'reg_lambda': 34.853141527379506}. Best is trial 16 with value: 3.126136746279345.
# [I 2026-06-09 07:00:29,800] Trial 75 pruned.
# [I 2026-06-09 07:00:45,621] Trial 76 pruned.
# [I 2026-06-09 07:01:22,708] Trial 77 pruned.
# [I 2026-06-09 07:01:45,701] Trial 78 pruned.
# [I 2026-06-09 07:01:56,626] Trial 79 pruned.
# [I 2026-06-09 07:02:02,608] Trial 80 pruned.
# [I 2026-06-09 07:02:21,122] Trial 81 pruned.
# [I 2026-06-09 07:02:42,342] Trial 82 finished with value: 3.138465071323788 and parameters: {'n_estimators': 1530, 'learning_rate': 0.015027477073982278, 'max_depth': 2, 'min_child_weight': 0.43439096616798617, 'gamma': 2.3211603614237646, 'subsample': 0.5334114276120621, 'colsample_bytree': 0.5319717694064919, 'reg_alpha': 7.445792798217731e-08, 'reg_lambda': 11.309993251800698}. Best is trial 16 with value: 3.126136746279345.
# [I 2026-06-09 07:03:03,121] Trial 83 finished with value: 3.132269810523087 and parameters: {'n_estimators': 1595, 'learning_rate': 0.01636136451741855, 'max_depth': 2, 'min_child_weight': 0.2557845501671739, 'gamma': 3.000763846938758, 'subsample': 0.5919629795617963, 'colsample_bytree': 0.571829674997175, 'reg_alpha': 1.6119502945462412e-08, 'reg_lambda': 16.95937944722366}. Best is trial 16 with value: 3.126136746279345.
# [I 2026-06-09 07:03:13,634] Trial 84 finished with value: 3.1398563804073163 and parameters: {'n_estimators': 1580, 'learning_rate': 0.026106880703101926, 'max_depth': 2, 'min_child_weight': 1.2224861756920726, 'gamma': 3.4169837316065883, 'subsample': 0.6275497565816331, 'colsample_bytree': 0.570974099839732, 'reg_alpha': 2.6744179046109625e-07, 'reg_lambda': 15.15710250371594}. Best is trial 16 with value: 3.126136746279345.
# [I 2026-06-09 07:03:25,993] Trial 85 pruned.
# [I 2026-06-09 07:03:42,303] Trial 86 finished with value: 3.1480421986994083 and parameters: {'n_estimators': 1471, 'learning_rate': 0.021090304264151864, 'max_depth': 2, 'min_child_weight': 0.23483825311197498, 'gamma': 3.2939732532505634, 'subsample': 0.5970425728558898, 'colsample_bytree': 0.553408513172515, 'reg_alpha': 4.813793204944539e-07, 'reg_lambda': 25.18180840106592}. Best is trial 16 with value: 3.126136746279345.
# [I 2026-06-09 07:04:09,945] Trial 87 pruned.
# [I 2026-06-09 07:04:23,480] Trial 88 pruned.
# [I 2026-06-09 07:04:33,869] Trial 89 pruned.
# [I 2026-06-09 07:04:44,203] Trial 90 pruned.
# [I 2026-06-09 07:04:47,506] Trial 91 pruned.
# [I 2026-06-09 07:05:02,718] Trial 92 pruned.
# [I 2026-06-09 07:05:13,720] Trial 93 pruned.
# [I 2026-06-09 07:05:32,741] Trial 94 pruned.
# [I 2026-06-09 07:05:38,893] Trial 95 pruned.
# [I 2026-06-09 07:05:44,209] Trial 96 pruned.
# [I 2026-06-09 07:05:48,464] Trial 97 pruned.
# [I 2026-06-09 07:06:04,310] Trial 98 pruned.
# [I 2026-06-09 07:06:13,212] Trial 99 pruned.
# [I 2026-06-09 07:06:13,218] A new study created in memory with name: no-name-7514bcba-7830-40c4-8b07-cff6cbe33004
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:06:28,124] Trial 0 finished with value: 3.3811529638751114 and parameters: {'n_estimators': 301, 'learning_rate': 0.03250177171527344, 'num_leaves': 37, 'max_depth': 4, 'min_child_samples': 52, 'min_split_gain': 1.7182749818971954, 'bagging_fraction': 0.8330451065490129, 'bagging_freq': 4, 'feature_fraction': 0.5145069122121801, 'lambda_l1': 0.04015454105555427, 'lambda_l2': 0.07175601133819473}. Best is trial 0 with value: 3.3811529638751114.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:07:45,147] Trial 1 finished with value: 3.4117708487358818 and parameters: {'n_estimators': 1620, 'learning_rate': 0.008116618171663207, 'num_leaves': 18, 'max_depth': 9, 'min_child_samples': 37, 'min_split_gain': 0.8099788960945193, 'bagging_fraction': 0.6580482355091044, 'bagging_freq': 1, 'feature_fraction': 0.9216123471148523, 'lambda_l1': 0.43697071238567825, 'lambda_l2': 36.7185332724254}. Best is trial 0 with value: 3.3811529638751114.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:07:56,981] Trial 2 finished with value: 3.3196452569618664 and parameters: {'n_estimators': 820, 'learning_rate': 0.1255359023925396, 'num_leaves': 116, 'max_depth': 8, 'min_child_samples': 17, 'min_split_gain': 1.7941971599630686, 'bagging_fraction': 0.6490017503443813, 'bagging_freq': 2, 'feature_fraction': 0.5025647745322285, 'lambda_l1': 0.0007741455782248723, 'lambda_l2': 0.1717169091593679}. Best is trial 2 with value: 3.3196452569618664.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:08:01,581] Trial 3 finished with value: 3.7362815024946476 and parameters: {'n_estimators': 1302, 'learning_rate': 0.13774020868800516, 'num_leaves': 233, 'max_depth': 10, 'min_child_samples': 81, 'min_split_gain': 0.2080378997095258, 'bagging_fraction': 0.5904572976289505, 'bagging_freq': 7, 'feature_fraction': 0.7059764916931793, 'lambda_l1': 0.6097531961875766, 'lambda_l2': 1.4405915859050216}. Best is trial 2 with value: 3.3196452569618664.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:08:38,327] Trial 4 finished with value: 3.4100777806976907 and parameters: {'n_estimators': 1287, 'learning_rate': 0.008816320113501107, 'num_leaves': 230, 'max_depth': 3, 'min_child_samples': 64, 'min_split_gain': 1.987144984788207, 'bagging_fraction': 0.8678635407535604, 'bagging_freq': 4, 'feature_fraction': 0.7803315847218675, 'lambda_l1': 5.026890229380336e-05, 'lambda_l2': 2.6067223030440956}. Best is trial 2 with value: 3.3196452569618664.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:08:44,295] Trial 5 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:08:48,391] Trial 6 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:08:52,376] Trial 7 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:08:53,646] Trial 8 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:09:04,760] Trial 9 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:10:51,142] Trial 10 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:10:55,450] Trial 11 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:11:20,383] Trial 12 finished with value: 3.303917718927411 and parameters: {'n_estimators': 517, 'learning_rate': 0.024262419120912624, 'num_leaves': 91, 'max_depth': 8, 'min_child_samples': 31, 'min_split_gain': 1.6887824309347674, 'bagging_fraction': 0.7533243400910767, 'bagging_freq': 2, 'feature_fraction': 0.5065623605708911, 'lambda_l1': 0.013234943178919222, 'lambda_l2': 0.05114673429014843}. Best is trial 12 with value: 3.303917718927411.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:11:32,557] Trial 13 finished with value: 3.302345315416474 and parameters: {'n_estimators': 675, 'learning_rate': 0.07837634048216681, 'num_leaves': 99, 'max_depth': 8, 'min_child_samples': 26, 'min_split_gain': 1.1936481141102784, 'bagging_fraction': 0.7318201539923618, 'bagging_freq': 2, 'feature_fraction': 0.6091484946086794, 'lambda_l1': 0.0002258437315475552, 'lambda_l2': 0.002382249432418657}. Best is trial 13 with value: 3.302345315416474.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:12:00,011] Trial 14 finished with value: 3.3098667254400347 and parameters: {'n_estimators': 569, 'learning_rate': 0.019285776368722102, 'num_leaves': 85, 'max_depth': 8, 'min_child_samples': 32, 'min_split_gain': 1.1526647845049771, 'bagging_fraction': 0.7587409687084421, 'bagging_freq': 2, 'feature_fraction': 0.602205334676884, 'lambda_l1': 8.412981494010534, 'lambda_l2': 0.0010944898563967323}. Best is trial 13 with value: 3.302345315416474.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:12:05,708] Trial 15 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:12:11,662] Trial 16 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:12:22,464] Trial 17 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:12:28,399] Trial 18 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:12:31,425] Trial 19 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:12:39,678] Trial 20 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:13:10,863] Trial 21 finished with value: 3.3246146482242116 and parameters: {'n_estimators': 613, 'learning_rate': 0.02103647663887878, 'num_leaves': 85, 'max_depth': 8, 'min_child_samples': 31, 'min_split_gain': 1.27921422048135, 'bagging_fraction': 0.7853887081654827, 'bagging_freq': 2, 'feature_fraction': 0.5906861235205568, 'lambda_l1': 3.2132764397245874, 'lambda_l2': 0.0012339877648667743}. Best is trial 13 with value: 3.302345315416474.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:13:51,224] Trial 22 finished with value: 3.19526017055391 and parameters: {'n_estimators': 416, 'learning_rate': 0.021878964490031003, 'num_leaves': 107, 'max_depth': 8, 'min_child_samples': 14, 'min_split_gain': 1.0739866665363496, 'bagging_fraction': 0.7620310231390888, 'bagging_freq': 2, 'feature_fraction': 0.646412014011286, 'lambda_l1': 6.40227417469113, 'lambda_l2': 0.0031559412986121734}. Best is trial 22 with value: 3.19526017055391.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:14:39,740] Trial 23 finished with value: 3.2154785026660893 and parameters: {'n_estimators': 405, 'learning_rate': 0.026914417752416785, 'num_leaves': 148, 'max_depth': 9, 'min_child_samples': 17, 'min_split_gain': 0.6085165199167715, 'bagging_fraction': 0.6910163339095924, 'bagging_freq': 1, 'feature_fraction': 0.7579013747286668, 'lambda_l1': 0.07952545615087642, 'lambda_l2': 0.0027617716813059354}. Best is trial 22 with value: 3.19526017055391.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:15:06,550] Trial 24 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:15:34,577] Trial 25 finished with value: 3.2775089065981717 and parameters: {'n_estimators': 417, 'learning_rate': 0.05123543896882976, 'num_leaves': 110, 'max_depth': 9, 'min_child_samples': 15, 'min_split_gain': 0.12209430219022616, 'bagging_fraction': 0.6278031563180952, 'bagging_freq': 1, 'feature_fraction': 0.7487295629620788, 'lambda_l1': 2.0852524011817373, 'lambda_l2': 0.00251010096359041}. Best is trial 22 with value: 3.19526017055391.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:16:07,728] Trial 26 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:17:00,608] Trial 27 finished with value: 3.2158944444289097 and parameters: {'n_estimators': 296, 'learning_rate': 0.04898905381578334, 'num_leaves': 204, 'max_depth': 10, 'min_child_samples': 17, 'min_split_gain': 0.0084051383781385, 'bagging_fraction': 0.6083421648650116, 'bagging_freq': 1, 'feature_fraction': 0.8280565200212173, 'lambda_l1': 8.106856346878944, 'lambda_l2': 0.0036198259074488558}. Best is trial 22 with value: 3.19526017055391.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:17:28,138] Trial 28 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:18:49,306] Trial 29 finished with value: 3.2037053710515617 and parameters: {'n_estimators': 255, 'learning_rate': 0.016010885925641725, 'num_leaves': 205, 'max_depth': 10, 'min_child_samples': 18, 'min_split_gain': 0.6317712618660895, 'bagging_fraction': 0.8184659669539344, 'bagging_freq': 3, 'feature_fraction': 0.8199862158936185, 'lambda_l1': 0.11326873252038189, 'lambda_l2': 0.004844418033421532}. Best is trial 22 with value: 3.19526017055391.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:18:56,262] Trial 30 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:20:04,063] Trial 31 finished with value: 3.1869278930022595 and parameters: {'n_estimators': 322, 'learning_rate': 0.015842781278957767, 'num_leaves': 252, 'max_depth': 10, 'min_child_samples': 16, 'min_split_gain': 0.3530760973963895, 'bagging_fraction': 0.7004643998003475, 'bagging_freq': 3, 'feature_fraction': 0.8265038858870541, 'lambda_l1': 0.08315368385506852, 'lambda_l2': 0.005211999897688602}. Best is trial 31 with value: 3.1869278930022595.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:21:44,810] Trial 32 finished with value: 3.2647182942499944 and parameters: {'n_estimators': 439, 'learning_rate': 0.015350807378434441, 'num_leaves': 254, 'max_depth': 10, 'min_child_samples': 21, 'min_split_gain': 0.594002590604451, 'bagging_fraction': 0.6970896214252683, 'bagging_freq': 3, 'feature_fraction': 0.8898611313014343, 'lambda_l1': 0.14118398441225408, 'lambda_l2': 0.005815991921954706}. Best is trial 31 with value: 3.1869278930022595.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:22:24,034] Trial 33 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:24:38,657] Trial 34 finished with value: 3.2789859706932987 and parameters: {'n_estimators': 784, 'learning_rate': 0.029325701133429635, 'num_leaves': 212, 'max_depth': 10, 'min_child_samples': 10, 'min_split_gain': 0.6129095905566044, 'bagging_fraction': 0.6477357094426689, 'bagging_freq': 3, 'feature_fraction': 0.7065035675131939, 'lambda_l1': 0.0025485628635888162, 'lambda_l2': 0.00451272764418299}. Best is trial 31 with value: 3.1869278930022595.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:25:04,946] Trial 35 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:26:47,923] Trial 36 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:29:20,118] Trial 37 finished with value: 3.2380741351187465 and parameters: {'n_estimators': 370, 'learning_rate': 0.023631352583961485, 'num_leaves': 170, 'max_depth': 10, 'min_child_samples': 22, 'min_split_gain': 0.24936331788831506, 'bagging_fraction': 0.7025199972077235, 'bagging_freq': 3, 'feature_fraction': 0.8711096349630021, 'lambda_l1': 0.03234807192854813, 'lambda_l2': 0.03194541727642699}. Best is trial 31 with value: 3.1869278930022595.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:30:21,151] Trial 38 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:33:04,276] Trial 39 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:33:40,695] Trial 40 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:38:13,530] Trial 41 finished with value: 3.2560152818658326 and parameters: {'n_estimators': 294, 'learning_rate': 0.026138228857104047, 'num_leaves': 203, 'max_depth': 10, 'min_child_samples': 19, 'min_split_gain': 0.01795939599151386, 'bagging_fraction': 0.6195171309968946, 'bagging_freq': 1, 'feature_fraction': 0.8299285798950204, 'lambda_l1': 4.604742445154386, 'lambda_l2': 0.003767686339758678}. Best is trial 31 with value: 3.1869278930022595.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:41:28,950] Trial 42 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:42:44,270] Trial 43 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:47:16,717] Trial 44 finished with value: 3.2129249168047327 and parameters: {'n_estimators': 543, 'learning_rate': 0.012689797221715515, 'num_leaves': 197, 'max_depth': 10, 'min_child_samples': 14, 'min_split_gain': 0.014798184204391291, 'bagging_fraction': 0.6793114216078674, 'bagging_freq': 3, 'feature_fraction': 0.8800235159292978, 'lambda_l1': 0.10734129462880337, 'lambda_l2': 0.0036651816980400784}. Best is trial 31 with value: 3.1869278930022595.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:47:45,019] Trial 45 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:50:16,403] Trial 46 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:50:33,288] Trial 47 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:51:03,477] Trial 48 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:54:12,495] Trial 49 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:54:37,664] Trial 50 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:54:56,283] Trial 51 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:57:22,671] Trial 52 finished with value: 3.2207822919022844 and parameters: {'n_estimators': 476, 'learning_rate': 0.01148315929712852, 'num_leaves': 217, 'max_depth': 10, 'min_child_samples': 12, 'min_split_gain': 0.070896466668282, 'bagging_fraction': 0.6748824548918845, 'bagging_freq': 1, 'feature_fraction': 0.8751683133849772, 'lambda_l1': 0.2720713819788772, 'lambda_l2': 0.00247743218152355}. Best is trial 31 with value: 3.1869278930022595.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:57:51,113] Trial 53 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:58:51,173] Trial 54 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:59:26,461] Trial 55 finished with value: 3.2560844606376196 and parameters: {'n_estimators': 580, 'learning_rate': 0.03625867086570797, 'num_leaves': 135, 'max_depth': 9, 'min_child_samples': 18, 'min_split_gain': 0.5362196904548103, 'bagging_fraction': 0.8834731509270083, 'bagging_freq': 1, 'feature_fraction': 0.9783980246165694, 'lambda_l1': 0.016664363567903205, 'lambda_l2': 0.004567400168026066}. Best is trial 31 with value: 3.1869278930022595.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:59:33,973] Trial 56 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 08:00:23,679] Trial 57 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 08:01:02,091] Trial 58 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# ...
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 08:10:39,446] Trial 68 finished with value: 3.2486813627556224 and parameters: {'n_estimators': 266, 'learning_rate': 0.04527139009986151, 'num_leaves': 67, 'max_depth': 8, 'min_child_samples': 18, 'min_split_gain': 0.7159168508683009, 'bagging_fraction': 0.768321533729306, 'bagging_freq': 2, 'feature_fraction': 0.5609422668938331, 'lambda_l1': 1.1222389127223175e-08, 'lambda_l2': 0.006587753610161928}. Best is trial 31 with value: 3.1869278930022595.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 08:10:50,376] Trial 69 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 08:11:02,469] Trial 70 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 08:12:50,562] Trial 71 finished with value: 3.245926883900902 and parameters: {'n_estimators': 478, 'learning_rate': 0.011319150453165129, 'num_leaves': 212, 'max_depth': 10, 'min_child_samples': 13, 'min_split_gain': 0.07823696405486508, 'bagging_fraction': 0.710260811578701, 'bagging_freq': 1, 'feature_fraction': 0.8819008325622334, 'lambda_l1': 0.2639248729308594, 'lambda_l2': 0.0025850837165416183}. Best is trial 31 with value: 3.1869278930022595.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 08:13:14,532] Trial 72 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 08:14:13,538] Trial 73 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [W 2026-06-09 08:15:12,789] Trial 74 failed with parameters: {'n_estimators': 629, 'learning_rate': 0.018545619046318067, 'num_leaves': 212, 'max_depth': 9, 'min_child_samples': 21, 'min_split_gain': 0.003041634601015402, 'bagging_fraction': 0.991026587252052, 'bagging_freq': 1, 'feature_fraction': 0.8496731734530327, 'lambda_l1': 5.320238728520514, 'lambda_l2': 0.005573096881969245} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "d:\dev\weather-research\.venv\Lib\site-packages\optuna\study\_optimize.py", line 206, in _run_trial
#     value_or_values = func(trial)
#   File "D:\dev\weather-research\src\calibration\station_stacking.py", line 800, in objective
#     year = pd.to_numeric(frame.get("year"), errors="coerce")
#                                               ^^^^^^^^^^^^^^
#     ...<8 lines>...
#             for fold in folds:
#             ^^^^^^^^^
#   File "D:\dev\weather-research\src\calibration\station_stacking.py", line 1909, in _fit_predict_base_model
#         train: pd.DataFrame,
#     ...<7 lines>...
#
#   File "D:\dev\weather-research\src\calibration\station_stacking.py", line 1951, in _fit_base_estimator
#         x_train: Any,
#                 ^^^^^
#     ...<5 lines>...
#         if early_stopping_rounds is None:
#         ^^^^^^^^^
#   File "d:\dev\weather-research\.venv\Lib\site-packages\lightgbm\sklearn.py", line 1398, in fit
#     super().fit(
#     ~~~~~~~~~~~^
#         X,
#         ^^
#     ...<11 lines>...
#         init_model=init_model,
#         ^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "d:\dev\weather-research\.venv\Lib\site-packages\lightgbm\sklearn.py", line 1049, in fit
#     self._Booster = train(
#                     ~~~~~^
#         params=params,
#         ^^^^^^^^^^^^^^
#     ...<6 lines>...
#         callbacks=callbacks,
#         ^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "d:\dev\weather-research\.venv\Lib\site-packages\lightgbm\engine.py", line 322, in train
#     booster.update(fobj=fobj)
#     ~~~~~~~~~~~~~~^^^^^^^^^^^
#   File "d:\dev\weather-research\.venv\Lib\site-packages\lightgbm\basic.py", line 4155, in update
#     _LIB.LGBM_BoosterUpdateOneIter(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         self._handle,
#         ^^^^^^^^^^^^^
#         ctypes.byref(is_finished),
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
# KeyboardInterrupt
# [W 2026-06-09 08:15:12,985] Trial 74 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 18
#      14     stack_optuna_trials=STACK_OPTUNA_TRIALS,
#      15     optuna_verbose=OPTUNA_VERBOSE,
#      16     output_dir=PROJECT_ROOT / "data" / "calibration" / "station_stacking_v4",
#      17 )
# ---> 18 result = run_station_year_split_experiment(config)
#      19 result.scoreboard
#
# File D:\dev\weather-research\src\calibration\station_stacking.py:654, in run_station_year_split_experiment(config)
#     643     feature_columns_frame.to_csv(paths["feature_columns"], index=False)
#     644     return StationStackingResult(
#     645         station_id=station,
#     646         features=features,
#    (...)    650         output_paths=paths,
#     651     )
# --> 654 def run_station_year_split_experiment(config: StationStackingConfig) -> YearSplitExperimentResult:
#     655     features = build_station_wide_dataset(
#     656         config.resolved_project_root(),
#     657         station_id=config.station_id,
#     658         timing_mode=config.timing_mode,
#     659         providers=config.providers,
#     660     )
#     661     modeling_frame, categorical, numeric = _modeling_frame(features, config)
#
# File D:\dev\weather-research\src\calibration\station_stacking.py:864, in tune_year_split_base_models(frame, config, categorical, numeric, folds)
#     850 rmse = float(metrics["rmse_f"])
#     851 fold_scores.append((fold, float(metrics[metric_col])))
#     852 rows.append(
#     853     {
#     854         "method": method,
#     855         "trial_number": trial.number,
#     856         "param_key": param_key,
#     857         "fold": fold.name,
#     858         "fold_weight": _year_split_fold_weight(fold),
#     859         "mae_f": mae,
#     860         "rmse_f": rmse,
#     861         "count": int(metrics["count"]),
#     862         "fit_numeric_features": fit_metadata["numeric_features"],
#     863         "fit_categorical_features": fit_metadata["categorical_features"],
# --> 864         "best_iteration": fit_metadata["best_iteration"],
#     865         "status": "ok",
#     866         "error": "",
#     867         **{f"param_{key}": value for key, value in params.items()},
#     868     }
#     869 )
#     870 current_score = _weighted_fold_score(fold_scores)
#     871 if hasattr(trial, "report"):
#
# File d:\dev\weather-research\.venv\Lib\site-packages\optuna\study\study.py:516, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     414 def optimize(
#     415     self,
#     416     func: ObjectiveFuncType,
#    (...)    423     show_progress_bar: bool = False,
#     424 ) -> None:
#     425     """Optimize an objective function.
#     426
#     427     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)    514             If nested invocation of this method occurs.
#     515     """
# --> 516     _optimize(
#     517         study=self,
#     518         func=func,
#     519         n_trials=n_trials,
#     520         timeout=timeout,
#     521         n_jobs=n_jobs,
#     522         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     523         callbacks=callbacks,
#     524         gc_after_trial=gc_after_trial,
#     525         show_progress_bar=show_progress_bar,
#     526     )
#
# File d:\dev\weather-research\.venv\Lib\site-packages\optuna\study\_optimize.py:68, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      66 try:
#      67     if n_jobs == 1:
# ---> 68         _optimize_sequential(
#      69             study,
#      70             func,
#      71             n_trials,
#      72             timeout,
#      73             catch,
#      74             callbacks,
#      75             gc_after_trial,
#      76             reseed_sampler_rng=False,
#      77             time_start=None,
#      78             progress_bar=progress_bar,
#      79         )
#      80     else:
#      81         if n_jobs == -1:
#
# File d:\dev\weather-research\.venv\Lib\site-packages\optuna\study\_optimize.py:165, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     162         break
#     164 try:
# --> 165     frozen_trial_id = _run_trial(study, func, catch)
#     166 finally:
#     167     # The following line mitigates memory problems that can be occurred in some
#     168     # environments (e.g., services that use computing containers such as GitHub Actions).
#     169     # Please refer to the following PR for further details:
#     170     # https://github.com/optuna/optuna/pull/325.
#     171     if gc_after_trial:
#
# File d:\dev\weather-research\.venv\Lib\site-packages\optuna\study\_optimize.py:263, in _run_trial(study, func, catch)
#     256         assert False, "Should not reach."
#     258 if (
#     259     updated_state == TrialState.FAIL
#     260     and func_err is not None
#     261     and not isinstance(func_err, catch)
#     262 ):
# --> 263     raise func_err
#     264 return trial._trial_id
#
# File d:\dev\weather-research\.venv\Lib\site-packages\optuna\study\_optimize.py:206, in _run_trial(study, func, catch)
#     204 with get_heartbeat_thread(trial._trial_id, study._storage):
#     205     try:
# --> 206         value_or_values = func(trial)
#     207     except exceptions.TrialPruned as e:
#     208         # TODO(mamu): Handle multi-objective cases.
#     209         state = TrialState.PRUNED
#
# File D:\dev\weather-research\src\calibration\station_stacking.py:800, in objective(trial)
#     798     return pd.DataFrame(), _empty_year_split_predictions(), pd.DataFrame()
#     799 rows: list[dict[str, Any]] = []
# --> 800 year = pd.to_numeric(frame.get("year"), errors="coerce")
#     801 metric_col = config.effective_optuna_metric
#     802 for method in BASE_MODEL_METHODS:
#
# File D:\dev\weather-research\src\calibration\station_stacking.py:1909, in _fit_predict_base_model(config, categorical, numeric, method, params, train, valid, early_stopping)
#    1885         return CatBoostRegressor(
#    1886             iterations=cat_iterations,
#    1887             learning_rate=float(params.get("learning_rate", 0.035)),
#    (...)   1898             allow_writing_files=False,
#    1899         )
#    1900     raise ValueError(f"Unknown base model method: {method}")
#    1903 def _fit_predict_base_model(
#    1904     config: StationStackingConfig,
#    1905     categorical: list[str],
#    1906     numeric: list[str],
#    1907     method: str,
#    1908     params: dict[str, Any],
# -> 1909     train: pd.DataFrame,
#    1910     valid: pd.DataFrame,
#    1911     early_stopping: bool,
#    1912 ) -> tuple[np.ndarray, dict[str, Any]]:
#    1913     fit_categorical, fit_numeric = _fit_feature_columns(train, categorical, numeric)
#    1914     feature_names = [*fit_categorical, *fit_numeric]
#
# File D:\dev\weather-research\src\calibration\station_stacking.py:1951, in _fit_base_estimator(estimator, method, x_train, y_train, x_valid, y_valid, early_stopping_rounds)
#    1944     fit_numeric = [column for column in numeric if column in train and pd.to_numeric(train[column], errors="coerce").notna().any()]
#    1945     return fit_categorical, fit_numeric
#    1948 def _fit_base_estimator(
#    1949     estimator: Any,
#    1950     method: str,
# -> 1951     x_train: Any,
#    1952     y_train: pd.Series,
#    1953     x_valid: Any,
#    1954     y_valid: pd.Series,
#    1955     early_stopping_rounds: int | None,
#    1956 ) -> None:
#    1957     if early_stopping_rounds is None:
#    1958         estimator.fit(x_train, y_train)
#
# File d:\dev\weather-research\.venv\Lib\site-packages\lightgbm\sklearn.py:1398, in LGBMRegressor.fit(self, X, y, sample_weight, init_score, eval_set, eval_names, eval_sample_weight, eval_init_score, eval_metric, feature_name, categorical_feature, callbacks, init_model)
#    1381 def fit(  # type: ignore[override]
#    1382     self,
#    1383     X: _LGBM_ScikitMatrixLike,
#    (...)   1395     init_model: Optional[Union[str, Path, Booster, LGBMModel]] = None,
#    1396 ) -> "LGBMRegressor":
#    1397     """Docstring is inherited from the LGBMModel."""
# -> 1398     super().fit(
#    1399         X,
#    1400         y,
#    1401         sample_weight=sample_weight,
#    1402         init_score=init_score,
#    1403         eval_set=eval_set,
#    1404         eval_names=eval_names,
#    1405         eval_sample_weight=eval_sample_weight,
#    1406         eval_init_score=eval_init_score,
#    1407         eval_metric=eval_metric,
#    1408         feature_name=feature_name,
#    1409         categorical_feature=categorical_feature,
#    1410         callbacks=callbacks,
#    1411         init_model=init_model,
#    1412     )
#    1413     return self
#
# File d:\dev\weather-research\.venv\Lib\site-packages\lightgbm\sklearn.py:1049, in LGBMModel.fit(self, X, y, sample_weight, init_score, group, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_group, eval_metric, feature_name, categorical_feature, callbacks, init_model)
#    1046 evals_result: _EvalResultDict = {}
#    1047 callbacks.append(record_evaluation(evals_result))
# -> 1049 self._Booster = train(
#    1050     params=params,
#    1051     train_set=train_set,
#    1052     num_boost_round=self.n_estimators,
#    1053     valid_sets=valid_sets,
#    1054     valid_names=eval_names,
#    1055     feval=eval_metrics_callable,  # type: ignore[arg-type]
#    1056     init_model=init_model,
#    1057     callbacks=callbacks,
#    1058 )
#    1060 # This populates the property self.n_features_, the number of features in the fitted model,
#    1061 # and so should only be set after fitting.
#    1062 #
#    1063 # The related property self._n_features_in, which populates self.n_features_in_,
#    1064 # is set BEFORE fitting.
#    1065 self._n_features = self._Booster.num_feature()
#
# File d:\dev\weather-research\.venv\Lib\site-packages\lightgbm\engine.py:322, in train(params, train_set, num_boost_round, valid_sets, valid_names, feval, init_model, keep_training_booster, callbacks)
#     310 for cb in callbacks_before_iter:
#     311     cb(
#     312         callback.CallbackEnv(
#     313             model=booster,
#    (...)    319         )
#     320     )
# --> 322 booster.update(fobj=fobj)
#     324 evaluation_result_list: List[_LGBM_BoosterEvalMethodResultType] = []
#     325 # check evaluation result.
#
# File d:\dev\weather-research\.venv\Lib\site-packages\lightgbm\basic.py:4155, in Booster.update(self, train_set, fobj)
#    4152 if self.__set_objective_to_none:
#    4153     raise LightGBMError("Cannot update due to null objective function.")
#    4154 _safe_call(
# -> 4155     _LIB.LGBM_BoosterUpdateOneIter(
#    4156         self._handle,
#    4157         ctypes.byref(is_finished),
#    4158     )
#    4159 )
#    4160 self.__is_predicted_cur_iter = [False for _ in range(self.__num_dataset)]
#    4161 return is_finished.value == 1
#
# KeyboardInterrupt:

# %% [markdown]
# ## Rounded Within 1F Accuracy

# %%
preds = pd.concat(
    [
        result.validation_predictions.assign(period="validation_2024_2025"),
        result.test_predictions.assign(period="test_2026"),
    ],
    ignore_index=True,
)

predicted_high = pd.to_numeric(preds["predicted_high_f"], errors="coerce")
preds["predicted_high_rounded_f"] = np.floor(predicted_high + 0.5)
preds["within_1f_after_round"] = (
    pd.to_numeric(preds["actual_high_f"], errors="coerce") - preds["predicted_high_rounded_f"]
).abs().le(1)

within_1f_accuracy_by_period = (
    preds
    .dropna(subset=["actual_high_f", "predicted_high_rounded_f"])
    .groupby(["period", "method"], as_index=False)
    .agg(
        count=("within_1f_after_round", "size"),
        within_1f_count=("within_1f_after_round", "sum"),
        within_1f_accuracy_pct=("within_1f_after_round", lambda x: x.mean() * 100),
    )
    .sort_values(["period", "within_1f_accuracy_pct"], ascending=[True, False])
)

within_1f_accuracy_by_period

# %% [markdown]
# ## Precipitation Feature Coverage

# %%
precip_columns = [column for column in result.features.columns if "precip" in column.lower()]
coverage = (
    result.features[precip_columns]
    .notna()
    .mean()
    .mul(100)
    .sort_values(ascending=False)
    .rename("coverage_pct")
    .reset_index()
    .rename(columns={"index": "feature"})
)
coverage

# %% [markdown]
# ## Version Comparison

# %%
comparison_frames = []
for version, folder in [
    ("v1", PROJECT_ROOT / "data" / "calibration" / "station_stacking"),
    ("v2", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v2"),
    ("v3", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v3"),
    ("v4", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v4"),
]:
    path = folder / f"{STATION_ID}_year_split_scoreboard.csv"
    if path.exists():
        frame = pd.read_csv(path)
        frame["version"] = version
        comparison_frames.append(frame)

version_comparison = pd.concat(comparison_frames, ignore_index=True) if comparison_frames else pd.DataFrame()
if not version_comparison.empty:
    version_comparison = version_comparison.sort_values(["period", "mae_f", "version", "method"]).reset_index(drop=True)
version_comparison

# %% [markdown]
# ## 2026 Weather Brackets

# %%
result.bracket_metrics

# %%
import pandas as pd


def adjacent_brackets(bracket):
    if pd.isna(bracket):
        return []
    text = str(bracket).strip()
    if not text or "-" not in text:
        return []
    try:
        lower = int(text.split("-", 1)[0])
    except ValueError:
        return []
    return [
        f"{lower - 2}-{lower - 1}",
        f"{lower}-{lower + 1}",
        f"{lower + 2}-{lower + 3}",
    ]


bracket_3way = result.bracket_predictions.copy()

valid = bracket_3way["actual_bracket"].notna() & bracket_3way["predicted_bracket"].astype(str).str.strip().ne("")
bracket_3way = bracket_3way.loc[valid].copy()
bracket_3way["picked_brackets"] = bracket_3way["predicted_bracket"].map(adjacent_brackets)
bracket_3way["three_bracket_hit"] = bracket_3way.apply(
    lambda row: row["actual_bracket"] in row["picked_brackets"],
    axis=1,
)

three_bracket_accuracy = (
    bracket_3way
    .groupby("method", as_index=False)
    .agg(
        count=("three_bracket_hit", "size"),
        exact_bracket_accuracy_pct=("bracket_hit", lambda x: x.mean() * 100),
        three_bracket_accuracy_pct=("three_bracket_hit", lambda x: x.mean() * 100),
    )
    .sort_values("three_bracket_accuracy_pct", ascending=False)
)

three_bracket_accuracy

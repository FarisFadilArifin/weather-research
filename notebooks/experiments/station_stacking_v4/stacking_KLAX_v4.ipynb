# %% [markdown]
# # Station Stacking v4 - KLAX
#
# Wide HRRR/GFS same-day 11am notebook for `KLAX`.
#
# This version keeps the v3 high-so-far features and adds SDK-backed precipitation features from HRRR/GFS forecast precipitation plus 11 AM METAR precipitation codes. Artifacts are written to `data/calibration/station_stacking_v4`.

# %%
from pathlib import Path
import sys
import warnings

warnings.filterwarnings("ignore", message="IProgress not found.*")
warnings.filterwarnings("ignore", message="Skipping features without any observed values.*")

PROJECT_ROOT = Path.cwd().resolve()
while not (PROJECT_ROOT / "src" / "calibration" / "station_stacking.py").exists():
    if PROJECT_ROOT.parent == PROJECT_ROOT:
        raise RuntimeError("Could not find project root containing src/calibration/station_stacking.py")
    PROJECT_ROOT = PROJECT_ROOT.parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

STATION_ID = "KLAX"
FAST_MODE = False
OPTUNA_TRIALS = 100
STACK_OPTUNA_TRIALS = 50
OPTUNA_VERBOSE = True
PROJECT_ROOT
# Out:
# WindowsPath('D:/dev/weather-research')

# %%
from src.calibration.station_stacking import (
    StationStackingConfig,
    missing_model_dependencies,
    run_station_year_split_experiment,
)

# %% [markdown]
# ## V4 Feature Engineering
#
# Adds v2/v3 temperature features plus forecast and observed precipitation signals. Forecast precipitation comes from provider-prefixed SDK summary columns such as `gfs_forecast_precip_total_mm`, with `gfs_precip_amount` as a fallback for older caches.

# %%
import numpy as np
import pandas as pd
import src.calibration.station_stacking as station_stacking_module

V4_PROVIDERS = ("gfs", "hrrr")
V4_FEATURE_COLUMNS = [
    "v2_recent_heat_anomaly_f",
    "v2_recent_heat_momentum_f",
    "v2_morning_warmup_to_consensus_f",
    "v2_consensus_minus_7d_actual_f",
    "v2_spread_per_warmup_f",
    "v2_humidity_warmup_interaction",
    "v3_high_so_far_above_current_f",
    "v3_remaining_warmup_from_high_so_far_f",
    "v3_high_so_far_minus_lag_1d_f",
    "v3_high_so_far_minus_7d_actual_f",
    "v3_remaining_warmup_per_spread_f",
    "v3_humidity_remaining_warmup_interaction",
    "v4_forecast_precip_total_mean_mm",
    "v4_forecast_precip_total_max_mm",
    "v4_forecast_precip_total_spread_mm",
    "v4_forecast_precip_max_1h_mean_mm",
    "v4_forecast_precip_hours_mean",
    "v4_forecast_precip_intensity_mean",
    "v4_forecast_precip_intensity_max",
    "v4_any_forecast_precip",
    "v4_all_forecast_precip",
    "v4_observed_precip_any",
    "v4_observed_precip_recent_mm_est",
    "v4_forecast_total_minus_observed_recent_mm",
    "v4_forecast_observed_precip_match",
    "v4_forecast_wet_observed_dry",
    "v4_observed_wet_forecast_dry",
    "v4_precip_humidity_interaction",
    "v4_precip_remaining_warmup_interaction",
]


def _num(frame: pd.DataFrame, column: str) -> pd.Series:
    if column in frame:
        return pd.to_numeric(frame[column], errors="coerce")
    return pd.Series(np.nan, index=frame.index, dtype="float64")


def _bool_num(frame: pd.DataFrame, column: str) -> pd.Series:
    if column not in frame:
        return pd.Series(0, index=frame.index, dtype="int64")
    series = frame[column]
    if pd.api.types.is_bool_dtype(series):
        return series.fillna(False).astype(int)
    if pd.api.types.is_numeric_dtype(series):
        return pd.to_numeric(series, errors="coerce").fillna(0).gt(0).astype(int)
    return series.astype("string").str.lower().isin({"1", "true", "yes", "y"}).astype(int)


def _provider_series(frame: pd.DataFrame, provider: str, primary: str, fallback: str | None = None) -> pd.Series:
    primary_column = f"{provider}_{primary}"
    if primary_column in frame:
        return _num(frame, primary_column)
    if fallback is not None:
        return _num(frame, f"{provider}_{fallback}")
    return pd.Series(np.nan, index=frame.index, dtype="float64")


def _provider_matrix(frame: pd.DataFrame, primary: str, fallback: str | None = None) -> pd.DataFrame:
    return pd.DataFrame(
        {provider: _provider_series(frame, provider, primary, fallback) for provider in V4_PROVIDERS},
        index=frame.index,
    )


def add_v4_feature_engineering(frame: pd.DataFrame) -> pd.DataFrame:
    out = frame.copy()
    observed_temp = _num(out, "observed_temp_at_as_of_f")
    high_so_far = _num(out, "observed_high_temp_through_as_of_f")
    observed_humidity = _num(out, "observed_humidity_at_as_of")
    provider_mean = _num(out, "provider_mean_high_f")
    provider_spread = _num(out, "provider_spread_high_f")
    lag_1d = _num(out, "actual_high_lag_1d")
    roll_7d = _num(out, "actual_high_roll_7d_mean")
    roll_30d = _num(out, "actual_high_roll_30d_mean")

    warmup_to_consensus = provider_mean - observed_temp
    remaining_warmup = provider_mean - high_so_far
    out["v2_recent_heat_anomaly_f"] = lag_1d - roll_30d
    out["v2_recent_heat_momentum_f"] = roll_7d - roll_30d
    out["v2_morning_warmup_to_consensus_f"] = warmup_to_consensus
    out["v2_consensus_minus_7d_actual_f"] = provider_mean - roll_7d
    out["v2_spread_per_warmup_f"] = provider_spread / warmup_to_consensus.abs().clip(lower=1.0)
    out["v2_humidity_warmup_interaction"] = (observed_humidity / 100.0) * warmup_to_consensus
    out["v3_high_so_far_above_current_f"] = high_so_far - observed_temp
    out["v3_remaining_warmup_from_high_so_far_f"] = remaining_warmup
    out["v3_high_so_far_minus_lag_1d_f"] = high_so_far - lag_1d
    out["v3_high_so_far_minus_7d_actual_f"] = high_so_far - roll_7d
    out["v3_remaining_warmup_per_spread_f"] = remaining_warmup / provider_spread.abs().clip(lower=1.0)
    out["v3_humidity_remaining_warmup_interaction"] = (observed_humidity / 100.0) * remaining_warmup

    precip_total = _provider_matrix(out, "forecast_precip_total_mm", fallback="precip_amount")
    precip_max_1h = _provider_matrix(out, "forecast_precip_max_1h_mm")
    precip_hours = _provider_matrix(out, "forecast_precip_hours_count")
    precip_intensity = _provider_matrix(out, "forecast_precip_intensity_code")
    has_precip = _provider_matrix(out, "forecast_has_precip").fillna(0).clip(lower=0, upper=1)

    out["v4_forecast_precip_total_mean_mm"] = precip_total.mean(axis=1)
    out["v4_forecast_precip_total_max_mm"] = precip_total.max(axis=1)
    out["v4_forecast_precip_total_spread_mm"] = precip_total.max(axis=1) - precip_total.min(axis=1)
    out["v4_forecast_precip_max_1h_mean_mm"] = precip_max_1h.mean(axis=1)
    out["v4_forecast_precip_hours_mean"] = precip_hours.mean(axis=1)
    out["v4_forecast_precip_intensity_mean"] = precip_intensity.mean(axis=1)
    out["v4_forecast_precip_intensity_max"] = precip_intensity.max(axis=1)
    out["v4_any_forecast_precip"] = has_precip.max(axis=1).fillna(0).astype(int)
    out["v4_all_forecast_precip"] = has_precip.min(axis=1).fillna(0).astype(int)

    observed_any = (
        _bool_num(out, "observed_is_raining_at_as_of")
        | _bool_num(out, "observed_is_drizzle_at_as_of")
        | _bool_num(out, "observed_is_snowing_at_as_of")
    ).astype(int)
    observed_recent_mm = _num(out, "observed_precip_recent_at_as_of") * 25.4
    out["v4_observed_precip_any"] = observed_any
    out["v4_observed_precip_recent_mm_est"] = observed_recent_mm
    out["v4_forecast_total_minus_observed_recent_mm"] = out["v4_forecast_precip_total_mean_mm"] - observed_recent_mm
    out["v4_forecast_observed_precip_match"] = out["v4_any_forecast_precip"].eq(observed_any).astype(int)
    out["v4_forecast_wet_observed_dry"] = (out["v4_any_forecast_precip"].eq(1) & observed_any.eq(0)).astype(int)
    out["v4_observed_wet_forecast_dry"] = (observed_any.eq(1) & out["v4_any_forecast_precip"].eq(0)).astype(int)
    out["v4_precip_humidity_interaction"] = out["v4_forecast_precip_total_mean_mm"] * (observed_humidity / 100.0)
    out["v4_precip_remaining_warmup_interaction"] = out["v4_forecast_precip_total_mean_mm"] * remaining_warmup
    return out


if not hasattr(station_stacking_module, "_v4_original_build_station_wide_dataset"):
    station_stacking_module._v4_original_build_station_wide_dataset = station_stacking_module.build_station_wide_dataset


def build_station_wide_dataset_v4(*args, **kwargs):
    frame = station_stacking_module._v4_original_build_station_wide_dataset(*args, **kwargs)
    return add_v4_feature_engineering(frame)


station_stacking_module.build_station_wide_dataset = build_station_wide_dataset_v4
V4_FEATURE_COLUMNS
# Out:
# ['v2_recent_heat_anomaly_f',
#  'v2_recent_heat_momentum_f',
#  'v2_morning_warmup_to_consensus_f',
#  'v2_consensus_minus_7d_actual_f',
#  'v2_spread_per_warmup_f',
#  'v2_humidity_warmup_interaction',
#  'v3_high_so_far_above_current_f',
#  'v3_remaining_warmup_from_high_so_far_f',
#  'v3_high_so_far_minus_lag_1d_f',
#  'v3_high_so_far_minus_7d_actual_f',
#  'v3_remaining_warmup_per_spread_f',
#  'v3_humidity_remaining_warmup_interaction',
#  'v4_forecast_precip_total_mean_mm',
#  'v4_forecast_precip_total_max_mm',
#  'v4_forecast_precip_total_spread_mm',
#  'v4_forecast_precip_max_1h_mean_mm',
#  'v4_forecast_precip_hours_mean',
#  'v4_forecast_precip_intensity_mean',
#  'v4_forecast_precip_intensity_max',
#  'v4_any_forecast_precip',
#  'v4_all_forecast_precip',
#  'v4_observed_precip_any',
#  'v4_observed_precip_recent_mm_est',
#  'v4_forecast_total_minus_observed_recent_mm',
#  'v4_forecast_observed_precip_match',
#  'v4_forecast_wet_observed_dry',
#  'v4_observed_wet_forecast_dry',
#  'v4_precip_humidity_interaction',
#  'v4_precip_remaining_warmup_interaction']

# %% [markdown]
# ## Model Scores

# %%
missing_packages = missing_model_dependencies()
if missing_packages:
    raise ImportError(
        "Missing station-stacking ML packages: "
        + ", ".join(missing_packages)
        + ". Install them with: python -m pip install -r requirements.txt"
    )

config = StationStackingConfig(
    station_id=STATION_ID,
    project_root=PROJECT_ROOT,
    fast_mode=FAST_MODE,
    optuna_trials=OPTUNA_TRIALS,
    stack_optuna_trials=STACK_OPTUNA_TRIALS,
    optuna_verbose=OPTUNA_VERBOSE,
    output_dir=PROJECT_ROOT / "data" / "calibration" / "station_stacking_v4",
)
result = run_station_year_split_experiment(config)
result.scoreboard
# Out:
# [I 2026-06-09 06:28:59,833] A new study created in memory with name: no-name-a8b1ae18-ed3f-4873-8d49-fc2c9d0f46d7
# [I 2026-06-09 06:29:32,776] Trial 0 finished with value: 4.624031765009244 and parameters: {'n_estimators': 799, 'learning_rate': 0.12369619597856178, 'max_depth': 6, 'min_child_weight': 2.385234757844707, 'gamma': 0.7800932022121826, 'subsample': 0.5779972601681014, 'colsample_bytree': 0.5290418060840998, 'reg_alpha': 0.6245760287469893, 'reg_lambda': 0.6677615511747083}. Best is trial 0 with value: 4.624031765009244.
# [I 2026-06-09 06:31:49,561] Trial 1 finished with value: 4.5388478730519495 and parameters: {'n_estimators': 1440, 'learning_rate': 0.0032515743808034223, 'max_depth': 8, 'min_child_weight': 8.23143373099555, 'gamma': 1.0616955533913808, 'subsample': 0.5909124836035503, 'colsample_bytree': 0.5917022549267169, 'reg_alpha': 5.472429642032198e-06, 'reg_lambda': 0.2922905212920093}. Best is trial 1 with value: 4.5388478730519495.
# [I 2026-06-09 06:32:25,798] Trial 2 finished with value: 4.586401044937615 and parameters: {'n_estimators': 909, 'learning_rate': 0.009373695213782608, 'max_depth': 5, 'min_child_weight': 0.20940138873937433, 'gamma': 1.4607232426760908, 'subsample': 0.6831809216468459, 'colsample_bytree': 0.728034992108518, 'reg_alpha': 0.1165691561324743, 'reg_lambda': 0.008674832802525461}. Best is trial 1 with value: 4.5388478730519495.
# [I 2026-06-09 06:32:39,519] Trial 3 finished with value: 4.533188090433701 and parameters: {'n_estimators': 1067, 'learning_rate': 0.03045200113778571, 'max_depth': 1, 'min_child_weight': 2.5002240473339543, 'gamma': 0.8526206184364576, 'subsample': 0.5325257964926398, 'colsample_bytree': 0.9744427686266666, 'reg_alpha': 4.905556676028774, 'reg_lambda': 6.289771819487036}. Best is trial 3 with value: 4.533188090433701.
# [I 2026-06-09 06:33:55,016] Trial 4 finished with value: 4.56290205333399 and parameters: {'n_estimators': 665, 'learning_rate': 0.004396056309201638, 'max_depth': 6, 'min_child_weight': 1.0299214204601976, 'gamma': 0.6101911742238941, 'subsample': 0.7475884550556351, 'colsample_bytree': 0.5171942605576092, 'reg_alpha': 1.527156759251193, 'reg_lambda': 0.016443693426189242}. Best is trial 3 with value: 4.533188090433701.
# [I 2026-06-09 06:34:44,393] Trial 5 finished with value: 4.5395524680014905 and parameters: {'n_estimators': 1352, 'learning_rate': 0.010155680350355932, 'max_depth': 5, 'min_child_weight': 1.811326544803338, 'gamma': 0.9242722776276352, 'subsample': 0.9847923138822793, 'colsample_bytree': 0.8875664116805573, 'reg_alpha': 2.854239907497756, 'reg_lambda': 16.023850290194936}. Best is trial 3 with value: 4.533188090433701.
# [I 2026-06-09 06:34:46,573] Trial 6 finished with value: 4.559163729905867 and parameters: {'n_estimators': 1228, 'learning_rate': 0.11049889315270257, 'max_depth': 1, 'min_child_weight': 0.28246357083904894, 'gamma': 0.22613644455269033, 'subsample': 0.6626651653816322, 'colsample_bytree': 0.6943386448447411, 'reg_alpha': 2.7678419414850017e-06, 'reg_lambda': 7.838134236608707}. Best is trial 3 with value: 4.533188090433701.
# [I 2026-06-09 06:34:53,530] Trial 7 pruned.
# [I 2026-06-09 06:34:57,531] Trial 8 finished with value: 4.54605735037191 and parameters: {'n_estimators': 90, 'learning_rate': 0.07287285110476487, 'max_depth': 6, 'min_child_weight': 4.758470274910409, 'gamma': 3.8563517334297286, 'subsample': 0.5370223258670452, 'colsample_bytree': 0.6792328642721364, 'reg_alpha': 1.1036250149900698e-07, 'reg_lambda': 11.368341439732731}. Best is trial 3 with value: 4.533188090433701.
# [I 2026-06-09 06:35:07,964] Trial 9 pruned.
# [I 2026-06-09 06:35:16,520] Trial 10 finished with value: 4.542155999403998 and parameters: {'n_estimators': 1915, 'learning_rate': 0.036235378997051045, 'max_depth': 3, 'min_child_weight': 13.97101765312176, 'gamma': 2.828065453407016, 'subsample': 0.8211770829222278, 'colsample_bytree': 0.9805126451489784, 'reg_alpha': 0.0025347992375043043, 'reg_lambda': 2.1525808090182244}. Best is trial 3 with value: 4.533188090433701.
# [I 2026-06-09 06:35:27,333] Trial 11 pruned.
# [I 2026-06-09 06:37:25,731] Trial 12 finished with value: 4.546834169638263 and parameters: {'n_estimators': 1606, 'learning_rate': 0.003196962615028647, 'max_depth': 8, 'min_child_weight': 5.967787778328425, 'gamma': 2.5182196590789347, 'subsample': 0.5224078715805444, 'colsample_bytree': 0.8285397244388237, 'reg_alpha': 2.0057322817130592e-08, 'reg_lambda': 0.9111568610251692}. Best is trial 3 with value: 4.533188090433701.
# [I 2026-06-09 06:37:35,776] Trial 13 finished with value: 4.528209262211327 and parameters: {'n_estimators': 1067, 'learning_rate': 0.022426968689597045, 'max_depth': 3, 'min_child_weight': 4.27533932135294, 'gamma': 0.022350197382312254, 'subsample': 0.6223441463224711, 'colsample_bytree': 0.8910368801788895, 'reg_alpha': 0.0005372302104189243, 'reg_lambda': 48.823076726100275}. Best is trial 13 with value: 4.528209262211327.
# [I 2026-06-09 06:37:47,181] Trial 14 finished with value: 4.509454323099796 and parameters: {'n_estimators': 382, 'learning_rate': 0.021885090402504376, 'max_depth': 3, 'min_child_weight': 3.0699737306547434, 'gamma': 0.14095477974946344, 'subsample': 0.678482277529767, 'colsample_bytree': 0.9103716164395093, 'reg_alpha': 0.004633011838829117, 'reg_lambda': 27.485711044390538}. Best is trial 14 with value: 4.509454323099796.
# [I 2026-06-09 06:38:00,940] Trial 15 finished with value: 4.521816088583829 and parameters: {'n_estimators': 385, 'learning_rate': 0.02291465164772231, 'max_depth': 3, 'min_child_weight': 0.7823885185586986, 'gamma': 0.04364284939487721, 'subsample': 0.7275269073411381, 'colsample_bytree': 0.8945384164358526, 'reg_alpha': 0.003043263840972833, 'reg_lambda': 39.09721369856506}. Best is trial 14 with value: 4.509454323099796.
# [I 2026-06-09 06:38:07,423] Trial 16 pruned.
# [I 2026-06-09 06:38:12,482] Trial 17 finished with value: 4.520770139071828 and parameters: {'n_estimators': 451, 'learning_rate': 0.07414377784156938, 'max_depth': 2, 'min_child_weight': 1.2355852881109584, 'gamma': 1.3444674096557927, 'subsample': 0.71804991678614, 'colsample_bytree': 0.7715384664162471, 'reg_alpha': 0.01697102763060976, 'reg_lambda': 49.11689268933243}. Best is trial 14 with value: 4.509454323099796.
# [I 2026-06-09 06:38:14,505] Trial 18 pruned.
# [I 2026-06-09 06:38:16,739] Trial 19 pruned.
# [I 2026-06-09 06:38:25,701] Trial 20 finished with value: 4.5368063739325315 and parameters: {'n_estimators': 566, 'learning_rate': 0.046921650118120335, 'max_depth': 4, 'min_child_weight': 3.5174022273810164, 'gamma': 4.64051434116436, 'subsample': 0.6910044295424804, 'colsample_bytree': 0.9330402796023959, 'reg_alpha': 0.025572899774365766, 'reg_lambda': 3.7335423693796232}. Best is trial 14 with value: 4.509454323099796.
# [I 2026-06-09 06:38:35,673] Trial 21 finished with value: 4.529655394754423 and parameters: {'n_estimators': 334, 'learning_rate': 0.01681553929016707, 'max_depth': 2, 'min_child_weight': 0.5330870157620875, 'gamma': 0.33097260344055346, 'subsample': 0.7419786625049484, 'colsample_bytree': 0.8435113793595451, 'reg_alpha': 0.004889580824509903, 'reg_lambda': 47.44323426729263}. Best is trial 14 with value: 4.509454323099796.
# [I 2026-06-09 06:38:46,057] Trial 22 finished with value: 4.538315973444753 and parameters: {'n_estimators': 370, 'learning_rate': 0.022017282595654296, 'max_depth': 4, 'min_child_weight': 1.0849862922424107, 'gamma': 1.244253838491003, 'subsample': 0.7821581812768248, 'colsample_bytree': 0.9287424922366181, 'reg_alpha': 0.0161938269776464, 'reg_lambda': 20.53786717743074}. Best is trial 14 with value: 4.509454323099796.
# [I 2026-06-09 06:38:48,163] Trial 23 pruned.
# [I 2026-06-09 06:38:57,551] Trial 24 pruned.
# [I 2026-06-09 06:39:08,416] Trial 25 finished with value: 4.5239482264531965 and parameters: {'n_estimators': 645, 'learning_rate': 0.044650445858528245, 'max_depth': 3, 'min_child_weight': 1.066811552486563, 'gamma': 1.2250007335935684, 'subsample': 0.8117414369429699, 'colsample_bytree': 0.8637065004274426, 'reg_alpha': 0.0006447273005711484, 'reg_lambda': 6.533012663235805}. Best is trial 14 with value: 4.509454323099796.
# [I 2026-06-09 06:39:17,428] Trial 26 pruned.
# [I 2026-06-09 06:39:23,645] Trial 27 pruned.
# [I 2026-06-09 06:39:31,509] Trial 28 pruned.
# [I 2026-06-09 06:39:34,527] Trial 29 pruned.
# [I 2026-06-09 06:39:47,157] Trial 30 finished with value: 4.558326805578101 and parameters: {'n_estimators': 720, 'learning_rate': 0.0862633328276375, 'max_depth': 7, 'min_child_weight': 0.8226777100115893, 'gamma': 0.773867434109565, 'subsample': 0.5859368086055616, 'colsample_bytree': 0.8513592590532997, 'reg_alpha': 0.026769006723320256, 'reg_lambda': 13.686514903633586}. Best is trial 14 with value: 4.509454323099796.
# [I 2026-06-09 06:39:56,262] Trial 31 finished with value: 4.517326441949649 and parameters: {'n_estimators': 614, 'learning_rate': 0.043177128373680304, 'max_depth': 3, 'min_child_weight': 1.2080415498216657, 'gamma': 1.095474707475105, 'subsample': 0.8096647568345656, 'colsample_bytree': 0.8658446821880998, 'reg_alpha': 0.0005922277149149404, 'reg_lambda': 7.641315331077203}. Best is trial 14 with value: 4.509454323099796.
# [I 2026-06-09 06:40:00,621] Trial 32 pruned.
# [I 2026-06-09 06:40:06,420] Trial 33 pruned.
# [I 2026-06-09 06:40:12,743] Trial 34 pruned.
# [I 2026-06-09 06:40:24,933] Trial 35 finished with value: 4.519008002422408 and parameters: {'n_estimators': 468, 'learning_rate': 0.016405348098824473, 'max_depth': 3, 'min_child_weight': 0.6814472585185537, 'gamma': 0.7640085304043431, 'subsample': 0.6865643330853571, 'colsample_bytree': 0.9617408721751677, 'reg_alpha': 0.34254522095407425, 'reg_lambda': 9.129007798283167}. Best is trial 14 with value: 4.509454323099796.
# [I 2026-06-09 06:40:41,899] Trial 36 finished with value: 4.541551590576586 and parameters: {'n_estimators': 768, 'learning_rate': 0.015297513792290484, 'max_depth': 5, 'min_child_weight': 1.2550151782215966, 'gamma': 1.5711967936748796, 'subsample': 0.6733526351356526, 'colsample_bytree': 0.9554534387959492, 'reg_alpha': 0.2878313828616268, 'reg_lambda': 7.438981371888765}. Best is trial 14 with value: 4.509454323099796.
# [I 2026-06-09 06:40:52,689] Trial 37 finished with value: 4.527945853992502 and parameters: {'n_estimators': 459, 'learning_rate': 0.02922522826423679, 'max_depth': 2, 'min_child_weight': 7.087102920578617, 'gamma': 0.8043886105736355, 'subsample': 0.6299038086330898, 'colsample_bytree': 0.5567598685384798, 'reg_alpha': 6.865727594660676, 'reg_lambda': 0.5185603434391582}. Best is trial 14 with value: 4.509454323099796.
# [I 2026-06-09 06:40:57,827] Trial 38 pruned.
# [I 2026-06-09 06:41:03,740] Trial 39 pruned.
# [I 2026-06-09 06:41:25,291] Trial 40 finished with value: 4.536675614644362 and parameters: {'n_estimators': 833, 'learning_rate': 0.037107344497180325, 'max_depth': 5, 'min_child_weight': 3.487691796602965, 'gamma': 0.6769234458972193, 'subsample': 0.5560330680929269, 'colsample_bytree': 0.9579997038502878, 'reg_alpha': 0.007278568401834729, 'reg_lambda': 8.637208784839038}. Best is trial 14 with value: 4.509454323099796.
# [I 2026-06-09 06:41:49,696] Trial 41 finished with value: 4.516982770807381 and parameters: {'n_estimators': 384, 'learning_rate': 0.012623411668825916, 'max_depth': 3, 'min_child_weight': 0.7584196850101487, 'gamma': 0.21613759079914185, 'subsample': 0.7218152280602518, 'colsample_bytree': 0.8641435848440056, 'reg_alpha': 1.8563267577896132, 'reg_lambda': 19.956984305868655}. Best is trial 14 with value: 4.509454323099796.
# [I 2026-06-09 06:42:24,143] Trial 42 finished with value: 4.511875910081873 and parameters: {'n_estimators': 687, 'learning_rate': 0.007631920443238709, 'max_depth': 3, 'min_child_weight': 0.627390504388291, 'gamma': 0.9145920487684577, 'subsample': 0.6504589941704513, 'colsample_bytree': 0.7866201095562748, 'reg_alpha': 2.628186308061223, 'reg_lambda': 16.635762958489806}. Best is trial 14 with value: 4.509454323099796.
# [I 2026-06-09 06:42:52,986] Trial 43 finished with value: 4.5106200944000605 and parameters: {'n_estimators': 675, 'learning_rate': 0.0074556722014462885, 'max_depth': 3, 'min_child_weight': 0.6592636855718152, 'gamma': 0.39172061885523624, 'subsample': 0.6513347784492287, 'colsample_bytree': 0.8663083723051138, 'reg_alpha': 2.070083303390298, 'reg_lambda': 16.264054417575238}. Best is trial 14 with value: 4.509454323099796.
# [I 2026-06-09 06:43:32,950] Trial 44 finished with value: 4.510588731568076 and parameters: {'n_estimators': 694, 'learning_rate': 0.007317932454945732, 'max_depth': 3, 'min_child_weight': 0.4157599855541319, 'gamma': 0.37036421417710574, 'subsample': 0.6518559194917479, 'colsample_bytree': 0.8657342718149007, 'reg_alpha': 1.8259863009010768, 'reg_lambda': 16.040471327798958}. Best is trial 14 with value: 4.509454323099796.
# [I 2026-06-09 06:44:15,231] Trial 45 finished with value: 4.524890308120051 and parameters: {'n_estimators': 694, 'learning_rate': 0.007081659124172866, 'max_depth': 4, 'min_child_weight': 0.153744273586397, 'gamma': 0.3566835486060846, 'subsample': 0.6459035591898032, 'colsample_bytree': 0.8031305293766307, 'reg_alpha': 2.1928422186715912, 'reg_lambda': 17.70596453036469}. Best is trial 14 with value: 4.509454323099796.
# [I 2026-06-09 06:45:09,163] Trial 46 finished with value: 4.508933659574911 and parameters: {'n_estimators': 1134, 'learning_rate': 0.004161353426319833, 'max_depth': 3, 'min_child_weight': 0.3525710502060431, 'gamma': 0.23563382531546245, 'subsample': 0.6069218899747112, 'colsample_bytree': 0.8364291993472862, 'reg_alpha': 1.0124176691535824, 'reg_lambda': 16.391777213522193}. Best is trial 46 with value: 4.508933659574911.
# [I 2026-06-09 06:46:07,545] Trial 47 pruned.
# [I 2026-06-09 06:46:37,110] Trial 48 pruned.
# [I 2026-06-09 06:46:59,115] Trial 49 pruned.
# [I 2026-06-09 06:47:34,403] Trial 50 pruned.
# [I 2026-06-09 06:47:53,642] Trial 51 finished with value: 4.512174668848497 and parameters: {'n_estimators': 1162, 'learning_rate': 0.011791928308005822, 'max_depth': 3, 'min_child_weight': 0.8797386945680562, 'gamma': 0.37014117157112836, 'subsample': 0.6613981517347878, 'colsample_bytree': 0.8723089761431386, 'reg_alpha': 2.2367800825812654, 'reg_lambda': 15.283203310976218}. Best is trial 46 with value: 4.508933659574911.
# [I 2026-06-09 06:48:50,867] Trial 52 finished with value: 4.512854572337768 and parameters: {'n_estimators': 1100, 'learning_rate': 0.00538031506172516, 'max_depth': 3, 'min_child_weight': 0.33597425705204154, 'gamma': 0.43742079156135627, 'subsample': 0.663087150129661, 'colsample_bytree': 0.8827483944082012, 'reg_alpha': 0.12476363071313451, 'reg_lambda': 14.705137967457302}. Best is trial 46 with value: 4.508933659574911.
# [I 2026-06-09 06:49:32,833] Trial 53 finished with value: 4.513342997349685 and parameters: {'n_estimators': 1226, 'learning_rate': 0.008561489180798179, 'max_depth': 3, 'min_child_weight': 0.22359286665245526, 'gamma': 0.3108698226331289, 'subsample': 0.6226668713110719, 'colsample_bytree': 0.8555587168469615, 'reg_alpha': 2.767273165671379, 'reg_lambda': 30.149269223543083}. Best is trial 46 with value: 4.508933659574911.
# [I 2026-06-09 06:50:01,539] Trial 54 finished with value: 4.512640545437423 and parameters: {'n_estimators': 1010, 'learning_rate': 0.01074450561810284, 'max_depth': 4, 'min_child_weight': 0.9005524631593268, 'gamma': 0.5698334862282554, 'subsample': 0.5681901596303975, 'colsample_bytree': 0.8296511118122756, 'reg_alpha': 0.9994884036891398, 'reg_lambda': 12.294946233529602}. Best is trial 46 with value: 4.508933659574911.
# [I 2026-06-09 06:50:30,044] Trial 55 pruned.
# [I 2026-06-09 06:50:57,205] Trial 56 pruned.
# [I 2026-06-09 06:51:17,094] Trial 57 pruned.
# [I 2026-06-09 06:51:59,504] Trial 58 finished with value: 4.510975796079469 and parameters: {'n_estimators': 782, 'learning_rate': 0.007318485984679725, 'max_depth': 3, 'min_child_weight': 0.31236904824979667, 'gamma': 0.4123086610212334, 'subsample': 0.6673403804364205, 'colsample_bytree': 0.9119920707604526, 'reg_alpha': 1.585568141800922, 'reg_lambda': 16.866412027421863}. Best is trial 46 with value: 4.508933659574911.
# [I 2026-06-09 06:52:20,995] Trial 59 pruned.
# [I 2026-06-09 06:52:53,595] Trial 60 finished with value: 4.51484282945292 and parameters: {'n_estimators': 694, 'learning_rate': 0.009253629365041703, 'max_depth': 4, 'min_child_weight': 0.2561669966302197, 'gamma': 4.992682327877372, 'subsample': 0.7021686434446401, 'colsample_bytree': 0.8972569083841544, 'reg_alpha': 8.854746459348993, 'reg_lambda': 20.100944754653618}. Best is trial 46 with value: 4.508933659574911.
# [I 2026-06-09 06:54:10,611] Trial 61 finished with value: 4.518092054223979 and parameters: {'n_estimators': 1300, 'learning_rate': 0.0030547730764012306, 'max_depth': 3, 'min_child_weight': 0.5265761258112368, 'gamma': 0.3426585244301338, 'subsample': 0.6540254681568477, 'colsample_bytree': 0.8799040892376365, 'reg_alpha': 2.447041775076062, 'reg_lambda': 15.660123765948939}. Best is trial 46 with value: 4.508933659574911.
# [I 2026-06-09 06:54:33,360] Trial 62 finished with value: 4.519618681469375 and parameters: {'n_estimators': 1179, 'learning_rate': 0.012227440848103382, 'max_depth': 3, 'min_child_weight': 0.9283885544389413, 'gamma': 0.43850781992613075, 'subsample': 0.6751021557383264, 'colsample_bytree': 0.9377699444213382, 'reg_alpha': 0.5754926742276412, 'reg_lambda': 31.61027938879959}. Best is trial 46 with value: 4.508933659574911.
# [I 2026-06-09 06:54:52,627] Trial 63 finished with value: 4.515873459414348 and parameters: {'n_estimators': 1025, 'learning_rate': 0.01001713679819812, 'max_depth': 3, 'min_child_weight': 0.5698523295106777, 'gamma': 0.6976132879406614, 'subsample': 0.6345081623932995, 'colsample_bytree': 0.9054891431611262, 'reg_alpha': 3.721766840816234, 'reg_lambda': 10.280981040629687}. Best is trial 46 with value: 4.508933659574911.
# [I 2026-06-09 06:55:20,675] Trial 64 finished with value: 4.512520220963138 and parameters: {'n_estimators': 550, 'learning_rate': 0.007537451868059803, 'max_depth': 3, 'min_child_weight': 0.22280215317132315, 'gamma': 0.1763461949914444, 'subsample': 0.6076203689774653, 'colsample_bytree': 0.7029543397055861, 'reg_alpha': 0.18072475685237188, 'reg_lambda': 15.574626345700455}. Best is trial 46 with value: 4.508933659574911.
# [I 2026-06-09 06:55:39,442] Trial 65 pruned.
# [I 2026-06-09 06:56:33,171] Trial 66 finished with value: 4.524838174272301 and parameters: {'n_estimators': 1408, 'learning_rate': 0.004598962116652958, 'max_depth': 4, 'min_child_weight': 0.3397866728053584, 'gamma': 0.8774963542712312, 'subsample': 0.7399504582061935, 'colsample_bytree': 0.841806740671269, 'reg_alpha': 0.04243790055437454, 'reg_lambda': 9.876047360356912}. Best is trial 46 with value: 4.508933659574911.
# [I 2026-06-09 06:56:51,492] Trial 67 finished with value: 4.510720105256394 and parameters: {'n_estimators': 1312, 'learning_rate': 0.0115710169373487, 'max_depth': 3, 'min_child_weight': 0.7293006880653274, 'gamma': 1.2146768418056035, 'subsample': 0.6597647132028184, 'colsample_bytree': 0.8189074102338895, 'reg_alpha': 4.50593458354125, 'reg_lambda': 5.082381886318642}. Best is trial 46 with value: 4.508933659574911.
# [I 2026-06-09 06:56:58,105] Trial 68 pruned.
# [I 2026-06-09 06:57:09,742] Trial 69 pruned.
# [I 2026-06-09 06:57:41,407] Trial 70 finished with value: 4.528564034078698 and parameters: {'n_estimators': 1450, 'learning_rate': 0.005511437800855551, 'max_depth': 4, 'min_child_weight': 5.254047825929145, 'gamma': 1.6172999832381971, 'subsample': 0.6424428399104256, 'colsample_bytree': 0.7670026399719215, 'reg_alpha': 6.712746233396649, 'reg_lambda': 1.8651057473010542}. Best is trial 46 with value: 4.508933659574911.
# [I 2026-06-09 06:58:00,573] Trial 71 finished with value: 4.513529678775928 and parameters: {'n_estimators': 928, 'learning_rate': 0.011414364604247027, 'max_depth': 3, 'min_child_weight': 0.4226243292840171, 'gamma': 0.44190655287366665, 'subsample': 0.6604406727856229, 'colsample_bytree': 0.8688605061845072, 'reg_alpha': 1.4244108010843632, 'reg_lambda': 22.543101419844426}. Best is trial 46 with value: 4.508933659574911.
# [I 2026-06-09 06:58:18,633] Trial 72 finished with value: 4.52098067047597 and parameters: {'n_estimators': 1481, 'learning_rate': 0.00816409612207446, 'max_depth': 3, 'min_child_weight': 0.7163903755572958, 'gamma': 0.14197778036296826, 'subsample': 0.6786577905816351, 'colsample_bytree': 0.8518930125694935, 'reg_alpha': 4.014778349474461, 'reg_lambda': 5.859243683151496}. Best is trial 46 with value: 4.508933659574911.
# [I 2026-06-09 06:58:25,235] Trial 73 pruned.
# [I 2026-06-09 06:58:40,903] Trial 74 finished with value: 4.510370083075372 and parameters: {'n_estimators': 582, 'learning_rate': 0.01436496419524569, 'max_depth': 3, 'min_child_weight': 0.5354381588662719, 'gamma': 0.30706683409861685, 'subsample': 0.6222498014349278, 'colsample_bytree': 0.8269677401674377, 'reg_alpha': 9.938679421438342, 'reg_lambda': 13.571321301811972}. Best is trial 46 with value: 4.508933659574911.
# [I 2026-06-09 06:58:57,398] Trial 75 pruned.
# [I 2026-06-09 06:59:00,897] Trial 76 pruned.
# [I 2026-06-09 06:59:10,426] Trial 77 finished with value: 4.514884489769704 and parameters: {'n_estimators': 532, 'learning_rate': 0.025844078327195808, 'max_depth': 3, 'min_child_weight': 0.588804898251123, 'gamma': 0.6386854240450315, 'subsample': 0.5457472533110711, 'colsample_bytree': 0.8080442808537901, 'reg_alpha': 0.1977989052504049, 'reg_lambda': 23.791982942142848}. Best is trial 46 with value: 4.508933659574911.
# [I 2026-06-09 06:59:17,347] Trial 78 pruned.
# [I 2026-06-09 06:59:22,350] Trial 79 pruned.
# [I 2026-06-09 06:59:39,677] Trial 80 finished with value: 4.527335151163248 and parameters: {'n_estimators': 800, 'learning_rate': 0.010292954160625773, 'max_depth': 4, 'min_child_weight': 15.574606925309778, 'gamma': 1.2759989590085967, 'subsample': 0.6385125813520821, 'colsample_bytree': 0.9149109805975775, 'reg_alpha': 1.3930132095867664, 'reg_lambda': 9.006898594020486}. Best is trial 46 with value: 4.508933659574911.
# [I 2026-06-09 06:59:54,941] Trial 81 finished with value: 4.515258813991712 and parameters: {'n_estimators': 1168, 'learning_rate': 0.011293767247735035, 'max_depth': 3, 'min_child_weight': 0.6106016460905533, 'gamma': 0.4004082880375445, 'subsample': 0.6662956176357209, 'colsample_bytree': 0.8596303832315182, 'reg_alpha': 2.4197488458710605, 'reg_lambda': 17.127807308184714}. Best is trial 46 with value: 4.508933659574911.
# [I 2026-06-09 06:59:57,554] Trial 82 pruned.
# [I 2026-06-09 07:00:12,640] Trial 83 finished with value: 4.5113698247268434 and parameters: {'n_estimators': 879, 'learning_rate': 0.006926907645659024, 'max_depth': 3, 'min_child_weight': 0.47986270051473945, 'gamma': 0.5734309533670918, 'subsample': 0.7096233391311447, 'colsample_bytree': 0.9397249158276682, 'reg_alpha': 4.661142344411642, 'reg_lambda': 24.307658141461978}. Best is trial 46 with value: 4.508933659574911.
# [I 2026-06-09 07:00:39,780] Trial 84 finished with value: 4.505378281794103 and parameters: {'n_estimators': 860, 'learning_rate': 0.006776498761247959, 'max_depth': 3, 'min_child_weight': 0.39428218827027894, 'gamma': 0.571333489782011, 'subsample': 0.7377772146128854, 'colsample_bytree': 0.9403997978541865, 'reg_alpha': 6.041134343304473, 'reg_lambda': 20.84821062253244}. Best is trial 84 with value: 4.505378281794103.
# [I 2026-06-09 07:01:10,426] Trial 85 finished with value: 4.515515710867543 and parameters: {'n_estimators': 858, 'learning_rate': 0.006425364974873158, 'max_depth': 3, 'min_child_weight': 0.2534177806115612, 'gamma': 0.5201429524305887, 'subsample': 0.736812545842769, 'colsample_bytree': 0.9444427085919047, 'reg_alpha': 5.757553442209928, 'reg_lambda': 34.97256887419064}. Best is trial 84 with value: 4.505378281794103.
# [I 2026-06-09 07:01:35,981] Trial 86 pruned.
# [I 2026-06-09 07:01:47,254] Trial 87 pruned.
# [I 2026-06-09 07:01:59,378] Trial 88 finished with value: 4.508422733567012 and parameters: {'n_estimators': 611, 'learning_rate': 0.007293675125464287, 'max_depth': 3, 'min_child_weight': 0.48540733701290806, 'gamma': 2.026486253385521, 'subsample': 0.7302483024834336, 'colsample_bytree': 0.9653001184788984, 'reg_alpha': 1.0710968058894113, 'reg_lambda': 21.400362615578008}. Best is trial 84 with value: 4.505378281794103.
# [I 2026-06-09 07:02:16,992] Trial 89 finished with value: 4.521099896560124 and parameters: {'n_estimators': 609, 'learning_rate': 0.008851018004468672, 'max_depth': 3, 'min_child_weight': 0.37939620534091695, 'gamma': 2.0004275409869674, 'subsample': 0.7126535998602794, 'colsample_bytree': 0.96872843166358, 'reg_alpha': 9.52327149578638, 'reg_lambda': 6.25975420395825}. Best is trial 84 with value: 4.505378281794103.
# [I 2026-06-09 07:02:30,660] Trial 90 pruned.
# [I 2026-06-09 07:02:51,549] Trial 91 finished with value: 4.506208759135614 and parameters: {'n_estimators': 719, 'learning_rate': 0.006986086958317962, 'max_depth': 3, 'min_child_weight': 0.47019625942288984, 'gamma': 0.7404292541302975, 'subsample': 0.7098299506825738, 'colsample_bytree': 0.9458328513369837, 'reg_alpha': 4.52184617153583, 'reg_lambda': 20.91860774529903}. Best is trial 84 with value: 4.505378281794103.
# [I 2026-06-09 07:03:06,516] Trial 92 pruned.
# [I 2026-06-09 07:03:23,483] Trial 93 finished with value: 4.512594553252148 and parameters: {'n_estimators': 628, 'learning_rate': 0.0077755493900096674, 'max_depth': 3, 'min_child_weight': 0.29100929609054565, 'gamma': 2.664661022309002, 'subsample': 0.7231564493941918, 'colsample_bytree': 0.9910650657383417, 'reg_alpha': 0.4250767402871839, 'reg_lambda': 13.20313698888255}. Best is trial 84 with value: 4.505378281794103.
# [I 2026-06-09 07:03:33,960] Trial 94 pruned.
# [I 2026-06-09 07:03:42,866] Trial 95 pruned.
# [I 2026-06-09 07:03:59,943] Trial 96 finished with value: 4.5152819415890715 and parameters: {'n_estimators': 525, 'learning_rate': 0.009384061949941873, 'max_depth': 3, 'min_child_weight': 0.5466526423417936, 'gamma': 0.30059227740277583, 'subsample': 0.6261173957100661, 'colsample_bytree': 0.9074175516587317, 'reg_alpha': 0.2988718110764831, 'reg_lambda': 10.217928598822615}. Best is trial 84 with value: 4.505378281794103.
# [I 2026-06-09 07:04:18,701] Trial 97 pruned.
# [I 2026-06-09 07:04:28,480] Trial 98 pruned.
# [I 2026-06-09 07:04:37,591] Trial 99 pruned.
# [I 2026-06-09 07:04:37,597] A new study created in memory with name: no-name-5ad895cc-73f5-41d2-b429-598dba484e5b
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:04:44,664] Trial 0 finished with value: 4.5421057345479126 and parameters: {'n_estimators': 301, 'learning_rate': 0.03250177171527344, 'num_leaves': 37, 'max_depth': 4, 'min_child_samples': 52, 'min_split_gain': 1.7182749818971954, 'bagging_fraction': 0.8330451065490129, 'bagging_freq': 4, 'feature_fraction': 0.5145069122121801, 'lambda_l1': 0.04015454105555427, 'lambda_l2': 0.07175601133819473}. Best is trial 0 with value: 4.5421057345479126.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:05:18,079] Trial 1 finished with value: 4.50923989221703 and parameters: {'n_estimators': 1620, 'learning_rate': 0.008116618171663207, 'num_leaves': 18, 'max_depth': 9, 'min_child_samples': 37, 'min_split_gain': 0.8099788960945193, 'bagging_fraction': 0.6580482355091044, 'bagging_freq': 1, 'feature_fraction': 0.9216123471148523, 'lambda_l1': 0.43697071238567825, 'lambda_l2': 36.7185332724254}. Best is trial 1 with value: 4.50923989221703.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:05:28,866] Trial 2 finished with value: 4.537947517512442 and parameters: {'n_estimators': 820, 'learning_rate': 0.1255359023925396, 'num_leaves': 116, 'max_depth': 8, 'min_child_samples': 17, 'min_split_gain': 1.7941971599630686, 'bagging_fraction': 0.6490017503443813, 'bagging_freq': 2, 'feature_fraction': 0.5025647745322285, 'lambda_l1': 0.0007741455782248723, 'lambda_l2': 0.1717169091593679}. Best is trial 1 with value: 4.50923989221703.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:05:32,766] Trial 3 finished with value: 4.57855387846262 and parameters: {'n_estimators': 1302, 'learning_rate': 0.13774020868800516, 'num_leaves': 233, 'max_depth': 10, 'min_child_samples': 81, 'min_split_gain': 0.2080378997095258, 'bagging_fraction': 0.5904572976289505, 'bagging_freq': 7, 'feature_fraction': 0.7059764916931793, 'lambda_l1': 0.6097531961875766, 'lambda_l2': 1.4405915859050216}. Best is trial 1 with value: 4.50923989221703.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:05:43,557] Trial 4 finished with value: 4.520563115714592 and parameters: {'n_estimators': 1287, 'learning_rate': 0.008816320113501107, 'num_leaves': 230, 'max_depth': 3, 'min_child_samples': 64, 'min_split_gain': 1.987144984788207, 'bagging_fraction': 0.8678635407535604, 'bagging_freq': 4, 'feature_fraction': 0.7803315847218675, 'lambda_l1': 5.026890229380336e-05, 'lambda_l2': 2.6067223030440956}. Best is trial 1 with value: 4.50923989221703.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:05:44,690] Trial 5 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:05:55,892] Trial 6 finished with value: 4.527482499562338 and parameters: {'n_estimators': 357, 'learning_rate': 0.014569059433190092, 'num_leaves': 82, 'max_depth': 4, 'min_child_samples': 90, 'min_split_gain': 0.4906865059267196, 'bagging_fraction': 0.8738853058964315, 'bagging_freq': 6, 'feature_fraction': 0.8476304334775464, 'lambda_l1': 8.407851008403197e-08, 'lambda_l2': 27.173617934406668}. Best is trial 1 with value: 4.50923989221703.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:05:57,732] Trial 7 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:05:59,814] Trial 8 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:06:20,458] Trial 9 finished with value: 4.519386519293672 and parameters: {'n_estimators': 1265, 'learning_rate': 0.004494838277163318, 'num_leaves': 127, 'max_depth': 2, 'min_child_samples': 50, 'min_split_gain': 1.50407937273205, 'bagging_fraction': 0.8577495432640323, 'bagging_freq': 7, 'feature_fraction': 0.8884476833543847, 'lambda_l1': 8.650807236918189e-07, 'lambda_l2': 17.882672893320727}. Best is trial 1 with value: 4.50923989221703.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:06:39,000] Trial 10 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:06:58,822] Trial 11 finished with value: 4.516605220010526 and parameters: {'n_estimators': 1684, 'learning_rate': 0.003932565195639531, 'num_leaves': 154, 'max_depth': 2, 'min_child_samples': 34, 'min_split_gain': 1.192541113252593, 'bagging_fraction': 0.7368592807094115, 'bagging_freq': 2, 'feature_fraction': 0.8886149382835806, 'lambda_l1': 3.1400027620721226e-05, 'lambda_l2': 29.005055588794846}. Best is trial 1 with value: 4.50923989221703.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:07:32,270] Trial 12 finished with value: 4.512700895825702 and parameters: {'n_estimators': 1896, 'learning_rate': 0.007304568974673966, 'num_leaves': 157, 'max_depth': 5, 'min_child_samples': 25, 'min_split_gain': 1.0122335453146316, 'bagging_fraction': 0.7338908269532369, 'bagging_freq': 2, 'feature_fraction': 0.8647257586763794, 'lambda_l1': 8.352295408784519e-05, 'lambda_l2': 37.776217585625325}. Best is trial 1 with value: 4.50923989221703.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:07:59,303] Trial 13 finished with value: 4.514098899344416 and parameters: {'n_estimators': 1761, 'learning_rate': 0.008711758097438481, 'num_leaves': 89, 'max_depth': 5, 'min_child_samples': 29, 'min_split_gain': 0.8779269362510127, 'bagging_fraction': 0.7272747585171591, 'bagging_freq': 1, 'feature_fraction': 0.8004327757686055, 'lambda_l1': 0.05956935567163238, 'lambda_l2': 5.580054800439067}. Best is trial 1 with value: 4.50923989221703.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:08:34,143] Trial 14 finished with value: 4.507564917206673 and parameters: {'n_estimators': 1657, 'learning_rate': 0.008221145253883195, 'num_leaves': 183, 'max_depth': 10, 'min_child_samples': 32, 'min_split_gain': 0.8268705628054354, 'bagging_fraction': 0.7457588620713497, 'bagging_freq': 2, 'feature_fraction': 0.9902728190691636, 'lambda_l1': 0.000631261676641598, 'lambda_l2': 9.58727815020148}. Best is trial 14 with value: 4.507564917206673.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:08:39,051] Trial 15 finished with value: 4.516611108440564 and parameters: {'n_estimators': 1585, 'learning_rate': 0.01623956607898928, 'num_leaves': 4, 'max_depth': 10, 'min_child_samples': 46, 'min_split_gain': 0.6613717319107411, 'bagging_fraction': 0.6870843323765002, 'bagging_freq': 3, 'feature_fraction': 0.9944222922519299, 'lambda_l1': 7.825611774032637, 'lambda_l2': 6.312465219324817}. Best is trial 14 with value: 4.507564917206673.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:08:44,040] Trial 16 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:08:59,758] Trial 17 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:09:24,647] Trial 18 finished with value: 4.54446767777233 and parameters: {'n_estimators': 1999, 'learning_rate': 0.02234678988335671, 'num_leaves': 197, 'max_depth': 8, 'min_child_samples': 10, 'min_split_gain': 0.7055304895755102, 'bagging_fraction': 0.6463313547470437, 'bagging_freq': 3, 'feature_fraction': 0.7941838671736351, 'lambda_l1': 0.00042802063863740586, 'lambda_l2': 3.922762476822346}. Best is trial 14 with value: 4.507564917206673.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:09:40,463] Trial 19 finished with value: 4.506302723252611 and parameters: {'n_estimators': 971, 'learning_rate': 0.01097372779179168, 'num_leaves': 254, 'max_depth': 10, 'min_child_samples': 43, 'min_split_gain': 1.2274536308982895, 'bagging_fraction': 0.5029695539555286, 'bagging_freq': 2, 'feature_fraction': 0.9451751205966394, 'lambda_l1': 0.8143995366336685, 'lambda_l2': 0.0013689290677315192}. Best is trial 19 with value: 4.506302723252611.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:09:43,948] Trial 20 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:10:11,123] Trial 21 finished with value: 4.510961070604366 and parameters: {'n_estimators': 1169, 'learning_rate': 0.005458434611674242, 'num_leaves': 256, 'max_depth': 9, 'min_child_samples': 37, 'min_split_gain': 0.6977913697741558, 'bagging_fraction': 0.5389922221927379, 'bagging_freq': 1, 'feature_fraction': 0.9257531762217541, 'lambda_l1': 1.1905827180857214, 'lambda_l2': 0.016737782315617573}. Best is trial 19 with value: 4.506302723252611.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:10:32,820] Trial 22 finished with value: 4.504762045824692 and parameters: {'n_estimators': 1012, 'learning_rate': 0.01027874343383628, 'num_leaves': 207, 'max_depth': 8, 'min_child_samples': 45, 'min_split_gain': 0.9464834834976228, 'bagging_fraction': 0.794797506610823, 'bagging_freq': 2, 'feature_fraction': 0.9566670801090331, 'lambda_l1': 0.03649545740359437, 'lambda_l2': 0.00411287158079664}. Best is trial 22 with value: 4.504762045824692.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:10:45,523] Trial 23 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:11:10,567] Trial 24 finished with value: 4.535142847962648 and parameters: {'n_estimators': 565, 'learning_rate': 0.02256838682338415, 'num_leaves': 167, 'max_depth': 10, 'min_child_samples': 20, 'min_split_gain': 1.296976927325186, 'bagging_fraction': 0.7752977005200488, 'bagging_freq': 2, 'feature_fraction': 0.8412851577581442, 'lambda_l1': 0.004550103528416494, 'lambda_l2': 0.003877023645564371}. Best is trial 22 with value: 4.504762045824692.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:11:18,674] Trial 25 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:11:20,203] Trial 26 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:11:31,954] Trial 27 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:11:40,673] Trial 28 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:11:46,187] Trial 29 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:11:54,998] Trial 30 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:12:22,507] Trial 31 finished with value: 4.508063565476522 and parameters: {'n_estimators': 1426, 'learning_rate': 0.008713528093367104, 'num_leaves': 104, 'max_depth': 9, 'min_child_samples': 42, 'min_split_gain': 0.8026379773640002, 'bagging_fraction': 0.6480636846051251, 'bagging_freq': 1, 'feature_fraction': 0.9229119604034773, 'lambda_l1': 0.5594695832262944, 'lambda_l2': 0.0550829136250097}. Best is trial 22 with value: 4.504762045824692.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:12:34,868] Trial 32 finished with value: 4.500932923543982 and parameters: {'n_estimators': 1388, 'learning_rate': 0.009882725679531109, 'num_leaves': 103, 'max_depth': 10, 'min_child_samples': 44, 'min_split_gain': 0.7871702164339509, 'bagging_fraction': 0.5452671600951998, 'bagging_freq': 1, 'feature_fraction': 0.917430684390504, 'lambda_l1': 1.7268646143262665, 'lambda_l2': 0.049816209295985694}. Best is trial 32 with value: 4.500932923543982.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:12:59,703] Trial 33 finished with value: 4.493124800328882 and parameters: {'n_estimators': 1128, 'learning_rate': 0.010899223405027412, 'num_leaves': 142, 'max_depth': 10, 'min_child_samples': 32, 'min_split_gain': 1.2222620793330392, 'bagging_fraction': 0.5605741823716082, 'bagging_freq': 2, 'feature_fraction': 0.9718462485699584, 'lambda_l1': 3.329046632979221, 'lambda_l2': 0.0022674709680076226}. Best is trial 33 with value: 4.493124800328882.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:13:23,273] Trial 34 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:13:37,526] Trial 35 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:13:57,628] Trial 36 pruned.
# ...
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 08:03:32,473] Trial 96 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 08:03:44,819] Trial 97 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 08:03:57,220] Trial 98 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 08:04:04,244] Trial 99 pruned.
# [I 2026-06-09 08:04:04,247] A new study created in memory with name: no-name-5c032692-41f2-4246-a548-ee2410a1f912
# [I 2026-06-09 08:07:53,294] Trial 0 finished with value: 4.5646187220605325 and parameters: {'iterations': 1683, 'learning_rate': 0.00452029410787974, 'depth': 8, 'l2_leaf_reg': 2.630096460705121, 'random_strength': 3.5931083780807196, 'bagging_temperature': 6.092383806181517, 'border_count': 120, 'rsm': 0.7045363049304494}. Best is trial 0 with value: 4.5646187220605325.
# [I 2026-06-09 08:09:33,353] Trial 1 finished with value: 4.5801984999798595 and parameters: {'iterations': 1059, 'learning_rate': 0.04826600949821074, 'depth': 10, 'l2_leaf_reg': 4.094606977950085, 'random_strength': 4.27651521061609, 'bagging_temperature': 1.134637011199704, 'border_count': 80, 'rsm': 0.9787360345339586}. Best is trial 0 with value: 4.5646187220605325.
# [I 2026-06-09 08:09:48,665] Trial 2 finished with value: 4.607217549635952 and parameters: {'iterations': 1892, 'learning_rate': 0.0944744250327489, 'depth': 7, 'l2_leaf_reg': 1.338503861993231, 'random_strength': 6.368320138068392, 'bagging_temperature': 1.391462519849035, 'border_count': 134, 'rsm': 0.9369315925781592}. Best is trial 0 with value: 4.5646187220605325.
# [I 2026-06-09 08:10:21,006] Trial 3 finished with value: 4.564657699770246 and parameters: {'iterations': 576, 'learning_rate': 0.0404280996182269, 'depth': 9, 'l2_leaf_reg': 0.9923528708302667, 'random_strength': 5.629499581589732, 'bagging_temperature': 1.591552638131477, 'border_count': 70, 'rsm': 0.5520114804951155}. Best is trial 0 with value: 4.5646187220605325.
# [I 2026-06-09 08:11:56,930] Trial 4 finished with value: 4.742724377899086 and parameters: {'iterations': 469, 'learning_rate': 0.017802222147843712, 'depth': 9, 'l2_leaf_reg': 47.93087599211837, 'random_strength': 8.050172005804523, 'bagging_temperature': 3.774154057164224, 'border_count': 147, 'rsm': 0.5294494606860387}. Best is trial 0 with value: 4.5646187220605325.
# [W 2026-06-09 08:15:15,673] Trial 5 failed with parameters: {'iterations': 1446, 'learning_rate': 0.003983913082142062, 'depth': 9, 'l2_leaf_reg': 14.160729974472108, 'random_strength': 8.33366212441756, 'bagging_temperature': 7.102306838296174, 'border_count': 188, 'rsm': 0.9650514017040863} because of the following error: KeyboardInterrupt('').
# Traceback (most recent call last):
#   File "d:\dev\weather-research\.venv\Lib\site-packages\optuna\study\_optimize.py", line 206, in _run_trial
#     value_or_values = func(trial)
#   File "D:\dev\weather-research\src\calibration\station_stacking.py", line 800, in objective
#     year = pd.to_numeric(frame.get("year"), errors="coerce")
#                                               ^^^^^^^^^^^^^^
#     ...<8 lines>...
#             for fold in folds:
#             ^^^^^^^^^
#   File "D:\dev\weather-research\src\calibration\station_stacking.py", line 1909, in _fit_predict_base_model
#         train: pd.DataFrame,
#     ...<7 lines>...
#
#   File "D:\dev\weather-research\src\calibration\station_stacking.py", line 1960, in _fit_base_estimator
#     try:
#
#     ...<6 lines>...
#             estimator.fit(
#             ^
#   File "d:\dev\weather-research\.venv\Lib\site-packages\catboost\core.py", line 6178, in fit
#     return self._fit(X, y, cat_features, text_features, embedding_features, None, graph, sample_weight, None, None, None, None, baseline,
#            ~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#                      use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description,
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#                      verbose_eval, metric_period, silent, early_stopping_rounds,
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#                      save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\dev\weather-research\.venv\Lib\site-packages\catboost\core.py", line 2716, in _fit
#     self._train(
#     ~~~~~~~~~~~^
#         train_pool,
#         ^^^^^^^^^^^
#     ...<3 lines>...
#         train_params["init_model"]
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "d:\dev\weather-research\.venv\Lib\site-packages\catboost\core.py", line 1824, in _train
#     self._object._train(train_pool, test_pool, params, allow_clear_pool, init_model._object if init_model else None)
#     ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "_catboost.pyx", line 5430, in _catboost._CatBoost._train
#   File "_catboost.pyx", line 5479, in _catboost._CatBoost._train
# KeyboardInterrupt
# [W 2026-06-09 08:15:15,756] Trial 5 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 18
#      14     stack_optuna_trials=STACK_OPTUNA_TRIALS,
#      15     optuna_verbose=OPTUNA_VERBOSE,
#      16     output_dir=PROJECT_ROOT / "data" / "calibration" / "station_stacking_v4",
#      17 )
# ---> 18 result = run_station_year_split_experiment(config)
#      19 result.scoreboard
#
# File D:\dev\weather-research\src\calibration\station_stacking.py:654, in run_station_year_split_experiment(config)
#     643     feature_columns_frame.to_csv(paths["feature_columns"], index=False)
#     644     return StationStackingResult(
#     645         station_id=station,
#     646         features=features,
#    (...)    650         output_paths=paths,
#     651     )
# --> 654 def run_station_year_split_experiment(config: StationStackingConfig) -> YearSplitExperimentResult:
#     655     features = build_station_wide_dataset(
#     656         config.resolved_project_root(),
#     657         station_id=config.station_id,
#     658         timing_mode=config.timing_mode,
#     659         providers=config.providers,
#     660     )
#     661     modeling_frame, categorical, numeric = _modeling_frame(features, config)
#
# File D:\dev\weather-research\src\calibration\station_stacking.py:864, in tune_year_split_base_models(frame, config, categorical, numeric, folds)
#     850 rmse = float(metrics["rmse_f"])
#     851 fold_scores.append((fold, float(metrics[metric_col])))
#     852 rows.append(
#     853     {
#     854         "method": method,
#     855         "trial_number": trial.number,
#     856         "param_key": param_key,
#     857         "fold": fold.name,
#     858         "fold_weight": _year_split_fold_weight(fold),
#     859         "mae_f": mae,
#     860         "rmse_f": rmse,
#     861         "count": int(metrics["count"]),
#     862         "fit_numeric_features": fit_metadata["numeric_features"],
#     863         "fit_categorical_features": fit_metadata["categorical_features"],
# --> 864         "best_iteration": fit_metadata["best_iteration"],
#     865         "status": "ok",
#     866         "error": "",
#     867         **{f"param_{key}": value for key, value in params.items()},
#     868     }
#     869 )
#     870 current_score = _weighted_fold_score(fold_scores)
#     871 if hasattr(trial, "report"):
#
# File d:\dev\weather-research\.venv\Lib\site-packages\optuna\study\study.py:516, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     414 def optimize(
#     415     self,
#     416     func: ObjectiveFuncType,
#    (...)    423     show_progress_bar: bool = False,
#     424 ) -> None:
#     425     """Optimize an objective function.
#     426
#     427     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)    514             If nested invocation of this method occurs.
#     515     """
# --> 516     _optimize(
#     517         study=self,
#     518         func=func,
#     519         n_trials=n_trials,
#     520         timeout=timeout,
#     521         n_jobs=n_jobs,
#     522         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     523         callbacks=callbacks,
#     524         gc_after_trial=gc_after_trial,
#     525         show_progress_bar=show_progress_bar,
#     526     )
#
# File d:\dev\weather-research\.venv\Lib\site-packages\optuna\study\_optimize.py:68, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      66 try:
#      67     if n_jobs == 1:
# ---> 68         _optimize_sequential(
#      69             study,
#      70             func,
#      71             n_trials,
#      72             timeout,
#      73             catch,
#      74             callbacks,
#      75             gc_after_trial,
#      76             reseed_sampler_rng=False,
#      77             time_start=None,
#      78             progress_bar=progress_bar,
#      79         )
#      80     else:
#      81         if n_jobs == -1:
#
# File d:\dev\weather-research\.venv\Lib\site-packages\optuna\study\_optimize.py:165, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     162         break
#     164 try:
# --> 165     frozen_trial_id = _run_trial(study, func, catch)
#     166 finally:
#     167     # The following line mitigates memory problems that can be occurred in some
#     168     # environments (e.g., services that use computing containers such as GitHub Actions).
#     169     # Please refer to the following PR for further details:
#     170     # https://github.com/optuna/optuna/pull/325.
#     171     if gc_after_trial:
#
# File d:\dev\weather-research\.venv\Lib\site-packages\optuna\study\_optimize.py:263, in _run_trial(study, func, catch)
#     256         assert False, "Should not reach."
#     258 if (
#     259     updated_state == TrialState.FAIL
#     260     and func_err is not None
#     261     and not isinstance(func_err, catch)
#     262 ):
# --> 263     raise func_err
#     264 return trial._trial_id
#
# File d:\dev\weather-research\.venv\Lib\site-packages\optuna\study\_optimize.py:206, in _run_trial(study, func, catch)
#     204 with get_heartbeat_thread(trial._trial_id, study._storage):
#     205     try:
# --> 206         value_or_values = func(trial)
#     207     except exceptions.TrialPruned as e:
#     208         # TODO(mamu): Handle multi-objective cases.
#     209         state = TrialState.PRUNED
#
# File D:\dev\weather-research\src\calibration\station_stacking.py:800, in objective(trial)
#     798     return pd.DataFrame(), _empty_year_split_predictions(), pd.DataFrame()
#     799 rows: list[dict[str, Any]] = []
# --> 800 year = pd.to_numeric(frame.get("year"), errors="coerce")
#     801 metric_col = config.effective_optuna_metric
#     802 for method in BASE_MODEL_METHODS:
#
# File D:\dev\weather-research\src\calibration\station_stacking.py:1909, in _fit_predict_base_model(config, categorical, numeric, method, params, train, valid, early_stopping)
#    1885         return CatBoostRegressor(
#    1886             iterations=cat_iterations,
#    1887             learning_rate=float(params.get("learning_rate", 0.035)),
#    (...)   1898             allow_writing_files=False,
#    1899         )
#    1900     raise ValueError(f"Unknown base model method: {method}")
#    1903 def _fit_predict_base_model(
#    1904     config: StationStackingConfig,
#    1905     categorical: list[str],
#    1906     numeric: list[str],
#    1907     method: str,
#    1908     params: dict[str, Any],
# -> 1909     train: pd.DataFrame,
#    1910     valid: pd.DataFrame,
#    1911     early_stopping: bool,
#    1912 ) -> tuple[np.ndarray, dict[str, Any]]:
#    1913     fit_categorical, fit_numeric = _fit_feature_columns(train, categorical, numeric)
#    1914     feature_names = [*fit_categorical, *fit_numeric]
#
# File D:\dev\weather-research\src\calibration\station_stacking.py:1960, in _fit_base_estimator(estimator, method, x_train, y_train, x_valid, y_valid, early_stopping_rounds)
#    1958     estimator.fit(x_train, y_train)
#    1959     return
# -> 1960 try:
#    1961     if method == "xgboost":
#    1962         estimator.fit(x_train, y_train, eval_set=[(x_valid, y_valid)], verbose=False)
#
# File d:\dev\weather-research\.venv\Lib\site-packages\catboost\core.py:6178, in CatBoostRegressor.fit(self, X, y, cat_features, text_features, embedding_features, graph, sample_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    6176 if 'loss_function' in params:
#    6177     CatBoostRegressor._check_is_compatible_loss(params['loss_function'])
# -> 6178 return self._fit(X, y, cat_features, text_features, embedding_features, None, graph, sample_weight, None, None, None, None, baseline,
#    6179                  use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description,
#    6180                  verbose_eval, metric_period, silent, early_stopping_rounds,
#    6181                  save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#
# File d:\dev\weather-research\.venv\Lib\site-packages\catboost\core.py:2716, in CatBoost._fit(self, X, y, cat_features, text_features, embedding_features, pairs, graph, sample_weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    2713 allow_clear_pool = train_params["allow_clear_pool"]
#    2715 with plot_wrapper(plot, plot_file, 'Training plots', [_get_train_dir(params)]):
# -> 2716     self._train(
#    2717         train_pool,
#    2718         train_params["eval_sets"],
#    2719         params,
#    2720         allow_clear_pool,
#    2721         train_params["init_model"]
#    2722     )
#    2724 # Have property feature_importance possibly set
#    2725 loss = self._object._get_loss_function_name()
#
# File d:\dev\weather-research\.venv\Lib\site-packages\catboost\core.py:1824, in _CatBoostBase._train(self, train_pool, test_pool, params, allow_clear_pool, init_model)
#    1823 def _train(self, train_pool, test_pool, params, allow_clear_pool, init_model):
# -> 1824     self._object._train(train_pool, test_pool, params, allow_clear_pool, init_model._object if init_model else None)
#    1825     self._set_trained_model_attributes()
#
# File _catboost.pyx:5430, in _catboost._CatBoost._train()
# -> 5430 'Could not get source, probably due dynamically evaluated source code.'
#
# File _catboost.pyx:5479, in _catboost._CatBoost._train()
# -> 5479 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyboardInterrupt:

# %% [markdown]
# ## Rounded Within 1F Accuracy

# %%
preds = pd.concat(
    [
        result.validation_predictions.assign(period="validation_2024_2025"),
        result.test_predictions.assign(period="test_2026"),
    ],
    ignore_index=True,
)

predicted_high = pd.to_numeric(preds["predicted_high_f"], errors="coerce")
preds["predicted_high_rounded_f"] = np.floor(predicted_high + 0.5)
preds["within_1f_after_round"] = (
    pd.to_numeric(preds["actual_high_f"], errors="coerce") - preds["predicted_high_rounded_f"]
).abs().le(1)

within_1f_accuracy_by_period = (
    preds
    .dropna(subset=["actual_high_f", "predicted_high_rounded_f"])
    .groupby(["period", "method"], as_index=False)
    .agg(
        count=("within_1f_after_round", "size"),
        within_1f_count=("within_1f_after_round", "sum"),
        within_1f_accuracy_pct=("within_1f_after_round", lambda x: x.mean() * 100),
    )
    .sort_values(["period", "within_1f_accuracy_pct"], ascending=[True, False])
)

within_1f_accuracy_by_period

# %% [markdown]
# ## Precipitation Feature Coverage

# %%
precip_columns = [column for column in result.features.columns if "precip" in column.lower()]
coverage = (
    result.features[precip_columns]
    .notna()
    .mean()
    .mul(100)
    .sort_values(ascending=False)
    .rename("coverage_pct")
    .reset_index()
    .rename(columns={"index": "feature"})
)
coverage

# %% [markdown]
# ## Version Comparison

# %%
comparison_frames = []
for version, folder in [
    ("v1", PROJECT_ROOT / "data" / "calibration" / "station_stacking"),
    ("v2", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v2"),
    ("v3", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v3"),
    ("v4", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v4"),
]:
    path = folder / f"{STATION_ID}_year_split_scoreboard.csv"
    if path.exists():
        frame = pd.read_csv(path)
        frame["version"] = version
        comparison_frames.append(frame)

version_comparison = pd.concat(comparison_frames, ignore_index=True) if comparison_frames else pd.DataFrame()
if not version_comparison.empty:
    version_comparison = version_comparison.sort_values(["period", "mae_f", "version", "method"]).reset_index(drop=True)
version_comparison

# %% [markdown]
# ## 2026 Weather Brackets

# %%
result.bracket_metrics

# %%
import pandas as pd


def adjacent_brackets(bracket):
    if pd.isna(bracket):
        return []
    text = str(bracket).strip()
    if not text or "-" not in text:
        return []
    try:
        lower = int(text.split("-", 1)[0])
    except ValueError:
        return []
    return [
        f"{lower - 2}-{lower - 1}",
        f"{lower}-{lower + 1}",
        f"{lower + 2}-{lower + 3}",
    ]


bracket_3way = result.bracket_predictions.copy()

valid = bracket_3way["actual_bracket"].notna() & bracket_3way["predicted_bracket"].astype(str).str.strip().ne("")
bracket_3way = bracket_3way.loc[valid].copy()
bracket_3way["picked_brackets"] = bracket_3way["predicted_bracket"].map(adjacent_brackets)
bracket_3way["three_bracket_hit"] = bracket_3way.apply(
    lambda row: row["actual_bracket"] in row["picked_brackets"],
    axis=1,
)

three_bracket_accuracy = (
    bracket_3way
    .groupby("method", as_index=False)
    .agg(
        count=("three_bracket_hit", "size"),
        exact_bracket_accuracy_pct=("bracket_hit", lambda x: x.mean() * 100),
        three_bracket_accuracy_pct=("three_bracket_hit", lambda x: x.mean() * 100),
    )
    .sort_values("three_bracket_accuracy_pct", ascending=False)
)

three_bracket_accuracy

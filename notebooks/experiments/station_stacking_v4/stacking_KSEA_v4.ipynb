# %% [markdown]
# # Station Stacking v4 - KSEA
#
# Wide HRRR/GFS same-day 11am notebook for `KSEA`.
#
# This version keeps the v3 high-so-far features and adds SDK-backed precipitation features from HRRR/GFS forecast precipitation plus 11 AM METAR precipitation codes. Artifacts are written to `data/calibration/station_stacking_v4`.

# %%
from pathlib import Path
import sys
import warnings

warnings.filterwarnings("ignore", message="IProgress not found.*")
warnings.filterwarnings("ignore", message="Skipping features without any observed values.*")

PROJECT_ROOT = Path.cwd().resolve()
while not (PROJECT_ROOT / "src" / "calibration" / "station_stacking.py").exists():
    if PROJECT_ROOT.parent == PROJECT_ROOT:
        raise RuntimeError("Could not find project root containing src/calibration/station_stacking.py")
    PROJECT_ROOT = PROJECT_ROOT.parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

STATION_ID = "KSEA"
FAST_MODE = False
OPTUNA_TRIALS = 100
STACK_OPTUNA_TRIALS = 50
OPTUNA_VERBOSE = True
PROJECT_ROOT
# Out:
# WindowsPath('D:/dev/weather-research')

# %%
from src.calibration.station_stacking import (
    StationStackingConfig,
    missing_model_dependencies,
    run_station_year_split_experiment,
)

# %% [markdown]
# ## V4 Feature Engineering
#
# Adds v2/v3 temperature features plus forecast and observed precipitation signals. Forecast precipitation comes from provider-prefixed SDK summary columns such as `gfs_forecast_precip_total_mm`, with `gfs_precip_amount` as a fallback for older caches.

# %%
import numpy as np
import pandas as pd
import src.calibration.station_stacking as station_stacking_module

V4_PROVIDERS = ("gfs", "hrrr")
V4_FEATURE_COLUMNS = [
    "v2_recent_heat_anomaly_f",
    "v2_recent_heat_momentum_f",
    "v2_morning_warmup_to_consensus_f",
    "v2_consensus_minus_7d_actual_f",
    "v2_spread_per_warmup_f",
    "v2_humidity_warmup_interaction",
    "v3_high_so_far_above_current_f",
    "v3_remaining_warmup_from_high_so_far_f",
    "v3_high_so_far_minus_lag_1d_f",
    "v3_high_so_far_minus_7d_actual_f",
    "v3_remaining_warmup_per_spread_f",
    "v3_humidity_remaining_warmup_interaction",
    "v4_forecast_precip_total_mean_mm",
    "v4_forecast_precip_total_max_mm",
    "v4_forecast_precip_total_spread_mm",
    "v4_forecast_precip_max_1h_mean_mm",
    "v4_forecast_precip_hours_mean",
    "v4_forecast_precip_intensity_mean",
    "v4_forecast_precip_intensity_max",
    "v4_any_forecast_precip",
    "v4_all_forecast_precip",
    "v4_observed_precip_any",
    "v4_observed_precip_recent_mm_est",
    "v4_forecast_total_minus_observed_recent_mm",
    "v4_forecast_observed_precip_match",
    "v4_forecast_wet_observed_dry",
    "v4_observed_wet_forecast_dry",
    "v4_precip_humidity_interaction",
    "v4_precip_remaining_warmup_interaction",
]


def _num(frame: pd.DataFrame, column: str) -> pd.Series:
    if column in frame:
        return pd.to_numeric(frame[column], errors="coerce")
    return pd.Series(np.nan, index=frame.index, dtype="float64")


def _bool_num(frame: pd.DataFrame, column: str) -> pd.Series:
    if column not in frame:
        return pd.Series(0, index=frame.index, dtype="int64")
    series = frame[column]
    if pd.api.types.is_bool_dtype(series):
        return series.fillna(False).astype(int)
    if pd.api.types.is_numeric_dtype(series):
        return pd.to_numeric(series, errors="coerce").fillna(0).gt(0).astype(int)
    return series.astype("string").str.lower().isin({"1", "true", "yes", "y"}).astype(int)


def _provider_series(frame: pd.DataFrame, provider: str, primary: str, fallback: str | None = None) -> pd.Series:
    primary_column = f"{provider}_{primary}"
    if primary_column in frame:
        return _num(frame, primary_column)
    if fallback is not None:
        return _num(frame, f"{provider}_{fallback}")
    return pd.Series(np.nan, index=frame.index, dtype="float64")


def _provider_matrix(frame: pd.DataFrame, primary: str, fallback: str | None = None) -> pd.DataFrame:
    return pd.DataFrame(
        {provider: _provider_series(frame, provider, primary, fallback) for provider in V4_PROVIDERS},
        index=frame.index,
    )


def add_v4_feature_engineering(frame: pd.DataFrame) -> pd.DataFrame:
    out = frame.copy()
    observed_temp = _num(out, "observed_temp_at_as_of_f")
    high_so_far = _num(out, "observed_high_temp_through_as_of_f")
    observed_humidity = _num(out, "observed_humidity_at_as_of")
    provider_mean = _num(out, "provider_mean_high_f")
    provider_spread = _num(out, "provider_spread_high_f")
    lag_1d = _num(out, "actual_high_lag_1d")
    roll_7d = _num(out, "actual_high_roll_7d_mean")
    roll_30d = _num(out, "actual_high_roll_30d_mean")

    warmup_to_consensus = provider_mean - observed_temp
    remaining_warmup = provider_mean - high_so_far
    out["v2_recent_heat_anomaly_f"] = lag_1d - roll_30d
    out["v2_recent_heat_momentum_f"] = roll_7d - roll_30d
    out["v2_morning_warmup_to_consensus_f"] = warmup_to_consensus
    out["v2_consensus_minus_7d_actual_f"] = provider_mean - roll_7d
    out["v2_spread_per_warmup_f"] = provider_spread / warmup_to_consensus.abs().clip(lower=1.0)
    out["v2_humidity_warmup_interaction"] = (observed_humidity / 100.0) * warmup_to_consensus
    out["v3_high_so_far_above_current_f"] = high_so_far - observed_temp
    out["v3_remaining_warmup_from_high_so_far_f"] = remaining_warmup
    out["v3_high_so_far_minus_lag_1d_f"] = high_so_far - lag_1d
    out["v3_high_so_far_minus_7d_actual_f"] = high_so_far - roll_7d
    out["v3_remaining_warmup_per_spread_f"] = remaining_warmup / provider_spread.abs().clip(lower=1.0)
    out["v3_humidity_remaining_warmup_interaction"] = (observed_humidity / 100.0) * remaining_warmup

    precip_total = _provider_matrix(out, "forecast_precip_total_mm", fallback="precip_amount")
    precip_max_1h = _provider_matrix(out, "forecast_precip_max_1h_mm")
    precip_hours = _provider_matrix(out, "forecast_precip_hours_count")
    precip_intensity = _provider_matrix(out, "forecast_precip_intensity_code")
    has_precip = _provider_matrix(out, "forecast_has_precip").fillna(0).clip(lower=0, upper=1)

    out["v4_forecast_precip_total_mean_mm"] = precip_total.mean(axis=1)
    out["v4_forecast_precip_total_max_mm"] = precip_total.max(axis=1)
    out["v4_forecast_precip_total_spread_mm"] = precip_total.max(axis=1) - precip_total.min(axis=1)
    out["v4_forecast_precip_max_1h_mean_mm"] = precip_max_1h.mean(axis=1)
    out["v4_forecast_precip_hours_mean"] = precip_hours.mean(axis=1)
    out["v4_forecast_precip_intensity_mean"] = precip_intensity.mean(axis=1)
    out["v4_forecast_precip_intensity_max"] = precip_intensity.max(axis=1)
    out["v4_any_forecast_precip"] = has_precip.max(axis=1).fillna(0).astype(int)
    out["v4_all_forecast_precip"] = has_precip.min(axis=1).fillna(0).astype(int)

    observed_any = (
        _bool_num(out, "observed_is_raining_at_as_of")
        | _bool_num(out, "observed_is_drizzle_at_as_of")
        | _bool_num(out, "observed_is_snowing_at_as_of")
    ).astype(int)
    observed_recent_mm = _num(out, "observed_precip_recent_at_as_of") * 25.4
    out["v4_observed_precip_any"] = observed_any
    out["v4_observed_precip_recent_mm_est"] = observed_recent_mm
    out["v4_forecast_total_minus_observed_recent_mm"] = out["v4_forecast_precip_total_mean_mm"] - observed_recent_mm
    out["v4_forecast_observed_precip_match"] = out["v4_any_forecast_precip"].eq(observed_any).astype(int)
    out["v4_forecast_wet_observed_dry"] = (out["v4_any_forecast_precip"].eq(1) & observed_any.eq(0)).astype(int)
    out["v4_observed_wet_forecast_dry"] = (observed_any.eq(1) & out["v4_any_forecast_precip"].eq(0)).astype(int)
    out["v4_precip_humidity_interaction"] = out["v4_forecast_precip_total_mean_mm"] * (observed_humidity / 100.0)
    out["v4_precip_remaining_warmup_interaction"] = out["v4_forecast_precip_total_mean_mm"] * remaining_warmup
    return out


if not hasattr(station_stacking_module, "_v4_original_build_station_wide_dataset"):
    station_stacking_module._v4_original_build_station_wide_dataset = station_stacking_module.build_station_wide_dataset


def build_station_wide_dataset_v4(*args, **kwargs):
    frame = station_stacking_module._v4_original_build_station_wide_dataset(*args, **kwargs)
    return add_v4_feature_engineering(frame)


station_stacking_module.build_station_wide_dataset = build_station_wide_dataset_v4
V4_FEATURE_COLUMNS
# Out:
# ['v2_recent_heat_anomaly_f',
#  'v2_recent_heat_momentum_f',
#  'v2_morning_warmup_to_consensus_f',
#  'v2_consensus_minus_7d_actual_f',
#  'v2_spread_per_warmup_f',
#  'v2_humidity_warmup_interaction',
#  'v3_high_so_far_above_current_f',
#  'v3_remaining_warmup_from_high_so_far_f',
#  'v3_high_so_far_minus_lag_1d_f',
#  'v3_high_so_far_minus_7d_actual_f',
#  'v3_remaining_warmup_per_spread_f',
#  'v3_humidity_remaining_warmup_interaction',
#  'v4_forecast_precip_total_mean_mm',
#  'v4_forecast_precip_total_max_mm',
#  'v4_forecast_precip_total_spread_mm',
#  'v4_forecast_precip_max_1h_mean_mm',
#  'v4_forecast_precip_hours_mean',
#  'v4_forecast_precip_intensity_mean',
#  'v4_forecast_precip_intensity_max',
#  'v4_any_forecast_precip',
#  'v4_all_forecast_precip',
#  'v4_observed_precip_any',
#  'v4_observed_precip_recent_mm_est',
#  'v4_forecast_total_minus_observed_recent_mm',
#  'v4_forecast_observed_precip_match',
#  'v4_forecast_wet_observed_dry',
#  'v4_observed_wet_forecast_dry',
#  'v4_precip_humidity_interaction',
#  'v4_precip_remaining_warmup_interaction']

# %% [markdown]
# ## Model Scores

# %%
missing_packages = missing_model_dependencies()
if missing_packages:
    raise ImportError(
        "Missing station-stacking ML packages: "
        + ", ".join(missing_packages)
        + ". Install them with: python -m pip install -r requirements.txt"
    )

config = StationStackingConfig(
    station_id=STATION_ID,
    project_root=PROJECT_ROOT,
    fast_mode=FAST_MODE,
    optuna_trials=OPTUNA_TRIALS,
    stack_optuna_trials=STACK_OPTUNA_TRIALS,
    optuna_verbose=OPTUNA_VERBOSE,
    output_dir=PROJECT_ROOT / "data" / "calibration" / "station_stacking_v4",
)
result = run_station_year_split_experiment(config)
result.scoreboard
# Out:
# [I 2026-06-09 06:30:04,767] A new study created in memory with name: no-name-7e8e2ea8-924f-4f41-9ba9-9803a6488020
# [I 2026-06-09 06:30:24,676] Trial 0 finished with value: 2.6943119619266396 and parameters: {'n_estimators': 799, 'learning_rate': 0.12369619597856178, 'max_depth': 6, 'min_child_weight': 2.385234757844707, 'gamma': 0.7800932022121826, 'subsample': 0.5779972601681014, 'colsample_bytree': 0.5290418060840998, 'reg_alpha': 0.6245760287469893, 'reg_lambda': 0.6677615511747083}. Best is trial 0 with value: 2.6943119619266396.
# [I 2026-06-09 06:33:57,302] Trial 1 finished with value: 2.5338193249769443 and parameters: {'n_estimators': 1440, 'learning_rate': 0.0032515743808034223, 'max_depth': 8, 'min_child_weight': 8.23143373099555, 'gamma': 1.0616955533913808, 'subsample': 0.5909124836035503, 'colsample_bytree': 0.5917022549267169, 'reg_alpha': 5.472429642032198e-06, 'reg_lambda': 0.2922905212920093}. Best is trial 1 with value: 2.5338193249769443.
# [I 2026-06-09 06:34:51,081] Trial 2 finished with value: 2.8764143104497895 and parameters: {'n_estimators': 909, 'learning_rate': 0.009373695213782608, 'max_depth': 5, 'min_child_weight': 0.20940138873937433, 'gamma': 1.4607232426760908, 'subsample': 0.6831809216468459, 'colsample_bytree': 0.728034992108518, 'reg_alpha': 0.1165691561324743, 'reg_lambda': 0.008674832802525461}. Best is trial 1 with value: 2.5338193249769443.
# [I 2026-06-09 06:34:57,733] Trial 3 finished with value: 2.5227035897198347 and parameters: {'n_estimators': 1067, 'learning_rate': 0.03045200113778571, 'max_depth': 1, 'min_child_weight': 2.5002240473339543, 'gamma': 0.8526206184364576, 'subsample': 0.5325257964926398, 'colsample_bytree': 0.9744427686266666, 'reg_alpha': 4.905556676028774, 'reg_lambda': 6.289771819487036}. Best is trial 3 with value: 2.5227035897198347.
# [I 2026-06-09 06:36:19,049] Trial 4 finished with value: 2.8064772891902523 and parameters: {'n_estimators': 665, 'learning_rate': 0.004396056309201638, 'max_depth': 6, 'min_child_weight': 1.0299214204601976, 'gamma': 0.6101911742238941, 'subsample': 0.7475884550556351, 'colsample_bytree': 0.5171942605576092, 'reg_alpha': 1.527156759251193, 'reg_lambda': 0.016443693426189242}. Best is trial 3 with value: 2.5227035897198347.
# [I 2026-06-09 06:37:34,417] Trial 5 pruned.
# [I 2026-06-09 06:37:37,961] Trial 6 finished with value: 2.5734962383613675 and parameters: {'n_estimators': 1228, 'learning_rate': 0.11049889315270257, 'max_depth': 1, 'min_child_weight': 0.28246357083904894, 'gamma': 0.22613644455269033, 'subsample': 0.6626651653816322, 'colsample_bytree': 0.6943386448447411, 'reg_alpha': 2.7678419414850017e-06, 'reg_lambda': 7.838134236608707}. Best is trial 3 with value: 2.5227035897198347.
# [I 2026-06-09 06:37:54,117] Trial 7 pruned.
# [I 2026-06-09 06:38:05,748] Trial 8 finished with value: 2.6191270557199466 and parameters: {'n_estimators': 90, 'learning_rate': 0.07287285110476487, 'max_depth': 6, 'min_child_weight': 4.758470274910409, 'gamma': 3.8563517334297286, 'subsample': 0.5370223258670452, 'colsample_bytree': 0.6792328642721364, 'reg_alpha': 1.1036250149900698e-07, 'reg_lambda': 11.368341439732731}. Best is trial 3 with value: 2.5227035897198347.
# [I 2026-06-09 06:38:36,601] Trial 9 finished with value: 2.558996834065127 and parameters: {'n_estimators': 1277, 'learning_rate': 0.01094730135557207, 'max_depth': 1, 'min_child_weight': 0.5194929407101735, 'gamma': 1.6259166101337352, 'subsample': 0.864803089169032, 'colsample_bytree': 0.8187787356776066, 'reg_alpha': 0.9658611176861268, 'reg_lambda': 0.16554793541373172}. Best is trial 3 with value: 2.5227035897198347.
# [I 2026-06-09 06:38:44,548] Trial 10 finished with value: 2.5368479827645287 and parameters: {'n_estimators': 1915, 'learning_rate': 0.036235378997051045, 'max_depth': 3, 'min_child_weight': 13.97101765312176, 'gamma': 2.828065453407016, 'subsample': 0.8211770829222278, 'colsample_bytree': 0.9805126451489784, 'reg_alpha': 0.0025347992375043043, 'reg_lambda': 2.1525808090182244}. Best is trial 3 with value: 2.5227035897198347.
# [I 2026-06-09 06:39:09,443] Trial 11 pruned.
# [I 2026-06-09 06:42:54,790] Trial 12 finished with value: 2.5537785624668445 and parameters: {'n_estimators': 1606, 'learning_rate': 0.003196962615028647, 'max_depth': 8, 'min_child_weight': 5.967787778328425, 'gamma': 2.5182196590789347, 'subsample': 0.5224078715805444, 'colsample_bytree': 0.8285397244388237, 'reg_alpha': 2.0057322817130592e-08, 'reg_lambda': 0.9111568610251692}. Best is trial 3 with value: 2.5227035897198347.
# [I 2026-06-09 06:43:43,143] Trial 13 pruned.
# [I 2026-06-09 06:44:02,185] Trial 14 finished with value: 2.5181486820872676 and parameters: {'n_estimators': 382, 'learning_rate': 0.018272312202213956, 'max_depth': 3, 'min_child_weight': 19.58235722169521, 'gamma': 1.4988959592627205, 'subsample': 0.730666690330899, 'colsample_bytree': 0.5869307363177139, 'reg_alpha': 4.003697756647738e-06, 'reg_lambda': 0.13349585351437454}. Best is trial 14 with value: 2.5181486820872676.
# [I 2026-06-09 06:44:10,240] Trial 15 pruned.
# [I 2026-06-09 06:44:14,340] Trial 16 pruned.
# [I 2026-06-09 06:44:16,060] Trial 17 pruned.
# [I 2026-06-09 06:44:21,978] Trial 18 finished with value: 2.5270276537429113 and parameters: {'n_estimators': 473, 'learning_rate': 0.03345221151115177, 'max_depth': 2, 'min_child_weight': 3.2602668431469963, 'gamma': 2.149461380427409, 'subsample': 0.8280219172107682, 'colsample_bytree': 0.7819873495107165, 'reg_alpha': 0.060876102112199, 'reg_lambda': 3.9534348383300673}. Best is trial 14 with value: 2.5181486820872676.
# [I 2026-06-09 06:44:25,817] Trial 19 pruned.
# [I 2026-06-09 06:44:32,525] Trial 20 pruned.
# [I 2026-06-09 06:44:49,455] Trial 21 finished with value: 2.5336437504137552 and parameters: {'n_estimators': 558, 'learning_rate': 0.032550331348486124, 'max_depth': 2, 'min_child_weight': 2.897359854140398, 'gamma': 2.1052209964538164, 'subsample': 0.8510379126733721, 'colsample_bytree': 0.7630629280939231, 'reg_alpha': 0.06349270562810422, 'reg_lambda': 3.320124403065871}. Best is trial 14 with value: 2.5181486820872676.
# [I 2026-06-09 06:44:56,882] Trial 22 pruned.
# [I 2026-06-09 06:45:04,539] Trial 23 pruned.
# [I 2026-06-09 06:45:25,617] Trial 24 pruned.
# [I 2026-06-09 06:45:58,344] Trial 25 finished with value: 2.552006310779728 and parameters: {'n_estimators': 643, 'learning_rate': 0.025609230142046458, 'max_depth': 1, 'min_child_weight': 9.981032311339955, 'gamma': 1.86477119634407, 'subsample': 0.978204246270755, 'colsample_bytree': 0.7390310897251647, 'reg_alpha': 0.27503041577118953, 'reg_lambda': 1.9227169357739116}. Best is trial 14 with value: 2.5181486820872676.
# [I 2026-06-09 06:46:00,569] Trial 26 pruned.
# [I 2026-06-09 06:46:11,468] Trial 27 pruned.
# [I 2026-06-09 06:46:23,644] Trial 28 pruned.
# [I 2026-06-09 06:46:32,726] Trial 29 pruned.
# [I 2026-06-09 06:46:41,857] Trial 30 pruned.
# [I 2026-06-09 06:47:03,709] Trial 31 finished with value: 2.535196872810757 and parameters: {'n_estimators': 539, 'learning_rate': 0.03215201819171417, 'max_depth': 2, 'min_child_weight': 2.79421125149155, 'gamma': 2.0391472854470925, 'subsample': 0.8338997111968103, 'colsample_bytree': 0.7121905650549634, 'reg_alpha': 0.03655389094578809, 'reg_lambda': 1.7070163963743636}. Best is trial 14 with value: 2.5181486820872676.
# [I 2026-06-09 06:47:30,756] Trial 32 finished with value: 2.541719004197496 and parameters: {'n_estimators': 414, 'learning_rate': 0.017877794569392872, 'max_depth': 2, 'min_child_weight': 5.154874420411056, 'gamma': 1.748225142350839, 'subsample': 0.8642740533382218, 'colsample_bytree': 0.6424622199180803, 'reg_alpha': 0.2243176336260481, 'reg_lambda': 5.07111941850024}. Best is trial 14 with value: 2.5181486820872676.
# [I 2026-06-09 06:47:48,023] Trial 33 finished with value: 2.542235778105391 and parameters: {'n_estimators': 582, 'learning_rate': 0.04062282244528435, 'max_depth': 1, 'min_child_weight': 1.0088120086029984, 'gamma': 1.2183226694072475, 'subsample': 0.9460505832747516, 'colsample_bytree': 0.7687143237410344, 'reg_alpha': 0.0638098821281843, 'reg_lambda': 20.181460987951855}. Best is trial 14 with value: 2.5181486820872676.
# [I 2026-06-09 06:47:50,964] Trial 34 pruned.
# [I 2026-06-09 06:47:58,762] Trial 35 pruned.
# [I 2026-06-09 06:48:16,754] Trial 36 pruned.
# [I 2026-06-09 06:48:41,522] Trial 37 finished with value: 2.5365381285618938 and parameters: {'n_estimators': 859, 'learning_rate': 0.02117508514855907, 'max_depth': 1, 'min_child_weight': 1.6743871539014659, 'gamma': 0.9234013252494957, 'subsample': 0.7096763211890255, 'colsample_bytree': 0.5368388671170272, 'reg_alpha': 5.64996656083885e-07, 'reg_lambda': 10.355000055125135}. Best is trial 14 with value: 2.5181486820872676.
# [I 2026-06-09 06:49:07,885] Trial 38 pruned.
# [I 2026-06-09 06:49:12,089] Trial 39 pruned.
# [I 2026-06-09 06:49:26,176] Trial 40 pruned.
# [I 2026-06-09 06:51:37,966] Trial 41 finished with value: 2.5165152595767135 and parameters: {'n_estimators': 1388, 'learning_rate': 0.004397061284257284, 'max_depth': 6, 'min_child_weight': 8.708052047231927, 'gamma': 1.5101062339171634, 'subsample': 0.5703418176852404, 'colsample_bytree': 0.5972653999822677, 'reg_alpha': 4.908980439045217e-07, 'reg_lambda': 0.2723000641393768}. Best is trial 41 with value: 2.5165152595767135.
# [I 2026-06-09 06:53:44,156] Trial 42 finished with value: 2.506003391332953 and parameters: {'n_estimators': 1163, 'learning_rate': 0.004980665423726365, 'max_depth': 7, 'min_child_weight': 12.469279096132503, 'gamma': 1.608707224350399, 'subsample': 0.5816028537662046, 'colsample_bytree': 0.5414970265955965, 'reg_alpha': 5.6921856301805236e-08, 'reg_lambda': 0.2556470478498834}. Best is trial 42 with value: 2.506003391332953.
# [I 2026-06-09 06:55:37,150] Trial 43 finished with value: 2.493976570324695 and parameters: {'n_estimators': 1136, 'learning_rate': 0.004824255756788763, 'max_depth': 7, 'min_child_weight': 11.08170292154543, 'gamma': 1.4506825825227014, 'subsample': 0.5639933571840917, 'colsample_bytree': 0.5357339252670921, 'reg_alpha': 7.787013578391578e-08, 'reg_lambda': 0.22025306086106472}. Best is trial 43 with value: 2.493976570324695.
# [I 2026-06-09 06:57:27,464] Trial 44 finished with value: 2.4871725129468643 and parameters: {'n_estimators': 1177, 'learning_rate': 0.004730789331761341, 'max_depth': 7, 'min_child_weight': 13.15819738661892, 'gamma': 1.4408930350573679, 'subsample': 0.5676078354518966, 'colsample_bytree': 0.5445818777709772, 'reg_alpha': 5.5920911970413285e-08, 'reg_lambda': 0.21499559830132303}. Best is trial 44 with value: 2.4871725129468643.
# [I 2026-06-09 06:58:58,237] Trial 45 finished with value: 2.505776741529261 and parameters: {'n_estimators': 1172, 'learning_rate': 0.004106826326662539, 'max_depth': 7, 'min_child_weight': 19.87418131623824, 'gamma': 1.472126105874149, 'subsample': 0.5699973629755427, 'colsample_bytree': 0.5436440424829236, 'reg_alpha': 6.857175655245746e-08, 'reg_lambda': 0.2077599844032227}. Best is trial 44 with value: 2.4871725129468643.
# [I 2026-06-09 07:00:12,786] Trial 46 finished with value: 2.49117215594444 and parameters: {'n_estimators': 1239, 'learning_rate': 0.004171966090593924, 'max_depth': 7, 'min_child_weight': 12.345202085180759, 'gamma': 1.3877950626196707, 'subsample': 0.557015038295562, 'colsample_bytree': 0.5309525020369718, 'reg_alpha': 6.415823953374512e-08, 'reg_lambda': 0.25591618236471503}. Best is trial 44 with value: 2.4871725129468643.
# [I 2026-06-09 07:01:45,608] Trial 47 finished with value: 2.492756377308374 and parameters: {'n_estimators': 1187, 'learning_rate': 0.003970632809802695, 'max_depth': 7, 'min_child_weight': 11.935418693480258, 'gamma': 0.6906160045382643, 'subsample': 0.5930562217104172, 'colsample_bytree': 0.5335878152463882, 'reg_alpha': 4.488977486179609e-08, 'reg_lambda': 0.06933557953959578}. Best is trial 44 with value: 2.4871725129468643.
# [I 2026-06-09 07:03:05,749] Trial 48 finished with value: 2.4948302013499895 and parameters: {'n_estimators': 1309, 'learning_rate': 0.0037500662169120866, 'max_depth': 7, 'min_child_weight': 15.609043567446266, 'gamma': 0.5467034359882225, 'subsample': 0.6095827664212021, 'colsample_bytree': 0.5234708107219045, 'reg_alpha': 9.658702420862184e-08, 'reg_lambda': 0.09275674222709711}. Best is trial 44 with value: 2.4871725129468643.
# [I 2026-06-09 07:04:20,996] Trial 49 finished with value: 2.4998565385472746 and parameters: {'n_estimators': 1279, 'learning_rate': 0.003611749846750528, 'max_depth': 6, 'min_child_weight': 14.734251916244803, 'gamma': 0.17660675825803895, 'subsample': 0.6125544630583794, 'colsample_bytree': 0.5005501716489149, 'reg_alpha': 1.7762149035407785e-07, 'reg_lambda': 0.0924230643252284}. Best is trial 44 with value: 2.4871725129468643.
# [I 2026-06-09 07:05:26,511] Trial 50 finished with value: 2.496575972020913 and parameters: {'n_estimators': 1514, 'learning_rate': 0.00571468161424143, 'max_depth': 8, 'min_child_weight': 11.358805170513513, 'gamma': 0.6844691132607463, 'subsample': 0.5408726684853814, 'colsample_bytree': 0.5234296295813444, 'reg_alpha': 3.6375651791556285e-08, 'reg_lambda': 0.028703945330059738}. Best is trial 44 with value: 2.4871725129468643.
# [I 2026-06-09 07:06:26,678] Trial 51 finished with value: 2.4998579820802496 and parameters: {'n_estimators': 1551, 'learning_rate': 0.005835734422634223, 'max_depth': 8, 'min_child_weight': 11.937675992293492, 'gamma': 0.6180624170752221, 'subsample': 0.5372286945223262, 'colsample_bytree': 0.5775769097610363, 'reg_alpha': 2.3756011833602748e-08, 'reg_lambda': 0.027170063064619786}. Best is trial 44 with value: 2.4871725129468643.
# [I 2026-06-09 07:07:03,386] Trial 52 finished with value: 2.5225736319041228 and parameters: {'n_estimators': 1315, 'learning_rate': 0.007552806656377237, 'max_depth': 7, 'min_child_weight': 7.998741965810597, 'gamma': 0.3304127577691829, 'subsample': 0.5513937035959665, 'colsample_bytree': 0.5271159110524234, 'reg_alpha': 1.6367615702183064e-07, 'reg_lambda': 0.0897888303515161}. Best is trial 44 with value: 2.4871725129468643.
# [I 2026-06-09 07:08:33,167] Trial 53 finished with value: 2.4756026213194 and parameters: {'n_estimators': 1434, 'learning_rate': 0.0035421520915808794, 'max_depth': 8, 'min_child_weight': 16.62346932201516, 'gamma': 0.693221932769222, 'subsample': 0.5079595668399339, 'colsample_bytree': 0.5258206821958528, 'reg_alpha': 1.4099352660205643e-06, 'reg_lambda': 0.027745407877534312}. Best is trial 53 with value: 2.4756026213194.
# [I 2026-06-09 07:09:40,499] Trial 54 finished with value: 2.5062549676052903 and parameters: {'n_estimators': 1195, 'learning_rate': 0.0031759615994528243, 'max_depth': 7, 'min_child_weight': 15.534096053507374, 'gamma': 0.9713016126998046, 'subsample': 0.51003854470436, 'colsample_bytree': 0.5545362087790897, 'reg_alpha': 1.0989968283692076e-06, 'reg_lambda': 0.5422272101351685}. Best is trial 53 with value: 2.4756026213194.
# [I 2026-06-09 07:10:54,039] Trial 55 finished with value: 2.4893788015416183 and parameters: {'n_estimators': 1658, 'learning_rate': 0.003757159669547334, 'max_depth': 7, 'min_child_weight': 16.212093954055774, 'gamma': 0.03976326883452286, 'subsample': 0.5963126109867729, 'colsample_bytree': 0.6173210465001123, 'reg_alpha': 2.5575128321297187e-07, 'reg_lambda': 0.046760833817819085}. Best is trial 53 with value: 2.4756026213194.
# [I 2026-06-09 07:11:23,660] Trial 56 pruned.
# [I 2026-06-09 07:12:31,321] Trial 57 finished with value: 2.517746377930867 and parameters: {'n_estimators': 1699, 'learning_rate': 0.005052314843770486, 'max_depth': 8, 'min_child_weight': 9.73941245136348, 'gamma': 0.041624427574542544, 'subsample': 0.5971030457995664, 'colsample_bytree': 0.6441375653687094, 'reg_alpha': 2.632538345055917e-07, 'reg_lambda': 0.016266358064394984}. Best is trial 53 with value: 2.4756026213194.
# [I 2026-06-09 07:14:22,131] Trial 58 finished with value: 2.477086382653945 and parameters: {'n_estimators': 1415, 'learning_rate': 0.003012841025208826, 'max_depth': 7, 'min_child_weight': 12.38903424325804, 'gamma': 1.2737685389669982, 'subsample': 0.5231683028380587, 'colsample_bytree': 0.582736921468916, 'reg_alpha': 1.2608520989151156e-08, 'reg_lambda': 0.009815643915867096}. Best is trial 53 with value: 2.4756026213194.
# [I 2026-06-09 07:15:53,418] Trial 59 pruned.
# [I 2026-06-09 07:18:55,133] Trial 60 finished with value: 2.497257293344263 and parameters: {'n_estimators': 1690, 'learning_rate': 0.003618586052881029, 'max_depth': 6, 'min_child_weight': 17.621716050755303, 'gamma': 1.1041401837208846, 'subsample': 0.6312746468500874, 'colsample_bytree': 0.6643387255151386, 'reg_alpha': 3.5882904955217917e-07, 'reg_lambda': 0.008156255040686447}. Best is trial 53 with value: 2.4756026213194.
# [I 2026-06-09 07:20:46,496] Trial 61 finished with value: 2.4839580949556033 and parameters: {'n_estimators': 1111, 'learning_rate': 0.004039096826995725, 'max_depth': 7, 'min_child_weight': 12.364493089099986, 'gamma': 1.349186484142844, 'subsample': 0.5223326632073392, 'colsample_bytree': 0.5493408210428418, 'reg_alpha': 3.1569897653910826e-08, 'reg_lambda': 0.021874153007722056}. Best is trial 53 with value: 2.4756026213194.
# [I 2026-06-09 07:24:53,659] Trial 62 finished with value: 2.488437511763123 and parameters: {'n_estimators': 1964, 'learning_rate': 0.003912810899801284, 'max_depth': 7, 'min_child_weight': 13.266877089275727, 'gamma': 1.2186833860855621, 'subsample': 0.5276722758245486, 'colsample_bytree': 0.5884892773471962, 'reg_alpha': 2.260155879312292e-08, 'reg_lambda': 0.02101852810693297}. Best is trial 53 with value: 2.4756026213194.
# [I 2026-06-09 07:28:57,369] Trial 63 finished with value: 2.4855138666355536 and parameters: {'n_estimators': 1948, 'learning_rate': 0.006932250935833024, 'max_depth': 6, 'min_child_weight': 13.819764965254759, 'gamma': 1.8359779519204424, 'subsample': 0.5284049650987892, 'colsample_bytree': 0.611996006084757, 'reg_alpha': 2.3510894077097995e-08, 'reg_lambda': 0.006498713122835766}. Best is trial 53 with value: 2.4756026213194.
# [I 2026-06-09 07:32:28,636] Trial 64 finished with value: 2.5000245965618646 and parameters: {'n_estimators': 1994, 'learning_rate': 0.006959927167558175, 'max_depth': 6, 'min_child_weight': 16.754026927743062, 'gamma': 1.7439611211656432, 'subsample': 0.5262647523671206, 'colsample_bytree': 0.614847578687547, 'reg_alpha': 2.5863754171095878e-08, 'reg_lambda': 0.005761631426290545}. Best is trial 53 with value: 2.4756026213194.
# [I 2026-06-09 07:34:41,528] Trial 65 pruned.
# [I 2026-06-09 07:40:48,810] Trial 66 pruned.
# [I 2026-06-09 07:43:22,932] Trial 67 pruned.
# [I 2026-06-09 07:48:32,426] Trial 68 finished with value: 2.502131500809585 and parameters: {'n_estimators': 1972, 'learning_rate': 0.0030086462869251896, 'max_depth': 7, 'min_child_weight': 10.10565243832751, 'gamma': 1.2695332530473078, 'subsample': 0.5336666479644309, 'colsample_bytree': 0.601746147730104, 'reg_alpha': 2.2345864178230922e-08, 'reg_lambda': 0.005750332983268355}. Best is trial 53 with value: 2.4756026213194.
# [I 2026-06-09 07:50:14,451] Trial 69 finished with value: 2.4921901264427264 and parameters: {'n_estimators': 1889, 'learning_rate': 0.0061982442881344454, 'max_depth': 8, 'min_child_weight': 13.90983714590013, 'gamma': 0.8280921722383786, 'subsample': 0.5817172086033893, 'colsample_bytree': 0.6606931651088709, 'reg_alpha': 2.8763604271095775e-06, 'reg_lambda': 0.03397944724313425}. Best is trial 53 with value: 2.4756026213194.
# [I 2026-06-09 07:50:44,634] Trial 70 pruned.
# [I 2026-06-09 07:54:12,728] Trial 71 finished with value: 2.4895551074832025 and parameters: {'n_estimators': 1245, 'learning_rate': 0.0042580040229579195, 'max_depth': 7, 'min_child_weight': 13.043647720076633, 'gamma': 1.1359229893854548, 'subsample': 0.5569381987104954, 'colsample_bytree': 0.5121503464391691, 'reg_alpha': 4.703622509500074e-08, 'reg_lambda': 0.014214324185451198}. Best is trial 53 with value: 2.4756026213194.
# [I 2026-06-09 07:56:23,237] Trial 72 finished with value: 2.499828797535821 and parameters: {'n_estimators': 999, 'learning_rate': 0.004380755003925713, 'max_depth': 7, 'min_child_weight': 17.11706297180221, 'gamma': 1.1924499414862682, 'subsample': 0.5457537759735624, 'colsample_bytree': 0.5536326848393404, 'reg_alpha': 3.2666485523377756e-08, 'reg_lambda': 0.014475616694041824}. Best is trial 53 with value: 2.4756026213194.
# [I 2026-06-09 07:58:36,165] Trial 73 finished with value: 2.4937248122746016 and parameters: {'n_estimators': 1105, 'learning_rate': 0.003398203924154248, 'max_depth': 7, 'min_child_weight': 13.895980372827397, 'gamma': 1.6365517074630085, 'subsample': 0.5037572894057292, 'colsample_bytree': 0.5116424218907998, 'reg_alpha': 1.7413361237940046e-08, 'reg_lambda': 0.006936639509563237}. Best is trial 53 with value: 2.4756026213194.
# [I 2026-06-09 07:59:15,377] Trial 74 pruned.
# [I 2026-06-09 08:00:01,654] Trial 75 finished with value: 2.4993288462374617 and parameters: {'n_estimators': 1374, 'learning_rate': 0.010750944121768826, 'max_depth': 8, 'min_child_weight': 10.280510486960527, 'gamma': 1.0136435722861765, 'subsample': 0.5561041698200393, 'colsample_bytree': 0.5881027306464421, 'reg_alpha': 1.0131411271426667e-08, 'reg_lambda': 0.04500734350022774}. Best is trial 53 with value: 2.4756026213194.
# [I 2026-06-09 08:00:42,553] Trial 76 pruned.
# [I 2026-06-09 08:01:31,619] Trial 77 pruned.
# [I 2026-06-09 08:02:29,334] Trial 78 finished with value: 2.4950583644794357 and parameters: {'n_estimators': 1432, 'learning_rate': 0.004709009387485712, 'max_depth': 7, 'min_child_weight': 16.271233582880594, 'gamma': 4.247001386902708, 'subsample': 0.535888739147644, 'colsample_bytree': 0.5920796401311751, 'reg_alpha': 9.826653722199191e-08, 'reg_lambda': 0.005689415980829301}. Best is trial 53 with value: 2.4756026213194.
# [I 2026-06-09 08:02:41,132] Trial 79 pruned.
# [I 2026-06-09 08:03:53,876] Trial 80 finished with value: 2.5035335833431525 and parameters: {'n_estimators': 1248, 'learning_rate': 0.004366010345404081, 'max_depth': 7, 'min_child_weight': 10.32171871032906, 'gamma': 0.800097416608307, 'subsample': 0.5654583910308931, 'colsample_bytree': 0.5154164224211115, 'reg_alpha': 1.650625406042942e-08, 'reg_lambda': 0.008757739709080609}. Best is trial 53 with value: 2.4756026213194.
# [I 2026-06-09 08:06:31,691] Trial 81 finished with value: 2.497382126362063 and parameters: {'n_estimators': 1234, 'learning_rate': 0.004083729534032732, 'max_depth': 7, 'min_child_weight': 12.11638944281585, 'gamma': 1.361400468553341, 'subsample': 0.5490133201967926, 'colsample_bytree': 0.5487689681079471, 'reg_alpha': 5.752725975589767e-08, 'reg_lambda': 0.385282550201273}. Best is trial 53 with value: 2.4756026213194.
# [I 2026-06-09 08:10:36,682] Trial 82 finished with value: 2.4984716347233493 and parameters: {'n_estimators': 1065, 'learning_rate': 0.004110837955744115, 'max_depth': 7, 'min_child_weight': 19.989844121158768, 'gamma': 1.5941980184203426, 'subsample': 0.5740286095933005, 'colsample_bytree': 0.5053117092013178, 'reg_alpha': 5.446858013115685e-08, 'reg_lambda': 0.025988190021087355}. Best is trial 53 with value: 2.4756026213194.
# [I 2026-06-09 08:11:24,911] Trial 83 pruned.
# [I 2026-06-09 08:13:08,410] Trial 84 finished with value: 2.4874030133693963 and parameters: {'n_estimators': 1768, 'learning_rate': 0.005154681574740503, 'max_depth': 8, 'min_child_weight': 12.486565084278974, 'gamma': 1.9930396503894343, 'subsample': 0.5173853803651802, 'colsample_bytree': 0.5645983691906865, 'reg_alpha': 2.4582000637032813e-07, 'reg_lambda': 0.018241667885365086}. Best is trial 53 with value: 2.4756026213194.
# [I 2026-06-09 08:15:07,902] Trial 85 finished with value: 2.4961679600655606 and parameters: {'n_estimators': 1956, 'learning_rate': 0.00633280490128867, 'max_depth': 8, 'min_child_weight': 15.251721968629328, 'gamma': 2.2500913976798187, 'subsample': 0.5132750733011692, 'colsample_bytree': 0.5644863653731829, 'reg_alpha': 3.949852002724967e-07, 'reg_lambda': 0.0046314762629777965}. Best is trial 53 with value: 2.4756026213194.
# [W 2026-06-09 08:15:22,855] Trial 86 failed with parameters: {'n_estimators': 1885, 'learning_rate': 0.008003591777663913, 'max_depth': 8, 'min_child_weight': 7.161775015854046, 'gamma': 1.9836723746869902, 'subsample': 0.52571989381992, 'colsample_bytree': 0.6010166087286941, 'reg_alpha': 2.670763096338761e-07, 'reg_lambda': 0.03412003150691444} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "d:\dev\weather-research\.venv\Lib\site-packages\optuna\study\_optimize.py", line 206, in _run_trial
#     value_or_values = func(trial)
#   File "D:\dev\weather-research\src\calibration\station_stacking.py", line 800, in objective
#     year = pd.to_numeric(frame.get("year"), errors="coerce")
#                                               ^^^^^^^^^^^^^^
#     ...<8 lines>...
#             for fold in folds:
#             ^^^^^^^^^
#   File "D:\dev\weather-research\src\calibration\station_stacking.py", line 1909, in _fit_predict_base_model
#         train: pd.DataFrame,
#     ...<7 lines>...
#
#   File "D:\dev\weather-research\src\calibration\station_stacking.py", line 1946, in _fit_base_estimator
#   File "d:\dev\weather-research\.venv\Lib\site-packages\xgboost\core.py", line 751, in inner_f
#     return func(**kwargs)
#   File "d:\dev\weather-research\.venv\Lib\site-packages\xgboost\sklearn.py", line 1368, in fit
#     self._Booster = train(
#                     ~~~~~^
#         params,
#         ^^^^^^^
#     ...<9 lines>...
#         callbacks=self.callbacks,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "d:\dev\weather-research\.venv\Lib\site-packages\xgboost\core.py", line 751, in inner_f
#     return func(**kwargs)
#   File "d:\dev\weather-research\.venv\Lib\site-packages\xgboost\training.py", line 200, in train
#     bst.update(dtrain, iteration=i, fobj=obj)
#     ~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\dev\weather-research\.venv\Lib\site-packages\xgboost\core.py", line 2391, in update
#     _LIB.XGBoosterUpdateOneIter(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         self.handle, ctypes.c_int(iteration), dtrain.handle
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
# KeyboardInterrupt
# [W 2026-06-09 08:15:22,893] Trial 86 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 18
#      14     stack_optuna_trials=STACK_OPTUNA_TRIALS,
#      15     optuna_verbose=OPTUNA_VERBOSE,
#      16     output_dir=PROJECT_ROOT / "data" / "calibration" / "station_stacking_v4",
#      17 )
# ---> 18 result = run_station_year_split_experiment(config)
#      19 result.scoreboard
#
# File D:\dev\weather-research\src\calibration\station_stacking.py:654, in run_station_year_split_experiment(config)
#     643     feature_columns_frame.to_csv(paths["feature_columns"], index=False)
#     644     return StationStackingResult(
#     645         station_id=station,
#     646         features=features,
#    (...)    650         output_paths=paths,
#     651     )
# --> 654 def run_station_year_split_experiment(config: StationStackingConfig) -> YearSplitExperimentResult:
#     655     features = build_station_wide_dataset(
#     656         config.resolved_project_root(),
#     657         station_id=config.station_id,
#     658         timing_mode=config.timing_mode,
#     659         providers=config.providers,
#     660     )
#     661     modeling_frame, categorical, numeric = _modeling_frame(features, config)
#
# File D:\dev\weather-research\src\calibration\station_stacking.py:864, in tune_year_split_base_models(frame, config, categorical, numeric, folds)
#     850 rmse = float(metrics["rmse_f"])
#     851 fold_scores.append((fold, float(metrics[metric_col])))
#     852 rows.append(
#     853     {
#     854         "method": method,
#     855         "trial_number": trial.number,
#     856         "param_key": param_key,
#     857         "fold": fold.name,
#     858         "fold_weight": _year_split_fold_weight(fold),
#     859         "mae_f": mae,
#     860         "rmse_f": rmse,
#     861         "count": int(metrics["count"]),
#     862         "fit_numeric_features": fit_metadata["numeric_features"],
#     863         "fit_categorical_features": fit_metadata["categorical_features"],
# --> 864         "best_iteration": fit_metadata["best_iteration"],
#     865         "status": "ok",
#     866         "error": "",
#     867         **{f"param_{key}": value for key, value in params.items()},
#     868     }
#     869 )
#     870 current_score = _weighted_fold_score(fold_scores)
#     871 if hasattr(trial, "report"):
#
# File d:\dev\weather-research\.venv\Lib\site-packages\optuna\study\study.py:516, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     414 def optimize(
#     415     self,
#     416     func: ObjectiveFuncType,
#    (...)    423     show_progress_bar: bool = False,
#     424 ) -> None:
#     425     """Optimize an objective function.
#     426
#     427     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)    514             If nested invocation of this method occurs.
#     515     """
# --> 516     _optimize(
#     517         study=self,
#     518         func=func,
#     519         n_trials=n_trials,
#     520         timeout=timeout,
#     521         n_jobs=n_jobs,
#     522         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     523         callbacks=callbacks,
#     524         gc_after_trial=gc_after_trial,
#     525         show_progress_bar=show_progress_bar,
#     526     )
#
# File d:\dev\weather-research\.venv\Lib\site-packages\optuna\study\_optimize.py:68, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      66 try:
#      67     if n_jobs == 1:
# ---> 68         _optimize_sequential(
#      69             study,
#      70             func,
#      71             n_trials,
#      72             timeout,
#      73             catch,
#      74             callbacks,
#      75             gc_after_trial,
#      76             reseed_sampler_rng=False,
#      77             time_start=None,
#      78             progress_bar=progress_bar,
#      79         )
#      80     else:
#      81         if n_jobs == -1:
#
# File d:\dev\weather-research\.venv\Lib\site-packages\optuna\study\_optimize.py:165, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     162         break
#     164 try:
# --> 165     frozen_trial_id = _run_trial(study, func, catch)
#     166 finally:
#     167     # The following line mitigates memory problems that can be occurred in some
#     168     # environments (e.g., services that use computing containers such as GitHub Actions).
#     169     # Please refer to the following PR for further details:
#     170     # https://github.com/optuna/optuna/pull/325.
#     171     if gc_after_trial:
#
# File d:\dev\weather-research\.venv\Lib\site-packages\optuna\study\_optimize.py:263, in _run_trial(study, func, catch)
#     256         assert False, "Should not reach."
#     258 if (
#     259     updated_state == TrialState.FAIL
#     260     and func_err is not None
#     261     and not isinstance(func_err, catch)
#     262 ):
# --> 263     raise func_err
#     264 return trial._trial_id
#
# File d:\dev\weather-research\.venv\Lib\site-packages\optuna\study\_optimize.py:206, in _run_trial(study, func, catch)
#     204 with get_heartbeat_thread(trial._trial_id, study._storage):
#     205     try:
# --> 206         value_or_values = func(trial)
#     207     except exceptions.TrialPruned as e:
#     208         # TODO(mamu): Handle multi-objective cases.
#     209         state = TrialState.PRUNED
#
# File D:\dev\weather-research\src\calibration\station_stacking.py:800, in objective(trial)
#     798     return pd.DataFrame(), _empty_year_split_predictions(), pd.DataFrame()
#     799 rows: list[dict[str, Any]] = []
# --> 800 year = pd.to_numeric(frame.get("year"), errors="coerce")
#     801 metric_col = config.effective_optuna_metric
#     802 for method in BASE_MODEL_METHODS:
#
# File D:\dev\weather-research\src\calibration\station_stacking.py:1909, in _fit_predict_base_model(config, categorical, numeric, method, params, train, valid, early_stopping)
#    1885         return CatBoostRegressor(
#    1886             iterations=cat_iterations,
#    1887             learning_rate=float(params.get("learning_rate", 0.035)),
#    (...)   1898             allow_writing_files=False,
#    1899         )
#    1900     raise ValueError(f"Unknown base model method: {method}")
#    1903 def _fit_predict_base_model(
#    1904     config: StationStackingConfig,
#    1905     categorical: list[str],
#    1906     numeric: list[str],
#    1907     method: str,
#    1908     params: dict[str, Any],
# -> 1909     train: pd.DataFrame,
#    1910     valid: pd.DataFrame,
#    1911     early_stopping: bool,
#    1912 ) -> tuple[np.ndarray, dict[str, Any]]:
#    1913     fit_categorical, fit_numeric = _fit_feature_columns(train, categorical, numeric)
#    1914     feature_names = [*fit_categorical, *fit_numeric]
#
# File D:\dev\weather-research\src\calibration\station_stacking.py:1946, in _fit_base_estimator(estimator, method, x_train, y_train, x_valid, y_valid, early_stopping_rounds)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File d:\dev\weather-research\.venv\Lib\site-packages\xgboost\core.py:751, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     749 for k, arg in zip(sig.parameters, args):
#     750     kwargs[k] = arg
# --> 751 return func(**kwargs)
#
# File d:\dev\weather-research\.venv\Lib\site-packages\xgboost\sklearn.py:1368, in XGBModel.fit(self, X, y, sample_weight, base_margin, eval_set, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights)
#    1365 else:
#    1366     obj = None
# -> 1368 self._Booster = train(
#    1369     params,
#    1370     train_dmatrix,
#    1371     self.get_num_boosting_rounds(),
#    1372     evals=evals,
#    1373     early_stopping_rounds=self.early_stopping_rounds,
#    1374     evals_result=evals_result,
#    1375     obj=obj,
#    1376     custom_metric=metric,
#    1377     verbose_eval=verbose,
#    1378     xgb_model=model,
#    1379     callbacks=self.callbacks,
#    1380 )
#    1382 self._set_evaluation_result(evals_result)
#    1383 return self
#
# File d:\dev\weather-research\.venv\Lib\site-packages\xgboost\core.py:751, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     749 for k, arg in zip(sig.parameters, args):
#     750     kwargs[k] = arg
# --> 751 return func(**kwargs)
#
# File d:\dev\weather-research\.venv\Lib\site-packages\xgboost\training.py:200, in train(params, dtrain, num_boost_round, evals, obj, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     198 if cb_container.before_iteration(bst, i, dtrain, evals):
#     199     break
# --> 200 bst.update(dtrain, iteration=i, fobj=obj)
#     201 if cb_container.after_iteration(bst, i, dtrain, evals):
#     202     break
#
# File d:\dev\weather-research\.venv\Lib\site-packages\xgboost\core.py:2391, in Booster.update(self, dtrain, iteration, fobj)
#    2387 self._assign_dmatrix_features(dtrain)
#    2389 if fobj is None:
#    2390     _check_call(
# -> 2391         _LIB.XGBoosterUpdateOneIter(
#    2392             self.handle, ctypes.c_int(iteration), dtrain.handle
#    2393         )
#    2394     )
#    2395     return
#    2397 # Forward the gradient calculation to the boost method.
#
# KeyboardInterrupt:

# %% [markdown]
# ## Rounded Within 1F Accuracy

# %%
preds = pd.concat(
    [
        result.validation_predictions.assign(period="validation_2024_2025"),
        result.test_predictions.assign(period="test_2026"),
    ],
    ignore_index=True,
)

predicted_high = pd.to_numeric(preds["predicted_high_f"], errors="coerce")
preds["predicted_high_rounded_f"] = np.floor(predicted_high + 0.5)
preds["within_1f_after_round"] = (
    pd.to_numeric(preds["actual_high_f"], errors="coerce") - preds["predicted_high_rounded_f"]
).abs().le(1)

within_1f_accuracy_by_period = (
    preds
    .dropna(subset=["actual_high_f", "predicted_high_rounded_f"])
    .groupby(["period", "method"], as_index=False)
    .agg(
        count=("within_1f_after_round", "size"),
        within_1f_count=("within_1f_after_round", "sum"),
        within_1f_accuracy_pct=("within_1f_after_round", lambda x: x.mean() * 100),
    )
    .sort_values(["period", "within_1f_accuracy_pct"], ascending=[True, False])
)

within_1f_accuracy_by_period

# %% [markdown]
# ## Precipitation Feature Coverage

# %%
precip_columns = [column for column in result.features.columns if "precip" in column.lower()]
coverage = (
    result.features[precip_columns]
    .notna()
    .mean()
    .mul(100)
    .sort_values(ascending=False)
    .rename("coverage_pct")
    .reset_index()
    .rename(columns={"index": "feature"})
)
coverage

# %% [markdown]
# ## Version Comparison

# %%
comparison_frames = []
for version, folder in [
    ("v1", PROJECT_ROOT / "data" / "calibration" / "station_stacking"),
    ("v2", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v2"),
    ("v3", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v3"),
    ("v4", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v4"),
]:
    path = folder / f"{STATION_ID}_year_split_scoreboard.csv"
    if path.exists():
        frame = pd.read_csv(path)
        frame["version"] = version
        comparison_frames.append(frame)

version_comparison = pd.concat(comparison_frames, ignore_index=True) if comparison_frames else pd.DataFrame()
if not version_comparison.empty:
    version_comparison = version_comparison.sort_values(["period", "mae_f", "version", "method"]).reset_index(drop=True)
version_comparison

# %% [markdown]
# ## 2026 Weather Brackets

# %%
result.bracket_metrics

# %%
import pandas as pd


def adjacent_brackets(bracket):
    if pd.isna(bracket):
        return []
    text = str(bracket).strip()
    if not text or "-" not in text:
        return []
    try:
        lower = int(text.split("-", 1)[0])
    except ValueError:
        return []
    return [
        f"{lower - 2}-{lower - 1}",
        f"{lower}-{lower + 1}",
        f"{lower + 2}-{lower + 3}",
    ]


bracket_3way = result.bracket_predictions.copy()

valid = bracket_3way["actual_bracket"].notna() & bracket_3way["predicted_bracket"].astype(str).str.strip().ne("")
bracket_3way = bracket_3way.loc[valid].copy()
bracket_3way["picked_brackets"] = bracket_3way["predicted_bracket"].map(adjacent_brackets)
bracket_3way["three_bracket_hit"] = bracket_3way.apply(
    lambda row: row["actual_bracket"] in row["picked_brackets"],
    axis=1,
)

three_bracket_accuracy = (
    bracket_3way
    .groupby("method", as_index=False)
    .agg(
        count=("three_bracket_hit", "size"),
        exact_bracket_accuracy_pct=("bracket_hit", lambda x: x.mean() * 100),
        three_bracket_accuracy_pct=("three_bracket_hit", lambda x: x.mean() * 100),
    )
    .sort_values("three_bracket_accuracy_pct", ascending=False)
)

three_bracket_accuracy

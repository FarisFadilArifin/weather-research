# %% [markdown]
# # Station Stacking v4 - KHOU
#
# Wide HRRR/GFS same-day 11am notebook for `KHOU`.
#
# This version keeps the v3 high-so-far features and adds SDK-backed precipitation features from HRRR/GFS forecast precipitation plus 11 AM METAR precipitation codes. Artifacts are written to `data/calibration/station_stacking_v4`.

# %%
from pathlib import Path
import sys
import warnings

warnings.filterwarnings("ignore", message="IProgress not found.*")
warnings.filterwarnings("ignore", message="Skipping features without any observed values.*")

PROJECT_ROOT = Path.cwd().resolve()
while not (PROJECT_ROOT / "src" / "calibration" / "station_stacking.py").exists():
    if PROJECT_ROOT.parent == PROJECT_ROOT:
        raise RuntimeError("Could not find project root containing src/calibration/station_stacking.py")
    PROJECT_ROOT = PROJECT_ROOT.parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

STATION_ID = "KHOU"
FAST_MODE = False
OPTUNA_TRIALS = 100
STACK_OPTUNA_TRIALS = 50
OPTUNA_VERBOSE = True
PROJECT_ROOT
# Out:
# WindowsPath('D:/dev/weather-research')

# %%
from src.calibration.station_stacking import (
    StationStackingConfig,
    missing_model_dependencies,
    run_station_year_split_experiment,
)

# %% [markdown]
# ## V4 Feature Engineering
#
# Adds v2/v3 temperature features plus forecast and observed precipitation signals. Forecast precipitation comes from provider-prefixed SDK summary columns such as `gfs_forecast_precip_total_mm`, with `gfs_precip_amount` as a fallback for older caches.

# %%
import numpy as np
import pandas as pd
import src.calibration.station_stacking as station_stacking_module

V4_PROVIDERS = ("gfs", "hrrr")
V4_FEATURE_COLUMNS = [
    "v2_recent_heat_anomaly_f",
    "v2_recent_heat_momentum_f",
    "v2_morning_warmup_to_consensus_f",
    "v2_consensus_minus_7d_actual_f",
    "v2_spread_per_warmup_f",
    "v2_humidity_warmup_interaction",
    "v3_high_so_far_above_current_f",
    "v3_remaining_warmup_from_high_so_far_f",
    "v3_high_so_far_minus_lag_1d_f",
    "v3_high_so_far_minus_7d_actual_f",
    "v3_remaining_warmup_per_spread_f",
    "v3_humidity_remaining_warmup_interaction",
    "v4_forecast_precip_total_mean_mm",
    "v4_forecast_precip_total_max_mm",
    "v4_forecast_precip_total_spread_mm",
    "v4_forecast_precip_max_1h_mean_mm",
    "v4_forecast_precip_hours_mean",
    "v4_forecast_precip_intensity_mean",
    "v4_forecast_precip_intensity_max",
    "v4_any_forecast_precip",
    "v4_all_forecast_precip",
    "v4_observed_precip_any",
    "v4_observed_precip_recent_mm_est",
    "v4_forecast_total_minus_observed_recent_mm",
    "v4_forecast_observed_precip_match",
    "v4_forecast_wet_observed_dry",
    "v4_observed_wet_forecast_dry",
    "v4_precip_humidity_interaction",
    "v4_precip_remaining_warmup_interaction",
]


def _num(frame: pd.DataFrame, column: str) -> pd.Series:
    if column in frame:
        return pd.to_numeric(frame[column], errors="coerce")
    return pd.Series(np.nan, index=frame.index, dtype="float64")


def _bool_num(frame: pd.DataFrame, column: str) -> pd.Series:
    if column not in frame:
        return pd.Series(0, index=frame.index, dtype="int64")
    series = frame[column]
    if pd.api.types.is_bool_dtype(series):
        return series.fillna(False).astype(int)
    if pd.api.types.is_numeric_dtype(series):
        return pd.to_numeric(series, errors="coerce").fillna(0).gt(0).astype(int)
    return series.astype("string").str.lower().isin({"1", "true", "yes", "y"}).astype(int)


def _provider_series(frame: pd.DataFrame, provider: str, primary: str, fallback: str | None = None) -> pd.Series:
    primary_column = f"{provider}_{primary}"
    if primary_column in frame:
        return _num(frame, primary_column)
    if fallback is not None:
        return _num(frame, f"{provider}_{fallback}")
    return pd.Series(np.nan, index=frame.index, dtype="float64")


def _provider_matrix(frame: pd.DataFrame, primary: str, fallback: str | None = None) -> pd.DataFrame:
    return pd.DataFrame(
        {provider: _provider_series(frame, provider, primary, fallback) for provider in V4_PROVIDERS},
        index=frame.index,
    )


def add_v4_feature_engineering(frame: pd.DataFrame) -> pd.DataFrame:
    out = frame.copy()
    observed_temp = _num(out, "observed_temp_at_as_of_f")
    high_so_far = _num(out, "observed_high_temp_through_as_of_f")
    observed_humidity = _num(out, "observed_humidity_at_as_of")
    provider_mean = _num(out, "provider_mean_high_f")
    provider_spread = _num(out, "provider_spread_high_f")
    lag_1d = _num(out, "actual_high_lag_1d")
    roll_7d = _num(out, "actual_high_roll_7d_mean")
    roll_30d = _num(out, "actual_high_roll_30d_mean")

    warmup_to_consensus = provider_mean - observed_temp
    remaining_warmup = provider_mean - high_so_far
    out["v2_recent_heat_anomaly_f"] = lag_1d - roll_30d
    out["v2_recent_heat_momentum_f"] = roll_7d - roll_30d
    out["v2_morning_warmup_to_consensus_f"] = warmup_to_consensus
    out["v2_consensus_minus_7d_actual_f"] = provider_mean - roll_7d
    out["v2_spread_per_warmup_f"] = provider_spread / warmup_to_consensus.abs().clip(lower=1.0)
    out["v2_humidity_warmup_interaction"] = (observed_humidity / 100.0) * warmup_to_consensus
    out["v3_high_so_far_above_current_f"] = high_so_far - observed_temp
    out["v3_remaining_warmup_from_high_so_far_f"] = remaining_warmup
    out["v3_high_so_far_minus_lag_1d_f"] = high_so_far - lag_1d
    out["v3_high_so_far_minus_7d_actual_f"] = high_so_far - roll_7d
    out["v3_remaining_warmup_per_spread_f"] = remaining_warmup / provider_spread.abs().clip(lower=1.0)
    out["v3_humidity_remaining_warmup_interaction"] = (observed_humidity / 100.0) * remaining_warmup

    precip_total = _provider_matrix(out, "forecast_precip_total_mm", fallback="precip_amount")
    precip_max_1h = _provider_matrix(out, "forecast_precip_max_1h_mm")
    precip_hours = _provider_matrix(out, "forecast_precip_hours_count")
    precip_intensity = _provider_matrix(out, "forecast_precip_intensity_code")
    has_precip = _provider_matrix(out, "forecast_has_precip").fillna(0).clip(lower=0, upper=1)

    out["v4_forecast_precip_total_mean_mm"] = precip_total.mean(axis=1)
    out["v4_forecast_precip_total_max_mm"] = precip_total.max(axis=1)
    out["v4_forecast_precip_total_spread_mm"] = precip_total.max(axis=1) - precip_total.min(axis=1)
    out["v4_forecast_precip_max_1h_mean_mm"] = precip_max_1h.mean(axis=1)
    out["v4_forecast_precip_hours_mean"] = precip_hours.mean(axis=1)
    out["v4_forecast_precip_intensity_mean"] = precip_intensity.mean(axis=1)
    out["v4_forecast_precip_intensity_max"] = precip_intensity.max(axis=1)
    out["v4_any_forecast_precip"] = has_precip.max(axis=1).fillna(0).astype(int)
    out["v4_all_forecast_precip"] = has_precip.min(axis=1).fillna(0).astype(int)

    observed_any = (
        _bool_num(out, "observed_is_raining_at_as_of")
        | _bool_num(out, "observed_is_drizzle_at_as_of")
        | _bool_num(out, "observed_is_snowing_at_as_of")
    ).astype(int)
    observed_recent_mm = _num(out, "observed_precip_recent_at_as_of") * 25.4
    out["v4_observed_precip_any"] = observed_any
    out["v4_observed_precip_recent_mm_est"] = observed_recent_mm
    out["v4_forecast_total_minus_observed_recent_mm"] = out["v4_forecast_precip_total_mean_mm"] - observed_recent_mm
    out["v4_forecast_observed_precip_match"] = out["v4_any_forecast_precip"].eq(observed_any).astype(int)
    out["v4_forecast_wet_observed_dry"] = (out["v4_any_forecast_precip"].eq(1) & observed_any.eq(0)).astype(int)
    out["v4_observed_wet_forecast_dry"] = (observed_any.eq(1) & out["v4_any_forecast_precip"].eq(0)).astype(int)
    out["v4_precip_humidity_interaction"] = out["v4_forecast_precip_total_mean_mm"] * (observed_humidity / 100.0)
    out["v4_precip_remaining_warmup_interaction"] = out["v4_forecast_precip_total_mean_mm"] * remaining_warmup
    return out


if not hasattr(station_stacking_module, "_v4_original_build_station_wide_dataset"):
    station_stacking_module._v4_original_build_station_wide_dataset = station_stacking_module.build_station_wide_dataset


def build_station_wide_dataset_v4(*args, **kwargs):
    frame = station_stacking_module._v4_original_build_station_wide_dataset(*args, **kwargs)
    return add_v4_feature_engineering(frame)


station_stacking_module.build_station_wide_dataset = build_station_wide_dataset_v4
V4_FEATURE_COLUMNS
# Out:
# ['v2_recent_heat_anomaly_f',
#  'v2_recent_heat_momentum_f',
#  'v2_morning_warmup_to_consensus_f',
#  'v2_consensus_minus_7d_actual_f',
#  'v2_spread_per_warmup_f',
#  'v2_humidity_warmup_interaction',
#  'v3_high_so_far_above_current_f',
#  'v3_remaining_warmup_from_high_so_far_f',
#  'v3_high_so_far_minus_lag_1d_f',
#  'v3_high_so_far_minus_7d_actual_f',
#  'v3_remaining_warmup_per_spread_f',
#  'v3_humidity_remaining_warmup_interaction',
#  'v4_forecast_precip_total_mean_mm',
#  'v4_forecast_precip_total_max_mm',
#  'v4_forecast_precip_total_spread_mm',
#  'v4_forecast_precip_max_1h_mean_mm',
#  'v4_forecast_precip_hours_mean',
#  'v4_forecast_precip_intensity_mean',
#  'v4_forecast_precip_intensity_max',
#  'v4_any_forecast_precip',
#  'v4_all_forecast_precip',
#  'v4_observed_precip_any',
#  'v4_observed_precip_recent_mm_est',
#  'v4_forecast_total_minus_observed_recent_mm',
#  'v4_forecast_observed_precip_match',
#  'v4_forecast_wet_observed_dry',
#  'v4_observed_wet_forecast_dry',
#  'v4_precip_humidity_interaction',
#  'v4_precip_remaining_warmup_interaction']

# %% [markdown]
# ## Model Scores

# %%
missing_packages = missing_model_dependencies()
if missing_packages:
    raise ImportError(
        "Missing station-stacking ML packages: "
        + ", ".join(missing_packages)
        + ". Install them with: python -m pip install -r requirements.txt"
    )

config = StationStackingConfig(
    station_id=STATION_ID,
    project_root=PROJECT_ROOT,
    fast_mode=FAST_MODE,
    optuna_trials=OPTUNA_TRIALS,
    stack_optuna_trials=STACK_OPTUNA_TRIALS,
    optuna_verbose=OPTUNA_VERBOSE,
    output_dir=PROJECT_ROOT / "data" / "calibration" / "station_stacking_v4",
)
result = run_station_year_split_experiment(config)
result.scoreboard
# Out:
# [I 2026-06-09 06:28:14,586] A new study created in memory with name: no-name-a22db88b-1b70-4278-82f5-479d44d3da84
# [I 2026-06-09 06:28:24,802] Trial 0 finished with value: 4.7866614607808735 and parameters: {'n_estimators': 799, 'learning_rate': 0.12369619597856178, 'max_depth': 6, 'min_child_weight': 2.385234757844707, 'gamma': 0.7800932022121826, 'subsample': 0.5779972601681014, 'colsample_bytree': 0.5290418060840998, 'reg_alpha': 0.6245760287469893, 'reg_lambda': 0.6677615511747083}. Best is trial 0 with value: 4.7866614607808735.
# [I 2026-06-09 06:31:15,556] Trial 1 finished with value: 4.596872459793541 and parameters: {'n_estimators': 1440, 'learning_rate': 0.0032515743808034223, 'max_depth': 8, 'min_child_weight': 8.23143373099555, 'gamma': 1.0616955533913808, 'subsample': 0.5909124836035503, 'colsample_bytree': 0.5917022549267169, 'reg_alpha': 5.472429642032198e-06, 'reg_lambda': 0.2922905212920093}. Best is trial 1 with value: 4.596872459793541.
# [I 2026-06-09 06:31:53,032] Trial 2 finished with value: 4.713494106799674 and parameters: {'n_estimators': 909, 'learning_rate': 0.009373695213782608, 'max_depth': 5, 'min_child_weight': 0.20940138873937433, 'gamma': 1.4607232426760908, 'subsample': 0.6831809216468459, 'colsample_bytree': 0.728034992108518, 'reg_alpha': 0.1165691561324743, 'reg_lambda': 0.008674832802525461}. Best is trial 1 with value: 4.596872459793541.
# [I 2026-06-09 06:32:12,130] Trial 3 finished with value: 4.558725149885496 and parameters: {'n_estimators': 1067, 'learning_rate': 0.03045200113778571, 'max_depth': 1, 'min_child_weight': 2.5002240473339543, 'gamma': 0.8526206184364576, 'subsample': 0.5325257964926398, 'colsample_bytree': 0.9744427686266666, 'reg_alpha': 4.905556676028774, 'reg_lambda': 6.289771819487036}. Best is trial 3 with value: 4.558725149885496.
# [I 2026-06-09 06:33:44,616] Trial 4 finished with value: 4.707563087268764 and parameters: {'n_estimators': 665, 'learning_rate': 0.004396056309201638, 'max_depth': 6, 'min_child_weight': 1.0299214204601976, 'gamma': 0.6101911742238941, 'subsample': 0.7475884550556351, 'colsample_bytree': 0.5171942605576092, 'reg_alpha': 1.527156759251193, 'reg_lambda': 0.016443693426189242}. Best is trial 3 with value: 4.558725149885496.
# [I 2026-06-09 06:34:17,109] Trial 5 pruned.
# [I 2026-06-09 06:34:25,864] Trial 6 finished with value: 4.643421250042589 and parameters: {'n_estimators': 1228, 'learning_rate': 0.11049889315270257, 'max_depth': 1, 'min_child_weight': 0.28246357083904894, 'gamma': 0.22613644455269033, 'subsample': 0.6626651653816322, 'colsample_bytree': 0.6943386448447411, 'reg_alpha': 2.7678419414850017e-06, 'reg_lambda': 7.838134236608707}. Best is trial 3 with value: 4.558725149885496.
# [I 2026-06-09 06:34:47,785] Trial 7 pruned.
# [I 2026-06-09 06:34:50,640] Trial 8 pruned.
# [I 2026-06-09 06:35:06,948] Trial 9 finished with value: 4.536955437414913 and parameters: {'n_estimators': 1277, 'learning_rate': 0.01094730135557207, 'max_depth': 1, 'min_child_weight': 0.5194929407101735, 'gamma': 1.6259166101337352, 'subsample': 0.864803089169032, 'colsample_bytree': 0.8187787356776066, 'reg_alpha': 0.9658611176861268, 'reg_lambda': 0.16554793541373172}. Best is trial 9 with value: 4.536955437414913.
# [I 2026-06-09 06:35:12,600] Trial 10 pruned.
# [I 2026-06-09 06:35:26,079] Trial 11 finished with value: 4.513393585526492 and parameters: {'n_estimators': 1702, 'learning_rate': 0.029837101549845032, 'max_depth': 1, 'min_child_weight': 0.688588546457162, 'gamma': 2.1717813587820567, 'subsample': 0.8579328744354449, 'colsample_bytree': 0.9777833521699496, 'reg_alpha': 0.0029151336209232823, 'reg_lambda': 1.477313598872863}. Best is trial 11 with value: 4.513393585526492.
# [I 2026-06-09 06:35:37,786] Trial 12 finished with value: 4.547279491042737 and parameters: {'n_estimators': 1782, 'learning_rate': 0.02600143267644442, 'max_depth': 2, 'min_child_weight': 0.6243838727697036, 'gamma': 2.343526094439211, 'subsample': 0.8608706114175635, 'colsample_bytree': 0.85058129769688, 'reg_alpha': 0.0018527674778937963, 'reg_lambda': 1.0698131273173805}. Best is trial 11 with value: 4.513393585526492.
# [I 2026-06-09 06:35:46,842] Trial 13 pruned.
# [I 2026-06-09 06:35:54,728] Trial 14 finished with value: 4.5646643480610125 and parameters: {'n_estimators': 1578, 'learning_rate': 0.05448914692799354, 'max_depth': 2, 'min_child_weight': 0.10461515075215143, 'gamma': 3.155421717694825, 'subsample': 0.8396779355177069, 'colsample_bytree': 0.7838182878658029, 'reg_alpha': 7.694401017870849e-05, 'reg_lambda': 2.053199814674828}. Best is trial 11 with value: 4.513393585526492.
# [I 2026-06-09 06:36:15,583] Trial 15 finished with value: 4.535965428696979 and parameters: {'n_estimators': 1937, 'learning_rate': 0.018451880385341596, 'max_depth': 1, 'min_child_weight': 0.8481185560035129, 'gamma': 1.75760829066606, 'subsample': 0.7848922692513441, 'colsample_bytree': 0.9314636609266265, 'reg_alpha': 0.02389740658062493, 'reg_lambda': 0.09299653023568379}. Best is trial 11 with value: 4.513393585526492.
# [I 2026-06-09 06:36:23,660] Trial 16 pruned.
# [I 2026-06-09 06:36:29,484] Trial 17 pruned.
# [I 2026-06-09 06:37:20,301] Trial 18 finished with value: 4.535449361285153 and parameters: {'n_estimators': 1999, 'learning_rate': 0.005276970420194563, 'max_depth': 1, 'min_child_weight': 5.113158661754189, 'gamma': 3.0207927475059955, 'subsample': 0.923864568817558, 'colsample_bytree': 0.9964797542029741, 'reg_alpha': 0.00014021547203370562, 'reg_lambda': 0.06045336547293837}. Best is trial 11 with value: 4.513393585526492.
# [I 2026-06-09 06:37:39,738] Trial 19 pruned.
# [I 2026-06-09 06:38:01,063] Trial 20 pruned.
# [I 2026-06-09 06:38:37,304] Trial 21 finished with value: 4.5397012331300175 and parameters: {'n_estimators': 1955, 'learning_rate': 0.006364139293033369, 'max_depth': 1, 'min_child_weight': 4.061356246881408, 'gamma': 3.116360633656509, 'subsample': 0.8081638781372212, 'colsample_bytree': 0.9422274076669946, 'reg_alpha': 0.0004577733334750678, 'reg_lambda': 0.044029898322040295}. Best is trial 11 with value: 4.513393585526492.
# [I 2026-06-09 06:38:44,203] Trial 22 pruned.
# [I 2026-06-09 06:38:47,712] Trial 23 finished with value: 4.533718004982063 and parameters: {'n_estimators': 1964, 'learning_rate': 0.04215227269262243, 'max_depth': 2, 'min_child_weight': 1.457385825070281, 'gamma': 3.600012640361156, 'subsample': 0.9988718544677748, 'colsample_bytree': 0.9981930598092277, 'reg_alpha': 3.2755891121027535e-06, 'reg_lambda': 0.41360941466131496}. Best is trial 11 with value: 4.513393585526492.
# [I 2026-06-09 06:38:50,781] Trial 24 finished with value: 4.5401717490742355 and parameters: {'n_estimators': 1494, 'learning_rate': 0.05709033890349845, 'max_depth': 2, 'min_child_weight': 1.7107790263528548, 'gamma': 3.7718887726202652, 'subsample': 0.9877427111019913, 'colsample_bytree': 0.991798060189385, 'reg_alpha': 2.710080602427406e-06, 'reg_lambda': 0.4246387109770982}. Best is trial 11 with value: 4.513393585526492.
# [I 2026-06-09 06:38:54,169] Trial 25 pruned.
# [I 2026-06-09 06:39:03,591] Trial 26 finished with value: 4.526713756703802 and parameters: {'n_estimators': 1828, 'learning_rate': 0.037922986358016705, 'max_depth': 2, 'min_child_weight': 3.01113020549592, 'gamma': 3.467374318487587, 'subsample': 0.8965123421639123, 'colsample_bytree': 0.9717961754249553, 'reg_alpha': 5.076294198713129e-07, 'reg_lambda': 0.22933154817334564}. Best is trial 11 with value: 4.513393585526492.
# [I 2026-06-09 06:39:10,964] Trial 27 pruned.
# [I 2026-06-09 06:39:21,105] Trial 28 finished with value: 4.55187976397938 and parameters: {'n_estimators': 1647, 'learning_rate': 0.034522440681095584, 'max_depth': 2, 'min_child_weight': 2.390055739059134, 'gamma': 4.158840279963768, 'subsample': 0.8196869494128134, 'colsample_bytree': 0.9130369544593636, 'reg_alpha': 4.184671878847924e-07, 'reg_lambda': 0.23326681893585235}. Best is trial 11 with value: 4.513393585526492.
# [I 2026-06-09 06:39:25,048] Trial 29 pruned.
# [I 2026-06-09 06:39:29,962] Trial 30 pruned.
# [I 2026-06-09 06:39:31,106] Trial 31 pruned.
# [I 2026-06-09 06:39:40,655] Trial 32 pruned.
# [I 2026-06-09 06:40:13,778] Trial 33 pruned.
# [I 2026-06-09 06:40:24,921] Trial 34 pruned.
# [I 2026-06-09 06:40:34,866] Trial 35 pruned.
# [I 2026-06-09 06:40:41,502] Trial 36 pruned.
# [I 2026-06-09 06:40:45,265] Trial 37 pruned.
# [I 2026-06-09 06:40:59,874] Trial 38 finished with value: 4.5248336651374075 and parameters: {'n_estimators': 1872, 'learning_rate': 0.023393123181304876, 'max_depth': 2, 'min_child_weight': 2.014405823418176, 'gamma': 4.9221722998707165, 'subsample': 0.9709266853129992, 'colsample_bytree': 0.9378444913292732, 'reg_alpha': 0.006985454054065159, 'reg_lambda': 0.0824084762480378}. Best is trial 11 with value: 4.513393585526492.
# [I 2026-06-09 06:41:10,844] Trial 39 pruned.
# [I 2026-06-09 06:41:26,036] Trial 40 finished with value: 4.541531246297646 and parameters: {'n_estimators': 1255, 'learning_rate': 0.03131832910409828, 'max_depth': 2, 'min_child_weight': 2.063942604454825, 'gamma': 4.980327291235506, 'subsample': 0.967841147631352, 'colsample_bytree': 0.9393275341919312, 'reg_alpha': 7.291234509629697e-08, 'reg_lambda': 0.30433470697049614}. Best is trial 11 with value: 4.513393585526492.
# [I 2026-06-09 06:41:36,164] Trial 41 finished with value: 4.532810677782355 and parameters: {'n_estimators': 1867, 'learning_rate': 0.06172171613088862, 'max_depth': 1, 'min_child_weight': 2.0418779684334094, 'gamma': 1.2489798253304216, 'subsample': 0.9200162713753108, 'colsample_bytree': 0.9762970603829156, 'reg_alpha': 0.005945389001063321, 'reg_lambda': 0.07469665772234572}. Best is trial 11 with value: 4.513393585526492.
# [I 2026-06-09 06:41:39,557] Trial 42 pruned.
# [I 2026-06-09 06:41:53,643] Trial 43 finished with value: 4.522116424539782 and parameters: {'n_estimators': 1866, 'learning_rate': 0.02805286434003436, 'max_depth': 1, 'min_child_weight': 1.4397193854581087, 'gamma': 1.2419955618227516, 'subsample': 0.8755211251926062, 'colsample_bytree': 0.972525324284932, 'reg_alpha': 0.005034390197546259, 'reg_lambda': 0.08713334506578804}. Best is trial 11 with value: 4.513393585526492.
# [I 2026-06-09 06:42:09,081] Trial 44 finished with value: 4.522024743732122 and parameters: {'n_estimators': 1874, 'learning_rate': 0.022375637918853, 'max_depth': 1, 'min_child_weight': 0.920049830985931, 'gamma': 1.2505397020386353, 'subsample': 0.8724276913306346, 'colsample_bytree': 0.9300924809959095, 'reg_alpha': 0.009581859024311887, 'reg_lambda': 0.004011537377537847}. Best is trial 11 with value: 4.513393585526492.
# [I 2026-06-09 06:42:28,636] Trial 45 finished with value: 4.545251635441554 and parameters: {'n_estimators': 1617, 'learning_rate': 0.015160508339489358, 'max_depth': 1, 'min_child_weight': 0.7744951493273398, 'gamma': 0.025503477827565124, 'subsample': 0.860998617100183, 'colsample_bytree': 0.8842242708042707, 'reg_alpha': 0.4319871142305104, 'reg_lambda': 0.004125626272898019}. Best is trial 11 with value: 4.513393585526492.
# [I 2026-06-09 06:42:37,026] Trial 46 finished with value: 4.523699378243288 and parameters: {'n_estimators': 1750, 'learning_rate': 0.022212621016483473, 'max_depth': 1, 'min_child_weight': 0.4242143793290184, 'gamma': 0.758063408763094, 'subsample': 0.8445113864405792, 'colsample_bytree': 0.9209008435321533, 'reg_alpha': 0.008666218831668692, 'reg_lambda': 0.015009375304119903}. Best is trial 11 with value: 4.513393585526492.
# [I 2026-06-09 06:42:53,604] Trial 47 finished with value: 4.526082965884665 and parameters: {'n_estimators': 1735, 'learning_rate': 0.023033899694077358, 'max_depth': 1, 'min_child_weight': 0.22814590344649674, 'gamma': 0.6906160045382643, 'subsample': 0.7407442561600073, 'colsample_bytree': 0.8119167396468142, 'reg_alpha': 0.007614758188710334, 'reg_lambda': 0.0024923412939065774}. Best is trial 11 with value: 4.513393585526492.
# [I 2026-06-09 06:43:17,970] Trial 48 finished with value: 4.5334148167209944 and parameters: {'n_estimators': 1452, 'learning_rate': 0.013593582220167516, 'max_depth': 1, 'min_child_weight': 0.36394845087211575, 'gamma': 0.42821415366796, 'subsample': 0.7996342892864784, 'colsample_bytree': 0.9229790391678874, 'reg_alpha': 0.04494805942503544, 'reg_lambda': 0.010735233632806046}. Best is trial 11 with value: 4.513393585526492.
# [I 2026-06-09 06:43:33,879] Trial 49 finished with value: 4.52615792518356 and parameters: {'n_estimators': 1596, 'learning_rate': 0.028626934270588874, 'max_depth': 1, 'min_child_weight': 0.5779444294907731, 'gamma': 1.2061124235845628, 'subsample': 0.8404315851977423, 'colsample_bytree': 0.9027408246471418, 'reg_alpha': 0.0016465767539037004, 'reg_lambda': 0.004513576782149147}. Best is trial 11 with value: 4.513393585526492.
# [I 2026-06-09 06:43:51,739] Trial 50 finished with value: 4.5291780570553035 and parameters: {'n_estimators': 1905, 'learning_rate': 0.019229550250767467, 'max_depth': 1, 'min_child_weight': 0.14650937457701385, 'gamma': 0.8965797009248322, 'subsample': 0.8770718677829026, 'colsample_bytree': 0.8604208810339511, 'reg_alpha': 0.01092799212112871, 'reg_lambda': 0.011798676469961258}. Best is trial 11 with value: 4.513393585526492.
# [I 2026-06-09 06:44:05,996] Trial 51 finished with value: 4.538178855550225 and parameters: {'n_estimators': 1735, 'learning_rate': 0.022122517279572037, 'max_depth': 1, 'min_child_weight': 0.2556089201037252, 'gamma': 0.6220884923474338, 'subsample': 0.7412966842212217, 'colsample_bytree': 0.797322154364592, 'reg_alpha': 0.004062066231290599, 'reg_lambda': 0.002315958304168605}. Best is trial 11 with value: 4.513393585526492.
# [I 2026-06-09 06:44:17,504] Trial 52 finished with value: 4.53800837146431 and parameters: {'n_estimators': 1722, 'learning_rate': 0.021841945796532994, 'max_depth': 1, 'min_child_weight': 0.40815339073155005, 'gamma': 0.730733066319053, 'subsample': 0.6630044327084786, 'colsample_bytree': 0.6899223917593338, 'reg_alpha': 0.0008254093140284901, 'reg_lambda': 0.0027608712106593322}. Best is trial 11 with value: 4.513393585526492.
# [I 2026-06-09 06:44:19,915] Trial 53 pruned.
# [I 2026-06-09 06:44:24,888] Trial 54 pruned.
# [I 2026-06-09 06:44:31,394] Trial 55 pruned.
# [I 2026-06-09 06:44:40,702] Trial 56 pruned.
# [I 2026-06-09 06:44:43,969] Trial 57 pruned.
# [I 2026-06-09 06:44:56,700] Trial 58 pruned.
# [I 2026-06-09 06:45:53,178] Trial 59 pruned.
# [I 2026-06-09 06:46:11,928] Trial 60 finished with value: 4.545802766482602 and parameters: {'n_estimators': 1906, 'learning_rate': 0.017709149304960266, 'max_depth': 1, 'min_child_weight': 1.2263513039027374, 'gamma': 0.6420627573962686, 'subsample': 0.8521347566815025, 'colsample_bytree': 0.8738204345445898, 'reg_alpha': 2.291905931607827, 'reg_lambda': 0.0015502291882347925}. Best is trial 11 with value: 4.513393585526492.
# [I 2026-06-09 06:46:32,732] Trial 61 finished with value: 4.502838145996728 and parameters: {'n_estimators': 1594, 'learning_rate': 0.02776033225402661, 'max_depth': 1, 'min_child_weight': 0.5911869120292876, 'gamma': 1.2276823006214532, 'subsample': 0.8500247835593598, 'colsample_bytree': 0.9149381576126699, 'reg_alpha': 0.0019524099119498295, 'reg_lambda': 0.00517770716154431}. Best is trial 61 with value: 4.502838145996728.
# [I 2026-06-09 06:46:53,816] Trial 62 finished with value: 4.518530177757429 and parameters: {'n_estimators': 1639, 'learning_rate': 0.026438950684850894, 'max_depth': 1, 'min_child_weight': 0.461461623784988, 'gamma': 1.6306706649413802, 'subsample': 0.811371374662447, 'colsample_bytree': 0.899506507482586, 'reg_alpha': 0.0012730226726430337, 'reg_lambda': 0.007973993146852027}. Best is trial 61 with value: 4.502838145996728.
# [I 2026-06-09 06:47:04,055] Trial 63 pruned.
# [I 2026-06-09 06:47:14,137] Trial 64 pruned.
# [I 2026-06-09 06:47:18,800] Trial 65 pruned.
# [I 2026-06-09 06:47:24,775] Trial 66 pruned.
# [I 2026-06-09 06:47:30,377] Trial 67 pruned.
# [I 2026-06-09 06:47:46,113] Trial 68 finished with value: 4.50281478623796 and parameters: {'n_estimators': 1557, 'learning_rate': 0.029163230408646473, 'max_depth': 1, 'min_child_weight': 0.8052989982573665, 'gamma': 2.2656626029141087, 'subsample': 0.9012377646379646, 'colsample_bytree': 0.8948704110249329, 'reg_alpha': 0.0021111679767499975, 'reg_lambda': 0.004352004153805363}. Best is trial 68 with value: 4.50281478623796.
# [I 2026-06-09 06:47:51,089] Trial 69 pruned.
# [I 2026-06-09 06:48:02,144] Trial 70 finished with value: 4.551060599326529 and parameters: {'n_estimators': 1658, 'learning_rate': 0.031138105356712006, 'max_depth': 1, 'min_child_weight': 0.8439851426683899, 'gamma': 2.3216516181966895, 'subsample': 0.8689935446158017, 'colsample_bytree': 0.8909425254296217, 'reg_alpha': 0.0003839692329771777, 'reg_lambda': 0.005109486735372563}. Best is trial 68 with value: 4.50281478623796.
# [I 2026-06-09 06:48:10,572] Trial 71 pruned.
# [I 2026-06-09 06:48:20,021] Trial 72 pruned.
# [I 2026-06-09 06:48:29,525] Trial 73 finished with value: 4.503403053962245 and parameters: {'n_estimators': 1615, 'learning_rate': 0.052576006255931396, 'max_depth': 1, 'min_child_weight': 1.0476762230089234, 'gamma': 1.1593763442851461, 'subsample': 0.8535530725646696, 'colsample_bytree': 0.9546904055956686, 'reg_alpha': 0.015297544944134897, 'reg_lambda': 0.00889160373775181}. Best is trial 68 with value: 4.50281478623796.
# [I 2026-06-09 06:48:39,252] Trial 74 finished with value: 4.532320358985405 and parameters: {'n_estimators': 1579, 'learning_rate': 0.04036309008285569, 'max_depth': 1, 'min_child_weight': 1.025650163022425, 'gamma': 2.4399741970425346, 'subsample': 0.8541358581355508, 'colsample_bytree': 0.9553552166085202, 'reg_alpha': 0.0013751771307171446, 'reg_lambda': 0.009400510385227089}. Best is trial 68 with value: 4.50281478623796.
# [I 2026-06-09 06:48:43,805] Trial 75 pruned.
# [I 2026-06-09 06:48:57,253] Trial 76 finished with value: 4.504029522107489 and parameters: {'n_estimators': 1370, 'learning_rate': 0.043198893130488004, 'max_depth': 1, 'min_child_weight': 0.7843156528943109, 'gamma': 2.096843728138891, 'subsample': 0.8797806114884016, 'colsample_bytree': 0.9331237344613402, 'reg_alpha': 0.016045993023183037, 'reg_lambda': 0.027279774500459777}. Best is trial 68 with value: 4.50281478623796.
# [I 2026-06-09 06:49:01,096] Trial 77 pruned.
# [I 2026-06-09 06:49:08,549] Trial 78 pruned.
# [I 2026-06-09 06:49:14,062] Trial 79 pruned.
# [I 2026-06-09 06:49:17,577] Trial 80 pruned.
# [I 2026-06-09 06:49:26,694] Trial 81 finished with value: 4.541723854248224 and parameters: {'n_estimators': 1697, 'learning_rate': 0.05941558479345998, 'max_depth': 1, 'min_child_weight': 0.439809921867678, 'gamma': 1.2979502997559536, 'subsample': 0.8629397737473204, 'colsample_bytree': 0.9477198114842837, 'reg_alpha': 8.45933063172784, 'reg_lambda': 0.019255686218953585}. Best is trial 68 with value: 4.50281478623796.
# [I 2026-06-09 06:49:36,990] Trial 82 finished with value: 4.539813700133664 and parameters: {'n_estimators': 1815, 'learning_rate': 0.03933432074883284, 'max_depth': 1, 'min_child_weight': 0.8026165163042353, 'gamma': 2.1886942935072553, 'subsample': 0.8510624699999694, 'colsample_bytree': 0.9195620680920833, 'reg_alpha': 0.009215205759678168, 'reg_lambda': 0.050094123148104464}. Best is trial 68 with value: 4.50281478623796.
# [I 2026-06-09 06:49:50,089] Trial 83 finished with value: 4.537376564766287 and parameters: {'n_estimators': 1536, 'learning_rate': 0.03228026271448437, 'max_depth': 1, 'min_child_weight': 1.1283795623070199, 'gamma': 0.9841038986018116, 'subsample': 0.8343175916700618, 'colsample_bytree': 0.9863864471695944, 'reg_alpha': 0.005455002129836855, 'reg_lambda': 0.00788026676702455}. Best is trial 68 with value: 4.50281478623796.
# [I 2026-06-09 06:49:55,905] Trial 84 pruned.
# [I 2026-06-09 06:50:14,591] Trial 85 finished with value: 4.542049708017092 and parameters: {'n_estimators': 1300, 'learning_rate': 0.016543771837571646, 'max_depth': 1, 'min_child_weight': 0.5289045157071046, 'gamma': 0.8119929576511908, 'subsample': 0.8017686221518331, 'colsample_bytree': 0.8519827833140092, 'reg_alpha': 0.01251361217165867, 'reg_lambda': 0.013746764701975568}. Best is trial 68 with value: 4.50281478623796.
# [I 2026-06-09 06:50:25,531] Trial 86 pruned.
# [I 2026-06-09 06:50:30,922] Trial 87 pruned.
# [I 2026-06-09 06:50:35,232] Trial 88 pruned.
# [I 2026-06-09 06:50:52,410] Trial 89 finished with value: 4.523934676956778 and parameters: {'n_estimators': 1676, 'learning_rate': 0.022419137018733683, 'max_depth': 1, 'min_child_weight': 0.3970363682155377, 'gamma': 1.8316643217614812, 'subsample': 0.92645409171678, 'colsample_bytree': 0.9277490782018581, 'reg_alpha': 0.09868753171493964, 'reg_lambda': 0.0032879536185223385}. Best is trial 68 with value: 4.50281478623796.
# [I 2026-06-09 06:50:59,557] Trial 90 pruned.
# [I 2026-06-09 06:51:06,648] Trial 91 pruned.
# [I 2026-06-09 06:51:17,161] Trial 92 pruned.
# [I 2026-06-09 06:51:39,251] Trial 93 finished with value: 4.531241923578598 and parameters: {'n_estimators': 1639, 'learning_rate': 0.018475363476390325, 'max_depth': 1, 'min_child_weight': 0.48563198633349464, 'gamma': 2.2049730715378884, 'subsample': 0.9440279161717812, 'colsample_bytree': 0.9107106250037595, 'reg_alpha': 0.005031471989975863, 'reg_lambda': 0.0020730376793338104}. Best is trial 68 with value: 4.50281478623796.
# [I 2026-06-09 06:51:49,028] Trial 94 pruned.
# [I 2026-06-09 06:52:02,647] Trial 95 pruned.
# [I 2026-06-09 06:52:07,912] Trial 96 pruned.
# [I 2026-06-09 06:52:20,092] Trial 97 pruned.
# [I 2026-06-09 06:52:23,608] Trial 98 pruned.
# [I 2026-06-09 06:52:29,383] Trial 99 pruned.
# [I 2026-06-09 06:52:29,386] A new study created in memory with name: no-name-7cfc1669-9a44-4946-b42e-75a84479de38
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 06:52:54,029] Trial 0 finished with value: 4.958012027168964 and parameters: {'n_estimators': 301, 'learning_rate': 0.03250177171527344, 'num_leaves': 37, 'max_depth': 4, 'min_child_samples': 52, 'min_split_gain': 1.7182749818971954, 'bagging_fraction': 0.8330451065490129, 'bagging_freq': 4, 'feature_fraction': 0.5145069122121801, 'lambda_l1': 0.04015454105555427, 'lambda_l2': 0.07175601133819473}. Best is trial 0 with value: 4.958012027168964.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 06:55:33,146] Trial 1 finished with value: 4.980949541337283 and parameters: {'n_estimators': 1620, 'learning_rate': 0.008116618171663207, 'num_leaves': 18, 'max_depth': 9, 'min_child_samples': 37, 'min_split_gain': 0.8099788960945193, 'bagging_fraction': 0.6580482355091044, 'bagging_freq': 1, 'feature_fraction': 0.9216123471148523, 'lambda_l1': 0.43697071238567825, 'lambda_l2': 36.7185332724254}. Best is trial 0 with value: 4.958012027168964.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 06:55:44,877] Trial 2 finished with value: 4.689181389257368 and parameters: {'n_estimators': 820, 'learning_rate': 0.1255359023925396, 'num_leaves': 116, 'max_depth': 8, 'min_child_samples': 17, 'min_split_gain': 1.7941971599630686, 'bagging_fraction': 0.6490017503443813, 'bagging_freq': 2, 'feature_fraction': 0.5025647745322285, 'lambda_l1': 0.0007741455782248723, 'lambda_l2': 0.1717169091593679}. Best is trial 2 with value: 4.689181389257368.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 06:55:59,383] Trial 3 finished with value: 5.1956143349075585 and parameters: {'n_estimators': 1302, 'learning_rate': 0.13774020868800516, 'num_leaves': 233, 'max_depth': 10, 'min_child_samples': 81, 'min_split_gain': 0.2080378997095258, 'bagging_fraction': 0.5904572976289505, 'bagging_freq': 7, 'feature_fraction': 0.7059764916931793, 'lambda_l1': 0.6097531961875766, 'lambda_l2': 1.4405915859050216}. Best is trial 2 with value: 4.689181389257368.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 06:56:45,948] Trial 4 finished with value: 5.020695352544304 and parameters: {'n_estimators': 1287, 'learning_rate': 0.008816320113501107, 'num_leaves': 230, 'max_depth': 3, 'min_child_samples': 64, 'min_split_gain': 1.987144984788207, 'bagging_fraction': 0.8678635407535604, 'bagging_freq': 4, 'feature_fraction': 0.7803315847218675, 'lambda_l1': 5.026890229380336e-05, 'lambda_l2': 2.6067223030440956}. Best is trial 2 with value: 4.689181389257368.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 06:56:55,243] Trial 5 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 06:57:03,488] Trial 6 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 06:57:14,460] Trial 7 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 06:57:16,705] Trial 8 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 06:57:35,002] Trial 9 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:01:44,518] Trial 10 finished with value: 4.678679920320817 and parameters: {'n_estimators': 1941, 'learning_rate': 0.0030655026296684197, 'num_leaves': 136, 'max_depth': 6, 'min_child_samples': 8, 'min_split_gain': 1.0711301272286968, 'bagging_fraction': 0.9966096264578707, 'bagging_freq': 1, 'feature_fraction': 0.553404595932398, 'lambda_l1': 0.0004360836620266861, 'lambda_l2': 0.00155495757555242}. Best is trial 10 with value: 4.678679920320817.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:04:55,702] Trial 11 finished with value: 4.733571707053997 and parameters: {'n_estimators': 1983, 'learning_rate': 0.003620712782212966, 'num_leaves': 129, 'max_depth': 6, 'min_child_samples': 6, 'min_split_gain': 1.0433356354222538, 'bagging_fraction': 0.9892744331528707, 'bagging_freq': 1, 'feature_fraction': 0.524354668722373, 'lambda_l1': 0.0003543118727538596, 'lambda_l2': 0.0010849289224727087}. Best is trial 10 with value: 4.678679920320817.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:05:09,241] Trial 12 finished with value: 4.645254219035655 and parameters: {'n_estimators': 728, 'learning_rate': 0.07157452246232128, 'num_leaves': 125, 'max_depth': 6, 'min_child_samples': 9, 'min_split_gain': 1.104998772133611, 'bagging_fraction': 0.7426368712340637, 'bagging_freq': 2, 'feature_fraction': 0.5807490547778765, 'lambda_l1': 0.0006682989933815717, 'lambda_l2': 0.0020165791368581053}. Best is trial 12 with value: 4.645254219035655.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:05:20,903] Trial 13 finished with value: 4.734632788561714 and parameters: {'n_estimators': 1992, 'learning_rate': 0.057041320254661146, 'num_leaves': 171, 'max_depth': 5, 'min_child_samples': 26, 'min_split_gain': 1.1021963961274381, 'bagging_fraction': 0.747067677640309, 'bagging_freq': 2, 'feature_fraction': 0.6054202139841016, 'lambda_l1': 1.5009257316881234e-05, 'lambda_l2': 0.0014810440946671584}. Best is trial 12 with value: 4.645254219035655.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:05:54,181] Trial 14 finished with value: 4.667571267187823 and parameters: {'n_estimators': 1640, 'learning_rate': 0.01754537145991472, 'num_leaves': 169, 'max_depth': 6, 'min_child_samples': 5, 'min_split_gain': 1.1526647845049771, 'bagging_fraction': 0.9864940239073102, 'bagging_freq': 2, 'feature_fraction': 0.5875870065278159, 'lambda_l1': 8.412981494010534, 'lambda_l2': 0.0064685770471145775}. Best is trial 12 with value: 4.645254219035655.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:06:16,080] Trial 15 finished with value: 4.819329979835947 and parameters: {'n_estimators': 556, 'learning_rate': 0.017303171791266378, 'num_leaves': 183, 'max_depth': 5, 'min_child_samples': 31, 'min_split_gain': 0.8156771408558756, 'bagging_fraction': 0.7669195674527245, 'bagging_freq': 3, 'feature_fraction': 0.7322533251465164, 'lambda_l1': 5.7457202540686865, 'lambda_l2': 0.010630305570258673}. Best is trial 12 with value: 4.645254219035655.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:06:25,506] Trial 16 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:06:36,714] Trial 17 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:06:41,774] Trial 18 finished with value: 4.724235580727912 and parameters: {'n_estimators': 731, 'learning_rate': 0.08122279530596171, 'num_leaves': 205, 'max_depth': 6, 'min_child_samples': 22, 'min_split_gain': 1.275229996212337, 'bagging_fraction': 0.7053803827481933, 'bagging_freq': 3, 'feature_fraction': 0.9991355829538757, 'lambda_l1': 0.15786736357473816, 'lambda_l2': 0.025634816711826214}. Best is trial 12 with value: 4.645254219035655.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:07:08,259] Trial 19 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:07:48,009] Trial 20 finished with value: 4.59687310227139 and parameters: {'n_estimators': 1773, 'learning_rate': 0.005606174212364054, 'num_leaves': 89, 'max_depth': 4, 'min_child_samples': 17, 'min_split_gain': 0.5925372616667715, 'bagging_fraction': 0.8186867915764636, 'bagging_freq': 3, 'feature_fraction': 0.7845996783353781, 'lambda_l1': 5.605712711328615e-06, 'lambda_l2': 0.02607676994497219}. Best is trial 20 with value: 4.59687310227139.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:08:31,323] Trial 21 finished with value: 4.633736715906435 and parameters: {'n_estimators': 1781, 'learning_rate': 0.005521525595177376, 'num_leaves': 90, 'max_depth': 4, 'min_child_samples': 21, 'min_split_gain': 0.5828560142894547, 'bagging_fraction': 0.8048588864402283, 'bagging_freq': 3, 'feature_fraction': 0.7884740096960836, 'lambda_l1': 2.536619829612093e-05, 'lambda_l2': 0.024997342571976826}. Best is trial 20 with value: 4.59687310227139.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:08:50,284] Trial 22 finished with value: 4.598517167008221 and parameters: {'n_estimators': 1803, 'learning_rate': 0.005544703247357174, 'num_leaves': 92, 'max_depth': 3, 'min_child_samples': 19, 'min_split_gain': 0.5523509406626144, 'bagging_fraction': 0.7936806277862674, 'bagging_freq': 3, 'feature_fraction': 0.8033497605070359, 'lambda_l1': 2.0452208636969348e-05, 'lambda_l2': 0.03686750066032825}. Best is trial 20 with value: 4.59687310227139.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:09:00,812] Trial 23 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:09:21,914] Trial 24 finished with value: 4.618453282396766 and parameters: {'n_estimators': 1781, 'learning_rate': 0.00613596950363452, 'num_leaves': 59, 'max_depth': 3, 'min_child_samples': 21, 'min_split_gain': 0.670620887758423, 'bagging_fraction': 0.8027067762712342, 'bagging_freq': 3, 'feature_fraction': 0.801487567424662, 'lambda_l1': 6.30791806994223e-07, 'lambda_l2': 0.2680007055426602}. Best is trial 20 with value: 4.59687310227139.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:09:33,931] Trial 25 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:09:53,821] Trial 26 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:10:00,806] Trial 27 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:10:31,698] Trial 28 finished with value: 4.604381820937872 and parameters: {'n_estimators': 1849, 'learning_rate': 0.0039027514633516473, 'num_leaves': 106, 'max_depth': 3, 'min_child_samples': 17, 'min_split_gain': 0.907669021671594, 'bagging_fraction': 0.8362151711126345, 'bagging_freq': 4, 'feature_fraction': 0.8705197256230293, 'lambda_l1': 1.983309498767389e-07, 'lambda_l2': 2.6542428470902535}. Best is trial 20 with value: 4.59687310227139.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:11:04,883] Trial 29 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:11:47,428] Trial 30 finished with value: 4.567656586326414 and parameters: {'n_estimators': 1876, 'learning_rate': 0.0030191183042405523, 'num_leaves': 149, 'max_depth': 3, 'min_child_samples': 15, 'min_split_gain': 0.9233868300558006, 'bagging_fraction': 0.8940489117946264, 'bagging_freq': 4, 'feature_fraction': 0.9596389192883252, 'lambda_l1': 8.935200991674397e-05, 'lambda_l2': 0.07965959377033333}. Best is trial 30 with value: 4.567656586326414.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:12:28,920] Trial 31 finished with value: 4.567543509832216 and parameters: {'n_estimators': 1865, 'learning_rate': 0.0030251866747167877, 'num_leaves': 143, 'max_depth': 3, 'min_child_samples': 16, 'min_split_gain': 0.8825771522326802, 'bagging_fraction': 0.8959534662920647, 'bagging_freq': 4, 'feature_fraction': 0.966474068978719, 'lambda_l1': 0.00012436930540098642, 'lambda_l2': 0.07201731324964022}. Best is trial 31 with value: 4.567543509832216.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:13:05,620] Trial 32 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:13:27,177] Trial 33 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:13:57,345] Trial 34 finished with value: 4.569216013225876 and parameters: {'n_estimators': 1689, 'learning_rate': 0.007620039204951702, 'num_leaves': 9, 'max_depth': 4, 'min_child_samples': 15, 'min_split_gain': 0.2670373230690652, 'bagging_fraction': 0.9030478559050731, 'bagging_freq': 3, 'feature_fraction': 0.9274922096803824, 'lambda_l1': 4.807158186502344e-06, 'lambda_l2': 0.015238033393481966}. Best is trial 31 with value: 4.567543509832216.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:14:41,026] Trial 35 finished with value: 4.564595041112435 and parameters: {'n_estimators': 1548, 'learning_rate': 0.00748648611602321, 'num_leaves': 9, 'max_depth': 4, 'min_child_samples': 15, 'min_split_gain': 0.12958928458705898, 'bagging_fraction': 0.89833620907128, 'bagging_freq': 5, 'feature_fraction': 0.9152711887378754, 'lambda_l1': 4.748774106939016e-06, 'lambda_l2': 0.014113335857933314}. Best is trial 35 with value: 4.564595041112435.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:15:16,195] Trial 36 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:15:42,261] Trial 37 finished with value: 4.567351118108048 and parameters: {'n_estimators': 1655, 'learning_rate': 0.010824735968329374, 'num_leaves': 7, 'max_depth': 4, 'min_child_samples': 15, 'min_split_gain': 0.24249891074099883, 'bagging_fraction': 0.8884299568353664, 'bagging_freq': 5, 'feature_fraction': 0.9675297674430003, 'lambda_l1': 0.0018099860967073023, 'lambda_l2': 0.01372351980592556}. Best is trial 35 with value: 4.564595041112435.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:15:55,015] Trial 38 finished with value: 4.576035825360979 and parameters: {'n_estimators': 1530, 'learning_rate': 0.024692003416737156, 'num_leaves': 11, 'max_depth': 3, 'min_child_samples': 11, 'min_split_gain': 0.14221607717904727, 'bagging_fraction': 0.8858610016302103, 'bagging_freq': 5, 'feature_fraction': 0.9730480148521886, 'lambda_l1': 0.0011252252073178748, 'lambda_l2': 0.003205504690061838}. Best is trial 35 with value: 4.564595041112435.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:16:36,843] Trial 39 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:17:13,841] Trial 40 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:18:25,744] Trial 41 finished with value: 4.580999220546676 and parameters: {'n_estimators': 1677, 'learning_rate': 0.0079374550082316, 'num_leaves': 13, 'max_depth': 4, 'min_child_samples': 16, 'min_split_gain': 0.2619446473060701, 'bagging_fraction': 0.8982086644045442, 'bagging_freq': 4, 'feature_fraction': 0.9242314127697531, 'lambda_l1': 6.006597414334175e-05, 'lambda_l2': 0.016419971081995614}. Best is trial 35 with value: 4.564595041112435.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:19:03,842] Trial 42 finished with value: 4.570863553736914 and parameters: {'n_estimators': 1892, 'learning_rate': 0.007267543131625591, 'num_leaves': 9, 'max_depth': 4, 'min_child_samples': 16, 'min_split_gain': 0.3384254026426698, 'bagging_fraction': 0.9112623425878651, 'bagging_freq': 4, 'feature_fraction': 0.9614964916741301, 'lambda_l1': 4.95205649765905e-06, 'lambda_l2': 0.015093061198858079}. Best is trial 35 with value: 4.564595041112435.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
# ...
#   warnings.warn(
# [I 2026-06-09 08:12:22,947] Trial 88 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 08:12:51,580] Trial 89 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 08:13:11,414] Trial 90 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 08:13:37,651] Trial 91 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 08:14:03,383] Trial 92 finished with value: 4.5516561956627255 and parameters: {'n_estimators': 1932, 'learning_rate': 0.00709514538709699, 'num_leaves': 163, 'max_depth': 2, 'min_child_samples': 9, 'min_split_gain': 1.2215684790404564, 'bagging_fraction': 0.8926630595301198, 'bagging_freq': 4, 'feature_fraction': 0.9156050617125562, 'lambda_l1': 9.34843838976227e-05, 'lambda_l2': 0.0665242490731973}. Best is trial 70 with value: 4.538748631839945.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 08:14:30,334] Trial 93 finished with value: 4.55611662650286 and parameters: {'n_estimators': 1951, 'learning_rate': 0.0074206006537073325, 'num_leaves': 166, 'max_depth': 2, 'min_child_samples': 9, 'min_split_gain': 1.271479312708443, 'bagging_fraction': 0.9223956748260229, 'bagging_freq': 4, 'feature_fraction': 0.9160612965429688, 'lambda_l1': 3.641446954705578e-05, 'lambda_l2': 0.06274761110266783}. Best is trial 70 with value: 4.538748631839945.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [W 2026-06-09 08:15:13,768] Trial 94 failed with parameters: {'n_estimators': 1955, 'learning_rate': 0.007110929887751895, 'num_leaves': 186, 'max_depth': 2, 'min_child_samples': 8, 'min_split_gain': 1.242537562208175, 'bagging_fraction': 0.9536047793597464, 'bagging_freq': 1, 'feature_fraction': 0.9064273634029464, 'lambda_l1': 9.582213536543676e-06, 'lambda_l2': 0.05821168380642881} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "d:\dev\weather-research\.venv\Lib\site-packages\optuna\study\_optimize.py", line 206, in _run_trial
#     value_or_values = func(trial)
#   File "D:\dev\weather-research\src\calibration\station_stacking.py", line 800, in objective
#     year = pd.to_numeric(frame.get("year"), errors="coerce")
#                                               ^^^^^^^^^^^^^^
#     ...<8 lines>...
#             for fold in folds:
#             ^^^^^^^^^
#   File "D:\dev\weather-research\src\calibration\station_stacking.py", line 1909, in _fit_predict_base_model
#         train: pd.DataFrame,
#     ...<7 lines>...
#
#   File "D:\dev\weather-research\src\calibration\station_stacking.py", line 1951, in _fit_base_estimator
#         x_train: Any,
#                 ^^^^^
#     ...<5 lines>...
#         if early_stopping_rounds is None:
#         ^^^^^^^^^
#   File "d:\dev\weather-research\.venv\Lib\site-packages\lightgbm\sklearn.py", line 1398, in fit
#     super().fit(
#     ~~~~~~~~~~~^
#         X,
#         ^^
#     ...<11 lines>...
#         init_model=init_model,
#         ^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "d:\dev\weather-research\.venv\Lib\site-packages\lightgbm\sklearn.py", line 1049, in fit
#     self._Booster = train(
#                     ~~~~~^
#         params=params,
#         ^^^^^^^^^^^^^^
#     ...<6 lines>...
#         callbacks=callbacks,
#         ^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "d:\dev\weather-research\.venv\Lib\site-packages\lightgbm\engine.py", line 322, in train
#     booster.update(fobj=fobj)
#     ~~~~~~~~~~~~~~^^^^^^^^^^^
#   File "d:\dev\weather-research\.venv\Lib\site-packages\lightgbm\basic.py", line 4155, in update
#     _LIB.LGBM_BoosterUpdateOneIter(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         self._handle,
#         ^^^^^^^^^^^^^
#         ctypes.byref(is_finished),
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
# KeyboardInterrupt
# [W 2026-06-09 08:15:13,788] Trial 94 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 18
#      14     stack_optuna_trials=STACK_OPTUNA_TRIALS,
#      15     optuna_verbose=OPTUNA_VERBOSE,
#      16     output_dir=PROJECT_ROOT / "data" / "calibration" / "station_stacking_v4",
#      17 )
# ---> 18 result = run_station_year_split_experiment(config)
#      19 result.scoreboard
#
# File D:\dev\weather-research\src\calibration\station_stacking.py:654, in run_station_year_split_experiment(config)
#     643     feature_columns_frame.to_csv(paths["feature_columns"], index=False)
#     644     return StationStackingResult(
#     645         station_id=station,
#     646         features=features,
#    (...)    650         output_paths=paths,
#     651     )
# --> 654 def run_station_year_split_experiment(config: StationStackingConfig) -> YearSplitExperimentResult:
#     655     features = build_station_wide_dataset(
#     656         config.resolved_project_root(),
#     657         station_id=config.station_id,
#     658         timing_mode=config.timing_mode,
#     659         providers=config.providers,
#     660     )
#     661     modeling_frame, categorical, numeric = _modeling_frame(features, config)
#
# File D:\dev\weather-research\src\calibration\station_stacking.py:864, in tune_year_split_base_models(frame, config, categorical, numeric, folds)
#     850 rmse = float(metrics["rmse_f"])
#     851 fold_scores.append((fold, float(metrics[metric_col])))
#     852 rows.append(
#     853     {
#     854         "method": method,
#     855         "trial_number": trial.number,
#     856         "param_key": param_key,
#     857         "fold": fold.name,
#     858         "fold_weight": _year_split_fold_weight(fold),
#     859         "mae_f": mae,
#     860         "rmse_f": rmse,
#     861         "count": int(metrics["count"]),
#     862         "fit_numeric_features": fit_metadata["numeric_features"],
#     863         "fit_categorical_features": fit_metadata["categorical_features"],
# --> 864         "best_iteration": fit_metadata["best_iteration"],
#     865         "status": "ok",
#     866         "error": "",
#     867         **{f"param_{key}": value for key, value in params.items()},
#     868     }
#     869 )
#     870 current_score = _weighted_fold_score(fold_scores)
#     871 if hasattr(trial, "report"):
#
# File d:\dev\weather-research\.venv\Lib\site-packages\optuna\study\study.py:516, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     414 def optimize(
#     415     self,
#     416     func: ObjectiveFuncType,
#    (...)    423     show_progress_bar: bool = False,
#     424 ) -> None:
#     425     """Optimize an objective function.
#     426
#     427     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)    514             If nested invocation of this method occurs.
#     515     """
# --> 516     _optimize(
#     517         study=self,
#     518         func=func,
#     519         n_trials=n_trials,
#     520         timeout=timeout,
#     521         n_jobs=n_jobs,
#     522         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     523         callbacks=callbacks,
#     524         gc_after_trial=gc_after_trial,
#     525         show_progress_bar=show_progress_bar,
#     526     )
#
# File d:\dev\weather-research\.venv\Lib\site-packages\optuna\study\_optimize.py:68, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      66 try:
#      67     if n_jobs == 1:
# ---> 68         _optimize_sequential(
#      69             study,
#      70             func,
#      71             n_trials,
#      72             timeout,
#      73             catch,
#      74             callbacks,
#      75             gc_after_trial,
#      76             reseed_sampler_rng=False,
#      77             time_start=None,
#      78             progress_bar=progress_bar,
#      79         )
#      80     else:
#      81         if n_jobs == -1:
#
# File d:\dev\weather-research\.venv\Lib\site-packages\optuna\study\_optimize.py:165, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     162         break
#     164 try:
# --> 165     frozen_trial_id = _run_trial(study, func, catch)
#     166 finally:
#     167     # The following line mitigates memory problems that can be occurred in some
#     168     # environments (e.g., services that use computing containers such as GitHub Actions).
#     169     # Please refer to the following PR for further details:
#     170     # https://github.com/optuna/optuna/pull/325.
#     171     if gc_after_trial:
#
# File d:\dev\weather-research\.venv\Lib\site-packages\optuna\study\_optimize.py:263, in _run_trial(study, func, catch)
#     256         assert False, "Should not reach."
#     258 if (
#     259     updated_state == TrialState.FAIL
#     260     and func_err is not None
#     261     and not isinstance(func_err, catch)
#     262 ):
# --> 263     raise func_err
#     264 return trial._trial_id
#
# File d:\dev\weather-research\.venv\Lib\site-packages\optuna\study\_optimize.py:206, in _run_trial(study, func, catch)
#     204 with get_heartbeat_thread(trial._trial_id, study._storage):
#     205     try:
# --> 206         value_or_values = func(trial)
#     207     except exceptions.TrialPruned as e:
#     208         # TODO(mamu): Handle multi-objective cases.
#     209         state = TrialState.PRUNED
#
# File D:\dev\weather-research\src\calibration\station_stacking.py:800, in objective(trial)
#     798     return pd.DataFrame(), _empty_year_split_predictions(), pd.DataFrame()
#     799 rows: list[dict[str, Any]] = []
# --> 800 year = pd.to_numeric(frame.get("year"), errors="coerce")
#     801 metric_col = config.effective_optuna_metric
#     802 for method in BASE_MODEL_METHODS:
#
# File D:\dev\weather-research\src\calibration\station_stacking.py:1909, in _fit_predict_base_model(config, categorical, numeric, method, params, train, valid, early_stopping)
#    1885         return CatBoostRegressor(
#    1886             iterations=cat_iterations,
#    1887             learning_rate=float(params.get("learning_rate", 0.035)),
#    (...)   1898             allow_writing_files=False,
#    1899         )
#    1900     raise ValueError(f"Unknown base model method: {method}")
#    1903 def _fit_predict_base_model(
#    1904     config: StationStackingConfig,
#    1905     categorical: list[str],
#    1906     numeric: list[str],
#    1907     method: str,
#    1908     params: dict[str, Any],
# -> 1909     train: pd.DataFrame,
#    1910     valid: pd.DataFrame,
#    1911     early_stopping: bool,
#    1912 ) -> tuple[np.ndarray, dict[str, Any]]:
#    1913     fit_categorical, fit_numeric = _fit_feature_columns(train, categorical, numeric)
#    1914     feature_names = [*fit_categorical, *fit_numeric]
#
# File D:\dev\weather-research\src\calibration\station_stacking.py:1951, in _fit_base_estimator(estimator, method, x_train, y_train, x_valid, y_valid, early_stopping_rounds)
#    1944     fit_numeric = [column for column in numeric if column in train and pd.to_numeric(train[column], errors="coerce").notna().any()]
#    1945     return fit_categorical, fit_numeric
#    1948 def _fit_base_estimator(
#    1949     estimator: Any,
#    1950     method: str,
# -> 1951     x_train: Any,
#    1952     y_train: pd.Series,
#    1953     x_valid: Any,
#    1954     y_valid: pd.Series,
#    1955     early_stopping_rounds: int | None,
#    1956 ) -> None:
#    1957     if early_stopping_rounds is None:
#    1958         estimator.fit(x_train, y_train)
#
# File d:\dev\weather-research\.venv\Lib\site-packages\lightgbm\sklearn.py:1398, in LGBMRegressor.fit(self, X, y, sample_weight, init_score, eval_set, eval_names, eval_sample_weight, eval_init_score, eval_metric, feature_name, categorical_feature, callbacks, init_model)
#    1381 def fit(  # type: ignore[override]
#    1382     self,
#    1383     X: _LGBM_ScikitMatrixLike,
#    (...)   1395     init_model: Optional[Union[str, Path, Booster, LGBMModel]] = None,
#    1396 ) -> "LGBMRegressor":
#    1397     """Docstring is inherited from the LGBMModel."""
# -> 1398     super().fit(
#    1399         X,
#    1400         y,
#    1401         sample_weight=sample_weight,
#    1402         init_score=init_score,
#    1403         eval_set=eval_set,
#    1404         eval_names=eval_names,
#    1405         eval_sample_weight=eval_sample_weight,
#    1406         eval_init_score=eval_init_score,
#    1407         eval_metric=eval_metric,
#    1408         feature_name=feature_name,
#    1409         categorical_feature=categorical_feature,
#    1410         callbacks=callbacks,
#    1411         init_model=init_model,
#    1412     )
#    1413     return self
#
# File d:\dev\weather-research\.venv\Lib\site-packages\lightgbm\sklearn.py:1049, in LGBMModel.fit(self, X, y, sample_weight, init_score, group, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_group, eval_metric, feature_name, categorical_feature, callbacks, init_model)
#    1046 evals_result: _EvalResultDict = {}
#    1047 callbacks.append(record_evaluation(evals_result))
# -> 1049 self._Booster = train(
#    1050     params=params,
#    1051     train_set=train_set,
#    1052     num_boost_round=self.n_estimators,
#    1053     valid_sets=valid_sets,
#    1054     valid_names=eval_names,
#    1055     feval=eval_metrics_callable,  # type: ignore[arg-type]
#    1056     init_model=init_model,
#    1057     callbacks=callbacks,
#    1058 )
#    1060 # This populates the property self.n_features_, the number of features in the fitted model,
#    1061 # and so should only be set after fitting.
#    1062 #
#    1063 # The related property self._n_features_in, which populates self.n_features_in_,
#    1064 # is set BEFORE fitting.
#    1065 self._n_features = self._Booster.num_feature()
#
# File d:\dev\weather-research\.venv\Lib\site-packages\lightgbm\engine.py:322, in train(params, train_set, num_boost_round, valid_sets, valid_names, feval, init_model, keep_training_booster, callbacks)
#     310 for cb in callbacks_before_iter:
#     311     cb(
#     312         callback.CallbackEnv(
#     313             model=booster,
#    (...)    319         )
#     320     )
# --> 322 booster.update(fobj=fobj)
#     324 evaluation_result_list: List[_LGBM_BoosterEvalMethodResultType] = []
#     325 # check evaluation result.
#
# File d:\dev\weather-research\.venv\Lib\site-packages\lightgbm\basic.py:4155, in Booster.update(self, train_set, fobj)
#    4152 if self.__set_objective_to_none:
#    4153     raise LightGBMError("Cannot update due to null objective function.")
#    4154 _safe_call(
# -> 4155     _LIB.LGBM_BoosterUpdateOneIter(
#    4156         self._handle,
#    4157         ctypes.byref(is_finished),
#    4158     )
#    4159 )
#    4160 self.__is_predicted_cur_iter = [False for _ in range(self.__num_dataset)]
#    4161 return is_finished.value == 1
#
# KeyboardInterrupt:

# %% [markdown]
# ## Rounded Within 1F Accuracy

# %%
preds = pd.concat(
    [
        result.validation_predictions.assign(period="validation_2024_2025"),
        result.test_predictions.assign(period="test_2026"),
    ],
    ignore_index=True,
)

predicted_high = pd.to_numeric(preds["predicted_high_f"], errors="coerce")
preds["predicted_high_rounded_f"] = np.floor(predicted_high + 0.5)
preds["within_1f_after_round"] = (
    pd.to_numeric(preds["actual_high_f"], errors="coerce") - preds["predicted_high_rounded_f"]
).abs().le(1)

within_1f_accuracy_by_period = (
    preds
    .dropna(subset=["actual_high_f", "predicted_high_rounded_f"])
    .groupby(["period", "method"], as_index=False)
    .agg(
        count=("within_1f_after_round", "size"),
        within_1f_count=("within_1f_after_round", "sum"),
        within_1f_accuracy_pct=("within_1f_after_round", lambda x: x.mean() * 100),
    )
    .sort_values(["period", "within_1f_accuracy_pct"], ascending=[True, False])
)

within_1f_accuracy_by_period

# %% [markdown]
# ## Precipitation Feature Coverage

# %%
precip_columns = [column for column in result.features.columns if "precip" in column.lower()]
coverage = (
    result.features[precip_columns]
    .notna()
    .mean()
    .mul(100)
    .sort_values(ascending=False)
    .rename("coverage_pct")
    .reset_index()
    .rename(columns={"index": "feature"})
)
coverage

# %% [markdown]
# ## Version Comparison

# %%
comparison_frames = []
for version, folder in [
    ("v1", PROJECT_ROOT / "data" / "calibration" / "station_stacking"),
    ("v2", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v2"),
    ("v3", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v3"),
    ("v4", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v4"),
]:
    path = folder / f"{STATION_ID}_year_split_scoreboard.csv"
    if path.exists():
        frame = pd.read_csv(path)
        frame["version"] = version
        comparison_frames.append(frame)

version_comparison = pd.concat(comparison_frames, ignore_index=True) if comparison_frames else pd.DataFrame()
if not version_comparison.empty:
    version_comparison = version_comparison.sort_values(["period", "mae_f", "version", "method"]).reset_index(drop=True)
version_comparison

# %% [markdown]
# ## 2026 Weather Brackets

# %%
result.bracket_metrics

# %%
import pandas as pd


def adjacent_brackets(bracket):
    if pd.isna(bracket):
        return []
    text = str(bracket).strip()
    if not text or "-" not in text:
        return []
    try:
        lower = int(text.split("-", 1)[0])
    except ValueError:
        return []
    return [
        f"{lower - 2}-{lower - 1}",
        f"{lower}-{lower + 1}",
        f"{lower + 2}-{lower + 3}",
    ]


bracket_3way = result.bracket_predictions.copy()

valid = bracket_3way["actual_bracket"].notna() & bracket_3way["predicted_bracket"].astype(str).str.strip().ne("")
bracket_3way = bracket_3way.loc[valid].copy()
bracket_3way["picked_brackets"] = bracket_3way["predicted_bracket"].map(adjacent_brackets)
bracket_3way["three_bracket_hit"] = bracket_3way.apply(
    lambda row: row["actual_bracket"] in row["picked_brackets"],
    axis=1,
)

three_bracket_accuracy = (
    bracket_3way
    .groupby("method", as_index=False)
    .agg(
        count=("three_bracket_hit", "size"),
        exact_bracket_accuracy_pct=("bracket_hit", lambda x: x.mean() * 100),
        three_bracket_accuracy_pct=("three_bracket_hit", lambda x: x.mean() * 100),
    )
    .sort_values("three_bracket_accuracy_pct", ascending=False)
)

three_bracket_accuracy

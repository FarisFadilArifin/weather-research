# %% [markdown]
# # Station Stacking v4 - KLGA
#
# Wide HRRR/GFS same-day 11am notebook for `KLGA`.
#
# This version keeps the v3 high-so-far features and adds SDK-backed precipitation features from HRRR/GFS forecast precipitation plus 11 AM METAR precipitation codes. Artifacts are written to `data/calibration/station_stacking_v4`.

# %%
from pathlib import Path
import sys
import warnings

warnings.filterwarnings("ignore", message="IProgress not found.*")
warnings.filterwarnings("ignore", message="Skipping features without any observed values.*")

PROJECT_ROOT = Path.cwd().resolve()
while not (PROJECT_ROOT / "src" / "calibration" / "station_stacking.py").exists():
    if PROJECT_ROOT.parent == PROJECT_ROOT:
        raise RuntimeError("Could not find project root containing src/calibration/station_stacking.py")
    PROJECT_ROOT = PROJECT_ROOT.parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

STATION_ID = "KLGA"
FAST_MODE = False
OPTUNA_TRIALS = 100
STACK_OPTUNA_TRIALS = 50
OPTUNA_VERBOSE = True
PROJECT_ROOT
# Out:
# WindowsPath('D:/dev/weather-research')

# %%
from src.calibration.station_stacking import (
    StationStackingConfig,
    missing_model_dependencies,
    run_station_year_split_experiment,
)

# %% [markdown]
# ## V4 Feature Engineering
#
# Adds v2/v3 temperature features plus forecast and observed precipitation signals. Forecast precipitation comes from provider-prefixed SDK summary columns such as `gfs_forecast_precip_total_mm`, with `gfs_precip_amount` as a fallback for older caches.

# %%
import numpy as np
import pandas as pd
import src.calibration.station_stacking as station_stacking_module

V4_PROVIDERS = ("gfs", "hrrr")
V4_FEATURE_COLUMNS = [
    "v2_recent_heat_anomaly_f",
    "v2_recent_heat_momentum_f",
    "v2_morning_warmup_to_consensus_f",
    "v2_consensus_minus_7d_actual_f",
    "v2_spread_per_warmup_f",
    "v2_humidity_warmup_interaction",
    "v3_high_so_far_above_current_f",
    "v3_remaining_warmup_from_high_so_far_f",
    "v3_high_so_far_minus_lag_1d_f",
    "v3_high_so_far_minus_7d_actual_f",
    "v3_remaining_warmup_per_spread_f",
    "v3_humidity_remaining_warmup_interaction",
    "v4_forecast_precip_total_mean_mm",
    "v4_forecast_precip_total_max_mm",
    "v4_forecast_precip_total_spread_mm",
    "v4_forecast_precip_max_1h_mean_mm",
    "v4_forecast_precip_hours_mean",
    "v4_forecast_precip_intensity_mean",
    "v4_forecast_precip_intensity_max",
    "v4_any_forecast_precip",
    "v4_all_forecast_precip",
    "v4_observed_precip_any",
    "v4_observed_precip_recent_mm_est",
    "v4_forecast_total_minus_observed_recent_mm",
    "v4_forecast_observed_precip_match",
    "v4_forecast_wet_observed_dry",
    "v4_observed_wet_forecast_dry",
    "v4_precip_humidity_interaction",
    "v4_precip_remaining_warmup_interaction",
]


def _num(frame: pd.DataFrame, column: str) -> pd.Series:
    if column in frame:
        return pd.to_numeric(frame[column], errors="coerce")
    return pd.Series(np.nan, index=frame.index, dtype="float64")


def _bool_num(frame: pd.DataFrame, column: str) -> pd.Series:
    if column not in frame:
        return pd.Series(0, index=frame.index, dtype="int64")
    series = frame[column]
    if pd.api.types.is_bool_dtype(series):
        return series.fillna(False).astype(int)
    if pd.api.types.is_numeric_dtype(series):
        return pd.to_numeric(series, errors="coerce").fillna(0).gt(0).astype(int)
    return series.astype("string").str.lower().isin({"1", "true", "yes", "y"}).astype(int)


def _provider_series(frame: pd.DataFrame, provider: str, primary: str, fallback: str | None = None) -> pd.Series:
    primary_column = f"{provider}_{primary}"
    if primary_column in frame:
        return _num(frame, primary_column)
    if fallback is not None:
        return _num(frame, f"{provider}_{fallback}")
    return pd.Series(np.nan, index=frame.index, dtype="float64")


def _provider_matrix(frame: pd.DataFrame, primary: str, fallback: str | None = None) -> pd.DataFrame:
    return pd.DataFrame(
        {provider: _provider_series(frame, provider, primary, fallback) for provider in V4_PROVIDERS},
        index=frame.index,
    )


def add_v4_feature_engineering(frame: pd.DataFrame) -> pd.DataFrame:
    out = frame.copy()
    observed_temp = _num(out, "observed_temp_at_as_of_f")
    high_so_far = _num(out, "observed_high_temp_through_as_of_f")
    observed_humidity = _num(out, "observed_humidity_at_as_of")
    provider_mean = _num(out, "provider_mean_high_f")
    provider_spread = _num(out, "provider_spread_high_f")
    lag_1d = _num(out, "actual_high_lag_1d")
    roll_7d = _num(out, "actual_high_roll_7d_mean")
    roll_30d = _num(out, "actual_high_roll_30d_mean")

    warmup_to_consensus = provider_mean - observed_temp
    remaining_warmup = provider_mean - high_so_far
    out["v2_recent_heat_anomaly_f"] = lag_1d - roll_30d
    out["v2_recent_heat_momentum_f"] = roll_7d - roll_30d
    out["v2_morning_warmup_to_consensus_f"] = warmup_to_consensus
    out["v2_consensus_minus_7d_actual_f"] = provider_mean - roll_7d
    out["v2_spread_per_warmup_f"] = provider_spread / warmup_to_consensus.abs().clip(lower=1.0)
    out["v2_humidity_warmup_interaction"] = (observed_humidity / 100.0) * warmup_to_consensus
    out["v3_high_so_far_above_current_f"] = high_so_far - observed_temp
    out["v3_remaining_warmup_from_high_so_far_f"] = remaining_warmup
    out["v3_high_so_far_minus_lag_1d_f"] = high_so_far - lag_1d
    out["v3_high_so_far_minus_7d_actual_f"] = high_so_far - roll_7d
    out["v3_remaining_warmup_per_spread_f"] = remaining_warmup / provider_spread.abs().clip(lower=1.0)
    out["v3_humidity_remaining_warmup_interaction"] = (observed_humidity / 100.0) * remaining_warmup

    precip_total = _provider_matrix(out, "forecast_precip_total_mm", fallback="precip_amount")
    precip_max_1h = _provider_matrix(out, "forecast_precip_max_1h_mm")
    precip_hours = _provider_matrix(out, "forecast_precip_hours_count")
    precip_intensity = _provider_matrix(out, "forecast_precip_intensity_code")
    has_precip = _provider_matrix(out, "forecast_has_precip").fillna(0).clip(lower=0, upper=1)

    out["v4_forecast_precip_total_mean_mm"] = precip_total.mean(axis=1)
    out["v4_forecast_precip_total_max_mm"] = precip_total.max(axis=1)
    out["v4_forecast_precip_total_spread_mm"] = precip_total.max(axis=1) - precip_total.min(axis=1)
    out["v4_forecast_precip_max_1h_mean_mm"] = precip_max_1h.mean(axis=1)
    out["v4_forecast_precip_hours_mean"] = precip_hours.mean(axis=1)
    out["v4_forecast_precip_intensity_mean"] = precip_intensity.mean(axis=1)
    out["v4_forecast_precip_intensity_max"] = precip_intensity.max(axis=1)
    out["v4_any_forecast_precip"] = has_precip.max(axis=1).fillna(0).astype(int)
    out["v4_all_forecast_precip"] = has_precip.min(axis=1).fillna(0).astype(int)

    observed_any = (
        _bool_num(out, "observed_is_raining_at_as_of")
        | _bool_num(out, "observed_is_drizzle_at_as_of")
        | _bool_num(out, "observed_is_snowing_at_as_of")
    ).astype(int)
    observed_recent_mm = _num(out, "observed_precip_recent_at_as_of") * 25.4
    out["v4_observed_precip_any"] = observed_any
    out["v4_observed_precip_recent_mm_est"] = observed_recent_mm
    out["v4_forecast_total_minus_observed_recent_mm"] = out["v4_forecast_precip_total_mean_mm"] - observed_recent_mm
    out["v4_forecast_observed_precip_match"] = out["v4_any_forecast_precip"].eq(observed_any).astype(int)
    out["v4_forecast_wet_observed_dry"] = (out["v4_any_forecast_precip"].eq(1) & observed_any.eq(0)).astype(int)
    out["v4_observed_wet_forecast_dry"] = (observed_any.eq(1) & out["v4_any_forecast_precip"].eq(0)).astype(int)
    out["v4_precip_humidity_interaction"] = out["v4_forecast_precip_total_mean_mm"] * (observed_humidity / 100.0)
    out["v4_precip_remaining_warmup_interaction"] = out["v4_forecast_precip_total_mean_mm"] * remaining_warmup
    return out


if not hasattr(station_stacking_module, "_v4_original_build_station_wide_dataset"):
    station_stacking_module._v4_original_build_station_wide_dataset = station_stacking_module.build_station_wide_dataset


def build_station_wide_dataset_v4(*args, **kwargs):
    frame = station_stacking_module._v4_original_build_station_wide_dataset(*args, **kwargs)
    return add_v4_feature_engineering(frame)


station_stacking_module.build_station_wide_dataset = build_station_wide_dataset_v4
V4_FEATURE_COLUMNS
# Out:
# ['v2_recent_heat_anomaly_f',
#  'v2_recent_heat_momentum_f',
#  'v2_morning_warmup_to_consensus_f',
#  'v2_consensus_minus_7d_actual_f',
#  'v2_spread_per_warmup_f',
#  'v2_humidity_warmup_interaction',
#  'v3_high_so_far_above_current_f',
#  'v3_remaining_warmup_from_high_so_far_f',
#  'v3_high_so_far_minus_lag_1d_f',
#  'v3_high_so_far_minus_7d_actual_f',
#  'v3_remaining_warmup_per_spread_f',
#  'v3_humidity_remaining_warmup_interaction',
#  'v4_forecast_precip_total_mean_mm',
#  'v4_forecast_precip_total_max_mm',
#  'v4_forecast_precip_total_spread_mm',
#  'v4_forecast_precip_max_1h_mean_mm',
#  'v4_forecast_precip_hours_mean',
#  'v4_forecast_precip_intensity_mean',
#  'v4_forecast_precip_intensity_max',
#  'v4_any_forecast_precip',
#  'v4_all_forecast_precip',
#  'v4_observed_precip_any',
#  'v4_observed_precip_recent_mm_est',
#  'v4_forecast_total_minus_observed_recent_mm',
#  'v4_forecast_observed_precip_match',
#  'v4_forecast_wet_observed_dry',
#  'v4_observed_wet_forecast_dry',
#  'v4_precip_humidity_interaction',
#  'v4_precip_remaining_warmup_interaction']

# %% [markdown]
# ## Model Scores

# %%
missing_packages = missing_model_dependencies()
if missing_packages:
    raise ImportError(
        "Missing station-stacking ML packages: "
        + ", ".join(missing_packages)
        + ". Install them with: python -m pip install -r requirements.txt"
    )

config = StationStackingConfig(
    station_id=STATION_ID,
    project_root=PROJECT_ROOT,
    fast_mode=FAST_MODE,
    optuna_trials=OPTUNA_TRIALS,
    stack_optuna_trials=STACK_OPTUNA_TRIALS,
    optuna_verbose=OPTUNA_VERBOSE,
    output_dir=PROJECT_ROOT / "data" / "calibration" / "station_stacking_v4",
)
result = run_station_year_split_experiment(config)
result.scoreboard
# Out:
# [I 2026-06-09 06:29:18,016] A new study created in memory with name: no-name-cc3cd579-c86b-4a74-91b2-2d3bea76f968
# [I 2026-06-09 06:30:01,472] Trial 0 finished with value: 3.3515926314575575 and parameters: {'n_estimators': 799, 'learning_rate': 0.12369619597856178, 'max_depth': 6, 'min_child_weight': 2.385234757844707, 'gamma': 0.7800932022121826, 'subsample': 0.5779972601681014, 'colsample_bytree': 0.5290418060840998, 'reg_alpha': 0.6245760287469893, 'reg_lambda': 0.6677615511747083}. Best is trial 0 with value: 3.3515926314575575.
# [I 2026-06-09 06:33:45,040] Trial 1 finished with value: 3.2448518413931855 and parameters: {'n_estimators': 1440, 'learning_rate': 0.0032515743808034223, 'max_depth': 8, 'min_child_weight': 8.23143373099555, 'gamma': 1.0616955533913808, 'subsample': 0.5909124836035503, 'colsample_bytree': 0.5917022549267169, 'reg_alpha': 5.472429642032198e-06, 'reg_lambda': 0.2922905212920093}. Best is trial 1 with value: 3.2448518413931855.
# [I 2026-06-09 06:34:56,465] Trial 2 finished with value: 3.5373986606267325 and parameters: {'n_estimators': 909, 'learning_rate': 0.009373695213782608, 'max_depth': 5, 'min_child_weight': 0.20940138873937433, 'gamma': 1.4607232426760908, 'subsample': 0.6831809216468459, 'colsample_bytree': 0.728034992108518, 'reg_alpha': 0.1165691561324743, 'reg_lambda': 0.008674832802525461}. Best is trial 1 with value: 3.2448518413931855.
# [I 2026-06-09 06:35:14,965] Trial 3 finished with value: 3.2430971304077847 and parameters: {'n_estimators': 1067, 'learning_rate': 0.03045200113778571, 'max_depth': 1, 'min_child_weight': 2.5002240473339543, 'gamma': 0.8526206184364576, 'subsample': 0.5325257964926398, 'colsample_bytree': 0.9744427686266666, 'reg_alpha': 4.905556676028774, 'reg_lambda': 6.289771819487036}. Best is trial 3 with value: 3.2430971304077847.
# [I 2026-06-09 06:36:34,446] Trial 4 finished with value: 3.532262585567408 and parameters: {'n_estimators': 665, 'learning_rate': 0.004396056309201638, 'max_depth': 6, 'min_child_weight': 1.0299214204601976, 'gamma': 0.6101911742238941, 'subsample': 0.7475884550556351, 'colsample_bytree': 0.5171942605576092, 'reg_alpha': 1.527156759251193, 'reg_lambda': 0.016443693426189242}. Best is trial 3 with value: 3.2430971304077847.
# [I 2026-06-09 06:37:06,795] Trial 5 pruned.
# [I 2026-06-09 06:37:13,808] Trial 6 finished with value: 3.2886092815819175 and parameters: {'n_estimators': 1228, 'learning_rate': 0.11049889315270257, 'max_depth': 1, 'min_child_weight': 0.28246357083904894, 'gamma': 0.22613644455269033, 'subsample': 0.6626651653816322, 'colsample_bytree': 0.6943386448447411, 'reg_alpha': 2.7678419414850017e-06, 'reg_lambda': 7.838134236608707}. Best is trial 3 with value: 3.2430971304077847.
# [I 2026-06-09 06:37:36,948] Trial 7 pruned.
# [I 2026-06-09 06:37:41,221] Trial 8 pruned.
# [I 2026-06-09 06:37:51,760] Trial 9 pruned.
# [I 2026-06-09 06:38:03,013] Trial 10 finished with value: 3.2881054585299143 and parameters: {'n_estimators': 1915, 'learning_rate': 0.036235378997051045, 'max_depth': 3, 'min_child_weight': 13.97101765312176, 'gamma': 2.828065453407016, 'subsample': 0.8211770829222278, 'colsample_bytree': 0.9805126451489784, 'reg_alpha': 0.0025347992375043043, 'reg_lambda': 2.1525808090182244}. Best is trial 3 with value: 3.2430971304077847.
# [I 2026-06-09 06:38:31,054] Trial 11 finished with value: 3.253822104357324 and parameters: {'n_estimators': 1816, 'learning_rate': 0.03287546171457566, 'max_depth': 8, 'min_child_weight': 10.967975722691842, 'gamma': 2.1717813587820567, 'subsample': 0.6158877708273484, 'colsample_bytree': 0.6109402802946341, 'reg_alpha': 6.982496886163948e-05, 'reg_lambda': 0.1500406109373817}. Best is trial 3 with value: 3.2430971304077847.
# [I 2026-06-09 06:41:59,904] Trial 12 finished with value: 3.2535684373578784 and parameters: {'n_estimators': 1606, 'learning_rate': 0.003196962615028647, 'max_depth': 8, 'min_child_weight': 5.967787778328425, 'gamma': 2.5182196590789347, 'subsample': 0.5224078715805444, 'colsample_bytree': 0.8285397244388237, 'reg_alpha': 2.0057322817130592e-08, 'reg_lambda': 0.9111568610251692}. Best is trial 3 with value: 3.2430971304077847.
# [I 2026-06-09 06:42:40,438] Trial 13 finished with value: 3.2346791773151495 and parameters: {'n_estimators': 1067, 'learning_rate': 0.022426968689597045, 'max_depth': 3, 'min_child_weight': 4.27533932135294, 'gamma': 0.022350197382312254, 'subsample': 0.6223441463224711, 'colsample_bytree': 0.8910368801788895, 'reg_alpha': 0.0005372302104189243, 'reg_lambda': 48.823076726100275}. Best is trial 13 with value: 3.2346791773151495.
# [I 2026-06-09 06:43:08,916] Trial 14 finished with value: 3.298493741850812 and parameters: {'n_estimators': 382, 'learning_rate': 0.021885090402504376, 'max_depth': 3, 'min_child_weight': 3.0699737306547434, 'gamma': 0.14095477974946344, 'subsample': 0.678482277529767, 'colsample_bytree': 0.9103716164395093, 'reg_alpha': 0.004633011838829117, 'reg_lambda': 27.485711044390538}. Best is trial 13 with value: 3.2346791773151495.
# [I 2026-06-09 06:43:46,066] Trial 15 finished with value: 3.247866846473159 and parameters: {'n_estimators': 1018, 'learning_rate': 0.023403812317643047, 'max_depth': 2, 'min_child_weight': 1.015606087965998, 'gamma': 0.04043537740255916, 'subsample': 0.757303939170667, 'colsample_bytree': 0.9175424010588125, 'reg_alpha': 0.003043263840972833, 'reg_lambda': 39.259353563133836}. Best is trial 13 with value: 3.2346791773151495.
# [I 2026-06-09 06:43:58,514] Trial 16 finished with value: 3.2388247675531447 and parameters: {'n_estimators': 1056, 'learning_rate': 0.051271021503965834, 'max_depth': 3, 'min_child_weight': 17.955437059949602, 'gamma': 1.678938385359599, 'subsample': 0.6267454591507512, 'colsample_bytree': 0.818143901032267, 'reg_alpha': 0.00021194824625201362, 'reg_lambda': 3.835223798821768}. Best is trial 13 with value: 3.2346791773151495.
# [I 2026-06-09 06:44:12,417] Trial 17 finished with value: 3.2218523147540497 and parameters: {'n_estimators': 489, 'learning_rate': 0.05819385016116549, 'max_depth': 3, 'min_child_weight': 15.289002752757323, 'gamma': 3.132394567758081, 'subsample': 0.6385064470732967, 'colsample_bytree': 0.7855166418058748, 'reg_alpha': 5.1730232739247147e-05, 'reg_lambda': 2.5122564429528085}. Best is trial 17 with value: 3.2218523147540497.
# [I 2026-06-09 06:44:14,926] Trial 18 pruned.
# [I 2026-06-09 06:44:15,967] Trial 19 pruned.
# [I 2026-06-09 06:44:32,611] Trial 20 finished with value: 3.2368096047090487 and parameters: {'n_estimators': 359, 'learning_rate': 0.053130073733855664, 'max_depth': 4, 'min_child_weight': 8.45271771632826, 'gamma': 4.983820120201943, 'subsample': 0.7045005355351618, 'colsample_bytree': 0.86719553329466, 'reg_alpha': 0.00047586372947605804, 'reg_lambda': 46.77754615679882}. Best is trial 17 with value: 3.2218523147540497.
# [I 2026-06-09 06:45:02,532] Trial 21 finished with value: 3.2567697077199704 and parameters: {'n_estimators': 344, 'learning_rate': 0.05255646980637484, 'max_depth': 4, 'min_child_weight': 8.6120598643628, 'gamma': 4.880683864734422, 'subsample': 0.6922339890457799, 'colsample_bytree': 0.8648067102061628, 'reg_alpha': 0.00045281065655936113, 'reg_lambda': 47.94420669869044}. Best is trial 17 with value: 3.2218523147540497.
# [I 2026-06-09 06:45:13,976] Trial 22 pruned.
# [I 2026-06-09 06:45:20,468] Trial 23 pruned.
# [I 2026-06-09 06:45:23,233] Trial 24 pruned.
# [I 2026-06-09 06:45:57,931] Trial 25 pruned.
# [I 2026-06-09 06:45:59,911] Trial 26 pruned.
# [I 2026-06-09 06:46:08,054] Trial 27 pruned.
# [I 2026-06-09 06:46:13,584] Trial 28 pruned.
# [I 2026-06-09 06:46:20,968] Trial 29 pruned.
# [I 2026-06-09 06:46:38,566] Trial 30 pruned.
# [I 2026-06-09 06:46:47,786] Trial 31 pruned.
# [I 2026-06-09 06:47:08,005] Trial 32 finished with value: 3.235627843489447 and parameters: {'n_estimators': 1578, 'learning_rate': 0.05891325306837584, 'max_depth': 3, 'min_child_weight': 18.772706152975346, 'gamma': 3.6421696352181248, 'subsample': 0.7088283035357253, 'colsample_bytree': 0.8059978291925158, 'reg_alpha': 1.7421165631850186e-05, 'reg_lambda': 12.492021192526513}. Best is trial 17 with value: 3.2218523147540497.
# [I 2026-06-09 06:47:46,787] Trial 33 pruned.
# [I 2026-06-09 06:47:49,480] Trial 34 pruned.
# [I 2026-06-09 06:48:28,360] Trial 35 finished with value: 3.249922399600777 and parameters: {'n_estimators': 1777, 'learning_rate': 0.024559312111862033, 'max_depth': 3, 'min_child_weight': 2.0126350824021726, 'gamma': 1.271899082130468, 'subsample': 0.6678245216424936, 'colsample_bytree': 0.7471358131716427, 'reg_alpha': 5.436649641105592e-06, 'reg_lambda': 25.244381930493986}. Best is trial 17 with value: 3.2218523147540497.
# [I 2026-06-09 06:48:38,230] Trial 36 pruned.
# [I 2026-06-09 06:48:49,789] Trial 37 finished with value: 3.2350834347477697 and parameters: {'n_estimators': 1442, 'learning_rate': 0.09332674805523934, 'max_depth': 2, 'min_child_weight': 4.939733875891636, 'gamma': 4.069228235608311, 'subsample': 0.5971892187781442, 'colsample_bytree': 0.5532819126765207, 'reg_alpha': 3.255210448329735e-05, 'reg_lambda': 20.42838007278642}. Best is trial 17 with value: 3.2218523147540497.
# [I 2026-06-09 06:48:53,673] Trial 38 pruned.
# [I 2026-06-09 06:48:57,921] Trial 39 pruned.
# [I 2026-06-09 06:49:01,391] Trial 40 pruned.
# [I 2026-06-09 06:49:25,649] Trial 41 finished with value: 3.3032271230429293 and parameters: {'n_estimators': 1451, 'learning_rate': 0.061721716130888594, 'max_depth': 3, 'min_child_weight': 4.405619481219853, 'gamma': 4.701138710474776, 'subsample': 0.6554194805710961, 'colsample_bytree': 0.6413923331598824, 'reg_alpha': 9.094083012706144e-05, 'reg_lambda': 44.78819452357009}. Best is trial 17 with value: 3.2218523147540497.
# [I 2026-06-09 06:49:35,546] Trial 42 finished with value: 3.21917016309675 and parameters: {'n_estimators': 1496, 'learning_rate': 0.08768110230631392, 'max_depth': 2, 'min_child_weight': 12.154546663395454, 'gamma': 4.960415420618248, 'subsample': 0.69578143665995, 'colsample_bytree': 0.8830299744060307, 'reg_alpha': 0.0011535358278474434, 'reg_lambda': 11.234224580201142}. Best is trial 42 with value: 3.21917016309675.
# [I 2026-06-09 06:49:40,314] Trial 43 pruned.
# [I 2026-06-09 06:49:44,401] Trial 44 pruned.
# [I 2026-06-09 06:49:49,679] Trial 45 pruned.
# [I 2026-06-09 06:49:51,036] Trial 46 pruned.
# [I 2026-06-09 06:50:20,790] Trial 47 pruned.
# [I 2026-06-09 06:50:27,501] Trial 48 pruned.
# [I 2026-06-09 06:50:45,569] Trial 49 finished with value: 3.2500269108600346 and parameters: {'n_estimators': 1809, 'learning_rate': 0.027701945756096715, 'max_depth': 3, 'min_child_weight': 15.34386182321261, 'gamma': 1.1475081154858007, 'subsample': 0.6029508975292449, 'colsample_bytree': 0.9874814432154788, 'reg_alpha': 0.036425777110446096, 'reg_lambda': 2.4983980733505433}. Best is trial 42 with value: 3.21917016309675.
# [I 2026-06-09 06:50:48,893] Trial 50 pruned.
# [I 2026-06-09 06:50:59,904] Trial 51 pruned.
# [I 2026-06-09 06:51:02,796] Trial 52 pruned.
# [I 2026-06-09 06:51:14,402] Trial 53 pruned.
# [I 2026-06-09 06:51:29,961] Trial 54 pruned.
# [I 2026-06-09 06:51:44,858] Trial 55 pruned.
# [I 2026-06-09 06:51:50,742] Trial 56 pruned.
# [I 2026-06-09 06:52:10,987] Trial 57 pruned.
# [I 2026-06-09 06:52:18,919] Trial 58 pruned.
# [I 2026-06-09 06:52:21,805] Trial 59 pruned.
# [I 2026-06-09 06:52:27,186] Trial 60 pruned.
# [I 2026-06-09 06:52:30,995] Trial 61 pruned.
# [I 2026-06-09 06:52:44,026] Trial 62 finished with value: 3.2474233754449155 and parameters: {'n_estimators': 1632, 'learning_rate': 0.06730182874993655, 'max_depth': 4, 'min_child_weight': 19.767883195925293, 'gamma': 1.8630598240470277, 'subsample': 0.6465870742762971, 'colsample_bytree': 0.8745104369342694, 'reg_alpha': 0.0009039519315707169, 'reg_lambda': 3.499013807321113}. Best is trial 42 with value: 3.21917016309675.
# [I 2026-06-09 06:52:54,695] Trial 63 pruned.
# [I 2026-06-09 06:53:01,457] Trial 64 pruned.
# [I 2026-06-09 06:53:07,803] Trial 65 pruned.
# [I 2026-06-09 06:53:17,396] Trial 66 pruned.
# [I 2026-06-09 06:53:24,883] Trial 67 pruned.
# [I 2026-06-09 06:53:27,540] Trial 68 pruned.
# [I 2026-06-09 06:53:55,498] Trial 69 pruned.
# [I 2026-06-09 06:54:02,010] Trial 70 pruned.
# [I 2026-06-09 06:54:13,356] Trial 71 pruned.
# [I 2026-06-09 06:54:21,821] Trial 72 pruned.
# [I 2026-06-09 06:54:28,519] Trial 73 pruned.
# [I 2026-06-09 06:54:35,879] Trial 74 pruned.
# [I 2026-06-09 06:54:40,917] Trial 75 pruned.
# [I 2026-06-09 06:55:00,262] Trial 76 finished with value: 3.2329581049342253 and parameters: {'n_estimators': 1215, 'learning_rate': 0.03357027450684726, 'max_depth': 1, 'min_child_weight': 3.8088688752965485, 'gamma': 1.9647716977564724, 'subsample': 0.5448230997075841, 'colsample_bytree': 0.7922637332443224, 'reg_alpha': 0.047366384463605624, 'reg_lambda': 25.840317714119795}. Best is trial 42 with value: 3.21917016309675.
# [I 2026-06-09 06:55:27,576] Trial 77 finished with value: 3.2243356725999113 and parameters: {'n_estimators': 1293, 'learning_rate': 0.024605615497435923, 'max_depth': 2, 'min_child_weight': 5.566403924005163, 'gamma': 2.328779334698363, 'subsample': 0.5419854435647325, 'colsample_bytree': 0.8032411033467418, 'reg_alpha': 0.03577213157527759, 'reg_lambda': 26.47663092255941}. Best is trial 42 with value: 3.21917016309675.
# [I 2026-06-09 06:56:02,837] Trial 78 finished with value: 3.219153446885684 and parameters: {'n_estimators': 1326, 'learning_rate': 0.020829008873928544, 'max_depth': 1, 'min_child_weight': 3.6504016258757424, 'gamma': 1.9785435717701365, 'subsample': 0.5358163936669196, 'colsample_bytree': 0.790812150066226, 'reg_alpha': 0.4876665823047811, 'reg_lambda': 28.48997952109704}. Best is trial 78 with value: 3.219153446885684.
# [I 2026-06-09 06:56:49,653] Trial 79 finished with value: 3.2325322432979586 and parameters: {'n_estimators': 1297, 'learning_rate': 0.014951764217618662, 'max_depth': 1, 'min_child_weight': 3.4918378600633915, 'gamma': 2.247970753119989, 'subsample': 0.5377745648115431, 'colsample_bytree': 0.7359985912397159, 'reg_alpha': 0.2999566946808148, 'reg_lambda': 26.989898846084323}. Best is trial 78 with value: 3.219153446885684.
# [I 2026-06-09 06:57:05,099] Trial 80 pruned.
# [I 2026-06-09 06:57:39,012] Trial 81 finished with value: 3.2287998707511227 and parameters: {'n_estimators': 1358, 'learning_rate': 0.012688262675710469, 'max_depth': 1, 'min_child_weight': 3.9810884782912295, 'gamma': 2.639871359791183, 'subsample': 0.5002098013756352, 'colsample_bytree': 0.7598147853296394, 'reg_alpha': 0.5877752147471766, 'reg_lambda': 19.081514122839412}. Best is trial 78 with value: 3.219153446885684.
# [I 2026-06-09 06:57:53,079] Trial 82 pruned.
# [I 2026-06-09 06:58:27,560] Trial 83 finished with value: 3.2355814580194577 and parameters: {'n_estimators': 1361, 'learning_rate': 0.012188574714019346, 'max_depth': 1, 'min_child_weight': 4.003156070024958, 'gamma': 2.6350125159300926, 'subsample': 0.5495705733495067, 'colsample_bytree': 0.7579448446186487, 'reg_alpha': 0.3465944882001489, 'reg_lambda': 20.948408046023825}. Best is trial 78 with value: 3.219153446885684.
# [I 2026-06-09 06:58:44,551] Trial 84 pruned.
# [I 2026-06-09 06:59:02,719] Trial 85 finished with value: 3.2081532563566997 and parameters: {'n_estimators': 1276, 'learning_rate': 0.02443870378431363, 'max_depth': 1, 'min_child_weight': 2.183267347034421, 'gamma': 2.4566000864238413, 'subsample': 0.5459859399990499, 'colsample_bytree': 0.6683868830400677, 'reg_alpha': 0.04426726141435948, 'reg_lambda': 24.425846394432824}. Best is trial 85 with value: 3.2081532563566997.
# [I 2026-06-09 06:59:19,561] Trial 86 pruned.
# [I 2026-06-09 06:59:47,569] Trial 87 finished with value: 3.212748961309969 and parameters: {'n_estimators': 1363, 'learning_rate': 0.02461910885022145, 'max_depth': 1, 'min_child_weight': 2.1000351382746185, 'gamma': 1.960909917305705, 'subsample': 0.5114552741235396, 'colsample_bytree': 0.7715351634469759, 'reg_alpha': 0.41454489094961194, 'reg_lambda': 37.12637842139399}. Best is trial 85 with value: 3.2081532563566997.
# [I 2026-06-09 07:00:04,011] Trial 88 finished with value: 3.2041103085424982 and parameters: {'n_estimators': 1381, 'learning_rate': 0.024700927030335766, 'max_depth': 1, 'min_child_weight': 1.7734526900545031, 'gamma': 1.8533289216233533, 'subsample': 0.5115708909331217, 'colsample_bytree': 0.7367427721822575, 'reg_alpha': 0.05633402735300509, 'reg_lambda': 34.451112866418605}. Best is trial 88 with value: 3.2041103085424982.
# [I 2026-06-09 07:00:14,031] Trial 89 pruned.
# [I 2026-06-09 07:00:18,664] Trial 90 pruned.
# [I 2026-06-09 07:00:49,791] Trial 91 finished with value: 3.218696084691484 and parameters: {'n_estimators': 1397, 'learning_rate': 0.016892648722570448, 'max_depth': 1, 'min_child_weight': 1.6273515232995968, 'gamma': 1.9289545355614912, 'subsample': 0.5539341064703412, 'colsample_bytree': 0.7337881696735499, 'reg_alpha': 0.0387221428354622, 'reg_lambda': 34.23513521539406}. Best is trial 88 with value: 3.2041103085424982.
# [I 2026-06-09 07:01:24,555] Trial 92 finished with value: 3.2115954848505606 and parameters: {'n_estimators': 1386, 'learning_rate': 0.016971063224151105, 'max_depth': 1, 'min_child_weight': 1.7771676946794837, 'gamma': 2.2323995143882844, 'subsample': 0.5577097127571563, 'colsample_bytree': 0.7409110765058531, 'reg_alpha': 0.05356775145654802, 'reg_lambda': 34.54878044520499}. Best is trial 88 with value: 3.2041103085424982.
# [I 2026-06-09 07:01:49,251] Trial 93 finished with value: 3.214974201173483 and parameters: {'n_estimators': 1414, 'learning_rate': 0.017713314430539827, 'max_depth': 1, 'min_child_weight': 1.505730026796139, 'gamma': 2.454872563263322, 'subsample': 0.5591717965806962, 'colsample_bytree': 0.7748548216637573, 'reg_alpha': 0.05462164291535685, 'reg_lambda': 34.97488813811605}. Best is trial 88 with value: 3.2041103085424982.
# [I 2026-06-09 07:01:57,333] Trial 94 pruned.
# [I 2026-06-09 07:02:28,393] Trial 95 finished with value: 3.204249589935655 and parameters: {'n_estimators': 1467, 'learning_rate': 0.017653124551099957, 'max_depth': 1, 'min_child_weight': 0.883419346565911, 'gamma': 1.5498199013569398, 'subsample': 0.5640291764523853, 'colsample_bytree': 0.7715040525742133, 'reg_alpha': 0.017686105535052964, 'reg_lambda': 38.03614849506535}. Best is trial 88 with value: 3.2041103085424982.
# [I 2026-06-09 07:02:42,209] Trial 96 pruned.
# [I 2026-06-09 07:02:55,229] Trial 97 pruned.
# [I 2026-06-09 07:03:12,138] Trial 98 pruned.
# [I 2026-06-09 07:03:20,264] Trial 99 pruned.
# [I 2026-06-09 07:03:20,271] A new study created in memory with name: no-name-fea2d71a-7a8c-42fc-8bbf-e5b58d7d135f
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:03:31,516] Trial 0 finished with value: 3.300830222382058 and parameters: {'n_estimators': 301, 'learning_rate': 0.03250177171527344, 'num_leaves': 37, 'max_depth': 4, 'min_child_samples': 52, 'min_split_gain': 1.7182749818971954, 'bagging_fraction': 0.8330451065490129, 'bagging_freq': 4, 'feature_fraction': 0.5145069122121801, 'lambda_l1': 0.04015454105555427, 'lambda_l2': 0.07175601133819473}. Best is trial 0 with value: 3.300830222382058.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:05:15,462] Trial 1 finished with value: 3.3425885545768974 and parameters: {'n_estimators': 1620, 'learning_rate': 0.008116618171663207, 'num_leaves': 18, 'max_depth': 9, 'min_child_samples': 37, 'min_split_gain': 0.8099788960945193, 'bagging_fraction': 0.6580482355091044, 'bagging_freq': 1, 'feature_fraction': 0.9216123471148523, 'lambda_l1': 0.43697071238567825, 'lambda_l2': 36.7185332724254}. Best is trial 0 with value: 3.300830222382058.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:05:29,334] Trial 2 finished with value: 3.3316950847343967 and parameters: {'n_estimators': 820, 'learning_rate': 0.1255359023925396, 'num_leaves': 116, 'max_depth': 8, 'min_child_samples': 17, 'min_split_gain': 1.7941971599630686, 'bagging_fraction': 0.6490017503443813, 'bagging_freq': 2, 'feature_fraction': 0.5025647745322285, 'lambda_l1': 0.0007741455782248723, 'lambda_l2': 0.1717169091593679}. Best is trial 0 with value: 3.300830222382058.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:05:35,825] Trial 3 finished with value: 3.6932578281984716 and parameters: {'n_estimators': 1302, 'learning_rate': 0.13774020868800516, 'num_leaves': 233, 'max_depth': 10, 'min_child_samples': 81, 'min_split_gain': 0.2080378997095258, 'bagging_fraction': 0.5904572976289505, 'bagging_freq': 7, 'feature_fraction': 0.7059764916931793, 'lambda_l1': 0.6097531961875766, 'lambda_l2': 1.4405915859050216}. Best is trial 0 with value: 3.300830222382058.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:06:13,589] Trial 4 finished with value: 3.3738187393299164 and parameters: {'n_estimators': 1287, 'learning_rate': 0.008816320113501107, 'num_leaves': 230, 'max_depth': 3, 'min_child_samples': 64, 'min_split_gain': 1.987144984788207, 'bagging_fraction': 0.8678635407535604, 'bagging_freq': 4, 'feature_fraction': 0.7803315847218675, 'lambda_l1': 5.026890229380336e-05, 'lambda_l2': 2.6067223030440956}. Best is trial 0 with value: 3.300830222382058.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:06:25,748] Trial 5 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:06:33,751] Trial 6 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:06:37,687] Trial 7 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:06:38,361] Trial 8 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:06:50,474] Trial 9 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:07:18,906] Trial 10 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:07:36,234] Trial 11 finished with value: 3.304425890041424 and parameters: {'n_estimators': 598, 'learning_rate': 0.05642532812077397, 'num_leaves': 112, 'max_depth': 6, 'min_child_samples': 6, 'min_split_gain': 1.5728258526088479, 'bagging_fraction': 0.7368592807094115, 'bagging_freq': 1, 'feature_fraction': 0.5259001926996263, 'lambda_l1': 0.0007798973479050788, 'lambda_l2': 0.017382620881059765}. Best is trial 0 with value: 3.300830222382058.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:07:53,767] Trial 12 finished with value: 3.283356532620054 and parameters: {'n_estimators': 473, 'learning_rate': 0.04425501344351966, 'num_leaves': 143, 'max_depth': 5, 'min_child_samples': 10, 'min_split_gain': 1.4396137038457515, 'bagging_fraction': 0.7445807570203351, 'bagging_freq': 1, 'feature_fraction': 0.5852484232649209, 'lambda_l1': 0.006165921259221086, 'lambda_l2': 0.008615096978222084}. Best is trial 12 with value: 3.283356532620054.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:08:18,713] Trial 13 finished with value: 3.2719573098454076 and parameters: {'n_estimators': 331, 'learning_rate': 0.023876686842685055, 'num_leaves': 162, 'max_depth': 5, 'min_child_samples': 31, 'min_split_gain': 1.1414201541152744, 'bagging_fraction': 0.7741904208705135, 'bagging_freq': 2, 'feature_fraction': 0.6091484946086794, 'lambda_l1': 0.02559020904036742, 'lambda_l2': 0.002382249432418657}. Best is trial 13 with value: 3.2719573098454076.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:08:38,032] Trial 14 finished with value: 3.301639312711279 and parameters: {'n_estimators': 541, 'learning_rate': 0.02013235568641657, 'num_leaves': 163, 'max_depth': 5, 'min_child_samples': 30, 'min_split_gain': 1.1526647845049771, 'bagging_fraction': 0.757058996926908, 'bagging_freq': 2, 'feature_fraction': 0.602205334676884, 'lambda_l1': 0.012242661910714407, 'lambda_l2': 0.001085955156408762}. Best is trial 13 with value: 3.2719573098454076.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:08:45,695] Trial 15 finished with value: 3.3074749515996325 and parameters: {'n_estimators': 87, 'learning_rate': 0.06298468502808904, 'num_leaves': 169, 'max_depth': 6, 'min_child_samples': 22, 'min_split_gain': 1.1877182988570527, 'bagging_fraction': 0.7594272816440204, 'bagging_freq': 2, 'feature_fraction': 0.7172581861942076, 'lambda_l1': 0.0001351361821738404, 'lambda_l2': 0.006034354665592721}. Best is trial 13 with value: 3.2719573098454076.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:09:17,973] Trial 16 finished with value: 3.288837382408506 and parameters: {'n_estimators': 546, 'learning_rate': 0.017773702452401615, 'num_leaves': 190, 'max_depth': 5, 'min_child_samples': 6, 'min_split_gain': 0.8733848662585414, 'bagging_fraction': 0.9826565708275925, 'bagging_freq': 1, 'feature_fraction': 0.5947686108709094, 'lambda_l1': 0.09401760516651696, 'lambda_l2': 0.003261946852283791}. Best is trial 13 with value: 3.2719573098454076.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:09:21,779] Trial 17 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:09:33,632] Trial 18 finished with value: 3.300774782601688 and parameters: {'n_estimators': 782, 'learning_rate': 0.07056517416350402, 'num_leaves': 203, 'max_depth': 6, 'min_child_samples': 23, 'min_split_gain': 0.8344699388788319, 'bagging_fraction': 0.9333536803927939, 'bagging_freq': 3, 'feature_fraction': 0.9991355829538757, 'lambda_l1': 0.0013585823633477036, 'lambda_l2': 0.036164147355487015}. Best is trial 13 with value: 3.2719573098454076.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:09:41,969] Trial 19 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:09:43,451] Trial 20 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:09:59,147] Trial 21 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:10:19,013] Trial 22 finished with value: 3.281502032322187 and parameters: {'n_estimators': 1022, 'learning_rate': 0.023606025157250875, 'num_leaves': 201, 'max_depth': 5, 'min_child_samples': 29, 'min_split_gain': 0.011702093078486131, 'bagging_fraction': 0.9245991204071191, 'bagging_freq': 1, 'feature_fraction': 0.6572230411257306, 'lambda_l1': 0.005762517731520266, 'lambda_l2': 0.008943222667061324}. Best is trial 13 with value: 3.2719573098454076.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:10:44,797] Trial 23 finished with value: 3.281976377951467 and parameters: {'n_estimators': 1037, 'learning_rate': 0.026800064773326582, 'num_leaves': 203, 'max_depth': 7, 'min_child_samples': 35, 'min_split_gain': 0.1840550999056304, 'bagging_fraction': 0.9196581651719984, 'bagging_freq': 2, 'feature_fraction': 0.6496600188276923, 'lambda_l1': 0.0029364560639016097, 'lambda_l2': 0.008780345319537601}. Best is trial 13 with value: 3.2719573098454076.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:10:54,607] Trial 24 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:11:13,634] Trial 25 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:11:37,128] Trial 26 finished with value: 3.2618895010739557 and parameters: {'n_estimators': 1507, 'learning_rate': 0.022899966557279234, 'num_leaves': 248, 'max_depth': 6, 'min_child_samples': 32, 'min_split_gain': 0.2985232157127129, 'bagging_fraction': 0.914467719809335, 'bagging_freq': 2, 'feature_fraction': 0.6526984333902189, 'lambda_l1': 1.0495698388680148e-05, 'lambda_l2': 0.005175986313626027}. Best is trial 26 with value: 3.2618895010739557.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:12:06,767] Trial 27 finished with value: 3.258635673561878 and parameters: {'n_estimators': 1610, 'learning_rate': 0.020770174780990868, 'num_leaves': 253, 'max_depth': 6, 'min_child_samples': 27, 'min_split_gain': 0.36470256804154977, 'bagging_fraction': 0.8011461165304636, 'bagging_freq': 3, 'feature_fraction': 0.7515226413560441, 'lambda_l1': 9.716639317918878e-06, 'lambda_l2': 0.001144073182705946}. Best is trial 27 with value: 3.258635673561878.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:12:38,824] Trial 28 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:12:45,442] Trial 29 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:12:57,242] Trial 30 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:13:24,504] Trial 31 finished with value: 3.2748856464057448 and parameters: {'n_estimators': 1487, 'learning_rate': 0.0226492705095566, 'num_leaves': 223, 'max_depth': 6, 'min_child_samples': 30, 'min_split_gain': 0.33599916931569296, 'bagging_fraction': 0.8965805097618479, 'bagging_freq': 2, 'feature_fraction': 0.6804540339199792, 'lambda_l1': 2.915965775991415e-07, 'lambda_l2': 0.0017782362804023212}. Best is trial 27 with value: 3.258635673561878.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:13:45,405] Trial 32 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:15:27,409] Trial 33 finished with value: 3.2642673792740244 and parameters: {'n_estimators': 1755, 'learning_rate': 0.010686974853995581, 'num_leaves': 253, 'max_depth': 8, 'min_child_samples': 25, 'min_split_gain': 0.3348301974366226, 'bagging_fraction': 0.8524444327668863, 'bagging_freq': 2, 'feature_fraction': 0.6778815235781349, 'lambda_l1': 1.7298346787028944e-07, 'lambda_l2': 0.001493011809202637}. Best is trial 27 with value: 3.258635673561878.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:18:44,149] Trial 34 finished with value: 3.2731191118340353 and parameters: {'n_estimators': 1809, 'learning_rate': 0.009480863424414005, 'num_leaves': 251, 'max_depth': 8, 'min_child_samples': 18, 'min_split_gain': 0.5229841707065251, 'bagging_fraction': 0.8276799931883028, 'bagging_freq': 2, 'feature_fraction': 0.618979380146179, 'lambda_l1': 0.0002572537552889431, 'lambda_l2': 0.0011839503637586803}. Best is trial 27 with value: 3.258635673561878.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:20:43,962] Trial 35 finished with value: 3.28856132878952 and parameters: {'n_estimators': 1703, 'learning_rate': 0.012546200997597734, 'num_leaves': 235, 'max_depth': 10, 'min_child_samples': 17, 'min_split_gain': 0.17944449072570368, 'bagging_fraction': 0.8694490070037679, 'bagging_freq': 4, 'feature_fraction': 0.8108530948275143, 'lambda_l1': 1.7571654191187673e-05, 'lambda_l2': 0.004766731397231881}. Best is trial 27 with value: 3.258635673561878.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:22:29,773] Trial 36 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:24:45,109] Trial 37 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:28:45,010] Trial 38 finished with value: 3.280963690218611 and parameters: {'n_estimators': 1865, 'learning_rate': 0.01692806712167172, 'num_leaves': 39, 'max_depth': 7, 'min_child_samples': 26, 'min_split_gain': 0.5390788315625843, 'bagging_fraction': 0.6972647655030568, 'bagging_freq': 2, 'feature_fraction': 0.5559528383314886, 'lambda_l1': 9.438392826250981e-07, 'lambda_l2': 0.002739051236597099}. Best is trial 27 with value: 3.258635673561878.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:42:28,829] Trial 39 finished with value: 3.2633106756076566 and parameters: {'n_estimators': 1311, 'learning_rate': 0.006751685115969003, 'num_leaves': 212, 'max_depth': 9, 'min_child_samples': 16, 'min_split_gain': 0.3854474575525582, 'bagging_fraction': 0.6618347721172536, 'bagging_freq': 4, 'feature_fraction': 0.6269477780937655, 'lambda_l1': 1.129154409900941e-08, 'lambda_l2': 0.005589547887231112}. Best is trial 27 with value: 3.258635673561878.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:47:40,030] Trial 40 finished with value: 3.2785047803814935 and parameters: {'n_estimators': 1191, 'learning_rate': 0.007274052917916112, 'num_leaves': 212, 'max_depth': 9, 'min_child_samples': 17, 'min_split_gain': 0.3508489912784904, 'bagging_fraction': 0.5536046578910148, 'bagging_freq': 5, 'feature_fraction': 0.7675229352707507, 'lambda_l1': 3.0461646421855156e-08, 'lambda_l2': 0.14538618290816419}. Best is trial 27 with value: 3.258635673561878.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:50:30,879] Trial 41 finished with value: 3.25569298396442 and parameters: {'n_estimators': 1410, 'learning_rate': 0.010895385010660525, 'num_leaves': 241, 'max_depth': 10, 'min_child_samples': 14, 'min_split_gain': 0.14419145900289287, 'bagging_fraction': 0.634146256509527, 'bagging_freq': 4, 'feature_fraction': 0.634317601489393, 'lambda_l1': 1.2096340490912613e-08, 'lambda_l2': 0.006069177871093286}. Best is trial 41 with value: 3.25569298396442.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:56:51,613] Trial 42 finished with value: 3.265183447825145 and parameters: {'n_estimators': 1386, 'learning_rate': 0.00487216177988531, 'num_leaves': 239, 'max_depth': 10, 'min_child_samples': 16, 'min_split_gain': 0.24901897874364293, 'bagging_fraction': 0.630140933280066, 'bagging_freq': 4, 'feature_fraction': 0.63136341625224, 'lambda_l1': 1.7418586315990622e-07, 'lambda_l2': 0.005915279713737297}. Best is trial 41 with value: 3.25569298396442.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:57:46,315] Trial 43 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:59:01,591] Trial 44 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 08:00:58,626] Trial 45 finished with value: 3.252645063991279 and parameters: {'n_estimators': 1713, 'learning_rate': 0.0076246309285676805, 'num_leaves': 223, 'max_depth': 8, 'min_child_samples': 13, 'min_split_gain': 0.3045388027171042, 'bagging_fraction': 0.5470399193846894, 'bagging_freq': 4, 'feature_fraction': 0.7053426812292378, 'lambda_l1': 4.736889192326956e-08, 'lambda_l2': 4.686429152890884}. Best is trial 45 with value: 3.252645063991279.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 08:02:37,308] Trial 46 finished with value: 3.2593579645518935 and parameters: {'n_estimators': 1375, 'learning_rate': 0.007295118909336469, 'num_leaves': 186, 'max_depth': 9, 'min_child_samples': 10, 'min_split_gain': 0.12568327188648198, 'bagging_fraction': 0.5006309837716255, 'bagging_freq': 4, 'feature_fraction': 0.7013474916405423, 'lambda_l1': 2.920162965278637e-08, 'lambda_l2': 0.3747805389165086}. Best is trial 45 with value: 3.252645063991279.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 08:05:43,273] Trial 47 finished with value: 3.2432239444384074 and parameters: {'n_estimators': 1489, 'learning_rate': 0.00519314325683784, 'num_leaves': 183, 'max_depth': 9, 'min_child_samples': 11, 'min_split_gain': 0.18438369819229167, 'bagging_fraction': 0.523686566952935, 'bagging_freq': 4, 'feature_fraction': 0.7085176970768414, 'lambda_l1': 3.695308672289473e-08, 'lambda_l2': 5.723519733014646}. Best is trial 47 with value: 3.2432239444384074.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 08:10:38,601] Trial 48 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 08:13:07,282] Trial 49 finished with value: 3.270945285216696 and parameters: {'n_estimators': 1677, 'learning_rate': 0.0052706338028827016, 'num_leaves': 185, 'max_depth': 10, 'min_child_samples': 15, 'min_split_gain': 0.11307041660004694, 'bagging_fraction': 0.5548845290642141, 'bagging_freq': 6, 'feature_fraction': 0.7975089932253031, 'lambda_l1': 5.319233378562726e-08, 'lambda_l2': 0.7638221399670715}. Best is trial 47 with value: 3.2432239444384074.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 08:13:29,220] Trial 50 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 08:14:40,036] Trial 51 pruned.
# [W 2026-06-09 08:15:17,246] Trial 52 failed with parameters: {'n_estimators': 1883, 'learning_rate': 0.0031620631117327495, 'num_leaves': 242, 'max_depth': 10, 'min_child_samples': 134, 'min_split_gain': 0.24044029817538365, 'bagging_fraction': 0.5281862602846232, 'bagging_freq': 5, 'feature_fraction': 0.7056718700762609, 'lambda_l1': 5.31332688202998e-08, 'lambda_l2': 49.91258629252329} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "d:\dev\weather-research\.venv\Lib\site-packages\optuna\study\_optimize.py", line 206, in _run_trial
#     value_or_values = func(trial)
#   File "D:\dev\weather-research\src\calibration\station_stacking.py", line 800, in objective
#     year = pd.to_numeric(frame.get("year"), errors="coerce")
#                                               ^^^^^^^^^^^^^^
#     ...<8 lines>...
#             for fold in folds:
#             ^^^^^^^^^
#   File "D:\dev\weather-research\src\calibration\station_stacking.py", line 1909, in _fit_predict_base_model
#         train: pd.DataFrame,
#     ...<7 lines>...
#
#   File "D:\dev\weather-research\src\calibration\station_stacking.py", line 1951, in _fit_base_estimator
#         x_train: Any,
#                 ^^^^^
#     ...<5 lines>...
#         if early_stopping_rounds is None:
#         ^^^^^^^^^
#   File "d:\dev\weather-research\.venv\Lib\site-packages\lightgbm\sklearn.py", line 1398, in fit
#     super().fit(
#     ~~~~~~~~~~~^
#         X,
#         ^^
#     ...<11 lines>...
#         init_model=init_model,
#         ^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "d:\dev\weather-research\.venv\Lib\site-packages\lightgbm\sklearn.py", line 1049, in fit
#     self._Booster = train(
#                     ~~~~~^
#         params=params,
#         ^^^^^^^^^^^^^^
#     ...<6 lines>...
#         callbacks=callbacks,
#         ^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "d:\dev\weather-research\.venv\Lib\site-packages\lightgbm\engine.py", line 322, in train
#     booster.update(fobj=fobj)
#     ~~~~~~~~~~~~~~^^^^^^^^^^^
#   File "d:\dev\weather-research\.venv\Lib\site-packages\lightgbm\basic.py", line 4155, in update
#     _LIB.LGBM_BoosterUpdateOneIter(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         self._handle,
#         ^^^^^^^^^^^^^
#         ctypes.byref(is_finished),
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
# KeyboardInterrupt
# [W 2026-06-09 08:15:17,268] Trial 52 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 18
#      14     stack_optuna_trials=STACK_OPTUNA_TRIALS,
#      15     optuna_verbose=OPTUNA_VERBOSE,
#      16     output_dir=PROJECT_ROOT / "data" / "calibration" / "station_stacking_v4",
#      17 )
# ---> 18 result = run_station_year_split_experiment(config)
#      19 result.scoreboard
#
# File D:\dev\weather-research\src\calibration\station_stacking.py:654, in run_station_year_split_experiment(config)
#     643     feature_columns_frame.to_csv(paths["feature_columns"], index=False)
#     644     return StationStackingResult(
#     645         station_id=station,
#     646         features=features,
#    (...)    650         output_paths=paths,
#     651     )
# --> 654 def run_station_year_split_experiment(config: StationStackingConfig) -> YearSplitExperimentResult:
#     655     features = build_station_wide_dataset(
#     656         config.resolved_project_root(),
#     657         station_id=config.station_id,
#     658         timing_mode=config.timing_mode,
#     659         providers=config.providers,
#     660     )
#     661     modeling_frame, categorical, numeric = _modeling_frame(features, config)
#
# File D:\dev\weather-research\src\calibration\station_stacking.py:864, in tune_year_split_base_models(frame, config, categorical, numeric, folds)
#     850 rmse = float(metrics["rmse_f"])
#     851 fold_scores.append((fold, float(metrics[metric_col])))
#     852 rows.append(
#     853     {
#     854         "method": method,
#     855         "trial_number": trial.number,
#     856         "param_key": param_key,
#     857         "fold": fold.name,
#     858         "fold_weight": _year_split_fold_weight(fold),
#     859         "mae_f": mae,
#     860         "rmse_f": rmse,
#     861         "count": int(metrics["count"]),
#     862         "fit_numeric_features": fit_metadata["numeric_features"],
#     863         "fit_categorical_features": fit_metadata["categorical_features"],
# --> 864         "best_iteration": fit_metadata["best_iteration"],
#     865         "status": "ok",
#     866         "error": "",
#     867         **{f"param_{key}": value for key, value in params.items()},
#     868     }
#     869 )
#     870 current_score = _weighted_fold_score(fold_scores)
#     871 if hasattr(trial, "report"):
#
# File d:\dev\weather-research\.venv\Lib\site-packages\optuna\study\study.py:516, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     414 def optimize(
#     415     self,
#     416     func: ObjectiveFuncType,
#    (...)    423     show_progress_bar: bool = False,
#     424 ) -> None:
#     425     """Optimize an objective function.
#     426
#     427     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)    514             If nested invocation of this method occurs.
#     515     """
# --> 516     _optimize(
#     517         study=self,
#     518         func=func,
#     519         n_trials=n_trials,
#     520         timeout=timeout,
#     521         n_jobs=n_jobs,
#     522         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     523         callbacks=callbacks,
#     524         gc_after_trial=gc_after_trial,
#     525         show_progress_bar=show_progress_bar,
#     526     )
#
# File d:\dev\weather-research\.venv\Lib\site-packages\optuna\study\_optimize.py:68, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      66 try:
#      67     if n_jobs == 1:
# ---> 68         _optimize_sequential(
#      69             study,
#      70             func,
#      71             n_trials,
#      72             timeout,
#      73             catch,
#      74             callbacks,
#      75             gc_after_trial,
#      76             reseed_sampler_rng=False,
#      77             time_start=None,
#      78             progress_bar=progress_bar,
#      79         )
#      80     else:
#      81         if n_jobs == -1:
#
# File d:\dev\weather-research\.venv\Lib\site-packages\optuna\study\_optimize.py:165, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     162         break
#     164 try:
# --> 165     frozen_trial_id = _run_trial(study, func, catch)
#     166 finally:
#     167     # The following line mitigates memory problems that can be occurred in some
#     168     # environments (e.g., services that use computing containers such as GitHub Actions).
#     169     # Please refer to the following PR for further details:
#     170     # https://github.com/optuna/optuna/pull/325.
#     171     if gc_after_trial:
#
# File d:\dev\weather-research\.venv\Lib\site-packages\optuna\study\_optimize.py:263, in _run_trial(study, func, catch)
#     256         assert False, "Should not reach."
#     258 if (
#     259     updated_state == TrialState.FAIL
#     260     and func_err is not None
#     261     and not isinstance(func_err, catch)
#     262 ):
# --> 263     raise func_err
#     264 return trial._trial_id
#
# File d:\dev\weather-research\.venv\Lib\site-packages\optuna\study\_optimize.py:206, in _run_trial(study, func, catch)
#     204 with get_heartbeat_thread(trial._trial_id, study._storage):
#     205     try:
# --> 206         value_or_values = func(trial)
#     207     except exceptions.TrialPruned as e:
#     208         # TODO(mamu): Handle multi-objective cases.
#     209         state = TrialState.PRUNED
#
# File D:\dev\weather-research\src\calibration\station_stacking.py:800, in objective(trial)
#     798     return pd.DataFrame(), _empty_year_split_predictions(), pd.DataFrame()
#     799 rows: list[dict[str, Any]] = []
# --> 800 year = pd.to_numeric(frame.get("year"), errors="coerce")
#     801 metric_col = config.effective_optuna_metric
#     802 for method in BASE_MODEL_METHODS:
#
# File D:\dev\weather-research\src\calibration\station_stacking.py:1909, in _fit_predict_base_model(config, categorical, numeric, method, params, train, valid, early_stopping)
#    1885         return CatBoostRegressor(
#    1886             iterations=cat_iterations,
#    1887             learning_rate=float(params.get("learning_rate", 0.035)),
#    (...)   1898             allow_writing_files=False,
#    1899         )
#    1900     raise ValueError(f"Unknown base model method: {method}")
#    1903 def _fit_predict_base_model(
#    1904     config: StationStackingConfig,
#    1905     categorical: list[str],
#    1906     numeric: list[str],
#    1907     method: str,
#    1908     params: dict[str, Any],
# -> 1909     train: pd.DataFrame,
#    1910     valid: pd.DataFrame,
#    1911     early_stopping: bool,
#    1912 ) -> tuple[np.ndarray, dict[str, Any]]:
#    1913     fit_categorical, fit_numeric = _fit_feature_columns(train, categorical, numeric)
#    1914     feature_names = [*fit_categorical, *fit_numeric]
#
# File D:\dev\weather-research\src\calibration\station_stacking.py:1951, in _fit_base_estimator(estimator, method, x_train, y_train, x_valid, y_valid, early_stopping_rounds)
#    1944     fit_numeric = [column for column in numeric if column in train and pd.to_numeric(train[column], errors="coerce").notna().any()]
#    1945     return fit_categorical, fit_numeric
#    1948 def _fit_base_estimator(
#    1949     estimator: Any,
#    1950     method: str,
# -> 1951     x_train: Any,
#    1952     y_train: pd.Series,
#    1953     x_valid: Any,
#    1954     y_valid: pd.Series,
#    1955     early_stopping_rounds: int | None,
#    1956 ) -> None:
#    1957     if early_stopping_rounds is None:
#    1958         estimator.fit(x_train, y_train)
#
# File d:\dev\weather-research\.venv\Lib\site-packages\lightgbm\sklearn.py:1398, in LGBMRegressor.fit(self, X, y, sample_weight, init_score, eval_set, eval_names, eval_sample_weight, eval_init_score, eval_metric, feature_name, categorical_feature, callbacks, init_model)
#    1381 def fit(  # type: ignore[override]
#    1382     self,
#    1383     X: _LGBM_ScikitMatrixLike,
#    (...)   1395     init_model: Optional[Union[str, Path, Booster, LGBMModel]] = None,
#    1396 ) -> "LGBMRegressor":
#    1397     """Docstring is inherited from the LGBMModel."""
# -> 1398     super().fit(
#    1399         X,
#    1400         y,
#    1401         sample_weight=sample_weight,
#    1402         init_score=init_score,
#    1403         eval_set=eval_set,
#    1404         eval_names=eval_names,
#    1405         eval_sample_weight=eval_sample_weight,
#    1406         eval_init_score=eval_init_score,
#    1407         eval_metric=eval_metric,
#    1408         feature_name=feature_name,
#    1409         categorical_feature=categorical_feature,
#    1410         callbacks=callbacks,
#    1411         init_model=init_model,
#    1412     )
#    1413     return self
#
# File d:\dev\weather-research\.venv\Lib\site-packages\lightgbm\sklearn.py:1049, in LGBMModel.fit(self, X, y, sample_weight, init_score, group, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_group, eval_metric, feature_name, categorical_feature, callbacks, init_model)
#    1046 evals_result: _EvalResultDict = {}
#    1047 callbacks.append(record_evaluation(evals_result))
# -> 1049 self._Booster = train(
#    1050     params=params,
#    1051     train_set=train_set,
#    1052     num_boost_round=self.n_estimators,
#    1053     valid_sets=valid_sets,
#    1054     valid_names=eval_names,
#    1055     feval=eval_metrics_callable,  # type: ignore[arg-type]
#    1056     init_model=init_model,
#    1057     callbacks=callbacks,
#    1058 )
#    1060 # This populates the property self.n_features_, the number of features in the fitted model,
#    1061 # and so should only be set after fitting.
#    1062 #
#    1063 # The related property self._n_features_in, which populates self.n_features_in_,
#    1064 # is set BEFORE fitting.
#    1065 self._n_features = self._Booster.num_feature()
#
# File d:\dev\weather-research\.venv\Lib\site-packages\lightgbm\engine.py:322, in train(params, train_set, num_boost_round, valid_sets, valid_names, feval, init_model, keep_training_booster, callbacks)
#     310 for cb in callbacks_before_iter:
#     311     cb(
#     312         callback.CallbackEnv(
#     313             model=booster,
#    (...)    319         )
#     320     )
# --> 322 booster.update(fobj=fobj)
#     324 evaluation_result_list: List[_LGBM_BoosterEvalMethodResultType] = []
#     325 # check evaluation result.
#
# File d:\dev\weather-research\.venv\Lib\site-packages\lightgbm\basic.py:4155, in Booster.update(self, train_set, fobj)
#    4152 if self.__set_objective_to_none:
#    4153     raise LightGBMError("Cannot update due to null objective function.")
#    4154 _safe_call(
# -> 4155     _LIB.LGBM_BoosterUpdateOneIter(
#    4156         self._handle,
#    4157         ctypes.byref(is_finished),
#    4158     )
#    4159 )
#    4160 self.__is_predicted_cur_iter = [False for _ in range(self.__num_dataset)]
#    4161 return is_finished.value == 1
#
# KeyboardInterrupt:

# %% [markdown]
# ## Rounded Within 1F Accuracy

# %%
preds = pd.concat(
    [
        result.validation_predictions.assign(period="validation_2024_2025"),
        result.test_predictions.assign(period="test_2026"),
    ],
    ignore_index=True,
)

predicted_high = pd.to_numeric(preds["predicted_high_f"], errors="coerce")
preds["predicted_high_rounded_f"] = np.floor(predicted_high + 0.5)
preds["within_1f_after_round"] = (
    pd.to_numeric(preds["actual_high_f"], errors="coerce") - preds["predicted_high_rounded_f"]
).abs().le(1)

within_1f_accuracy_by_period = (
    preds
    .dropna(subset=["actual_high_f", "predicted_high_rounded_f"])
    .groupby(["period", "method"], as_index=False)
    .agg(
        count=("within_1f_after_round", "size"),
        within_1f_count=("within_1f_after_round", "sum"),
        within_1f_accuracy_pct=("within_1f_after_round", lambda x: x.mean() * 100),
    )
    .sort_values(["period", "within_1f_accuracy_pct"], ascending=[True, False])
)

within_1f_accuracy_by_period

# %% [markdown]
# ## Precipitation Feature Coverage

# %%
precip_columns = [column for column in result.features.columns if "precip" in column.lower()]
coverage = (
    result.features[precip_columns]
    .notna()
    .mean()
    .mul(100)
    .sort_values(ascending=False)
    .rename("coverage_pct")
    .reset_index()
    .rename(columns={"index": "feature"})
)
coverage

# %% [markdown]
# ## Version Comparison

# %%
comparison_frames = []
for version, folder in [
    ("v1", PROJECT_ROOT / "data" / "calibration" / "station_stacking"),
    ("v2", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v2"),
    ("v3", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v3"),
    ("v4", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v4"),
]:
    path = folder / f"{STATION_ID}_year_split_scoreboard.csv"
    if path.exists():
        frame = pd.read_csv(path)
        frame["version"] = version
        comparison_frames.append(frame)

version_comparison = pd.concat(comparison_frames, ignore_index=True) if comparison_frames else pd.DataFrame()
if not version_comparison.empty:
    version_comparison = version_comparison.sort_values(["period", "mae_f", "version", "method"]).reset_index(drop=True)
version_comparison

# %% [markdown]
# ## 2026 Weather Brackets

# %%
result.bracket_metrics

# %%
import pandas as pd


def adjacent_brackets(bracket):
    if pd.isna(bracket):
        return []
    text = str(bracket).strip()
    if not text or "-" not in text:
        return []
    try:
        lower = int(text.split("-", 1)[0])
    except ValueError:
        return []
    return [
        f"{lower - 2}-{lower - 1}",
        f"{lower}-{lower + 1}",
        f"{lower + 2}-{lower + 3}",
    ]


bracket_3way = result.bracket_predictions.copy()

valid = bracket_3way["actual_bracket"].notna() & bracket_3way["predicted_bracket"].astype(str).str.strip().ne("")
bracket_3way = bracket_3way.loc[valid].copy()
bracket_3way["picked_brackets"] = bracket_3way["predicted_bracket"].map(adjacent_brackets)
bracket_3way["three_bracket_hit"] = bracket_3way.apply(
    lambda row: row["actual_bracket"] in row["picked_brackets"],
    axis=1,
)

three_bracket_accuracy = (
    bracket_3way
    .groupby("method", as_index=False)
    .agg(
        count=("three_bracket_hit", "size"),
        exact_bracket_accuracy_pct=("bracket_hit", lambda x: x.mean() * 100),
        three_bracket_accuracy_pct=("three_bracket_hit", lambda x: x.mean() * 100),
    )
    .sort_values("three_bracket_accuracy_pct", ascending=False)
)

three_bracket_accuracy

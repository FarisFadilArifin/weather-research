# %% [markdown]
# # Station Stacking v4 - KAUS
#
# Wide HRRR/GFS same-day 11am notebook for `KAUS`.
#
# This version keeps the v3 high-so-far features and adds SDK-backed precipitation features from HRRR/GFS forecast precipitation plus 11 AM METAR precipitation codes. Artifacts are written to `data/calibration/station_stacking_v4`.

# %%
from pathlib import Path
import sys
import warnings

warnings.filterwarnings("ignore", message="IProgress not found.*")
warnings.filterwarnings("ignore", message="Skipping features without any observed values.*")

PROJECT_ROOT = Path.cwd().resolve()
while not (PROJECT_ROOT / "src" / "calibration" / "station_stacking.py").exists():
    if PROJECT_ROOT.parent == PROJECT_ROOT:
        raise RuntimeError("Could not find project root containing src/calibration/station_stacking.py")
    PROJECT_ROOT = PROJECT_ROOT.parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

STATION_ID = "KAUS"
FAST_MODE = False
OPTUNA_TRIALS = 100
STACK_OPTUNA_TRIALS = 50
OPTUNA_VERBOSE = True
PROJECT_ROOT
# Out:
# WindowsPath('D:/dev/weather-research')

# %%
from src.calibration.station_stacking import (
    StationStackingConfig,
    missing_model_dependencies,
    run_station_year_split_experiment,
)

# %% [markdown]
# ## V4 Feature Engineering
#
# Adds v2/v3 temperature features plus forecast and observed precipitation signals. Forecast precipitation comes from provider-prefixed SDK summary columns such as `gfs_forecast_precip_total_mm`, with `gfs_precip_amount` as a fallback for older caches.

# %%
import numpy as np
import pandas as pd
import src.calibration.station_stacking as station_stacking_module

V4_PROVIDERS = ("gfs", "hrrr")
V4_FEATURE_COLUMNS = [
    "v2_recent_heat_anomaly_f",
    "v2_recent_heat_momentum_f",
    "v2_morning_warmup_to_consensus_f",
    "v2_consensus_minus_7d_actual_f",
    "v2_spread_per_warmup_f",
    "v2_humidity_warmup_interaction",
    "v3_high_so_far_above_current_f",
    "v3_remaining_warmup_from_high_so_far_f",
    "v3_high_so_far_minus_lag_1d_f",
    "v3_high_so_far_minus_7d_actual_f",
    "v3_remaining_warmup_per_spread_f",
    "v3_humidity_remaining_warmup_interaction",
    "v4_forecast_precip_total_mean_mm",
    "v4_forecast_precip_total_max_mm",
    "v4_forecast_precip_total_spread_mm",
    "v4_forecast_precip_max_1h_mean_mm",
    "v4_forecast_precip_hours_mean",
    "v4_forecast_precip_intensity_mean",
    "v4_forecast_precip_intensity_max",
    "v4_any_forecast_precip",
    "v4_all_forecast_precip",
    "v4_observed_precip_any",
    "v4_observed_precip_recent_mm_est",
    "v4_forecast_total_minus_observed_recent_mm",
    "v4_forecast_observed_precip_match",
    "v4_forecast_wet_observed_dry",
    "v4_observed_wet_forecast_dry",
    "v4_precip_humidity_interaction",
    "v4_precip_remaining_warmup_interaction",
]


def _num(frame: pd.DataFrame, column: str) -> pd.Series:
    if column in frame:
        return pd.to_numeric(frame[column], errors="coerce")
    return pd.Series(np.nan, index=frame.index, dtype="float64")


def _bool_num(frame: pd.DataFrame, column: str) -> pd.Series:
    if column not in frame:
        return pd.Series(0, index=frame.index, dtype="int64")
    series = frame[column]
    if pd.api.types.is_bool_dtype(series):
        return series.fillna(False).astype(int)
    if pd.api.types.is_numeric_dtype(series):
        return pd.to_numeric(series, errors="coerce").fillna(0).gt(0).astype(int)
    return series.astype("string").str.lower().isin({"1", "true", "yes", "y"}).astype(int)


def _provider_series(frame: pd.DataFrame, provider: str, primary: str, fallback: str | None = None) -> pd.Series:
    primary_column = f"{provider}_{primary}"
    if primary_column in frame:
        return _num(frame, primary_column)
    if fallback is not None:
        return _num(frame, f"{provider}_{fallback}")
    return pd.Series(np.nan, index=frame.index, dtype="float64")


def _provider_matrix(frame: pd.DataFrame, primary: str, fallback: str | None = None) -> pd.DataFrame:
    return pd.DataFrame(
        {provider: _provider_series(frame, provider, primary, fallback) for provider in V4_PROVIDERS},
        index=frame.index,
    )


def add_v4_feature_engineering(frame: pd.DataFrame) -> pd.DataFrame:
    out = frame.copy()
    observed_temp = _num(out, "observed_temp_at_as_of_f")
    high_so_far = _num(out, "observed_high_temp_through_as_of_f")
    observed_humidity = _num(out, "observed_humidity_at_as_of")
    provider_mean = _num(out, "provider_mean_high_f")
    provider_spread = _num(out, "provider_spread_high_f")
    lag_1d = _num(out, "actual_high_lag_1d")
    roll_7d = _num(out, "actual_high_roll_7d_mean")
    roll_30d = _num(out, "actual_high_roll_30d_mean")

    warmup_to_consensus = provider_mean - observed_temp
    remaining_warmup = provider_mean - high_so_far
    out["v2_recent_heat_anomaly_f"] = lag_1d - roll_30d
    out["v2_recent_heat_momentum_f"] = roll_7d - roll_30d
    out["v2_morning_warmup_to_consensus_f"] = warmup_to_consensus
    out["v2_consensus_minus_7d_actual_f"] = provider_mean - roll_7d
    out["v2_spread_per_warmup_f"] = provider_spread / warmup_to_consensus.abs().clip(lower=1.0)
    out["v2_humidity_warmup_interaction"] = (observed_humidity / 100.0) * warmup_to_consensus
    out["v3_high_so_far_above_current_f"] = high_so_far - observed_temp
    out["v3_remaining_warmup_from_high_so_far_f"] = remaining_warmup
    out["v3_high_so_far_minus_lag_1d_f"] = high_so_far - lag_1d
    out["v3_high_so_far_minus_7d_actual_f"] = high_so_far - roll_7d
    out["v3_remaining_warmup_per_spread_f"] = remaining_warmup / provider_spread.abs().clip(lower=1.0)
    out["v3_humidity_remaining_warmup_interaction"] = (observed_humidity / 100.0) * remaining_warmup

    precip_total = _provider_matrix(out, "forecast_precip_total_mm", fallback="precip_amount")
    precip_max_1h = _provider_matrix(out, "forecast_precip_max_1h_mm")
    precip_hours = _provider_matrix(out, "forecast_precip_hours_count")
    precip_intensity = _provider_matrix(out, "forecast_precip_intensity_code")
    has_precip = _provider_matrix(out, "forecast_has_precip").fillna(0).clip(lower=0, upper=1)

    out["v4_forecast_precip_total_mean_mm"] = precip_total.mean(axis=1)
    out["v4_forecast_precip_total_max_mm"] = precip_total.max(axis=1)
    out["v4_forecast_precip_total_spread_mm"] = precip_total.max(axis=1) - precip_total.min(axis=1)
    out["v4_forecast_precip_max_1h_mean_mm"] = precip_max_1h.mean(axis=1)
    out["v4_forecast_precip_hours_mean"] = precip_hours.mean(axis=1)
    out["v4_forecast_precip_intensity_mean"] = precip_intensity.mean(axis=1)
    out["v4_forecast_precip_intensity_max"] = precip_intensity.max(axis=1)
    out["v4_any_forecast_precip"] = has_precip.max(axis=1).fillna(0).astype(int)
    out["v4_all_forecast_precip"] = has_precip.min(axis=1).fillna(0).astype(int)

    observed_any = (
        _bool_num(out, "observed_is_raining_at_as_of")
        | _bool_num(out, "observed_is_drizzle_at_as_of")
        | _bool_num(out, "observed_is_snowing_at_as_of")
    ).astype(int)
    observed_recent_mm = _num(out, "observed_precip_recent_at_as_of") * 25.4
    out["v4_observed_precip_any"] = observed_any
    out["v4_observed_precip_recent_mm_est"] = observed_recent_mm
    out["v4_forecast_total_minus_observed_recent_mm"] = out["v4_forecast_precip_total_mean_mm"] - observed_recent_mm
    out["v4_forecast_observed_precip_match"] = out["v4_any_forecast_precip"].eq(observed_any).astype(int)
    out["v4_forecast_wet_observed_dry"] = (out["v4_any_forecast_precip"].eq(1) & observed_any.eq(0)).astype(int)
    out["v4_observed_wet_forecast_dry"] = (observed_any.eq(1) & out["v4_any_forecast_precip"].eq(0)).astype(int)
    out["v4_precip_humidity_interaction"] = out["v4_forecast_precip_total_mean_mm"] * (observed_humidity / 100.0)
    out["v4_precip_remaining_warmup_interaction"] = out["v4_forecast_precip_total_mean_mm"] * remaining_warmup
    return out


if not hasattr(station_stacking_module, "_v4_original_build_station_wide_dataset"):
    station_stacking_module._v4_original_build_station_wide_dataset = station_stacking_module.build_station_wide_dataset


def build_station_wide_dataset_v4(*args, **kwargs):
    frame = station_stacking_module._v4_original_build_station_wide_dataset(*args, **kwargs)
    return add_v4_feature_engineering(frame)


station_stacking_module.build_station_wide_dataset = build_station_wide_dataset_v4
V4_FEATURE_COLUMNS
# Out:
# ['v2_recent_heat_anomaly_f',
#  'v2_recent_heat_momentum_f',
#  'v2_morning_warmup_to_consensus_f',
#  'v2_consensus_minus_7d_actual_f',
#  'v2_spread_per_warmup_f',
#  'v2_humidity_warmup_interaction',
#  'v3_high_so_far_above_current_f',
#  'v3_remaining_warmup_from_high_so_far_f',
#  'v3_high_so_far_minus_lag_1d_f',
#  'v3_high_so_far_minus_7d_actual_f',
#  'v3_remaining_warmup_per_spread_f',
#  'v3_humidity_remaining_warmup_interaction',
#  'v4_forecast_precip_total_mean_mm',
#  'v4_forecast_precip_total_max_mm',
#  'v4_forecast_precip_total_spread_mm',
#  'v4_forecast_precip_max_1h_mean_mm',
#  'v4_forecast_precip_hours_mean',
#  'v4_forecast_precip_intensity_mean',
#  'v4_forecast_precip_intensity_max',
#  'v4_any_forecast_precip',
#  'v4_all_forecast_precip',
#  'v4_observed_precip_any',
#  'v4_observed_precip_recent_mm_est',
#  'v4_forecast_total_minus_observed_recent_mm',
#  'v4_forecast_observed_precip_match',
#  'v4_forecast_wet_observed_dry',
#  'v4_observed_wet_forecast_dry',
#  'v4_precip_humidity_interaction',
#  'v4_precip_remaining_warmup_interaction']

# %% [markdown]
# ## Model Scores

# %%
missing_packages = missing_model_dependencies()
if missing_packages:
    raise ImportError(
        "Missing station-stacking ML packages: "
        + ", ".join(missing_packages)
        + ". Install them with: python -m pip install -r requirements.txt"
    )

config = StationStackingConfig(
    station_id=STATION_ID,
    project_root=PROJECT_ROOT,
    fast_mode=FAST_MODE,
    optuna_trials=OPTUNA_TRIALS,
    stack_optuna_trials=STACK_OPTUNA_TRIALS,
    optuna_verbose=OPTUNA_VERBOSE,
    output_dir=PROJECT_ROOT / "data" / "calibration" / "station_stacking_v4",
)
result = run_station_year_split_experiment(config)
result.scoreboard
# Out:
# [I 2026-06-09 06:27:26,865] A new study created in memory with name: no-name-6279b0ab-8b82-47c6-b2e3-7affd166a0b5
# [I 2026-06-09 06:27:47,414] Trial 0 finished with value: 6.040664545168206 and parameters: {'n_estimators': 799, 'learning_rate': 0.12369619597856178, 'max_depth': 6, 'min_child_weight': 2.385234757844707, 'gamma': 0.7800932022121826, 'subsample': 0.5779972601681014, 'colsample_bytree': 0.5290418060840998, 'reg_alpha': 0.6245760287469893, 'reg_lambda': 0.6677615511747083}. Best is trial 0 with value: 6.040664545168206.
# [I 2026-06-09 06:30:30,990] Trial 1 finished with value: 5.92612106014859 and parameters: {'n_estimators': 1440, 'learning_rate': 0.0032515743808034223, 'max_depth': 8, 'min_child_weight': 8.23143373099555, 'gamma': 1.0616955533913808, 'subsample': 0.5909124836035503, 'colsample_bytree': 0.5917022549267169, 'reg_alpha': 5.472429642032198e-06, 'reg_lambda': 0.2922905212920093}. Best is trial 1 with value: 5.92612106014859.
# [I 2026-06-09 06:31:04,417] Trial 2 finished with value: 6.22719693175805 and parameters: {'n_estimators': 909, 'learning_rate': 0.009373695213782608, 'max_depth': 5, 'min_child_weight': 0.20940138873937433, 'gamma': 1.4607232426760908, 'subsample': 0.6831809216468459, 'colsample_bytree': 0.728034992108518, 'reg_alpha': 0.1165691561324743, 'reg_lambda': 0.008674832802525461}. Best is trial 1 with value: 5.92612106014859.
# [I 2026-06-09 06:31:16,187] Trial 3 finished with value: 5.87505058083417 and parameters: {'n_estimators': 1067, 'learning_rate': 0.03045200113778571, 'max_depth': 1, 'min_child_weight': 2.5002240473339543, 'gamma': 0.8526206184364576, 'subsample': 0.5325257964926398, 'colsample_bytree': 0.9744427686266666, 'reg_alpha': 4.905556676028774, 'reg_lambda': 6.289771819487036}. Best is trial 3 with value: 5.87505058083417.
# [I 2026-06-09 06:32:39,340] Trial 4 finished with value: 6.071962382951633 and parameters: {'n_estimators': 665, 'learning_rate': 0.004396056309201638, 'max_depth': 6, 'min_child_weight': 1.0299214204601976, 'gamma': 0.6101911742238941, 'subsample': 0.7475884550556351, 'colsample_bytree': 0.5171942605576092, 'reg_alpha': 1.527156759251193, 'reg_lambda': 0.016443693426189242}. Best is trial 3 with value: 5.87505058083417.
# [I 2026-06-09 06:34:03,339] Trial 5 finished with value: 6.120584669196901 and parameters: {'n_estimators': 1352, 'learning_rate': 0.010155680350355932, 'max_depth': 5, 'min_child_weight': 1.811326544803338, 'gamma': 0.9242722776276352, 'subsample': 0.9847923138822793, 'colsample_bytree': 0.8875664116805573, 'reg_alpha': 2.854239907497756, 'reg_lambda': 16.023850290194936}. Best is trial 3 with value: 5.87505058083417.
# [I 2026-06-09 06:34:10,790] Trial 6 finished with value: 5.920688976920541 and parameters: {'n_estimators': 1228, 'learning_rate': 0.11049889315270257, 'max_depth': 1, 'min_child_weight': 0.28246357083904894, 'gamma': 0.22613644455269033, 'subsample': 0.6626651653816322, 'colsample_bytree': 0.6943386448447411, 'reg_alpha': 2.7678419414850017e-06, 'reg_lambda': 7.838134236608707}. Best is trial 3 with value: 5.87505058083417.
# [I 2026-06-09 06:34:36,681] Trial 7 pruned.
# [I 2026-06-09 06:34:43,550] Trial 8 pruned.
# [I 2026-06-09 06:35:00,059] Trial 9 finished with value: 5.844964047333287 and parameters: {'n_estimators': 1277, 'learning_rate': 0.01094730135557207, 'max_depth': 1, 'min_child_weight': 0.5194929407101735, 'gamma': 1.6259166101337352, 'subsample': 0.864803089169032, 'colsample_bytree': 0.8187787356776066, 'reg_alpha': 0.9658611176861268, 'reg_lambda': 0.16554793541373172}. Best is trial 9 with value: 5.844964047333287.
# [I 2026-06-09 06:35:12,386] Trial 10 finished with value: 5.861286482719182 and parameters: {'n_estimators': 1931, 'learning_rate': 0.02978874982792026, 'max_depth': 3, 'min_child_weight': 13.97101765312176, 'gamma': 2.5126560883739817, 'subsample': 0.9538323976412588, 'colsample_bytree': 0.8271882613853765, 'reg_alpha': 0.0024423918600740835, 'reg_lambda': 0.12179541546611129}. Best is trial 9 with value: 5.844964047333287.
# [I 2026-06-09 06:35:27,092] Trial 11 finished with value: 5.868235858307364 and parameters: {'n_estimators': 1994, 'learning_rate': 0.02795472889231388, 'max_depth': 3, 'min_child_weight': 14.640731896068813, 'gamma': 2.506284264843383, 'subsample': 0.9346365951768512, 'colsample_bytree': 0.8243778617818325, 'reg_alpha': 0.0016469936688646852, 'reg_lambda': 0.1343940773790924}. Best is trial 9 with value: 5.844964047333287.
# [I 2026-06-09 06:35:34,697] Trial 12 pruned.
# [I 2026-06-09 06:35:55,380] Trial 13 finished with value: 5.8656260440009715 and parameters: {'n_estimators': 1731, 'learning_rate': 0.015284248266726867, 'max_depth': 2, 'min_child_weight': 0.10711549383745607, 'gamma': 2.4686809932799925, 'subsample': 0.8557430599301392, 'colsample_bytree': 0.8638922060341145, 'reg_alpha': 0.0031420534530038624, 'reg_lambda': 1.0697993006690072}. Best is trial 9 with value: 5.844964047333287.
# [I 2026-06-09 06:36:07,751] Trial 14 finished with value: 5.858519801060587 and parameters: {'n_estimators': 1595, 'learning_rate': 0.050522263064705024, 'max_depth': 3, 'min_child_weight': 19.58235722169521, 'gamma': 3.155421717694825, 'subsample': 0.8396779355177069, 'colsample_bytree': 0.7793992915216571, 'reg_alpha': 6.023245611116305e-05, 'reg_lambda': 0.04488198099935767}. Best is trial 9 with value: 5.844964047333287.
# [I 2026-06-09 06:36:14,771] Trial 15 finished with value: 5.873711294228568 and parameters: {'n_estimators': 1623, 'learning_rate': 0.06353235540333176, 'max_depth': 2, 'min_child_weight': 0.581206733803663, 'gamma': 3.322350316801756, 'subsample': 0.81192449771089, 'colsample_bytree': 0.7463167709978714, 'reg_alpha': 1.345120247056174e-05, 'reg_lambda': 0.0422722994953449}. Best is trial 9 with value: 5.844964047333287.
# [I 2026-06-09 06:36:20,376] Trial 16 pruned.
# [I 2026-06-09 06:36:30,347] Trial 17 pruned.
# [I 2026-06-09 06:36:45,232] Trial 18 pruned.
# [I 2026-06-09 06:36:54,979] Trial 19 pruned.
# [I 2026-06-09 06:36:59,984] Trial 20 pruned.
# [I 2026-06-09 06:37:06,375] Trial 21 pruned.
# [I 2026-06-09 06:37:26,472] Trial 22 pruned.
# [I 2026-06-09 06:37:47,994] Trial 23 pruned.
# [I 2026-06-09 06:38:06,907] Trial 24 finished with value: 5.836811332684268 and parameters: {'n_estimators': 1237, 'learning_rate': 0.02096313518525604, 'max_depth': 1, 'min_child_weight': 6.5102514767177375, 'gamma': 2.772766012241858, 'subsample': 0.7735801954464039, 'colsample_bytree': 0.9416860695555195, 'reg_alpha': 0.29694452107459135, 'reg_lambda': 2.5943849754751285}. Best is trial 24 with value: 5.836811332684268.
# [I 2026-06-09 06:38:34,268] Trial 25 finished with value: 5.848713909318514 and parameters: {'n_estimators': 1234, 'learning_rate': 0.012821820911529008, 'max_depth': 1, 'min_child_weight': 6.264646157959041, 'gamma': 4.24846322558455, 'subsample': 0.7789999241104493, 'colsample_bytree': 0.9431245104866058, 'reg_alpha': 0.4306156928951826, 'reg_lambda': 3.5279207507675916}. Best is trial 24 with value: 5.836811332684268.
# [I 2026-06-09 06:38:49,425] Trial 26 finished with value: 5.844319221286949 and parameters: {'n_estimators': 1077, 'learning_rate': 0.012501128170390898, 'max_depth': 1, 'min_child_weight': 3.2760361571931407, 'gamma': 4.391583202123327, 'subsample': 0.7657521110683772, 'colsample_bytree': 0.9648736783796611, 'reg_alpha': 0.29462004220155125, 'reg_lambda': 2.7111143802096964}. Best is trial 24 with value: 5.836811332684268.
# [I 2026-06-09 06:39:09,728] Trial 27 pruned.
# [I 2026-06-09 06:39:31,504] Trial 28 finished with value: 5.851926432872528 and parameters: {'n_estimators': 556, 'learning_rate': 0.012418112690230104, 'max_depth': 2, 'min_child_weight': 1.2272064006570074, 'gamma': 1.3733525078728563, 'subsample': 0.739431861242908, 'colsample_bytree': 0.9626143436423489, 'reg_alpha': 0.12136767407808043, 'reg_lambda': 3.1200395022646332}. Best is trial 24 with value: 5.836811332684268.
# [I 2026-06-09 06:39:49,355] Trial 29 pruned.
# [I 2026-06-09 06:40:06,881] Trial 30 finished with value: 5.847924647512199 and parameters: {'n_estimators': 849, 'learning_rate': 0.021269937913484253, 'max_depth': 2, 'min_child_weight': 1.761961453966741, 'gamma': 0.030911622005784123, 'subsample': 0.77579697362929, 'colsample_bytree': 0.9267031236062994, 'reg_alpha': 0.02718581416813148, 'reg_lambda': 0.4885501174932798}. Best is trial 24 with value: 5.836811332684268.
# [I 2026-06-09 06:40:19,433] Trial 31 finished with value: 5.849749284236483 and parameters: {'n_estimators': 821, 'learning_rate': 0.02011774483503294, 'max_depth': 2, 'min_child_weight': 0.6055408378135938, 'gamma': 0.5189735802788078, 'subsample': 0.7819409266605394, 'colsample_bytree': 0.9992483437747102, 'reg_alpha': 0.027438674294667138, 'reg_lambda': 0.5076785554931731}. Best is trial 24 with value: 5.836811332684268.
# [I 2026-06-09 06:41:16,798] Trial 32 pruned.
# [I 2026-06-09 06:41:32,592] Trial 33 pruned.
# [I 2026-06-09 06:42:02,513] Trial 34 finished with value: 5.852783919517469 and parameters: {'n_estimators': 888, 'learning_rate': 0.010231217284154154, 'max_depth': 2, 'min_child_weight': 2.0802263230261544, 'gamma': 1.0816656475979702, 'subsample': 0.7800350602024843, 'colsample_bytree': 0.919120770637177, 'reg_alpha': 0.05222212033947716, 'reg_lambda': 0.7269107532768935}. Best is trial 24 with value: 5.836811332684268.
# [I 2026-06-09 06:42:21,288] Trial 35 pruned.
# [I 2026-06-09 06:42:29,506] Trial 36 pruned.
# [I 2026-06-09 06:42:47,820] Trial 37 pruned.
# [I 2026-06-09 06:43:02,088] Trial 38 finished with value: 5.862493902929945 and parameters: {'n_estimators': 288, 'learning_rate': 0.02275052418504189, 'max_depth': 2, 'min_child_weight': 1.605384889325434, 'gamma': 4.5321920480670155, 'subsample': 0.8093077953455072, 'colsample_bytree': 0.8507279304735875, 'reg_alpha': 9.229374564255409, 'reg_lambda': 0.25203979528116527}. Best is trial 24 with value: 5.836811332684268.
# [I 2026-06-09 06:43:19,025] Trial 39 pruned.
# [I 2026-06-09 06:43:36,778] Trial 40 pruned.
# [I 2026-06-09 06:44:04,545] Trial 41 finished with value: 5.842441395125475 and parameters: {'n_estimators': 1200, 'learning_rate': 0.017090020540614072, 'max_depth': 1, 'min_child_weight': 6.3146548430156235, 'gamma': 4.1878416450716225, 'subsample': 0.7605631630268803, 'colsample_bytree': 0.9585183920823945, 'reg_alpha': 0.40576525036217903, 'reg_lambda': 5.167609532698172}. Best is trial 24 with value: 5.836811332684268.
# [I 2026-06-09 06:44:23,455] Trial 42 finished with value: 5.858170722476985 and parameters: {'n_estimators': 1097, 'learning_rate': 0.01647839852962292, 'max_depth': 1, 'min_child_weight': 9.652157258089899, 'gamma': 4.574546236340607, 'subsample': 0.7538181880111855, 'colsample_bytree': 0.9801726760047964, 'reg_alpha': 0.6230666961333026, 'reg_lambda': 11.868790741095244}. Best is trial 24 with value: 5.836811332684268.
# [I 2026-06-09 06:45:13,812] Trial 43 finished with value: 5.867053669551563 and parameters: {'n_estimators': 1479, 'learning_rate': 0.00858125116471707, 'max_depth': 1, 'min_child_weight': 4.26402069521173, 'gamma': 4.08463609492647, 'subsample': 0.6766643899084799, 'colsample_bytree': 0.9480556671003662, 'reg_alpha': 3.179328491220643, 'reg_lambda': 5.9187389218511575}. Best is trial 24 with value: 5.836811332684268.
# [I 2026-06-09 06:45:36,574] Trial 44 finished with value: 5.866177779602504 and parameters: {'n_estimators': 1193, 'learning_rate': 0.032921162617159896, 'max_depth': 1, 'min_child_weight': 6.7968406490291144, 'gamma': 3.4554318335886496, 'subsample': 0.8276669016204896, 'colsample_bytree': 0.9071600994564377, 'reg_alpha': 0.21591458008788383, 'reg_lambda': 4.9322780925355545}. Best is trial 24 with value: 5.836811332684268.
# [I 2026-06-09 06:45:59,107] Trial 45 finished with value: 5.859819719845737 and parameters: {'n_estimators': 741, 'learning_rate': 0.018162063632491208, 'max_depth': 2, 'min_child_weight': 0.153744273586397, 'gamma': 0.006847511451219163, 'subsample': 0.8006575767792509, 'colsample_bytree': 0.7202858728190467, 'reg_alpha': 0.054730332077937295, 'reg_lambda': 1.4468430762383018}. Best is trial 24 with value: 5.836811332684268.
# [I 2026-06-09 06:46:48,349] Trial 46 finished with value: 5.8781972609425654 and parameters: {'n_estimators': 1302, 'learning_rate': 0.010917251627824807, 'max_depth': 1, 'min_child_weight': 4.043208219627279, 'gamma': 2.0481634636189128, 'subsample': 0.7282624742683338, 'colsample_bytree': 0.8522063390233394, 'reg_alpha': 0.011556670884244209, 'reg_lambda': 8.487866103724427}. Best is trial 24 with value: 5.836811332684268.
# [I 2026-06-09 06:47:20,376] Trial 47 pruned.
# [I 2026-06-09 06:47:40,826] Trial 48 finished with value: 5.815581007640123 and parameters: {'n_estimators': 973, 'learning_rate': 0.028742455863609663, 'max_depth': 1, 'min_child_weight': 11.919714039496561, 'gamma': 4.052740806196026, 'subsample': 0.7683204298514722, 'colsample_bytree': 0.9634072066965035, 'reg_alpha': 0.02468182401126555, 'reg_lambda': 2.2866102112670377}. Best is trial 48 with value: 5.815581007640123.
# [I 2026-06-09 06:47:49,437] Trial 49 pruned.
# [I 2026-06-09 06:48:07,114] Trial 50 pruned.
# [I 2026-06-09 06:48:26,009] Trial 51 finished with value: 5.865695688964644 and parameters: {'n_estimators': 1023, 'learning_rate': 0.02377812626288755, 'max_depth': 2, 'min_child_weight': 7.539399511405621, 'gamma': 4.599393208343466, 'subsample': 0.7649726081196725, 'colsample_bytree': 0.9610028204003832, 'reg_alpha': 0.03231908433188818, 'reg_lambda': 1.0077232622250112}. Best is trial 48 with value: 5.815581007640123.
# [I 2026-06-09 06:48:39,812] Trial 52 pruned.
# [I 2026-06-09 06:48:57,804] Trial 53 finished with value: 5.8486747983748 and parameters: {'n_estimators': 1255, 'learning_rate': 0.03018602197597646, 'max_depth': 2, 'min_child_weight': 5.5279698453742, 'gamma': 4.100970426738642, 'subsample': 0.6946378355634278, 'colsample_bytree': 0.9764101555110863, 'reg_alpha': 0.11324464621525407, 'reg_lambda': 1.7978214738787606}. Best is trial 48 with value: 5.815581007640123.
# [I 2026-06-09 06:49:08,186] Trial 54 pruned.
# [I 2026-06-09 06:49:44,549] Trial 55 finished with value: 5.8359391403787475 and parameters: {'n_estimators': 901, 'learning_rate': 0.009521905838350138, 'max_depth': 2, 'min_child_weight': 8.266404778899927, 'gamma': 2.2538945985062644, 'subsample': 0.7328474215990028, 'colsample_bytree': 0.9589996033481609, 'reg_alpha': 0.12087027362570643, 'reg_lambda': 0.35976761159758924}. Best is trial 48 with value: 5.815581007640123.
# [I 2026-06-09 06:50:11,309] Trial 56 pruned.
# [I 2026-06-09 06:50:31,142] Trial 57 pruned.
# [I 2026-06-09 06:51:02,152] Trial 58 finished with value: 5.853660219047414 and parameters: {'n_estimators': 1400, 'learning_rate': 0.009714060335559544, 'max_depth': 2, 'min_child_weight': 15.883071574428751, 'gamma': 1.4818623512811075, 'subsample': 0.91772253954707, 'colsample_bytree': 0.936988376498738, 'reg_alpha': 0.006464043244628087, 'reg_lambda': 0.11621692467811046}. Best is trial 48 with value: 5.815581007640123.
# [I 2026-06-09 06:52:00,669] Trial 59 pruned.
# [I 2026-06-09 06:52:21,475] Trial 60 pruned.
# [I 2026-06-09 06:52:31,517] Trial 61 finished with value: 5.849150127982034 and parameters: {'n_estimators': 1171, 'learning_rate': 0.020669979711871407, 'max_depth': 2, 'min_child_weight': 4.068898747865883, 'gamma': 0.35620043992159367, 'subsample': 0.7437940371788777, 'colsample_bytree': 0.9285665273182307, 'reg_alpha': 0.032342632057621064, 'reg_lambda': 0.6532089475958787}. Best is trial 48 with value: 5.815581007640123.
# [I 2026-06-09 06:52:43,134] Trial 62 finished with value: 5.84727908371201 and parameters: {'n_estimators': 864, 'learning_rate': 0.026667391111839744, 'max_depth': 2, 'min_child_weight': 0.9207569947511771, 'gamma': 2.6494013899073834, 'subsample': 0.7683971062494462, 'colsample_bytree': 0.9642278750578019, 'reg_alpha': 0.01544532920845642, 'reg_lambda': 1.2650474025828327}. Best is trial 48 with value: 5.815581007640123.
# [I 2026-06-09 06:52:51,806] Trial 63 pruned.
# [I 2026-06-09 06:53:10,375] Trial 64 finished with value: 5.857913956119976 and parameters: {'n_estimators': 646, 'learning_rate': 0.02637462301813311, 'max_depth': 1, 'min_child_weight': 0.21748966359451596, 'gamma': 2.5569983320708407, 'subsample': 0.6998370528596047, 'colsample_bytree': 0.9985417173464862, 'reg_alpha': 0.01462397537302841, 'reg_lambda': 2.9486274079324954}. Best is trial 48 with value: 5.815581007640123.
# [I 2026-06-09 06:53:14,490] Trial 65 pruned.
# [I 2026-06-09 06:53:26,270] Trial 66 pruned.
# [I 2026-06-09 06:53:49,384] Trial 67 pruned.
# [I 2026-06-09 06:53:59,022] Trial 68 finished with value: 5.832394148593758 and parameters: {'n_estimators': 1070, 'learning_rate': 0.05785298767196287, 'max_depth': 1, 'min_child_weight': 0.9154808728574813, 'gamma': 1.8884808032525164, 'subsample': 0.8530223118176954, 'colsample_bytree': 0.9845994845667927, 'reg_alpha': 0.47382898360736253, 'reg_lambda': 0.9953411917954862}. Best is trial 48 with value: 5.815581007640123.
# [I 2026-06-09 06:54:20,113] Trial 69 pruned.
# [I 2026-06-09 06:54:29,351] Trial 70 finished with value: 5.803440385695486 and parameters: {'n_estimators': 1371, 'learning_rate': 0.07160268622595946, 'max_depth': 1, 'min_child_weight': 0.4594786749717172, 'gamma': 1.9323249282878563, 'subsample': 0.8568445503563659, 'colsample_bytree': 0.9017955685215417, 'reg_alpha': 1.1708102321479141, 'reg_lambda': 0.17625033876916016}. Best is trial 70 with value: 5.803440385695486.
# [I 2026-06-09 06:54:38,735] Trial 71 finished with value: 5.835490235652271 and parameters: {'n_estimators': 1362, 'learning_rate': 0.06968562787948823, 'max_depth': 1, 'min_child_weight': 0.44063717718727946, 'gamma': 1.9117574560751263, 'subsample': 0.9603571047241954, 'colsample_bytree': 0.9000466909291739, 'reg_alpha': 5.469407459513865, 'reg_lambda': 0.18832931264371697}. Best is trial 70 with value: 5.803440385695486.
# [I 2026-06-09 06:54:46,603] Trial 72 finished with value: 5.8410573494877465 and parameters: {'n_estimators': 1355, 'learning_rate': 0.06759308411815602, 'max_depth': 1, 'min_child_weight': 0.2701560323767074, 'gamma': 1.9158748683537559, 'subsample': 0.9566980017161362, 'colsample_bytree': 0.8955411212445594, 'reg_alpha': 6.184430161455857, 'reg_lambda': 0.18997018181856593}. Best is trial 70 with value: 5.803440385695486.
# [I 2026-06-09 06:54:54,155] Trial 73 finished with value: 5.831602415002091 and parameters: {'n_estimators': 1386, 'learning_rate': 0.07190299047613562, 'max_depth': 1, 'min_child_weight': 0.2751807994373172, 'gamma': 1.912821321214383, 'subsample': 0.976783576818544, 'colsample_bytree': 0.8767050441064309, 'reg_alpha': 6.870004641105209, 'reg_lambda': 0.20269789736098995}. Best is trial 70 with value: 5.803440385695486.
# [I 2026-06-09 06:55:04,440] Trial 74 finished with value: 5.858908503588344 and parameters: {'n_estimators': 1642, 'learning_rate': 0.07730594719308993, 'max_depth': 1, 'min_child_weight': 0.28573387706587466, 'gamma': 1.8553404054194393, 'subsample': 0.96908443909389, 'colsample_bytree': 0.8979278373695173, 'reg_alpha': 5.622615930843863, 'reg_lambda': 0.1995365322365063}. Best is trial 70 with value: 5.803440385695486.
# [I 2026-06-09 06:55:14,828] Trial 75 finished with value: 5.866683124878268 and parameters: {'n_estimators': 1522, 'learning_rate': 0.0646769334098821, 'max_depth': 1, 'min_child_weight': 0.2582010258592311, 'gamma': 2.1452545555212086, 'subsample': 0.9939825416618184, 'colsample_bytree': 0.884674096802411, 'reg_alpha': 5.92288126769007, 'reg_lambda': 0.058343052955933054}. Best is trial 70 with value: 5.803440385695486.
# [I 2026-06-09 06:55:19,287] Trial 76 pruned.
# [I 2026-06-09 06:55:27,770] Trial 77 finished with value: 5.864517517872229 and parameters: {'n_estimators': 1690, 'learning_rate': 0.0594140623363697, 'max_depth': 1, 'min_child_weight': 0.4099661203974365, 'gamma': 2.001511481602565, 'subsample': 0.9380375810745768, 'colsample_bytree': 0.9134814573741785, 'reg_alpha': 1.3061144087325092, 'reg_lambda': 0.139066269452358}. Best is trial 70 with value: 5.803440385695486.
# [I 2026-06-09 06:55:36,681] Trial 78 finished with value: 5.833077272509317 and parameters: {'n_estimators': 1362, 'learning_rate': 0.0794333059861588, 'max_depth': 1, 'min_child_weight': 0.14985731805655686, 'gamma': 2.428994223337953, 'subsample': 0.9187427347367177, 'colsample_bytree': 0.8340575877458759, 'reg_alpha': 8.927475537521806, 'reg_lambda': 0.30146353598318704}. Best is trial 70 with value: 5.803440385695486.
# [I 2026-06-09 06:55:39,761] Trial 79 pruned.
# [I 2026-06-09 06:55:41,605] Trial 80 pruned.
# [I 2026-06-09 06:55:47,485] Trial 81 finished with value: 5.858126206649983 and parameters: {'n_estimators': 1315, 'learning_rate': 0.06983128380412511, 'max_depth': 1, 'min_child_weight': 0.2681114145175739, 'gamma': 1.7869613590629858, 'subsample': 0.9043472335401898, 'colsample_bytree': 0.8932564990719761, 'reg_alpha': 8.60529457889025, 'reg_lambda': 0.22898951621184047}. Best is trial 70 with value: 5.803440385695486.
# [I 2026-06-09 06:55:56,562] Trial 82 finished with value: 5.845266089757052 and parameters: {'n_estimators': 1468, 'learning_rate': 0.10780215471259501, 'max_depth': 1, 'min_child_weight': 0.17936614395858005, 'gamma': 1.6710285207431008, 'subsample': 0.9269837307089306, 'colsample_bytree': 0.8766152819917346, 'reg_alpha': 4.657597325332828, 'reg_lambda': 0.3675961747244873}. Best is trial 70 with value: 5.803440385695486.
# [I 2026-06-09 06:56:05,590] Trial 83 finished with value: 5.86097977039427 and parameters: {'n_estimators': 1365, 'learning_rate': 0.08124559981084922, 'max_depth': 1, 'min_child_weight': 0.6840161719252228, 'gamma': 1.9737324904914129, 'subsample': 0.943641015527771, 'colsample_bytree': 0.8382279574604523, 'reg_alpha': 0.955140616711769, 'reg_lambda': 0.16382883872454845}. Best is trial 70 with value: 5.803440385695486.
# [I 2026-06-09 06:56:15,642] Trial 84 finished with value: 5.839977596556007 and parameters: {'n_estimators': 1450, 'learning_rate': 0.09345367621826464, 'max_depth': 1, 'min_child_weight': 0.3130113249186609, 'gamma': 2.376568083000288, 'subsample': 0.9576720175706144, 'colsample_bytree': 0.9248475378205326, 'reg_alpha': 9.015001507293416, 'reg_lambda': 0.28211402694777277}. Best is trial 70 with value: 5.803440385695486.
# [I 2026-06-09 06:56:19,744] Trial 85 pruned.
# [I 2026-06-09 06:56:24,263] Trial 86 pruned.
# [I 2026-06-09 06:56:29,158] Trial 87 pruned.
# [I 2026-06-09 06:56:35,922] Trial 88 pruned.
# [I 2026-06-09 06:56:44,000] Trial 89 finished with value: 5.856258145428069 and parameters: {'n_estimators': 1005, 'learning_rate': 0.051139476507699136, 'max_depth': 1, 'min_child_weight': 0.5134157482667042, 'gamma': 1.2358117829058526, 'subsample': 0.9305511744918112, 'colsample_bytree': 0.8066160704313189, 'reg_alpha': 1.1533994425091418, 'reg_lambda': 0.057512215714488446}. Best is trial 70 with value: 5.803440385695486.
# [I 2026-06-09 06:56:46,330] Trial 90 pruned.
# [I 2026-06-09 06:56:54,300] Trial 91 finished with value: 5.886734574415016 and parameters: {'n_estimators': 1367, 'learning_rate': 0.0733655936977255, 'max_depth': 1, 'min_child_weight': 0.181829768807654, 'gamma': 1.9017039986322706, 'subsample': 0.9532959360719294, 'colsample_bytree': 0.9207757131593695, 'reg_alpha': 6.114523552901746, 'reg_lambda': 0.17025581773217274}. Best is trial 70 with value: 5.803440385695486.
# [I 2026-06-09 06:57:01,828] Trial 92 finished with value: 5.8494128324753065 and parameters: {'n_estimators': 1500, 'learning_rate': 0.06410946561561837, 'max_depth': 1, 'min_child_weight': 0.23844979230758834, 'gamma': 2.0942940453975183, 'subsample': 0.9670017586172371, 'colsample_bytree': 0.9007741627791005, 'reg_alpha': 5.591415245290688, 'reg_lambda': 0.24857781563339493}. Best is trial 70 with value: 5.803440385695486.
# [I 2026-06-09 06:57:06,245] Trial 93 finished with value: 5.840035430090496 and parameters: {'n_estimators': 1330, 'learning_rate': 0.08637787129706731, 'max_depth': 1, 'min_child_weight': 0.32037958904490904, 'gamma': 2.290740112277635, 'subsample': 0.9126772437895647, 'colsample_bytree': 0.9508866744094742, 'reg_alpha': 3.0420650716606064, 'reg_lambda': 0.14612847448662594}. Best is trial 70 with value: 5.803440385695486.
# [I 2026-06-09 06:57:15,214] Trial 94 finished with value: 5.867664457069727 and parameters: {'n_estimators': 1315, 'learning_rate': 0.0850892647789661, 'max_depth': 1, 'min_child_weight': 0.3055688608410924, 'gamma': 2.231888786152939, 'subsample': 0.880393226142782, 'colsample_bytree': 0.9520520915945179, 'reg_alpha': 3.615099584989205, 'reg_lambda': 0.09720999513421152}. Best is trial 70 with value: 5.803440385695486.
# [I 2026-06-09 06:57:18,339] Trial 95 pruned.
# [I 2026-06-09 06:57:24,362] Trial 96 pruned.
# [I 2026-06-09 06:57:27,980] Trial 97 pruned.
# [I 2026-06-09 06:57:34,520] Trial 98 finished with value: 5.838820392389728 and parameters: {'n_estimators': 1223, 'learning_rate': 0.04062577213389002, 'max_depth': 1, 'min_child_weight': 0.20294630496709198, 'gamma': 2.4084542420826183, 'subsample': 0.9892057830735355, 'colsample_bytree': 0.9720680837001376, 'reg_alpha': 1.2226102316754701e-08, 'reg_lambda': 0.30303340342756224}. Best is trial 70 with value: 5.803440385695486.
# [I 2026-06-09 06:57:37,077] Trial 99 pruned.
# [I 2026-06-09 06:57:37,079] A new study created in memory with name: no-name-181c0ab0-d054-4d95-b72e-fc73c9b91000
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 06:57:49,152] Trial 0 finished with value: 5.956077289559314 and parameters: {'n_estimators': 301, 'learning_rate': 0.03250177171527344, 'num_leaves': 37, 'max_depth': 4, 'min_child_samples': 52, 'min_split_gain': 1.7182749818971954, 'bagging_fraction': 0.8330451065490129, 'bagging_freq': 4, 'feature_fraction': 0.5145069122121801, 'lambda_l1': 0.04015454105555427, 'lambda_l2': 0.07175601133819473}. Best is trial 0 with value: 5.956077289559314.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 06:58:59,641] Trial 1 finished with value: 6.110043962052431 and parameters: {'n_estimators': 1620, 'learning_rate': 0.008116618171663207, 'num_leaves': 18, 'max_depth': 9, 'min_child_samples': 37, 'min_split_gain': 0.8099788960945193, 'bagging_fraction': 0.6580482355091044, 'bagging_freq': 1, 'feature_fraction': 0.9216123471148523, 'lambda_l1': 0.43697071238567825, 'lambda_l2': 36.7185332724254}. Best is trial 0 with value: 5.956077289559314.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 06:59:12,829] Trial 2 finished with value: 6.094214845777975 and parameters: {'n_estimators': 820, 'learning_rate': 0.1255359023925396, 'num_leaves': 116, 'max_depth': 8, 'min_child_samples': 17, 'min_split_gain': 1.7941971599630686, 'bagging_fraction': 0.6490017503443813, 'bagging_freq': 2, 'feature_fraction': 0.5025647745322285, 'lambda_l1': 0.0007741455782248723, 'lambda_l2': 0.1717169091593679}. Best is trial 0 with value: 5.956077289559314.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 06:59:18,564] Trial 3 finished with value: 6.288356707334476 and parameters: {'n_estimators': 1302, 'learning_rate': 0.13774020868800516, 'num_leaves': 233, 'max_depth': 10, 'min_child_samples': 81, 'min_split_gain': 0.2080378997095258, 'bagging_fraction': 0.5904572976289505, 'bagging_freq': 7, 'feature_fraction': 0.7059764916931793, 'lambda_l1': 0.6097531961875766, 'lambda_l2': 1.4405915859050216}. Best is trial 0 with value: 5.956077289559314.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 06:59:47,926] Trial 4 finished with value: 5.986158603239042 and parameters: {'n_estimators': 1287, 'learning_rate': 0.008816320113501107, 'num_leaves': 230, 'max_depth': 3, 'min_child_samples': 64, 'min_split_gain': 1.987144984788207, 'bagging_fraction': 0.8678635407535604, 'bagging_freq': 4, 'feature_fraction': 0.7803315847218675, 'lambda_l1': 5.026890229380336e-05, 'lambda_l2': 2.6067223030440956}. Best is trial 0 with value: 5.956077289559314.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 06:59:53,176] Trial 5 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 06:59:57,154] Trial 6 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 06:59:58,663] Trial 7 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 06:59:59,519] Trial 8 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:00:10,454] Trial 9 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:00:47,088] Trial 10 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:01:07,906] Trial 11 finished with value: 5.986619612556273 and parameters: {'n_estimators': 465, 'learning_rate': 0.01572007574080421, 'num_leaves': 176, 'max_depth': 4, 'min_child_samples': 57, 'min_split_gain': 1.5887482987449109, 'bagging_fraction': 0.8036505404654823, 'bagging_freq': 4, 'feature_fraction': 0.7709976650516075, 'lambda_l1': 0.00010294390889708499, 'lambda_l2': 3.119464104210885}. Best is trial 0 with value: 5.956077289559314.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:01:14,119] Trial 12 finished with value: 5.832161138629952 and parameters: {'n_estimators': 564, 'learning_rate': 0.04243655135252123, 'num_leaves': 157, 'max_depth': 2, 'min_child_samples': 10, 'min_split_gain': 1.9861349475524857, 'bagging_fraction': 0.7841069688382478, 'bagging_freq': 5, 'feature_fraction': 0.8027121280151075, 'lambda_l1': 0.013016801452870026, 'lambda_l2': 0.009217121367599503}. Best is trial 12 with value: 5.832161138629952.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:01:20,841] Trial 13 finished with value: 5.86349790787148 and parameters: {'n_estimators': 494, 'learning_rate': 0.04968247089400717, 'num_leaves': 145, 'max_depth': 2, 'min_child_samples': 18, 'min_split_gain': 1.2104408428825577, 'bagging_fraction': 0.747067677640309, 'bagging_freq': 5, 'feature_fraction': 0.990226763080333, 'lambda_l1': 0.021359736221392457, 'lambda_l2': 0.006527742842111132}. Best is trial 12 with value: 5.832161138629952.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:01:27,674] Trial 14 finished with value: 5.876797315745466 and parameters: {'n_estimators': 639, 'learning_rate': 0.05676996504686777, 'num_leaves': 149, 'max_depth': 2, 'min_child_samples': 5, 'min_split_gain': 1.1526647845049771, 'bagging_fraction': 0.757145141539498, 'bagging_freq': 5, 'feature_fraction': 0.9942017414936116, 'lambda_l1': 0.006922125739820067, 'lambda_l2': 0.0032972664368709015}. Best is trial 12 with value: 5.832161138629952.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:01:32,351] Trial 15 finished with value: 5.907362636313833 and parameters: {'n_estimators': 589, 'learning_rate': 0.06702118222456788, 'num_leaves': 183, 'max_depth': 2, 'min_child_samples': 28, 'min_split_gain': 1.2044805131398284, 'bagging_fraction': 0.7360083450660551, 'bagging_freq': 6, 'feature_fraction': 0.8325490225165961, 'lambda_l1': 0.08938086113505234, 'lambda_l2': 0.008448555809633893}. Best is trial 12 with value: 5.832161138629952.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:01:42,585] Trial 16 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:01:45,536] Trial 17 finished with value: 5.949194043809603 and parameters: {'n_estimators': 772, 'learning_rate': 0.07391886605004405, 'num_leaves': 151, 'max_depth': 3, 'min_child_samples': 26, 'min_split_gain': 0.01097276481777576, 'bagging_fraction': 0.725139024399724, 'bagging_freq': 5, 'feature_fraction': 0.747532345621363, 'lambda_l1': 7.939915648532848, 'lambda_l2': 0.00109490926375827}. Best is trial 12 with value: 5.832161138629952.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:01:50,726] Trial 18 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:01:57,251] Trial 19 finished with value: 5.861099452117447 and parameters: {'n_estimators': 495, 'learning_rate': 0.021519986264343805, 'num_leaves': 150, 'max_depth': 3, 'min_child_samples': 18, 'min_split_gain': 0.7796656940114906, 'bagging_fraction': 0.7902523386738332, 'bagging_freq': 5, 'feature_fraction': 0.6689397065496052, 'lambda_l1': 0.0010577426968172699, 'lambda_l2': 0.005345524983233015}. Best is trial 12 with value: 5.832161138629952.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:02:07,082] Trial 20 finished with value: 5.903726893520721 and parameters: {'n_estimators': 265, 'learning_rate': 0.025095278961467828, 'num_leaves': 75, 'max_depth': 3, 'min_child_samples': 39, 'min_split_gain': 0.7023398323210867, 'bagging_fraction': 0.7986251003469402, 'bagging_freq': 3, 'feature_fraction': 0.6527972762117497, 'lambda_l1': 0.0006484600812816075, 'lambda_l2': 0.0379248606345411}. Best is trial 12 with value: 5.832161138629952.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:02:17,919] Trial 21 finished with value: 5.8571535597894115 and parameters: {'n_estimators': 544, 'learning_rate': 0.01781319697315849, 'num_leaves': 147, 'max_depth': 2, 'min_child_samples': 20, 'min_split_gain': 0.9405936960951551, 'bagging_fraction': 0.6983347971237, 'bagging_freq': 5, 'feature_fraction': 0.5878540024025516, 'lambda_l1': 0.010731132476481891, 'lambda_l2': 0.0034106631337855148}. Best is trial 12 with value: 5.832161138629952.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:02:38,844] Trial 22 finished with value: 5.882356322913912 and parameters: {'n_estimators': 709, 'learning_rate': 0.01027874343383628, 'num_leaves': 165, 'max_depth': 3, 'min_child_samples': 19, 'min_split_gain': 0.9403708193979852, 'bagging_fraction': 0.6599933417610679, 'bagging_freq': 6, 'feature_fraction': 0.5969184648901151, 'lambda_l1': 0.002720511854897822, 'lambda_l2': 0.003237923533626483}. Best is trial 12 with value: 5.832161138629952.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:02:54,573] Trial 23 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:03:02,806] Trial 24 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:03:12,258] Trial 25 finished with value: 5.8871904630476015 and parameters: {'n_estimators': 352, 'learning_rate': 0.0285671337802902, 'num_leaves': 133, 'max_depth': 3, 'min_child_samples': 16, 'min_split_gain': 0.708716312892633, 'bagging_fraction': 0.6960096658128028, 'bagging_freq': 5, 'feature_fraction': 0.5976380609160533, 'lambda_l1': 0.00032036542128188614, 'lambda_l2': 0.0018395194965803864}. Best is trial 12 with value: 5.832161138629952.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:03:21,908] Trial 26 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:03:25,925] Trial 27 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:03:27,274] Trial 28 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:03:43,079] Trial 29 finished with value: 5.930816854391456 and parameters: {'n_estimators': 370, 'learning_rate': 0.0278526711020611, 'num_leaves': 89, 'max_depth': 4, 'min_child_samples': 13, 'min_split_gain': 1.718298656008669, 'bagging_fraction': 0.7046126516725565, 'bagging_freq': 4, 'feature_fraction': 0.6679998414704373, 'lambda_l1': 0.0026114256977927204, 'lambda_l2': 0.0416388490209766}. Best is trial 12 with value: 5.832161138629952.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:03:48,470] Trial 30 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:03:51,107] Trial 31 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:03:57,672] Trial 32 finished with value: 5.902710820147323 and parameters: {'n_estimators': 534, 'learning_rate': 0.038957276477345947, 'num_leaves': 254, 'max_depth': 2, 'min_child_samples': 33, 'min_split_gain': 1.2999799061753092, 'bagging_fraction': 0.7410186391925889, 'bagging_freq': 4, 'feature_fraction': 0.9418853532241817, 'lambda_l1': 0.1185380813443909, 'lambda_l2': 0.0022786063295185646}. Best is trial 12 with value: 5.832161138629952.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:04:05,229] Trial 33 finished with value: 5.901737747603665 and parameters: {'n_estimators': 426, 'learning_rate': 0.05865531552176375, 'num_leaves': 167, 'max_depth': 3, 'min_child_samples': 18, 'min_split_gain': 1.0790749697601985, 'bagging_fraction': 0.6380900512698713, 'bagging_freq': 1, 'feature_fraction': 0.9001153747089319, 'lambda_l1': 0.002497623007189759, 'lambda_l2': 0.014982975225681467}. Best is trial 12 with value: 5.832161138629952.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:04:11,924] Trial 34 finished with value: 5.86006045127275 and parameters: {'n_estimators': 225, 'learning_rate': 0.02447570944494794, 'num_leaves': 140, 'max_depth': 2, 'min_child_samples': 10, 'min_split_gain': 0.8488246964356849, 'bagging_fraction': 0.6694429729788676, 'bagging_freq': 5, 'feature_fraction': 0.5025062144896069, 'lambda_l1': 0.000262581937337142, 'lambda_l2': 0.007019585689331501}. Best is trial 12 with value: 5.832161138629952.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:04:21,914] Trial 35 finished with value: 5.853580251693131 and parameters: {'n_estimators': 214, 'learning_rate': 0.02203261882594307, 'num_leaves': 115, 'max_depth': 3, 'min_child_samples': 10, 'min_split_gain': 0.5797969472704154, 'bagging_fraction': 0.6662466830225899, 'bagging_freq': 5, 'feature_fraction': 0.505848287386816, 'lambda_l1': 0.00022753010803274625, 'lambda_l2': 0.02834675522695358}. Best is trial 12 with value: 5.832161138629952.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:04:25,784] Trial 36 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:04:31,899] Trial 37 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:04:33,530] Trial 38 pruned.
# ...
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
#                   period       method  count     mae_f    rmse_f
# 0   validation_2024_2025      xgboost    660  5.333859  6.998391
# 1   validation_2024_2025     lightgbm    660  4.325619  6.310665
# 2   validation_2024_2025     catboost    660  3.922394  5.890335
# 3   validation_2024_2025     hrrr_raw    660  4.139337  5.917629
# 4   validation_2024_2025      gfs_raw    660  4.616216  6.792032
# 5              test_2026      xgboost    137  4.379572  5.566353
# 6              test_2026     lightgbm    137  4.917326  6.183180
# 7              test_2026     catboost    137  4.901789  6.095673
# 8              test_2026  ridge_stack    137  4.504005  5.619942
# 9              test_2026     hrrr_raw    137  3.486340  4.885076
# 10             test_2026      gfs_raw    137  3.656254  4.990693

# %% [markdown]
# ## Rounded Within 1F Accuracy

# %%
preds = pd.concat(
    [
        result.validation_predictions.assign(period="validation_2024_2025"),
        result.test_predictions.assign(period="test_2026"),
    ],
    ignore_index=True,
)

predicted_high = pd.to_numeric(preds["predicted_high_f"], errors="coerce")
preds["predicted_high_rounded_f"] = np.floor(predicted_high + 0.5)
preds["within_1f_after_round"] = (
    pd.to_numeric(preds["actual_high_f"], errors="coerce") - preds["predicted_high_rounded_f"]
).abs().le(1)

within_1f_accuracy_by_period = (
    preds
    .dropna(subset=["actual_high_f", "predicted_high_rounded_f"])
    .groupby(["period", "method"], as_index=False)
    .agg(
        count=("within_1f_after_round", "size"),
        within_1f_count=("within_1f_after_round", "sum"),
        within_1f_accuracy_pct=("within_1f_after_round", lambda x: x.mean() * 100),
    )
    .sort_values(["period", "within_1f_accuracy_pct"], ascending=[True, False])
)

within_1f_accuracy_by_period
# Out:
#                   period       method  count  within_1f_count  \
# 2              test_2026     hrrr_raw    137               41
# 1              test_2026      gfs_raw    137               35
# 5              test_2026      xgboost    137               25
# 0              test_2026     catboost    137               24
# 3              test_2026     lightgbm    137               23
# 4              test_2026  ridge_stack    137               18
# 6   validation_2024_2025     catboost    660              225
# 9   validation_2024_2025     lightgbm    660              195
# 8   validation_2024_2025     hrrr_raw    660              167
# 7   validation_2024_2025      gfs_raw    660              166
# 10  validation_2024_2025      xgboost    660              134
#
#     within_1f_accuracy_pct
# 2                29.927007
# 1                25.547445
# 5                18.248175
# 0                17.518248
# 3                16.788321
# 4                13.138686
# 6                34.090909
# 9                29.545455
# 8                25.303030
# 7                25.151515
# 10               20.303030

# %% [markdown]
# ## Precipitation Feature Coverage

# %%
precip_columns = [column for column in result.features.columns if "precip" in column.lower()]
coverage = (
    result.features[precip_columns]
    .notna()
    .mean()
    .mul(100)
    .sort_values(ascending=False)
    .rename("coverage_pct")
    .reset_index()
    .rename(columns={"index": "feature"})
)
coverage
# Out:
#                                               feature  coverage_pct
# 0                     observed_precip_recent_at_as_of    100.000000
# 1                              v4_any_forecast_precip    100.000000
# 2                    v4_observed_precip_recent_mm_est    100.000000
# 3                              v4_all_forecast_precip    100.000000
# 4                   v4_forecast_observed_precip_match    100.000000
# 5                           observed_precip_intensity    100.000000
# 6                              v4_observed_precip_any    100.000000
# 7                      observed_precip_intensity_code    100.000000
# 8                     v4_forecast_precip_total_max_mm     99.745418
# 9                    v4_forecast_precip_total_mean_mm     99.745418
# 10                  v4_forecast_precip_intensity_mean     99.745418
# 11                   v4_forecast_precip_intensity_max     99.745418
# 12                 v4_forecast_precip_total_spread_mm     99.745418
# 13             v4_precip_remaining_warmup_interaction     99.745418
# 14                     v4_precip_humidity_interaction     99.745418
# 15                       gfs_forecast_precip_total_mm     96.079430
# 16                                  gfs_precip_amount     96.079430
# 17                            gfs_forecast_has_precip     96.079430
# 18                 gfs_forecast_precip_intensity_code     96.079430
# 19                      gfs_forecast_precip_intensity     96.079430
# 20                                 hrrr_precip_amount     95.417515
# 21                hrrr_forecast_precip_intensity_code     95.417515
# 22                     hrrr_forecast_precip_intensity     95.417515
# 23                      hrrr_forecast_precip_total_mm     95.417515
# 24                           hrrr_forecast_has_precip     95.417515
# 25  gfs_hrrr_forecast_precip_intensity_code_abs_di...     91.751527
# 26     gfs_hrrr_forecast_precip_intensity_code_diff_f     91.751527
# 27                      gfs_hrrr_precip_amount_diff_f     91.751527
# 28                  gfs_hrrr_precip_amount_abs_diff_f     91.751527
# 29       gfs_hrrr_forecast_precip_total_mm_abs_diff_f     91.751527
# 30           gfs_hrrr_forecast_precip_total_mm_diff_f     91.751527
# 31                      v4_forecast_precip_hours_mean      0.203666
# 32                  v4_forecast_precip_max_1h_mean_mm      0.203666
# 33                      gfs_forecast_precip_max_1h_mm      0.152749
# 34                    gfs_forecast_precip_hours_count      0.152749
# 35                   hrrr_forecast_precip_hours_count      0.152749
# 36                     hrrr_forecast_precip_max_1h_mm      0.152749
# 37    gfs_hrrr_forecast_precip_hours_count_abs_diff_f      0.101833
# 38        gfs_hrrr_forecast_precip_hours_count_diff_f      0.101833
# 39      gfs_hrrr_forecast_precip_max_1h_mm_abs_diff_f      0.101833
# 40          gfs_hrrr_forecast_precip_max_1h_mm_diff_f      0.101833

# %% [markdown]
# ## Version Comparison

# %%
comparison_frames = []
for version, folder in [
    ("v1", PROJECT_ROOT / "data" / "calibration" / "station_stacking"),
    ("v2", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v2"),
    ("v3", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v3"),
    ("v4", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v4"),
]:
    path = folder / f"{STATION_ID}_year_split_scoreboard.csv"
    if path.exists():
        frame = pd.read_csv(path)
        frame["version"] = version
        comparison_frames.append(frame)

version_comparison = pd.concat(comparison_frames, ignore_index=True) if comparison_frames else pd.DataFrame()
if not version_comparison.empty:
    version_comparison = version_comparison.sort_values(["period", "mae_f", "version", "method"]).reset_index(drop=True)
version_comparison
# Out:
#                   period       method  count     mae_f    rmse_f version
# 0              test_2026     hrrr_raw    137  3.486340  4.885076      v2
# 1              test_2026     hrrr_raw    137  3.486340  4.885076      v3
# 2              test_2026     hrrr_raw    137  3.486340  4.885076      v4
# 3              test_2026      gfs_raw    137  3.656254  4.990693      v2
# 4              test_2026      gfs_raw    137  3.656254  4.990693      v3
# 5              test_2026      gfs_raw    137  3.656254  4.990693      v4
# 6              test_2026     catboost    137  3.968941  5.149760      v3
# 7              test_2026      gfs_raw    102  3.971651  5.397913      v1
# 8              test_2026     catboost    137  4.006909  5.113676      v2
# 9              test_2026     hrrr_raw    102  4.018587  5.456511      v1
# 10             test_2026  ridge_stack    137  4.096248  5.201524      v3
# 11             test_2026  ridge_stack    137  4.202218  5.271690      v2
# 12             test_2026      xgboost    137  4.218668  5.297317      v2
# 13             test_2026      xgboost    137  4.274583  5.363051      v3
# 14             test_2026     lightgbm    137  4.370841  5.506246      v3
# 15             test_2026      xgboost    137  4.379572  5.566353      v4
# 16             test_2026  ridge_stack    137  4.504005  5.619942      v4
# 17             test_2026     lightgbm    137  4.641082  5.802545      v2
# 18             test_2026  ridge_stack    102  4.757982  5.916183      v1
# 19             test_2026     catboost    137  4.901789  6.095673      v4
# 20             test_2026     lightgbm    137  4.917326  6.183180      v4
# 21             test_2026     catboost    102  5.190067  6.391611      v1
# 22             test_2026      xgboost    102  5.261474  6.365847      v1
# 23             test_2026     lightgbm    102  5.333900  6.680975      v1
# 24  validation_2024_2025     catboost    660  3.791782  5.734047      v3
# 25  validation_2024_2025     catboost    660  3.821433  5.761305      v2
# 26  validation_2024_2025     lightgbm    660  3.865543  5.929835      v3
# 27  validation_2024_2025     lightgbm    660  3.880778  5.874299      v2
# 28  validation_2024_2025      xgboost    660  3.884542  5.842583      v2
# 29  validation_2024_2025     catboost    660  3.922394  5.890335      v4
# 30  validation_2024_2025     hrrr_raw    660  4.139337  5.917629      v2
# 31  validation_2024_2025     hrrr_raw    660  4.139337  5.917629      v3
# 32  validation_2024_2025     hrrr_raw    660  4.139337  5.917629      v4
# 33  validation_2024_2025      xgboost    596  4.190077  6.266381      v1
# 34  validation_2024_2025      xgboost    660  4.208539  6.019106      v3
# 35  validation_2024_2025     catboost    596  4.225242  6.192952      v1
# 36  validation_2024_2025     lightgbm    660  4.325619  6.310665      v4
# 37  validation_2024_2025     hrrr_raw    596  4.342980  6.152263      v1
# 38  validation_2024_2025     lightgbm    596  4.558466  6.724134      v1
# 39  validation_2024_2025      gfs_raw    660  4.616216  6.792032      v2
# 40  validation_2024_2025      gfs_raw    660  4.616216  6.792032      v3
# 41  validation_2024_2025      gfs_raw    660  4.616216  6.792032      v4
# 42  validation_2024_2025      gfs_raw    596  4.846561  7.070391      v1
# 43  validation_2024_2025      xgboost    660  5.333859  6.998391      v4

# %% [markdown]
# ## 2026 Weather Brackets

# %%
result.bracket_metrics
# Out:
#         method  count     mae_f    rmse_f  bracket_accuracy_pct
# 0      xgboost    137  4.379572  5.566353             12.408759
# 1     lightgbm    137  4.917326  6.183180             10.948905
# 2     catboost    137  4.901789  6.095673             11.678832
# 3  ridge_stack    137  4.504005  5.619942               7.29927
# 4     hrrr_raw    137  3.486340  4.885076             18.248175
# 5      gfs_raw    137  3.656254  4.990693             15.328467

# %%
import pandas as pd


def adjacent_brackets(bracket):
    if pd.isna(bracket):
        return []
    text = str(bracket).strip()
    if not text or "-" not in text:
        return []
    try:
        lower = int(text.split("-", 1)[0])
    except ValueError:
        return []
    return [
        f"{lower - 2}-{lower - 1}",
        f"{lower}-{lower + 1}",
        f"{lower + 2}-{lower + 3}",
    ]


bracket_3way = result.bracket_predictions.copy()

valid = bracket_3way["actual_bracket"].notna() & bracket_3way["predicted_bracket"].astype(str).str.strip().ne("")
bracket_3way = bracket_3way.loc[valid].copy()
bracket_3way["picked_brackets"] = bracket_3way["predicted_bracket"].map(adjacent_brackets)
bracket_3way["three_bracket_hit"] = bracket_3way.apply(
    lambda row: row["actual_bracket"] in row["picked_brackets"],
    axis=1,
)

three_bracket_accuracy = (
    bracket_3way
    .groupby("method", as_index=False)
    .agg(
        count=("three_bracket_hit", "size"),
        exact_bracket_accuracy_pct=("bracket_hit", lambda x: x.mean() * 100),
        three_bracket_accuracy_pct=("three_bracket_hit", lambda x: x.mean() * 100),
    )
    .sort_values("three_bracket_accuracy_pct", ascending=False)
)

three_bracket_accuracy
# Out:
#         method  count  exact_bracket_accuracy_pct  three_bracket_accuracy_pct
# 2     hrrr_raw    137                   18.248175                   54.014599
# 1      gfs_raw    137                   15.328467                   50.364964
# 5      xgboost    137                   12.408759                   41.605839
# 3     lightgbm    137                   10.948905                   36.496350
# 4  ridge_stack    137                     7.29927                   35.766423
# 0     catboost    137                   11.678832                   32.846715

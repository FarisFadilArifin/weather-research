# %% [markdown]
# # Station Stacking v4 - KMIA
#
# Wide HRRR/GFS same-day 11am notebook for `KMIA`.
#
# This version keeps the v3 high-so-far features and adds SDK-backed precipitation features from HRRR/GFS forecast precipitation plus 11 AM METAR precipitation codes. Artifacts are written to `data/calibration/station_stacking_v4`.

# %%
from pathlib import Path
import sys
import warnings

warnings.filterwarnings("ignore", message="IProgress not found.*")
warnings.filterwarnings("ignore", message="Skipping features without any observed values.*")

PROJECT_ROOT = Path.cwd().resolve()
while not (PROJECT_ROOT / "src" / "calibration" / "station_stacking.py").exists():
    if PROJECT_ROOT.parent == PROJECT_ROOT:
        raise RuntimeError("Could not find project root containing src/calibration/station_stacking.py")
    PROJECT_ROOT = PROJECT_ROOT.parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

STATION_ID = "KMIA"
FAST_MODE = False
OPTUNA_TRIALS = 100
STACK_OPTUNA_TRIALS = 50
OPTUNA_VERBOSE = True
PROJECT_ROOT
# Out:
# WindowsPath('D:/dev/weather-research')

# %%
from src.calibration.station_stacking import (
    StationStackingConfig,
    missing_model_dependencies,
    run_station_year_split_experiment,
)

# %% [markdown]
# ## V4 Feature Engineering
#
# Adds v2/v3 temperature features plus forecast and observed precipitation signals. Forecast precipitation comes from provider-prefixed SDK summary columns such as `gfs_forecast_precip_total_mm`, with `gfs_precip_amount` as a fallback for older caches.

# %%
import numpy as np
import pandas as pd
import src.calibration.station_stacking as station_stacking_module

V4_PROVIDERS = ("gfs", "hrrr")
V4_FEATURE_COLUMNS = [
    "v2_recent_heat_anomaly_f",
    "v2_recent_heat_momentum_f",
    "v2_morning_warmup_to_consensus_f",
    "v2_consensus_minus_7d_actual_f",
    "v2_spread_per_warmup_f",
    "v2_humidity_warmup_interaction",
    "v3_high_so_far_above_current_f",
    "v3_remaining_warmup_from_high_so_far_f",
    "v3_high_so_far_minus_lag_1d_f",
    "v3_high_so_far_minus_7d_actual_f",
    "v3_remaining_warmup_per_spread_f",
    "v3_humidity_remaining_warmup_interaction",
    "v4_forecast_precip_total_mean_mm",
    "v4_forecast_precip_total_max_mm",
    "v4_forecast_precip_total_spread_mm",
    "v4_forecast_precip_max_1h_mean_mm",
    "v4_forecast_precip_hours_mean",
    "v4_forecast_precip_intensity_mean",
    "v4_forecast_precip_intensity_max",
    "v4_any_forecast_precip",
    "v4_all_forecast_precip",
    "v4_observed_precip_any",
    "v4_observed_precip_recent_mm_est",
    "v4_forecast_total_minus_observed_recent_mm",
    "v4_forecast_observed_precip_match",
    "v4_forecast_wet_observed_dry",
    "v4_observed_wet_forecast_dry",
    "v4_precip_humidity_interaction",
    "v4_precip_remaining_warmup_interaction",
]


def _num(frame: pd.DataFrame, column: str) -> pd.Series:
    if column in frame:
        return pd.to_numeric(frame[column], errors="coerce")
    return pd.Series(np.nan, index=frame.index, dtype="float64")


def _bool_num(frame: pd.DataFrame, column: str) -> pd.Series:
    if column not in frame:
        return pd.Series(0, index=frame.index, dtype="int64")
    series = frame[column]
    if pd.api.types.is_bool_dtype(series):
        return series.fillna(False).astype(int)
    if pd.api.types.is_numeric_dtype(series):
        return pd.to_numeric(series, errors="coerce").fillna(0).gt(0).astype(int)
    return series.astype("string").str.lower().isin({"1", "true", "yes", "y"}).astype(int)


def _provider_series(frame: pd.DataFrame, provider: str, primary: str, fallback: str | None = None) -> pd.Series:
    primary_column = f"{provider}_{primary}"
    if primary_column in frame:
        return _num(frame, primary_column)
    if fallback is not None:
        return _num(frame, f"{provider}_{fallback}")
    return pd.Series(np.nan, index=frame.index, dtype="float64")


def _provider_matrix(frame: pd.DataFrame, primary: str, fallback: str | None = None) -> pd.DataFrame:
    return pd.DataFrame(
        {provider: _provider_series(frame, provider, primary, fallback) for provider in V4_PROVIDERS},
        index=frame.index,
    )


def add_v4_feature_engineering(frame: pd.DataFrame) -> pd.DataFrame:
    out = frame.copy()
    observed_temp = _num(out, "observed_temp_at_as_of_f")
    high_so_far = _num(out, "observed_high_temp_through_as_of_f")
    observed_humidity = _num(out, "observed_humidity_at_as_of")
    provider_mean = _num(out, "provider_mean_high_f")
    provider_spread = _num(out, "provider_spread_high_f")
    lag_1d = _num(out, "actual_high_lag_1d")
    roll_7d = _num(out, "actual_high_roll_7d_mean")
    roll_30d = _num(out, "actual_high_roll_30d_mean")

    warmup_to_consensus = provider_mean - observed_temp
    remaining_warmup = provider_mean - high_so_far
    out["v2_recent_heat_anomaly_f"] = lag_1d - roll_30d
    out["v2_recent_heat_momentum_f"] = roll_7d - roll_30d
    out["v2_morning_warmup_to_consensus_f"] = warmup_to_consensus
    out["v2_consensus_minus_7d_actual_f"] = provider_mean - roll_7d
    out["v2_spread_per_warmup_f"] = provider_spread / warmup_to_consensus.abs().clip(lower=1.0)
    out["v2_humidity_warmup_interaction"] = (observed_humidity / 100.0) * warmup_to_consensus
    out["v3_high_so_far_above_current_f"] = high_so_far - observed_temp
    out["v3_remaining_warmup_from_high_so_far_f"] = remaining_warmup
    out["v3_high_so_far_minus_lag_1d_f"] = high_so_far - lag_1d
    out["v3_high_so_far_minus_7d_actual_f"] = high_so_far - roll_7d
    out["v3_remaining_warmup_per_spread_f"] = remaining_warmup / provider_spread.abs().clip(lower=1.0)
    out["v3_humidity_remaining_warmup_interaction"] = (observed_humidity / 100.0) * remaining_warmup

    precip_total = _provider_matrix(out, "forecast_precip_total_mm", fallback="precip_amount")
    precip_max_1h = _provider_matrix(out, "forecast_precip_max_1h_mm")
    precip_hours = _provider_matrix(out, "forecast_precip_hours_count")
    precip_intensity = _provider_matrix(out, "forecast_precip_intensity_code")
    has_precip = _provider_matrix(out, "forecast_has_precip").fillna(0).clip(lower=0, upper=1)

    out["v4_forecast_precip_total_mean_mm"] = precip_total.mean(axis=1)
    out["v4_forecast_precip_total_max_mm"] = precip_total.max(axis=1)
    out["v4_forecast_precip_total_spread_mm"] = precip_total.max(axis=1) - precip_total.min(axis=1)
    out["v4_forecast_precip_max_1h_mean_mm"] = precip_max_1h.mean(axis=1)
    out["v4_forecast_precip_hours_mean"] = precip_hours.mean(axis=1)
    out["v4_forecast_precip_intensity_mean"] = precip_intensity.mean(axis=1)
    out["v4_forecast_precip_intensity_max"] = precip_intensity.max(axis=1)
    out["v4_any_forecast_precip"] = has_precip.max(axis=1).fillna(0).astype(int)
    out["v4_all_forecast_precip"] = has_precip.min(axis=1).fillna(0).astype(int)

    observed_any = (
        _bool_num(out, "observed_is_raining_at_as_of")
        | _bool_num(out, "observed_is_drizzle_at_as_of")
        | _bool_num(out, "observed_is_snowing_at_as_of")
    ).astype(int)
    observed_recent_mm = _num(out, "observed_precip_recent_at_as_of") * 25.4
    out["v4_observed_precip_any"] = observed_any
    out["v4_observed_precip_recent_mm_est"] = observed_recent_mm
    out["v4_forecast_total_minus_observed_recent_mm"] = out["v4_forecast_precip_total_mean_mm"] - observed_recent_mm
    out["v4_forecast_observed_precip_match"] = out["v4_any_forecast_precip"].eq(observed_any).astype(int)
    out["v4_forecast_wet_observed_dry"] = (out["v4_any_forecast_precip"].eq(1) & observed_any.eq(0)).astype(int)
    out["v4_observed_wet_forecast_dry"] = (observed_any.eq(1) & out["v4_any_forecast_precip"].eq(0)).astype(int)
    out["v4_precip_humidity_interaction"] = out["v4_forecast_precip_total_mean_mm"] * (observed_humidity / 100.0)
    out["v4_precip_remaining_warmup_interaction"] = out["v4_forecast_precip_total_mean_mm"] * remaining_warmup
    return out


if not hasattr(station_stacking_module, "_v4_original_build_station_wide_dataset"):
    station_stacking_module._v4_original_build_station_wide_dataset = station_stacking_module.build_station_wide_dataset


def build_station_wide_dataset_v4(*args, **kwargs):
    frame = station_stacking_module._v4_original_build_station_wide_dataset(*args, **kwargs)
    return add_v4_feature_engineering(frame)


station_stacking_module.build_station_wide_dataset = build_station_wide_dataset_v4
V4_FEATURE_COLUMNS
# Out:
# ['v2_recent_heat_anomaly_f',
#  'v2_recent_heat_momentum_f',
#  'v2_morning_warmup_to_consensus_f',
#  'v2_consensus_minus_7d_actual_f',
#  'v2_spread_per_warmup_f',
#  'v2_humidity_warmup_interaction',
#  'v3_high_so_far_above_current_f',
#  'v3_remaining_warmup_from_high_so_far_f',
#  'v3_high_so_far_minus_lag_1d_f',
#  'v3_high_so_far_minus_7d_actual_f',
#  'v3_remaining_warmup_per_spread_f',
#  'v3_humidity_remaining_warmup_interaction',
#  'v4_forecast_precip_total_mean_mm',
#  'v4_forecast_precip_total_max_mm',
#  'v4_forecast_precip_total_spread_mm',
#  'v4_forecast_precip_max_1h_mean_mm',
#  'v4_forecast_precip_hours_mean',
#  'v4_forecast_precip_intensity_mean',
#  'v4_forecast_precip_intensity_max',
#  'v4_any_forecast_precip',
#  'v4_all_forecast_precip',
#  'v4_observed_precip_any',
#  'v4_observed_precip_recent_mm_est',
#  'v4_forecast_total_minus_observed_recent_mm',
#  'v4_forecast_observed_precip_match',
#  'v4_forecast_wet_observed_dry',
#  'v4_observed_wet_forecast_dry',
#  'v4_precip_humidity_interaction',
#  'v4_precip_remaining_warmup_interaction']

# %% [markdown]
# ## Model Scores

# %%
missing_packages = missing_model_dependencies()
if missing_packages:
    raise ImportError(
        "Missing station-stacking ML packages: "
        + ", ".join(missing_packages)
        + ". Install them with: python -m pip install -r requirements.txt"
    )

config = StationStackingConfig(
    station_id=STATION_ID,
    project_root=PROJECT_ROOT,
    fast_mode=FAST_MODE,
    optuna_trials=OPTUNA_TRIALS,
    stack_optuna_trials=STACK_OPTUNA_TRIALS,
    optuna_verbose=OPTUNA_VERBOSE,
    output_dir=PROJECT_ROOT / "data" / "calibration" / "station_stacking_v4",
)
result = run_station_year_split_experiment(config)
result.scoreboard
# Out:
# [I 2026-06-09 06:29:33,362] A new study created in memory with name: no-name-8040302c-ec67-4455-9e77-a9fed07e3e78
# [I 2026-06-09 06:30:07,855] Trial 0 finished with value: 2.2823039125280813 and parameters: {'n_estimators': 799, 'learning_rate': 0.12369619597856178, 'max_depth': 6, 'min_child_weight': 2.385234757844707, 'gamma': 0.7800932022121826, 'subsample': 0.5779972601681014, 'colsample_bytree': 0.5290418060840998, 'reg_alpha': 0.6245760287469893, 'reg_lambda': 0.6677615511747083}. Best is trial 0 with value: 2.2823039125280813.
# [I 2026-06-09 06:33:35,499] Trial 1 finished with value: 2.1966952721956265 and parameters: {'n_estimators': 1440, 'learning_rate': 0.0032515743808034223, 'max_depth': 8, 'min_child_weight': 8.23143373099555, 'gamma': 1.0616955533913808, 'subsample': 0.5909124836035503, 'colsample_bytree': 0.5917022549267169, 'reg_alpha': 5.472429642032198e-06, 'reg_lambda': 0.2922905212920093}. Best is trial 1 with value: 2.1966952721956265.
# [I 2026-06-09 06:34:21,332] Trial 2 finished with value: 2.2892305154083576 and parameters: {'n_estimators': 909, 'learning_rate': 0.009373695213782608, 'max_depth': 5, 'min_child_weight': 0.20940138873937433, 'gamma': 1.4607232426760908, 'subsample': 0.6831809216468459, 'colsample_bytree': 0.728034992108518, 'reg_alpha': 0.1165691561324743, 'reg_lambda': 0.008674832802525461}. Best is trial 1 with value: 2.1966952721956265.
# [I 2026-06-09 06:34:47,890] Trial 3 finished with value: 2.167343918847394 and parameters: {'n_estimators': 1067, 'learning_rate': 0.03045200113778571, 'max_depth': 1, 'min_child_weight': 2.5002240473339543, 'gamma': 0.8526206184364576, 'subsample': 0.5325257964926398, 'colsample_bytree': 0.9744427686266666, 'reg_alpha': 4.905556676028774, 'reg_lambda': 6.289771819487036}. Best is trial 3 with value: 2.167343918847394.
# [I 2026-06-09 06:35:52,706] Trial 4 finished with value: 2.237685102210847 and parameters: {'n_estimators': 665, 'learning_rate': 0.004396056309201638, 'max_depth': 6, 'min_child_weight': 1.0299214204601976, 'gamma': 0.6101911742238941, 'subsample': 0.7475884550556351, 'colsample_bytree': 0.5171942605576092, 'reg_alpha': 1.527156759251193, 'reg_lambda': 0.016443693426189242}. Best is trial 3 with value: 2.167343918847394.
# [I 2026-06-09 06:36:27,848] Trial 5 pruned.
# [I 2026-06-09 06:36:35,319] Trial 6 finished with value: 2.2182941145751003 and parameters: {'n_estimators': 1228, 'learning_rate': 0.11049889315270257, 'max_depth': 1, 'min_child_weight': 0.28246357083904894, 'gamma': 0.22613644455269033, 'subsample': 0.6626651653816322, 'colsample_bytree': 0.6943386448447411, 'reg_alpha': 2.7678419414850017e-06, 'reg_lambda': 7.838134236608707}. Best is trial 3 with value: 2.167343918847394.
# [I 2026-06-09 06:36:49,061] Trial 7 pruned.
# [I 2026-06-09 06:36:54,891] Trial 8 pruned.
# [I 2026-06-09 06:37:33,778] Trial 9 finished with value: 2.2097859642706394 and parameters: {'n_estimators': 1277, 'learning_rate': 0.01094730135557207, 'max_depth': 1, 'min_child_weight': 0.5194929407101735, 'gamma': 1.6259166101337352, 'subsample': 0.864803089169032, 'colsample_bytree': 0.8187787356776066, 'reg_alpha': 0.9658611176861268, 'reg_lambda': 0.16554793541373172}. Best is trial 3 with value: 2.167343918847394.
# [I 2026-06-09 06:37:35,943] Trial 10 pruned.
# [I 2026-06-09 06:37:46,499] Trial 11 pruned.
# [I 2026-06-09 06:38:52,595] Trial 12 pruned.
# [I 2026-06-09 06:39:44,694] Trial 13 finished with value: 2.2400302457275103 and parameters: {'n_estimators': 1067, 'learning_rate': 0.022426968689597045, 'max_depth': 3, 'min_child_weight': 4.27533932135294, 'gamma': 0.022350197382312254, 'subsample': 0.6223441463224711, 'colsample_bytree': 0.8910368801788895, 'reg_alpha': 0.0005372302104189243, 'reg_lambda': 48.823076726100275}. Best is trial 3 with value: 2.167343918847394.
# [I 2026-06-09 06:39:57,677] Trial 14 pruned.
# [I 2026-06-09 06:41:13,083] Trial 15 finished with value: 2.178246952162109 and parameters: {'n_estimators': 1567, 'learning_rate': 0.0054302816952434725, 'max_depth': 2, 'min_child_weight': 1.442472624894894, 'gamma': 3.202139292383121, 'subsample': 0.5891074478961835, 'colsample_bytree': 0.7848102912411731, 'reg_alpha': 0.010836930382935862, 'reg_lambda': 2.8828636675558346}. Best is trial 3 with value: 2.167343918847394.
# [I 2026-06-09 06:41:20,342] Trial 16 pruned.
# [I 2026-06-09 06:42:32,757] Trial 17 finished with value: 2.185413703520006 and parameters: {'n_estimators': 1558, 'learning_rate': 0.005644185750726001, 'max_depth': 2, 'min_child_weight': 2.33892001832476, 'gamma': 3.4483721260588363, 'subsample': 0.6637452938214105, 'colsample_bytree': 0.9255905863021827, 'reg_alpha': 9.907160017111647, 'reg_lambda': 3.0958111805322592}. Best is trial 3 with value: 2.167343918847394.
# [I 2026-06-09 06:43:12,920] Trial 18 finished with value: 2.2083050252489405 and parameters: {'n_estimators': 992, 'learning_rate': 0.014997443341363473, 'max_depth': 2, 'min_child_weight': 0.10382308179385973, 'gamma': 1.9167984518661956, 'subsample': 0.578975650030028, 'colsample_bytree': 0.7995837608322627, 'reg_alpha': 0.00316852665621634, 'reg_lambda': 33.77607601070091}. Best is trial 3 with value: 2.167343918847394.
# [I 2026-06-09 06:43:25,001] Trial 19 pruned.
# [I 2026-06-09 06:43:31,760] Trial 20 pruned.
# [I 2026-06-09 06:44:32,557] Trial 21 finished with value: 2.184453605483955 and parameters: {'n_estimators': 1551, 'learning_rate': 0.0057418182371771044, 'max_depth': 2, 'min_child_weight': 1.9725447725514933, 'gamma': 3.3140245495226552, 'subsample': 0.65477426123904, 'colsample_bytree': 0.9395595089415656, 'reg_alpha': 4.445228114011411, 'reg_lambda': 3.774401339460363}. Best is trial 3 with value: 2.167343918847394.
# [I 2026-06-09 06:46:06,978] Trial 22 finished with value: 2.1790079245085554 and parameters: {'n_estimators': 1736, 'learning_rate': 0.006488866386340559, 'max_depth': 2, 'min_child_weight': 0.7177601113016634, 'gamma': 4.369944130106116, 'subsample': 0.6307599276432756, 'colsample_bytree': 0.9501085925609326, 'reg_alpha': 9.489175007246127, 'reg_lambda': 6.0158656086886895}. Best is trial 3 with value: 2.167343918847394.
# [I 2026-06-09 06:46:50,341] Trial 23 pruned.
# [I 2026-06-09 06:47:45,013] Trial 24 finished with value: 2.1802486088948094 and parameters: {'n_estimators': 1952, 'learning_rate': 0.0151520503566303, 'max_depth': 3, 'min_child_weight': 0.716082973444476, 'gamma': 4.234654575600331, 'subsample': 0.6292662751029876, 'colsample_bytree': 0.8597906537511614, 'reg_alpha': 0.38789665629995346, 'reg_lambda': 7.735305456428499}. Best is trial 3 with value: 2.167343918847394.
# [I 2026-06-09 06:49:16,658] Trial 25 finished with value: 2.208108015331427 and parameters: {'n_estimators': 1736, 'learning_rate': 0.0045087743523239505, 'max_depth': 2, 'min_child_weight': 0.38039159575107145, 'gamma': 2.9860798475225643, 'subsample': 0.5004323956357576, 'colsample_bytree': 0.9471215716493201, 'reg_alpha': 0.017773055565934254, 'reg_lambda': 16.011718306474698}. Best is trial 3 with value: 2.167343918847394.
# [I 2026-06-09 06:50:34,587] Trial 26 finished with value: 2.168351982216117 and parameters: {'n_estimators': 1444, 'learning_rate': 0.0075923599948029535, 'max_depth': 4, 'min_child_weight': 1.304916831581364, 'gamma': 4.5059236253993085, 'subsample': 0.6917403297961575, 'colsample_bytree': 0.7710643501932481, 'reg_alpha': 6.1442860179517504, 'reg_lambda': 0.4799885807487049}. Best is trial 3 with value: 2.167343918847394.
# [I 2026-06-09 06:50:56,370] Trial 27 finished with value: 2.174394402763649 and parameters: {'n_estimators': 1438, 'learning_rate': 0.02430870816141423, 'max_depth': 4, 'min_child_weight': 1.4156378538715766, 'gamma': 3.7050203147189125, 'subsample': 0.6988896999608456, 'colsample_bytree': 0.7644136494683753, 'reg_alpha': 0.11876366904180949, 'reg_lambda': 0.565098489788318}. Best is trial 3 with value: 2.167343918847394.
# [I 2026-06-09 06:51:05,495] Trial 28 pruned.
# [I 2026-06-09 06:51:16,488] Trial 29 pruned.
# [I 2026-06-09 06:51:33,000] Trial 30 pruned.
# [I 2026-06-09 06:51:49,003] Trial 31 pruned.
# [I 2026-06-09 06:53:20,415] Trial 32 finished with value: 2.168942555262866 and parameters: {'n_estimators': 1403, 'learning_rate': 0.00436631900023668, 'max_depth': 3, 'min_child_weight': 1.4717877880444676, 'gamma': 4.592138454464855, 'subsample': 0.7033673389499971, 'colsample_bytree': 0.7068740626635707, 'reg_alpha': 2.0340147741933645, 'reg_lambda': 1.0420429957792334}. Best is trial 3 with value: 2.167343918847394.
# [I 2026-06-09 06:54:03,223] Trial 33 pruned.
# [I 2026-06-09 06:54:29,764] Trial 34 pruned.
# [I 2026-06-09 06:55:03,583] Trial 35 finished with value: 2.1684692402704204 and parameters: {'n_estimators': 1217, 'learning_rate': 0.012202677701119241, 'max_depth': 3, 'min_child_weight': 1.1417212120514522, 'gamma': 3.7563311161190946, 'subsample': 0.7520299262308341, 'colsample_bytree': 0.7460413558075762, 'reg_alpha': 1.393674082120789, 'reg_lambda': 1.5401040217640252}. Best is trial 3 with value: 2.167343918847394.
# [I 2026-06-09 06:55:40,601] Trial 36 finished with value: 2.167241270647885 and parameters: {'n_estimators': 1211, 'learning_rate': 0.011861623760533617, 'max_depth': 3, 'min_child_weight': 0.5329183194893496, 'gamma': 0.6955807003128323, 'subsample': 0.8397514815085239, 'colsample_bytree': 0.708712490586713, 'reg_alpha': 1.7347317853724196, 'reg_lambda': 1.4401864247375817}. Best is trial 36 with value: 2.167241270647885.
# [I 2026-06-09 06:56:08,557] Trial 37 pruned.
# [I 2026-06-09 06:57:09,707] Trial 38 finished with value: 2.1813209313962743 and parameters: {'n_estimators': 1239, 'learning_rate': 0.008214488425518748, 'max_depth': 3, 'min_child_weight': 0.37848036104515514, 'gamma': 1.0446057118280205, 'subsample': 0.8423963502534771, 'colsample_bytree': 0.6602466872931143, 'reg_alpha': 1.3225613656816222, 'reg_lambda': 4.8774762611689635}. Best is trial 36 with value: 2.167241270647885.
# [I 2026-06-09 06:57:32,747] Trial 39 pruned.
# [I 2026-06-09 06:57:34,225] Trial 40 pruned.
# [I 2026-06-09 06:58:23,227] Trial 41 finished with value: 2.1845902860198705 and parameters: {'n_estimators': 1188, 'learning_rate': 0.004014997954879604, 'max_depth': 3, 'min_child_weight': 2.062003598550589, 'gamma': 1.292699428796026, 'subsample': 0.7519843239715954, 'colsample_bytree': 0.7115219978621177, 'reg_alpha': 1.6025857657388192, 'reg_lambda': 1.2739864177913134}. Best is trial 36 with value: 2.167241270647885.
# [I 2026-06-09 06:58:53,552] Trial 42 finished with value: 2.1794624705196846 and parameters: {'n_estimators': 1336, 'learning_rate': 0.010532326481921686, 'max_depth': 3, 'min_child_weight': 1.0531605328733802, 'gamma': 0.36839961762327833, 'subsample': 0.7454987976623842, 'colsample_bytree': 0.6853757918950176, 'reg_alpha': 2.183247769232986, 'reg_lambda': 0.06961325781279329}. Best is trial 36 with value: 2.167241270647885.
# [I 2026-06-09 06:58:59,411] Trial 43 pruned.
# [I 2026-06-09 06:59:20,733] Trial 44 pruned.
# [I 2026-06-09 06:59:33,743] Trial 45 pruned.
# [I 2026-06-09 06:59:57,979] Trial 46 pruned.
# [I 2026-06-09 07:00:15,048] Trial 47 pruned.
# [I 2026-06-09 07:00:31,938] Trial 48 pruned.
# [I 2026-06-09 07:00:36,937] Trial 49 pruned.
# [I 2026-06-09 07:00:40,410] Trial 50 pruned.
# [I 2026-06-09 07:00:45,205] Trial 51 pruned.
# [I 2026-06-09 07:00:53,113] Trial 52 pruned.
# [I 2026-06-09 07:01:04,525] Trial 53 pruned.
# [I 2026-06-09 07:01:15,984] Trial 54 pruned.
# [I 2026-06-09 07:01:21,174] Trial 55 pruned.
# [I 2026-06-09 07:01:32,185] Trial 56 pruned.
# [I 2026-06-09 07:01:34,712] Trial 57 pruned.
# [I 2026-06-09 07:01:45,442] Trial 58 pruned.
# [I 2026-06-09 07:01:49,443] Trial 59 pruned.
# [I 2026-06-09 07:01:53,297] Trial 60 pruned.
# [I 2026-06-09 07:02:13,659] Trial 61 pruned.
# [I 2026-06-09 07:02:57,451] Trial 62 finished with value: 2.1720224296568937 and parameters: {'n_estimators': 1567, 'learning_rate': 0.005446706493532322, 'max_depth': 2, 'min_child_weight': 1.1795296745928205, 'gamma': 3.987593848707045, 'subsample': 0.5553365489783262, 'colsample_bytree': 0.75400677032122, 'reg_alpha': 0.012908930949309694, 'reg_lambda': 1.4984448891782154}. Best is trial 36 with value: 2.167241270647885.
# [I 2026-06-09 07:03:16,407] Trial 63 pruned.
# [I 2026-06-09 07:03:24,972] Trial 64 pruned.
# [I 2026-06-09 07:03:33,728] Trial 65 pruned.
# [I 2026-06-09 07:04:31,557] Trial 66 finished with value: 2.19137637848044 and parameters: {'n_estimators': 1460, 'learning_rate': 0.00585957734337795, 'max_depth': 3, 'min_child_weight': 0.4924804356241788, 'gamma': 3.5983543169570527, 'subsample': 0.5360945111657953, 'colsample_bytree': 0.7361810756628542, 'reg_alpha': 0.9676010836711463, 'reg_lambda': 10.270481276455603}. Best is trial 36 with value: 2.167241270647885.
# [I 2026-06-09 07:05:09,657] Trial 67 finished with value: 2.190944530675648 and parameters: {'n_estimators': 1827, 'learning_rate': 0.0088920699100454, 'max_depth': 3, 'min_child_weight': 2.866027746854446, 'gamma': 3.421745073065064, 'subsample': 0.7071299804663691, 'colsample_bytree': 0.7224677611211712, 'reg_alpha': 0.12994139585529277, 'reg_lambda': 14.866926441504527}. Best is trial 36 with value: 2.167241270647885.
# [I 2026-06-09 07:05:40,075] Trial 68 pruned.
# [I 2026-06-09 07:05:43,109] Trial 69 pruned.
# [I 2026-06-09 07:05:56,418] Trial 70 pruned.
# [I 2026-06-09 07:06:21,599] Trial 71 pruned.
# [I 2026-06-09 07:07:02,544] Trial 72 finished with value: 2.17193578341758 and parameters: {'n_estimators': 1377, 'learning_rate': 0.005076174543998427, 'max_depth': 3, 'min_child_weight': 1.6262655578575487, 'gamma': 3.8695520472864615, 'subsample': 0.594333288623221, 'colsample_bytree': 0.785739788358552, 'reg_alpha': 0.016353528573986604, 'reg_lambda': 4.790820580942686}. Best is trial 36 with value: 2.167241270647885.
# [I 2026-06-09 07:07:43,049] Trial 73 finished with value: 2.191006833956946 and parameters: {'n_estimators': 1216, 'learning_rate': 0.00425295950068272, 'max_depth': 3, 'min_child_weight': 1.5494231447405855, 'gamma': 3.8894926019545006, 'subsample': 0.5344557846335789, 'colsample_bytree': 0.7512594389864655, 'reg_alpha': 0.015256190818159336, 'reg_lambda': 4.476274213314705}. Best is trial 36 with value: 2.167241270647885.
# [I 2026-06-09 07:08:29,464] Trial 74 pruned.
# [I 2026-06-09 07:09:04,053] Trial 75 finished with value: 2.2547781935155307 and parameters: {'n_estimators': 1270, 'learning_rate': 0.005483694430919301, 'max_depth': 3, 'min_child_weight': 1.1664411759841022, 'gamma': 4.365274116584632, 'subsample': 0.6174726960601195, 'colsample_bytree': 0.814692787778421, 'reg_alpha': 0.005647174668206472, 'reg_lambda': 24.040825088498593}. Best is trial 36 with value: 2.167241270647885.
# [I 2026-06-09 07:09:19,502] Trial 76 pruned.
# [I 2026-06-09 07:09:41,591] Trial 77 finished with value: 2.1746307027450964 and parameters: {'n_estimators': 1539, 'learning_rate': 0.010130673876730698, 'max_depth': 3, 'min_child_weight': 0.8931328533607081, 'gamma': 4.6314075739111376, 'subsample': 0.5168689439807452, 'colsample_bytree': 0.7172825650494586, 'reg_alpha': 1.759809657862768, 'reg_lambda': 0.7181796150815878}. Best is trial 36 with value: 2.167241270647885.
# [I 2026-06-09 07:09:59,685] Trial 78 finished with value: 2.1759007028128634 and parameters: {'n_estimators': 1467, 'learning_rate': 0.012642927149849187, 'max_depth': 4, 'min_child_weight': 2.804170547774099, 'gamma': 3.7491364059413095, 'subsample': 0.5765229436030666, 'colsample_bytree': 0.8340575877458759, 'reg_alpha': 0.07972630540034276, 'reg_lambda': 1.5135622459946387}. Best is trial 36 with value: 2.167241270647885.
# [I 2026-06-09 07:10:10,522] Trial 79 finished with value: 2.1723800963557123 and parameters: {'n_estimators': 1407, 'learning_rate': 0.02365681907421099, 'max_depth': 3, 'min_child_weight': 0.7062849782914713, 'gamma': 2.0957386386925716, 'subsample': 0.5940876650617274, 'colsample_bytree': 0.7345992523511993, 'reg_alpha': 0.022602275096989404, 'reg_lambda': 2.5996682087834415}. Best is trial 36 with value: 2.167241270647885.
# [I 2026-06-09 07:10:21,935] Trial 80 finished with value: 2.1680758883842635 and parameters: {'n_estimators': 1166, 'learning_rate': 0.01874730490392799, 'max_depth': 3, 'min_child_weight': 0.4587520485916191, 'gamma': 1.2907187272594338, 'subsample': 0.6036044642085274, 'colsample_bytree': 0.7386504833689581, 'reg_alpha': 0.00026783934081089683, 'reg_lambda': 2.521769438291102}. Best is trial 36 with value: 2.167241270647885.
# [I 2026-06-09 07:10:27,923] Trial 81 pruned.
# [I 2026-06-09 07:10:47,128] Trial 82 finished with value: 2.1703862944647194 and parameters: {'n_estimators': 1160, 'learning_rate': 0.019081377835932528, 'max_depth': 3, 'min_child_weight': 0.6706996591267403, 'gamma': 1.1011209387499747, 'subsample': 0.560339304347261, 'colsample_bytree': 0.6841310263974647, 'reg_alpha': 1.1573496591736159e-05, 'reg_lambda': 5.197617909716965}. Best is trial 36 with value: 2.167241270647885.
# [I 2026-06-09 07:11:02,829] Trial 83 finished with value: 2.1687856943944395 and parameters: {'n_estimators': 1165, 'learning_rate': 0.019165682036296112, 'max_depth': 2, 'min_child_weight': 0.4367689564467975, 'gamma': 0.9334979707480682, 'subsample': 0.5541531229609175, 'colsample_bytree': 0.692539173180555, 'reg_alpha': 6.360893324657743e-06, 'reg_lambda': 9.221131046983949}. Best is trial 36 with value: 2.167241270647885.
# [I 2026-06-09 07:11:19,666] Trial 84 finished with value: 2.1862743223228995 and parameters: {'n_estimators': 1046, 'learning_rate': 0.019271235351261944, 'max_depth': 3, 'min_child_weight': 0.49377023165759654, 'gamma': 0.9223493730020388, 'subsample': 0.5281310464644108, 'colsample_bytree': 0.7013037730710289, 'reg_alpha': 4.60827978246904e-07, 'reg_lambda': 8.516640345225609}. Best is trial 36 with value: 2.167241270647885.
# [I 2026-06-09 07:11:38,856] Trial 85 finished with value: 2.1792371009797042 and parameters: {'n_estimators': 992, 'learning_rate': 0.015849953795481566, 'max_depth': 3, 'min_child_weight': 0.5668996542295235, 'gamma': 1.1924067786399444, 'subsample': 0.563120584881657, 'colsample_bytree': 0.6801585127314351, 'reg_alpha': 1.839260029186745e-05, 'reg_lambda': 4.95490314748296}. Best is trial 36 with value: 2.167241270647885.
# [I 2026-06-09 07:11:54,185] Trial 86 finished with value: 2.181689775595709 and parameters: {'n_estimators': 1160, 'learning_rate': 0.020281419179093943, 'max_depth': 2, 'min_child_weight': 0.42801388389325495, 'gamma': 0.7896733420109193, 'subsample': 0.5038453798782067, 'colsample_bytree': 0.6520762122275152, 'reg_alpha': 2.796839490323216e-06, 'reg_lambda': 14.300032678618091}. Best is trial 36 with value: 2.167241270647885.
# [I 2026-06-09 07:12:18,909] Trial 87 finished with value: 2.1671208609375165 and parameters: {'n_estimators': 1197, 'learning_rate': 0.013756326806070075, 'max_depth': 3, 'min_child_weight': 0.29659045228714803, 'gamma': 0.5301717260124259, 'subsample': 0.5476325674620491, 'colsample_bytree': 0.714206337541064, 'reg_alpha': 1.1271330748179603e-06, 'reg_lambda': 3.3644839545842973}. Best is trial 87 with value: 2.1671208609375165.
# [I 2026-06-09 07:12:40,368] Trial 88 finished with value: 2.1608064144931545 and parameters: {'n_estimators': 1198, 'learning_rate': 0.01352685698511026, 'max_depth': 2, 'min_child_weight': 0.295898322067301, 'gamma': 0.43178685503323555, 'subsample': 0.5449628009801023, 'colsample_bytree': 0.692244455451488, 'reg_alpha': 1.1255917366518371e-06, 'reg_lambda': 3.7477231359875045}. Best is trial 88 with value: 2.1608064144931545.
# [I 2026-06-09 07:12:49,819] Trial 89 pruned.
# [I 2026-06-09 07:13:11,176] Trial 90 finished with value: 2.1636239640432917 and parameters: {'n_estimators': 957, 'learning_rate': 0.013949205483192345, 'max_depth': 2, 'min_child_weight': 0.2727574555804829, 'gamma': 0.6677134927136528, 'subsample': 0.5727068610029047, 'colsample_bytree': 0.6924302029729499, 'reg_alpha': 1.103772652532009e-06, 'reg_lambda': 7.963329133277824}. Best is trial 88 with value: 2.1608064144931545.
# [I 2026-06-09 07:13:39,710] Trial 91 finished with value: 2.1701657884251158 and parameters: {'n_estimators': 947, 'learning_rate': 0.01412902455158668, 'max_depth': 2, 'min_child_weight': 0.2799131007170887, 'gamma': 0.2259467558953147, 'subsample': 0.5802102862101045, 'colsample_bytree': 0.6665127355831479, 'reg_alpha': 5.096713479713198e-07, 'reg_lambda': 8.009258204659142}. Best is trial 88 with value: 2.1608064144931545.
# [I 2026-06-09 07:14:03,718] Trial 92 finished with value: 2.1934370905308143 and parameters: {'n_estimators': 895, 'learning_rate': 0.01401396327263324, 'max_depth': 2, 'min_child_weight': 0.24329874490296577, 'gamma': 0.6888567067842537, 'subsample': 0.5474040034745051, 'colsample_bytree': 0.6964128549148225, 'reg_alpha': 1.0808235133843231e-06, 'reg_lambda': 23.719544865841474}. Best is trial 88 with value: 2.1608064144931545.
# [I 2026-06-09 07:14:21,278] Trial 93 pruned.
# [I 2026-06-09 07:15:00,351] Trial 94 finished with value: 2.1733183118599166 and parameters: {'n_estimators': 984, 'learning_rate': 0.012638077382695954, 'max_depth': 2, 'min_child_weight': 0.4381798363508173, 'gamma': 0.2827560081544905, 'subsample': 0.5714692153853917, 'colsample_bytree': 0.6876449455548356, 'reg_alpha': 1.5317116433112908e-06, 'reg_lambda': 10.245004414884642}. Best is trial 88 with value: 2.1608064144931545.
# [I 2026-06-09 07:15:17,526] Trial 95 pruned.
# [I 2026-06-09 07:15:32,711] Trial 96 pruned.
# [I 2026-06-09 07:16:32,274] Trial 97 finished with value: 2.191224689306797 and parameters: {'n_estimators': 1200, 'learning_rate': 0.013830580215145176, 'max_depth': 3, 'min_child_weight': 0.24093484761537634, 'gamma': 0.04599305681035748, 'subsample': 0.6116284950549329, 'colsample_bytree': 0.9803938414077539, 'reg_alpha': 2.7055608298250755e-08, 'reg_lambda': 12.84759793957279}. Best is trial 88 with value: 2.1608064144931545.
# [I 2026-06-09 07:17:12,584] Trial 98 pruned.
# [I 2026-06-09 07:18:28,558] Trial 99 finished with value: 2.2118159240032136 and parameters: {'n_estimators': 1240, 'learning_rate': 0.009537118901625384, 'max_depth': 2, 'min_child_weight': 0.4244766132302501, 'gamma': 0.18091688535565492, 'subsample': 0.6674261535950342, 'colsample_bytree': 0.9167989735622408, 'reg_alpha': 5.119352942454487e-06, 'reg_lambda': 38.073321049414425}. Best is trial 88 with value: 2.1608064144931545.
# [I 2026-06-09 07:18:28,565] A new study created in memory with name: no-name-4f404423-9d42-4543-98e9-f0cd6def9956
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:18:43,569] Trial 0 finished with value: 2.3196583428131805 and parameters: {'n_estimators': 301, 'learning_rate': 0.03250177171527344, 'num_leaves': 37, 'max_depth': 4, 'min_child_samples': 52, 'min_split_gain': 1.7182749818971954, 'bagging_fraction': 0.8330451065490129, 'bagging_freq': 4, 'feature_fraction': 0.5145069122121801, 'lambda_l1': 0.04015454105555427, 'lambda_l2': 0.07175601133819473}. Best is trial 0 with value: 2.3196583428131805.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:20:31,364] Trial 1 finished with value: 2.2968239266589254 and parameters: {'n_estimators': 1620, 'learning_rate': 0.008116618171663207, 'num_leaves': 18, 'max_depth': 9, 'min_child_samples': 37, 'min_split_gain': 0.8099788960945193, 'bagging_fraction': 0.6580482355091044, 'bagging_freq': 1, 'feature_fraction': 0.9216123471148523, 'lambda_l1': 0.43697071238567825, 'lambda_l2': 36.7185332724254}. Best is trial 1 with value: 2.2968239266589254.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:20:42,099] Trial 2 finished with value: 2.2976914308317755 and parameters: {'n_estimators': 820, 'learning_rate': 0.1255359023925396, 'num_leaves': 116, 'max_depth': 8, 'min_child_samples': 17, 'min_split_gain': 1.7941971599630686, 'bagging_fraction': 0.6490017503443813, 'bagging_freq': 2, 'feature_fraction': 0.5025647745322285, 'lambda_l1': 0.0007741455782248723, 'lambda_l2': 0.1717169091593679}. Best is trial 1 with value: 2.2968239266589254.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:20:53,073] Trial 3 finished with value: 2.560033933314194 and parameters: {'n_estimators': 1302, 'learning_rate': 0.13774020868800516, 'num_leaves': 233, 'max_depth': 10, 'min_child_samples': 81, 'min_split_gain': 0.2080378997095258, 'bagging_fraction': 0.5904572976289505, 'bagging_freq': 7, 'feature_fraction': 0.7059764916931793, 'lambda_l1': 0.6097531961875766, 'lambda_l2': 1.4405915859050216}. Best is trial 1 with value: 2.2968239266589254.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:22:02,351] Trial 4 finished with value: 2.3250671541433645 and parameters: {'n_estimators': 1287, 'learning_rate': 0.008816320113501107, 'num_leaves': 230, 'max_depth': 3, 'min_child_samples': 64, 'min_split_gain': 1.987144984788207, 'bagging_fraction': 0.8678635407535604, 'bagging_freq': 4, 'feature_fraction': 0.7803315847218675, 'lambda_l1': 5.026890229380336e-05, 'lambda_l2': 2.6067223030440956}. Best is trial 1 with value: 2.2968239266589254.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:22:15,769] Trial 5 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:22:41,226] Trial 6 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:22:51,019] Trial 7 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:22:54,902] Trial 8 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:24:18,341] Trial 9 finished with value: 2.3427235757151155 and parameters: {'n_estimators': 1265, 'learning_rate': 0.004494838277163318, 'num_leaves': 127, 'max_depth': 2, 'min_child_samples': 50, 'min_split_gain': 1.50407937273205, 'bagging_fraction': 0.8577495432640323, 'bagging_freq': 7, 'feature_fraction': 0.8884476833543847, 'lambda_l1': 8.650807236918189e-07, 'lambda_l2': 17.882672893320727}. Best is trial 1 with value: 2.2968239266589254.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:26:46,590] Trial 10 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:28:20,395] Trial 11 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:30:44,386] Trial 12 finished with value: 2.2967321291956964 and parameters: {'n_estimators': 1655, 'learning_rate': 0.013041541875598977, 'num_leaves': 157, 'max_depth': 8, 'min_child_samples': 31, 'min_split_gain': 1.0122335453146316, 'bagging_fraction': 0.7010866563866872, 'bagging_freq': 2, 'feature_fraction': 0.7669885765773305, 'lambda_l1': 0.0005434906375677747, 'lambda_l2': 9.16111839794086}. Best is trial 12 with value: 2.2967321291956964.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:35:18,065] Trial 13 finished with value: 2.2945246160142645 and parameters: {'n_estimators': 1646, 'learning_rate': 0.012722610061376883, 'num_leaves': 167, 'max_depth': 10, 'min_child_samples': 35, 'min_split_gain': 0.9605016854015649, 'bagging_fraction': 0.7331384069677157, 'bagging_freq': 2, 'feature_fraction': 0.798648134667717, 'lambda_l1': 0.08369991639189364, 'lambda_l2': 7.48402910518403}. Best is trial 13 with value: 2.2945246160142645.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:39:54,600] Trial 14 finished with value: 2.303638486278252 and parameters: {'n_estimators': 1736, 'learning_rate': 0.016224015421943565, 'num_leaves': 167, 'max_depth': 10, 'min_child_samples': 37, 'min_split_gain': 1.2072930492931482, 'bagging_fraction': 0.7598796288593272, 'bagging_freq': 3, 'feature_fraction': 0.7985450818347442, 'lambda_l1': 2.672934562225984e-05, 'lambda_l2': 4.301164986434846}. Best is trial 13 with value: 2.2945246160142645.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:42:48,514] Trial 15 finished with value: 2.284621746272646 and parameters: {'n_estimators': 1604, 'learning_rate': 0.014880371650757543, 'num_leaves': 169, 'max_depth': 6, 'min_child_samples': 29, 'min_split_gain': 1.1642849115182503, 'bagging_fraction': 0.7737144463714739, 'bagging_freq': 2, 'feature_fraction': 0.7473520099788133, 'lambda_l1': 0.009479630382349726, 'lambda_l2': 6.801671434801453}. Best is trial 15 with value: 2.284621746272646.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:44:09,184] Trial 16 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:46:19,670] Trial 17 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:46:26,608] Trial 18 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:47:22,966] Trial 19 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:48:27,949] Trial 20 finished with value: 2.30882122001117 and parameters: {'n_estimators': 1465, 'learning_rate': 0.011139044525643084, 'num_leaves': 83, 'max_depth': 5, 'min_child_samples': 44, 'min_split_gain': 0.5925372616667715, 'bagging_fraction': 0.6973101241209971, 'bagging_freq': 3, 'feature_fraction': 0.8686360998612093, 'lambda_l1': 0.06168854495517419, 'lambda_l2': 2.391035991403229}. Best is trial 15 with value: 2.284621746272646.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:49:51,197] Trial 21 finished with value: 2.2755050199542253 and parameters: {'n_estimators': 1746, 'learning_rate': 0.01266233307665638, 'num_leaves': 148, 'max_depth': 8, 'min_child_samples': 27, 'min_split_gain': 1.0652063561048992, 'bagging_fraction': 0.7313743132159589, 'bagging_freq': 2, 'feature_fraction': 0.7688546186318922, 'lambda_l1': 0.0001775350577300914, 'lambda_l2': 12.140522475537779}. Best is trial 21 with value: 2.2755050199542253.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:51:03,075] Trial 22 finished with value: 2.240461555940561 and parameters: {'n_estimators': 1844, 'learning_rate': 0.02020701292839159, 'num_leaves': 146, 'max_depth': 8, 'min_child_samples': 23, 'min_split_gain': 1.08962280768737, 'bagging_fraction': 0.7515380319422161, 'bagging_freq': 2, 'feature_fraction': 0.749347212541707, 'lambda_l1': 7.969899120850856e-05, 'lambda_l2': 16.009586801173715}. Best is trial 22 with value: 2.240461555940561.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:51:44,776] Trial 23 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:52:25,909] Trial 24 finished with value: 2.252915637530696 and parameters: {'n_estimators': 1887, 'learning_rate': 0.04811653314304197, 'num_leaves': 140, 'max_depth': 7, 'min_child_samples': 22, 'min_split_gain': 1.0944114890840493, 'bagging_fraction': 0.7605827924238889, 'bagging_freq': 2, 'feature_fraction': 0.6778979434103043, 'lambda_l1': 8.938554581695354e-06, 'lambda_l2': 46.29161835524026}. Best is trial 22 with value: 2.240461555940561.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:54:06,253] Trial 25 finished with value: 2.2350766542066456 and parameters: {'n_estimators': 1893, 'learning_rate': 0.05152788213668221, 'num_leaves': 88, 'max_depth': 7, 'min_child_samples': 14, 'min_split_gain': 1.0858736765674326, 'bagging_fraction': 0.6607348956199908, 'bagging_freq': 3, 'feature_fraction': 0.6658605487344263, 'lambda_l1': 3.439000777871188e-06, 'lambda_l2': 39.27100430368513}. Best is trial 25 with value: 2.2350766542066456.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:54:56,835] Trial 26 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:55:09,211] Trial 27 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:55:40,259] Trial 28 finished with value: 2.2091667853345927 and parameters: {'n_estimators': 1879, 'learning_rate': 0.04289995695874889, 'num_leaves': 65, 'max_depth': 5, 'min_child_samples': 14, 'min_split_gain': 1.6276493786661819, 'bagging_fraction': 0.6809019493179091, 'bagging_freq': 3, 'feature_fraction': 0.5667505256254705, 'lambda_l1': 8.412394146677962e-06, 'lambda_l2': 18.335320216875967}. Best is trial 28 with value: 2.2091667853345927.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:55:54,769] Trial 29 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:56:17,100] Trial 30 finished with value: 2.215404158416565 and parameters: {'n_estimators': 1743, 'learning_rate': 0.03309566635106173, 'num_leaves': 65, 'max_depth': 4, 'min_child_samples': 14, 'min_split_gain': 1.6016397087574146, 'bagging_fraction': 0.6147027385497448, 'bagging_freq': 5, 'feature_fraction': 0.5604077802432353, 'lambda_l1': 5.3918735226821346e-06, 'lambda_l2': 13.711119067899418}. Best is trial 28 with value: 2.2091667853345927.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:56:37,575] Trial 31 finished with value: 2.214641496489433 and parameters: {'n_estimators': 1719, 'learning_rate': 0.03397506667263053, 'num_leaves': 63, 'max_depth': 4, 'min_child_samples': 14, 'min_split_gain': 1.6502120341335749, 'bagging_fraction': 0.5587909508602601, 'bagging_freq': 5, 'feature_fraction': 0.5541585782931292, 'lambda_l1': 4.064146570051792e-06, 'lambda_l2': 17.324925036858033}. Best is trial 28 with value: 2.2091667853345927.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:57:07,638] Trial 32 finished with value: 2.2026906700487836 and parameters: {'n_estimators': 1571, 'learning_rate': 0.035521900824306486, 'num_leaves': 67, 'max_depth': 4, 'min_child_samples': 12, 'min_split_gain': 1.6587682740493799, 'bagging_fraction': 0.5536672312770099, 'bagging_freq': 5, 'feature_fraction': 0.5508649822788572, 'lambda_l1': 5.689765325001905e-06, 'lambda_l2': 21.568985714263114}. Best is trial 32 with value: 2.2026906700487836.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:57:19,663] Trial 33 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:57:25,993] Trial 34 finished with value: 2.2199498222350953 and parameters: {'n_estimators': 1594, 'learning_rate': 0.07510156419615922, 'num_leaves': 34, 'max_depth': 3, 'min_child_samples': 14, 'min_split_gain': 1.774321965124089, 'bagging_fraction': 0.5577170987935105, 'bagging_freq': 5, 'feature_fraction': 0.5396031781022816, 'lambda_l1': 5.26850296467226e-07, 'lambda_l2': 19.897993123962276}. Best is trial 32 with value: 2.2026906700487836.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:57:45,140] Trial 35 finished with value: 2.305866773081021 and parameters: {'n_estimators': 1733, 'learning_rate': 0.02874911926080558, 'num_leaves': 67, 'max_depth': 3, 'min_child_samples': 39, 'min_split_gain': 1.5827404905071325, 'bagging_fraction': 0.6171613102970485, 'bagging_freq': 6, 'feature_fraction': 0.5848062601333542, 'lambda_l1': 1.8793791961160116e-06, 'lambda_l2': 4.492565303600353}. Best is trial 32 with value: 2.2026906700487836.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:58:15,520] Trial 36 finished with value: 2.262462018769561 and parameters: {'n_estimators': 1193, 'learning_rate': 0.039801189622890615, 'num_leaves': 69, 'max_depth': 4, 'min_child_samples': 16, 'min_split_gain': 1.8770789991848735, 'bagging_fraction': 0.5565150677141656, 'bagging_freq': 5, 'feature_fraction': 0.5174001989988705, 'lambda_l1': 0.00018507831412074383, 'lambda_l2': 11.21886653092553}. Best is trial 32 with value: 2.2026906700487836.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:58:18,530] Trial 37 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:58:26,804] Trial 38 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:58:50,776] Trial 39 finished with value: 2.2989906883029403 and parameters: {'n_estimators': 473, 'learning_rate': 0.0274487951892486, 'num_leaves': 52, 'max_depth': 5, 'min_child_samples': 31, 'min_split_gain': 1.3398690237962412, 'bagging_fraction': 0.6243915506599526, 'bagging_freq': 6, 'feature_fraction': 0.6282285374548773, 'lambda_l1': 1.129154409900941e-08, 'lambda_l2': 0.02051558959541049}. Best is trial 32 with value: 2.2026906700487836.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:58:56,456] Trial 40 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:59:00,731] Trial 41 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:59:08,675] Trial 42 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:59:10,621] Trial 43 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:59:14,828] Trial 44 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 07:59:18,950] Trial 45 pruned.
# ...
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 08:12:23,116] Trial 94 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 08:12:49,765] Trial 95 finished with value: 2.2791058059934812 and parameters: {'n_estimators': 1450, 'learning_rate': 0.05339774028908067, 'num_leaves': 67, 'max_depth': 10, 'min_child_samples': 23, 'min_split_gain': 1.117501842157252, 'bagging_fraction': 0.5536174644649422, 'bagging_freq': 4, 'feature_fraction': 0.5018811321476025, 'lambda_l1': 9.465376689691793e-06, 'lambda_l2': 27.754892297527952}. Best is trial 32 with value: 2.2026906700487836.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 08:13:00,689] Trial 96 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 08:13:19,435] Trial 97 finished with value: 2.268345522756456 and parameters: {'n_estimators': 1389, 'learning_rate': 0.03268147987666282, 'num_leaves': 50, 'max_depth': 9, 'min_child_samples': 29, 'min_split_gain': 1.6754879548762667, 'bagging_fraction': 0.6860582171761093, 'bagging_freq': 4, 'feature_fraction': 0.5176020728182411, 'lambda_l1': 8.481655209331471e-07, 'lambda_l2': 1.8446736447994005}. Best is trial 32 with value: 2.2026906700487836.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 08:13:23,745] Trial 98 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-09 08:13:29,991] Trial 99 pruned.
# [I 2026-06-09 08:13:29,996] A new study created in memory with name: no-name-048da23e-192a-4704-a5fa-ad70ae79eb78
# [W 2026-06-09 08:15:18,823] Trial 0 failed with parameters: {'iterations': 1683, 'learning_rate': 0.00452029410787974, 'depth': 8, 'l2_leaf_reg': 2.630096460705121, 'random_strength': 3.5931083780807196, 'bagging_temperature': 6.092383806181517, 'border_count': 120, 'rsm': 0.7045363049304494} because of the following error: KeyboardInterrupt('').
# Traceback (most recent call last):
#   File "d:\dev\weather-research\.venv\Lib\site-packages\optuna\study\_optimize.py", line 206, in _run_trial
#     value_or_values = func(trial)
#   File "D:\dev\weather-research\src\calibration\station_stacking.py", line 800, in objective
#     year = pd.to_numeric(frame.get("year"), errors="coerce")
#                                               ^^^^^^^^^^^^^^
#     ...<8 lines>...
#             for fold in folds:
#             ^^^^^^^^^
#   File "D:\dev\weather-research\src\calibration\station_stacking.py", line 1909, in _fit_predict_base_model
#         train: pd.DataFrame,
#     ...<7 lines>...
#
#   File "D:\dev\weather-research\src\calibration\station_stacking.py", line 1960, in _fit_base_estimator
#     try:
#
#     ...<6 lines>...
#             estimator.fit(
#             ^
#   File "d:\dev\weather-research\.venv\Lib\site-packages\catboost\core.py", line 6178, in fit
#     return self._fit(X, y, cat_features, text_features, embedding_features, None, graph, sample_weight, None, None, None, None, baseline,
#            ~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#                      use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description,
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#                      verbose_eval, metric_period, silent, early_stopping_rounds,
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#                      save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\dev\weather-research\.venv\Lib\site-packages\catboost\core.py", line 2716, in _fit
#     self._train(
#     ~~~~~~~~~~~^
#         train_pool,
#         ^^^^^^^^^^^
#     ...<3 lines>...
#         train_params["init_model"]
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "d:\dev\weather-research\.venv\Lib\site-packages\catboost\core.py", line 1824, in _train
#     self._object._train(train_pool, test_pool, params, allow_clear_pool, init_model._object if init_model else None)
#     ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "_catboost.pyx", line 5430, in _catboost._CatBoost._train
#   File "_catboost.pyx", line 5479, in _catboost._CatBoost._train
# KeyboardInterrupt
# [W 2026-06-09 08:15:18,866] Trial 0 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 18
#      14     stack_optuna_trials=STACK_OPTUNA_TRIALS,
#      15     optuna_verbose=OPTUNA_VERBOSE,
#      16     output_dir=PROJECT_ROOT / "data" / "calibration" / "station_stacking_v4",
#      17 )
# ---> 18 result = run_station_year_split_experiment(config)
#      19 result.scoreboard
#
# File D:\dev\weather-research\src\calibration\station_stacking.py:654, in run_station_year_split_experiment(config)
#     643     feature_columns_frame.to_csv(paths["feature_columns"], index=False)
#     644     return StationStackingResult(
#     645         station_id=station,
#     646         features=features,
#    (...)    650         output_paths=paths,
#     651     )
# --> 654 def run_station_year_split_experiment(config: StationStackingConfig) -> YearSplitExperimentResult:
#     655     features = build_station_wide_dataset(
#     656         config.resolved_project_root(),
#     657         station_id=config.station_id,
#     658         timing_mode=config.timing_mode,
#     659         providers=config.providers,
#     660     )
#     661     modeling_frame, categorical, numeric = _modeling_frame(features, config)
#
# File D:\dev\weather-research\src\calibration\station_stacking.py:864, in tune_year_split_base_models(frame, config, categorical, numeric, folds)
#     850 rmse = float(metrics["rmse_f"])
#     851 fold_scores.append((fold, float(metrics[metric_col])))
#     852 rows.append(
#     853     {
#     854         "method": method,
#     855         "trial_number": trial.number,
#     856         "param_key": param_key,
#     857         "fold": fold.name,
#     858         "fold_weight": _year_split_fold_weight(fold),
#     859         "mae_f": mae,
#     860         "rmse_f": rmse,
#     861         "count": int(metrics["count"]),
#     862         "fit_numeric_features": fit_metadata["numeric_features"],
#     863         "fit_categorical_features": fit_metadata["categorical_features"],
# --> 864         "best_iteration": fit_metadata["best_iteration"],
#     865         "status": "ok",
#     866         "error": "",
#     867         **{f"param_{key}": value for key, value in params.items()},
#     868     }
#     869 )
#     870 current_score = _weighted_fold_score(fold_scores)
#     871 if hasattr(trial, "report"):
#
# File d:\dev\weather-research\.venv\Lib\site-packages\optuna\study\study.py:516, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     414 def optimize(
#     415     self,
#     416     func: ObjectiveFuncType,
#    (...)    423     show_progress_bar: bool = False,
#     424 ) -> None:
#     425     """Optimize an objective function.
#     426
#     427     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)    514             If nested invocation of this method occurs.
#     515     """
# --> 516     _optimize(
#     517         study=self,
#     518         func=func,
#     519         n_trials=n_trials,
#     520         timeout=timeout,
#     521         n_jobs=n_jobs,
#     522         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     523         callbacks=callbacks,
#     524         gc_after_trial=gc_after_trial,
#     525         show_progress_bar=show_progress_bar,
#     526     )
#
# File d:\dev\weather-research\.venv\Lib\site-packages\optuna\study\_optimize.py:68, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      66 try:
#      67     if n_jobs == 1:
# ---> 68         _optimize_sequential(
#      69             study,
#      70             func,
#      71             n_trials,
#      72             timeout,
#      73             catch,
#      74             callbacks,
#      75             gc_after_trial,
#      76             reseed_sampler_rng=False,
#      77             time_start=None,
#      78             progress_bar=progress_bar,
#      79         )
#      80     else:
#      81         if n_jobs == -1:
#
# File d:\dev\weather-research\.venv\Lib\site-packages\optuna\study\_optimize.py:165, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     162         break
#     164 try:
# --> 165     frozen_trial_id = _run_trial(study, func, catch)
#     166 finally:
#     167     # The following line mitigates memory problems that can be occurred in some
#     168     # environments (e.g., services that use computing containers such as GitHub Actions).
#     169     # Please refer to the following PR for further details:
#     170     # https://github.com/optuna/optuna/pull/325.
#     171     if gc_after_trial:
#
# File d:\dev\weather-research\.venv\Lib\site-packages\optuna\study\_optimize.py:263, in _run_trial(study, func, catch)
#     256         assert False, "Should not reach."
#     258 if (
#     259     updated_state == TrialState.FAIL
#     260     and func_err is not None
#     261     and not isinstance(func_err, catch)
#     262 ):
# --> 263     raise func_err
#     264 return trial._trial_id
#
# File d:\dev\weather-research\.venv\Lib\site-packages\optuna\study\_optimize.py:206, in _run_trial(study, func, catch)
#     204 with get_heartbeat_thread(trial._trial_id, study._storage):
#     205     try:
# --> 206         value_or_values = func(trial)
#     207     except exceptions.TrialPruned as e:
#     208         # TODO(mamu): Handle multi-objective cases.
#     209         state = TrialState.PRUNED
#
# File D:\dev\weather-research\src\calibration\station_stacking.py:800, in objective(trial)
#     798     return pd.DataFrame(), _empty_year_split_predictions(), pd.DataFrame()
#     799 rows: list[dict[str, Any]] = []
# --> 800 year = pd.to_numeric(frame.get("year"), errors="coerce")
#     801 metric_col = config.effective_optuna_metric
#     802 for method in BASE_MODEL_METHODS:
#
# File D:\dev\weather-research\src\calibration\station_stacking.py:1909, in _fit_predict_base_model(config, categorical, numeric, method, params, train, valid, early_stopping)
#    1885         return CatBoostRegressor(
#    1886             iterations=cat_iterations,
#    1887             learning_rate=float(params.get("learning_rate", 0.035)),
#    (...)   1898             allow_writing_files=False,
#    1899         )
#    1900     raise ValueError(f"Unknown base model method: {method}")
#    1903 def _fit_predict_base_model(
#    1904     config: StationStackingConfig,
#    1905     categorical: list[str],
#    1906     numeric: list[str],
#    1907     method: str,
#    1908     params: dict[str, Any],
# -> 1909     train: pd.DataFrame,
#    1910     valid: pd.DataFrame,
#    1911     early_stopping: bool,
#    1912 ) -> tuple[np.ndarray, dict[str, Any]]:
#    1913     fit_categorical, fit_numeric = _fit_feature_columns(train, categorical, numeric)
#    1914     feature_names = [*fit_categorical, *fit_numeric]
#
# File D:\dev\weather-research\src\calibration\station_stacking.py:1960, in _fit_base_estimator(estimator, method, x_train, y_train, x_valid, y_valid, early_stopping_rounds)
#    1958     estimator.fit(x_train, y_train)
#    1959     return
# -> 1960 try:
#    1961     if method == "xgboost":
#    1962         estimator.fit(x_train, y_train, eval_set=[(x_valid, y_valid)], verbose=False)
#
# File d:\dev\weather-research\.venv\Lib\site-packages\catboost\core.py:6178, in CatBoostRegressor.fit(self, X, y, cat_features, text_features, embedding_features, graph, sample_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    6176 if 'loss_function' in params:
#    6177     CatBoostRegressor._check_is_compatible_loss(params['loss_function'])
# -> 6178 return self._fit(X, y, cat_features, text_features, embedding_features, None, graph, sample_weight, None, None, None, None, baseline,
#    6179                  use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description,
#    6180                  verbose_eval, metric_period, silent, early_stopping_rounds,
#    6181                  save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#
# File d:\dev\weather-research\.venv\Lib\site-packages\catboost\core.py:2716, in CatBoost._fit(self, X, y, cat_features, text_features, embedding_features, pairs, graph, sample_weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    2713 allow_clear_pool = train_params["allow_clear_pool"]
#    2715 with plot_wrapper(plot, plot_file, 'Training plots', [_get_train_dir(params)]):
# -> 2716     self._train(
#    2717         train_pool,
#    2718         train_params["eval_sets"],
#    2719         params,
#    2720         allow_clear_pool,
#    2721         train_params["init_model"]
#    2722     )
#    2724 # Have property feature_importance possibly set
#    2725 loss = self._object._get_loss_function_name()
#
# File d:\dev\weather-research\.venv\Lib\site-packages\catboost\core.py:1824, in _CatBoostBase._train(self, train_pool, test_pool, params, allow_clear_pool, init_model)
#    1823 def _train(self, train_pool, test_pool, params, allow_clear_pool, init_model):
# -> 1824     self._object._train(train_pool, test_pool, params, allow_clear_pool, init_model._object if init_model else None)
#    1825     self._set_trained_model_attributes()
#
# File _catboost.pyx:5430, in _catboost._CatBoost._train()
# -> 5430 'Could not get source, probably due dynamically evaluated source code.'
#
# File _catboost.pyx:5479, in _catboost._CatBoost._train()
# -> 5479 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyboardInterrupt:

# %% [markdown]
# ## Rounded Within 1F Accuracy

# %%
preds = pd.concat(
    [
        result.validation_predictions.assign(period="validation_2024_2025"),
        result.test_predictions.assign(period="test_2026"),
    ],
    ignore_index=True,
)

predicted_high = pd.to_numeric(preds["predicted_high_f"], errors="coerce")
preds["predicted_high_rounded_f"] = np.floor(predicted_high + 0.5)
preds["within_1f_after_round"] = (
    pd.to_numeric(preds["actual_high_f"], errors="coerce") - preds["predicted_high_rounded_f"]
).abs().le(1)

within_1f_accuracy_by_period = (
    preds
    .dropna(subset=["actual_high_f", "predicted_high_rounded_f"])
    .groupby(["period", "method"], as_index=False)
    .agg(
        count=("within_1f_after_round", "size"),
        within_1f_count=("within_1f_after_round", "sum"),
        within_1f_accuracy_pct=("within_1f_after_round", lambda x: x.mean() * 100),
    )
    .sort_values(["period", "within_1f_accuracy_pct"], ascending=[True, False])
)

within_1f_accuracy_by_period

# %% [markdown]
# ## Precipitation Feature Coverage

# %%
precip_columns = [column for column in result.features.columns if "precip" in column.lower()]
coverage = (
    result.features[precip_columns]
    .notna()
    .mean()
    .mul(100)
    .sort_values(ascending=False)
    .rename("coverage_pct")
    .reset_index()
    .rename(columns={"index": "feature"})
)
coverage

# %% [markdown]
# ## Version Comparison

# %%
comparison_frames = []
for version, folder in [
    ("v1", PROJECT_ROOT / "data" / "calibration" / "station_stacking"),
    ("v2", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v2"),
    ("v3", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v3"),
    ("v4", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v4"),
]:
    path = folder / f"{STATION_ID}_year_split_scoreboard.csv"
    if path.exists():
        frame = pd.read_csv(path)
        frame["version"] = version
        comparison_frames.append(frame)

version_comparison = pd.concat(comparison_frames, ignore_index=True) if comparison_frames else pd.DataFrame()
if not version_comparison.empty:
    version_comparison = version_comparison.sort_values(["period", "mae_f", "version", "method"]).reset_index(drop=True)
version_comparison

# %% [markdown]
# ## 2026 Weather Brackets

# %%
result.bracket_metrics

# %%
import pandas as pd


def adjacent_brackets(bracket):
    if pd.isna(bracket):
        return []
    text = str(bracket).strip()
    if not text or "-" not in text:
        return []
    try:
        lower = int(text.split("-", 1)[0])
    except ValueError:
        return []
    return [
        f"{lower - 2}-{lower - 1}",
        f"{lower}-{lower + 1}",
        f"{lower + 2}-{lower + 3}",
    ]


bracket_3way = result.bracket_predictions.copy()

valid = bracket_3way["actual_bracket"].notna() & bracket_3way["predicted_bracket"].astype(str).str.strip().ne("")
bracket_3way = bracket_3way.loc[valid].copy()
bracket_3way["picked_brackets"] = bracket_3way["predicted_bracket"].map(adjacent_brackets)
bracket_3way["three_bracket_hit"] = bracket_3way.apply(
    lambda row: row["actual_bracket"] in row["picked_brackets"],
    axis=1,
)

three_bracket_accuracy = (
    bracket_3way
    .groupby("method", as_index=False)
    .agg(
        count=("three_bracket_hit", "size"),
        exact_bracket_accuracy_pct=("bracket_hit", lambda x: x.mean() * 100),
        three_bracket_accuracy_pct=("three_bracket_hit", lambda x: x.mean() * 100),
    )
    .sort_values("three_bracket_accuracy_pct", ascending=False)
)

three_bracket_accuracy

# %% [markdown]
# # Station Stacking v18 Wunderground Physics - KDAL
#
# Experimental notebook for `KDAL`.
#
# This v18 run keeps the v11 remaining-warmup ridge-stack backbone, requires Wunderground station-history labels, adds NBM hourly curve and HRRR/RAP physics shard features, and writes isolated artifacts to `data/calibration/station_stacking_v18`.

# %%
from pathlib import Path
import os
import sys
import warnings

warnings.filterwarnings("ignore", message="IProgress not found.*")
warnings.filterwarnings("ignore", message="Skipping features without any observed values.*")

PROJECT_ROOT = Path.cwd().resolve()
while not (PROJECT_ROOT / "src" / "calibration" / "station_stacking.py").exists():
    if PROJECT_ROOT.parent == PROJECT_ROOT:
        raise RuntimeError("Could not find project root containing src/calibration/station_stacking.py")
    PROJECT_ROOT = PROJECT_ROOT.parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

os.environ["WEATHER_RESEARCH_INCLUDE_DIRECT_NBM"] = "1"

STATION_ID = "KDAL"
PROVIDERS = ("gfs", "hrrr", "nbm")
TREND_COLUMNS = [
    "observed_temp_change_last_1h_f",
    "observed_temp_change_last_3h_f",
    "observed_morning_warmup_rate_f_per_hour",
    "observed_high_so_far_change_since_9am_f",
]
TIMING_MODE = "same_day_11am_live_safe"
FAST_MODE = False
OPTUNA_TRIALS = 100
STACK_OPTUNA_TRIALS = 100
OPTUNA_STARTUP_TRIALS = 40
STACK_OPTUNA_STARTUP_TRIALS = 40
OPTUNA_METRIC = "mae_f"
OPTUNA_VERBOSE = True
MODEL_VERSION = "station_high_regressor_v18_nbm_hrrr_physics_settlement_stack"
PROJECT_ROOT
# Out:
# WindowsPath('D:/dev/weather-research')

# %%
import numpy as np
import pandas as pd

from src.export_station_stacking_v2_models import export_station_model_weights
from src.calibration.station_stacking import (
    StationStackingConfig,
    V11_DROPPED_FEATURE_COLUMNS,
    V11_FEATURE_COLUMNS,
    YEAR_SPLIT_EXPANDING_FOLDS,
    missing_model_dependencies,
    provider_availability,
    run_station_year_split_experiment,
)

# %% [markdown]
# ## V11 Contract
#
# `feature_version="v18"` adds coverage-gated NBM hourly curve and HRRR/RAP physics features while selecting by validation MAE.

# %%
fold_spec = pd.DataFrame(
    [
        {
            "fold": fold.name,
            "train_start_year": fold.train_start_year,
            "train_end_year": fold.train_end_year,
            "validation_year": fold.validation_year,
        }
        for fold in YEAR_SPLIT_EXPANDING_FOLDS
    ]
)

fold_spec
# Out:
#                      fold  train_start_year  train_end_year  validation_year
# 0  fold_2021_2023_to_2024              2021            2023             2024
# 1  fold_2021_2024_to_2025              2021            2024             2025

# %%
V11_FEATURE_COLUMNS, sorted(V11_DROPPED_FEATURE_COLUMNS)
# Out:
# (['v2_recent_heat_anomaly_f',
#   'v2_recent_heat_momentum_f',
#   'v2_morning_warmup_to_consensus_f',
#   'v2_consensus_minus_7d_actual_f',
#   'v2_spread_per_warmup_f',
#   'v2_humidity_warmup_interaction',
#   'v3_high_so_far_above_current_f',
#   'v3_remaining_warmup_from_high_so_far_f',
#   'v3_high_so_far_minus_lag_1d_f',
#   'v3_high_so_far_minus_7d_actual_f',
#   'v3_remaining_warmup_per_spread_f',
#   'v3_humidity_remaining_warmup_interaction',
#   'v4_forecast_precip_total_mean_mm',
#   'v4_forecast_precip_total_max_mm',
#   'v4_forecast_precip_total_spread_mm',
#   'v4_forecast_precip_max_1h_mean_mm',
#   'v4_forecast_precip_hours_mean',
#   'v4_forecast_precip_intensity_mean',
#   'v4_forecast_precip_intensity_max',
#   'v4_any_forecast_precip',
#   'v4_all_forecast_precip',
#   'v4_observed_precip_any',
#   'v4_observed_precip_recent_mm_est',
#   'v4_forecast_total_minus_observed_recent_mm',
#   'v4_forecast_observed_precip_match',
#   'v4_forecast_wet_observed_dry',
#   'v4_observed_wet_forecast_dry',
#   'v4_precip_humidity_interaction',
#   'v4_precip_remaining_warmup_interaction',
#   'observed_temp_change_last_1h_f',
#   'observed_temp_change_last_3h_f',
#   'observed_morning_warmup_rate_f_per_hour',
#   'observed_high_so_far_change_since_9am_f',
#   'v8_provider_max_remaining_from_high_so_far_f',
#   'v8_provider_min_remaining_from_high_so_far_f',
#   'v8_provider_median_remaining_from_high_so_far_f',
#   'v8_provider_spread_per_remaining_warmup_f',
#   'v8_month_remaining_warmup_mean_f',
#   'v8_month_remaining_warmup_count',
#   'v8_recent_remaining_warmup_7d_mean_f',
#   'v8_recent_remaining_warmup_30d_mean_f',
#   'v8_provider_mean_remaining_vs_month_normal_f',
#   'v8_cloud_cover_mean_remaining_warmup_interaction',
#   'v8_cloud_cover_max_remaining_warmup_interaction',
#   'v8_precip_total_remaining_warmup_interaction',
#   'v8_precip_max_1h_remaining_warmup_interaction',
#   'v8_wind_speed_mean_remaining_warmup_interaction',
#   'v8_wind_gust_max_remaining_warmup_interaction',
#   'v8_forecast_dewpoint_mean_f',
#   'v8_forecast_dewpoint_depression_mean_f',
#   'v8_dewpoint_mean_remaining_warmup_interaction',
#   'v8_dewpoint_depression_remaining_warmup_interaction',
#   'climatology_high_10y_f',
#   'climatology_high_10y_std_f',
#   'climatology_high_10y_count',
#   'provider_mean_minus_climatology_10y_f',
#   'observed_temp_minus_climatology_10y_f',
#   'observed_high_so_far_minus_climatology_10y_f'],
#  ['actual_minus_climatology_10y_f_DIAGNOSTIC_ONLY',
#   'climatology_source_end_year',
#   'climatology_source_start_year',
#   'gfs_as_of_hour_local',
#   'gfs_available',
#   'gfs_forecast_window_hours',
#   'gfs_grid_dist_km_mean',
#   'gfs_horizon_hours',
#   'gfs_hrrr_grid_dist_km_mean_abs_diff_f',
#   'gfs_hrrr_grid_dist_km_mean_diff_f',
#   'gfs_issue_hour_utc',
#   'gfs_missing',
#   'hrrr_as_of_hour_local',
#   'hrrr_available',
#   'hrrr_forecast_hour_max',
#   'hrrr_forecast_hour_min',
#   'hrrr_forecast_lead_hours',
#   'hrrr_forecast_window_hours',
#   'hrrr_grid_dist_km_mean',
#   'hrrr_horizon_hours',
#   'hrrr_issue_hour_local',
#   'hrrr_issue_hour_utc',
#   'hrrr_missing',
#   'is_active_polymarket_station',
#   'lat',
#   'lon',
#   'nbm_as_of_hour_local',
#   'nbm_available',
#   'nbm_forecast_window_hours',
#   'nbm_horizon_hours',
#   'nbm_issue_hour_local',
#   'nbm_issue_hour_utc',
#   'nbm_missing',
#   'observed_fetch_status',
#   'observed_observation_type',
#   'observed_pressure_source',
#   'provider_count_available',
#   'year'])

# %% [markdown]
# ## Data Availability

# %%
availability = provider_availability(
    PROJECT_ROOT,
    timing_mode=TIMING_MODE,
    providers=PROVIDERS,
)

availability.loc[availability["station_id"].eq(STATION_ID)]
# Out:
#   station_id provider  row_count first_contract_date last_contract_date
# 6       KDAL      gfs       1992          2021-01-01         2026-06-21
# 7       KDAL     hrrr       1998          2021-01-01         2026-06-21
# 8       KDAL      nbm       1997          2021-01-01         2026-06-21

# %% [markdown]
# ## Model Scores

# %%
missing_packages = missing_model_dependencies()
if missing_packages:
    raise ImportError(
        "Missing station-stacking ML packages: "
        + ", ".join(missing_packages)
        + ". Install them with: python -m pip install -r requirements.txt"
    )

config = StationStackingConfig(
    station_id=STATION_ID,
    project_root=PROJECT_ROOT,
    timing_mode=TIMING_MODE,
    providers=PROVIDERS,
    fast_mode=FAST_MODE,
    optuna_trials=OPTUNA_TRIALS,
    stack_optuna_trials=STACK_OPTUNA_TRIALS,
    optuna_startup_trials=OPTUNA_STARTUP_TRIALS,
    stack_optuna_startup_trials=STACK_OPTUNA_STARTUP_TRIALS,
    optuna_metric=OPTUNA_METRIC,
    optuna_verbose=OPTUNA_VERBOSE,
    feature_version="v18",
    target_mode="remaining_warmup",
    target_source="wunderground_only",
    base_model_methods=("xgboost", "lightgbm", "catboost"),
    stack_enabled=True,
    hyperparameter_space="wide_plus",
    year_split_folds=YEAR_SPLIT_EXPANDING_FOLDS,
    year_split_test_train_years=(2021, 2025),
    year_split_test_year=2026,
    output_dir=PROJECT_ROOT / "data" / "calibration" / "station_stacking_v18",
)

config.resolved_optuna_storage_path()
# Out:
# WindowsPath('D:/dev/weather-research/data/calibration/station_stacking_v18/KDAL_optuna.sqlite3')

# %%
result = run_station_year_split_experiment(config)
result.scoreboard
# Out:
# [I 2026-07-10 01:57:42,742] A new study created in RDB with name: KDAL_v18_remaining_warmup_base_xgboost_mae_f_wide_plus
# [I 2026-07-10 01:57:54,464] Trial 0 finished with value: 1.5556899323499416 and parameters: {'n_estimators': 2278, 'learning_rate': 0.18404304074388048, 'max_depth': 9, 'min_child_weight': 2.481040974867813, 'gamma': 2.340279606636548, 'subsample': 0.4513964382185317, 'colsample_bytree': 0.3877543479093296, 'reg_alpha': 2.478071022662141, 'reg_lambda': 0.6132587025321562}. Best is trial 0 with value: 1.5556899323499416.
# [I 2026-07-10 01:58:29,373] Trial 1 finished with value: 1.4891128048431743 and parameters: {'n_estimators': 4263, 'learning_rate': 0.0005682336350005583, 'max_depth': 12, 'min_child_weight': 21.368329072358772, 'gamma': 3.185086660174142, 'subsample': 0.4681862286846154, 'colsample_bytree': 0.46921293140473197, 'reg_alpha': 4.476173538513514e-07, 'reg_lambda': 0.20253776634919213}. Best is trial 1 with value: 1.4891128048431743.
# [I 2026-07-10 01:58:40,970] Trial 2 finished with value: 1.3250396228121124 and parameters: {'n_estimators': 2620, 'learning_rate': 0.0030548417550612453, 'max_depth': 8, 'min_child_weight': 0.03613894271216528, 'gamma': 4.3821697280282725, 'subsample': 0.5881351981408995, 'colsample_bytree': 0.6464454897410734, 'reg_alpha': 0.26430874752361627, 'reg_lambda': 0.0018119678627933364}. Best is trial 2 with value: 1.3250396228121124.
# [I 2026-07-10 01:58:46,759] Trial 3 finished with value: 1.7508032919974115 and parameters: {'n_estimators': 3110, 'learning_rate': 0.019855423553962363, 'max_depth': 1, 'min_child_weight': 2.69264691008618, 'gamma': 2.557861855309373, 'subsample': 0.39228353544043165, 'colsample_bytree': 0.9667755992146666, 'reg_alpha': 38.6887231523051, 'reg_lambda': 12.408975837016275}. Best is trial 2 with value: 1.3250396228121124.
# [I 2026-07-10 01:59:11,168] Trial 4 finished with value: 1.4778311873473495 and parameters: {'n_estimators': 1862, 'learning_rate': 0.0009174536024527723, 'max_depth': 9, 'min_child_weight': 0.5762487216478605, 'gamma': 1.8305735226716824, 'subsample': 0.6718649915723256, 'colsample_bytree': 0.37235253872489193, 'reg_alpha': 8.162906555194692, 'reg_lambda': 0.004271500153828077}. Best is trial 2 with value: 1.3250396228121124.
# [I 2026-07-10 01:59:33,807] Trial 5 finished with value: 1.4317379941750359 and parameters: {'n_estimators': 3992, 'learning_rate': 0.0034695156333098714, 'max_depth': 7, 'min_child_weight': 1.5375920235481764, 'gamma': 2.7728168328829055, 'subsample': 0.980230008046963, 'colsample_bytree': 0.8538363351847245, 'reg_alpha': 18.792618557420877, 'reg_lambda': 43.484449457612314}. Best is trial 2 with value: 1.3250396228121124.
# [I 2026-07-10 01:59:35,573] Trial 6 finished with value: 1.2831878753702393 and parameters: {'n_estimators': 3608, 'learning_rate': 0.15384412371507689, 'max_depth': 2, 'min_child_weight': 0.06080390190296603, 'gamma': 0.678409333658071, 'subsample': 0.5614647149961218, 'colsample_bytree': 0.6026402382981633, 'reg_alpha': 1.8037999945880162e-07, 'reg_lambda': 16.668629892722056}. Best is trial 6 with value: 1.2831878753702393.
# [I 2026-07-10 01:59:42,866] Trial 7 finished with value: 1.3643606415617915 and parameters: {'n_estimators': 2173, 'learning_rate': 0.0028655224755223816, 'max_depth': 7, 'min_child_weight': 0.0366181922039243, 'gamma': 12.032954711310595, 'subsample': 0.398457918391851, 'colsample_bytree': 0.9914765087903362, 'reg_alpha': 0.18490013641000916, 'reg_lambda': 0.0017869543989965139}. Best is trial 6 with value: 1.2831878753702393.
# [I 2026-07-10 01:59:43,535] Trial 8 pruned.
# [I 2026-07-10 01:59:54,987] Trial 9 finished with value: 1.373751981429459 and parameters: {'n_estimators': 3759, 'learning_rate': 0.003908893589205689, 'max_depth': 1, 'min_child_weight': 0.17535949529764422, 'gamma': 4.877749830401205, 'subsample': 0.8242440159197416, 'colsample_bytree': 0.7644123563808884, 'reg_alpha': 4.4315220126915325, 'reg_lambda': 0.09450187118503514}. Best is trial 6 with value: 1.2831878753702393.
# [I 2026-07-10 01:59:57,106] Trial 10 finished with value: 1.3878086554823996 and parameters: {'n_estimators': 761, 'learning_rate': 0.04207230350793264, 'max_depth': 10, 'min_child_weight': 1.7583640270008525, 'gamma': 11.564507699318415, 'subsample': 0.670967137636854, 'colsample_bytree': 0.689776339098296, 'reg_alpha': 1.3504926357029513e-05, 'reg_lambda': 0.0001445994629863374}. Best is trial 6 with value: 1.2831878753702393.
# [I 2026-07-10 02:00:03,629] Trial 11 pruned.
# [I 2026-07-10 02:00:10,158] Trial 12 pruned.
# [I 2026-07-10 02:00:12,216] Trial 13 finished with value: 1.3338460117291944 and parameters: {'n_estimators': 1160, 'learning_rate': 0.12822123876714564, 'max_depth': 7, 'min_child_weight': 16.973078532467014, 'gamma': 13.4413694988524, 'subsample': 0.5567022587317115, 'colsample_bytree': 0.4215337509429899, 'reg_alpha': 5.435280359192946e-08, 'reg_lambda': 0.049115547267693904}. Best is trial 6 with value: 1.2831878753702393.
# [I 2026-07-10 02:00:15,738] Trial 14 finished with value: 1.3359937132838704 and parameters: {'n_estimators': 4918, 'learning_rate': 0.10520976010930978, 'max_depth': 1, 'min_child_weight': 1.1040511903162256, 'gamma': 6.261165047231685, 'subsample': 0.49437007680597467, 'colsample_bytree': 0.4279124887668938, 'reg_alpha': 1.125594744942969e-06, 'reg_lambda': 87.35792858155622}. Best is trial 6 with value: 1.2831878753702393.
# [I 2026-07-10 02:00:17,690] Trial 15 pruned.
# [I 2026-07-10 02:00:51,012] Trial 16 finished with value: 1.3125015936855349 and parameters: {'n_estimators': 1745, 'learning_rate': 0.0006288206118124717, 'max_depth': 8, 'min_child_weight': 1.0249816559563216, 'gamma': 0.7721812687498403, 'subsample': 0.5311202017537975, 'colsample_bytree': 0.9403728258783249, 'reg_alpha': 7.494500415302305e-08, 'reg_lambda': 0.0008184401669032867}. Best is trial 6 with value: 1.2831878753702393.
# [I 2026-07-10 02:00:51,922] Trial 17 pruned.
# [I 2026-07-10 02:00:55,856] Trial 18 finished with value: 1.2666705843671173 and parameters: {'n_estimators': 3820, 'learning_rate': 0.013963998893741949, 'max_depth': 2, 'min_child_weight': 21.938654178115062, 'gamma': 4.811700974576038, 'subsample': 0.4712370317599052, 'colsample_bytree': 0.3765038420105965, 'reg_alpha': 0.0012322967930262527, 'reg_lambda': 1.859316691031827}. Best is trial 18 with value: 1.2666705843671173.
# [I 2026-07-10 02:00:56,619] Trial 19 pruned.
# [I 2026-07-10 02:01:07,075] Trial 20 pruned.
# [I 2026-07-10 02:01:10,184] Trial 21 pruned.
# [I 2026-07-10 02:01:11,131] Trial 22 pruned.
# [I 2026-07-10 02:01:20,230] Trial 23 pruned.
# [I 2026-07-10 02:01:21,862] Trial 24 finished with value: 1.2966571717181212 and parameters: {'n_estimators': 1986, 'learning_rate': 0.051728265370804466, 'max_depth': 8, 'min_child_weight': 24.939838794891504, 'gamma': 9.86419338450515, 'subsample': 0.7194005921680565, 'colsample_bytree': 0.4108885990882601, 'reg_alpha': 2.5857684771732316e-06, 'reg_lambda': 0.0046886527972766386}. Best is trial 18 with value: 1.2666705843671173.
# [I 2026-07-10 02:01:22,548] Trial 25 pruned.
# [I 2026-07-10 02:01:24,360] Trial 26 pruned.
# [I 2026-07-10 02:01:37,467] Trial 27 pruned.
# [I 2026-07-10 02:01:45,549] Trial 28 finished with value: 1.333572477559958 and parameters: {'n_estimators': 5115, 'learning_rate': 0.0035837110844026934, 'max_depth': 3, 'min_child_weight': 1.687349510456895, 'gamma': 14.042321612411715, 'subsample': 0.8024193678387325, 'colsample_bytree': 0.7205397605580872, 'reg_alpha': 1.4659458394743598e-09, 'reg_lambda': 0.7502033220845526}. Best is trial 18 with value: 1.2666705843671173.
# [I 2026-07-10 02:02:13,817] Trial 29 finished with value: 1.3137908483913379 and parameters: {'n_estimators': 5941, 'learning_rate': 0.001194132613025411, 'max_depth': 7, 'min_child_weight': 32.32155805617899, 'gamma': 11.111529266313067, 'subsample': 0.8030602316469242, 'colsample_bytree': 0.8066146545916211, 'reg_alpha': 2.0601261491259473e-06, 'reg_lambda': 0.007078333440672503}. Best is trial 18 with value: 1.2666705843671173.
# [I 2026-07-10 02:02:14,685] Trial 30 pruned.
# [I 2026-07-10 02:02:15,748] Trial 31 pruned.
# [I 2026-07-10 02:02:20,069] Trial 32 finished with value: 1.3364148381724954 and parameters: {'n_estimators': 1755, 'learning_rate': 0.01966125573748198, 'max_depth': 1, 'min_child_weight': 0.014105638677535273, 'gamma': 12.339008409894873, 'subsample': 0.5841239169173209, 'colsample_bytree': 0.43258933322372506, 'reg_alpha': 0.0001848924258849832, 'reg_lambda': 7.108082741221897}. Best is trial 18 with value: 1.2666705843671173.
# [I 2026-07-10 02:02:32,680] Trial 33 pruned.
# [I 2026-07-10 02:03:00,254] Trial 34 pruned.
# [I 2026-07-10 02:03:08,960] Trial 35 pruned.
# [I 2026-07-10 02:03:21,818] Trial 36 finished with value: 1.3247210027265957 and parameters: {'n_estimators': 5732, 'learning_rate': 0.04903787573670302, 'max_depth': 7, 'min_child_weight': 2.7982272717049295, 'gamma': 6.2940009364168485, 'subsample': 0.5110251431757523, 'colsample_bytree': 0.58138224112332, 'reg_alpha': 0.12420907443411108, 'reg_lambda': 0.00012322357473726174}. Best is trial 18 with value: 1.2666705843671173.
# [I 2026-07-10 02:03:29,692] Trial 37 pruned.
# [I 2026-07-10 02:03:51,579] Trial 38 finished with value: 1.2492589069875264 and parameters: {'n_estimators': 1080, 'learning_rate': 0.0074117812297848015, 'max_depth': 5, 'min_child_weight': 2.9067012153229124, 'gamma': 9.526404763014657, 'subsample': 0.3794476063518289, 'colsample_bytree': 0.5934981995072063, 'reg_alpha': 0.0032383142323839692, 'reg_lambda': 0.14800509200124298}. Best is trial 38 with value: 1.2492589069875264.
# [I 2026-07-10 02:03:55,059] Trial 39 pruned.
# [I 2026-07-10 02:04:01,621] Trial 40 pruned.
# [I 2026-07-10 02:06:10,334] Trial 41 finished with value: 1.2464220736437774 and parameters: {'n_estimators': 3377, 'learning_rate': 0.0017664741061053793, 'max_depth': 6, 'min_child_weight': 15.598643197521517, 'gamma': 0.3511651971340511, 'subsample': 0.6127791062662747, 'colsample_bytree': 0.47007870877754443, 'reg_alpha': 5.940497552118815e-08, 'reg_lambda': 1.800502919734144}. Best is trial 41 with value: 1.2464220736437774.
# [I 2026-07-10 02:06:41,966] Trial 42 finished with value: 1.2420218467319404 and parameters: {'n_estimators': 3555, 'learning_rate': 0.0018947530664553372, 'max_depth': 5, 'min_child_weight': 14.819999957375012, 'gamma': 0.7063723313013544, 'subsample': 0.6133073637338451, 'colsample_bytree': 0.46617287023958265, 'reg_alpha': 3.291138541989083e-08, 'reg_lambda': 1.8272587105707454}. Best is trial 42 with value: 1.2420218467319404.
# [I 2026-07-10 02:07:06,793] Trial 43 finished with value: 1.2580396779478722 and parameters: {'n_estimators': 3473, 'learning_rate': 0.0014489192785482156, 'max_depth': 5, 'min_child_weight': 14.737944093064105, 'gamma': 0.184325050070943, 'subsample': 0.6211662229651576, 'colsample_bytree': 0.4607144387785188, 'reg_alpha': 7.569648634340661e-09, 'reg_lambda': 1.8699303864106698}. Best is trial 42 with value: 1.2420218467319404.
# [I 2026-07-10 02:09:01,065] Trial 44 finished with value: 1.2466462068351891 and parameters: {'n_estimators': 3389, 'learning_rate': 0.0013949981341918785, 'max_depth': 5, 'min_child_weight': 10.439659637970058, 'gamma': 0.4491582829762939, 'subsample': 0.6289088973421539, 'colsample_bytree': 0.4657087036377633, 'reg_alpha': 9.697848083540297e-09, 'reg_lambda': 2.1858160039758374}. Best is trial 42 with value: 1.2420218467319404.
# [I 2026-07-10 02:11:54,555] Trial 45 finished with value: 1.2351597752424397 and parameters: {'n_estimators': 3439, 'learning_rate': 0.0016613557099930244, 'max_depth': 6, 'min_child_weight': 11.468433833007357, 'gamma': 0.2702725172801474, 'subsample': 0.6260849102742868, 'colsample_bytree': 0.4634490790871307, 'reg_alpha': 1.2642367118505469e-08, 'reg_lambda': 3.273946691608769}. Best is trial 45 with value: 1.2351597752424397.
# [I 2026-07-10 02:13:45,452] Trial 46 finished with value: 1.230369755213896 and parameters: {'n_estimators': 2576, 'learning_rate': 0.0021929201897045326, 'max_depth': 6, 'min_child_weight': 9.743867084590846, 'gamma': 1.62154499337455, 'subsample': 0.6252594666320369, 'colsample_bytree': 0.5513055068158655, 'reg_alpha': 7.86373238969304e-09, 'reg_lambda': 3.454068739282211}. Best is trial 46 with value: 1.230369755213896.
# [I 2026-07-10 02:15:54,376] Trial 47 finished with value: 1.219121751745825 and parameters: {'n_estimators': 3402, 'learning_rate': 0.0021266102182392436, 'max_depth': 6, 'min_child_weight': 9.375066816031312, 'gamma': 1.58436227484974, 'subsample': 0.6334648918219821, 'colsample_bytree': 0.47096676627441586, 'reg_alpha': 8.982222096313365e-09, 'reg_lambda': 3.5432592074413893}. Best is trial 47 with value: 1.219121751745825.
# [I 2026-07-10 02:16:36,838] Trial 48 finished with value: 1.234775732555094 and parameters: {'n_estimators': 2719, 'learning_rate': 0.0021982156830471877, 'max_depth': 6, 'min_child_weight': 5.89934600731832, 'gamma': 1.6736466049506469, 'subsample': 0.6268353234403964, 'colsample_bytree': 0.5552470199617383, 'reg_alpha': 4.664639536922072e-10, 'reg_lambda': 4.321893456482561}. Best is trial 47 with value: 1.219121751745825.
# [I 2026-07-10 02:17:08,842] Trial 49 finished with value: 1.240725142684366 and parameters: {'n_estimators': 2505, 'learning_rate': 0.0022662244747277825, 'max_depth': 6, 'min_child_weight': 7.34886247752127, 'gamma': 1.5623714971754417, 'subsample': 0.6449839417855328, 'colsample_bytree': 0.6348327999695315, 'reg_alpha': 2.3737033135500415e-10, 'reg_lambda': 5.028605016097174}. Best is trial 47 with value: 1.219121751745825.
# [I 2026-07-10 02:19:27,436] Trial 50 finished with value: 1.240262837806604 and parameters: {'n_estimators': 2627, 'learning_rate': 0.002475600032876819, 'max_depth': 6, 'min_child_weight': 6.8096892549093475, 'gamma': 1.2993431467258787, 'subsample': 0.6429838552945137, 'colsample_bytree': 0.6344736850462663, 'reg_alpha': 1.0656660471902059e-10, 'reg_lambda': 6.022368386985008}. Best is trial 47 with value: 1.219121751745825.
# [I 2026-07-10 02:20:33,608] Trial 51 finished with value: 1.2386671785708865 and parameters: {'n_estimators': 2564, 'learning_rate': 0.002465595525887401, 'max_depth': 6, 'min_child_weight': 6.129567113856277, 'gamma': 1.9472199701907191, 'subsample': 0.6475697494442596, 'colsample_bytree': 0.6355173908435534, 'reg_alpha': 1.5498051919147015e-10, 'reg_lambda': 5.685462684775016}. Best is trial 47 with value: 1.219121751745825.
# [I 2026-07-10 02:20:46,104] Trial 52 finished with value: 1.2345618152915203 and parameters: {'n_estimators': 2832, 'learning_rate': 0.005193278596186076, 'max_depth': 6, 'min_child_weight': 5.7934989707988676, 'gamma': 3.1565772643256262, 'subsample': 0.5429071061787196, 'colsample_bytree': 0.5566711641707706, 'reg_alpha': 5.332970759776386e-10, 'reg_lambda': 9.095444208681572}. Best is trial 47 with value: 1.219121751745825.
# [I 2026-07-10 02:21:28,589] Trial 53 finished with value: 1.2506133588074175 and parameters: {'n_estimators': 2916, 'learning_rate': 0.0028461631202945036, 'max_depth': 6, 'min_child_weight': 4.636773116699872, 'gamma': 3.2961309591670815, 'subsample': 0.5423351811307959, 'colsample_bytree': 0.5546679816448901, 'reg_alpha': 6.663082718397014e-10, 'reg_lambda': 9.468994849352336}. Best is trial 47 with value: 1.219121751745825.
# [I 2026-07-10 02:21:46,491] Trial 54 finished with value: 1.248550146212136 and parameters: {'n_estimators': 3129, 'learning_rate': 0.004886822152320498, 'max_depth': 4, 'min_child_weight': 10.618694952504033, 'gamma': 3.0009847989949385, 'subsample': 0.6042484627772923, 'colsample_bytree': 0.5429542166826686, 'reg_alpha': 7.570130960463152e-09, 'reg_lambda': 21.50426401547228}. Best is trial 47 with value: 1.219121751745825.
# [I 2026-07-10 02:21:59,512] Trial 55 finished with value: 1.2259659644567846 and parameters: {'n_estimators': 2842, 'learning_rate': 0.005024570909678855, 'max_depth': 7, 'min_child_weight': 5.128718553187732, 'gamma': 2.136391492163229, 'subsample': 0.5879255209112376, 'colsample_bytree': 0.5127107390843328, 'reg_alpha': 9.875701299424184e-10, 'reg_lambda': 3.6236063870437794}. Best is trial 47 with value: 1.219121751745825.
# [I 2026-07-10 02:22:17,086] Trial 56 finished with value: 1.2241911071558371 and parameters: {'n_estimators': 2783, 'learning_rate': 0.004911643957554809, 'max_depth': 7, 'min_child_weight': 3.720080898094739, 'gamma': 1.9984232234351316, 'subsample': 0.5883921029003708, 'colsample_bytree': 0.5050081130741556, 'reg_alpha': 7.976153368746582e-10, 'reg_lambda': 3.464418716950396}. Best is trial 47 with value: 1.219121751745825.
# [I 2026-07-10 02:22:24,958] Trial 57 finished with value: 1.227651255559803 and parameters: {'n_estimators': 2883, 'learning_rate': 0.00881193517734157, 'max_depth': 7, 'min_child_weight': 3.74643962514725, 'gamma': 2.0582868361628175, 'subsample': 0.5873302133946586, 'colsample_bytree': 0.510432946065105, 'reg_alpha': 1.8903227777059425e-09, 'reg_lambda': 1.0678912144096369}. Best is trial 47 with value: 1.219121751745825.
# [I 2026-07-10 02:22:32,608] Trial 58 finished with value: 1.2357272497134968 and parameters: {'n_estimators': 2349, 'learning_rate': 0.009415252749270403, 'max_depth': 7, 'min_child_weight': 1.075647117230404, 'gamma': 2.2135887257762197, 'subsample': 0.5835720978956197, 'colsample_bytree': 0.5010980594145777, 'reg_alpha': 2.5222757308086537e-09, 'reg_lambda': 1.0531460649432713}. Best is trial 47 with value: 1.219121751745825.
# [I 2026-07-10 02:22:40,935] Trial 59 pruned.
# [I 2026-07-10 02:22:58,598] Trial 60 finished with value: 1.2137431895683757 and parameters: {'n_estimators': 2813, 'learning_rate': 0.004880747690962087, 'max_depth': 8, 'min_child_weight': 3.6119071060699337, 'gamma': 0.981345073892947, 'subsample': 0.5613919442623359, 'colsample_bytree': 0.5263864484766331, 'reg_alpha': 7.477263711449283e-10, 'reg_lambda': 0.44843978699647724}. Best is trial 60 with value: 1.2137431895683757.
# [I 2026-07-10 02:23:17,864] Trial 61 finished with value: 1.211528307114124 and parameters: {'n_estimators': 3184, 'learning_rate': 0.004889500238311653, 'max_depth': 8, 'min_child_weight': 3.6154402055329817, 'gamma': 1.1092966867896117, 'subsample': 0.5527716199292303, 'colsample_bytree': 0.5200452298612918, 'reg_alpha': 7.096171303706606e-10, 'reg_lambda': 0.5082332728383907}. Best is trial 61 with value: 1.211528307114124.
# [I 2026-07-10 02:23:32,704] Trial 62 finished with value: 1.230645457885054 and parameters: {'n_estimators': 3865, 'learning_rate': 0.00957088258637111, 'max_depth': 8, 'min_child_weight': 3.775977506882844, 'gamma': 1.1024463694512892, 'subsample': 0.5579644164982589, 'colsample_bytree': 0.5198063006227853, 'reg_alpha': 3.800091690956091e-09, 'reg_lambda': 0.44742462747378753}. Best is trial 61 with value: 1.211528307114124.
# [I 2026-07-10 02:24:23,303] Trial 63 finished with value: 1.2084606821927149 and parameters: {'n_estimators': 3158, 'learning_rate': 0.0031394791910133997, 'max_depth': 9, 'min_child_weight': 3.529816442758447, 'gamma': 2.189265125146723, 'subsample': 0.5950682133127789, 'colsample_bytree': 0.4953945580625561, 'reg_alpha': 2.4250832952263178e-08, 'reg_lambda': 0.8816448858558161}. Best is trial 63 with value: 1.2084606821927149.
# [I 2026-07-10 02:24:45,299] Trial 64 finished with value: 1.2094914547166185 and parameters: {'n_estimators': 3134, 'learning_rate': 0.004201329782209997, 'max_depth': 9, 'min_child_weight': 3.6179538243622087, 'gamma': 2.420083715993084, 'subsample': 0.5164324212693088, 'colsample_bytree': 0.43936082796635084, 'reg_alpha': 2.5266624412954605e-08, 'reg_lambda': 1.2210848352439994}. Best is trial 63 with value: 1.2084606821927149.
# [I 2026-07-10 02:24:57,568] Trial 65 finished with value: 1.210012222539741 and parameters: {'n_estimators': 3169, 'learning_rate': 0.004457570047764707, 'max_depth': 9, 'min_child_weight': 2.1731535786958043, 'gamma': 2.601047515869387, 'subsample': 0.4988542352261167, 'colsample_bytree': 0.4856088927634633, 'reg_alpha': 1.31465338123198e-07, 'reg_lambda': 0.32863503912092884}. Best is trial 63 with value: 1.2084606821927149.
# [I 2026-07-10 02:25:15,382] Trial 66 finished with value: 1.209008201192396 and parameters: {'n_estimators': 3182, 'learning_rate': 0.003889387389632948, 'max_depth': 9, 'min_child_weight': 2.2084392715301253, 'gamma': 0.941598499609082, 'subsample': 0.42641727633640947, 'colsample_bytree': 0.4411621324591286, 'reg_alpha': 2.6545224517660105e-08, 'reg_lambda': 0.3274215129971734}. Best is trial 63 with value: 1.2084606821927149.
# [I 2026-07-10 02:25:34,393] Trial 67 finished with value: 1.2173624641161698 and parameters: {'n_estimators': 3300, 'learning_rate': 0.004064458974906469, 'max_depth': 9, 'min_child_weight': 0.6635129355454387, 'gamma': 1.0491734946313722, 'subsample': 0.43836838793858396, 'colsample_bytree': 0.4453116028082219, 'reg_alpha': 1.6914768181801713e-07, 'reg_lambda': 0.33440891311002746}. Best is trial 63 with value: 1.2084606821927149.
# [I 2026-07-10 02:26:23,281] Trial 68 finished with value: 1.2060919734860187 and parameters: {'n_estimators': 3223, 'learning_rate': 0.0030547641485373185, 'max_depth': 10, 'min_child_weight': 0.8434988622410096, 'gamma': 1.0006370338961779, 'subsample': 0.43171847550855774, 'colsample_bytree': 0.4424781860179772, 'reg_alpha': 3.391580244869111e-07, 'reg_lambda': 0.33097225886549186}. Best is trial 68 with value: 1.2060919734860187.
# [I 2026-07-10 02:26:44,419] Trial 69 finished with value: 1.2148942972678733 and parameters: {'n_estimators': 3689, 'learning_rate': 0.0032048864857863713, 'max_depth': 10, 'min_child_weight': 0.7922240806491708, 'gamma': 2.5308730198977347, 'subsample': 0.4261767013533312, 'colsample_bytree': 0.4029602177138211, 'reg_alpha': 7.258400427035703e-07, 'reg_lambda': 0.6780863579341492}. Best is trial 68 with value: 1.2060919734860187.
# [I 2026-07-10 02:26:54,839] Trial 70 finished with value: 1.2135003900003958 and parameters: {'n_estimators': 3213, 'learning_rate': 0.0057241819220564686, 'max_depth': 9, 'min_child_weight': 1.8874017625913242, 'gamma': 4.387296505787196, 'subsample': 0.4849043007931654, 'colsample_bytree': 0.35049101554245893, 'reg_alpha': 2.4840570596679518e-08, 'reg_lambda': 0.07229512355072722}. Best is trial 68 with value: 1.2060919734860187.
# [I 2026-07-10 02:27:06,991] Trial 71 finished with value: 1.2215712315002634 and parameters: {'n_estimators': 3244, 'learning_rate': 0.006607187181380239, 'max_depth': 9, 'min_child_weight': 2.1950058566133754, 'gamma': 5.624058135201518, 'subsample': 0.4856177468070041, 'colsample_bytree': 0.43831420140058686, 'reg_alpha': 2.856821941386499e-08, 'reg_lambda': 0.048761930372636535}. Best is trial 68 with value: 1.2060919734860187.
# [I 2026-07-10 02:27:29,870] Trial 72 finished with value: 1.2229545522308305 and parameters: {'n_estimators': 3124, 'learning_rate': 0.002935645858128762, 'max_depth': 10, 'min_child_weight': 1.4904491983136963, 'gamma': 4.367182566645997, 'subsample': 0.5126209131572477, 'colsample_bytree': 0.3927050618696554, 'reg_alpha': 1.90999907377296e-07, 'reg_lambda': 0.2501022534532594}. Best is trial 68 with value: 1.2060919734860187.
# [I 2026-07-10 02:27:58,527] Trial 73 finished with value: 1.2234871175896969 and parameters: {'n_estimators': 2393, 'learning_rate': 0.003926637108948292, 'max_depth': 8, 'min_child_weight': 1.3352354725587796, 'gamma': 2.725074729418744, 'subsample': 0.48020119301405334, 'colsample_bytree': 0.4842264760282909, 'reg_alpha': 2.5609212392674865e-08, 'reg_lambda': 0.0169143752158711}. Best is trial 68 with value: 1.2060919734860187.
# [I 2026-07-10 02:28:08,337] Trial 74 pruned.
# [I 2026-07-10 02:28:26,664] Trial 75 finished with value: 1.2106551403840902 and parameters: {'n_estimators': 3606, 'learning_rate': 0.004185872937507354, 'max_depth': 9, 'min_child_weight': 2.103022083983463, 'gamma': 0.011342882602572102, 'subsample': 0.42046935777754063, 'colsample_bytree': 0.38667657988901044, 'reg_alpha': 1.0773127168739486e-07, 'reg_lambda': 0.07475986904631997}. Best is trial 68 with value: 1.2060919734860187.
# [I 2026-07-10 02:29:04,819] Trial 76 finished with value: 1.2259245990173746 and parameters: {'n_estimators': 3659, 'learning_rate': 0.004209835567986709, 'max_depth': 11, 'min_child_weight': 1.9822755985807279, 'gamma': 3.380463550699466, 'subsample': 0.41031927101334853, 'colsample_bytree': 0.3528761951925013, 'reg_alpha': 8.310033440665838e-06, 'reg_lambda': 0.07538780620200773}. Best is trial 68 with value: 1.2060919734860187.
# [I 2026-07-10 02:29:16,657] Trial 77 finished with value: 1.220733716567303 and parameters: {'n_estimators': 4565, 'learning_rate': 0.0033177884476641843, 'max_depth': 9, 'min_child_weight': 0.8104762746320138, 'gamma': 4.392998540617293, 'subsample': 0.46432428961184863, 'colsample_bytree': 0.3859896556890802, 'reg_alpha': 1.1729355553148498e-07, 'reg_lambda': 0.06783026727084421}. Best is trial 68 with value: 1.2060919734860187.
# [I 2026-07-10 02:29:29,442] Trial 78 finished with value: 1.2060872140895207 and parameters: {'n_estimators': 3876, 'learning_rate': 0.005969558865520095, 'max_depth': 9, 'min_child_weight': 2.6911888243583504, 'gamma': 0.1005092523583595, 'subsample': 0.44043730386447627, 'colsample_bytree': 0.4460157991998878, 'reg_alpha': 1.083800881713443e-06, 'reg_lambda': 0.014219775286369815}. Best is trial 78 with value: 1.2060872140895207.
# [I 2026-07-10 02:29:39,679] Trial 79 finished with value: 1.2376199815040556 and parameters: {'n_estimators': 3925, 'learning_rate': 0.007677114290185189, 'max_depth': 10, 'min_child_weight': 1.310382555872316, 'gamma': 0.19533602814056206, 'subsample': 0.4175477528993296, 'colsample_bytree': 0.48745024757237426, 'reg_alpha': 5.596296939016384e-07, 'reg_lambda': 0.015704863236606092}. Best is trial 78 with value: 1.2060872140895207.
# [I 2026-07-10 02:29:47,648] Trial 80 finished with value: 1.2144342899971876 and parameters: {'n_estimators': 4368, 'learning_rate': 0.01308621308808556, 'max_depth': 11, 'min_child_weight': 2.71644861970748, 'gamma': 0.5915820708294204, 'subsample': 0.4462477969629091, 'colsample_bytree': 0.44622914550946013, 'reg_alpha': 1.1997538180329304e-06, 'reg_lambda': 0.18451228370143966}. Best is trial 78 with value: 1.2060872140895207.
# [I 2026-07-10 02:30:17,260] Trial 81 finished with value: 1.2188658771121486 and parameters: {'n_estimators': 3762, 'learning_rate': 0.0027389436957954267, 'max_depth': 9, 'min_child_weight': 2.643422504620435, 'gamma': 1.1784464510090107, 'subsample': 0.3553342422396234, 'colsample_bytree': 0.42764104482304, 'reg_alpha': 8.168047878803645e-08, 'reg_lambda': 1.2308712514618372}. Best is trial 78 with value: 1.2060872140895207.
# [I 2026-07-10 02:30:30,634] Trial 82 finished with value: 1.2160428136992423 and parameters: {'n_estimators': 3060, 'learning_rate': 0.0056140919689530245, 'max_depth': 9, 'min_child_weight': 1.8148083301813915, 'gamma': 0.020934722368100546, 'subsample': 0.3913649429227099, 'colsample_bytree': 0.40330652479789303, 'reg_alpha': 3.924903775519553e-07, 'reg_lambda': 0.5507147600515161}. Best is trial 78 with value: 1.2060872140895207.
# [I 2026-07-10 02:30:36,185] Trial 83 finished with value: 1.2251117574614934 and parameters: {'n_estimators': 3246, 'learning_rate': 0.010939067839321923, 'max_depth': 8, 'min_child_weight': 0.9165779465445105, 'gamma': 0.7226941030944478, 'subsample': 0.42905107473599635, 'colsample_bytree': 0.41945962945665116, 'reg_alpha': 1.995334708578289e-08, 'reg_lambda': 0.01137650783462833}. Best is trial 78 with value: 1.2060872140895207.
# [I 2026-07-10 02:30:49,834] Trial 84 finished with value: 1.2169208491960881 and parameters: {'n_estimators': 4041, 'learning_rate': 0.0035054936119616725, 'max_depth': 9, 'min_child_weight': 3.0896647289407033, 'gamma': 2.712177084128351, 'subsample': 0.4949647399922369, 'colsample_bytree': 0.37651922528480647, 'reg_alpha': 5.214332197047519e-06, 'reg_lambda': 0.2853042448707102}. Best is trial 78 with value: 1.2060872140895207.
# [I 2026-07-10 02:31:01,322] Trial 85 finished with value: 1.2688504166642183 and parameters: {'n_estimators': 4288, 'learning_rate': 0.00427550065416159, 'max_depth': 10, 'min_child_weight': 0.3968790505372586, 'gamma': 0.010983717959182182, 'subsample': 0.4625834819579826, 'colsample_bytree': 0.4487280877804413, 'reg_alpha': 4.779956986519765e-08, 'reg_lambda': 0.031690563771355734}. Best is trial 78 with value: 1.2060872140895207.
# [I 2026-07-10 02:31:08,545] Trial 86 finished with value: 1.2225949055328198 and parameters: {'n_estimators': 3522, 'learning_rate': 0.006540148070708093, 'max_depth': 9, 'min_child_weight': 1.1303688343078642, 'gamma': 1.3658285666985073, 'subsample': 0.5219373484312624, 'colsample_bytree': 0.48458477119584287, 'reg_alpha': 1.179928591294891e-06, 'reg_lambda': 0.002777875548197158}. Best is trial 78 with value: 1.2060872140895207.
# [I 2026-07-10 02:31:14,337] Trial 87 finished with value: 1.2197726969749942 and parameters: {'n_estimators': 3615, 'learning_rate': 0.008248924505530447, 'max_depth': 8, 'min_child_weight': 2.26381702021509, 'gamma': 3.6412551177896018, 'subsample': 0.49446591290960684, 'colsample_bytree': 0.40000168424512594, 'reg_alpha': 4.4773570394176756e-09, 'reg_lambda': 0.8618378867541578}. Best is trial 78 with value: 1.2060872140895207.
# [I 2026-07-10 02:31:22,879] Trial 88 finished with value: 1.223581996884115 and parameters: {'n_estimators': 3013, 'learning_rate': 0.005817049380486189, 'max_depth': 10, 'min_child_weight': 4.573634315926354, 'gamma': 2.451711290772738, 'subsample': 0.3801187936894765, 'colsample_bytree': 0.4203256476041935, 'reg_alpha': 8.847964335487516e-08, 'reg_lambda': 0.11722622601262662}. Best is trial 78 with value: 1.2060872140895207.
# [I 2026-07-10 02:31:35,287] Trial 89 finished with value: 1.2111282435241717 and parameters: {'n_estimators': 3284, 'learning_rate': 0.004252475662528351, 'max_depth': 9, 'min_child_weight': 1.740218818065845, 'gamma': 1.8530643517204954, 'subsample': 0.4763177137933337, 'colsample_bytree': 0.386808077983758, 'reg_alpha': 1.166572314269664, 'reg_lambda': 0.05473627394502443}. Best is trial 78 with value: 1.2060872140895207.
# [I 2026-07-10 02:31:37,013] Trial 90 pruned.
# [I 2026-07-10 02:31:48,189] Trial 91 pruned.
# [I 2026-07-10 02:31:58,040] Trial 92 finished with value: 1.2034087179440514 and parameters: {'n_estimators': 3334, 'learning_rate': 0.004233738063340258, 'max_depth': 9, 'min_child_weight': 1.4600154577667597, 'gamma': 2.9255270935110387, 'subsample': 0.4749391654529534, 'colsample_bytree': 0.36828321723965907, 'reg_alpha': 1.5199590883559594e-08, 'reg_lambda': 0.18397011124652143}. Best is trial 92 with value: 1.2034087179440514.
# [I 2026-07-10 02:32:14,282] Trial 93 finished with value: 1.2213953951851895 and parameters: {'n_estimators': 3343, 'learning_rate': 0.004295366982682674, 'max_depth': 10, 'min_child_weight': 3.2231848443363584, 'gamma': 1.4316123563676921, 'subsample': 0.4752748142987219, 'colsample_bytree': 0.4784062450629121, 'reg_alpha': 3.386129278970354e-07, 'reg_lambda': 0.17120314447519344}. Best is trial 92 with value: 1.2034087179440514.
# [I 2026-07-10 02:32:29,658] Trial 94 finished with value: 1.2067522161400743 and parameters: {'n_estimators': 3529, 'learning_rate': 0.0027622284619524076, 'max_depth': 9, 'min_child_weight': 1.2839945105940769, 'gamma': 2.2309173523338837, 'subsample': 0.40550751220792847, 'colsample_bytree': 0.4294151008059932, 'reg_alpha': 4.171059965526329e-09, 'reg_lambda': 0.3520503924500959}. Best is trial 92 with value: 1.2034087179440514.
# [I 2026-07-10 02:32:51,028] Trial 95 finished with value: 1.2097714223096578 and parameters: {'n_estimators': 3471, 'learning_rate': 0.001877884316415635, 'max_depth': 9, 'min_child_weight': 1.3823330767111128, 'gamma': 2.9849001733951614, 'subsample': 0.4142099132396758, 'colsample_bytree': 0.4300226377994209, 'reg_alpha': 0.42491884107992295, 'reg_lambda': 0.34666010149996146}. Best is trial 92 with value: 1.2034087179440514.
# [I 2026-07-10 02:33:12,155] Trial 96 finished with value: 1.207891838539975 and parameters: {'n_estimators': 3515, 'learning_rate': 0.0018955596027177327, 'max_depth': 9, 'min_child_weight': 1.3001413353736095, 'gamma': 2.9655318728768703, 'subsample': 0.4141488767268201, 'colsample_bytree': 0.42485556707387917, 'reg_alpha': 1.557912112241306e-08, 'reg_lambda': 0.33849319490641316}. Best is trial 92 with value: 1.2034087179440514.
# [I 2026-07-10 02:33:41,810] Trial 97 finished with value: 1.2138186481816613 and parameters: {'n_estimators': 3549, 'learning_rate': 0.0012549546748273346, 'max_depth': 9, 'min_child_weight': 1.3235393431332034, 'gamma': 2.8817493417574016, 'subsample': 0.40281088874755416, 'colsample_bytree': 0.4389796559822882, 'reg_alpha': 1.609926132144171e-08, 'reg_lambda': 0.36728903502393667}. Best is trial 92 with value: 1.2034087179440514.
# [I 2026-07-10 02:34:07,324] Trial 98 finished with value: 1.2119371942204558 and parameters: {'n_estimators': 3473, 'learning_rate': 0.0017104190831413433, 'max_depth': 10, 'min_child_weight': 1.0553811775187059, 'gamma': 3.406806291013705, 'subsample': 0.3868496424319119, 'colsample_bytree': 0.43080942112572274, 'reg_alpha': 4.976732741013696e-09, 'reg_lambda': 0.6375244807801949}. Best is trial 92 with value: 1.2034087179440514.
# [I 2026-07-10 02:34:25,126] Trial 99 pruned.
# [I 2026-07-10 02:34:25,203] A new study created in RDB with name: KDAL_v18_remaining_warmup_base_lightgbm_mae_f_wide_plus
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-10 02:34:27,764] Trial 0 finished with value: 1.3169723738432002 and parameters: {'n_estimators': 447, 'learning_rate': 0.028873871707375695, 'num_leaves': 71, 'max_depth': 5, 'min_child_samples': 83, 'min_split_gain': 4.295687454742988, 'bagging_fraction': 0.7829586385137167, 'bagging_freq': 4, 'feature_fraction': 0.3688589858758342, 'lambda_l1': 0.06382334403151436, 'lambda_l2': 0.03080292177315921, 'huber_alpha': 0.95}. Best is trial 0 with value: 1.3169723738432002.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-10 02:34:30,570] Trial 1 finished with value: 1.7789095949447078 and parameters: {'n_estimators': 812, 'learning_rate': 0.009357081249483435, 'num_leaves': 164, 'max_depth': 2, 'min_child_samples': 211, 'min_split_gain': 4.244695738724308, 'bagging_fraction': 0.9814523094330022, 'bagging_freq': 3, 'feature_fraction': 0.9704172813206324, 'lambda_l1': 2.234088279028776e-05, 'lambda_l2': 1.6594154120142632, 'huber_alpha': 0.85}. Best is trial 0 with value: 1.3169723738432002.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-10 02:34:31,506] Trial 2 finished with value: 2.5858106815141513 and parameters: {'n_estimators': 67, 'learning_rate': 0.02007090910723469, 'num_leaves': 246, 'max_depth': 10, 'min_child_samples': 245, 'min_split_gain': 4.543313789155439, 'bagging_fraction': 0.9415994992571017, 'bagging_freq': 4, 'feature_fraction': 0.41761231740559585, 'lambda_l1': 1.4824332354449863e-08, 'lambda_l2': 101.18939970488272, 'huber_alpha': 0.85}. Best is trial 0 with value: 1.3169723738432002.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-10 02:34:32,689] Trial 3 finished with value: 1.6520599176268103 and parameters: {'n_estimators': 1000, 'learning_rate': 0.1413663860910666, 'num_leaves': 109, 'max_depth': 7, 'min_child_samples': 249, 'min_split_gain': 3.678635407535604, 'bagging_fraction': 0.6392899181182937, 'bagging_freq': 4, 'feature_fraction': 0.6173160679063129, 'lambda_l1': 0.052948773379180566, 'lambda_l2': 0.032760577756785814, 'huber_alpha': 0.85}. Best is trial 0 with value: 1.3169723738432002.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-10 02:34:34,752] Trial 4 finished with value: 2.3851595593893786 and parameters: {'n_estimators': 761, 'learning_rate': 0.003003151716938294, 'num_leaves': 409, 'max_depth': 5, 'min_child_samples': 165, 'min_split_gain': 1.498083879035124, 'bagging_fraction': 0.44391094597483866, 'bagging_freq': 3, 'feature_fraction': 0.5516751924489833, 'lambda_l1': 8.332516750396116e-08, 'lambda_l2': 0.5077631895453656, 'huber_alpha': 0.85}. Best is trial 0 with value: 1.3169723738432002.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-10 02:34:35,927] Trial 5 finished with value: 1.2972043438971494 and parameters: {'n_estimators': 404, 'learning_rate': 0.18314620854695027, 'num_leaves': 260, 'max_depth': 13, 'min_child_samples': 51, 'min_split_gain': 2.972245934092154, 'bagging_fraction': 0.9775155780902212, 'bagging_freq': 7, 'feature_fraction': 0.365709606237354, 'lambda_l1': 5.9654059281874116e-05, 'lambda_l2': 0.006859036422781172, 'huber_alpha': 0.95}. Best is trial 5 with value: 1.2972043438971494.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-10 02:34:37,361] Trial 6 finished with value: 1.2811271683373056 and parameters: {'n_estimators': 3052, 'learning_rate': 0.13146898336096702, 'num_leaves': 489, 'max_depth': 11, 'min_child_samples': 47, 'min_split_gain': 2.173391605434026, 'bagging_fraction': 0.9258346721061177, 'bagging_freq': 2, 'feature_fraction': 0.6381532515738396, 'lambda_l1': 0.002530717742378322, 'lambda_l2': 0.0004479476588817844, 'huber_alpha': 0.95}. Best is trial 6 with value: 1.2811271683373056.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-10 02:34:38,457] Trial 7 finished with value: 1.424494093912692 and parameters: {'n_estimators': 2519, 'learning_rate': 0.18104669093362824, 'num_leaves': 399, 'max_depth': 4, 'min_child_samples': 227, 'min_split_gain': 2.761320735057018, 'bagging_fraction': 0.8991836269249566, 'bagging_freq': 7, 'feature_fraction': 0.8888248313104422, 'lambda_l1': 5.374969144858311e-06, 'lambda_l2': 0.5877618471031133, 'huber_alpha': 0.85}. Best is trial 6 with value: 1.2811271683373056.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-10 02:34:42,743] Trial 8 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-10 02:34:45,571] Trial 9 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-10 02:34:53,083] Trial 10 finished with value: 1.4502846880509563 and parameters: {'n_estimators': 2941, 'learning_rate': 0.007104579859769969, 'num_leaves': 424, 'max_depth': 2, 'min_child_samples': 2, 'min_split_gain': 4.6220887565718325, 'bagging_fraction': 0.7880566131549542, 'bagging_freq': 7, 'feature_fraction': 0.661678263936434, 'lambda_l1': 8.121756387194875e-09, 'lambda_l2': 100.08386764870838, 'huber_alpha': 0.9}. Best is trial 6 with value: 1.2811271683373056.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-10 02:34:53,778] Trial 11 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-10 02:34:55,570] Trial 12 finished with value: 1.321137850258551 and parameters: {'n_estimators': 3404, 'learning_rate': 0.03866939016656176, 'num_leaves': 50, 'max_depth': 9, 'min_child_samples': 54, 'min_split_gain': 3.975378174997817, 'bagging_fraction': 0.5776988884481041, 'bagging_freq': 4, 'feature_fraction': 0.8073004449855348, 'lambda_l1': 1.1469173194560514e-08, 'lambda_l2': 0.6127644589218547, 'huber_alpha': 0.85}. Best is trial 6 with value: 1.2811271683373056.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-10 02:34:56,211] Trial 13 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-10 02:35:01,567] Trial 14 finished with value: 1.344184331180468 and parameters: {'n_estimators': 2440, 'learning_rate': 0.007089782197514698, 'num_leaves': 92, 'max_depth': 2, 'min_child_samples': 83, 'min_split_gain': 1.7789721315624618, 'bagging_fraction': 0.6616016865596667, 'bagging_freq': 5, 'feature_fraction': 0.4058624376375402, 'lambda_l1': 3.60867143771307e-07, 'lambda_l2': 0.0019132656772962273, 'huber_alpha': 0.9}. Best is trial 6 with value: 1.2811271683373056.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-10 02:35:02,208] Trial 15 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-10 02:35:02,906] Trial 16 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-10 02:35:04,809] Trial 17 finished with value: 1.2770279305673387 and parameters: {'n_estimators': 3309, 'learning_rate': 0.078175866300593, 'num_leaves': 508, 'max_depth': 13, 'min_child_samples': 103, 'min_split_gain': 2.183821929239314, 'bagging_fraction': 0.7553174967176419, 'bagging_freq': 3, 'feature_fraction': 0.37118098042063996, 'lambda_l1': 9.397361325633357e-09, 'lambda_l2': 0.32009070345347035, 'huber_alpha': 0.85}. Best is trial 17 with value: 1.2770279305673387.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-10 02:35:08,146] Trial 18 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-10 02:35:13,196] Trial 19 finished with value: 1.3454992215468253 and parameters: {'n_estimators': 3252, 'learning_rate': 0.02501313663854293, 'num_leaves': 402, 'max_depth': 8, 'min_child_samples': 146, 'min_split_gain': 1.178268236209778, 'bagging_fraction': 0.6282995151444424, 'bagging_freq': 5, 'feature_fraction': 0.5335865487841387, 'lambda_l1': 1.8282669790174765e-05, 'lambda_l2': 89.92068191792774, 'huber_alpha': 0.9}. Best is trial 17 with value: 1.2770279305673387.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-10 02:35:21,387] Trial 20 finished with value: 1.317235529564303 and parameters: {'n_estimators': 1960, 'learning_rate': 0.006941218470506332, 'num_leaves': 273, 'max_depth': 6, 'min_child_samples': 21, 'min_split_gain': 4.473620394562171, 'bagging_fraction': 0.989323795144767, 'bagging_freq': 3, 'feature_fraction': 0.8083932285131131, 'lambda_l1': 1.1401380577799733e-05, 'lambda_l2': 6.450184926416296, 'huber_alpha': 0.95}. Best is trial 17 with value: 1.2770279305673387.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# ...
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
#                   period                method  count     mae_f    rmse_f
# 0   validation_2024_2025               xgboost    728  1.192436  1.646088
# 1   validation_2024_2025              lightgbm    728  1.208952  1.661065
# 2   validation_2024_2025              catboost    728  1.204122  1.655794
# 3   validation_2024_2025         provider_mean    728  2.372415  3.150214
# 4   validation_2024_2025       provider_median    728  2.034498  2.889602
# 5   validation_2024_2025               nbm_raw    728  1.882840  2.761133
# 6   validation_2024_2025              hrrr_raw    728  4.542543  5.430395
# 7   validation_2024_2025               gfs_raw    728  2.644711  3.533007
# 8              test_2026               xgboost    170  1.323110  1.726393
# 9              test_2026              lightgbm    170  1.328121  1.717304
# 10             test_2026              catboost    170  1.356751  1.756482
# 11             test_2026           ridge_stack    170  1.328366  1.721907
# 12             test_2026  guarded_blend_cap_1f    170  1.999955  2.727066
# 13             test_2026  guarded_blend_cap_2f    170  1.661322  2.354497
# 14             test_2026  guarded_blend_cap_3f    170  1.542765  2.182368
# 15             test_2026         provider_mean    170  2.583543  3.303107
# 16             test_2026       provider_median    170  2.428105  3.214617
# 17             test_2026               nbm_raw    170  2.045105  2.795566
# 18             test_2026              hrrr_raw    170  4.927253  5.592931
# 19             test_2026               gfs_raw    170  2.550131  3.455843

# %%
exported_weights = export_station_model_weights(
    project_root=PROJECT_ROOT,
    station_id=STATION_ID,
    artifact_dir=config.resolved_output_dir(),
    model_version=MODEL_VERSION,
    timing_mode=config.timing_mode,
    providers=tuple(config.providers),
    feature_version=config.effective_feature_version,
    optuna_metric=config.effective_optuna_metric,
    target_mode=config.effective_target_mode,
    target_source=config.effective_target_source,
    base_model_methods=tuple(config.effective_base_model_methods),
    stack_enabled=config.stack_enabled,
    source_pipeline="notebooks/experiments/station_stacking_v18",
)

exported_weights.bundle_path, exported_weights.manifest_path
# Out:
# (WindowsPath('D:/dev/weather-research/data/calibration/station_stacking_v18/model_weights/KDAL_station_high_regressor_v18_nbm_hrrr_physics_settlement_stack.joblib'),
#  WindowsPath('D:/dev/weather-research/data/calibration/station_stacking_v18/model_weights/KDAL_station_high_regressor_v18_nbm_hrrr_physics_settlement_stack.json'))

# %% [markdown]
# ## V11 Feature Coverage

# %%
v11_feature_coverage = (
    result.features[V11_FEATURE_COLUMNS]
    .notna()
    .mean()
    .mul(100)
    .sort_values(ascending=False)
    .rename("coverage_pct")
    .reset_index()
    .rename(columns={"index": "feature"})
)

v11_feature_coverage
# Out:
#                                               feature  coverage_pct
# 0                              v2_spread_per_warmup_f    100.000000
# 1                    v2_morning_warmup_to_consensus_f    100.000000
# 2              v3_remaining_warmup_from_high_so_far_f    100.000000
# 3                      v3_high_so_far_above_current_f    100.000000
# 4                      v2_humidity_warmup_interaction    100.000000
# 5                        v4_forecast_wet_observed_dry    100.000000
# 6                   v4_forecast_observed_precip_match    100.000000
# 7                              v4_all_forecast_precip    100.000000
# 8            v3_humidity_remaining_warmup_interaction    100.000000
# 9                    v3_remaining_warmup_per_spread_f    100.000000
# 10                             v4_any_forecast_precip    100.000000
# 11                             v4_observed_precip_any    100.000000
# 12       observed_high_so_far_minus_climatology_10y_f    100.000000
# 13              observed_temp_minus_climatology_10y_f    100.000000
# 14                             climatology_high_10y_f    100.000000
# 15                         climatology_high_10y_std_f    100.000000
# 16                    v8_month_remaining_warmup_count    100.000000
# 17          v8_provider_spread_per_remaining_warmup_f    100.000000
# 18       v8_provider_min_remaining_from_high_so_far_f    100.000000
# 19    v8_provider_median_remaining_from_high_so_far_f    100.000000
# 20       v8_provider_max_remaining_from_high_so_far_f    100.000000
# 21            observed_high_so_far_change_since_9am_f    100.000000
# 22                     observed_temp_change_last_3h_f    100.000000
# 23            observed_morning_warmup_rate_f_per_hour    100.000000
# 24                     observed_temp_change_last_1h_f    100.000000
# 25                       v4_observed_wet_forecast_dry    100.000000
# 26              provider_mean_minus_climatology_10y_f    100.000000
# 27                         climatology_high_10y_count    100.000000
# 28                   v3_high_so_far_minus_7d_actual_f     99.949950
# 29                          v2_recent_heat_momentum_f     99.949950
# 30                   v4_observed_precip_recent_mm_est     99.949950
# 31                     v2_consensus_minus_7d_actual_f     99.949950
# 32               v8_recent_remaining_warmup_7d_mean_f     99.899900
# 33              v8_recent_remaining_warmup_30d_mean_f     99.749750
# 34                           v2_recent_heat_anomaly_f     99.649650
# 35                      v3_high_so_far_minus_lag_1d_f     99.649650
# 36       v8_provider_mean_remaining_vs_month_normal_f     98.798799
# 37                   v8_month_remaining_warmup_mean_f     98.798799
# 38      v8_dewpoint_mean_remaining_warmup_interaction     79.929930
# 39  v8_dewpoint_depression_remaining_warmup_intera...     79.929930
# 40                        v8_forecast_dewpoint_mean_f     79.929930
# 41             v8_forecast_dewpoint_depression_mean_f     79.929930
# 42             v4_precip_remaining_warmup_interaction     79.479479
# 43                   v4_forecast_precip_intensity_max     79.479479
# 44                   v4_forecast_precip_total_mean_mm     79.479479
# 45                    v4_forecast_precip_total_max_mm     79.479479
# 46                 v4_forecast_precip_total_spread_mm     79.479479
# 47                  v4_forecast_precip_max_1h_mean_mm     79.479479
# 48                      v4_forecast_precip_hours_mean     79.479479
# 49                  v4_forecast_precip_intensity_mean     79.479479
# 50       v8_precip_total_remaining_warmup_interaction     79.479479
# 51                     v4_precip_humidity_interaction     79.479479
# 52      v8_precip_max_1h_remaining_warmup_interaction     79.479479
# 53         v4_forecast_total_minus_observed_recent_mm     79.429429
# 54    v8_wind_speed_mean_remaining_warmup_interaction     36.186186
# 55      v8_wind_gust_max_remaining_warmup_interaction     36.186186
# 56    v8_cloud_cover_max_remaining_warmup_interaction      0.000000
# 57   v8_cloud_cover_mean_remaining_warmup_interaction      0.000000

# %%
result.feature_columns.loc[result.feature_columns["feature"].isin(V11_FEATURE_COLUMNS)]
# Out:
#                                                feature     kind
# 3                       observed_temp_change_last_1h_f  numeric
# 4                       observed_temp_change_last_3h_f  numeric
# 5              observed_morning_warmup_rate_f_per_hour  numeric
# 6              observed_high_so_far_change_since_9am_f  numeric
# 49                            v2_recent_heat_anomaly_f  numeric
# 50                           v2_recent_heat_momentum_f  numeric
# 51                    v2_morning_warmup_to_consensus_f  numeric
# 52                      v2_consensus_minus_7d_actual_f  numeric
# 53                              v2_spread_per_warmup_f  numeric
# 54                      v2_humidity_warmup_interaction  numeric
# 55                      v3_high_so_far_above_current_f  numeric
# 56              v3_remaining_warmup_from_high_so_far_f  numeric
# 57                       v3_high_so_far_minus_lag_1d_f  numeric
# 58                    v3_high_so_far_minus_7d_actual_f  numeric
# 59                    v3_remaining_warmup_per_spread_f  numeric
# 60            v3_humidity_remaining_warmup_interaction  numeric
# 61                    v4_forecast_precip_total_mean_mm  numeric
# 62                     v4_forecast_precip_total_max_mm  numeric
# 63                  v4_forecast_precip_total_spread_mm  numeric
# 64                   v4_forecast_precip_max_1h_mean_mm  numeric
# 65                       v4_forecast_precip_hours_mean  numeric
# 66                   v4_forecast_precip_intensity_mean  numeric
# 67                    v4_forecast_precip_intensity_max  numeric
# 68                              v4_any_forecast_precip  numeric
# 69                              v4_all_forecast_precip  numeric
# 70                              v4_observed_precip_any  numeric
# 71                    v4_observed_precip_recent_mm_est  numeric
# 72          v4_forecast_total_minus_observed_recent_mm  numeric
# 73                   v4_forecast_observed_precip_match  numeric
# 74                        v4_forecast_wet_observed_dry  numeric
# 75                        v4_observed_wet_forecast_dry  numeric
# 76                      v4_precip_humidity_interaction  numeric
# 77              v4_precip_remaining_warmup_interaction  numeric
# 78        v8_provider_max_remaining_from_high_so_far_f  numeric
# 79        v8_provider_min_remaining_from_high_so_far_f  numeric
# 80     v8_provider_median_remaining_from_high_so_far_f  numeric
# 81           v8_provider_spread_per_remaining_warmup_f  numeric
# 82                    v8_month_remaining_warmup_mean_f  numeric
# 83                     v8_month_remaining_warmup_count  numeric
# 84                v8_recent_remaining_warmup_7d_mean_f  numeric
# 85               v8_recent_remaining_warmup_30d_mean_f  numeric
# 86        v8_provider_mean_remaining_vs_month_normal_f  numeric
# 87        v8_precip_total_remaining_warmup_interaction  numeric
# 88       v8_precip_max_1h_remaining_warmup_interaction  numeric
# 89     v8_wind_speed_mean_remaining_warmup_interaction  numeric
# 90       v8_wind_gust_max_remaining_warmup_interaction  numeric
# 91                         v8_forecast_dewpoint_mean_f  numeric
# 92              v8_forecast_dewpoint_depression_mean_f  numeric
# 93       v8_dewpoint_mean_remaining_warmup_interaction  numeric
# 94   v8_dewpoint_depression_remaining_warmup_intera...  numeric
# 95                              climatology_high_10y_f  numeric
# 96                          climatology_high_10y_std_f  numeric
# 97                          climatology_high_10y_count  numeric
# 98               provider_mean_minus_climatology_10y_f  numeric
# 99               observed_temp_minus_climatology_10y_f  numeric
# 100       observed_high_so_far_minus_climatology_10y_f  numeric

# %% [markdown]
# ## Dropped Feature Check

# %%
dropped_present = result.feature_columns.loc[
    result.feature_columns["feature"].isin(V11_DROPPED_FEATURE_COLUMNS)
]

dropped_present
# Out:
# Empty DataFrame
# Columns: [feature, kind]
# Index: []

# %% [markdown]
# ## Morning Trend Coverage

# %%
trend_coverage = (
    result.features[TREND_COLUMNS]
    .notna()
    .mean()
    .mul(100)
    .sort_values(ascending=False)
    .rename("coverage_pct")
    .reset_index()
    .rename(columns={"index": "feature"})
)

trend_coverage
# Out:
#                                    feature  coverage_pct
# 0           observed_temp_change_last_1h_f         100.0
# 1           observed_temp_change_last_3h_f         100.0
# 2  observed_morning_warmup_rate_f_per_hour         100.0
# 3  observed_high_so_far_change_since_9am_f         100.0

# %% [markdown]
# ## Rounded Within 1F Accuracy

# %%
preds = pd.concat(
    [
        result.validation_predictions.assign(period="validation_2024_2025"),
        result.test_predictions.assign(period="oof_2026"),
    ],
    ignore_index=True,
)

predicted_high = pd.to_numeric(preds["predicted_high_f"], errors="coerce")
preds["predicted_high_rounded_f"] = np.floor(predicted_high + 0.5)
preds["within_1f_after_round"] = (
    pd.to_numeric(preds["actual_high_f"], errors="coerce") - preds["predicted_high_rounded_f"]
).abs().le(1)

within_1f_accuracy_by_period = (
    preds
    .dropna(subset=["actual_high_f", "predicted_high_rounded_f"])
    .groupby(["period", "method"], as_index=False)
    .agg(
        count=("within_1f_after_round", "size"),
        within_1f_count=("within_1f_after_round", "sum"),
        within_1f_accuracy_pct=("within_1f_after_round", lambda x: x.mean() * 100),
    )
    .sort_values(["period", "within_1f_accuracy_pct"], ascending=[True, False])
)

within_1f_accuracy_by_period
# Out:
#                   period                method  count  within_1f_count  \
# 0               oof_2026              catboost    170              107
# 6               oof_2026              lightgbm    170              107
# 11              oof_2026               xgboost    170              107
# 10              oof_2026           ridge_stack    170              105
# 4               oof_2026  guarded_blend_cap_3f    170              101
# 3               oof_2026  guarded_blend_cap_2f    170               97
# 7               oof_2026               nbm_raw    170               84
# 2               oof_2026  guarded_blend_cap_1f    170               78
# 1               oof_2026               gfs_raw    170               69
# 9               oof_2026       provider_median    170               69
# 8               oof_2026         provider_mean    170               57
# 5               oof_2026              hrrr_raw    170               17
# 19  validation_2024_2025               xgboost    728              515
# 12  validation_2024_2025              catboost    728              507
# 15  validation_2024_2025              lightgbm    728              502
# 16  validation_2024_2025               nbm_raw    728              387
# 18  validation_2024_2025       provider_median    728              348
# 17  validation_2024_2025         provider_mean    728              261
# 13  validation_2024_2025               gfs_raw    728              256
# 14  validation_2024_2025              hrrr_raw    728              126
#
#     within_1f_accuracy_pct
# 0                62.941176
# 6                62.941176
# 11               62.941176
# 10               61.764706
# 4                59.411765
# 3                57.058824
# 7                49.411765
# 2                45.882353
# 1                40.588235
# 9                40.588235
# 8                33.529412
# 5                10.000000
# 19               70.741758
# 12               69.642857
# 15               68.956044
# 16               53.159341
# 18               47.802198
# 17               35.851648
# 13               35.164835
# 14               17.307692

# %% [markdown]
# ## Version Comparison

# %%
comparison_frames = []
for version, folder in [
    ("v1", PROJECT_ROOT / "data" / "calibration" / "station_stacking"),
    ("v2", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v2"),
    ("v3", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v3"),
    ("v4", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v4"),
    ("v5", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v5"),
    ("v6", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v6"),
    ("v7", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v7"),
    ("v8", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v8"),
    ("v9", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v9"),
    ("v10", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v10"),
    ("v11", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v11"),
]:
    path = folder / f"{STATION_ID}_year_split_scoreboard.csv"
    if path.exists():
        frame = pd.read_csv(path)
        frame["version"] = version
        comparison_frames.append(frame)

version_comparison = pd.concat(comparison_frames, ignore_index=True) if comparison_frames else pd.DataFrame()
if not version_comparison.empty:
    version_comparison = version_comparison.sort_values(["period", "mae_f", "version", "method"]).reset_index(drop=True)
version_comparison
# Out:
#                   period       method  count     mae_f    rmse_f version
# 0              test_2026  ridge_stack    138  1.369446  1.890651      v9
# 1              test_2026      xgboost    138  1.402066  1.889472     v11
# 2              test_2026      xgboost    138  1.419940  1.895994      v9
# 3              test_2026  ridge_stack    138  1.429989  1.907881     v11
# 4              test_2026     lightgbm    138  1.454606  1.932482     v11
# ..                   ...          ...    ...       ...       ...     ...
# 83  validation_2024_2025     hrrr_raw    660  5.477361  6.266007      v3
# 84  validation_2024_2025     hrrr_raw    668  5.486824  6.274688      v7
# 85  validation_2024_2025     hrrr_raw    606  5.497186  6.283967      v5
# 86  validation_2024_2025     hrrr_raw    606  5.497186  6.283967      v6
# 87  validation_2024_2025     hrrr_raw    623  5.564150  6.352240      v1
#
# [88 rows x 6 columns]

# %% [markdown]
# ## 2026 OOF Weather Brackets

# %%
result.bracket_metrics
# Out:
#                   method  count     mae_f    rmse_f  bucket_log_loss  \
# 0                xgboost    170  1.323110  1.726393         1.313777
# 1               lightgbm    170  1.328121  1.717304         1.317197
# 2               catboost    170  1.356751  1.756482         1.325745
# 3            ridge_stack    170  1.328366  1.721907         1.305465
# 4   guarded_blend_cap_1f    170  1.999955  2.727066         1.598807
# 5   guarded_blend_cap_2f    170  1.661322  2.354497         1.527463
# 6   guarded_blend_cap_3f    170  1.542765  2.182368         1.491132
# 7          provider_mean    170  2.583543  3.303107         1.678281
# 8        provider_median    170  2.428105  3.214617         1.757808
# 9                nbm_raw    170  2.045105  2.795566         1.726940
# 10              hrrr_raw    170  4.927253  5.592931         1.838395
# 11               gfs_raw    170  2.550131  3.455843         1.948382
#
#     bracket_accuracy_pct  p95_absolute_error_f  large_miss_5f_pct
# 0              45.294118              3.294992           1.176471
# 1              42.352941              3.084216           0.588235
# 2              45.294118              3.470479           1.176471
# 3              44.705882              3.333429           1.176471
# 4                   30.0              4.749879           4.705882
# 5              42.352941              4.345396           3.529412
# 6              41.764706              4.127499           2.941176
# 7              23.529412              5.481044           8.235294
# 8              22.941176              5.950489           8.823529
# 9              34.117647              5.718984           8.235294
# 10              5.294118              9.733436          45.294118
# 11             27.058824              6.385804          11.176471

# %% [markdown]
# # Station Stacking v9 - KMIA
#
# Experimental notebook for `KMIA`.
#
# This version keeps the v8 live-safe GFS/HRRR/NBM contract, adds source-owned 10-year calendar-day max-temperature climatology features, and trains base learners on remaining warmup from the observed high-so-far. Artifacts are written to `data/calibration/station_stacking_v9`.

# %%
from pathlib import Path
import os
import sys
import warnings

warnings.filterwarnings("ignore", message="IProgress not found.*")
warnings.filterwarnings("ignore", message="Skipping features without any observed values.*")

PROJECT_ROOT = Path.cwd().resolve()
while not (PROJECT_ROOT / "src" / "calibration" / "station_stacking.py").exists():
    if PROJECT_ROOT.parent == PROJECT_ROOT:
        raise RuntimeError("Could not find project root containing src/calibration/station_stacking.py")
    PROJECT_ROOT = PROJECT_ROOT.parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

os.environ["WEATHER_RESEARCH_INCLUDE_DIRECT_NBM"] = "1"

STATION_ID = "KMIA"
PROVIDERS = ("gfs", "hrrr", "nbm")
TREND_COLUMNS = [
    "observed_temp_change_last_1h_f",
    "observed_temp_change_last_3h_f",
    "observed_morning_warmup_rate_f_per_hour",
    "observed_high_so_far_change_since_9am_f",
]
TIMING_MODE = "same_day_11am_live_safe"
FAST_MODE = False
OPTUNA_TRIALS = 30
STACK_OPTUNA_TRIALS = 30
OPTUNA_STARTUP_TRIALS = 15
STACK_OPTUNA_STARTUP_TRIALS = 15
OPTUNA_METRIC = "mae_f"
OPTUNA_VERBOSE = True
MODEL_VERSION = "station_high_regressor_v9_remaining_warmup"
PROJECT_ROOT
# Out:
# WindowsPath('D:/dev/weather-research')

# %%
import numpy as np
import pandas as pd

from src.export_station_stacking_v2_models import export_station_model_weights
from src.calibration.station_stacking import (
    StationStackingConfig,
    V9_DROPPED_FEATURE_COLUMNS,
    V9_FEATURE_COLUMNS,
    YEAR_SPLIT_EXPANDING_FOLDS,
    missing_model_dependencies,
    provider_availability,
    run_station_year_split_experiment,
)

# %% [markdown]
# ## V9 Contract
#
# `feature_version="v9"` keeps the v8 remaining-warmup feature set, adds leakage-safe 10-year calendar-day climatology features, and uses `target_mode="remaining_warmup"` so base learners fit `actual_high_f - observed_high_temp_through_as_of_f` before converting back to `predicted_high_f`.

# %%
fold_spec = pd.DataFrame(
    [
        {
            "fold": fold.name,
            "train_start_year": fold.train_start_year,
            "train_end_year": fold.train_end_year,
            "validation_year": fold.validation_year,
        }
        for fold in YEAR_SPLIT_EXPANDING_FOLDS
    ]
)

fold_spec
# Out:
#                      fold  train_start_year  train_end_year  validation_year
# 0  fold_2021_2023_to_2024              2021            2023             2024
# 1  fold_2021_2024_to_2025              2021            2024             2025

# %%
V9_FEATURE_COLUMNS, sorted(V9_DROPPED_FEATURE_COLUMNS)
# Out:
# (['v2_recent_heat_anomaly_f',
#   'v2_recent_heat_momentum_f',
#   'v2_morning_warmup_to_consensus_f',
#   'v2_consensus_minus_7d_actual_f',
#   'v2_spread_per_warmup_f',
#   'v2_humidity_warmup_interaction',
#   'v3_high_so_far_above_current_f',
#   'v3_remaining_warmup_from_high_so_far_f',
#   'v3_high_so_far_minus_lag_1d_f',
#   'v3_high_so_far_minus_7d_actual_f',
#   'v3_remaining_warmup_per_spread_f',
#   'v3_humidity_remaining_warmup_interaction',
#   'v4_forecast_precip_total_mean_mm',
#   'v4_forecast_precip_total_max_mm',
#   'v4_forecast_precip_total_spread_mm',
#   'v4_forecast_precip_max_1h_mean_mm',
#   'v4_forecast_precip_hours_mean',
#   'v4_forecast_precip_intensity_mean',
#   'v4_forecast_precip_intensity_max',
#   'v4_any_forecast_precip',
#   'v4_all_forecast_precip',
#   'v4_observed_precip_any',
#   'v4_observed_precip_recent_mm_est',
#   'v4_forecast_total_minus_observed_recent_mm',
#   'v4_forecast_observed_precip_match',
#   'v4_forecast_wet_observed_dry',
#   'v4_observed_wet_forecast_dry',
#   'v4_precip_humidity_interaction',
#   'v4_precip_remaining_warmup_interaction',
#   'observed_temp_change_last_1h_f',
#   'observed_temp_change_last_3h_f',
#   'observed_morning_warmup_rate_f_per_hour',
#   'observed_high_so_far_change_since_9am_f',
#   'v8_provider_max_remaining_from_high_so_far_f',
#   'v8_provider_min_remaining_from_high_so_far_f',
#   'v8_provider_median_remaining_from_high_so_far_f',
#   'v8_provider_spread_per_remaining_warmup_f',
#   'v8_month_remaining_warmup_mean_f',
#   'v8_month_remaining_warmup_count',
#   'v8_recent_remaining_warmup_7d_mean_f',
#   'v8_recent_remaining_warmup_30d_mean_f',
#   'v8_provider_mean_remaining_vs_month_normal_f',
#   'v8_cloud_cover_mean_remaining_warmup_interaction',
#   'v8_cloud_cover_max_remaining_warmup_interaction',
#   'v8_precip_total_remaining_warmup_interaction',
#   'v8_precip_max_1h_remaining_warmup_interaction',
#   'v8_wind_speed_mean_remaining_warmup_interaction',
#   'v8_wind_gust_max_remaining_warmup_interaction',
#   'v8_forecast_dewpoint_mean_f',
#   'v8_forecast_dewpoint_depression_mean_f',
#   'v8_dewpoint_mean_remaining_warmup_interaction',
#   'v8_dewpoint_depression_remaining_warmup_interaction',
#   'climatology_high_10y_f',
#   'climatology_high_10y_std_f',
#   'climatology_high_10y_count',
#   'provider_mean_minus_climatology_10y_f',
#   'observed_temp_minus_climatology_10y_f',
#   'observed_high_so_far_minus_climatology_10y_f'],
#  ['actual_minus_climatology_10y_f_DIAGNOSTIC_ONLY',
#   'climatology_source_end_year',
#   'climatology_source_start_year',
#   'gfs_as_of_hour_local',
#   'gfs_available',
#   'gfs_forecast_window_hours',
#   'gfs_grid_dist_km_mean',
#   'gfs_horizon_hours',
#   'gfs_hrrr_grid_dist_km_mean_abs_diff_f',
#   'gfs_hrrr_grid_dist_km_mean_diff_f',
#   'gfs_issue_hour_utc',
#   'gfs_missing',
#   'hrrr_as_of_hour_local',
#   'hrrr_available',
#   'hrrr_forecast_hour_max',
#   'hrrr_forecast_hour_min',
#   'hrrr_forecast_lead_hours',
#   'hrrr_forecast_window_hours',
#   'hrrr_grid_dist_km_mean',
#   'hrrr_horizon_hours',
#   'hrrr_issue_hour_local',
#   'hrrr_issue_hour_utc',
#   'hrrr_missing',
#   'is_active_polymarket_station',
#   'lat',
#   'lon',
#   'nbm_as_of_hour_local',
#   'nbm_available',
#   'nbm_forecast_window_hours',
#   'nbm_horizon_hours',
#   'nbm_issue_hour_local',
#   'nbm_issue_hour_utc',
#   'nbm_missing',
#   'observed_fetch_status',
#   'observed_observation_type',
#   'observed_pressure_source',
#   'provider_count_available',
#   'year'])

# %% [markdown]
# ## Data Availability

# %%
availability = provider_availability(
    PROJECT_ROOT,
    timing_mode=TIMING_MODE,
    providers=PROVIDERS,
)

availability.loc[availability["station_id"].eq(STATION_ID)]
# Out:
#    station_id provider  row_count first_contract_date last_contract_date
# 18       KMIA      gfs       1987          2021-01-01         2026-06-10
# 19       KMIA     hrrr       1987          2021-01-01         2026-06-10
# 20       KMIA      nbm       1986          2021-01-01         2026-06-10

# %% [markdown]
# ## Model Scores

# %%
missing_packages = missing_model_dependencies()
if missing_packages:
    raise ImportError(
        "Missing station-stacking ML packages: "
        + ", ".join(missing_packages)
        + ". Install them with: python -m pip install -r requirements.txt"
    )

config = StationStackingConfig(
    station_id=STATION_ID,
    project_root=PROJECT_ROOT,
    timing_mode=TIMING_MODE,
    providers=PROVIDERS,
    fast_mode=FAST_MODE,
    optuna_trials=OPTUNA_TRIALS,
    stack_optuna_trials=STACK_OPTUNA_TRIALS,
    optuna_startup_trials=OPTUNA_STARTUP_TRIALS,
    stack_optuna_startup_trials=STACK_OPTUNA_STARTUP_TRIALS,
    optuna_metric=OPTUNA_METRIC,
    optuna_verbose=OPTUNA_VERBOSE,
    feature_version="v9",
    target_mode="remaining_warmup",
    hyperparameter_space="wide",
    year_split_folds=YEAR_SPLIT_EXPANDING_FOLDS,
    year_split_test_train_years=(2021, 2025),
    year_split_test_year=2026,
    output_dir=PROJECT_ROOT / "data" / "calibration" / "station_stacking_v9",
)

config.resolved_optuna_storage_path()
# Out:
# WindowsPath('D:/dev/weather-research/data/calibration/station_stacking_v9/KMIA_optuna.sqlite3')

# %%
result = run_station_year_split_experiment(config)
result.scoreboard
# Out:
# [I 2026-06-16 07:24:19,226] A new study created in RDB with name: KMIA_v9_remaining_warmup_base_xgboost_mae_f
# [I 2026-06-16 07:24:46,042] Trial 0 finished with value: 1.3177837373029597 and parameters: {'n_estimators': 1342, 'learning_rate': 0.19043899115982607, 'max_depth': 9, 'min_child_weight': 2.481040974867813, 'gamma': 2.340279606636548, 'subsample': 0.4513964382185317, 'colsample_bytree': 0.3877543479093296, 'reg_alpha': 2.478071022662141, 'reg_lambda': 0.6132587025321562}. Best is trial 0 with value: 1.3177837373029597.
# [I 2026-06-16 07:30:43,179] Trial 1 finished with value: 1.2168251510856662 and parameters: {'n_estimators': 2493, 'learning_rate': 0.001120367191095075, 'max_depth': 12, 'min_child_weight': 21.368329072358772, 'gamma': 3.185086660174142, 'subsample': 0.4681862286846154, 'colsample_bytree': 0.46921293140473197, 'reg_alpha': 4.476173538513514e-07, 'reg_lambda': 0.20253776634919213}. Best is trial 1 with value: 1.2168251510856662.
# [I 2026-06-16 07:32:31,050] Trial 2 finished with value: 1.2194327715540711 and parameters: {'n_estimators': 1540, 'learning_rate': 0.004992867109217114, 'max_depth': 8, 'min_child_weight': 0.03613894271216528, 'gamma': 4.3821697280282725, 'subsample': 0.5881351981408995, 'colsample_bytree': 0.6464454897410734, 'reg_alpha': 0.26430874752361627, 'reg_lambda': 0.0018119678627933364}. Best is trial 1 with value: 1.2168251510856662.
# [I 2026-06-16 07:32:58,266] Trial 3 finished with value: 1.2414412366203655 and parameters: {'n_estimators': 1824, 'learning_rate': 0.026337502897485255, 'max_depth': 1, 'min_child_weight': 2.69264691008618, 'gamma': 2.557861855309373, 'subsample': 0.39228353544043165, 'colsample_bytree': 0.9667755992146666, 'reg_alpha': 38.6887231523051, 'reg_lambda': 12.408975837016275}. Best is trial 1 with value: 1.2168251510856662.
# [I 2026-06-16 07:35:26,157] Trial 4 finished with value: 1.305827425266028 and parameters: {'n_estimators': 1101, 'learning_rate': 0.0017147936629846843, 'max_depth': 9, 'min_child_weight': 0.5762487216478605, 'gamma': 1.8305735226716824, 'subsample': 0.6718649915723256, 'colsample_bytree': 0.37235253872489193, 'reg_alpha': 8.162906555194692, 'reg_lambda': 0.004271500153828077}. Best is trial 1 with value: 1.2168251510856662.
# [I 2026-06-16 07:37:39,780] Trial 5 finished with value: 1.2581291126012892 and parameters: {'n_estimators': 2336, 'learning_rate': 0.00559067775661512, 'max_depth': 7, 'min_child_weight': 1.5375920235481764, 'gamma': 2.7728168328829055, 'subsample': 0.980230008046963, 'colsample_bytree': 0.8538363351847245, 'reg_alpha': 18.792618557420877, 'reg_lambda': 43.484449457612314}. Best is trial 1 with value: 1.2168251510856662.
# [I 2026-06-16 07:37:47,564] Trial 6 finished with value: 1.1856700801810727 and parameters: {'n_estimators': 2113, 'learning_rate': 0.16240489353272883, 'max_depth': 2, 'min_child_weight': 0.06080390190296603, 'gamma': 0.678409333658071, 'subsample': 0.5614647149961218, 'colsample_bytree': 0.6026402382981633, 'reg_alpha': 1.8037999945880162e-07, 'reg_lambda': 16.668629892722056}. Best is trial 6 with value: 1.1856700801810727.
# [I 2026-06-16 07:39:08,552] Trial 7 finished with value: 1.2084873447252236 and parameters: {'n_estimators': 1281, 'learning_rate': 0.0047169807141865345, 'max_depth': 7, 'min_child_weight': 0.0366181922039243, 'gamma': 12.032954711310595, 'subsample': 0.398457918391851, 'colsample_bytree': 0.9914765087903362, 'reg_alpha': 0.18490013641000916, 'reg_lambda': 0.0017869543989965139}. Best is trial 6 with value: 1.1856700801810727.
# [I 2026-06-16 07:39:09,947] Trial 8 pruned.
# [I 2026-06-16 07:39:57,211] Trial 9 finished with value: 1.2206145490788356 and parameters: {'n_estimators': 2201, 'learning_rate': 0.006215464818952927, 'max_depth': 1, 'min_child_weight': 0.17535949529764422, 'gamma': 4.877749830401205, 'subsample': 0.8242440159197416, 'colsample_bytree': 0.7644123563808884, 'reg_alpha': 4.4315220126915325, 'reg_lambda': 0.09450187118503514}. Best is trial 6 with value: 1.1856700801810727.
# [I 2026-06-16 07:40:04,402] Trial 10 pruned.
# [I 2026-06-16 07:40:35,044] Trial 11 pruned.
# [I 2026-06-16 07:41:37,909] Trial 12 pruned.
# [I 2026-06-16 07:41:50,988] Trial 13 pruned.
# [I 2026-06-16 07:41:58,560] Trial 14 pruned.
# [I 2026-06-16 07:42:29,666] Trial 15 finished with value: 1.2185143742121411 and parameters: {'n_estimators': 3311, 'learning_rate': 0.021882197214300323, 'max_depth': 4, 'min_child_weight': 0.010825117624685654, 'gamma': 0.2911528796498949, 'subsample': 0.6605945169194728, 'colsample_bytree': 0.9832796906523807, 'reg_alpha': 0.003083204463756954, 'reg_lambda': 0.012869285860036094}. Best is trial 6 with value: 1.1856700801810727.
# [I 2026-06-16 07:44:00,517] Trial 16 finished with value: 1.2116683487236362 and parameters: {'n_estimators': 1867, 'learning_rate': 0.015494337554087339, 'max_depth': 4, 'min_child_weight': 0.012617266144018207, 'gamma': 8.359124020737127, 'subsample': 0.36349806463002954, 'colsample_bytree': 0.8840349069177305, 'reg_alpha': 0.0019329084666673943, 'reg_lambda': 0.00011784065061038623}. Best is trial 6 with value: 1.1856700801810727.
# [I 2026-06-16 07:44:08,720] Trial 17 pruned.
# [I 2026-06-16 07:44:50,078] Trial 18 pruned.
# [I 2026-06-16 07:45:58,779] Trial 19 finished with value: 1.215361720524449 and parameters: {'n_estimators': 1191, 'learning_rate': 0.0031504688539478925, 'max_depth': 3, 'min_child_weight': 0.3810831162314367, 'gamma': 14.977695121172474, 'subsample': 0.5133230376221232, 'colsample_bytree': 0.7786531267890316, 'reg_alpha': 5.374047492964804e-05, 'reg_lambda': 0.0006941520930956824}. Best is trial 6 with value: 1.1856700801810727.
# [I 2026-06-16 07:46:01,161] Trial 20 pruned.
# [I 2026-06-16 07:46:57,031] Trial 21 finished with value: 1.197778691198951 and parameters: {'n_estimators': 1853, 'learning_rate': 0.010617195366412277, 'max_depth': 6, 'min_child_weight': 0.01020270577383769, 'gamma': 7.913549278024169, 'subsample': 0.35941111601502507, 'colsample_bytree': 0.9137336691025132, 'reg_alpha': 0.001541941571636923, 'reg_lambda': 0.0001210716957163458}. Best is trial 6 with value: 1.1856700801810727.
# [I 2026-06-16 07:48:11,161] Trial 22 finished with value: 1.2016422044408743 and parameters: {'n_estimators': 2064, 'learning_rate': 0.01027211765396897, 'max_depth': 6, 'min_child_weight': 0.02346425344546976, 'gamma': 6.503269068495079, 'subsample': 0.4191536691708393, 'colsample_bytree': 0.9579612259626723, 'reg_alpha': 0.03253960656165418, 'reg_lambda': 0.0004342585809925839}. Best is trial 6 with value: 1.1856700801810727.
# [I 2026-06-16 07:52:24,807] Trial 23 finished with value: 1.2146496364139174 and parameters: {'n_estimators': 2173, 'learning_rate': 0.008908131824087754, 'max_depth': 6, 'min_child_weight': 0.020005917545179715, 'gamma': 6.178337685817622, 'subsample': 0.44397240854963893, 'colsample_bytree': 0.9187443631756244, 'reg_alpha': 0.001209593761280589, 'reg_lambda': 0.0003514257409125605}. Best is trial 6 with value: 1.1856700801810727.
# [I 2026-06-16 07:52:55,282] Trial 24 pruned.
# [I 2026-06-16 07:53:21,686] Trial 25 pruned.
# [I 2026-06-16 07:56:46,365] Trial 26 pruned.
# [I 2026-06-16 08:02:59,446] Trial 27 finished with value: 1.1879744240552315 and parameters: {'n_estimators': 3026, 'learning_rate': 0.008372180687705198, 'max_depth': 5, 'min_child_weight': 0.057512799354001366, 'gamma': 4.2124089600940655, 'subsample': 0.7236750728807821, 'colsample_bytree': 0.7173074779518634, 'reg_alpha': 0.00010824334540633422, 'reg_lambda': 0.0012352714590078905}. Best is trial 6 with value: 1.1856700801810727.
# [I 2026-06-16 08:03:27,686] Trial 28 finished with value: 1.1934016885291996 and parameters: {'n_estimators': 2898, 'learning_rate': 0.0706807953099245, 'max_depth': 2, 'min_child_weight': 0.17596375745106357, 'gamma': 1.0681674774759804, 'subsample': 0.7333484243891487, 'colsample_bytree': 0.6194846417867093, 'reg_alpha': 0.0003511402484872301, 'reg_lambda': 0.4995646218172018}. Best is trial 6 with value: 1.1856700801810727.
# [I 2026-06-16 08:03:35,003] Trial 29 pruned.
# [I 2026-06-16 08:03:35,664] A new study created in RDB with name: KMIA_v9_remaining_warmup_base_lightgbm_mae_f
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 08:04:48,660] Trial 0 finished with value: 1.2353102359876424 and parameters: {'n_estimators': 447, 'learning_rate': 0.028873871707375695, 'num_leaves': 71, 'max_depth': 5, 'min_child_samples': 83, 'min_split_gain': 4.295687454742988, 'bagging_fraction': 0.7829586385137167, 'bagging_freq': 4, 'feature_fraction': 0.3688589858758342, 'lambda_l1': 0.06382334403151436, 'lambda_l2': 0.03080292177315921}. Best is trial 0 with value: 1.2353102359876424.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 08:17:00,552] Trial 1 finished with value: 1.2282279212442082 and parameters: {'n_estimators': 2817, 'learning_rate': 0.004074615160588706, 'num_leaves': 32, 'max_depth': 13, 'min_child_samples': 57, 'min_split_gain': 2.0249472402362985, 'bagging_fraction': 0.5554627061618356, 'bagging_freq': 1, 'feature_fraction': 0.898096051249308, 'lambda_l1': 1.5391104005532914, 'lambda_l2': 132.19976430960952}. Best is trial 1 with value: 1.2282279212442082.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 08:17:25,756] Trial 2 finished with value: 1.293551892502469 and parameters: {'n_estimators': 1379, 'learning_rate': 0.1944487980595256, 'num_leaves': 230, 'max_depth': 10, 'min_child_samples': 22, 'min_split_gain': 4.485492899907672, 'bagging_fraction': 0.5437022754476957, 'bagging_freq': 2, 'feature_fraction': 0.353334206891897, 'lambda_l1': 0.00032993636349211094, 'lambda_l2': 0.09925376145099525}. Best is trial 1 with value: 1.2282279212442082.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 08:17:39,217] Trial 3 finished with value: 1.2580302264740657 and parameters: {'n_estimators': 2246, 'learning_rate': 0.22165362064553062, 'num_leaves': 466, 'max_depth': 13, 'min_child_samples': 132, 'min_split_gain': 0.5200947492738145, 'bagging_fraction': 0.4675944869176356, 'bagging_freq': 7, 'feature_fraction': 0.6177694392011331, 'lambda_l1': 2.399967979035352, 'lambda_l2': 1.7195277953675168}. Best is trial 1 with value: 1.2282279212442082.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 08:22:10,552] Trial 4 finished with value: 1.233502755476878 and parameters: {'n_estimators': 2219, 'learning_rate': 0.004579029224032115, 'num_leaves': 460, 'max_depth': 4, 'min_child_samples': 102, 'min_split_gain': 4.967862461970517, 'bagging_fraction': 0.8282226029796285, 'bagging_freq': 4, 'feature_fraction': 0.7144310601384277, 'lambda_l1': 8.61124348208611e-06, 'lambda_l2': 3.808668235343267}. Best is trial 1 with value: 1.2282279212442082.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 08:22:14,802] Trial 5 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 08:22:29,696] Trial 6 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 08:22:30,386] Trial 7 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 08:22:31,547] Trial 8 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 08:22:44,512] Trial 9 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 08:22:48,611] Trial 10 finished with value: 1.2449639802702526 and parameters: {'n_estimators': 1955, 'learning_rate': 0.10617308776731572, 'num_leaves': 473, 'max_depth': 12, 'min_child_samples': 100, 'min_split_gain': 2.990940682910633, 'bagging_fraction': 0.6312537517163401, 'bagging_freq': 5, 'feature_fraction': 0.6650462182423572, 'lambda_l1': 3.4603824354229108e-09, 'lambda_l2': 1.1486767413892263}. Best is trial 1 with value: 1.2282279212442082.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 08:22:53,612] Trial 11 finished with value: 1.2359147949795544 and parameters: {'n_estimators': 756, 'learning_rate': 0.06114521776634082, 'num_leaves': 57, 'max_depth': 2, 'min_child_samples': 85, 'min_split_gain': 4.846277519155279, 'bagging_fraction': 0.8056341981316478, 'bagging_freq': 3, 'feature_fraction': 0.42848891083526186, 'lambda_l1': 5.301057710204056e-10, 'lambda_l2': 3.7660106129974493}. Best is trial 1 with value: 1.2282279212442082.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 08:26:58,330] Trial 12 finished with value: 1.226493548521094 and parameters: {'n_estimators': 3174, 'learning_rate': 0.0010925194811392835, 'num_leaves': 301, 'max_depth': 11, 'min_child_samples': 74, 'min_split_gain': 2.613988081636218, 'bagging_fraction': 0.8796537260629015, 'bagging_freq': 5, 'feature_fraction': 0.5960609706435204, 'lambda_l1': 8.524985832885774e-10, 'lambda_l2': 0.1169527455154188}. Best is trial 12 with value: 1.226493548521094.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 08:27:16,314] Trial 13 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 08:27:19,905] Trial 14 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 08:37:17,013] Trial 15 finished with value: 1.213271075479383 and parameters: {'n_estimators': 3220, 'learning_rate': 0.001009303102602458, 'num_leaves': 169, 'max_depth': 12, 'min_child_samples': 33, 'min_split_gain': 2.1872471099818434, 'bagging_fraction': 0.6699587430206588, 'bagging_freq': 1, 'feature_fraction': 0.9900177965782365, 'lambda_l1': 1.154377994920124e-05, 'lambda_l2': 0.002018844981827155}. Best is trial 15 with value: 1.213271075479383.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 09:57:28,003] Trial 16 finished with value: 1.2194650285274475 and parameters: {'n_estimators': 3478, 'learning_rate': 0.0011041139930669421, 'num_leaves': 242, 'max_depth': 11, 'min_child_samples': 5, 'min_split_gain': 2.230087000425617, 'bagging_fraction': 0.6754870453134177, 'bagging_freq': 1, 'feature_fraction': 0.7888821549851943, 'lambda_l1': 4.598046653413572e-06, 'lambda_l2': 0.0007829527663020838}. Best is trial 15 with value: 1.213271075479383.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 10:19:30,914] Trial 17 finished with value: 1.2153067121213517 and parameters: {'n_estimators': 3378, 'learning_rate': 0.0010546736917472206, 'num_leaves': 168, 'max_depth': 7, 'min_child_samples': 9, 'min_split_gain': 1.7587764233544436, 'bagging_fraction': 0.7078306734162884, 'bagging_freq': 1, 'feature_fraction': 0.9873220013534265, 'lambda_l1': 1.5187452019907982e-05, 'lambda_l2': 0.0016150305704728755}. Best is trial 15 with value: 1.213271075479383.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 10:21:41,683] Trial 18 finished with value: 1.2061589976126454 and parameters: {'n_estimators': 2699, 'learning_rate': 0.009167066863625447, 'num_leaves': 176, 'max_depth': 7, 'min_child_samples': 33, 'min_split_gain': 1.756335595311392, 'bagging_fraction': 0.7064475471316675, 'bagging_freq': 2, 'feature_fraction': 0.9923974128375445, 'lambda_l1': 5.3384797711742476e-05, 'lambda_l2': 0.0027561723104965346}. Best is trial 18 with value: 1.2061589976126454.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 10:22:07,877] Trial 19 finished with value: 1.2060174196249716 and parameters: {'n_estimators': 2951, 'learning_rate': 0.013709064485768419, 'num_leaves': 147, 'max_depth': 7, 'min_child_samples': 47, 'min_split_gain': 1.5652093981002344, 'bagging_fraction': 0.7146334374753556, 'bagging_freq': 2, 'feature_fraction': 0.9949537183274804, 'lambda_l1': 0.0006585707636633434, 'lambda_l2': 0.004192051168565256}. Best is trial 19 with value: 1.2060174196249716.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 10:22:49,814] Trial 20 finished with value: 1.2113370076429515 and parameters: {'n_estimators': 2685, 'learning_rate': 0.010346165434627543, 'num_leaves': 121, 'max_depth': 7, 'min_child_samples': 42, 'min_split_gain': 1.5617538566389126, 'bagging_fraction': 0.7202665145588959, 'bagging_freq': 2, 'feature_fraction': 0.9333856712822748, 'lambda_l1': 0.000930340454329843, 'lambda_l2': 0.006117510050697865}. Best is trial 19 with value: 1.2060174196249716.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 10:23:15,216] Trial 21 finished with value: 1.210910185414299 and parameters: {'n_estimators': 2712, 'learning_rate': 0.012317819831752423, 'num_leaves': 120, 'max_depth': 7, 'min_child_samples': 48, 'min_split_gain': 0.1257699713326701, 'bagging_fraction': 0.7371515725667345, 'bagging_freq': 2, 'feature_fraction': 0.9339192224601869, 'lambda_l1': 0.002033038698103841, 'lambda_l2': 0.011561490043478942}. Best is trial 19 with value: 1.2060174196249716.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 10:23:41,567] Trial 22 finished with value: 1.2167670974161362 and parameters: {'n_estimators': 2743, 'learning_rate': 0.013731488272772938, 'num_leaves': 201, 'max_depth': 6, 'min_child_samples': 50, 'min_split_gain': 0.0023977118767075645, 'bagging_fraction': 0.7460024065406161, 'bagging_freq': 3, 'feature_fraction': 0.8426410742426085, 'lambda_l1': 0.00030435343917399263, 'lambda_l2': 0.012117683250786111}. Best is trial 19 with value: 1.2060174196249716.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 10:23:56,750] Trial 23 finished with value: 1.2226605505114632 and parameters: {'n_estimators': 2961, 'learning_rate': 0.017016897098765315, 'num_leaves': 114, 'max_depth': 7, 'min_child_samples': 61, 'min_split_gain': 0.18962581717526045, 'bagging_fraction': 0.6133225614514182, 'bagging_freq': 3, 'feature_fraction': 0.9991143661696383, 'lambda_l1': 0.01387301241873506, 'lambda_l2': 0.0026989152581618566}. Best is trial 19 with value: 1.2060174196249716.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 10:24:47,077] Trial 24 finished with value: 1.199395211346907 and parameters: {'n_estimators': 2523, 'learning_rate': 0.007076800677741211, 'num_leaves': 8, 'max_depth': 4, 'min_child_samples': 28, 'min_split_gain': 2.860512340890998, 'bagging_fraction': 0.8823301047627877, 'bagging_freq': 2, 'feature_fraction': 0.937360387149544, 'lambda_l1': 8.890585248180424e-05, 'lambda_l2': 0.013586525811631587}. Best is trial 24 with value: 1.199395211346907.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 10:26:14,761] Trial 25 finished with value: 1.1947643819323477 and parameters: {'n_estimators': 2466, 'learning_rate': 0.006656706034902866, 'num_leaves': 15, 'max_depth': 4, 'min_child_samples': 24, 'min_split_gain': 2.8351348548630853, 'bagging_fraction': 0.9203249650011295, 'bagging_freq': 2, 'feature_fraction': 0.8754176692211909, 'lambda_l1': 4.0438212796207724e-07, 'lambda_l2': 0.0005472638215652903}. Best is trial 25 with value: 1.1947643819323477.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 10:27:11,078] Trial 26 finished with value: 1.215968914892814 and parameters: {'n_estimators': 2361, 'learning_rate': 0.005769372856188302, 'num_leaves': 79, 'max_depth': 4, 'min_child_samples': 15, 'min_split_gain': 3.098096523750363, 'bagging_fraction': 0.9994872916856206, 'bagging_freq': 3, 'feature_fraction': 0.7588423996534266, 'lambda_l1': 5.469492862036501e-07, 'lambda_l2': 0.00044785316015053894}. Best is trial 25 with value: 1.1947643819323477.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 10:28:14,323] Trial 27 finished with value: 1.1993473814722835 and parameters: {'n_estimators': 2409, 'learning_rate': 0.00568653269125402, 'num_leaves': 15, 'max_depth': 3, 'min_child_samples': 30, 'min_split_gain': 3.2383532801988006, 'bagging_fraction': 0.9240651380865392, 'bagging_freq': 2, 'feature_fraction': 0.8735825237746854, 'lambda_l1': 1.0972963295862112e-06, 'lambda_l2': 0.000155185332222094}. Best is trial 25 with value: 1.1947643819323477.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 10:29:00,779] Trial 28 finished with value: 1.1975470160562494 and parameters: {'n_estimators': 2388, 'learning_rate': 0.006170863783914819, 'num_leaves': 7, 'max_depth': 3, 'min_child_samples': 26, 'min_split_gain': 3.393816328216555, 'bagging_fraction': 0.9141347874841129, 'bagging_freq': 3, 'feature_fraction': 0.8849355795494473, 'lambda_l1': 7.906898841217634e-07, 'lambda_l2': 0.00014144041421182074}. Best is trial 25 with value: 1.1947643819323477.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 10:29:15,600] Trial 29 pruned.
# [I 2026-06-16 10:29:15,849] A new study created in RDB with name: KMIA_v9_remaining_warmup_base_catboost_mae_f
# [I 2026-06-16 10:46:31,714] Trial 0 finished with value: 1.3159347749174013 and parameters: {'iterations': 2931, 'learning_rate': 0.001783588943232587, 'depth': 10, 'l2_leaf_reg': 0.9942958882300413, 'random_strength': 7.186216756161439, 'bagging_temperature': 12.184767612363034, 'border_count': 110, 'rsm': 0.6158971964095841}. Best is trial 0 with value: 1.3159347749174013.
# [I 2026-06-16 10:53:30,632] Trial 1 finished with value: 1.3037028492721927 and parameters: {'iterations': 1809, 'learning_rate': 0.05045361458210069, 'depth': 12, 'l2_leaf_reg': 2.206716955900187, 'random_strength': 8.55303042123218, 'bagging_temperature': 2.269274022399408, 'border_count': 68, 'rsm': 0.9723568448941463}. Best is trial 1 with value: 1.3037028492721927.
# [I 2026-06-16 10:53:56,783] Trial 2 finished with value: 1.2947236152886024 and parameters: {'iterations': 3305, 'learning_rate': 0.13018523290940803, 'depth': 9, 'l2_leaf_reg': 0.29456409265689415, 'random_strength': 12.736640276136784, 'bagging_temperature': 2.78292503969807, 'border_count': 126, 'rsm': 0.9180110703516069}. Best is trial 2 with value: 1.2947236152886024.
# [I 2026-06-16 10:55:03,506] Trial 3 finished with value: 1.2905365368556672 and parameters: {'iterations': 941, 'learning_rate': 0.039289187448897187, 'depth': 11, 'l2_leaf_reg': 0.17184213389305913, 'random_strength': 11.258999163179464, 'bagging_temperature': 3.183105276262954, 'border_count': 57, 'rsm': 0.4176149246436502}. Best is trial 3 with value: 1.2905365368556672.
# [I 2026-06-16 10:57:48,419] Trial 4 finished with value: 1.5345280244828607 and parameters: {'iterations': 750, 'learning_rate': 0.012345725775087685, 'depth': 10, 'l2_leaf_reg': 185.34152922460115, 'random_strength': 16.100344011609046, 'bagging_temperature': 7.548308114328448, 'border_count': 139, 'rsm': 0.3882842988918503}. Best is trial 3 with value: 1.2905365368556672.

# %%
exported_weights = export_station_model_weights(
    project_root=PROJECT_ROOT,
    station_id=STATION_ID,
    artifact_dir=config.resolved_output_dir(),
    model_version=MODEL_VERSION,
    timing_mode=config.timing_mode,
    providers=tuple(config.providers),
    feature_version=config.effective_feature_version,
    optuna_metric=config.effective_optuna_metric,
    target_mode=config.effective_target_mode,
    source_pipeline="notebooks/experiments/station_stacking_v9",
)

exported_weights.bundle_path, exported_weights.manifest_path

# %% [markdown]
# ## V9 Feature Coverage

# %%
v9_feature_coverage = (
    result.features[V9_FEATURE_COLUMNS]
    .notna()
    .mean()
    .mul(100)
    .sort_values(ascending=False)
    .rename("coverage_pct")
    .reset_index()
    .rename(columns={"index": "feature"})
)

v9_feature_coverage

# %%
result.feature_columns.loc[result.feature_columns["feature"].isin(V9_FEATURE_COLUMNS)]

# %% [markdown]
# ## Dropped Feature Check

# %%
dropped_present = result.feature_columns.loc[
    result.feature_columns["feature"].isin(V9_DROPPED_FEATURE_COLUMNS)
]

dropped_present

# %% [markdown]
# ## Morning Trend Coverage

# %%
trend_coverage = (
    result.features[TREND_COLUMNS]
    .notna()
    .mean()
    .mul(100)
    .sort_values(ascending=False)
    .rename("coverage_pct")
    .reset_index()
    .rename(columns={"index": "feature"})
)

trend_coverage

# %% [markdown]
# ## Rounded Within 1F Accuracy

# %%
preds = pd.concat(
    [
        result.validation_predictions.assign(period="validation_2024_2025"),
        result.test_predictions.assign(period="oof_2026"),
    ],
    ignore_index=True,
)

predicted_high = pd.to_numeric(preds["predicted_high_f"], errors="coerce")
preds["predicted_high_rounded_f"] = np.floor(predicted_high + 0.5)
preds["within_1f_after_round"] = (
    pd.to_numeric(preds["actual_high_f"], errors="coerce") - preds["predicted_high_rounded_f"]
).abs().le(1)

within_1f_accuracy_by_period = (
    preds
    .dropna(subset=["actual_high_f", "predicted_high_rounded_f"])
    .groupby(["period", "method"], as_index=False)
    .agg(
        count=("within_1f_after_round", "size"),
        within_1f_count=("within_1f_after_round", "sum"),
        within_1f_accuracy_pct=("within_1f_after_round", lambda x: x.mean() * 100),
    )
    .sort_values(["period", "within_1f_accuracy_pct"], ascending=[True, False])
)

within_1f_accuracy_by_period

# %% [markdown]
# ## Version Comparison

# %%
comparison_frames = []
for version, folder in [
    ("v1", PROJECT_ROOT / "data" / "calibration" / "station_stacking"),
    ("v2", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v2"),
    ("v3", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v3"),
    ("v4", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v4"),
    ("v5", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v5"),
    ("v6", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v6"),
    ("v7", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v7"),
    ("v8", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v8"),
    ("v9", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v9"),
]:
    path = folder / f"{STATION_ID}_year_split_scoreboard.csv"
    if path.exists():
        frame = pd.read_csv(path)
        frame["version"] = version
        comparison_frames.append(frame)

version_comparison = pd.concat(comparison_frames, ignore_index=True) if comparison_frames else pd.DataFrame()
if not version_comparison.empty:
    version_comparison = version_comparison.sort_values(["period", "mae_f", "version", "method"]).reset_index(drop=True)
version_comparison

# %% [markdown]
# ## 2026 OOF Weather Brackets

# %%
result.bracket_metrics

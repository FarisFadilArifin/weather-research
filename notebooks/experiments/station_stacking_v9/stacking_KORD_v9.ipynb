# %% [markdown]
# # Station Stacking v9 - KORD
#
# Experimental notebook for `KORD`.
#
# This version keeps the v8 live-safe GFS/HRRR/NBM contract, adds source-owned 10-year calendar-day max-temperature climatology features, and trains base learners on remaining warmup from the observed high-so-far. Artifacts are written to `data/calibration/station_stacking_v9`.

# %%
from pathlib import Path
import os
import sys
import warnings

warnings.filterwarnings("ignore", message="IProgress not found.*")
warnings.filterwarnings("ignore", message="Skipping features without any observed values.*")

PROJECT_ROOT = Path.cwd().resolve()
while not (PROJECT_ROOT / "src" / "calibration" / "station_stacking.py").exists():
    if PROJECT_ROOT.parent == PROJECT_ROOT:
        raise RuntimeError("Could not find project root containing src/calibration/station_stacking.py")
    PROJECT_ROOT = PROJECT_ROOT.parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

os.environ["WEATHER_RESEARCH_INCLUDE_DIRECT_NBM"] = "1"

STATION_ID = "KORD"
PROVIDERS = ("gfs", "hrrr", "nbm")
TREND_COLUMNS = [
    "observed_temp_change_last_1h_f",
    "observed_temp_change_last_3h_f",
    "observed_morning_warmup_rate_f_per_hour",
    "observed_high_so_far_change_since_9am_f",
]
TIMING_MODE = "same_day_11am_live_safe"
FAST_MODE = False
OPTUNA_TRIALS = 30
STACK_OPTUNA_TRIALS = 30
OPTUNA_STARTUP_TRIALS = 15
STACK_OPTUNA_STARTUP_TRIALS = 15
OPTUNA_METRIC = "mae_f"
OPTUNA_VERBOSE = True
MODEL_VERSION = "station_high_regressor_v9_remaining_warmup"
PROJECT_ROOT
# Out:
# WindowsPath('D:/dev/weather-research')

# %%
import numpy as np
import pandas as pd

from src.export_station_stacking_v2_models import export_station_model_weights
from src.calibration.station_stacking import (
    StationStackingConfig,
    V9_DROPPED_FEATURE_COLUMNS,
    V9_FEATURE_COLUMNS,
    YEAR_SPLIT_EXPANDING_FOLDS,
    missing_model_dependencies,
    provider_availability,
    run_station_year_split_experiment,
)

# %% [markdown]
# ## V9 Contract
#
# `feature_version="v9"` keeps the v8 remaining-warmup feature set, adds leakage-safe 10-year calendar-day climatology features, and uses `target_mode="remaining_warmup"` so base learners fit `actual_high_f - observed_high_temp_through_as_of_f` before converting back to `predicted_high_f`.

# %%
fold_spec = pd.DataFrame(
    [
        {
            "fold": fold.name,
            "train_start_year": fold.train_start_year,
            "train_end_year": fold.train_end_year,
            "validation_year": fold.validation_year,
        }
        for fold in YEAR_SPLIT_EXPANDING_FOLDS
    ]
)

fold_spec
# Out:
#                      fold  train_start_year  train_end_year  validation_year
# 0  fold_2021_2023_to_2024              2021            2023             2024
# 1  fold_2021_2024_to_2025              2021            2024             2025

# %%
V9_FEATURE_COLUMNS, sorted(V9_DROPPED_FEATURE_COLUMNS)
# Out:
# (['v2_recent_heat_anomaly_f',
#   'v2_recent_heat_momentum_f',
#   'v2_morning_warmup_to_consensus_f',
#   'v2_consensus_minus_7d_actual_f',
#   'v2_spread_per_warmup_f',
#   'v2_humidity_warmup_interaction',
#   'v3_high_so_far_above_current_f',
#   'v3_remaining_warmup_from_high_so_far_f',
#   'v3_high_so_far_minus_lag_1d_f',
#   'v3_high_so_far_minus_7d_actual_f',
#   'v3_remaining_warmup_per_spread_f',
#   'v3_humidity_remaining_warmup_interaction',
#   'v4_forecast_precip_total_mean_mm',
#   'v4_forecast_precip_total_max_mm',
#   'v4_forecast_precip_total_spread_mm',
#   'v4_forecast_precip_max_1h_mean_mm',
#   'v4_forecast_precip_hours_mean',
#   'v4_forecast_precip_intensity_mean',
#   'v4_forecast_precip_intensity_max',
#   'v4_any_forecast_precip',
#   'v4_all_forecast_precip',
#   'v4_observed_precip_any',
#   'v4_observed_precip_recent_mm_est',
#   'v4_forecast_total_minus_observed_recent_mm',
#   'v4_forecast_observed_precip_match',
#   'v4_forecast_wet_observed_dry',
#   'v4_observed_wet_forecast_dry',
#   'v4_precip_humidity_interaction',
#   'v4_precip_remaining_warmup_interaction',
#   'observed_temp_change_last_1h_f',
#   'observed_temp_change_last_3h_f',
#   'observed_morning_warmup_rate_f_per_hour',
#   'observed_high_so_far_change_since_9am_f',
#   'v8_provider_max_remaining_from_high_so_far_f',
#   'v8_provider_min_remaining_from_high_so_far_f',
#   'v8_provider_median_remaining_from_high_so_far_f',
#   'v8_provider_spread_per_remaining_warmup_f',
#   'v8_month_remaining_warmup_mean_f',
#   'v8_month_remaining_warmup_count',
#   'v8_recent_remaining_warmup_7d_mean_f',
#   'v8_recent_remaining_warmup_30d_mean_f',
#   'v8_provider_mean_remaining_vs_month_normal_f',
#   'v8_cloud_cover_mean_remaining_warmup_interaction',
#   'v8_cloud_cover_max_remaining_warmup_interaction',
#   'v8_precip_total_remaining_warmup_interaction',
#   'v8_precip_max_1h_remaining_warmup_interaction',
#   'v8_wind_speed_mean_remaining_warmup_interaction',
#   'v8_wind_gust_max_remaining_warmup_interaction',
#   'v8_forecast_dewpoint_mean_f',
#   'v8_forecast_dewpoint_depression_mean_f',
#   'v8_dewpoint_mean_remaining_warmup_interaction',
#   'v8_dewpoint_depression_remaining_warmup_interaction',
#   'climatology_high_10y_f',
#   'climatology_high_10y_std_f',
#   'climatology_high_10y_count',
#   'provider_mean_minus_climatology_10y_f',
#   'observed_temp_minus_climatology_10y_f',
#   'observed_high_so_far_minus_climatology_10y_f'],
#  ['actual_minus_climatology_10y_f_DIAGNOSTIC_ONLY',
#   'climatology_source_end_year',
#   'climatology_source_start_year',
#   'gfs_as_of_hour_local',
#   'gfs_available',
#   'gfs_forecast_window_hours',
#   'gfs_grid_dist_km_mean',
#   'gfs_horizon_hours',
#   'gfs_hrrr_grid_dist_km_mean_abs_diff_f',
#   'gfs_hrrr_grid_dist_km_mean_diff_f',
#   'gfs_issue_hour_utc',
#   'gfs_missing',
#   'hrrr_as_of_hour_local',
#   'hrrr_available',
#   'hrrr_forecast_hour_max',
#   'hrrr_forecast_hour_min',
#   'hrrr_forecast_lead_hours',
#   'hrrr_forecast_window_hours',
#   'hrrr_grid_dist_km_mean',
#   'hrrr_horizon_hours',
#   'hrrr_issue_hour_local',
#   'hrrr_issue_hour_utc',
#   'hrrr_missing',
#   'is_active_polymarket_station',
#   'lat',
#   'lon',
#   'nbm_as_of_hour_local',
#   'nbm_available',
#   'nbm_forecast_window_hours',
#   'nbm_horizon_hours',
#   'nbm_issue_hour_local',
#   'nbm_issue_hour_utc',
#   'nbm_missing',
#   'observed_fetch_status',
#   'observed_observation_type',
#   'observed_pressure_source',
#   'provider_count_available',
#   'year'])

# %% [markdown]
# ## Data Availability

# %%
availability = provider_availability(
    PROJECT_ROOT,
    timing_mode=TIMING_MODE,
    providers=PROVIDERS,
)

availability.loc[availability["station_id"].eq(STATION_ID)]
# Out:
#    station_id provider  row_count first_contract_date last_contract_date
# 21       KORD      gfs       1983          2021-01-01         2026-06-10
# 22       KORD     hrrr       1987          2021-01-01         2026-06-10
# 23       KORD      nbm       1986          2021-01-01         2026-06-10

# %% [markdown]
# ## Model Scores

# %%
missing_packages = missing_model_dependencies()
if missing_packages:
    raise ImportError(
        "Missing station-stacking ML packages: "
        + ", ".join(missing_packages)
        + ". Install them with: python -m pip install -r requirements.txt"
    )

config = StationStackingConfig(
    station_id=STATION_ID,
    project_root=PROJECT_ROOT,
    timing_mode=TIMING_MODE,
    providers=PROVIDERS,
    fast_mode=FAST_MODE,
    optuna_trials=OPTUNA_TRIALS,
    stack_optuna_trials=STACK_OPTUNA_TRIALS,
    optuna_startup_trials=OPTUNA_STARTUP_TRIALS,
    stack_optuna_startup_trials=STACK_OPTUNA_STARTUP_TRIALS,
    optuna_metric=OPTUNA_METRIC,
    optuna_verbose=OPTUNA_VERBOSE,
    feature_version="v9",
    target_mode="remaining_warmup",
    hyperparameter_space="wide",
    year_split_folds=YEAR_SPLIT_EXPANDING_FOLDS,
    year_split_test_train_years=(2021, 2025),
    year_split_test_year=2026,
    output_dir=PROJECT_ROOT / "data" / "calibration" / "station_stacking_v9",
)

config.resolved_optuna_storage_path()
# Out:
# WindowsPath('D:/dev/weather-research/data/calibration/station_stacking_v9/KORD_optuna.sqlite3')

# %%
result = run_station_year_split_experiment(config)
result.scoreboard
# Out:
# [I 2026-06-16 07:24:45,838] A new study created in RDB with name: KORD_v9_remaining_warmup_base_xgboost_mae_f
# [I 2026-06-16 07:25:01,332] Trial 0 finished with value: 1.5655714946732302 and parameters: {'n_estimators': 1342, 'learning_rate': 0.19043899115982607, 'max_depth': 9, 'min_child_weight': 2.481040974867813, 'gamma': 2.340279606636548, 'subsample': 0.4513964382185317, 'colsample_bytree': 0.3877543479093296, 'reg_alpha': 2.478071022662141, 'reg_lambda': 0.6132587025321562}. Best is trial 0 with value: 1.5655714946732302.
# [I 2026-06-16 07:30:28,431] Trial 1 finished with value: 1.4877886190097322 and parameters: {'n_estimators': 2493, 'learning_rate': 0.001120367191095075, 'max_depth': 12, 'min_child_weight': 21.368329072358772, 'gamma': 3.185086660174142, 'subsample': 0.4681862286846154, 'colsample_bytree': 0.46921293140473197, 'reg_alpha': 4.476173538513514e-07, 'reg_lambda': 0.20253776634919213}. Best is trial 1 with value: 1.4877886190097322.
# [I 2026-06-16 07:32:18,079] Trial 2 finished with value: 1.4486005429349134 and parameters: {'n_estimators': 1540, 'learning_rate': 0.004992867109217114, 'max_depth': 8, 'min_child_weight': 0.03613894271216528, 'gamma': 4.3821697280282725, 'subsample': 0.5881351981408995, 'colsample_bytree': 0.6464454897410734, 'reg_alpha': 0.26430874752361627, 'reg_lambda': 0.0018119678627933364}. Best is trial 2 with value: 1.4486005429349134.
# [I 2026-06-16 07:32:37,668] Trial 3 finished with value: 1.534182897541443 and parameters: {'n_estimators': 1824, 'learning_rate': 0.026337502897485255, 'max_depth': 1, 'min_child_weight': 2.69264691008618, 'gamma': 2.557861855309373, 'subsample': 0.39228353544043165, 'colsample_bytree': 0.9667755992146666, 'reg_alpha': 38.6887231523051, 'reg_lambda': 12.408975837016275}. Best is trial 2 with value: 1.4486005429349134.
# [I 2026-06-16 07:35:03,268] Trial 4 finished with value: 1.6261660877376038 and parameters: {'n_estimators': 1101, 'learning_rate': 0.0017147936629846843, 'max_depth': 9, 'min_child_weight': 0.5762487216478605, 'gamma': 1.8305735226716824, 'subsample': 0.6718649915723256, 'colsample_bytree': 0.37235253872489193, 'reg_alpha': 8.162906555194692, 'reg_lambda': 0.004271500153828077}. Best is trial 2 with value: 1.4486005429349134.
# [I 2026-06-16 07:36:40,331] Trial 5 pruned.
# [I 2026-06-16 07:36:45,463] Trial 6 finished with value: 1.461953964813404 and parameters: {'n_estimators': 2113, 'learning_rate': 0.16240489353272883, 'max_depth': 2, 'min_child_weight': 0.06080390190296603, 'gamma': 0.678409333658071, 'subsample': 0.5614647149961218, 'colsample_bytree': 0.6026402382981633, 'reg_alpha': 1.8037999945880162e-07, 'reg_lambda': 16.668629892722056}. Best is trial 2 with value: 1.4486005429349134.
# [I 2026-06-16 07:38:03,439] Trial 7 finished with value: 1.4367123689958092 and parameters: {'n_estimators': 1281, 'learning_rate': 0.0047169807141865345, 'max_depth': 7, 'min_child_weight': 0.0366181922039243, 'gamma': 12.032954711310595, 'subsample': 0.398457918391851, 'colsample_bytree': 0.9914765087903362, 'reg_alpha': 0.18490013641000916, 'reg_lambda': 0.0017869543989965139}. Best is trial 7 with value: 1.4367123689958092.
# [I 2026-06-16 07:38:09,047] Trial 8 pruned.
# [I 2026-06-16 07:39:10,774] Trial 9 finished with value: 1.4668978933596502 and parameters: {'n_estimators': 2201, 'learning_rate': 0.006215464818952927, 'max_depth': 1, 'min_child_weight': 0.17535949529764422, 'gamma': 4.877749830401205, 'subsample': 0.8242440159197416, 'colsample_bytree': 0.7644123563808884, 'reg_alpha': 4.4315220126915325, 'reg_lambda': 0.09450187118503514}. Best is trial 7 with value: 1.4367123689958092.
# [I 2026-06-16 07:39:18,335] Trial 10 finished with value: 1.4901924171122962 and parameters: {'n_estimators': 462, 'learning_rate': 0.051323729958866915, 'max_depth': 10, 'min_child_weight': 1.7583640270008525, 'gamma': 11.564507699318415, 'subsample': 0.670967137636854, 'colsample_bytree': 0.689776339098296, 'reg_alpha': 1.3504926357029513e-05, 'reg_lambda': 0.0001445994629863374}. Best is trial 7 with value: 1.4367123689958092.
# [I 2026-06-16 07:39:45,832] Trial 11 pruned.
# [I 2026-06-16 07:40:14,824] Trial 12 pruned.
# [I 2026-06-16 07:40:18,327] Trial 13 pruned.
# [I 2026-06-16 07:40:31,081] Trial 14 finished with value: 1.4762296911175505 and parameters: {'n_estimators': 2872, 'learning_rate': 0.11587248002108354, 'max_depth': 1, 'min_child_weight': 1.1040511903162256, 'gamma': 6.261165047231685, 'subsample': 0.49437007680597467, 'colsample_bytree': 0.4279124887668938, 'reg_alpha': 1.125594744942969e-06, 'reg_lambda': 87.35792858155622}. Best is trial 7 with value: 1.4367123689958092.
# [I 2026-06-16 07:42:34,116] Trial 15 finished with value: 1.4447891533175634 and parameters: {'n_estimators': 1450, 'learning_rate': 0.006031201630098316, 'max_depth': 5, 'min_child_weight': 0.010825117624685654, 'gamma': 9.207834502381042, 'subsample': 0.6751949773929053, 'colsample_bytree': 0.9845458960256637, 'reg_alpha': 0.0068670144396942604, 'reg_lambda': 0.0010702366059917871}. Best is trial 7 with value: 1.4367123689958092.
# [I 2026-06-16 07:43:36,463] Trial 16 pruned.
# [I 2026-06-16 07:45:58,340] Trial 17 finished with value: 1.4607030957888574 and parameters: {'n_estimators': 1683, 'learning_rate': 0.002964813715144446, 'max_depth': 5, 'min_child_weight': 0.010651095114498622, 'gamma': 9.900657277274286, 'subsample': 0.7240515678657221, 'colsample_bytree': 0.9054222541299508, 'reg_alpha': 0.008231222853503419, 'reg_lambda': 0.0020474808389936774}. Best is trial 7 with value: 1.4367123689958092.
# [I 2026-06-16 07:46:10,454] Trial 18 pruned.
# [I 2026-06-16 07:47:01,492] Trial 19 finished with value: 1.4640699737471319 and parameters: {'n_estimators': 986, 'learning_rate': 0.008737417060620015, 'max_depth': 6, 'min_child_weight': 0.13046315760171479, 'gamma': 14.952751770305316, 'subsample': 0.6485674273792982, 'colsample_bytree': 0.9880808260630232, 'reg_alpha': 0.0002379694961662832, 'reg_lambda': 0.000441359274017044}. Best is trial 7 with value: 1.4367123689958092.
# [I 2026-06-16 07:47:54,289] Trial 20 pruned.
# [I 2026-06-16 07:52:48,612] Trial 21 pruned.
# [I 2026-06-16 07:57:39,038] Trial 22 finished with value: 1.4512787384152106 and parameters: {'n_estimators': 1438, 'learning_rate': 0.007588159540362721, 'max_depth': 11, 'min_child_weight': 0.06570976356377647, 'gamma': 7.827449727124844, 'subsample': 0.5173731999107088, 'colsample_bytree': 0.7089926625552748, 'reg_alpha': 0.1530574005342073, 'reg_lambda': 0.0005994052295888814}. Best is trial 7 with value: 1.4367123689958092.
# [I 2026-06-16 08:02:34,211] Trial 23 pruned.
# [I 2026-06-16 08:03:24,308] Trial 24 pruned.
# [I 2026-06-16 08:07:51,932] Trial 25 pruned.
# [I 2026-06-16 08:09:39,353] Trial 26 finished with value: 1.459973171909108 and parameters: {'n_estimators': 723, 'learning_rate': 0.029583000028224452, 'max_depth': 8, 'min_child_weight': 0.0364456097292703, 'gamma': 4.881029817548571, 'subsample': 0.551206539610752, 'colsample_bytree': 0.5133337254766398, 'reg_alpha': 0.4708260200656459, 'reg_lambda': 0.00028527357527133773}. Best is trial 7 with value: 1.4367123689958092.
# [I 2026-06-16 08:15:48,381] Trial 27 finished with value: 1.4447361481468604 and parameters: {'n_estimators': 1591, 'learning_rate': 0.004901383237176615, 'max_depth': 5, 'min_child_weight': 0.01729291811298725, 'gamma': 6.218676048475828, 'subsample': 0.6120030368011062, 'colsample_bytree': 0.7893146203952413, 'reg_alpha': 0.00015739051741730562, 'reg_lambda': 0.028977571065172406}. Best is trial 7 with value: 1.4367123689958092.
# [I 2026-06-16 08:19:08,043] Trial 28 finished with value: 1.4326511712704968 and parameters: {'n_estimators': 2016, 'learning_rate': 0.008653459476094002, 'max_depth': 4, 'min_child_weight': 0.015201512834717375, 'gamma': 6.1559548006996545, 'subsample': 0.7394884261088771, 'colsample_bytree': 0.9979415776653897, 'reg_alpha': 9.729993894598084e-05, 'reg_lambda': 0.988404886583712}. Best is trial 28 with value: 1.4326511712704968.
# [I 2026-06-16 08:19:21,993] Trial 29 pruned.
# [I 2026-06-16 08:19:22,540] A new study created in RDB with name: KORD_v9_remaining_warmup_base_lightgbm_mae_f
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 08:21:55,359] Trial 0 finished with value: 1.477845325854815 and parameters: {'n_estimators': 447, 'learning_rate': 0.028873871707375695, 'num_leaves': 71, 'max_depth': 5, 'min_child_samples': 83, 'min_split_gain': 4.295687454742988, 'bagging_fraction': 0.7829586385137167, 'bagging_freq': 4, 'feature_fraction': 0.3688589858758342, 'lambda_l1': 0.06382334403151436, 'lambda_l2': 0.03080292177315921}. Best is trial 0 with value: 1.477845325854815.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 08:23:53,162] Trial 1 finished with value: 1.5197384689486515 and parameters: {'n_estimators': 2817, 'learning_rate': 0.004074615160588706, 'num_leaves': 32, 'max_depth': 13, 'min_child_samples': 57, 'min_split_gain': 2.0249472402362985, 'bagging_fraction': 0.5554627061618356, 'bagging_freq': 1, 'feature_fraction': 0.898096051249308, 'lambda_l1': 1.5391104005532914, 'lambda_l2': 132.19976430960952}. Best is trial 0 with value: 1.477845325854815.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 08:23:58,856] Trial 2 finished with value: 1.467261459027609 and parameters: {'n_estimators': 1379, 'learning_rate': 0.1944487980595256, 'num_leaves': 230, 'max_depth': 10, 'min_child_samples': 22, 'min_split_gain': 4.485492899907672, 'bagging_fraction': 0.5437022754476957, 'bagging_freq': 2, 'feature_fraction': 0.353334206891897, 'lambda_l1': 0.00032993636349211094, 'lambda_l2': 0.09925376145099525}. Best is trial 2 with value: 1.467261459027609.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 08:24:04,176] Trial 3 finished with value: 1.568161304799033 and parameters: {'n_estimators': 2246, 'learning_rate': 0.22165362064553062, 'num_leaves': 466, 'max_depth': 13, 'min_child_samples': 132, 'min_split_gain': 0.5200947492738145, 'bagging_fraction': 0.4675944869176356, 'bagging_freq': 7, 'feature_fraction': 0.6177694392011331, 'lambda_l1': 2.399967979035352, 'lambda_l2': 1.7195277953675168}. Best is trial 2 with value: 1.467261459027609.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 08:25:11,354] Trial 4 finished with value: 1.512019496531085 and parameters: {'n_estimators': 2219, 'learning_rate': 0.004579029224032115, 'num_leaves': 460, 'max_depth': 4, 'min_child_samples': 102, 'min_split_gain': 4.967862461970517, 'bagging_fraction': 0.8282226029796285, 'bagging_freq': 4, 'feature_fraction': 0.7144310601384277, 'lambda_l1': 8.61124348208611e-06, 'lambda_l2': 3.808668235343267}. Best is trial 2 with value: 1.467261459027609.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 08:25:14,495] Trial 5 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 08:25:31,142] Trial 6 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 08:25:33,583] Trial 7 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 08:25:37,377] Trial 8 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 08:26:17,630] Trial 9 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 08:26:21,689] Trial 10 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 08:26:29,846] Trial 11 finished with value: 1.4574257175078777 and parameters: {'n_estimators': 756, 'learning_rate': 0.06114521776634082, 'num_leaves': 57, 'max_depth': 2, 'min_child_samples': 85, 'min_split_gain': 4.846277519155279, 'bagging_fraction': 0.8056341981316478, 'bagging_freq': 3, 'feature_fraction': 0.42848891083526186, 'lambda_l1': 5.301057710204056e-10, 'lambda_l2': 3.7660106129974493}. Best is trial 11 with value: 1.4574257175078777.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 08:29:03,960] Trial 12 finished with value: 1.5160359215271781 and parameters: {'n_estimators': 3174, 'learning_rate': 0.0010925194811392835, 'num_leaves': 301, 'max_depth': 11, 'min_child_samples': 74, 'min_split_gain': 2.613988081636218, 'bagging_fraction': 0.8796537260629015, 'bagging_freq': 5, 'feature_fraction': 0.5960609706435204, 'lambda_l1': 8.524985832885774e-10, 'lambda_l2': 0.1169527455154188}. Best is trial 11 with value: 1.4574257175078777.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 08:29:23,642] Trial 13 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 08:29:26,377] Trial 14 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 08:29:39,068] Trial 15 finished with value: 1.4561797122580034 and parameters: {'n_estimators': 1059, 'learning_rate': 0.0762325922699799, 'num_leaves': 172, 'max_depth': 7, 'min_child_samples': 7, 'min_split_gain': 4.29797426762184, 'bagging_fraction': 0.6872347928407148, 'bagging_freq': 2, 'feature_fraction': 0.3803537419595536, 'lambda_l1': 0.0003638671644394094, 'lambda_l2': 13.944079404946716}. Best is trial 15 with value: 1.4561797122580034.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 08:30:08,660] Trial 16 finished with value: 1.4654512313457537 and parameters: {'n_estimators': 1061, 'learning_rate': 0.0715924223782409, 'num_leaves': 147, 'max_depth': 7, 'min_child_samples': 4, 'min_split_gain': 3.807811374040158, 'bagging_fraction': 0.7278550857749273, 'bagging_freq': 2, 'feature_fraction': 0.4491338962431932, 'lambda_l1': 4.598046653413572e-06, 'lambda_l2': 13.72990199966158}. Best is trial 15 with value: 1.4561797122580034.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 08:30:31,899] Trial 17 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 08:31:16,611] Trial 18 finished with value: 1.458974754597752 and parameters: {'n_estimators': 809, 'learning_rate': 0.06386859555410404, 'num_leaves': 105, 'max_depth': 6, 'min_child_samples': 32, 'min_split_gain': 4.3432306610365945, 'bagging_fraction': 0.9610905027619268, 'bagging_freq': 1, 'feature_fraction': 0.43326112247013576, 'lambda_l1': 5.690506123526996e-07, 'lambda_l2': 12.953432630897868}. Best is trial 15 with value: 1.4561797122580034.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 08:31:59,124] Trial 19 finished with value: 1.4439068830951984 and parameters: {'n_estimators': 1241, 'learning_rate': 0.014686373893607947, 'num_leaves': 8, 'max_depth': 3, 'min_child_samples': 45, 'min_split_gain': 4.517405380294325, 'bagging_fraction': 0.6369942064651551, 'bagging_freq': 3, 'feature_fraction': 0.4006258575761135, 'lambda_l1': 0.0011742184238298864, 'lambda_l2': 0.002424590415633956}. Best is trial 19 with value: 1.4439068830951984.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 08:32:54,848] Trial 20 finished with value: 1.452623410029668 and parameters: {'n_estimators': 1381, 'learning_rate': 0.015175984312069691, 'num_leaves': 5, 'max_depth': 4, 'min_child_samples': 46, 'min_split_gain': 3.3097055791444365, 'bagging_fraction': 0.6237391623437989, 'bagging_freq': 3, 'feature_fraction': 0.4897836272918511, 'lambda_l1': 0.003018538600923164, 'lambda_l2': 0.0017910652523956982}. Best is trial 19 with value: 1.4439068830951984.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 08:34:05,688] Trial 21 finished with value: 1.4493506742627875 and parameters: {'n_estimators': 1250, 'learning_rate': 0.012317819831752423, 'num_leaves': 204, 'max_depth': 4, 'min_child_samples': 49, 'min_split_gain': 3.3002915813623948, 'bagging_fraction': 0.6292125190343529, 'bagging_freq': 3, 'feature_fraction': 0.4794872656231891, 'lambda_l1': 0.005975122323757684, 'lambda_l2': 0.001767109835027613}. Best is trial 19 with value: 1.4439068830951984.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 08:35:58,299] Trial 22 finished with value: 1.4576073221824932 and parameters: {'n_estimators': 1307, 'learning_rate': 0.012656691938572327, 'num_leaves': 10, 'max_depth': 4, 'min_child_samples': 45, 'min_split_gain': 2.1941090469193876, 'bagging_fraction': 0.5934248266523693, 'bagging_freq': 3, 'feature_fraction': 0.49926903422002705, 'lambda_l1': 0.008305483831727354, 'lambda_l2': 0.0016531706979705657}. Best is trial 19 with value: 1.4439068830951984.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 08:38:07,499] Trial 23 finished with value: 1.46432022578729 and parameters: {'n_estimators': 1512, 'learning_rate': 0.007792368462045585, 'num_leaves': 7, 'max_depth': 3, 'min_child_samples': 48, 'min_split_gain': 3.2499108638243746, 'bagging_fraction': 0.6322295425640821, 'bagging_freq': 3, 'feature_fraction': 0.9988762578400383, 'lambda_l1': 0.023462362581378127, 'lambda_l2': 0.0018025553502365006}. Best is trial 19 with value: 1.4439068830951984.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 08:39:17,423] Trial 24 finished with value: 1.477082274158913 and parameters: {'n_estimators': 2609, 'learning_rate': 0.01951430841780518, 'num_leaves': 99, 'max_depth': 4, 'min_child_samples': 60, 'min_split_gain': 3.476090390225602, 'bagging_fraction': 0.7267118366653247, 'bagging_freq': 3, 'feature_fraction': 0.5154267080115253, 'lambda_l1': 0.0008668606200101689, 'lambda_l2': 0.0015068477402054288}. Best is trial 19 with value: 1.4439068830951984.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 08:41:46,279] Trial 25 finished with value: 1.4480782725491497 and parameters: {'n_estimators': 1169, 'learning_rate': 0.006269863857748368, 'num_leaves': 264, 'max_depth': 3, 'min_child_samples': 28, 'min_split_gain': 2.4147141630241524, 'bagging_fraction': 0.5493993666305377, 'bagging_freq': 2, 'feature_fraction': 0.41935054173150776, 'lambda_l1': 0.060179351301551644, 'lambda_l2': 0.008507197296305271}. Best is trial 19 with value: 1.4439068830951984.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 08:44:46,646] Trial 26 finished with value: 1.4574724876932152 and parameters: {'n_estimators': 1174, 'learning_rate': 0.006231473414338924, 'num_leaves': 240, 'max_depth': 3, 'min_child_samples': 31, 'min_split_gain': 1.738310487558495, 'bagging_fraction': 0.5452814650155995, 'bagging_freq': 1, 'feature_fraction': 0.40559638330599423, 'lambda_l1': 0.15871328071837423, 'lambda_l2': 0.009841993357265927}. Best is trial 19 with value: 1.4439068830951984.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 08:45:44,889] Trial 27 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 08:46:24,878] Trial 28 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 08:51:17,988] Trial 29 finished with value: 1.4890615530127673 and parameters: {'n_estimators': 623, 'learning_rate': 0.0055375188260514225, 'num_leaves': 206, 'max_depth': 5, 'min_child_samples': 33, 'min_split_gain': 2.609016513124846, 'bagging_fraction': 0.7333891069015124, 'bagging_freq': 4, 'feature_fraction': 0.3619531921576506, 'lambda_l1': 0.16752459595836222, 'lambda_l2': 0.004008767922222539}. Best is trial 19 with value: 1.4439068830951984.
# [I 2026-06-16 08:51:18,391] A new study created in RDB with name: KORD_v9_remaining_warmup_base_catboost_mae_f
# [I 2026-06-16 09:12:55,135] Trial 0 finished with value: 1.706014731704799 and parameters: {'iterations': 2931, 'learning_rate': 0.001783588943232587, 'depth': 10, 'l2_leaf_reg': 0.9942958882300413, 'random_strength': 7.186216756161439, 'bagging_temperature': 12.184767612363034, 'border_count': 110, 'rsm': 0.6158971964095841}. Best is trial 0 with value: 1.706014731704799.
# [I 2026-06-16 09:25:19,466] Trial 1 finished with value: 1.629023452221944 and parameters: {'iterations': 1809, 'learning_rate': 0.05045361458210069, 'depth': 12, 'l2_leaf_reg': 2.206716955900187, 'random_strength': 8.55303042123218, 'bagging_temperature': 2.269274022399408, 'border_count': 68, 'rsm': 0.9723568448941463}. Best is trial 1 with value: 1.629023452221944.
# [I 2026-06-16 09:26:33,939] Trial 2 finished with value: 1.5832534650815144 and parameters: {'iterations': 3305, 'learning_rate': 0.13018523290940803, 'depth': 9, 'l2_leaf_reg': 0.29456409265689415, 'random_strength': 12.736640276136784, 'bagging_temperature': 2.78292503969807, 'border_count': 126, 'rsm': 0.9180110703516069}. Best is trial 2 with value: 1.5832534650815144.
# [I 2026-06-16 09:28:51,842] Trial 3 finished with value: 1.6211163203106498 and parameters: {'iterations': 941, 'learning_rate': 0.039289187448897187, 'depth': 11, 'l2_leaf_reg': 0.17184213389305913, 'random_strength': 11.258999163179464, 'bagging_temperature': 3.183105276262954, 'border_count': 57, 'rsm': 0.4176149246436502}. Best is trial 2 with value: 1.5832534650815144.
# [I 2026-06-16 09:36:24,416] Trial 4 finished with value: 2.2640858323605895 and parameters: {'iterations': 750, 'learning_rate': 0.012345725775087685, 'depth': 10, 'l2_leaf_reg': 185.34152922460115, 'random_strength': 16.100344011609046, 'bagging_temperature': 7.548308114328448, 'border_count': 139, 'rsm': 0.3882842988918503}. Best is trial 2 with value: 1.5832534650815144.
# [I 2026-06-16 10:00:25,019] Trial 5 pruned.
# [I 2026-06-16 10:07:48,656] Trial 6 finished with value: 1.5394885715588191 and parameters: {'iterations': 3092, 'learning_rate': 0.0016894180053021765, 'depth': 7, 'l2_leaf_reg': 2.9770736659303028, 'random_strength': 2.1794700787166432, 'bagging_temperature': 3.0746892172349938, 'border_count': 252, 'rsm': 0.5265140999127667}. Best is trial 6 with value: 1.5394885715588191.
# [I 2026-06-16 10:08:48,304] Trial 7 finished with value: 1.5319957439870928 and parameters: {'iterations': 3146, 'learning_rate': 0.0024764229908984673, 'depth': 3, 'l2_leaf_reg': 0.6951779671472356, 'random_strength': 6.148451176512449, 'bagging_temperature': 8.441103735088014, 'border_count': 95, 'rsm': 0.7192489923988105}. Best is trial 7 with value: 1.5319957439870928.
# [I 2026-06-16 10:09:14,609] Trial 8 finished with value: 1.528147931490605 and parameters: {'iterations': 378, 'learning_rate': 0.08194116550819189, 'depth': 4, 'l2_leaf_reg': 95.92707399961093, 'random_strength': 18.034879593317157, 'bagging_temperature': 0.3171560070252766, 'border_count': 220, 'rsm': 0.7891440128855358}. Best is trial 8 with value: 1.528147931490605.
# [I 2026-06-16 10:09:46,317] Trial 9 pruned.
# [I 2026-06-16 10:11:27,171] Trial 10 pruned.
# [I 2026-06-16 10:11:37,764] Trial 11 pruned.
# [I 2026-06-16 10:12:14,483] Trial 12 pruned.
# [I 2026-06-16 10:12:22,789] Trial 13 pruned.
# [I 2026-06-16 10:12:51,769] Trial 14 pruned.
# [I 2026-06-16 10:12:58,084] Trial 15 finished with value: 1.4606633063344043 and parameters: {'iterations': 1613, 'learning_rate': 0.17400560929273204, 'depth': 3, 'l2_leaf_reg': 0.05272080051940796, 'random_strength': 19.80133610807421, 'bagging_temperature': 9.006476155816854, 'border_count': 17, 'rsm': 0.7470092642138426}. Best is trial 15 with value: 1.4606633063344043.
# [I 2026-06-16 10:13:02,896] Trial 16 finished with value: 1.5061968798895067 and parameters: {'iterations': 1333, 'learning_rate': 0.21849498986979207, 'depth': 3, 'l2_leaf_reg': 0.11923820693276029, 'random_strength': 19.99201330625332, 'bagging_temperature': 0.40633186988867287, 'border_count': 18, 'rsm': 0.7682154289388926}. Best is trial 15 with value: 1.4606633063344043.
# [I 2026-06-16 10:13:04,856] Trial 17 pruned.
# [I 2026-06-16 10:13:09,268] Trial 18 finished with value: 1.6046847256308747 and parameters: {'iterations': 1847, 'learning_rate': 0.24430955102327206, 'depth': 5, 'l2_leaf_reg': 0.055914433018036, 'random_strength': 19.79559335918311, 'bagging_temperature': 5.910459732318402, 'border_count': 21, 'rsm': 0.8235932218979889}. Best is trial 15 with value: 1.4606633063344043.
# [I 2026-06-16 10:13:18,760] Trial 19 finished with value: 1.5258562840305407 and parameters: {'iterations': 1662, 'learning_rate': 0.12393747497004912, 'depth': 5, 'l2_leaf_reg': 0.15669867386935404, 'random_strength': 15.611554823795153, 'bagging_temperature': 19.894137039228873, 'border_count': 16, 'rsm': 0.6522687302274486}. Best is trial 15 with value: 1.4606633063344043.
# [I 2026-06-16 10:13:24,551] Trial 20 finished with value: 1.4126996340697824 and parameters: {'iterations': 1188, 'learning_rate': 0.11112225504937953, 'depth': 2, 'l2_leaf_reg': 0.3235189618443754, 'random_strength': 18.482385873852692, 'bagging_temperature': 0.2525767811267752, 'border_count': 48, 'rsm': 0.7859857322786038}. Best is trial 20 with value: 1.4126996340697824.
# [I 2026-06-16 10:13:29,521] Trial 21 finished with value: 1.4624222789951185 and parameters: {'iterations': 1212, 'learning_rate': 0.11124555911529299, 'depth': 2, 'l2_leaf_reg': 0.36353478283024593, 'random_strength': 18.45216842463662, 'bagging_temperature': 0.11340941132974722, 'border_count': 44, 'rsm': 0.7822026291488543}. Best is trial 20 with value: 1.4126996340697824.
# [I 2026-06-16 10:13:37,077] Trial 22 finished with value: 1.452179790340617 and parameters: {'iterations': 1203, 'learning_rate': 0.08344838326126582, 'depth': 2, 'l2_leaf_reg': 0.48351235337656967, 'random_strength': 17.896831820071505, 'bagging_temperature': 0.44046680595580523, 'border_count': 49, 'rsm': 0.8647313722757732}. Best is trial 20 with value: 1.4126996340697824.
# [I 2026-06-16 10:13:46,938] Trial 23 finished with value: 1.4224529293893449 and parameters: {'iterations': 2166, 'learning_rate': 0.0731100528163832, 'depth': 3, 'l2_leaf_reg': 0.45513808091142527, 'random_strength': 17.21568433585248, 'bagging_temperature': 5.283042519866729, 'border_count': 69, 'rsm': 0.8577975563534274}. Best is trial 20 with value: 1.4126996340697824.
# [I 2026-06-16 10:13:59,385] Trial 24 finished with value: 1.4472394898372816 and parameters: {'iterations': 2108, 'learning_rate': 0.06774443638285745, 'depth': 4, 'l2_leaf_reg': 0.4789313743999834, 'random_strength': 14.26546994457502, 'bagging_temperature': 5.378369906320496, 'border_count': 71, 'rsm': 0.8660645704220382}. Best is trial 20 with value: 1.4126996340697824.
# [I 2026-06-16 10:14:22,221] Trial 25 finished with value: 1.5032318821105601 and parameters: {'iterations': 2110, 'learning_rate': 0.06897289148238252, 'depth': 5, 'l2_leaf_reg': 5.845320280336573, 'random_strength': 14.405068086233472, 'bagging_temperature': 4.892568823842701, 'border_count': 71, 'rsm': 0.8700891192328545}. Best is trial 20 with value: 1.4126996340697824.
# [I 2026-06-16 10:14:51,194] Trial 26 finished with value: 1.4466021146172776 and parameters: {'iterations': 2171, 'learning_rate': 0.02428818147343144, 'depth': 4, 'l2_leaf_reg': 0.958980004028203, 'random_strength': 10.319995758882955, 'bagging_temperature': 5.975118749922187, 'border_count': 126, 'rsm': 0.9843517253055357}. Best is trial 20 with value: 1.4126996340697824.
# [I 2026-06-16 10:15:42,644] Trial 27 finished with value: 1.4606739386455467 and parameters: {'iterations': 2291, 'learning_rate': 0.023397434424819813, 'depth': 4, 'l2_leaf_reg': 1.1271011570783982, 'random_strength': 10.813486856423596, 'bagging_temperature': 9.97236136543093, 'border_count': 136, 'rsm': 0.9710634695991801}. Best is trial 20 with value: 1.4126996340697824.
# [I 2026-06-16 10:17:35,551] Trial 28 finished with value: 1.5003328710681063 and parameters: {'iterations': 2667, 'learning_rate': 0.010267000676250393, 'depth': 6, 'l2_leaf_reg': 4.497673748414185, 'random_strength': 9.308494626207855, 'bagging_temperature': 6.590906616198234, 'border_count': 150, 'rsm': 0.999172720404975}. Best is trial 20 with value: 1.4126996340697824.
# [I 2026-06-16 10:17:57,140] Trial 29 finished with value: 1.4318023201200814 and parameters: {'iterations': 2059, 'learning_rate': 0.02456200331422441, 'depth': 3, 'l2_leaf_reg': 1.0582360499348054, 'random_strength': 16.835940760946038, 'bagging_temperature': 1.6573679222851094, 'border_count': 111, 'rsm': 0.9234818750421321}. Best is trial 20 with value: 1.4126996340697824.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 10:22:42,774] A new study created in RDB with name: KORD_v9_remaining_warmup_stack_ridge_stack_mae_f
# [I 2026-06-16 10:22:43,361] Trial 0 finished with value: 1.447846562806967 and parameters: {'feature_set': 'models_only', 'alpha': 1061.6032395070417, 'fit_intercept': False}. Best is trial 0 with value: 1.447846562806967.
# [I 2026-06-16 10:22:43,799] Trial 1 finished with value: 1.4574328117696878 and parameters: {'feature_set': 'models_only', 'alpha': 29.13552742298041, 'fit_intercept': False}. Best is trial 0 with value: 1.447846562806967.
# [I 2026-06-16 10:22:44,259] Trial 2 finished with value: 1.455640972291872 and parameters: {'feature_set': 'models_only', 'alpha': 0.0005260598165963439, 'fit_intercept': True}. Best is trial 0 with value: 1.447846562806967.
# [I 2026-06-16 10:22:44,731] Trial 3 finished with value: 1.463869511135231 and parameters: {'feature_set': 'models_only', 'alpha': 2.2872748315304782e-05, 'fit_intercept': False}. Best is trial 0 with value: 1.447846562806967.
# [I 2026-06-16 10:22:45,196] Trial 4 finished with value: 1.5382654670580589 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 1013.2424299869091, 'fit_intercept': True}. Best is trial 0 with value: 1.447846562806967.
# [I 2026-06-16 10:22:45,626] Trial 5 finished with value: 1.5266058288475985 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 826.0185608286423, 'fit_intercept': True}. Best is trial 0 with value: 1.447846562806967.
# [I 2026-06-16 10:22:46,064] Trial 6 finished with value: 1.4688021945003795 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 3.929417958656645e-06, 'fit_intercept': True}. Best is trial 0 with value: 1.447846562806967.
# [I 2026-06-16 10:22:46,517] Trial 7 finished with value: 1.468660417171479 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 0.8901780240435773, 'fit_intercept': True}. Best is trial 0 with value: 1.447846562806967.
# [I 2026-06-16 10:22:46,960] Trial 8 finished with value: 1.4405921376524433 and parameters: {'feature_set': 'models_only', 'alpha': 2828.538706546869, 'fit_intercept': False}. Best is trial 8 with value: 1.4405921376524433.
# [I 2026-06-16 10:22:47,403] Trial 9 finished with value: 1.4569828001827205 and parameters: {'feature_set': 'models_only', 'alpha': 35.97860619804126, 'fit_intercept': False}. Best is trial 8 with value: 1.4405921376524433.
# [I 2026-06-16 10:22:47,849] Trial 10 finished with value: 1.4556411578858337 and parameters: {'feature_set': 'models_only', 'alpha': 1.8087400416300714e-05, 'fit_intercept': True}. Best is trial 8 with value: 1.4405921376524433.
# [I 2026-06-16 10:22:48,306] Trial 11 finished with value: 1.4688021237845532 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 0.00039823854294263674, 'fit_intercept': True}. Best is trial 8 with value: 1.4405921376524433.
# [I 2026-06-16 10:22:48,726] Trial 12 finished with value: 1.4672791041608337 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 0.44507773547737556, 'fit_intercept': False}. Best is trial 8 with value: 1.4405921376524433.
# [I 2026-06-16 10:22:49,177] Trial 13 finished with value: 1.4673818928288074 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 7.810619739021528e-06, 'fit_intercept': False}. Best is trial 8 with value: 1.4405921376524433.
# [I 2026-06-16 10:22:49,619] Trial 14 finished with value: 1.4538034138430984 and parameters: {'feature_set': 'models_only', 'alpha': 150.11205568245393, 'fit_intercept': False}. Best is trial 8 with value: 1.4405921376524433.
# [I 2026-06-16 10:22:50,142] Trial 15 finished with value: 1.3918124248139383 and parameters: {'feature_set': 'models_only', 'alpha': 76566.80105600263, 'fit_intercept': False}. Best is trial 15 with value: 1.3918124248139383.
# [I 2026-06-16 10:22:50,627] Trial 16 finished with value: 1.3730090998537723 and parameters: {'feature_set': 'models_only', 'alpha': 67853.4204477103, 'fit_intercept': False}. Best is trial 16 with value: 1.3730090998537723.
# [I 2026-06-16 10:22:51,089] Trial 17 finished with value: 1.3564056168425633 and parameters: {'feature_set': 'models_only', 'alpha': 44955.65545194395, 'fit_intercept': False}. Best is trial 17 with value: 1.3564056168425633.
# [I 2026-06-16 10:22:51,552] Trial 18 finished with value: 1.399004593924426 and parameters: {'feature_set': 'models_only', 'alpha': 79181.27638964474, 'fit_intercept': False}. Best is trial 17 with value: 1.3564056168425633.
# [I 2026-06-16 10:22:52,014] Trial 19 finished with value: 1.41343593158238 and parameters: {'feature_set': 'models_only', 'alpha': 10750.125573436802, 'fit_intercept': False}. Best is trial 17 with value: 1.3564056168425633.
# [I 2026-06-16 10:22:52,493] Trial 20 finished with value: 1.4632572512313127 and parameters: {'feature_set': 'models_only', 'alpha': 1.4813807006059896, 'fit_intercept': False}. Best is trial 17 with value: 1.3564056168425633.
# [I 2026-06-16 10:22:52,918] Trial 21 finished with value: 1.358081948061771 and parameters: {'feature_set': 'models_only', 'alpha': 54498.00722754936, 'fit_intercept': False}. Best is trial 17 with value: 1.3564056168425633.
# [I 2026-06-16 10:22:53,402] Trial 22 finished with value: 1.3949115480288266 and parameters: {'feature_set': 'models_only', 'alpha': 17248.172857967027, 'fit_intercept': False}. Best is trial 17 with value: 1.3564056168425633.
# [I 2026-06-16 10:22:53,844] Trial 23 finished with value: 1.411518787148743 and parameters: {'feature_set': 'models_only', 'alpha': 11395.345151415659, 'fit_intercept': False}. Best is trial 17 with value: 1.3564056168425633.
# [I 2026-06-16 10:22:54,311] Trial 24 finished with value: 1.3801866893012662 and parameters: {'feature_set': 'models_only', 'alpha': 71598.15114709547, 'fit_intercept': False}. Best is trial 17 with value: 1.3564056168425633.
# [I 2026-06-16 10:22:54,787] Trial 25 finished with value: 1.4285354408080666 and parameters: {'feature_set': 'models_only', 'alpha': 6102.141534884684, 'fit_intercept': False}. Best is trial 17 with value: 1.3564056168425633.
# [I 2026-06-16 10:22:55,278] Trial 26 finished with value: 1.4518700148140031 and parameters: {'feature_set': 'models_only', 'alpha': 321.3725854403503, 'fit_intercept': False}. Best is trial 17 with value: 1.3564056168425633.
# [I 2026-06-16 10:22:55,722] Trial 27 finished with value: 1.457715980892772 and parameters: {'feature_set': 'models_only', 'alpha': 25.600793550835903, 'fit_intercept': False}. Best is trial 17 with value: 1.3564056168425633.
# [I 2026-06-16 10:22:56,217] Trial 28 finished with value: 1.4398952702299597 and parameters: {'feature_set': 'models_only', 'alpha': 92424.52070607888, 'fit_intercept': False}. Best is trial 17 with value: 1.3564056168425633.
# [I 2026-06-16 10:22:56,704] Trial 29 finished with value: 1.4465023520585394 and parameters: {'feature_set': 'models_only', 'alpha': 1368.3271993468086, 'fit_intercept': False}. Best is trial 17 with value: 1.3564056168425633.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
# ...
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
#                   period       method  count     mae_f    rmse_f
# 0   validation_2024_2025      xgboost    722  1.395672  1.880488
# 1   validation_2024_2025     lightgbm    722  1.420861  1.943833
# 2   validation_2024_2025     catboost    722  1.435825  1.944244
# 3   validation_2024_2025     hrrr_raw    722  2.079907  2.927016
# 4   validation_2024_2025      gfs_raw    722  2.760890  3.651039
# 5              test_2026      xgboost    137  1.391125  1.821460
# 6              test_2026     lightgbm    137  1.561493  2.064168
# 7              test_2026     catboost    137  1.406520  1.847189
# 8              test_2026  ridge_stack    137  1.393311  1.886898
# 9              test_2026     hrrr_raw    137  2.848991  4.747871
# 10             test_2026      gfs_raw    137  3.577404  5.044083

# %%
exported_weights = export_station_model_weights(
    project_root=PROJECT_ROOT,
    station_id=STATION_ID,
    artifact_dir=config.resolved_output_dir(),
    model_version=MODEL_VERSION,
    timing_mode=config.timing_mode,
    providers=tuple(config.providers),
    feature_version=config.effective_feature_version,
    optuna_metric=config.effective_optuna_metric,
    target_mode=config.effective_target_mode,
    source_pipeline="notebooks/experiments/station_stacking_v9",
)

exported_weights.bundle_path, exported_weights.manifest_path
# Out:
# (WindowsPath('D:/dev/weather-research/data/calibration/station_stacking_v9/model_weights/KORD_station_high_regressor_v9_remaining_warmup.joblib'),
#  WindowsPath('D:/dev/weather-research/data/calibration/station_stacking_v9/model_weights/KORD_station_high_regressor_v9_remaining_warmup.json'))

# %% [markdown]
# ## V9 Feature Coverage

# %%
v9_feature_coverage = (
    result.features[V9_FEATURE_COLUMNS]
    .notna()
    .mean()
    .mul(100)
    .sort_values(ascending=False)
    .rename("coverage_pct")
    .reset_index()
    .rename(columns={"index": "feature"})
)

v9_feature_coverage
# Out:
#                                               feature  coverage_pct
# 0                              v2_spread_per_warmup_f    100.000000
# 1                    v2_morning_warmup_to_consensus_f    100.000000
# 2              v3_remaining_warmup_from_high_so_far_f    100.000000
# 3                      v3_high_so_far_above_current_f    100.000000
# 4                      v2_humidity_warmup_interaction    100.000000
# 5                    v4_observed_precip_recent_mm_est    100.000000
# 6                        v4_forecast_wet_observed_dry    100.000000
# 7                   v4_forecast_observed_precip_match    100.000000
# 8            v3_humidity_remaining_warmup_interaction    100.000000
# 9                    v3_remaining_warmup_per_spread_f    100.000000
# 10                             v4_all_forecast_precip    100.000000
# 11                             v4_observed_precip_any    100.000000
# 12                             v4_any_forecast_precip    100.000000
# 13                    v8_month_remaining_warmup_count    100.000000
# 14                             climatology_high_10y_f    100.000000
# 15                         climatology_high_10y_std_f    100.000000
# 16       observed_high_so_far_minus_climatology_10y_f    100.000000
# 17              observed_temp_minus_climatology_10y_f    100.000000
# 18                         climatology_high_10y_count    100.000000
# 19              provider_mean_minus_climatology_10y_f    100.000000
# 20          v8_provider_spread_per_remaining_warmup_f    100.000000
# 21                       v4_observed_wet_forecast_dry    100.000000
# 22       v8_provider_min_remaining_from_high_so_far_f    100.000000
# 23    v8_provider_median_remaining_from_high_so_far_f    100.000000
# 24       v8_provider_max_remaining_from_high_so_far_f    100.000000
# 25                   v3_high_so_far_minus_7d_actual_f     99.949084
# 26                          v2_recent_heat_momentum_f     99.949084
# 27                     v2_consensus_minus_7d_actual_f     99.949084
# 28                      v3_high_so_far_minus_lag_1d_f     99.949084
# 29                           v2_recent_heat_anomaly_f     99.949084
# 30            observed_high_so_far_change_since_9am_f     99.949084
# 31            observed_morning_warmup_rate_f_per_hour     99.949084
# 32                     observed_temp_change_last_3h_f     99.949084
# 33                     observed_temp_change_last_1h_f     99.949084
# 34               v8_recent_remaining_warmup_7d_mean_f     99.898167
# 35              v8_recent_remaining_warmup_30d_mean_f     99.745418
# 36       v8_provider_mean_remaining_vs_month_normal_f     98.778004
# 37                   v8_month_remaining_warmup_mean_f     98.778004
# 38                 v4_forecast_precip_total_spread_mm      0.000000
# 39                  v4_forecast_precip_max_1h_mean_mm      0.000000
# 40                      v4_forecast_precip_hours_mean      0.000000
# 41                  v4_forecast_precip_intensity_mean      0.000000
# 42         v4_forecast_total_minus_observed_recent_mm      0.000000
# 43                   v4_forecast_precip_intensity_max      0.000000
# 44                   v4_forecast_precip_total_mean_mm      0.000000
# 45                    v4_forecast_precip_total_max_mm      0.000000
# 46             v4_precip_remaining_warmup_interaction      0.000000
# 47                     v4_precip_humidity_interaction      0.000000
# 48   v8_cloud_cover_mean_remaining_warmup_interaction      0.000000
# 49    v8_cloud_cover_max_remaining_warmup_interaction      0.000000
# 50             v8_forecast_dewpoint_depression_mean_f      0.000000
# 51                        v8_forecast_dewpoint_mean_f      0.000000
# 52      v8_wind_gust_max_remaining_warmup_interaction      0.000000
# 53    v8_wind_speed_mean_remaining_warmup_interaction      0.000000
# 54      v8_precip_max_1h_remaining_warmup_interaction      0.000000
# 55       v8_precip_total_remaining_warmup_interaction      0.000000
# 56      v8_dewpoint_mean_remaining_warmup_interaction      0.000000
# 57  v8_dewpoint_depression_remaining_warmup_intera...      0.000000

# %%
result.feature_columns.loc[result.feature_columns["feature"].isin(V9_FEATURE_COLUMNS)]
# Out:
#                                              feature     kind
# 20                    observed_temp_change_last_1h_f  numeric
# 21                    observed_temp_change_last_3h_f  numeric
# 22           observed_morning_warmup_rate_f_per_hour  numeric
# 23           observed_high_so_far_change_since_9am_f  numeric
# 163                         v2_recent_heat_anomaly_f  numeric
# 164                        v2_recent_heat_momentum_f  numeric
# 165                 v2_morning_warmup_to_consensus_f  numeric
# 166                   v2_consensus_minus_7d_actual_f  numeric
# 167                           v2_spread_per_warmup_f  numeric
# 168                   v2_humidity_warmup_interaction  numeric
# 169                   v3_high_so_far_above_current_f  numeric
# 170           v3_remaining_warmup_from_high_so_far_f  numeric
# 171                    v3_high_so_far_minus_lag_1d_f  numeric
# 172                 v3_high_so_far_minus_7d_actual_f  numeric
# 173                 v3_remaining_warmup_per_spread_f  numeric
# 174         v3_humidity_remaining_warmup_interaction  numeric
# 175                           v4_any_forecast_precip  numeric
# 176                           v4_all_forecast_precip  numeric
# 177                           v4_observed_precip_any  numeric
# 178                 v4_observed_precip_recent_mm_est  numeric
# 179                v4_forecast_observed_precip_match  numeric
# 180                     v4_forecast_wet_observed_dry  numeric
# 181                     v4_observed_wet_forecast_dry  numeric
# 182     v8_provider_max_remaining_from_high_so_far_f  numeric
# 183     v8_provider_min_remaining_from_high_so_far_f  numeric
# 184  v8_provider_median_remaining_from_high_so_far_f  numeric
# 185        v8_provider_spread_per_remaining_warmup_f  numeric
# 186                 v8_month_remaining_warmup_mean_f  numeric
# 187                  v8_month_remaining_warmup_count  numeric
# 188             v8_recent_remaining_warmup_7d_mean_f  numeric
# 189            v8_recent_remaining_warmup_30d_mean_f  numeric
# 190     v8_provider_mean_remaining_vs_month_normal_f  numeric
# 191                           climatology_high_10y_f  numeric
# 192                       climatology_high_10y_std_f  numeric
# 193                       climatology_high_10y_count  numeric
# 194            provider_mean_minus_climatology_10y_f  numeric
# 195            observed_temp_minus_climatology_10y_f  numeric
# 196     observed_high_so_far_minus_climatology_10y_f  numeric

# %% [markdown]
# ## Dropped Feature Check

# %%
dropped_present = result.feature_columns.loc[
    result.feature_columns["feature"].isin(V9_DROPPED_FEATURE_COLUMNS)
]

dropped_present
# Out:
# Empty DataFrame
# Columns: [feature, kind]
# Index: []

# %% [markdown]
# ## Morning Trend Coverage

# %%
trend_coverage = (
    result.features[TREND_COLUMNS]
    .notna()
    .mean()
    .mul(100)
    .sort_values(ascending=False)
    .rename("coverage_pct")
    .reset_index()
    .rename(columns={"index": "feature"})
)

trend_coverage
# Out:
#                                    feature  coverage_pct
# 0           observed_temp_change_last_1h_f     99.949084
# 1           observed_temp_change_last_3h_f     99.949084
# 2  observed_morning_warmup_rate_f_per_hour     99.949084
# 3  observed_high_so_far_change_since_9am_f     99.949084

# %% [markdown]
# ## Rounded Within 1F Accuracy

# %%
preds = pd.concat(
    [
        result.validation_predictions.assign(period="validation_2024_2025"),
        result.test_predictions.assign(period="oof_2026"),
    ],
    ignore_index=True,
)

predicted_high = pd.to_numeric(preds["predicted_high_f"], errors="coerce")
preds["predicted_high_rounded_f"] = np.floor(predicted_high + 0.5)
preds["within_1f_after_round"] = (
    pd.to_numeric(preds["actual_high_f"], errors="coerce") - preds["predicted_high_rounded_f"]
).abs().le(1)

within_1f_accuracy_by_period = (
    preds
    .dropna(subset=["actual_high_f", "predicted_high_rounded_f"])
    .groupby(["period", "method"], as_index=False)
    .agg(
        count=("within_1f_after_round", "size"),
        within_1f_count=("within_1f_after_round", "sum"),
        within_1f_accuracy_pct=("within_1f_after_round", lambda x: x.mean() * 100),
    )
    .sort_values(["period", "within_1f_accuracy_pct"], ascending=[True, False])
)

within_1f_accuracy_by_period
# Out:
#                   period       method  count  within_1f_count  \
# 5               oof_2026  ridge_stack    137               88
# 6               oof_2026      xgboost    137               86
# 0               oof_2026     catboost    137               84
# 3               oof_2026     lightgbm    137               84
# 2               oof_2026     hrrr_raw    137               64
# 4               oof_2026      nbm_raw    137               59
# 1               oof_2026      gfs_raw    137               48
# 12  validation_2024_2025      xgboost    722              468
# 10  validation_2024_2025     lightgbm    722              464
# 7   validation_2024_2025     catboost    722              450
# 9   validation_2024_2025     hrrr_raw    722              364
# 11  validation_2024_2025      nbm_raw    722              316
# 8   validation_2024_2025      gfs_raw    722              252
#
#     within_1f_accuracy_pct
# 5                64.233577
# 6                62.773723
# 0                61.313869
# 3                61.313869
# 2                46.715328
# 4                43.065693
# 1                35.036496
# 12               64.819945
# 10               64.265928
# 7                62.326870
# 9                50.415512
# 11               43.767313
# 8                34.903047

# %% [markdown]
# ## Version Comparison

# %%
comparison_frames = []
for version, folder in [
    ("v1", PROJECT_ROOT / "data" / "calibration" / "station_stacking"),
    ("v2", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v2"),
    ("v3", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v3"),
    ("v4", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v4"),
    ("v5", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v5"),
    ("v6", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v6"),
    ("v7", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v7"),
    ("v8", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v8"),
    ("v9", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v9"),
]:
    path = folder / f"{STATION_ID}_year_split_scoreboard.csv"
    if path.exists():
        frame = pd.read_csv(path)
        frame["version"] = version
        comparison_frames.append(frame)

version_comparison = pd.concat(comparison_frames, ignore_index=True) if comparison_frames else pd.DataFrame()
if not version_comparison.empty:
    version_comparison = version_comparison.sort_values(["period", "mae_f", "version", "method"]).reset_index(drop=True)
version_comparison
# Out:
#                   period       method  count     mae_f    rmse_f version
# 0              test_2026      xgboost    137  1.391125  1.821460      v9
# 1              test_2026  ridge_stack    137  1.393311  1.886898      v9
# 2              test_2026     catboost    137  1.406520  1.847189      v9
# 3              test_2026     catboost    119  1.485735  1.948349      v5
# 4              test_2026     lightgbm    137  1.561493  2.064168      v9
# ..                   ...          ...    ...       ...       ...     ...
# 72  validation_2024_2025      gfs_raw    722  2.760890  3.651039      v9
# 73  validation_2024_2025      gfs_raw    658  2.805959  3.717535      v7
# 74  validation_2024_2025      gfs_raw    660  2.893424  4.186794      v1
# 75  validation_2024_2025      gfs_raw    660  2.893424  4.186794      v2
# 76  validation_2024_2025      gfs_raw    660  2.893424  4.186794      v3
#
# [77 rows x 6 columns]

# %% [markdown]
# ## 2026 OOF Weather Brackets

# %%
result.bracket_metrics
# Out:
#         method  count     mae_f    rmse_f  bracket_accuracy_pct
# 0      xgboost    137  1.391125  1.821460             40.875912
# 1     lightgbm    137  1.561493  2.064168              36.49635
# 2     catboost    137  1.406520  1.847189             42.335766
# 3  ridge_stack    137  1.393311  1.886898             45.255474
# 4     hrrr_raw    137  2.848991  4.747871             30.656934
# 5      gfs_raw    137  3.577404  5.044083             24.087591

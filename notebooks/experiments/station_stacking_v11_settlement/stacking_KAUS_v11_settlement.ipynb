# %% [markdown]
# # Station Stacking v11 Settlement - KAUS
#
# Experimental notebook for `KAUS`.
#
# This controlled rerun keeps the exact v11 feature/model contract, replaces daily-high labels with settlement-first Wunderground station history when available, and writes separate artifacts to `data/calibration/station_stacking_v11_settlement`.

# %%
from pathlib import Path
import os
import sys
import warnings

warnings.filterwarnings("ignore", message="IProgress not found.*")
warnings.filterwarnings("ignore", message="Skipping features without any observed values.*")

PROJECT_ROOT = Path.cwd().resolve()
while not (PROJECT_ROOT / "src" / "calibration" / "station_stacking.py").exists():
    if PROJECT_ROOT.parent == PROJECT_ROOT:
        raise RuntimeError("Could not find project root containing src/calibration/station_stacking.py")
    PROJECT_ROOT = PROJECT_ROOT.parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

os.environ["WEATHER_RESEARCH_INCLUDE_DIRECT_NBM"] = "1"

STATION_ID = "KAUS"
PROVIDERS = ("gfs", "hrrr", "nbm")
TREND_COLUMNS = [
    "observed_temp_change_last_1h_f",
    "observed_temp_change_last_3h_f",
    "observed_morning_warmup_rate_f_per_hour",
    "observed_high_so_far_change_since_9am_f",
]
TIMING_MODE = "same_day_11am_live_safe"
FAST_MODE = False
OPTUNA_TRIALS = 30
STACK_OPTUNA_TRIALS = 30
OPTUNA_STARTUP_TRIALS = 15
STACK_OPTUNA_STARTUP_TRIALS = 15
OPTUNA_METRIC = "mae_f"
OPTUNA_VERBOSE = True
MODEL_VERSION = "station_high_regressor_v11_wunderground_settlement_stack"
PROJECT_ROOT
# Out:
# WindowsPath('D:/dev/weather-research')

# %%
import numpy as np
import pandas as pd

from src.export_station_stacking_v2_models import export_station_model_weights
from src.calibration.station_stacking import (
    StationStackingConfig,
    V11_DROPPED_FEATURE_COLUMNS,
    V11_FEATURE_COLUMNS,
    YEAR_SPLIT_EXPANDING_FOLDS,
    missing_model_dependencies,
    provider_availability,
    run_station_year_split_experiment,
)

# %% [markdown]
# ## V11 Contract
#
# `feature_version="v11"` keeps the v9 feature contract and remaining-warmup target, but trains base learners with Huber-style objectives while retaining the ridge stack selected by validation MAE.

# %%
fold_spec = pd.DataFrame(
    [
        {
            "fold": fold.name,
            "train_start_year": fold.train_start_year,
            "train_end_year": fold.train_end_year,
            "validation_year": fold.validation_year,
        }
        for fold in YEAR_SPLIT_EXPANDING_FOLDS
    ]
)

fold_spec
# Out:
#                      fold  train_start_year  train_end_year  validation_year
# 0  fold_2021_2023_to_2024              2021            2023             2024
# 1  fold_2021_2024_to_2025              2021            2024             2025

# %%
V11_FEATURE_COLUMNS, sorted(V11_DROPPED_FEATURE_COLUMNS)
# Out:
# (['v2_recent_heat_anomaly_f',
#   'v2_recent_heat_momentum_f',
#   'v2_morning_warmup_to_consensus_f',
#   'v2_consensus_minus_7d_actual_f',
#   'v2_spread_per_warmup_f',
#   'v2_humidity_warmup_interaction',
#   'v3_high_so_far_above_current_f',
#   'v3_remaining_warmup_from_high_so_far_f',
#   'v3_high_so_far_minus_lag_1d_f',
#   'v3_high_so_far_minus_7d_actual_f',
#   'v3_remaining_warmup_per_spread_f',
#   'v3_humidity_remaining_warmup_interaction',
#   'v4_forecast_precip_total_mean_mm',
#   'v4_forecast_precip_total_max_mm',
#   'v4_forecast_precip_total_spread_mm',
#   'v4_forecast_precip_max_1h_mean_mm',
#   'v4_forecast_precip_hours_mean',
#   'v4_forecast_precip_intensity_mean',
#   'v4_forecast_precip_intensity_max',
#   'v4_any_forecast_precip',
#   'v4_all_forecast_precip',
#   'v4_observed_precip_any',
#   'v4_observed_precip_recent_mm_est',
#   'v4_forecast_total_minus_observed_recent_mm',
#   'v4_forecast_observed_precip_match',
#   'v4_forecast_wet_observed_dry',
#   'v4_observed_wet_forecast_dry',
#   'v4_precip_humidity_interaction',
#   'v4_precip_remaining_warmup_interaction',
#   'observed_temp_change_last_1h_f',
#   'observed_temp_change_last_3h_f',
#   'observed_morning_warmup_rate_f_per_hour',
#   'observed_high_so_far_change_since_9am_f',
#   'v8_provider_max_remaining_from_high_so_far_f',
#   'v8_provider_min_remaining_from_high_so_far_f',
#   'v8_provider_median_remaining_from_high_so_far_f',
#   'v8_provider_spread_per_remaining_warmup_f',
#   'v8_month_remaining_warmup_mean_f',
#   'v8_month_remaining_warmup_count',
#   'v8_recent_remaining_warmup_7d_mean_f',
#   'v8_recent_remaining_warmup_30d_mean_f',
#   'v8_provider_mean_remaining_vs_month_normal_f',
#   'v8_cloud_cover_mean_remaining_warmup_interaction',
#   'v8_cloud_cover_max_remaining_warmup_interaction',
#   'v8_precip_total_remaining_warmup_interaction',
#   'v8_precip_max_1h_remaining_warmup_interaction',
#   'v8_wind_speed_mean_remaining_warmup_interaction',
#   'v8_wind_gust_max_remaining_warmup_interaction',
#   'v8_forecast_dewpoint_mean_f',
#   'v8_forecast_dewpoint_depression_mean_f',
#   'v8_dewpoint_mean_remaining_warmup_interaction',
#   'v8_dewpoint_depression_remaining_warmup_interaction',
#   'climatology_high_10y_f',
#   'climatology_high_10y_std_f',
#   'climatology_high_10y_count',
#   'provider_mean_minus_climatology_10y_f',
#   'observed_temp_minus_climatology_10y_f',
#   'observed_high_so_far_minus_climatology_10y_f'],
#  ['actual_minus_climatology_10y_f_DIAGNOSTIC_ONLY',
#   'climatology_source_end_year',
#   'climatology_source_start_year',
#   'gfs_as_of_hour_local',
#   'gfs_available',
#   'gfs_forecast_window_hours',
#   'gfs_grid_dist_km_mean',
#   'gfs_horizon_hours',
#   'gfs_hrrr_grid_dist_km_mean_abs_diff_f',
#   'gfs_hrrr_grid_dist_km_mean_diff_f',
#   'gfs_issue_hour_utc',
#   'gfs_missing',
#   'hrrr_as_of_hour_local',
#   'hrrr_available',
#   'hrrr_forecast_hour_max',
#   'hrrr_forecast_hour_min',
#   'hrrr_forecast_lead_hours',
#   'hrrr_forecast_window_hours',
#   'hrrr_grid_dist_km_mean',
#   'hrrr_horizon_hours',
#   'hrrr_issue_hour_local',
#   'hrrr_issue_hour_utc',
#   'hrrr_missing',
#   'is_active_polymarket_station',
#   'lat',
#   'lon',
#   'nbm_as_of_hour_local',
#   'nbm_available',
#   'nbm_forecast_window_hours',
#   'nbm_horizon_hours',
#   'nbm_issue_hour_local',
#   'nbm_issue_hour_utc',
#   'nbm_missing',
#   'observed_fetch_status',
#   'observed_observation_type',
#   'observed_pressure_source',
#   'provider_count_available',
#   'year'])

# %% [markdown]
# ## Data Availability

# %%
availability = provider_availability(
    PROJECT_ROOT,
    timing_mode=TIMING_MODE,
    providers=PROVIDERS,
)

availability.loc[availability["station_id"].eq(STATION_ID)]
# Out:
#   station_id provider  row_count first_contract_date last_contract_date
# 3       KAUS      gfs       1992          2021-01-01         2026-06-21
# 4       KAUS     hrrr       1998          2021-01-01         2026-06-21
# 5       KAUS      nbm       1997          2021-01-01         2026-06-21

# %% [markdown]
# ## Model Scores

# %%
missing_packages = missing_model_dependencies()
if missing_packages:
    raise ImportError(
        "Missing station-stacking ML packages: "
        + ", ".join(missing_packages)
        + ". Install them with: python -m pip install -r requirements.txt"
    )

config = StationStackingConfig(
    station_id=STATION_ID,
    project_root=PROJECT_ROOT,
    timing_mode=TIMING_MODE,
    providers=PROVIDERS,
    fast_mode=FAST_MODE,
    optuna_trials=OPTUNA_TRIALS,
    stack_optuna_trials=STACK_OPTUNA_TRIALS,
    optuna_startup_trials=OPTUNA_STARTUP_TRIALS,
    stack_optuna_startup_trials=STACK_OPTUNA_STARTUP_TRIALS,
    optuna_metric=OPTUNA_METRIC,
    optuna_verbose=OPTUNA_VERBOSE,
    feature_version="v11",
    target_mode="remaining_warmup",
    target_source="settlement_first",
    base_model_methods=("xgboost", "lightgbm", "catboost"),
    stack_enabled=True,
    hyperparameter_space="wide",
    year_split_folds=YEAR_SPLIT_EXPANDING_FOLDS,
    year_split_test_train_years=(2021, 2025),
    year_split_test_year=2026,
    output_dir=PROJECT_ROOT / "data" / "calibration" / "station_stacking_v11_settlement",
)

config.resolved_optuna_storage_path()
# Out:
# WindowsPath('D:/dev/weather-research/data/calibration/station_stacking_v11_settlement/KAUS_optuna.sqlite3')

# %%
result = run_station_year_split_experiment(config)
result.scoreboard
# Out:
# [I 2026-07-08 13:10:12,236] A new study created in RDB with name: KAUS_v11_remaining_warmup_base_xgboost_mae_f
# [I 2026-07-08 13:10:17,636] Trial 0 finished with value: 2.6987692232643647 and parameters: {'n_estimators': 1342, 'learning_rate': 0.19043899115982607, 'max_depth': 9, 'min_child_weight': 2.481040974867813, 'gamma': 2.340279606636548, 'subsample': 0.4513964382185317, 'colsample_bytree': 0.3877543479093296, 'reg_alpha': 2.478071022662141, 'reg_lambda': 0.6132587025321562}. Best is trial 0 with value: 2.6987692232643647.
# [I 2026-07-08 13:10:18,349] Trial 1 finished with value: 7.40774962944276 and parameters: {'n_estimators': 2493, 'learning_rate': 0.001120367191095075, 'max_depth': 12, 'min_child_weight': 21.368329072358772, 'gamma': 3.185086660174142, 'subsample': 0.4681862286846154, 'colsample_bytree': 0.46921293140473197, 'reg_alpha': 4.476173538513514e-07, 'reg_lambda': 0.20253776634919213}. Best is trial 0 with value: 2.6987692232643647.
# [I 2026-07-08 13:10:34,065] Trial 2 finished with value: 1.6982253700219099 and parameters: {'n_estimators': 1540, 'learning_rate': 0.004992867109217114, 'max_depth': 8, 'min_child_weight': 0.03613894271216528, 'gamma': 4.3821697280282725, 'subsample': 0.5881351981408995, 'colsample_bytree': 0.6464454897410734, 'reg_alpha': 0.26430874752361627, 'reg_lambda': 0.0018119678627933364}. Best is trial 2 with value: 1.6982253700219099.
# [I 2026-07-08 13:10:38,965] Trial 3 finished with value: 1.6184879342565042 and parameters: {'n_estimators': 1824, 'learning_rate': 0.026337502897485255, 'max_depth': 1, 'min_child_weight': 2.69264691008618, 'gamma': 2.557861855309373, 'subsample': 0.39228353544043165, 'colsample_bytree': 0.9667755992146666, 'reg_alpha': 38.6887231523051, 'reg_lambda': 12.408975837016275}. Best is trial 3 with value: 1.6184879342565042.
# [I 2026-07-08 13:11:02,492] Trial 4 finished with value: 1.4627311653407304 and parameters: {'n_estimators': 1101, 'learning_rate': 0.0017147936629846843, 'max_depth': 9, 'min_child_weight': 0.5762487216478605, 'gamma': 1.8305735226716824, 'subsample': 0.6718649915723256, 'colsample_bytree': 0.37235253872489193, 'reg_alpha': 8.162906555194692, 'reg_lambda': 0.004271500153828077}. Best is trial 4 with value: 1.4627311653407304.
# [I 2026-07-08 13:11:26,704] Trial 5 finished with value: 1.4678906090941017 and parameters: {'n_estimators': 2336, 'learning_rate': 0.00559067775661512, 'max_depth': 7, 'min_child_weight': 1.5375920235481764, 'gamma': 2.7728168328829055, 'subsample': 0.980230008046963, 'colsample_bytree': 0.8538363351847245, 'reg_alpha': 18.792618557420877, 'reg_lambda': 43.484449457612314}. Best is trial 4 with value: 1.4627311653407304.
# [I 2026-07-08 13:11:28,389] Trial 6 finished with value: 1.4477411613991706 and parameters: {'n_estimators': 2113, 'learning_rate': 0.16240489353272883, 'max_depth': 2, 'min_child_weight': 0.06080390190296603, 'gamma': 0.678409333658071, 'subsample': 0.5614647149961218, 'colsample_bytree': 0.6026402382981633, 'reg_alpha': 1.8037999945880162e-07, 'reg_lambda': 16.668629892722056}. Best is trial 6 with value: 1.4477411613991706.
# [I 2026-07-08 13:11:39,830] Trial 7 finished with value: 1.5945664669736137 and parameters: {'n_estimators': 1281, 'learning_rate': 0.0047169807141865345, 'max_depth': 7, 'min_child_weight': 0.0366181922039243, 'gamma': 12.032954711310595, 'subsample': 0.398457918391851, 'colsample_bytree': 0.9914765087903362, 'reg_alpha': 0.18490013641000916, 'reg_lambda': 0.0017869543989965139}. Best is trial 6 with value: 1.4477411613991706.
# [I 2026-07-08 13:11:42,548] Trial 8 finished with value: 1.4943412739615043 and parameters: {'n_estimators': 69, 'learning_rate': 0.09024592169686073, 'max_depth': 9, 'min_child_weight': 8.241925264876453, 'gamma': 11.569055200289187, 'subsample': 0.39812902362715874, 'colsample_bytree': 0.5830027235537771, 'reg_alpha': 2.457133280848974e-09, 'reg_lambda': 27.44356809444336}. Best is trial 6 with value: 1.4477411613991706.
# [I 2026-07-08 13:12:04,651] Trial 9 finished with value: 1.5138451972924432 and parameters: {'n_estimators': 2201, 'learning_rate': 0.006215464818952927, 'max_depth': 1, 'min_child_weight': 0.17535949529764422, 'gamma': 4.877749830401205, 'subsample': 0.8242440159197416, 'colsample_bytree': 0.7644123563808884, 'reg_alpha': 4.4315220126915325, 'reg_lambda': 0.09450187118503514}. Best is trial 6 with value: 1.4477411613991706.
# [I 2026-07-08 13:12:09,775] Trial 10 finished with value: 1.5903725998764986 and parameters: {'n_estimators': 462, 'learning_rate': 0.051323729958866915, 'max_depth': 10, 'min_child_weight': 1.7583640270008525, 'gamma': 11.564507699318415, 'subsample': 0.670967137636854, 'colsample_bytree': 0.689776339098296, 'reg_alpha': 1.3504926357029513e-05, 'reg_lambda': 0.0001445994629863374}. Best is trial 6 with value: 1.4477411613991706.
# [I 2026-07-08 13:12:19,964] Trial 11 pruned.
# [I 2026-07-08 13:12:30,164] Trial 12 pruned.
# [I 2026-07-08 13:12:31,727] Trial 13 finished with value: 1.4514939250495673 and parameters: {'n_estimators': 693, 'learning_rate': 0.13813474572232612, 'max_depth': 7, 'min_child_weight': 16.973078532467014, 'gamma': 13.4413694988524, 'subsample': 0.5567022587317115, 'colsample_bytree': 0.4215337509429899, 'reg_alpha': 5.435280359192946e-08, 'reg_lambda': 0.049115547267693904}. Best is trial 6 with value: 1.4477411613991706.
# [I 2026-07-08 13:12:34,234] Trial 14 finished with value: 1.4339579763679096 and parameters: {'n_estimators': 2872, 'learning_rate': 0.11587248002108354, 'max_depth': 1, 'min_child_weight': 1.1040511903162256, 'gamma': 6.261165047231685, 'subsample': 0.49437007680597467, 'colsample_bytree': 0.4279124887668938, 'reg_alpha': 1.125594744942969e-06, 'reg_lambda': 87.35792858155622}. Best is trial 14 with value: 1.4339579763679096.
# [I 2026-07-08 13:12:41,294] Trial 15 finished with value: 1.38437878332733 and parameters: {'n_estimators': 3311, 'learning_rate': 0.04016687409111762, 'max_depth': 3, 'min_child_weight': 0.012905294825774771, 'gamma': 0.18586716971939637, 'subsample': 0.5599207159834859, 'colsample_bytree': 0.5396163811224401, 'reg_alpha': 0.0016913438352762248, 'reg_lambda': 131.8838700608262}. Best is trial 15 with value: 1.38437878332733.
# [I 2026-07-08 13:12:50,163] Trial 16 finished with value: 1.430841776843757 and parameters: {'n_estimators': 3332, 'learning_rate': 0.031184182180475774, 'max_depth': 4, 'min_child_weight': 0.016581267455563507, 'gamma': 7.515853622869325, 'subsample': 0.7245159430745359, 'colsample_bytree': 0.5157551306129865, 'reg_alpha': 0.0014033169134723444, 'reg_lambda': 196.90312078844747}. Best is trial 15 with value: 1.38437878332733.
# [I 2026-07-08 13:13:00,199] Trial 17 finished with value: 1.4376403446244614 and parameters: {'n_estimators': 3370, 'learning_rate': 0.021072972815770495, 'max_depth': 4, 'min_child_weight': 0.010763258581119832, 'gamma': 8.88777737527129, 'subsample': 0.740012537037852, 'colsample_bytree': 0.508738271467292, 'reg_alpha': 0.00878137790353996, 'reg_lambda': 187.125496799384}. Best is trial 15 with value: 1.38437878332733.
# [I 2026-07-08 13:13:02,318] Trial 18 pruned.
# [I 2026-07-08 13:13:02,994] Trial 19 pruned.
# [I 2026-07-08 13:13:19,988] Trial 20 finished with value: 1.3852944832514535 and parameters: {'n_estimators': 2783, 'learning_rate': 0.013844176553780094, 'max_depth': 3, 'min_child_weight': 0.13177936998830583, 'gamma': 0.5291480850315224, 'subsample': 0.6300291263848595, 'colsample_bytree': 0.4725888027359317, 'reg_alpha': 8.96900743139677e-05, 'reg_lambda': 144.76877707742284}. Best is trial 15 with value: 1.38437878332733.
# [I 2026-07-08 13:13:38,577] Trial 21 finished with value: 1.3801213462266588 and parameters: {'n_estimators': 2885, 'learning_rate': 0.012022228846125766, 'max_depth': 3, 'min_child_weight': 0.12711794703719262, 'gamma': 0.19934283041850698, 'subsample': 0.5971355952564541, 'colsample_bytree': 0.4910906641146721, 'reg_alpha': 0.00021139264352211217, 'reg_lambda': 137.80222740094544}. Best is trial 21 with value: 1.3801213462266588.
# [I 2026-07-08 13:13:52,873] Trial 22 finished with value: 1.385323562734606 and parameters: {'n_estimators': 2698, 'learning_rate': 0.011165768124789038, 'max_depth': 3, 'min_child_weight': 0.16265584586825377, 'gamma': 0.07186377827035828, 'subsample': 0.6149054730695186, 'colsample_bytree': 0.45663609838519925, 'reg_alpha': 0.00019798849464847842, 'reg_lambda': 62.006369781912056}. Best is trial 21 with value: 1.3801213462266588.
# [I 2026-07-08 13:14:09,952] Trial 23 finished with value: 1.3938901182631043 and parameters: {'n_estimators': 2874, 'learning_rate': 0.011197744873665656, 'max_depth': 3, 'min_child_weight': 0.5382480247341842, 'gamma': 1.0096081335649654, 'subsample': 0.5197048510357811, 'colsample_bytree': 0.35447294479963, 'reg_alpha': 4.133321213711666e-05, 'reg_lambda': 169.3391895329904}. Best is trial 21 with value: 1.3801213462266588.
# [I 2026-07-08 13:14:30,601] Trial 24 finished with value: 1.399142572798683 and parameters: {'n_estimators': 3047, 'learning_rate': 0.010685212646498897, 'max_depth': 5, 'min_child_weight': 0.07783135584704255, 'gamma': 0.1997534392161027, 'subsample': 0.6171782432369924, 'colsample_bytree': 0.5717144675417448, 'reg_alpha': 0.011512591547314068, 'reg_lambda': 43.45016900954872}. Best is trial 21 with value: 1.3801213462266588.
# [I 2026-07-08 13:14:33,681] Trial 25 pruned.
# [I 2026-07-08 13:14:47,990] Trial 26 pruned.
# [I 2026-07-08 13:14:53,525] Trial 27 finished with value: 1.4245939406539208 and parameters: {'n_estimators': 3037, 'learning_rate': 0.015958487955756575, 'max_depth': 3, 'min_child_weight': 0.24910163538639044, 'gamma': 1.5763761761217983, 'subsample': 0.8175895518767464, 'colsample_bytree': 0.5428032874298707, 'reg_alpha': 3.676778464540044e-06, 'reg_lambda': 6.622246555635002}. Best is trial 21 with value: 1.3801213462266588.
Trial 21 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-08 13:16:07,925] Trial 22 finished with value: 1.3849351458265984 and parameters: {'n_estimators': 2055, 'learning_rate': 0.046128456183836604, 'num_leaves': 347, 'max_depth': 13, 'min_child_samples': 28, 'min_split_gain': 0.9671987726705117, 'bagging_fraction': 0.8665927277296104, 'bagging_freq': 1, 'feature_fraction': 0.5397623740000719, 'lambda_l1': 0.004320469653742817, 'lambda_l2': 0.0007363742010087261, 'huber_alpha': 0.95}. Best is trial 19 with value: 1.3729550870675662.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-08 13:16:12,167] Trial 23 finished with value: 1.3716892001415721 and parameters: {'n_estimators': 2109, 'learning_rate': 0.03641975695899514, 'num_leaves': 344, 'max_depth': 13, 'min_child_samples': 20, 'min_split_gain': 1.0413136756232446, 'bagging_fraction': 0.8554625959530964, 'bagging_freq': 1, 'feature_fraction': 0.5532123411314687, 'lambda_l1': 0.9100777646757591, 'lambda_l2': 0.004804534972712218, 'huber_alpha': 0.95}. Best is trial 23 with value: 1.3716892001415721.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-08 13:16:16,736] Trial 24 finished with value: 1.3966590740284044 and parameters: {'n_estimators': 1408, 'learning_rate': 0.02334435335991663, 'num_leaves': 332, 'max_depth': 13, 'min_child_samples': 68, 'min_split_gain': 1.2517538075691048, 'bagging_fraction': 0.7836893981137134, 'bagging_freq': 1, 'feature_fraction': 0.4578765176092077, 'lambda_l1': 1.1284356770941455, 'lambda_l2': 0.008424816325523792, 'huber_alpha': 0.95}. Best is trial 23 with value: 1.3716892001415721.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-08 13:16:23,691] Trial 25 finished with value: 1.3789856276305614 and parameters: {'n_estimators': 1990, 'learning_rate': 0.014469931569957049, 'num_leaves': 5, 'max_depth': 14, 'min_child_samples': 21, 'min_split_gain': 0.4563742903618905, 'bagging_fraction': 0.700382735743568, 'bagging_freq': 3, 'feature_fraction': 0.834029424265224, 'lambda_l1': 1.6522517834478845, 'lambda_l2': 0.09891036537472203, 'huber_alpha': 0.9}. Best is trial 23 with value: 1.3716892001415721.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-08 13:16:30,169] Trial 26 finished with value: 1.366299791286807 and parameters: {'n_estimators': 1820, 'learning_rate': 0.034442845198523205, 'num_leaves': 459, 'max_depth': 12, 'min_child_samples': 17, 'min_split_gain': 0.6619837612269412, 'bagging_fraction': 0.8292738290922836, 'bagging_freq': 1, 'feature_fraction': 0.8956944454867455, 'lambda_l1': 0.20749642029872387, 'lambda_l2': 0.007445160381539105, 'huber_alpha': 0.75}. Best is trial 26 with value: 1.366299791286807.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-08 13:16:34,837] Trial 27 finished with value: 1.3818573367580018 and parameters: {'n_estimators': 2176, 'learning_rate': 0.034073872225401994, 'num_leaves': 297, 'max_depth': 10, 'min_child_samples': 16, 'min_split_gain': 1.2190042238786576, 'bagging_fraction': 0.8073766842275479, 'bagging_freq': 2, 'feature_fraction': 0.9192533987720439, 'lambda_l1': 0.2653212512759772, 'lambda_l2': 9.962594239215232, 'huber_alpha': 0.75}. Best is trial 26 with value: 1.366299791286807.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-08 13:17:01,950] Trial 28 finished with value: 1.4004989297381802 and parameters: {'n_estimators': 1867, 'learning_rate': 0.014238193139828067, 'num_leaves': 451, 'max_depth': 12, 'min_child_samples': 74, 'min_split_gain': 0.6712357894025494, 'bagging_fraction': 0.8962543354752457, 'bagging_freq': 1, 'feature_fraction': 0.8897313504594405, 'lambda_l1': 0.0002480131224026581, 'lambda_l2': 0.017783014629272068, 'huber_alpha': 0.75}. Best is trial 26 with value: 1.366299791286807.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-08 13:17:43,098] Trial 29 finished with value: 1.3842435568265299 and parameters: {'n_estimators': 1248, 'learning_rate': 0.02456287934617516, 'num_leaves': 368, 'max_depth': 10, 'min_child_samples': 18, 'min_split_gain': 1.3319688903833806, 'bagging_fraction': 0.7231969876994022, 'bagging_freq': 2, 'feature_fraction': 0.8330837140784257, 'lambda_l1': 0.07107304684925897, 'lambda_l2': 0.06489518523944675, 'huber_alpha': 0.75}. Best is trial 26 with value: 1.366299791286807.
# [I 2026-07-08 13:17:43,254] A new study created in RDB with name: KAUS_v11_remaining_warmup_base_catboost_mae_f
# [I 2026-07-08 13:30:32,219] Trial 0 finished with value: 1.7562892240273322 and parameters: {'iterations': 2931, 'learning_rate': 0.001783588943232587, 'depth': 10, 'l2_leaf_reg': 0.9942958882300413, 'random_strength': 7.186216756161439, 'bagging_temperature': 12.184767612363034, 'border_count': 110, 'rsm': 0.6158971964095841, 'huber_delta': 1.5}. Best is trial 0 with value: 1.7562892240273322.
# [I 2026-07-08 13:46:08,197] Trial 1 finished with value: 2.0006471814831235 and parameters: {'iterations': 801, 'learning_rate': 0.19767902101650964, 'depth': 12, 'l2_leaf_reg': 75.05056513807031, 'random_strength': 12.92821124806787, 'bagging_temperature': 4.276496242612171, 'border_count': 168, 'rsm': 0.4404450637901872, 'huber_delta': 1.0}. Best is trial 0 with value: 1.7562892240273322.
# [I 2026-07-08 13:47:08,866] Trial 2 finished with value: 2.0602103183964338 and parameters: {'iterations': 1992, 'learning_rate': 0.0024079350849750287, 'depth': 3, 'l2_leaf_reg': 0.118485976001343, 'random_strength': 4.058751860003342, 'bagging_temperature': 9.103785934457758, 'border_count': 206, 'rsm': 0.994034742637508, 'huber_delta': 0.5}. Best is trial 0 with value: 1.7562892240273322.
# [I 2026-07-08 14:10:01,094] Trial 3 finished with value: 1.9214682992205119 and parameters: {'iterations': 3095, 'learning_rate': 0.05508623515899769, 'depth': 11, 'l2_leaf_reg': 18.082710740309665, 'random_strength': 13.948598364083836, 'bagging_temperature': 18.60205606816345, 'border_count': 227, 'rsm': 0.4117317891426977, 'huber_delta': 3.0}. Best is trial 0 with value: 1.7562892240273322.
# [I 2026-07-08 14:11:25,372] Trial 4 finished with value: 1.5808458708443527 and parameters: {'iterations': 3146, 'learning_rate': 0.0024764229908984673, 'depth': 3, 'l2_leaf_reg': 0.6951779671472356, 'random_strength': 6.148451176512449, 'bagging_temperature': 8.441103735088014, 'border_count': 95, 'rsm': 0.7192489923988105, 'huber_delta': 2.0}. Best is trial 4 with value: 1.5808458708443527.
# [I 2026-07-08 14:12:01,980] Trial 5 finished with value: 1.5182012491760069 and parameters: {'iterations': 2996, 'learning_rate': 0.04169299311145666, 'depth': 2, 'l2_leaf_reg': 0.6483636109972302, 'random_strength': 11.284989840243444, 'bagging_temperature': 11.881552589055849, 'border_count': 179, 'rsm': 0.7610806862514128, 'huber_delta': 0.5}. Best is trial 5 with value: 1.5182012491760069.
# [I 2026-07-08 14:12:04,416] Trial 6 pruned.
# [I 2026-07-08 14:12:17,319] Trial 7 finished with value: 1.5520495586883967 and parameters: {'iterations': 2269, 'learning_rate': 0.05988786419186062, 'depth': 3, 'l2_leaf_reg': 0.8727148674658863, 'random_strength': 13.785080578883292, 'bagging_temperature': 3.643240241026453, 'border_count': 16, 'rsm': 0.5239102067389221, 'huber_delta': 0.5}. Best is trial 5 with value: 1.5182012491760069.
# [I 2026-07-08 14:12:58,856] Trial 8 pruned.
# [I 2026-07-08 14:16:20,856] Trial 9 finished with value: 1.4947244700704796 and parameters: {'iterations': 2176, 'learning_rate': 0.006973123504821021, 'depth': 7, 'l2_leaf_reg': 1.0111907140307084, 'random_strength': 19.613513312465464, 'bagging_temperature': 8.113717548278494, 'border_count': 208, 'rsm': 0.7899333278528806, 'huber_delta': 5.0}. Best is trial 9 with value: 1.4947244700704796.
# [I 2026-07-08 14:16:56,634] Trial 10 pruned.
# [I 2026-07-08 14:18:33,553] Trial 11 finished with value: 1.4644452251121685 and parameters: {'iterations': 2772, 'learning_rate': 0.014522829031783214, 'depth': 5, 'l2_leaf_reg': 15.987388321276002, 'random_strength': 11.591109950971106, 'bagging_temperature': 7.790667047006705, 'border_count': 126, 'rsm': 0.7500006952294106, 'huber_delta': 5.0}. Best is trial 11 with value: 1.4644452251121685.
# [I 2026-07-08 14:19:41,327] Trial 12 pruned.
# [I 2026-07-08 14:19:51,708] Trial 13 pruned.
# [I 2026-07-08 14:20:02,819] Trial 14 finished with value: 1.5378112488021287 and parameters: {'iterations': 2033, 'learning_rate': 0.03406017942217813, 'depth': 3, 'l2_leaf_reg': 2.8273302406131626, 'random_strength': 2.5986858551767766, 'bagging_temperature': 5.630188860588947, 'border_count': 58, 'rsm': 0.9026140460549269, 'huber_delta': 1.0}. Best is trial 11 with value: 1.4644452251121685.
# [I 2026-07-08 14:20:51,843] Trial 15 pruned.
# [I 2026-07-08 14:21:17,148] Trial 16 pruned.
# [I 2026-07-08 14:23:16,872] Trial 17 finished with value: 1.4637817195768403 and parameters: {'iterations': 2536, 'learning_rate': 0.008839187675884689, 'depth': 8, 'l2_leaf_reg': 7.939365760496926, 'random_strength': 16.574794818938415, 'bagging_temperature': 1.3263969896774768, 'border_count': 43, 'rsm': 0.8989809553994637, 'huber_delta': 5.0}. Best is trial 17 with value: 1.4637817195768403.
# [I 2026-07-08 14:24:14,895] Trial 18 finished with value: 1.4600888217896322 and parameters: {'iterations': 2586, 'learning_rate': 0.01434793462583799, 'depth': 8, 'l2_leaf_reg': 6.917992938395442, 'random_strength': 15.709820874401833, 'bagging_temperature': 0.31515488633751154, 'border_count': 22, 'rsm': 0.9279709214507983, 'huber_delta': 5.0}. Best is trial 18 with value: 1.4600888217896322.
 'fit_intercept': True}. Best is trial 5 with value: 1.3547664394676866.
# [I 2026-07-08 14:42:25,310] Trial 16 finished with value: 1.491217925547044 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 47590.802764145235, 'fit_intercept': False}. Best is trial 5 with value: 1.3547664394676866.
# [I 2026-07-08 14:42:25,554] Trial 17 finished with value: 1.3682789132878626 and parameters: {'feature_set': 'models_only', 'alpha': 0.6157774532481516, 'fit_intercept': True}. Best is trial 5 with value: 1.3547664394676866.
# [I 2026-07-08 14:42:25,796] Trial 18 finished with value: 1.3864458286102954 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 4438.410470784403, 'fit_intercept': False}. Best is trial 5 with value: 1.3547664394676866.
# [I 2026-07-08 14:42:26,052] Trial 19 finished with value: 1.366986529045366 and parameters: {'feature_set': 'models_only', 'alpha': 4.358270202053984, 'fit_intercept': True}. Best is trial 5 with value: 1.3547664394676866.
# [I 2026-07-08 14:42:26,280] Trial 20 finished with value: 1.3718498630445006 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 0.023287131158877265, 'fit_intercept': False}. Best is trial 5 with value: 1.3547664394676866.
# [I 2026-07-08 14:42:26,509] Trial 21 finished with value: 1.3558482759539274 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 1269.0590609504886, 'fit_intercept': True}. Best is trial 5 with value: 1.3547664394676866.
# [I 2026-07-08 14:42:26,733] Trial 22 finished with value: 1.3601073186689026 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 202.76338900543286, 'fit_intercept': True}. Best is trial 5 with value: 1.3547664394676866.
# [I 2026-07-08 14:42:26,954] Trial 23 finished with value: 1.4077642572978002 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 8132.269261460028, 'fit_intercept': True}. Best is trial 5 with value: 1.3547664394676866.
# [I 2026-07-08 14:42:27,178] Trial 24 finished with value: 1.3564476704313793 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 390.6518650948634, 'fit_intercept': True}. Best is trial 5 with value: 1.3547664394676866.
# [I 2026-07-08 14:42:27,413] Trial 25 finished with value: 1.3765318467989258 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 9.461862127365176, 'fit_intercept': True}. Best is trial 5 with value: 1.3547664394676866.
# [I 2026-07-08 14:42:27,631] Trial 26 finished with value: 1.6652565967291468 and parameters: {'feature_set': 'models_only', 'alpha': 17599.63923015665, 'fit_intercept': True}. Best is trial 5 with value: 1.3547664394676866.
# [I 2026-07-08 14:42:27,865] Trial 27 finished with value: 1.3548310210911068 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 707.8409327155018, 'fit_intercept': True}. Best is trial 5 with value: 1.3547664394676866.
# [I 2026-07-08 14:42:28,088] Trial 28 finished with value: 1.3611998849460456 and parameters: {'feature_set': 'models_only', 'alpha': 58.51710832158476, 'fit_intercept': False}. Best is trial 5 with value: 1.3547664394676866.
# [I 2026-07-08 14:42:28,322] Trial 29 finished with value: 1.365182266469031 and parameters: {'feature_set': 'models_only', 'alpha': 21.30475083825194, 'fit_intercept': False}. Best is trial 5 with value: 1.3547664394676866.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# ...
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
#                   period           method  count     mae_f    rmse_f
# 0   validation_2024_2025          xgboost    729  1.382996  1.938109
# 1   validation_2024_2025         lightgbm    729  1.388670  1.944455
# 2   validation_2024_2025         catboost    729  1.425630  1.936151
# 3   validation_2024_2025    provider_mean    729  1.925151  2.578121
# 4   validation_2024_2025  provider_median    729  1.945498  2.621630
# 5   validation_2024_2025          nbm_raw    729  2.006049  2.734667
# 6   validation_2024_2025         hrrr_raw    729  2.441988  3.337908
# 7   validation_2024_2025          gfs_raw    729  2.728847  3.543254
# 8              test_2026          xgboost    171  1.416994  1.895118
# 9              test_2026         lightgbm    171  1.434090  1.914983
# 10             test_2026         catboost    171  1.475430  1.950210
# 11             test_2026      ridge_stack    171  1.412573  1.876879
# 12             test_2026    provider_mean    171  1.958742  2.447969
# 13             test_2026  provider_median    171  1.899362  2.381778
# 14             test_2026          nbm_raw    171  1.852189  2.421658
# 15             test_2026         hrrr_raw    171  2.284943  2.853978
# 16             test_2026          gfs_raw    171  2.571035  3.273241

# %%
exported_weights = export_station_model_weights(
    project_root=PROJECT_ROOT,
    station_id=STATION_ID,
    artifact_dir=config.resolved_output_dir(),
    model_version=MODEL_VERSION,
    timing_mode=config.timing_mode,
    providers=tuple(config.providers),
    feature_version=config.effective_feature_version,
    optuna_metric=config.effective_optuna_metric,
    target_mode=config.effective_target_mode,
    target_source=config.effective_target_source,
    base_model_methods=tuple(config.effective_base_model_methods),
    stack_enabled=config.stack_enabled,
    source_pipeline="notebooks/experiments/station_stacking_v11_settlement",
)

exported_weights.bundle_path, exported_weights.manifest_path
# Out:
# (WindowsPath('D:/dev/weather-research/data/calibration/station_stacking_v11_settlement/model_weights/KAUS_station_high_regressor_v11_wunderground_settlement_stack.joblib'),
#  WindowsPath('D:/dev/weather-research/data/calibration/station_stacking_v11_settlement/model_weights/KAUS_station_high_regressor_v11_wunderground_settlement_stack.json'))

# %% [markdown]
# ## V11 Feature Coverage

# %%
v11_feature_coverage = (
    result.features[V11_FEATURE_COLUMNS]
    .notna()
    .mean()
    .mul(100)
    .sort_values(ascending=False)
    .rename("coverage_pct")
    .reset_index()
    .rename(columns={"index": "feature"})
)

v11_feature_coverage
# Out:
#                                               feature  coverage_pct
# 0                              v2_spread_per_warmup_f    100.000000
# 1                    v2_morning_warmup_to_consensus_f    100.000000
# 2              v3_remaining_warmup_from_high_so_far_f    100.000000
# 3                      v3_high_so_far_above_current_f    100.000000
# 4                      v2_humidity_warmup_interaction    100.000000
# 5                    v4_observed_precip_recent_mm_est    100.000000
# 6                        v4_forecast_wet_observed_dry    100.000000
# 7                   v4_forecast_observed_precip_match    100.000000
# 8            v3_humidity_remaining_warmup_interaction    100.000000
# 9                    v3_remaining_warmup_per_spread_f    100.000000
# 10                             v4_all_forecast_precip    100.000000
# 11                             v4_observed_precip_any    100.000000
# 12                             v4_any_forecast_precip    100.000000
# 13              provider_mean_minus_climatology_10y_f    100.000000
# 14                             climatology_high_10y_f    100.000000
# 15                         climatology_high_10y_std_f    100.000000
# 16       observed_high_so_far_minus_climatology_10y_f    100.000000
# 17              observed_temp_minus_climatology_10y_f    100.000000
# 18                         climatology_high_10y_count    100.000000
# 19    v8_provider_median_remaining_from_high_so_far_f    100.000000
# 20          v8_provider_spread_per_remaining_warmup_f    100.000000
# 21                    v8_month_remaining_warmup_count    100.000000
# 22       v8_provider_min_remaining_from_high_so_far_f    100.000000
# 23            observed_high_so_far_change_since_9am_f    100.000000
# 24       v8_provider_max_remaining_from_high_so_far_f    100.000000
# 25                       v4_observed_wet_forecast_dry    100.000000
# 26                          v2_recent_heat_momentum_f     99.949950
# 27                     v2_consensus_minus_7d_actual_f     99.949950
# 28                      v3_high_so_far_minus_lag_1d_f     99.949950
# 29                           v2_recent_heat_anomaly_f     99.949950
# 30                   v3_high_so_far_minus_7d_actual_f     99.949950
# 31            observed_morning_warmup_rate_f_per_hour     99.949950
# 32                     observed_temp_change_last_3h_f     99.949950
# 33                     observed_temp_change_last_1h_f     99.949950
# 34               v8_recent_remaining_warmup_7d_mean_f     99.899900
# 35              v8_recent_remaining_warmup_30d_mean_f     99.749750
# 36       v8_provider_mean_remaining_vs_month_normal_f     98.798799
# 37                   v8_month_remaining_warmup_mean_f     98.798799
# 38      v8_dewpoint_mean_remaining_warmup_interaction     79.929930
# 39  v8_dewpoint_depression_remaining_warmup_intera...     79.929930
# 40                        v8_forecast_dewpoint_mean_f     79.929930
# 41             v8_forecast_dewpoint_depression_mean_f     79.929930
# 42         v4_forecast_total_minus_observed_recent_mm     79.479479
# 43                   v4_forecast_precip_intensity_max     79.479479
# 44                   v4_forecast_precip_total_mean_mm     79.479479
# 45                    v4_forecast_precip_total_max_mm     79.479479
# 46                 v4_forecast_precip_total_spread_mm     79.479479
# 47                  v4_forecast_precip_max_1h_mean_mm     79.479479
# 48                      v4_forecast_precip_hours_mean     79.479479
# 49                  v4_forecast_precip_intensity_mean     79.479479
# 50             v4_precip_remaining_warmup_interaction     79.479479
# 51                     v4_precip_humidity_interaction     79.479479
# 52       v8_precip_total_remaining_warmup_interaction     79.479479
# 53      v8_precip_max_1h_remaining_warmup_interaction     79.479479
# 54    v8_wind_speed_mean_remaining_warmup_interaction     36.186186
# 55      v8_wind_gust_max_remaining_warmup_interaction     36.186186
# 56    v8_cloud_cover_max_remaining_warmup_interaction      0.000000
# 57   v8_cloud_cover_mean_remaining_warmup_interaction      0.000000

# %%
result.feature_columns.loc[result.feature_columns["feature"].isin(V11_FEATURE_COLUMNS)]
# Out:
#                                                feature     kind
# 20                      observed_temp_change_last_1h_f  numeric
# 21                      observed_temp_change_last_3h_f  numeric
# 22             observed_morning_warmup_rate_f_per_hour  numeric
# 23             observed_high_so_far_change_since_9am_f  numeric
# 221                           v2_recent_heat_anomaly_f  numeric
# 222                          v2_recent_heat_momentum_f  numeric
# 223                   v2_morning_warmup_to_consensus_f  numeric
# 224                     v2_consensus_minus_7d_actual_f  numeric
# 225                             v2_spread_per_warmup_f  numeric
# 226                     v2_humidity_warmup_interaction  numeric
# 227                     v3_high_so_far_above_current_f  numeric
# 228             v3_remaining_warmup_from_high_so_far_f  numeric
# 229                      v3_high_so_far_minus_lag_1d_f  numeric
# 230                   v3_high_so_far_minus_7d_actual_f  numeric
# 231                   v3_remaining_warmup_per_spread_f  numeric
# 232           v3_humidity_remaining_warmup_interaction  numeric
# 233                   v4_forecast_precip_total_mean_mm  numeric
# 234                    v4_forecast_precip_total_max_mm  numeric
# 235                 v4_forecast_precip_total_spread_mm  numeric
# 236                  v4_forecast_precip_max_1h_mean_mm  numeric
# 237                      v4_forecast_precip_hours_mean  numeric
# 238                  v4_forecast_precip_intensity_mean  numeric
# 239                   v4_forecast_precip_intensity_max  numeric
# 240                             v4_any_forecast_precip  numeric
# 241                             v4_all_forecast_precip  numeric
# 242                             v4_observed_precip_any  numeric
# 243                   v4_observed_precip_recent_mm_est  numeric
# 244         v4_forecast_total_minus_observed_recent_mm  numeric
# 245                  v4_forecast_observed_precip_match  numeric
# 246                       v4_forecast_wet_observed_dry  numeric
# 247                       v4_observed_wet_forecast_dry  numeric
# 248                     v4_precip_humidity_interaction  numeric
# 249             v4_precip_remaining_warmup_interaction  numeric
# 250       v8_provider_max_remaining_from_high_so_far_f  numeric
# 251       v8_provider_min_remaining_from_high_so_far_f  numeric
# 252    v8_provider_median_remaining_from_high_so_far_f  numeric
# 253          v8_provider_spread_per_remaining_warmup_f  numeric
# 254                   v8_month_remaining_warmup_mean_f  numeric
# 255                    v8_month_remaining_warmup_count  numeric
# 256               v8_recent_remaining_warmup_7d_mean_f  numeric
# 257              v8_recent_remaining_warmup_30d_mean_f  numeric
# 258       v8_provider_mean_remaining_vs_month_normal_f  numeric
# 259       v8_precip_total_remaining_warmup_interaction  numeric
# 260      v8_precip_max_1h_remaining_warmup_interaction  numeric
# 261    v8_wind_speed_mean_remaining_warmup_interaction  numeric
# 262      v8_wind_gust_max_remaining_warmup_interaction  numeric
# 263                        v8_forecast_dewpoint_mean_f  numeric
# 264             v8_forecast_dewpoint_depression_mean_f  numeric
# 265      v8_dewpoint_mean_remaining_warmup_interaction  numeric
# 266  v8_dewpoint_depression_remaining_warmup_intera...  numeric
# 267                             climatology_high_10y_f  numeric
# 268                         climatology_high_10y_std_f  numeric
# 269                         climatology_high_10y_count  numeric
# 270              provider_mean_minus_climatology_10y_f  numeric
# 271              observed_temp_minus_climatology_10y_f  numeric
# 272       observed_high_so_far_minus_climatology_10y_f  numeric

# %% [markdown]
# ## Dropped Feature Check

# %%
dropped_present = result.feature_columns.loc[
    result.feature_columns["feature"].isin(V11_DROPPED_FEATURE_COLUMNS)
]

dropped_present
# Out:
# Empty DataFrame
# Columns: [feature, kind]
# Index: []

# %% [markdown]
# ## Morning Trend Coverage

# %%
trend_coverage = (
    result.features[TREND_COLUMNS]
    .notna()
    .mean()
    .mul(100)
    .sort_values(ascending=False)
    .rename("coverage_pct")
    .reset_index()
    .rename(columns={"index": "feature"})
)

trend_coverage
# Out:
#                                    feature  coverage_pct
# 0  observed_high_so_far_change_since_9am_f     100.00000
# 1           observed_temp_change_last_1h_f      99.94995
# 2           observed_temp_change_last_3h_f      99.94995
# 3  observed_morning_warmup_rate_f_per_hour      99.94995

# %% [markdown]
# ## Rounded Within 1F Accuracy

# %%
preds = pd.concat(
    [
        result.validation_predictions.assign(period="validation_2024_2025"),
        result.test_predictions.assign(period="oof_2026"),
    ],
    ignore_index=True,
)

predicted_high = pd.to_numeric(preds["predicted_high_f"], errors="coerce")
preds["predicted_high_rounded_f"] = np.floor(predicted_high + 0.5)
preds["within_1f_after_round"] = (
    pd.to_numeric(preds["actual_high_f"], errors="coerce") - preds["predicted_high_rounded_f"]
).abs().le(1)

within_1f_accuracy_by_period = (
    preds
    .dropna(subset=["actual_high_f", "predicted_high_rounded_f"])
    .groupby(["period", "method"], as_index=False)
    .agg(
        count=("within_1f_after_round", "size"),
        within_1f_count=("within_1f_after_round", "sum"),
        within_1f_accuracy_pct=("within_1f_after_round", lambda x: x.mean() * 100),
    )
    .sort_values(["period", "within_1f_accuracy_pct"], ascending=[True, False])
)

within_1f_accuracy_by_period
# Out:
#                   period           method  count  within_1f_count  \
# 3               oof_2026         lightgbm    171              105
# 8               oof_2026          xgboost    171              104
# 7               oof_2026      ridge_stack    171              102
# 0               oof_2026         catboost    171               99
# 4               oof_2026          nbm_raw    171               80
# 5               oof_2026    provider_mean    171               80
# 6               oof_2026  provider_median    171               75
# 2               oof_2026         hrrr_raw    171               66
# 1               oof_2026          gfs_raw    171               62
# 12  validation_2024_2025         lightgbm    729              496
# 16  validation_2024_2025          xgboost    729              488
# 9   validation_2024_2025         catboost    729              476
# 14  validation_2024_2025    provider_mean    729              367
# 15  validation_2024_2025  provider_median    729              359
# 13  validation_2024_2025          nbm_raw    729              354
# 11  validation_2024_2025         hrrr_raw    729              296
# 10  validation_2024_2025          gfs_raw    729              236
#
#     within_1f_accuracy_pct
# 3                61.403509
# 8                60.818713
# 7                59.649123
# 0                57.894737
# 4                46.783626
# 5                46.783626
# 6                43.859649
# 2                38.596491
# 1                36.257310
# 12               68.038409
# 16               66.941015
# 9                65.294925
# 14               50.342936
# 15               49.245542
# 13               48.559671
# 11               40.603567
# 10               32.373114

# %% [markdown]
# ## Version Comparison

# %%
comparison_frames = []
for version, folder in [
    ("v1", PROJECT_ROOT / "data" / "calibration" / "station_stacking"),
    ("v2", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v2"),
    ("v3", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v3"),
    ("v4", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v4"),
    ("v5", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v5"),
    ("v6", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v6"),
    ("v7", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v7"),
    ("v8", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v8"),
    ("v9", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v9"),
    ("v10", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v10"),
    ("v11", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v11"),
]:
    path = folder / f"{STATION_ID}_year_split_scoreboard.csv"
    if path.exists():
        frame = pd.read_csv(path)
        frame["version"] = version
        comparison_frames.append(frame)

version_comparison = pd.concat(comparison_frames, ignore_index=True) if comparison_frames else pd.DataFrame()
if not version_comparison.empty:
    version_comparison = version_comparison.sort_values(["period", "mae_f", "version", "method"]).reset_index(drop=True)
version_comparison
# Out:
#                    period       method  count     mae_f    rmse_f version
# 0               test_2026     lightgbm    137  1.529158  2.006654      v8
# 1               test_2026      xgboost    137  1.532705  1.993087     v11
# 2               test_2026  ridge_stack    137  1.557921  2.024451      v8
# 3               test_2026     lightgbm    137  1.572570  2.077610     v11
# 4               test_2026  ridge_stack     98  1.587308  2.183874      v7
# ..                    ...          ...    ...       ...       ...     ...
# 111  validation_2024_2025      gfs_raw    660  4.616216  6.792032      v2
# 112  validation_2024_2025      gfs_raw    660  4.616216  6.792032      v3
# 113  validation_2024_2025      gfs_raw    660  4.616216  6.792032      v4
# 114  validation_2024_2025      gfs_raw    596  4.846561  7.070391      v1
# 115  validation_2024_2025      xgboost    660  5.333859  6.998391      v4
#
# [116 rows x 6 columns]

# %% [markdown]
# ## 2026 OOF Weather Brackets

# %%
result.bracket_metrics
# Out:
#             method  count     mae_f    rmse_f  bracket_accuracy_pct
# 0          xgboost    171  1.416994  1.895118             43.274854
# 1         lightgbm    171  1.434090  1.914983             44.444444
# 2         catboost    171  1.475430  1.950210             40.935673
# 3      ridge_stack    171  1.412573  1.876879             43.859649
# 4    provider_mean    171  1.958742  2.447969             33.918129
# 5  provider_median    171  1.899362  2.381778             32.748538
# 6          nbm_raw    171  1.852189  2.421658             33.333333
# 7         hrrr_raw    171  2.284943  2.853978             25.730994
# 8          gfs_raw    171  2.571035  3.273241              27.48538

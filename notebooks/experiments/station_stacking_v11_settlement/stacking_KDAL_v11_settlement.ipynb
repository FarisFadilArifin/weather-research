# %% [markdown]
# # Station Stacking v11 Settlement - KDAL
#
# Experimental notebook for `KDAL`.
#
# This controlled rerun keeps the exact v11 feature/model contract, replaces daily-high labels with settlement-first Wunderground station history when available, and writes separate artifacts to `data/calibration/station_stacking_v11_settlement`.

# %%
from pathlib import Path
import os
import sys
import warnings

warnings.filterwarnings("ignore", message="IProgress not found.*")
warnings.filterwarnings("ignore", message="Skipping features without any observed values.*")

PROJECT_ROOT = Path.cwd().resolve()
while not (PROJECT_ROOT / "src" / "calibration" / "station_stacking.py").exists():
    if PROJECT_ROOT.parent == PROJECT_ROOT:
        raise RuntimeError("Could not find project root containing src/calibration/station_stacking.py")
    PROJECT_ROOT = PROJECT_ROOT.parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

os.environ["WEATHER_RESEARCH_INCLUDE_DIRECT_NBM"] = "1"

STATION_ID = "KDAL"
PROVIDERS = ("gfs", "hrrr", "nbm")
TREND_COLUMNS = [
    "observed_temp_change_last_1h_f",
    "observed_temp_change_last_3h_f",
    "observed_morning_warmup_rate_f_per_hour",
    "observed_high_so_far_change_since_9am_f",
]
TIMING_MODE = "same_day_11am_live_safe"
FAST_MODE = False
OPTUNA_TRIALS = 30
STACK_OPTUNA_TRIALS = 30
OPTUNA_STARTUP_TRIALS = 15
STACK_OPTUNA_STARTUP_TRIALS = 15
OPTUNA_METRIC = "mae_f"
OPTUNA_VERBOSE = True
MODEL_VERSION = "station_high_regressor_v11_wunderground_settlement_stack"
PROJECT_ROOT
# Out:
# WindowsPath('D:/dev/weather-research')

# %%
import numpy as np
import pandas as pd

from src.export_station_stacking_v2_models import export_station_model_weights
from src.calibration.station_stacking import (
    StationStackingConfig,
    V11_DROPPED_FEATURE_COLUMNS,
    V11_FEATURE_COLUMNS,
    YEAR_SPLIT_EXPANDING_FOLDS,
    missing_model_dependencies,
    provider_availability,
    run_station_year_split_experiment,
)

# %% [markdown]
# ## V11 Contract
#
# `feature_version="v11"` keeps the v9 feature contract and remaining-warmup target, but trains base learners with Huber-style objectives while retaining the ridge stack selected by validation MAE.

# %%
fold_spec = pd.DataFrame(
    [
        {
            "fold": fold.name,
            "train_start_year": fold.train_start_year,
            "train_end_year": fold.train_end_year,
            "validation_year": fold.validation_year,
        }
        for fold in YEAR_SPLIT_EXPANDING_FOLDS
    ]
)

fold_spec
# Out:
#                      fold  train_start_year  train_end_year  validation_year
# 0  fold_2021_2023_to_2024              2021            2023             2024
# 1  fold_2021_2024_to_2025              2021            2024             2025

# %%
V11_FEATURE_COLUMNS, sorted(V11_DROPPED_FEATURE_COLUMNS)
# Out:
# (['v2_recent_heat_anomaly_f',
#   'v2_recent_heat_momentum_f',
#   'v2_morning_warmup_to_consensus_f',
#   'v2_consensus_minus_7d_actual_f',
#   'v2_spread_per_warmup_f',
#   'v2_humidity_warmup_interaction',
#   'v3_high_so_far_above_current_f',
#   'v3_remaining_warmup_from_high_so_far_f',
#   'v3_high_so_far_minus_lag_1d_f',
#   'v3_high_so_far_minus_7d_actual_f',
#   'v3_remaining_warmup_per_spread_f',
#   'v3_humidity_remaining_warmup_interaction',
#   'v4_forecast_precip_total_mean_mm',
#   'v4_forecast_precip_total_max_mm',
#   'v4_forecast_precip_total_spread_mm',
#   'v4_forecast_precip_max_1h_mean_mm',
#   'v4_forecast_precip_hours_mean',
#   'v4_forecast_precip_intensity_mean',
#   'v4_forecast_precip_intensity_max',
#   'v4_any_forecast_precip',
#   'v4_all_forecast_precip',
#   'v4_observed_precip_any',
#   'v4_observed_precip_recent_mm_est',
#   'v4_forecast_total_minus_observed_recent_mm',
#   'v4_forecast_observed_precip_match',
#   'v4_forecast_wet_observed_dry',
#   'v4_observed_wet_forecast_dry',
#   'v4_precip_humidity_interaction',
#   'v4_precip_remaining_warmup_interaction',
#   'observed_temp_change_last_1h_f',
#   'observed_temp_change_last_3h_f',
#   'observed_morning_warmup_rate_f_per_hour',
#   'observed_high_so_far_change_since_9am_f',
#   'v8_provider_max_remaining_from_high_so_far_f',
#   'v8_provider_min_remaining_from_high_so_far_f',
#   'v8_provider_median_remaining_from_high_so_far_f',
#   'v8_provider_spread_per_remaining_warmup_f',
#   'v8_month_remaining_warmup_mean_f',
#   'v8_month_remaining_warmup_count',
#   'v8_recent_remaining_warmup_7d_mean_f',
#   'v8_recent_remaining_warmup_30d_mean_f',
#   'v8_provider_mean_remaining_vs_month_normal_f',
#   'v8_cloud_cover_mean_remaining_warmup_interaction',
#   'v8_cloud_cover_max_remaining_warmup_interaction',
#   'v8_precip_total_remaining_warmup_interaction',
#   'v8_precip_max_1h_remaining_warmup_interaction',
#   'v8_wind_speed_mean_remaining_warmup_interaction',
#   'v8_wind_gust_max_remaining_warmup_interaction',
#   'v8_forecast_dewpoint_mean_f',
#   'v8_forecast_dewpoint_depression_mean_f',
#   'v8_dewpoint_mean_remaining_warmup_interaction',
#   'v8_dewpoint_depression_remaining_warmup_interaction',
#   'climatology_high_10y_f',
#   'climatology_high_10y_std_f',
#   'climatology_high_10y_count',
#   'provider_mean_minus_climatology_10y_f',
#   'observed_temp_minus_climatology_10y_f',
#   'observed_high_so_far_minus_climatology_10y_f'],
#  ['actual_minus_climatology_10y_f_DIAGNOSTIC_ONLY',
#   'climatology_source_end_year',
#   'climatology_source_start_year',
#   'gfs_as_of_hour_local',
#   'gfs_available',
#   'gfs_forecast_window_hours',
#   'gfs_grid_dist_km_mean',
#   'gfs_horizon_hours',
#   'gfs_hrrr_grid_dist_km_mean_abs_diff_f',
#   'gfs_hrrr_grid_dist_km_mean_diff_f',
#   'gfs_issue_hour_utc',
#   'gfs_missing',
#   'hrrr_as_of_hour_local',
#   'hrrr_available',
#   'hrrr_forecast_hour_max',
#   'hrrr_forecast_hour_min',
#   'hrrr_forecast_lead_hours',
#   'hrrr_forecast_window_hours',
#   'hrrr_grid_dist_km_mean',
#   'hrrr_horizon_hours',
#   'hrrr_issue_hour_local',
#   'hrrr_issue_hour_utc',
#   'hrrr_missing',
#   'is_active_polymarket_station',
#   'lat',
#   'lon',
#   'nbm_as_of_hour_local',
#   'nbm_available',
#   'nbm_forecast_window_hours',
#   'nbm_horizon_hours',
#   'nbm_issue_hour_local',
#   'nbm_issue_hour_utc',
#   'nbm_missing',
#   'observed_fetch_status',
#   'observed_observation_type',
#   'observed_pressure_source',
#   'provider_count_available',
#   'year'])

# %% [markdown]
# ## Data Availability

# %%
availability = provider_availability(
    PROJECT_ROOT,
    timing_mode=TIMING_MODE,
    providers=PROVIDERS,
)

availability.loc[availability["station_id"].eq(STATION_ID)]
# Out:
#   station_id provider  row_count first_contract_date last_contract_date
# 6       KDAL      gfs       1992          2021-01-01         2026-06-21
# 7       KDAL     hrrr       1998          2021-01-01         2026-06-21
# 8       KDAL      nbm       1997          2021-01-01         2026-06-21

# %% [markdown]
# ## Model Scores

# %%
missing_packages = missing_model_dependencies()
if missing_packages:
    raise ImportError(
        "Missing station-stacking ML packages: "
        + ", ".join(missing_packages)
        + ". Install them with: python -m pip install -r requirements.txt"
    )

config = StationStackingConfig(
    station_id=STATION_ID,
    project_root=PROJECT_ROOT,
    timing_mode=TIMING_MODE,
    providers=PROVIDERS,
    fast_mode=FAST_MODE,
    optuna_trials=OPTUNA_TRIALS,
    stack_optuna_trials=STACK_OPTUNA_TRIALS,
    optuna_startup_trials=OPTUNA_STARTUP_TRIALS,
    stack_optuna_startup_trials=STACK_OPTUNA_STARTUP_TRIALS,
    optuna_metric=OPTUNA_METRIC,
    optuna_verbose=OPTUNA_VERBOSE,
    feature_version="v11",
    target_mode="remaining_warmup",
    target_source="settlement_first",
    base_model_methods=("xgboost", "lightgbm", "catboost"),
    stack_enabled=True,
    hyperparameter_space="wide",
    year_split_folds=YEAR_SPLIT_EXPANDING_FOLDS,
    year_split_test_train_years=(2021, 2025),
    year_split_test_year=2026,
    output_dir=PROJECT_ROOT / "data" / "calibration" / "station_stacking_v11_settlement",
)

config.resolved_optuna_storage_path()
# Out:
# WindowsPath('D:/dev/weather-research/data/calibration/station_stacking_v11_settlement/KDAL_optuna.sqlite3')

# %%
result = run_station_year_split_experiment(config)
result.scoreboard
# Out:
# [I 2026-07-06 23:00:05,226] A new study created in RDB with name: KDAL_v11_remaining_warmup_base_xgboost_mae_f
# [I 2026-07-06 23:00:15,628] Trial 0 finished with value: 1.6123222906684427 and parameters: {'n_estimators': 1342, 'learning_rate': 0.19043899115982607, 'max_depth': 9, 'min_child_weight': 2.481040974867813, 'gamma': 2.340279606636548, 'subsample': 0.4513964382185317, 'colsample_bytree': 0.3877543479093296, 'reg_alpha': 2.478071022662141, 'reg_lambda': 0.6132587025321562}. Best is trial 0 with value: 1.6123222906684427.
# [I 2026-07-06 23:00:53,968] Trial 1 finished with value: 1.4905544134002844 and parameters: {'n_estimators': 2493, 'learning_rate': 0.001120367191095075, 'max_depth': 12, 'min_child_weight': 21.368329072358772, 'gamma': 3.185086660174142, 'subsample': 0.4681862286846154, 'colsample_bytree': 0.46921293140473197, 'reg_alpha': 4.476173538513514e-07, 'reg_lambda': 0.20253776634919213}. Best is trial 1 with value: 1.4905544134002844.
# [I 2026-07-06 23:01:13,629] Trial 2 finished with value: 1.3367545157040226 and parameters: {'n_estimators': 1540, 'learning_rate': 0.004992867109217114, 'max_depth': 8, 'min_child_weight': 0.03613894271216528, 'gamma': 4.3821697280282725, 'subsample': 0.5881351981408995, 'colsample_bytree': 0.6464454897410734, 'reg_alpha': 0.26430874752361627, 'reg_lambda': 0.0018119678627933364}. Best is trial 2 with value: 1.3367545157040226.
# [I 2026-07-06 23:01:23,247] Trial 3 finished with value: 1.707796968502541 and parameters: {'n_estimators': 1824, 'learning_rate': 0.026337502897485255, 'max_depth': 1, 'min_child_weight': 2.69264691008618, 'gamma': 2.557861855309373, 'subsample': 0.39228353544043165, 'colsample_bytree': 0.9667755992146666, 'reg_alpha': 38.6887231523051, 'reg_lambda': 12.408975837016275}. Best is trial 2 with value: 1.3367545157040226.
# [I 2026-07-06 23:01:43,232] Trial 4 finished with value: 1.5028662223162716 and parameters: {'n_estimators': 1101, 'learning_rate': 0.0017147936629846843, 'max_depth': 9, 'min_child_weight': 0.5762487216478605, 'gamma': 1.8305735226716824, 'subsample': 0.6718649915723256, 'colsample_bytree': 0.37235253872489193, 'reg_alpha': 8.162906555194692, 'reg_lambda': 0.004271500153828077}. Best is trial 2 with value: 1.3367545157040226.
# [I 2026-07-06 23:02:20,738] Trial 5 finished with value: 1.4803805021341532 and parameters: {'n_estimators': 2336, 'learning_rate': 0.00559067775661512, 'max_depth': 7, 'min_child_weight': 1.5375920235481764, 'gamma': 2.7728168328829055, 'subsample': 0.980230008046963, 'colsample_bytree': 0.8538363351847245, 'reg_alpha': 18.792618557420877, 'reg_lambda': 43.484449457612314}. Best is trial 2 with value: 1.3367545157040226.
# [I 2026-07-06 23:02:23,370] Trial 6 finished with value: 1.3434799955347425 and parameters: {'n_estimators': 2113, 'learning_rate': 0.16240489353272883, 'max_depth': 2, 'min_child_weight': 0.06080390190296603, 'gamma': 0.678409333658071, 'subsample': 0.5614647149961218, 'colsample_bytree': 0.6026402382981633, 'reg_alpha': 1.8037999945880162e-07, 'reg_lambda': 16.668629892722056}. Best is trial 2 with value: 1.3367545157040226.
# [I 2026-07-06 23:02:31,788] Trial 7 finished with value: 1.3770856978114479 and parameters: {'n_estimators': 1281, 'learning_rate': 0.0047169807141865345, 'max_depth': 7, 'min_child_weight': 0.0366181922039243, 'gamma': 12.032954711310595, 'subsample': 0.398457918391851, 'colsample_bytree': 0.9914765087903362, 'reg_alpha': 0.18490013641000916, 'reg_lambda': 0.0017869543989965139}. Best is trial 2 with value: 1.3367545157040226.
# [I 2026-07-06 23:02:32,382] Trial 8 pruned.
# [I 2026-07-06 23:02:39,917] Trial 9 finished with value: 1.3564119533798467 and parameters: {'n_estimators': 2201, 'learning_rate': 0.006215464818952927, 'max_depth': 1, 'min_child_weight': 0.17535949529764422, 'gamma': 4.877749830401205, 'subsample': 0.8242440159197416, 'colsample_bytree': 0.7644123563808884, 'reg_alpha': 4.4315220126915325, 'reg_lambda': 0.09450187118503514}. Best is trial 2 with value: 1.3367545157040226.
# [I 2026-07-06 23:02:41,802] Trial 10 finished with value: 1.424256804913027 and parameters: {'n_estimators': 462, 'learning_rate': 0.051323729958866915, 'max_depth': 10, 'min_child_weight': 1.7583640270008525, 'gamma': 11.564507699318415, 'subsample': 0.670967137636854, 'colsample_bytree': 0.689776339098296, 'reg_alpha': 1.3504926357029513e-05, 'reg_lambda': 0.0001445994629863374}. Best is trial 2 with value: 1.3367545157040226.
# [I 2026-07-06 23:02:48,212] Trial 11 pruned.
# [I 2026-07-06 23:02:53,296] Trial 12 pruned.
# [I 2026-07-06 23:02:54,478] Trial 13 finished with value: 1.4131641733249367 and parameters: {'n_estimators': 693, 'learning_rate': 0.13813474572232612, 'max_depth': 7, 'min_child_weight': 16.973078532467014, 'gamma': 13.4413694988524, 'subsample': 0.5567022587317115, 'colsample_bytree': 0.4215337509429899, 'reg_alpha': 5.435280359192946e-08, 'reg_lambda': 0.049115547267693904}. Best is trial 2 with value: 1.3367545157040226.
# [I 2026-07-06 23:02:56,642] Trial 14 finished with value: 1.3815004254097807 and parameters: {'n_estimators': 2872, 'learning_rate': 0.11587248002108354, 'max_depth': 1, 'min_child_weight': 1.1040511903162256, 'gamma': 6.261165047231685, 'subsample': 0.49437007680597467, 'colsample_bytree': 0.4279124887668938, 'reg_alpha': 1.125594744942969e-06, 'reg_lambda': 87.35792858155622}. Best is trial 2 with value: 1.3367545157040226.
# [I 2026-07-06 23:03:06,571] Trial 15 finished with value: 1.316528924881433 and parameters: {'n_estimators': 3311, 'learning_rate': 0.021659849180609474, 'max_depth': 4, 'min_child_weight': 0.011054022093830057, 'gamma': 0.3744567555104146, 'subsample': 0.6098242026591096, 'colsample_bytree': 0.6181229892049431, 'reg_alpha': 0.003083204463756954, 'reg_lambda': 1.7165588122951194}. Best is trial 15 with value: 1.316528924881433.
# [I 2026-07-06 23:03:08,157] Trial 16 pruned.
# [I 2026-07-06 23:03:15,698] Trial 17 pruned.
# [I 2026-07-06 23:03:20,837] Trial 18 pruned.
# [I 2026-07-06 23:03:25,760] Trial 19 pruned.
# [I 2026-07-06 23:03:27,532] Trial 20 pruned.
# [I 2026-07-06 23:03:32,757] Trial 21 finished with value: 1.288170432768558 and parameters: {'n_estimators': 1913, 'learning_rate': 0.0579347754359845, 'max_depth': 3, 'min_child_weight': 0.07127758834065642, 'gamma': 0.04880469577886126, 'subsample': 0.544940236435552, 'colsample_bytree': 0.6138418291882624, 'reg_alpha': 7.474918518541996e-10, 'reg_lambda': 2.301268202112952}. Best is trial 21 with value: 1.288170432768558.
# [I 2026-07-06 23:03:38,982] Trial 22 finished with value: 1.366074723659721 and parameters: {'n_estimators': 1722, 'learning_rate': 0.06380721717117166, 'max_depth': 5, 'min_child_weight': 0.01746788199557318, 'gamma': 0.06903211330705528, 'subsample': 0.5220589300307791, 'colsample_bytree': 0.667636959283389, 'reg_alpha': 2.7268280876026274e-10, 'reg_lambda': 2.221013635134538}. Best is trial 21 with value: 1.288170432768558.
# [I 2026-07-06 23:03:44,871] Trial 23 finished with value: 1.3355293926591028 and parameters: {'n_estimators': 2568, 'learning_rate': 0.027967139759843804, 'max_depth': 3, 'min_child_weight': 0.10447428719706058, 'gamma': 1.2728590087898217, 'subsample': 0.607333053484852, 'colsample_bytree': 0.7386788162163644, 'reg_alpha': 0.023336753315326423, 'reg_lambda': 0.4188493982312238}. Best is trial 21 with value: 1.288170432768558.
# [I 2026-07-06 23:03:51,251] Trial 24 finished with value: 1.3635272034602623 and parameters: {'n_estimators': 2644, 'learning_rate': 0.030552696164343873, 'max_depth': 3, 'min_child_weight': 0.45875640788747596, 'gamma': 1.3371548567760048, 'subsample': 0.6343750130522289, 'colsample_bytree': 0.7494094144807486, 'reg_alpha': 8.621810410813608e-09, 'reg_lambda': 0.24495708233129926}. Best is trial 21 with value: 1.288170432768558.
# [I 2026-07-06 23:03:56,447] Trial 25 finished with value: 1.2837755109773923 and parameters: {'n_estimators': 3123, 'learning_rate': 0.017445966374136982, 'max_depth': 3, 'min_child_weight': 0.0895646103388434, 'gamma': 1.1815355171742383, 'subsample': 0.5114654059283691, 'colsample_bytree': 0.8273541932830581, 'reg_alpha': 0.0003235329426990888, 'reg_lambda': 3.281469702917626}. Best is trial 25 with value: 1.2837755109773923.
# [I 2026-07-06 23:04:03,988] Trial 26 finished with value: 1.3050871413853082 and parameters: {'n_estimators': 3450, 'learning_rate': 0.013687513328278444, 'max_depth': 4, 'min_child_weight': 0.29344276567089433, 'gamma': 0.003593667286866109, 'subsample': 0.5232113596887039, 'colsample_bytree': 0.8242487232680117, 'reg_alpha': 0.0001176747994653898, 'reg_lambda': 3.1936872501514557}. Best is trial 25 with value: 1.2837755109773923.
# [I 2026-07-06 23:04:12,368] Trial 27 finished with value: 1.260990863037691 and parameters: {'n_estimators': 3105, 'learning_rate': 0.010970065805800556, 'max_depth': 2, 'min_child_weight': 0.3753895650666246, 'gamma': 3.356104032612374, 'subsample': 0.5225257522816378, 'colsample_bytree': 0.8491830025747924, 'reg_alpha': 5.226252888226937e-05, 'reg_lambda': 4.757784218741634}. Best is trial 27 with value: 1.260990863037691.
# [I 2026-07-06 23:04:21,031] Trial 28 finished with value: 1.277137876330173 and parameters: {'n_estimators': 3085, 'learning_rate': 0.009663906695574619, 'max_depth': 2, 'min_child_weight': 0.09655271837713122, 'gamma': 3.8406165266364964, 'subsample': 0.4415937629789101, 'colsample_bytree': 0.92647275806587, 'reg_alpha': 1.4884253001486586e-10, 'reg_lambda': 5.402933209026566}. Best is trial 27 with value: 1.260990863037691.
# [I 2026-07-06 23:04:22,010] Trial 29 pruned.
# [I 2026-07-06 23:04:22,065] A new study created in RDB with name: KDAL_v11_remaining_warmup_base_lightgbm_mae_f
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-06 23:04:24,191] Trial 0 finished with value: 1.3626249325652553 and parameters: {'n_estimators': 447, 'learning_rate': 0.028873871707375695, 'num_leaves': 71, 'max_depth': 5, 'min_child_samples': 83, 'min_split_gain': 4.295687454742988, 'bagging_fraction': 0.7829586385137167, 'bagging_freq': 4, 'feature_fraction': 0.3688589858758342, 'lambda_l1': 0.06382334403151436, 'lambda_l2': 0.03080292177315921, 'huber_alpha': 0.95}. Best is trial 0 with value: 1.3626249325652553.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-06 23:04:29,567] Trial 1 finished with value: 1.7892687109402672 and parameters: {'n_estimators': 812, 'learning_rate': 0.009357081249483435, 'num_leaves': 164, 'max_depth': 2, 'min_child_samples': 211, 'min_split_gain': 4.244695738724308, 'bagging_fraction': 0.9814523094330022, 'bagging_freq': 3, 'feature_fraction': 0.9704172813206324, 'lambda_l1': 2.234088279028776e-05, 'lambda_l2': 1.6594154120142632, 'huber_alpha': 0.85}. Best is trial 0 with value: 1.3626249325652553.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-06 23:04:31,174] Trial 2 finished with value: 2.59619295968506 and parameters: {'n_estimators': 67, 'learning_rate': 0.02007090910723469, 'num_leaves': 246, 'max_depth': 10, 'min_child_samples': 245, 'min_split_gain': 4.543313789155439, 'bagging_fraction': 0.9415994992571017, 'bagging_freq': 4, 'feature_fraction': 0.41761231740559585, 'lambda_l1': 1.4824332354449863e-08, 'lambda_l2': 101.18939970488272, 'huber_alpha': 0.85}. Best is trial 0 with value: 1.

# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-06 23:06:12,709] Trial 23 finished with value: 1.2800139893330176 and parameters: {'n_estimators': 1287, 'learning_rate': 0.019844387523399364, 'num_leaves': 331, 'max_depth': 6, 'min_child_samples': 19, 'min_split_gain': 0.014082414370328838, 'bagging_fraction': 0.7368086990262468, 'bagging_freq': 3, 'feature_fraction': 0.4582587451598624, 'lambda_l1': 0.6909998908246285, 'lambda_l2': 0.0077354285454641685, 'huber_alpha': 0.95}. Best is trial 23 with value: 1.2800139893330176.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-06 23:06:26,808] Trial 24 finished with value: 1.2883043150792275 and parameters: {'n_estimators': 1323, 'learning_rate': 0.015508007978074194, 'num_leaves': 359, 'max_depth': 6, 'min_child_samples': 21, 'min_split_gain': 0.0450336867886135, 'bagging_fraction': 0.7515628882436379, 'bagging_freq': 3, 'feature_fraction': 0.45391734176751897, 'lambda_l1': 1.1959023966100844, 'lambda_l2': 0.008424816325523792, 'huber_alpha': 0.95}. Best is trial 23 with value: 1.2800139893330176.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-06 23:06:31,061] Trial 25 finished with value: 1.320525832930593 and parameters: {'n_estimators': 1366, 'learning_rate': 0.027033429995275145, 'num_leaves': 215, 'max_depth': 6, 'min_child_samples': 69, 'min_split_gain': 0.5531138273242822, 'bagging_fraction': 0.8665495766955374, 'bagging_freq': 1, 'feature_fraction': 0.5319752967768991, 'lambda_l1': 0.47563087840178925, 'lambda_l2': 0.00917789416994039, 'huber_alpha': 0.75}. Best is trial 23 with value: 1.2800139893330176.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-06 23:06:37,409] Trial 26 finished with value: 1.3079695373639797 and parameters: {'n_estimators': 2107, 'learning_rate': 0.012550419827702435, 'num_leaves': 429, 'max_depth': 8, 'min_child_samples': 17, 'min_split_gain': 1.1482831902440505, 'bagging_fraction': 0.6208274865145657, 'bagging_freq': 3, 'feature_fraction': 0.44358636651267336, 'lambda_l1': 2.6859061300448444, 'lambda_l2': 0.08350190263725474, 'huber_alpha': 0.9}. Best is trial 23 with value: 1.2800139893330176.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-06 23:06:40,411] Trial 27 finished with value: 1.3090025668843852 and parameters: {'n_estimators': 1424, 'learning_rate': 0.030730770832001528, 'num_leaves': 451, 'max_depth': 5, 'min_child_samples': 69, 'min_split_gain': 0.38994696647572236, 'bagging_fraction': 0.8051597366146143, 'bagging_freq': 3, 'feature_fraction': 0.5845024204395282, 'lambda_l1': 0.00038794493405317675, 'lambda_l2': 0.0009665497466332504, 'huber_alpha': 0.95}. Best is trial 23 with value: 1.2800139893330176.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-06 23:06:41,447] Trial 28 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-06 23:06:44,864] Trial 29 finished with value: 1.324365762638874 and parameters: {'n_estimators': 2055, 'learning_rate': 0.023362729579517252, 'num_leaves': 302, 'max_depth': 5, 'min_child_samples': 102, 'min_split_gain': 0.08412777031221076, 'bagging_fraction': 0.7588611050367274, 'bagging_freq': 2, 'feature_fraction': 0.35116603870998925, 'lambda_l1': 0.0003365466218612148, 'lambda_l2': 0.0042410316564729916, 'huber_alpha': 0.95}. Best is trial 23 with value: 1.2800139893330176.
# [I 2026-07-06 23:06:44,923] A new study created in RDB with name: KDAL_v11_remaining_warmup_base_catboost_mae_f
# [I 2026-07-06 23:15:55,570] Trial 0 finished with value: 1.7400979784800634 and parameters: {'iterations': 2931, 'learning_rate': 0.001783588943232587, 'depth': 10, 'l2_leaf_reg': 0.9942958882300413, 'random_strength': 7.186216756161439, 'bagging_temperature': 12.184767612363034, 'border_count': 110, 'rsm': 0.6158971964095841, 'huber_delta': 1.5}. Best is trial 0 with value: 1.7400979784800634.
# [I 2026-07-06 23:28:05,733] Trial 1 finished with value: 2.1756496969272967 and parameters: {'iterations': 801, 'learning_rate': 0.19767902101650964, 'depth': 12, 'l2_leaf_reg': 75.05056513807031, 'random_strength': 12.92821124806787, 'bagging_temperature': 4.276496242612171, 'border_count': 168, 'rsm': 0.4404450637901872, 'huber_delta': 1.0}. Best is trial 0 with value: 1.7400979784800634.
# [I 2026-07-06 23:28:22,670] Trial 2 finished with value: 1.6324716394396737 and parameters: {'iterations': 1992, 'learning_rate': 0.0024079350849750287, 'depth': 3, 'l2_leaf_reg': 0.118485976001343, 'random_strength': 4.058751860003342, 'bagging_temperature': 9.103785934457758, 'border_count': 206, 'rsm': 0.994034742637508, 'huber_delta': 0.5}. Best is trial 2 with value: 1.6324716394396737.
# [I 2026-07-06 23:50:39,741] Trial 3 finished with value: 2.024509501680703 and parameters: {'iterations': 3095, 'learning_rate': 0.05508623515899769, 'depth': 11, 'l2_leaf_reg': 18.082710740309665, 'random_strength': 13.948598364083836, 'bagging_temperature': 18.60205606816345, 'border_count': 227, 'rsm': 0.4117317891426977, 'huber_delta': 3.0}. Best is trial 2 with value: 1.6324716394396737.
# [I 2026-07-06 23:51:08,137] Trial 4 finished with value: 1.5066234567424017 and parameters: {'iterations': 3146, 'learning_rate': 0.0024764229908984673, 'depth': 3, 'l2_leaf_reg': 0.6951779671472356, 'random_strength': 6.148451176512449, 'bagging_temperature': 8.441103735088014, 'border_count': 95, 'rsm': 0.7192489923988105, 'huber_delta': 2.0}. Best is trial 4 with value: 1.5066234567424017.
# [I 2026-07-06 23:51:16,218] Trial 5 finished with value: 1.4439458454978982 and parameters: {'iterations': 2996, 'learning_rate': 0.04169299311145666, 'depth': 2, 'l2_leaf_reg': 0.6483636109972302, 'random_strength': 11.284989840243444, 'bagging_temperature': 11.881552589055849, 'border_count': 179, 'rsm': 0.7610806862514128, 'huber_delta': 0.5}. Best is trial 5 with value: 1.4439458454978982.
# [I 2026-07-06 23:51:17,419] Trial 6 pruned.
# [I 2026-07-06 23:51:23,527] Trial 7 finished with value: 1.5104371153787328 and parameters: {'iterations': 2269, 'learning_rate': 0.05988786419186062, 'depth': 3, 'l2_leaf_reg': 0.8727148674658863, 'random_strength': 13.785080578883292, 'bagging_temperature': 3.643240241026453, 'border_count': 16, 'rsm': 0.5239102067389221, 'huber_delta': 0.5}. Best is trial 5 with value: 1.4439458454978982.
# [I 2026-07-06 23:51:43,326] Trial 8 pruned.
# [I 2026-07-06 23:55:07,311] Trial 9 finished with value: 1.433917786786304 and parameters: {'iterations': 2176, 'learning_rate': 0.006973123504821021, 'depth': 7, 'l2_leaf_reg': 1.0111907140307084, 'random_strength': 19.613513312465464, 'bagging_temperature': 8.113717548278494, 'border_count': 208, 'rsm': 0.7899333278528806, 'huber_delta': 5.0}. Best is trial 9 with value: 1.433917786786304.
# [I 2026-07-06 23:56:30,118] Trial 10 pruned.
# [I 2026-07-06 23:57:31,393] Trial 11 finished with value: 1.3533795525764671 and parameters: {'iterations': 2772, 'learning_rate': 0.014522829031783214, 'depth': 5, 'l2_leaf_reg': 15.987388321276002, 'random_strength': 11.591109950971106, 'bagging_temperature': 7.790667047006705, 'border_count': 126, 'rsm': 0.7500006952294106, 'huber_delta': 5.0}. Best is trial 11 with value: 1.3533795525764671.
# [I 2026-07-06 23:58:38,797] Trial 12 pruned.
# [I 2026-07-06 23:58:44,361] Trial 13 pruned.
# [I 2026-07-06 23:58:52,995] Trial 14 finished with value: 1.4061180533577948 and parameters: {'iterations': 2033, 'learning_rate': 0.03406017942217813, 'depth': 3, 'l2_leaf_reg': 2.8273302406131626, 'random_strength': 2.5986858551767766, 'bagging_temperature': 5.630188860588947, 'border_count': 58, 'rsm': 0.9026140460549269, 'huber_delta': 1.0}. Best is trial 11 with value: 1.3533795525764671.
# [I 2026-07-06 23:59:07,688] Trial 15 finished with value: 1.3843229652081246 and parameters: {'iterations': 1315, 'learning_rate': 0.014385732536856719, 'depth': 5, 'l2_leaf_reg': 3.851734847884429, 'random_strength': 16.094365397211288, 'bagging_temperature': 5.889443951608335, 'border_count': 45, 'rsm': 0.9247512589809201, 'huber_delta': 5.0}. Best is trial 11 with value: 1.3533795525764671.
# [I 2026-07-06 23:59:14,508] Trial 16 pruned.
# [I 2026-07-07 00:01:44,598] Trial 17 finished with value: 1.3410659363283823 and parameters: {'iterations': 3466, 'learning_rate': 0.006277057772508926, 'depth': 6, 'l2_leaf_reg': 8.15026783421867, 'random_strength': 16.574794818938415, 'bagging_temperature': 1.3263969896774768, 'border_count': 147, 'rsm': 0.9160969794177436, 'huber_delta': 5.0}. Best is trial 17 with value: 1.3410659363283823.
# [I 2026-07-07 00:03:23,206] Trial 18 finished with value: 1.3953481754198234 and parameters: {'iterations': 2613, 'learning_rate': 0.004994299712769344, 'depth': 6, 'l2_leaf_reg': 13.631090697889816, 'random_strength': 17.124972126147984, 'bagging_temperature': 0.31515488633751154, 'border_count': 125, 'rsm': 0.8260109735014788, 'huber_delta': 5.0}. Best is trial 17 with value: 1.3410659363283823.
# [I 2026-07-07 00:09:22,738] Trial 19 finished with value: 1.4300584940157712 and parameters: {'iterations': 3472, 'learning_rate': 0.004501937745014823, 'depth': 8, 'l2_leaf_reg': 11.368163253677341, 'random_strength': 11.184394489768632, 'bagging_temperature': 2.3007263719374276, 'border_count': 149, 'rsm': 0.6950418748652112, 'huber_delta': 3.0}. Best is trial 17 with value: 1.3410659363283823.
# [I 2026-07-07 00:10:05,690] Trial 20 finished with value: 1.3729450851989324 and parameters: {'iterations': 3478, 'learning_rate': 0.019410928337830636, 'depth': 5, 'l2_leaf_reg': 7.7001667147105195, 'random_strength': 15.230008686860389, 'bagging_temperature': 2.521731951133892, 'border_count': 155, 'rsm': 0.8910683221416084, 'huber_delta': 2.0}. Best is trial 17 with value: 1.3410659363283823.
# [I 2026-07-07 00:10:43,029] Trial 21 finished with value: 1.3838003129812255 and parameters: {'iterations': 3368, 'learning_rate': 0.016814137239349623, 'depth': 5, 'l2_leaf_reg': 6.192427308840934, 'random_strength': 15.774251347671672, 'bagging_temperature': 2.5230716910799504, 'border_count': 158, 'rsm': 0.9092126910829951, 'huber_delta': 2.0}. Best is trial 17 with value: 1.3410659363283823.
# [I 2026-07-07 00
 'fit_intercept': False}. Best is trial 9 with value: 1.2778031652146409.
# [I 2026-07-07 00:19:49,662] Trial 20 finished with value: 1.2778032871865848 and parameters: {'feature_set': 'models_only', 'alpha': 45.296929575684835, 'fit_intercept': False}. Best is trial 9 with value: 1.2778031652146409.
# [I 2026-07-07 00:19:49,908] Trial 21 finished with value: 1.2785840141757236 and parameters: {'feature_set': 'models_only', 'alpha': 13.785426281269004, 'fit_intercept': False}. Best is trial 9 with value: 1.2778031652146409.
# [I 2026-07-07 00:19:50,173] Trial 22 finished with value: 1.4100417668787022 and parameters: {'feature_set': 'models_only', 'alpha': 53275.92412632527, 'fit_intercept': False}. Best is trial 9 with value: 1.2778031652146409.
# [I 2026-07-07 00:19:50,412] Trial 23 finished with value: 1.2782037714045305 and parameters: {'feature_set': 'models_only', 'alpha': 77.29571603447799, 'fit_intercept': False}. Best is trial 9 with value: 1.2778031652146409.
# [I 2026-07-07 00:19:50,640] Trial 24 finished with value: 1.280754690935712 and parameters: {'feature_set': 'models_only', 'alpha': 0.8846724392127512, 'fit_intercept': False}. Best is trial 9 with value: 1.2778031652146409.
# [I 2026-07-07 00:19:50,886] Trial 25 finished with value: 1.2810468691607038 and parameters: {'feature_set': 'models_only', 'alpha': 0.07002884365181197, 'fit_intercept': False}. Best is trial 9 with value: 1.2778031652146409.
# [I 2026-07-07 00:19:51,123] Trial 26 finished with value: 1.2787679520872224 and parameters: {'feature_set': 'models_only', 'alpha': 111.88066958238566, 'fit_intercept': False}. Best is trial 9 with value: 1.2778031652146409.
# [I 2026-07-07 00:19:51,371] Trial 27 finished with value: 1.2801329338945473 and parameters: {'feature_set': 'models_only', 'alpha': 3.322142946858887, 'fit_intercept': False}. Best is trial 9 with value: 1.2778031652146409.
# [I 2026-07-07 00:19:51,608] Trial 28 finished with value: 1.2853263856801218 and parameters: {'feature_set': 'models_only', 'alpha': 5095.789819776959, 'fit_intercept': False}. Best is trial 9 with value: 1.2778031652146409.
# [I 2026-07-07 00:19:51,875] Trial 29 finished with value: 1.2808380320609636 and parameters: {'feature_set': 'models_only', 'alpha': 404.99205590497166, 'fit_intercept': False}. Best is trial 9 with value: 1.2778031652146409.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# ...
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
#                   period           method  count     mae_f    rmse_f
# 0   validation_2024_2025          xgboost    730  1.263732  1.745490
# 1   validation_2024_2025         lightgbm    730  1.282426  1.783597
# 2   validation_2024_2025         catboost    730  1.332268  1.830981
# 3   validation_2024_2025    provider_mean    730  2.379282  3.156391
# 4   validation_2024_2025  provider_median    730  2.040450  2.894332
# 5   validation_2024_2025          nbm_raw    730  1.886852  2.762963
# 6   validation_2024_2025         hrrr_raw    730  4.545822  5.431401
# 7   validation_2024_2025          gfs_raw    730  2.652673  3.541885
# 8              test_2026          xgboost    171  1.343245  1.792567
# 9              test_2026         lightgbm    171  1.353914  1.801763
# 10             test_2026         catboost    171  1.374929  1.822929
# 11             test_2026      ridge_stack    171  1.337174  1.796257
# 12             test_2026    provider_mean    171  2.600430  3.319904
# 13             test_2026  provider_median    171  2.441380  3.225277
# 14             test_2026          nbm_raw    171  2.052396  2.798726
# 15             test_2026         hrrr_raw    171  4.947699  5.613634
# 16             test_2026          gfs_raw    171  2.562692  3.464403

# %%
exported_weights = export_station_model_weights(
    project_root=PROJECT_ROOT,
    station_id=STATION_ID,
    artifact_dir=config.resolved_output_dir(),
    model_version=MODEL_VERSION,
    timing_mode=config.timing_mode,
    providers=tuple(config.providers),
    feature_version=config.effective_feature_version,
    optuna_metric=config.effective_optuna_metric,
    target_mode=config.effective_target_mode,
    target_source=config.effective_target_source,
    base_model_methods=tuple(config.effective_base_model_methods),
    stack_enabled=config.stack_enabled,
    source_pipeline="notebooks/experiments/station_stacking_v11_settlement",
)

exported_weights.bundle_path, exported_weights.manifest_path
# Out:
# (WindowsPath('D:/dev/weather-research/data/calibration/station_stacking_v11_settlement/model_weights/KDAL_station_high_regressor_v11_wunderground_settlement_stack.joblib'),
#  WindowsPath('D:/dev/weather-research/data/calibration/station_stacking_v11_settlement/model_weights/KDAL_station_high_regressor_v11_wunderground_settlement_stack.json'))

# %% [markdown]
# ## V11 Feature Coverage

# %%
v11_feature_coverage = (
    result.features[V11_FEATURE_COLUMNS]
    .notna()
    .mean()
    .mul(100)
    .sort_values(ascending=False)
    .rename("coverage_pct")
    .reset_index()
    .rename(columns={"index": "feature"})
)

v11_feature_coverage
# Out:
#                                               feature  coverage_pct
# 0                              v2_spread_per_warmup_f    100.000000
# 1                    v2_morning_warmup_to_consensus_f    100.000000
# 2              v3_remaining_warmup_from_high_so_far_f    100.000000
# 3                      v3_high_so_far_above_current_f    100.000000
# 4                      v2_humidity_warmup_interaction    100.000000
# 5                        v4_forecast_wet_observed_dry    100.000000
# 6                   v4_forecast_observed_precip_match    100.000000
# 7                              v4_all_forecast_precip    100.000000
# 8            v3_humidity_remaining_warmup_interaction    100.000000
# 9                    v3_remaining_warmup_per_spread_f    100.000000
# 10                             v4_any_forecast_precip    100.000000
# 11                             v4_observed_precip_any    100.000000
# 12       observed_high_so_far_minus_climatology_10y_f    100.000000
# 13              observed_temp_minus_climatology_10y_f    100.000000
# 14                             climatology_high_10y_f    100.000000
# 15                         climatology_high_10y_std_f    100.000000
# 16                    v8_month_remaining_warmup_count    100.000000
# 17          v8_provider_spread_per_remaining_warmup_f    100.000000
# 18       v8_provider_min_remaining_from_high_so_far_f    100.000000
# 19    v8_provider_median_remaining_from_high_so_far_f    100.000000
# 20       v8_provider_max_remaining_from_high_so_far_f    100.000000
# 21            observed_high_so_far_change_since_9am_f    100.000000
# 22                     observed_temp_change_last_3h_f    100.000000
# 23            observed_morning_warmup_rate_f_per_hour    100.000000
# 24                     observed_temp_change_last_1h_f    100.000000
# 25                       v4_observed_wet_forecast_dry    100.000000
# 26              provider_mean_minus_climatology_10y_f    100.000000
# 27                         climatology_high_10y_count    100.000000
# 28                   v4_observed_precip_recent_mm_est     99.949950
# 29                     v2_consensus_minus_7d_actual_f     99.949950
# 30                          v2_recent_heat_momentum_f     99.949950
# 31                   v3_high_so_far_minus_7d_actual_f     99.949950
# 32                      v3_high_so_far_minus_lag_1d_f     99.949950
# 33                           v2_recent_heat_anomaly_f     99.949950
# 34               v8_recent_remaining_warmup_7d_mean_f     99.899900
# 35              v8_recent_remaining_warmup_30d_mean_f     99.749750
# 36       v8_provider_mean_remaining_vs_month_normal_f     98.798799
# 37                   v8_month_remaining_warmup_mean_f     98.798799
# 38      v8_dewpoint_mean_remaining_warmup_interaction     79.929930
# 39  v8_dewpoint_depression_remaining_warmup_intera...     79.929930
# 40                        v8_forecast_dewpoint_mean_f     79.929930
# 41             v8_forecast_dewpoint_depression_mean_f     79.929930
# 42             v4_precip_remaining_warmup_interaction     79.479479
# 43                   v4_forecast_precip_intensity_max     79.479479
# 44                   v4_forecast_precip_total_mean_mm     79.479479
# 45                    v4_forecast_precip_total_max_mm     79.479479
# 46                 v4_forecast_precip_total_spread_mm     79.479479
# 47                  v4_forecast_precip_max_1h_mean_mm     79.479479
# 48                      v4_forecast_precip_hours_mean     79.479479
# 49                  v4_forecast_precip_intensity_mean     79.479479
# 50       v8_precip_total_remaining_warmup_interaction     79.479479
# 51                     v4_precip_humidity_interaction     79.479479
# 52      v8_precip_max_1h_remaining_warmup_interaction     79.479479
# 53         v4_forecast_total_minus_observed_recent_mm     79.429429
# 54    v8_wind_speed_mean_remaining_warmup_interaction     36.186186
# 55      v8_wind_gust_max_remaining_warmup_interaction     36.186186
# 56    v8_cloud_cover_max_remaining_warmup_interaction      0.000000
# 57   v8_cloud_cover_mean_remaining_warmup_interaction      0.000000

# %%
result.feature_columns.loc[result.feature_columns["feature"].isin(V11_FEATURE_COLUMNS)]
# Out:
#                                                feature     kind
# 20                      observed_temp_change_last_1h_f  numeric
# 21                      observed_temp_change_last_3h_f  numeric
# 22             observed_morning_warmup_rate_f_per_hour  numeric
# 23             observed_high_so_far_change_since_9am_f  numeric
# 221                           v2_recent_heat_anomaly_f  numeric
# 222                          v2_recent_heat_momentum_f  numeric
# 223                   v2_morning_warmup_to_consensus_f  numeric
# 224                     v2_consensus_minus_7d_actual_f  numeric
# 225                             v2_spread_per_warmup_f  numeric
# 226                     v2_humidity_warmup_interaction  numeric
# 227                     v3_high_so_far_above_current_f  numeric
# 228             v3_remaining_warmup_from_high_so_far_f  numeric
# 229                      v3_high_so_far_minus_lag_1d_f  numeric
# 230                   v3_high_so_far_minus_7d_actual_f  numeric
# 231                   v3_remaining_warmup_per_spread_f  numeric
# 232           v3_humidity_remaining_warmup_interaction  numeric
# 233                   v4_forecast_precip_total_mean_mm  numeric
# 234                    v4_forecast_precip_total_max_mm  numeric
# 235                 v4_forecast_precip_total_spread_mm  numeric
# 236                  v4_forecast_precip_max_1h_mean_mm  numeric
# 237                      v4_forecast_precip_hours_mean  numeric
# 238                  v4_forecast_precip_intensity_mean  numeric
# 239                   v4_forecast_precip_intensity_max  numeric
# 240                             v4_any_forecast_precip  numeric
# 241                             v4_all_forecast_precip  numeric
# 242                             v4_observed_precip_any  numeric
# 243                   v4_observed_precip_recent_mm_est  numeric
# 244         v4_forecast_total_minus_observed_recent_mm  numeric
# 245                  v4_forecast_observed_precip_match  numeric
# 246                       v4_forecast_wet_observed_dry  numeric
# 247                       v4_observed_wet_forecast_dry  numeric
# 248                     v4_precip_humidity_interaction  numeric
# 249             v4_precip_remaining_warmup_interaction  numeric
# 250       v8_provider_max_remaining_from_high_so_far_f  numeric
# 251       v8_provider_min_remaining_from_high_so_far_f  numeric
# 252    v8_provider_median_remaining_from_high_so_far_f  numeric
# 253          v8_provider_spread_per_remaining_warmup_f  numeric
# 254                   v8_month_remaining_warmup_mean_f  numeric
# 255                    v8_month_remaining_warmup_count  numeric
# 256               v8_recent_remaining_warmup_7d_mean_f  numeric
# 257              v8_recent_remaining_warmup_30d_mean_f  numeric
# 258       v8_provider_mean_remaining_vs_month_normal_f  numeric
# 259       v8_precip_total_remaining_warmup_interaction  numeric
# 260      v8_precip_max_1h_remaining_warmup_interaction  numeric
# 261    v8_wind_speed_mean_remaining_warmup_interaction  numeric
# 262      v8_wind_gust_max_remaining_warmup_interaction  numeric
# 263                        v8_forecast_dewpoint_mean_f  numeric
# 264             v8_forecast_dewpoint_depression_mean_f  numeric
# 265      v8_dewpoint_mean_remaining_warmup_interaction  numeric
# 266  v8_dewpoint_depression_remaining_warmup_intera...  numeric
# 267                             climatology_high_10y_f  numeric
# 268                         climatology_high_10y_std_f  numeric
# 269                         climatology_high_10y_count  numeric
# 270              provider_mean_minus_climatology_10y_f  numeric
# 271              observed_temp_minus_climatology_10y_f  numeric
# 272       observed_high_so_far_minus_climatology_10y_f  numeric

# %% [markdown]
# ## Dropped Feature Check

# %%
dropped_present = result.feature_columns.loc[
    result.feature_columns["feature"].isin(V11_DROPPED_FEATURE_COLUMNS)
]

dropped_present
# Out:
# Empty DataFrame
# Columns: [feature, kind]
# Index: []

# %% [markdown]
# ## Morning Trend Coverage

# %%
trend_coverage = (
    result.features[TREND_COLUMNS]
    .notna()
    .mean()
    .mul(100)
    .sort_values(ascending=False)
    .rename("coverage_pct")
    .reset_index()
    .rename(columns={"index": "feature"})
)

trend_coverage
# Out:
#                                    feature  coverage_pct
# 0           observed_temp_change_last_1h_f         100.0
# 1           observed_temp_change_last_3h_f         100.0
# 2  observed_morning_warmup_rate_f_per_hour         100.0
# 3  observed_high_so_far_change_since_9am_f         100.0

# %% [markdown]
# ## Rounded Within 1F Accuracy

# %%
preds = pd.concat(
    [
        result.validation_predictions.assign(period="validation_2024_2025"),
        result.test_predictions.assign(period="oof_2026"),
    ],
    ignore_index=True,
)

predicted_high = pd.to_numeric(preds["predicted_high_f"], errors="coerce")
preds["predicted_high_rounded_f"] = np.floor(predicted_high + 0.5)
preds["within_1f_after_round"] = (
    pd.to_numeric(preds["actual_high_f"], errors="coerce") - preds["predicted_high_rounded_f"]
).abs().le(1)

within_1f_accuracy_by_period = (
    preds
    .dropna(subset=["actual_high_f", "predicted_high_rounded_f"])
    .groupby(["period", "method"], as_index=False)
    .agg(
        count=("within_1f_after_round", "size"),
        within_1f_count=("within_1f_after_round", "sum"),
        within_1f_accuracy_pct=("within_1f_after_round", lambda x: x.mean() * 100),
    )
    .sort_values(["period", "within_1f_accuracy_pct"], ascending=[True, False])
)

within_1f_accuracy_by_period
# Out:
#                   period           method  count  within_1f_count  \
# 8               oof_2026          xgboost    171              117
# 7               oof_2026      ridge_stack    171              115
# 3               oof_2026         lightgbm    171              111
# 0               oof_2026         catboost    171              108
# 4               oof_2026          nbm_raw    171               84
# 1               oof_2026          gfs_raw    171               69
# 6               oof_2026  provider_median    171               69
# 5               oof_2026    provider_mean    171               57
# 2               oof_2026         hrrr_raw    171               17
# 16  validation_2024_2025          xgboost    730              499
# 12  validation_2024_2025         lightgbm    730              492
# 9   validation_2024_2025         catboost    730              484
# 13  validation_2024_2025          nbm_raw    730              387
# 15  validation_2024_2025  provider_median    730              348
# 14  validation_2024_2025    provider_mean    730              261
# 10  validation_2024_2025          gfs_raw    730              256
# 11  validation_2024_2025         hrrr_raw    730              126
#
#     within_1f_accuracy_pct
# 8                68.421053
# 7                67.251462
# 3                64.912281
# 0                63.157895
# 4                49.122807
# 1                40.350877
# 6                40.350877
# 5                33.333333
# 2                 9.941520
# 16               68.356164
# 12               67.397260
# 9                66.301370
# 13               53.013699
# 15               47.671233
# 14               35.753425
# 10               35.068493
# 11               17.260274

# %% [markdown]
# ## Version Comparison

# %%
comparison_frames = []
for version, folder in [
    ("v1", PROJECT_ROOT / "data" / "calibration" / "station_stacking"),
    ("v2", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v2"),
    ("v3", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v3"),
    ("v4", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v4"),
    ("v5", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v5"),
    ("v6", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v6"),
    ("v7", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v7"),
    ("v8", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v8"),
    ("v9", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v9"),
    ("v10", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v10"),
    ("v11", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v11"),
]:
    path = folder / f"{STATION_ID}_year_split_scoreboard.csv"
    if path.exists():
        frame = pd.read_csv(path)
        frame["version"] = version
        comparison_frames.append(frame)

version_comparison = pd.concat(comparison_frames, ignore_index=True) if comparison_frames else pd.DataFrame()
if not version_comparison.empty:
    version_comparison = version_comparison.sort_values(["period", "mae_f", "version", "method"]).reset_index(drop=True)
version_comparison
# Out:
#                   period       method  count     mae_f    rmse_f version
# 0              test_2026  ridge_stack    138  1.369446  1.890651      v9
# 1              test_2026      xgboost    138  1.402066  1.889472     v11
# 2              test_2026      xgboost    138  1.419940  1.895994      v9
# 3              test_2026  ridge_stack    138  1.429989  1.907881     v11
# 4              test_2026     lightgbm    138  1.454606  1.932482     v11
# ..                   ...          ...    ...       ...       ...     ...
# 83  validation_2024_2025     hrrr_raw    660  5.477361  6.266007      v3
# 84  validation_2024_2025     hrrr_raw    668  5.486824  6.274688      v7
# 85  validation_2024_2025     hrrr_raw    606  5.497186  6.283967      v5
# 86  validation_2024_2025     hrrr_raw    606  5.497186  6.283967      v6
# 87  validation_2024_2025     hrrr_raw    623  5.564150  6.352240      v1
#
# [88 rows x 6 columns]

# %% [markdown]
# ## 2026 OOF Weather Brackets

# %%
result.bracket_metrics
# Out:
#             method  count     mae_f    rmse_f  bracket_accuracy_pct
# 0          xgboost    171  1.343245  1.792567              45.02924
# 1         lightgbm    171  1.353914  1.801763             45.614035
# 2         catboost    171  1.374929  1.822929             39.766082
# 3      ridge_stack    171  1.337174  1.796257             47.368421
# 4    provider_mean    171  2.600430  3.319904             23.391813
# 5  provider_median    171  2.441380  3.225277             22.807018
# 6          nbm_raw    171  2.052396  2.798726             33.918129
# 7         hrrr_raw    171  4.947699  5.613634              5.263158
# 8          gfs_raw    171  2.562692  3.464403             26.900585
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

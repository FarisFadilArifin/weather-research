# %% [markdown]
# # Station Stacking v18.1 RAP Wunderground Ablation - KATL
#
# Experimental notebook for `KATL`.
#
# This v18.1 RAP ablation keeps the v11 remaining-warmup ridge-stack backbone, requires Wunderground station-history labels, and adds only the coverage-gated RAP physics and station-specific physics shard features. It writes isolated artifacts to `data/calibration/station_stacking_v18_1_rap`.

# %%
from pathlib import Path
import os
import sys
import warnings

warnings.filterwarnings("ignore", message="IProgress not found.*")
warnings.filterwarnings("ignore", message="Skipping features without any observed values.*")

PROJECT_ROOT = Path.cwd().resolve()
while not (PROJECT_ROOT / "src" / "calibration" / "station_stacking.py").exists():
    if PROJECT_ROOT.parent == PROJECT_ROOT:
        raise RuntimeError("Could not find project root containing src/calibration/station_stacking.py")
    PROJECT_ROOT = PROJECT_ROOT.parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

os.environ["WEATHER_RESEARCH_INCLUDE_DIRECT_NBM"] = "1"

STATION_ID = "KATL"
PROVIDERS = ("gfs", "hrrr", "nbm")
TREND_COLUMNS = [
    "observed_temp_change_last_1h_f",
    "observed_temp_change_last_3h_f",
    "observed_morning_warmup_rate_f_per_hour",
    "observed_high_so_far_change_since_9am_f",
]
TIMING_MODE = "same_day_11am_live_safe"
FAST_MODE = False
OPTUNA_TRIALS = 100
STACK_OPTUNA_TRIALS = 100
OPTUNA_STARTUP_TRIALS = 40
STACK_OPTUNA_STARTUP_TRIALS = 40
OPTUNA_METRIC = "mae_f"
OPTUNA_VERBOSE = True
MODEL_VERSION = "station_high_regressor_v18_1_rap_physics_settlement_stack"
PROJECT_ROOT
# Out:
# WindowsPath('D:/dev/weather-research')

# %%
import numpy as np
import pandas as pd

from src.export_station_stacking_v2_models import export_station_model_weights
from src.calibration.station_stacking import (
    StationStackingConfig,
    V11_DROPPED_FEATURE_COLUMNS,
    V11_FEATURE_COLUMNS,
    YEAR_SPLIT_EXPANDING_FOLDS,
    missing_model_dependencies,
    provider_availability,
    run_station_year_split_experiment,
)

# %% [markdown]
# ## V11 Contract
#
# `feature_version="v18_1_rap"` adds only the coverage-gated RAP physics and station-specific physics shard features while selecting by validation MAE.

# %%
fold_spec = pd.DataFrame(
    [
        {
            "fold": fold.name,
            "train_start_year": fold.train_start_year,
            "train_end_year": fold.train_end_year,
            "validation_year": fold.validation_year,
        }
        for fold in YEAR_SPLIT_EXPANDING_FOLDS
    ]
)

fold_spec
# Out:
#                      fold  train_start_year  train_end_year  validation_year
# 0  fold_2021_2023_to_2024              2021            2023             2024
# 1  fold_2021_2024_to_2025              2021            2024             2025

# %%
V11_FEATURE_COLUMNS, sorted(V11_DROPPED_FEATURE_COLUMNS)
# Out:
# (['v2_recent_heat_anomaly_f',
#   'v2_recent_heat_momentum_f',
#   'v2_morning_warmup_to_consensus_f',
#   'v2_consensus_minus_7d_actual_f',
#   'v2_spread_per_warmup_f',
#   'v2_humidity_warmup_interaction',
#   'v3_high_so_far_above_current_f',
#   'v3_remaining_warmup_from_high_so_far_f',
#   'v3_high_so_far_minus_lag_1d_f',
#   'v3_high_so_far_minus_7d_actual_f',
#   'v3_remaining_warmup_per_spread_f',
#   'v3_humidity_remaining_warmup_interaction',
#   'v4_forecast_precip_total_mean_mm',
#   'v4_forecast_precip_total_max_mm',
#   'v4_forecast_precip_total_spread_mm',
#   'v4_forecast_precip_max_1h_mean_mm',
#   'v4_forecast_precip_hours_mean',
#   'v4_forecast_precip_intensity_mean',
#   'v4_forecast_precip_intensity_max',
#   'v4_any_forecast_precip',
#   'v4_all_forecast_precip',
#   'v4_observed_precip_any',
#   'v4_observed_precip_recent_mm_est',
#   'v4_forecast_total_minus_observed_recent_mm',
#   'v4_forecast_observed_precip_match',
#   'v4_forecast_wet_observed_dry',
#   'v4_observed_wet_forecast_dry',
#   'v4_precip_humidity_interaction',
#   'v4_precip_remaining_warmup_interaction',
#   'observed_temp_change_last_1h_f',
#   'observed_temp_change_last_3h_f',
#   'observed_morning_warmup_rate_f_per_hour',
#   'observed_high_so_far_change_since_9am_f',
#   'v8_provider_max_remaining_from_high_so_far_f',
#   'v8_provider_min_remaining_from_high_so_far_f',
#   'v8_provider_median_remaining_from_high_so_far_f',
#   'v8_provider_spread_per_remaining_warmup_f',
#   'v8_month_remaining_warmup_mean_f',
#   'v8_month_remaining_warmup_count',
#   'v8_recent_remaining_warmup_7d_mean_f',
#   'v8_recent_remaining_warmup_30d_mean_f',
#   'v8_provider_mean_remaining_vs_month_normal_f',
#   'v8_cloud_cover_mean_remaining_warmup_interaction',
#   'v8_cloud_cover_max_remaining_warmup_interaction',
#   'v8_precip_total_remaining_warmup_interaction',
#   'v8_precip_max_1h_remaining_warmup_interaction',
#   'v8_wind_speed_mean_remaining_warmup_interaction',
#   'v8_wind_gust_max_remaining_warmup_interaction',
#   'v8_forecast_dewpoint_mean_f',
#   'v8_forecast_dewpoint_depression_mean_f',
#   'v8_dewpoint_mean_remaining_warmup_interaction',
#   'v8_dewpoint_depression_remaining_warmup_interaction',
#   'climatology_high_10y_f',
#   'climatology_high_10y_std_f',
#   'climatology_high_10y_count',
#   'provider_mean_minus_climatology_10y_f',
#   'observed_temp_minus_climatology_10y_f',
#   'observed_high_so_far_minus_climatology_10y_f'],
#  ['actual_minus_climatology_10y_f_DIAGNOSTIC_ONLY',
#   'climatology_source_end_year',
#   'climatology_source_start_year',
#   'gfs_as_of_hour_local',
#   'gfs_available',
#   'gfs_forecast_window_hours',
#   'gfs_grid_dist_km_mean',
#   'gfs_horizon_hours',
#   'gfs_hrrr_grid_dist_km_mean_abs_diff_f',
#   'gfs_hrrr_grid_dist_km_mean_diff_f',
#   'gfs_issue_hour_utc',
#   'gfs_missing',
#   'hrrr_as_of_hour_local',
#   'hrrr_available',
#   'hrrr_forecast_hour_max',
#   'hrrr_forecast_hour_min',
#   'hrrr_forecast_lead_hours',
#   'hrrr_forecast_window_hours',
#   'hrrr_grid_dist_km_mean',
#   'hrrr_horizon_hours',
#   'hrrr_issue_hour_local',
#   'hrrr_issue_hour_utc',
#   'hrrr_missing',
#   'is_active_polymarket_station',
#   'lat',
#   'lon',
#   'nbm_as_of_hour_local',
#   'nbm_available',
#   'nbm_forecast_window_hours',
#   'nbm_horizon_hours',
#   'nbm_issue_hour_local',
#   'nbm_issue_hour_utc',
#   'nbm_missing',
#   'observed_fetch_status',
#   'observed_observation_type',
#   'observed_pressure_source',
#   'provider_count_available',
#   'year'])

# %% [markdown]
# ## Data Availability

# %%
availability = provider_availability(
    PROJECT_ROOT,
    timing_mode=TIMING_MODE,
    providers=PROVIDERS,
)

availability.loc[availability["station_id"].eq(STATION_ID)]
# Out:
#   station_id provider  row_count first_contract_date last_contract_date
# 0       KATL      gfs       1998          2021-01-01         2026-06-21
# 1       KATL     hrrr       1998          2021-01-01         2026-06-21
# 2       KATL      nbm       1997          2021-01-01         2026-06-21

# %% [markdown]
# ## Model Scores

# %%
missing_packages = missing_model_dependencies()
if missing_packages:
    raise ImportError(
        "Missing station-stacking ML packages: "
        + ", ".join(missing_packages)
        + ". Install them with: python -m pip install -r requirements.txt"
    )

config = StationStackingConfig(
    station_id=STATION_ID,
    project_root=PROJECT_ROOT,
    timing_mode=TIMING_MODE,
    providers=PROVIDERS,
    fast_mode=FAST_MODE,
    optuna_trials=OPTUNA_TRIALS,
    stack_optuna_trials=STACK_OPTUNA_TRIALS,
    optuna_startup_trials=OPTUNA_STARTUP_TRIALS,
    stack_optuna_startup_trials=STACK_OPTUNA_STARTUP_TRIALS,
    optuna_metric=OPTUNA_METRIC,
    optuna_verbose=OPTUNA_VERBOSE,
    feature_version="v18_1_rap",
    target_mode="remaining_warmup",
    target_source="wunderground_only",
    base_model_methods=("xgboost", "lightgbm", "catboost"),
    stack_enabled=True,
    hyperparameter_space="wide_plus",
    year_split_folds=YEAR_SPLIT_EXPANDING_FOLDS,
    year_split_test_train_years=(2021, 2025),
    year_split_test_year=2026,
    output_dir=PROJECT_ROOT / "data" / "calibration" / "station_stacking_v18_1_rap",
)

config.resolved_optuna_storage_path()
# Out:
# WindowsPath('D:/dev/weather-research/data/calibration/station_stacking_v18_1_rap/KATL_optuna.sqlite3')

# %%
result = run_station_year_split_experiment(config)
result.scoreboard
# Out:
# [I 2026-07-10 06:09:51,391] A new study created in RDB with name: KATL_v18_1_rap_remaining_warmup_base_xgboost_mae_f_wide_plus
# [I 2026-07-10 06:09:55,655] Trial 0 finished with value: 1.551900287704524 and parameters: {'n_estimators': 2278, 'learning_rate': 0.18404304074388048, 'max_depth': 9, 'min_child_weight': 2.481040974867813, 'gamma': 2.340279606636548, 'subsample': 0.4513964382185317, 'colsample_bytree': 0.3877543479093296, 'reg_alpha': 2.478071022662141, 'reg_lambda': 0.6132587025321562}. Best is trial 0 with value: 1.551900287704524.
# [I 2026-07-10 06:10:16,149] Trial 1 finished with value: 1.4094417857916155 and parameters: {'n_estimators': 4263, 'learning_rate': 0.0005682336350005583, 'max_depth': 12, 'min_child_weight': 21.368329072358772, 'gamma': 3.185086660174142, 'subsample': 0.4681862286846154, 'colsample_bytree': 0.46921293140473197, 'reg_alpha': 4.476173538513514e-07, 'reg_lambda': 0.20253776634919213}. Best is trial 1 with value: 1.4094417857916155.
# [I 2026-07-10 06:10:22,093] Trial 2 finished with value: 1.2976593967027812 and parameters: {'n_estimators': 2620, 'learning_rate': 0.0030548417550612453, 'max_depth': 8, 'min_child_weight': 0.03613894271216528, 'gamma': 4.3821697280282725, 'subsample': 0.5881351981408995, 'colsample_bytree': 0.6464454897410734, 'reg_alpha': 0.26430874752361627, 'reg_lambda': 0.0018119678627933364}. Best is trial 2 with value: 1.2976593967027812.
# [I 2026-07-10 06:10:26,510] Trial 3 finished with value: 1.5582847596161984 and parameters: {'n_estimators': 3110, 'learning_rate': 0.019855423553962363, 'max_depth': 1, 'min_child_weight': 2.69264691008618, 'gamma': 2.557861855309373, 'subsample': 0.39228353544043165, 'colsample_bytree': 0.9667755992146666, 'reg_alpha': 38.6887231523051, 'reg_lambda': 12.408975837016275}. Best is trial 2 with value: 1.2976593967027812.
# [I 2026-07-10 06:10:40,420] Trial 4 finished with value: 1.3886433714505817 and parameters: {'n_estimators': 1862, 'learning_rate': 0.0009174536024527723, 'max_depth': 9, 'min_child_weight': 0.5762487216478605, 'gamma': 1.8305735226716824, 'subsample': 0.6718649915723256, 'colsample_bytree': 0.37235253872489193, 'reg_alpha': 8.162906555194692, 'reg_lambda': 0.004271500153828077}. Best is trial 2 with value: 1.2976593967027812.
# [I 2026-07-10 06:11:00,839] Trial 5 finished with value: 1.3924191230818952 and parameters: {'n_estimators': 3992, 'learning_rate': 0.0034695156333098714, 'max_depth': 7, 'min_child_weight': 1.5375920235481764, 'gamma': 2.7728168328829055, 'subsample': 0.980230008046963, 'colsample_bytree': 0.8538363351847245, 'reg_alpha': 18.792618557420877, 'reg_lambda': 43.484449457612314}. Best is trial 2 with value: 1.2976593967027812.
# [I 2026-07-10 06:11:02,163] Trial 6 finished with value: 1.2945029862475839 and parameters: {'n_estimators': 3608, 'learning_rate': 0.15384412371507689, 'max_depth': 2, 'min_child_weight': 0.06080390190296603, 'gamma': 0.678409333658071, 'subsample': 0.5614647149961218, 'colsample_bytree': 0.6026402382981633, 'reg_alpha': 1.8037999945880162e-07, 'reg_lambda': 16.668629892722056}. Best is trial 6 with value: 1.2945029862475839.
# [I 2026-07-10 06:11:08,144] Trial 7 finished with value: 1.3571209950476535 and parameters: {'n_estimators': 2173, 'learning_rate': 0.0028655224755223816, 'max_depth': 7, 'min_child_weight': 0.0366181922039243, 'gamma': 12.032954711310595, 'subsample': 0.398457918391851, 'colsample_bytree': 0.9914765087903362, 'reg_alpha': 0.18490013641000916, 'reg_lambda': 0.0017869543989965139}. Best is trial 6 with value: 1.2945029862475839.
# [I 2026-07-10 06:11:08,736] Trial 8 pruned.
# [I 2026-07-10 06:11:16,758] Trial 9 finished with value: 1.2854092766799163 and parameters: {'n_estimators': 3759, 'learning_rate': 0.003908893589205689, 'max_depth': 1, 'min_child_weight': 0.17535949529764422, 'gamma': 4.877749830401205, 'subsample': 0.8242440159197416, 'colsample_bytree': 0.7644123563808884, 'reg_alpha': 4.4315220126915325, 'reg_lambda': 0.09450187118503514}. Best is trial 9 with value: 1.2854092766799163.
# [I 2026-07-10 06:11:17,482] Trial 10 pruned.
# [I 2026-07-10 06:11:22,341] Trial 11 pruned.
# [I 2026-07-10 06:11:27,194] Trial 12 pruned.
# [I 2026-07-10 06:11:27,769] Trial 13 pruned.
# [I 2026-07-10 06:11:29,505] Trial 14 finished with value: 1.3135913529259349 and parameters: {'n_estimators': 4918, 'learning_rate': 0.10520976010930978, 'max_depth': 1, 'min_child_weight': 1.1040511903162256, 'gamma': 6.261165047231685, 'subsample': 0.49437007680597467, 'colsample_bytree': 0.4279124887668938, 'reg_alpha': 1.125594744942969e-06, 'reg_lambda': 87.35792858155622}. Best is trial 9 with value: 1.2854092766799163.
# [I 2026-07-10 06:11:30,754] Trial 15 pruned.
# [I 2026-07-10 06:11:54,472] Trial 16 finished with value: 1.235328662495178 and parameters: {'n_estimators': 1745, 'learning_rate': 0.0006288206118124717, 'max_depth': 8, 'min_child_weight': 1.0249816559563216, 'gamma': 0.7721812687498403, 'subsample': 0.5311202017537975, 'colsample_bytree': 0.9403728258783249, 'reg_alpha': 7.494500415302305e-08, 'reg_lambda': 0.0008184401669032867}. Best is trial 16 with value: 1.235328662495178.
# [I 2026-07-10 06:11:55,032] Trial 17 pruned.
# [I 2026-07-10 06:11:58,617] Trial 18 finished with value: 1.300061170605527 and parameters: {'n_estimators': 3820, 'learning_rate': 0.013963998893741949, 'max_depth': 2, 'min_child_weight': 21.938654178115062, 'gamma': 4.811700974576038, 'subsample': 0.4712370317599052, 'colsample_bytree': 0.3765038420105965, 'reg_alpha': 0.0012322967930262527, 'reg_lambda': 1.859316691031827}. Best is trial 16 with value: 1.235328662495178.
# [I 2026-07-10 06:11:59,504] Trial 19 pruned.
# [I 2026-07-10 06:12:06,637] Trial 20 pruned.
# [I 2026-07-10 06:12:10,032] Trial 21 pruned.
# [I 2026-07-10 06:12:11,321] Trial 22 pruned.
# [I 2026-07-10 06:12:25,756] Trial 23 finished with value: 1.324223058946992 and parameters: {'n_estimators': 3998, 'learning_rate': 0.0005159778604125024, 'max_depth': 2, 'min_child_weight': 1.566517163094647, 'gamma': 10.378427965390399, 'subsample': 0.7737748186766904, 'colsample_bytree': 0.4957750511493638, 'reg_alpha': 0.03516824175268894, 'reg_lambda': 0.003125457636899047}. Best is trial 16 with value: 1.235328662495178.
# [I 2026-07-10 06:12:27,133] Trial 24 finished with value: 1.325658825812734 and parameters: {'n_estimators': 1986, 'learning_rate': 0.051728265370804466, 'max_depth': 8, 'min_child_weight': 24.939838794891504, 'gamma': 9.86419338450515, 'subsample': 0.7194005921680565, 'colsample_bytree': 0.4108885990882601, 'reg_alpha': 2.5857684771732316e-06, 'reg_lambda': 0.0046886527972766386}. Best is trial 16 with value: 1.235328662495178.
# [I 2026-07-10 06:12:28,317] Trial 25 finished with value: 1.3006473645626873 and parameters: {'n_estimators': 1501, 'learning_rate': 0.21139577614731828, 'max_depth': 5, 'min_child_weight': 36.99867920489091, 'gamma': 9.467079389958943, 'subsample': 0.8666273473020715, 'colsample_bytree': 0.6767141105183749, 'reg_alpha': 0.0008372335350726891, 'reg_lambda': 0.12687286940538833}. Best is trial 16 with value: 1.235328662495178.
# [I 2026-07-10 06:12:29,476] Trial 26 pruned.
# [I 2026-07-10 06:12:48,771] Trial 27 finished with value: 1.28172311847248 and parameters: {'n_estimators': 2252, 'learning_rate': 0.0005504108022880858, 'max_depth': 12, 'min_child_weight': 0.5161032492347074, 'gamma': 14.499822285655043, 'subsample': 0.9763529851080144, 'colsample_bytree': 0.904456146053784, 'reg_alpha': 3.414968521807482e-07, 'reg_lambda': 0.026700066263292452}. Best is trial 16 with value: 1.235328662495178.
# [I 2026-07-10 06:12:53,567] Trial 28 finished with value: 1.2625894922405598 and parameters: {'n_estimators': 5115, 'learning_rate': 0.0035837110844026934, 'max_depth': 3, 'min_child_weight': 1.687349510456895, 'gamma': 14.042321612411715, 'subsample': 0.8024193678387325, 'colsample_bytree': 0.7205397605580872, 'reg_alpha': 1.4659458394743598e-09, 'reg_lambda': 0.7502033220845526}. Best is trial 16 with value: 1.235328662495178.
# [I 2026-07-10 06:13:17,997] Trial 29 finished with value: 1.299040283992697 and parameters: {'n_estimators': 5941, 'learning_rate': 0.001194132613025411, 'max_depth': 7, 'min_child_weight': 32.32155805617899, 'gamma': 11.111529266313067, 'subsample': 0.8030602316469242, 'colsample_bytree': 0.8066146545916211, 'reg_alpha': 2.0601261491259473e-06, 'reg_lambda': 0.007078333440672503}. Best is trial 16 with value: 1.235328662495178.
# [I 2026-07-10 06:13:19,092] Trial 30 pruned.
# [I 2026-07-10 06:13:19,801] Trial 31 pruned.
# [I 2026-07-10 06:13:23,109] Trial 32 finished with value: 1.288673741435366 and parameters: {'n_estimators': 1755, 'learning_rate': 0.01966125573748198, 'max_depth': 1, 'min_child_weight': 0.014105638677535273, 'gamma': 12.339008409894873, 'subsample': 0.5841239169173209, 'colsample_bytree': 0.43258933322372506, 'reg_alpha': 0.0001848924258849832, 'reg_lambda': 7.108082741221897}. Best is trial 16 with value: 1.235328662495178.
# [I 2026-07-10 06:13:25,563] Trial 33 pruned.
# [I 2026-07-10 06:13:30,449] Trial 34 pruned.
# [I 2026-07-10 06:13:32,363] Trial 35 pruned.
# [I 2026-07-10 06:13:34,107] Trial 36 finished with value: 1.2770103748147767 and parameters: {'n_estimators': 5732, 'learning_rate': 0.04903787573670302, 'max_depth': 7, 'min_child_weight': 2.7982272717049295, 'gamma': 6.2940009364168485, 'subsample': 0.5110251431757523, 'colsample_bytree': 0.58138224112332, 'reg_alpha': 0.12420907443411108, 'reg_lambda': 0.00012322357473726174}. Best is trial 16 with value: 1.235328662495178.
# [I 2026-07-10 06:13:35,264] Trial 37 pruned.
# [I 2026-07-10 06:13:39,506] Trial 38 finished with value: 1.2460179396693005 and parameters: {'n_estimators': 1080, 'learning_rate': 0.0074117812297848015, 'max_depth': 5, 'min_child_weight': 2.9067012153229124, 'gamma': 9.526404763014657, 'subsample': 0.3794476063518289, 'colsample_bytree': 0.5934981995072063, 'reg_alpha': 0.0032383142323839692, 'reg_lambda': 0.14800509200124298}. Best is trial 16 with value: 1.235328662495178.
# [I 2026-07-10 06:13:40,517] Trial 39 pruned.
# [I 2026-07-10 06:13:51,067] Trial 40 finished with value: 1.2388523213453715 and parameters: {'n_estimators': 5645, 'learning_rate': 0.0017360316408241015, 'max_depth': 6, 'min_child_weight': 11.097142071326635, 'gamma': 8.484196360221048, 'subsample': 0.6306066176559424, 'colsample_bytree': 0.5444200153094431, 'reg_alpha': 5.549111761517157e-09, 'reg_lambda': 0.00016788579373558398}. Best is trial 16 with value: 1.235328662495178.
# [I 2026-07-10 06:13:59,461] Trial 41 finished with value: 1.2346925743768746 and parameters: {'n_estimators': 5955, 'learning_rate': 0.001940398130567705, 'max_depth': 6, 'min_child_weight': 6.680276826942007, 'gamma': 8.684004615256931, 'subsample': 0.6268151874865276, 'colsample_bytree': 0.5565187219844878, 'reg_alpha': 6.316156783485229e-09, 'reg_lambda': 0.00012029085274438112}. Best is trial 41 with value: 1.2346925743768746.
# [I 2026-07-10 06:14:12,998] Trial 42 finished with value: 1.2436254689158497 and parameters: {'n_estimators': 5409, 'learning_rate': 0.001575691880614687, 'max_depth': 6, 'min_child_weight': 12.792880591368833, 'gamma': 8.352878319687537, 'subsample': 0.6260511048943505, 'colsample_bytree': 0.6290792927179508, 'reg_alpha': 1.0428437019374575e-08, 'reg_lambda': 0.0004071091570844169}. Best is trial 41 with value: 1.2346925743768746.
# [I 2026-07-10 06:14:13,496] Trial 43 pruned.
# [I 2026-07-10 06:14:22,770] Trial 44 finished with value: 1.2411878615924676 and parameters: {'n_estimators': 5510, 'learning_rate': 0.0017329720390296822, 'max_depth': 6, 'min_child_weight': 9.443198039188713, 'gamma': 8.357825905837592, 'subsample': 0.6190354858341118, 'colsample_bytree': 0.6419946476653234, 'reg_alpha': 6.640595997226676e-09, 'reg_lambda': 0.0008027219631491326}. Best is trial 41 with value: 1.2346925743768746.
# [I 2026-07-10 06:14:33,570] Trial 45 finished with value: 1.242277177459267 and parameters: {'n_estimators': 4562, 'learning_rate': 0.0018617097243997566, 'max_depth': 6, 'min_child_weight': 11.99093509071175, 'gamma': 8.305263849816985, 'subsample': 0.6358611969389281, 'colsample_bytree': 0.632451886069961, 'reg_alpha': 5.000470848921992e-09, 'reg_lambda': 0.001105744504635659}. Best is trial 41 with value: 1.2346925743768746.
# [I 2026-07-10 06:14:42,349] Trial 46 finished with value: 1.223145943838193 and parameters: {'n_estimators': 4440, 'learning_rate': 0.0023826193191006126, 'max_depth': 6, 'min_child_weight': 7.817526035417685, 'gamma': 7.056336812654412, 'subsample': 0.5367140581822318, 'colsample_bytree': 0.6412249941243575, 'reg_alpha': 8.308566072176473e-10, 'reg_lambda': 0.0010491210078493215}. Best is trial 46 with value: 1.223145943838193.
# [I 2026-07-10 06:14:50,877] Trial 47 finished with value: 1.2215816934463721 and parameters: {'n_estimators': 5553, 'learning_rate': 0.0028027830571783563, 'max_depth': 6, 'min_child_weight': 7.274682950284022, 'gamma': 5.54867578457728, 'subsample': 0.5488337228610438, 'colsample_bytree': 0.5478037123023345, 'reg_alpha': 6.005754012104164e-10, 'reg_lambda': 0.00019420659962795245}. Best is trial 47 with value: 1.2215816934463721.
# [I 2026-07-10 06:15:00,686] Trial 48 finished with value: 1.2199217915049319 and parameters: {'n_estimators': 5997, 'learning_rate': 0.002580405758774046, 'max_depth': 5, 'min_child_weight': 6.315514382993465, 'gamma': 0.2048576552239234, 'subsample': 0.5440579761895286, 'colsample_bytree': 0.5382952813245322, 'reg_alpha': 2.472231509783907e-10, 'reg_lambda': 0.00021269590913266352}. Best is trial 48 with value: 1.2199217915049319.
# [I 2026-07-10 06:15:06,200] Trial 49 finished with value: 1.2075904410982143 and parameters: {'n_estimators': 5964, 'learning_rate': 0.00528594548059364, 'max_depth': 4, 'min_child_weight': 5.215998957459963, 'gamma': 0.14601975294191225, 'subsample': 0.5333939931972911, 'colsample_bytree': 0.46449022583381594, 'reg_alpha': 2.5966467123287225e-10, 'reg_lambda': 0.001902240075093472}. Best is trial 49 with value: 1.2075904410982143.
# [I 2026-07-10 06:15:13,622] Trial 50 finished with value: 1.2259465201035171 and parameters: {'n_estimators': 5954, 'learning_rate': 0.0026157382761626915, 'max_depth': 4, 'min_child_weight': 6.386846449091411, 'gamma': 0.22531817438530943, 'subsample': 0.5295571844623048, 'colsample_bytree': 0.45219907453648706, 'reg_alpha': 1.0670337085151023e-10, 'reg_lambda': 0.0153676588878643}. Best is trial 49 with value: 1.2075904410982143.
# [I 2026-07-10 06:15:24,279] Trial 51 finished with value: 1.2217180477885525 and parameters: {'n_estimators': 5955, 'learning_rate': 0.002641146233339961, 'max_depth': 4, 'min_child_weight': 5.962509015593588, 'gamma': 0.00242412996170957, 'subsample': 0.5374735058294261, 'colsample_bytree': 0.4661668246620713, 'reg_alpha': 1.4602999132273146e-10, 'reg_lambda': 0.018060194527754158}. Best is trial 49 with value: 1.2075904410982143.
# [I 2026-07-10 06:15:31,536] Trial 52 finished with value: 1.2197511620453019 and parameters: {'n_estimators': 4563, 'learning_rate': 0.002688455457608005, 'max_depth': 4, 'min_child_weight': 5.778581860137692, 'gamma': 1.4009007311799562, 'subsample': 0.5429071061787196, 'colsample_bytree': 0.4670085184764512, 'reg_alpha': 1.1143646246352096e-10, 'reg_lambda': 0.016825959528865276}. Best is trial 49 with value: 1.2075904410982143.
# [I 2026-07-10 06:15:37,435] Trial 53 finished with value: 1.221632141489368 and parameters: {'n_estimators': 4568, 'learning_rate': 0.004636786042650244, 'max_depth': 4, 'min_child_weight': 4.1391336856519505, 'gamma': 1.4912625544750133, 'subsample': 0.54722125030388, 'colsample_bytree': 0.47559534334731624, 'reg_alpha': 1.064085250643957e-09, 'reg_lambda': 0.001944777040261706}. Best is trial 49 with value: 1.2075904410982143.
# [I 2026-07-10 06:15:42,271] Trial 54 finished with value: 1.2192995798801183 and parameters: {'n_estimators': 5218, 'learning_rate': 0.0052397446289785075, 'max_depth': 4, 'min_child_weight': 4.143971226359066, 'gamma': 1.5486909106285986, 'subsample': 0.4375090856081506, 'colsample_bytree': 0.47966103176491054, 'reg_alpha': 3.5937494002699323e-10, 'reg_lambda': 0.0028010896946993073}. Best is trial 49 with value: 1.2075904410982143.
# [I 2026-07-10 06:15:47,730] Trial 55 finished with value: 1.2198600258761454 and parameters: {'n_estimators': 5153, 'learning_rate': 0.005024570909678855, 'max_depth': 5, 'min_child_weight': 4.5640013313281935, 'gamma': 1.4960474818700908, 'subsample': 0.41046064314914427, 'colsample_bytree': 0.497753939178353, 'reg_alpha': 3.303902901676139e-10, 'reg_lambda': 0.0025583175806515052}. Best is trial 49 with value: 1.2075904410982143.
# [I 2026-07-10 06:15:50,794] Trial 56 pruned.
# [I 2026-07-10 06:15:54,391] Trial 57 finished with value: 1.22676643587849 and parameters: {'n_estimators': 5381, 'learning_rate': 0.00881193517734157, 'max_depth': 5, 'min_child_weight': 3.736964906225802, 'gamma': 1.9327167100726712, 'subsample': 0.4257002079989293, 'colsample_bytree': 0.49067352870238123, 'reg_alpha': 3.532512288530433e-10, 'reg_lambda': 0.012035389338551144}. Best is trial 49 with value: 1.2075904410982143.
# [I 2026-07-10 06:15:57,165] Trial 58 pruned.
# [I 2026-07-10 06:16:04,900] Trial 59 finished with value: 1.229359493646275 and parameters: {'n_estimators': 5599, 'learning_rate': 0.00942250774642586, 'max_depth': 5, 'min_child_weight': 2.152905994101289, 'gamma': 3.0184199468546837, 'subsample': 0.3508983045913914, 'colsample_bytree': 0.4508096282792927, 'reg_alpha': 4.450285915693324e-08, 'reg_lambda': 0.00021963097958465225}. Best is trial 49 with value: 1.2075904410982143.
# [I 2026-07-10 06:16:26,068] Trial 60 finished with value: 1.2359671560520569 and parameters: {'n_estimators': 5252, 'learning_rate': 0.006834060205468119, 'max_depth': 4, 'min_child_weight': 3.2493029130440987, 'gamma': 1.101145529282122, 'subsample': 0.445990294936275, 'colsample_bytree': 0.5250894432877325, 'reg_alpha': 2.2648339159202344e-09, 'reg_lambda': 0.003578638316726391}. Best is trial 49 with value: 1.2075904410982143.
# [I 2026-07-10 06:16:56,663] Trial 61 finished with value: 1.2183151657946205 and parameters: {'n_estimators': 4720, 'learning_rate': 0.004616526379244901, 'max_depth': 4, 'min_child_weight': 4.579302621961977, 'gamma': 1.8649415706556023, 'subsample': 0.5966606734290363, 'colsample_bytree': 0.4853922030972666, 'reg_alpha': 8.982286194109266e-10, 'reg_lambda': 0.001940050737448804}. Best is trial 49 with value: 1.2075904410982143.
# [I 2026-07-10 06:17:25,905] Trial 62 finished with value: 1.2299900286296082 and parameters: {'n_estimators': 4350, 'learning_rate': 0.004427241060655185, 'max_depth': 3, 'min_child_weight': 5.2079781008377495, 'gamma': 2.0107614763923456, 'subsample': 0.5944056332387193, 'colsample_bytree': 0.48709044696443304, 'reg_alpha': 3.9624179446571805e-10, 'reg_lambda': 0.00048815371981375674}. Best is trial 49 with value: 1.2075904410982143.
# [I 2026-07-10 06:18:06,339] Trial 63 finished with value: 1.211510342810252 and parameters: {'n_estimators': 4695, 'learning_rate': 0.0029649689935221783, 'max_depth': 5, 'min_child_weight': 2.2816667632510623, 'gamma': 0.5305162303801567, 'subsample': 0.4754734535880027, 'colsample_bytree': 0.39380159941882903, 'reg_alpha': 2.184080463451951e-09, 'reg_lambda': 0.0013737636494699052}. Best is trial 49 with value: 1.2075904410982143.
# [I 2026-07-10 06:18:42,679] Trial 64 finished with value: 1.2037066206895326 and parameters: {'n_estimators': 4709, 'learning_rate': 0.0034396953288419623, 'max_depth': 5, 'min_child_weight': 2.3399609326988418, 'gamma': 3.585119248831837, 'subsample': 0.4865082174817531, 'colsample_bytree': 0.40140790269612314, 'reg_alpha': 2.16403419962988e-09, 'reg_lambda': 0.0016744354700038598}. Best is trial 64 with value: 1.2037066206895326.
# [I 2026-07-10 06:19:05,316] Trial 65 finished with value: 1.2266538343714612 and parameters: {'n_estimators': 4698, 'learning_rate': 0.005503605560106425, 'max_depth': 3, 'min_child_weight': 2.0998321850799306, 'gamma': 3.4844661437711717, 'subsample': 0.48484076596960596, 'colsample_bytree': 0.40145482253623216, 'reg_alpha': 2.4834040494215877e-09, 'reg_lambda': 0.009766765502729561}. Best is trial 64 with value: 1.2037066206895326.
# [I 2026-07-10 06:19:38,432] Trial 66 finished with value: 1.216277904867324 and parameters: {'n_estimators': 4153, 'learning_rate': 0.00310266436012098, 'max_depth': 4, 'min_child_weight': 1.2198682670096406, 'gamma': 2.5696682885028075, 'subsample': 0.4140165801113648, 'colsample_bytree': 0.35069566967864024, 'reg_alpha': 2.4686775857642904e-08, 'reg_lambda': 0.0013918537329933758}. Best is trial 64 with value: 1.2037066206895326.
# [I 2026-07-10 06:19:48,485] Trial 67 pruned.
# [I 2026-07-10 06:20:29,129] Trial 68 finished with value: 1.2129537169192262 and parameters: {'n_estimators': 4090, 'learning_rate': 0.0022138819751379196, 'max_depth': 4, 'min_child_weight': 1.2171980346933837, 'gamma': 2.398587258402986, 'subsample': 0.5122688131166813, 'colsample_bytree': 0.439142274092879, 'reg_alpha': 1.764482743997011e-08, 'reg_lambda': 0.0015205360149512727}. Best is trial 64 with value: 1.2037066206895326.
# [I 2026-07-10 06:20:54,741] Trial 69 pruned.
# [I 2026-07-10 06:21:07,950] Trial 70 pruned.
# [I 2026-07-10 06:21:30,470] Trial 71 finished with value: 1.2477471147102126 and parameters: {'n_estimators': 3967, 'learning_rate': 0.004002539589869864, 'max_depth': 4, 'min_child_weight': 0.7804048897314185, 'gamma': 0.6036059062936203, 'subsample': 0.5690271627320078, 'colsample_bytree': 0.4532430839091671, 'reg_alpha': 2.4798924733640615e-09, 'reg_lambda': 0.0014293500926835612}. Best is trial 64 with value: 1.2037066206895326.
# [I 2026-07-10 06:22:02,184] Trial 72 finished with value: 1.2318782631226173 and parameters: {'n_estimators': 4046, 'learning_rate': 0.003357959728716876, 'max_depth': 4, 'min_child_weight': 1.9139049531305603, 'gamma': 2.8388188471529583, 'subsample': 0.5938294865192482, 'colsample_bytree': 0.4288637988348175, 'reg_alpha': 2.0248637216474667e-08, 'reg_lambda': 0.0006927930680096084}. Best is trial 64 with value: 1.2037066206895326.
# [I 2026-07-10 06:23:13,480] Trial 73 finished with value: 1.2075253204593248 and parameters: {'n_estimators': 4634, 'learning_rate': 0.0013776923908878345, 'max_depth': 5, 'min_child_weight': 2.541356273879842, 'gamma': 2.168471962932805, 'subsample': 0.44990583343099017, 'colsample_bytree': 0.39140791835756666, 'reg_alpha': 1.2284820500043362e-09, 'reg_lambda': 0.0030954780153010057}. Best is trial 64 with value: 1.2037066206895326.
# [I 2026-07-10 06:24:25,381] Trial 74 finished with value: 1.2039383372921821 and parameters: {'n_estimators': 4895, 'learning_rate': 0.0013491824173976835, 'max_depth': 5, 'min_child_weight': 1.3505392411839856, 'gamma': 2.1168323482473634, 'subsample': 0.45044717498993436, 'colsample_bytree': 0.3805394866873287, 'reg_alpha': 2.1052565849811352e-07, 'reg_lambda': 0.003289192321355374}. Best is trial 64 with value: 1.2037066206895326.
# [I 2026-07-10 06:25:52,079] Trial 75 finished with value: 1.2092160757770016 and parameters: {'n_estimators': 4949, 'learning_rate': 0.001178822852387804, 'max_depth': 5, 'min_child_weight': 1.242263484269291, 'gamma': 2.2839064027105085, 'subsample': 0.42156280246406735, 'colsample_bytree': 0.35332276755659064, 'reg_alpha': 2.0331452413799264e-07, 'reg_lambda': 0.0068668917913060614}. Best is trial 64 with value: 1.2037066206895326.
# [I 2026-07-10 06:26:57,442] Trial 76 finished with value: 1.2153300447233328 and parameters: {'n_estimators': 5004, 'learning_rate': 0.0013851676611456236, 'max_depth': 5, 'min_child_weight': 0.3490455018613714, 'gamma': 2.1635497108130863, 'subsample': 0.4172279064995195, 'colsample_bytree': 0.3528236149117845, 'reg_alpha': 1.7381271501674554e-07, 'reg_lambda': 0.006618159995169394}. Best is trial 64 with value: 1.2037066206895326.
# [I 2026-07-10 06:28:58,931] Trial 77 finished with value: 1.211602403546791 and parameters: {'n_estimators': 4938, 'learning_rate': 0.0007690570714253321, 'max_depth': 5, 'min_child_weight': 0.7942443309341685, 'gamma': 3.966179459239874, 'subsample': 0.4515564189898891, 'colsample_bytree': 0.385766897675302, 'reg_alpha': 9.537843872570978e-08, 'reg_lambda': 0.0064643872789028525}. Best is trial 64 with value: 1.2037066206895326.
# [I 2026-07-10 06:29:19,279] Trial 78 finished with value: 1.2110979991536497 and parameters: {'n_estimators': 3517, 'learning_rate': 0.000736750310956703, 'max_depth': 5, 'min_child_weight': 1.448773382536936, 'gamma': 3.8440843751874376, 'subsample': 0.45289242103723276, 'colsample_bytree': 0.38667520046629367, 'reg_alpha': 2.879151040686268e-07, 'reg_lambda': 0.004996788916708212}. Best is trial 64 with value: 1.2037066206895326.
# [I 2026-07-10 06:29:33,409] Trial 79 finished with value: 1.2142498677654334 and parameters: {'n_estimators': 2640, 'learning_rate': 0.0008032037677057415, 'max_depth': 5, 'min_child_weight': 0.8013555218092444, 'gamma': 3.9023691436228845, 'subsample': 0.4551107219549416, 'colsample_bytree': 0.3852363151384973, 'reg_alpha': 2.751833926488027e-07, 'reg_lambda': 0.029130112835797698}. Best is trial 64 with value: 1.2037066206895326.
# [I 2026-07-10 06:29:52,459] Trial 80 finished with value: 1.212283969858654 and parameters: {'n_estimators': 3480, 'learning_rate': 0.0007076740631567962, 'max_depth': 7, 'min_child_weight': 1.656883899236902, 'gamma': 4.220522378687292, 'subsample': 0.3811575050475316, 'colsample_bytree': 0.4069789869673863, 'reg_alpha': 9.244614701070898e-06, 'reg_lambda': 0.004751658352488712}. Best is trial 64 with value: 1.2037066206895326.
# [I 2026-07-10 06:30:10,050] Trial 81 finished with value: 1.2253158973399951 and parameters: {'n_estimators': 2691, 'learning_rate': 0.000711831284828665, 'max_depth': 7, 'min_child_weight': 2.448098812414293, 'gamma': 4.481399698176257, 'subsample': 0.38213775531544936, 'colsample_bytree': 0.403661290445749, 'reg_alpha': 6.2900391641980965e-06, 'reg_lambda': 0.004668791366518191}. Best is trial 64 with value: 1.2037066206895326.
# [I 2026-07-10 06:30:25,335] Trial 82 finished with value: 1.205597457218733 and parameters: {'n_estimators': 4345, 'learning_rate': 0.0009765116554590626, 'max_depth': 5, 'min_child_weight': 1.549259642317282, 'gamma': 5.15258454552, 'subsample': 0.4835695281863151, 'colsample_bytree': 0.3813148076488862, 'reg_alpha': 8.637127046380759e-07, 'reg_lambda': 0.00933399587018139}. Best is trial 64 with value: 1.2037066206895326.
# [I 2026-07-10 06:30:39,324] Trial 83 finished with value: 1.2144612909328822 and parameters: {'n_estimators': 4386, 'learning_rate': 0.0009386449574323325, 'max_depth': 5, 'min_child_weight': 0.42038660412015033, 'gamma': 5.19313178433325, 'subsample': 0.48239800401077776, 'colsample_bytree': 0.37930801085603383, 'reg_alpha': 7.058517864405076e-07, 'reg_lambda': 0.007776661965931047}. Best is trial 64 with value: 1.2037066206895326.
# [I 2026-07-10 06:30:52,694] Trial 84 finished with value: 1.216355033047293 and parameters: {'n_estimators': 4921, 'learning_rate': 0.0010923084708730202, 'max_depth': 5, 'min_child_weight': 0.9257854197774954, 'gamma': 3.2204025033295474, 'subsample': 0.45310602095721164, 'colsample_bytree': 0.37249435520006374, 'reg_alpha': 1.2054061936921985e-07, 'reg_lambda': 0.010652570751258365}. Best is trial 64 with value: 1.2037066206895326.
# [I 2026-07-10 06:31:04,056] Trial 85 finished with value: 1.200320830268534 and parameters: {'n_estimators': 4754, 'learning_rate': 0.0012329158048994104, 'max_depth': 6, 'min_child_weight': 0.2254466120747611, 'gamma': 3.719440178757357, 'subsample': 0.5187837240242569, 'colsample_bytree': 0.39144574264478155, 'reg_alpha': 1.4130118148982015e-06, 'reg_lambda': 0.0033179231787835235}. Best is trial 85 with value: 1.200320830268534.
# [I 2026-07-10 06:31:20,344] Trial 86 finished with value: 1.2008679764076426 and parameters: {'n_estimators': 4731, 'learning_rate': 0.001347109496732672, 'max_depth': 6, 'min_child_weight': 1.4696114454672131, 'gamma': 4.744052202724936, 'subsample': 0.502563788404188, 'colsample_bytree': 0.4204673265316138, 'reg_alpha': 1.6399914145539474e-06, 'reg_lambda': 0.0035181533852767406}. Best is trial 85 with value: 1.200320830268534.
# [I 2026-07-10 06:31:33,179] Trial 87 finished with value: 1.2208214470339527 and parameters: {'n_estimators': 3851, 'learning_rate': 0.001348224602202403, 'max_depth': 6, 'min_child_weight': 0.10054336694643905, 'gamma': 3.57138768574461, 'subsample': 0.5000807904596204, 'colsample_bytree': 0.41568765765673016, 'reg_alpha': 2.110162380866043e-05, 'reg_lambda': 0.05767172919822125}. Best is trial 85 with value: 1.200320830268534.
# [I 2026-07-10 06:31:46,575] Trial 88 finished with value: 1.205288753983377 and parameters: {'n_estimators': 4315, 'learning_rate': 0.0013878112230098457, 'max_depth': 6, 'min_child_weight': 1.4581202340448192, 'gamma': 5.0941710433143745, 'subsample': 0.5242067269314205, 'colsample_bytree': 0.36484785400436476, 'reg_alpha': 1.3134989355225713e-06, 'reg_lambda': 0.0035099038537982686}. Best is trial 85 with value: 1.200320830268534.
# [I 2026-07-10 06:32:02,865] Trial 89 finished with value: 1.2080802102655013 and parameters: {'n_estimators': 4307, 'learning_rate': 0.0014066470269003329, 'max_depth': 7, 'min_child_weight': 3.10687178697774, 'gamma': 5.031892766952394, 'subsample': 0.5211564175575648, 'colsample_bytree': 0.367104248982141, 'reg_alpha': 1.1392479131364224e-06, 'reg_lambda': 0.002894091486128599}. Best is trial 85 with value: 1.200320830268534.
# [I 2026-07-10 06:32:14,564] Trial 90 finished with value: 1.20627593832067 and parameters: {'n_estimators': 4340, 'learning_rate': 0.0014048153801657342, 'max_depth': 7, 'min_child_weight': 0.6359249660222136, 'gamma': 4.983996917277313, 'subsample': 0.519954676324207, 'colsample_bytree': 0.4173715893447994, 'reg_alpha': 3.5330927551218548e-06, 'reg_lambda': 0.0033709370374669046}. Best is trial 85 with value: 1.200320830268534.
# [I 2026-07-10 06:32:20,064] Trial 91 pruned.
# [I 2026-07-10 06:32:36,389] Trial 92 finished with value: 1.2021874259311685 and parameters: {'n_estimators': 4260, 'learning_rate': 0.0009782676074500361, 'max_depth': 7, 'min_child_weight': 0.5765083684276315, 'gamma': 5.881831966989665, 'subsample': 0.49830302933485243, 'colsample_bytree': 0.4421612755862043, 'reg_alpha': 1.1839848344418982e-06, 'reg_lambda': 0.0006051838815233065}. Best is trial 85 with value: 1.200320830268534.
# [I 2026-07-10 06:32:52,914] Trial 93 finished with value: 1.2106096448332524 and parameters: {'n_estimators': 4613, 'learning_rate': 0.0009321088589431338, 'max_depth': 8, 'min_child_weight': 0.6352672673925637, 'gamma': 5.561503122419884, 'subsample': 0.558922769480361, 'colsample_bytree': 0.4504290688389678, 'reg_alpha': 1.4972864987731191e-06, 'reg_lambda': 0.0006272266094955742}. Best is trial 85 with value: 1.200320830268534.
# [I 2026-07-10 06:33:15,432] Trial 94 finished with value: 1.2178108911868804 and parameters: {'n_estimators': 3905, 'learning_rate': 0.0005871840829545523, 'max_depth': 6, 'min_child_weight': 0.24437886268367184, 'gamma': 6.025529416333952, 'subsample': 0.5011974940728081, 'colsample_bytree': 0.4179566205349735, 'reg_alpha': 3.3687550421753684e-06, 'reg_lambda': 0.0034700822848119477}. Best is trial 85 with value: 1.200320830268534.
# [I 2026-07-10 06:33:29,569] Trial 95 finished with value: 1.217931843937071 and parameters: {'n_estimators': 4790, 'learning_rate': 0.000992567758822696, 'max_depth': 8, 'min_child_weight': 0.40219074433609203, 'gamma': 6.69495461901993, 'subsample': 0.5802005941822947, 'colsample_bytree': 0.4397671722549472, 'reg_alpha': 2.8105022820747746e-05, 'reg_lambda': 0.0022736904871508267}. Best is trial 85 with value: 1.200320830268534.
# [I 2026-07-10 06:33:33,795] Trial 96 pruned.
# [I 2026-07-10 06:33:42,587] Trial 97 finished with value: 1.226751214090097 and parameters: {'n_estimators': 4284, 'learning_rate': 0.0020936341676600204, 'max_depth': 6, 'min_child_weight': 0.6457061297908683, 'gamma': 5.126014656074095, 'subsample': 0.5192985298919, 'colsample_bytree': 0.3962426373994791, 'reg_alpha': 1.429805163197164e-05, 'reg_lambda': 0.0009209783480535597}. Best is trial 85 with value: 1.200320830268534.
# [I 2026-07-10 06:33:55,115] Trial 98 finished with value: 1.2275657547658452 and parameters: {'n_estimators': 4230, 'learning_rate': 0.0013133486206267646, 'max_depth': 7, 'min_child_weight': 0.10013312291636924, 'gamma': 4.681322954180916, 'subsample': 0.4704910255252653, 'colsample_bytree': 0.4235762095275183, 'reg_alpha': 1.2698796332657844e-06, 'reg_lambda': 0.012969274060832594}. Best is trial 85 with value: 1.200320830268534.
# [I 2026-07-10 06:34:15,135] Trial 99 finished with value: 1.1995445968088938 and parameters: {'n_estimators': 3709, 'learning_rate': 0.00105849760811424, 'max_depth': 6, 'min_child_weight': 1.6038834116337615, 'gamma': 4.226369257516955, 'subsample': 0.49653363352479, 'colsample_bytree': 0.40559683835983884, 'reg_alpha': 2.2427551974400022e-06, 'reg_lambda': 0.0006001162644226705}. Best is trial 99 with value: 1.1995445968088938.
# [I 2026-07-10 06:34:15,209] A new study created in RDB with name: KATL_v18_1_rap_remaining_warmup_base_lightgbm_mae_f_wide_plus
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-10 06:34:18,565] Trial 0 finished with value: 1.3081905752129057 and parameters: {'n_estimators': 447, 'learning_rate': 0.028873871707375695, 'num_leaves': 71, 'max_depth': 5, 'min_child_samples': 83, 'min_split_gain': 4.295687454742988, 'bagging_fraction': 0.7829586385137167, 'bagging_freq': 4, 'feature_fraction': 0.3688589858758342, 'lambda_l1': 0.06382334403151436, 'lambda_l2': 0.03080292177315921, 'huber_alpha': 0.95}. Best is trial 0 with value: 1.3081905752129057.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-10 06:34:22,297] Trial 1 finished with value: 1.664173068571222 and parameters: {'n_estimators': 812, 'learning_rate': 0.009357081249483435, 'num_leaves': 164, 'max_depth': 2, 'min_child_samples': 211, 'min_split_gain': 4.244695738724308, 'bagging_fraction': 0.9814523094330022, 'bagging_freq': 3, 'feature_fraction': 0.9704172813206324, 'lambda_l1': 2.234088279028776e-05, 'lambda_l2': 1.6594154120142632, 'huber_alpha': 0.85}. Best is trial 0 with value: 1.3081905752129057.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-10 06:34:23,532] Trial 2 finished with value: 2.5294550133660487 and parameters: {'n_estimators': 67, 'learning_rate': 0.02007090910723469, 'num_leaves': 246, 'max_depth': 10, 'min_child_samples': 245, 'min_split_gain': 4.543313789155439, 'bagging_fraction': 0.9415994992571017, 'bagging_freq': 4, 'feature_fraction': 0.41761231740559585, 'lambda_l1': 1.4824332354449863e-08, 'lambda_l2': 101.18939970488272, 'huber_alpha': 0.85}. Best is trial 0 with value: 1.3081905752129057.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-10 06:34:24,844] Trial 3 finished with value: 1.580202461448681 and parameters: {'n_estimators': 1000, 'learning_rate': 0.1413663860910666, 'num_leaves': 109, 'max_depth': 7, 'min_child_samples': 249, 'min_split_gain': 3.678635407535604, 'bagging_fraction': 0.6392899181182937, 'bagging_freq': 4, 'feature_fraction': 0.6173160679063129, 'lambda_l1': 0.052948773379180566, 'lambda_l2': 0.032760577756785814, 'huber_alpha': 0.85}. Best is trial 0 with value: 1.3081905752129057.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-10 06:34:26,982] Trial 4 finished with value: 2.3111441476012318 and parameters: {'n_estimators': 761, 'learning_rate': 0.003003151716938294, 'num_leaves': 409, 'max_depth': 5, 'min_child_samples': 165, 'min_split_gain': 1.498083879035124, 'bagging_fraction': 0.44391094597483866, 'bagging_freq': 3, 'feature_fraction': 0.5516751924489833, 'lambda_l1': 8.332516750396116e-08, 'lambda_l2': 0.5077631895453656, 'huber_alpha': 0.85}. Best is trial 0 with value: 1.3081905752129057.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-10 06:34:28,220] Trial 5 finished with value: 1.2594288658182937 and parameters: {'n_estimators': 404, 'learning_rate': 0.18314620854695027, 'num_leaves': 260, 'max_depth': 13, 'min_child_samples': 51, 'min_split_gain': 2.972245934092154, 'bagging_fraction': 0.9775155780902212, 'bagging_freq': 7, 'feature_fraction': 0.365709606237354, 'lambda_l1': 5.9654059281874116e-05, 'lambda_l2': 0.006859036422781172, 'huber_alpha': 0.95}. Best is trial 5 with value: 1.2594288658182937.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-10 06:34:29,897] Trial 6 finished with value: 1.2556937916319817 and parameters: {'n_estimators': 3052, 'learning_rate': 0.13146898336096702, 'num_leaves': 489, 'max_depth': 11, 'min_child_samples': 47, 'min_split_gain': 2.173391605434026, 'bagging_fraction': 0.9258346721061177, 'bagging_freq': 2, 'feature_fraction': 0.6381532515738396, 'lambda_l1': 0.002530717742378322, 'lambda_l2': 0.0004479476588817844, 'huber_alpha': 0.95}. Best is trial 6 with value: 1.2556937916319817.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-10 06:34:30,975] Trial 7 finished with value: 1.3974085971434986 and parameters: {'n_estimators': 2519, 'learning_rate': 0.18104669093362824, 'num_leaves': 399, 'max_depth': 4, 'min_child_samples': 227, 'min_split_gain': 2.761320735057018, 'bagging_fraction': 0.8991836269249566, 'bagging_freq': 7, 'feature_fraction': 0.8888248313104422, 'lambda_l1': 5.374969144858311e-06, 'lambda_l2': 0.5877618471031133, 'huber_alpha': 0.85}. Best is trial 6 with value: 1.2556937916319817.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-10 06:34:42,830] Trial 8 finished with value: 1.4910010896872647 and parameters: {'n_estimators': 2273, 'learning_rate': 0.0030965152683643635, 'num_leaves': 383, 'max_depth': 3, 'min_child_samples': 3, 'min_split_gain': 1.6724449577646616, 'bagging_fraction': 0.9800160774901863, 'bagging_freq': 5, 'feature_fraction': 0.6188955975766686, 'lambda_l1': 2.8120694751804143e-09, 'lambda_l2': 0.00024007807690373727, 'huber_alpha': 0.85}. Best is trial 6 with value: 1.2556937916319817.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-10 06:34:46,153] Trial 9 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-10 06:34:55,915] Trial 10 finished with value: 1.3809570690707171 and parameters: {'n_estimators': 2941, 'learning_rate': 0.007104579859769969, 'num_leaves': 424, 'max_depth': 2, 'min_child_samples': 2, 'min_split_gain': 4.6220887565718325, 'bagging_fraction': 0.7880566131549542, 'bagging_freq': 7, 'feature_fraction': 0.661678263936434, 'lambda_l1': 8.121756387194875e-09, 'lambda_l2': 100.08386764870838, 'huber_alpha': 0.9}. Best is trial 6 with value: 1.2556937916319817.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-10 06:34:56,673] Trial 11 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-10 06:34:59,250] Trial 12 finished with value: 1.282633511291809 and parameters: {'n_estimators': 3404, 'learning_rate': 0.03866939016656176, 'num_leaves': 50, 'max_depth': 9, 'min_child_samples': 54, 'min_split_gain': 3.975378174997817, 'bagging_fraction': 0.5776988884481041, 'bagging_freq': 4, 'feature_fraction': 0.8073004449855348, 'lambda_l1': 1.1469173194560514e-08, 'lambda_l2': 0.6127644589218547, 'huber_alpha': 0.85}. Best is trial 6 with value: 1.2556937916319817.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-10 06:34:59,947] Trial 13 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-10 06:35:08,440] Trial 14 finished with value: 1.32731242137558 and parameters: {'n_estimators': 2440, 'learning_rate': 0.007089782197514698, 'num_leaves': 92, 'max_depth': 2, 'min_child_samples': 83, 'min_split_gain': 1.7789721315624618, 'bagging_fraction': 0.6616016865596667, 'bagging_freq': 5, 'feature_fraction': 0.4058624376375402, 'lambda_l1': 3.60867143771307e-07, 'lambda_l2': 0.0019132656772962273, 'huber_alpha': 0.9}. Best is trial 6 with value: 1.2556937916319817.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-10 06:35:09,145] Trial 15 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-10 06:35:10,211] Trial 16 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-10 06:35:13,063] Trial 17 finished with value: 1.3166430818639707 and parameters: {'n_estimators': 3309, 'learning_rate': 0.078175866300593, 'num_leaves': 508, 'max_depth': 13, 'min_child_samples': 103, 'min_split_gain': 2.183821929239314, 'bagging_fraction': 0.7553174967176419, 'bagging_freq': 3, 'feature_fraction': 0.37118098042063996, 'lambda_l1': 9.397361325633357e-09, 'lambda_l2': 0.32009070345347035, 'huber_alpha': 0.85}. Best is trial 6 with value: 1.2556937916319817.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-10 06:35:17,325] Trial 18 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-10 06:35:20,354] Trial 19 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-07-10 06:35:32,013] Trial 20 finished with value: 1.2763185069551994 and parameters: {'n_estimators': 1960, 'learning_rate': 0.006941218470506332, 'num_leaves': 273, 'max_depth': 6, 'min_child_samples': 21, 'min_split_gain': 4.473620394562171, 'bagging_fraction': 0.989323795144767, 'bagging_freq': 3, 'feature_fraction': 0.8083932285131131, 'lambda_l1': 1.1401380577799733e-05, 'lambda_l2': 6.450184926416296, 'huber_alpha': 0.95}. Best is trial 6 with value: 1.2556937916319817.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# ...
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
#                   period                method  count     mae_f    rmse_f
# 0   validation_2024_2025               xgboost    729  1.192436  1.605421
# 1   validation_2024_2025              lightgbm    729  1.220041  1.654826
# 2   validation_2024_2025              catboost    729  1.189325  1.593284
# 3   validation_2024_2025         provider_mean    729  2.102767  3.049105
# 4   validation_2024_2025       provider_median    729  2.022252  2.951401
# 5   validation_2024_2025               nbm_raw    729  1.987547  2.848066
# 6   validation_2024_2025              hrrr_raw    729  2.790393  3.978949
# 7   validation_2024_2025               gfs_raw    729  2.859717  3.849158
# 8              test_2026               xgboost    171  1.166031  1.594217
# 9              test_2026              lightgbm    171  1.188192  1.591824
# 10             test_2026              catboost    171  1.186970  1.564145
# 11             test_2026           ridge_stack    171  1.158697  1.561117
# 12             test_2026  guarded_blend_cap_1f    171  1.728402  2.886913
# 13             test_2026  guarded_blend_cap_2f    171  1.508520  2.614328
# 14             test_2026  guarded_blend_cap_3f    171  1.419220  2.443119
# 15             test_2026         provider_mean    171  2.145562  3.337353
# 16             test_2026       provider_median    171  2.126776  3.276249
# 17             test_2026               nbm_raw    171  2.088445  3.229287
# 18             test_2026              hrrr_raw    171  2.539610  3.830303
# 19             test_2026               gfs_raw    171  2.838918  3.971651

# %%
exported_weights = export_station_model_weights(
    project_root=PROJECT_ROOT,
    station_id=STATION_ID,
    artifact_dir=config.resolved_output_dir(),
    model_version=MODEL_VERSION,
    timing_mode=config.timing_mode,
    providers=tuple(config.providers),
    feature_version=config.effective_feature_version,
    optuna_metric=config.effective_optuna_metric,
    target_mode=config.effective_target_mode,
    target_source=config.effective_target_source,
    base_model_methods=tuple(config.effective_base_model_methods),
    stack_enabled=config.stack_enabled,
    source_pipeline="notebooks/experiments/station_stacking_v18_1",
)

exported_weights.bundle_path, exported_weights.manifest_path
# Out:
# (WindowsPath('D:/dev/weather-research/data/calibration/station_stacking_v18_1_rap/model_weights/KATL_station_high_regressor_v18_1_rap_physics_settlement_stack.joblib'),
#  WindowsPath('D:/dev/weather-research/data/calibration/station_stacking_v18_1_rap/model_weights/KATL_station_high_regressor_v18_1_rap_physics_settlement_stack.json'))

# %% [markdown]
# ## V11 Feature Coverage

# %%
v11_feature_coverage = (
    result.features[V11_FEATURE_COLUMNS]
    .notna()
    .mean()
    .mul(100)
    .sort_values(ascending=False)
    .rename("coverage_pct")
    .reset_index()
    .rename(columns={"index": "feature"})
)

v11_feature_coverage
# Out:
#                                               feature  coverage_pct
# 0                              v2_spread_per_warmup_f    100.000000
# 1                    v2_morning_warmup_to_consensus_f    100.000000
# 2              v3_remaining_warmup_from_high_so_far_f    100.000000
# 3                      v3_high_so_far_above_current_f    100.000000
# 4                      v2_humidity_warmup_interaction    100.000000
# 5                    v4_observed_precip_recent_mm_est    100.000000
# 6                        v4_forecast_wet_observed_dry    100.000000
# 7                   v4_forecast_observed_precip_match    100.000000
# 8            v3_humidity_remaining_warmup_interaction    100.000000
# 9                    v3_remaining_warmup_per_spread_f    100.000000
# 10                             v4_all_forecast_precip    100.000000
# 11                             v4_observed_precip_any    100.000000
# 12                             v4_any_forecast_precip    100.000000
# 13                    v8_month_remaining_warmup_count    100.000000
# 14                             climatology_high_10y_f    100.000000
# 15                         climatology_high_10y_std_f    100.000000
# 16       observed_high_so_far_minus_climatology_10y_f    100.000000
# 17              observed_temp_minus_climatology_10y_f    100.000000
# 18                         climatology_high_10y_count    100.000000
# 19              provider_mean_minus_climatology_10y_f    100.000000
# 20          v8_provider_spread_per_remaining_warmup_f    100.000000
# 21                       v4_observed_wet_forecast_dry    100.000000
# 22       v8_provider_min_remaining_from_high_so_far_f    100.000000
# 23    v8_provider_median_remaining_from_high_so_far_f    100.000000
# 24       v8_provider_max_remaining_from_high_so_far_f    100.000000
# 25                          v2_recent_heat_momentum_f     99.949950
# 26                   v3_high_so_far_minus_7d_actual_f     99.949950
# 27                     v2_consensus_minus_7d_actual_f     99.949950
# 28            observed_high_so_far_change_since_9am_f     99.899900
# 29            observed_morning_warmup_rate_f_per_hour     99.899900
# 30               v8_recent_remaining_warmup_7d_mean_f     99.899900
# 31                     observed_temp_change_last_1h_f     99.899900
# 32                     observed_temp_change_last_3h_f     99.899900
# 33              v8_recent_remaining_warmup_30d_mean_f     99.749750
# 34                           v2_recent_heat_anomaly_f     99.699700
# 35                      v3_high_so_far_minus_lag_1d_f     99.699700
# 36       v8_provider_mean_remaining_vs_month_normal_f     98.798799
# 37                   v8_month_remaining_warmup_mean_f     98.798799
# 38      v8_dewpoint_mean_remaining_warmup_interaction     78.828829
# 39  v8_dewpoint_depression_remaining_warmup_intera...     78.828829
# 40                        v8_forecast_dewpoint_mean_f     78.828829
# 41             v8_forecast_dewpoint_depression_mean_f     78.828829
# 42         v4_forecast_total_minus_observed_recent_mm     78.478478
# 43                   v4_forecast_precip_intensity_max     78.478478
# 44                   v4_forecast_precip_total_mean_mm     78.478478
# 45                    v4_forecast_precip_total_max_mm     78.478478
# 46                 v4_forecast_precip_total_spread_mm     78.478478
# 47                  v4_forecast_precip_max_1h_mean_mm     78.478478
# 48                      v4_forecast_precip_hours_mean     78.478478
# 49                  v4_forecast_precip_intensity_mean     78.478478
# 50             v4_precip_remaining_warmup_interaction     78.478478
# 51                     v4_precip_humidity_interaction     78.478478
# 52       v8_precip_total_remaining_warmup_interaction     78.478478
# 53      v8_precip_max_1h_remaining_warmup_interaction     78.478478
# 54    v8_wind_speed_mean_remaining_warmup_interaction     30.980981
# 55      v8_wind_gust_max_remaining_warmup_interaction     30.980981
# 56    v8_cloud_cover_max_remaining_warmup_interaction      0.000000
# 57   v8_cloud_cover_mean_remaining_warmup_interaction      0.000000

# %%
result.feature_columns.loc[result.feature_columns["feature"].isin(V11_FEATURE_COLUMNS)]
# Out:
#                                               feature     kind
# 3                      observed_temp_change_last_1h_f  numeric
# 4                      observed_temp_change_last_3h_f  numeric
# 5             observed_morning_warmup_rate_f_per_hour  numeric
# 6             observed_high_so_far_change_since_9am_f  numeric
# 36                           v2_recent_heat_anomaly_f  numeric
# 37                          v2_recent_heat_momentum_f  numeric
# 38                   v2_morning_warmup_to_consensus_f  numeric
# 39                     v2_consensus_minus_7d_actual_f  numeric
# 40                             v2_spread_per_warmup_f  numeric
# 41                     v2_humidity_warmup_interaction  numeric
# 42                     v3_high_so_far_above_current_f  numeric
# 43             v3_remaining_warmup_from_high_so_far_f  numeric
# 44                      v3_high_so_far_minus_lag_1d_f  numeric
# 45                   v3_high_so_far_minus_7d_actual_f  numeric
# 46                   v3_remaining_warmup_per_spread_f  numeric
# 47           v3_humidity_remaining_warmup_interaction  numeric
# 48                   v4_forecast_precip_total_mean_mm  numeric
# 49                    v4_forecast_precip_total_max_mm  numeric
# 50                 v4_forecast_precip_total_spread_mm  numeric
# 51                  v4_forecast_precip_max_1h_mean_mm  numeric
# 52                      v4_forecast_precip_hours_mean  numeric
# 53                  v4_forecast_precip_intensity_mean  numeric
# 54                   v4_forecast_precip_intensity_max  numeric
# 55                             v4_any_forecast_precip  numeric
# 56                             v4_all_forecast_precip  numeric
# 57                             v4_observed_precip_any  numeric
# 58                   v4_observed_precip_recent_mm_est  numeric
# 59         v4_forecast_total_minus_observed_recent_mm  numeric
# 60                  v4_forecast_observed_precip_match  numeric
# 61                       v4_forecast_wet_observed_dry  numeric
# 62                       v4_observed_wet_forecast_dry  numeric
# 63                     v4_precip_humidity_interaction  numeric
# 64             v4_precip_remaining_warmup_interaction  numeric
# 65       v8_provider_max_remaining_from_high_so_far_f  numeric
# 66       v8_provider_min_remaining_from_high_so_far_f  numeric
# 67    v8_provider_median_remaining_from_high_so_far_f  numeric
# 68          v8_provider_spread_per_remaining_warmup_f  numeric
# 69                   v8_month_remaining_warmup_mean_f  numeric
# 70                    v8_month_remaining_warmup_count  numeric
# 71               v8_recent_remaining_warmup_7d_mean_f  numeric
# 72              v8_recent_remaining_warmup_30d_mean_f  numeric
# 73       v8_provider_mean_remaining_vs_month_normal_f  numeric
# 74       v8_precip_total_remaining_warmup_interaction  numeric
# 75      v8_precip_max_1h_remaining_warmup_interaction  numeric
# 76    v8_wind_speed_mean_remaining_warmup_interaction  numeric
# 77      v8_wind_gust_max_remaining_warmup_interaction  numeric
# 78                        v8_forecast_dewpoint_mean_f  numeric
# 79             v8_forecast_dewpoint_depression_mean_f  numeric
# 80      v8_dewpoint_mean_remaining_warmup_interaction  numeric
# 81  v8_dewpoint_depression_remaining_warmup_intera...  numeric
# 82                             climatology_high_10y_f  numeric
# 83                         climatology_high_10y_std_f  numeric
# 84                         climatology_high_10y_count  numeric
# 85              provider_mean_minus_climatology_10y_f  numeric
# 86              observed_temp_minus_climatology_10y_f  numeric
# 87       observed_high_so_far_minus_climatology_10y_f  numeric

# %% [markdown]
# ## Dropped Feature Check

# %%
dropped_present = result.feature_columns.loc[
    result.feature_columns["feature"].isin(V11_DROPPED_FEATURE_COLUMNS)
]

dropped_present
# Out:
# Empty DataFrame
# Columns: [feature, kind]
# Index: []

# %% [markdown]
# ## Morning Trend Coverage

# %%
trend_coverage = (
    result.features[TREND_COLUMNS]
    .notna()
    .mean()
    .mul(100)
    .sort_values(ascending=False)
    .rename("coverage_pct")
    .reset_index()
    .rename(columns={"index": "feature"})
)

trend_coverage
# Out:
#                                    feature  coverage_pct
# 0           observed_temp_change_last_1h_f       99.8999
# 1           observed_temp_change_last_3h_f       99.8999
# 2  observed_morning_warmup_rate_f_per_hour       99.8999
# 3  observed_high_so_far_change_since_9am_f       99.8999

# %% [markdown]
# ## Rounded Within 1F Accuracy

# %%
preds = pd.concat(
    [
        result.validation_predictions.assign(period="validation_2024_2025"),
        result.test_predictions.assign(period="oof_2026"),
    ],
    ignore_index=True,
)

predicted_high = pd.to_numeric(preds["predicted_high_f"], errors="coerce")
preds["predicted_high_rounded_f"] = np.floor(predicted_high + 0.5)
preds["within_1f_after_round"] = (
    pd.to_numeric(preds["actual_high_f"], errors="coerce") - preds["predicted_high_rounded_f"]
).abs().le(1)

within_1f_accuracy_by_period = (
    preds
    .dropna(subset=["actual_high_f", "predicted_high_rounded_f"])
    .groupby(["period", "method"], as_index=False)
    .agg(
        count=("within_1f_after_round", "size"),
        within_1f_count=("within_1f_after_round", "sum"),
        within_1f_accuracy_pct=("within_1f_after_round", lambda x: x.mean() * 100),
    )
    .sort_values(["period", "within_1f_accuracy_pct"], ascending=[True, False])
)

within_1f_accuracy_by_period
# Out:
#                   period                method  count  within_1f_count  \
# 0               oof_2026              catboost    171              127
# 10              oof_2026           ridge_stack    171              127
# 11              oof_2026               xgboost    171              125
# 6               oof_2026              lightgbm    171              122
# 4               oof_2026  guarded_blend_cap_3f    171              121
# 3               oof_2026  guarded_blend_cap_2f    171              118
# 2               oof_2026  guarded_blend_cap_1f    171              110
# 7               oof_2026               nbm_raw    171               91
# 9               oof_2026       provider_median    171               84
# 8               oof_2026         provider_mean    171               78
# 5               oof_2026              hrrr_raw    171               71
# 1               oof_2026               gfs_raw    171               59
# 19  validation_2024_2025               xgboost    729              517
# 12  validation_2024_2025              catboost    729              507
# 15  validation_2024_2025              lightgbm    729              507
# 16  validation_2024_2025               nbm_raw    729              358
# 18  validation_2024_2025       provider_median    729              353
# 17  validation_2024_2025         provider_mean    729              344
# 14  validation_2024_2025              hrrr_raw    729              278
# 13  validation_2024_2025               gfs_raw    729              233
#
#     within_1f_accuracy_pct
# 0                74.269006
# 10               74.269006
# 11               73.099415
# 6                71.345029
# 4                70.760234
# 3                69.005848
# 2                64.327485
# 7                53.216374
# 9                49.122807
# 8                45.614035
# 5                41.520468
# 1                34.502924
# 19               70.919067
# 12               69.547325
# 15               69.547325
# 16               49.108368
# 18               48.422497
# 17               47.187929
# 14               38.134431
# 13               31.961591

# %% [markdown]
# ## Version Comparison

# %%
comparison_frames = []
for version, folder in [
    ("v1", PROJECT_ROOT / "data" / "calibration" / "station_stacking"),
    ("v2", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v2"),
    ("v3", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v3"),
    ("v4", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v4"),
    ("v5", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v5"),
    ("v6", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v6"),
    ("v7", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v7"),
    ("v8", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v8"),
    ("v9", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v9"),
    ("v10", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v10"),
    ("v11", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v11"),
]:
    path = folder / f"{STATION_ID}_year_split_scoreboard.csv"
    if path.exists():
        frame = pd.read_csv(path)
        frame["version"] = version
        comparison_frames.append(frame)

version_comparison = pd.concat(comparison_frames, ignore_index=True) if comparison_frames else pd.DataFrame()
if not version_comparison.empty:
    version_comparison = version_comparison.sort_values(["period", "mae_f", "version", "method"]).reset_index(drop=True)
version_comparison
# Out:
#                    period       method  count     mae_f    rmse_f version
# 0               test_2026     lightgbm    137  1.529121  2.224566     v11
# 1               test_2026  ridge_stack    137  1.531900  2.209782     v11
# 2               test_2026     lightgbm    125  1.547989  2.093915      v5
# 3               test_2026  ridge_stack    125  1.566708  2.118374      v5
# 4               test_2026      xgboost    125  1.569277  2.117086      v5
# ..                    ...          ...    ...       ...       ...     ...
# 111  validation_2024_2025      gfs_raw    541  3.557627  5.060559      v1
# 112  validation_2024_2025     hrrr_raw    664  3.630969  5.083107      v2
# 113  validation_2024_2025     hrrr_raw    664  3.630969  5.083107      v3
# 114  validation_2024_2025     hrrr_raw    664  3.630969  5.083107      v4
# 115  validation_2024_2025     hrrr_raw    541  4.010898  5.487445      v1
#
# [116 rows x 6 columns]

# %% [markdown]
# ## 2026 OOF Weather Brackets

# %%
result.bracket_metrics
# Out:
#                   method  count     mae_f    rmse_f  bucket_log_loss  \
# 0                xgboost    171  1.166031  1.594217         1.278800
# 1               lightgbm    171  1.188192  1.591824         1.278848
# 2               catboost    171  1.186970  1.564145         1.263121
# 3            ridge_stack    171  1.158697  1.561117         1.261541
# 4   guarded_blend_cap_1f    171  1.728402  2.886913         1.774577
# 5   guarded_blend_cap_2f    171  1.508520  2.614328         1.703532
# 6   guarded_blend_cap_3f    171  1.419220  2.443119         1.645327
# 7          provider_mean    171  2.145562  3.337353         1.877072
# 8        provider_median    171  2.126776  3.276249         1.874809
# 9                nbm_raw    171  2.088445  3.229287         1.869976
# 10              hrrr_raw    171  2.539610  3.830303         1.975896
# 11               gfs_raw    171  2.838918  3.971651         2.083263
#
#     bracket_accuracy_pct  p95_absolute_error_f  large_miss_5f_pct
# 0              50.877193              3.055171           1.754386
# 1               45.02924              2.997570           1.169591
# 2               46.19883              2.910141           1.754386
# 3              49.707602              3.002812           1.754386
# 4              40.935673              4.357125           4.678363
# 5              45.614035              3.764967           4.093567
# 6              47.953216              3.611886           4.093567
# 7              34.502924              5.357125           6.432749
# 8              33.918129              5.905997           7.017544
# 9              35.672515              5.905997           7.602339
# 10             29.824561              7.038774          12.280702
# 11             21.637427              7.412432          12.865497

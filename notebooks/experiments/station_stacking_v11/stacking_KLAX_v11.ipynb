# %% [markdown]
# # Station Stacking v11 - KLAX
#
# Experimental notebook for `KLAX`.
#
# This version keeps the v9 remaining-warmup feature contract, trains XGBoost/LightGBM/CatBoost with Huber-style objectives, keeps ridge stacking enabled, and writes artifacts to `data/calibration/station_stacking_v11`.

# %%
from pathlib import Path
import os
import sys
import warnings

warnings.filterwarnings("ignore", message="IProgress not found.*")
warnings.filterwarnings("ignore", message="Skipping features without any observed values.*")

PROJECT_ROOT = Path.cwd().resolve()
while not (PROJECT_ROOT / "src" / "calibration" / "station_stacking.py").exists():
    if PROJECT_ROOT.parent == PROJECT_ROOT:
        raise RuntimeError("Could not find project root containing src/calibration/station_stacking.py")
    PROJECT_ROOT = PROJECT_ROOT.parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

os.environ["WEATHER_RESEARCH_INCLUDE_DIRECT_NBM"] = "1"

STATION_ID = "KLAX"
PROVIDERS = ("gfs", "hrrr", "nbm")
TREND_COLUMNS = [
    "observed_temp_change_last_1h_f",
    "observed_temp_change_last_3h_f",
    "observed_morning_warmup_rate_f_per_hour",
    "observed_high_so_far_change_since_9am_f",
]
TIMING_MODE = "same_day_11am_live_safe"
FAST_MODE = False
OPTUNA_TRIALS = 30
STACK_OPTUNA_TRIALS = 30
OPTUNA_STARTUP_TRIALS = 15
STACK_OPTUNA_STARTUP_TRIALS = 15
OPTUNA_METRIC = "mae_f"
OPTUNA_VERBOSE = True
MODEL_VERSION = "station_high_regressor_v11_huber_ridge_stack"
PROJECT_ROOT
# Out:
# WindowsPath('D:/dev/weather-research')

# %%
import numpy as np
import pandas as pd

from src.export_station_stacking_v2_models import export_station_model_weights
from src.calibration.station_stacking import (
    StationStackingConfig,
    V11_DROPPED_FEATURE_COLUMNS,
    V11_FEATURE_COLUMNS,
    YEAR_SPLIT_EXPANDING_FOLDS,
    missing_model_dependencies,
    provider_availability,
    run_station_year_split_experiment,
)

# %% [markdown]
# ## V11 Contract
#
# `feature_version="v11"` keeps the v9 feature contract and remaining-warmup target, but trains base learners with Huber-style objectives while retaining the ridge stack selected by validation MAE.

# %%
fold_spec = pd.DataFrame(
    [
        {
            "fold": fold.name,
            "train_start_year": fold.train_start_year,
            "train_end_year": fold.train_end_year,
            "validation_year": fold.validation_year,
        }
        for fold in YEAR_SPLIT_EXPANDING_FOLDS
    ]
)

fold_spec
# Out:
#                      fold  train_start_year  train_end_year  validation_year
# 0  fold_2021_2023_to_2024              2021            2023             2024
# 1  fold_2021_2024_to_2025              2021            2024             2025

# %%
V11_FEATURE_COLUMNS, sorted(V11_DROPPED_FEATURE_COLUMNS)
# Out:
# (['v2_recent_heat_anomaly_f',
#   'v2_recent_heat_momentum_f',
#   'v2_morning_warmup_to_consensus_f',
#   'v2_consensus_minus_7d_actual_f',
#   'v2_spread_per_warmup_f',
#   'v2_humidity_warmup_interaction',
#   'v3_high_so_far_above_current_f',
#   'v3_remaining_warmup_from_high_so_far_f',
#   'v3_high_so_far_minus_lag_1d_f',
#   'v3_high_so_far_minus_7d_actual_f',
#   'v3_remaining_warmup_per_spread_f',
#   'v3_humidity_remaining_warmup_interaction',
#   'v4_forecast_precip_total_mean_mm',
#   'v4_forecast_precip_total_max_mm',
#   'v4_forecast_precip_total_spread_mm',
#   'v4_forecast_precip_max_1h_mean_mm',
#   'v4_forecast_precip_hours_mean',
#   'v4_forecast_precip_intensity_mean',
#   'v4_forecast_precip_intensity_max',
#   'v4_any_forecast_precip',
#   'v4_all_forecast_precip',
#   'v4_observed_precip_any',
#   'v4_observed_precip_recent_mm_est',
#   'v4_forecast_total_minus_observed_recent_mm',
#   'v4_forecast_observed_precip_match',
#   'v4_forecast_wet_observed_dry',
#   'v4_observed_wet_forecast_dry',
#   'v4_precip_humidity_interaction',
#   'v4_precip_remaining_warmup_interaction',
#   'observed_temp_change_last_1h_f',
#   'observed_temp_change_last_3h_f',
#   'observed_morning_warmup_rate_f_per_hour',
#   'observed_high_so_far_change_since_9am_f',
#   'v8_provider_max_remaining_from_high_so_far_f',
#   'v8_provider_min_remaining_from_high_so_far_f',
#   'v8_provider_median_remaining_from_high_so_far_f',
#   'v8_provider_spread_per_remaining_warmup_f',
#   'v8_month_remaining_warmup_mean_f',
#   'v8_month_remaining_warmup_count',
#   'v8_recent_remaining_warmup_7d_mean_f',
#   'v8_recent_remaining_warmup_30d_mean_f',
#   'v8_provider_mean_remaining_vs_month_normal_f',
#   'v8_cloud_cover_mean_remaining_warmup_interaction',
#   'v8_cloud_cover_max_remaining_warmup_interaction',
#   'v8_precip_total_remaining_warmup_interaction',
#   'v8_precip_max_1h_remaining_warmup_interaction',
#   'v8_wind_speed_mean_remaining_warmup_interaction',
#   'v8_wind_gust_max_remaining_warmup_interaction',
#   'v8_forecast_dewpoint_mean_f',
#   'v8_forecast_dewpoint_depression_mean_f',
#   'v8_dewpoint_mean_remaining_warmup_interaction',
#   'v8_dewpoint_depression_remaining_warmup_interaction',
#   'climatology_high_10y_f',
#   'climatology_high_10y_std_f',
#   'climatology_high_10y_count',
#   'provider_mean_minus_climatology_10y_f',
#   'observed_temp_minus_climatology_10y_f',
#   'observed_high_so_far_minus_climatology_10y_f'],
#  ['actual_minus_climatology_10y_f_DIAGNOSTIC_ONLY',
#   'climatology_source_end_year',
#   'climatology_source_start_year',
#   'gfs_as_of_hour_local',
#   'gfs_available',
#   'gfs_forecast_window_hours',
#   'gfs_grid_dist_km_mean',
#   'gfs_horizon_hours',
#   'gfs_hrrr_grid_dist_km_mean_abs_diff_f',
#   'gfs_hrrr_grid_dist_km_mean_diff_f',
#   'gfs_issue_hour_utc',
#   'gfs_missing',
#   'hrrr_as_of_hour_local',
#   'hrrr_available',
#   'hrrr_forecast_hour_max',
#   'hrrr_forecast_hour_min',
#   'hrrr_forecast_lead_hours',
#   'hrrr_forecast_window_hours',
#   'hrrr_grid_dist_km_mean',
#   'hrrr_horizon_hours',
#   'hrrr_issue_hour_local',
#   'hrrr_issue_hour_utc',
#   'hrrr_missing',
#   'is_active_polymarket_station',
#   'lat',
#   'lon',
#   'nbm_as_of_hour_local',
#   'nbm_available',
#   'nbm_forecast_window_hours',
#   'nbm_horizon_hours',
#   'nbm_issue_hour_local',
#   'nbm_issue_hour_utc',
#   'nbm_missing',
#   'observed_fetch_status',
#   'observed_observation_type',
#   'observed_pressure_source',
#   'provider_count_available',
#   'year'])

# %% [markdown]
# ## Data Availability

# %%
availability = provider_availability(
    PROJECT_ROOT,
    timing_mode=TIMING_MODE,
    providers=PROVIDERS,
)

availability.loc[availability["station_id"].eq(STATION_ID)]
# Out:
#    station_id provider  row_count first_contract_date last_contract_date
# 12       KLAX      gfs       1982          2021-01-01         2026-06-10
# 13       KLAX     hrrr       1987          2021-01-01         2026-06-10
# 14       KLAX      nbm       1986          2021-01-01         2026-06-10

# %% [markdown]
# ## Model Scores

# %%
missing_packages = missing_model_dependencies()
if missing_packages:
    raise ImportError(
        "Missing station-stacking ML packages: "
        + ", ".join(missing_packages)
        + ". Install them with: python -m pip install -r requirements.txt"
    )

config = StationStackingConfig(
    station_id=STATION_ID,
    project_root=PROJECT_ROOT,
    timing_mode=TIMING_MODE,
    providers=PROVIDERS,
    fast_mode=FAST_MODE,
    optuna_trials=OPTUNA_TRIALS,
    stack_optuna_trials=STACK_OPTUNA_TRIALS,
    optuna_startup_trials=OPTUNA_STARTUP_TRIALS,
    stack_optuna_startup_trials=STACK_OPTUNA_STARTUP_TRIALS,
    optuna_metric=OPTUNA_METRIC,
    optuna_verbose=OPTUNA_VERBOSE,
    feature_version="v11",
    target_mode="remaining_warmup",
    base_model_methods=("xgboost", "lightgbm", "catboost"),
    stack_enabled=True,
    hyperparameter_space="wide",
    year_split_folds=YEAR_SPLIT_EXPANDING_FOLDS,
    year_split_test_train_years=(2021, 2025),
    year_split_test_year=2026,
    output_dir=PROJECT_ROOT / "data" / "calibration" / "station_stacking_v11",
)

config.resolved_optuna_storage_path()
# Out:
# WindowsPath('D:/dev/weather-research/data/calibration/station_stacking_v11/KLAX_optuna.sqlite3')

# %%
result = run_station_year_split_experiment(config)
result.scoreboard
# Out:
# [I 2026-06-16 16:40:55,147] A new study created in RDB with name: KLAX_v11_remaining_warmup_base_xgboost_mae_f
# [I 2026-06-16 16:40:58,226] Trial 0 finished with value: 1.6994793319693136 and parameters: {'n_estimators': 1342, 'learning_rate': 0.19043899115982607, 'max_depth': 9, 'min_child_weight': 2.481040974867813, 'gamma': 2.340279606636548, 'subsample': 0.4513964382185317, 'colsample_bytree': 0.3877543479093296, 'reg_alpha': 2.478071022662141, 'reg_lambda': 0.6132587025321562}. Best is trial 0 with value: 1.6994793319693136.
# [I 2026-06-16 16:41:22,732] Trial 1 finished with value: 1.4396603693187844 and parameters: {'n_estimators': 2493, 'learning_rate': 0.001120367191095075, 'max_depth': 12, 'min_child_weight': 21.368329072358772, 'gamma': 3.185086660174142, 'subsample': 0.4681862286846154, 'colsample_bytree': 0.46921293140473197, 'reg_alpha': 4.476173538513514e-07, 'reg_lambda': 0.20253776634919213}. Best is trial 1 with value: 1.4396603693187844.
# [I 2026-06-16 16:41:32,406] Trial 2 finished with value: 1.5613065664111334 and parameters: {'n_estimators': 1540, 'learning_rate': 0.004992867109217114, 'max_depth': 8, 'min_child_weight': 0.03613894271216528, 'gamma': 4.3821697280282725, 'subsample': 0.5881351981408995, 'colsample_bytree': 0.6464454897410734, 'reg_alpha': 0.26430874752361627, 'reg_lambda': 0.0018119678627933364}. Best is trial 1 with value: 1.4396603693187844.
# [I 2026-06-16 16:41:36,089] Trial 3 finished with value: 1.54470414036866 and parameters: {'n_estimators': 1824, 'learning_rate': 0.026337502897485255, 'max_depth': 1, 'min_child_weight': 2.69264691008618, 'gamma': 2.557861855309373, 'subsample': 0.39228353544043165, 'colsample_bytree': 0.9667755992146666, 'reg_alpha': 38.6887231523051, 'reg_lambda': 12.408975837016275}. Best is trial 1 with value: 1.4396603693187844.
# [I 2026-06-16 16:41:56,899] Trial 4 finished with value: 1.5963740024480106 and parameters: {'n_estimators': 1101, 'learning_rate': 0.0017147936629846843, 'max_depth': 9, 'min_child_weight': 0.5762487216478605, 'gamma': 1.8305735226716824, 'subsample': 0.6718649915723256, 'colsample_bytree': 0.37235253872489193, 'reg_alpha': 8.162906555194692, 'reg_lambda': 0.004271500153828077}. Best is trial 1 with value: 1.4396603693187844.
# [I 2026-06-16 16:42:11,423] Trial 5 finished with value: 1.5397791103931446 and parameters: {'n_estimators': 2336, 'learning_rate': 0.00559067775661512, 'max_depth': 7, 'min_child_weight': 1.5375920235481764, 'gamma': 2.7728168328829055, 'subsample': 0.980230008046963, 'colsample_bytree': 0.8538363351847245, 'reg_alpha': 18.792618557420877, 'reg_lambda': 43.484449457612314}. Best is trial 1 with value: 1.4396603693187844.
# [I 2026-06-16 16:42:12,680] Trial 6 finished with value: 1.42203187559053 and parameters: {'n_estimators': 2113, 'learning_rate': 0.16240489353272883, 'max_depth': 2, 'min_child_weight': 0.06080390190296603, 'gamma': 0.678409333658071, 'subsample': 0.5614647149961218, 'colsample_bytree': 0.6026402382981633, 'reg_alpha': 1.8037999945880162e-07, 'reg_lambda': 16.668629892722056}. Best is trial 6 with value: 1.42203187559053.
# [I 2026-06-16 16:42:18,414] Trial 7 finished with value: 1.5163807014233215 and parameters: {'n_estimators': 1281, 'learning_rate': 0.0047169807141865345, 'max_depth': 7, 'min_child_weight': 0.0366181922039243, 'gamma': 12.032954711310595, 'subsample': 0.398457918391851, 'colsample_bytree': 0.9914765087903362, 'reg_alpha': 0.18490013641000916, 'reg_lambda': 0.0017869543989965139}. Best is trial 6 with value: 1.42203187559053.
# [I 2026-06-16 16:42:19,439] Trial 8 finished with value: 1.4573965220696565 and parameters: {'n_estimators': 69, 'learning_rate': 0.09024592169686073, 'max_depth': 9, 'min_child_weight': 8.241925264876453, 'gamma': 11.569055200289187, 'subsample': 0.39812902362715874, 'colsample_bytree': 0.5830027235537771, 'reg_alpha': 2.457133280848974e-09, 'reg_lambda': 27.44356809444336}. Best is trial 6 with value: 1.42203187559053.
# [I 2026-06-16 16:42:25,270] Trial 9 finished with value: 1.455526595840363 and parameters: {'n_estimators': 2201, 'learning_rate': 0.006215464818952927, 'max_depth': 1, 'min_child_weight': 0.17535949529764422, 'gamma': 4.877749830401205, 'subsample': 0.8242440159197416, 'colsample_bytree': 0.7644123563808884, 'reg_alpha': 4.4315220126915325, 'reg_lambda': 0.09450187118503514}. Best is trial 6 with value: 1.42203187559053.
# [I 2026-06-16 16:42:27,043] Trial 10 finished with value: 1.4965321014412942 and parameters: {'n_estimators': 462, 'learning_rate': 0.051323729958866915, 'max_depth': 10, 'min_child_weight': 1.7583640270008525, 'gamma': 11.564507699318415, 'subsample': 0.670967137636854, 'colsample_bytree': 0.689776339098296, 'reg_alpha': 1.3504926357029513e-05, 'reg_lambda': 0.0001445994629863374}. Best is trial 6 with value: 1.42203187559053.
# [I 2026-06-16 16:42:30,903] Trial 11 pruned.
# [I 2026-06-16 16:42:34,336] Trial 12 pruned.
# [I 2026-06-16 16:42:35,245] Trial 13 finished with value: 1.475193891677421 and parameters: {'n_estimators': 693, 'learning_rate': 0.13813474572232612, 'max_depth': 7, 'min_child_weight': 16.973078532467014, 'gamma': 13.4413694988524, 'subsample': 0.5567022587317115, 'colsample_bytree': 0.4215337509429899, 'reg_alpha': 5.435280359192946e-08, 'reg_lambda': 0.049115547267693904}. Best is trial 6 with value: 1.42203187559053.
# [I 2026-06-16 16:42:36,907] Trial 14 finished with value: 1.440162096949153 and parameters: {'n_estimators': 2872, 'learning_rate': 0.11587248002108354, 'max_depth': 1, 'min_child_weight': 1.1040511903162256, 'gamma': 6.261165047231685, 'subsample': 0.49437007680597467, 'colsample_bytree': 0.4279124887668938, 'reg_alpha': 1.125594744942969e-06, 'reg_lambda': 87.35792858155622}. Best is trial 6 with value: 1.42203187559053.
# [I 2026-06-16 16:42:39,558] Trial 15 finished with value: 1.4304427670913689 and parameters: {'n_estimators': 3381, 'learning_rate': 0.019024516150723935, 'max_depth': 12, 'min_child_weight': 56.224880144648544, 'gamma': 0.2553890616700283, 'subsample': 0.6604436385708168, 'colsample_bytree': 0.5160382481973793, 'reg_alpha': 0.0009613862055329912, 'reg_lambda': 0.8912768993161009}. Best is trial 6 with value: 1.42203187559053.
# [I 2026-06-16 16:42:41,856] Trial 16 finished with value: 1.4231903851213723 and parameters: {'n_estimators': 3489, 'learning_rate': 0.026340459123935678, 'max_depth': 5, 'min_child_weight': 55.77320820357099, 'gamma': 0.4309273795998875, 'subsample': 0.735511098727408, 'colsample_bytree': 0.5497427978759516, 'reg_alpha': 0.0007576903076688566, 'reg_lambda': 1.1625216460944126}. Best is trial 6 with value: 1.42203187559053.
# [I 2026-06-16 16:42:43,736] Trial 17 finished with value: 1.4520276625418367 and parameters: {'n_estimators': 3322, 'learning_rate': 0.04281351903346082, 'max_depth': 4, 'min_child_weight': 0.012748888933395592, 'gamma': 0.29761831638445385, 'subsample': 0.7742427801462375, 'colsample_bytree': 0.6020771913424021, 'reg_alpha': 0.0019137392018860786, 'reg_lambda': 1.465423547146301}. Best is trial 6 with value: 1.42203187559053.
# [I 2026-06-16 16:42:50,898] Trial 18 finished with value: 1.4446864379206084 and parameters: {'n_estimators': 3003, 'learning_rate': 0.012659077511513253, 'max_depth': 4, 'min_child_weight': 99.4145050297258, 'gamma': 0.03902756560663012, 'subsample': 0.7524591203126603, 'colsample_bytree': 0.5535299329349814, 'reg_alpha': 6.451639986471798e-10, 'reg_lambda': 185.67511625653825}. Best is trial 6 with value: 1.42203187559053.
# [I 2026-06-16 16:42:52,134] Trial 19 finished with value: 1.440025241929721 and parameters: {'n_estimators': 1914, 'learning_rate': 0.0650156245237339, 'max_depth': 3, 'min_child_weight': 0.2773116308155135, 'gamma': 7.1516674210798294, 'subsample': 0.5799071804457733, 'colsample_bytree': 0.6974701796382673, 'reg_alpha': 0.0008320854043626867, 'reg_lambda': 2.7654556131213868}. Best is trial 6 with value: 1.42203187559053.
# [I 2026-06-16 16:42:52,781] Trial 20 pruned.
# [I 2026-06-16 16:42:55,731] Trial 21 finished with value: 1.4431778118009682 and parameters: {'n_estimators': 3417, 'learning_rate': 0.01970186053041892, 'max_depth': 12, 'min_child_weight': 87.01999959195103, 'gamma': 0.9906759803585286, 'subsample': 0.6588370527505403, 'colsample_bytree': 0.513305401398434, 'reg_alpha': 0.0006371750277414204, 'reg_lambda': 0.4954479753521028}. Best is trial 6 with value: 1.42203187559053.
# [I 2026-06-16 16:42:58,909] Trial 22 finished with value: 1.4123623254062327 and parameters: {'n_estimators': 3158, 'learning_rate': 0.011165768124789038, 'max_depth': 2, 'min_child_weight': 35.28342355407478, 'gamma': 1.4324635503565988, 'subsample': 0.6334648918219821, 'colsample_bytree': 0.6319213720070157, 'reg_alpha': 0.010555923209142622, 'reg_lambda': 1.5854160144823657}. Best is trial 22 with value: 1.4123623254062327.
# [I 2026-06-16 16:43:04,306] Trial 23 finished with value: 1.4257722045334635 and parameters: {'n_estimators': 3066, 'learning_rate': 0.00963155676072271, 'max_depth': 2, 'min_child_weight': 40.797034415661415, 'gamma': 4.085695911169797, 'subsample': 0.5354721767390915, 'colsample_bytree': 0.6489977663265548, 'reg_alpha': 0.065810814567811, 'reg_lambda': 3.5652469637212367}. Best is trial 22 with value: 1.4123623254062327.
# [I 2026-06-16 16:43:08,493] Trial 24 finished with value: 1.4298226221390853 and parameters: {'n_estimators': 2802, 'learning_rate': 0.031521648856336355, 'max_depth': 5, 'min_child_weight': 22.621902131725484, 'gamma': 1.4490983940667834, 'subsample': 0.6175089577201317, 'colsample_bytree': 0.62710853597401, 'reg_alpha': 0.023054259354749498, 'reg_lambda': 10.837981942479592}. Best is trial 22 with value: 1.4123623254062327.
# [I 2026-06-16 16:43:48,080] Trial 25 finished with value: 1.4392602742220815 and parameters: {'n_estimators': 3166, 'learning_rate': 0.0026166364427840064, 'max_depth': 2, 'min_child_weight': 8.13109529059537, 'gamma': 3.554760103171229, 'subsample': 0.699587926082218, 'colsample_bytree': 0.7077124106509562, 'reg_alpha': 0.00014688893191438092, 'reg_lambda': 0.1587622257972758}. Best is trial 22 with value: 1.4123623254062327.
# [I 2026-06-16 16:44:07,631] Trial 26 finished with value: 1.419346659076949 and parameters: {'n_estimators': 2641, 'learning_rate': 0.011456709987187098, 'max_depth': 3, 'min_child_weight': 32.49138770980706, 'gamma': 1.2982159280683554, 'subsample': 0.8171806966399614, 'colsample_bytree': 0.5552598933259819, 'reg_alpha': 2.992931290116121e-08, 'reg_lambda': 1.7408473356160445}. Best is trial 22 with value: 1.4123623254062327.
# [I 2026-06-16 16:44:19,842] Trial 27 pruned.
# [I 2026-06-16 16:45:19,280] Trial 28 finished with value: 1.4355187208637608 and parameters: {'n_estimators': 2561, 'learning_rate': 0.002782600762234524, 'max_depth': 2, 'min_child_weight': 0.011837194736763892, 'gamma': 1.4912625544750133, 'subsample': 0.7981134964120221, 'colsample_bytree': 0.5757712465480533, 'reg_alpha': 7.622441937532181e-09, 'reg_lambda': 3.242898675759139}. Best is trial 22 with value: 1.4123623254062327.
# [I 2026-06-16 16:45:34,370] Trial 29 finished with value: 1.4424029745527374 and parameters: {'n_estimators': 1645, 'learning_rate': 0.014392288780969363, 'max_depth': 3, 'min_child_weight': 0.7637821473133101, 'gamma': 2.3017913298827635, 'subsample': 0.5027797381971518, 'colsample_bytree': 0.7562077575741647, 'reg_alpha': 1.7283138670268757e-07, 'reg_lambda': 0.41818044258983383}. Best is trial 22 with value: 1.4123623254062327.
# [I 2026-06-16 16:45:34,557] A new study created in RDB with name: KLAX_v11_remaining_warmup_base_lightgbm_mae_f
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 16:45:43,528] Trial 0 finished with value: 1.4363302402352138 and parameters: {'n_estimators': 447, 'learning_rate': 0.028873871707375695, 'num_leaves': 71, 'max_depth': 5, 'min_child_samples': 83, 'min_split_gain': 4.295687454742988, 'bagging_fraction': 0.7829586385137167, 'bagging_freq': 4, 'feature_fraction': 0.3688589858758342, 'lambda_l1': 0.06382334403151436, 'lambda_l2': 0.03080292177315921, 'huber_alpha': 0.95}. Best is trial 0 with value: 1.4363302402352138.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 16:45:54,381] Trial 1 finished with value: 1.4922565272303343 and parameters: {'n_estimators': 812, 'learning_rate': 0.009357081249483435, 'num_leaves': 164, 'max_depth': 2, 'min_child_samples': 211, 'min_split_gain': 4.244695738724308, 'bagging_fraction': 0.9814523094330022, 'bagging_freq': 3, 'feature_fraction': 0.9704172813206324, 'lambda_l1': 2.234088279028776e-05, 'lambda_l2': 1.6594154120142632, 'huber_alpha': 0.85}. Best is trial 0 with value: 1.4363302402352138.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 16:45:56,835] Trial 2 finished with value: 1.7047129248753277 and parameters: {'n_estimators': 67, 'learning_rate': 0.02007090910723469, 'num_leaves': 246, 'max_depth': 10, 'min_child_samples': 245, 'min_split_gain': 4.543313789155439, 'bagging_fraction': 0.9415994992571017, 'bagging_freq': 4, 'feature_fraction': 0.41761231740559585, 'lambda_l1': 1.4824332354449863e-08, 'lambda_l2': 101.18939970488272, 'huber_alpha': 0.85}. Best is trial 0 with value: 1.4363302402352138.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 16:46:00,225] Trial 3 finished with value: 1.4612583894572895 and parameters: {'n_estimators': 1000, 'learning_rate': 0.1413663860910666, 'num_leaves': 109, 'max_depth': 7, 'min_child_samples': 249, 'min_split_gain': 3.678635407535604, 'bagging_fraction': 0.6392899181182937, 'bagging_freq': 4, 'feature_fraction': 0.6173160679063129, 'lambda_l1': 0.052948773379180566, 'lambda_l2': 0.032760577756785814, 'huber_alpha': 0.85}. Best is trial 0 with value: 1.4363302402352138.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 16:46:11,189] Trial 4 finished with value: 1.6516326243071608 and parameters: {'n_estimators': 761, 'learning_rate': 0.003003151716938294, 'num_leaves': 409, 'max_depth': 5, 'min_child_samples': 165, 'min_split_gain': 1.498083879035124, 'bagging_fraction': 0.44391094597483866, 'bagging_freq': 3, 'feature_fraction': 0.5516751924489833, 'lambda_l1': 8.332516750396116e-08, 'lambda_l2': 0.5077631895453656, 'huber_alpha': 0.85}. Best is trial 0 with value: 1.4363302402352138.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 16:46:15,359] Trial 5 finished with value: 1.4460131541357761 and parameters: {'n_estimators': 404, 'learning_rate': 0.18314620854695027, 'num_leaves': 260, 'max_depth': 13, 'min_child_samples': 51, 'min_split_gain': 2.972245934092154, 'bagging_fraction': 0.9775155780902212, 'bagging_freq': 7, 'feature_fraction': 0.365709606237354, 'lambda_l1': 5.9654059281874116e-05, 'lambda_l2': 0.006859036422781172, 'huber_alpha': 0.95}. Best is trial 0 with value: 1.4363302402352138.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 16:46:20,835] Trial 6 finished with value: 1.440162505669446 and parameters: {'n_estimators': 3052, 'learning_rate': 0.13146898336096702, 'num_leaves': 489, 'max_depth': 11, 'min_child_samples': 47, 'min_split_gain': 2.173391605434026, 'bagging_fraction': 0.9258346721061177, 'bagging_freq': 2, 'feature_fraction': 0.6381532515738396, 'lambda_l1': 0.002530717742378322, 'lambda_l2': 0.0004479476588817844, 'huber_alpha': 0.95}. Best is trial 0 with value: 1.4363302402352138.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 16:46:22,802] Trial 7 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 16:46:45,189] Trial 8 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 16:46:59,344] Trial 9 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 16:47:28,726] Trial 10 finished with value: 1.4452505553828998 and parameters: {'n_estimators': 2941, 'learning_rate': 0.007104579859769969, 'num_leaves': 424, 'max_depth': 2, 'min_child_samples': 2, 'min_split_gain': 4.6220887565718325, 'bagging_fraction': 0.7880566131549542, 'bagging_freq': 7, 'feature_fraction': 0.661678263936434, 'lambda_l1': 8.121756387194875e-09, 'lambda_l2': 100.08386764870838, 'huber_alpha': 0.9}. Best is trial 0 with value: 1.4363302402352138.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 16:47:30,751] Trial 11 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 16:47:37,767] Trial 12 finished with value: 1.4270239354079561 and parameters: {'n_estimators': 3404, 'learning_rate': 0.03866939016656176, 'num_leaves': 50, 'max_depth': 9, 'min_child_samples': 54, 'min_split_gain': 3.975378174997817, 'bagging_fraction': 0.5776988884481041, 'bagging_freq': 4, 'feature_fraction': 0.8073004449855348, 'lambda_l1': 1.1469173194560514e-08, 'lambda_l2': 0.6127644589218547, 'huber_alpha': 0.85}. Best is trial 12 with value: 1.4270239354079561.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 16:47:39,329] Trial 13 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 16:48:09,195] Trial 14 finished with value: 1.4281489581140387 and parameters: {'n_estimators': 2440, 'learning_rate': 0.007089782197514698, 'num_leaves': 92, 'max_depth': 2, 'min_child_samples': 83, 'min_split_gain': 1.7789721315624618, 'bagging_fraction': 0.6616016865596667, 'bagging_freq': 5, 'feature_fraction': 0.4058624376375402, 'lambda_l1': 3.60867143771307e-07, 'lambda_l2': 0.0019132656772962273, 'huber_alpha': 0.9}. Best is trial 12 with value: 1.4270239354079561.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 16:48:41,657] Trial 15 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 16:48:51,794] Trial 16 finished with value: 1.428494994708988 and parameters: {'n_estimators': 1888, 'learning_rate': 0.03383658278725633, 'num_leaves': 13, 'max_depth': 8, 'min_child_samples': 108, 'min_split_gain': 0.7650578764838312, 'bagging_fraction': 0.6995250789249651, 'bagging_freq': 5, 'feature_fraction': 0.4785667004725682, 'lambda_l1': 11.66659353664676, 'lambda_l2': 0.004242279538165009, 'huber_alpha': 0.9}. Best is trial 12 with value: 1.4270239354079561.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 16:48:54,526] Trial 17 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 16:49:00,465] Trial 18 finished with value: 1.4222149689644943 and parameters: {'n_estimators': 1870, 'learning_rate': 0.06561157425411632, 'num_leaves': 105, 'max_depth': 6, 'min_child_samples': 137, 'min_split_gain': 1.0914849460867937, 'bagging_fraction': 0.7056668718542651, 'bagging_freq': 6, 'feature_fraction': 0.7648740586535334, 'lambda_l1': 6.848373732553136e-10, 'lambda_l2': 0.0021151431160791236, 'huber_alpha': 0.9}. Best is trial 18 with value: 1.4222149689644943.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 16:49:05,660] Trial 19 finished with value: 1.4307063594699838 and parameters: {'n_estimators': 1546, 'learning_rate': 0.06814976126644301, 'num_leaves': 208, 'max_depth': 7, 'min_child_samples': 158, 'min_split_gain': 0.9508199293110933, 'bagging_fraction': 0.7509742263651711, 'bagging_freq': 6, 'feature_fraction': 0.7690429582735089, 'lambda_l1': 1.0612674116708008e-10, 'lambda_l2': 0.05320156595577125, 'huber_alpha': 0.9}. Best is trial 18 with value: 1.4222149689644943.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 16:49:09,515] Trial 20 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 16:49:24,861] Trial 21 finished with value: 1.4261092050844342 and parameters: {'n_estimators': 1411, 'learning_rate': 0.015037328735981776, 'num_leaves': 62, 'max_depth': 6, 'min_child_samples': 123, 'min_split_gain': 1.2938082888219942, 'bagging_fraction': 0.6750553715010789, 'bagging_freq': 5, 'feature_fraction': 0.9022727231513064, 'lambda_l1': 5.573989596237841e-07, 'lambda_l2': 0.0019775413422172703, 'huber_alpha': 0.9}. Best is trial 18 with value: 1.4222149689644943.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 16:49:44,061] Trial 22 finished with value: 1.4303473078795315 and parameters: {'n_estimators': 1287, 'learning_rate': 0.01538634371897863, 'num_leaves': 40, 'max_depth': 6, 'min_child_samples': 129, 'min_split_gain': 1.1718204449046494, 'bagging_fraction': 0.7207725290503924, 'bagging_freq': 3, 'feature_fraction': 0.9032306146591653, 'lambda_l1': 6.416136175750655e-07, 'lambda_l2': 0.0008646570882006485, 'huber_alpha': 0.9}. Best is trial 18 with value: 1.4222149689644943.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 16:49:50,491] Trial 23 finished with value: 1.4216754932685818 and parameters: {'n_estimators': 1544, 'learning_rate': 0.08206595386290863, 'num_leaves': 119, 'max_depth': 6, 'min_child_samples': 127, 'min_split_gain': 0.5952965664881733, 'bagging_fraction': 0.8554625959530964, 'bagging_freq': 6, 'feature_fraction': 0.8189630336844506, 'lambda_l1': 1.1993943390917514e-09, 'lambda_l2': 0.007851553624987385, 'huber_alpha': 0.9}. Best is trial 23 with value: 1.4216754932685818.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 16:49:54,249] Trial 24 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 16:50:01,050] Trial 25 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 16:50:09,239] Trial 26 finished with value: 1.4277847792810507 and parameters: {'n_estimators': 1220, 'learning_rate': 0.0915371890907426, 'num_leaves': 128, 'max_depth': 5, 'min_child_samples': 117, 'min_split_gain': 0.029255232696215216, 'bagging_fraction': 0.8545964369161383, 'bagging_freq': 5, 'feature_fraction': 0.8529908680004799, 'lambda_l1': 0.0003669925450678548, 'lambda_l2': 0.013781607869487025, 'huber_alpha': 0.9}. Best is trial 23 with value: 1.4216754932685818.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 16:50:18,610] Trial 27 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 16:50:41,457] Trial 28 finished with value: 1.4279366156978006 and parameters: {'n_estimators': 1795, 'learning_rate': 0.015097101232158442, 'num_leaves': 92, 'max_depth': 4, 'min_child_samples': 141, 'min_split_gain': 1.303919459880045, 'bagging_fraction': 0.7887986708549906, 'bagging_freq': 5, 'feature_fraction': 0.8335829965537018, 'lambda_l1': 2.507543267081455e-06, 'lambda_l2': 0.0001107413863725394, 'huber_alpha': 0.9}. Best is trial 23 with value: 1.4216754932685818.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 16:50:44,930] Trial 29 pruned.
# [I 2026-06-16 16:50:45,082] A new study created in RDB with name: KLAX_v11_remaining_warmup_base_catboost_mae_f
# [I 2026-06-16 17:03:24,501] Trial 0 finished with value: 1.5088092106019868 and parameters: {'iterations': 2931, 'learning_rate': 0.001783588943232587, 'depth': 10, 'l2_leaf_reg': 0.9942958882300413, 'random_strength': 7.186216756161439, 'bagging_temperature': 12.184767612363034, 'border_count': 110, 'rsm': 0.6158971964095841, 'huber_delta': 1.5}. Best is trial 0 with value: 1.5088092106019868.
# [I 2026-06-16 17:21:25,440] Trial 1 finished with value: 1.62645245084158 and parameters: {'iterations': 801, 'learning_rate': 0.19767902101650964, 'depth': 12, 'l2_leaf_reg': 75.05056513807031, 'random_strength': 12.92821124806787, 'bagging_temperature': 4.276496242612171, 'border_count': 168, 'rsm': 0.4404450637901872, 'huber_delta': 1.0}. Best is trial 0 with value: 1.5088092106019868.
# [I 2026-06-16 17:22:45,734] Trial 2 finished with value: 1.5357039228923233 and parameters: {'iterations': 1992, 'learning_rate': 0.0024079350849750287, 'depth': 3, 'l2_leaf_reg': 0.118485976001343, 'random_strength': 4.058751860003342, 'bagging_temperature': 9.103785934457758, 'border_count': 206, 'rsm': 0.994034742637508, 'huber_delta': 0.5}. Best is trial 0 with value: 1.5088092106019868.
# [I 2026-06-16 17:33:53,447] Trial 3 finished with value: 1.5718947155644496 and parameters: {'iterations': 3095, 'learning_rate': 0.05508623515899769, 'depth': 11, 'l2_leaf_reg': 18.082710740309665, 'random_strength': 13.948598364083836, 'bagging_temperature': 18.60205606816345, 'border_count': 227, 'rsm': 0.4117317891426977, 'huber_delta': 3.0}. Best is trial 0 with value: 1.5088092106019868.
# [I 2026-06-16 17:35:30,698] Trial 4 finished with value: 1.4836635023135338 and parameters: {'iterations': 3146, 'learning_rate': 0.0024764229908984673, 'depth': 3, 'l2_leaf_reg': 0.6951779671472356, 'random_strength': 6.148451176512449, 'bagging_temperature': 8.441103735088014, 'border_count': 95, 'rsm': 0.7192489923988105, 'huber_delta': 2.0}. Best is trial 4 with value: 1.4836635023135338.
# [I 2026-06-16 17:35:56,968] Trial 5 finished with value: 1.4411369706920933 and parameters: {'iterations': 2996, 'learning_rate': 0.04169299311145666, 'depth': 2, 'l2_leaf_reg': 0.6483636109972302, 'random_strength': 11.284989840243444, 'bagging_temperature': 11.881552589055849, 'border_count': 179, 'rsm': 0.7610806862514128, 'huber_delta': 0.5}. Best is trial 5 with value: 1.4411369706920933.
# [I 2026-06-16 17:36:01,078] Trial 6 pruned.
# [I 2026-06-16 17:36:13,471] Trial 7 finished with value: 1.4484514189731001 and parameters: {'iterations': 2269, 'learning_rate': 0.05988786419186062, 'depth': 3, 'l2_leaf_reg': 0.8727148674658863, 'random_strength': 13.785080578883292, 'bagging_temperature': 3.643240241026453, 'border_count': 16, 'rsm': 0.5239102067389221, 'huber_delta': 0.5}. Best is trial 5 with value: 1.4411369706920933.
# [I 2026-06-16 17:36:45,141] Trial 8 pruned.
# [I 2026-06-16 17:39:07,096] Trial 9 finished with value: 1.4906931525196336 and parameters: {'iterations': 2176, 'learning_rate': 0.006973123504821021, 'depth': 7, 'l2_leaf_reg': 1.0111907140307084, 'random_strength': 19.613513312465464, 'bagging_temperature': 8.113717548278494, 'border_count': 208, 'rsm': 0.7899333278528806, 'huber_delta': 5.0}. Best is trial 5 with value: 1.4411369706920933.
# [I 2026-06-16 17:39:55,194] Trial 10 pruned.
# [I 2026-06-16 17:40:47,359] Trial 11 finished with value: 1.4700271055026923 and parameters: {'iterations': 2772, 'learning_rate': 0.014522829031783214, 'depth': 5, 'l2_leaf_reg': 15.987388321276002, 'random_strength': 11.591109950971106, 'bagging_temperature': 7.790667047006705, 'border_count': 126, 'rsm': 0.7500006952294106, 'huber_delta': 5.0}. Best is trial 5 with value: 1.4411369706920933.
# [I 2026-06-16 17:42:23,369] Trial 12 pruned.
# [I 2026-06-16 17:42:42,048] Trial 13 pruned.
# [I 2026-06-16 17:43:02,286] Trial 14 finished with value: 1.429232708607878 and parameters: {'iterations': 2033, 'learning_rate': 0.03406017942217813, 'depth': 3, 'l2_leaf_reg': 2.8273302406131626, 'random_strength': 2.5986858551767766, 'bagging_temperature': 5.630188860588947, 'border_count': 58, 'rsm': 0.9026140460549269, 'huber_delta': 1.0}. Best is trial 14 with value: 1.429232708607878.
# [I 2026-06-16 17:43:11,106] Trial 15 pruned.
# [I 2026-06-16 17:43:21,309] Trial 16 finished with value: 1.4250389840107869 and parameters: {'iterations': 1383, 'learning_rate': 0.09987554746836637, 'depth': 5, 'l2_leaf_reg': 4.922593532448983, 'random_strength': 3.450199815230458, 'bagging_temperature': 0.4833121300079206, 'border_count': 57, 'rsm': 0.8908239203972562, 'huber_delta': 2.0}. Best is trial 16 with value: 1.4250389840107869.
# [I 2026-06-16 17:43:28,944] Trial 17 finished with value: 1.4722581072027094 and parameters: {'iterations': 1309, 'learning_rate': 0.1314471423481544, 'depth': 5, 'l2_leaf_reg': 4.362541652646771, 'random_strength': 3.5640663232235603, 'bagging_temperature': 0.5344867605651892, 'border_count': 62, 'rsm': 0.9962515597662266, 'huber_delta': 2.0}. Best is trial 16 with value: 1.4250389840107869.
# [I 2026-06-16 17:43:36,257] Trial 18 pruned.
# [I 2026-06-16 17:44:24,174] Trial 19 pruned.
# [I 2026-06-16 17:44:35,229] Trial 20 finished with value: 1.454278328696458 and parameters: {'iterations': 1033, 'learning_rate': 0.09076794291930769, 'depth': 4, 'l2_leaf_reg': 2.632349344998039, 'random_strength': 5.557301178934456, 'bagging_temperature': 5.496431439855865, 'border_count': 46, 'rsm': 0.8441988090397761, 'huber_delta': 2.0}. Best is trial 16 with value: 1.4250389840107869.
# [I 2026-06-16 17:44:58,113] Trial 21 finished with value: 1.448537450445028 and parameters: {'iterations': 1831, 'learning_rate': 0.0321758855073392, 'depth': 2, 'l2_leaf_reg': 0.2567753439843001, 'random_strength': 9.854067777045412, 'bagging_temperature': 13.26187467455955, 'border_count': 153, 'rsm': 0.820004921278122, 'huber_delta': 0.5}. Best is trial 16 with value: 1.4250389840107869.
# [I 2026-06-16 17:45:19,320] Trial 22 finished with value: 1.4215161873001338 and parameters: {'iterations': 2379, 'learning_rate': 0.029612076710971647, 'depth': 4, 'l2_leaf_reg': 1.9468757668811547, 'random_strength': 16.940389293315345, 'bagging_temperature': 2.1263342721466416, 'border_count': 82, 'rsm': 0.7091157903271095, 'huber_delta': 1.0}. Best is trial 22 with value: 1.4215161873001338.
# [I 2026-06-16 17:45:42,703] Trial 23 finished with value: 1.449062351485877 and parameters: {'iterations': 2353, 'learning_rate': 0.027015819023584943, 'depth': 4, 'l2_leaf_reg': 2.156311941354261, 'random_strength': 17.015932005643652, 'bagging_temperature': 2.250784986715642, 'border_count': 78, 'rsm': 0.6572051833199907, 'huber_delta': 1.0}. Best is trial 22 with value: 1.4215161873001338.
# [I 2026-06-16 17:46:16,240] Trial 24 pruned.
# [I 2026-06-16 17:46:28,212] Trial 25 pruned.
# [I 2026-06-16 17:46:32,748] Trial 26 pruned.
# [I 2026-06-16 17:46:37,957] Trial 27 pruned.
# [I 2026-06-16 17:47:01,898] Trial 28 pruned.
# [I 2026-06-16 17:47:49,698] Trial 29 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 17:52:27,685] A new study created in RDB with name: KLAX_v11_remaining_warmup_stack_ridge_stack_mae_f
# [I 2026-06-16 17:52:28,345] Trial 0 finished with value: 1.4504006103085816 and parameters: {'feature_set': 'models_only', 'alpha': 1061.6032395070417, 'fit_intercept': False}. Best is trial 0 with value: 1.4504006103085816.
# [I 2026-06-16 17:52:28,837] Trial 1 finished with value: 1.4701306990602503 and parameters: {'feature_set': 'models_only', 'alpha': 29.13552742298041, 'fit_intercept': False}. Best is trial 0 with value: 1.4504006103085816.
# [I 2026-06-16 17:52:29,372] Trial 2 finished with value: 1.5069775759152588 and parameters: {'feature_set': 'models_only', 'alpha': 0.0005260598165963439, 'fit_intercept': True}. Best is trial 0 with value: 1.4504006103085816.
# [I 2026-06-16 17:52:29,887] Trial 3 finished with value: 1.4806320017420782 and parameters: {'feature_set': 'models_only', 'alpha': 2.2872748315304782e-05, 'fit_intercept': False}. Best is trial 0 with value: 1.4504006103085816.
# [I 2026-06-16 17:52:30,466] Trial 4 finished with value: 1.4348475460131955 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 1013.2424299869091, 'fit_intercept': True}. Best is trial 4 with value: 1.4348475460131955.
# [I 2026-06-16 17:52:30,981] Trial 5 finished with value: 1.4391150295167146 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 826.0185608286423, 'fit_intercept': True}. Best is trial 4 with value: 1.4348475460131955.
# [I 2026-06-16 17:52:31,488] Trial 6 finished with value: 1.4901474730548927 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 3.929417958656645e-06, 'fit_intercept': True}. Best is trial 4 with value: 1.4348475460131955.
# [I 2026-06-16 17:52:31,923] Trial 7 finished with value: 1.4899695703776126 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 0.8901780240435773, 'fit_intercept': True}. Best is trial 4 with value: 1.4348475460131955.
# [I 2026-06-16 17:52:32,414] Trial 8 finished with value: 1.44472801789397 and parameters: {'feature_set': 'models_only', 'alpha': 2828.538706546869, 'fit_intercept': False}. Best is trial 4 with value: 1.4348475460131955.
# [I 2026-06-16 17:52:32,870] Trial 9 finished with value: 1.4687214727969562 and parameters: {'feature_set': 'models_only', 'alpha': 35.97860619804126, 'fit_intercept': False}. Best is trial 4 with value: 1.4348475460131955.
# [I 2026-06-16 17:52:33,380] Trial 10 finished with value: 1.506977688176195 and parameters: {'feature_set': 'models_only', 'alpha': 1.8087400416300714e-05, 'fit_intercept': True}. Best is trial 4 with value: 1.4348475460131955.
# [I 2026-06-16 17:52:33,839] Trial 11 finished with value: 1.4901473876404694 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 0.00039823854294263674, 'fit_intercept': True}. Best is trial 4 with value: 1.4348475460131955.
# [I 2026-06-16 17:52:34,290] Trial 12 finished with value: 1.491458424862656 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 0.44507773547737556, 'fit_intercept': False}. Best is trial 4 with value: 1.4348475460131955.
# [I 2026-06-16 17:52:34,743] Trial 13 finished with value: 1.4915537274839201 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 7.810619739021528e-06, 'fit_intercept': False}. Best is trial 4 with value: 1.4348475460131955.
# [I 2026-06-16 17:52:35,193] Trial 14 finished with value: 1.458886852121681 and parameters: {'feature_set': 'models_only', 'alpha': 150.11205568245393, 'fit_intercept': False}. Best is trial 4 with value: 1.4348475460131955.
# [I 2026-06-16 17:52:35,672] Trial 15 finished with value: 2.6271999679930635 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 72074.18370227715, 'fit_intercept': True}. Best is trial 4 with value: 1.4348475460131955.
# [I 2026-06-16 17:52:36,107] Trial 16 finished with value: 2.204870384668559 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 47590.802764145235, 'fit_intercept': True}. Best is trial 4 with value: 1.4348475460131955.
# [I 2026-06-16 17:52:36,634] Trial 17 finished with value: 1.4900233258826379 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 0.5945622832595627, 'fit_intercept': True}. Best is trial 4 with value: 1.4348475460131955.
# [I 2026-06-16 17:52:37,103] Trial 18 finished with value: 1.3903545906196157 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 4358.763004510425, 'fit_intercept': True}. Best is trial 18 with value: 1.3903545906196157.
# [I 2026-06-16 17:52:37,586] Trial 19 finished with value: 1.4178984647429698 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 10750.125573436802, 'fit_intercept': True}. Best is trial 18 with value: 1.3903545906196157.
# [I 2026-06-16 17:52:38,044] Trial 20 finished with value: 1.6141360862428158 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 21321.273776744893, 'fit_intercept': True}. Best is trial 18 with value: 1.3903545906196157.
# [I 2026-06-16 17:52:38,511] Trial 21 finished with value: 1.3876776217194646 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 5480.144735242524, 'fit_intercept': True}. Best is trial 21 with value: 1.3876776217194646.
# [I 2026-06-16 17:52:38,959] Trial 22 finished with value: 1.4262324144861511 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 11408.019143423897, 'fit_intercept': True}. Best is trial 21 with value: 1.3876776217194646.
# [I 2026-06-16 17:52:39,545] Trial 23 finished with value: 1.388123770480099 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 6093.392357679742, 'fit_intercept': True}. Best is trial 21 with value: 1.3876776217194646.
# [I 2026-06-16 17:52:39,967] Trial 24 finished with value: 1.4888420834584564 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 5.159354713014635, 'fit_intercept': True}. Best is trial 21 with value: 1.3876776217194646.
# [I 2026-06-16 17:52:40,448] Trial 25 finished with value: 1.4671754109486896 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 129.278356349986, 'fit_intercept': True}. Best is trial 21 with value: 1.3876776217194646.
# [I 2026-06-16 17:52:40,903] Trial 26 finished with value: 1.3915505238184251 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 4177.146399091806, 'fit_intercept': True}. Best is trial 21 with value: 1.3876776217194646.
# [I 2026-06-16 17:52:41,373] Trial 27 finished with value: 1.4647263370521963 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 163.11281997794467, 'fit_intercept': True}. Best is trial 21 with value: 1.3876776217194646.
# [I 2026-06-16 17:52:41,831] Trial 28 finished with value: 2.841471313201572 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 87788.13843609412, 'fit_intercept': True}. Best is trial 21 with value: 1.3876776217194646.
# [I 2026-06-16 17:52:42,372] Trial 29 finished with value: 1.4509432534308426 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 443.90693064461726, 'fit_intercept': True}. Best is trial 21 with value: 1.3876776217194646.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
# ...
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
#                   period       method  count     mae_f    rmse_f
# 0   validation_2024_2025      xgboost    730  1.465277  2.818396
# 1   validation_2024_2025     lightgbm    730  1.506406  2.857480
# 2   validation_2024_2025     catboost    730  1.470451  2.815706
# 3   validation_2024_2025     hrrr_raw    730  1.824908  3.106160
# 4   validation_2024_2025      gfs_raw    730  3.102706  4.345859
# 5              test_2026      xgboost    137  1.328043  1.641883
# 6              test_2026     lightgbm    137  1.388054  1.710114
# 7              test_2026     catboost    137  1.282165  1.602849
# 8              test_2026  ridge_stack    137  1.439378  1.788356
# 9              test_2026     hrrr_raw    137  1.534561  2.020557
# 10             test_2026      gfs_raw    137  3.172394  3.790030

# %%
exported_weights = export_station_model_weights(
    project_root=PROJECT_ROOT,
    station_id=STATION_ID,
    artifact_dir=config.resolved_output_dir(),
    model_version=MODEL_VERSION,
    timing_mode=config.timing_mode,
    providers=tuple(config.providers),
    feature_version=config.effective_feature_version,
    optuna_metric=config.effective_optuna_metric,
    target_mode=config.effective_target_mode,
    base_model_methods=tuple(config.effective_base_model_methods),
    stack_enabled=config.stack_enabled,
    source_pipeline="notebooks/experiments/station_stacking_v11",
)

exported_weights.bundle_path, exported_weights.manifest_path
# Out:
# (WindowsPath('D:/dev/weather-research/data/calibration/station_stacking_v11/model_weights/KLAX_station_high_regressor_v11_huber_ridge_stack.joblib'),
#  WindowsPath('D:/dev/weather-research/data/calibration/station_stacking_v11/model_weights/KLAX_station_high_regressor_v11_huber_ridge_stack.json'))

# %% [markdown]
# ## V11 Feature Coverage

# %%
v11_feature_coverage = (
    result.features[V11_FEATURE_COLUMNS]
    .notna()
    .mean()
    .mul(100)
    .sort_values(ascending=False)
    .rename("coverage_pct")
    .reset_index()
    .rename(columns={"index": "feature"})
)

v11_feature_coverage
# Out:
#                                               feature  coverage_pct
# 0                              v2_spread_per_warmup_f    100.000000
# 1                    v2_morning_warmup_to_consensus_f    100.000000
# 2              v3_remaining_warmup_from_high_so_far_f    100.000000
# 3                      v3_high_so_far_above_current_f    100.000000
# 4                      v2_humidity_warmup_interaction    100.000000
# 5                    v4_observed_precip_recent_mm_est    100.000000
# 6                        v4_forecast_wet_observed_dry    100.000000
# 7                   v4_forecast_observed_precip_match    100.000000
# 8            v3_humidity_remaining_warmup_interaction    100.000000
# 9                    v3_remaining_warmup_per_spread_f    100.000000
# 10                             v4_all_forecast_precip    100.000000
# 11                             v4_observed_precip_any    100.000000
# 12                             v4_any_forecast_precip    100.000000
# 13              observed_temp_minus_climatology_10y_f    100.000000
# 14                             climatology_high_10y_f    100.000000
# 15                         climatology_high_10y_std_f    100.000000
# 16                    v8_month_remaining_warmup_count    100.000000
# 17          v8_provider_spread_per_remaining_warmup_f    100.000000
# 18       v8_provider_min_remaining_from_high_so_far_f    100.000000
# 19    v8_provider_median_remaining_from_high_so_far_f    100.000000
# 20       v8_provider_max_remaining_from_high_so_far_f    100.000000
# 21            observed_high_so_far_change_since_9am_f    100.000000
# 22                     observed_temp_change_last_3h_f    100.000000
# 23            observed_morning_warmup_rate_f_per_hour    100.000000
# 24                     observed_temp_change_last_1h_f    100.000000
# 25                       v4_observed_wet_forecast_dry    100.000000
# 26              provider_mean_minus_climatology_10y_f    100.000000
# 27       observed_high_so_far_minus_climatology_10y_f    100.000000
# 28                         climatology_high_10y_count    100.000000
# 29                          v2_recent_heat_momentum_f     99.949084
# 30                   v3_high_so_far_minus_7d_actual_f     99.949084
# 31                     v2_consensus_minus_7d_actual_f     99.949084
# 32                      v3_high_so_far_minus_lag_1d_f     99.949084
# 33                           v2_recent_heat_anomaly_f     99.949084
# 34               v8_recent_remaining_warmup_7d_mean_f     99.898167
# 35              v8_recent_remaining_warmup_30d_mean_f     99.745418
# 36       v8_provider_mean_remaining_vs_month_normal_f     98.778004
# 37                   v8_month_remaining_warmup_mean_f     98.778004
# 38                 v4_forecast_precip_total_spread_mm      0.000000
# 39                  v4_forecast_precip_max_1h_mean_mm      0.000000
# 40                      v4_forecast_precip_hours_mean      0.000000
# 41                  v4_forecast_precip_intensity_mean      0.000000
# 42         v4_forecast_total_minus_observed_recent_mm      0.000000
# 43                   v4_forecast_precip_intensity_max      0.000000
# 44                   v4_forecast_precip_total_mean_mm      0.000000
# 45                    v4_forecast_precip_total_max_mm      0.000000
# 46             v4_precip_remaining_warmup_interaction      0.000000
# 47                     v4_precip_humidity_interaction      0.000000
# 48   v8_cloud_cover_mean_remaining_warmup_interaction      0.000000
# 49    v8_cloud_cover_max_remaining_warmup_interaction      0.000000
# 50             v8_forecast_dewpoint_depression_mean_f      0.000000
# 51                        v8_forecast_dewpoint_mean_f      0.000000
# 52      v8_wind_gust_max_remaining_warmup_interaction      0.000000
# 53    v8_wind_speed_mean_remaining_warmup_interaction      0.000000
# 54      v8_precip_max_1h_remaining_warmup_interaction      0.000000
# 55       v8_precip_total_remaining_warmup_interaction      0.000000
# 56      v8_dewpoint_mean_remaining_warmup_interaction      0.000000
# 57  v8_dewpoint_depression_remaining_warmup_intera...      0.000000

# %%
result.feature_columns.loc[result.feature_columns["feature"].isin(V11_FEATURE_COLUMNS)]
# Out:
#                                              feature     kind
# 20                    observed_temp_change_last_1h_f  numeric
# 21                    observed_temp_change_last_3h_f  numeric
# 22           observed_morning_warmup_rate_f_per_hour  numeric
# 23           observed_high_so_far_change_since_9am_f  numeric
# 163                         v2_recent_heat_anomaly_f  numeric
# 164                        v2_recent_heat_momentum_f  numeric
# 165                 v2_morning_warmup_to_consensus_f  numeric
# 166                   v2_consensus_minus_7d_actual_f  numeric
# 167                           v2_spread_per_warmup_f  numeric
# 168                   v2_humidity_warmup_interaction  numeric
# 169                   v3_high_so_far_above_current_f  numeric
# 170           v3_remaining_warmup_from_high_so_far_f  numeric
# 171                    v3_high_so_far_minus_lag_1d_f  numeric
# 172                 v3_high_so_far_minus_7d_actual_f  numeric
# 173                 v3_remaining_warmup_per_spread_f  numeric
# 174         v3_humidity_remaining_warmup_interaction  numeric
# 175                           v4_any_forecast_precip  numeric
# 176                           v4_all_forecast_precip  numeric
# 177                           v4_observed_precip_any  numeric
# 178                 v4_observed_precip_recent_mm_est  numeric
# 179                v4_forecast_observed_precip_match  numeric
# 180                     v4_forecast_wet_observed_dry  numeric
# 181                     v4_observed_wet_forecast_dry  numeric
# 182     v8_provider_max_remaining_from_high_so_far_f  numeric
# 183     v8_provider_min_remaining_from_high_so_far_f  numeric
# 184  v8_provider_median_remaining_from_high_so_far_f  numeric
# 185        v8_provider_spread_per_remaining_warmup_f  numeric
# 186                 v8_month_remaining_warmup_mean_f  numeric
# 187                  v8_month_remaining_warmup_count  numeric
# 188             v8_recent_remaining_warmup_7d_mean_f  numeric
# 189            v8_recent_remaining_warmup_30d_mean_f  numeric
# 190     v8_provider_mean_remaining_vs_month_normal_f  numeric
# 191                           climatology_high_10y_f  numeric
# 192                       climatology_high_10y_std_f  numeric
# 193                       climatology_high_10y_count  numeric
# 194            provider_mean_minus_climatology_10y_f  numeric
# 195            observed_temp_minus_climatology_10y_f  numeric
# 196     observed_high_so_far_minus_climatology_10y_f  numeric

# %% [markdown]
# ## Dropped Feature Check

# %%
dropped_present = result.feature_columns.loc[
    result.feature_columns["feature"].isin(V11_DROPPED_FEATURE_COLUMNS)
]

dropped_present
# Out:
# Empty DataFrame
# Columns: [feature, kind]
# Index: []

# %% [markdown]
# ## Morning Trend Coverage

# %%
trend_coverage = (
    result.features[TREND_COLUMNS]
    .notna()
    .mean()
    .mul(100)
    .sort_values(ascending=False)
    .rename("coverage_pct")
    .reset_index()
    .rename(columns={"index": "feature"})
)

trend_coverage
# Out:
#                                    feature  coverage_pct
# 0           observed_temp_change_last_1h_f         100.0
# 1           observed_temp_change_last_3h_f         100.0
# 2  observed_morning_warmup_rate_f_per_hour         100.0
# 3  observed_high_so_far_change_since_9am_f         100.0

# %% [markdown]
# ## Rounded Within 1F Accuracy

# %%
preds = pd.concat(
    [
        result.validation_predictions.assign(period="validation_2024_2025"),
        result.test_predictions.assign(period="oof_2026"),
    ],
    ignore_index=True,
)

predicted_high = pd.to_numeric(preds["predicted_high_f"], errors="coerce")
preds["predicted_high_rounded_f"] = np.floor(predicted_high + 0.5)
preds["within_1f_after_round"] = (
    pd.to_numeric(preds["actual_high_f"], errors="coerce") - preds["predicted_high_rounded_f"]
).abs().le(1)

within_1f_accuracy_by_period = (
    preds
    .dropna(subset=["actual_high_f", "predicted_high_rounded_f"])
    .groupby(["period", "method"], as_index=False)
    .agg(
        count=("within_1f_after_round", "size"),
        within_1f_count=("within_1f_after_round", "sum"),
        within_1f_accuracy_pct=("within_1f_after_round", lambda x: x.mean() * 100),
    )
    .sort_values(["period", "within_1f_accuracy_pct"], ascending=[True, False])
)

within_1f_accuracy_by_period
# Out:
#                   period       method  count  within_1f_count  \
# 0               oof_2026     catboost    137               89
# 6               oof_2026      xgboost    137               86
# 2               oof_2026     hrrr_raw    137               83
# 5               oof_2026  ridge_stack    137               83
# 3               oof_2026     lightgbm    137               81
# 4               oof_2026      nbm_raw    137               60
# 1               oof_2026      gfs_raw    137               38
# 12  validation_2024_2025      xgboost    730              476
# 7   validation_2024_2025     catboost    730              468
# 10  validation_2024_2025     lightgbm    730              464
# 9   validation_2024_2025     hrrr_raw    730              388
# 11  validation_2024_2025      nbm_raw    730              255
# 8   validation_2024_2025      gfs_raw    730              200
#
#     within_1f_accuracy_pct
# 0                64.963504
# 6                62.773723
# 2                60.583942
# 5                60.583942
# 3                59.124088
# 4                43.795620
# 1                27.737226
# 12               65.205479
# 7                64.109589
# 10               63.561644
# 9                53.150685
# 11               34.931507
# 8                27.397260

# %% [markdown]
# ## Version Comparison

# %%
comparison_frames = []
for version, folder in [
    ("v1", PROJECT_ROOT / "data" / "calibration" / "station_stacking"),
    ("v2", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v2"),
    ("v3", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v3"),
    ("v4", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v4"),
    ("v5", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v5"),
    ("v6", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v6"),
    ("v7", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v7"),
    ("v8", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v8"),
    ("v9", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v9"),
    ("v10", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v10"),
    ("v11", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v11"),
]:
    path = folder / f"{STATION_ID}_year_split_scoreboard.csv"
    if path.exists():
        frame = pd.read_csv(path)
        frame["version"] = version
        comparison_frames.append(frame)

version_comparison = pd.concat(comparison_frames, ignore_index=True) if comparison_frames else pd.DataFrame()
if not version_comparison.empty:
    version_comparison = version_comparison.sort_values(["period", "mae_f", "version", "method"]).reset_index(drop=True)
version_comparison
# Out:
#                   period       method  count     mae_f    rmse_f version
# 0              test_2026      xgboost     78  1.176843  1.523835      v6
# 1              test_2026  ridge_stack     78  1.265691  1.581265      v6
# 2              test_2026     lightgbm     78  1.280411  1.654181      v6
# 3              test_2026     catboost    137  1.282165  1.602849     v11
# 4              test_2026     catboost    137  1.317827  1.652116      v9
# ..                   ...          ...    ...       ...       ...     ...
# 83  validation_2024_2025      gfs_raw    592  3.404574  5.253908      v7
# 84  validation_2024_2025      gfs_raw    533  3.660056  5.474728      v5
# 85  validation_2024_2025      gfs_raw    533  3.660056  5.474728      v6
# 86  validation_2024_2025      gfs_raw    664  3.666696  5.648337      v1
# 87  validation_2024_2025      gfs_raw    664  3.666696  5.648337      v2
#
# [88 rows x 6 columns]

# %% [markdown]
# ## 2026 OOF Weather Brackets

# %%
result.bracket_metrics
# Out:
#         method  count     mae_f    rmse_f  bracket_accuracy_pct
# 0      xgboost    137  1.328043  1.641883             41.605839
# 1     lightgbm    137  1.388054  1.710114             41.605839
# 2     catboost    137  1.282165  1.602849             45.985401
# 3  ridge_stack    137  1.439378  1.788356              36.49635
# 4     hrrr_raw    137  1.534561  2.020557              43.79562
# 5      gfs_raw    137  3.172394  3.790030             16.788321

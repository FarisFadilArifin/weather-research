# %% [markdown]
# # Station Stacking v11 - KSEA
#
# Experimental notebook for `KSEA`.
#
# This version keeps the v9 remaining-warmup feature contract, trains XGBoost/LightGBM/CatBoost with Huber-style objectives, keeps ridge stacking enabled, and writes artifacts to `data/calibration/station_stacking_v11`.

# %%
from pathlib import Path
import os
import sys
import warnings

warnings.filterwarnings("ignore", message="IProgress not found.*")
warnings.filterwarnings("ignore", message="Skipping features without any observed values.*")

PROJECT_ROOT = Path.cwd().resolve()
while not (PROJECT_ROOT / "src" / "calibration" / "station_stacking.py").exists():
    if PROJECT_ROOT.parent == PROJECT_ROOT:
        raise RuntimeError("Could not find project root containing src/calibration/station_stacking.py")
    PROJECT_ROOT = PROJECT_ROOT.parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

os.environ["WEATHER_RESEARCH_INCLUDE_DIRECT_NBM"] = "1"

STATION_ID = "KSEA"
PROVIDERS = ("gfs", "hrrr", "nbm")
TREND_COLUMNS = [
    "observed_temp_change_last_1h_f",
    "observed_temp_change_last_3h_f",
    "observed_morning_warmup_rate_f_per_hour",
    "observed_high_so_far_change_since_9am_f",
]
TIMING_MODE = "same_day_11am_live_safe"
FAST_MODE = False
OPTUNA_TRIALS = 30
STACK_OPTUNA_TRIALS = 30
OPTUNA_STARTUP_TRIALS = 15
STACK_OPTUNA_STARTUP_TRIALS = 15
OPTUNA_METRIC = "mae_f"
OPTUNA_VERBOSE = True
MODEL_VERSION = "station_high_regressor_v11_huber_ridge_stack"
PROJECT_ROOT
# Out:
# WindowsPath('D:/dev/weather-research')

# %%
import numpy as np
import pandas as pd

from src.export_station_stacking_v2_models import export_station_model_weights
from src.calibration.station_stacking import (
    StationStackingConfig,
    V11_DROPPED_FEATURE_COLUMNS,
    V11_FEATURE_COLUMNS,
    YEAR_SPLIT_EXPANDING_FOLDS,
    missing_model_dependencies,
    provider_availability,
    run_station_year_split_experiment,
)

# %% [markdown]
# ## V11 Contract
#
# `feature_version="v11"` keeps the v9 feature contract and remaining-warmup target, but trains base learners with Huber-style objectives while retaining the ridge stack selected by validation MAE.

# %%
fold_spec = pd.DataFrame(
    [
        {
            "fold": fold.name,
            "train_start_year": fold.train_start_year,
            "train_end_year": fold.train_end_year,
            "validation_year": fold.validation_year,
        }
        for fold in YEAR_SPLIT_EXPANDING_FOLDS
    ]
)

fold_spec
# Out:
#                      fold  train_start_year  train_end_year  validation_year
# 0  fold_2021_2023_to_2024              2021            2023             2024
# 1  fold_2021_2024_to_2025              2021            2024             2025

# %%
V11_FEATURE_COLUMNS, sorted(V11_DROPPED_FEATURE_COLUMNS)
# Out:
# (['v2_recent_heat_anomaly_f',
#   'v2_recent_heat_momentum_f',
#   'v2_morning_warmup_to_consensus_f',
#   'v2_consensus_minus_7d_actual_f',
#   'v2_spread_per_warmup_f',
#   'v2_humidity_warmup_interaction',
#   'v3_high_so_far_above_current_f',
#   'v3_remaining_warmup_from_high_so_far_f',
#   'v3_high_so_far_minus_lag_1d_f',
#   'v3_high_so_far_minus_7d_actual_f',
#   'v3_remaining_warmup_per_spread_f',
#   'v3_humidity_remaining_warmup_interaction',
#   'v4_forecast_precip_total_mean_mm',
#   'v4_forecast_precip_total_max_mm',
#   'v4_forecast_precip_total_spread_mm',
#   'v4_forecast_precip_max_1h_mean_mm',
#   'v4_forecast_precip_hours_mean',
#   'v4_forecast_precip_intensity_mean',
#   'v4_forecast_precip_intensity_max',
#   'v4_any_forecast_precip',
#   'v4_all_forecast_precip',
#   'v4_observed_precip_any',
#   'v4_observed_precip_recent_mm_est',
#   'v4_forecast_total_minus_observed_recent_mm',
#   'v4_forecast_observed_precip_match',
#   'v4_forecast_wet_observed_dry',
#   'v4_observed_wet_forecast_dry',
#   'v4_precip_humidity_interaction',
#   'v4_precip_remaining_warmup_interaction',
#   'observed_temp_change_last_1h_f',
#   'observed_temp_change_last_3h_f',
#   'observed_morning_warmup_rate_f_per_hour',
#   'observed_high_so_far_change_since_9am_f',
#   'v8_provider_max_remaining_from_high_so_far_f',
#   'v8_provider_min_remaining_from_high_so_far_f',
#   'v8_provider_median_remaining_from_high_so_far_f',
#   'v8_provider_spread_per_remaining_warmup_f',
#   'v8_month_remaining_warmup_mean_f',
#   'v8_month_remaining_warmup_count',
#   'v8_recent_remaining_warmup_7d_mean_f',
#   'v8_recent_remaining_warmup_30d_mean_f',
#   'v8_provider_mean_remaining_vs_month_normal_f',
#   'v8_cloud_cover_mean_remaining_warmup_interaction',
#   'v8_cloud_cover_max_remaining_warmup_interaction',
#   'v8_precip_total_remaining_warmup_interaction',
#   'v8_precip_max_1h_remaining_warmup_interaction',
#   'v8_wind_speed_mean_remaining_warmup_interaction',
#   'v8_wind_gust_max_remaining_warmup_interaction',
#   'v8_forecast_dewpoint_mean_f',
#   'v8_forecast_dewpoint_depression_mean_f',
#   'v8_dewpoint_mean_remaining_warmup_interaction',
#   'v8_dewpoint_depression_remaining_warmup_interaction',
#   'climatology_high_10y_f',
#   'climatology_high_10y_std_f',
#   'climatology_high_10y_count',
#   'provider_mean_minus_climatology_10y_f',
#   'observed_temp_minus_climatology_10y_f',
#   'observed_high_so_far_minus_climatology_10y_f'],
#  ['actual_minus_climatology_10y_f_DIAGNOSTIC_ONLY',
#   'climatology_source_end_year',
#   'climatology_source_start_year',
#   'gfs_as_of_hour_local',
#   'gfs_available',
#   'gfs_forecast_window_hours',
#   'gfs_grid_dist_km_mean',
#   'gfs_horizon_hours',
#   'gfs_hrrr_grid_dist_km_mean_abs_diff_f',
#   'gfs_hrrr_grid_dist_km_mean_diff_f',
#   'gfs_issue_hour_utc',
#   'gfs_missing',
#   'hrrr_as_of_hour_local',
#   'hrrr_available',
#   'hrrr_forecast_hour_max',
#   'hrrr_forecast_hour_min',
#   'hrrr_forecast_lead_hours',
#   'hrrr_forecast_window_hours',
#   'hrrr_grid_dist_km_mean',
#   'hrrr_horizon_hours',
#   'hrrr_issue_hour_local',
#   'hrrr_issue_hour_utc',
#   'hrrr_missing',
#   'is_active_polymarket_station',
#   'lat',
#   'lon',
#   'nbm_as_of_hour_local',
#   'nbm_available',
#   'nbm_forecast_window_hours',
#   'nbm_horizon_hours',
#   'nbm_issue_hour_local',
#   'nbm_issue_hour_utc',
#   'nbm_missing',
#   'observed_fetch_status',
#   'observed_observation_type',
#   'observed_pressure_source',
#   'provider_count_available',
#   'year'])

# %% [markdown]
# ## Data Availability

# %%
availability = provider_availability(
    PROJECT_ROOT,
    timing_mode=TIMING_MODE,
    providers=PROVIDERS,
)

availability.loc[availability["station_id"].eq(STATION_ID)]
# Out:
#    station_id provider  row_count first_contract_date last_contract_date
# 24       KSEA      gfs       1982          2021-01-01         2026-06-10
# 25       KSEA     hrrr       1987          2021-01-01         2026-06-10
# 26       KSEA      nbm       1986          2021-01-01         2026-06-10

# %% [markdown]
# ## Model Scores

# %%
missing_packages = missing_model_dependencies()
if missing_packages:
    raise ImportError(
        "Missing station-stacking ML packages: "
        + ", ".join(missing_packages)
        + ". Install them with: python -m pip install -r requirements.txt"
    )

config = StationStackingConfig(
    station_id=STATION_ID,
    project_root=PROJECT_ROOT,
    timing_mode=TIMING_MODE,
    providers=PROVIDERS,
    fast_mode=FAST_MODE,
    optuna_trials=OPTUNA_TRIALS,
    stack_optuna_trials=STACK_OPTUNA_TRIALS,
    optuna_startup_trials=OPTUNA_STARTUP_TRIALS,
    stack_optuna_startup_trials=STACK_OPTUNA_STARTUP_TRIALS,
    optuna_metric=OPTUNA_METRIC,
    optuna_verbose=OPTUNA_VERBOSE,
    feature_version="v11",
    target_mode="remaining_warmup",
    base_model_methods=("xgboost", "lightgbm", "catboost"),
    stack_enabled=True,
    hyperparameter_space="wide",
    year_split_folds=YEAR_SPLIT_EXPANDING_FOLDS,
    year_split_test_train_years=(2021, 2025),
    year_split_test_year=2026,
    output_dir=PROJECT_ROOT / "data" / "calibration" / "station_stacking_v11",
)

config.resolved_optuna_storage_path()
# Out:
# WindowsPath('D:/dev/weather-research/data/calibration/station_stacking_v11/KSEA_optuna.sqlite3')

# %%
result = run_station_year_split_experiment(config)
result.scoreboard
# Out:
# [I 2026-06-17 02:34:31,683] A new study created in RDB with name: KSEA_v11_remaining_warmup_base_xgboost_mae_f
# [I 2026-06-17 02:34:41,818] Trial 0 finished with value: 1.7198530089126756 and parameters: {'n_estimators': 1342, 'learning_rate': 0.19043899115982607, 'max_depth': 9, 'min_child_weight': 2.481040974867813, 'gamma': 2.340279606636548, 'subsample': 0.4513964382185317, 'colsample_bytree': 0.3877543479093296, 'reg_alpha': 2.478071022662141, 'reg_lambda': 0.6132587025321562}. Best is trial 0 with value: 1.7198530089126756.
# [I 2026-06-17 02:36:41,282] Trial 1 finished with value: 1.4967418676110047 and parameters: {'n_estimators': 2493, 'learning_rate': 0.001120367191095075, 'max_depth': 12, 'min_child_weight': 21.368329072358772, 'gamma': 3.185086660174142, 'subsample': 0.4681862286846154, 'colsample_bytree': 0.46921293140473197, 'reg_alpha': 4.476173538513514e-07, 'reg_lambda': 0.20253776634919213}. Best is trial 1 with value: 1.4967418676110047.
# [I 2026-06-17 02:37:27,285] Trial 2 finished with value: 1.6262277287659537 and parameters: {'n_estimators': 1540, 'learning_rate': 0.004992867109217114, 'max_depth': 8, 'min_child_weight': 0.03613894271216528, 'gamma': 4.3821697280282725, 'subsample': 0.5881351981408995, 'colsample_bytree': 0.6464454897410734, 'reg_alpha': 0.26430874752361627, 'reg_lambda': 0.0018119678627933364}. Best is trial 1 with value: 1.4967418676110047.
# [I 2026-06-17 02:37:41,858] Trial 3 finished with value: 1.6322434975490634 and parameters: {'n_estimators': 1824, 'learning_rate': 0.026337502897485255, 'max_depth': 1, 'min_child_weight': 2.69264691008618, 'gamma': 2.557861855309373, 'subsample': 0.39228353544043165, 'colsample_bytree': 0.9667755992146666, 'reg_alpha': 38.6887231523051, 'reg_lambda': 12.408975837016275}. Best is trial 1 with value: 1.4967418676110047.
# [I 2026-06-17 02:38:43,145] Trial 4 finished with value: 1.6123226062653402 and parameters: {'n_estimators': 1101, 'learning_rate': 0.0017147936629846843, 'max_depth': 9, 'min_child_weight': 0.5762487216478605, 'gamma': 1.8305735226716824, 'subsample': 0.6718649915723256, 'colsample_bytree': 0.37235253872489193, 'reg_alpha': 8.162906555194692, 'reg_lambda': 0.004271500153828077}. Best is trial 1 with value: 1.4967418676110047.
# [I 2026-06-17 02:40:01,885] Trial 5 finished with value: 1.5839495041982992 and parameters: {'n_estimators': 2336, 'learning_rate': 0.00559067775661512, 'max_depth': 7, 'min_child_weight': 1.5375920235481764, 'gamma': 2.7728168328829055, 'subsample': 0.980230008046963, 'colsample_bytree': 0.8538363351847245, 'reg_alpha': 18.792618557420877, 'reg_lambda': 43.484449457612314}. Best is trial 1 with value: 1.4967418676110047.
# [I 2026-06-17 02:40:05,849] Trial 6 finished with value: 1.479543839011141 and parameters: {'n_estimators': 2113, 'learning_rate': 0.16240489353272883, 'max_depth': 2, 'min_child_weight': 0.06080390190296603, 'gamma': 0.678409333658071, 'subsample': 0.5614647149961218, 'colsample_bytree': 0.6026402382981633, 'reg_alpha': 1.8037999945880162e-07, 'reg_lambda': 16.668629892722056}. Best is trial 6 with value: 1.479543839011141.
# [I 2026-06-17 02:40:15,981] Trial 7 pruned.
# [I 2026-06-17 02:40:19,529] Trial 8 finished with value: 1.5409145669723294 and parameters: {'n_estimators': 69, 'learning_rate': 0.09024592169686073, 'max_depth': 9, 'min_child_weight': 8.241925264876453, 'gamma': 11.569055200289187, 'subsample': 0.39812902362715874, 'colsample_bytree': 0.5830027235537771, 'reg_alpha': 2.457133280848974e-09, 'reg_lambda': 27.44356809444336}. Best is trial 6 with value: 1.479543839011141.
# [I 2026-06-17 02:40:52,704] Trial 9 finished with value: 1.522605167713728 and parameters: {'n_estimators': 2201, 'learning_rate': 0.006215464818952927, 'max_depth': 1, 'min_child_weight': 0.17535949529764422, 'gamma': 4.877749830401205, 'subsample': 0.8242440159197416, 'colsample_bytree': 0.7644123563808884, 'reg_alpha': 4.4315220126915325, 'reg_lambda': 0.09450187118503514}. Best is trial 6 with value: 1.479543839011141.
# [I 2026-06-17 02:40:56,119] Trial 10 pruned.
# [I 2026-06-17 02:41:16,198] Trial 11 pruned.
# [I 2026-06-17 02:41:35,836] Trial 12 pruned.
# [I 2026-06-17 02:41:39,940] Trial 13 finished with value: 1.519352216681301 and parameters: {'n_estimators': 693, 'learning_rate': 0.13813474572232612, 'max_depth': 7, 'min_child_weight': 16.973078532467014, 'gamma': 13.4413694988524, 'subsample': 0.5567022587317115, 'colsample_bytree': 0.4215337509429899, 'reg_alpha': 5.435280359192946e-08, 'reg_lambda': 0.049115547267693904}. Best is trial 6 with value: 1.479543839011141.
# [I 2026-06-17 02:41:46,551] Trial 14 finished with value: 1.516840239992225 and parameters: {'n_estimators': 2872, 'learning_rate': 0.11587248002108354, 'max_depth': 1, 'min_child_weight': 1.1040511903162256, 'gamma': 6.261165047231685, 'subsample': 0.49437007680597467, 'colsample_bytree': 0.4279124887668938, 'reg_alpha': 1.125594744942969e-06, 'reg_lambda': 87.35792858155622}. Best is trial 6 with value: 1.479543839011141.
# [I 2026-06-17 02:41:48,694] Trial 15 pruned.
# [I 2026-06-17 02:42:46,988] Trial 16 finished with value: 1.5103069757669256 and parameters: {'n_estimators': 2598, 'learning_rate': 0.01867771620829029, 'max_depth': 4, 'min_child_weight': 38.248720272771735, 'gamma': 0.4706880742637828, 'subsample': 0.5486460363176647, 'colsample_bytree': 0.5135624770231518, 'reg_alpha': 1.7417636237940342e-10, 'reg_lambda': 194.33954617472529}. Best is trial 6 with value: 1.479543839011141.
# [I 2026-06-17 02:42:50,613] Trial 17 pruned.
# [I 2026-06-17 02:42:52,018] Trial 18 pruned.
# [I 2026-06-17 02:43:47,251] Trial 19 finished with value: 1.418881557885261 and parameters: {'n_estimators': 2685, 'learning_rate': 0.0032530471166634487, 'max_depth': 5, 'min_child_weight': 8.961761225226251, 'gamma': 9.466265153084475, 'subsample': 0.6102668472567698, 'colsample_bytree': 0.7132190789781543, 'reg_alpha': 0.00042812108624002234, 'reg_lambda': 0.011508452112407907}. Best is trial 19 with value: 1.418881557885261.
# [I 2026-06-17 02:44:21,650] Trial 20 finished with value: 1.5196836515059595 and parameters: {'n_estimators': 2881, 'learning_rate': 0.002906215880615357, 'max_depth': 3, 'min_child_weight': 0.31326424086561006, 'gamma': 9.42772778022373, 'subsample': 0.7691314920236245, 'colsample_bytree': 0.7423408073177311, 'reg_alpha': 0.002047007691626987, 'reg_lambda': 0.006310067170744174}. Best is trial 19 with value: 1.418881557885261.
# [I 2026-06-17 02:45:43,741] Trial 21 finished with value: 1.4283554620277323 and parameters: {'n_estimators': 2486, 'learning_rate': 0.0022121979518881733, 'max_depth': 5, 'min_child_weight': 10.914583415836889, 'gamma': 9.439929990447231, 'subsample': 0.5954516011197811, 'colsample_bytree': 0.8410128983023729, 'reg_alpha': 2.0353152116701198e-07, 'reg_lambda': 0.019797366381933718}. Best is trial 19 with value: 1.418881557885261.
# [I 2026-06-17 02:46:43,122] Trial 22 finished with value: 1.410841616565111 and parameters: {'n_estimators': 2020, 'learning_rate': 0.002625024324643962, 'max_depth': 5, 'min_child_weight': 6.490935814956495, 'gamma': 9.397183703274244, 'subsample': 0.6133583455759469, 'colsample_bytree': 0.8641898530160497, 'reg_alpha': 9.186953117814013e-05, 'reg_lambda': 0.013366013031110124}. Best is trial 22 with value: 1.410841616565111.
# [I 2026-06-17 02:47:38,436] Trial 23 finished with value: 1.4122229862828029 and parameters: {'n_estimators': 1755, 'learning_rate': 0.002726239717317172, 'max_depth': 5, 'min_child_weight': 6.236215251189249, 'gamma': 9.764092984700852, 'subsample': 0.6249686398025646, 'colsample_bytree': 0.8701740261987213, 'reg_alpha': 6.671104833067711e-05, 'reg_lambda': 0.02274409198389545}. Best is trial 22 with value: 1.410841616565111.
# [I 2026-06-17 02:48:16,616] Trial 24 finished with value: 1.4096485742411384 and parameters: {'n_estimators': 1738, 'learning_rate': 0.0030737134044092167, 'max_depth': 5, 'min_child_weight': 5.063372770920694, 'gamma': 9.907334339075405, 'subsample': 0.6347883594776687, 'colsample_bytree': 0.8963317369718479, 'reg_alpha': 5.2519139101645306e-05, 'reg_lambda': 0.0004592621975108455}. Best is trial 24 with value: 1.4096485742411384.
# [I 2026-06-17 02:48:24,597] Trial 25 finished with value: 1.4147603011807666 and parameters: {'n_estimators': 1582, 'learning_rate': 0.009499718688992664, 'max_depth': 6, 'min_child_weight': 4.736608619736662, 'gamma': 10.495253407411422, 'subsample': 0.7167873797237406, 'colsample_bytree': 0.9109641853931965, 'reg_alpha': 5.828207759975067e-05, 'reg_lambda': 0.00026765487478149587}. Best is trial 24 with value: 1.4096485742411384.
# [I 2026-06-17 02:48:42,876] Trial 26 finished with value: 1.4060667009690246 and parameters: {'n_estimators': 1728, 'learning_rate': 0.0031094998207049844, 'max_depth': 6, 'min_child_weight': 4.760105346120291, 'gamma': 7.668214632466782, 'subsample': 0.6372491018266162, 'colsample_bytree': 0.832761424438907, 'reg_alpha': 0.02688560590051551, 'reg_lambda': 0.0006752118424947049}. Best is trial 26 with value: 1.4060667009690246.
# [I 2026-06-17 02:48:52,781] Trial 27 finished with value: 1.4045574284530713 and parameters: {'n_estimators': 1964, 'learning_rate': 0.008238731473111051, 'max_depth': 6, 'min_child_weight': 3.9667484034756932, 'gamma': 7.594113571126056, 'subsample': 0.7143328631624752, 'colsample_bytree': 0.8054045890353372, 'reg_alpha': 0.019016590723861325, 'reg_lambda': 0.00049760138010915}. Best is trial 27 with value: 1.4045574284530713.
# [I 2026-06-17 02:48:57,302] Trial 28 pruned.
# [I 2026-06-17 02:48:58,992] Trial 29 pruned.
# [I 2026-06-17 02:48:59,131] A new study created in RDB with name: KSEA_v11_remaining_warmup_base_lightgbm_mae_f
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-17 02:49:03,264] Trial 0 finished with value: 1.4488021471894363 and parameters: {'n_estimators': 447, 'learning_rate': 0.028873871707375695, 'num_leaves': 71, 'max_depth': 5, 'min_child_samples': 83, 'min_split_gain': 4.295687454742988, 'bagging_fraction': 0.7829586385137167, 'bagging_freq': 4, 'feature_fraction': 0.3688589858758342, 'lambda_l1': 0.06382334403151436, 'lambda_l2': 0.03080292177315921, 'huber_alpha': 0.95}. Best is trial 0 with value: 1.4488021471894363.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-17 02:49:08,345] Trial 1 finished with value: 1.673339121904676 and parameters: {'n_estimators': 812, 'learning_rate': 0.009357081249483435, 'num_leaves': 164, 'max_depth': 2, 'min_child_samples': 211, 'min_split_gain': 4.244695738724308, 'bagging_fraction': 0.9814523094330022, 'bagging_freq': 3, 'feature_fraction': 0.9704172813206324, 'lambda_l1': 2.234088279028776e-05, 'lambda_l2': 1.6594154120142632, 'huber_alpha': 0.85}. Best is trial 0 with value: 1.4488021471894363.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-17 02:49:09,816] Trial 2 finished with value: 3.052251688038379 and parameters: {'n_estimators': 67, 'learning_rate': 0.02007090910723469, 'num_leaves': 246, 'max_depth': 10, 'min_child_samples': 245, 'min_split_gain': 4.543313789155439, 'bagging_fraction': 0.9415994992571017, 'bagging_freq': 4, 'feature_fraction': 0.41761231740559585, 'lambda_l1': 1.4824332354449863e-08, 'lambda_l2': 101.18939970488272, 'huber_alpha': 0.85}. Best is trial 0 with value: 1.4488021471894363.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-17 02:49:11,530] Trial 3 finished with value: 1.6214120229614135 and parameters: {'n_estimators': 1000, 'learning_rate': 0.1413663860910666, 'num_leaves': 109, 'max_depth': 7, 'min_child_samples': 249, 'min_split_gain': 3.678635407535604, 'bagging_fraction': 0.6392899181182937, 'bagging_freq': 4, 'feature_fraction': 0.6173160679063129, 'lambda_l1': 0.052948773379180566, 'lambda_l2': 0.032760577756785814, 'huber_alpha': 0.85}. Best is trial 0 with value: 1.4488021471894363.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-17 02:49:15,130] Trial 4 finished with value: 2.675283410815836 and parameters: {'n_estimators': 761, 'learning_rate': 0.003003151716938294, 'num_leaves': 409, 'max_depth': 5, 'min_child_samples': 165, 'min_split_gain': 1.498083879035124, 'bagging_fraction': 0.44391094597483866, 'bagging_freq': 3, 'feature_fraction': 0.5516751924489833, 'lambda_l1': 8.332516750396116e-08, 'lambda_l2': 0.5077631895453656, 'huber_alpha': 0.85}. Best is trial 0 with value: 1.4488021471894363.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-17 02:49:16,954] Trial 5 finished with value: 1.4257228092125471 and parameters: {'n_estimators': 404, 'learning_rate': 0.18314620854695027, 'num_leaves': 260, 'max_depth': 13, 'min_child_samples': 51, 'min_split_gain': 2.972245934092154, 'bagging_fraction': 0.9775155780902212, 'bagging_freq': 7, 'feature_fraction': 0.365709606237354, 'lambda_l1': 5.9654059281874116e-05, 'lambda_l2': 0.006859036422781172, 'huber_alpha': 0.95}. Best is trial 5 with value: 1.4257228092125471.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-17 02:49:19,611] Trial 6 finished with value: 1.3995599212358831 and parameters: {'n_estimators': 3052, 'learning_rate': 0.13146898336096702, 'num_leaves': 489, 'max_depth': 11, 'min_child_samples': 47, 'min_split_gain': 2.173391605434026, 'bagging_fraction': 0.9258346721061177, 'bagging_freq': 2, 'feature_fraction': 0.6381532515738396, 'lambda_l1': 0.002530717742378322, 'lambda_l2': 0.0004479476588817844, 'huber_alpha': 0.95}. Best is trial 6 with value: 1.3995599212358831.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-17 02:49:21,539] Trial 7 finished with value: 1.5013956661842052 and parameters: {'n_estimators': 2519, 'learning_rate': 0.18104669093362824, 'num_leaves': 399, 'max_depth': 4, 'min_child_samples': 227, 'min_split_gain': 2.761320735057018, 'bagging_fraction': 0.8991836269249566, 'bagging_freq': 7, 'feature_fraction': 0.8888248313104422, 'lambda_l1': 5.374969144858311e-06, 'lambda_l2': 0.5877618471031133, 'huber_alpha': 0.85}. Best is trial 6 with value: 1.3995599212358831.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-17 02:49:31,863] Trial 8 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-17 02:49:35,526] Trial 9 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-17 02:49:59,472] Trial 10 finished with value: 1.506349273610906 and parameters: {'n_estimators': 2941, 'learning_rate': 0.007104579859769969, 'num_leaves': 424, 'max_depth': 2, 'min_child_samples': 2, 'min_split_gain': 4.6220887565718325, 'bagging_fraction': 0.7880566131549542, 'bagging_freq': 7, 'feature_fraction': 0.661678263936434, 'lambda_l1': 8.121756387194875e-09, 'lambda_l2': 100.08386764870838, 'huber_alpha': 0.9}. Best is trial 6 with value: 1.3995599212358831.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-17 02:50:01,781] Trial 11 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-17 02:50:05,572] Trial 12 finished with value: 1.4418885742317515 and parameters: {'n_estimators': 3404, 'learning_rate': 0.03866939016656176, 'num_leaves': 50, 'max_depth': 9, 'min_child_samples': 54, 'min_split_gain': 3.975378174997817, 'bagging_fraction': 0.5776988884481041, 'bagging_freq': 4, 'feature_fraction': 0.8073004449855348, 'lambda_l1': 1.1469173194560514e-08, 'lambda_l2': 0.6127644589218547, 'huber_alpha': 0.85}. Best is trial 6 with value: 1.3995599212358831.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-17 02:50:06,584] Trial 13 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-17 02:50:16,422] Trial 14 finished with value: 1.4710050630198477 and parameters: {'n_estimators': 2440, 'learning_rate': 0.007089782197514698, 'num_leaves': 92, 'max_depth': 2, 'min_child_samples': 83, 'min_split_gain': 1.7789721315624618, 'bagging_fraction': 0.6616016865596667, 'bagging_freq': 5, 'feature_fraction': 0.4058624376375402, 'lambda_l1': 3.60867143771307e-07, 'lambda_l2': 0.0019132656772962273, 'huber_alpha': 0.9}. Best is trial 6 with value: 1.3995599212358831.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-17 02:50:21,167] Trial 15 finished with value: 1.4306988232530995 and parameters: {'n_estimators': 1596, 'learning_rate': 0.07412684021464837, 'num_leaves': 490, 'max_depth': 14, 'min_child_samples': 54, 'min_split_gain': 0.3349947053308182, 'bagging_fraction': 0.8356054383416602, 'bagging_freq': 1, 'feature_fraction': 0.4928412115082472, 'lambda_l1': 5.944760726571435, 'lambda_l2': 0.004183303285898086, 'huber_alpha': 0.95}. Best is trial 6 with value: 1.3995599212358831.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-17 02:50:28,062] Trial 16 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-17 02:50:30,066] Trial 17 finished with value: 1.4444139526986728 and parameters: {'n_estimators': 1939, 'learning_rate': 0.06601040845187384, 'num_leaves': 335, 'max_depth': 11, 'min_child_samples': 109, 'min_split_gain': 0.746195463071214, 'bagging_fraction': 0.7435257664196396, 'bagging_freq': 2, 'feature_fraction': 0.5028717448517069, 'lambda_l1': 0.0010276678078745551, 'lambda_l2': 0.021235591088357413, 'huber_alpha': 0.95}. Best is trial 6 with value: 1.3995599212358831.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-17 02:50:32,762] Trial 18 finished with value: 1.4309992217897407 and parameters: {'n_estimators': 3495, 'learning_rate': 0.08139171960739669, 'num_leaves': 509, 'max_depth': 8, 'min_child_samples': 34, 'min_split_gain': 2.877766570869717, 'bagging_fraction': 0.8859850943498181, 'bagging_freq': 2, 'feature_fraction': 0.7648740586535334, 'lambda_l1': 1.905088566882004, 'lambda_l2': 0.0006347269765127932, 'huber_alpha': 0.75}. Best is trial 6 with value: 1.3995599212358831.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-17 02:50:33,864] Trial 19 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-17 02:50:36,563] Trial 20 finished with value: 1.434905281506402 and parameters: {'n_estimators': 1190, 'learning_rate': 0.10971232271434933, 'num_leaves': 462, 'max_depth': 10, 'min_child_samples': 82, 'min_split_gain': 2.2764986429331424, 'bagging_fraction': 0.9993031764129383, 'bagging_freq': 6, 'feature_fraction': 0.5629966097897123, 'lambda_l1': 0.0009758284285596601, 'lambda_l2': 0.10372651727216303, 'huber_alpha': 0.95}. Best is trial 6 with value: 1.3995599212358831.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-17 02:50:39,221] Trial 21 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-17 02:50:42,538] Trial 22 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-17 02:50:48,929] Trial 23 finished with value: 1.423416366587532 and parameters: {'n_estimators': 509, 'learning_rate': 0.03901044045346463, 'num_leaves': 459, 'max_depth': 12, 'min_child_samples': 65, 'min_split_gain': 0.8668999334448991, 'bagging_fraction': 0.7270927241354869, 'bagging_freq': 1, 'feature_fraction': 0.4291412815594152, 'lambda_l1': 1.4370923439864658, 'lambda_l2': 0.007103172694272659, 'huber_alpha': 0.95}. Best is trial 6 with value: 1.3995599212358831.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-17 02:50:50,958] Trial 24 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-17 02:50:52,900] Trial 25 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-17 02:50:55,415] Trial 26 finished with value: 1.4268977689154871 and parameters: {'n_estimators': 712, 'learning_rate': 0.24000476731171647, 'num_leaves': 357, 'max_depth': 10, 'min_child_samples': 19, 'min_split_gain': 3.542897352215046, 'bagging_fraction': 0.705594647914993, 'bagging_freq': 1, 'feature_fraction': 0.35013700045262364, 'lambda_l1': 0.009699500084375017, 'lambda_l2': 0.0007547924577895202, 'huber_alpha': 0.9}. Best is trial 6 with value: 1.3995599212358831.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-17 02:50:59,918] Trial 27 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-17 02:51:03,985] Trial 28 finished with value: 1.4184957852638782 and parameters: {'n_estimators': 1008, 'learning_rate': 0.04937734270764415, 'num_leaves': 305, 'max_depth': 13, 'min_child_samples': 65, 'min_split_gain': 1.3039194598800457, 'bagging_fraction': 0.5812673264333954, 'bagging_freq': 2, 'feature_fraction': 0.7076695080217358, 'lambda_l1': 2.507543267081455e-06, 'lambda_l2': 0.07469043403059741, 'huber_alpha': 0.95}. Best is trial 6 with value: 1.3995599212358831.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-17 02:51:08,083] Trial 29 finished with value: 1.4249748186253595 and parameters: {'n_estimators': 1337, 'learning_rate': 0.04329637143560553, 'num_leaves': 302, 'max_depth': 7, 'min_child_samples': 68, 'min_split_gain': 1.267854877530277, 'bagging_fraction': 0.6229796650734096, 'bagging_freq': 2, 'feature_fraction': 0.7072665477111966, 'lambda_l1': 5.045739081635067e-07, 'lambda_l2': 0.07169871770170695, 'huber_alpha': 0.95}. Best is trial 6 with value: 1.3995599212358831.
# [I 2026-06-17 02:51:08,209] A new study created in RDB with name: KSEA_v11_remaining_warmup_base_catboost_mae_f
# [I 2026-06-17 03:00:33,850] Trial 0 finished with value: 1.620479529445583 and parameters: {'iterations': 2931, 'learning_rate': 0.001783588943232587, 'depth': 10, 'l2_leaf_reg': 0.9942958882300413, 'random_strength': 7.186216756161439, 'bagging_temperature': 12.184767612363034, 'border_count': 110, 'rsm': 0.6158971964095841, 'huber_delta': 1.5}. Best is trial 0 with value: 1.620479529445583.
# [I 2026-06-17 03:11:01,478] Trial 1 finished with value: 1.8147051720916134 and parameters: {'iterations': 801, 'learning_rate': 0.19767902101650964, 'depth': 12, 'l2_leaf_reg': 75.05056513807031, 'random_strength': 12.92821124806787, 'bagging_temperature': 4.276496242612171, 'border_count': 168, 'rsm': 0.4404450637901872, 'huber_delta': 1.0}. Best is trial 0 with value: 1.620479529445583.
# [I 2026-06-17 03:11:18,750] Trial 2 finished with value: 1.7449313006320222 and parameters: {'iterations': 1992, 'learning_rate': 0.0024079350849750287, 'depth': 3, 'l2_leaf_reg': 0.118485976001343, 'random_strength': 4.058751860003342, 'bagging_temperature': 9.103785934457758, 'border_count': 206, 'rsm': 0.994034742637508, 'huber_delta': 0.5}. Best is trial 0 with value: 1.620479529445583.
# [I 2026-06-17 03:22:13,655] Trial 3 finished with value: 1.8565205709406407 and parameters: {'iterations': 3095, 'learning_rate': 0.05508623515899769, 'depth': 11, 'l2_leaf_reg': 18.082710740309665, 'random_strength': 13.948598364083836, 'bagging_temperature': 18.60205606816345, 'border_count': 227, 'rsm': 0.4117317891426977, 'huber_delta': 3.0}. Best is trial 0 with value: 1.620479529445583.
# [I 2026-06-17 03:22:30,058] Trial 4 finished with value: 1.553812593285432 and parameters: {'iterations': 3146, 'learning_rate': 0.0024764229908984673, 'depth': 3, 'l2_leaf_reg': 0.6951779671472356, 'random_strength': 6.148451176512449, 'bagging_temperature': 8.441103735088014, 'border_count': 95, 'rsm': 0.7192489923988105, 'huber_delta': 2.0}. Best is trial 4 with value: 1.553812593285432.
# [I 2026-06-17 03:22:34,932] Trial 5 finished with value: 1.618902368302767 and parameters: {'iterations': 2996, 'learning_rate': 0.04169299311145666, 'depth': 2, 'l2_leaf_reg': 0.6483636109972302, 'random_strength': 11.284989840243444, 'bagging_temperature': 11.881552589055849, 'border_count': 179, 'rsm': 0.7610806862514128, 'huber_delta': 0.5}. Best is trial 4 with value: 1.553812593285432.
# [I 2026-06-17 03:22:36,483] Trial 6 pruned.
# [I 2026-06-17 03:22:39,058] Trial 7 finished with value: 1.6695004553285193 and parameters: {'iterations': 2269, 'learning_rate': 0.05988786419186062, 'depth': 3, 'l2_leaf_reg': 0.8727148674658863, 'random_strength': 13.785080578883292, 'bagging_temperature': 3.643240241026453, 'border_count': 16, 'rsm': 0.5239102067389221, 'huber_delta': 0.5}. Best is trial 4 with value: 1.553812593285432.
# [I 2026-06-17 03:22:52,944] Trial 8 pruned.
# [I 2026-06-17 03:24:27,640] Trial 9 pruned.
# [I 2026-06-17 03:25:26,827] Trial 10 pruned.
# [I 2026-06-17 03:25:47,085] Trial 11 finished with value: 1.553752578107555 and parameters: {'iterations': 2772, 'learning_rate': 0.014522829031783214, 'depth': 5, 'l2_leaf_reg': 15.987388321276002, 'random_strength': 11.591109950971106, 'bagging_temperature': 7.790667047006705, 'border_count': 126, 'rsm': 0.7500006952294106, 'huber_delta': 5.0}. Best is trial 11 with value: 1.553752578107555.
# [I 2026-06-17 03:26:45,114] Trial 12 pruned.
# [I 2026-06-17 03:26:54,043] Trial 13 pruned.
# [I 2026-06-17 03:27:03,738] Trial 14 finished with value: 1.5773656255128823 and parameters: {'iterations': 2033, 'learning_rate': 0.03406017942217813, 'depth': 3, 'l2_leaf_reg': 2.8273302406131626, 'random_strength': 2.5986858551767766, 'bagging_temperature': 5.630188860588947, 'border_count': 58, 'rsm': 0.9026140460549269, 'huber_delta': 1.0}. Best is trial 11 with value: 1.553752578107555.
# [I 2026-06-17 03:27:10,276] Trial 15 pruned.
# [I 2026-06-17 03:28:02,267] Trial 16 finished with value: 1.5466463589740855 and parameters: {'iterations': 3416, 'learning_rate': 0.006424948471040994, 'depth': 5, 'l2_leaf_reg': 197.98083807490883, 'random_strength': 17.110130348053506, 'bagging_temperature': 0.2920642424315254, 'border_count': 68, 'rsm': 0.7385632694163883, 'huber_delta': 2.0}. Best is trial 16 with value: 1.5466463589740855.
# [I 2026-06-17 03:29:15,234] Trial 17 finished with value: 1.514745465404293 and parameters: {'iterations': 3466, 'learning_rate': 0.008839187675884689, 'depth': 6, 'l2_leaf_reg': 181.94585851916037, 'random_strength': 16.574794818938415, 'bagging_temperature': 0.7402526726861892, 'border_count': 55, 'rsm': 0.8398125158187049, 'huber_delta': 2.0}. Best is trial 17 with value: 1.514745465404293.
# [I 2026-06-17 03:30:10,153] Trial 18 pruned.
# [I 2026-06-17 03:31:41,679] Trial 19 pruned.
# [I 2026-06-17 03:31:51,836] Trial 20 pruned.
# [I 2026-06-17 03:32:10,254] Trial 21 finished with value: 1.5095267427608898 and parameters: {'iterations': 2696, 'learning_rate': 0.016814137239349623, 'depth': 5, 'l2_leaf_reg': 15.79990078921059, 'random_strength': 14.918808685209598, 'bagging_temperature': 1.5669231220504591, 'border_count': 124, 'rsm': 0.7434671082087949, 'huber_delta': 5.0}. Best is trial 21 with value: 1.5095267427608898.
# [I 2026-06-17 03:32:21,769] Trial 22 pruned.
# [I 2026-06-17 03:32:32,743] Trial 23 finished with value: 1.4992184161107924 and parameters: {'iterations': 3309, 'learning_rate': 0.010024855338442946, 'depth': 4, 'l2_leaf_reg': 34.001309628112345, 'random_strength': 15.359653239864226, 'bagging_temperature': 1.929742968711332, 'border_count': 18, 'rsm': 0.9156489291642014, 'huber_delta': 5.0}. Best is trial 23 with value: 1.4992184161107924.
# [I 2026-06-17 03:32:48,051] Trial 24 finished with value: 1.4991782969276977 and parameters: {'iterations': 1641, 'learning_rate': 0.012140770289001844, 'depth': 6, 'l2_leaf_reg': 30.30738253798325, 'random_strength': 18.233665875630674, 'bagging_temperature': 2.6775829721974436, 'border_count': 22, 'rsm': 0.8997135920370296, 'huber_delta': 5.0}. Best is trial 24 with value: 1.4991782969276977.
# [I 2026-06-17 03:32:53,909] Trial 25 finished with value: 1.5127372676653335 and parameters: {'iterations': 1536, 'learning_rate': 0.02932907512708471, 'depth': 4, 'l2_leaf_reg': 32.167354307895316, 'random_strength': 18.612244465693077, 'bagging_temperature': 3.4623201183665726, 'border_count': 21, 'rsm': 0.9253493971316055, 'huber_delta': 5.0}. Best is trial 24 with value: 1.4991782969276977.
# [I 2026-06-17 03:32:55,559] Trial 26 pruned.
# [I 2026-06-17 03:33:04,759] Trial 27 pruned.
# [I 2026-06-17 03:33:14,592] Trial 28 finished with value: 1.550183822398472 and parameters: {'iterations': 1824, 'learning_rate': 0.010556645166493534, 'depth': 4, 'l2_leaf_reg': 12.091750165012813, 'random_strength': 12.230131713146038, 'bagging_temperature': 6.514585023772553, 'border_count': 161, 'rsm': 0.8023593550445223, 'huber_delta': 5.0}. Best is trial 24 with value: 1.4991782969276977.
# [I 2026-06-17 03:33:44,422] Trial 29 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-17 03:34:24,951] A new study created in RDB with name: KSEA_v11_remaining_warmup_stack_ridge_stack_mae_f
# [I 2026-06-17 03:34:25,297] Trial 0 finished with value: 1.317761761587896 and parameters: {'feature_set': 'models_only', 'alpha': 1061.6032395070417, 'fit_intercept': False}. Best is trial 0 with value: 1.317761761587896.
# [I 2026-06-17 03:34:25,594] Trial 1 finished with value: 1.3095325273919003 and parameters: {'feature_set': 'models_only', 'alpha': 29.13552742298041, 'fit_intercept': False}. Best is trial 1 with value: 1.3095325273919003.
# [I 2026-06-17 03:34:25,891] Trial 2 finished with value: 1.3070286318983382 and parameters: {'feature_set': 'models_only', 'alpha': 0.0005260598165963439, 'fit_intercept': True}. Best is trial 2 with value: 1.3070286318983382.
# [I 2026-06-17 03:34:26,191] Trial 3 finished with value: 1.307320692974421 and parameters: {'feature_set': 'models_only', 'alpha': 2.2872748315304782e-05, 'fit_intercept': False}. Best is trial 2 with value: 1.3070286318983382.
# [I 2026-06-17 03:34:26,503] Trial 4 finished with value: 1.335386144625438 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 1013.2424299869091, 'fit_intercept': True}. Best is trial 2 with value: 1.3070286318983382.
# [I 2026-06-17 03:34:26,776] Trial 5 finished with value: 1.3293447566507337 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 826.0185608286423, 'fit_intercept': True}. Best is trial 2 with value: 1.3070286318983382.
# [I 2026-06-17 03:34:27,065] Trial 6 finished with value: 1.3034706470371533 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 3.929417958656645e-06, 'fit_intercept': True}. Best is trial 6 with value: 1.3034706470371533.
# [I 2026-06-17 03:34:27,352] Trial 7 finished with value: 1.303527046476173 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 0.8901780240435773, 'fit_intercept': True}. Best is trial 6 with value: 1.3034706470371533.
# [I 2026-06-17 03:34:27,633] Trial 8 finished with value: 1.314453071881053 and parameters: {'feature_set': 'models_only', 'alpha': 2828.538706546869, 'fit_intercept': False}. Best is trial 6 with value: 1.3034706470371533.
# [I 2026-06-17 03:34:27,905] Trial 9 finished with value: 1.3099348447673633 and parameters: {'feature_set': 'models_only', 'alpha': 35.97860619804126, 'fit_intercept': False}. Best is trial 6 with value: 1.3034706470371533.
# [I 2026-06-17 03:34:28,186] Trial 10 finished with value: 1.3070285808993376 and parameters: {'feature_set': 'models_only', 'alpha': 1.8087400416300714e-05, 'fit_intercept': True}. Best is trial 6 with value: 1.3034706470371533.
# [I 2026-06-17 03:34:28,438] Trial 11 finished with value: 1.3034706723279874 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 0.00039823854294263674, 'fit_intercept': True}. Best is trial 6 with value: 1.3034706470371533.
# [I 2026-06-17 03:34:28,723] Trial 12 finished with value: 1.3045159548719272 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 0.44507773547737556, 'fit_intercept': False}. Best is trial 6 with value: 1.3034706470371533.
# [I 2026-06-17 03:34:29,001] Trial 13 finished with value: 1.3044906503669336 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 7.810619739021528e-06, 'fit_intercept': False}. Best is trial 6 with value: 1.3034706470371533.
# [I 2026-06-17 03:34:29,261] Trial 14 finished with value: 1.3141583886174013 and parameters: {'feature_set': 'models_only', 'alpha': 150.11205568245393, 'fit_intercept': False}. Best is trial 6 with value: 1.3034706470371533.
# [I 2026-06-17 03:34:29,561] Trial 15 finished with value: 1.3034707747470715 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 0.001995097626521938, 'fit_intercept': True}. Best is trial 6 with value: 1.3034706470371533.
# [I 2026-06-17 03:34:29,843] Trial 16 finished with value: 1.3034706468495174 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 1.003907498952333e-06, 'fit_intercept': True}. Best is trial 16 with value: 1.3034706468495174.
# [I 2026-06-17 03:34:30,150] Trial 17 finished with value: 1.3034706468568777 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 1.1187009965901744e-06, 'fit_intercept': True}. Best is trial 16 with value: 1.3034706468495174.
# [I 2026-06-17 03:34:30,446] Trial 18 finished with value: 1.3034706468550412 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 1.0900491510483821e-06, 'fit_intercept': True}. Best is trial 16 with value: 1.3034706468495174.
# [I 2026-06-17 03:34:30,736] Trial 19 finished with value: 1.3034716060721498 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 0.014959252581730084, 'fit_intercept': True}. Best is trial 16 with value: 1.3034706468495174.
# [I 2026-06-17 03:34:31,031] Trial 20 finished with value: 1.303470657914726 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 0.00017352102127970534, 'fit_intercept': True}. Best is trial 16 with value: 1.3034706468495174.
# [I 2026-06-17 03:34:31,347] Trial 21 finished with value: 1.3034706468531554 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 1.0605834356931868e-06, 'fit_intercept': True}. Best is trial 16 with value: 1.3034706468495174.
# [I 2026-06-17 03:34:31,634] Trial 22 finished with value: 1.3034706468791761 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 1.4663482545761526e-06, 'fit_intercept': True}. Best is trial 16 with value: 1.3034706468495174.
# [I 2026-06-17 03:34:31,905] Trial 23 finished with value: 1.3034706500893913 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 5.151649671240562e-05, 'fit_intercept': True}. Best is trial 16 with value: 1.3034706468495174.
# [I 2026-06-17 03:34:32,188] Trial 24 finished with value: 1.3034706468509305 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 1.025959437817385e-06, 'fit_intercept': True}. Best is trial 16 with value: 1.3034706468495174.
# [I 2026-06-17 03:34:32,473] Trial 25 finished with value: 1.8049728348704221 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 35855.55721556136, 'fit_intercept': True}. Best is trial 16 with value: 1.3034706468495174.
# [I 2026-06-17 03:34:32,754] Trial 26 finished with value: 1.3034706501085516 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 5.1815263597705456e-05, 'fit_intercept': True}. Best is trial 16 with value: 1.3034706468495174.
# [I 2026-06-17 03:34:33,038] Trial 27 finished with value: 1.3034709765320462 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 0.0051414189456231345, 'fit_intercept': True}. Best is trial 16 with value: 1.3034706468495174.
# [I 2026-06-17 03:34:33,328] Trial 28 finished with value: 1.303470647154737 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 5.762587855690696e-06, 'fit_intercept': True}. Best is trial 16 with value: 1.3034706468495174.
# [I 2026-06-17 03:34:33,608] Trial 29 finished with value: 1.3034706516824455 and parameters: {'feature_set': 'models_plus_raw', 'alpha': 7.635369779970294e-05, 'fit_intercept': True}. Best is trial 16 with value: 1.3034706468495174.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# ...
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
#                   period       method  count     mae_f    rmse_f
# 0   validation_2024_2025      xgboost    729  1.442987  1.983413
# 1   validation_2024_2025     lightgbm    729  1.446512  1.983650
# 2   validation_2024_2025     catboost    729  1.543567  2.067032
# 3   validation_2024_2025     hrrr_raw    729  2.673930  3.334396
# 4   validation_2024_2025      gfs_raw    729  2.833972  3.760439
# 5              test_2026      xgboost    136  1.411409  1.766750
# 6              test_2026     lightgbm    136  1.356156  1.712203
# 7              test_2026     catboost    136  1.354835  1.761921
# 8              test_2026  ridge_stack    136  1.395297  1.730816
# 9              test_2026     hrrr_raw    136  2.924646  3.398490
# 10             test_2026      gfs_raw    136  2.022681  2.805218

# %%
exported_weights = export_station_model_weights(
    project_root=PROJECT_ROOT,
    station_id=STATION_ID,
    artifact_dir=config.resolved_output_dir(),
    model_version=MODEL_VERSION,
    timing_mode=config.timing_mode,
    providers=tuple(config.providers),
    feature_version=config.effective_feature_version,
    optuna_metric=config.effective_optuna_metric,
    target_mode=config.effective_target_mode,
    base_model_methods=tuple(config.effective_base_model_methods),
    stack_enabled=config.stack_enabled,
    source_pipeline="notebooks/experiments/station_stacking_v11",
)

exported_weights.bundle_path, exported_weights.manifest_path
# Out:
# (WindowsPath('D:/dev/weather-research/data/calibration/station_stacking_v11/model_weights/KSEA_station_high_regressor_v11_huber_ridge_stack.joblib'),
#  WindowsPath('D:/dev/weather-research/data/calibration/station_stacking_v11/model_weights/KSEA_station_high_regressor_v11_huber_ridge_stack.json'))

# %% [markdown]
# ## V11 Feature Coverage

# %%
v11_feature_coverage = (
    result.features[V11_FEATURE_COLUMNS]
    .notna()
    .mean()
    .mul(100)
    .sort_values(ascending=False)
    .rename("coverage_pct")
    .reset_index()
    .rename(columns={"index": "feature"})
)

v11_feature_coverage
# Out:
#                                               feature  coverage_pct
# 0                              v2_spread_per_warmup_f    100.000000
# 1                    v2_morning_warmup_to_consensus_f    100.000000
# 2              v3_remaining_warmup_from_high_so_far_f    100.000000
# 3                      v3_high_so_far_above_current_f    100.000000
# 4                      v2_humidity_warmup_interaction    100.000000
# 5                    v4_observed_precip_recent_mm_est    100.000000
# 6                        v4_forecast_wet_observed_dry    100.000000
# 7                   v4_forecast_observed_precip_match    100.000000
# 8            v3_humidity_remaining_warmup_interaction    100.000000
# 9                    v3_remaining_warmup_per_spread_f    100.000000
# 10                             v4_all_forecast_precip    100.000000
# 11                             v4_observed_precip_any    100.000000
# 12                             v4_any_forecast_precip    100.000000
# 13              observed_temp_minus_climatology_10y_f    100.000000
# 14                             climatology_high_10y_f    100.000000
# 15                         climatology_high_10y_std_f    100.000000
# 16                    v8_month_remaining_warmup_count    100.000000
# 17          v8_provider_spread_per_remaining_warmup_f    100.000000
# 18       v8_provider_min_remaining_from_high_so_far_f    100.000000
# 19    v8_provider_median_remaining_from_high_so_far_f    100.000000
# 20       v8_provider_max_remaining_from_high_so_far_f    100.000000
# 21            observed_high_so_far_change_since_9am_f    100.000000
# 22                     observed_temp_change_last_3h_f    100.000000
# 23            observed_morning_warmup_rate_f_per_hour    100.000000
# 24                     observed_temp_change_last_1h_f    100.000000
# 25                       v4_observed_wet_forecast_dry    100.000000
# 26              provider_mean_minus_climatology_10y_f    100.000000
# 27       observed_high_so_far_minus_climatology_10y_f    100.000000
# 28                         climatology_high_10y_count    100.000000
# 29                          v2_recent_heat_momentum_f     99.949084
# 30                   v3_high_so_far_minus_7d_actual_f     99.949084
# 31                     v2_consensus_minus_7d_actual_f     99.949084
# 32                      v3_high_so_far_minus_lag_1d_f     99.949084
# 33                           v2_recent_heat_anomaly_f     99.949084
# 34               v8_recent_remaining_warmup_7d_mean_f     99.898167
# 35              v8_recent_remaining_warmup_30d_mean_f     99.745418
# 36       v8_provider_mean_remaining_vs_month_normal_f     98.778004
# 37                   v8_month_remaining_warmup_mean_f     98.778004
# 38                 v4_forecast_precip_total_spread_mm      0.000000
# 39                  v4_forecast_precip_max_1h_mean_mm      0.000000
# 40                      v4_forecast_precip_hours_mean      0.000000
# 41                  v4_forecast_precip_intensity_mean      0.000000
# 42         v4_forecast_total_minus_observed_recent_mm      0.000000
# 43                   v4_forecast_precip_intensity_max      0.000000
# 44                   v4_forecast_precip_total_mean_mm      0.000000
# 45                    v4_forecast_precip_total_max_mm      0.000000
# 46             v4_precip_remaining_warmup_interaction      0.000000
# 47                     v4_precip_humidity_interaction      0.000000
# 48   v8_cloud_cover_mean_remaining_warmup_interaction      0.000000
# 49    v8_cloud_cover_max_remaining_warmup_interaction      0.000000
# 50             v8_forecast_dewpoint_depression_mean_f      0.000000
# 51                        v8_forecast_dewpoint_mean_f      0.000000
# 52      v8_wind_gust_max_remaining_warmup_interaction      0.000000
# 53    v8_wind_speed_mean_remaining_warmup_interaction      0.000000
# 54      v8_precip_max_1h_remaining_warmup_interaction      0.000000
# 55       v8_precip_total_remaining_warmup_interaction      0.000000
# 56      v8_dewpoint_mean_remaining_warmup_interaction      0.000000
# 57  v8_dewpoint_depression_remaining_warmup_intera...      0.000000

# %%
result.feature_columns.loc[result.feature_columns["feature"].isin(V11_FEATURE_COLUMNS)]
# Out:
#                                              feature     kind
# 21                    observed_temp_change_last_1h_f  numeric
# 22                    observed_temp_change_last_3h_f  numeric
# 23           observed_morning_warmup_rate_f_per_hour  numeric
# 24           observed_high_so_far_change_since_9am_f  numeric
# 164                         v2_recent_heat_anomaly_f  numeric
# 165                        v2_recent_heat_momentum_f  numeric
# 166                 v2_morning_warmup_to_consensus_f  numeric
# 167                   v2_consensus_minus_7d_actual_f  numeric
# 168                           v2_spread_per_warmup_f  numeric
# 169                   v2_humidity_warmup_interaction  numeric
# 170                   v3_high_so_far_above_current_f  numeric
# 171           v3_remaining_warmup_from_high_so_far_f  numeric
# 172                    v3_high_so_far_minus_lag_1d_f  numeric
# 173                 v3_high_so_far_minus_7d_actual_f  numeric
# 174                 v3_remaining_warmup_per_spread_f  numeric
# 175         v3_humidity_remaining_warmup_interaction  numeric
# 176                           v4_any_forecast_precip  numeric
# 177                           v4_all_forecast_precip  numeric
# 178                           v4_observed_precip_any  numeric
# 179                 v4_observed_precip_recent_mm_est  numeric
# 180                v4_forecast_observed_precip_match  numeric
# 181                     v4_forecast_wet_observed_dry  numeric
# 182                     v4_observed_wet_forecast_dry  numeric
# 183     v8_provider_max_remaining_from_high_so_far_f  numeric
# 184     v8_provider_min_remaining_from_high_so_far_f  numeric
# 185  v8_provider_median_remaining_from_high_so_far_f  numeric
# 186        v8_provider_spread_per_remaining_warmup_f  numeric
# 187                 v8_month_remaining_warmup_mean_f  numeric
# 188                  v8_month_remaining_warmup_count  numeric
# 189             v8_recent_remaining_warmup_7d_mean_f  numeric
# 190            v8_recent_remaining_warmup_30d_mean_f  numeric
# 191     v8_provider_mean_remaining_vs_month_normal_f  numeric
# 192                           climatology_high_10y_f  numeric
# 193                       climatology_high_10y_std_f  numeric
# 194                       climatology_high_10y_count  numeric
# 195            provider_mean_minus_climatology_10y_f  numeric
# 196            observed_temp_minus_climatology_10y_f  numeric
# 197     observed_high_so_far_minus_climatology_10y_f  numeric

# %% [markdown]
# ## Dropped Feature Check

# %%
dropped_present = result.feature_columns.loc[
    result.feature_columns["feature"].isin(V11_DROPPED_FEATURE_COLUMNS)
]

dropped_present
# Out:
# Empty DataFrame
# Columns: [feature, kind]
# Index: []

# %% [markdown]
# ## Morning Trend Coverage

# %%
trend_coverage = (
    result.features[TREND_COLUMNS]
    .notna()
    .mean()
    .mul(100)
    .sort_values(ascending=False)
    .rename("coverage_pct")
    .reset_index()
    .rename(columns={"index": "feature"})
)

trend_coverage
# Out:
#                                    feature  coverage_pct
# 0           observed_temp_change_last_1h_f         100.0
# 1           observed_temp_change_last_3h_f         100.0
# 2  observed_morning_warmup_rate_f_per_hour         100.0
# 3  observed_high_so_far_change_since_9am_f         100.0

# %% [markdown]
# ## Rounded Within 1F Accuracy

# %%
preds = pd.concat(
    [
        result.validation_predictions.assign(period="validation_2024_2025"),
        result.test_predictions.assign(period="oof_2026"),
    ],
    ignore_index=True,
)

predicted_high = pd.to_numeric(preds["predicted_high_f"], errors="coerce")
preds["predicted_high_rounded_f"] = np.floor(predicted_high + 0.5)
preds["within_1f_after_round"] = (
    pd.to_numeric(preds["actual_high_f"], errors="coerce") - preds["predicted_high_rounded_f"]
).abs().le(1)

within_1f_accuracy_by_period = (
    preds
    .dropna(subset=["actual_high_f", "predicted_high_rounded_f"])
    .groupby(["period", "method"], as_index=False)
    .agg(
        count=("within_1f_after_round", "size"),
        within_1f_count=("within_1f_after_round", "sum"),
        within_1f_accuracy_pct=("within_1f_after_round", lambda x: x.mean() * 100),
    )
    .sort_values(["period", "within_1f_accuracy_pct"], ascending=[True, False])
)

within_1f_accuracy_by_period
# Out:
#                   period       method  count  within_1f_count  \
# 5               oof_2026  ridge_stack    136               86
# 3               oof_2026     lightgbm    136               85
# 0               oof_2026     catboost    136               84
# 6               oof_2026      xgboost    136               83
# 1               oof_2026      gfs_raw    136               71
# 4               oof_2026      nbm_raw    136               57
# 2               oof_2026     hrrr_raw    136               33
# 12  validation_2024_2025      xgboost    729              464
# 10  validation_2024_2025     lightgbm    729              463
# 7   validation_2024_2025     catboost    729              444
# 8   validation_2024_2025      gfs_raw    729              267
# 11  validation_2024_2025      nbm_raw    729              264
# 9   validation_2024_2025     hrrr_raw    729              230
#
#     within_1f_accuracy_pct
# 5                63.235294
# 3                62.500000
# 0                61.764706
# 6                61.029412
# 1                52.205882
# 4                41.911765
# 2                24.264706
# 12               63.648834
# 10               63.511660
# 7                60.905350
# 8                36.625514
# 11               36.213992
# 9                31.550069

# %% [markdown]
# ## Version Comparison

# %%
comparison_frames = []
for version, folder in [
    ("v1", PROJECT_ROOT / "data" / "calibration" / "station_stacking"),
    ("v2", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v2"),
    ("v3", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v3"),
    ("v4", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v4"),
    ("v5", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v5"),
    ("v6", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v6"),
    ("v7", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v7"),
    ("v8", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v8"),
    ("v9", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v9"),
    ("v10", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v10"),
    ("v11", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v11"),
]:
    path = folder / f"{STATION_ID}_year_split_scoreboard.csv"
    if path.exists():
        frame = pd.read_csv(path)
        frame["version"] = version
        comparison_frames.append(frame)

version_comparison = pd.concat(comparison_frames, ignore_index=True) if comparison_frames else pd.DataFrame()
if not version_comparison.empty:
    version_comparison = version_comparison.sort_values(["period", "mae_f", "version", "method"]).reset_index(drop=True)
version_comparison
# Out:
#                   period       method  count     mae_f    rmse_f version
# 0              test_2026  ridge_stack    113  1.246979  1.575892      v6
# 1              test_2026     lightgbm    114  1.270993  1.676493      v7
# 2              test_2026     catboost    114  1.282843  1.677358      v7
# 3              test_2026     catboost    113  1.282965  1.612390      v6
# 4              test_2026      xgboost    136  1.292638  1.737796      v8
# ..                   ...          ...    ...       ...       ...     ...
# 83  validation_2024_2025     hrrr_raw    664  2.844736  3.500632      v3
# 84  validation_2024_2025     hrrr_raw    663  2.848232  3.503212      v5
# 85  validation_2024_2025     hrrr_raw    589  2.854942  3.482365      v6
# 86  validation_2024_2025      gfs_raw    644  2.917917  3.861741      v7
# 87  validation_2024_2025     hrrr_raw    568  3.000941  3.671190      v1
#
# [88 rows x 6 columns]

# %% [markdown]
# ## 2026 OOF Weather Brackets

# %%
result.bracket_metrics
# Out:
#         method  count     mae_f    rmse_f  bracket_accuracy_pct
# 0      xgboost    136  1.411409  1.766750             39.705882
# 1     lightgbm    136  1.356156  1.712203             42.647059
# 2     catboost    136  1.354835  1.761921             41.176471
# 3  ridge_stack    136  1.395297  1.730816             41.176471
# 4     hrrr_raw    136  2.924646  3.398490             13.970588
# 5      gfs_raw    136  2.022681  2.805218             39.705882

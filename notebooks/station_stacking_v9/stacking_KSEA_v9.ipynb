# %% [markdown]
# # Station Stacking v9 - KSEA
#
# Experimental notebook for `KSEA`.
#
# This version keeps the v8 live-safe GFS/HRRR/NBM contract, adds source-owned 10-year calendar-day max-temperature climatology features, and trains base learners on remaining warmup from the observed high-so-far. Artifacts are written to `data/calibration/station_stacking_v9`.

# %%
from pathlib import Path
import os
import sys
import warnings

warnings.filterwarnings("ignore", message="IProgress not found.*")
warnings.filterwarnings("ignore", message="Skipping features without any observed values.*")

PROJECT_ROOT = Path.cwd().resolve()
while not (PROJECT_ROOT / "src" / "calibration" / "station_stacking.py").exists():
    if PROJECT_ROOT.parent == PROJECT_ROOT:
        raise RuntimeError("Could not find project root containing src/calibration/station_stacking.py")
    PROJECT_ROOT = PROJECT_ROOT.parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

os.environ["WEATHER_RESEARCH_INCLUDE_DIRECT_NBM"] = "1"

STATION_ID = "KSEA"
PROVIDERS = ("gfs", "hrrr", "nbm")
TREND_COLUMNS = [
    "observed_temp_change_last_1h_f",
    "observed_temp_change_last_3h_f",
    "observed_morning_warmup_rate_f_per_hour",
    "observed_high_so_far_change_since_9am_f",
]
TIMING_MODE = "same_day_11am_live_safe"
FAST_MODE = False
OPTUNA_TRIALS = 30
STACK_OPTUNA_TRIALS = 30
OPTUNA_STARTUP_TRIALS = 15
STACK_OPTUNA_STARTUP_TRIALS = 15
OPTUNA_METRIC = "mae_f"
OPTUNA_VERBOSE = True
MODEL_VERSION = "station_high_regressor_v9_remaining_warmup"
PROJECT_ROOT
# Out:
# WindowsPath('D:/dev/weather-research')

# %%
import numpy as np
import pandas as pd

from src.export_station_stacking_v2_models import export_station_model_weights
from src.calibration.station_stacking import (
    StationStackingConfig,
    V9_DROPPED_FEATURE_COLUMNS,
    V9_FEATURE_COLUMNS,
    YEAR_SPLIT_EXPANDING_FOLDS,
    missing_model_dependencies,
    provider_availability,
    run_station_year_split_experiment,
)

# %% [markdown]
# ## V9 Contract
#
# `feature_version="v9"` keeps the v8 remaining-warmup feature set, adds leakage-safe 10-year calendar-day climatology features, and uses `target_mode="remaining_warmup"` so base learners fit `actual_high_f - observed_high_temp_through_as_of_f` before converting back to `predicted_high_f`.

# %%
fold_spec = pd.DataFrame(
    [
        {
            "fold": fold.name,
            "train_start_year": fold.train_start_year,
            "train_end_year": fold.train_end_year,
            "validation_year": fold.validation_year,
        }
        for fold in YEAR_SPLIT_EXPANDING_FOLDS
    ]
)

fold_spec
# Out:
#                      fold  train_start_year  train_end_year  validation_year
# 0  fold_2021_2023_to_2024              2021            2023             2024
# 1  fold_2021_2024_to_2025              2021            2024             2025

# %%
V9_FEATURE_COLUMNS, sorted(V9_DROPPED_FEATURE_COLUMNS)
# Out:
# (['v2_recent_heat_anomaly_f',
#   'v2_recent_heat_momentum_f',
#   'v2_morning_warmup_to_consensus_f',
#   'v2_consensus_minus_7d_actual_f',
#   'v2_spread_per_warmup_f',
#   'v2_humidity_warmup_interaction',
#   'v3_high_so_far_above_current_f',
#   'v3_remaining_warmup_from_high_so_far_f',
#   'v3_high_so_far_minus_lag_1d_f',
#   'v3_high_so_far_minus_7d_actual_f',
#   'v3_remaining_warmup_per_spread_f',
#   'v3_humidity_remaining_warmup_interaction',
#   'v4_forecast_precip_total_mean_mm',
#   'v4_forecast_precip_total_max_mm',
#   'v4_forecast_precip_total_spread_mm',
#   'v4_forecast_precip_max_1h_mean_mm',
#   'v4_forecast_precip_hours_mean',
#   'v4_forecast_precip_intensity_mean',
#   'v4_forecast_precip_intensity_max',
#   'v4_any_forecast_precip',
#   'v4_all_forecast_precip',
#   'v4_observed_precip_any',
#   'v4_observed_precip_recent_mm_est',
#   'v4_forecast_total_minus_observed_recent_mm',
#   'v4_forecast_observed_precip_match',
#   'v4_forecast_wet_observed_dry',
#   'v4_observed_wet_forecast_dry',
#   'v4_precip_humidity_interaction',
#   'v4_precip_remaining_warmup_interaction',
#   'observed_temp_change_last_1h_f',
#   'observed_temp_change_last_3h_f',
#   'observed_morning_warmup_rate_f_per_hour',
#   'observed_high_so_far_change_since_9am_f',
#   'v8_provider_max_remaining_from_high_so_far_f',
#   'v8_provider_min_remaining_from_high_so_far_f',
#   'v8_provider_median_remaining_from_high_so_far_f',
#   'v8_provider_spread_per_remaining_warmup_f',
#   'v8_month_remaining_warmup_mean_f',
#   'v8_month_remaining_warmup_count',
#   'v8_recent_remaining_warmup_7d_mean_f',
#   'v8_recent_remaining_warmup_30d_mean_f',
#   'v8_provider_mean_remaining_vs_month_normal_f',
#   'v8_cloud_cover_mean_remaining_warmup_interaction',
#   'v8_cloud_cover_max_remaining_warmup_interaction',
#   'v8_precip_total_remaining_warmup_interaction',
#   'v8_precip_max_1h_remaining_warmup_interaction',
#   'v8_wind_speed_mean_remaining_warmup_interaction',
#   'v8_wind_gust_max_remaining_warmup_interaction',
#   'v8_forecast_dewpoint_mean_f',
#   'v8_forecast_dewpoint_depression_mean_f',
#   'v8_dewpoint_mean_remaining_warmup_interaction',
#   'v8_dewpoint_depression_remaining_warmup_interaction',
#   'climatology_high_10y_f',
#   'climatology_high_10y_std_f',
#   'climatology_high_10y_count',
#   'provider_mean_minus_climatology_10y_f',
#   'observed_temp_minus_climatology_10y_f',
#   'observed_high_so_far_minus_climatology_10y_f'],
#  ['actual_minus_climatology_10y_f_DIAGNOSTIC_ONLY',
#   'climatology_source_end_year',
#   'climatology_source_start_year',
#   'gfs_as_of_hour_local',
#   'gfs_available',
#   'gfs_forecast_window_hours',
#   'gfs_grid_dist_km_mean',
#   'gfs_horizon_hours',
#   'gfs_hrrr_grid_dist_km_mean_abs_diff_f',
#   'gfs_hrrr_grid_dist_km_mean_diff_f',
#   'gfs_issue_hour_utc',
#   'gfs_missing',
#   'hrrr_as_of_hour_local',
#   'hrrr_available',
#   'hrrr_forecast_hour_max',
#   'hrrr_forecast_hour_min',
#   'hrrr_forecast_lead_hours',
#   'hrrr_forecast_window_hours',
#   'hrrr_grid_dist_km_mean',
#   'hrrr_horizon_hours',
#   'hrrr_issue_hour_local',
#   'hrrr_issue_hour_utc',
#   'hrrr_missing',
#   'is_active_polymarket_station',
#   'lat',
#   'lon',
#   'nbm_as_of_hour_local',
#   'nbm_available',
#   'nbm_forecast_window_hours',
#   'nbm_horizon_hours',
#   'nbm_issue_hour_local',
#   'nbm_issue_hour_utc',
#   'nbm_missing',
#   'observed_fetch_status',
#   'observed_observation_type',
#   'observed_pressure_source',
#   'provider_count_available',
#   'year'])

# %% [markdown]
# ## Data Availability

# %%
availability = provider_availability(
    PROJECT_ROOT,
    timing_mode=TIMING_MODE,
    providers=PROVIDERS,
)

availability.loc[availability["station_id"].eq(STATION_ID)]
# Out:
#    station_id provider  row_count first_contract_date last_contract_date
# 24       KSEA      gfs       1982          2021-01-01         2026-06-10
# 25       KSEA     hrrr       1987          2021-01-01         2026-06-10
# 26       KSEA      nbm       1986          2021-01-01         2026-06-10

# %% [markdown]
# ## Model Scores

# %%
missing_packages = missing_model_dependencies()
if missing_packages:
    raise ImportError(
        "Missing station-stacking ML packages: "
        + ", ".join(missing_packages)
        + ". Install them with: python -m pip install -r requirements.txt"
    )

config = StationStackingConfig(
    station_id=STATION_ID,
    project_root=PROJECT_ROOT,
    timing_mode=TIMING_MODE,
    providers=PROVIDERS,
    fast_mode=FAST_MODE,
    optuna_trials=OPTUNA_TRIALS,
    stack_optuna_trials=STACK_OPTUNA_TRIALS,
    optuna_startup_trials=OPTUNA_STARTUP_TRIALS,
    stack_optuna_startup_trials=STACK_OPTUNA_STARTUP_TRIALS,
    optuna_metric=OPTUNA_METRIC,
    optuna_verbose=OPTUNA_VERBOSE,
    feature_version="v9",
    target_mode="remaining_warmup",
    hyperparameter_space="wide",
    year_split_folds=YEAR_SPLIT_EXPANDING_FOLDS,
    year_split_test_train_years=(2021, 2025),
    year_split_test_year=2026,
    output_dir=PROJECT_ROOT / "data" / "calibration" / "station_stacking_v9",
)

config.resolved_optuna_storage_path()
# Out:
# WindowsPath('D:/dev/weather-research/data/calibration/station_stacking_v9/KSEA_optuna.sqlite3')

# %%
result = run_station_year_split_experiment(config)
result.scoreboard
# Out:
# [I 2026-06-16 07:25:28,309] A new study created in RDB with name: KSEA_v9_remaining_warmup_base_xgboost_mae_f
# [I 2026-06-16 07:25:52,058] Trial 0 finished with value: 1.7188526369522745 and parameters: {'n_estimators': 1342, 'learning_rate': 0.19043899115982607, 'max_depth': 9, 'min_child_weight': 2.481040974867813, 'gamma': 2.340279606636548, 'subsample': 0.4513964382185317, 'colsample_bytree': 0.3877543479093296, 'reg_alpha': 2.478071022662141, 'reg_lambda': 0.6132587025321562}. Best is trial 0 with value: 1.7188526369522745.
# [I 2026-06-16 07:30:52,318] Trial 1 finished with value: 1.4808537282820118 and parameters: {'n_estimators': 2493, 'learning_rate': 0.001120367191095075, 'max_depth': 12, 'min_child_weight': 21.368329072358772, 'gamma': 3.185086660174142, 'subsample': 0.4681862286846154, 'colsample_bytree': 0.46921293140473197, 'reg_alpha': 4.476173538513514e-07, 'reg_lambda': 0.20253776634919213}. Best is trial 1 with value: 1.4808537282820118.
# [I 2026-06-16 07:32:32,797] Trial 2 finished with value: 1.5654292706540565 and parameters: {'n_estimators': 1540, 'learning_rate': 0.004992867109217114, 'max_depth': 8, 'min_child_weight': 0.03613894271216528, 'gamma': 4.3821697280282725, 'subsample': 0.5881351981408995, 'colsample_bytree': 0.6464454897410734, 'reg_alpha': 0.26430874752361627, 'reg_lambda': 0.0018119678627933364}. Best is trial 1 with value: 1.4808537282820118.
# [I 2026-06-16 07:32:50,757] Trial 3 finished with value: 1.5687407418202186 and parameters: {'n_estimators': 1824, 'learning_rate': 0.026337502897485255, 'max_depth': 1, 'min_child_weight': 2.69264691008618, 'gamma': 2.557861855309373, 'subsample': 0.39228353544043165, 'colsample_bytree': 0.9667755992146666, 'reg_alpha': 38.6887231523051, 'reg_lambda': 12.408975837016275}. Best is trial 1 with value: 1.4808537282820118.
# [I 2026-06-16 07:35:21,748] Trial 4 finished with value: 1.7078904378823845 and parameters: {'n_estimators': 1101, 'learning_rate': 0.0017147936629846843, 'max_depth': 9, 'min_child_weight': 0.5762487216478605, 'gamma': 1.8305735226716824, 'subsample': 0.6718649915723256, 'colsample_bytree': 0.37235253872489193, 'reg_alpha': 8.162906555194692, 'reg_lambda': 0.004271500153828077}. Best is trial 1 with value: 1.4808537282820118.
# [I 2026-06-16 07:37:37,345] Trial 5 pruned.
# [I 2026-06-16 07:37:43,827] Trial 6 pruned.
# [I 2026-06-16 07:38:18,236] Trial 7 pruned.
# [I 2026-06-16 07:38:26,810] Trial 8 pruned.
# [I 2026-06-16 07:39:10,328] Trial 9 finished with value: 1.5624832760239231 and parameters: {'n_estimators': 2201, 'learning_rate': 0.006215464818952927, 'max_depth': 1, 'min_child_weight': 0.17535949529764422, 'gamma': 4.877749830401205, 'subsample': 0.8242440159197416, 'colsample_bytree': 0.7644123563808884, 'reg_alpha': 4.4315220126915325, 'reg_lambda': 0.09450187118503514}. Best is trial 1 with value: 1.4808537282820118.
# [I 2026-06-16 07:39:15,199] Trial 10 pruned.
# [I 2026-06-16 07:39:42,077] Trial 11 pruned.
# [I 2026-06-16 07:40:06,434] Trial 12 pruned.
# [I 2026-06-16 07:40:16,489] Trial 13 finished with value: 1.5449875160355515 and parameters: {'n_estimators': 693, 'learning_rate': 0.13813474572232612, 'max_depth': 7, 'min_child_weight': 16.973078532467014, 'gamma': 13.4413694988524, 'subsample': 0.5567022587317115, 'colsample_bytree': 0.4215337509429899, 'reg_alpha': 5.435280359192946e-08, 'reg_lambda': 0.049115547267693904}. Best is trial 1 with value: 1.4808537282820118.
# [I 2026-06-16 07:40:23,770] Trial 14 pruned.
# [I 2026-06-16 07:41:01,596] Trial 15 finished with value: 1.5023102313186834 and parameters: {'n_estimators': 3389, 'learning_rate': 0.018965632630243198, 'max_depth': 12, 'min_child_weight': 67.94364327569595, 'gamma': 8.899081458519458, 'subsample': 0.7017846631490905, 'colsample_bytree': 0.507341466842611, 'reg_alpha': 1.7474595831747068e-10, 'reg_lambda': 0.13084844939400364}. Best is trial 1 with value: 1.4808537282820118.
# [I 2026-06-16 07:42:11,839] Trial 16 finished with value: 1.5082054133858669 and parameters: {'n_estimators': 3492, 'learning_rate': 0.014593208257834948, 'max_depth': 12, 'min_child_weight': 77.06616292238813, 'gamma': 9.11219070114452, 'subsample': 0.7312953466790875, 'colsample_bytree': 0.5060432790401248, 'reg_alpha': 1.6811790758109838e-10, 'reg_lambda': 0.5684326293422212}. Best is trial 1 with value: 1.4808537282820118.
# [I 2026-06-16 07:42:43,454] Trial 17 finished with value: 1.5326141987579684 and parameters: {'n_estimators': 3372, 'learning_rate': 0.017478919982976338, 'max_depth': 12, 'min_child_weight': 98.89118786228569, 'gamma': 9.136107951506167, 'subsample': 0.7742427801462375, 'colsample_bytree': 0.4680651245340617, 'reg_alpha': 0.0022146353005139336, 'reg_lambda': 0.035168450158712915}. Best is trial 1 with value: 1.4808537282820118.
# [I 2026-06-16 07:46:20,630] Trial 18 finished with value: 1.476493822297408 and parameters: {'n_estimators': 2798, 'learning_rate': 0.002573574103247072, 'max_depth': 11, 'min_child_weight': 28.505322089850193, 'gamma': 8.750984378084244, 'subsample': 0.6375713043200772, 'colsample_bytree': 0.552753253367327, 'reg_alpha': 0.0004970813869178757, 'reg_lambda': 1.1112592521255409}. Best is trial 18 with value: 1.476493822297408.
# [I 2026-06-16 07:54:51,433] Trial 19 finished with value: 1.489441530016446 and parameters: {'n_estimators': 2921, 'learning_rate': 0.0023127262440949987, 'max_depth': 11, 'min_child_weight': 19.63554549263731, 'gamma': 4.7645081384425545, 'subsample': 0.6175601149231938, 'colsample_bytree': 0.5600717144434368, 'reg_alpha': 0.000679667819992592, 'reg_lambda': 1.2893424066810315}. Best is trial 18 with value: 1.476493822297408.
# [I 2026-06-16 08:07:50,534] Trial 20 finished with value: 1.5151296631305387 and parameters: {'n_estimators': 2666, 'learning_rate': 0.002906215880615357, 'max_depth': 10, 'min_child_weight': 6.997321129167345, 'gamma': 6.728220853351139, 'subsample': 0.5005907751679259, 'colsample_bytree': 0.6956456341507938, 'reg_alpha': 0.002047007691626987, 'reg_lambda': 3.501015648024058}. Best is trial 18 with value: 1.476493822297408.
# [I 2026-06-16 08:18:52,395] Trial 21 finished with value: 1.4815152351634455 and parameters: {'n_estimators': 2939, 'learning_rate': 0.002516864885285797, 'max_depth': 11, 'min_child_weight': 22.09486025576843, 'gamma': 4.692391091993255, 'subsample': 0.6189502370137611, 'colsample_bytree': 0.569329683780955, 'reg_alpha': 0.00033046880493899496, 'reg_lambda': 0.8083079862309112}. Best is trial 18 with value: 1.476493822297408.
# [I 2026-06-16 08:25:30,670] Trial 22 finished with value: 1.4851293246421324 and parameters: {'n_estimators': 2590, 'learning_rate': 0.0010261582364307926, 'max_depth': 11, 'min_child_weight': 29.40102785607315, 'gamma': 0.3002771118765475, 'subsample': 0.6334648918219821, 'colsample_bytree': 0.5533185192757664, 'reg_alpha': 3.7743265343354176e-05, 'reg_lambda': 0.2923599840162268}. Best is trial 18 with value: 1.476493822297408.
# [I 2026-06-16 08:26:42,551] Trial 23 pruned.
# [I 2026-06-16 08:27:07,775] Trial 24 finished with value: 1.4807422491323683 and parameters: {'n_estimators': 2421, 'learning_rate': 0.008126876569551116, 'max_depth': 10, 'min_child_weight': 36.52761487790675, 'gamma': 6.153306338839648, 'subsample': 0.4489251302792846, 'colsample_bytree': 0.446967252297657, 'reg_alpha': 0.038885005199799726, 'reg_lambda': 1.791110469991017}. Best is trial 18 with value: 1.476493822297408.
# [I 2026-06-16 08:27:34,870] Trial 25 finished with value: 1.4916308321753033 and parameters: {'n_estimators': 1839, 'learning_rate': 0.009637699280528034, 'max_depth': 10, 'min_child_weight': 40.04359953572452, 'gamma': 6.062531313542438, 'subsample': 0.45247100947418617, 'colsample_bytree': 0.4513343410358298, 'reg_alpha': 0.024381542619209256, 'reg_lambda': 2.2960251773966953}. Best is trial 18 with value: 1.476493822297408.
# [I 2026-06-16 08:27:54,438] Trial 26 pruned.
# [I 2026-06-16 08:28:40,962] Trial 27 pruned.
# [I 2026-06-16 08:31:18,420] Trial 28 pruned.
# [I 2026-06-16 08:31:24,102] Trial 29 pruned.
# [I 2026-06-16 08:31:24,702] A new study created in RDB with name: KSEA_v9_remaining_warmup_base_lightgbm_mae_f
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 08:31:46,159] Trial 0 finished with value: 1.5144731924970984 and parameters: {'n_estimators': 447, 'learning_rate': 0.028873871707375695, 'num_leaves': 71, 'max_depth': 5, 'min_child_samples': 83, 'min_split_gain': 4.295687454742988, 'bagging_fraction': 0.7829586385137167, 'bagging_freq': 4, 'feature_fraction': 0.3688589858758342, 'lambda_l1': 0.06382334403151436, 'lambda_l2': 0.03080292177315921}. Best is trial 0 with value: 1.5144731924970984.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 08:36:55,364] Trial 1 finished with value: 1.5411891560567803 and parameters: {'n_estimators': 2817, 'learning_rate': 0.004074615160588706, 'num_leaves': 32, 'max_depth': 13, 'min_child_samples': 57, 'min_split_gain': 2.0249472402362985, 'bagging_fraction': 0.5554627061618356, 'bagging_freq': 1, 'feature_fraction': 0.898096051249308, 'lambda_l1': 1.5391104005532914, 'lambda_l2': 132.19976430960952}. Best is trial 0 with value: 1.5144731924970984.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 08:37:27,162] Trial 2 finished with value: 1.541523501320085 and parameters: {'n_estimators': 1379, 'learning_rate': 0.1944487980595256, 'num_leaves': 230, 'max_depth': 10, 'min_child_samples': 22, 'min_split_gain': 4.485492899907672, 'bagging_fraction': 0.5437022754476957, 'bagging_freq': 2, 'feature_fraction': 0.353334206891897, 'lambda_l1': 0.00032993636349211094, 'lambda_l2': 0.09925376145099525}. Best is trial 0 with value: 1.5144731924970984.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 08:37:38,991] Trial 3 finished with value: 1.587351791307703 and parameters: {'n_estimators': 2246, 'learning_rate': 0.22165362064553062, 'num_leaves': 466, 'max_depth': 13, 'min_child_samples': 132, 'min_split_gain': 0.5200947492738145, 'bagging_fraction': 0.4675944869176356, 'bagging_freq': 7, 'feature_fraction': 0.6177694392011331, 'lambda_l1': 2.399967979035352, 'lambda_l2': 1.7195277953675168}. Best is trial 0 with value: 1.5144731924970984.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 08:40:10,947] Trial 4 finished with value: 1.5366788590619533 and parameters: {'n_estimators': 2219, 'learning_rate': 0.004579029224032115, 'num_leaves': 460, 'max_depth': 4, 'min_child_samples': 102, 'min_split_gain': 4.967862461970517, 'bagging_fraction': 0.8282226029796285, 'bagging_freq': 4, 'feature_fraction': 0.7144310601384277, 'lambda_l1': 8.61124348208611e-06, 'lambda_l2': 3.808668235343267}. Best is trial 0 with value: 1.5144731924970984.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 08:40:20,997] Trial 5 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 08:40:51,069] Trial 6 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 08:40:53,117] Trial 7 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 08:40:55,076] Trial 8 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 08:42:34,917] Trial 9 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 08:42:43,015] Trial 10 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 08:42:47,911] Trial 11 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 09:00:52,631] Trial 12 finished with value: 1.5025034520835663 and parameters: {'n_estimators': 3174, 'learning_rate': 0.0010925194811392835, 'num_leaves': 301, 'max_depth': 11, 'min_child_samples': 74, 'min_split_gain': 2.613988081636218, 'bagging_fraction': 0.8796537260629015, 'bagging_freq': 5, 'feature_fraction': 0.5960609706435204, 'lambda_l1': 8.524985832885774e-10, 'lambda_l2': 0.1169527455154188}. Best is trial 12 with value: 1.5025034520835663.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 09:03:42,153] Trial 13 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 09:03:52,326] Trial 14 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 09:43:19,147] Trial 15 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 09:43:58,506] Trial 16 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 09:47:06,600] Trial 17 finished with value: 1.4790791565439307 and parameters: {'n_estimators': 2738, 'learning_rate': 0.019111483284660686, 'num_leaves': 117, 'max_depth': 11, 'min_child_samples': 44, 'min_split_gain': 2.8128439063936024, 'bagging_fraction': 0.910419375890395, 'bagging_freq': 3, 'feature_fraction': 0.3585310687421585, 'lambda_l1': 7.4939975129214e-06, 'lambda_l2': 0.044242061308984976}. Best is trial 17 with value: 1.4790791565439307.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 09:49:45,958] Trial 18 finished with value: 1.498440552675977 and parameters: {'n_estimators': 2925, 'learning_rate': 0.010794378646574983, 'num_leaves': 142, 'max_depth': 11, 'min_child_samples': 42, 'min_split_gain': 2.5481013418348293, 'bagging_fraction': 0.9013444459509277, 'bagging_freq': 3, 'feature_fraction': 0.9872947920044326, 'lambda_l1': 3.159601596592457e-06, 'lambda_l2': 0.3282315848893584}. Best is trial 17 with value: 1.4790791565439307.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 09:51:43,601] Trial 19 finished with value: 1.5014547766378863 and parameters: {'n_estimators': 2694, 'learning_rate': 0.012772707630299605, 'num_leaves': 131, 'max_depth': 11, 'min_child_samples': 51, 'min_split_gain': 1.72367419102359, 'bagging_fraction': 0.9211750757356665, 'bagging_freq': 2, 'feature_fraction': 0.9867285120208348, 'lambda_l1': 1.0860427686649133e-05, 'lambda_l2': 21.83779249111581}. Best is trial 17 with value: 1.4790791565439307.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 09:53:39,878] Trial 20 finished with value: 1.4956167568451624 and parameters: {'n_estimators': 2708, 'learning_rate': 0.019422857973955127, 'num_leaves': 153, 'max_depth': 11, 'min_child_samples': 33, 'min_split_gain': 3.149014648657099, 'bagging_fraction': 0.7301604767732601, 'bagging_freq': 3, 'feature_fraction': 0.9814535145779777, 'lambda_l1': 0.00013235202357594287, 'lambda_l2': 0.0010021402327976437}. Best is trial 17 with value: 1.4790791565439307.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 09:55:59,362] Trial 21 finished with value: 1.4602489299938424 and parameters: {'n_estimators': 2740, 'learning_rate': 0.016488216364143615, 'num_leaves': 155, 'max_depth': 11, 'min_child_samples': 37, 'min_split_gain': 3.1008052497046514, 'bagging_fraction': 0.7242896779886223, 'bagging_freq': 3, 'feature_fraction': 0.9650773830909576, 'lambda_l1': 9.910974380231977e-05, 'lambda_l2': 0.0005600927864973398}. Best is trial 21 with value: 1.4602489299938424.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 09:57:47,376] Trial 22 finished with value: 1.46320689440017 and parameters: {'n_estimators': 2643, 'learning_rate': 0.01866719541575876, 'num_leaves': 186, 'max_depth': 10, 'min_child_samples': 27, 'min_split_gain': 3.0338818456220746, 'bagging_fraction': 0.6990444467719156, 'bagging_freq': 3, 'feature_fraction': 0.827476936020976, 'lambda_l1': 0.0003374184559871162, 'lambda_l2': 0.0007456957635263394}. Best is trial 21 with value: 1.4602489299938424.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 10:00:38,231] Trial 23 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 10:00:59,487] Trial 24 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 10:01:11,995] Trial 25 finished with value: 1.4838885227894392 and parameters: {'n_estimators': 2497, 'learning_rate': 0.053954531864538156, 'num_leaves': 182, 'max_depth': 8, 'min_child_samples': 55, 'min_split_gain': 1.9990975925559054, 'bagging_fraction': 0.6147862704906177, 'bagging_freq': 2, 'feature_fraction': 0.7939549987097521, 'lambda_l1': 0.00012837483619741502, 'lambda_l2': 0.00010659202214854304}. Best is trial 21 with value: 1.4602489299938424.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 10:01:28,018] Trial 26 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 10:01:40,697] Trial 27 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 10:02:24,313] Trial 28 finished with value: 1.4903833514412415 and parameters: {'n_estimators': 2932, 'learning_rate': 0.007447982704372278, 'num_leaves': 7, 'max_depth': 14, 'min_child_samples': 33, 'min_split_gain': 4.052558797917689, 'bagging_fraction': 0.5975399841446587, 'bagging_freq': 3, 'feature_fraction': 0.7188644522238415, 'lambda_l1': 0.08514398905842968, 'lambda_l2': 0.012635904380169524}. Best is trial 21 with value: 1.4602489299938424.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2026-06-16 10:02:39,961] Trial 29 pruned.
# [I 2026-06-16 10:02:40,199] A new study created in RDB with name: KSEA_v9_remaining_warmup_base_catboost_mae_f
# [I 2026-06-16 10:14:44,563] Trial 0 finished with value: 1.6868839623566783 and parameters: {'iterations': 2931, 'learning_rate': 0.001783588943232587, 'depth': 10, 'l2_leaf_reg': 0.9942958882300413, 'random_strength': 7.186216756161439, 'bagging_temperature': 12.184767612363034, 'border_count': 110, 'rsm': 0.6158971964095841}. Best is trial 0 with value: 1.6868839623566783.
# [I 2026-06-16 10:21:34,923] Trial 1 finished with value: 1.6311680228917411 and parameters: {'iterations': 1809, 'learning_rate': 0.05045361458210069, 'depth': 12, 'l2_leaf_reg': 2.206716955900187, 'random_strength': 8.55303042123218, 'bagging_temperature': 2.269274022399408, 'border_count': 68, 'rsm': 0.9723568448941463}. Best is trial 1 with value: 1.6311680228917411.
# [I 2026-06-16 10:22:07,236] Trial 2 finished with value: 1.609849705336425 and parameters: {'iterations': 3305, 'learning_rate': 0.13018523290940803, 'depth': 9, 'l2_leaf_reg': 0.29456409265689415, 'random_strength': 12.736640276136784, 'bagging_temperature': 2.78292503969807, 'border_count': 126, 'rsm': 0.9180110703516069}. Best is trial 2 with value: 1.609849705336425.
# [I 2026-06-16 10:23:44,036] Trial 3 finished with value: 1.6061601597625694 and parameters: {'iterations': 941, 'learning_rate': 0.039289187448897187, 'depth': 11, 'l2_leaf_reg': 0.17184213389305913, 'random_strength': 11.258999163179464, 'bagging_temperature': 3.183105276262954, 'border_count': 57, 'rsm': 0.4176149246436502}. Best is trial 3 with value: 1.6061601597625694.
# [I 2026-06-16 10:25:58,279] Trial 4 finished with value: 2.270652030355591 and parameters: {'iterations': 750, 'learning_rate': 0.012345725775087685, 'depth': 10, 'l2_leaf_reg': 185.34152922460115, 'random_strength': 16.100344011609046, 'bagging_temperature': 7.548308114328448, 'border_count': 139, 'rsm': 0.3882842988918503}. Best is trial 3 with value: 1.6061601597625694.
# [I 2026-06-16 10:52:34,153] Trial 5 pruned.
# [I 2026-06-16 10:58:44,048] Trial 6 finished with value: 1.556291850208284 and parameters: {'iterations': 3092, 'learning_rate': 0.0016894180053021765, 'depth': 7, 'l2_leaf_reg': 2.9770736659303028, 'random_strength': 2.1794700787166432, 'bagging_temperature': 3.0746892172349938, 'border_count': 252, 'rsm': 0.5265140999127667}. Best is trial 6 with value: 1.556291850208284.
# [I 2026-06-16 10:59:48,818] Trial 7 finished with value: 1.5744717010689966 and parameters: {'iterations': 3146, 'learning_rate': 0.0024764229908984673, 'depth': 3, 'l2_leaf_reg': 0.6951779671472356, 'random_strength': 6.148451176512449, 'bagging_temperature': 8.441103735088014, 'border_count': 95, 'rsm': 0.7192489923988105}. Best is trial 6 with value: 1.556291850208284.
# [I 2026-06-16 11:00:12,934] Trial 8 finished with value: 1.5355533570765707 and parameters: {'iterations': 378, 'learning_rate': 0.08194116550819189, 'depth': 4, 'l2_leaf_reg': 95.92707399961093, 'random_strength': 18.034879593317157, 'bagging_temperature': 0.3171560070252766, 'border_count': 220, 'rsm': 0.7891440128855358}. Best is trial 8 with value: 1.5355533570765707.
# [I 2026-06-16 11:00:53,705] Trial 9 pruned.
# [I 2026-06-16 11:02:29,444] Trial 10 pruned.
# [I 2026-06-16 11:02:40,870] Trial 11 pruned.
# [I 2026-06-16 11:03:14,429] Trial 12 pruned.
# [I 2026-06-16 11:03:21,909] Trial 13 pruned.
# [I 2026-06-16 11:03:48,525] Trial 14 pruned.
# [I 2026-06-16 11:03:51,691] Trial 15 pruned.
# [I 2026-06-16 11:04:09,127] Trial 16 finished with value: 1.526255173547653 and parameters: {'iterations': 1412, 'learning_rate': 0.09289298055917693, 'depth': 5, 'l2_leaf_reg': 6.353977158997474, 'random_strength': 3.145341694858591, 'bagging_temperature': 0.09853554456352512, 'border_count': 218, 'rsm': 0.7682154289388926}. Best is trial 16 with value: 1.526255173547653.
# [I 2026-06-16 11:04:32,354] Trial 17 finished with value: 1.5756099493987992 and parameters: {'iterations': 1293, 'learning_rate': 0.11030922415732927, 'depth': 5, 'l2_leaf_reg': 6.310234510379289, 'random_strength': 18.899261720712776, 'bagging_temperature': 0.09250832633413353, 'border_count': 214, 'rsm': 0.7590001129941495}. Best is trial 16 with value: 1.526255173547653.
# [I 2026-06-16 11:04:37,146] Trial 18 pruned.
# [I 2026-06-16 11:05:14,728] Trial 19 finished with value: 1.5333823380534817 and parameters: {'iterations': 1014, 'learning_rate': 0.11049280563666074, 'depth': 5, 'l2_leaf_reg': 184.08353316488558, 'random_strength': 4.602629158800258, 'bagging_temperature': 0.4294604661156226, 'border_count': 221, 'rsm': 0.6688961272537146}. Best is trial 16 with value: 1.526255173547653.
# [I 2026-06-16 11:05:55,297] Trial 20 finished with value: 1.5411297356070444 and parameters: {'iterations': 1169, 'learning_rate': 0.07044915322505144, 'depth': 5, 'l2_leaf_reg': 185.3722785618308, 'random_strength': 4.319475975404209, 'bagging_temperature': 5.422691312030581, 'border_count': 186, 'rsm': 0.6541007647373536}. Best is trial 16 with value: 1.526255173547653.
# [I 2026-06-16 11:06:37,497] Trial 21 finished with value: 1.527127521911034 and parameters: {'iterations': 683, 'learning_rate': 0.09015081983210568, 'depth': 5, 'l2_leaf_reg': 64.61626707247196, 'random_strength': 3.6517060710579106, 'bagging_temperature': 0.11756846269375226, 'border_count': 224, 'rsm': 0.8080117575026263}. Best is trial 16 with value: 1.526255173547653.
# [I 2026-06-16 11:06:47,925] Trial 22 pruned.
# [I 2026-06-16 11:07:52,398] Trial 23 finished with value: 1.5506536995373743 and parameters: {'iterations': 794, 'learning_rate': 0.08124576542639862, 'depth': 6, 'l2_leaf_reg': 111.68975521481208, 'random_strength': 3.9130673715987236, 'bagging_temperature': 4.938208082368668, 'border_count': 201, 'rsm': 0.6802124739913501}. Best is trial 16 with value: 1.526255173547653.
# [I 2026-06-16 11:08:05,004] Trial 24 finished with value: 1.525240511062372 and parameters: {'iterations': 965, 'learning_rate': 0.02488358235034913, 'depth': 3, 'l2_leaf_reg': 13.940488608237223, 'random_strength': 2.3866766481535926, 'bagging_temperature': 0.23865134956553166, 'border_count': 18, 'rsm': 0.7487681905680806}. Best is trial 24 with value: 1.525240511062372.
# [I 2026-06-16 11:08:12,986] Trial 25 pruned.
# [I 2026-06-16 11:08:21,011] Trial 26 pruned.
# [I 2026-06-16 11:08:34,325] Trial 27 finished with value: 1.5299667388050657 and parameters: {'iterations': 1512, 'learning_rate': 0.027952828721620648, 'depth': 3, 'l2_leaf_reg': 13.085608408364035, 'random_strength': 5.295620157481149, 'bagging_temperature': 0.03311816680049651, 'border_count': 28, 'rsm': 0.7469442022363458}. Best is trial 24 with value: 1.525240511062372.
# [I 2026-06-16 11:08:59,380] Trial 28 finished with value: 1.5477805948375702 and parameters: {'iterations': 2044, 'learning_rate': 0.0571895567494265, 'depth': 4, 'l2_leaf_reg': 39.069442218003985, 'random_strength': 8.436540388474608, 'bagging_temperature': 1.9092836575265624, 'border_count': 154, 'rsm': 0.8560812872175948}. Best is trial 24 with value: 1.525240511062372.
# [I 2026-06-16 11:09:11,185] Trial 29 pruned.
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\dev\weather-research\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(

# %%
exported_weights = export_station_model_weights(
    project_root=PROJECT_ROOT,
    station_id=STATION_ID,
    artifact_dir=config.resolved_output_dir(),
    model_version=MODEL_VERSION,
    timing_mode=config.timing_mode,
    providers=tuple(config.providers),
    feature_version=config.effective_feature_version,
    optuna_metric=config.effective_optuna_metric,
    target_mode=config.effective_target_mode,
    source_pipeline="notebooks/station_stacking_v9",
)

exported_weights.bundle_path, exported_weights.manifest_path

# %% [markdown]
# ## V9 Feature Coverage

# %%
v9_feature_coverage = (
    result.features[V9_FEATURE_COLUMNS]
    .notna()
    .mean()
    .mul(100)
    .sort_values(ascending=False)
    .rename("coverage_pct")
    .reset_index()
    .rename(columns={"index": "feature"})
)

v9_feature_coverage

# %%
result.feature_columns.loc[result.feature_columns["feature"].isin(V9_FEATURE_COLUMNS)]

# %% [markdown]
# ## Dropped Feature Check

# %%
dropped_present = result.feature_columns.loc[
    result.feature_columns["feature"].isin(V9_DROPPED_FEATURE_COLUMNS)
]

dropped_present

# %% [markdown]
# ## Morning Trend Coverage

# %%
trend_coverage = (
    result.features[TREND_COLUMNS]
    .notna()
    .mean()
    .mul(100)
    .sort_values(ascending=False)
    .rename("coverage_pct")
    .reset_index()
    .rename(columns={"index": "feature"})
)

trend_coverage

# %% [markdown]
# ## Rounded Within 1F Accuracy

# %%
preds = pd.concat(
    [
        result.validation_predictions.assign(period="validation_2024_2025"),
        result.test_predictions.assign(period="oof_2026"),
    ],
    ignore_index=True,
)

predicted_high = pd.to_numeric(preds["predicted_high_f"], errors="coerce")
preds["predicted_high_rounded_f"] = np.floor(predicted_high + 0.5)
preds["within_1f_after_round"] = (
    pd.to_numeric(preds["actual_high_f"], errors="coerce") - preds["predicted_high_rounded_f"]
).abs().le(1)

within_1f_accuracy_by_period = (
    preds
    .dropna(subset=["actual_high_f", "predicted_high_rounded_f"])
    .groupby(["period", "method"], as_index=False)
    .agg(
        count=("within_1f_after_round", "size"),
        within_1f_count=("within_1f_after_round", "sum"),
        within_1f_accuracy_pct=("within_1f_after_round", lambda x: x.mean() * 100),
    )
    .sort_values(["period", "within_1f_accuracy_pct"], ascending=[True, False])
)

within_1f_accuracy_by_period

# %% [markdown]
# ## Version Comparison

# %%
comparison_frames = []
for version, folder in [
    ("v1", PROJECT_ROOT / "data" / "calibration" / "station_stacking"),
    ("v2", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v2"),
    ("v3", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v3"),
    ("v4", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v4"),
    ("v5", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v5"),
    ("v6", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v6"),
    ("v7", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v7"),
    ("v8", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v8"),
    ("v9", PROJECT_ROOT / "data" / "calibration" / "station_stacking_v9"),
]:
    path = folder / f"{STATION_ID}_year_split_scoreboard.csv"
    if path.exists():
        frame = pd.read_csv(path)
        frame["version"] = version
        comparison_frames.append(frame)

version_comparison = pd.concat(comparison_frames, ignore_index=True) if comparison_frames else pd.DataFrame()
if not version_comparison.empty:
    version_comparison = version_comparison.sort_values(["period", "mae_f", "version", "method"]).reset_index(drop=True)
version_comparison

# %% [markdown]
# ## 2026 OOF Weather Brackets

# %%
result.bracket_metrics
